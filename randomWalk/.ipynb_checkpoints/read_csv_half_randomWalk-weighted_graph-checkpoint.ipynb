# %% [markdown]
# ### Data extraction
# Extract data from MIMIC-III

# %%
import time
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Import pandas 
import pandas as pd 

start = time.time()
# reading csv file 
admissions_df = pd.read_csv("../../datasets/mmc-3/ADMISSIONS.csv")
noteevents_df = pd.read_csv("../../datasets/mmc-3/NOTEEVENTS.csv") 
end = time.time()
print(end - start)
# Out:
# /home/evan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning:
#
# Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
# 32.265886306762695

# %%
start = time.time()
# Left join of two dataframes
note_admiss_df_left = noteevents_df.merge(admissions_df, on='HADM_ID', how='left', indicator=True)
end = time.time()
print(end - start)
# Out:
# 5.822153568267822

# %%
note_admiss_df_left[['DIAGNOSIS', 'SUBJECT_ID_x', 'SUBJECT_ID_y','DESCRIPTION', 'CATEGORY']]
# Out:
#                                      DIAGNOSIS  SUBJECT_ID_x  SUBJECT_ID_y  \
# 0                      RT LOWER LOBE PNEUMONIA         22532       22532.0
# 1        CHRONIC OBSTRUCTIVE PULMONARY DISEASE         13702       13702.0
# 2                TRACHEALBRONCHEAL MALACEA/SDA         13702       13702.0
# 3                     ASTHMA;COPD EXACERBATION         13702       13702.0
# 4                           S/P FALL;TELEMETRY         26880       26880.0
# ...                                        ...           ...           ...
# 2083175                                NEWBORN         31097       31097.0
# 2083176                                NEWBORN         31097       31097.0
# 2083177                                NEWBORN         31097       31097.0
# 2083178                                NEWBORN         31097       31097.0
# 2083179                                NEWBORN         31097       31097.0
#
#         DESCRIPTION           CATEGORY
# 0            Report  Discharge summary
# 1            Report  Discharge summary
# 2            Report  Discharge summary
# 3            Report  Discharge summary
# 4            Report  Discharge summary
# ...             ...                ...
# 2083175      Report      Nursing/other
# 2083176      Report      Nursing/other
# 2083177      Report      Nursing/other
# 2083178      Report      Nursing/other
# 2083179      Report      Nursing/other
#
# [2083180 rows x 5 columns]

# %%
pneumonia_df = note_admiss_df_left.loc[note_admiss_df_left["DIAGNOSIS"] == 'PNEUMONIA', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]

# %%
#pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]
pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x','SUBJECT_ID_x','CHARTDATE','STORETIME','CATEGORY','DESCRIPTION','TEXT', 'DEATHTIME']]

# %%
pneumonia_alive_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.isnull()]
pneumonia_dead_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.notnull()]

# %%
pneumonia_dead_no_disch.shape
# Out:
# (11895, 8)

# %%
pneumonia_alive_no_disch.shape
# Out:
# (46134, 8)

# %%
pneumonia_alive_no_disch = pneumonia_alive_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])
pneumonia_dead_no_disch = pneumonia_dead_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])

# %%
# Number of patients
pneumonia_dead_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 252

# %%
# Number of patients
pneumonia_alive_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 1167

# %%
# import text handling tool
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from collections import Counter

import sys
import re
import csv
import os.path

# define constants
# RESULT_HEADER = "WORD, FREQUENCY\n"
MIN_SEQ_LEN = 4
USE_1_N_SEQ = 2


# words that do not have meaning (can be modified later)
USELESS_WORDS = ["a", "the", "he", "she", ",", ".", "?", "!", ":", ";", "+", "*", "**"\
                 "your", "you"]

# count up the frequency of every word in every disease file
stemmer = PorterStemmer()
# create set of words to ignore in text
stop_words = set(stopwords.words('english'))

for word in USELESS_WORDS:
    stop_words.add(word)

# %%
#----------
def count_notes_per_patient(disease_df):
    patient_id_to_num_notes = {}
    patient_id = -1
    note_counter = 0
            
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        patient_id_check = int(row['SUBJECT_ID_x'])
                
        if not patient_id == patient_id_check:
            patient_id_to_num_notes[patient_id] = note_counter
            note_counter = 1
        else:
            note_counter += 1
                    
        patient_id = patient_id_check
                
    patient_id_to_num_notes[patient_id] = note_counter
    del patient_id_to_num_notes[-1]
    return patient_id_to_num_notes

patient_id_to_num_notes = {}
patient_id_to_num_notes['pneumonia_dead'] = count_notes_per_patient(pneumonia_dead_no_disch)
patient_id_to_num_notes['pneumonia_alive'] = count_notes_per_patient(pneumonia_alive_no_disch)
# Out:
# 100%|██████████| 11895/11895 [00:01<00:00, 8184.05it/s]
# 100%|██████████| 46134/46134 [00:04<00:00, 9901.74it/s]

# %%
patient_id_to_num_notes
# Out:
# {'pneumonia_dead': {111: 12,
#   346: 25,
#   404: 3,
#   546: 6,
#   618: 16,
#   705: 15,
#   726: 48,
#   1039: 55,
#   1556: 37,
#   1872: 3,
#   1944: 56,
#   2286: 69,
#   2990: 166,
#   3055: 29,
#   3099: 13,
#   3201: 8,
#   3526: 7,
#   3773: 6,
#   3881: 20,
#   4122: 51,
#   4754: 101,
#   4811: 21,
#   5476: 1,
#   5494: 22,
#   5774: 104,
#   5786: 152,
#   5913: 1,
#   6133: 68,
#   6735: 13,
#   6745: 13,
#   6973: 36,
#   6981: 8,
#   7277: 66,
#   7310: 8,
#   7924: 9,
#   7977: 9,
#   9908: 11,
#   9984: 15,
#   10302: 100,
#   10510: 86,
#   10545: 10,
#   10642: 10,
#   11049: 14,
#   11209: 9,
#   11395: 41,
#   12530: 24,
#   12849: 50,
#   13098: 46,
#   13566: 23,
#   14125: 9,
#   14514: 96,
#   14965: 25,
#   15159: 15,
#   15251: 11,
#   15396: 17,
#   15566: 37,
#   15853: 45,
#   16275: 17,
#   16344: 27,
#   16622: 51,
#   16684: 29,
#   17122: 16,
#   17354: 5,
#   17802: 64,
#   17983: 65,
#   18094: 23,
#   18736: 35,
#   18768: 46,
#   18848: 205,
#   18971: 26,
#   19243: 25,
#   19323: 6,
#   19390: 21,
#   19463: 20,
#   19535: 59,
#   19754: 13,
#   19827: 22,
#   19833: 58,
#   19872: 10,
#   20006: 8,
#   20023: 9,
#   20190: 6,
#   21046: 101,
#   21094: 36,
#   21427: 10,
#   21502: 102,
#   21580: 52,
#   21676: 12,
#   21699: 7,
#   21979: 11,
#   22735: 15,
#   23660: 12,
#   23795: 78,
#   24181: 13,
#   24582: 37,
#   24725: 57,
#   24730: 19,
#   24854: 25,
#   25003: 182,
#   25046: 7,
#   25774: 61,
#   25975: 9,
#   26474: 89,
#   26578: 15,
#   26716: 41,
#   26774: 3,
#   26849: 33,
#   27005: 5,
#   27145: 24,
#   27421: 61,
#   27431: 5,
#   27496: 7,
#   27504: 72,
#   27639: 221,
#   28004: 13,
#   28072: 34,
#   28178: 202,
#   28427: 6,
#   28498: 25,
#   28726: 34,
#   28750: 19,
#   28906: 32,
#   28907: 13,
#   28933: 394,
#   29105: 468,
#   29588: 72,
#   29647: 26,
#   29872: 225,
#   30476: 174,
#   30549: 12,
#   30614: 8,
#   30699: 14,
#   30786: 9,
#   30941: 110,
#   31030: 168,
#   31134: 24,
#   31139: 9,
#   31451: 48,
#   31556: 57,
#   31690: 18,
#   31692: 35,
#   32050: 34,
#   32326: 24,
#   32618: 42,
#   41546: 25,
#   43937: 6,
#   44851: 274,
#   45381: 16,
#   46589: 26,
#   46763: 6,
#   47045: 9,
#   48632: 147,
#   49079: 20,
#   49683: 3,
#   49922: 13,
#   50093: 8,
#   50231: 3,
#   50556: 216,
#   50859: 537,
#   51914: 313,
#   52010: 12,
#   53105: 115,
#   53399: 78,
#   54193: 85,
#   54401: 14,
#   54408: 2,
#   54739: 75,
#   54946: 7,
#   55400: 5,
#   55570: 14,
#   55887: 37,
#   55944: 34,
#   55987: 20,
#   56390: 19,
#   56648: 8,
#   56854: 170,
#   57091: 88,
#   57102: 35,
#   58702: 479,
#   59260: 11,
#   59437: 26,
#   60849: 2,
#   60868: 6,
#   61652: 7,
#   61667: 30,
#   63039: 8,
#   65513: 8,
#   68044: 40,
#   68095: 23,
#   68184: 5,
#   68308: 8,
#   68860: 14,
#   69719: 13,
#   69745: 25,
#   69776: 17,
#   70226: 8,
#   70447: 9,
#   72930: 11,
#   73811: 9,
#   73888: 109,
#   74316: 2,
#   74444: 81,
#   74686: 75,
#   75824: 10,
#   76282: 21,
#   76827: 2,
#   77382: 10,
#   78241: 3,
#   78388: 14,
#   79008: 27,
#   79055: 21,
#   79222: 18,
#   79877: 156,
#   80637: 148,
#   80678: 9,
#   80737: 46,
#   80805: 79,
#   81437: 27,
#   82393: 5,
#   82769: 85,
#   83932: 2,
#   84474: 34,
#   85160: 8,
#   85258: 52,
#   85404: 11,
#   85797: 9,
#   86007: 35,
#   86394: 4,
#   86684: 11,
#   86832: 67,
#   86863: 8,
#   86872: 326,
#   88193: 16,
#   88660: 11,
#   90256: 18,
#   91350: 19,
#   92074: 28,
#   92278: 52,
#   92331: 42,
#   93422: 7,
#   94341: 2,
#   94997: 9,
#   95280: 23,
#   95803: 18,
#   95830: 33,
#   95933: 56,
#   96699: 85,
#   97181: 30,
#   97795: 60,
#   98009: 33,
#   98299: 29,
#   98597: 2},
#  'pneumonia_alive': {68: 18,
#   85: 8,
#   94: 100,
#   165: 2,
#   211: 24,
#   224: 8,
#   231: 75,
#   283: 131,
#   357: 17,
#   368: 45,
#   370: 13,
#   384: 26,
#   426: 10,
#   509: 34,
#   514: 7,
#   596: 23,
#   674: 16,
#   707: 29,
#   711: 537,
#   770: 83,
#   773: 74,
#   899: 17,
#   1096: 17,
#   1135: 32,
#   1163: 12,
#   1174: 42,
#   1180: 5,
#   1283: 3,
#   1332: 66,
#   1339: 134,
#   1546: 21,
#   1568: 22,
#   1601: 12,
#   1606: 13,
#   1642: 4,
#   1660: 23,
#   1895: 22,
#   1923: 23,
#   2029: 175,
#   2090: 179,
#   2098: 26,
#   2128: 31,
#   2170: 9,
#   2187: 30,
#   2208: 139,
#   2337: 8,
#   2378: 57,
#   2386: 18,
#   2452: 22,
#   2508: 22,
#   2561: 126,
#   2585: 9,
#   2589: 92,
#   2590: 5,
#   2628: 218,
#   2658: 16,
#   2732: 12,
#   2784: 23,
#   2823: 21,
#   3070: 8,
#   3100: 70,
#   3154: 22,
#   3220: 28,
#   3277: 35,
#   3347: 15,
#   3359: 15,
#   3516: 11,
#   3602: 18,
#   3623: 116,
#   3641: 57,
#   3676: 49,
#   3830: 80,
#   3860: 203,
#   3862: 22,
#   3865: 8,
#   3895: 6,
#   3935: 44,
#   3952: 20,
#   3975: 34,
#   4109: 9,
#   4155: 23,
#   4236: 14,
#   4275: 45,
#   4316: 13,
#   4317: 106,
#   4328: 23,
#   4388: 14,
#   4454: 5,
#   4467: 12,
#   4489: 21,
#   4494: 18,
#   4584: 39,
#   4588: 80,
#   4641: 23,
#   4694: 19,
#   4804: 6,
#   5030: 49,
#   5145: 9,
#   5244: 113,
#   5264: 115,
#   5360: 19,
#   5434: 24,
#   5476: 36,
#   5516: 31,
#   5536: 21,
#   5564: 30,
#   5579: 14,
#   5609: 39,
#   5619: 25,
#   5631: 9,
#   5681: 9,
#   5691: 12,
#   5727: 41,
#   5761: 85,
#   5819: 19,
#   5904: 16,
#   5937: 61,
#   6038: 4,
#   6143: 15,
#   6176: 5,
#   6183: 17,
#   6206: 7,
#   6279: 20,
#   6378: 112,
#   6398: 11,
#   6557: 16,
#   6603: 15,
#   6884: 43,
#   6901: 8,
#   6915: 190,
#   7107: 230,
#   7169: 9,
#   7271: 117,
#   7356: 12,
#   7363: 284,
#   7492: 58,
#   7569: 32,
#   7603: 39,
#   7666: 9,
#   7700: 68,
#   7787: 18,
#   7849: 96,
#   7936: 3,
#   8070: 69,
#   8312: 29,
#   8337: 22,
#   8366: 25,
#   8471: 15,
#   8512: 16,
#   8515: 21,
#   8532: 9,
#   8556: 71,
#   8803: 4,
#   8895: 10,
#   8900: 11,
#   9124: 18,
#   9128: 2,
#   9253: 76,
#   9304: 12,
#   9332: 7,
#   9457: 6,
#   9505: 2,
#   9518: 80,
#   9544: 228,
#   9727: 37,
#   9736: 19,
#   9859: 12,
#   9871: 17,
#   9957: 15,
#   9973: 59,
#   10057: 144,
#   10207: 36,
#   10299: 167,
#   10304: 8,
#   10377: 125,
#   10502: 9,
#   10581: 11,
#   10589: 18,
#   10626: 72,
#   10635: 6,
#   10666: 84,
#   10675: 13,
#   10761: 9,
#   10830: 14,
#   10848: 16,
#   10950: 23,
#   11003: 63,
#   11018: 24,
#   11061: 11,
#   11065: 40,
#   11197: 14,
#   11236: 58,
#   11247: 6,
#   11275: 26,
#   11313: 9,
#   11320: 66,
#   11421: 37,
#   11446: 13,
#   11593: 19,
#   11616: 64,
#   11671: 14,
#   11702: 7,
#   11708: 44,
#   11747: 20,
#   11762: 10,
#   11829: 25,
#   11850: 23,
#   11860: 11,
#   11932: 18,
#   11989: 17,
#   12028: 221,
#   12140: 36,
#   12177: 53,
#   12183: 26,
#   12274: 9,
#   12312: 13,
#   12380: 45,
#   12508: 136,
#   12567: 61,
#   12585: 4,
#   12629: 43,
#   12633: 11,
#   12799: 77,
#   12803: 21,
#   12824: 21,
#   13123: 10,
#   13329: 22,
#   13330: 13,
#   13503: 15,
#   13546: 20,
#   13577: 7,
#   13593: 20,
#   13615: 10,
#   13627: 31,
#   13664: 120,
#   13728: 13,
#   13748: 21,
#   13864: 5,
#   13881: 2,
#   14035: 12,
#   14144: 24,
#   14172: 9,
#   14193: 8,
#   14256: 26,
#   14269: 21,
#   14309: 13,
#   14342: 20,
#   14385: 14,
#   14507: 9,
#   14520: 56,
#   14705: 17,
#   14805: 16,
#   14855: 96,
#   14975: 23,
#   15046: 86,
#   15054: 33,
#   15301: 5,
#   15347: 4,
#   15361: 15,
#   15472: 13,
#   15590: 85,
#   15716: 323,
#   15852: 15,
#   15875: 192,
#   16038: 89,
#   16053: 17,
#   16076: 397,
#   16102: 6,
#   16129: 22,
#   16147: 7,
#   16216: 17,
#   16275: 90,
#   16318: 12,
#   16367: 47,
#   16384: 48,
#   16409: 40,
#   16412: 8,
#   16438: 28,
#   16468: 15,
#   16469: 20,
#   16479: 7,
#   16492: 6,
#   16554: 19,
#   16560: 8,
#   16685: 1,
#   16733: 14,
#   16755: 24,
#   16800: 12,
#   16802: 27,
#   16850: 14,
#   16975: 186,
#   16992: 42,
#   17107: 6,
#   17149: 17,
#   17150: 23,
#   17250: 28,
#   17260: 10,
#   17276: 10,
#   17539: 24,
#   17547: 9,
#   17617: 4,
#   17631: 19,
#   17664: 24,
#   17722: 8,
#   17764: 3,
#   17795: 215,
#   17843: 37,
#   17882: 6,
#   17903: 7,
#   17906: 88,
#   18082: 22,
#   18123: 146,
#   18233: 8,
#   18250: 2,
#   18281: 61,
#   18320: 207,
#   18353: 16,
#   18365: 10,
#   18459: 33,
#   18637: 35,
#   18673: 38,
#   18681: 10,
#   18737: 7,
#   18999: 40,
#   19029: 4,
#   19036: 12,
#   19164: 20,
#   19463: 14,
#   19569: 4,
#   19653: 30,
#   19698: 79,
#   19793: 37,
#   19803: 9,
#   19833: 77,
#   19851: 83,
#   19859: 14,
#   19940: 9,
#   20061: 7,
#   20086: 85,
#   20133: 121,
#   20181: 204,
#   20187: 25,
#   20263: 6,
#   20265: 7,
#   20289: 63,
#   20381: 10,
#   20425: 103,
#   20528: 37,
#   20580: 1,
#   20598: 31,
#   20600: 16,
#   20624: 32,
#   20643: 20,
#   20804: 25,
#   20899: 17,
#   20951: 8,
#   20979: 26,
#   21037: 21,
#   21056: 9,
#   21093: 60,
#   21255: 3,
#   21269: 279,
#   21277: 23,
#   21301: 16,
#   21350: 18,
#   21548: 7,
#   21581: 11,
#   21737: 7,
#   21745: 5,
#   21764: 7,
#   22019: 2,
#   22180: 5,
#   22192: 5,
#   22287: 10,
#   22432: 6,
#   22450: 11,
#   22520: 63,
#   22534: 4,
#   22580: 10,
#   22624: 43,
#   22667: 72,
#   22684: 14,
#   22706: 8,
#   22754: 44,
#   22855: 47,
#   22921: 2,
#   23028: 22,
#   23109: 2,
#   23131: 49,
#   23161: 29,
#   23215: 9,
#   23318: 15,
#   23418: 22,
#   23423: 11,
#   23451: 26,
#   23568: 8,
#   23657: 34,
#   23734: 15,
#   23763: 21,
#   23847: 9,
#   24099: 2,
#   24170: 2,
#   24178: 209,
#   24276: 82,
#   24344: 290,
#   24483: 7,
#   24535: 23,
#   24562: 10,
#   24569: 20,
#   24622: 1,
#   24687: 45,
#   24807: 41,
#   24847: 12,
#   24868: 57,
#   24903: 45,
#   25001: 25,
#   25016: 78,
#   25038: 66,
#   25097: 42,
#   25117: 38,
#   25225: 17,
#   25256: 30,
#   25295: 59,
#   25326: 17,
#   25373: 158,
#   25406: 5,
#   25515: 18,
#   25526: 86,
#   25579: 27,
#   25591: 61,
#   25671: 11,
#   25750: 107,
#   25775: 38,
#   25844: 22,
#   25860: 9,
#   25861: 16,
#   25889: 20,
#   25941: 86,
#   26036: 11,
#   26040: 79,
#   26052: 3,
#   26080: 5,
#   26097: 65,
#   26118: 60,
#   26311: 28,
#   26391: 64,
#   26398: 14,
#   26469: 52,
#   26542: 55,
#   26601: 58,
#   26638: 155,
#   26727: 10,
#   26797: 8,
#   26869: 11,
#   26884: 5,
#   26887: 4,
#   26956: 23,
#   27003: 18,
#   27036: 10,
#   27043: 30,
#   27047: 41,
#   27049: 14,
#   27089: 24,
#   27121: 89,
#   27143: 135,
#   27172: 9,
#   27179: 118,
#   27194: 60,
#   27269: 19,
#   27367: 84,
#   27371: 17,
#   27431: 33,
#   27486: 2,
#   27576: 84,
#   27597: 60,
#   27600: 28,
#   27677: 11,
#   27726: 59,
#   27729: 70,
#   27752: 11,
#   27800: 12,
#   27809: 18,
#   27823: 31,
#   27879: 13,
#   27886: 30,
#   27999: 25,
#   28050: 20,
#   28055: 4,
#   28073: 74,
#   28093: 21,
#   28103: 16,
#   28164: 159,
#   28173: 124,
#   28230: 23,
#   28291: 36,
#   28298: 31,
#   28356: 10,
#   28527: 46,
#   28530: 24,
#   28642: 2,
#   28668: 3,
#   28671: 33,
#   28689: 5,
#   28717: 23,
#   28729: 73,
#   28742: 7,
#   28758: 94,
#   28827: 12,
#   28843: 1,
#   28884: 12,
#   28932: 24,
#   28935: 4,
#   28939: 4,
#   28973: 152,
#   29007: 9,
#   29043: 12,
#   29093: 5,
#   29096: 21,
#   29102: 18,
#   29129: 15,
#   29137: 8,
#   29139: 17,
#   29141: 27,
#   29219: 19,
#   29240: 10,
#   29274: 17,
#   29350: 18,
#   29377: 80,
#   29379: 21,
#   29456: 22,
#   29478: 32,
#   29501: 6,
#   29503: 11,
#   29504: 18,
#   29513: 65,
#   29528: 5,
#   29556: 5,
#   29566: 17,
#   29619: 18,
#   29638: 15,
#   29639: 26,
#   29660: 9,
#   29703: 12,
#   29866: 12,
#   29872: 14,
#   29913: 11,
#   29919: 24,
#   29927: 63,
#   29965: 26,
#   29972: 7,
#   30010: 7,
#   30015: 36,
#   30139: 529,
#   30208: 18,
#   30227: 35,
#   30287: 23,
#   30299: 1,
#   30301: 117,
#   30316: 17,
#   30365: 47,
#   30490: 17,
#   30501: 10,
#   30505: 33,
#   30561: 6,
#   30575: 6,
#   30599: 24,
#   30631: 11,
#   30663: 24,
#   30696: 54,
#   30786: 11,
#   30798: 14,
#   30860: 28,
#   31003: 45,
#   31183: 129,
#   31216: 80,
#   31221: 17,
#   31262: 28,
#   31298: 13,
#   31332: 59,
#   31361: 20,
#   31442: 32,
#   31470: 17,
#   31516: 74,
#   31528: 60,
#   31544: 11,
#   31580: 34,
#   31585: 39,
#   31610: 17,
#   31660: 3,
#   31664: 45,
#   31692: 23,
#   31723: 17,
#   31813: 234,
#   31942: 102,
#   31986: 41,
#   32018: 145,
#   32061: 11,
#   32106: 18,
#   32135: 12,
#   32161: 25,
#   32181: 8,
#   32183: 27,
#   32193: 16,
#   32268: 6,
#   32286: 117,
#   32355: 6,
#   32367: 42,
#   32394: 6,
#   32414: 485,
#   32436: 271,
#   32583: 5,
#   32605: 19,
#   32639: 12,
#   32740: 48,
#   32746: 11,
#   32773: 112,
#   32790: 103,
#   40059: 11,
#   40124: 68,
#   40246: 20,
#   40370: 11,
#   40442: 107,
#   40456: 43,
#   40576: 48,
#   40631: 4,
#   40911: 35,
#   41192: 45,
#   41373: 28,
#   41434: 10,
#   41446: 8,
#   41890: 7,
#   41958: 5,
#   41962: 10,
#   41976: 177,
#   42009: 30,
#   42035: 49,
#   42054: 18,
#   42194: 1,
#   42346: 30,
#   42458: 9,
#   42515: 38,
#   42572: 17,
#   42715: 21,
#   42794: 6,
#   42924: 3,
#   43067: 90,
#   43074: 18,
#   43112: 394,
#   43128: 1,
#   43147: 150,
#   43305: 48,
#   43323: 15,
#   43937: 4,
#   43943: 6,
#   43959: 3,
#   44146: 16,
#   44206: 5,
#   44214: 30,
#   44326: 8,
#   44437: 12,
#   44530: 2,
#   44534: 37,
#   44741: 8,
#   44787: 7,
#   44829: 55,
#   44841: 19,
#   44848: 2,
#   45193: 11,
#   45280: 9,
#   45435: 7,
#   46011: 61,
#   46335: 49,
#   46366: 42,
#   46415: 53,
#   46521: 14,
#   46728: 34,
#   46926: 1,
#   46961: 1,
#   47216: 17,
#   47219: 67,
#   47407: 2,
#   47467: 6,
#   47670: 7,
#   47747: 12,
#   47852: 95,
#   47930: 5,
#   48058: 4,
#   48143: 6,
#   48297: 11,
#   48340: 7,
#   48660: 343,
#   48687: 15,
#   48750: 8,
#   48812: 36,
#   48837: 14,
#   48929: 7,
#   49292: 18,
#   49510: 31,
#   49558: 347,
#   49623: 9,
#   49747: 7,
#   49764: 10,
#   49963: 4,
#   50007: 4,
#   50041: 10,
#   50093: 6,
#   50257: 11,
#   50294: 20,
#   50409: 75,
#   50762: 8,
#   50772: 17,
#   50807: 21,
#   50828: 126,
#   50911: 81,
#   50998: 29,
#   51195: 29,
#   51237: 11,
#   51401: 33,
#   51418: 68,
#   51497: 3,
#   51545: 97,
#   51601: 5,
#   51607: 5,
#   51669: 10,
#   51933: 5,
#   52011: 8,
#   52054: 1,
#   52172: 13,
#   52191: 46,
#   52307: 5,
#   52452: 5,
#   52606: 54,
#   52622: 5,
#   52898: 6,
#   52957: 52,
#   53119: 7,
#   53160: 13,
#   53173: 14,
#   53534: 9,
#   53650: 15,
#   53743: 151,
#   53749: 6,
#   53847: 14,
#   54172: 6,
#   54197: 13,
#   54305: 8,
#   54514: 116,
#   54709: 9,
#   54741: 5,
#   54832: 7,
#   54922: 2,
#   55059: 17,
#   55074: 7,
#   55188: 9,
#   55571: 212,
#   55700: 4,
#   55753: 37,
#   55841: 14,
#   55920: 17,
#   56027: 7,
#   56229: 31,
#   56440: 9,
#   56490: 12,
#   56621: 11,
#   56635: 2,
#   56772: 31,
#   56798: 4,
#   56867: 16,
#   56874: 51,
#   57050: 205,
#   57081: 32,
#   57157: 5,
#   57277: 19,
#   57290: 15,
#   57449: 17,
#   57788: 36,
#   57795: 7,
#   57889: 105,
#   58105: 49,
#   58242: 6,
#   58264: 7,
#   58286: 20,
#   58416: 3,
#   58433: 51,
#   58522: 9,
#   58580: 5,
#   58610: 13,
#   58631: 15,
#   58732: 5,
#   58794: 32,
#   58810: 10,
#   58955: 6,
#   59275: 1,
#   59278: 17,
#   59411: 6,
#   59496: 75,
#   59765: 300,
#   59789: 10,
#   59801: 2,
#   59822: 14,
#   59903: 483,
#   59943: 121,
#   60003: 9,
#   60050: 4,
#   60130: 44,
#   60674: 10,
#   60685: 4,
#   60958: 8,
#   60977: 9,
#   61005: 10,
#   61084: 216,
#   61195: 9,
#   61259: 83,
#   61331: 4,
#   61630: 19,
#   61738: 6,
#   61886: 6,
#   62231: 4,
#   62239: 5,
#   62284: 6,
#   62402: 56,
#   62641: 8,
#   62733: 9,
#   62858: 120,
#   63145: 25,
#   63327: 16,
#   63351: 10,
#   63362: 7,
#   63430: 56,
#   63499: 32,
#   63560: 25,
#   63943: 31,
#   63968: 10,
#   64160: 4,
#   64232: 28,
#   64249: 7,
#   64715: 17,
#   65004: 11,
#   65027: 1,
#   65033: 2,
#   65164: 4,
#   65361: 20,
#   65435: 40,
#   65449: 6,
#   65515: 5,
#   65582: 576,
#   65594: 9,
#   65692: 25,
#   65710: 18,
#   65837: 47,
#   66002: 636,
#   66009: 373,
#   66206: 12,
#   66412: 5,
#   66492: 1,
#   66549: 36,
#   66556: 20,
#   66671: 32,
#   66739: 1,
#   66753: 8,
#   66823: 21,
#   67053: 238,
#   67111: 16,
#   67117: 19,
#   67408: 15,
#   67446: 8,
#   67796: 7,
#   67844: 7,
#   67887: 13,
#   68059: 3,
#   68315: 3,
#   68591: 7,
#   68791: 13,
#   68836: 7,
#   68839: 21,
#   68905: 3,
#   68944: 39,
#   68962: 1,
#   69098: 12,
#   69158: 13,
#   69250: 4,
#   69296: 13,
#   69359: 26,
#   69380: 265,
#   69483: 26,
#   69546: 64,
#   69556: 11,
#   69578: 7,
#   69673: 6,
#   69776: 53,
#   69799: 6,
#   69932: 6,
#   70285: 2,
#   70466: 18,
#   70476: 22,
#   70492: 10,
#   70563: 3,
#   70645: 29,
#   70682: 48,
#   70728: 12,
#   71107: 9,
#   71108: 220,
#   71220: 45,
#   71336: 5,
#   71377: 39,
#   71915: 6,
#   71943: 4,
#   71983: 3,
#   72229: 189,
#   72230: 154,
#   72233: 2,
#   72378: 7,
#   72532: 6,
#   72714: 4,
#   72751: 35,
#   73043: 3,
#   73107: 479,
#   73129: 105,
#   73388: 37,
#   73389: 87,
#   73479: 3,
#   73686: 4,
#   73713: 458,
#   73770: 9,
#   73808: 49,
#   73899: 2,
#   73941: 7,
#   74016: 8,
#   74253: 388,
#   74505: 32,
#   74562: 98,
#   74640: 7,
#   74654: 7,
#   75047: 3,
#   75107: 124,
#   75200: 87,
#   75387: 14,
#   75446: 34,
#   75609: 5,
#   75640: 45,
#   75741: 8,
#   75782: 90,
#   75806: 3,
#   75983: 9,
#   76021: 39,
#   76056: 1,
#   76074: 31,
#   76141: 4,
#   76178: 22,
#   76437: 5,
#   76446: 18,
#   76476: 3,
#   76797: 6,
#   76915: 8,
#   76993: 13,
#   77019: 8,
#   77128: 9,
#   77177: 14,
#   77237: 198,
#   77279: 2,
#   77434: 18,
#   77453: 2,
#   77469: 31,
#   77676: 4,
#   77690: 19,
#   77697: 10,
#   77816: 8,
#   77947: 11,
#   78017: 2,
#   78086: 110,
#   78565: 78,
#   78705: 3,
#   78707: 16,
#   78859: 5,
#   78914: 13,
#   79079: 18,
#   79090: 16,
#   79115: 12,
#   79292: 15,
#   80045: 6,
#   80106: 5,
#   80218: 13,
#   80430: 10,
#   80722: 3,
#   80813: 11,
#   80825: 3,
#   81114: 58,
#   81223: 39,
#   81233: 22,
#   81436: 9,
#   81745: 28,
#   81840: 25,
#   81960: 8,
#   81992: 11,
#   82100: 74,
#   82104: 2,
#   82150: 84,
#   82202: 28,
#   82211: 647,
#   82309: 9,
#   ...}}

# %%
print(len(patient_id_to_num_notes['pneumonia_dead']))
print(len(patient_id_to_num_notes['pneumonia_alive']))
# Out:
# 252
# 1167

# %%
pneumonia_dead_no_disch.loc[pneumonia_dead_no_disch["SUBJECT_ID_x"] == 111, ['ROW_ID_x','SUBJECT_ID_x','DESCRIPTION','TEXT', 'DEATHTIME']]
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 70391       70124           111
# 142529     151749           111
# 142097     151750           111
# 142303     151751           111
# 380576     375732           111
# 380109     375744           111
# 379907     375749           111
# 379806     375753           111
# 379909     375760           111
# 1066971   1079317           111
# 1065833   1079339           111
# 1067121   1079351           111
#
#                                                DESCRIPTION  \
# 70391                                               Report
# 142529                                              Report
# 142097                                              Report
# 142303                                              Report
# 380576                   Physician Resident Admission Note
# 380109                                      ICU Event Note
# 379907   Physician Resident/Attending Admission Note - ...
# 379806                          Social Work Admission Note
# 379909                                      ICU Event Note
# 1066971                                CHEST (PORTABLE AP)
# 1065833                                CHEST (PORTABLE AP)
# 1067121                         CHEST PORT. LINE PLACEMENT
#
#                                                       TEXT  \
# 70391    PATIENT/TEST INFORMATION:\nIndication: s/p PEA...
# 142529   Compared to the previous tracing QRS voltage i...
# 142097   Normal sinus rhythm, rate 80.  Biatrial abnorm...
# 142303   Normal sinus rhythm.  Q waves in leads V1-V2 c...
# 380576   Chief Complaint:  respiratory distress\n   HPI...
# 380109   Clinician:  Nurse\n   Pt admitted from the ED ...
# 379907   Chief Complaint:  respiratory distress\n   HPI...
# 379806   Social Work Initial Note:\n   Family Informati...
# 379909   TITLE:\n   Clinician:  Resident\n   Patient ex...
# 1066971  [**2144-7-1**] 2:43 AM\n CHEST (PORTABLE AP)  ...
# 1065833  [**2144-7-1**] 7:27 AM\n CHEST (PORTABLE AP); ...
# 1067121  [**2144-7-1**] 9:01 AM\n CHEST PORT. LINE PLAC...
#
#                    DEATHTIME
# 70391    2144-07-01 14:55:00
# 142529   2144-07-01 14:55:00
# 142097   2144-07-01 14:55:00
# 142303   2144-07-01 14:55:00
# 380576   2144-07-01 14:55:00
# 380109   2144-07-01 14:55:00
# 379907   2144-07-01 14:55:00
# 379806   2144-07-01 14:55:00
# 379909   2144-07-01 14:55:00
# 1066971  2144-07-01 14:55:00
# 1065833  2144-07-01 14:55:00
# 1067121  2144-07-01 14:55:00

# %%
def count_words_per_patient(disease_df, patient_id_to_num_notes):
    note_appearance_counter = {}
    number_of_patients = 0 # number of patients
    note_counter = 0

# -----------
    patient_id = -1
    word_set = set()
    note_event_counter = 0

    # Iterate through each note
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):

        
        patient_id_check = int(row['SUBJECT_ID_x'])
    
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check:
            number_of_patients += 1
            note_event_counter = 0
        
            for word in word_set:
                if word in note_appearance_counter:
                    note_appearance_counter[word] += 1
                else:
                    note_appearance_counter[word] = 1

        
            # reset word_set
            word_set = set()
        
        # update patient id
        patient_id = patient_id_check

            
        if patient_id_to_num_notes[patient_id_check] <= MIN_SEQ_LEN:
            continue
            
        if note_event_counter < patient_id_to_num_notes[patient_id] // USE_1_N_SEQ:
            note_event_counter += 1
            continue
                
        note_counter += 1
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        tokenized_note = word_tokenize(note)
        
        
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())
            if not stemmed_word in stop_words:
                word_set.add(stemmed_word)
    
    print(str(note_counter) + " note events")
    print("finished counting frequent words for patients!")
#     return note_counter, note_appearance_counter
    return number_of_patients, note_appearance_counter

# variable dictionaries
number_of_notes = {}
note_appearance_counter = {}

number_of_notes['pneumonia_dead'], note_appearance_counter['pneumonia_dead'] = count_words_per_patient(pneumonia_dead_no_disch, patient_id_to_num_notes['pneumonia_dead'])
number_of_notes['pneumonia_alive'], note_appearance_counter['pneumonia_alive'] = count_words_per_patient(pneumonia_alive_no_disch, patient_id_to_num_notes['pneumonia_alive'])
# Out:
# 100%|██████████| 11895/11895 [00:40<00:00, 292.80it/s]
#   0%|          | 24/46134 [00:00<03:23, 226.45it/s]
# 5989 note events
# finished counting frequent words for patients!
# 100%|██████████| 46134/46134 [02:30<00:00, 307.03it/s]
# 23172 note events
# finished counting frequent words for patients!

# %%
number_of_notes
# Out:
# {'pneumonia_dead': 252, 'pneumonia_alive': 1167}

# %%
print(note_appearance_counter)
# Out:
# {'pneumonia_dead': {'murmur': 42, 'artic': 2, 'venou': 99, 'meal': 10, 'elder': 1, 'bicarbon': 9, 'micu': 131, 'consolid': 110, 'scale': 61, 'cardiac': 156, 'stress': 66, 'sign': 110, 'hypovolemia': 12, 'resuscit': 44, 'albuterol': 58, 'pna': 151, 'evid': 141, 'ceftriaxon': 24, 'cough': 125, 'insulin': 80, 'upright': 57, 'transfus': 52, 'time': 188, 'pneumoboot': 25, 'took': 27, 'saw': 64, 'hyperinfl': 5, 'hypercapnia': 4, 'expir': 58, 'peep': 106, 'ct': 132, 'fluticason': 2, 'review': 135, 'lead': 83, 'prevent': 35, 'comparison': 166, 'clinic': 117, 'sbp': 114, 'code': 135, 'fluid': 183, 'well': 180, 'inr': 88, 'hpi': 58, 'impress': 176, 'hospit': 75, 'hypertens': 82, 'q': 136, 'mono': 43, 'taken': 60, 'person': 33, 'major': 40, 'superimpos': 56, 'fissur': 12, 'long': 58, 'clip': 175, 'jpg': 63, 'hepat': 27, 'morn': 93, 'b': 106, 'occup': 18, 'wa': 210, 'trend': 68, 'exclud': 72, 'unremark': 66, 'mandat': 6, 'daughter': 84, 'rij': 35, 'stool': 150, 'guard': 18, 'known': 85, 'clear': 163, 'po': 143, 'current': 158, 'spent': 65, 'dure': 114, 'u': 143, 'abg': 143, 'global': 31, 'simultan': 2, 'report': 205, 'veteran': 1, 'addit': 117, 'prepar': 21, 'provid': 114, 'may': 142, 'previous': 80, 'bipap': 43, 'hypotens': 131, 'mmhg': 71, 'bolus': 98, 'dx': 29, 'radiolog': 68, 'er': 19, 'densiti': 45, 'breath': 162, 'situat': 29, 'urin': 165, '<': 77, 'cage': 1, 'hco': 15, 'lactat': 47, 'bradi': 12, 'legal': 10, 'malign': 32, 'boot': 52, 'entir': 36, 'cv': 136, 'renal': 107, 'recommend': 82, 'would': 127, 'event': 121, 'bed': 103, 'bilater': 175, 'cm': 141, 'death': 42, 'diagnosi': 176, 'could': 111, 'unrespons': 78, 'tazo': 9, 'hi': 121, 'pleural': 176, 'flowsheet': 113, 'girlfriend': 2, 'acidosi': 70, 'e': 64, 'function': 95, 'friend': 32, 'anoth': 58, 'acid': 56, 'warfarin': 5, 'right': 211, 'degre': 47, 'copi': 13, 'clinician': 41, 'ventil': 129, "c'ed": 12, 'ipratropium': 6, 'arriv': 82, 'tf': 110, 'bowel': 151, 'lab': 132, 'rml': 18, 'k': 116, 'member': 57, 'recurr': 33, 'rebound': 8, 'qday': 4, 'distant': 27, 'block': 44, 'concern': 114, 'comment': 93, 'underli': 79, 'infus': 111, 'bicarb': 28, 'thi': 230, 'hematoma': 20, 'resid': 111, 'requir': 145, 'distend': 108, 'l': 171, 'plan': 161, 'sun': 14, 'chief': 63, 'arrest': 27, 'point': 75, 'privat': 7, 'obtain': 159, 'cultur': 100, 'ye': 42, 'emot': 68, 'peripher': 97, 'niec': 13, 'methylpr': 5, 'interv': 156, 'followup': 38, 'epi': 11, 'patient': 205, 'afternoon': 103, 'amp': 21, 'mg': 163, 'heart': 157, 'transient': 33, 'lung': 203, 'one': 117, 'cool': 67, 'glucos': 82, 'fio': 119, 'pneumothorax': 118, 'admiss': 88, 'ij': 79, 'serial': 23, 'access': 113, 'progress': 166, 'portabl': 178, 'ratio': 7, 'simvastatin': 4, 'ph': 61, 'fen': 44, 'drop': 120, 'balanc': 85, 'medic': 217, 'retrocardiac': 50, 'sulcu': 7, 'ml': 99, 'fall': 42, 'norepinephrin': 22, 'pericardi': 61, 'appropri': 101, 'intact': 103, 'also': 175, 'pneumonia': 203, 'protect': 61, 'check': 116, 'cpr': 32, 'anicter': 12, 'contact': 91, 'aggress': 62, '[': 80, 'meq': 92, 'attempt': 119, 'emphysema': 28, 'edema': 182, 'laundri': 1, 'nodular': 15, 'extrem': 141, 'hilar': 36, 'metabol': 52, 'vasopressin': 27, 'devic': 94, 'poor': 134, 'express': 42, 'rr': 150, 'hemodynam': 111, 'need': 155, 'unsuccess': 37, 'ed': 61, 'preren': 12, 'copd': 45, 'lvef': 38, 'glycem': 62, 'growth': 28, 'arch': 15, 'paralyt': 16, 'vital': 80, 'worsen': 162, 'r': 178, 'refractori': 8, 'empir': 36, 'anion': 8, 'vap': 72, 'icu': 108, 'stroke': 14, 'atropin': 8, 'promin': 65, 'work': 87, 'replet': 84, 'port': 83, 'electrolyt': 43, 'jvp': 18, 'phone': 47, 'tach': 21, 'defer': 39, 'place': 196, 'got': 28, 'consult': 99, 'mottl': 15, 'va': 11, 'second': 40, 'howev': 131, 'key': 61, 'verapamil': 2, 'brother': 29, 'ns': 119, 'system': 99, 'involv': 85, 'list': 25, 'insert': 61, 'dic': 20, 'azotemia': 6, 'calcium': 55, 'product': 99, 'nutrit': 85, 'differenti': 70, '#': 211, 'primari': 43, 'pedal': 41, 'evalu': 173, 'compar': 163, 'lipas': 16, 'addend ...

# %%
# # get hyper-paramters n_fold and threshold from user input
n_fold = float(3)
threshold = float(0.01)

frequent_word_lists = {}
factor = {}

# %%
"""function description:
for each disease in note_appearance_counter
    1. checks whether a word in disease file is frequent(frequency standard as defined by factor, n_fold, and threshold)
    2. adds to frequent_word_list
"""

# def find_frequent_word(note_appearance_counter, frequent_word_lists, number_of_notes, factor, n_fold, threshold):

# calculate normalizing factor for each disease
note_sum = 0

# Count from two labels
for disease in number_of_notes:
    note_sum += float(number_of_notes[disease])
    
for disease in number_of_notes:
    factor[disease] = number_of_notes[disease] / note_sum

# determine frequent word for each disease file
for disease in note_appearance_counter:
    frequent_word_lists[disease] = []

    print(disease + " has " + str(len(note_appearance_counter[disease])) + " unique words!")

    for word in note_appearance_counter[disease]:
        
        freq_check = True
        for check_disease in note_appearance_counter:
            
            if not disease == check_disease:
                if word in note_appearance_counter[check_disease]:
                    if not (note_appearance_counter[disease][word] / note_appearance_counter[check_disease][word] / factor[disease] * factor[check_disease] > n_fold \
                        and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):

                        freq_check = False
                        break

                else:
                    if not (note_appearance_counter[disease][word] > n_fold and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):
                        freq_check = False
                        break
        if freq_check:
            frequent_word_lists[disease].append((word))
            # Create a tuple of word and its count
#             frequent_word_lists[disease].append((word, note_appearance_counter[disease][word]))

        

print("finished making frequent words list for " + disease)
# Out:
# pneumonia_dead has 11678 unique words!
# pneumonia_alive has 22572 unique words!
# finished making frequent words list for pneumonia_alive

# %%
print(note_sum)
print(factor)

# number of notes
# 58029.0
# {'pneumonia_dead': 0.2049837150390322, 'pneumonia_alive': 0.7950162849609678}
# Out:
# 1419.0
# {'pneumonia_dead': 0.17758985200845667, 'pneumonia_alive': 0.8224101479915433}

# %%
print(len(frequent_word_lists['pneumonia_dead']))
print(len(frequent_word_lists['pneumonia_alive']))


# n_fold = float(3) threshold = float(0.01)
# 454
# 329

# n_fold = float(2) threshold = float(0.01)
# 914
# 600

# n_fold = float(1) threshold = float(0.01)
# 3320
# 2196
# Out:
# 454
# 329

# %%
print(frequent_word_lists)
# Out:
# {'pneumonia_dead': ['bicarbon', 'hypercapnia', 'expir', 'death', 'unrespons', 'clinician', 'arrest', 'norepinephrin', 'cpr', 'vasopressin', 'paralyt', 'refractori', 'mottl', 'dic', 'azotemia', 'phenylephrin', 'arrang', 'pea', 'recruit', 'suffer', 'park', 'pcv', 'funer', 'cremat', 'elig', 'acidem', 'anur', 'profound', 'autopeep', 'clergi', 'hypothermia', 'hypercapn', 'cmo', 'virtual', 'sluggish', 'dnr', 'dni', 'lubric', 'slough', 'pinpoint', 'gum', 'dk', 'nonpurpos', 'nacl', 'oder', 'float', 'levoph', 'mso', 'wish', 'clariti', 'option', 'pronounc', 'peerla', 'grim', 'prognosi', 'antb', 'suport', 'respon', 'bow', 'remin', 'priest', 'dead', 'institut', 'dd', 'purpl', 'viabl', 'hypotent', 'gather', 'mad', 'agreement', 'mortem', 'depth', 'aprv', 'life', 'asystol', 'centimet', 'bye', 'acv', 'synch', 'sync', 'chaplain', 'nrbm', 'mgx', 'duski', 'peac', 'througout', 'moniotr', 'ppn', 'hover', 'surviv', 'cathol', 'vtach', 'cvvh', 'quiac', 'defibril', 'pfr', 'rusti', 'acidot', 'agon', 'jerk', 'suppport', 'hemothorax', 'pulseless', 'cvvhdf', 'cvvhd', 'mortum', 'corneal', 'seriou', 'vasopressor', 'deliv', 'neosynephrin', 'deterior', 'crrt', 'maroon', 'mtg', 'hugger', 'multisystem', 'lw', 'cyanot', 'declin', 'pray', 'unequ', 'ffp', 'gratitud', 'scl', 'elimin', 'ethic', 'bair', 'ultrafiltr', 'quinton', 'among', 'spiritu', 'pitressin', 'levof', 'cooler', 'lc', 'cagluc', 'rewir', 'uffp', 'brb', 'hypotherm', 'towel', 'polymorph', 'chane', 'paco', 'neo', 'autopsi', 'absorb', 'promod', 'triadyn', 'morgu', 'syring', 'ashen', 'erythro', 'warmer', 'bond', 'nahco', 'zero', 'asynchron', 'rabbi', 'ran', 'discoordin', 'bank', 'sml', "tf'ing", 'motil', 'circuit', 'town', 'prayer', 'norepi', 'escal', 'bairhugg', 'discard', 'edt', 'hunger', 'mind', 'unstabl', 'gc', '^rr', 'rediscuss', 'dopamin', 'hung', 'polici', 'intiat', 'cantones', 'palli', 'moan', 'tacycard', 'acc', 'readdress', 'fliud', 'overlay', 'ozz', 'artifici', 'gurgl', 'anuria', 'inclus', 'proph', 'judgement', 'underneath', 'broader', 'recalibr', 'dobutamin', 'oncologist', 'hospic', 'platlet', 'adenosin', 'platelet', 'quadrent', 'oligur', 'gut', 'sorb', 'cellcept', 'griev', 'influenc', 'cardiovert', 'gvhd', 'anyway', 'core', 'psup', 'nephrolog', 'pheresi', 'kerlix', 'surgicel', 'hepati', 'oximetri', 'chemic', 'fentenyl', 'caspofungin', 'pose', 'repsons', 'fc', 'cisatracurium', 'extremitiy', 'ettub', 'grimmac', 'fungemia', 'premed', 'snt', 'hiccup', 'barotrauma', 'twitch', 'wether', 'conc', 'liw', 'fentani', 'nephrogram', 'crt', 'rescan', 'postpylor', 'lcw', 'sacrament', 'plat', 'nonreact', 'mail', 'grave', 'chb', 'heroic', 'awhil', 'nonrebreath', 'pleuravac', 'occupi', 'familt', 'ultra', 'struggl', 'propos', 'reappear', 'palliat', 'opinion', 'reveiw', 'icter', 'gentamycin', 'criticar', 'resucit', 'amongst', 'tubular', 'meaning', 'cvo', 'abruptli', 'wma', 'fibrinogen', 'reguard', 'ogtub', 'themselv', 'pplat', 'ardsnet', 'preoxygen', 'sooner', 'pneumonectomi', 'kyphoscoliosi', 'sibl', 'vasoconstrict', 'gasp', 'recev', 'hook', 'colour', 'realist', 'hida', 'tran', 'aricept', 'moreov', 'innumer', 'unreli', 'pharmacolog', 'irrevers', 'pvr', 'creep', 'buck', 'vigil', 'aliv', 'argatroban', 'wil', 'derecruit', 'attemtp', 'epsiod', 'religi', 'ration', 'eyelid', 'respitori', 'famil', 'analgesia', 'myeloma', 'imbal', 'neob', 'muddi', 'adam', 'dorsal', 'declar', 'moisten', 'od', 'diflucan', 'requr', 'heliox', 'emper', 'osteoblast', 'illeu', 'futil', 'perisplen', 'nimv', 'currentl', 'fli', 'preliminarili', 'rhochor', 'plerual', 'prioriti', 'esoph', 'dysynchron', 'forth', 'sluggishli', 'occurr', 'unplan', 'binder', 'ipf', 'goodby', 'ccn', 'stg', 'meatu', 'scopalamin', 'unarous', 'tobra', 'hemodynim', 'rite', 'harm', 'fentayl', 'bless', 'petechia', 'doen', 'furhter', 'calvarium', 'fmaili', 'stack', 'chol', 'montitor', 'underpenetr', 'figur', 'pyuria', 'massag', 'thrombot', 'ggt', 'outer', 'mrcp', 'formul', 'synchroni', 'contini', 'treatement', 'news', 'amioderon', 'anasarc', 'unobtain', 'mvo', 'led', 'pastor',  ...

# %% [markdown]
# ### 2. Co-occurrence generation
# FP-growth

# %%
FREQUENT_WORD_LIST = frequent_word_lists['pneumonia_dead'] + frequent_word_lists['pneumonia_alive']
print(len(FREQUENT_WORD_LIST))
print(len(set(FREQUENT_WORD_LIST)))
# Out:
# 783
# 783

# %%
"""function description:
generates frequent word set for the disease
"""
word_dict = {}
word_id = 1
stemmer = PorterStemmer()


for word in FREQUENT_WORD_LIST:
    if not word == "WORD":
        word_dict[stemmer.stem(word.strip())] = word_id
        word_id += 1
             
print(f"\nword dictionary created! Length: {len(word_dict)}\n")
print(word_dict)
# Out:
# word dictionary created! Length: 783
#
# {'bicarbon': 1, 'hypercapnia': 2, 'expir': 3, 'death': 4, 'unrespon': 5, 'clinician': 6, 'arrest': 7, 'norepinephrin': 8, 'cpr': 9, 'vasopressin': 10, 'paralyt': 11, 'refractori': 12, 'mottl': 13, 'dic': 14, 'azotemia': 15, 'phenylephrin': 16, 'arrang': 17, 'pea': 18, 'recruit': 19, 'suffer': 20, 'park': 21, 'pcv': 22, 'funer': 23, 'cremat': 24, 'elig': 25, 'acidem': 26, 'anur': 27, 'profound': 28, 'autopeep': 29, 'clergi': 30, 'hypothermia': 31, 'hypercapn': 32, 'cmo': 33, 'virtual': 34, 'sluggish': 35, 'dnr': 36, 'dni': 37, 'lubric': 38, 'slough': 39, 'pinpoint': 40, 'gum': 41, 'dk': 42, 'nonpurpo': 43, 'nacl': 44, 'oder': 45, 'float': 46, 'levoph': 47, 'mso': 48, 'wish': 49, 'clariti': 50, 'option': 51, 'pronounc': 52, 'peerla': 53, 'grim': 54, 'prognosi': 55, 'antb': 56, 'suport': 57, 'respon': 58, 'bow': 59, 'remin': 60, 'priest': 61, 'dead': 62, 'institut': 63, 'dd': 64, 'purpl': 65, 'viabl': 66, 'hypot': 67, 'gather': 68, 'mad': 69, 'agreement': 70, 'mortem': 71, 'depth': 72, 'aprv': 73, 'life': 74, 'asystol': 75, 'centimet': 76, 'bye': 77, 'acv': 78, 'synch': 79, 'sync': 80, 'chaplain': 81, 'nrbm': 82, 'mgx': 83, 'duski': 84, 'peac': 85, 'througout': 86, 'moniotr': 87, 'ppn': 88, 'hover': 89, 'surviv': 90, 'cathol': 91, 'vtach': 92, 'cvvh': 93, 'quiac': 94, 'defibril': 95, 'pfr': 96, 'rusti': 97, 'acidot': 98, 'agon': 99, 'jerk': 100, 'suppport': 101, 'hemothorax': 102, 'pulseless': 103, 'cvvhdf': 104, 'cvvhd': 105, 'mortum': 106, 'corneal': 107, 'seriou': 108, 'vasopressor': 109, 'deliv': 110, 'neosynephrin': 111, 'deterior': 112, 'crrt': 113, 'maroon': 114, 'mtg': 115, 'hugger': 116, 'multisystem': 117, 'lw': 118, 'cyanot': 119, 'declin': 120, 'pray': 121, 'unequ': 122, 'ffp': 123, 'gratitud': 124, 'scl': 125, 'elimin': 126, 'ethic': 127, 'bair': 128, 'ultrafiltr': 129, 'quinton': 130, 'among': 131, 'spiritu': 132, 'pitressin': 133, 'levof': 134, 'cooler': 135, 'lc': 136, 'cagluc': 137, 'rewir': 138, 'uffp': 139, 'brb': 140, 'hypotherm': 141, 'towel': 142, 'polymorph': 143, 'chane': 144, 'paco': 145, 'neo': 146, 'autopsi': 147, 'absorb': 148, 'promod': 149, 'triadyn': 150, 'morgu': 151, 'syre': 152, 'ashen': 153, 'erythro': 154, 'warmer': 155, 'bond': 156, 'nahco': 157, 'zero': 158, 'asynchron': 159, 'rabbi': 160, 'ran': 161, 'discoordin': 162, 'bank': 163, 'sml': 164, "tf'ing": 165, 'motil': 166, 'circuit': 167, 'town': 168, 'prayer': 169, 'norepi': 170, 'escal': 171, 'bairhugg': 172, 'discard': 173, 'edt': 174, 'hunger': 175, 'mind': 176, 'unstabl': 177, 'gc': 178, '^rr': 179, 'rediscuss': 180, 'dopamin': 181, 'hung': 182, 'polici': 183, 'intiat': 184, 'canton': 185, 'palli': 186, 'moan': 187, 'tacycard': 188, 'acc': 189, 'readdress': 190, 'fliud': 191, 'overlay': 192, 'ozz': 193, 'artifici': 194, 'gurgl': 195, 'anuria': 196, 'inclu': 197, 'proph': 198, 'judgement': 199, 'underneath': 200, 'broader': 201, 'recalibr': 202, 'dobutamin': 203, 'oncologist': 204, 'hospic': 205, 'platlet': 206, 'adenosin': 207, 'platelet': 208, 'quadrent': 209, 'oligur': 210, 'gut': 211, 'sorb': 212, 'cellcept': 213, 'griev': 214, 'influenc': 215, 'cardiovert': 216, 'gvhd': 217, 'anyway': 218, 'core': 219, 'psup': 220, 'nephrolog': 221, 'pheresi': 222, 'kerlix': 223, 'surgicel': 224, 'hepati': 225, 'oximetri': 226, 'chemic': 227, 'fentenyl': 228, 'caspofungin': 229, 'pose': 230, 'repson': 231, 'fc': 232, 'cisatracurium': 233, 'extremitiy': 234, 'ettub': 235, 'grimmac': 236, 'fungemia': 237, 'preme': 238, 'snt': 239, 'hiccup': 240, 'barotrauma': 241, 'twitch': 242, 'wether': 243, 'conc': 244, 'liw': 245, 'fentani': 246, 'nephrogram': 247, 'crt': 248, 'rescan': 249, 'postpylor': 250, 'lcw': 251, 'sacrament': 252, 'plat': 253, 'nonreact': 254, 'mail': 255, 'grave': 256, 'chb': 257, 'heroic': 258, 'awhil': 259, 'nonrebreath': 260, 'pleuravac': 261, 'occupi': 262, 'familt': 263, 'ultra': 264, 'struggl': 265, 'propo': 266, 'reappear': 267, 'palliat': 268, 'opinion': 269, 'reveiw': 270, 'icter': 271, 'gentamycin': 272, 'criticar': 273, 'resucit ...

# %% [markdown]
# ### Implementetion with python for FP_growth

# %% [markdown]
# ### Count co-occurrences per patient

# %%
import os
import operator
from pathlib import Path
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import math

# ----
def fp_growth_input_per_patient_python(disease_df, word_dict, min_support):
    
    # For dataframe
    patient_cooc_dict = {}
    patient_node_dict = {}
    patient_note_cnt = {}
    
    # --------------    
    patient_id = -1
    note_cnt = 0
    patient_note_list = []
    
    # read line in from file (each line is one note)
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        
        # only regard certain type of notes
        patient_id_check = int(row['SUBJECT_ID_x'])
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        patient_word_set = set()
    
#         print(f"patient_id_check: {patient_id_check}, patient_id: {patient_id}")
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check and not patient_id == -1:
            te = TransactionEncoder()
            te_ary = te.fit(patient_note_list).transform(patient_note_list)
            df = pd.DataFrame(te_ary, columns=te.columns_)
            df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
            cooc_tmp = []
            cooc_minsup_tmp = []
            node_minsup_tmp = []
            cooc_node_idx_tmp = []
            
            for index, row in df_itemsets.iterrows():
                if len(row['itemsets']) == 1:
                    word = list(row['itemsets'])[0]
                    min_sup = row['support']

                    node_minsup_tmp.append(len(patient_note_list) * row['support'])
                    cooc_node_idx_tmp.append(word)
                    
                if len(row['itemsets']) == 2:
                    cooc_ = sorted(list(row['itemsets']))
                    cooc_tmp.append(cooc_)
                    cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
            
            cooc_dict = {}

            for num, i in enumerate(cooc_tmp):
                if tuple(i) not in cooc_dict:
                    cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

            # dictionary = dict(zip(keys, values))
            node_dict = {}
            for num, i in enumerate(cooc_node_idx_tmp):
                if i not in node_dict:
                    node_dict[i] = node_minsup_tmp[num]
                    
            # Update glob lists
            if patient_id not in patient_cooc_dict:
                patient_cooc_dict[patient_id] = cooc_dict
                patient_node_dict[patient_id] = node_dict
                patient_note_cnt[patient_id] = note_cnt
            else:
                print(f"patient_id: {patient_id} is already in the dictionary!")
            
            
            # Reset local lists
            patient_note_list = []
            note_cnt = 0
                    
        # update patient id
        patient_id = patient_id_check
        tokenized_note = word_tokenize(note)
        note_cnt += 1

        # loop through each word in note to count word belonging to each disease
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())       
            if stemmed_word in word_dict:
                    patient_word_set.add(stemmed_word)

        templst = []
        for word in patient_word_set:
            templst.append(word)

        if templst:
            patient_note_list.append(templst)
    
    # Last patient info
    te = TransactionEncoder()
    te_ary = te.fit(patient_note_list).transform(patient_note_list)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
    cooc_tmp = []
    cooc_minsup_tmp = []
    #-----
    node_minsup_tmp = []
    cooc_node_idx_tmp = []
            
    for index, row in df_itemsets.iterrows():
        if len(row['itemsets']) == 1:
            word = list(row['itemsets'])[0]
            node_minsup_tmp.append(len(patient_note_list) * row['support'])
            cooc_node_idx_tmp.append(word)

        if len(row['itemsets']) == 2:
            cooc_ = sorted(list(row['itemsets']))
            cooc_tmp.append(cooc_)
            cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
    
                    
    cooc_dict = {}

    for num, i in enumerate(cooc_tmp):
        if tuple(i) not in cooc_dict:
            cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

    # dictionary = dict(zip(keys, values))
    node_dict = {}
    for num, i in enumerate(cooc_node_idx_tmp):
        if i not in node_dict:
            node_dict[i] = node_minsup_tmp[num]

    # Update glob lists
    if patient_id not in patient_cooc_dict:
        patient_cooc_dict[patient_id] = cooc_dict
        patient_node_dict[patient_id] = node_dict
        patient_note_cnt[patient_id] = note_cnt
    else:
        print(f"patient_id: {patient_id} is already in the dictionary!")

    return patient_node_dict, patient_cooc_dict, patient_note_cnt

patient_node_0, patient_cooc_0, patient_note_num_0 = fp_growth_input_per_patient_python(pneumonia_dead_no_disch, word_dict, 0.15)
patient_node_1, patient_cooc_1, patient_note_num_1 = fp_growth_input_per_patient_python(pneumonia_alive_no_disch, word_dict, 0.15)
# Out:
# 100%|██████████| 11895/11895 [01:26<00:00, 138.27it/s]
# 100%|██████████| 46134/46134 [05:26<00:00, 141.48it/s]

# %%
print(patient_node_1)
# Out:
# {68: {'commod': 4.0, 'ambul': 4.0, 'gait': 2.0, 'chair': 2.0, 'oob': 2.0}, 85: {'lat': 1.0}, 94: {'lift': 11.0, 'dopamin': 11.0}, 165: {'habitu': 1.0}, 211: {'dopamin': 3.0, 'aox': 3.0, 'levoph': 3.0}, 224: {'lat': 1.0, 'rigor': 1.0, 'platelet': 1.0, 'commod': 1.0, 'awhil': 1.0, 'fax': 1.0, 'bank': 1.0, 'pleasant': 1.0, 'chair': 1.0}, 231: {}, 283: {'recruit': 10.0, 'criticar': 10.0}, 357: {'unasyn': 4.0, 'intent': 2.0, 'dz': 2.0, 'ctx': 2.0, 'moan': 4.0, 'distort': 2.0}, 368: {'pleasant': 3.0, 'dnr': 3.0, 'hhn': 3.0, 'oob': 6.0, 'ambul': 4.0}, 370: {'dnr': 2.0}, 384: {'bipolar': 9.0, 'wish': 4.0, 'dnr': 3.0, 'schizophrenia': 4.0}, 426: {'align': 1.0, 'mottl': 1.0, 'lat': 1.0, 'unenhanc': 1.0, 'mail': 1.0, 'bronchovascular': 1.0, 'pleasant': 1.0, 'arthrit': 1.0}, 509: {'oob': 3.0}, 514: {'lat': 1.0, 'schizophrenia': 1.0, 'nicotin': 1.0, 'lighthead': 1.0, 'burn': 1.0, 'pleasant': 2.0, 'commod': 2.0, 'ambul': 1.0, 'oob': 1.0}, 596: {'dnr': 4.0, 'dopamin': 3.0, 'dni': 4.0, 'chair': 2.0}, 674: {'profound': 1.0, 'nimv': 1.0, 'xl': 2.0, 'rememb': 1.0, 'neo': 1.0, 'mso': 1.0, 'lotion': 1.0, 'tranfer': 1.0, 'fu': 1.0, 'cardiovert': 1.0}, 707: {'pleasantli': 4.0, 'lpm': 2.0, 'oob': 3.0, 'pleasant': 2.0}, 711: {'dnr': 190.99999999999997, 'mellitu': 78.0, 'fibrinogen': 186.0, 'captopril': 77.0, 'olanzapin': 109.0, 'palli': 60.0, 'fungemia': 95.0, 'caspofungin': 105.0}, 770: {'iddm': 24.0, 'vp': 20.0}, 773: {'pneumococc': 7.0, 'mso': 8.0, 'levoph': 8.0}, 899: {'lat': 2.0, 'chip': 2.0, 'pleasant': 3.0}, 1096: {'syst': 1.0, 'ppd': 1.0, 'lc': 1.0, 'forc': 1.0, 'tubular': 1.0}, 1135: {'scab': 3.0, 'oob': 6.0, 'chair': 7.0, 'argatroban': 4.0, 'pleasant': 3.0, 'lat': 3.0, 'xl': 3.0}, 1163: {'osa': 1.0, 'pleasant': 1.0, 'twitch': 1.0, 'captopril': 1.0}, 1174: {}, 1180: {'influenc': 1.0}, 1283: {'unavail': 1.0, 'seat': 1.0, 'habitu': 1.0}, 1332: {'levoph': 4.0, 'dnr': 6.0, 'dni': 5.0, 'oob': 4.0}, 1339: {'oob': 20.0, 'stair': 18.0, 'ctx': 18.0, 'ambul': 18.0, 'seroquel': 23.0, 'video': 22.0, 'barium': 18.0, 'phenylephrin': 25.0, 'neo': 27.0}, 1546: {'asthma': 4.0, 'spacer': 2.0, 'oob': 2.0, 'db': 2.0}, 1568: {'pericard': 5.0, 'pleasant': 4.0, 'oob': 2.0}, 1601: {'levoph': 3.0, 'pleasant': 2.0, 'ambien': 2.0}, 1606: {'precordium': 1.0, 'unalt': 1.0, 'dnr': 1.0, 'dni': 1.0, 'lat': 1.0, 'dome': 1.0}, 1642: {'pleasant': 2.0, 'dnr': 2.0, 'dni': 2.0, 'quadrent': 1.0, 'declin': 1.0}, 1660: {'behavior': 2.0, 'pleasant': 2.0}, 1895: {'pleasant': 2.0}, 1923: {'moan': 3.0, 'dnr': 3.0, 'sarna': 2.0, 'lotion': 2.0}, 2029: {'xanax': 28.0, 'dnr': 20.0}, 2090: {'chair': 18.0, 'splint': 13.0, 'dyslipidemia': 23.000000000000004, 'ctx': 17.0, 'bromid': 17.0, 'ntnd': 14.000000000000002}, 2098: {'hugger': 4.0, 'bair': 4.0, 'cpr': 2.0}, 2128: {'dopamin': 10.0, 'mso': 6.0, 'unasyn': 4.0, 'flight': 3.0}, 2170: {'qtc': 1.0, 'nonrebreath': 1.0, 'spur': 2.0, 'lat': 1.0}, 2187: {'osa': 2.0, 'morbid': 2.0, 'captopril': 2.0}, 2208: {'vp': 35.0, 'bipolar': 16.0, 'clonidin': 19.0, 'levoph': 16.0}, 2337: {'smooth': 1.0, 'hemangioma': 1.0, 'slough': 1.0, 'pleasant': 1.0, 'dnr': 2.0, 'pleasantli': 1.0}, 2378: {'ultram': 16.0, 'silent': 16.0, 'video': 15.0, 'sensat': 13.0}, 2386: {'dnr': 7.0, 'hospic': 3.0, 'town': 2.0, 'dni': 3.0}, 2452: {'lat': 4.0}, 2508: {'levoph': 2.0, 'dopamin': 2.0, 'ppd': 2.0, 'ciwa': 2.0, 'lpm': 2.0, 'chair': 2.0}, 2561: {}, 2585: {'hilum': 2.0, 'para': 1.0, 'ultram': 1.0, 'sluggish': 1.0, 'prognosi': 1.0, 'hook': 1.0, 'grave': 1.0, 'dnr': 1.0, 'dni': 1.0}, 2589: {'bipolar': 28.000000000000004, 'pneumococc': 22.0, 'zyprexa': 7.000000000000001, 'dz': 9.0, 'mood': 7.000000000000001, 'historian': 10.0}, 2590: {'dnr': 2.0, 'dni': 2.0, 'nonrebreath': 1.0, 'venti': 2.0, 'lpm': 1.0, 'pleasant': 1.0}, 2628: {}, 2658: {'moan': 3.0}, 2732: {'vertebra': 2.0, 'lat': 2.0}, 2784: {'arrest': 2.0, 'commod': 3.0, 'video': 2.0, 'diaper': 2.0, 'gait': 2.0}, 2823: {'dnr': 4.0, 'venti': 3.0, 'dni': 3.0}, 3070: {'svn': 2.0, 'osa': 1.0, 'ofm': 1.0, 'pleasant': 1.0, 'video': 1.0, ...

# %%
print(patient_cooc_1)
# Out:
# {68: {('ambul', 'commod'): 3.0, ('ambul', 'oob'): 2.0, ('commod', 'oob'): 2.0}, 85: {}, 94: {}, 165: {}, 211: {}, 224: {('platelet', 'rigor'): 1.0, ('commod', 'platelet'): 1.0, ('commod', 'rigor'): 1.0, ('bank', 'fax'): 1.0, ('chair', 'pleasant'): 1.0}, 231: {}, 283: {}, 357: {('intent', 'unasyn'): 2.0, ('dz', 'intent'): 2.0, ('dz', 'unasyn'): 2.0, ('ctx', 'unasyn'): 2.0}, 368: {}, 370: {}, 384: {('bipolar', 'wish'): 4.0}, 426: {('lat', 'mottl'): 1.0, ('mail', 'unenhanc'): 1.0, ('bronchovascular', 'mail'): 1.0, ('bronchovascular', 'unenhanc'): 1.0, ('arthrit', 'pleasant'): 1.0}, 509: {}, 514: {('nicotin', 'schizophrenia'): 1.0, ('lighthead', 'nicotin'): 1.0, ('lighthead', 'schizophrenia'): 1.0, ('burn', 'lighthead'): 1.0, ('burn', 'nicotin'): 1.0, ('burn', 'schizophrenia'): 1.0, ('commod', 'pleasant'): 2.0, ('ambul', 'commod'): 1.0, ('ambul', 'pleasant'): 1.0, ('commod', 'oob'): 1.0, ('oob', 'pleasant'): 1.0}, 596: {('dni', 'dnr'): 2.0}, 674: {('nimv', 'profound'): 1.0, ('rememb', 'xl'): 1.0, ('neo', 'rememb'): 1.0, ('neo', 'xl'): 1.0, ('mso', 'neo'): 1.0, ('mso', 'rememb'): 1.0, ('mso', 'xl'): 1.0, ('lotion', 'mso'): 1.0, ('lotion', 'neo'): 1.0, ('lotion', 'rememb'): 1.0, ('lotion', 'xl'): 1.0, ('tranfer', 'xl'): 1.0, ('fu', 'tranfer'): 1.0, ('fu', 'xl'): 1.0, ('cardiovert', 'fu'): 1.0, ('cardiovert', 'tranfer'): 1.0, ('cardiovert', 'xl'): 1.0}, 707: {('oob', 'pleasantli'): 2.0}, 711: {('fibrinogen', 'mellitu'): 59.0, ('dnr', 'fibrinogen'): 159.0, ('captopril', 'fibrinogen'): 66.0, ('fibrinogen', 'olanzapin'): 99.0, ('dnr', 'olanzapin'): 85.0, ('dnr', 'fungemia'): 80.0, ('fibrinogen', 'fungemia'): 78.0, ('caspofungin', 'fungemia'): 87.0, ('fungemia', 'olanzapin'): 57.0, ('caspofungin', 'dnr'): 81.0, ('caspofungin', 'fibrinogen'): 79.0}, 770: {('iddm', 'vp'): 16.0}, 773: {}, 899: {}, 1096: {('ppd', 'syst'): 1.0}, 1135: {('chair', 'oob'): 4.0, ('argatroban', 'chair'): 3.0}, 1163: {('captopril', 'twitch'): 1.0}, 1174: {}, 1180: {}, 1283: {('seat', 'unavail'): 1.0, ('habitu', 'unavail'): 1.0, ('habitu', 'seat'): 1.0}, 1332: {('dni', 'dnr'): 5.0}, 1339: {('oob', 'stair'): 18.0, ('ctx', 'stair'): 18.0, ('ctx', 'oob'): 18.0, ('ambul', 'ctx'): 18.0, ('ambul', 'stair'): 18.0, ('ambul', 'oob'): 18.0, ('phenylephrin', 'video'): 15.0, ('barium', 'video'): 15.0}, 1546: {('db', 'oob'): 2.0}, 1568: {('pericard', 'pleasant'): 3.0, ('oob', 'pleasant'): 2.0}, 1601: {('levoph', 'pleasant'): 2.0}, 1606: {('dni', 'dnr'): 1.0}, 1642: {('dnr', 'pleasant'): 2.0, ('dni', 'pleasant'): 2.0, ('pleasant', 'quadrent'): 1.0, ('declin', 'pleasant'): 1.0, ('dni', 'dnr'): 2.0, ('dnr', 'quadrent'): 1.0, ('declin', 'dnr'): 1.0, ('dni', 'quadrent'): 1.0, ('declin', 'dni'): 1.0, ('declin', 'quadrent'): 1.0}, 1660: {}, 1895: {}, 1923: {('dnr', 'moan'): 2.0, ('dnr', 'sarna'): 2.0, ('moan', 'sarna'): 2.0, ('lotion', 'sarna'): 2.0, ('dnr', 'lotion'): 2.0, ('lotion', 'moan'): 2.0}, 2029: {}, 2090: {('ctx', 'dyslipidemia'): 13.0, ('bromid', 'dyslipidemia'): 17.0}, 2098: {('bair', 'hugger'): 4.0}, 2128: {('dopamin', 'mso'): 4.0, ('dopamin', 'unasyn'): 3.0}, 2170: {}, 2187: {('morbid', 'osa'): 2.0}, 2208: {('bipolar', 'vp'): 16.0}, 2337: {('hemangioma', 'smooth'): 1.0, ('pleasant', 'slough'): 1.0, ('dnr', 'pleasantli'): 1.0}, 2378: {('silent', 'video'): 14.000000000000002, ('sensat', 'video'): 12.0, ('sensat', 'silent'): 12.0}, 2386: {('dnr', 'hospic'): 3.0, ('dnr', 'town'): 2.0, ('dni', 'dnr'): 3.0}, 2452: {}, 2508: {('dopamin', 'levoph'): 2.0}, 2561: {}, 2585: {('hilum', 'para'): 1.0, ('prognosi', 'sluggish'): 1.0, ('hook', 'prognosi'): 1.0, ('hook', 'sluggish'): 1.0, ('grave', 'hook'): 1.0, ('grave', 'prognosi'): 1.0, ('grave', 'sluggish'): 1.0, ('dnr', 'grave'): 1.0, ('dnr', 'hook'): 1.0, ('dnr', 'prognosi'): 1.0, ('dnr', 'sluggish'): 1.0, ('dni', 'dnr'): 1.0, ('dni', 'grave'): 1.0, ('dni', 'hook'): 1.0, ('dni', 'prognosi'): 1.0, ('dni', 'sluggish'): 1.0}, 2589: {('bipolar', 'pneumococc'): 19.0, ('pneumococc', 'zyprexa'): 7.000000000000001, ('bipolar', 'zyprexa'): 7. ...

# %%
patient_note_num_0
# Out:
# {111: 12,
#  346: 25,
#  404: 3,
#  546: 6,
#  618: 16,
#  705: 15,
#  726: 48,
#  1039: 55,
#  1556: 37,
#  1872: 3,
#  1944: 56,
#  2286: 69,
#  2990: 166,
#  3055: 29,
#  3099: 13,
#  3201: 8,
#  3526: 7,
#  3773: 6,
#  3881: 20,
#  4122: 51,
#  4754: 101,
#  4811: 21,
#  5476: 1,
#  5494: 22,
#  5774: 104,
#  5786: 152,
#  5913: 1,
#  6133: 68,
#  6735: 13,
#  6745: 13,
#  6973: 36,
#  6981: 8,
#  7277: 66,
#  7310: 8,
#  7924: 9,
#  7977: 9,
#  9908: 11,
#  9984: 15,
#  10302: 100,
#  10510: 86,
#  10545: 10,
#  10642: 10,
#  11049: 14,
#  11209: 9,
#  11395: 41,
#  12530: 24,
#  12849: 50,
#  13098: 46,
#  13566: 23,
#  14125: 9,
#  14514: 96,
#  14965: 25,
#  15159: 15,
#  15251: 11,
#  15396: 17,
#  15566: 37,
#  15853: 45,
#  16275: 17,
#  16344: 27,
#  16622: 51,
#  16684: 29,
#  17122: 16,
#  17354: 5,
#  17802: 64,
#  17983: 65,
#  18094: 23,
#  18736: 35,
#  18768: 46,
#  18848: 205,
#  18971: 26,
#  19243: 25,
#  19323: 6,
#  19390: 21,
#  19463: 20,
#  19535: 59,
#  19754: 13,
#  19827: 22,
#  19833: 58,
#  19872: 10,
#  20006: 8,
#  20023: 9,
#  20190: 6,
#  21046: 101,
#  21094: 36,
#  21427: 10,
#  21502: 102,
#  21580: 52,
#  21676: 12,
#  21699: 7,
#  21979: 11,
#  22735: 15,
#  23660: 12,
#  23795: 78,
#  24181: 13,
#  24582: 37,
#  24725: 57,
#  24730: 19,
#  24854: 25,
#  25003: 182,
#  25046: 7,
#  25774: 61,
#  25975: 9,
#  26474: 89,
#  26578: 15,
#  26716: 41,
#  26774: 3,
#  26849: 33,
#  27005: 5,
#  27145: 24,
#  27421: 61,
#  27431: 5,
#  27496: 7,
#  27504: 72,
#  27639: 221,
#  28004: 13,
#  28072: 34,
#  28178: 202,
#  28427: 6,
#  28498: 25,
#  28726: 34,
#  28750: 19,
#  28906: 32,
#  28907: 13,
#  28933: 394,
#  29105: 468,
#  29588: 72,
#  29647: 26,
#  29872: 225,
#  30476: 174,
#  30549: 12,
#  30614: 8,
#  30699: 14,
#  30786: 9,
#  30941: 110,
#  31030: 168,
#  31134: 24,
#  31139: 9,
#  31451: 48,
#  31556: 57,
#  31690: 18,
#  31692: 35,
#  32050: 34,
#  32326: 24,
#  32618: 42,
#  41546: 25,
#  43937: 6,
#  44851: 274,
#  45381: 16,
#  46589: 26,
#  46763: 6,
#  47045: 9,
#  48632: 147,
#  49079: 20,
#  49683: 3,
#  49922: 13,
#  50093: 8,
#  50231: 3,
#  50556: 216,
#  50859: 537,
#  51914: 313,
#  52010: 12,
#  53105: 115,
#  53399: 78,
#  54193: 85,
#  54401: 14,
#  54408: 2,
#  54739: 75,
#  54946: 7,
#  55400: 5,
#  55570: 14,
#  55887: 37,
#  55944: 34,
#  55987: 20,
#  56390: 19,
#  56648: 8,
#  56854: 170,
#  57091: 88,
#  57102: 35,
#  58702: 479,
#  59260: 11,
#  59437: 26,
#  60849: 2,
#  60868: 6,
#  61652: 7,
#  61667: 30,
#  63039: 8,
#  65513: 8,
#  68044: 40,
#  68095: 23,
#  68184: 5,
#  68308: 8,
#  68860: 14,
#  69719: 13,
#  69745: 25,
#  69776: 17,
#  70226: 8,
#  70447: 9,
#  72930: 11,
#  73811: 9,
#  73888: 109,
#  74316: 2,
#  74444: 81,
#  74686: 75,
#  75824: 10,
#  76282: 21,
#  76827: 2,
#  77382: 10,
#  78241: 3,
#  78388: 14,
#  79008: 27,
#  79055: 21,
#  79222: 18,
#  79877: 156,
#  80637: 148,
#  80678: 9,
#  80737: 46,
#  80805: 79,
#  81437: 27,
#  82393: 5,
#  82769: 85,
#  83932: 2,
#  84474: 34,
#  85160: 8,
#  85258: 52,
#  85404: 11,
#  85797: 9,
#  86007: 35,
#  86394: 4,
#  86684: 11,
#  86832: 67,
#  86863: 8,
#  86872: 326,
#  88193: 16,
#  88660: 11,
#  90256: 18,
#  91350: 19,
#  92074: 28,
#  92278: 52,
#  92331: 42,
#  93422: 7,
#  94341: 2,
#  94997: 9,
#  95280: 23,
#  95803: 18,
#  95830: 33,
#  95933: 56,
#  96699: 85,
#  97181: 30,
#  97795: 60,
#  98009: 33,
#  98299: 29,
#  98597: 2}

# %% [markdown]
# #### Create set of patient co-occurrences from two groups

# %%
# Create a set of all unique co-occurrences from both group
patient_cooc_set = set()
patient_cooc_0_dict = {}
patient_cooc_1_dict = {}

for k, v in patient_cooc_0.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_0_dict:
            patient_cooc_0_dict[item] = v[item]
        else:
            patient_cooc_0_dict[item] = patient_cooc_0_dict[item] + v[item]
            
    
for k, v in patient_cooc_1.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_1_dict:
            patient_cooc_1_dict[item] = v[item]
        else:
            patient_cooc_1_dict[item] = patient_cooc_1_dict[item] + v[item]

# %%
print(len(patient_cooc_set))
print(len(patient_cooc_0_dict))
print(len(patient_cooc_1_dict))
# Out:
# 6776
# 1989
# 5152

# %%
# count log-odds score

# reverse
# --------------- co-occurrences --------------->

        
# Get the set of coocurrencies from two groups
# Count log_odd_score

patient_cooc_odd_scores = {}
for set_item in patient_cooc_set:
    if set_item in patient_cooc_0_dict and set_item in patient_cooc_1_dict: 
        d_prob = patient_cooc_0_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        a_prob = patient_cooc_1_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
# --------------- co-occurrences ---------------<

# %%
patient_cooc_odd_scores
# Out:
# {('life', 'trazodon'): -6.90875477931522,
#  ('gadolinium', 'outer'): 6.90875477931522,
#  ('historian', 'uri'): 6.90875477931522,
#  ('aricept', 'dead'): -6.90875477931522,
#  ('ppn', 'retic'): 6.90875477931522,
#  ('hypothermia', 'wma'): 6.90875477931522,
#  ('bottl', 'rememb'): 6.90875477931522,
#  ('ctx', 'dietari'): 6.90875477931522,
#  ('lat', 'mva'): 6.90875477931522,
#  ('ba', 'omeprazol'): 6.90875477931522,
#  ('ashen', 'mellitu'): 6.90875477931522,
#  ('venti', 'young'): 6.90875477931522,
#  ('argatroban', 'vasopressin'): -6.90875477931522,
#  ('bottl', 'syncop'): 6.90875477931522,
#  ('cdb', 'incent'): 6.90875477931522,
#  ('incent', 'itchi'): 6.90875477931522,
#  ('dni', 'itchi'): 6.90875477931522,
#  ('mva', 'omeprazol'): 6.90875477931522,
#  ('dnr', 'palliat'): -6.90875477931522,
#  ('rememb', 'vertebra'): 6.90875477931522,
#  ('hypotherm', 'hypothermia'): 0.2508075216675933,
#  ('bronchovascular', 'fatti'): 6.90875477931522,
#  ('hypothermia', 'robitussin'): 6.90875477931522,
#  ('msicu', 'pleasant'): 6.90875477931522,
#  ('chair', 'spiromet'): 6.90875477931522,
#  ('death', 'ferrou'): 6.90875477931522,
#  ('absorb', 'uri'): 6.90875477931522,
#  ('foci', 'outer'): 6.90875477931522,
#  ('declin', 'scab'): 6.90875477931522,
#  ('cpr', 'pulseless'): -6.90875477931522,
#  ('profound', 'ration'): 6.90875477931522,
#  ('hook', 'qam'): 6.90875477931522,
#  ('nephrolog', 'pleasant'): 6.90875477931522,
#  ('declar', 'deterior'): -6.90875477931522,
#  ('clonidin', 'sibl'): 6.90875477931522,
#  ('recalibr', 'stitch'): 6.90875477931522,
#  ('levoph', 'mucinex'): 6.90875477931522,
#  ('corneal', 'dnr'): -6.90875477931522,
#  ('cg', 'dnr'): -6.90875477931522,
#  ('lpm', 'pleasant'): 6.90875477931522,
#  ('hsq', 'stair'): 6.90875477931522,
#  ('oncologist', 'pleasant'): 6.90875477931522,
#  ('dic', 'pyuria'): 6.90875477931522,
#  ('asthma', 'opiat'): 6.90875477931522,
#  ('dizzi', 'signatur'): 6.90875477931522,
#  ('commod', 'illeu'): -6.90875477931522,
#  ('cup', 'video'): 6.90875477931522,
#  ('echocardiogram', 'puff'): 6.90875477931522,
#  ('plerual', 'scar'): 6.90875477931522,
#  ('death', 'omeprazol'): 6.90875477931522,
#  ('aaox', 'chip'): 6.90875477931522,
#  ('pose', 'ran'): 6.90875477931522,
#  ('chair', 'tran'): 6.90875477931522,
#  ('cyanot', 'dopamin'): -6.90875477931522,
#  ('dietari', 'hsq'): 6.90875477931522,
#  ('captopril', 'lpm'): 6.90875477931522,
#  ('bromid', 'opiat'): 6.90875477931522,
#  ('clonidin', 'crowd'): 6.90875477931522,
#  ('autoset', 'declin'): 6.90875477931522,
#  ('core', 'icter'): -6.90875477931522,
#  ('dni', 'herp'): 6.90875477931522,
#  ('impli', 'video'): -6.90875477931522,
#  ('asthma', 'hsq'): 6.90875477931522,
#  ('laryng', 'pathologist'): 6.90875477931522,
#  ('aaox', 'commod'): 6.90875477931522,
#  ('pleasant', 'spacer'): 6.90875477931522,
#  ('liw', 'vasopressin'): -6.90875477931522,
#  ('levoph', 'mso'): -6.90875477931522,
#  ('cash', 'oob'): 6.90875477931522,
#  ('gait', 'sensat'): 6.90875477931522,
#  ('ciwa', 'ran'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('bipolar', 'gastriti'): 6.90875477931522,
#  ('declin', 'prognosi'): -1.9852670803394386,
#  ('hospic', 'underneath'): -6.90875477931522,
#  ('nifedipin', 'scar'): 6.90875477931522,
#  ('expir', 'neo'): -6.90875477931522,
#  ('cdb', 'dni'): 6.90875477931522,
#  ('bipolar', 'seroquel'): 6.90875477931522,
#  ('deterior', 'religi'): -6.90875477931522,
#  ('adam', 'hypotherm'): -6.90875477931522,
#  ('osa', 'panic'): 6.90875477931522,
#  ('endplat', 'magnevist'): 6.90875477931522,
#  ('dni', 'fwb'): 6.90875477931522,
#  ('spacer', 'unstabl'): 6.90875477931522,
#  ('dnr', 'hospic'): 0.025267268054695924,
#  ('hepatobiliari', 'synthet'): -6.90875477931522,
#  ('fibrinogen', 'nice'): 6.90875477931522,
#  ('elimin', 'pharyng'): 6.90875477931522,
#  ('fibrinogen', 'lusb'): 6.90875477931522,
#  ('dnr', 'gvhd'): 6.90875477931522,
#  ('cloth', 'pivot'): -6.90875477931522,
#  ('gastriti', 'predict'): 6.90875477931522,
#  ('acc', 'ctx'): 6.90875477931522,
#  ('db', 'dni'): 6.90875477931522,
#  ('duski', 'wish'): -6.90875477931522,
#  ('historian', 'opiat'): 6.90875477931522,
#  ('incis', 'omeprazol'): 6.90875477931522,
#  ('lat', 'sweat'): 6.90875477931522,
#  ('asthma', 'db'): 6.90875477931522,
#  ('lat', 'syncop'): 6.90875477931522,
#  ('gotten', 'msicu'): 6.90875477931522,
#  ('chair', 'cloth'): 6.90875477931522,
#  ('fu', 'ntnd'): 6.90875477931522,
#  ('gabapentin', 'shorter'): 6.90875477931522,
#  ('adam', 'neo'): -6.90875477931522,
#  ('nectar', 'pleasant'): 6.90875477931522,
#  ('phlegm', 'sensat'): 6.90875477931522,
#  ('levoph', 'lpm'): 6.90875477931522,
#  ('commod', 'levoph'): -0.25080752166759324,
#  ('ferritin', 'mellitu'): 6.90875477931522,
#  ('chb', 'hemothorax'): -6.90875477931522,
#  ('dnr', 'pea'): -6.90875477931522,
#  ('dnr', 'hsq'): 6.90875477931522,
#  ('dni', 'mrg'): 6.90875477931522,
#  ('fatti', 'ferritin'): 6.90875477931522,
#  ('dnr', 'osa'): 0.11100317119789695,
#  ('hypothermia', 'sweat'): 6.90875477931522,
#  ('hsq', 'lusb'): 6.90875477931522,
#  ('hypercapnia', 'pcv'): -6.90875477931522,
#  ('levoph', 'suffer'): -6.90875477931522,
#  ('asthma', 'itchi'): 6.90875477931522,
#  ('crack', 'dizzi'): 6.90875477931522,
#  ('magnevist', 'motor'): 6.90875477931522,
#  ('mrcp', 'synthet'): -6.90875477931522,
#  ('bottl', 'puff'): 6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('assymetr', 'ppd'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('aricept', 'syncop'): 6.90875477931522,
#  ('breakfast', 'panic'): 6.90875477931522,
#  ('cpr', 'hypothermia'): -6.90875477931522,
#  ('asthma', 'omeprazol'): 6.90875477931522,
#  ('oob', 'tran'): 6.90875477931522,
#  ('pleasant', 'subq'): 6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('expir', 'moan'): -6.90875477931522,
#  ('expir', 'homogen'): 6.90875477931522,
#  ('azotemia', 'echocardiogram'): 6.90875477931522,
#  ('historian', 'signatur'): 6.90875477931522,
#  ('gait', 'motor'): 6.90875477931522,
#  ('dnr', 'omeprazol'): 2.040109298143704,
#  ('hung', 'trazodon'): -6.90875477931522,
#  ('azotemia', 'platelet'): -6.90875477931522,
#  ('phlegm', 'spiromet'): 6.90875477931522,
#  ('oob', 'thrive'): 6.90875477931522,
#  ('sibl', 'subq'): 6.90875477931522,
#  ('levoph', 'pcv'): 6.90875477931522,
#  ('agon', 'neosynephrin'): -6.90875477931522,
#  ('arrest', 'hypercapnia'): -6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('motor', 'thiamin'): 6.90875477931522,
#  ('chb', 'dopamin'): 6.90875477931522,
#  ('puff', 'trazodon'): 6.90875477931522,
#  ('osa', 'strictur'): 6.90875477931522,
#  ('bill', 'gastrojejunostomi'): 6.90875477931522,
#  ('aricept', 'cash'): -6.90875477931522,
#  ('lighthead', 'schizophrenia'): 6.90875477931522,
#  ('robitussin', 'wish'): 6.90875477931522,
#  ('bromid', 'im'): 6.90875477931522,
#  ('colonoscopi', 'scar'): 6.90875477931522,
#  ('dni', 'laminectomi'): 6.90875477931522,
#  ('omeprazol', 'silent'): 6.90875477931522,
#  ('acetazolamid', 'fibrinogen'): 6.90875477931522,
#  ('contractur', 'dnr'): 0.6916505477038827,
#  ('opiat', 'seroquel'): 6.90875477931522,
#  ('im', 'romi'): 6.90875477931522,
#  ('refractori', 'young'): 6.90875477931522,
#  ('anaphylaxi', 'nocturn'): 6.90875477931522,
#  ('hsq', 'pleasant'): 6.90875477931522,
#  ('core', 'dic'): -6.90875477931522,
#  ('mood', 'zyprexa'): 6.90875477931522,
#  ('breakfast', 'uffp'): 6.90875477931522,
#  ('ba', 'opiat'): 6.90875477931522,
#  ('amb', 'oob'): 6.90875477931522,
#  ('azotemia', 'pneumococc'): 6.90875477931522,
#  ('asthma', 'iddm'): 6.90875477931522,
#  ('clonidin', 'gastriti'): 6.90875477931522,
#  ('bicarbon', 'readmit'): 6.90875477931522,
#  ('aricept', 'resucit'): 6.90875477931522,
#  ('cs', 'nicotin'): 6.90875477931522,
#  ('fibrinogen', 'osa'): 6.90875477931522,
#  ('chair', 'wish'): 6.90875477931522,
#  ('assymetr', 'underpenetr'): -6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('cocain', 'vagu'): 6.90875477931522,
#  ('dni', 'life'): 0.9141958635336067,
#  ('oob', 'readmit'): 6.90875477931522,
#  ('nephrolog', 'scar'): 6.90875477931522,
#  ('bicarbon', 'life'): -6.90875477931522,
#  ('asthma', 'chair'): 2.09609753878805,
#  ('cloth', 'redirect'): -6.90875477931522,
#  ('asthma', 'unavail'): 6.90875477931522,
#  ('laminectomi', 'schizophrenia'): 6.90875477931522,
#  ('oncologist', 'ppd'): 6.90875477931522,
#  ('adenocarcinoma', 'tremul'): 6.90875477931522,
#  ('gc', 'im'): 6.90875477931522,
#  ('cooki', 'laryng'): 6.90875477931522,
#  ('aox', 'clonidin'): 6.90875477931522,
#  ('calculi', 'refractori'): 6.90875477931522,
#  ('chair', 'jewelri'): 6.90875477931522,
#  ('qam', 'vagu'): 6.90875477931522,
#  ('foci', 'neo'): 6.90875477931522,
#  ('prilosec', 'wish'): 6.90875477931522,
#  ('compani', 'pleasant'): 6.90875477931522,
#  ('declin', 'dnr'): 2.7567935411197357,
#  ('hilum', 'zyprexa'): -6.90875477931522,
#  ('prognosi', 'unstabl'): -6.90875477931522,
#  ('death', 'dnr'): -6.90875477931522,
#  ('seat', 'wish'): 6.90875477931522,
#  ('diaphoresi', 'lpm'): 6.90875477931522,
#  ('adam', 'dic'): -6.90875477931522,
#  ('itchi', 'tracheomalacia'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('fibrinogen', 'wish'): 6.90875477931522,
#  ('asthma', 'soln'): 6.90875477931522,
#  ('fibrinogen', 'gastriti'): 6.90875477931522,
#  ('oncologist', 'osa'): 6.90875477931522,
#  ('muir', 'passi'): 6.90875477931522,
#  ('aricept', 'sibl'): 6.90875477931522,
#  ('dni', 'opinion'): -6.90875477931522,
#  ('pod', 'readmit'): 6.90875477931522,
#  ('diflucan', 'jewelri'): 6.90875477931522,
#  ('para', 'young'): 6.90875477931522,
#  ('dobutamin', 'vasopressin'): -6.90875477931522,
#  ('oob', 'pca'): 6.90875477931522,
#  ('ambul', 'prec'): 6.90875477931522,
#  ('clonazepam', 'nocturn'): 6.90875477931522,
#  ('escal', 'seroquel'): 6.90875477931522,
#  ('arrest', 'morbid'): 6.90875477931522,
#  ('dnr', 'weekli'): 6.90875477931522,
#  ('furhter', 'twitch'): -6.90875477931522,
#  ('colonoscopi', 'syncop'): 6.90875477931522,
#  ('gc', 'omeprazol'): 6.90875477931522,
#  ('dnr', 'fibrinogen'): 1.6507429622330152,
#  ('ffp', 'myeloma'): 6.90875477931522,
#  ('hospic', 'vasopressor'): 6.90875477931522,
#  ('echocardiogram', 'xl'): 6.90875477931522,
#  ('diaphoresi', 'xii'): 6.90875477931522,
#  ('neo', 'sibl'): -6.90875477931522,
#  ('declin', 'phlegm'): -6.90875477931522,
#  ('omeprazol', 'weekli'): 6.90875477931522,
#  ('dnr', 'hemothorax'): -6.90875477931522,
#  ('freeli', 'videofluoroscopi'): 6.90875477931522,
#  ('angri', 'expir'): 6.90875477931522,
#  ('dnr', 'trazodon'): 6.90875477931522,
#  ('deterior', 'levoph'): 2.09609753878805,
#  ('habitu', 'morbid'): 6.90875477931522,
#  ('lighthead', 'sweat'): 6.90875477931522,
#  ('asthma', 'cdb'): 6.90875477931522,
#  ('abruptli', 'chb'): -6.90875477931522,
#  ('cs', 'hugger'): -6.90875477931522,
#  ('angri', 'im'): 6.90875477931522,
#  ('venti', 'zero'): 6.90875477931522,
#  ('levoph', 'svv'): -6.90875477931522,
#  ('mrg', 'readmit'): 6.90875477931522,
#  ('hunger', 'rabbi'): -6.90875477931522,
#  ('levoph', 'opiat'): 6.90875477931522,
#  ('mellitu', 'ppd'): 6.90875477931522,
#  ('dni', 'hypercapn'): 6.90875477931522,
#  ('behavior', 'venti'): 6.90875477931522,
#  ('gastrojejunostomi', 'homogen'): 6.90875477931522,
#  ('contractur', 'fliud'): -6.90875477931522,
#  ('dni', 'redirect'): 2.2204460492503128e-16,
#  ('commod', 'cramp'): 6.90875477931522,
#  ('dz', 'lat'): 6.90875477931522,
#  ('bow', 'spfc'): 6.90875477931522,
#  ('thirst', 'video'): -6.90875477931522,
#  ('fliud', 'moan'): -6.90875477931522,
#  ('cmo', 'sluggish'): -6.90875477931522,
#  ('learn', 'moan'): 6.90875477931522,
#  ('cmo', 'tran'): -6.90875477931522,
#  ('book', 'fax'): 6.90875477931522,
#  ('nephrolog', 'ntnd'): -6.90875477931522,
#  ('clonidin', 'proph'): 6.90875477931522,
#  ('dni', 'lpm'): -6.90875477931522,
#  ('ciwa', 'sibl'): 6.90875477931522,
#  ('opinion', 'palliat'): -6.90875477931522,
#  ('cloth', 'diflucan'): 6.90875477931522,
#  ('oligur', 'vasopressor'): -6.90875477931522,
#  ('cvvh', 'sluggishli'): -6.90875477931522,
#  ('anur', 'banana'): 6.90875477931522,
#  ('neo', 'oob'): 6.90875477931522,
#  ('currenlti', 'modifi'): 6.90875477931522,
#  ('cyanot', 'iddm'): 6.90875477931522,
#  ('asystol', 'levoph'): -6.90875477931522,
#  ('gentamycin', 'illeu'): -6.90875477931522,
#  ('panic', 'xii'): 6.90875477931522,
#  ('ffp', 'intiat'): 6.90875477931522,
#  ('ctx', 'ferritin'): 6.90875477931522,
#  ('declin', 'icter'): -6.90875477931522,
#  ('dome', 'plate'): 6.90875477931522,
#  ('cpr', 'hsq'): -6.90875477931522,
#  ('oob', 'wish'): 6.90875477931522,
#  ('azotemia', 'epigastr'): 6.90875477931522,
#  ('dni', 'td'): 6.90875477931522,
#  ('dizzi', 'lighthead'): 6.90875477931522,
#  ('redirect', 'wallet'): -6.90875477931522,
#  ('aaox', 'emper'): 6.90875477931522,
#  ('abnl', 'occipit'): 6.90875477931522,
#  ('nicotin', 'schizophrenia'): 6.90875477931522,
#  ('gadolinium', 'uri'): 6.90875477931522,
#  ('aliv', 'paperwork'): 6.90875477931522,
#  ('para', 'smooth'): 0.0,
#  ('fibrinogen', 'subq'): 6.90875477931522,
#  ('hctz', 'subdur'): 6.90875477931522,
#  ('reguard', 'uncoop'): 6.90875477931522,
#  ('moan', 'mso'): -6.90875477931522,
#  ('behavior', 'seroquel'): 6.90875477931522,
#  ('diaphoresi', 'xl'): 6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('gabapentin', 'hsq'): 6.90875477931522,
#  ('death', 'predict'): -6.90875477931522,
#  ('bicarbon', 'pcv'): -6.90875477931522,
#  ('sluggishli', 'vasopressin'): -6.90875477931522,
#  ('ambien', 'pharmacolog'): 6.90875477931522,
#  ('omeprazol', 'strictur'): 6.90875477931522,
#  ('aliv', 'dni'): 6.90875477931522,
#  ('signatur', 'xl'): 6.90875477931522,
#  ('levoph', 'sluggishli'): -6.90875477931522,
#  ('oob', 'purpl'): 6.90875477931522,
#  ('breakfast', 'probe'): 6.90875477931522,
#  ('autopeep', 'pcv'): -6.90875477931522,
#  ('icter', 'prilosec'): 6.90875477931522,
#  ('esld', 'fibrinogen'): -6.90875477931522,
#  ('clonazepam', 'strictur'): 6.90875477931522,
#  ('bipolar', 'strictur'): 6.90875477931522,
#  ('articul', 'hypothermia'): 6.90875477931522,
#  ('silent', 'video'): 6.90875477931522,
#  ('iddm', 'vp'): 6.90875477931522,
#  ('captopril', 'gabapentin'): 6.90875477931522,
#  ('deterior', 'echocardiogram'): 6.90875477931522,
#  ('gadolinium', 'norepinephrin'): 6.90875477931522,
#  ('azotemia', 'bicarbon'): -6.90875477931522,
#  ('peribronchovascular', 'smooth'): -6.90875477931522,
#  ('neosynephrin', 'sluggishli'): -6.90875477931522,
#  ('chemic', 'crack'): 6.90875477931522,
#  ('suprapub', 'young'): 6.90875477931522,
#  ('dermat', 'dni'): 1.8806492362025304,
#  ('incis', 'palli'): -6.90875477931522,
#  ('seroquel', 'td'): 6.90875477931522,
#  ('expir', 'morgu'): -6.90875477931522,
#  ('chair', 'cs'): 6.90875477931522,
#  ('esld', 'neutral'): 6.90875477931522,
#  ('dnr', 'hypercapn'): 6.90875477931522,
#  ('dizzi', 'rigor'): 6.90875477931522,
#  ('dizzi', 'venti'): 1.9390841839849136,
#  ('fibrinogen', 'impli'): 6.90875477931522,
#  ('dnr', 'lpm'): -6.90875477931522,
#  ('azotemia', 'incent'): -6.90875477931522,
#  ('bair', 'pcv'): 6.90875477931522,
#  ('hunger', 'mso'): -6.90875477931522,
#  ('grave', 'sluggish'): 6.90875477931522,
#  ('splint', 'stair'): 6.90875477931522,
#  ('dni', 'ppn'): 6.90875477931522,
#  ('calculi', 'homogen'): 6.90875477931522,
#  ('colonoscopi', 'epidur'): 6.90875477931522,
#  ('aox', 'dni'): 6.90875477931522,
#  ('jewelri', 'redirect'): -6.90875477931522,
#  ('hypothermia', 'sensat'): 6.90875477931522,
#  ('bipolar', 'ppd'): 6.90875477931522,
#  ('gait', 'soln'): 6.90875477931522,
#  ('fatti', 'hilum'): 0.6916505477038827,
#  ('icter', 'mellitu'): 6.90875477931522,
#  ('ambul', 'sibl'): 6.90875477931522,
#  ('omeprazol', 'osa'): 6.90875477931522,
#  ('agon', 'mso'): -6.90875477931522,
#  ('qam', 'strictur'): 6.90875477931522,
#  ('ctx', 'readmit'): 6.90875477931522,
#  ('asthma', 'morbid'): 6.90875477931522,
#  ('schizophrenia', 'seroquel'): 6.90875477931522,
#  ('barium', 'osa'): 6.90875477931522,
#  ('pleasant', 'ppd'): 6.90875477931522,
#  ('habitu', 'mean'): 6.90875477931522,
#  ('asthma', 'phlegm'): 6.90875477931522,
#  ('dnr', 'xii'): -1.604655121332035,
#  ('behavior', 'rm'): 6.90875477931522,
#  ('cdb', 'phlegm'): 6.90875477931522,
#  ('bottl', 'gc'): 6.90875477931522,
#  ('hctz', 'protrud'): 6.90875477931522,
#  ('banana', 'historian'): 6.90875477931522,
#  ('defibril', 'tran'): 6.90875477931522,
#  ('dopamin', 'furhter'): -6.90875477931522,
#  ('dopamin', 'moan'): -6.90875477931522,
#  ('ba', 'bottl'): 6.90875477931522,
#  ('intent', 'phlegm'): 6.90875477931522,
#  ('dni', 'quinolon'): -6.90875477931522,
#  ('myeloma', 'xii'): -6.90875477931522,
#  ('banana', 'omeprazol'): 6.90875477931522,
#  ('anur', 'chair'): -6.90875477931522,
#  ('klonopin', 'unsteadi'): 6.90875477931522,
#  ('gastrojejunostomi', 'metoclopramid'): 6.90875477931522,
#  ('opiat', 'pharyng'): 6.90875477931522,
#  ('gvhd', 'nephrolog'): 6.90875477931522,
#  ('gastrojejunostomi', 'sarna'): 6.90875477931522,
#  ('dni', 'synthet'): -6.90875477931522,
#  ('chair', 'rigor'): 6.90875477931522,
#  ('pharyng', 'video'): 6.90875477931522,
#  ('anaphylaxi', 'seroquel'): 6.90875477931522,
#  ('dopamin', 'levof'): -6.90875477931522,
#  ('nocturn', 'rhinorrhea'): 6.90875477931522,
#  ('incis', 'occipit'): 6.90875477931522,
#  ('dnr', 'zoloft'): -1.3825560390092835,
#  ('assymetr', 'puff'): 6.90875477931522,
#  ('expir', 'levof'): -6.90875477931522,
#  ('hctz', 'nifedipin'): 6.90875477931522,
#  ('esld', 'ffp'): -0.8191521327074153,
#  ('lotion', 'metoclopramid'): 6.90875477931522,
#  ('chair', 'iddm'): 6.90875477931522,
#  ('adenosin', 'tcdb'): 6.90875477931522,
#  ('dni', 'hunger'): -1.8806492362025307,
#  ('phenylephrin', 'requr'): -6.90875477931522,
#  ('dnr', 'morgu'): -6.90875477931522,
#  ('olanzapin', 'qtc'): 6.90875477931522,
#  ('dnr', 'oob'): 0.509761227710204,
#  ('adam', 'levoph'): -6.90875477931522,
#  ('asthma', 'commod'): 6.90875477931522,
#  ('dic', 'hung'): -6.90875477931522,
#  ('flight', 'rhinorrhea'): 6.90875477931522,
#  ('chair', 'vagu'): 6.90875477931522,
#  ('habitu', 'hive'): 6.90875477931522,
#  ('pronounc', 'vasopressin'): -6.90875477931522,
#  ('nonlabor', 'oob'): 6.90875477931522,
#  ('diaper', 'nicotin'): 6.90875477931522,
#  ('bipolar', 'clonidin'): 6.90875477931522,
#  ('dnr', 'retic'): 6.90875477931522,
#  ('dead', 'nimv'): -6.90875477931522,
#  ('asthma', 'corneal'): -6.90875477931522,
#  ('cyanot', 'furhter'): -6.90875477931522,
#  ('perisplen', 'plerual'): 6.90875477931522,
#  ('contractur', 'criticar'): 6.90875477931522,
#  ('hypothermia', 'mind'): 6.90875477931522,
#  ('omeprazol', 'sibl'): 6.90875477931522,
#  ('asthma', 'jewelri'): 6.90875477931522,
#  ('dex', 'levoph'): 6.90875477931522,
#  ('phasic', 'unstabl'): 6.90875477931522,
#  ('chair', 'palli'): 6.90875477931522,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('furhter', 'gvhd'): -6.90875477931522,
#  ('death', 'trazodon'): 6.90875477931522,
#  ('angiogram', 'flight'): 6.90875477931522,
#  ('dnr', 'sibl'): 6.90875477931522,
#  ('levoph', 'nectar'): 6.90875477931522,
#  ('impli', 'peribronchovascular'): 6.90875477931522,
#  ('hctz', 'pleasant'): 6.90875477931522,
#  ('hugger', 'pcv'): 6.90875477931522,
#  ('nifedipin', 'nonrebreath'): 6.90875477931522,
#  ('mrg', 'weekli'): 6.90875477931522,
#  ('azotemia', 'thiamin'): 6.90875477931522,
#  ('mtg', 'seroquel'): 6.90875477931522,
#  ('nephrolog', 'stair'): 6.90875477931522,
#  ('burn', 'lighthead'): 6.90875477931522,
#  ('laminectomi', 'predict'): 6.90875477931522,
#  ('struggl', 'xii'): -6.90875477931522,
#  ('ciwa', 'lusb'): 6.90875477931522,
#  ('kerlix', 'vigil'): 6.90875477931522,
#  ('aricept', 'chair'): -6.90875477931522,
#  ('dni', 'gvhd'): 6.90875477931522,
#  ('aprv', 'gvhd'): -6.90875477931522,
#  ('diaphoresi', 'hunger'): 6.90875477931522,
#  ('norepinephrin', 'phenylephrin'): -6.90875477931522,
#  ('sensat', 'thiamin'): 6.90875477931522,
#  ('contractur', 'neo'): 6.90875477931522,
#  ('hive', 'palli'): -6.90875477931522,
#  ('compani', 'dizzi'): 6.90875477931522,
#  ('echocardiogram', 'ligament'): 6.90875477931522,
#  ('qtc', 'venti'): 6.90875477931522,
#  ('dnr', 'ruptur'): 6.90875477931522,
#  ('pcv', 'pea'): -6.90875477931522,
#  ('svv', 'vasopressin'): -6.90875477931522,
#  ('fibrinogen', 'suffer'): 6.90875477931522,
#  ('furhter', 'rescan'): 6.90875477931522,
#  ('ardsnet', 'wma'): -6.90875477931522,
#  ('diaphoresi', 'strictur'): 6.90875477931522,
#  ('massag', 'oncologist'): 6.90875477931522,
#  ('lusb', 'romi'): 6.90875477931522,
#  ('asthma', 'ruptur'): 6.90875477931522,
#  ('assymetr', 'echocardiogram'): 6.90875477931522,
#  ('ambul', 'aricept'): 6.90875477931522,
#  ('sweat', 'thiamin'): 6.90875477931522,
#  ('coach', 'gait'): 6.90875477931522,
#  ('clinician', 'escal'): -6.90875477931522,
#  ('dizzi', 'rhinorrhea'): 6.90875477931522,
#  ('phlegm', 'stair'): 6.90875477931522,
#  ('dopamin', 'liw'): -6.90875477931522,
#  ('declin', 'money'): 6.90875477931522,
#  ('crack', 'ctx'): 6.90875477931522,
#  ('klonopin', 'strictur'): 6.90875477931522,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('cdb', 'dizzi'): 6.90875477931522,
#  ('hhn', 'lpm'): 6.90875477931522,
#  ('dermat', 'gadolinium'): 6.90875477931522,
#  ('chip', 'venti'): 6.90875477931522,
#  ('arrest', 'bottl'): 6.90875477931522,
#  ('chair', 'uncoop'): 6.90875477931522,
#  ('death', 'mso'): -6.90875477931522,
#  ('cdb', 'spiromet'): 6.90875477931522,
#  ('emper', 'moan'): 6.90875477931522,
#  ('death', 'dopamin'): -6.90875477931522,
#  ('pleasant', 'qam'): 6.90875477931522,
#  ('syncop', 'young'): 6.90875477931522,
#  ('ambien', 'unsteadi'): 6.90875477931522,
#  ('pinpoint', 'rusti'): 6.90875477931522,
#  ('db', 'levoph'): 6.90875477931522,
#  ('foci', 'tubular'): 6.90875477931522,
#  ('dni', 'sibl'): 6.90875477931522,
#  ('acc', 'ba'): 6.90875477931522,
#  ('hilum', 'vertebra'): -6.90875477931522,
#  ('dnr', 'modifi'): 6.90875477931522,
#  ('align', 'simpli'): 6.90875477931522,
#  ('chip', 'oob'): 6.90875477931522,
#  ('azotemia', 'calculi'): 6.90875477931522,
#  ('anyway', 'dnr'): 6.90875477931522,
#  ('aox', 'bottl'): 6.90875477931522,
#  ('habitu', 'occupi'): 6.90875477931522,
#  ('fatti', 'syncop'): 6.90875477931522,
#  ('ferrou', 'puff'): 6.90875477931522,
#  ('captopril', 'laryng'): 6.90875477931522,
#  ('crack', 'pleasant'): 6.90875477931522,
#  ('commod', 'kerlix'): 6.90875477931522,
#  ('dnr', 'hook'): 6.90875477931522,
#  ('hemothorax', 'levoph'): -6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('rememb', 'thiamin'): 6.90875477931522,
#  ('anaphylaxi', 'opiat'): 6.90875477931522,
#  ('hemothorax', 'platelet'): -6.90875477931522,
#  ('captopril', 'palli'): 6.90875477931522,
#  ('dopamin', 'unasyn'): 6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('herp', 'stair'): 6.90875477931522,
#  ('dnr', 'signatur'): -0.4046335072286383,
#  ('gasp', 'hilum'): -6.90875477931522,
#  ('pleasant', 'unsteadi'): 6.90875477931522,
#  ('dz', 'postop'): 6.90875477931522,
#  ('ctx', 'trazodon'): 6.90875477931522,
#  ('conc', 'dnr'): 6.90875477931522,
#  ('articul', 'rehabilit'): 6.90875477931522,
#  ('mellitu', 'mood'): 6.90875477931522,
#  ('ba', 'dietari'): 6.90875477931522,
#  ('readmit', 'subdur'): 6.90875477931522,
#  ('absorb', 'option'): 6.90875477931522,
#  ('argatroban', 'levoph'): -6.90875477931522,
#  ('compani', 'oob'): 6.90875477931522,
#  ('gastrojejunostomi', 'nephrogram'): 6.90875477931522,
#  ('moan', 'phenylephrin'): -6.90875477931522,
#  ('calculi', 'puff'): 6.90875477931522,
#  ('gait', 'pleasant'): 6.90875477931522,
#  ('itchi', 'lotion'): 6.90875477931522,
#  ('ferritin', 'romi'): 6.90875477931522,
#  ('bottl', 'coach'): 6.90875477931522,
#  ('dyslipidemia', 'osa'): 6.90875477931522,
#  ('carvedilol', 'video'): 6.90875477931522,
#  ('cmo', 'dead'): -6.90875477931522,
#  ('flight', 'nephrolog'): 6.90875477931522,
#  ('escal', 'ultram'): 6.90875477931522,
#  ('dead', 'neosynephrin'): -6.90875477931522,
#  ('oligur', 'permiss'): -6.90875477931522,
#  ('adenosin', 'oob'): 6.90875477931522,
#  ('ppd', 'young'): 6.90875477931522,
#  ('sarna', 'soln'): 6.90875477931522,
#  ('oligur', 'vasopressin'): 0.44092196573215015,
#  ('azotemia', 'prilosec'): -6.90875477931522,
#  ('sluggishli', 'wma'): -6.90875477931522,
#  ('cmo', 'unrel'): -6.90875477931522,
#  ('anaphylaxi', 'muddi'): 6.90875477931522,
#  ('anur', 'mso'): -6.90875477931522,
#  ('levoph', 'phlegm'): -6.90875477931522,
#  ('asthma', 'mean'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('declin', 'rabbi'): -6.90875477931522,
#  ('hemangioma', 'phasic'): 6.90875477931522,
#  ('profound', 'rabbi'): -6.90875477931522,
#  ('dopamin', 'echocardiogram'): 6.90875477931522,
#  ('cocain', 'rm'): 6.90875477931522,
#  ('death', 'pronounc'): -6.90875477931522,
#  ('azotemia', 'xii'): 6.90875477931522,
#  ('declin', 'mellitu'): 6.90875477931522,
#  ('cmo', 'pinpoint'): -6.90875477931522,
#  ('dnr', 'mean'): -6.90875477931522,
#  ('chair', 'nonrebreath'): 6.90875477931522,
#  ('exophyt', 'peribronchovascular'): 6.90875477931522,
#  ('incent', 'spacer'): 6.90875477931522,
#  ('barium', 'burn'): 6.90875477931522,
#  ('sensat', 'xii'): 6.90875477931522,
#  ('adam', 'prognosi'): -6.90875477931522,
#  ('commod', 'compani'): 6.90875477931522,
#  ('db', 'sweat'): 6.90875477931522,
#  ('chair', 'gurgl'): -6.90875477931522,
#  ('furhter', 'neoplast'): 6.90875477931522,
#  ('hive', 'trazodon'): 6.90875477931522,
#  ('diaphoresi', 'pleasant'): 6.90875477931522,
#  ('mellitu', 'surviv'): 6.90875477931522,
#  ('criticar', 'dnr'): 6.90875477931522,
#  ('gabapentin', 'morbid'): 6.90875477931522,
#  ('platelet', 'young'): 6.90875477931522,
#  ('sibl', 'unstabl'): -6.90875477931522,
#  ('iddm', 'uri'): 6.90875477931522,
#  ('dizzi', 'syncop'): 6.90875477931522,
#  ('dni', 'lw'): 6.90875477931522,
#  ('declin', 'palli'): 1.7859498421315991,
#  ('asystol', 'morgu'): -6.90875477931522,
#  ('spill', 'video'): 6.90875477931522,
#  ('epidur', 'unsteadi'): 6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('osa', 'zyprexa'): 6.90875477931522,
#  ('dnr', 'dyslipidemia'): 6.90875477931522,
#  ('qam', 'zyprexa'): -6.90875477931522,
#  ('arrest', 'clonazepam'): 6.90875477931522,
#  ('gait', 'rigor'): 6.90875477931522,
#  ('db', 'signatur'): 6.90875477931522,
#  ('bottl', 'occipit'): 6.90875477931522,
#  ('dic', 'platelet'): -0.2770704566718008,
#  ('diaphoresi', 'stitch'): 6.90875477931522,
#  ('hive', 'lat'): 6.90875477931522,
#  ('maroon', 'simpli'): 6.90875477931522,
#  ('life', 'paralyt'): -6.90875477931522,
#  ('ctx', 'video'): 6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('rigor', 'zero'): 6.90875477931522,
#  ('adenocarcinoma', 'pleasant'): 6.90875477931522,
#  ('hover', 'nahco'): 6.90875477931522,
#  ('mso', 'wish'): -6.90875477931522,
#  ('anaphylaxi', 'imbal'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('mood', 'sensat'): 6.90875477931522,
#  ('articul', 'cup'): 6.90875477931522,
#  ('chair', 'thk'): 6.90875477931522,
#  ('pea', 'scar'): 6.90875477931522,
#  ('anaphylaxi', 'xl'): 6.90875477931522,
#  ('ferrou', 'motor'): 6.90875477931522,
#  ('^rr', 'moan'): 6.90875477931522,
#  ('levoph', 'oob'): 6.90875477931522,
#  ('seat', 'subcost'): 6.90875477931522,
#  ('cyanot', 'fungemia'): -6.90875477931522,
#  ('aaox', 'effac'): 6.90875477931522,
#  ('incent', 'rm'): 6.90875477931522,
#  ('adam', 'deterior'): -6.90875477931522,
#  ('arrest', 'chair'): 6.90875477931522,
#  ('cloth', 'dnr'): 0.0,
#  ('pneumococc', 'ppd'): 6.90875477931522,
#  ('ambien', 'elimin'): 6.90875477931522,
#  ('unstabl', 'vasopressin'): -6.90875477931522,
#  ('agon', 'expir'): -6.90875477931522,
#  ('echocardiogram', 'fatti'): 6.90875477931522,
#  ('dnr', 'town'): 6.90875477931522,
#  ('anur', 'omeprazol'): 6.90875477931522,
#  ('death', 'deterior'): -6.90875477931522,
#  ('slice', 'smooth'): 0.0,
#  ('hive', 'nocturn'): 6.90875477931522,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('dni', 'paperwork'): 1.3825560390092835,
#  ('abnl', 'laminectomi'): 6.90875477931522,
#  ('barium', 'spur'): 6.90875477931522,
#  ('lat', 'rehabilit'): 6.90875477931522,
#  ('ashen', 'romi'): 6.90875477931522,
#  ('^th', 'dni'): 6.90875477931522,
#  ('permiss', 'pleasant'): 6.90875477931522,
#  ('hctz', 'xii'): 6.90875477931522,
#  ('cvo', 'hive'): 6.90875477931522,
#  ('barium', 'silent'): 6.90875477931522,
#  ('pleasantli', 'seroquel'): 6.90875477931522,
#  ('db', 'respon'): 6.90875477931522,
#  ('ppd', 'silent'): 6.90875477931522,
#  ('chb', 'platelet'): -6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('acidot', 'fdp'): -6.90875477931522,
#  ('asthma', 'nicotin'): 6.90875477931522,
#  ('para', 'uri'): 6.90875477931522,
#  ('aaox', 'pod'): 6.90875477931522,
#  ('burn', 'unstabl'): 6.90875477931522,
#  ('acc', 'young'): 6.90875477931522,
#  ('endplat', 'osa'): 6.90875477931522,
#  ('epidur', 'im'): 6.90875477931522,
#  ('cpr', 'profound'): -6.90875477931522,
#  ('sweat', 'xl'): 6.90875477931522,
#  ('bottl', 'currenlti'): 6.90875477931522,
#  ('fc', 'osa'): 6.90875477931522,
#  ('method', 'predict'): -6.90875477931522,
#  ('hilum', 'peribronchovascular'): 0.0,
#  ('ferrou', 'xl'): 6.90875477931522,
#  ('life', 'pastor'): -6.90875477931522,
#  ('arrest', 'asystol'): -6.90875477931522,
#  ('arrest', 'norepinephrin'): -6.90875477931522,
#  ('appi', 'venti'): 6.90875477931522,
#  ('clonidin', 'dz'): 6.90875477931522,
#  ('angiogram', 'option'): 6.90875477931522,
#  ('intiat', 'panic'): 6.90875477931522,
#  ('mellitu', 'wish'): 6.90875477931522,
#  ('oncologist', 'paperwork'): 6.90875477931522,
#  ('gabapentin', 'lat'): 6.90875477931522,
#  ('intiat', 'mso'): -6.90875477931522,
#  ('pea', 'sluggish'): -6.90875477931522,
#  ('cpr', 'death'): -6.90875477931522,
#  ('dex', 'dopamin'): 6.90875477931522,
#  ('acc', 'aricept'): 6.90875477931522,
#  ('esophagogastr', 'hemithorac'): -6.90875477931522,
#  ('gait', 'gastriti'): 6.90875477931522,
#  ('dome', 'homogen'): 6.90875477931522,
#  ('agon', 'pronounc'): -6.90875477931522,
#  ('neo', 'readdress'): -6.90875477931522,
#  ('chair', 'intent'): 6.90875477931522,
#  ('ardsnet', 'levoph'): 1.3256334536733387,
#  ('bromid', 'mellitu'): 6.90875477931522,
#  ('arrest', 'bicarbon'): -6.90875477931522,
#  ('cyanot', 'dni'): -6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('dizzi', 'sarna'): 6.90875477931522,
#  ('hospic', 'xanax'): 6.90875477931522,
#  ('puff', 'thiamin'): 6.90875477931522,
#  ('judgement', 'rememb'): 6.90875477931522,
#  ('breakfast', 'neo'): 6.90875477931522,
#  ('ciwa', 'echocardiogram'): 6.90875477931522,
#  ('rememb', 'ruptur'): 6.90875477931522,
#  ('mean', 'stg'): -6.90875477931522,
#  ('cs', 'lpm'): -6.90875477931522,
#  ('chb', 'zyprexa'): 6.90875477931522,
#  ('klonopin', 'sweat'): 6.90875477931522,
#  ('hung', 'pea'): -6.90875477931522,
#  ('dopamin', 'vasopressor'): -6.90875477931522,
#  ('bicarbon', 'sluggishli'): -6.90875477931522,
#  ('banana', 'rememb'): 6.90875477931522,
#  ('dni', 'underneath'): -6.90875477931522,
#  ('osa', 'uri'): 6.90875477931522,
#  ('dnr', 'pleasant'): 1.3825560390092835,
#  ('fdp', 'rhinorrhea'): -6.90875477931522,
#  ('cash', 'cdb'): 6.90875477931522,
#  ('chb', 'gurgl'): -6.90875477931522,
#  ('nifedipin', 'robitussin'): 6.90875477931522,
#  ('clonidin', 'wish'): 6.90875477931522,
#  ('klonopin', 'mycolyt'): 6.90875477931522,
#  ('mtg', 'omeprazol'): 6.90875477931522,
#  ('pneumococc', 'subq'): 6.90875477931522,
#  ('pcv', 'phenylephrin'): -6.90875477931522,
#  ('mortem', 'unequ'): -6.90875477931522,
#  ('dysynchron', 'neo'): -6.90875477931522,
#  ('captopril', 'tcdb'): 6.90875477931522,
#  ('ciwa', 'omeprazol'): 6.90875477931522,
#  ('captopril', 'nephrolog'): 6.90875477931522,
#  ('nectar', 'pleasantli'): 6.90875477931522,
#  ('cpr', 'norepinephrin'): -6.90875477931522,
#  ('sensat', 'unstabl'): 6.90875477931522,
#  ('aricept', 'jewelri'): -6.90875477931522,
#  ('incis', 'video'): 6.90875477931522,
#  ('thiamin', 'unasyn'): 6.90875477931522,
#  ('chair', 'dz'): 6.90875477931522,
#  ('neo', 'norepinephrin'): -2.625239572123001,
#  ('conc', 'flake'): 6.90875477931522,
#  ('gait', 'vasopressin'): -6.90875477931522,
#  ('cocain', 'klonopin'): 6.90875477931522,
#  ('barium', 'pathologist'): 6.90875477931522,
#  ('angioplasti', 'deploy'): 6.90875477931522,
#  ('nifedipin', 'splint'): 6.90875477931522,
#  ('dni', 'gabapentin'): 6.90875477931522,
#  ('dni', 'trabecul'): 6.90875477931522,
#  ('ambul', 'ferrou'): 6.90875477931522,
#  ('dz', 'pneumococc'): 6.90875477931522,
#  ('adenosin', 'vasopressin'): 6.90875477931522,
#  ('peribronchovascular', 'requr'): 6.90875477931522,
#  ('azotemia', 'rhinorrhea'): -6.90875477931522,
#  ('ggo', 'iddm'): 6.90875477931522,
#  ('diaper', 'tran'): 6.90875477931522,
#  ('ciwa', 'itchi'): 6.90875477931522,
#  ('historian', 'jewelri'): 6.90875477931522,
#  ('anaphylaxi', 'zoloft'): 6.90875477931522,
#  ('bicarbon', 'oligur'): -6.90875477931522,
#  ('clonidin', 'romi'): 6.90875477931522,
#  ('breakfast', 'mellitu'): 6.90875477931522,
#  ('echocardiogram', 'ppn'): 6.90875477931522,
#  ('anuria', 'crrt'): -6.90875477931522,
#  ('oob', 'wallet'): 6.90875477931522,
#  ('money', 'redirect'): -6.90875477931522,
#  ('fibrinogen', 'pastor'): -6.90875477931522,
#  ('declin', 'norepinephrin'): -6.90875477931522,
#  ('echocardiogram', 'retic'): 6.90875477931522,
#  ('bromid', 'dni'): 6.90875477931522,
#  ('diuril', 'dopamin'): 6.90875477931522,
#  ('commod', 'jewelri'): -6.90875477931522,
#  ('rabbi', 'suffer'): -6.90875477931522,
#  ('pharyng', 'rhinorrhea'): 6.90875477931522,
#  ('argatroban', 'crrt'): -6.90875477931522,
#  ('aricept', 'lusb'): 6.90875477931522,
#  ('asthma', 'ppd'): 6.90875477931522,
#  ('stack', 'underpenetr'): -6.90875477931522,
#  ('ba', 'hctz'): 6.90875477931522,
#  ('life', 'mean'): 6.90875477931522,
#  ('qam', 'subq'): 6.90875477931522,
#  ('cash', 'pivot'): -6.90875477931522,
#  ('angiogram', 'slice'): 6.90875477931522,
#  ('hospic', 'stg'): -6.90875477931522,
#  ('abruptli', 'expir'): -6.90875477931522,
#  ('dni', 'lymphangit'): 6.90875477931522,
#  ('anaphylaxi', 'morbid'): 6.90875477931522,
#  ('gc', 'lpm'): 6.90875477931522,
#  ('mottl', 'option'): -6.90875477931522,
#  ('acc', 'angri'): 6.90875477931522,
#  ('habitu', 'ppd'): 6.90875477931522,
#  ('cellcept', 'hospic'): 6.90875477931522,
#  ('deterior', 'suffer'): -6.90875477931522,
#  ('dni', 'proph'): 6.90875477931522,
#  ('mjmgb', 'plate'): 6.90875477931522,
#  ('lpm', 'osa'): 6.90875477931522,
#  ('chair', 'tcdb'): 6.90875477931522,
#  ('agon', 'sluggish'): -6.90875477931522,
#  ('aaox', 'zyprexa'): 6.90875477931522,
#  ('clonidin', 'mellitu'): 6.90875477931522,
#  ('ctx', 'wma'): 6.90875477931522,
#  ('nectar', 'piriform'): 6.90875477931522,
#  ('artifici', 'xl'): -6.90875477931522,
#  ('gait', 'unsteadi'): 6.90875477931522,
#  ('im', 'profound'): 6.90875477931522,
#  ('declin', 'moan'): -6.90875477931522,
#  ('bank', 'wish'): 6.90875477931522,
#  ('oligur', 'wma'): -6.90875477931522,
#  ('cdb', 'diflucan'): 6.90875477931522,
#  ('fwb', 'tremul'): 6.90875477931522,
#  ('dizzi', 'lotion'): 6.90875477931522,
#  ('aaox', 'syst'): 6.90875477931522,
#  ('chol', 'hospic'): -6.90875477931522,
#  ('arrang', 'dnr'): -6.90875477931522,
#  ('captopril', 'twitch'): 6.90875477931522,
#  ('agon', 'deterior'): -6.90875477931522,
#  ('ctx', 'hypothermia'): 6.90875477931522,
#  ('bottl', 'seriou'): 6.90875477931522,
#  ('cdb', 'money'): 6.90875477931522,
#  ('foci', 'scar'): 6.90875477931522,
#  ('escal', 'wish'): -6.90875477931522,
#  ('mucinex', 'omeprazol'): 6.90875477931522,
#  ('gabapentin', 'unstabl'): 6.90875477931522,
#  ('dopamin', 'prognosi'): -6.90875477931522,
#  ('neo', 'vasopressin'): -0.6618713625681694,
#  ('dni', 'unobtain'): 0.6916505477038827,
#  ('dnr', 'jewelri'): -0.4046335072286383,
#  ('ashen', 'declin'): 6.90875477931522,
#  ('freeli', 'vallecula'): 6.90875477931522,
#  ('jewelri', 'pleasant'): -0.4046335072286383,
#  ('omeprazol', 'para'): 6.90875477931522,
#  ('db', 'para'): 6.90875477931522,
#  ('azotemia', 'qam'): 6.90875477931522,
#  ('intiat', 'jerk'): -6.90875477931522,
#  ('cdb', 'ctx'): 6.90875477931522,
#  ('declin', 'hive'): 6.90875477931522,
#  ('core', 'fibrinogen'): -6.90875477931522,
#  ('cloth', 'thiamin'): 6.90875477931522,
#  ('distort', 'slice'): -6.90875477931522,
#  ('bipolar', 'chip'): 6.90875477931522,
#  ('hugger', 'paralyt'): 6.90875477931522,
#  ('prognosi', 'viabl'): -6.90875477931522,
#  ('barium', 'panic'): 6.90875477931522,
#  ('declar', 'dopamin'): -6.90875477931522,
#  ('oob', 'sundown'): 6.90875477931522,
#  ('aaox', 'nimv'): 6.90875477931522,
#  ('hive', 'stitch'): 6.90875477931522,
#  ('ambien', 'dyslipidemia'): 6.90875477931522,
#  ('aricept', 'colonoscopi'): 6.90875477931522,
#  ('homogen', 'treitz'): 6.90875477931522,
#  ('occipit', 'seriou'): 6.90875477931522,
#  ('mellitu', 'pod'): 6.90875477931522,
#  ('diaper', 'dnr'): 6.90875477931522,
#  ('captopril', 'predict'): 6.90875477931522,
#  ('adam', 'icter'): -6.90875477931522,
#  ('pathologist', 'video'): 6.90875477931522,
#  ('azotemia', 'fibrinogen'): 1.3825560390092835,
#  ('bicarbon', 'stitch'): 6.90875477931522,
#  ('echocardiogram', 'thiamin'): 6.90875477931522,
#  ('cash', 'klonopin'): 6.90875477931522,
#  ('captopril', 'scar'): 6.90875477931522,
#  ('bipolar', 'clonazepam'): 6.90875477931522,
#  ('silent', 'young'): 6.90875477931522,
#  ('meatu', 'trabecul'): -6.90875477931522,
#  ('brb', 'fibrinogen'): -6.90875477931522,
#  ('pronounc', 'unequ'): -6.90875477931522,
#  ('hemangioma', 'plerual'): 6.90875477931522,
#  ('ctx', 'lotion'): 6.90875477931522,
#  ('deterior', 'lift'): 6.90875477931522,
#  ('mellitu', 'stair'): 6.90875477931522,
#  ('peribronchovascular', 'plate'): 6.90875477931522,
#  ('ctx', 'schizophrenia'): 6.90875477931522,
#  ('phlegm', 'splint'): 6.90875477931522,
#  ('cyanot', 'lw'): -6.90875477931522,
#  ('aox', 'laminectomi'): 6.90875477931522,
#  ('clinician', 'occipit'): 6.90875477931522,
#  ('qam', 'rememb'): 6.90875477931522,
#  ('abnl', 'clonidin'): 6.90875477931522,
#  ('epigastr', 'nifedipin'): 6.90875477931522,
#  ('ipf', 'norepinephrin'): -6.90875477931522,
#  ('chair', 'levoph'): 6.90875477931522,
#  ('ferrou', 'rhinorrhea'): 6.90875477931522,
#  ('declar', 'religi'): -6.90875477931522,
#  ('dnr', 'pleuravac'): -6.90875477931522,
#  ('mellitu', 'scar'): 6.90875477931522,
#  ('asthma', 'autoset'): 6.90875477931522,
#  ('ambien', 'spacer'): 6.90875477931522,
#  ('im', 'mva'): 6.90875477931522,
#  ('ferritin', 'platelet'): 6.90875477931522,
#  ('ctx', 'im'): 6.90875477931522,
#  ('furhter', 'lw'): -6.90875477931522,
#  ('omeprazol', 'qam'): 6.90875477931522,
#  ('mva', 'td'): 6.90875477931522,
#  ('pneumococc', 'puff'): 6.90875477931522,
#  ('mso', 'oob'): 6.90875477931522,
#  ('mva', 'spacer'): 6.90875477931522,
#  ('lpm', 'myeloma'): -1.3825560390092835,
#  ('mtg', 'paralyt'): -6.90875477931522,
#  ('hugger', 'levoph'): 1.6688498669946448,
#  ('permiss', 'pose'): 6.90875477931522,
#  ('bronchovascular', 'crowd'): 1.462247919771027,
#  ('dead', 'dopamin'): -6.90875477931522,
#  ('hida', 'mjmgb'): 6.90875477931522,
#  ('ferrou', 'gait'): 6.90875477931522,
#  ('life', 'neo'): 6.90875477931522,
#  ('phlegm', 'wish'): -6.90875477931522,
#  ('leukocyt', 'scar'): 6.90875477931522,
#  ('puff', 'xl'): 6.90875477931522,
#  ('deliv', 'respitori'): 6.90875477931522,
#  ('neosynephrin', 'pitressin'): -6.90875477931522,
#  ('dz', 'venti'): 6.90875477931522,
#  ('hypercapnia', 'oob'): 6.90875477931522,
#  ('dyslipidemia', 'rhinorrhea'): 6.90875477931522,
#  ('flight', 'pleasant'): 6.90875477931522,
#  ('ctx', 'suffer'): 6.90875477931522,
#  ('im', 'sweat'): 6.90875477931522,
#  ('acidot', 'grim'): -6.90875477931522,
#  ('agon', 'grim'): -6.90875477931522,
#  ('asthma', 'dermat'): 6.90875477931522,
#  ('gastriti', 'xii'): 6.90875477931522,
#  ('asthma', 'intent'): 6.90875477931522,
#  ('ctx', 'palli'): 6.90875477931522,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('ppn', 'prognosi'): 6.90875477931522,
#  ('colonoscopi', 'readdress'): 6.90875477931522,
#  ('ambul', 'levoph'): 6.90875477931522,
#  ('hilum', 'lymphangit'): 6.90875477931522,
#  ('cocain', 'ultram'): 6.90875477931522,
#  ('chb', 'dni'): 0.0,
#  ('angiogram', 'gadolinium'): 6.90875477931522,
#  ('db', 'hive'): 6.90875477931522,
#  ('neo', 'palli'): -6.90875477931522,
#  ('bill', 'fibrinogen'): 6.90875477931522,
#  ('oob', 'prec'): 6.90875477931522,
#  ('epigastr', 'fibrinogen'): 6.90875477931522,
#  ('preme', 'zero'): 6.90875477931522,
#  ('aaox', 'subdur'): 6.90875477931522,
#  ('diaphoresi', 'lighthead'): 6.90875477931522,
#  ('incis', 'opinion'): 6.90875477931522,
#  ('impli', 'pea'): 6.90875477931522,
#  ('puff', 'qam'): 6.90875477931522,
#  ('bottl', 'pea'): 6.90875477931522,
#  ('asthma', 'mucinex'): 6.90875477931522,
#  ('deliv', 'dni'): 6.90875477931522,
#  ('brb', 'unstabl'): -6.90875477931522,
#  ('ferritin', 'wish'): 6.90875477931522,
#  ('levoph', 'pleasant'): 6.90875477931522,
#  ('dnr', 'muddi'): 1.0271828417136022,
#  ('bipolar', 'olanzapin'): 6.90875477931522,
#  ('asthma', 'seroquel'): 6.90875477931522,
#  ('gastrojejunostomi', 'soln'): 6.90875477931522,
#  ('commod', 'spiromet'): 6.90875477931522,
#  ('natg', 'scar'): -6.90875477931522,
#  ('fdp', 'petechia'): -6.90875477931522,
#  ('bicarbon', 'wma'): -6.90875477931522,
#  ('acidot', 'ffp'): -6.90875477931522,
#  ('autoset', 'db'): 6.90875477931522,
#  ('behavior', 'readmit'): 6.90875477931522,
#  ('diaphoresi', 'hygein'): 6.90875477931522,
#  ('option', 'thrive'): -6.90875477931522,
#  ('gastrojejunostomi', 'ligament'): 6.90875477931522,
#  ('nicotin', 'xopenex'): 6.90875477931522,
#  ('breakfast', 'sensat'): 6.90875477931522,
#  ('diaphoresi', 'dizzi'): 6.90875477931522,
#  ('dome', 'lat'): 6.90875477931522,
#  ('crack', 'habitu'): 6.90875477931522,
#  ('hctz', 'young'): 6.90875477931522,
#  ('fibrinogen', 'rigor'): 6.90875477931522,
#  ('endur', 'pod'): 6.90875477931522,
#  ('icter', 'palli'): 6.90875477931522,
#  ('aricept', 'pivot'): -6.90875477931522,
#  ('ba', 'ppd'): 6.90875477931522,
#  ('clonazepam', 'seroquel'): 6.90875477931522,
#  ('aaox', 'lac'): 6.90875477931522,
#  ('currenlti', 'trabecul'): 6.90875477931522,
#  ('norepinephrin', 'wma'): -6.90875477931522,
#  ('itchi', 'wish'): 6.90875477931522,
#  ('^th', 'ciwa'): 6.90875477931522,
#  ('pleasant', 'wish'): 6.90875477931522,
#  ('commod', 'cyanot'): -6.90875477931522,
#  ('lift', 'mrg'): 6.90875477931522,
#  ('norepinephrin', 'recalibr'): 6.90875477931522,
#  ('esld', 'phenylephrin'): -0.06655815957840429,
#  ('oligur', 'sluggishli'): -6.90875477931522,
#  ('dead', 'vasopressin'): -6.90875477931522,
#  ('profound', 'vasopressin'): -6.90875477931522,
#  ('chair', 'redirect'): 6.90875477931522,
#  ('osa', 'pod'): 6.90875477931522,
#  ('hospic', 'ppn'): 6.90875477931522,
#  ('lat', 'occupi'): 6.90875477931522,
#  ('pose', 'vasoconstrict'): -6.90875477931522,
#  ('declin', 'romi'): 6.90875477931522,
#  ('pinpoint', 'sluggish'): -6.90875477931522,
#  ('ffp', 'vasopressin'): -6.90875477931522,
#  ...}

# %% [markdown]
# ### Train mode

# %% [markdown]
# #### Method 2. Each patient graph => [model training]

# %%
# Dictionaries to use
 # struct: {word: word2vec[128, numpy.array]}
patient_cooc_odd_scores # struct: {cooc_tuple: log_odds_score}
print()

# %%
patient_cooc_odd_scores
# Out:
# {('life', 'trazodon'): -6.90875477931522,
#  ('gadolinium', 'outer'): 6.90875477931522,
#  ('historian', 'uri'): 6.90875477931522,
#  ('aricept', 'dead'): -6.90875477931522,
#  ('ppn', 'retic'): 6.90875477931522,
#  ('hypothermia', 'wma'): 6.90875477931522,
#  ('bottl', 'rememb'): 6.90875477931522,
#  ('ctx', 'dietari'): 6.90875477931522,
#  ('lat', 'mva'): 6.90875477931522,
#  ('ba', 'omeprazol'): 6.90875477931522,
#  ('ashen', 'mellitu'): 6.90875477931522,
#  ('venti', 'young'): 6.90875477931522,
#  ('argatroban', 'vasopressin'): -6.90875477931522,
#  ('bottl', 'syncop'): 6.90875477931522,
#  ('cdb', 'incent'): 6.90875477931522,
#  ('incent', 'itchi'): 6.90875477931522,
#  ('dni', 'itchi'): 6.90875477931522,
#  ('mva', 'omeprazol'): 6.90875477931522,
#  ('dnr', 'palliat'): -6.90875477931522,
#  ('rememb', 'vertebra'): 6.90875477931522,
#  ('hypotherm', 'hypothermia'): 0.2508075216675933,
#  ('bronchovascular', 'fatti'): 6.90875477931522,
#  ('hypothermia', 'robitussin'): 6.90875477931522,
#  ('msicu', 'pleasant'): 6.90875477931522,
#  ('chair', 'spiromet'): 6.90875477931522,
#  ('death', 'ferrou'): 6.90875477931522,
#  ('absorb', 'uri'): 6.90875477931522,
#  ('foci', 'outer'): 6.90875477931522,
#  ('declin', 'scab'): 6.90875477931522,
#  ('cpr', 'pulseless'): -6.90875477931522,
#  ('profound', 'ration'): 6.90875477931522,
#  ('hook', 'qam'): 6.90875477931522,
#  ('nephrolog', 'pleasant'): 6.90875477931522,
#  ('declar', 'deterior'): -6.90875477931522,
#  ('clonidin', 'sibl'): 6.90875477931522,
#  ('recalibr', 'stitch'): 6.90875477931522,
#  ('levoph', 'mucinex'): 6.90875477931522,
#  ('corneal', 'dnr'): -6.90875477931522,
#  ('cg', 'dnr'): -6.90875477931522,
#  ('lpm', 'pleasant'): 6.90875477931522,
#  ('hsq', 'stair'): 6.90875477931522,
#  ('oncologist', 'pleasant'): 6.90875477931522,
#  ('dic', 'pyuria'): 6.90875477931522,
#  ('asthma', 'opiat'): 6.90875477931522,
#  ('dizzi', 'signatur'): 6.90875477931522,
#  ('commod', 'illeu'): -6.90875477931522,
#  ('cup', 'video'): 6.90875477931522,
#  ('echocardiogram', 'puff'): 6.90875477931522,
#  ('plerual', 'scar'): 6.90875477931522,
#  ('death', 'omeprazol'): 6.90875477931522,
#  ('aaox', 'chip'): 6.90875477931522,
#  ('pose', 'ran'): 6.90875477931522,
#  ('chair', 'tran'): 6.90875477931522,
#  ('cyanot', 'dopamin'): -6.90875477931522,
#  ('dietari', 'hsq'): 6.90875477931522,
#  ('captopril', 'lpm'): 6.90875477931522,
#  ('bromid', 'opiat'): 6.90875477931522,
#  ('clonidin', 'crowd'): 6.90875477931522,
#  ('autoset', 'declin'): 6.90875477931522,
#  ('core', 'icter'): -6.90875477931522,
#  ('dni', 'herp'): 6.90875477931522,
#  ('impli', 'video'): -6.90875477931522,
#  ('asthma', 'hsq'): 6.90875477931522,
#  ('laryng', 'pathologist'): 6.90875477931522,
#  ('aaox', 'commod'): 6.90875477931522,
#  ('pleasant', 'spacer'): 6.90875477931522,
#  ('liw', 'vasopressin'): -6.90875477931522,
#  ('levoph', 'mso'): -6.90875477931522,
#  ('cash', 'oob'): 6.90875477931522,
#  ('gait', 'sensat'): 6.90875477931522,
#  ('ciwa', 'ran'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('bipolar', 'gastriti'): 6.90875477931522,
#  ('declin', 'prognosi'): -1.9852670803394386,
#  ('hospic', 'underneath'): -6.90875477931522,
#  ('nifedipin', 'scar'): 6.90875477931522,
#  ('expir', 'neo'): -6.90875477931522,
#  ('cdb', 'dni'): 6.90875477931522,
#  ('bipolar', 'seroquel'): 6.90875477931522,
#  ('deterior', 'religi'): -6.90875477931522,
#  ('adam', 'hypotherm'): -6.90875477931522,
#  ('osa', 'panic'): 6.90875477931522,
#  ('endplat', 'magnevist'): 6.90875477931522,
#  ('dni', 'fwb'): 6.90875477931522,
#  ('spacer', 'unstabl'): 6.90875477931522,
#  ('dnr', 'hospic'): 0.025267268054695924,
#  ('hepatobiliari', 'synthet'): -6.90875477931522,
#  ('fibrinogen', 'nice'): 6.90875477931522,
#  ('elimin', 'pharyng'): 6.90875477931522,
#  ('fibrinogen', 'lusb'): 6.90875477931522,
#  ('dnr', 'gvhd'): 6.90875477931522,
#  ('cloth', 'pivot'): -6.90875477931522,
#  ('gastriti', 'predict'): 6.90875477931522,
#  ('acc', 'ctx'): 6.90875477931522,
#  ('db', 'dni'): 6.90875477931522,
#  ('duski', 'wish'): -6.90875477931522,
#  ('historian', 'opiat'): 6.90875477931522,
#  ('incis', 'omeprazol'): 6.90875477931522,
#  ('lat', 'sweat'): 6.90875477931522,
#  ('asthma', 'db'): 6.90875477931522,
#  ('lat', 'syncop'): 6.90875477931522,
#  ('gotten', 'msicu'): 6.90875477931522,
#  ('chair', 'cloth'): 6.90875477931522,
#  ('fu', 'ntnd'): 6.90875477931522,
#  ('gabapentin', 'shorter'): 6.90875477931522,
#  ('adam', 'neo'): -6.90875477931522,
#  ('nectar', 'pleasant'): 6.90875477931522,
#  ('phlegm', 'sensat'): 6.90875477931522,
#  ('levoph', 'lpm'): 6.90875477931522,
#  ('commod', 'levoph'): -0.25080752166759324,
#  ('ferritin', 'mellitu'): 6.90875477931522,
#  ('chb', 'hemothorax'): -6.90875477931522,
#  ('dnr', 'pea'): -6.90875477931522,
#  ('dnr', 'hsq'): 6.90875477931522,
#  ('dni', 'mrg'): 6.90875477931522,
#  ('fatti', 'ferritin'): 6.90875477931522,
#  ('dnr', 'osa'): 0.11100317119789695,
#  ('hypothermia', 'sweat'): 6.90875477931522,
#  ('hsq', 'lusb'): 6.90875477931522,
#  ('hypercapnia', 'pcv'): -6.90875477931522,
#  ('levoph', 'suffer'): -6.90875477931522,
#  ('asthma', 'itchi'): 6.90875477931522,
#  ('crack', 'dizzi'): 6.90875477931522,
#  ('magnevist', 'motor'): 6.90875477931522,
#  ('mrcp', 'synthet'): -6.90875477931522,
#  ('bottl', 'puff'): 6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('assymetr', 'ppd'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('aricept', 'syncop'): 6.90875477931522,
#  ('breakfast', 'panic'): 6.90875477931522,
#  ('cpr', 'hypothermia'): -6.90875477931522,
#  ('asthma', 'omeprazol'): 6.90875477931522,
#  ('oob', 'tran'): 6.90875477931522,
#  ('pleasant', 'subq'): 6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('expir', 'moan'): -6.90875477931522,
#  ('expir', 'homogen'): 6.90875477931522,
#  ('azotemia', 'echocardiogram'): 6.90875477931522,
#  ('historian', 'signatur'): 6.90875477931522,
#  ('gait', 'motor'): 6.90875477931522,
#  ('dnr', 'omeprazol'): 2.040109298143704,
#  ('hung', 'trazodon'): -6.90875477931522,
#  ('azotemia', 'platelet'): -6.90875477931522,
#  ('phlegm', 'spiromet'): 6.90875477931522,
#  ('oob', 'thrive'): 6.90875477931522,
#  ('sibl', 'subq'): 6.90875477931522,
#  ('levoph', 'pcv'): 6.90875477931522,
#  ('agon', 'neosynephrin'): -6.90875477931522,
#  ('arrest', 'hypercapnia'): -6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('motor', 'thiamin'): 6.90875477931522,
#  ('chb', 'dopamin'): 6.90875477931522,
#  ('puff', 'trazodon'): 6.90875477931522,
#  ('osa', 'strictur'): 6.90875477931522,
#  ('bill', 'gastrojejunostomi'): 6.90875477931522,
#  ('aricept', 'cash'): -6.90875477931522,
#  ('lighthead', 'schizophrenia'): 6.90875477931522,
#  ('robitussin', 'wish'): 6.90875477931522,
#  ('bromid', 'im'): 6.90875477931522,
#  ('colonoscopi', 'scar'): 6.90875477931522,
#  ('dni', 'laminectomi'): 6.90875477931522,
#  ('omeprazol', 'silent'): 6.90875477931522,
#  ('acetazolamid', 'fibrinogen'): 6.90875477931522,
#  ('contractur', 'dnr'): 0.6916505477038827,
#  ('opiat', 'seroquel'): 6.90875477931522,
#  ('im', 'romi'): 6.90875477931522,
#  ('refractori', 'young'): 6.90875477931522,
#  ('anaphylaxi', 'nocturn'): 6.90875477931522,
#  ('hsq', 'pleasant'): 6.90875477931522,
#  ('core', 'dic'): -6.90875477931522,
#  ('mood', 'zyprexa'): 6.90875477931522,
#  ('breakfast', 'uffp'): 6.90875477931522,
#  ('ba', 'opiat'): 6.90875477931522,
#  ('amb', 'oob'): 6.90875477931522,
#  ('azotemia', 'pneumococc'): 6.90875477931522,
#  ('asthma', 'iddm'): 6.90875477931522,
#  ('clonidin', 'gastriti'): 6.90875477931522,
#  ('bicarbon', 'readmit'): 6.90875477931522,
#  ('aricept', 'resucit'): 6.90875477931522,
#  ('cs', 'nicotin'): 6.90875477931522,
#  ('fibrinogen', 'osa'): 6.90875477931522,
#  ('chair', 'wish'): 6.90875477931522,
#  ('assymetr', 'underpenetr'): -6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('cocain', 'vagu'): 6.90875477931522,
#  ('dni', 'life'): 0.9141958635336067,
#  ('oob', 'readmit'): 6.90875477931522,
#  ('nephrolog', 'scar'): 6.90875477931522,
#  ('bicarbon', 'life'): -6.90875477931522,
#  ('asthma', 'chair'): 2.09609753878805,
#  ('cloth', 'redirect'): -6.90875477931522,
#  ('asthma', 'unavail'): 6.90875477931522,
#  ('laminectomi', 'schizophrenia'): 6.90875477931522,
#  ('oncologist', 'ppd'): 6.90875477931522,
#  ('adenocarcinoma', 'tremul'): 6.90875477931522,
#  ('gc', 'im'): 6.90875477931522,
#  ('cooki', 'laryng'): 6.90875477931522,
#  ('aox', 'clonidin'): 6.90875477931522,
#  ('calculi', 'refractori'): 6.90875477931522,
#  ('chair', 'jewelri'): 6.90875477931522,
#  ('qam', 'vagu'): 6.90875477931522,
#  ('foci', 'neo'): 6.90875477931522,
#  ('prilosec', 'wish'): 6.90875477931522,
#  ('compani', 'pleasant'): 6.90875477931522,
#  ('declin', 'dnr'): 2.7567935411197357,
#  ('hilum', 'zyprexa'): -6.90875477931522,
#  ('prognosi', 'unstabl'): -6.90875477931522,
#  ('death', 'dnr'): -6.90875477931522,
#  ('seat', 'wish'): 6.90875477931522,
#  ('diaphoresi', 'lpm'): 6.90875477931522,
#  ('adam', 'dic'): -6.90875477931522,
#  ('itchi', 'tracheomalacia'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('fibrinogen', 'wish'): 6.90875477931522,
#  ('asthma', 'soln'): 6.90875477931522,
#  ('fibrinogen', 'gastriti'): 6.90875477931522,
#  ('oncologist', 'osa'): 6.90875477931522,
#  ('muir', 'passi'): 6.90875477931522,
#  ('aricept', 'sibl'): 6.90875477931522,
#  ('dni', 'opinion'): -6.90875477931522,
#  ('pod', 'readmit'): 6.90875477931522,
#  ('diflucan', 'jewelri'): 6.90875477931522,
#  ('para', 'young'): 6.90875477931522,
#  ('dobutamin', 'vasopressin'): -6.90875477931522,
#  ('oob', 'pca'): 6.90875477931522,
#  ('ambul', 'prec'): 6.90875477931522,
#  ('clonazepam', 'nocturn'): 6.90875477931522,
#  ('escal', 'seroquel'): 6.90875477931522,
#  ('arrest', 'morbid'): 6.90875477931522,
#  ('dnr', 'weekli'): 6.90875477931522,
#  ('furhter', 'twitch'): -6.90875477931522,
#  ('colonoscopi', 'syncop'): 6.90875477931522,
#  ('gc', 'omeprazol'): 6.90875477931522,
#  ('dnr', 'fibrinogen'): 1.6507429622330152,
#  ('ffp', 'myeloma'): 6.90875477931522,
#  ('hospic', 'vasopressor'): 6.90875477931522,
#  ('echocardiogram', 'xl'): 6.90875477931522,
#  ('diaphoresi', 'xii'): 6.90875477931522,
#  ('neo', 'sibl'): -6.90875477931522,
#  ('declin', 'phlegm'): -6.90875477931522,
#  ('omeprazol', 'weekli'): 6.90875477931522,
#  ('dnr', 'hemothorax'): -6.90875477931522,
#  ('freeli', 'videofluoroscopi'): 6.90875477931522,
#  ('angri', 'expir'): 6.90875477931522,
#  ('dnr', 'trazodon'): 6.90875477931522,
#  ('deterior', 'levoph'): 2.09609753878805,
#  ('habitu', 'morbid'): 6.90875477931522,
#  ('lighthead', 'sweat'): 6.90875477931522,
#  ('asthma', 'cdb'): 6.90875477931522,
#  ('abruptli', 'chb'): -6.90875477931522,
#  ('cs', 'hugger'): -6.90875477931522,
#  ('angri', 'im'): 6.90875477931522,
#  ('venti', 'zero'): 6.90875477931522,
#  ('levoph', 'svv'): -6.90875477931522,
#  ('mrg', 'readmit'): 6.90875477931522,
#  ('hunger', 'rabbi'): -6.90875477931522,
#  ('levoph', 'opiat'): 6.90875477931522,
#  ('mellitu', 'ppd'): 6.90875477931522,
#  ('dni', 'hypercapn'): 6.90875477931522,
#  ('behavior', 'venti'): 6.90875477931522,
#  ('gastrojejunostomi', 'homogen'): 6.90875477931522,
#  ('contractur', 'fliud'): -6.90875477931522,
#  ('dni', 'redirect'): 2.2204460492503128e-16,
#  ('commod', 'cramp'): 6.90875477931522,
#  ('dz', 'lat'): 6.90875477931522,
#  ('bow', 'spfc'): 6.90875477931522,
#  ('thirst', 'video'): -6.90875477931522,
#  ('fliud', 'moan'): -6.90875477931522,
#  ('cmo', 'sluggish'): -6.90875477931522,
#  ('learn', 'moan'): 6.90875477931522,
#  ('cmo', 'tran'): -6.90875477931522,
#  ('book', 'fax'): 6.90875477931522,
#  ('nephrolog', 'ntnd'): -6.90875477931522,
#  ('clonidin', 'proph'): 6.90875477931522,
#  ('dni', 'lpm'): -6.90875477931522,
#  ('ciwa', 'sibl'): 6.90875477931522,
#  ('opinion', 'palliat'): -6.90875477931522,
#  ('cloth', 'diflucan'): 6.90875477931522,
#  ('oligur', 'vasopressor'): -6.90875477931522,
#  ('cvvh', 'sluggishli'): -6.90875477931522,
#  ('anur', 'banana'): 6.90875477931522,
#  ('neo', 'oob'): 6.90875477931522,
#  ('currenlti', 'modifi'): 6.90875477931522,
#  ('cyanot', 'iddm'): 6.90875477931522,
#  ('asystol', 'levoph'): -6.90875477931522,
#  ('gentamycin', 'illeu'): -6.90875477931522,
#  ('panic', 'xii'): 6.90875477931522,
#  ('ffp', 'intiat'): 6.90875477931522,
#  ('ctx', 'ferritin'): 6.90875477931522,
#  ('declin', 'icter'): -6.90875477931522,
#  ('dome', 'plate'): 6.90875477931522,
#  ('cpr', 'hsq'): -6.90875477931522,
#  ('oob', 'wish'): 6.90875477931522,
#  ('azotemia', 'epigastr'): 6.90875477931522,
#  ('dni', 'td'): 6.90875477931522,
#  ('dizzi', 'lighthead'): 6.90875477931522,
#  ('redirect', 'wallet'): -6.90875477931522,
#  ('aaox', 'emper'): 6.90875477931522,
#  ('abnl', 'occipit'): 6.90875477931522,
#  ('nicotin', 'schizophrenia'): 6.90875477931522,
#  ('gadolinium', 'uri'): 6.90875477931522,
#  ('aliv', 'paperwork'): 6.90875477931522,
#  ('para', 'smooth'): 0.0,
#  ('fibrinogen', 'subq'): 6.90875477931522,
#  ('hctz', 'subdur'): 6.90875477931522,
#  ('reguard', 'uncoop'): 6.90875477931522,
#  ('moan', 'mso'): -6.90875477931522,
#  ('behavior', 'seroquel'): 6.90875477931522,
#  ('diaphoresi', 'xl'): 6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('gabapentin', 'hsq'): 6.90875477931522,
#  ('death', 'predict'): -6.90875477931522,
#  ('bicarbon', 'pcv'): -6.90875477931522,
#  ('sluggishli', 'vasopressin'): -6.90875477931522,
#  ('ambien', 'pharmacolog'): 6.90875477931522,
#  ('omeprazol', 'strictur'): 6.90875477931522,
#  ('aliv', 'dni'): 6.90875477931522,
#  ('signatur', 'xl'): 6.90875477931522,
#  ('levoph', 'sluggishli'): -6.90875477931522,
#  ('oob', 'purpl'): 6.90875477931522,
#  ('breakfast', 'probe'): 6.90875477931522,
#  ('autopeep', 'pcv'): -6.90875477931522,
#  ('icter', 'prilosec'): 6.90875477931522,
#  ('esld', 'fibrinogen'): -6.90875477931522,
#  ('clonazepam', 'strictur'): 6.90875477931522,
#  ('bipolar', 'strictur'): 6.90875477931522,
#  ('articul', 'hypothermia'): 6.90875477931522,
#  ('silent', 'video'): 6.90875477931522,
#  ('iddm', 'vp'): 6.90875477931522,
#  ('captopril', 'gabapentin'): 6.90875477931522,
#  ('deterior', 'echocardiogram'): 6.90875477931522,
#  ('gadolinium', 'norepinephrin'): 6.90875477931522,
#  ('azotemia', 'bicarbon'): -6.90875477931522,
#  ('peribronchovascular', 'smooth'): -6.90875477931522,
#  ('neosynephrin', 'sluggishli'): -6.90875477931522,
#  ('chemic', 'crack'): 6.90875477931522,
#  ('suprapub', 'young'): 6.90875477931522,
#  ('dermat', 'dni'): 1.8806492362025304,
#  ('incis', 'palli'): -6.90875477931522,
#  ('seroquel', 'td'): 6.90875477931522,
#  ('expir', 'morgu'): -6.90875477931522,
#  ('chair', 'cs'): 6.90875477931522,
#  ('esld', 'neutral'): 6.90875477931522,
#  ('dnr', 'hypercapn'): 6.90875477931522,
#  ('dizzi', 'rigor'): 6.90875477931522,
#  ('dizzi', 'venti'): 1.9390841839849136,
#  ('fibrinogen', 'impli'): 6.90875477931522,
#  ('dnr', 'lpm'): -6.90875477931522,
#  ('azotemia', 'incent'): -6.90875477931522,
#  ('bair', 'pcv'): 6.90875477931522,
#  ('hunger', 'mso'): -6.90875477931522,
#  ('grave', 'sluggish'): 6.90875477931522,
#  ('splint', 'stair'): 6.90875477931522,
#  ('dni', 'ppn'): 6.90875477931522,
#  ('calculi', 'homogen'): 6.90875477931522,
#  ('colonoscopi', 'epidur'): 6.90875477931522,
#  ('aox', 'dni'): 6.90875477931522,
#  ('jewelri', 'redirect'): -6.90875477931522,
#  ('hypothermia', 'sensat'): 6.90875477931522,
#  ('bipolar', 'ppd'): 6.90875477931522,
#  ('gait', 'soln'): 6.90875477931522,
#  ('fatti', 'hilum'): 0.6916505477038827,
#  ('icter', 'mellitu'): 6.90875477931522,
#  ('ambul', 'sibl'): 6.90875477931522,
#  ('omeprazol', 'osa'): 6.90875477931522,
#  ('agon', 'mso'): -6.90875477931522,
#  ('qam', 'strictur'): 6.90875477931522,
#  ('ctx', 'readmit'): 6.90875477931522,
#  ('asthma', 'morbid'): 6.90875477931522,
#  ('schizophrenia', 'seroquel'): 6.90875477931522,
#  ('barium', 'osa'): 6.90875477931522,
#  ('pleasant', 'ppd'): 6.90875477931522,
#  ('habitu', 'mean'): 6.90875477931522,
#  ('asthma', 'phlegm'): 6.90875477931522,
#  ('dnr', 'xii'): -1.604655121332035,
#  ('behavior', 'rm'): 6.90875477931522,
#  ('cdb', 'phlegm'): 6.90875477931522,
#  ('bottl', 'gc'): 6.90875477931522,
#  ('hctz', 'protrud'): 6.90875477931522,
#  ('banana', 'historian'): 6.90875477931522,
#  ('defibril', 'tran'): 6.90875477931522,
#  ('dopamin', 'furhter'): -6.90875477931522,
#  ('dopamin', 'moan'): -6.90875477931522,
#  ('ba', 'bottl'): 6.90875477931522,
#  ('intent', 'phlegm'): 6.90875477931522,
#  ('dni', 'quinolon'): -6.90875477931522,
#  ('myeloma', 'xii'): -6.90875477931522,
#  ('banana', 'omeprazol'): 6.90875477931522,
#  ('anur', 'chair'): -6.90875477931522,
#  ('klonopin', 'unsteadi'): 6.90875477931522,
#  ('gastrojejunostomi', 'metoclopramid'): 6.90875477931522,
#  ('opiat', 'pharyng'): 6.90875477931522,
#  ('gvhd', 'nephrolog'): 6.90875477931522,
#  ('gastrojejunostomi', 'sarna'): 6.90875477931522,
#  ('dni', 'synthet'): -6.90875477931522,
#  ('chair', 'rigor'): 6.90875477931522,
#  ('pharyng', 'video'): 6.90875477931522,
#  ('anaphylaxi', 'seroquel'): 6.90875477931522,
#  ('dopamin', 'levof'): -6.90875477931522,
#  ('nocturn', 'rhinorrhea'): 6.90875477931522,
#  ('incis', 'occipit'): 6.90875477931522,
#  ('dnr', 'zoloft'): -1.3825560390092835,
#  ('assymetr', 'puff'): 6.90875477931522,
#  ('expir', 'levof'): -6.90875477931522,
#  ('hctz', 'nifedipin'): 6.90875477931522,
#  ('esld', 'ffp'): -0.8191521327074153,
#  ('lotion', 'metoclopramid'): 6.90875477931522,
#  ('chair', 'iddm'): 6.90875477931522,
#  ('adenosin', 'tcdb'): 6.90875477931522,
#  ('dni', 'hunger'): -1.8806492362025307,
#  ('phenylephrin', 'requr'): -6.90875477931522,
#  ('dnr', 'morgu'): -6.90875477931522,
#  ('olanzapin', 'qtc'): 6.90875477931522,
#  ('dnr', 'oob'): 0.509761227710204,
#  ('adam', 'levoph'): -6.90875477931522,
#  ('asthma', 'commod'): 6.90875477931522,
#  ('dic', 'hung'): -6.90875477931522,
#  ('flight', 'rhinorrhea'): 6.90875477931522,
#  ('chair', 'vagu'): 6.90875477931522,
#  ('habitu', 'hive'): 6.90875477931522,
#  ('pronounc', 'vasopressin'): -6.90875477931522,
#  ('nonlabor', 'oob'): 6.90875477931522,
#  ('diaper', 'nicotin'): 6.90875477931522,
#  ('bipolar', 'clonidin'): 6.90875477931522,
#  ('dnr', 'retic'): 6.90875477931522,
#  ('dead', 'nimv'): -6.90875477931522,
#  ('asthma', 'corneal'): -6.90875477931522,
#  ('cyanot', 'furhter'): -6.90875477931522,
#  ('perisplen', 'plerual'): 6.90875477931522,
#  ('contractur', 'criticar'): 6.90875477931522,
#  ('hypothermia', 'mind'): 6.90875477931522,
#  ('omeprazol', 'sibl'): 6.90875477931522,
#  ('asthma', 'jewelri'): 6.90875477931522,
#  ('dex', 'levoph'): 6.90875477931522,
#  ('phasic', 'unstabl'): 6.90875477931522,
#  ('chair', 'palli'): 6.90875477931522,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('furhter', 'gvhd'): -6.90875477931522,
#  ('death', 'trazodon'): 6.90875477931522,
#  ('angiogram', 'flight'): 6.90875477931522,
#  ('dnr', 'sibl'): 6.90875477931522,
#  ('levoph', 'nectar'): 6.90875477931522,
#  ('impli', 'peribronchovascular'): 6.90875477931522,
#  ('hctz', 'pleasant'): 6.90875477931522,
#  ('hugger', 'pcv'): 6.90875477931522,
#  ('nifedipin', 'nonrebreath'): 6.90875477931522,
#  ('mrg', 'weekli'): 6.90875477931522,
#  ('azotemia', 'thiamin'): 6.90875477931522,
#  ('mtg', 'seroquel'): 6.90875477931522,
#  ('nephrolog', 'stair'): 6.90875477931522,
#  ('burn', 'lighthead'): 6.90875477931522,
#  ('laminectomi', 'predict'): 6.90875477931522,
#  ('struggl', 'xii'): -6.90875477931522,
#  ('ciwa', 'lusb'): 6.90875477931522,
#  ('kerlix', 'vigil'): 6.90875477931522,
#  ('aricept', 'chair'): -6.90875477931522,
#  ('dni', 'gvhd'): 6.90875477931522,
#  ('aprv', 'gvhd'): -6.90875477931522,
#  ('diaphoresi', 'hunger'): 6.90875477931522,
#  ('norepinephrin', 'phenylephrin'): -6.90875477931522,
#  ('sensat', 'thiamin'): 6.90875477931522,
#  ('contractur', 'neo'): 6.90875477931522,
#  ('hive', 'palli'): -6.90875477931522,
#  ('compani', 'dizzi'): 6.90875477931522,
#  ('echocardiogram', 'ligament'): 6.90875477931522,
#  ('qtc', 'venti'): 6.90875477931522,
#  ('dnr', 'ruptur'): 6.90875477931522,
#  ('pcv', 'pea'): -6.90875477931522,
#  ('svv', 'vasopressin'): -6.90875477931522,
#  ('fibrinogen', 'suffer'): 6.90875477931522,
#  ('furhter', 'rescan'): 6.90875477931522,
#  ('ardsnet', 'wma'): -6.90875477931522,
#  ('diaphoresi', 'strictur'): 6.90875477931522,
#  ('massag', 'oncologist'): 6.90875477931522,
#  ('lusb', 'romi'): 6.90875477931522,
#  ('asthma', 'ruptur'): 6.90875477931522,
#  ('assymetr', 'echocardiogram'): 6.90875477931522,
#  ('ambul', 'aricept'): 6.90875477931522,
#  ('sweat', 'thiamin'): 6.90875477931522,
#  ('coach', 'gait'): 6.90875477931522,
#  ('clinician', 'escal'): -6.90875477931522,
#  ('dizzi', 'rhinorrhea'): 6.90875477931522,
#  ('phlegm', 'stair'): 6.90875477931522,
#  ('dopamin', 'liw'): -6.90875477931522,
#  ('declin', 'money'): 6.90875477931522,
#  ('crack', 'ctx'): 6.90875477931522,
#  ('klonopin', 'strictur'): 6.90875477931522,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('cdb', 'dizzi'): 6.90875477931522,
#  ('hhn', 'lpm'): 6.90875477931522,
#  ('dermat', 'gadolinium'): 6.90875477931522,
#  ('chip', 'venti'): 6.90875477931522,
#  ('arrest', 'bottl'): 6.90875477931522,
#  ('chair', 'uncoop'): 6.90875477931522,
#  ('death', 'mso'): -6.90875477931522,
#  ('cdb', 'spiromet'): 6.90875477931522,
#  ('emper', 'moan'): 6.90875477931522,
#  ('death', 'dopamin'): -6.90875477931522,
#  ('pleasant', 'qam'): 6.90875477931522,
#  ('syncop', 'young'): 6.90875477931522,
#  ('ambien', 'unsteadi'): 6.90875477931522,
#  ('pinpoint', 'rusti'): 6.90875477931522,
#  ('db', 'levoph'): 6.90875477931522,
#  ('foci', 'tubular'): 6.90875477931522,
#  ('dni', 'sibl'): 6.90875477931522,
#  ('acc', 'ba'): 6.90875477931522,
#  ('hilum', 'vertebra'): -6.90875477931522,
#  ('dnr', 'modifi'): 6.90875477931522,
#  ('align', 'simpli'): 6.90875477931522,
#  ('chip', 'oob'): 6.90875477931522,
#  ('azotemia', 'calculi'): 6.90875477931522,
#  ('anyway', 'dnr'): 6.90875477931522,
#  ('aox', 'bottl'): 6.90875477931522,
#  ('habitu', 'occupi'): 6.90875477931522,
#  ('fatti', 'syncop'): 6.90875477931522,
#  ('ferrou', 'puff'): 6.90875477931522,
#  ('captopril', 'laryng'): 6.90875477931522,
#  ('crack', 'pleasant'): 6.90875477931522,
#  ('commod', 'kerlix'): 6.90875477931522,
#  ('dnr', 'hook'): 6.90875477931522,
#  ('hemothorax', 'levoph'): -6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('rememb', 'thiamin'): 6.90875477931522,
#  ('anaphylaxi', 'opiat'): 6.90875477931522,
#  ('hemothorax', 'platelet'): -6.90875477931522,
#  ('captopril', 'palli'): 6.90875477931522,
#  ('dopamin', 'unasyn'): 6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('herp', 'stair'): 6.90875477931522,
#  ('dnr', 'signatur'): -0.4046335072286383,
#  ('gasp', 'hilum'): -6.90875477931522,
#  ('pleasant', 'unsteadi'): 6.90875477931522,
#  ('dz', 'postop'): 6.90875477931522,
#  ('ctx', 'trazodon'): 6.90875477931522,
#  ('conc', 'dnr'): 6.90875477931522,
#  ('articul', 'rehabilit'): 6.90875477931522,
#  ('mellitu', 'mood'): 6.90875477931522,
#  ('ba', 'dietari'): 6.90875477931522,
#  ('readmit', 'subdur'): 6.90875477931522,
#  ('absorb', 'option'): 6.90875477931522,
#  ('argatroban', 'levoph'): -6.90875477931522,
#  ('compani', 'oob'): 6.90875477931522,
#  ('gastrojejunostomi', 'nephrogram'): 6.90875477931522,
#  ('moan', 'phenylephrin'): -6.90875477931522,
#  ('calculi', 'puff'): 6.90875477931522,
#  ('gait', 'pleasant'): 6.90875477931522,
#  ('itchi', 'lotion'): 6.90875477931522,
#  ('ferritin', 'romi'): 6.90875477931522,
#  ('bottl', 'coach'): 6.90875477931522,
#  ('dyslipidemia', 'osa'): 6.90875477931522,
#  ('carvedilol', 'video'): 6.90875477931522,
#  ('cmo', 'dead'): -6.90875477931522,
#  ('flight', 'nephrolog'): 6.90875477931522,
#  ('escal', 'ultram'): 6.90875477931522,
#  ('dead', 'neosynephrin'): -6.90875477931522,
#  ('oligur', 'permiss'): -6.90875477931522,
#  ('adenosin', 'oob'): 6.90875477931522,
#  ('ppd', 'young'): 6.90875477931522,
#  ('sarna', 'soln'): 6.90875477931522,
#  ('oligur', 'vasopressin'): 0.44092196573215015,
#  ('azotemia', 'prilosec'): -6.90875477931522,
#  ('sluggishli', 'wma'): -6.90875477931522,
#  ('cmo', 'unrel'): -6.90875477931522,
#  ('anaphylaxi', 'muddi'): 6.90875477931522,
#  ('anur', 'mso'): -6.90875477931522,
#  ('levoph', 'phlegm'): -6.90875477931522,
#  ('asthma', 'mean'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('declin', 'rabbi'): -6.90875477931522,
#  ('hemangioma', 'phasic'): 6.90875477931522,
#  ('profound', 'rabbi'): -6.90875477931522,
#  ('dopamin', 'echocardiogram'): 6.90875477931522,
#  ('cocain', 'rm'): 6.90875477931522,
#  ('death', 'pronounc'): -6.90875477931522,
#  ('azotemia', 'xii'): 6.90875477931522,
#  ('declin', 'mellitu'): 6.90875477931522,
#  ('cmo', 'pinpoint'): -6.90875477931522,
#  ('dnr', 'mean'): -6.90875477931522,
#  ('chair', 'nonrebreath'): 6.90875477931522,
#  ('exophyt', 'peribronchovascular'): 6.90875477931522,
#  ('incent', 'spacer'): 6.90875477931522,
#  ('barium', 'burn'): 6.90875477931522,
#  ('sensat', 'xii'): 6.90875477931522,
#  ('adam', 'prognosi'): -6.90875477931522,
#  ('commod', 'compani'): 6.90875477931522,
#  ('db', 'sweat'): 6.90875477931522,
#  ('chair', 'gurgl'): -6.90875477931522,
#  ('furhter', 'neoplast'): 6.90875477931522,
#  ('hive', 'trazodon'): 6.90875477931522,
#  ('diaphoresi', 'pleasant'): 6.90875477931522,
#  ('mellitu', 'surviv'): 6.90875477931522,
#  ('criticar', 'dnr'): 6.90875477931522,
#  ('gabapentin', 'morbid'): 6.90875477931522,
#  ('platelet', 'young'): 6.90875477931522,
#  ('sibl', 'unstabl'): -6.90875477931522,
#  ('iddm', 'uri'): 6.90875477931522,
#  ('dizzi', 'syncop'): 6.90875477931522,
#  ('dni', 'lw'): 6.90875477931522,
#  ('declin', 'palli'): 1.7859498421315991,
#  ('asystol', 'morgu'): -6.90875477931522,
#  ('spill', 'video'): 6.90875477931522,
#  ('epidur', 'unsteadi'): 6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('osa', 'zyprexa'): 6.90875477931522,
#  ('dnr', 'dyslipidemia'): 6.90875477931522,
#  ('qam', 'zyprexa'): -6.90875477931522,
#  ('arrest', 'clonazepam'): 6.90875477931522,
#  ('gait', 'rigor'): 6.90875477931522,
#  ('db', 'signatur'): 6.90875477931522,
#  ('bottl', 'occipit'): 6.90875477931522,
#  ('dic', 'platelet'): -0.2770704566718008,
#  ('diaphoresi', 'stitch'): 6.90875477931522,
#  ('hive', 'lat'): 6.90875477931522,
#  ('maroon', 'simpli'): 6.90875477931522,
#  ('life', 'paralyt'): -6.90875477931522,
#  ('ctx', 'video'): 6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('rigor', 'zero'): 6.90875477931522,
#  ('adenocarcinoma', 'pleasant'): 6.90875477931522,
#  ('hover', 'nahco'): 6.90875477931522,
#  ('mso', 'wish'): -6.90875477931522,
#  ('anaphylaxi', 'imbal'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('mood', 'sensat'): 6.90875477931522,
#  ('articul', 'cup'): 6.90875477931522,
#  ('chair', 'thk'): 6.90875477931522,
#  ('pea', 'scar'): 6.90875477931522,
#  ('anaphylaxi', 'xl'): 6.90875477931522,
#  ('ferrou', 'motor'): 6.90875477931522,
#  ('^rr', 'moan'): 6.90875477931522,
#  ('levoph', 'oob'): 6.90875477931522,
#  ('seat', 'subcost'): 6.90875477931522,
#  ('cyanot', 'fungemia'): -6.90875477931522,
#  ('aaox', 'effac'): 6.90875477931522,
#  ('incent', 'rm'): 6.90875477931522,
#  ('adam', 'deterior'): -6.90875477931522,
#  ('arrest', 'chair'): 6.90875477931522,
#  ('cloth', 'dnr'): 0.0,
#  ('pneumococc', 'ppd'): 6.90875477931522,
#  ('ambien', 'elimin'): 6.90875477931522,
#  ('unstabl', 'vasopressin'): -6.90875477931522,
#  ('agon', 'expir'): -6.90875477931522,
#  ('echocardiogram', 'fatti'): 6.90875477931522,
#  ('dnr', 'town'): 6.90875477931522,
#  ('anur', 'omeprazol'): 6.90875477931522,
#  ('death', 'deterior'): -6.90875477931522,
#  ('slice', 'smooth'): 0.0,
#  ('hive', 'nocturn'): 6.90875477931522,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('dni', 'paperwork'): 1.3825560390092835,
#  ('abnl', 'laminectomi'): 6.90875477931522,
#  ('barium', 'spur'): 6.90875477931522,
#  ('lat', 'rehabilit'): 6.90875477931522,
#  ('ashen', 'romi'): 6.90875477931522,
#  ('^th', 'dni'): 6.90875477931522,
#  ('permiss', 'pleasant'): 6.90875477931522,
#  ('hctz', 'xii'): 6.90875477931522,
#  ('cvo', 'hive'): 6.90875477931522,
#  ('barium', 'silent'): 6.90875477931522,
#  ('pleasantli', 'seroquel'): 6.90875477931522,
#  ('db', 'respon'): 6.90875477931522,
#  ('ppd', 'silent'): 6.90875477931522,
#  ('chb', 'platelet'): -6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('acidot', 'fdp'): -6.90875477931522,
#  ('asthma', 'nicotin'): 6.90875477931522,
#  ('para', 'uri'): 6.90875477931522,
#  ('aaox', 'pod'): 6.90875477931522,
#  ('burn', 'unstabl'): 6.90875477931522,
#  ('acc', 'young'): 6.90875477931522,
#  ('endplat', 'osa'): 6.90875477931522,
#  ('epidur', 'im'): 6.90875477931522,
#  ('cpr', 'profound'): -6.90875477931522,
#  ('sweat', 'xl'): 6.90875477931522,
#  ('bottl', 'currenlti'): 6.90875477931522,
#  ('fc', 'osa'): 6.90875477931522,
#  ('method', 'predict'): -6.90875477931522,
#  ('hilum', 'peribronchovascular'): 0.0,
#  ('ferrou', 'xl'): 6.90875477931522,
#  ('life', 'pastor'): -6.90875477931522,
#  ('arrest', 'asystol'): -6.90875477931522,
#  ('arrest', 'norepinephrin'): -6.90875477931522,
#  ('appi', 'venti'): 6.90875477931522,
#  ('clonidin', 'dz'): 6.90875477931522,
#  ('angiogram', 'option'): 6.90875477931522,
#  ('intiat', 'panic'): 6.90875477931522,
#  ('mellitu', 'wish'): 6.90875477931522,
#  ('oncologist', 'paperwork'): 6.90875477931522,
#  ('gabapentin', 'lat'): 6.90875477931522,
#  ('intiat', 'mso'): -6.90875477931522,
#  ('pea', 'sluggish'): -6.90875477931522,
#  ('cpr', 'death'): -6.90875477931522,
#  ('dex', 'dopamin'): 6.90875477931522,
#  ('acc', 'aricept'): 6.90875477931522,
#  ('esophagogastr', 'hemithorac'): -6.90875477931522,
#  ('gait', 'gastriti'): 6.90875477931522,
#  ('dome', 'homogen'): 6.90875477931522,
#  ('agon', 'pronounc'): -6.90875477931522,
#  ('neo', 'readdress'): -6.90875477931522,
#  ('chair', 'intent'): 6.90875477931522,
#  ('ardsnet', 'levoph'): 1.3256334536733387,
#  ('bromid', 'mellitu'): 6.90875477931522,
#  ('arrest', 'bicarbon'): -6.90875477931522,
#  ('cyanot', 'dni'): -6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('dizzi', 'sarna'): 6.90875477931522,
#  ('hospic', 'xanax'): 6.90875477931522,
#  ('puff', 'thiamin'): 6.90875477931522,
#  ('judgement', 'rememb'): 6.90875477931522,
#  ('breakfast', 'neo'): 6.90875477931522,
#  ('ciwa', 'echocardiogram'): 6.90875477931522,
#  ('rememb', 'ruptur'): 6.90875477931522,
#  ('mean', 'stg'): -6.90875477931522,
#  ('cs', 'lpm'): -6.90875477931522,
#  ('chb', 'zyprexa'): 6.90875477931522,
#  ('klonopin', 'sweat'): 6.90875477931522,
#  ('hung', 'pea'): -6.90875477931522,
#  ('dopamin', 'vasopressor'): -6.90875477931522,
#  ('bicarbon', 'sluggishli'): -6.90875477931522,
#  ('banana', 'rememb'): 6.90875477931522,
#  ('dni', 'underneath'): -6.90875477931522,
#  ('osa', 'uri'): 6.90875477931522,
#  ('dnr', 'pleasant'): 1.3825560390092835,
#  ('fdp', 'rhinorrhea'): -6.90875477931522,
#  ('cash', 'cdb'): 6.90875477931522,
#  ('chb', 'gurgl'): -6.90875477931522,
#  ('nifedipin', 'robitussin'): 6.90875477931522,
#  ('clonidin', 'wish'): 6.90875477931522,
#  ('klonopin', 'mycolyt'): 6.90875477931522,
#  ('mtg', 'omeprazol'): 6.90875477931522,
#  ('pneumococc', 'subq'): 6.90875477931522,
#  ('pcv', 'phenylephrin'): -6.90875477931522,
#  ('mortem', 'unequ'): -6.90875477931522,
#  ('dysynchron', 'neo'): -6.90875477931522,
#  ('captopril', 'tcdb'): 6.90875477931522,
#  ('ciwa', 'omeprazol'): 6.90875477931522,
#  ('captopril', 'nephrolog'): 6.90875477931522,
#  ('nectar', 'pleasantli'): 6.90875477931522,
#  ('cpr', 'norepinephrin'): -6.90875477931522,
#  ('sensat', 'unstabl'): 6.90875477931522,
#  ('aricept', 'jewelri'): -6.90875477931522,
#  ('incis', 'video'): 6.90875477931522,
#  ('thiamin', 'unasyn'): 6.90875477931522,
#  ('chair', 'dz'): 6.90875477931522,
#  ('neo', 'norepinephrin'): -2.625239572123001,
#  ('conc', 'flake'): 6.90875477931522,
#  ('gait', 'vasopressin'): -6.90875477931522,
#  ('cocain', 'klonopin'): 6.90875477931522,
#  ('barium', 'pathologist'): 6.90875477931522,
#  ('angioplasti', 'deploy'): 6.90875477931522,
#  ('nifedipin', 'splint'): 6.90875477931522,
#  ('dni', 'gabapentin'): 6.90875477931522,
#  ('dni', 'trabecul'): 6.90875477931522,
#  ('ambul', 'ferrou'): 6.90875477931522,
#  ('dz', 'pneumococc'): 6.90875477931522,
#  ('adenosin', 'vasopressin'): 6.90875477931522,
#  ('peribronchovascular', 'requr'): 6.90875477931522,
#  ('azotemia', 'rhinorrhea'): -6.90875477931522,
#  ('ggo', 'iddm'): 6.90875477931522,
#  ('diaper', 'tran'): 6.90875477931522,
#  ('ciwa', 'itchi'): 6.90875477931522,
#  ('historian', 'jewelri'): 6.90875477931522,
#  ('anaphylaxi', 'zoloft'): 6.90875477931522,
#  ('bicarbon', 'oligur'): -6.90875477931522,
#  ('clonidin', 'romi'): 6.90875477931522,
#  ('breakfast', 'mellitu'): 6.90875477931522,
#  ('echocardiogram', 'ppn'): 6.90875477931522,
#  ('anuria', 'crrt'): -6.90875477931522,
#  ('oob', 'wallet'): 6.90875477931522,
#  ('money', 'redirect'): -6.90875477931522,
#  ('fibrinogen', 'pastor'): -6.90875477931522,
#  ('declin', 'norepinephrin'): -6.90875477931522,
#  ('echocardiogram', 'retic'): 6.90875477931522,
#  ('bromid', 'dni'): 6.90875477931522,
#  ('diuril', 'dopamin'): 6.90875477931522,
#  ('commod', 'jewelri'): -6.90875477931522,
#  ('rabbi', 'suffer'): -6.90875477931522,
#  ('pharyng', 'rhinorrhea'): 6.90875477931522,
#  ('argatroban', 'crrt'): -6.90875477931522,
#  ('aricept', 'lusb'): 6.90875477931522,
#  ('asthma', 'ppd'): 6.90875477931522,
#  ('stack', 'underpenetr'): -6.90875477931522,
#  ('ba', 'hctz'): 6.90875477931522,
#  ('life', 'mean'): 6.90875477931522,
#  ('qam', 'subq'): 6.90875477931522,
#  ('cash', 'pivot'): -6.90875477931522,
#  ('angiogram', 'slice'): 6.90875477931522,
#  ('hospic', 'stg'): -6.90875477931522,
#  ('abruptli', 'expir'): -6.90875477931522,
#  ('dni', 'lymphangit'): 6.90875477931522,
#  ('anaphylaxi', 'morbid'): 6.90875477931522,
#  ('gc', 'lpm'): 6.90875477931522,
#  ('mottl', 'option'): -6.90875477931522,
#  ('acc', 'angri'): 6.90875477931522,
#  ('habitu', 'ppd'): 6.90875477931522,
#  ('cellcept', 'hospic'): 6.90875477931522,
#  ('deterior', 'suffer'): -6.90875477931522,
#  ('dni', 'proph'): 6.90875477931522,
#  ('mjmgb', 'plate'): 6.90875477931522,
#  ('lpm', 'osa'): 6.90875477931522,
#  ('chair', 'tcdb'): 6.90875477931522,
#  ('agon', 'sluggish'): -6.90875477931522,
#  ('aaox', 'zyprexa'): 6.90875477931522,
#  ('clonidin', 'mellitu'): 6.90875477931522,
#  ('ctx', 'wma'): 6.90875477931522,
#  ('nectar', 'piriform'): 6.90875477931522,
#  ('artifici', 'xl'): -6.90875477931522,
#  ('gait', 'unsteadi'): 6.90875477931522,
#  ('im', 'profound'): 6.90875477931522,
#  ('declin', 'moan'): -6.90875477931522,
#  ('bank', 'wish'): 6.90875477931522,
#  ('oligur', 'wma'): -6.90875477931522,
#  ('cdb', 'diflucan'): 6.90875477931522,
#  ('fwb', 'tremul'): 6.90875477931522,
#  ('dizzi', 'lotion'): 6.90875477931522,
#  ('aaox', 'syst'): 6.90875477931522,
#  ('chol', 'hospic'): -6.90875477931522,
#  ('arrang', 'dnr'): -6.90875477931522,
#  ('captopril', 'twitch'): 6.90875477931522,
#  ('agon', 'deterior'): -6.90875477931522,
#  ('ctx', 'hypothermia'): 6.90875477931522,
#  ('bottl', 'seriou'): 6.90875477931522,
#  ('cdb', 'money'): 6.90875477931522,
#  ('foci', 'scar'): 6.90875477931522,
#  ('escal', 'wish'): -6.90875477931522,
#  ('mucinex', 'omeprazol'): 6.90875477931522,
#  ('gabapentin', 'unstabl'): 6.90875477931522,
#  ('dopamin', 'prognosi'): -6.90875477931522,
#  ('neo', 'vasopressin'): -0.6618713625681694,
#  ('dni', 'unobtain'): 0.6916505477038827,
#  ('dnr', 'jewelri'): -0.4046335072286383,
#  ('ashen', 'declin'): 6.90875477931522,
#  ('freeli', 'vallecula'): 6.90875477931522,
#  ('jewelri', 'pleasant'): -0.4046335072286383,
#  ('omeprazol', 'para'): 6.90875477931522,
#  ('db', 'para'): 6.90875477931522,
#  ('azotemia', 'qam'): 6.90875477931522,
#  ('intiat', 'jerk'): -6.90875477931522,
#  ('cdb', 'ctx'): 6.90875477931522,
#  ('declin', 'hive'): 6.90875477931522,
#  ('core', 'fibrinogen'): -6.90875477931522,
#  ('cloth', 'thiamin'): 6.90875477931522,
#  ('distort', 'slice'): -6.90875477931522,
#  ('bipolar', 'chip'): 6.90875477931522,
#  ('hugger', 'paralyt'): 6.90875477931522,
#  ('prognosi', 'viabl'): -6.90875477931522,
#  ('barium', 'panic'): 6.90875477931522,
#  ('declar', 'dopamin'): -6.90875477931522,
#  ('oob', 'sundown'): 6.90875477931522,
#  ('aaox', 'nimv'): 6.90875477931522,
#  ('hive', 'stitch'): 6.90875477931522,
#  ('ambien', 'dyslipidemia'): 6.90875477931522,
#  ('aricept', 'colonoscopi'): 6.90875477931522,
#  ('homogen', 'treitz'): 6.90875477931522,
#  ('occipit', 'seriou'): 6.90875477931522,
#  ('mellitu', 'pod'): 6.90875477931522,
#  ('diaper', 'dnr'): 6.90875477931522,
#  ('captopril', 'predict'): 6.90875477931522,
#  ('adam', 'icter'): -6.90875477931522,
#  ('pathologist', 'video'): 6.90875477931522,
#  ('azotemia', 'fibrinogen'): 1.3825560390092835,
#  ('bicarbon', 'stitch'): 6.90875477931522,
#  ('echocardiogram', 'thiamin'): 6.90875477931522,
#  ('cash', 'klonopin'): 6.90875477931522,
#  ('captopril', 'scar'): 6.90875477931522,
#  ('bipolar', 'clonazepam'): 6.90875477931522,
#  ('silent', 'young'): 6.90875477931522,
#  ('meatu', 'trabecul'): -6.90875477931522,
#  ('brb', 'fibrinogen'): -6.90875477931522,
#  ('pronounc', 'unequ'): -6.90875477931522,
#  ('hemangioma', 'plerual'): 6.90875477931522,
#  ('ctx', 'lotion'): 6.90875477931522,
#  ('deterior', 'lift'): 6.90875477931522,
#  ('mellitu', 'stair'): 6.90875477931522,
#  ('peribronchovascular', 'plate'): 6.90875477931522,
#  ('ctx', 'schizophrenia'): 6.90875477931522,
#  ('phlegm', 'splint'): 6.90875477931522,
#  ('cyanot', 'lw'): -6.90875477931522,
#  ('aox', 'laminectomi'): 6.90875477931522,
#  ('clinician', 'occipit'): 6.90875477931522,
#  ('qam', 'rememb'): 6.90875477931522,
#  ('abnl', 'clonidin'): 6.90875477931522,
#  ('epigastr', 'nifedipin'): 6.90875477931522,
#  ('ipf', 'norepinephrin'): -6.90875477931522,
#  ('chair', 'levoph'): 6.90875477931522,
#  ('ferrou', 'rhinorrhea'): 6.90875477931522,
#  ('declar', 'religi'): -6.90875477931522,
#  ('dnr', 'pleuravac'): -6.90875477931522,
#  ('mellitu', 'scar'): 6.90875477931522,
#  ('asthma', 'autoset'): 6.90875477931522,
#  ('ambien', 'spacer'): 6.90875477931522,
#  ('im', 'mva'): 6.90875477931522,
#  ('ferritin', 'platelet'): 6.90875477931522,
#  ('ctx', 'im'): 6.90875477931522,
#  ('furhter', 'lw'): -6.90875477931522,
#  ('omeprazol', 'qam'): 6.90875477931522,
#  ('mva', 'td'): 6.90875477931522,
#  ('pneumococc', 'puff'): 6.90875477931522,
#  ('mso', 'oob'): 6.90875477931522,
#  ('mva', 'spacer'): 6.90875477931522,
#  ('lpm', 'myeloma'): -1.3825560390092835,
#  ('mtg', 'paralyt'): -6.90875477931522,
#  ('hugger', 'levoph'): 1.6688498669946448,
#  ('permiss', 'pose'): 6.90875477931522,
#  ('bronchovascular', 'crowd'): 1.462247919771027,
#  ('dead', 'dopamin'): -6.90875477931522,
#  ('hida', 'mjmgb'): 6.90875477931522,
#  ('ferrou', 'gait'): 6.90875477931522,
#  ('life', 'neo'): 6.90875477931522,
#  ('phlegm', 'wish'): -6.90875477931522,
#  ('leukocyt', 'scar'): 6.90875477931522,
#  ('puff', 'xl'): 6.90875477931522,
#  ('deliv', 'respitori'): 6.90875477931522,
#  ('neosynephrin', 'pitressin'): -6.90875477931522,
#  ('dz', 'venti'): 6.90875477931522,
#  ('hypercapnia', 'oob'): 6.90875477931522,
#  ('dyslipidemia', 'rhinorrhea'): 6.90875477931522,
#  ('flight', 'pleasant'): 6.90875477931522,
#  ('ctx', 'suffer'): 6.90875477931522,
#  ('im', 'sweat'): 6.90875477931522,
#  ('acidot', 'grim'): -6.90875477931522,
#  ('agon', 'grim'): -6.90875477931522,
#  ('asthma', 'dermat'): 6.90875477931522,
#  ('gastriti', 'xii'): 6.90875477931522,
#  ('asthma', 'intent'): 6.90875477931522,
#  ('ctx', 'palli'): 6.90875477931522,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('ppn', 'prognosi'): 6.90875477931522,
#  ('colonoscopi', 'readdress'): 6.90875477931522,
#  ('ambul', 'levoph'): 6.90875477931522,
#  ('hilum', 'lymphangit'): 6.90875477931522,
#  ('cocain', 'ultram'): 6.90875477931522,
#  ('chb', 'dni'): 0.0,
#  ('angiogram', 'gadolinium'): 6.90875477931522,
#  ('db', 'hive'): 6.90875477931522,
#  ('neo', 'palli'): -6.90875477931522,
#  ('bill', 'fibrinogen'): 6.90875477931522,
#  ('oob', 'prec'): 6.90875477931522,
#  ('epigastr', 'fibrinogen'): 6.90875477931522,
#  ('preme', 'zero'): 6.90875477931522,
#  ('aaox', 'subdur'): 6.90875477931522,
#  ('diaphoresi', 'lighthead'): 6.90875477931522,
#  ('incis', 'opinion'): 6.90875477931522,
#  ('impli', 'pea'): 6.90875477931522,
#  ('puff', 'qam'): 6.90875477931522,
#  ('bottl', 'pea'): 6.90875477931522,
#  ('asthma', 'mucinex'): 6.90875477931522,
#  ('deliv', 'dni'): 6.90875477931522,
#  ('brb', 'unstabl'): -6.90875477931522,
#  ('ferritin', 'wish'): 6.90875477931522,
#  ('levoph', 'pleasant'): 6.90875477931522,
#  ('dnr', 'muddi'): 1.0271828417136022,
#  ('bipolar', 'olanzapin'): 6.90875477931522,
#  ('asthma', 'seroquel'): 6.90875477931522,
#  ('gastrojejunostomi', 'soln'): 6.90875477931522,
#  ('commod', 'spiromet'): 6.90875477931522,
#  ('natg', 'scar'): -6.90875477931522,
#  ('fdp', 'petechia'): -6.90875477931522,
#  ('bicarbon', 'wma'): -6.90875477931522,
#  ('acidot', 'ffp'): -6.90875477931522,
#  ('autoset', 'db'): 6.90875477931522,
#  ('behavior', 'readmit'): 6.90875477931522,
#  ('diaphoresi', 'hygein'): 6.90875477931522,
#  ('option', 'thrive'): -6.90875477931522,
#  ('gastrojejunostomi', 'ligament'): 6.90875477931522,
#  ('nicotin', 'xopenex'): 6.90875477931522,
#  ('breakfast', 'sensat'): 6.90875477931522,
#  ('diaphoresi', 'dizzi'): 6.90875477931522,
#  ('dome', 'lat'): 6.90875477931522,
#  ('crack', 'habitu'): 6.90875477931522,
#  ('hctz', 'young'): 6.90875477931522,
#  ('fibrinogen', 'rigor'): 6.90875477931522,
#  ('endur', 'pod'): 6.90875477931522,
#  ('icter', 'palli'): 6.90875477931522,
#  ('aricept', 'pivot'): -6.90875477931522,
#  ('ba', 'ppd'): 6.90875477931522,
#  ('clonazepam', 'seroquel'): 6.90875477931522,
#  ('aaox', 'lac'): 6.90875477931522,
#  ('currenlti', 'trabecul'): 6.90875477931522,
#  ('norepinephrin', 'wma'): -6.90875477931522,
#  ('itchi', 'wish'): 6.90875477931522,
#  ('^th', 'ciwa'): 6.90875477931522,
#  ('pleasant', 'wish'): 6.90875477931522,
#  ('commod', 'cyanot'): -6.90875477931522,
#  ('lift', 'mrg'): 6.90875477931522,
#  ('norepinephrin', 'recalibr'): 6.90875477931522,
#  ('esld', 'phenylephrin'): -0.06655815957840429,
#  ('oligur', 'sluggishli'): -6.90875477931522,
#  ('dead', 'vasopressin'): -6.90875477931522,
#  ('profound', 'vasopressin'): -6.90875477931522,
#  ('chair', 'redirect'): 6.90875477931522,
#  ('osa', 'pod'): 6.90875477931522,
#  ('hospic', 'ppn'): 6.90875477931522,
#  ('lat', 'occupi'): 6.90875477931522,
#  ('pose', 'vasoconstrict'): -6.90875477931522,
#  ('declin', 'romi'): 6.90875477931522,
#  ('pinpoint', 'sluggish'): -6.90875477931522,
#  ('ffp', 'vasopressin'): -6.90875477931522,
#  ...}

# %%
# Data normalization
import numpy
def data_norm(cooc_odd_scores):

    def norm_arr(array):
        arr = numpy.array(list(array))
        start = 0
        end = 1
        width = end - start
        res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
        return res.tolist()

    cooc_keys, cooc_values = zip(*cooc_odd_scores.items())
    new_cooc_odd_scores = dict(zip(cooc_keys, norm_arr(cooc_values)))

    return new_cooc_odd_scores

new_patient_cooc_odd_scores = data_norm(patient_cooc_odd_scores)

# %%
new_patient_cooc_odd_scores
# Out:
# {('life', 'trazodon'): 0.0,
#  ('gadolinium', 'outer'): 1.0,
#  ('historian', 'uri'): 1.0,
#  ('aricept', 'dead'): 0.0,
#  ('ppn', 'retic'): 1.0,
#  ('hypothermia', 'wma'): 1.0,
#  ('bottl', 'rememb'): 1.0,
#  ('ctx', 'dietari'): 1.0,
#  ('lat', 'mva'): 1.0,
#  ('ba', 'omeprazol'): 1.0,
#  ('ashen', 'mellitu'): 1.0,
#  ('venti', 'young'): 1.0,
#  ('argatroban', 'vasopressin'): 0.0,
#  ('bottl', 'syncop'): 1.0,
#  ('cdb', 'incent'): 1.0,
#  ('incent', 'itchi'): 1.0,
#  ('dni', 'itchi'): 1.0,
#  ('mva', 'omeprazol'): 1.0,
#  ('dnr', 'palliat'): 0.0,
#  ('rememb', 'vertebra'): 1.0,
#  ('hypotherm', 'hypothermia'): 0.5181514274047264,
#  ('bronchovascular', 'fatti'): 1.0,
#  ('hypothermia', 'robitussin'): 1.0,
#  ('msicu', 'pleasant'): 1.0,
#  ('chair', 'spiromet'): 1.0,
#  ('death', 'ferrou'): 1.0,
#  ('absorb', 'uri'): 1.0,
#  ('foci', 'outer'): 1.0,
#  ('declin', 'scab'): 1.0,
#  ('cpr', 'pulseless'): 0.0,
#  ('profound', 'ration'): 1.0,
#  ('hook', 'qam'): 1.0,
#  ('nephrolog', 'pleasant'): 1.0,
#  ('declar', 'deterior'): 0.0,
#  ('clonidin', 'sibl'): 1.0,
#  ('recalibr', 'stitch'): 1.0,
#  ('levoph', 'mucinex'): 1.0,
#  ('corneal', 'dnr'): 0.0,
#  ('cg', 'dnr'): 0.0,
#  ('lpm', 'pleasant'): 1.0,
#  ('hsq', 'stair'): 1.0,
#  ('oncologist', 'pleasant'): 1.0,
#  ('dic', 'pyuria'): 1.0,
#  ('asthma', 'opiat'): 1.0,
#  ('dizzi', 'signatur'): 1.0,
#  ('commod', 'illeu'): 0.0,
#  ('cup', 'video'): 1.0,
#  ('echocardiogram', 'puff'): 1.0,
#  ('plerual', 'scar'): 1.0,
#  ('death', 'omeprazol'): 1.0,
#  ('aaox', 'chip'): 1.0,
#  ('pose', 'ran'): 1.0,
#  ('chair', 'tran'): 1.0,
#  ('cyanot', 'dopamin'): 0.0,
#  ('dietari', 'hsq'): 1.0,
#  ('captopril', 'lpm'): 1.0,
#  ('bromid', 'opiat'): 1.0,
#  ('clonidin', 'crowd'): 1.0,
#  ('autoset', 'declin'): 1.0,
#  ('core', 'icter'): 0.0,
#  ('dni', 'herp'): 1.0,
#  ('impli', 'video'): 0.0,
#  ('asthma', 'hsq'): 1.0,
#  ('laryng', 'pathologist'): 1.0,
#  ('aaox', 'commod'): 1.0,
#  ('pleasant', 'spacer'): 1.0,
#  ('liw', 'vasopressin'): 0.0,
#  ('levoph', 'mso'): 0.0,
#  ('cash', 'oob'): 1.0,
#  ('gait', 'sensat'): 1.0,
#  ('ciwa', 'ran'): 1.0,
#  ('calculi', 'omeprazol'): 1.0,
#  ('bipolar', 'gastriti'): 1.0,
#  ('declin', 'prognosi'): 0.35632236605912554,
#  ('hospic', 'underneath'): 0.0,
#  ('nifedipin', 'scar'): 1.0,
#  ('expir', 'neo'): 0.0,
#  ('cdb', 'dni'): 1.0,
#  ('bipolar', 'seroquel'): 1.0,
#  ('deterior', 'religi'): 0.0,
#  ('adam', 'hypotherm'): 0.0,
#  ('osa', 'panic'): 1.0,
#  ('endplat', 'magnevist'): 1.0,
#  ('dni', 'fwb'): 1.0,
#  ('spacer', 'unstabl'): 1.0,
#  ('dnr', 'hospic'): 0.5018286412574916,
#  ('hepatobiliari', 'synthet'): 0.0,
#  ('fibrinogen', 'nice'): 1.0,
#  ('elimin', 'pharyng'): 1.0,
#  ('fibrinogen', 'lusb'): 1.0,
#  ('dnr', 'gvhd'): 1.0,
#  ('cloth', 'pivot'): 0.0,
#  ('gastriti', 'predict'): 1.0,
#  ('acc', 'ctx'): 1.0,
#  ('db', 'dni'): 1.0,
#  ('duski', 'wish'): 0.0,
#  ('historian', 'opiat'): 1.0,
#  ('incis', 'omeprazol'): 1.0,
#  ('lat', 'sweat'): 1.0,
#  ('asthma', 'db'): 1.0,
#  ('lat', 'syncop'): 1.0,
#  ('gotten', 'msicu'): 1.0,
#  ('chair', 'cloth'): 1.0,
#  ('fu', 'ntnd'): 1.0,
#  ('gabapentin', 'shorter'): 1.0,
#  ('adam', 'neo'): 0.0,
#  ('nectar', 'pleasant'): 1.0,
#  ('phlegm', 'sensat'): 1.0,
#  ('levoph', 'lpm'): 1.0,
#  ('commod', 'levoph'): 0.4818485725952736,
#  ('ferritin', 'mellitu'): 1.0,
#  ('chb', 'hemothorax'): 0.0,
#  ('dnr', 'pea'): 0.0,
#  ('dnr', 'hsq'): 1.0,
#  ('dni', 'mrg'): 1.0,
#  ('fatti', 'ferritin'): 1.0,
#  ('dnr', 'osa'): 0.508033515064845,
#  ('hypothermia', 'sweat'): 1.0,
#  ('hsq', 'lusb'): 1.0,
#  ('hypercapnia', 'pcv'): 0.0,
#  ('levoph', 'suffer'): 0.0,
#  ('asthma', 'itchi'): 1.0,
#  ('crack', 'dizzi'): 1.0,
#  ('magnevist', 'motor'): 1.0,
#  ('mrcp', 'synthet'): 0.0,
#  ('bottl', 'puff'): 1.0,
#  ('option', 'readdress'): 0.0,
#  ('assymetr', 'ppd'): 1.0,
#  ('epigastr', 'postop'): 1.0,
#  ('aricept', 'syncop'): 1.0,
#  ('breakfast', 'panic'): 1.0,
#  ('cpr', 'hypothermia'): 0.0,
#  ('asthma', 'omeprazol'): 1.0,
#  ('oob', 'tran'): 1.0,
#  ('pleasant', 'subq'): 1.0,
#  ('ctx', 'modifi'): 1.0,
#  ('expir', 'moan'): 0.0,
#  ('expir', 'homogen'): 1.0,
#  ('azotemia', 'echocardiogram'): 1.0,
#  ('historian', 'signatur'): 1.0,
#  ('gait', 'motor'): 1.0,
#  ('dnr', 'omeprazol'): 0.6476466717455208,
#  ('hung', 'trazodon'): 0.0,
#  ('azotemia', 'platelet'): 0.0,
#  ('phlegm', 'spiromet'): 1.0,
#  ('oob', 'thrive'): 1.0,
#  ('sibl', 'subq'): 1.0,
#  ('levoph', 'pcv'): 1.0,
#  ('agon', 'neosynephrin'): 0.0,
#  ('arrest', 'hypercapnia'): 0.0,
#  ('ofm', 'osa'): 1.0,
#  ('motor', 'thiamin'): 1.0,
#  ('chb', 'dopamin'): 1.0,
#  ('puff', 'trazodon'): 1.0,
#  ('osa', 'strictur'): 1.0,
#  ('bill', 'gastrojejunostomi'): 1.0,
#  ('aricept', 'cash'): 0.0,
#  ('lighthead', 'schizophrenia'): 1.0,
#  ('robitussin', 'wish'): 1.0,
#  ('bromid', 'im'): 1.0,
#  ('colonoscopi', 'scar'): 1.0,
#  ('dni', 'laminectomi'): 1.0,
#  ('omeprazol', 'silent'): 1.0,
#  ('acetazolamid', 'fibrinogen'): 1.0,
#  ('contractur', 'dnr'): 0.5500560933045909,
#  ('opiat', 'seroquel'): 1.0,
#  ('im', 'romi'): 1.0,
#  ('refractori', 'young'): 1.0,
#  ('anaphylaxi', 'nocturn'): 1.0,
#  ('hsq', 'pleasant'): 1.0,
#  ('core', 'dic'): 0.0,
#  ('mood', 'zyprexa'): 1.0,
#  ('breakfast', 'uffp'): 1.0,
#  ('ba', 'opiat'): 1.0,
#  ('amb', 'oob'): 1.0,
#  ('azotemia', 'pneumococc'): 1.0,
#  ('asthma', 'iddm'): 1.0,
#  ('clonidin', 'gastriti'): 1.0,
#  ('bicarbon', 'readmit'): 1.0,
#  ('aricept', 'resucit'): 1.0,
#  ('cs', 'nicotin'): 1.0,
#  ('fibrinogen', 'osa'): 1.0,
#  ('chair', 'wish'): 1.0,
#  ('assymetr', 'underpenetr'): 0.0,
#  ('calvarium', 'slice'): 1.0,
#  ('cocain', 'vagu'): 1.0,
#  ('dni', 'life'): 0.5661621299883667,
#  ('oob', 'readmit'): 1.0,
#  ('nephrolog', 'scar'): 1.0,
#  ('bicarbon', 'life'): 0.0,
#  ('asthma', 'chair'): 0.6516986494486501,
#  ('cloth', 'redirect'): 0.0,
#  ('asthma', 'unavail'): 1.0,
#  ('laminectomi', 'schizophrenia'): 1.0,
#  ('oncologist', 'ppd'): 1.0,
#  ('adenocarcinoma', 'tremul'): 1.0,
#  ('gc', 'im'): 1.0,
#  ('cooki', 'laryng'): 1.0,
#  ('aox', 'clonidin'): 1.0,
#  ('calculi', 'refractori'): 1.0,
#  ('chair', 'jewelri'): 1.0,
#  ('qam', 'vagu'): 1.0,
#  ('foci', 'neo'): 1.0,
#  ('prilosec', 'wish'): 1.0,
#  ('compani', 'pleasant'): 1.0,
#  ('declin', 'dnr'): 0.6995145021917382,
#  ('hilum', 'zyprexa'): 0.0,
#  ('prognosi', 'unstabl'): 0.0,
#  ('death', 'dnr'): 0.0,
#  ('seat', 'wish'): 1.0,
#  ('diaphoresi', 'lpm'): 1.0,
#  ('adam', 'dic'): 0.0,
#  ('itchi', 'tracheomalacia'): 1.0,
#  ('strictur', 'zyprexa'): 1.0,
#  ('fibrinogen', 'wish'): 1.0,
#  ('asthma', 'soln'): 1.0,
#  ('fibrinogen', 'gastriti'): 1.0,
#  ('oncologist', 'osa'): 1.0,
#  ('muir', 'passi'): 1.0,
#  ('aricept', 'sibl'): 1.0,
#  ('dni', 'opinion'): 0.0,
#  ('pod', 'readmit'): 1.0,
#  ('diflucan', 'jewelri'): 1.0,
#  ('para', 'young'): 1.0,
#  ('dobutamin', 'vasopressin'): 0.0,
#  ('oob', 'pca'): 1.0,
#  ('ambul', 'prec'): 1.0,
#  ('clonazepam', 'nocturn'): 1.0,
#  ('escal', 'seroquel'): 1.0,
#  ('arrest', 'morbid'): 1.0,
#  ('dnr', 'weekli'): 1.0,
#  ('furhter', 'twitch'): 0.0,
#  ('colonoscopi', 'syncop'): 1.0,
#  ('gc', 'omeprazol'): 1.0,
#  ('dnr', 'fibrinogen'): 0.6194674738764308,
#  ('ffp', 'myeloma'): 1.0,
#  ('hospic', 'vasopressor'): 1.0,
#  ('echocardiogram', 'xl'): 1.0,
#  ('diaphoresi', 'xii'): 1.0,
#  ('neo', 'sibl'): 0.0,
#  ('declin', 'phlegm'): 0.0,
#  ('omeprazol', 'weekli'): 1.0,
#  ('dnr', 'hemothorax'): 0.0,
#  ('freeli', 'videofluoroscopi'): 1.0,
#  ('angri', 'expir'): 1.0,
#  ('dnr', 'trazodon'): 1.0,
#  ('deterior', 'levoph'): 0.6516986494486501,
#  ('habitu', 'morbid'): 1.0,
#  ('lighthead', 'sweat'): 1.0,
#  ('asthma', 'cdb'): 1.0,
#  ('abruptli', 'chb'): 0.0,
#  ('cs', 'hugger'): 0.0,
#  ('angri', 'im'): 1.0,
#  ('venti', 'zero'): 1.0,
#  ('levoph', 'svv'): 0.0,
#  ('mrg', 'readmit'): 1.0,
#  ('hunger', 'rabbi'): 0.0,
#  ('levoph', 'opiat'): 1.0,
#  ('mellitu', 'ppd'): 1.0,
#  ('dni', 'hypercapn'): 1.0,
#  ('behavior', 'venti'): 1.0,
#  ('gastrojejunostomi', 'homogen'): 1.0,
#  ('contractur', 'fliud'): 0.0,
#  ('dni', 'redirect'): 0.5,
#  ('commod', 'cramp'): 1.0,
#  ('dz', 'lat'): 1.0,
#  ('bow', 'spfc'): 1.0,
#  ('thirst', 'video'): 0.0,
#  ('fliud', 'moan'): 0.0,
#  ('cmo', 'sluggish'): 0.0,
#  ('learn', 'moan'): 1.0,
#  ('cmo', 'tran'): 0.0,
#  ('book', 'fax'): 1.0,
#  ('nephrolog', 'ntnd'): 0.0,
#  ('clonidin', 'proph'): 1.0,
#  ('dni', 'lpm'): 0.0,
#  ('ciwa', 'sibl'): 1.0,
#  ('opinion', 'palliat'): 0.0,
#  ('cloth', 'diflucan'): 1.0,
#  ('oligur', 'vasopressor'): 0.0,
#  ('cvvh', 'sluggishli'): 0.0,
#  ('anur', 'banana'): 1.0,
#  ('neo', 'oob'): 1.0,
#  ('currenlti', 'modifi'): 1.0,
#  ('cyanot', 'iddm'): 1.0,
#  ('asystol', 'levoph'): 0.0,
#  ('gentamycin', 'illeu'): 0.0,
#  ('panic', 'xii'): 1.0,
#  ('ffp', 'intiat'): 1.0,
#  ('ctx', 'ferritin'): 1.0,
#  ('declin', 'icter'): 0.0,
#  ('dome', 'plate'): 1.0,
#  ('cpr', 'hsq'): 0.0,
#  ('oob', 'wish'): 1.0,
#  ('azotemia', 'epigastr'): 1.0,
#  ('dni', 'td'): 1.0,
#  ('dizzi', 'lighthead'): 1.0,
#  ('redirect', 'wallet'): 0.0,
#  ('aaox', 'emper'): 1.0,
#  ('abnl', 'occipit'): 1.0,
#  ('nicotin', 'schizophrenia'): 1.0,
#  ('gadolinium', 'uri'): 1.0,
#  ('aliv', 'paperwork'): 1.0,
#  ('para', 'smooth'): 0.5,
#  ('fibrinogen', 'subq'): 1.0,
#  ('hctz', 'subdur'): 1.0,
#  ('reguard', 'uncoop'): 1.0,
#  ('moan', 'mso'): 0.0,
#  ('behavior', 'seroquel'): 1.0,
#  ('diaphoresi', 'xl'): 1.0,
#  ('dnr', 'laminectomi'): 1.0,
#  ('gabapentin', 'hsq'): 1.0,
#  ('death', 'predict'): 0.0,
#  ('bicarbon', 'pcv'): 0.0,
#  ('sluggishli', 'vasopressin'): 0.0,
#  ('ambien', 'pharmacolog'): 1.0,
#  ('omeprazol', 'strictur'): 1.0,
#  ('aliv', 'dni'): 1.0,
#  ('signatur', 'xl'): 1.0,
#  ('levoph', 'sluggishli'): 0.0,
#  ('oob', 'purpl'): 1.0,
#  ('breakfast', 'probe'): 1.0,
#  ('autopeep', 'pcv'): 0.0,
#  ('icter', 'prilosec'): 1.0,
#  ('esld', 'fibrinogen'): 0.0,
#  ('clonazepam', 'strictur'): 1.0,
#  ('bipolar', 'strictur'): 1.0,
#  ('articul', 'hypothermia'): 1.0,
#  ('silent', 'video'): 1.0,
#  ('iddm', 'vp'): 1.0,
#  ('captopril', 'gabapentin'): 1.0,
#  ('deterior', 'echocardiogram'): 1.0,
#  ('gadolinium', 'norepinephrin'): 1.0,
#  ('azotemia', 'bicarbon'): 0.0,
#  ('peribronchovascular', 'smooth'): 0.0,
#  ('neosynephrin', 'sluggishli'): 0.0,
#  ('chemic', 'crack'): 1.0,
#  ('suprapub', 'young'): 1.0,
#  ('dermat', 'dni'): 0.6361062373955713,
#  ('incis', 'palli'): 0.0,
#  ('seroquel', 'td'): 1.0,
#  ('expir', 'morgu'): 0.0,
#  ('chair', 'cs'): 1.0,
#  ('esld', 'neutral'): 1.0,
#  ('dnr', 'hypercapn'): 1.0,
#  ('dizzi', 'rigor'): 1.0,
#  ('dizzi', 'venti'): 0.6403352880457216,
#  ('fibrinogen', 'impli'): 1.0,
#  ('dnr', 'lpm'): 0.0,
#  ('azotemia', 'incent'): 0.0,
#  ('bair', 'pcv'): 1.0,
#  ('hunger', 'mso'): 0.0,
#  ('grave', 'sluggish'): 1.0,
#  ('splint', 'stair'): 1.0,
#  ('dni', 'ppn'): 1.0,
#  ('calculi', 'homogen'): 1.0,
#  ('colonoscopi', 'epidur'): 1.0,
#  ('aox', 'dni'): 1.0,
#  ('jewelri', 'redirect'): 0.0,
#  ('hypothermia', 'sensat'): 1.0,
#  ('bipolar', 'ppd'): 1.0,
#  ('gait', 'soln'): 1.0,
#  ('fatti', 'hilum'): 0.5500560933045909,
#  ('icter', 'mellitu'): 1.0,
#  ('ambul', 'sibl'): 1.0,
#  ('omeprazol', 'osa'): 1.0,
#  ('agon', 'mso'): 0.0,
#  ('qam', 'strictur'): 1.0,
#  ('ctx', 'readmit'): 1.0,
#  ('asthma', 'morbid'): 1.0,
#  ('schizophrenia', 'seroquel'): 1.0,
#  ('barium', 'osa'): 1.0,
#  ('pleasant', 'ppd'): 1.0,
#  ('habitu', 'mean'): 1.0,
#  ('asthma', 'phlegm'): 1.0,
#  ('dnr', 'xii'): 0.3838679926709539,
#  ('behavior', 'rm'): 1.0,
#  ('cdb', 'phlegm'): 1.0,
#  ('bottl', 'gc'): 1.0,
#  ('hctz', 'protrud'): 1.0,
#  ('banana', 'historian'): 1.0,
#  ('defibril', 'tran'): 1.0,
#  ('dopamin', 'furhter'): 0.0,
#  ('dopamin', 'moan'): 0.0,
#  ('ba', 'bottl'): 1.0,
#  ('intent', 'phlegm'): 1.0,
#  ('dni', 'quinolon'): 0.0,
#  ('myeloma', 'xii'): 0.0,
#  ('banana', 'omeprazol'): 1.0,
#  ('anur', 'chair'): 0.0,
#  ('klonopin', 'unsteadi'): 1.0,
#  ('gastrojejunostomi', 'metoclopramid'): 1.0,
#  ('opiat', 'pharyng'): 1.0,
#  ('gvhd', 'nephrolog'): 1.0,
#  ('gastrojejunostomi', 'sarna'): 1.0,
#  ('dni', 'synthet'): 0.0,
#  ('chair', 'rigor'): 1.0,
#  ('pharyng', 'video'): 1.0,
#  ('anaphylaxi', 'seroquel'): 1.0,
#  ('dopamin', 'levof'): 0.0,
#  ('nocturn', 'rhinorrhea'): 1.0,
#  ('incis', 'occipit'): 1.0,
#  ('dnr', 'zoloft'): 0.39994173456925625,
#  ('assymetr', 'puff'): 1.0,
#  ('expir', 'levof'): 0.0,
#  ('hctz', 'nifedipin'): 1.0,
#  ('esld', 'ffp'): 0.4407163693839624,
#  ('lotion', 'metoclopramid'): 1.0,
#  ('chair', 'iddm'): 1.0,
#  ('adenosin', 'tcdb'): 1.0,
#  ('dni', 'hunger'): 0.3638937626044287,
#  ('phenylephrin', 'requr'): 0.0,
#  ('dnr', 'morgu'): 0.0,
#  ('olanzapin', 'qtc'): 1.0,
#  ('dnr', 'oob'): 0.5368924099923496,
#  ('adam', 'levoph'): 0.0,
#  ('asthma', 'commod'): 1.0,
#  ('dic', 'hung'): 0.0,
#  ('flight', 'rhinorrhea'): 1.0,
#  ('chair', 'vagu'): 1.0,
#  ('habitu', 'hive'): 1.0,
#  ('pronounc', 'vasopressin'): 0.0,
#  ('nonlabor', 'oob'): 1.0,
#  ('diaper', 'nicotin'): 1.0,
#  ('bipolar', 'clonidin'): 1.0,
#  ('dnr', 'retic'): 1.0,
#  ('dead', 'nimv'): 0.0,
#  ('asthma', 'corneal'): 0.0,
#  ('cyanot', 'furhter'): 0.0,
#  ('perisplen', 'plerual'): 1.0,
#  ('contractur', 'criticar'): 1.0,
#  ('hypothermia', 'mind'): 1.0,
#  ('omeprazol', 'sibl'): 1.0,
#  ('asthma', 'jewelri'): 1.0,
#  ('dex', 'levoph'): 1.0,
#  ('phasic', 'unstabl'): 1.0,
#  ('chair', 'palli'): 1.0,
#  ('ambul', 'msicu'): 1.0,
#  ('furhter', 'gvhd'): 0.0,
#  ('death', 'trazodon'): 1.0,
#  ('angiogram', 'flight'): 1.0,
#  ('dnr', 'sibl'): 1.0,
#  ('levoph', 'nectar'): 1.0,
#  ('impli', 'peribronchovascular'): 1.0,
#  ('hctz', 'pleasant'): 1.0,
#  ('hugger', 'pcv'): 1.0,
#  ('nifedipin', 'nonrebreath'): 1.0,
#  ('mrg', 'weekli'): 1.0,
#  ('azotemia', 'thiamin'): 1.0,
#  ('mtg', 'seroquel'): 1.0,
#  ('nephrolog', 'stair'): 1.0,
#  ('burn', 'lighthead'): 1.0,
#  ('laminectomi', 'predict'): 1.0,
#  ('struggl', 'xii'): 0.0,
#  ('ciwa', 'lusb'): 1.0,
#  ('kerlix', 'vigil'): 1.0,
#  ('aricept', 'chair'): 0.0,
#  ('dni', 'gvhd'): 1.0,
#  ('aprv', 'gvhd'): 0.0,
#  ('diaphoresi', 'hunger'): 1.0,
#  ('norepinephrin', 'phenylephrin'): 0.0,
#  ('sensat', 'thiamin'): 1.0,
#  ('contractur', 'neo'): 1.0,
#  ('hive', 'palli'): 0.0,
#  ('compani', 'dizzi'): 1.0,
#  ('echocardiogram', 'ligament'): 1.0,
#  ('qtc', 'venti'): 1.0,
#  ('dnr', 'ruptur'): 1.0,
#  ('pcv', 'pea'): 0.0,
#  ('svv', 'vasopressin'): 0.0,
#  ('fibrinogen', 'suffer'): 1.0,
#  ('furhter', 'rescan'): 1.0,
#  ('ardsnet', 'wma'): 0.0,
#  ('diaphoresi', 'strictur'): 1.0,
#  ('massag', 'oncologist'): 1.0,
#  ('lusb', 'romi'): 1.0,
#  ('asthma', 'ruptur'): 1.0,
#  ('assymetr', 'echocardiogram'): 1.0,
#  ('ambul', 'aricept'): 1.0,
#  ('sweat', 'thiamin'): 1.0,
#  ('coach', 'gait'): 1.0,
#  ('clinician', 'escal'): 0.0,
#  ('dizzi', 'rhinorrhea'): 1.0,
#  ('phlegm', 'stair'): 1.0,
#  ('dopamin', 'liw'): 0.0,
#  ('declin', 'money'): 1.0,
#  ('crack', 'ctx'): 1.0,
#  ('klonopin', 'strictur'): 1.0,
#  ('deploy', 'epigastr'): 1.0,
#  ('cdb', 'dizzi'): 1.0,
#  ('hhn', 'lpm'): 1.0,
#  ('dermat', 'gadolinium'): 1.0,
#  ('chip', 'venti'): 1.0,
#  ('arrest', 'bottl'): 1.0,
#  ('chair', 'uncoop'): 1.0,
#  ('death', 'mso'): 0.0,
#  ('cdb', 'spiromet'): 1.0,
#  ('emper', 'moan'): 1.0,
#  ('death', 'dopamin'): 0.0,
#  ('pleasant', 'qam'): 1.0,
#  ('syncop', 'young'): 1.0,
#  ('ambien', 'unsteadi'): 1.0,
#  ('pinpoint', 'rusti'): 1.0,
#  ('db', 'levoph'): 1.0,
#  ('foci', 'tubular'): 1.0,
#  ('dni', 'sibl'): 1.0,
#  ('acc', 'ba'): 1.0,
#  ('hilum', 'vertebra'): 0.0,
#  ('dnr', 'modifi'): 1.0,
#  ('align', 'simpli'): 1.0,
#  ('chip', 'oob'): 1.0,
#  ('azotemia', 'calculi'): 1.0,
#  ('anyway', 'dnr'): 1.0,
#  ('aox', 'bottl'): 1.0,
#  ('habitu', 'occupi'): 1.0,
#  ('fatti', 'syncop'): 1.0,
#  ('ferrou', 'puff'): 1.0,
#  ('captopril', 'laryng'): 1.0,
#  ('crack', 'pleasant'): 1.0,
#  ('commod', 'kerlix'): 1.0,
#  ('dnr', 'hook'): 1.0,
#  ('hemothorax', 'levoph'): 0.0,
#  ('ambul', 'sarna'): 1.0,
#  ('rememb', 'thiamin'): 1.0,
#  ('anaphylaxi', 'opiat'): 1.0,
#  ('hemothorax', 'platelet'): 0.0,
#  ('captopril', 'palli'): 1.0,
#  ('dopamin', 'unasyn'): 1.0,
#  ('bottl', 'bromid'): 1.0,
#  ('herp', 'stair'): 1.0,
#  ('dnr', 'signatur'): 0.47071588729418296,
#  ('gasp', 'hilum'): 0.0,
#  ('pleasant', 'unsteadi'): 1.0,
#  ('dz', 'postop'): 1.0,
#  ('ctx', 'trazodon'): 1.0,
#  ('conc', 'dnr'): 1.0,
#  ('articul', 'rehabilit'): 1.0,
#  ('mellitu', 'mood'): 1.0,
#  ('ba', 'dietari'): 1.0,
#  ('readmit', 'subdur'): 1.0,
#  ('absorb', 'option'): 1.0,
#  ('argatroban', 'levoph'): 0.0,
#  ('compani', 'oob'): 1.0,
#  ('gastrojejunostomi', 'nephrogram'): 1.0,
#  ('moan', 'phenylephrin'): 0.0,
#  ('calculi', 'puff'): 1.0,
#  ('gait', 'pleasant'): 1.0,
#  ('itchi', 'lotion'): 1.0,
#  ('ferritin', 'romi'): 1.0,
#  ('bottl', 'coach'): 1.0,
#  ('dyslipidemia', 'osa'): 1.0,
#  ('carvedilol', 'video'): 1.0,
#  ('cmo', 'dead'): 0.0,
#  ('flight', 'nephrolog'): 1.0,
#  ('escal', 'ultram'): 1.0,
#  ('dead', 'neosynephrin'): 0.0,
#  ('oligur', 'permiss'): 0.0,
#  ('adenosin', 'oob'): 1.0,
#  ('ppd', 'young'): 1.0,
#  ('sarna', 'soln'): 1.0,
#  ('oligur', 'vasopressin'): 0.5319103789189528,
#  ('azotemia', 'prilosec'): 0.0,
#  ('sluggishli', 'wma'): 0.0,
#  ('cmo', 'unrel'): 0.0,
#  ('anaphylaxi', 'muddi'): 1.0,
#  ('anur', 'mso'): 0.0,
#  ('levoph', 'phlegm'): 0.0,
#  ('asthma', 'mean'): 1.0,
#  ('romi', 'young'): 1.0,
#  ('declin', 'rabbi'): 0.0,
#  ('hemangioma', 'phasic'): 1.0,
#  ('profound', 'rabbi'): 0.0,
#  ('dopamin', 'echocardiogram'): 1.0,
#  ('cocain', 'rm'): 1.0,
#  ('death', 'pronounc'): 0.0,
#  ('azotemia', 'xii'): 1.0,
#  ('declin', 'mellitu'): 1.0,
#  ('cmo', 'pinpoint'): 0.0,
#  ('dnr', 'mean'): 0.0,
#  ('chair', 'nonrebreath'): 1.0,
#  ('exophyt', 'peribronchovascular'): 1.0,
#  ('incent', 'spacer'): 1.0,
#  ('barium', 'burn'): 1.0,
#  ('sensat', 'xii'): 1.0,
#  ('adam', 'prognosi'): 0.0,
#  ('commod', 'compani'): 1.0,
#  ('db', 'sweat'): 1.0,
#  ('chair', 'gurgl'): 0.0,
#  ('furhter', 'neoplast'): 1.0,
#  ('hive', 'trazodon'): 1.0,
#  ('diaphoresi', 'pleasant'): 1.0,
#  ('mellitu', 'surviv'): 1.0,
#  ('criticar', 'dnr'): 1.0,
#  ('gabapentin', 'morbid'): 1.0,
#  ('platelet', 'young'): 1.0,
#  ('sibl', 'unstabl'): 0.0,
#  ('iddm', 'uri'): 1.0,
#  ('dizzi', 'syncop'): 1.0,
#  ('dni', 'lw'): 1.0,
#  ('declin', 'palli'): 0.6292526583429132,
#  ('asystol', 'morgu'): 0.0,
#  ('spill', 'video'): 1.0,
#  ('epidur', 'unsteadi'): 1.0,
#  ('nahco', 'vasopressin'): 0.0,
#  ('neutral', 'scar'): 1.0,
#  ('osa', 'zyprexa'): 1.0,
#  ('dnr', 'dyslipidemia'): 1.0,
#  ('qam', 'zyprexa'): 0.0,
#  ('arrest', 'clonazepam'): 1.0,
#  ('gait', 'rigor'): 1.0,
#  ('db', 'signatur'): 1.0,
#  ('bottl', 'occipit'): 1.0,
#  ('dic', 'platelet'): 0.47994787298708674,
#  ('diaphoresi', 'stitch'): 1.0,
#  ('hive', 'lat'): 1.0,
#  ('maroon', 'simpli'): 1.0,
#  ('life', 'paralyt'): 0.0,
#  ('ctx', 'video'): 1.0,
#  ('arrest', 'pronounc'): 0.0,
#  ('rigor', 'zero'): 1.0,
#  ('adenocarcinoma', 'pleasant'): 1.0,
#  ('hover', 'nahco'): 1.0,
#  ('mso', 'wish'): 0.0,
#  ('anaphylaxi', 'imbal'): 1.0,
#  ('anaphylaxi', 'uri'): 1.0,
#  ('mood', 'sensat'): 1.0,
#  ('articul', 'cup'): 1.0,
#  ('chair', 'thk'): 1.0,
#  ('pea', 'scar'): 1.0,
#  ('anaphylaxi', 'xl'): 1.0,
#  ('ferrou', 'motor'): 1.0,
#  ('^rr', 'moan'): 1.0,
#  ('levoph', 'oob'): 1.0,
#  ('seat', 'subcost'): 1.0,
#  ('cyanot', 'fungemia'): 0.0,
#  ('aaox', 'effac'): 1.0,
#  ('incent', 'rm'): 1.0,
#  ('adam', 'deterior'): 0.0,
#  ('arrest', 'chair'): 1.0,
#  ('cloth', 'dnr'): 0.5,
#  ('pneumococc', 'ppd'): 1.0,
#  ('ambien', 'elimin'): 1.0,
#  ('unstabl', 'vasopressin'): 0.0,
#  ('agon', 'expir'): 0.0,
#  ('echocardiogram', 'fatti'): 1.0,
#  ('dnr', 'town'): 1.0,
#  ('anur', 'omeprazol'): 1.0,
#  ('death', 'deterior'): 0.0,
#  ('slice', 'smooth'): 0.5,
#  ('hive', 'nocturn'): 1.0,
#  ('paperwork', 'rhinorrhea'): 1.0,
#  ('dni', 'paperwork'): 0.6000582654307438,
#  ('abnl', 'laminectomi'): 1.0,
#  ('barium', 'spur'): 1.0,
#  ('lat', 'rehabilit'): 1.0,
#  ('ashen', 'romi'): 1.0,
#  ('^th', 'dni'): 1.0,
#  ('permiss', 'pleasant'): 1.0,
#  ('hctz', 'xii'): 1.0,
#  ('cvo', 'hive'): 1.0,
#  ('barium', 'silent'): 1.0,
#  ('pleasantli', 'seroquel'): 1.0,
#  ('db', 'respon'): 1.0,
#  ('ppd', 'silent'): 1.0,
#  ('chb', 'platelet'): 0.0,
#  ('hypotherm', 'wish'): 0.0,
#  ('acidot', 'fdp'): 0.0,
#  ('asthma', 'nicotin'): 1.0,
#  ('para', 'uri'): 1.0,
#  ('aaox', 'pod'): 1.0,
#  ('burn', 'unstabl'): 1.0,
#  ('acc', 'young'): 1.0,
#  ('endplat', 'osa'): 1.0,
#  ('epidur', 'im'): 1.0,
#  ('cpr', 'profound'): 0.0,
#  ('sweat', 'xl'): 1.0,
#  ('bottl', 'currenlti'): 1.0,
#  ('fc', 'osa'): 1.0,
#  ('method', 'predict'): 0.0,
#  ('hilum', 'peribronchovascular'): 0.5,
#  ('ferrou', 'xl'): 1.0,
#  ('life', 'pastor'): 0.0,
#  ('arrest', 'asystol'): 0.0,
#  ('arrest', 'norepinephrin'): 0.0,
#  ('appi', 'venti'): 1.0,
#  ('clonidin', 'dz'): 1.0,
#  ('angiogram', 'option'): 1.0,
#  ('intiat', 'panic'): 1.0,
#  ('mellitu', 'wish'): 1.0,
#  ('oncologist', 'paperwork'): 1.0,
#  ('gabapentin', 'lat'): 1.0,
#  ('intiat', 'mso'): 0.0,
#  ('pea', 'sluggish'): 0.0,
#  ('cpr', 'death'): 0.0,
#  ('dex', 'dopamin'): 1.0,
#  ('acc', 'aricept'): 1.0,
#  ('esophagogastr', 'hemithorac'): 0.0,
#  ('gait', 'gastriti'): 1.0,
#  ('dome', 'homogen'): 1.0,
#  ('agon', 'pronounc'): 0.0,
#  ('neo', 'readdress'): 0.0,
#  ('chair', 'intent'): 1.0,
#  ('ardsnet', 'levoph'): 0.5959386673878105,
#  ('bromid', 'mellitu'): 1.0,
#  ('arrest', 'bicarbon'): 0.0,
#  ('cyanot', 'dni'): 0.0,
#  ('imbal', 'strictur'): 1.0,
#  ('dizzi', 'sarna'): 1.0,
#  ('hospic', 'xanax'): 1.0,
#  ('puff', 'thiamin'): 1.0,
#  ('judgement', 'rememb'): 1.0,
#  ('breakfast', 'neo'): 1.0,
#  ('ciwa', 'echocardiogram'): 1.0,
#  ('rememb', 'ruptur'): 1.0,
#  ('mean', 'stg'): 0.0,
#  ('cs', 'lpm'): 0.0,
#  ('chb', 'zyprexa'): 1.0,
#  ('klonopin', 'sweat'): 1.0,
#  ('hung', 'pea'): 0.0,
#  ('dopamin', 'vasopressor'): 0.0,
#  ('bicarbon', 'sluggishli'): 0.0,
#  ('banana', 'rememb'): 1.0,
#  ('dni', 'underneath'): 0.0,
#  ('osa', 'uri'): 1.0,
#  ('dnr', 'pleasant'): 0.6000582654307438,
#  ('fdp', 'rhinorrhea'): 0.0,
#  ('cash', 'cdb'): 1.0,
#  ('chb', 'gurgl'): 0.0,
#  ('nifedipin', 'robitussin'): 1.0,
#  ('clonidin', 'wish'): 1.0,
#  ('klonopin', 'mycolyt'): 1.0,
#  ('mtg', 'omeprazol'): 1.0,
#  ('pneumococc', 'subq'): 1.0,
#  ('pcv', 'phenylephrin'): 0.0,
#  ('mortem', 'unequ'): 0.0,
#  ('dysynchron', 'neo'): 0.0,
#  ('captopril', 'tcdb'): 1.0,
#  ('ciwa', 'omeprazol'): 1.0,
#  ('captopril', 'nephrolog'): 1.0,
#  ('nectar', 'pleasantli'): 1.0,
#  ('cpr', 'norepinephrin'): 0.0,
#  ('sensat', 'unstabl'): 1.0,
#  ('aricept', 'jewelri'): 0.0,
#  ('incis', 'video'): 1.0,
#  ('thiamin', 'unasyn'): 1.0,
#  ('chair', 'dz'): 1.0,
#  ('neo', 'norepinephrin'): 0.31000631401892015,
#  ('conc', 'flake'): 1.0,
#  ('gait', 'vasopressin'): 0.0,
#  ('cocain', 'klonopin'): 1.0,
#  ('barium', 'pathologist'): 1.0,
#  ('angioplasti', 'deploy'): 1.0,
#  ('nifedipin', 'splint'): 1.0,
#  ('dni', 'gabapentin'): 1.0,
#  ('dni', 'trabecul'): 1.0,
#  ('ambul', 'ferrou'): 1.0,
#  ('dz', 'pneumococc'): 1.0,
#  ('adenosin', 'vasopressin'): 1.0,
#  ('peribronchovascular', 'requr'): 1.0,
#  ('azotemia', 'rhinorrhea'): 0.0,
#  ('ggo', 'iddm'): 1.0,
#  ('diaper', 'tran'): 1.0,
#  ('ciwa', 'itchi'): 1.0,
#  ('historian', 'jewelri'): 1.0,
#  ('anaphylaxi', 'zoloft'): 1.0,
#  ('bicarbon', 'oligur'): 0.0,
#  ('clonidin', 'romi'): 1.0,
#  ('breakfast', 'mellitu'): 1.0,
#  ('echocardiogram', 'ppn'): 1.0,
#  ('anuria', 'crrt'): 0.0,
#  ('oob', 'wallet'): 1.0,
#  ('money', 'redirect'): 0.0,
#  ('fibrinogen', 'pastor'): 0.0,
#  ('declin', 'norepinephrin'): 0.0,
#  ('echocardiogram', 'retic'): 1.0,
#  ('bromid', 'dni'): 1.0,
#  ('diuril', 'dopamin'): 1.0,
#  ('commod', 'jewelri'): 0.0,
#  ('rabbi', 'suffer'): 0.0,
#  ('pharyng', 'rhinorrhea'): 1.0,
#  ('argatroban', 'crrt'): 0.0,
#  ('aricept', 'lusb'): 1.0,
#  ('asthma', 'ppd'): 1.0,
#  ('stack', 'underpenetr'): 0.0,
#  ('ba', 'hctz'): 1.0,
#  ('life', 'mean'): 1.0,
#  ('qam', 'subq'): 1.0,
#  ('cash', 'pivot'): 0.0,
#  ('angiogram', 'slice'): 1.0,
#  ('hospic', 'stg'): 0.0,
#  ('abruptli', 'expir'): 0.0,
#  ('dni', 'lymphangit'): 1.0,
#  ('anaphylaxi', 'morbid'): 1.0,
#  ('gc', 'lpm'): 1.0,
#  ('mottl', 'option'): 0.0,
#  ('acc', 'angri'): 1.0,
#  ('habitu', 'ppd'): 1.0,
#  ('cellcept', 'hospic'): 1.0,
#  ('deterior', 'suffer'): 0.0,
#  ('dni', 'proph'): 1.0,
#  ('mjmgb', 'plate'): 1.0,
#  ('lpm', 'osa'): 1.0,
#  ('chair', 'tcdb'): 1.0,
#  ('agon', 'sluggish'): 0.0,
#  ('aaox', 'zyprexa'): 1.0,
#  ('clonidin', 'mellitu'): 1.0,
#  ('ctx', 'wma'): 1.0,
#  ('nectar', 'piriform'): 1.0,
#  ('artifici', 'xl'): 0.0,
#  ('gait', 'unsteadi'): 1.0,
#  ('im', 'profound'): 1.0,
#  ('declin', 'moan'): 0.0,
#  ('bank', 'wish'): 1.0,
#  ('oligur', 'wma'): 0.0,
#  ('cdb', 'diflucan'): 1.0,
#  ('fwb', 'tremul'): 1.0,
#  ('dizzi', 'lotion'): 1.0,
#  ('aaox', 'syst'): 1.0,
#  ('chol', 'hospic'): 0.0,
#  ('arrang', 'dnr'): 0.0,
#  ('captopril', 'twitch'): 1.0,
#  ('agon', 'deterior'): 0.0,
#  ('ctx', 'hypothermia'): 1.0,
#  ('bottl', 'seriou'): 1.0,
#  ('cdb', 'money'): 1.0,
#  ('foci', 'scar'): 1.0,
#  ('escal', 'wish'): 0.0,
#  ('mucinex', 'omeprazol'): 1.0,
#  ('gabapentin', 'unstabl'): 1.0,
#  ('dopamin', 'prognosi'): 0.0,
#  ('neo', 'vasopressin'): 0.4520990841540788,
#  ('dni', 'unobtain'): 0.5500560933045909,
#  ('dnr', 'jewelri'): 0.47071588729418296,
#  ('ashen', 'declin'): 1.0,
#  ('freeli', 'vallecula'): 1.0,
#  ('jewelri', 'pleasant'): 0.47071588729418296,
#  ('omeprazol', 'para'): 1.0,
#  ('db', 'para'): 1.0,
#  ('azotemia', 'qam'): 1.0,
#  ('intiat', 'jerk'): 0.0,
#  ('cdb', 'ctx'): 1.0,
#  ('declin', 'hive'): 1.0,
#  ('core', 'fibrinogen'): 0.0,
#  ('cloth', 'thiamin'): 1.0,
#  ('distort', 'slice'): 0.0,
#  ('bipolar', 'chip'): 1.0,
#  ('hugger', 'paralyt'): 1.0,
#  ('prognosi', 'viabl'): 0.0,
#  ('barium', 'panic'): 1.0,
#  ('declar', 'dopamin'): 0.0,
#  ('oob', 'sundown'): 1.0,
#  ('aaox', 'nimv'): 1.0,
#  ('hive', 'stitch'): 1.0,
#  ('ambien', 'dyslipidemia'): 1.0,
#  ('aricept', 'colonoscopi'): 1.0,
#  ('homogen', 'treitz'): 1.0,
#  ('occipit', 'seriou'): 1.0,
#  ('mellitu', 'pod'): 1.0,
#  ('diaper', 'dnr'): 1.0,
#  ('captopril', 'predict'): 1.0,
#  ('adam', 'icter'): 0.0,
#  ('pathologist', 'video'): 1.0,
#  ('azotemia', 'fibrinogen'): 0.6000582654307438,
#  ('bicarbon', 'stitch'): 1.0,
#  ('echocardiogram', 'thiamin'): 1.0,
#  ('cash', 'klonopin'): 1.0,
#  ('captopril', 'scar'): 1.0,
#  ('bipolar', 'clonazepam'): 1.0,
#  ('silent', 'young'): 1.0,
#  ('meatu', 'trabecul'): 0.0,
#  ('brb', 'fibrinogen'): 0.0,
#  ('pronounc', 'unequ'): 0.0,
#  ('hemangioma', 'plerual'): 1.0,
#  ('ctx', 'lotion'): 1.0,
#  ('deterior', 'lift'): 1.0,
#  ('mellitu', 'stair'): 1.0,
#  ('peribronchovascular', 'plate'): 1.0,
#  ('ctx', 'schizophrenia'): 1.0,
#  ('phlegm', 'splint'): 1.0,
#  ('cyanot', 'lw'): 0.0,
#  ('aox', 'laminectomi'): 1.0,
#  ('clinician', 'occipit'): 1.0,
#  ('qam', 'rememb'): 1.0,
#  ('abnl', 'clonidin'): 1.0,
#  ('epigastr', 'nifedipin'): 1.0,
#  ('ipf', 'norepinephrin'): 0.0,
#  ('chair', 'levoph'): 1.0,
#  ('ferrou', 'rhinorrhea'): 1.0,
#  ('declar', 'religi'): 0.0,
#  ('dnr', 'pleuravac'): 0.0,
#  ('mellitu', 'scar'): 1.0,
#  ('asthma', 'autoset'): 1.0,
#  ('ambien', 'spacer'): 1.0,
#  ('im', 'mva'): 1.0,
#  ('ferritin', 'platelet'): 1.0,
#  ('ctx', 'im'): 1.0,
#  ('furhter', 'lw'): 0.0,
#  ('omeprazol', 'qam'): 1.0,
#  ('mva', 'td'): 1.0,
#  ('pneumococc', 'puff'): 1.0,
#  ('mso', 'oob'): 1.0,
#  ('mva', 'spacer'): 1.0,
#  ('lpm', 'myeloma'): 0.39994173456925625,
#  ('mtg', 'paralyt'): 0.0,
#  ('hugger', 'levoph'): 0.6207779057371651,
#  ('permiss', 'pose'): 1.0,
#  ('bronchovascular', 'crowd'): 0.6058257216010178,
#  ('dead', 'dopamin'): 0.0,
#  ('hida', 'mjmgb'): 1.0,
#  ('ferrou', 'gait'): 1.0,
#  ('life', 'neo'): 1.0,
#  ('phlegm', 'wish'): 0.0,
#  ('leukocyt', 'scar'): 1.0,
#  ('puff', 'xl'): 1.0,
#  ('deliv', 'respitori'): 1.0,
#  ('neosynephrin', 'pitressin'): 0.0,
#  ('dz', 'venti'): 1.0,
#  ('hypercapnia', 'oob'): 1.0,
#  ('dyslipidemia', 'rhinorrhea'): 1.0,
#  ('flight', 'pleasant'): 1.0,
#  ('ctx', 'suffer'): 1.0,
#  ('im', 'sweat'): 1.0,
#  ('acidot', 'grim'): 0.0,
#  ('agon', 'grim'): 0.0,
#  ('asthma', 'dermat'): 1.0,
#  ('gastriti', 'xii'): 1.0,
#  ('asthma', 'intent'): 1.0,
#  ('ctx', 'palli'): 1.0,
#  ('dnr', 'phenylephrin'): 0.0,
#  ('ppn', 'prognosi'): 1.0,
#  ('colonoscopi', 'readdress'): 1.0,
#  ('ambul', 'levoph'): 1.0,
#  ('hilum', 'lymphangit'): 1.0,
#  ('cocain', 'ultram'): 1.0,
#  ('chb', 'dni'): 0.5,
#  ('angiogram', 'gadolinium'): 1.0,
#  ('db', 'hive'): 1.0,
#  ('neo', 'palli'): 0.0,
#  ('bill', 'fibrinogen'): 1.0,
#  ('oob', 'prec'): 1.0,
#  ('epigastr', 'fibrinogen'): 1.0,
#  ('preme', 'zero'): 1.0,
#  ('aaox', 'subdur'): 1.0,
#  ('diaphoresi', 'lighthead'): 1.0,
#  ('incis', 'opinion'): 1.0,
#  ('impli', 'pea'): 1.0,
#  ('puff', 'qam'): 1.0,
#  ('bottl', 'pea'): 1.0,
#  ('asthma', 'mucinex'): 1.0,
#  ('deliv', 'dni'): 1.0,
#  ('brb', 'unstabl'): 0.0,
#  ('ferritin', 'wish'): 1.0,
#  ('levoph', 'pleasant'): 1.0,
#  ('dnr', 'muddi'): 0.5743392170170073,
#  ('bipolar', 'olanzapin'): 1.0,
#  ('asthma', 'seroquel'): 1.0,
#  ('gastrojejunostomi', 'soln'): 1.0,
#  ('commod', 'spiromet'): 1.0,
#  ('natg', 'scar'): 0.0,
#  ('fdp', 'petechia'): 0.0,
#  ('bicarbon', 'wma'): 0.0,
#  ('acidot', 'ffp'): 0.0,
#  ('autoset', 'db'): 1.0,
#  ('behavior', 'readmit'): 1.0,
#  ('diaphoresi', 'hygein'): 1.0,
#  ('option', 'thrive'): 0.0,
#  ('gastrojejunostomi', 'ligament'): 1.0,
#  ('nicotin', 'xopenex'): 1.0,
#  ('breakfast', 'sensat'): 1.0,
#  ('diaphoresi', 'dizzi'): 1.0,
#  ('dome', 'lat'): 1.0,
#  ('crack', 'habitu'): 1.0,
#  ('hctz', 'young'): 1.0,
#  ('fibrinogen', 'rigor'): 1.0,
#  ('endur', 'pod'): 1.0,
#  ('icter', 'palli'): 1.0,
#  ('aricept', 'pivot'): 0.0,
#  ('ba', 'ppd'): 1.0,
#  ('clonazepam', 'seroquel'): 1.0,
#  ('aaox', 'lac'): 1.0,
#  ('currenlti', 'trabecul'): 1.0,
#  ('norepinephrin', 'wma'): 0.0,
#  ('itchi', 'wish'): 1.0,
#  ('^th', 'ciwa'): 1.0,
#  ('pleasant', 'wish'): 1.0,
#  ('commod', 'cyanot'): 0.0,
#  ('lift', 'mrg'): 1.0,
#  ('norepinephrin', 'recalibr'): 1.0,
#  ('esld', 'phenylephrin'): 0.495183056737107,
#  ('oligur', 'sluggishli'): 0.0,
#  ('dead', 'vasopressin'): 0.0,
#  ('profound', 'vasopressin'): 0.0,
#  ('chair', 'redirect'): 1.0,
#  ('osa', 'pod'): 1.0,
#  ('hospic', 'ppn'): 1.0,
#  ('lat', 'occupi'): 1.0,
#  ('pose', 'vasoconstrict'): 0.0,
#  ('declin', 'romi'): 1.0,
#  ('pinpoint', 'sluggish'): 0.0,
#  ('ffp', 'vasopressin'): 0.0,
#  ...}

# %%
# patient_dead_cooc_df
print(patient_cooc_0)
# Out:
# {111: {('arrest', 'pea'): 5.0, ('cpr', 'pea'): 4.0, ('arrest', 'cpr'): 4.0, ('cpr', 'vasopressin'): 4.0, ('pea', 'vasopressin'): 4.0, ('arrest', 'vasopressin'): 4.0, ('pcv', 'vasopressin'): 2.0, ('cpr', 'pcv'): 2.0, ('pcv', 'pea'): 2.0, ('arrest', 'pcv'): 2.0, ('paralyt', 'pcv'): 2.0, ('paralyt', 'vasopressin'): 2.0, ('cpr', 'paralyt'): 2.0, ('paralyt', 'pea'): 2.0, ('arrest', 'paralyt'): 2.0, ('norepinephrin', 'paralyt'): 2.0, ('norepinephrin', 'pcv'): 2.0, ('norepinephrin', 'vasopressin'): 2.0, ('cpr', 'norepinephrin'): 2.0, ('norepinephrin', 'pea'): 2.0, ('arrest', 'norepinephrin'): 2.0, ('hypothermia', 'norepinephrin'): 2.0, ('hypothermia', 'paralyt'): 2.0, ('hypothermia', 'pcv'): 2.0, ('hypothermia', 'vasopressin'): 2.0, ('cpr', 'hypothermia'): 2.0, ('hypothermia', 'pea'): 2.0, ('arrest', 'hypothermia'): 2.0, ('hypercapnia', 'hypothermia'): 2.0, ('hypercapnia', 'norepinephrin'): 2.0, ('hypercapnia', 'paralyt'): 2.0, ('hypercapnia', 'pcv'): 2.0, ('hypercapnia', 'vasopressin'): 2.0, ('cpr', 'hypercapnia'): 2.0, ('hypercapnia', 'pea'): 2.0, ('arrest', 'hypercapnia'): 2.0, ('dic', 'hypercapnia'): 2.0, ('dic', 'hypothermia'): 2.0, ('dic', 'norepinephrin'): 2.0, ('dic', 'paralyt'): 2.0, ('dic', 'pcv'): 2.0, ('dic', 'vasopressin'): 2.0, ('cpr', 'dic'): 2.0, ('dic', 'pea'): 2.0, ('arrest', 'dic'): 2.0, ('dic', 'phenylephrin'): 2.0, ('hypercapnia', 'phenylephrin'): 2.0, ('hypothermia', 'phenylephrin'): 2.0, ('norepinephrin', 'phenylephrin'): 2.0, ('paralyt', 'phenylephrin'): 2.0, ('pcv', 'phenylephrin'): 2.0, ('phenylephrin', 'vasopressin'): 2.0, ('cpr', 'phenylephrin'): 2.0, ('pea', 'phenylephrin'): 2.0, ('arrest', 'phenylephrin'): 2.0, ('bicarbon', 'phenylephrin'): 2.0, ('bicarbon', 'dic'): 2.0, ('bicarbon', 'hypercapnia'): 2.0, ('bicarbon', 'hypothermia'): 2.0, ('bicarbon', 'norepinephrin'): 2.0, ('bicarbon', 'paralyt'): 2.0, ('bicarbon', 'pcv'): 2.0, ('bicarbon', 'vasopressin'): 2.0, ('bicarbon', 'cpr'): 2.0, ('bicarbon', 'pea'): 2.0, ('arrest', 'bicarbon'): 2.0, ('azotemia', 'bicarbon'): 2.0, ('azotemia', 'phenylephrin'): 2.0, ('azotemia', 'dic'): 2.0, ('azotemia', 'hypercapnia'): 2.0, ('azotemia', 'hypothermia'): 2.0, ('azotemia', 'norepinephrin'): 2.0, ('azotemia', 'paralyt'): 2.0, ('azotemia', 'pcv'): 2.0, ('azotemia', 'vasopressin'): 2.0, ('azotemia', 'cpr'): 2.0, ('azotemia', 'pea'): 2.0, ('arrest', 'azotemia'): 2.0, ('autopeep', 'azotemia'): 2.0, ('autopeep', 'bicarbon'): 2.0, ('autopeep', 'phenylephrin'): 2.0, ('autopeep', 'dic'): 2.0, ('autopeep', 'hypercapnia'): 2.0, ('autopeep', 'hypothermia'): 2.0, ('autopeep', 'norepinephrin'): 2.0, ('autopeep', 'paralyt'): 2.0, ('autopeep', 'pcv'): 2.0, ('autopeep', 'vasopressin'): 2.0, ('autopeep', 'cpr'): 2.0, ('autopeep', 'pea'): 2.0, ('arrest', 'autopeep'): 2.0, ('arrest', 'death'): 3.0, ('death', 'vasopressin'): 2.0, ('cpr', 'death'): 2.0, ('death', 'pea'): 2.0, ('clinician', 'death'): 2.0, ('clinician', 'vasopressin'): 2.0, ('clinician', 'cpr'): 2.0, ('clinician', 'pea'): 2.0, ('arrest', 'clinician'): 2.0, ('profound', 'vasopressin'): 2.0, ('cpr', 'profound'): 2.0, ('pea', 'profound'): 2.0, ('arrest', 'profound'): 2.0, ('death', 'expir'): 2.0, ('arrest', 'expir'): 2.0}, 346: {}, 404: {('death', 'paco'): 1.0}, 546: {('hurt', 'oder'): 1.0, ('historian', 'oder'): 1.0, ('historian', 'hurt'): 1.0}, 618: {}, 705: {('dni', 'dnr'): 2.0, ('cmo', 'dnr'): 2.0}, 726: {}, 1039: {}, 1556: {('dnr', 'mso'): 7.0, ('dni', 'dnr'): 8.0, ('dni', 'mso'): 7.0}, 1872: {}, 1944: {}, 2286: {('cyanot', 'pitressin'): 11.0, ('cyanot', 'incis'): 8.0, ('anur', 'cyanot'): 7.0, ('bair', 'hugger'): 7.0}, 2990: {}, 3055: {}, 3099: {('neo', 'neosynephrin'): 1.0, ('dopamin', 'neosynephrin'): 1.0, ('ffp', 'neo'): 1.0, ('ffp', 'neosynephrin'): 1.0, ('ffp', 'vasopressin'): 1.0, ('neo', 'vasopressin'): 1.0, ('neosynephrin', 'vasopressin'): 1.0, ('levoph', 'vasopressin'): 1.0, ('ffp', 'levoph'): 1.0, ('levoph', 'neo'): 1.0, ('levoph', 'neosynephrin'): 1.0, ('hypotherm', 'levoph'): 1.0, ('hypotherm', 'vasopressin'): ...

# %%
print(patient_node_0)
# Out:
# {111: {'arrest': 6.0, 'pea': 5.0, 'cpr': 4.0, 'vasopressin': 4.0, 'pcv': 2.0, 'paralyt': 2.0, 'norepinephrin': 2.0, 'hypothermia': 2.0, 'hypercapnia': 2.0, 'dic': 2.0, 'phenylephrin': 2.0, 'bicarbon': 2.0, 'azotemia': 2.0, 'autopeep': 2.0, 'death': 3.0, 'clinician': 2.0, 'profound': 2.0, 'expir': 2.0}, 346: {'arrest': 4.0, 'sluggish': 6.0}, 404: {'paco': 1.0, 'death': 1.0}, 546: {'oder': 1.0, 'hurt': 1.0, 'historian': 1.0}, 618: {'video': 2.0}, 705: {'dnr': 5.0, 'dni': 2.0, 'cmo': 5.0, 'mso': 2.0}, 726: {'mso': 3.0, 'dnr': 3.0}, 1039: {'wish': 4.0}, 1556: {'mso': 13.0, 'dnr': 8.0, 'dni': 8.0}, 1872: {'pronounc': 1.0}, 1944: {'arrest': 4.0, 'cvvhd': 5.0}, 2286: {'cyanot': 17.0, 'vasopressin': 14.0, 'levoph': 8.0, 'dnr': 7.0, 'prognosi': 7.0, 'purpl': 10.0, 'mottl': 7.0, 'pitressin': 15.0, 'incis': 10.0, 'anur': 9.0, 'cvvh': 9.0, 'hugger': 7.0, 'bair': 7.0}, 2990: {'chair': 17.0, 'oob': 17.0, 'levoph': 31.0, 'anur': 24.0}, 3055: {'gc': 3.0, 'wish': 3.0, 'cmo': 4.0}, 3099: {'neo': 2.0, 'neosynephrin': 2.0, 'dopamin': 1.0, 'ffp': 2.0, 'vasopressin': 1.0, 'levoph': 1.0, 'hypotherm': 1.0, 'hung': 1.0, 'dic': 1.0, 'cagluc': 1.0, 'suport': 1.0, 'polici': 1.0, 'ethic': 1.0, 'cpr': 1.0}, 3201: {'sluggish': 3.0, 'dopamin': 3.0, 'norepinephrin': 1.0, 'levoph': 1.0, 'unavail': 1.0, 'neo': 2.0, 'pitressin': 1.0, 'vasopressin': 1.0, 'unequ': 1.0, 'pronounc': 1.0, 'nahco': 1.0, 'mortem': 1.0, 'levof': 1.0, 'expir': 1.0, 'cpr': 1.0}, 3526: {'levoph': 2.0, 'dnr': 2.0, 'dni': 2.0, 'laryng': 1.0, 'pronounc': 1.0, 'mso': 1.0, 'jerk': 1.0, 'intiat': 1.0, 'declin': 1.0, 'death': 1.0, 'agon': 1.0}, 3773: {'plate': 1.0, 'mso': 2.0, 'escal': 1.0, 'dopamin': 1.0, 'dnr': 1.0, 'dni': 1.0, 'cmo': 1.0, 'pronounc': 1.0, 'death': 1.0}, 3881: {'dnr': 3.0, 'dni': 3.0, 'cmo': 3.0, 'moan': 2.0, 'sluggish': 2.0}, 4122: {}, 4754: {'levoph': 11.0, 'dobutamin': 10.0, 'captopril': 17.0}, 4811: {'life': 2.0, 'dnr': 2.0, 'dni': 2.0, 'hospic': 2.0}, 5476: {}, 5494: {'dnr': 2.0, 'dni': 2.0, 'wish': 2.0, 'escal': 2.0, 'video': 2.0}, 5774: {'levoph': 13.0, 'neo': 11.0, 'cvvhd': 11.0, 'sluggish': 9.0, 'pneumococc': 13.0, 'hugger': 12.0, 'cpr': 12.0}, 5786: {'dobutamin': 9.0}, 5913: {}, 6133: {'lc': 6.0}, 6735: {'prognosi': 3.0, 'dopamin': 3.0, 'mottl': 2.0, 'mso': 2.0, 'levoph': 2.0, 'cpr': 2.0, 'grave': 2.0}, 6745: {'dnr': 4.0, 'dni': 4.0, 'mso': 2.0, 'wish': 1.0, 'heroic': 1.0, 'rabbi': 1.0, 'profound': 1.0, 'moan': 1.0}, 6973: {'dnr': 3.0, 'dni': 3.0}, 6981: {'lat': 1.0, 'occupi': 1.0, 'dnr': 2.0, 'dni': 2.0, 'pleuravac': 1.0, 'priest': 1.0}, 7277: {'neo': 6.0, 'mso': 14.0}, 7310: {'hospic': 3.0, 'dnr': 3.0, 'dni': 3.0, 'nonrebreath': 1.0, 'palliat': 2.0, 'opinion': 2.0, 'sacrament': 1.0, 'peac': 1.0, 'prognosi': 1.0}, 7924: {'neo': 1.0, 'wish': 1.0, 'reveiw': 1.0}, 7977: {'neo': 3.0, 'levoph': 2.0}, 9908: {'levof': 1.0, 'neosynephrin': 1.0, 'levoph': 1.0, 'intiat': 1.0, 'dnr': 1.0, 'dni': 1.0, 'agon': 1.0, 'cmo': 2.0}, 9984: {'levoph': 4.0, 'incis': 2.0, 'hugger': 2.0}, 10302: {'levoph': 56.0, 'dnr': 41.0, 'hive': 39.0, 'fibrinogen': 39.0, 'platelet': 36.0, 'hemothorax': 36.0, 'chb': 29.999999999999996, 'suffer': 26.0, 'norepinephrin': 17.0, 'dic': 31.0, 'abruptli': 18.0}, 10510: {'xopenex': 7.000000000000001}, 10545: {'gvhd': 2.0, 'dopamin': 2.0, 'cyanot': 1.0, 'eyelid': 1.0, 'fungemia': 1.0, 'furhter': 1.0, 'lw': 1.0, 'twitch': 1.0, 'ambul': 1.0, 'vasopressin': 1.0, 'cmo': 1.0, 'levoph': 1.0, 'vasoconstrict': 1.0, 'liw': 1.0, 'mso': 1.0, 'pose': 1.0, 'prognosi': 1.0, 'sibl': 1.0, 'unstabl': 1.0, 'asystol': 1.0, 'dead': 1.0, 'pronounc': 1.0, 'autopsi': 1.0}, 10642: {'scar': 1.0, 'centimet': 1.0, 'dnr': 4.0, 'dni': 3.0, 'mso': 1.0, 'gasp': 1.0, 'prognosi': 1.0, 'moan': 1.0}, 11049: {'neo': 6.0, 'lw': 2.0, 'phenylephrin': 2.0}, 11209: {'subdur': 1.0, 'deterior': 1.0, 'dni': 3.0, 'dnr': 3.0, 'vasopressor': 1.0, 'bair': 1.0, 'dopamin': 1.0, 'hugger': 1.0, 'hypotherm': 1.0, 'hypothermia': 1.0, 'levoph': 1.0, 'paperwork': 1.0, 'rusti': 1.0, 'sluggish': 1.0, 'wish': 1.0, 'arre ...

# %%
# Check if all nodes has embeddings
patient_node_set = set()
patient_node_0_dict = {}
patient_node_1_dict = {}
    
for k, v in patient_node_0.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_0_dict:
            patient_node_0_dict[item] = v[item]
        else:
            patient_node_0_dict[item] = patient_node_0_dict[item] + v[item]
        
    
for k, v in patient_node_1.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_1_dict:
            patient_node_1_dict[item] = v[item]
        else:
            patient_node_1_dict[item] = patient_node_1_dict[item] + v[item]

# %%
print(len(patient_node_set))
print(len(patient_node_0_dict))
print(len(patient_node_1_dict))
# Out:
# 633
# 379
# 571

# %%
patient_node_odd_scores = {}

for set_item in patient_node_set:
    if set_item in patient_node_0_dict and set_item in patient_node_1_dict:
        d_prob = patient_node_0_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        a_prob = patient_node_1_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_node_odd_scores[set_item] = log_odd_score

# %%
print(patient_node_odd_scores)
# Out:
# {'angri': 6.90875477931522, 'peribronchovascular': 2.1317280276818393, 'vertebra': 1.3825560390092835, 'bicarbon': -0.21662784268989682, 'nephrolog': -0.11754739745695504, 'bottl': 0.7376251128347686, 'im': 2.0293823968853086, 'panic': 6.90875477931522, 'barium': 3.5875897086472195, 'rigor': 6.90875477931522, 'appi': 6.90875477931522, 'respitori': -0.6916505477038827, 'pathologist': 6.90875477931522, 'gabapentin': 6.90875477931522, 'vtach': -2.007571633726069, 'precordium': 1.604655121332035, 'rhinorrhea': 2.765541476724378, 'nahco': 2.473073171472692, 'gurgl': 3.464102558012661, 'wma': -1.9852670803394386, 'nectar': 6.90875477931522, 'thiamin': 6.90875477931522, 'religi': -6.90875477931522, 'conc': 1.3825560390092835, 'cvvh': -0.02545138452962548, 'hurt': 2.2927445483990123, 'nonreact': -6.90875477931522, 'hypercapnia': -2.014895675944767, 'expir': -0.07988277164760577, 'macu': 6.90875477931522, 'cardiovert': 0.08876971262771659, 'syncop': 6.90875477931522, 'probe': 6.90875477931522, 'motil': 0.0, 'hilum': 1.604655121332035, 'maroon': 6.90875477931522, 'dyslipidemia': 6.90875477931522, 'spur': 6.90875477931522, 'smooth': 1.295899090635986, 'gastriti': 6.90875477931522, 'zero': 6.90875477931522, 'oximetri': 6.90875477931522, 'adenocarcinoma': 3.112820623527696, 'diuril': 6.90875477931522, 'familt': -6.90875477931522, 'uri': 6.90875477931522, 'herp': 6.90875477931522, 'option': -1.4352492835070114, 'mrcp': -1.0271828417136022, 'jejunum': 0.5378679732223675, 'chip': 6.90875477931522, 'pronounc': 1.121185584669415, 'hive': 2.0229359235263975, 'mva': 6.90875477931522, 'analgesia': -6.90875477931522, 'stack': -6.90875477931522, 'town': 2.9256884298210646, 'heroic': -6.90875477931522, 'ferritin': 6.90875477931522, 'liw': -6.90875477931522, 'mtg': -2.7191649053795555, 'xanax': 6.90875477931522, 'amb': 6.90875477931522, 'dietari': 6.90875477931522, 'lift': 6.90875477931522, 'oder': -6.90875477931522, 'peerla': 6.90875477931522, 'hugger': -0.9072953759720636, 'cmo': -1.3973812618169323, 'diflucan': 0.5378679732223675, 'viscou': 6.90875477931522, 'lw': 0.8453976222857142, 'unavail': 2.4165779821478726, 'impli': 0.6916505477038827, 'hydralizin': 6.90875477931522, 'xopenex': 1.1046572873035894, 'cyanot': -0.5584397574369147, 'triadyn': -0.07988277164760577, 'anuria': 1.1884144866522524, 'strictur': 6.90875477931522, 'knew': 6.90875477931522, 'mail': 6.90875477931522, 'scab': 2.8164316892990344, 'spfc': 2.0716061679700735, 'deflat': 6.90875477931522, 'bromid': 6.90875477931522, 'struggl': -6.90875477931522, 'cs': 2.552122795903801, 'grim': -6.90875477931522, 'fresh': -6.90875477931522, 'endur': 6.90875477931522, 'acetazolamid': 6.90875477931522, 'hygein': 6.90875477931522, 'effac': 2.552122795903801, 'declin': -0.3251358805203766, 'virtual': 0.0, 'quiac': 6.90875477931522, 'agreement': -6.90875477931522, 'phasic': 1.3825560390092835, 'gvhd': -3.914727064425406, 'icter': 1.0389798967708495, 'morgu': -6.90875477931522, 'bell': 6.90875477931522, 'spirit': 6.90875477931522, 'kerlix': 6.90875477931522, 'oncologist': 2.0823295643174276, 'chemic': 0.4585825764835029, 'forc': 0.9407862693217649, 'compani': 6.90875477931522, 'fibrinogen': 0.6890116342592116, 'death': -0.6916505477038827, 'prognosi': -2.5801888227026284, 'polymorph': -6.90875477931522, 'cg': -6.90875477931522, 'subq': 6.90875477931522, 'unequ': 0.0, 'currenlti': 6.90875477931522, 'grd': 6.90875477931522, 'pneumonectomi': 1.782563518479713, 'nicotin': 6.90875477931522, 'nrbm': 0.0, 'simpli': 6.90875477931522, 'clinician': 0.809128888289493, 'quietli': -1.604655121332035, 'defibril': 6.90875477931522, 'rememb': 6.90875477931522, 'chane': 6.90875477931522, 'osa': 3.0298720743851866, 'dxae': 0.0, 'paco': 2.2927445483990123, 'outer': 1.095952712632351, 'pharmacolog': 6.90875477931522, 'mortem': -6.90875477931522, 'ffp': -0.8734901684270467, 'lcw': 6.90875477931522, 'chol': -6.90875477931522, 'cup': 6.90875477931522, 'ba': 6.90875477931522, 'occupi': 2.0716061679700735, 'lighthead': 6.908 ...

# %%
patient_square_node_data = pd.DataFrame({'node':list(patient_node_odd_scores.keys()), 'feature':list(patient_node_odd_scores.values())})
patient_square_node_data
# Out:
#                     node   feature
# 0                  angri  6.908755
# 1    peribronchovascular  2.131728
# 2               vertebra  1.382556
# 3               bicarbon -0.216628
# 4              nephrolog -0.117547
# ..                   ...       ...
# 628            hypercapn -1.308752
# 629             assymetr  0.914196
# 630             influenc  6.908755
# 631                  lat  2.781918
# 632                  mrg  6.908755
#
# [633 rows x 2 columns]

# %%
patient_square_node_id_data = patient_square_node_data.set_index("node")
patient_square_node_id_data['subject'] = ["positive" if r['feature'] > 0 else "negative" for i, r in patient_square_node_id_data.iterrows()]
patient_square_node_id_data
# Out:
#                       feature   subject
# node
# angri                6.908755  positive
# peribronchovascular  2.131728  positive
# vertebra             1.382556  positive
# bicarbon            -0.216628  negative
# nephrolog           -0.117547  negative
# ...                       ...       ...
# hypercapn           -1.308752  negative
# assymetr             0.914196  positive
# influenc             6.908755  positive
# lat                  2.781918  positive
# mrg                  6.908755  positive
#
# [633 rows x 2 columns]

# %%
patient_subjects = patient_square_node_id_data["subject"]
patient_subjects
# Out:
# node
# angri                  positive
# peribronchovascular    positive
# vertebra               positive
# bicarbon               negative
# nephrolog              negative
#                          ...
# hypercapn              negative
# assymetr               positive
# influenc               positive
# lat                    positive
# mrg                    positive
# Name: subject, Length: 633, dtype: object

# %%
patient_square_node_data_no_feature = patient_square_node_id_data.drop(columns=["feature","subject"])
patient_square_node_data_no_feature
# Out:
# Empty DataFrame
# Columns: []
# Index: [angri, peribronchovascular, vertebra, bicarbon, nephrolog, bottl, im, panic, barium, rigor, appi, respitori, pathologist, gabapentin, vtach, precordium, rhinorrhea, nahco, gurgl, wma, nectar, thiamin, religi, conc, cvvh, hurt, nonreact, hypercapnia, expir, macu, cardiovert, syncop, probe, motil, hilum, maroon, dyslipidemia, spur, smooth, gastriti, zero, oximetri, adenocarcinoma, diuril, familt, uri, herp, option, mrcp, jejunum, chip, pronounc, hive, mva, analgesia, stack, town, heroic, ferritin, liw, mtg, xanax, amb, dietari, lift, oder, peerla, hugger, cmo, diflucan, viscou, lw, unavail, impli, hydralizin, xopenex, cyanot, triadyn, anuria, strictur, knew, mail, scab, spfc, deflat, bromid, struggl, cs, grim, fresh, endur, acetazolamid, hygein, effac, declin, virtual, quiac, agreement, phasic, gvhd, ...]
#
# [633 rows x 0 columns]

# %%
from sklearn.manifold import TSNE
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
from gensim.models import Word2Vec

# %% [markdown]
# ### Create a bi-directional df

# %%
# with edge weight
bidirect_source = []
bidirect_target = []
edge_weight = []

for item, val in new_patient_cooc_odd_scores.items():
    bidirect_source.extend([item[0], item[1]])
    bidirect_target.extend([item[1], item[0]])
    edge_weight.extend([val, val])
    
print(f"source: {len(bidirect_source)}, target: {len(bidirect_target)}")

weighted_patient_bidirect_square_edge_data = pd.DataFrame(
    {
        "source": bidirect_source,
        "target": bidirect_target,
        "weight": edge_weight,
    })
weighted_patient_bidirect_square_edge_data
# Out:
# source: 13552, target: 13552
#            source      target  weight
# 0            life    trazodon     0.0
# 1        trazodon        life     0.0
# 2      gadolinium       outer     1.0
# 3           outer  gadolinium     1.0
# 4       historian         uri     1.0
# ...           ...         ...     ...
# 13547        tran      absorb     1.0
# 13548     asystol   pulseless     0.0
# 13549   pulseless     asystol     0.0
# 13550      ambien      freeli     1.0
# 13551      freeli      ambien     1.0
#
# [13552 rows x 3 columns]

# %%
# Weighted
G_weighted_patient_bidirect = StellarGraph(
    {"corner": patient_square_node_data_no_feature}, {"line": weighted_patient_bidirect_square_edge_data}
)
print(G_weighted_patient_bidirect.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 633, Edges: 13552
#
#  Node types:
#   corner: [633]
#     Features: none
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [13552]
#         Weights: range=[0, 1], mean=0.734681, std=0.426758
#         Features: none

# %%
# Weighted
rw_weighted_patient_bidirect = BiasedRandomWalk(G_weighted_patient_bidirect)

# %%
# Weighted
weighted_walks_patient_bidirect = rw_weighted_patient_bidirect.run(
    nodes=G_weighted_patient_bidirect.nodes(),  # root nodes
    length=100,  # maximum length of a random walk
    n=10,  # number of random walks per root node
    p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
    q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
#     weighted=True,  # for weighted random walks
    seed=42,  # random seed fixed for reproducibility
)
print("Number of random walks: {}".format(len(weighted_walks_patient_bidirect)))
# Out:
# Number of random walks: 6330

# %%
print(weighted_walks_patient_bidirect[0])
# Out:
# ['angri', 'declin', 'azotemia', 'wma', 'hypothermia', 'paralyt', 'hugger', 'ctx', 'levoph', 'dnr', 'occipit', 'calvarium', 'slice', 'occipit', 'angiogram', 'flight', 'rhinorrhea', 'sweat', 'phlegm', 'levoph', 'svv', 'neo', 'acidot', 'prognosi', 'pronounc', 'dnr', 'fungemia', 'dnr', 'lymphangit', 'lac', 'dni', 'struggl', 'palli', 'prilosec', 'xopenex', 'prilosec', 'asthma', 'schizophrenia', 'ctx', 'death', 'oob', 'compani', 'prilosec', 'carvedilol', 'dni', 'sweat', 'hypothermia', 'sweat', 'ciwa', 'lusb', 'wish', 'hive', 'asthma', 'deterior', 'contd', 'dopamin', 'rusti', 'levoph', 'ccn', 'levoph', 'gait', 'hung', 'gait', 'arrest', 'mellitu', 'klonopin', 'led', 'klonopin', 'schizophrenia', 'dizzi', 'dnr', 'ferrou', 'readmit', 'ferrou', 'aox', 'dnr', 'rhinorrhea', 'mellitu', 'itchi', 'phenylephrin', 'platelet', 'qtc', 'zyprexa', 'qtc', 'postop', 'tubular', 'gotten', 'bottl', 'carvedilol', 'prilosec', 'fibrinogen', 'palli', 'prilosec', 'palli', 'deterior', 'asthma', 'deterior', 'hunger', 'deterior', 'readmit']

# %%
# Weighted
weighted_model_patient = Word2Vec(
    weighted_walks_patient_bidirect, size=128, window=5, min_count=0, sg=1, workers=4, iter=1
)

# %%
# Weighted
emb = weighted_model_patient.wv["cmo"]
emb
# Out:
# array([-0.1459338 ,  0.0764907 ,  0.08501972, -0.11614478,  0.2989457 ,
#        -0.11658391, -0.25964987, -0.24873349, -0.00510632, -0.01106197,
#        -0.12185645,  0.16332667, -0.10879204, -0.26113355,  0.23762348,
#         0.02120691,  0.07743695,  0.39331707, -0.06719822, -0.13361138,
#         0.14497826,  0.01681575, -0.26039016,  0.12916636,  0.16420852,
#        -0.01700177, -0.13415702, -0.04476665, -0.15749386, -0.368695  ,
#         0.02805015,  0.3204966 , -0.04131727, -0.14308305, -0.04420976,
#        -0.32230178, -0.24756937, -0.05431841, -0.10964144,  0.23507126,
#        -0.013694  , -0.08990972,  0.11272962, -0.00994182,  0.1630974 ,
#        -0.33265513,  0.22573061,  0.3537934 , -0.31589407, -0.13769658,
#        -0.07433578,  0.59769356, -0.26204538, -0.08734526,  0.17831892,
#        -0.23126754,  0.1781018 , -0.03284152, -0.00291121, -0.01026342,
#         0.09466639,  0.41922176,  0.0034988 ,  0.23609854, -0.22423384,
#        -0.37250543, -0.06648222, -0.12035035,  0.1448952 , -0.26208904,
#         0.18925089, -0.10942571,  0.25982642, -0.5947244 ,  0.07889443,
#        -0.44915828,  0.19491343,  0.19679844, -0.1819697 , -0.13661465,
#        -0.09336176, -0.10752854, -0.17836992,  0.09046532,  0.04487041,
#        -0.24127266, -0.01956481, -0.21199226,  0.1837249 , -0.06944786,
#         0.42190808, -0.1731125 ,  0.13710357, -0.24402943, -0.28046736,
#         0.11053751, -0.082739  , -0.18620083,  0.05587145,  0.05263319,
#        -0.00654797, -0.08500707,  0.22324768, -0.08283636, -0.107762  ,
#         0.0814555 , -0.06849146, -0.61454725, -0.19431071,  0.0919876 ,
#         0.47710133, -0.18878444, -0.19057922, -0.54262364, -0.08081284,
#         0.14596245, -0.24009486,  0.22669134, -0.00443756,  0.30747658,
#         0.22878776, -0.03108631, -0.3114657 , -0.05960777,  0.04302422,
#         0.10762119,  0.1379485 , -0.09799738], dtype=float32)

# %% [markdown]
# ### Visualise Node Embeddings generated by weighted random walks

# %% [markdown]
# ### Weighted edges

# %%
# Retrieve node embeddings and corresponding subjects
patient_weighted_node_ids = weighted_model_patient.wv.index2word  # list of node IDs
patient_weighted_node_embeddings = (
    weighted_model_patient.wv.vectors
)  # numpy.ndarray of size number of nodes times embeddings dimensionality
# the gensim ordering may not match the StellarGraph one, so rearrange
patient_node_targets = patient_subjects.loc[patient_weighted_node_ids].astype("category")

# %%
# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2, random_state=42)
patient_weighted_node_embeddings_2d = tsne.fit_transform(patient_weighted_node_embeddings)

# %%
# draw the points
alpha = 0.7

plt.figure(figsize=(10, 8))
plt.scatter(
    patient_weighted_node_embeddings_2d[:, 0],
    patient_weighted_node_embeddings_2d[:, 1],
    c=patient_node_targets.cat.codes,
    cmap="jet",
    alpha=0.7,
)
plt.show()

# %%
patient_weighted_node_emb_dict = {}
for index, row in patient_square_node_data_no_feature.iterrows():
    if index not in patient_weighted_node_emb_dict:
        patient_weighted_node_emb_dict[index] = weighted_model_patient.wv[index]
    else:
        print(f"index: {index} is already in a dictionary!")

# %%
# print(type(patient_weighted_node_emb_dict['aprv']))

# %%
import pandas as pd
import numpy as np

import stellargraph as sg
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import GCNSupervisedGraphClassification
from stellargraph import StellarGraph

from stellargraph import datasets

from sklearn import model_selection
from IPython.display import display, HTML

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import matplotlib.pyplot as plt

seed = 42
numpy.random.seed(seed)
tf.random.set_seed(seed)
sg.random.set_seed(seed)

# %% [markdown]
# ### Load the data

# %%
from collections import defaultdict

def create_graph_list(patient_cooc_dict, cooc_odd_scores, node_emb_dict, label):
    
    graphs = []
    labels = []
    
    for key,row in patient_cooc_dict.items():
     
        if row:
            source = []
            target = []
            edge_weight = []
            
            node_feature = []
            node_idx = []
            for cooc in row:
                source.extend([cooc[0], cooc[1]])
                target.extend([cooc[1], cooc[0]])
                edge_weight.extend([cooc_odd_scores[cooc], cooc_odd_scores[cooc]])
        
            node_idx = list(set(source + target))
    
            # Create a dataframe of only nodes
            square_node_data = pd.DataFrame(
                index=node_idx)
            
#             square_node_data['feature'] = [1] * len(node_idx)
        
            # Create a dictionary for each column for a vector
            node_features = defaultdict(list)
            for node in node_idx:
                for i, vec in enumerate(node_emb_dict[node]):
                    node_features['w_' + str(i)].append(vec)
        
            # Add columns to a dataframe
            for k, v in node_features.items():
              
                square_node_data[k] = v

            square_edges = pd.DataFrame({ 
                "source": source, 
                "target": target, 
                "weight":edge_weight
            })
        
            square = StellarGraph({"corner": square_node_data}, {"line": square_edges})
            graphs.append(square)
            labels.append(label)
            
    return graphs, labels

graphs = []
labels = []

# patient_weighted_node_emb_dict
graph_0, label_0 = create_graph_list(patient_cooc_0, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, -1)
graph_1, label_1 = create_graph_list(patient_cooc_1, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, 1)

graphs.extend(graph_0)
labels.extend(label_0)
print(f"graphs_0: {len(graphs)}, labels_0: {len(labels)}")
graphs.extend(graph_1)
labels.extend(label_1)
print(f"graphs_1: {len(graph_1)}, labels_1: {len(label_1)}")
print(f"graphs: {len(graphs)}, labels: {len(labels)}")
# Out:
# graphs_0: 162, labels_0: 162
# graphs_1: 726, labels_1: 726
# graphs: 888, labels: 888

# %%
# prepare test and train datasets
test_cnt = int(len(graphs)*0.1)/2
print(test_cnt)

pos_start = len(graph_0)
print(pos_start)

test_arr = []
train_arr = []
for i, v in enumerate(graphs):
    # Take first items for neg set
    if i < test_cnt:
        test_arr.append(i)    
    elif i > pos_start and i <= pos_start + test_cnt:
        test_arr.append(i)    
    else:
        train_arr.append(i)
# Out:
# 44.0
# 162

# %%
import random
seed = 42
c = list(test_arr)
random.Random(seed).shuffle(c)
test_arr =  c

# %%
c = list(train_arr)
random.Random(seed).shuffle(c)
train_arr =  c

# %%
train_index = np.array(train_arr)
test_index = np.array(test_arr)

# %%
print(len(test_index))
print(test_index)
# Out:
# 88
# [178 182  33  30  19  26 165 187  15 185  42   1 195 179 175  37 186  36
#  171 164 192  20 202   8  41 198  40 177  32 174  39 205  43 196  12  23
#   18 189 169 168   7  34 190   2  16  38 166  22 180  24   5   6 184 181
#  199   9 206  21 191 163  10 170 167   0 203 176 201 172  25 193 183  29
#   27 197 204   4 173 194  11 188  13  17  28  31  35   3  14 200]

# %%
print(len(train_index))
print(train_index)
# Out:
# 800
# [820 462 661 578 735 619 446 737 538 861 583 732 876 425  68 879 265 466
#  428 149 486 132 703 509 288 289 577 319 327 464 108 822 818 317 632 700
#  598 324 719 767 309 532 587 819 417 368 390 279 489 404 122 300 762 471
#  824 479 744 838 389 238 626  80 690 273 260 268 136  53 445  94 551 118
#  754  57 826 262 857 627 490 539 365 353 447 663 408 716 320 870 522 444
#  791 595 301 728 777 335  52 442  72 835 734 485 582 611 413  54 675 473
#  510 352 693 261 492 725 741 350 714 102 671 565 860  77 525  67 610 154
#   61 286 775 695 569 678 665 250  86 814 351 236 670 812 638 789 519 568
#  399 502 225 592 457 813 505 677 608 602 329  49 237 649 360 474 623 808
#  207 497 128 684 755  60 590  83 325 394 469 381 615 226 783 129 666 766
#  800 837 752 276 694 571 212 540 790 749 564 481 344 491 278  84 421 228
#  463 217 272 337 511 281 844 240 697 403 452 739 315 866 705  75 378 480
#  850 162 220 727 763  89 100 723 287 864 400 589 280 881 483 398 630 736
#  339 664 573 883 531 555  93 235 545 560 150 518 465 636 776 423 443 804
#  798 852 537 145 159 544 576 488 259 527  87 130 621 395 535 356 612 815
#  252 382 453 770 243 594 295 606 874 603 303 720 707 239 575 794 297 604
#  534 512 107 657 409 415 460 456 625 682 354 713 396 484 218 141 383 285
#  761 349 868 554 264 601 722 549 647 773 385 438 591 507  58 873 781 548
#  618 563 416 530 768 613 292 142 495 708 160 718 267 672 146 157 328 709
#  283 643 816 224 859 556 298 745 135  56 299 134 127 209 503 644 296 374
#  269  96 515 832 437 499 271 887 274 245 674 676 845 119 831 562 528  62
#  367 120 441  82 786 516 375 616 449 370 314 807 126 222 414 110 620  45
#   66 757 688 494  91  70 696 795 346 645 412 439 771 797 839 151 397 232
#  227 123 513 468  98 726 827 112  97 427 796 371 506 429 542 836 422 501
#  401 242 448 366 514 758 710 233 277 213 581 266 680 729 347 153 363 829
#  624 376 406 546  48  81 472 559 667 241 418 431 877 290 656 210 597 454
#  430 843 221 750 355 377 386 424 805 584 405  64 681 817 214 379 543 570
#  105 294 208 648 433  78 392  79 622 523  85 348 579 596 712 756 524 834
#  740 332 387 885  73 248 683 641 865 310 391 635 246 586 858 380 553 854
#  487  46 792 256 702 782 306 580 659 652 258 330 869  59  95 642 541 121
#  343 793 660 275 748 231 855 651 823 342 155 435 500 106 144  99 566 508
#  689 450 529 840 140 282 504 673 336 572 223 687 307 699 373 331 614 669
#  426 784 113 785 104 116  51 856 323 655  65 434 772 318 341 211 550 617
#  536 717 760 407 293 715 779 521 628 769 257 650 574 219 216 633 114 585
#  131 830 778 334 103 333 402 459 733  63 588 419 701  44 631 640 253 470
#  801 862 799 724 393 152 607 270 600 764  47 811 249 533 828 886 848 803
#  833 161  55 654 345 629 567 747 478 482 109 698 849 851 730 244 156  92
#  137 593 609 229 788 825 496 685 526 686 357 639 863 340 880 359 234 557
#  746 493 599 759 305 410 668 304 111 362 498 411 871 322 101 420 312 658
#  743 364 476 561 255 882 634 263 810 711 117 751 787 361 774 302 451 467
#  254 461 738 552 884 841 147 867 125 384 321 765  90 115 809 284 679 458
#  721 731 388 653 124 475 215 637 558  88 358 706 440 455 143 477 138 878
#  432 308 247 853 436 872 802 251  50 372 691 547 313 517 875 806 753 821
#  291 662  71 704 605 326 311 139  74  76 520 692 133 646 846 780 148 842
#  230 316 338 369 847  69 158 742]

# %%
print(test_arr)
# Out:
# [178, 182, 33, 30, 19, 26, 165, 187, 15, 185, 42, 1, 195, 179, 175, 37, 186, 36, 171, 164, 192, 20, 202, 8, 41, 198, 40, 177, 32, 174, 39, 205, 43, 196, 12, 23, 18, 189, 169, 168, 7, 34, 190, 2, 16, 38, 166, 22, 180, 24, 5, 6, 184, 181, 199, 9, 206, 21, 191, 163, 10, 170, 167, 0, 203, 176, 201, 172, 25, 193, 183, 29, 27, 197, 204, 4, 173, 194, 11, 188, 13, 17, 28, 31, 35, 3, 14, 200]

# %%
print(graphs[0].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 18, Edges: 212
#
#  Node types:
#   corner: [18]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [212]
#         Weights: range=[0, 0.788597], mean=0.0526238, std=0.175607
#         Features: none

# %%
print(graphs[100].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 11, Edges: 76
#
#  Node types:
#   corner: [11]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [76]
#         Weights: range=[0, 0.552589], mean=0.214523, std=0.219258
#         Features: none

# %%
summary = pd.DataFrame(
    [(g.number_of_nodes(), g.number_of_edges()) for g in graphs],
    columns=["nodes", "edges"],
)
summary.describe().round(1)
# Out:
#        nodes  edges
# count  888.0  888.0
# mean     5.6   22.4
# std      3.7   33.8
# min      2.0    2.0
# 25%      2.0    2.0
# 50%      5.0    8.0
# 75%      8.0   26.0
# max     23.0  272.0

# %%
graph_labels = pd.Series(labels)

# %%
print(graph_labels)
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 883    1
# 884    1
# 885    1
# 886    1
# 887    1
# Length: 888, dtype: int64

# %%
graph_labels.value_counts().to_frame()
# Out:
#       0
#  1  726
# -1  162

# %%
graph_labels = pd.get_dummies(graph_labels, drop_first=True)

# %%
print(type(graph_labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
graph_labels
# Out:
#      1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 883  1
# 884  1
# 885  1
# 886  1
# 887  1
#
# [888 rows x 1 columns]

# %%
generator = PaddedGraphGenerator(graphs=graphs)

# %%
def create_graph_classification_model(generator):
    gc_model = GCNSupervisedGraphClassification(
        layer_sizes=[64, 64],
        activations=["relu", "relu"],
        generator=generator,
        dropout=0.5,
    )
    x_inp, x_out = gc_model.in_out_tensors()
    predictions = Dense(units=32, activation="relu")(x_out)
    predictions = Dense(units=16, activation="relu")(predictions)
    predictions = Dense(units=1, activation="sigmoid")(predictions)

    # Let's create the Keras model and prepare it for training
    model = Model(inputs=x_inp, outputs=predictions)
    model.compile(optimizer=Adam(0.005), loss=binary_crossentropy, metrics=["acc"])

    return model

# %%
epochs = 200  # maximum number of training epochs
# folds = 10  # the number of folds for k-fold cross validation
# n_repeats = 5  # the number of repeats for repeated k-fold cross validation

# %%
es = EarlyStopping(
    monitor="val_loss", min_delta=0, patience=25, restore_best_weights=True
)

# %%
# To train in folds
def train_fold(model, train_gen, test_gen, es, epochs):
    history = model.fit(
        train_gen, epochs=epochs, validation_data=test_gen, verbose=0, callbacks=[es],
    )
    # calculate performance on the test data and return along with history
    test_metrics = model.evaluate(test_gen, verbose=0)
    test_acc = test_metrics[model.metrics_names.index("acc")]

    return history, test_acc

# %%
# To train in folds
def get_generators(train_index, test_index, graph_labels, batch_size):
    train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )
    test_gen = generator.flow(
        test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )

    return train_gen, test_gen

# %%
# # To train in folds
# test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"Training and evaluating on fold {i+1} out of {folds * n_repeats}...")
#     train_gen, test_gen = get_generators(
#         train_index, test_index, graph_labels, batch_size=30
#     )

#     model = create_graph_classification_model(generator)

#     history, acc = train_fold(model, train_gen, test_gen, es, epochs)

#     test_accs.append(acc)

# %%
# To train in folds
test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
for i in range(50):
    print(f"Training and evaluating on fold {i+1}...")
    
    train_gen, test_gen = get_generators(
        train_index, test_index, graph_labels, batch_size=30
    )

    model = create_graph_classification_model(generator)

    history, acc = train_fold(model, train_gen, test_gen, es, epochs)

    test_accs.append(acc)
# Out:
# Training and evaluating on fold 1...
# Training and evaluating on fold 2...
# Training and evaluating on fold 3...
# Training and evaluating on fold 4...
# Training and evaluating on fold 5...
# Training and evaluating on fold 6...
# Training and evaluating on fold 7...
# Training and evaluating on fold 8...
# Training and evaluating on fold 9...
# Training and evaluating on fold 10...
# Training and evaluating on fold 11...
# Training and evaluating on fold 12...
# Training and evaluating on fold 13...
# Training and evaluating on fold 14...
# Training and evaluating on fold 15...
# Training and evaluating on fold 16...
# Training and evaluating on fold 17...
# Training and evaluating on fold 18...
# Training and evaluating on fold 19...
# Training and evaluating on fold 20...
# Training and evaluating on fold 21...
# Training and evaluating on fold 22...
# Training and evaluating on fold 23...
# Training and evaluating on fold 24...
# Training and evaluating on fold 25...
# Training and evaluating on fold 26...
# Training and evaluating on fold 27...
# Training and evaluating on fold 28...
# Training and evaluating on fold 29...
# Training and evaluating on fold 30...
# Training and evaluating on fold 31...
# Training and evaluating on fold 32...
# Training and evaluating on fold 33...
# Training and evaluating on fold 34...
# Training and evaluating on fold 35...
# Training and evaluating on fold 36...
# Training and evaluating on fold 37...
# Training and evaluating on fold 38...
# Training and evaluating on fold 39...
# Training and evaluating on fold 40...
# Training and evaluating on fold 41...
# Training and evaluating on fold 42...
# Training and evaluating on fold 43...
# Training and evaluating on fold 44...
# Training and evaluating on fold 45...
# Training and evaluating on fold 46...
# Training and evaluating on fold 47...
# Training and evaluating on fold 48...
# Training and evaluating on fold 49...
# Training and evaluating on fold 50...

# %%
# 1: Accuracy over all folds mean: 78.3% and std: 3.2%
# 2: Accuracy over all folds mean: 80.2% and std: 2.6%
# 3: Accuracy over all folds mean: 78.0% and std: 4.5%
# 4: Accuracy over all folds mean: 78.0% and std: 4.5%
# 5: Accuracy over all folds mean: 78.9% and std: 4.8%

# ------------------ After setting random
# 1: Accuracy over all folds mean: 78.1% and std: 2.6%
# 2: Accuracy over all folds mean: 77.4% and std: 4.7%
# 3: Accuracy over all folds mean: 78.5% and std: 2.4%
# 4: Accuracy over all folds mean: 77.7% and std: 4.5%
# 5: Accuracy over all folds mean: 77.0% and std: 7.5%

print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 77.0% and std: 7.5%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# 2nd try
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 72.1% and std: 9.2%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"\ntrain_index: \n{train_index}\ntest_index: \n{test_index}\n")
#     break
# print(f"train: {len(train_index)}, test: {len(test_index)}")

# %%
train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)
test_gen = generator.flow(
    test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)

# %%
model_weighted = create_graph_classification_model(generator)

history = model_weighted.fit(
        train_gen, epochs=200, validation_data=test_gen, verbose=1, callbacks=[es])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 61ms/step - loss: 0.5292 - acc: 0.7898 - val_loss: 0.7795 - val_acc: 0.5000
# Epoch 2/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3744 - acc: 0.8505 - val_loss: 0.6660 - val_acc: 0.5000
# Epoch 3/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3378 - acc: 0.8505 - val_loss: 0.5932 - val_acc: 0.5000
# Epoch 4/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.3253 - acc: 0.8660 - val_loss: 0.5577 - val_acc: 0.7564
# Epoch 5/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.3111 - acc: 0.8970 - val_loss: 0.7263 - val_acc: 0.6410
# Epoch 6/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2923 - acc: 0.8787 - val_loss: 0.7418 - val_acc: 0.6410
# Epoch 7/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3078 - acc: 0.8886 - val_loss: 0.6489 - val_acc: 0.6410
# Epoch 8/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.2972 - acc: 0.8956 - val_loss: 0.5324 - val_acc: 0.7564
# Epoch 9/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2898 - acc: 0.8900 - val_loss: 0.5721 - val_acc: 0.7308
# Epoch 10/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2881 - acc: 0.8928 - val_loss: 0.5497 - val_acc: 0.7308
# Epoch 11/200
# 18/18 [==============================] - 1s 49ms/step - loss: 0.2663 - acc: 0.9013 - val_loss: 0.4908 - val_acc: 0.7821
# Epoch 12/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2608 - acc: 0.8984 - val_loss: 0.6779 - val_acc: 0.6667
# Epoch 13/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2698 - acc: 0.9013 - val_loss: 0.5233 - val_acc: 0.7436
# Epoch 14/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2573 - acc: 0.9055 - val_loss: 0.6405 - val_acc: 0.6923
# Epoch 15/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2375 - acc: 0.9097 - val_loss: 0.7150 - val_acc: 0.7179
# Epoch 16/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2365 - acc: 0.9041 - val_loss: 0.8433 - val_acc: 0.6667
# Epoch 17/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2410 - acc: 0.9069 - val_loss: 0.8310 - val_acc: 0.6282
# Epoch 18/200
# 18/18 [==============================] - 0s 28ms/step - loss: 0.2296 - acc: 0.9111 - val_loss: 0.7483 - val_acc: 0.6795
# Epoch 19/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2328 - acc: 0.9111 - val_loss: 0.9809 - val_acc: 0.5513
# Epoch 20/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.2223 - acc: 0.9140 - val_loss: 1.2209 - val_acc: 0.5513
# Epoch 21/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2456 - acc: 0.9154 - val_loss: 0.6157 - val_acc: 0.6923
# Epoch 22/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2258 - acc: 0.9126 - val_loss: 0.6728 - val_acc: 0.6923
# Epoch 23/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2157 - acc: 0.9267 - val_loss: 0.6729 - val_acc: 0.7308
# Epoch 24/200
# 18/18 [==============================] - 1s 49ms/step - loss: 0.2148 - acc: 0.9083 - val_loss: 0.7301 - val_acc: 0.6795
# Epoch 25/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2020 - acc: 0.9182 - val_loss: 0.7652 - val_acc: 0.6795
# Epoch 26/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2361 - acc: 0.9013 - val_loss: 0.8236 - val_acc: 0.5256
# Epoch 27/200
# 18/18 [==============================] - 1s 37ms/step - loss: 0.2234 - acc: 0.9126 - val_loss: 1.0063 - val_acc: 0.5513
# Epoch 28/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.2185 - acc: 0.9140 - val_loss: 0.8404 - val_acc: 0.6667
# Epoch 29/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2188 - acc: 0.9182 - val_loss: 0.7107 - val_acc: 0.6795
# Epoch 30/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2028 - acc: 0.9168 - val_loss: 1.0354 - val_acc: 0.6154
# Epoch 31/200
# 18/18 [==============================] - 1s 47ms/step - loss: 0.1995 - acc: 0.9140 - val_loss: 0.8398 - val_acc: 0.6923
# Epoch 32/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2047 - acc: 0.9224 - val_loss: 0.9179 - val_acc: 0.6282
# Epoch 33/200
# 18/18 [==============================] - 1s 49ms/step - loss: 0.2040 - acc: 0.9252 - val_loss: 0.8058 - val_acc: 0.6795
# Epoch 34/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2086 - acc: 0.9210 - val_loss: 0.7145 - val_acc: 0.6538
# Epoch 35/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.1910 - acc: 0.9210 - val_loss: 0.7358 - val_acc: 0.7179
# Epoch 36/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.1947 - acc: 0.9323 - val_loss: 0.6610 - val_acc: 0.7308

# %%
# calculate performance on the test data and return along with history
# Node features 128 node2vec, edge features all 1
test_metrics = model_weighted.evaluate(test_gen, verbose=1)
test_acc = test_metrics[model_weighted.metrics_names.index("acc")]
# Out:
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4908 - acc: 0.7821

# %%
print(test_metrics)
# loss and accuracy: [0.594617486000061, 0.7307692170143127]
# 2nd try: [0.5068581700325012, 0.7948718070983887]
# [0.5637023448944092, 0.7051281929016113]
print(test_acc)
# Out:
# [0.4908079504966736, 0.7820512652397156]
# 0.7820512652397156

# %%
print("Generate predictions for samples")
predictions = model_weighted.predict(test_gen, verbose=0)
print("predictions shape:", predictions.shape)
# predictions shape: (79, 1)
print(predictions)

# %%
print(test_gen.targets)
