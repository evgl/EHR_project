# %% [markdown]
# ### Data extraction
# Extract data from MIMIC-III

# %%
import time
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Import pandas 
import pandas as pd 

start = time.time()
# reading csv file 
admissions_df = pd.read_csv("../../datasets/mmc-3/ADMISSIONS.csv")
noteevents_df = pd.read_csv("../../datasets/mmc-3/NOTEEVENTS.csv") 
end = time.time()
print(end - start)
# Out:
# /home/evan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning:
#
# Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
# 35.00346636772156

# %%
start = time.time()
# Left join of two dataframes
note_admiss_df_left = noteevents_df.merge(admissions_df, on='HADM_ID', how='left', indicator=True)
end = time.time()
print(end - start)
# Out:
# 6.949193000793457

# %%
note_admiss_df_left[['DIAGNOSIS', 'SUBJECT_ID_x', 'SUBJECT_ID_y','DESCRIPTION', 'CATEGORY']]
# Out:
#                                      DIAGNOSIS  SUBJECT_ID_x  SUBJECT_ID_y  \
# 0                      RT LOWER LOBE PNEUMONIA         22532       22532.0
# 1        CHRONIC OBSTRUCTIVE PULMONARY DISEASE         13702       13702.0
# 2                TRACHEALBRONCHEAL MALACEA/SDA         13702       13702.0
# 3                     ASTHMA;COPD EXACERBATION         13702       13702.0
# 4                           S/P FALL;TELEMETRY         26880       26880.0
# ...                                        ...           ...           ...
# 2083175                                NEWBORN         31097       31097.0
# 2083176                                NEWBORN         31097       31097.0
# 2083177                                NEWBORN         31097       31097.0
# 2083178                                NEWBORN         31097       31097.0
# 2083179                                NEWBORN         31097       31097.0
#
#         DESCRIPTION           CATEGORY
# 0            Report  Discharge summary
# 1            Report  Discharge summary
# 2            Report  Discharge summary
# 3            Report  Discharge summary
# 4            Report  Discharge summary
# ...             ...                ...
# 2083175      Report      Nursing/other
# 2083176      Report      Nursing/other
# 2083177      Report      Nursing/other
# 2083178      Report      Nursing/other
# 2083179      Report      Nursing/other
#
# [2083180 rows x 5 columns]

# %%
pneumonia_df = note_admiss_df_left.loc[note_admiss_df_left["DIAGNOSIS"] == 'PNEUMONIA', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]

# %%
#pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]
pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x','SUBJECT_ID_x','CHARTDATE','STORETIME','CATEGORY','DESCRIPTION','TEXT', 'DEATHTIME']]

# %%
pneumonia_alive_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.isnull()]
pneumonia_dead_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.notnull()]

# %%
pneumonia_dead_no_disch.shape
# Out:
# (11895, 8)

# %%
pneumonia_alive_no_disch.shape
# Out:
# (46134, 8)

# %%
pneumonia_alive_no_disch = pneumonia_alive_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])
pneumonia_dead_no_disch = pneumonia_dead_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])

# %%
# Number of patients
pneumonia_dead_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 252

# %%
# Number of patients
pneumonia_alive_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 1167

# %%
# import text handling tool
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from collections import Counter

import sys
import re
import csv
import os.path

# define constants
# RESULT_HEADER = "WORD, FREQUENCY\n"
MIN_SEQ_LEN = 4
USE_1_N_SEQ = 2


# words that do not have meaning (can be modified later)
USELESS_WORDS = ["a", "the", "he", "she", ",", ".", "?", "!", ":", ";", "+", "*", "**"\
                 "your", "you"]

# count up the frequency of every word in every disease file
stemmer = PorterStemmer()
# create set of words to ignore in text
stop_words = set(stopwords.words('english'))

for word in USELESS_WORDS:
    stop_words.add(word)

# %%
#----------
def count_notes_per_patient(disease_df):
    patient_id_to_num_notes = {}
    patient_id = -1
    note_counter = 0
            
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        patient_id_check = int(row['SUBJECT_ID_x'])
                
        if not patient_id == patient_id_check:
            patient_id_to_num_notes[patient_id] = note_counter
            note_counter = 1
        else:
            note_counter += 1
                    
        patient_id = patient_id_check
                
    patient_id_to_num_notes[patient_id] = note_counter
    del patient_id_to_num_notes[-1]
    return patient_id_to_num_notes

patient_id_to_num_notes = {}
patient_id_to_num_notes['pneumonia_dead'] = count_notes_per_patient(pneumonia_dead_no_disch)
patient_id_to_num_notes['pneumonia_alive'] = count_notes_per_patient(pneumonia_alive_no_disch)
# Out:
# 100%|██████████| 11895/11895 [00:01<00:00, 10413.60it/s]
# 100%|██████████| 46134/46134 [00:04<00:00, 9894.63it/s]

# %%
patient_id_to_num_notes
# Out:
# {'pneumonia_dead': {111: 12,
#   346: 25,
#   404: 3,
#   546: 6,
#   618: 16,
#   705: 15,
#   726: 48,
#   1039: 55,
#   1556: 37,
#   1872: 3,
#   1944: 56,
#   2286: 69,
#   2990: 166,
#   3055: 29,
#   3099: 13,
#   3201: 8,
#   3526: 7,
#   3773: 6,
#   3881: 20,
#   4122: 51,
#   4754: 101,
#   4811: 21,
#   5476: 1,
#   5494: 22,
#   5774: 104,
#   5786: 152,
#   5913: 1,
#   6133: 68,
#   6735: 13,
#   6745: 13,
#   6973: 36,
#   6981: 8,
#   7277: 66,
#   7310: 8,
#   7924: 9,
#   7977: 9,
#   9908: 11,
#   9984: 15,
#   10302: 100,
#   10510: 86,
#   10545: 10,
#   10642: 10,
#   11049: 14,
#   11209: 9,
#   11395: 41,
#   12530: 24,
#   12849: 50,
#   13098: 46,
#   13566: 23,
#   14125: 9,
#   14514: 96,
#   14965: 25,
#   15159: 15,
#   15251: 11,
#   15396: 17,
#   15566: 37,
#   15853: 45,
#   16275: 17,
#   16344: 27,
#   16622: 51,
#   16684: 29,
#   17122: 16,
#   17354: 5,
#   17802: 64,
#   17983: 65,
#   18094: 23,
#   18736: 35,
#   18768: 46,
#   18848: 205,
#   18971: 26,
#   19243: 25,
#   19323: 6,
#   19390: 21,
#   19463: 20,
#   19535: 59,
#   19754: 13,
#   19827: 22,
#   19833: 58,
#   19872: 10,
#   20006: 8,
#   20023: 9,
#   20190: 6,
#   21046: 101,
#   21094: 36,
#   21427: 10,
#   21502: 102,
#   21580: 52,
#   21676: 12,
#   21699: 7,
#   21979: 11,
#   22735: 15,
#   23660: 12,
#   23795: 78,
#   24181: 13,
#   24582: 37,
#   24725: 57,
#   24730: 19,
#   24854: 25,
#   25003: 182,
#   25046: 7,
#   25774: 61,
#   25975: 9,
#   26474: 89,
#   26578: 15,
#   26716: 41,
#   26774: 3,
#   26849: 33,
#   27005: 5,
#   27145: 24,
#   27421: 61,
#   27431: 5,
#   27496: 7,
#   27504: 72,
#   27639: 221,
#   28004: 13,
#   28072: 34,
#   28178: 202,
#   28427: 6,
#   28498: 25,
#   28726: 34,
#   28750: 19,
#   28906: 32,
#   28907: 13,
#   28933: 394,
#   29105: 468,
#   29588: 72,
#   29647: 26,
#   29872: 225,
#   30476: 174,
#   30549: 12,
#   30614: 8,
#   30699: 14,
#   30786: 9,
#   30941: 110,
#   31030: 168,
#   31134: 24,
#   31139: 9,
#   31451: 48,
#   31556: 57,
#   31690: 18,
#   31692: 35,
#   32050: 34,
#   32326: 24,
#   32618: 42,
#   41546: 25,
#   43937: 6,
#   44851: 274,
#   45381: 16,
#   46589: 26,
#   46763: 6,
#   47045: 9,
#   48632: 147,
#   49079: 20,
#   49683: 3,
#   49922: 13,
#   50093: 8,
#   50231: 3,
#   50556: 216,
#   50859: 537,
#   51914: 313,
#   52010: 12,
#   53105: 115,
#   53399: 78,
#   54193: 85,
#   54401: 14,
#   54408: 2,
#   54739: 75,
#   54946: 7,
#   55400: 5,
#   55570: 14,
#   55887: 37,
#   55944: 34,
#   55987: 20,
#   56390: 19,
#   56648: 8,
#   56854: 170,
#   57091: 88,
#   57102: 35,
#   58702: 479,
#   59260: 11,
#   59437: 26,
#   60849: 2,
#   60868: 6,
#   61652: 7,
#   61667: 30,
#   63039: 8,
#   65513: 8,
#   68044: 40,
#   68095: 23,
#   68184: 5,
#   68308: 8,
#   68860: 14,
#   69719: 13,
#   69745: 25,
#   69776: 17,
#   70226: 8,
#   70447: 9,
#   72930: 11,
#   73811: 9,
#   73888: 109,
#   74316: 2,
#   74444: 81,
#   74686: 75,
#   75824: 10,
#   76282: 21,
#   76827: 2,
#   77382: 10,
#   78241: 3,
#   78388: 14,
#   79008: 27,
#   79055: 21,
#   79222: 18,
#   79877: 156,
#   80637: 148,
#   80678: 9,
#   80737: 46,
#   80805: 79,
#   81437: 27,
#   82393: 5,
#   82769: 85,
#   83932: 2,
#   84474: 34,
#   85160: 8,
#   85258: 52,
#   85404: 11,
#   85797: 9,
#   86007: 35,
#   86394: 4,
#   86684: 11,
#   86832: 67,
#   86863: 8,
#   86872: 326,
#   88193: 16,
#   88660: 11,
#   90256: 18,
#   91350: 19,
#   92074: 28,
#   92278: 52,
#   92331: 42,
#   93422: 7,
#   94341: 2,
#   94997: 9,
#   95280: 23,
#   95803: 18,
#   95830: 33,
#   95933: 56,
#   96699: 85,
#   97181: 30,
#   97795: 60,
#   98009: 33,
#   98299: 29,
#   98597: 2},
#  'pneumonia_alive': {68: 18,
#   85: 8,
#   94: 100,
#   165: 2,
#   211: 24,
#   224: 8,
#   231: 75,
#   283: 131,
#   357: 17,
#   368: 45,
#   370: 13,
#   384: 26,
#   426: 10,
#   509: 34,
#   514: 7,
#   596: 23,
#   674: 16,
#   707: 29,
#   711: 537,
#   770: 83,
#   773: 74,
#   899: 17,
#   1096: 17,
#   1135: 32,
#   1163: 12,
#   1174: 42,
#   1180: 5,
#   1283: 3,
#   1332: 66,
#   1339: 134,
#   1546: 21,
#   1568: 22,
#   1601: 12,
#   1606: 13,
#   1642: 4,
#   1660: 23,
#   1895: 22,
#   1923: 23,
#   2029: 175,
#   2090: 179,
#   2098: 26,
#   2128: 31,
#   2170: 9,
#   2187: 30,
#   2208: 139,
#   2337: 8,
#   2378: 57,
#   2386: 18,
#   2452: 22,
#   2508: 22,
#   2561: 126,
#   2585: 9,
#   2589: 92,
#   2590: 5,
#   2628: 218,
#   2658: 16,
#   2732: 12,
#   2784: 23,
#   2823: 21,
#   3070: 8,
#   3100: 70,
#   3154: 22,
#   3220: 28,
#   3277: 35,
#   3347: 15,
#   3359: 15,
#   3516: 11,
#   3602: 18,
#   3623: 116,
#   3641: 57,
#   3676: 49,
#   3830: 80,
#   3860: 203,
#   3862: 22,
#   3865: 8,
#   3895: 6,
#   3935: 44,
#   3952: 20,
#   3975: 34,
#   4109: 9,
#   4155: 23,
#   4236: 14,
#   4275: 45,
#   4316: 13,
#   4317: 106,
#   4328: 23,
#   4388: 14,
#   4454: 5,
#   4467: 12,
#   4489: 21,
#   4494: 18,
#   4584: 39,
#   4588: 80,
#   4641: 23,
#   4694: 19,
#   4804: 6,
#   5030: 49,
#   5145: 9,
#   5244: 113,
#   5264: 115,
#   5360: 19,
#   5434: 24,
#   5476: 36,
#   5516: 31,
#   5536: 21,
#   5564: 30,
#   5579: 14,
#   5609: 39,
#   5619: 25,
#   5631: 9,
#   5681: 9,
#   5691: 12,
#   5727: 41,
#   5761: 85,
#   5819: 19,
#   5904: 16,
#   5937: 61,
#   6038: 4,
#   6143: 15,
#   6176: 5,
#   6183: 17,
#   6206: 7,
#   6279: 20,
#   6378: 112,
#   6398: 11,
#   6557: 16,
#   6603: 15,
#   6884: 43,
#   6901: 8,
#   6915: 190,
#   7107: 230,
#   7169: 9,
#   7271: 117,
#   7356: 12,
#   7363: 284,
#   7492: 58,
#   7569: 32,
#   7603: 39,
#   7666: 9,
#   7700: 68,
#   7787: 18,
#   7849: 96,
#   7936: 3,
#   8070: 69,
#   8312: 29,
#   8337: 22,
#   8366: 25,
#   8471: 15,
#   8512: 16,
#   8515: 21,
#   8532: 9,
#   8556: 71,
#   8803: 4,
#   8895: 10,
#   8900: 11,
#   9124: 18,
#   9128: 2,
#   9253: 76,
#   9304: 12,
#   9332: 7,
#   9457: 6,
#   9505: 2,
#   9518: 80,
#   9544: 228,
#   9727: 37,
#   9736: 19,
#   9859: 12,
#   9871: 17,
#   9957: 15,
#   9973: 59,
#   10057: 144,
#   10207: 36,
#   10299: 167,
#   10304: 8,
#   10377: 125,
#   10502: 9,
#   10581: 11,
#   10589: 18,
#   10626: 72,
#   10635: 6,
#   10666: 84,
#   10675: 13,
#   10761: 9,
#   10830: 14,
#   10848: 16,
#   10950: 23,
#   11003: 63,
#   11018: 24,
#   11061: 11,
#   11065: 40,
#   11197: 14,
#   11236: 58,
#   11247: 6,
#   11275: 26,
#   11313: 9,
#   11320: 66,
#   11421: 37,
#   11446: 13,
#   11593: 19,
#   11616: 64,
#   11671: 14,
#   11702: 7,
#   11708: 44,
#   11747: 20,
#   11762: 10,
#   11829: 25,
#   11850: 23,
#   11860: 11,
#   11932: 18,
#   11989: 17,
#   12028: 221,
#   12140: 36,
#   12177: 53,
#   12183: 26,
#   12274: 9,
#   12312: 13,
#   12380: 45,
#   12508: 136,
#   12567: 61,
#   12585: 4,
#   12629: 43,
#   12633: 11,
#   12799: 77,
#   12803: 21,
#   12824: 21,
#   13123: 10,
#   13329: 22,
#   13330: 13,
#   13503: 15,
#   13546: 20,
#   13577: 7,
#   13593: 20,
#   13615: 10,
#   13627: 31,
#   13664: 120,
#   13728: 13,
#   13748: 21,
#   13864: 5,
#   13881: 2,
#   14035: 12,
#   14144: 24,
#   14172: 9,
#   14193: 8,
#   14256: 26,
#   14269: 21,
#   14309: 13,
#   14342: 20,
#   14385: 14,
#   14507: 9,
#   14520: 56,
#   14705: 17,
#   14805: 16,
#   14855: 96,
#   14975: 23,
#   15046: 86,
#   15054: 33,
#   15301: 5,
#   15347: 4,
#   15361: 15,
#   15472: 13,
#   15590: 85,
#   15716: 323,
#   15852: 15,
#   15875: 192,
#   16038: 89,
#   16053: 17,
#   16076: 397,
#   16102: 6,
#   16129: 22,
#   16147: 7,
#   16216: 17,
#   16275: 90,
#   16318: 12,
#   16367: 47,
#   16384: 48,
#   16409: 40,
#   16412: 8,
#   16438: 28,
#   16468: 15,
#   16469: 20,
#   16479: 7,
#   16492: 6,
#   16554: 19,
#   16560: 8,
#   16685: 1,
#   16733: 14,
#   16755: 24,
#   16800: 12,
#   16802: 27,
#   16850: 14,
#   16975: 186,
#   16992: 42,
#   17107: 6,
#   17149: 17,
#   17150: 23,
#   17250: 28,
#   17260: 10,
#   17276: 10,
#   17539: 24,
#   17547: 9,
#   17617: 4,
#   17631: 19,
#   17664: 24,
#   17722: 8,
#   17764: 3,
#   17795: 215,
#   17843: 37,
#   17882: 6,
#   17903: 7,
#   17906: 88,
#   18082: 22,
#   18123: 146,
#   18233: 8,
#   18250: 2,
#   18281: 61,
#   18320: 207,
#   18353: 16,
#   18365: 10,
#   18459: 33,
#   18637: 35,
#   18673: 38,
#   18681: 10,
#   18737: 7,
#   18999: 40,
#   19029: 4,
#   19036: 12,
#   19164: 20,
#   19463: 14,
#   19569: 4,
#   19653: 30,
#   19698: 79,
#   19793: 37,
#   19803: 9,
#   19833: 77,
#   19851: 83,
#   19859: 14,
#   19940: 9,
#   20061: 7,
#   20086: 85,
#   20133: 121,
#   20181: 204,
#   20187: 25,
#   20263: 6,
#   20265: 7,
#   20289: 63,
#   20381: 10,
#   20425: 103,
#   20528: 37,
#   20580: 1,
#   20598: 31,
#   20600: 16,
#   20624: 32,
#   20643: 20,
#   20804: 25,
#   20899: 17,
#   20951: 8,
#   20979: 26,
#   21037: 21,
#   21056: 9,
#   21093: 60,
#   21255: 3,
#   21269: 279,
#   21277: 23,
#   21301: 16,
#   21350: 18,
#   21548: 7,
#   21581: 11,
#   21737: 7,
#   21745: 5,
#   21764: 7,
#   22019: 2,
#   22180: 5,
#   22192: 5,
#   22287: 10,
#   22432: 6,
#   22450: 11,
#   22520: 63,
#   22534: 4,
#   22580: 10,
#   22624: 43,
#   22667: 72,
#   22684: 14,
#   22706: 8,
#   22754: 44,
#   22855: 47,
#   22921: 2,
#   23028: 22,
#   23109: 2,
#   23131: 49,
#   23161: 29,
#   23215: 9,
#   23318: 15,
#   23418: 22,
#   23423: 11,
#   23451: 26,
#   23568: 8,
#   23657: 34,
#   23734: 15,
#   23763: 21,
#   23847: 9,
#   24099: 2,
#   24170: 2,
#   24178: 209,
#   24276: 82,
#   24344: 290,
#   24483: 7,
#   24535: 23,
#   24562: 10,
#   24569: 20,
#   24622: 1,
#   24687: 45,
#   24807: 41,
#   24847: 12,
#   24868: 57,
#   24903: 45,
#   25001: 25,
#   25016: 78,
#   25038: 66,
#   25097: 42,
#   25117: 38,
#   25225: 17,
#   25256: 30,
#   25295: 59,
#   25326: 17,
#   25373: 158,
#   25406: 5,
#   25515: 18,
#   25526: 86,
#   25579: 27,
#   25591: 61,
#   25671: 11,
#   25750: 107,
#   25775: 38,
#   25844: 22,
#   25860: 9,
#   25861: 16,
#   25889: 20,
#   25941: 86,
#   26036: 11,
#   26040: 79,
#   26052: 3,
#   26080: 5,
#   26097: 65,
#   26118: 60,
#   26311: 28,
#   26391: 64,
#   26398: 14,
#   26469: 52,
#   26542: 55,
#   26601: 58,
#   26638: 155,
#   26727: 10,
#   26797: 8,
#   26869: 11,
#   26884: 5,
#   26887: 4,
#   26956: 23,
#   27003: 18,
#   27036: 10,
#   27043: 30,
#   27047: 41,
#   27049: 14,
#   27089: 24,
#   27121: 89,
#   27143: 135,
#   27172: 9,
#   27179: 118,
#   27194: 60,
#   27269: 19,
#   27367: 84,
#   27371: 17,
#   27431: 33,
#   27486: 2,
#   27576: 84,
#   27597: 60,
#   27600: 28,
#   27677: 11,
#   27726: 59,
#   27729: 70,
#   27752: 11,
#   27800: 12,
#   27809: 18,
#   27823: 31,
#   27879: 13,
#   27886: 30,
#   27999: 25,
#   28050: 20,
#   28055: 4,
#   28073: 74,
#   28093: 21,
#   28103: 16,
#   28164: 159,
#   28173: 124,
#   28230: 23,
#   28291: 36,
#   28298: 31,
#   28356: 10,
#   28527: 46,
#   28530: 24,
#   28642: 2,
#   28668: 3,
#   28671: 33,
#   28689: 5,
#   28717: 23,
#   28729: 73,
#   28742: 7,
#   28758: 94,
#   28827: 12,
#   28843: 1,
#   28884: 12,
#   28932: 24,
#   28935: 4,
#   28939: 4,
#   28973: 152,
#   29007: 9,
#   29043: 12,
#   29093: 5,
#   29096: 21,
#   29102: 18,
#   29129: 15,
#   29137: 8,
#   29139: 17,
#   29141: 27,
#   29219: 19,
#   29240: 10,
#   29274: 17,
#   29350: 18,
#   29377: 80,
#   29379: 21,
#   29456: 22,
#   29478: 32,
#   29501: 6,
#   29503: 11,
#   29504: 18,
#   29513: 65,
#   29528: 5,
#   29556: 5,
#   29566: 17,
#   29619: 18,
#   29638: 15,
#   29639: 26,
#   29660: 9,
#   29703: 12,
#   29866: 12,
#   29872: 14,
#   29913: 11,
#   29919: 24,
#   29927: 63,
#   29965: 26,
#   29972: 7,
#   30010: 7,
#   30015: 36,
#   30139: 529,
#   30208: 18,
#   30227: 35,
#   30287: 23,
#   30299: 1,
#   30301: 117,
#   30316: 17,
#   30365: 47,
#   30490: 17,
#   30501: 10,
#   30505: 33,
#   30561: 6,
#   30575: 6,
#   30599: 24,
#   30631: 11,
#   30663: 24,
#   30696: 54,
#   30786: 11,
#   30798: 14,
#   30860: 28,
#   31003: 45,
#   31183: 129,
#   31216: 80,
#   31221: 17,
#   31262: 28,
#   31298: 13,
#   31332: 59,
#   31361: 20,
#   31442: 32,
#   31470: 17,
#   31516: 74,
#   31528: 60,
#   31544: 11,
#   31580: 34,
#   31585: 39,
#   31610: 17,
#   31660: 3,
#   31664: 45,
#   31692: 23,
#   31723: 17,
#   31813: 234,
#   31942: 102,
#   31986: 41,
#   32018: 145,
#   32061: 11,
#   32106: 18,
#   32135: 12,
#   32161: 25,
#   32181: 8,
#   32183: 27,
#   32193: 16,
#   32268: 6,
#   32286: 117,
#   32355: 6,
#   32367: 42,
#   32394: 6,
#   32414: 485,
#   32436: 271,
#   32583: 5,
#   32605: 19,
#   32639: 12,
#   32740: 48,
#   32746: 11,
#   32773: 112,
#   32790: 103,
#   40059: 11,
#   40124: 68,
#   40246: 20,
#   40370: 11,
#   40442: 107,
#   40456: 43,
#   40576: 48,
#   40631: 4,
#   40911: 35,
#   41192: 45,
#   41373: 28,
#   41434: 10,
#   41446: 8,
#   41890: 7,
#   41958: 5,
#   41962: 10,
#   41976: 177,
#   42009: 30,
#   42035: 49,
#   42054: 18,
#   42194: 1,
#   42346: 30,
#   42458: 9,
#   42515: 38,
#   42572: 17,
#   42715: 21,
#   42794: 6,
#   42924: 3,
#   43067: 90,
#   43074: 18,
#   43112: 394,
#   43128: 1,
#   43147: 150,
#   43305: 48,
#   43323: 15,
#   43937: 4,
#   43943: 6,
#   43959: 3,
#   44146: 16,
#   44206: 5,
#   44214: 30,
#   44326: 8,
#   44437: 12,
#   44530: 2,
#   44534: 37,
#   44741: 8,
#   44787: 7,
#   44829: 55,
#   44841: 19,
#   44848: 2,
#   45193: 11,
#   45280: 9,
#   45435: 7,
#   46011: 61,
#   46335: 49,
#   46366: 42,
#   46415: 53,
#   46521: 14,
#   46728: 34,
#   46926: 1,
#   46961: 1,
#   47216: 17,
#   47219: 67,
#   47407: 2,
#   47467: 6,
#   47670: 7,
#   47747: 12,
#   47852: 95,
#   47930: 5,
#   48058: 4,
#   48143: 6,
#   48297: 11,
#   48340: 7,
#   48660: 343,
#   48687: 15,
#   48750: 8,
#   48812: 36,
#   48837: 14,
#   48929: 7,
#   49292: 18,
#   49510: 31,
#   49558: 347,
#   49623: 9,
#   49747: 7,
#   49764: 10,
#   49963: 4,
#   50007: 4,
#   50041: 10,
#   50093: 6,
#   50257: 11,
#   50294: 20,
#   50409: 75,
#   50762: 8,
#   50772: 17,
#   50807: 21,
#   50828: 126,
#   50911: 81,
#   50998: 29,
#   51195: 29,
#   51237: 11,
#   51401: 33,
#   51418: 68,
#   51497: 3,
#   51545: 97,
#   51601: 5,
#   51607: 5,
#   51669: 10,
#   51933: 5,
#   52011: 8,
#   52054: 1,
#   52172: 13,
#   52191: 46,
#   52307: 5,
#   52452: 5,
#   52606: 54,
#   52622: 5,
#   52898: 6,
#   52957: 52,
#   53119: 7,
#   53160: 13,
#   53173: 14,
#   53534: 9,
#   53650: 15,
#   53743: 151,
#   53749: 6,
#   53847: 14,
#   54172: 6,
#   54197: 13,
#   54305: 8,
#   54514: 116,
#   54709: 9,
#   54741: 5,
#   54832: 7,
#   54922: 2,
#   55059: 17,
#   55074: 7,
#   55188: 9,
#   55571: 212,
#   55700: 4,
#   55753: 37,
#   55841: 14,
#   55920: 17,
#   56027: 7,
#   56229: 31,
#   56440: 9,
#   56490: 12,
#   56621: 11,
#   56635: 2,
#   56772: 31,
#   56798: 4,
#   56867: 16,
#   56874: 51,
#   57050: 205,
#   57081: 32,
#   57157: 5,
#   57277: 19,
#   57290: 15,
#   57449: 17,
#   57788: 36,
#   57795: 7,
#   57889: 105,
#   58105: 49,
#   58242: 6,
#   58264: 7,
#   58286: 20,
#   58416: 3,
#   58433: 51,
#   58522: 9,
#   58580: 5,
#   58610: 13,
#   58631: 15,
#   58732: 5,
#   58794: 32,
#   58810: 10,
#   58955: 6,
#   59275: 1,
#   59278: 17,
#   59411: 6,
#   59496: 75,
#   59765: 300,
#   59789: 10,
#   59801: 2,
#   59822: 14,
#   59903: 483,
#   59943: 121,
#   60003: 9,
#   60050: 4,
#   60130: 44,
#   60674: 10,
#   60685: 4,
#   60958: 8,
#   60977: 9,
#   61005: 10,
#   61084: 216,
#   61195: 9,
#   61259: 83,
#   61331: 4,
#   61630: 19,
#   61738: 6,
#   61886: 6,
#   62231: 4,
#   62239: 5,
#   62284: 6,
#   62402: 56,
#   62641: 8,
#   62733: 9,
#   62858: 120,
#   63145: 25,
#   63327: 16,
#   63351: 10,
#   63362: 7,
#   63430: 56,
#   63499: 32,
#   63560: 25,
#   63943: 31,
#   63968: 10,
#   64160: 4,
#   64232: 28,
#   64249: 7,
#   64715: 17,
#   65004: 11,
#   65027: 1,
#   65033: 2,
#   65164: 4,
#   65361: 20,
#   65435: 40,
#   65449: 6,
#   65515: 5,
#   65582: 576,
#   65594: 9,
#   65692: 25,
#   65710: 18,
#   65837: 47,
#   66002: 636,
#   66009: 373,
#   66206: 12,
#   66412: 5,
#   66492: 1,
#   66549: 36,
#   66556: 20,
#   66671: 32,
#   66739: 1,
#   66753: 8,
#   66823: 21,
#   67053: 238,
#   67111: 16,
#   67117: 19,
#   67408: 15,
#   67446: 8,
#   67796: 7,
#   67844: 7,
#   67887: 13,
#   68059: 3,
#   68315: 3,
#   68591: 7,
#   68791: 13,
#   68836: 7,
#   68839: 21,
#   68905: 3,
#   68944: 39,
#   68962: 1,
#   69098: 12,
#   69158: 13,
#   69250: 4,
#   69296: 13,
#   69359: 26,
#   69380: 265,
#   69483: 26,
#   69546: 64,
#   69556: 11,
#   69578: 7,
#   69673: 6,
#   69776: 53,
#   69799: 6,
#   69932: 6,
#   70285: 2,
#   70466: 18,
#   70476: 22,
#   70492: 10,
#   70563: 3,
#   70645: 29,
#   70682: 48,
#   70728: 12,
#   71107: 9,
#   71108: 220,
#   71220: 45,
#   71336: 5,
#   71377: 39,
#   71915: 6,
#   71943: 4,
#   71983: 3,
#   72229: 189,
#   72230: 154,
#   72233: 2,
#   72378: 7,
#   72532: 6,
#   72714: 4,
#   72751: 35,
#   73043: 3,
#   73107: 479,
#   73129: 105,
#   73388: 37,
#   73389: 87,
#   73479: 3,
#   73686: 4,
#   73713: 458,
#   73770: 9,
#   73808: 49,
#   73899: 2,
#   73941: 7,
#   74016: 8,
#   74253: 388,
#   74505: 32,
#   74562: 98,
#   74640: 7,
#   74654: 7,
#   75047: 3,
#   75107: 124,
#   75200: 87,
#   75387: 14,
#   75446: 34,
#   75609: 5,
#   75640: 45,
#   75741: 8,
#   75782: 90,
#   75806: 3,
#   75983: 9,
#   76021: 39,
#   76056: 1,
#   76074: 31,
#   76141: 4,
#   76178: 22,
#   76437: 5,
#   76446: 18,
#   76476: 3,
#   76797: 6,
#   76915: 8,
#   76993: 13,
#   77019: 8,
#   77128: 9,
#   77177: 14,
#   77237: 198,
#   77279: 2,
#   77434: 18,
#   77453: 2,
#   77469: 31,
#   77676: 4,
#   77690: 19,
#   77697: 10,
#   77816: 8,
#   77947: 11,
#   78017: 2,
#   78086: 110,
#   78565: 78,
#   78705: 3,
#   78707: 16,
#   78859: 5,
#   78914: 13,
#   79079: 18,
#   79090: 16,
#   79115: 12,
#   79292: 15,
#   80045: 6,
#   80106: 5,
#   80218: 13,
#   80430: 10,
#   80722: 3,
#   80813: 11,
#   80825: 3,
#   81114: 58,
#   81223: 39,
#   81233: 22,
#   81436: 9,
#   81745: 28,
#   81840: 25,
#   81960: 8,
#   81992: 11,
#   82100: 74,
#   82104: 2,
#   82150: 84,
#   82202: 28,
#   82211: 647,
#   82309: 9,
#   ...}}

# %%
print(len(patient_id_to_num_notes['pneumonia_dead']))
print(len(patient_id_to_num_notes['pneumonia_alive']))
# Out:
# 252
# 1167

# %%
pneumonia_dead_no_disch.loc[pneumonia_dead_no_disch["SUBJECT_ID_x"] == 111, ['ROW_ID_x','SUBJECT_ID_x','DESCRIPTION','TEXT', 'DEATHTIME']]
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 70391       70124           111
# 142529     151749           111
# 142097     151750           111
# 142303     151751           111
# 380576     375732           111
# 380109     375744           111
# 379907     375749           111
# 379806     375753           111
# 379909     375760           111
# 1066971   1079317           111
# 1065833   1079339           111
# 1067121   1079351           111
#
#                                                DESCRIPTION  \
# 70391                                               Report
# 142529                                              Report
# 142097                                              Report
# 142303                                              Report
# 380576                   Physician Resident Admission Note
# 380109                                      ICU Event Note
# 379907   Physician Resident/Attending Admission Note - ...
# 379806                          Social Work Admission Note
# 379909                                      ICU Event Note
# 1066971                                CHEST (PORTABLE AP)
# 1065833                                CHEST (PORTABLE AP)
# 1067121                         CHEST PORT. LINE PLACEMENT
#
#                                                       TEXT  \
# 70391    PATIENT/TEST INFORMATION:\nIndication: s/p PEA...
# 142529   Compared to the previous tracing QRS voltage i...
# 142097   Normal sinus rhythm, rate 80.  Biatrial abnorm...
# 142303   Normal sinus rhythm.  Q waves in leads V1-V2 c...
# 380576   Chief Complaint:  respiratory distress\n   HPI...
# 380109   Clinician:  Nurse\n   Pt admitted from the ED ...
# 379907   Chief Complaint:  respiratory distress\n   HPI...
# 379806   Social Work Initial Note:\n   Family Informati...
# 379909   TITLE:\n   Clinician:  Resident\n   Patient ex...
# 1066971  [**2144-7-1**] 2:43 AM\n CHEST (PORTABLE AP)  ...
# 1065833  [**2144-7-1**] 7:27 AM\n CHEST (PORTABLE AP); ...
# 1067121  [**2144-7-1**] 9:01 AM\n CHEST PORT. LINE PLAC...
#
#                    DEATHTIME
# 70391    2144-07-01 14:55:00
# 142529   2144-07-01 14:55:00
# 142097   2144-07-01 14:55:00
# 142303   2144-07-01 14:55:00
# 380576   2144-07-01 14:55:00
# 380109   2144-07-01 14:55:00
# 379907   2144-07-01 14:55:00
# 379806   2144-07-01 14:55:00
# 379909   2144-07-01 14:55:00
# 1066971  2144-07-01 14:55:00
# 1065833  2144-07-01 14:55:00
# 1067121  2144-07-01 14:55:00

# %%
def count_words_per_patient(disease_df, patient_id_to_num_notes):
    note_appearance_counter = {}
    number_of_patients = 0 # number of patients
    note_counter = 0

# -----------
    patient_id = -1
    word_set = set()
    note_event_counter = 0

    # Iterate through each note
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):

        
        patient_id_check = int(row['SUBJECT_ID_x'])
    
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check:
            number_of_patients += 1
            note_event_counter = 0
        
            for word in word_set:
                if word in note_appearance_counter:
                    note_appearance_counter[word] += 1
                else:
                    note_appearance_counter[word] = 1

        
            # reset word_set
            word_set = set()
        
        # update patient id
        patient_id = patient_id_check

            
        if patient_id_to_num_notes[patient_id_check] <= MIN_SEQ_LEN:
            continue
            
        if note_event_counter < patient_id_to_num_notes[patient_id] // USE_1_N_SEQ:
            note_event_counter += 1
            continue
                
        note_counter += 1
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        tokenized_note = word_tokenize(note)
        
        
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())
            if not stemmed_word in stop_words:
                word_set.add(stemmed_word)
    
    print(str(note_counter) + " note events")
    print("finished counting frequent words for patients!")
#     return note_counter, note_appearance_counter
    return number_of_patients, note_appearance_counter

# variable dictionaries
number_of_notes = {}
note_appearance_counter = {}

number_of_notes['pneumonia_dead'], note_appearance_counter['pneumonia_dead'] = count_words_per_patient(pneumonia_dead_no_disch, patient_id_to_num_notes['pneumonia_dead'])
number_of_notes['pneumonia_alive'], note_appearance_counter['pneumonia_alive'] = count_words_per_patient(pneumonia_alive_no_disch, patient_id_to_num_notes['pneumonia_alive'])
# Out:
# 100%|██████████| 11895/11895 [00:40<00:00, 295.02it/s]
#   0%|          | 30/46134 [00:00<02:33, 299.78it/s]
# 5989 note events
# finished counting frequent words for patients!
# 100%|██████████| 46134/46134 [02:40<00:00, 288.03it/s]
# 23172 note events
# finished counting frequent words for patients!

# %%
number_of_notes
# Out:
# {'pneumonia_dead': 252, 'pneumonia_alive': 1167}

# %%
print(note_appearance_counter)
# Out:
# {'pneumonia_dead': {'tobacco': 15, 'breath': 162, 'head': 114, 'unabl': 130, 'cv': 136, 'short': 86, 'gap': 11, 'htn': 50, 'levofloxacin': 40, 'evid': 141, 'sr': 94, 'neck': 50, 'electrolyt': 43, '(': 229, 'mono': 43, 'baselin': 86, 'previous': 80, 'second': 40, 'wbc': 131, 'nc': 62, 'svc': 87, 'cardiac': 156, 'comment': 93, 'major': 40, 'port': 83, 'tf': 110, 'control': 101, 'drug': 55, 'understand': 45, 'pericardi': 61, 'meantim': 3, 'band': 44, 'room': 70, 'ventilatori': 63, 'antibiot': 102, 'progress': 166, 'costophren': 30, 'took': 27, 'contact': 91, 'level': 148, 'connect': 7, 'mandat': 6, 'immedi': 45, 'gener': 124, 'met': 61, 'cvp': 66, 'tachycardia': 94, 'arf': 34, 'distant': 27, 'infecti': 53, 'cpr': 32, 'would': 127, 'add': 51, 'ast': 48, 'p': 193, 'dextros': 11, 'sat': 167, 'proxi': 40, 'meq': 92, 'g': 96, 'bicarbon': 9, 'radiolog': 68, 'arteri': 119, 'norepinephrin': 22, 'chemistri': 16, 'though': 89, 'etho': 2, 'fluid': 183, 'arrang': 21, 'set': 141, 'protocol': 57, 'bp': 181, 'physic': 72, 'bedsid': 127, 'cough': 125, 'pneumonia': 203, 'arch': 15, 'resp': 163, 'bradi': 12, 'protect': 61, 'son': 89, 'recent': 129, 'po': 143, 'examin': 202, 'stabl': 177, 'slide': 50, 'old': 200, 'anicter': 12, 'autopeep': 6, 'hyperinfl': 5, 'cmh': 51, 'eeg': 7, 'team': 141, 'point': 75, 'spent': 65, 'alcohol': 15, 'know': 27, 'ceftriaxon': 24, ')': 229, 'system': 99, 'aortic': 68, 'saw': 64, 'seen': 157, 'presep': 6, 'w': 177, 'onli': 153, 'low': 172, 'hyperlipidemia': 9, 'anion': 8, 'grief': 2, 'coars': 117, 'list': 25, 'ptt': 80, 'bag': 43, 'death': 42, 'verapamil': 2, 'pedal': 41, 'come': 72, 'situat': 29, 'hct': 122, 'peripher': 97, 'lobe': 142, 'respiratiori': 1, 'earli': 73, 'arrest': 27, 'homemak': 1, 'tcurrent': 61, 'year': 195, 'degre': 47, 'flowsheet': 113, 'rij': 35, 'effort': 47, 'aspir': 108, 'hepat': 27, 'spontan': 91, 'infus': 111, 'puls': 133, 'hypercapn': 6, 'admiss': 88, 'last': 148, 'exam': 110, 'despit': 90, 'friend': 32, 'lipas': 16, 'suffer': 13, 'wave': 81, 'addict': 8, 'offer': 47, 'blocker': 33, 'place': 196, 'amylas': 17, 'father': 16, 'copd': 45, 'serial': 23, 'normal': 164, 'ipratropium': 6, 'rhythm': 126, 'refractori': 8, 'albumin': 49, 'sinu': 139, 'lower': 166, 'approxim': 72, 'block': 44, 'experienc': 17, 'inferior': 37, 'inform': 122, 'exclud': 72, 'bolus': 98, 'q': 136, 'keep': 104, 'hi': 121, 'loss': 52, 'occup': 18, 'agre': 84, 'lactat': 47, 'warfarin': 5, 'issu': 84, 'without': 143, 'morn': 93, 'vasopressin': 27, ']': 80, 'sepsi': 79, 'abov': 158, 'tidal': 47, 'pna': 151, 'kg': 111, 'non': 170, 'retrocardiac': 50, 'hous': 20, 'atenolol': 4, 'patient': 205, 'stool': 150, 'mode': 73, 'limb': 32, 'poor': 134, 'regular': 66, 'afternoon': 103, 'stomach': 93, 'central': 107, 'eo': 44, 'section': 56, 'titl': 38, 'propofol': 31, 'meal': 10, 'respiratori': 166, 'hypotens': 131, 'social': 138, 'anoth': 58, 'ani': 142, 'ph': 61, 'legal': 10, 'infect': 100, 'tach': 21, 'member': 57, 'assess': 176, 'prevent': 35, 'c': 177, 'rml': 18, 'angl': 28, 'f': 111, 'chief': 63, 'femal': 61, 'fix': 29, 'repres': 91, 'appoint': 7, 'atropin': 8, 'histori': 173, '#': 211, 'cm': 141, 'marri': 4, 'lactic': 54, 'bpm': 102, 'carina': 78, 'septic': 41, 'echo': 58, 'cxr': 136, 'statin': 17, 'neut': 43, 'elderli': 5, 'ca': 105, 'balanc': 85, 'receiv': 151, 'new': 160, 'question': 128, 'funer': 16, 'pcv': 14, 'rub': 32, 'prior': 186, 'consolid': 110, 'sputum': 132, 'mottl': 15, 'independ': 19, 'hospit': 75, 'impress': 176, 'clinic': 117, 'also': 175, 'inh': 3, 'presum': 40, 'et': 95, 'interv': 156, 'clinician': 41, 'acut': 134, 'rosc': 1, 'cultur': 100, 'distress': 118, 'appropri': 101, 'subsequ': 50, 'med': 141, 'hemodynam': 111, 'ratio': 7, 'veteran': 1, 'va': 11, 'privat': 7, 'support': 171, 'fio': 119, 'left': 216, 'condit': 206, 'elder': 1, 'day': 160, 'interim': 26, 'blood': 141, 'lung': 203, 'upper': 162, 'studi': 160, 'radiograph': 127, 'pea': 8, 'work': 87, 'n': 70, 'cardiomediastin': 48, 'effus': 183, 'chest': 206, 're ...

# %%
# # get hyper-paramters n_fold and threshold from user input
n_fold = float(3)
threshold = float(0.01)

frequent_word_lists = {}
factor = {}

# %%
"""function description:
for each disease in note_appearance_counter
    1. checks whether a word in disease file is frequent(frequency standard as defined by factor, n_fold, and threshold)
    2. adds to frequent_word_list
"""

# def find_frequent_word(note_appearance_counter, frequent_word_lists, number_of_notes, factor, n_fold, threshold):

# calculate normalizing factor for each disease
note_sum = 0

# Count from two labels
for disease in number_of_notes:
    note_sum += float(number_of_notes[disease])
    
for disease in number_of_notes:
    factor[disease] = number_of_notes[disease] / note_sum

# determine frequent word for each disease file
for disease in note_appearance_counter:
    frequent_word_lists[disease] = []

    print(disease + " has " + str(len(note_appearance_counter[disease])) + " unique words!")

    for word in note_appearance_counter[disease]:
        
        freq_check = True
        for check_disease in note_appearance_counter:
            
            if not disease == check_disease:
                if word in note_appearance_counter[check_disease]:
                    if not (note_appearance_counter[disease][word] / note_appearance_counter[check_disease][word] / factor[disease] * factor[check_disease] > n_fold \
                        and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):

                        freq_check = False
                        break

                else:
                    if not (note_appearance_counter[disease][word] > n_fold and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):
                        freq_check = False
                        break
        if freq_check:
            frequent_word_lists[disease].append((word))
            # Create a tuple of word and its count
#             frequent_word_lists[disease].append((word, note_appearance_counter[disease][word]))

        

print("finished making frequent words list for " + disease)
# Out:
# pneumonia_dead has 11678 unique words!
# pneumonia_alive has 22572 unique words!
# finished making frequent words list for pneumonia_alive

# %%
print(note_sum)
print(factor)

# number of notes
# 58029.0
# {'pneumonia_dead': 0.2049837150390322, 'pneumonia_alive': 0.7950162849609678}
# Out:
# 1419.0
# {'pneumonia_dead': 0.17758985200845667, 'pneumonia_alive': 0.8224101479915433}

# %%
print(len(frequent_word_lists['pneumonia_dead']))
print(len(frequent_word_lists['pneumonia_alive']))


# n_fold = float(3) threshold = float(0.01)
# 454
# 329

# n_fold = float(2) threshold = float(0.01)
# 914
# 600

# n_fold = float(1) threshold = float(0.01)
# 3320
# 2196
# Out:
# 454
# 329

# %%
print(frequent_word_lists)
# Out:
# {'pneumonia_dead': ['cpr', 'bicarbon', 'norepinephrin', 'arrang', 'autopeep', 'death', 'arrest', 'hypercapn', 'suffer', 'refractori', 'vasopressin', 'funer', 'pcv', 'mottl', 'clinician', 'pea', 'phenylephrin', 'paralyt', 'unrespons', 'clergi', 'recruit', 'cremat', 'hypothermia', 'profound', 'hypercapnia', 'azotemia', 'acidem', 'dic', 'anur', 'elig', 'expir', 'park', 'dnr', 'gum', 'nonpurpos', 'dni', 'sluggish', 'virtual', 'nacl', 'pinpoint', 'slough', 'cmo', 'dk', 'lubric', 'oder', 'float', 'clariti', 'levoph', 'wish', 'mso', 'antb', 'priest', 'option', 'grim', 'pronounc', 'remin', 'institut', 'prognosi', 'viabl', 'hypotent', 'bow', 'purpl', 'gather', 'peerla', 'dead', 'dd', 'suport', 'respon', 'synch', 'aprv', 'acv', 'depth', 'agreement', 'mad', 'centimet', 'bye', 'asystol', 'life', 'mortem', 'nrbm', 'mgx', 'cathol', 'ppn', 'chaplain', 'surviv', 'duski', 'peac', 'hover', 'moniotr', 'sync', 'througout', 'quiac', 'cvvhdf', 'cvvhd', 'defibril', 'agon', 'vtach', 'seriou', 'corneal', 'jerk', 'deliv', 'suppport', 'acidot', 'mortum', 'vasopressor', 'neosynephrin', 'rusti', 'deterior', 'crrt', 'hemothorax', 'cvvh', 'pfr', 'pulseless', 'gratitud', 'ultrafiltr', 'bair', 'lc', 'pitressin', 'pray', 'cagluc', 'elimin', 'uffp', 'multisystem', 'cooler', 'spiritu', 'hypotherm', 'mtg', 'ffp', 'hugger', 'scl', 'maroon', 'ethic', 'lw', 'declin', 'rewir', 'levof', 'among', 'unequ', 'towel', 'quinton', 'cyanot', 'brb', 'bairhugg', 'rabbi', 'ashen', 'escal', 'discard', 'autopsi', 'erythro', 'town', 'absorb', 'promod', 'zero', 'syring', 'asynchron', 'paco', 'triadyn', 'warmer', 'sml', 'neo', 'motil', 'discoordin', 'polymorph', 'morgu', 'prayer', 'circuit', 'ran', 'bond', 'norepi', "tf'ing", 'nahco', 'bank', 'chane', 'rediscuss', 'mind', 'gc', '^rr', 'edt', 'hunger', 'unstabl', 'dopamin', 'polici', 'hung', 'intiat', 'palli', 'tacycard', 'moan', 'cantones', 'fliud', 'overlay', 'acc', 'ozz', 'artifici', 'readdress', 'recalibr', 'underneath', 'proph', 'gurgl', 'broader', 'anuria', 'judgement', 'inclus', 'dobutamin', 'platlet', 'adenosin', 'hospic', 'oncologist', 'platelet', 'quadrent', 'anyway', 'kerlix', 'gvhd', 'gut', 'nephrolog', 'oligur', 'hepati', 'cellcept', 'psup', 'surgicel', 'influenc', 'cardiovert', 'sorb', 'pheresi', 'core', 'griev', 'fentenyl', 'repsons', 'snt', 'cisatracurium', 'fc', 'hiccup', 'barotrauma', 'premed', 'grimmac', 'ettub', 'oximetri', 'extremitiy', 'twitch', 'wether', 'chemic', 'pose', 'fungemia', 'caspofungin', 'conc', 'rescan', 'crt', 'fentani', 'sacrament', 'liw', 'lcw', 'postpylor', 'plat', 'nephrogram', 'mail', 'grave', 'nonreact', 'chb', 'heroic', 'nonrebreath', 'awhil', 'occupi', 'pleuravac', 'propos', 'reappear', 'struggl', 'ultra', 'familt', 'palliat', 'opinion', 'reveiw', 'icter', 'gentamycin', 'criticar', 'resucit', 'tubular', 'reguard', 'sooner', 'pplat', 'themselv', 'ogtub', 'cvo', 'fibrinogen', 'wma', 'meaning', 'ardsnet', 'preoxygen', 'abruptli', 'amongst', 'kyphoscoliosi', 'pneumonectomi', 'sibl', 'vasoconstrict', 'gasp', 'hook', 'recev', 'colour', 'realist', 'hida', 'tran', 'innumer', 'moreov', 'aricept', 'creep', 'pvr', 'argatroban', 'vigil', 'aliv', 'irrevers', 'buck', 'unreli', 'pharmacolog', 'derecruit', 'wil', 'attemtp', 'epsiod', 'eyelid', 'religi', 'ration', 'famil', 'respitori', 'analgesia', 'myeloma', 'imbal', 'neob', 'dorsal', 'adam', 'muddi', 'declar', 'od', 'moisten', 'diflucan', 'requr', 'heliox', 'futil', 'osteoblast', 'illeu', 'emper', 'currentl', 'perisplen', 'nimv', 'fli', 'preliminarili', 'plerual', 'rhochor', 'prioriti', 'forth', 'esoph', 'dysynchron', 'sluggishli', 'unplan', 'occurr', 'binder', 'ipf', 'goodby', 'ccn', 'meatu', 'stg', 'scopalamin', 'unarous', 'tobra', 'petechia', 'harm', 'hemodynim', 'bless', 'fentayl', 'rite', 'doen', 'calvarium', 'furhter', 'montitor', 'stack', 'fmaili', 'chol', 'figur', 'underpenetr', 'thrombot', 'pyuria', 'ggt', 'massag', 'outer', 'mrcp', 'contini', 'formul', 'synchroni', 'treatement', 'news', 'amioderon', 'pastor', 'anasarc', 'led', 'unobtain', 'mvo',  ...

# %% [markdown]
# ### 2. Co-occurrence generation
# FP-growth

# %%
FREQUENT_WORD_LIST = frequent_word_lists['pneumonia_dead'] + frequent_word_lists['pneumonia_alive']
print(len(FREQUENT_WORD_LIST))
print(len(set(FREQUENT_WORD_LIST)))
# Out:
# 783
# 783

# %%
"""function description:
generates frequent word set for the disease
"""
word_dict = {}
word_id = 1
stemmer = PorterStemmer()


for word in FREQUENT_WORD_LIST:
    if not word == "WORD":
        word_dict[stemmer.stem(word.strip())] = word_id
        word_id += 1
             
print(f"\nword dictionary created! Length: {len(word_dict)}\n")
print(word_dict)
# Out:
# word dictionary created! Length: 783
#
# {'cpr': 1, 'bicarbon': 2, 'norepinephrin': 3, 'arrang': 4, 'autopeep': 5, 'death': 6, 'arrest': 7, 'hypercapn': 8, 'suffer': 9, 'refractori': 10, 'vasopressin': 11, 'funer': 12, 'pcv': 13, 'mottl': 14, 'clinician': 15, 'pea': 16, 'phenylephrin': 17, 'paralyt': 18, 'unrespon': 19, 'clergi': 20, 'recruit': 21, 'cremat': 22, 'hypothermia': 23, 'profound': 24, 'hypercapnia': 25, 'azotemia': 26, 'acidem': 27, 'dic': 28, 'anur': 29, 'elig': 30, 'expir': 31, 'park': 32, 'dnr': 33, 'gum': 34, 'nonpurpo': 35, 'dni': 36, 'sluggish': 37, 'virtual': 38, 'nacl': 39, 'pinpoint': 40, 'slough': 41, 'cmo': 42, 'dk': 43, 'lubric': 44, 'oder': 45, 'float': 46, 'clariti': 47, 'levoph': 48, 'wish': 49, 'mso': 50, 'antb': 51, 'priest': 52, 'option': 53, 'grim': 54, 'pronounc': 55, 'remin': 56, 'institut': 57, 'prognosi': 58, 'viabl': 59, 'hypot': 60, 'bow': 61, 'purpl': 62, 'gather': 63, 'peerla': 64, 'dead': 65, 'dd': 66, 'suport': 67, 'respon': 68, 'synch': 69, 'aprv': 70, 'acv': 71, 'depth': 72, 'agreement': 73, 'mad': 74, 'centimet': 75, 'bye': 76, 'asystol': 77, 'life': 78, 'mortem': 79, 'nrbm': 80, 'mgx': 81, 'cathol': 82, 'ppn': 83, 'chaplain': 84, 'surviv': 85, 'duski': 86, 'peac': 87, 'hover': 88, 'moniotr': 89, 'sync': 90, 'througout': 91, 'quiac': 92, 'cvvhdf': 93, 'cvvhd': 94, 'defibril': 95, 'agon': 96, 'vtach': 97, 'seriou': 98, 'corneal': 99, 'jerk': 100, 'deliv': 101, 'suppport': 102, 'acidot': 103, 'mortum': 104, 'vasopressor': 105, 'neosynephrin': 106, 'rusti': 107, 'deterior': 108, 'crrt': 109, 'hemothorax': 110, 'cvvh': 111, 'pfr': 112, 'pulseless': 113, 'gratitud': 114, 'ultrafiltr': 115, 'bair': 116, 'lc': 117, 'pitressin': 118, 'pray': 119, 'cagluc': 120, 'elimin': 121, 'uffp': 122, 'multisystem': 123, 'cooler': 124, 'spiritu': 125, 'hypotherm': 126, 'mtg': 127, 'ffp': 128, 'hugger': 129, 'scl': 130, 'maroon': 131, 'ethic': 132, 'lw': 133, 'declin': 134, 'rewir': 135, 'levof': 136, 'among': 137, 'unequ': 138, 'towel': 139, 'quinton': 140, 'cyanot': 141, 'brb': 142, 'bairhugg': 143, 'rabbi': 144, 'ashen': 145, 'escal': 146, 'discard': 147, 'autopsi': 148, 'erythro': 149, 'town': 150, 'absorb': 151, 'promod': 152, 'zero': 153, 'syre': 154, 'asynchron': 155, 'paco': 156, 'triadyn': 157, 'warmer': 158, 'sml': 159, 'neo': 160, 'motil': 161, 'discoordin': 162, 'polymorph': 163, 'morgu': 164, 'prayer': 165, 'circuit': 166, 'ran': 167, 'bond': 168, 'norepi': 169, "tf'ing": 170, 'nahco': 171, 'bank': 172, 'chane': 173, 'rediscuss': 174, 'mind': 175, 'gc': 176, '^rr': 177, 'edt': 178, 'hunger': 179, 'unstabl': 180, 'dopamin': 181, 'polici': 182, 'hung': 183, 'intiat': 184, 'palli': 185, 'tacycard': 186, 'moan': 187, 'canton': 188, 'fliud': 189, 'overlay': 190, 'acc': 191, 'ozz': 192, 'artifici': 193, 'readdress': 194, 'recalibr': 195, 'underneath': 196, 'proph': 197, 'gurgl': 198, 'broader': 199, 'anuria': 200, 'judgement': 201, 'inclu': 202, 'dobutamin': 203, 'platlet': 204, 'adenosin': 205, 'hospic': 206, 'oncologist': 207, 'platelet': 208, 'quadrent': 209, 'anyway': 210, 'kerlix': 211, 'gvhd': 212, 'gut': 213, 'nephrolog': 214, 'oligur': 215, 'hepati': 216, 'cellcept': 217, 'psup': 218, 'surgicel': 219, 'influenc': 220, 'cardiovert': 221, 'sorb': 222, 'pheresi': 223, 'core': 224, 'griev': 225, 'fentenyl': 226, 'repson': 227, 'snt': 228, 'cisatracurium': 229, 'fc': 230, 'hiccup': 231, 'barotrauma': 232, 'preme': 233, 'grimmac': 234, 'ettub': 235, 'oximetri': 236, 'extremitiy': 237, 'twitch': 238, 'wether': 239, 'chemic': 240, 'pose': 241, 'fungemia': 242, 'caspofungin': 243, 'conc': 244, 'rescan': 245, 'crt': 246, 'fentani': 247, 'sacrament': 248, 'liw': 249, 'lcw': 250, 'postpylor': 251, 'plat': 252, 'nephrogram': 253, 'mail': 254, 'grave': 255, 'nonreact': 256, 'chb': 257, 'heroic': 258, 'nonrebreath': 259, 'awhil': 260, 'occupi': 261, 'pleuravac': 262, 'propo': 263, 'reappear': 264, 'struggl': 265, 'ultra': 266, 'familt': 267, 'palliat': 268, 'opinion': 269, 'reveiw': 270, 'icter': 271, 'gentamycin': 272, 'criticar': 273, 'resucit ...

# %% [markdown]
# ### Implementetion with python for FP_growth

# %% [markdown]
# ### Count co-occurrences per patient

# %%
import os
import operator
from pathlib import Path
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import math

# ----
def fp_growth_input_per_patient_python(disease_df, word_dict, min_support):
    
    # For dataframe
    patient_cooc_dict = {}
    patient_node_dict = {}
    patient_note_cnt = {}
    
    # --------------    
    patient_id = -1
    note_cnt = 0
    patient_note_list = []
    
    # read line in from file (each line is one note)
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        
        # only regard certain type of notes
        patient_id_check = int(row['SUBJECT_ID_x'])
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        patient_word_set = set()
    
#         print(f"patient_id_check: {patient_id_check}, patient_id: {patient_id}")
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check and not patient_id == -1:
            te = TransactionEncoder()
            te_ary = te.fit(patient_note_list).transform(patient_note_list)
            df = pd.DataFrame(te_ary, columns=te.columns_)
            df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
            cooc_tmp = []
            cooc_minsup_tmp = []
            node_minsup_tmp = []
            cooc_node_idx_tmp = []
            
            for index, row in df_itemsets.iterrows():
                if len(row['itemsets']) == 1:
                    word = list(row['itemsets'])[0]
                    min_sup = row['support']

                    node_minsup_tmp.append(len(patient_note_list) * row['support'])
                    cooc_node_idx_tmp.append(word)
                    
                if len(row['itemsets']) == 2:
                    cooc_ = sorted(list(row['itemsets']))
                    cooc_tmp.append(cooc_)
                    cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
            
            cooc_dict = {}

            for num, i in enumerate(cooc_tmp):
                if tuple(i) not in cooc_dict:
                    cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

            # dictionary = dict(zip(keys, values))
            node_dict = {}
            for num, i in enumerate(cooc_node_idx_tmp):
                if i not in node_dict:
                    node_dict[i] = node_minsup_tmp[num]
                    
            # Update glob lists
            if patient_id not in patient_cooc_dict:
                patient_cooc_dict[patient_id] = cooc_dict
                patient_node_dict[patient_id] = node_dict
                patient_note_cnt[patient_id] = note_cnt
            else:
                print(f"patient_id: {patient_id} is already in the dictionary!")
            
            
            # Reset local lists
            patient_note_list = []
            note_cnt = 0
                    
        # update patient id
        patient_id = patient_id_check
        tokenized_note = word_tokenize(note)
        note_cnt += 1

        # loop through each word in note to count word belonging to each disease
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())       
            if stemmed_word in word_dict:
                    patient_word_set.add(stemmed_word)

        templst = []
        for word in patient_word_set:
            templst.append(word)

        if templst:
            patient_note_list.append(templst)
    
    # Last patient info
    te = TransactionEncoder()
    te_ary = te.fit(patient_note_list).transform(patient_note_list)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
    cooc_tmp = []
    cooc_minsup_tmp = []
    #-----
    node_minsup_tmp = []
    cooc_node_idx_tmp = []
            
    for index, row in df_itemsets.iterrows():
        if len(row['itemsets']) == 1:
            word = list(row['itemsets'])[0]
            node_minsup_tmp.append(len(patient_note_list) * row['support'])
            cooc_node_idx_tmp.append(word)

        if len(row['itemsets']) == 2:
            cooc_ = sorted(list(row['itemsets']))
            cooc_tmp.append(cooc_)
            cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
    
                    
    cooc_dict = {}

    for num, i in enumerate(cooc_tmp):
        if tuple(i) not in cooc_dict:
            cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

    # dictionary = dict(zip(keys, values))
    node_dict = {}
    for num, i in enumerate(cooc_node_idx_tmp):
        if i not in node_dict:
            node_dict[i] = node_minsup_tmp[num]

    # Update glob lists
    if patient_id not in patient_cooc_dict:
        patient_cooc_dict[patient_id] = cooc_dict
        patient_node_dict[patient_id] = node_dict
        patient_note_cnt[patient_id] = note_cnt
    else:
        print(f"patient_id: {patient_id} is already in the dictionary!")

    return patient_node_dict, patient_cooc_dict, patient_note_cnt

patient_node_0, patient_cooc_0, patient_note_num_0 = fp_growth_input_per_patient_python(pneumonia_dead_no_disch, word_dict, 0.15)
patient_node_1, patient_cooc_1, patient_note_num_1 = fp_growth_input_per_patient_python(pneumonia_alive_no_disch, word_dict, 0.15)
# Out:
# 100%|██████████| 11895/11895 [01:33<00:00, 126.99it/s]
# 100%|██████████| 46134/46134 [05:53<00:00, 130.49it/s]

# %%
print(patient_node_1)
# Out:
# {68: {'commod': 4.0, 'ambul': 4.0, 'gait': 2.0, 'chair': 2.0, 'oob': 2.0}, 85: {'lat': 1.0}, 94: {'lift': 11.0, 'dopamin': 11.0}, 165: {'habitu': 1.0}, 211: {'dopamin': 3.0, 'aox': 3.0, 'levoph': 3.0}, 224: {'lat': 1.0, 'rigor': 1.0, 'platelet': 1.0, 'commod': 1.0, 'awhil': 1.0, 'fax': 1.0, 'bank': 1.0, 'pleasant': 1.0, 'chair': 1.0}, 231: {}, 283: {'recruit': 10.0, 'criticar': 10.0}, 357: {'unasyn': 4.0, 'intent': 2.0, 'dz': 2.0, 'ctx': 2.0, 'moan': 4.0, 'distort': 2.0}, 368: {'pleasant': 3.0, 'dnr': 3.0, 'hhn': 3.0, 'oob': 6.0, 'ambul': 4.0}, 370: {'dnr': 2.0}, 384: {'bipolar': 9.0, 'wish': 4.0, 'dnr': 3.0, 'schizophrenia': 4.0}, 426: {'align': 1.0, 'mottl': 1.0, 'lat': 1.0, 'unenhanc': 1.0, 'mail': 1.0, 'bronchovascular': 1.0, 'pleasant': 1.0, 'arthrit': 1.0}, 509: {'oob': 3.0}, 514: {'lat': 1.0, 'schizophrenia': 1.0, 'nicotin': 1.0, 'lighthead': 1.0, 'burn': 1.0, 'pleasant': 2.0, 'commod': 2.0, 'ambul': 1.0, 'oob': 1.0}, 596: {'dnr': 4.0, 'dopamin': 3.0, 'dni': 4.0, 'chair': 2.0}, 674: {'profound': 1.0, 'nimv': 1.0, 'xl': 2.0, 'rememb': 1.0, 'neo': 1.0, 'mso': 1.0, 'lotion': 1.0, 'tranfer': 1.0, 'fu': 1.0, 'cardiovert': 1.0}, 707: {'pleasantli': 4.0, 'lpm': 2.0, 'oob': 3.0, 'pleasant': 2.0}, 711: {'dnr': 190.99999999999997, 'mellitu': 78.0, 'fibrinogen': 186.0, 'captopril': 77.0, 'olanzapin': 109.0, 'palli': 60.0, 'fungemia': 95.0, 'caspofungin': 105.0}, 770: {'iddm': 24.0, 'vp': 20.0}, 773: {'pneumococc': 7.0, 'mso': 8.0, 'levoph': 8.0}, 899: {'lat': 2.0, 'chip': 2.0, 'pleasant': 3.0}, 1096: {'syst': 1.0, 'ppd': 1.0, 'lc': 1.0, 'forc': 1.0, 'tubular': 1.0}, 1135: {'scab': 3.0, 'oob': 6.0, 'chair': 7.0, 'argatroban': 4.0, 'pleasant': 3.0, 'lat': 3.0, 'xl': 3.0}, 1163: {'osa': 1.0, 'pleasant': 1.0, 'twitch': 1.0, 'captopril': 1.0}, 1174: {}, 1180: {'influenc': 1.0}, 1283: {'unavail': 1.0, 'seat': 1.0, 'habitu': 1.0}, 1332: {'levoph': 4.0, 'dnr': 6.0, 'dni': 5.0, 'oob': 4.0}, 1339: {'oob': 20.0, 'stair': 18.0, 'ctx': 18.0, 'ambul': 18.0, 'seroquel': 23.0, 'video': 22.0, 'barium': 18.0, 'phenylephrin': 25.0, 'neo': 27.0}, 1546: {'asthma': 4.0, 'spacer': 2.0, 'oob': 2.0, 'db': 2.0}, 1568: {'pericard': 5.0, 'pleasant': 4.0, 'oob': 2.0}, 1601: {'levoph': 3.0, 'pleasant': 2.0, 'ambien': 2.0}, 1606: {'precordium': 1.0, 'unalt': 1.0, 'dnr': 1.0, 'dni': 1.0, 'lat': 1.0, 'dome': 1.0}, 1642: {'pleasant': 2.0, 'dnr': 2.0, 'dni': 2.0, 'quadrent': 1.0, 'declin': 1.0}, 1660: {'behavior': 2.0, 'pleasant': 2.0}, 1895: {'pleasant': 2.0}, 1923: {'moan': 3.0, 'dnr': 3.0, 'sarna': 2.0, 'lotion': 2.0}, 2029: {'xanax': 28.0, 'dnr': 20.0}, 2090: {'chair': 18.0, 'splint': 13.0, 'dyslipidemia': 23.000000000000004, 'ctx': 17.0, 'bromid': 17.0, 'ntnd': 14.000000000000002}, 2098: {'hugger': 4.0, 'bair': 4.0, 'cpr': 2.0}, 2128: {'dopamin': 10.0, 'mso': 6.0, 'unasyn': 4.0, 'flight': 3.0}, 2170: {'qtc': 1.0, 'nonrebreath': 1.0, 'spur': 2.0, 'lat': 1.0}, 2187: {'osa': 2.0, 'morbid': 2.0, 'captopril': 2.0}, 2208: {'vp': 35.0, 'bipolar': 16.0, 'clonidin': 19.0, 'levoph': 16.0}, 2337: {'smooth': 1.0, 'hemangioma': 1.0, 'slough': 1.0, 'pleasant': 1.0, 'dnr': 2.0, 'pleasantli': 1.0}, 2378: {'ultram': 16.0, 'silent': 16.0, 'video': 15.0, 'sensat': 13.0}, 2386: {'dnr': 7.0, 'hospic': 3.0, 'town': 2.0, 'dni': 3.0}, 2452: {'lat': 4.0}, 2508: {'levoph': 2.0, 'dopamin': 2.0, 'ppd': 2.0, 'ciwa': 2.0, 'lpm': 2.0, 'chair': 2.0}, 2561: {}, 2585: {'hilum': 2.0, 'para': 1.0, 'ultram': 1.0, 'sluggish': 1.0, 'prognosi': 1.0, 'hook': 1.0, 'grave': 1.0, 'dnr': 1.0, 'dni': 1.0}, 2589: {'bipolar': 28.000000000000004, 'pneumococc': 22.0, 'zyprexa': 7.000000000000001, 'dz': 9.0, 'mood': 7.000000000000001, 'historian': 10.0}, 2590: {'dnr': 2.0, 'dni': 2.0, 'nonrebreath': 1.0, 'venti': 2.0, 'lpm': 1.0, 'pleasant': 1.0}, 2628: {}, 2658: {'moan': 3.0}, 2732: {'vertebra': 2.0, 'lat': 2.0}, 2784: {'arrest': 2.0, 'commod': 3.0, 'video': 2.0, 'diaper': 2.0, 'gait': 2.0}, 2823: {'dnr': 4.0, 'venti': 3.0, 'dni': 3.0}, 3070: {'svn': 2.0, 'osa': 1.0, 'ofm': 1.0, 'pleasant': 1.0, 'video': 1.0, ...

# %%
print(patient_cooc_1)
# Out:
# {68: {('ambul', 'commod'): 3.0, ('ambul', 'oob'): 2.0, ('commod', 'oob'): 2.0}, 85: {}, 94: {}, 165: {}, 211: {}, 224: {('platelet', 'rigor'): 1.0, ('commod', 'platelet'): 1.0, ('commod', 'rigor'): 1.0, ('bank', 'fax'): 1.0, ('chair', 'pleasant'): 1.0}, 231: {}, 283: {}, 357: {('intent', 'unasyn'): 2.0, ('dz', 'intent'): 2.0, ('dz', 'unasyn'): 2.0, ('ctx', 'unasyn'): 2.0}, 368: {}, 370: {}, 384: {('bipolar', 'wish'): 4.0}, 426: {('lat', 'mottl'): 1.0, ('mail', 'unenhanc'): 1.0, ('bronchovascular', 'mail'): 1.0, ('bronchovascular', 'unenhanc'): 1.0, ('arthrit', 'pleasant'): 1.0}, 509: {}, 514: {('nicotin', 'schizophrenia'): 1.0, ('lighthead', 'nicotin'): 1.0, ('lighthead', 'schizophrenia'): 1.0, ('burn', 'lighthead'): 1.0, ('burn', 'nicotin'): 1.0, ('burn', 'schizophrenia'): 1.0, ('commod', 'pleasant'): 2.0, ('ambul', 'commod'): 1.0, ('ambul', 'pleasant'): 1.0, ('commod', 'oob'): 1.0, ('oob', 'pleasant'): 1.0}, 596: {('dni', 'dnr'): 2.0}, 674: {('nimv', 'profound'): 1.0, ('rememb', 'xl'): 1.0, ('neo', 'rememb'): 1.0, ('neo', 'xl'): 1.0, ('mso', 'neo'): 1.0, ('mso', 'rememb'): 1.0, ('mso', 'xl'): 1.0, ('lotion', 'mso'): 1.0, ('lotion', 'neo'): 1.0, ('lotion', 'rememb'): 1.0, ('lotion', 'xl'): 1.0, ('tranfer', 'xl'): 1.0, ('fu', 'tranfer'): 1.0, ('fu', 'xl'): 1.0, ('cardiovert', 'fu'): 1.0, ('cardiovert', 'tranfer'): 1.0, ('cardiovert', 'xl'): 1.0}, 707: {('oob', 'pleasantli'): 2.0}, 711: {('fibrinogen', 'mellitu'): 59.0, ('dnr', 'fibrinogen'): 159.0, ('captopril', 'fibrinogen'): 66.0, ('fibrinogen', 'olanzapin'): 99.0, ('dnr', 'olanzapin'): 85.0, ('dnr', 'fungemia'): 80.0, ('fibrinogen', 'fungemia'): 78.0, ('caspofungin', 'fungemia'): 87.0, ('fungemia', 'olanzapin'): 57.0, ('caspofungin', 'dnr'): 81.0, ('caspofungin', 'fibrinogen'): 79.0}, 770: {('iddm', 'vp'): 16.0}, 773: {}, 899: {}, 1096: {('ppd', 'syst'): 1.0}, 1135: {('chair', 'oob'): 4.0, ('argatroban', 'chair'): 3.0}, 1163: {('captopril', 'twitch'): 1.0}, 1174: {}, 1180: {}, 1283: {('seat', 'unavail'): 1.0, ('habitu', 'unavail'): 1.0, ('habitu', 'seat'): 1.0}, 1332: {('dni', 'dnr'): 5.0}, 1339: {('oob', 'stair'): 18.0, ('ctx', 'stair'): 18.0, ('ctx', 'oob'): 18.0, ('ambul', 'ctx'): 18.0, ('ambul', 'stair'): 18.0, ('ambul', 'oob'): 18.0, ('phenylephrin', 'video'): 15.0, ('barium', 'video'): 15.0}, 1546: {('db', 'oob'): 2.0}, 1568: {('pericard', 'pleasant'): 3.0, ('oob', 'pleasant'): 2.0}, 1601: {('levoph', 'pleasant'): 2.0}, 1606: {('dni', 'dnr'): 1.0}, 1642: {('dnr', 'pleasant'): 2.0, ('dni', 'pleasant'): 2.0, ('pleasant', 'quadrent'): 1.0, ('declin', 'pleasant'): 1.0, ('dni', 'dnr'): 2.0, ('dnr', 'quadrent'): 1.0, ('declin', 'dnr'): 1.0, ('dni', 'quadrent'): 1.0, ('declin', 'dni'): 1.0, ('declin', 'quadrent'): 1.0}, 1660: {}, 1895: {}, 1923: {('dnr', 'moan'): 2.0, ('dnr', 'sarna'): 2.0, ('moan', 'sarna'): 2.0, ('lotion', 'sarna'): 2.0, ('dnr', 'lotion'): 2.0, ('lotion', 'moan'): 2.0}, 2029: {}, 2090: {('ctx', 'dyslipidemia'): 13.0, ('bromid', 'dyslipidemia'): 17.0}, 2098: {('bair', 'hugger'): 4.0}, 2128: {('dopamin', 'mso'): 4.0, ('dopamin', 'unasyn'): 3.0}, 2170: {}, 2187: {('morbid', 'osa'): 2.0}, 2208: {('bipolar', 'vp'): 16.0}, 2337: {('hemangioma', 'smooth'): 1.0, ('pleasant', 'slough'): 1.0, ('dnr', 'pleasantli'): 1.0}, 2378: {('silent', 'video'): 14.000000000000002, ('sensat', 'video'): 12.0, ('sensat', 'silent'): 12.0}, 2386: {('dnr', 'hospic'): 3.0, ('dnr', 'town'): 2.0, ('dni', 'dnr'): 3.0}, 2452: {}, 2508: {('dopamin', 'levoph'): 2.0}, 2561: {}, 2585: {('hilum', 'para'): 1.0, ('prognosi', 'sluggish'): 1.0, ('hook', 'prognosi'): 1.0, ('hook', 'sluggish'): 1.0, ('grave', 'hook'): 1.0, ('grave', 'prognosi'): 1.0, ('grave', 'sluggish'): 1.0, ('dnr', 'grave'): 1.0, ('dnr', 'hook'): 1.0, ('dnr', 'prognosi'): 1.0, ('dnr', 'sluggish'): 1.0, ('dni', 'dnr'): 1.0, ('dni', 'grave'): 1.0, ('dni', 'hook'): 1.0, ('dni', 'prognosi'): 1.0, ('dni', 'sluggish'): 1.0}, 2589: {('bipolar', 'pneumococc'): 19.0, ('pneumococc', 'zyprexa'): 7.000000000000001, ('bipolar', 'zyprexa'): 7. ...

# %%
patient_note_num_0
# Out:
# {111: 12,
#  346: 25,
#  404: 3,
#  546: 6,
#  618: 16,
#  705: 15,
#  726: 48,
#  1039: 55,
#  1556: 37,
#  1872: 3,
#  1944: 56,
#  2286: 69,
#  2990: 166,
#  3055: 29,
#  3099: 13,
#  3201: 8,
#  3526: 7,
#  3773: 6,
#  3881: 20,
#  4122: 51,
#  4754: 101,
#  4811: 21,
#  5476: 1,
#  5494: 22,
#  5774: 104,
#  5786: 152,
#  5913: 1,
#  6133: 68,
#  6735: 13,
#  6745: 13,
#  6973: 36,
#  6981: 8,
#  7277: 66,
#  7310: 8,
#  7924: 9,
#  7977: 9,
#  9908: 11,
#  9984: 15,
#  10302: 100,
#  10510: 86,
#  10545: 10,
#  10642: 10,
#  11049: 14,
#  11209: 9,
#  11395: 41,
#  12530: 24,
#  12849: 50,
#  13098: 46,
#  13566: 23,
#  14125: 9,
#  14514: 96,
#  14965: 25,
#  15159: 15,
#  15251: 11,
#  15396: 17,
#  15566: 37,
#  15853: 45,
#  16275: 17,
#  16344: 27,
#  16622: 51,
#  16684: 29,
#  17122: 16,
#  17354: 5,
#  17802: 64,
#  17983: 65,
#  18094: 23,
#  18736: 35,
#  18768: 46,
#  18848: 205,
#  18971: 26,
#  19243: 25,
#  19323: 6,
#  19390: 21,
#  19463: 20,
#  19535: 59,
#  19754: 13,
#  19827: 22,
#  19833: 58,
#  19872: 10,
#  20006: 8,
#  20023: 9,
#  20190: 6,
#  21046: 101,
#  21094: 36,
#  21427: 10,
#  21502: 102,
#  21580: 52,
#  21676: 12,
#  21699: 7,
#  21979: 11,
#  22735: 15,
#  23660: 12,
#  23795: 78,
#  24181: 13,
#  24582: 37,
#  24725: 57,
#  24730: 19,
#  24854: 25,
#  25003: 182,
#  25046: 7,
#  25774: 61,
#  25975: 9,
#  26474: 89,
#  26578: 15,
#  26716: 41,
#  26774: 3,
#  26849: 33,
#  27005: 5,
#  27145: 24,
#  27421: 61,
#  27431: 5,
#  27496: 7,
#  27504: 72,
#  27639: 221,
#  28004: 13,
#  28072: 34,
#  28178: 202,
#  28427: 6,
#  28498: 25,
#  28726: 34,
#  28750: 19,
#  28906: 32,
#  28907: 13,
#  28933: 394,
#  29105: 468,
#  29588: 72,
#  29647: 26,
#  29872: 225,
#  30476: 174,
#  30549: 12,
#  30614: 8,
#  30699: 14,
#  30786: 9,
#  30941: 110,
#  31030: 168,
#  31134: 24,
#  31139: 9,
#  31451: 48,
#  31556: 57,
#  31690: 18,
#  31692: 35,
#  32050: 34,
#  32326: 24,
#  32618: 42,
#  41546: 25,
#  43937: 6,
#  44851: 274,
#  45381: 16,
#  46589: 26,
#  46763: 6,
#  47045: 9,
#  48632: 147,
#  49079: 20,
#  49683: 3,
#  49922: 13,
#  50093: 8,
#  50231: 3,
#  50556: 216,
#  50859: 537,
#  51914: 313,
#  52010: 12,
#  53105: 115,
#  53399: 78,
#  54193: 85,
#  54401: 14,
#  54408: 2,
#  54739: 75,
#  54946: 7,
#  55400: 5,
#  55570: 14,
#  55887: 37,
#  55944: 34,
#  55987: 20,
#  56390: 19,
#  56648: 8,
#  56854: 170,
#  57091: 88,
#  57102: 35,
#  58702: 479,
#  59260: 11,
#  59437: 26,
#  60849: 2,
#  60868: 6,
#  61652: 7,
#  61667: 30,
#  63039: 8,
#  65513: 8,
#  68044: 40,
#  68095: 23,
#  68184: 5,
#  68308: 8,
#  68860: 14,
#  69719: 13,
#  69745: 25,
#  69776: 17,
#  70226: 8,
#  70447: 9,
#  72930: 11,
#  73811: 9,
#  73888: 109,
#  74316: 2,
#  74444: 81,
#  74686: 75,
#  75824: 10,
#  76282: 21,
#  76827: 2,
#  77382: 10,
#  78241: 3,
#  78388: 14,
#  79008: 27,
#  79055: 21,
#  79222: 18,
#  79877: 156,
#  80637: 148,
#  80678: 9,
#  80737: 46,
#  80805: 79,
#  81437: 27,
#  82393: 5,
#  82769: 85,
#  83932: 2,
#  84474: 34,
#  85160: 8,
#  85258: 52,
#  85404: 11,
#  85797: 9,
#  86007: 35,
#  86394: 4,
#  86684: 11,
#  86832: 67,
#  86863: 8,
#  86872: 326,
#  88193: 16,
#  88660: 11,
#  90256: 18,
#  91350: 19,
#  92074: 28,
#  92278: 52,
#  92331: 42,
#  93422: 7,
#  94341: 2,
#  94997: 9,
#  95280: 23,
#  95803: 18,
#  95830: 33,
#  95933: 56,
#  96699: 85,
#  97181: 30,
#  97795: 60,
#  98009: 33,
#  98299: 29,
#  98597: 2}

# %% [markdown]
# #### Create set of patient co-occurrences from two groups

# %%
# Create a set of all unique co-occurrences from both group
patient_cooc_set = set()
patient_cooc_0_dict = {}
patient_cooc_1_dict = {}

for k, v in patient_cooc_0.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_0_dict:
            patient_cooc_0_dict[item] = v[item]
        else:
            patient_cooc_0_dict[item] = patient_cooc_0_dict[item] + v[item]
            
    
for k, v in patient_cooc_1.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_1_dict:
            patient_cooc_1_dict[item] = v[item]
        else:
            patient_cooc_1_dict[item] = patient_cooc_1_dict[item] + v[item]

# %%
print(len(patient_cooc_set))
print(len(patient_cooc_0_dict))
print(len(patient_cooc_1_dict))
# Out:
# 6776
# 1989
# 5152

# %%
# count log-odds score

# reverse
# --------------- co-occurrences --------------->

        
# Get the set of coocurrencies from two groups
# Count log_odd_score

patient_cooc_odd_scores = {}
for set_item in patient_cooc_set:
    if set_item in patient_cooc_0_dict and set_item in patient_cooc_1_dict: 
        d_prob = patient_cooc_0_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        a_prob = patient_cooc_1_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
# --------------- co-occurrences ---------------<

# %%
patient_cooc_odd_scores
# Out:
# {('assymetr', 'death'): 6.90875477931522,
#  ('sweat', 'ultrafiltr'): 6.90875477931522,
#  ('gabapentin', 'puff'): 6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('historian', 'incent'): 6.90875477931522,
#  ('dnr', 'paperwork'): 2.625239572123001,
#  ('cash', 'cdb'): 6.90875477931522,
#  ('echocardiogram', 'slice'): -6.90875477931522,
#  ('itchi', 'xii'): 6.90875477931522,
#  ('cyanot', 'laminectomi'): 6.90875477931522,
#  ('jewelri', 'wallet'): 2.2927445483990123,
#  ('dic', 'hive'): -6.90875477931522,
#  ('lc', 'sluggish'): -6.90875477931522,
#  ('gastrojejunostomi', 'homogen'): 6.90875477931522,
#  ('absorb', 'deterior'): 6.90875477931522,
#  ('epigastr', 'nifedipin'): 6.90875477931522,
#  ('fibrinogen', 'levoph'): -2.061768222000086,
#  ('hctz', 'unstabl'): 6.90875477931522,
#  ('breakfast', 'ruptur'): 6.90875477931522,
#  ('dead', 'mortem'): -6.90875477931522,
#  ('life', 'trazodon'): -6.90875477931522,
#  ('caspofungin', 'metoclopramid'): 6.90875477931522,
#  ('dermat', 'herp'): 6.90875477931522,
#  ('breakfast', 'nitroglycerin'): 6.90875477931522,
#  ('natg', 'scar'): -6.90875477931522,
#  ('arrest', 'ffp'): 6.90875477931522,
#  ('bipolar', 'moan'): 6.90875477931522,
#  ('puff', 'unavail'): 6.90875477931522,
#  ('freeli', 'pharyng'): 6.90875477931522,
#  ('deliv', 'moan'): 6.90875477931522,
#  ('autoset', 'cocain'): 6.90875477931522,
#  ('fibrinogen', 'mellitu'): 6.90875477931522,
#  ('aricept', 'gown'): -6.90875477931522,
#  ('splint', 'uri'): 6.90875477931522,
#  ('bronchovascular', 'peribronchovascular'): 6.90875477931522,
#  ('solut', 'treatement'): 6.90875477931522,
#  ('oob', 'wallet'): 6.90875477931522,
#  ('cocain', 'ultram'): 6.90875477931522,
#  ('im', 'nocturn'): 6.90875477931522,
#  ('duski', 'wish'): -6.90875477931522,
#  ('duski', 'palli'): -6.90875477931522,
#  ('dnr', 'td'): 6.90875477931522,
#  ('incis', 'motor'): 6.90875477931522,
#  ('aaox', 'moan'): 6.90875477931522,
#  ('osa', 'pleasant'): 6.90875477931522,
#  ('dni', 'epigastr'): 6.90875477931522,
#  ('omeprazol', 'prilosec'): 6.90875477931522,
#  ('ctx', 'ferritin'): 6.90875477931522,
#  ('oncologist', 'palli'): -0.05395925023558934,
#  ('behavior', 'im'): 6.90875477931522,
#  ('scopalamin', 'seroquel'): 6.90875477931522,
#  ('bipolar', 'strictur'): 6.90875477931522,
#  ('binder', 'cramp'): 6.90875477931522,
#  ('metoclopramid', 'sarna'): 6.90875477931522,
#  ('dni', 'herp'): 6.90875477931522,
#  ('hive', 'itchi'): 6.90875477931522,
#  ('escal', 'mva'): 6.90875477931522,
#  ('bicarbon', 'hypercapnia'): -6.90875477931522,
#  ('historian', 'oder'): -6.90875477931522,
#  ('dietari', 'iddm'): 6.90875477931522,
#  ('laminectomi', 'mellitu'): 6.90875477931522,
#  ('asthma', 'lac'): 6.90875477931522,
#  ('chemic', 'lusb'): -6.90875477931522,
#  ('suprapub', 'thrive'): 6.90875477931522,
#  ('palli', 'xanax'): 6.90875477931522,
#  ('clonazepam', 'zyprexa'): 6.90875477931522,
#  ('chair', 'nectar'): 6.90875477931522,
#  ('arrang', 'dnr'): -6.90875477931522,
#  ('currenlti', 'trabecul'): 6.90875477931522,
#  ('fatti', 'occipit'): 6.90875477931522,
#  ('ambul', 'palli'): -6.90875477931522,
#  ('gabapentin', 'suprapub'): 6.90875477931522,
#  ('ctx', 'money'): 6.90875477931522,
#  ('hunger', 'mso'): -6.90875477931522,
#  ('azotemia', 'unasyn'): 6.90875477931522,
#  ('oligur', 'wish'): -6.90875477931522,
#  ('db', 'hive'): 6.90875477931522,
#  ('dead', 'dnr'): -6.90875477931522,
#  ('incent', 'tracheomalacia'): 6.90875477931522,
#  ('echocardiogram', 'omeprazol'): 6.90875477931522,
#  ('laryng', 'vallecula'): 6.90875477931522,
#  ('cocain', 'dni'): 6.90875477931522,
#  ('motor', 'soln'): 6.90875477931522,
#  ('acc', 'distanc'): 6.90875477931522,
#  ('declin', 'dietari'): 6.90875477931522,
#  ('gabapentin', 'laminectomi'): 6.90875477931522,
#  ('dnr', 'lat'): 6.90875477931522,
#  ('fatti', 'vagu'): 6.90875477931522,
#  ('ciwa', 'protrud'): 6.90875477931522,
#  ('arrest', 'artifici'): -6.90875477931522,
#  ('fatti', 'splint'): 6.90875477931522,
#  ('ambul', 'commod'): 6.90875477931522,
#  ('paperwork', 'wish'): 6.90875477931522,
#  ('asthma', 'unstabl'): 6.90875477931522,
#  ('chair', 'gentamycin'): -6.90875477931522,
#  ('behavior', 'nectar'): 6.90875477931522,
#  ('azotemia', 'crack'): 6.90875477931522,
#  ('colonoscopi', 'gabapentin'): 6.90875477931522,
#  ('oob', 'quietli'): -6.90875477931522,
#  ('ferritin', 'seriou'): 6.90875477931522,
#  ('bipolar', 'incis'): 6.90875477931522,
#  ('ffp', 'mean'): -6.90875477931522,
#  ('cmo', 'hypotherm'): -6.90875477931522,
#  ('prec', 'vagu'): 6.90875477931522,
#  ('epigastr', 'splint'): 6.90875477931522,
#  ('dizzi', 'dni'): 6.90875477931522,
#  ('stair', 'sweat'): 6.90875477931522,
#  ('ccn', 'levoph'): -6.90875477931522,
#  ('lpm', 'strictur'): 6.90875477931522,
#  ('dni', 'zyprexa'): 1.6812038300138494,
#  ('asthma', 'barium'): 6.90875477931522,
#  ('led', 'predict'): 6.90875477931522,
#  ('peribronchovascular', 'smooth'): -6.90875477931522,
#  ('azotemia', 'subq'): 6.90875477931522,
#  ('dnr', 'uri'): 6.90875477931522,
#  ('adam', 'icter'): -6.90875477931522,
#  ('breakfast', 'intiat'): 6.90875477931522,
#  ('metoclopramid', 'soln'): 6.90875477931522,
#  ('azotemia', 'phenylephrin'): -6.90875477931522,
#  ('breakfast', 'uffp'): 6.90875477931522,
#  ('hook', 'sluggish'): 6.90875477931522,
#  ('gait', 'thirst'): 6.90875477931522,
#  ('dnr', 'sluggishli'): -6.90875477931522,
#  ('hemothorax', 'levoph'): -6.90875477931522,
#  ('hilum', 'vagu'): 6.90875477931522,
#  ('hurt', 'profound'): 6.90875477931522,
#  ('ciwa', 'fibrinogen'): 6.90875477931522,
#  ('gait', 'religi'): -6.90875477931522,
#  ('anuria', 'mellitu'): 6.90875477931522,
#  ('preme', 'rigor'): 6.90875477931522,
#  ('asthma', 'nectar'): 6.90875477931522,
#  ('compani', 'prilosec'): 6.90875477931522,
#  ('depth', 'diaphoresi'): 6.90875477931522,
#  ('pleasant', 'venti'): 6.90875477931522,
#  ('grave', 'judgement'): -6.90875477931522,
#  ('commod', 'wallet'): -6.90875477931522,
#  ('agon', 'pea'): -6.90875477931522,
#  ('bipolar', 'ppd'): 6.90875477931522,
#  ('agon', 'venti'): 6.90875477931522,
#  ('life', 'pleasant'): -6.90875477931522,
#  ('intiat', 'jerk'): -6.90875477931522,
#  ('dietari', 'historian'): 6.90875477931522,
#  ('dnr', 'fliud'): -6.90875477931522,
#  ('cagluc', 'hung'): -6.90875477931522,
#  ('dnr', 'wish'): 0.45453473275630624,
#  ('nocturn', 'sweat'): 6.90875477931522,
#  ('abnl', 'dnr'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('opinion', 'prognosi'): -6.90875477931522,
#  ('ppd', 'schizophrenia'): 6.90875477931522,
#  ('para', 'young'): 6.90875477931522,
#  ('option', 'unstabl'): -6.90875477931522,
#  ('azotemia', 'puff'): 6.90875477931522,
#  ('chol', 'stg'): -6.90875477931522,
#  ('declin', 'trazodon'): 6.90875477931522,
#  ('ctx', 'mellitu'): 6.90875477931522,
#  ('ffp', 'lw'): 6.90875477931522,
#  ('burn', 'scar'): 6.90875477931522,
#  ('itchi', 'nitroglycerin'): 6.90875477931522,
#  ('ciwa', 'ntnd'): 6.90875477931522,
#  ('pharyng', 'vallecula'): 6.90875477931522,
#  ('fibrinogen', 'schizophrenia'): 6.90875477931522,
#  ('fu', 'pleasant'): 6.90875477931522,
#  ('mva', 'scopalamin'): 6.90875477931522,
#  ('occipit', 'zyprexa'): 6.90875477931522,
#  ('neosynephrin', 'unrel'): -6.90875477931522,
#  ('phlegm', 'stair'): 6.90875477931522,
#  ('hospic', 'mucinex'): 6.90875477931522,
#  ('ambien', 'scl'): 6.90875477931522,
#  ('clergi', 'paralyt'): -6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('fatti', 'habitu'): 6.90875477931522,
#  ('bottl', 'strictur'): 6.90875477931522,
#  ('assymetr', 'hive'): 6.90875477931522,
#  ('hive', 'wish'): 6.90875477931522,
#  ('cmo', 'vasopressin'): -6.90875477931522,
#  ('levoph', 'sibl'): -6.90875477931522,
#  ('hive', 'palli'): -6.90875477931522,
#  ('opiat', 'unasyn'): 6.90875477931522,
#  ('ffp', 'wish'): 6.90875477931522,
#  ('mso', 'vasoconstrict'): -6.90875477931522,
#  ('gabapentin', 'jerk'): 6.90875477931522,
#  ('mrg', 'platelet'): 6.90875477931522,
#  ('azotemia', 'prilosec'): -6.90875477931522,
#  ('epidur', 'ofm'): 6.90875477931522,
#  ('ambien', 'hive'): 6.90875477931522,
#  ('ntnd', 'thiamin'): 6.90875477931522,
#  ('cash', 'chair'): 6.90875477931522,
#  ('dyslipidemia', 'gastrojejunostomi'): 6.90875477931522,
#  ('dnr', 'lw'): 6.90875477931522,
#  ('declin', 'vasopressor'): -6.90875477931522,
#  ('intent', 'unasyn'): 6.90875477931522,
#  ('hypercapn', 'neo'): 6.90875477931522,
#  ('historian', 'money'): 6.90875477931522,
#  ('ferrou', 'omeprazol'): 6.90875477931522,
#  ('calculi', 'trazodon'): 6.90875477931522,
#  ('dermat', 'osa'): 6.90875477931522,
#  ('argatroban', 'norepinephrin'): -6.90875477931522,
#  ('cpr', 'icter'): -6.90875477931522,
#  ('rehabilit', 'rhinorrhea'): 6.90875477931522,
#  ('aox', 'solut'): 6.90875477931522,
#  ('hsq', 'venti'): 6.90875477931522,
#  ('nectar', 'quiac'): 6.90875477931522,
#  ('dizzi', 'unstabl'): 6.90875477931522,
#  ('bromid', 'dizzi'): 6.90875477931522,
#  ('scar', 'wish'): 6.90875477931522,
#  ('abruptli', 'levoph'): -6.90875477931522,
#  ('rhinorrhea', 'sweat'): 6.90875477931522,
#  ('colonoscopi', 'dnr'): 6.90875477931522,
#  ('lighthead', 'sweat'): 6.90875477931522,
#  ('ba', 'hypothermia'): 6.90875477931522,
#  ('laryng', 'lat'): 6.90875477931522,
#  ('bottl', 'qam'): 6.90875477931522,
#  ('mva', 'td'): 6.90875477931522,
#  ('arrest', 'dnr'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('deliv', 'soln'): 6.90875477931522,
#  ('pastor', 'trazodon'): -6.90875477931522,
#  ('fatti', 'homogen'): 6.90875477931522,
#  ('chair', 'money'): 6.90875477931522,
#  ('azotemia', 'bottl'): 6.90875477931522,
#  ('clonidin', 'thrive'): 6.90875477931522,
#  ('hsq', 'sweat'): 6.90875477931522,
#  ('hive', 'lusb'): 6.90875477931522,
#  ('cocain', 'osa'): 6.90875477931522,
#  ('historian', 'ppd'): 6.90875477931522,
#  ('osa', 'rhinorrhea'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('anaphylaxi', 'ferritin'): 6.90875477931522,
#  ('aox', 'xii'): 6.90875477931522,
#  ('asystol', 'bank'): -6.90875477931522,
#  ('cisatracurium', 'levoph'): -6.90875477931522,
#  ('hive', 'sarna'): 6.90875477931522,
#  ('massag', 'refractori'): 6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('emper', 'respitori'): 6.90875477931522,
#  ('clonazepam', 'gum'): 6.90875477931522,
#  ('declin', 'hunger'): -6.90875477931522,
#  ('escal', 'wish'): -6.90875477931522,
#  ('dyslipidemia', 'metoclopramid'): 6.90875477931522,
#  ('declin', 'gait'): 6.90875477931522,
#  ('oob', 'rigor'): 6.90875477931522,
#  ('chair', 'sooner'): 6.90875477931522,
#  ('burn', 'tran'): 6.90875477931522,
#  ('dnr', 'nephrolog'): -1.2495579516853903,
#  ('hospic', 'synthet'): 6.90875477931522,
#  ('agonist', 'asthma'): 6.90875477931522,
#  ('fdp', 'petechia'): -6.90875477931522,
#  ('fatti', 'protrud'): -6.90875477931522,
#  ('ferrou', 'retic'): 6.90875477931522,
#  ('ppd', 'vagu'): 6.90875477931522,
#  ('omeprazol', 'sibl'): 6.90875477931522,
#  ('chair', 'predict'): 6.90875477931522,
#  ('cash', 'oob'): 6.90875477931522,
#  ('pneumococc', 'qam'): 6.90875477931522,
#  ('sensat', 'signatur'): 6.90875477931522,
#  ('declin', 'sweat'): 6.90875477931522,
#  ('hypothermia', 'nifedipin'): 6.90875477931522,
#  ('cmo', 'prognosi'): -6.90875477931522,
#  ('bipolar', 'historian'): 6.90875477931522,
#  ('declin', 'ferritin'): 6.90875477931522,
#  ('syncop', 'young'): 6.90875477931522,
#  ('bank', 'dni'): 6.90875477931522,
#  ('levoph', 'para'): 6.90875477931522,
#  ('chemic', 'exophyt'): -6.90875477931522,
#  ('mrcp', 'wma'): -6.90875477931522,
#  ('lpm', 'meropenam'): -6.90875477931522,
#  ('dni', 'lotion'): -6.90875477931522,
#  ('mortem', 'mso'): -6.90875477931522,
#  ('crrt', 'unstabl'): -6.90875477931522,
#  ('cellcept', 'cocain'): 6.90875477931522,
#  ('asthma', 'young'): 6.90875477931522,
#  ('chair', 'romi'): 6.90875477931522,
#  ('compani', 'gastriti'): 6.90875477931522,
#  ('chair', 'platelet'): 6.90875477931522,
#  ('gum', 'impli'): 6.90875477931522,
#  ('sibl', 'xl'): 6.90875477931522,
#  ('dni', 'tran'): 6.90875477931522,
#  ('aliv', 'paperwork'): 6.90875477931522,
#  ('contractur', 'dnr'): 0.6916505477038827,
#  ('phenylephrin', 'vasopressin'): -6.90875477931522,
#  ('gastriti', 'soln'): 6.90875477931522,
#  ('omeprazol', 'xii'): 0.4046335072286383,
#  ('autopeep', 'bicarbon'): -6.90875477931522,
#  ('arrest', 'chair'): 6.90875477931522,
#  ('bair', 'chair'): -6.90875477931522,
#  ('levoph', 'trazodon'): 6.90875477931522,
#  ('hilum', 'unenhanc'): 6.90875477931522,
#  ('phasic', 'spectral'): 6.90875477931522,
#  ('lat', 'lax'): 6.90875477931522,
#  ('stitch', 'weekli'): 6.90875477931522,
#  ('absorb', 'asthma'): 6.90875477931522,
#  ('azotemia', 'ciwa'): 6.90875477931522,
#  ('mso', 'unstabl'): -6.90875477931522,
#  ('cvvh', 'permiss'): -6.90875477931522,
#  ('dnr', 'funer'): 6.90875477931522,
#  ('postop', 'tremul'): 6.90875477931522,
#  ('lotion', 'oob'): -3.02380801661965,
#  ('asthma', 'quinolon'): 6.90875477931522,
#  ('diaphoresi', 'osa'): 6.90875477931522,
#  ('lat', 'pneumothorac'): 0.6916505477038827,
#  ('hypothermia', 'paralyt'): -6.90875477931522,
#  ('carvedilol', 'thirst'): 6.90875477931522,
#  ('flight', 'pleasantli'): 6.90875477931522,
#  ('barium', 'freeli'): 6.90875477931522,
#  ('recalibr', 'video'): 6.90875477931522,
#  ('commod', 'foci'): 6.90875477931522,
#  ('ambien', 'dni'): 6.90875477931522,
#  ('nice', 'quinton'): 6.90875477931522,
#  ('cdb', 'wallet'): 6.90875477931522,
#  ('spill', 'video'): 6.90875477931522,
#  ('lift', 'readmit'): 6.90875477931522,
#  ('bicarbon', 'hypothermia'): -6.90875477931522,
#  ('effac', 'subdur'): 6.90875477931522,
#  ('declar', 'deterior'): -6.90875477931522,
#  ('acc', 'im'): 6.90875477931522,
#  ('dermat', 'fibrinogen'): 6.90875477931522,
#  ('olanzapin', 'xanax'): 6.90875477931522,
#  ('aricept', 'sundown'): -6.90875477931522,
#  ('bipolar', 'habitu'): 6.90875477931522,
#  ('norepinephrin', 'sluggishli'): -6.90875477931522,
#  ('dni', 'levoph'): -0.5525652299387559,
#  ('incent', 'syst'): 6.90875477931522,
#  ('omeprazol', 'rhinorrhea'): 0.4046335072286383,
#  ('expir', 'ipf'): 6.90875477931522,
#  ('contd', 'refractori'): 6.90875477931522,
#  ('hospic', 'levoph'): -6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('subq', 'vp'): 6.90875477931522,
#  ('aliv', 'robitussin'): 6.90875477931522,
#  ('freeli', 'gastrojejunostomi'): 6.90875477931522,
#  ('cpr', 'suport'): -6.90875477931522,
#  ('levoph', 'modifi'): 6.90875477931522,
#  ('phlegm', 'thiamin'): 6.90875477931522,
#  ('commod', 'msicu'): 6.90875477931522,
#  ('thiamin', 'xii'): 6.90875477931522,
#  ('duski', 'escal'): -6.90875477931522,
#  ('bicarbon', 'permiss'): -6.90875477931522,
#  ('bottl', 'syncop'): 6.90875477931522,
#  ('strictur', 'trabecul'): 6.90875477931522,
#  ('gabapentin', 'pod'): 6.90875477931522,
#  ('hhn', 'lpm'): 6.90875477931522,
#  ('chair', 'levoph'): 6.90875477931522,
#  ('epigastr', 'fibrinogen'): 6.90875477931522,
#  ('agon', 'cmo'): -6.90875477931522,
#  ('parastern', 'subcost'): 6.90875477931522,
#  ('dizzi', 'historian'): -6.90875477931522,
#  ('aox', 'pleasant'): 6.90875477931522,
#  ('caspofungin', 'fungemia'): 6.90875477931522,
#  ('habitu', 'trabecul'): 6.90875477931522,
#  ('modifi', 'omeprazol'): 6.90875477931522,
#  ('autoset', 'clonidin'): 6.90875477931522,
#  ('dnr', 'tranfer'): 6.90875477931522,
#  ('dermat', 'uri'): 6.90875477931522,
#  ('bottl', 'historian'): 6.90875477931522,
#  ('hive', 'lymphangit'): 6.90875477931522,
#  ('contractur', 'oligur'): -0.6916505477038827,
#  ('para', 'slice'): 6.90875477931522,
#  ('distanc', 'romi'): 6.90875477931522,
#  ('puff', 'xii'): 6.90875477931522,
#  ('hilum', 'pronounc'): 6.90875477931522,
#  ('chb', 'oob'): 6.90875477931522,
#  ('ambul', 'xl'): 6.90875477931522,
#  ('phenylephrin', 'prognosi'): -6.90875477931522,
#  ('arrest', 'osa'): 6.90875477931522,
#  ('asthma', 'lat'): 6.90875477931522,
#  ('rhochor', 'scar'): 6.90875477931522,
#  ('absorb', 'quinolon'): 6.90875477931522,
#  ('omeprazol', 'video'): 6.90875477931522,
#  ('dopamin', 'neo'): 2.473073171472692,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('hypotherm', 'levoph'): 1.2495579516853903,
#  ('breakfast', 'hsq'): 6.90875477931522,
#  ('cash', 'money'): 2.1509787690125033,
#  ('lusb', 'xii'): 6.90875477931522,
#  ('hctz', 'sensat'): 6.90875477931522,
#  ('dni', 'quietli'): -6.90875477931522,
#  ('mtg', 'palli'): -6.90875477931522,
#  ('qam', 'rhochor'): 6.90875477931522,
#  ('cocain', 'dnr'): 6.90875477931522,
#  ('dex', 'dopamin'): 6.90875477931522,
#  ('oob', 'tcdb'): 6.90875477931522,
#  ('mood', 'nocturn'): 6.90875477931522,
#  ('arrest', 'autopeep'): -6.90875477931522,
#  ('cyanot', 'gvhd'): -6.90875477931522,
#  ('asthma', 'rhinorrhea'): 6.90875477931522,
#  ('lat', 'pericard'): 6.90875477931522,
#  ('dni', 'occipit'): 6.90875477931522,
#  ('bair', 'sluggish'): -6.90875477931522,
#  ('platelet', 'young'): 6.90875477931522,
#  ('db', 'iddm'): 6.90875477931522,
#  ('struggl', 'wish'): -6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('morbid', 'osa'): 6.90875477931522,
#  ('cocain', 'ppd'): 6.90875477931522,
#  ('bronchovascular', 'fatti'): 6.90875477931522,
#  ('declin', 'doen'): -6.90875477931522,
#  ('bicarbon', 'diaphoresi'): 6.90875477931522,
#  ('ambul', 'life'): 6.90875477931522,
#  ('exophyt', 'fc'): -6.90875477931522,
#  ('ipf', 'pcv'): 6.90875477931522,
#  ('lighthead', 'schizophrenia'): 6.90875477931522,
#  ('omeprazol', 'zyprexa'): 6.90875477931522,
#  ('hook', 'prognosi'): 6.90875477931522,
#  ('db', 'wallet'): 6.90875477931522,
#  ('pronounc', 'sacrament'): -6.90875477931522,
#  ('levoph', 'palli'): -6.90875477931522,
#  ('cellcept', 'lpm'): 6.90875477931522,
#  ('dnr', 'quietli'): -6.90875477931522,
#  ('cash', 'palli'): 6.90875477931522,
#  ('ambien', 'bromid'): 6.90875477931522,
#  ('ipf', 'occipit'): 0.0,
#  ('hive', 'nocturn'): 6.90875477931522,
#  ('conc', 'omeprazol'): 6.90875477931522,
#  ('goc', 'neosynephrin'): -6.90875477931522,
#  ('bicarbon', 'omeprazol'): 6.90875477931522,
#  ('asthma', 'db'): 6.90875477931522,
#  ('ppd', 'xl'): 6.90875477931522,
#  ('asthma', 'ctx'): 6.90875477931522,
#  ('bicarbon', 'readmit'): 6.90875477931522,
#  ('captopril', 'venti'): 6.90875477931522,
#  ('dni', 'refractori'): 6.90875477931522,
#  ('adam', 'neo'): -6.90875477931522,
#  ('ctx', 'signatur'): 6.90875477931522,
#  ('hospic', 'rigor'): 6.90875477931522,
#  ('adenocarcinoma', 'readmit'): 6.90875477931522,
#  ('banana', 'oob'): 6.90875477931522,
#  ('chair', 'cyanot'): -6.90875477931522,
#  ('aox', 'rememb'): 6.90875477931522,
#  ('levoph', 'opiat'): 6.90875477931522,
#  ('contractur', 'pharmacolog'): 6.90875477931522,
#  ('aaox', 'deliv'): 6.90875477931522,
#  ('sensat', 'unstabl'): 6.90875477931522,
#  ('asthma', 'fatti'): 6.90875477931522,
#  ('echocardiogram', 'fatti'): 6.90875477931522,
#  ('esld', 'venti'): 6.90875477931522,
#  ('adam', 'cpr'): -6.90875477931522,
#  ('gastriti', 'omeprazol'): 6.90875477931522,
#  ('nicotin', 'pleasant'): 6.90875477931522,
#  ('declin', 'oligur'): -6.90875477931522,
#  ('plate', 'splint'): 6.90875477931522,
#  ('ferritin', 'ferrou'): 6.90875477931522,
#  ('dni', 'scab'): 0.4046335072286383,
#  ('dic', 'hypotherm'): -6.90875477931522,
#  ('deterior', 'sluggish'): 6.90875477931522,
#  ('dni', 'dyslipidemia'): 6.90875477931522,
#  ('bottl', 'rememb'): 6.90875477931522,
#  ('hive', 'wallet'): 6.90875477931522,
#  ('contractur', 'hypothermia'): -6.90875477931522,
#  ('homogen', 'slice'): 6.90875477931522,
#  ('clonidin', 'dz'): 6.90875477931522,
#  ('lotion', 'sarna'): 6.90875477931522,
#  ('flight', 'nitroglycerin'): 6.90875477931522,
#  ('dopamin', 'xanax'): 6.90875477931522,
#  ('dnr', 'gc'): 6.90875477931522,
#  ('cmo', 'expir'): -6.90875477931522,
#  ('flight', 'xii'): 6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('carvedilol', 'ctx'): 6.90875477931522,
#  ('anur', 'judgement'): -6.90875477931522,
#  ('mrg', 'readmit'): 6.90875477931522,
#  ('acidot', 'agon'): -6.90875477931522,
#  ('dnr', 'mucinex'): 6.90875477931522,
#  ('dni', 'thk'): 6.90875477931522,
#  ('ambul', 'fungemia'): -6.90875477931522,
#  ('arrest', 'passi'): 6.90875477931522,
#  ('ctx', 'db'): 6.90875477931522,
#  ('aox', 'ba'): 6.90875477931522,
#  ('ambul', 'levoph'): 6.90875477931522,
#  ('bipolar', 'dni'): -2.2784985714248847,
#  ('asthma', 'lusb'): 6.90875477931522,
#  ('death', 'trazodon'): 6.90875477931522,
#  ('gasp', 'oder'): -6.90875477931522,
#  ('gabapentin', 'jewelri'): 6.90875477931522,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('dni', 'option'): -1.6812038300138494,
#  ('motor', 'ppd'): 6.90875477931522,
#  ('cmo', 'life'): -6.90875477931522,
#  ('lc', 'viabl'): -6.90875477931522,
#  ('dizzi', 'gastriti'): 6.90875477931522,
#  ('angiogram', 'tran'): 6.90875477931522,
#  ('ctx', 'neo'): 6.90875477931522,
#  ('barium', 'stitch'): 6.90875477931522,
#  ('oncologist', 'thrive'): 6.90875477931522,
#  ('cellcept', 'gvhd'): -6.90875477931522,
#  ('bair', 'paperwork'): -6.90875477931522,
#  ('moan', 'mso'): -6.90875477931522,
#  ('asthma', 'iddm'): 6.90875477931522,
#  ('fungemia', 'twitch'): -6.90875477931522,
#  ('norepinephrin', 'readdress'): -6.90875477931522,
#  ('aricept', 'signatur'): -6.90875477931522,
#  ('asthma', 'dizzi'): 6.90875477931522,
#  ('pivot', 'wallet'): -6.90875477931522,
#  ('dnr', 'option'): -1.6812038300138494,
#  ('dni', 'phenylephrin'): -6.90875477931522,
#  ('dni', 'xl'): 6.90875477931522,
#  ('pea', 'rhinorrhea'): 6.90875477931522,
#  ('escal', 'ultram'): 6.90875477931522,
#  ('nectar', 'videofluoroscopi'): 6.90875477931522,
#  ('echocardiogram', 'tdi'): 6.90875477931522,
#  ('ferrou', 'trazodon'): 6.90875477931522,
#  ('oob', 'rusti'): 6.90875477931522,
#  ('dietari', 'hugger'): 6.90875477931522,
#  ('neo', 'platelet'): -6.90875477931522,
#  ('hospic', 'wallet'): 6.90875477931522,
#  ('dnr', 'laryng'): 1.095952712632351,
#  ('oob', 'xl'): 6.90875477931522,
#  ('dnr', 'sarna'): 6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('commod', 'xopenex'): 6.90875477931522,
#  ('nectar', 'silent'): 6.90875477931522,
#  ('barium', 'laryng'): 6.90875477931522,
#  ('cmo', 'nifedipin'): -6.90875477931522,
#  ('agon', 'neosynephrin'): -6.90875477931522,
#  ('expir', 'neo'): -6.90875477931522,
#  ('asthma', 'pea'): 6.90875477931522,
#  ('sluggish', 'venti'): 6.90875477931522,
#  ('omeprazol', 'pneumococc'): 6.90875477931522,
#  ('epigastr', 'unstabl'): 6.90875477931522,
#  ('ciwa', 'qam'): 6.90875477931522,
#  ('paperwork', 'vasopressor'): -6.90875477931522,
#  ('hemangioma', 'plerual'): 6.90875477931522,
#  ('mtg', 'paralyt'): -6.90875477931522,
#  ('dni', 'ipf'): -0.4046335072286383,
#  ('mso', 'rememb'): 6.90875477931522,
#  ('declin', 'ppn'): 6.90875477931522,
#  ('incent', 'osa'): 6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('pharmacolog', 'scar'): 6.90875477931522,
#  ('icter', 'weekli'): 6.90875477931522,
#  ('captopril', 'cpr'): -6.90875477931522,
#  ('ambien', 'klonopin'): 6.90875477931522,
#  ('asthma', 'habitu'): 6.90875477931522,
#  ('clonidin', 'proph'): 6.90875477931522,
#  ('fatti', 'hsq'): 6.90875477931522,
#  ('life', 'peac'): -6.90875477931522,
#  ('bicarbon', 'bromid'): 6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('levoph', 'ultram'): 6.90875477931522,
#  ('anyway', 'weekli'): 6.90875477931522,
#  ('burn', 'levoph'): 6.90875477931522,
#  ('paco', 'pleasant'): 6.90875477931522,
#  ('incis', 'levoph'): 6.90875477931522,
#  ('ctx', 'seroquel'): 6.90875477931522,
#  ('mortem', 'sluggish'): -6.90875477931522,
#  ('ipf', 'nectar'): 6.90875477931522,
#  ('norepinephrin', 'pcv'): -6.90875477931522,
#  ('omeprazol', 'retic'): 6.90875477931522,
#  ('arrest', 'oncologist'): 6.90875477931522,
#  ('reveiw', 'wish'): -6.90875477931522,
#  ('neo', 'phenylephrin'): -0.2463623386430715,
#  ('compani', 'dizzi'): 6.90875477931522,
#  ('asthma', 'unavail'): 6.90875477931522,
#  ('ambien', 'hctz'): 6.90875477931522,
#  ('moan', 'zyprexa'): 6.90875477931522,
#  ('behavior', 'flight'): 6.90875477931522,
#  ('anur', 'ggt'): -6.90875477931522,
#  ('dni', 'pca'): 6.90875477931522,
#  ('levoph', 'neosynephrin'): -6.90875477931522,
#  ('opiat', 'thiamin'): 6.90875477931522,
#  ('preme', 'zero'): 6.90875477931522,
#  ('db', 'yel'): 6.90875477931522,
#  ('epigastr', 'romi'): 6.90875477931522,
#  ('angioplasti', 'dnr'): 6.90875477931522,
#  ('contractur', 'scar'): 6.90875477931522,
#  ('absorb', 'uri'): 6.90875477931522,
#  ('hemangioma', 'mjmgb'): 6.90875477931522,
#  ('pose', 'vasoconstrict'): -6.90875477931522,
#  ('ultram', 'unstabl'): 6.90875477931522,
#  ('ba', 'omeprazol'): 6.90875477931522,
#  ('ambul', 'seroquel'): 6.90875477931522,
#  ('ba', 'phlegm'): 6.90875477931522,
#  ('aliv', 'rehabilit'): 6.90875477931522,
#  ('dead', 'morgu'): -6.90875477931522,
#  ('calculi', 'rehabilit'): 6.90875477931522,
#  ('aricept', 'jewelri'): -6.90875477931522,
#  ('laminectomi', 'osa'): 6.90875477931522,
#  ('cyanot', 'hive'): 6.90875477931522,
#  ('synthet', 'wma'): -6.90875477931522,
#  ('ambul', 'twitch'): -6.90875477931522,
#  ('commod', 'unasyn'): 6.90875477931522,
#  ('fibrinogen', 'futil'): -6.90875477931522,
#  ('dni', 'lpm'): -6.90875477931522,
#  ('habitu', 'unstabl'): 6.90875477931522,
#  ('purpl', 'ultram'): 6.90875477931522,
#  ('foci', 'subdur'): 6.90875477931522,
#  ('angioplasti', 'diaphoresi'): 6.90875477931522,
#  ('nectar', 'seroquel'): 6.90875477931522,
#  ('slice', 'vertebra'): 6.90875477931522,
#  ('cyanot', 'oob'): -6.90875477931522,
#  ('gadolinium', 'occipit'): 6.90875477931522,
#  ('chair', 'hugger'): -6.90875477931522,
#  ('calculi', 'suprapub'): 6.90875477931522,
#  ('lusb', 'romi'): 6.90875477931522,
#  ('cash', 'ctx'): 6.90875477931522,
#  ('para', 'sweat'): 6.90875477931522,
#  ('arrest', 'recruit'): 6.90875477931522,
#  ('phenylephrin', 'sluggish'): -6.90875477931522,
#  ('commod', 'pose'): 6.90875477931522,
#  ('epigastr', 'sensat'): 6.90875477931522,
#  ('ciwa', 'motor'): 6.90875477931522,
#  ('forth', 'pleasant'): 6.90875477931522,
#  ('death', 'mso'): -6.90875477931522,
#  ('bronchovascular', 'unenhanc'): 6.90875477931522,
#  ('panic', 'sensat'): 6.90875477931522,
#  ('clonidin', 'mellitu'): 6.90875477931522,
#  ('cmo', 'colonoscopi'): 6.90875477931522,
#  ('azotemia', 'chemic'): 6.90875477931522,
#  ('dnr', 'unasyn'): 6.90875477931522,
#  ('mean', 'phenylephrin'): 6.90875477931522,
#  ('neo', 'rememb'): 6.90875477931522,
#  ('dni', 'vp'): 6.90875477931522,
#  ('dizzi', 'jewelri'): 6.90875477931522,
#  ('mellitu', 'romi'): 6.90875477931522,
#  ('cvvh', 'phenylephrin'): -6.90875477931522,
#  ('acc', 'ctx'): 6.90875477931522,
#  ('anur', 'prilosec'): -6.90875477931522,
#  ('robitussin', 'sweat'): 6.90875477931522,
#  ('hsq', 'phlegm'): 6.90875477931522,
#  ('echocardiogram', 'transmitr'): 6.90875477931522,
#  ('metoclopramid', 'omeprazol'): 6.90875477931522,
#  ('aox', 'ffp'): 6.90875477931522,
#  ('chair', 'zyprexa'): 6.90875477931522,
#  ('mellitu', 'paralyt'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('ambul', 'eyelid'): -6.90875477931522,
#  ('asthma', 'para'): 6.90875477931522,
#  ('pleasant', 'qam'): 6.90875477931522,
#  ('occupi', 'rehabilit'): 6.90875477931522,
#  ('deterior', 'gc'): 6.90875477931522,
#  ('hctz', 'mellitu'): 6.90875477931522,
#  ('chair', 'qtc'): 6.90875477931522,
#  ('hctz', 'thiamin'): 6.90875477931522,
#  ('cash', 'crack'): 6.90875477931522,
#  ('platelet', 'prognosi'): 6.90875477931522,
#  ('dic', 'zoloft'): 6.90875477931522,
#  ('hilum', 'vertebra'): -6.90875477931522,
#  ('cmo', 'mso'): -6.90875477931522,
#  ('nonlabor', 'oob'): 6.90875477931522,
#  ('hilum', 'peribronchovascular'): 0.0,
#  ('intiat', 'levoph'): -0.6916505477038827,
#  ('fatti', 'nephrogram'): 6.90875477931522,
#  ('expir', 'vasopressin'): -6.90875477931522,
#  ('gasp', 'hospic'): -6.90875477931522,
#  ('dni', 'ntnd'): 1.4174966125472825,
#  ('asthma', 'director'): 6.90875477931522,
#  ('commod', 'diaper'): 6.90875477931522,
#  ('ferrou', 'xii'): 6.90875477931522,
#  ('binder', 'dnr'): 6.90875477931522,
#  ('palli', 'scopalamin'): -6.90875477931522,
#  ('criticar', 'pinpoint'): -6.90875477931522,
#  ('dizzi', 'schizophrenia'): 6.90875477931522,
#  ('compani', 'dni'): 6.90875477931522,
#  ('death', 'im'): -0.4046335072286383,
#  ('reguard', 'simpli'): 6.90875477931522,
#  ('neosynephrin', 'wish'): -6.90875477931522,
#  ('requr', 'rm'): 6.90875477931522,
#  ('bell', 'option'): 6.90875477931522,
#  ('gait', 'im'): 6.90875477931522,
#  ('fdp', 'ggt'): -6.90875477931522,
#  ('declin', 'fliud'): -6.90875477931522,
#  ('dic', 'vasopressor'): -6.90875477931522,
#  ('cash', 'wallet'): 2.0293823968853086,
#  ('declin', 'ferrou'): 6.90875477931522,
#  ('cagluc', 'neosynephrin'): -6.90875477931522,
#  ('autopsi', 'prognosi'): -6.90875477931522,
#  ('anaphylaxi', 'dyslipidemia'): 6.90875477931522,
#  ('osa', 'seat'): 6.90875477931522,
#  ('chair', 'sundown'): -6.90875477931522,
#  ('aaox', 'commod'): 6.90875477931522,
#  ('platelet', 'profound'): 6.90875477931522,
#  ('coach', 'gait'): 6.90875477931522,
#  ('lat', 'occupi'): 6.90875477931522,
#  ('dic', 'ferritin'): 6.90875477931522,
#  ('director', 'venti'): 6.90875477931522,
#  ('dnr', 'friction'): 6.90875477931522,
#  ('osa', 'ppd'): 6.90875477931522,
#  ('^th', 'commod'): 6.90875477931522,
#  ('cocain', 'cramp'): 6.90875477931522,
#  ('barium', 'video'): 6.90875477931522,
#  ('bronchovascular', 'hilum'): 6.90875477931522,
#  ('dni', 'fibrinogen'): 1.095952712632351,
#  ('moan', 'rabbi'): -6.90875477931522,
#  ('foci', 'peribronchovascular'): 0.0,
#  ('bicarbon', 'wma'): -6.90875477931522,
#  ('lac', 'vertebra'): 6.90875477931522,
#  ('cdb', 'levoph'): 6.90875477931522,
#  ('dnr', 'shorter'): 6.90875477931522,
#  ('myeloma', 'omeprazol'): 0.5584397574369147,
#  ('acidot', 'neo'): -6.90875477931522,
#  ('heroic', 'readdress'): -6.90875477931522,
#  ('habitu', 'subcost'): 6.90875477931522,
#  ('cocain', 'ferrou'): 6.90875477931522,
#  ('subcost', 'unavail'): 6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('duski', 'sluggish'): 6.90875477931522,
#  ('arrest', 'life'): -6.90875477931522,
#  ('captopril', 'prilosec'): 6.90875477931522,
#  ('morgu', 'mso'): -6.90875477931522,
#  ('mrg', 'zoloft'): 6.90875477931522,
#  ('ba', 'rhinorrhea'): 6.90875477931522,
#  ('mellitu', 'oob'): 6.90875477931522,
#  ('dyslipidemia', 'soln'): 6.90875477931522,
#  ('cefapim', 'kerlix'): 6.90875477931522,
#  ('ba', 'seroquel'): 6.90875477931522,
#  ('deterior', 'escal'): -6.90875477931522,
#  ('grave', 'mottl'): -6.90875477931522,
#  ('furhter', 'rescan'): 6.90875477931522,
#  ('chair', 'cramp'): 6.90875477931522,
#  ('ambien', 'pharmacolog'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('rhinorrhea', 'stair'): 6.90875477931522,
#  ('aox', 'phenylephrin'): 6.90875477931522,
#  ('occupi', 'recruit'): 6.90875477931522,
#  ('aricept', 'romi'): 6.90875477931522,
#  ('deliv', 'lymphangit'): 6.90875477931522,
#  ('ambul', 'syncop'): 6.90875477931522,
#  ('cisatracurium', 'dopamin'): -6.90875477931522,
#  ('dopamin', 'scar'): 6.90875477931522,
#  ('dnr', 'omeprazol'): 2.040109298143704,
#  ('incent', 'nonrebreath'): 6.90875477931522,
#  ('declin', 'im'): 6.90875477931522,
#  ('ppd', 'puff'): 6.90875477931522,
#  ('pleasant', 'strictur'): 6.90875477931522,
#  ('endplat', 'gadolinium'): 6.90875477931522,
#  ('ba', 'diaphoresi'): 6.90875477931522,
#  ('cpr', 'cvvhd'): 6.90875477931522,
#  ('clinician', 'im'): 6.90875477931522,
#  ('oob', 'thk'): 6.90875477931522,
#  ('aox', 'omeprazol'): 6.90875477931522,
#  ('hypercapnia', 'pea'): -6.90875477931522,
#  ('levoph', 'pitressin'): -6.90875477931522,
#  ('ciwa', 'thiamin'): 6.90875477931522,
#  ('captopril', 'lpm'): 6.90875477931522,
#  ('fibrinogen', 'subq'): 6.90875477931522,
#  ('arrest', 'carvedilol'): 6.90875477931522,
#  ('lighthead', 'omeprazol'): 6.90875477931522,
#  ('ferritin', 'mellitu'): 6.90875477931522,
#  ('friction', 'unobtain'): 6.90875477931522,
#  ('liw', 'vasoconstrict'): -6.90875477931522,
#  ('sundown', 'zyprexa'): 6.90875477931522,
#  ('dopamin', 'twitch'): -6.90875477931522,
#  ('bronchovascular', 'ctx'): 6.90875477931522,
#  ('bell', 'lpm'): 6.90875477931522,
#  ('osa', 'silent'): 6.90875477931522,
#  ('dnr', 'nicotin'): 6.90875477931522,
#  ('clonidin', 'gastriti'): 6.90875477931522,
#  ('exophyt', 'lusb'): -6.90875477931522,
#  ('barium', 'motor'): 6.90875477931522,
#  ('judgement', 'mso'): -6.90875477931522,
#  ('asthma', 'bipolar'): 6.90875477931522,
#  ('dni', 'gvhd'): 6.90875477931522,
#  ('dni', 'dobutamin'): 6.90875477931522,
#  ('lotion', 'neo'): 6.90875477931522,
#  ('ctx', 'hilum'): 6.90875477931522,
#  ('qam', 'vagu'): 6.90875477931522,
#  ('ferritin', 'platelet'): 6.90875477931522,
#  ('cyanot', 'neosynephrin'): -6.90875477931522,
#  ('barium', 'osa'): 6.90875477931522,
#  ('argatroban', 'cvvh'): -6.90875477931522,
#  ('adam', 'duski'): -6.90875477931522,
#  ('conc', 'hospic'): 6.90875477931522,
#  ('ferritin', 'hive'): 6.90875477931522,
#  ('acc', 'romi'): 6.90875477931522,
#  ('caspofungin', 'fibrinogen'): 6.90875477931522,
#  ('seriou', 'wish'): -6.90875477931522,
#  ('eg', 'pharyng'): 6.90875477931522,
#  ('fatti', 'spectral'): -6.90875477931522,
#  ('nocturn', 'trazodon'): 6.90875477931522,
#  ('aaox', 'lac'): 6.90875477931522,
#  ('ntnd', 'synthet'): -6.90875477931522,
#  ('calculi', 'habitu'): 6.90875477931522,
#  ('aprv', 'gvhd'): -6.90875477931522,
#  ('cellcept', 'option'): 6.90875477931522,
#  ('cracker', 'spiromet'): -6.90875477931522,
#  ('articul', 'splint'): 6.90875477931522,
#  ('assymetr', 'pronounc'): -6.90875477931522,
#  ('barium', 'hsq'): 6.90875477931522,
#  ('platelet', 'scar'): 6.90875477931522,
#  ('gadolinium', 'impli'): 6.90875477931522,
#  ('dnr', 'platelet'): -1.128632200393624,
#  ('grave', 'prognosi'): -0.6916505477038827,
#  ('declin', 'mso'): -6.90875477931522,
#  ('nitroglycerin', 'pleasant'): 6.90875477931522,
#  ('cvvhd', 'hugger'): -6.90875477931522,
#  ('bipolar', 'klonopin'): 6.90875477931522,
#  ('declin', 'levoph'): -2.552122795903801,
#  ('pose', 'unstabl'): -6.90875477931522,
#  ('dnr', 'paralyt'): -4.232757431880003,
#  ('osa', 'robitussin'): -6.90875477931522,
#  ('seroquel', 'vp'): 6.90875477931522,
#  ('dic', 'hypothermia'): -6.90875477931522,
#  ('flight', 'gvhd'): 6.90875477931522,
#  ('arrest', 'escal'): -6.90875477931522,
#  ('ciwa', 'declin'): 6.90875477931522,
#  ('bicarbon', 'fibrinogen'): -6.90875477931522,
#  ('cg', 'levoph'): -6.90875477931522,
#  ('bromid', 'dyslipidemia'): 6.90875477931522,
#  ('rehabilit', 'suprapub'): 6.90875477931522,
#  ('levoph', 'life'): 6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('dni', 'synthet'): -6.90875477931522,
#  ('bank', 'gabapentin'): 6.90875477931522,
#  ('ppd', 'suprapub'): 6.90875477931522,
#  ('bicarbon', 'oligur'): -6.90875477931522,
#  ('hospic', 'oder'): -6.90875477931522,
#  ('life', 'mean'): 6.90875477931522,
#  ('epidur', 'fibrinogen'): 6.90875477931522,
#  ('levoph', 'rpr'): 6.90875477931522,
#  ('chip', 'hook'): 6.90875477931522,
#  ('ambien', 'unasyn'): 6.90875477931522,
#  ('asthma', 'historian'): 6.90875477931522,
#  ('historian', 'opiat'): 6.90875477931522,
#  ('ctx', 'dz'): 6.90875477931522,
#  ('ciwa', 'tubular'): 6.90875477931522,
#  ('coach', 'soln'): 6.90875477931522,
#  ('declin', 'retic'): 6.90875477931522,
#  ('dnr', 'unstabl'): -6.90875477931522,
#  ('anaphylaxi', 'barium'): 6.90875477931522,
#  ('myeloma', 'rhinorrhea'): -6.90875477931522,
#  ('assymetr', 'unenhanc'): -6.90875477931522,
#  ('gurgl', 'levoph'): 6.90875477931522,
#  ('captopril', 'predict'): 6.90875477931522,
#  ('muddi', 'uri'): 6.90875477931522,
#  ('anur', 'hypercapn'): -6.90875477931522,
#  ('chair', 'neo'): 6.90875477931522,
#  ('crack', 'ultram'): 6.90875477931522,
#  ('readmit', 'subdur'): 6.90875477931522,
#  ('rememb', 'uri'): 6.90875477931522,
#  ('abnl', 'clinician'): 6.90875477931522,
#  ('dni', 'syncop'): 6.90875477931522,
#  ('anuria', 'crrt'): -6.90875477931522,
#  ('pleasant', 'redirect'): -6.90875477931522,
#  ('bottl', 'unavail'): 6.90875477931522,
#  ('dermat', 'incis'): -6.90875477931522,
#  ('anaphylaxi', 'imbal'): 6.90875477931522,
#  ('barium', 'thrive'): 6.90875477931522,
#  ('chair', 'msicu'): 6.90875477931522,
#  ('dni', 'neo'): -0.7604677155175794,
#  ('gait', 'rm'): 6.90875477931522,
#  ('mood', 'profound'): 6.90875477931522,
#  ('dni', 'mottl'): -6.90875477931522,
#  ('dnr', 'ffp'): -1.095952712632351,
#  ('oob', 'sooner'): 6.90875477931522,
#  ('mood', 'suprapub'): 6.90875477931522,
#  ('ciwa', 'palli'): 6.90875477931522,
#  ('ggt', 'petechia'): -6.90875477931522,
#  ('intiat', 'neosynephrin'): -6.90875477931522,
#  ('cocain', 'ultrafiltr'): 6.90875477931522,
#  ('ctx', 'metoclopramid'): 6.90875477931522,
#  ('chair', 'jewelri'): 6.90875477931522,
#  ('pastor', 'pea'): -6.90875477931522,
#  ('paperwork', 'robitussin'): 6.90875477931522,
#  ('mucinex', 'omeprazol'): 6.90875477931522,
#  ('ntnd', 'prilosec'): 6.90875477931522,
#  ('captopril', 'twitch'): 6.90875477931522,
#  ('dz', 'phenylephrin'): 6.90875477931522,
#  ('sluggish', 'viabl'): -6.90875477931522,
#  ('bill', 'dyslipidemia'): 6.90875477931522,
#  ('bromid', 'lac'): 6.90875477931522,
#  ('ctx', 'dyslipidemia'): 6.90875477931522,
#  ('hospic', 'ppn'): 6.90875477931522,
#  ('cocain', 'phlegm'): 6.90875477931522,
#  ('cloth', 'dni'): 0.0,
#  ('pinpoint', "tf'ing"): 6.90875477931522,
#  ('hypotherm', 'scopalamin'): -6.90875477931522,
#  ('mso', 'syst'): 6.90875477931522,
#  ('azotemia', 'ctx'): 6.90875477931522,
#  ('cpr', 'dobutamin'): -6.90875477931522,
#  ('mottl', 'mso'): -6.90875477931522,
#  ('dysynchron', 'ffp'): -6.90875477931522,
#  ('aaox', 'foci'): 6.90875477931522,
#  ('bow', 'ipf'): 6.90875477931522,
#  ('dnr', 'strictur'): 6.90875477931522,
#  ('hctz', 'icter'): 6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('distanc', 'young'): 6.90875477931522,
#  ('chip', 'dnr'): 6.90875477931522,
#  ('dni', 'forc'): -6.90875477931522,
#  ('aricept', 'syncop'): 6.90875477931522,
#  ('ctx', 'quinolon'): 6.90875477931522,
#  ('adenocarcinoma', 'vertebra'): 6.90875477931522,
#  ('aricept', 'ruptur'): 6.90875477931522,
#  ('breakfast', 'stitch'): 6.90875477931522,
#  ('harm', 'oob'): 6.90875477931522,
#  ('foci', 'pronounc'): 6.90875477931522,
#  ('bipolar', 'seriou'): 6.90875477931522,
#  ('bair', 'cs'): -6.90875477931522,
#  ('coarctat', 'mean'): -6.90875477931522,
#  ('chair', 'suprapub'): 6.90875477931522,
#  ('ppn', 'prognosi'): 6.90875477931522,
#  ('ctx', 'diaphoresi'): 6.90875477931522,
#  ('asthma', 'motor'): 6.90875477931522,
#  ('echocardiogram', 'hive'): 6.90875477931522,
#  ('bipolar', 'unequ'): 6.90875477931522,
#  ('lotion', 'moan'): 6.90875477931522,
#  ('anyway', 'diaphoresi'): 6.90875477931522,
#  ('deliv', 'dnr'): 6.90875477931522,
#  ('arrest', 'jejunum'): -6.90875477931522,
#  ('chemic', 'habitu'): 6.90875477931522,
#  ('neo', 'readdress'): -6.90875477931522,
#  ('ctx', 'phlegm'): 6.90875477931522,
#  ('banana', 'historian'): 6.90875477931522,
#  ('ambul', 'scar'): 6.90875477931522,
#  ('captopril', 'platelet'): -6.90875477931522,
#  ('dni', 'flight'): 6.90875477931522,
#  ('lw', 'pca'): 6.90875477931522,
#  ('crrt', 'ffp'): -6.90875477931522,
#  ('levoph', 'mean'): 6.90875477931522,
#  ('levoph', 'uri'): 6.90875477931522,
#  ('esophagogastr', 'hemithorac'): -6.90875477931522,
#  ('herp', 'pleasant'): 6.90875477931522,
#  ('mrg', 'suprapub'): 6.90875477931522,
#  ('hive', 'metoclopramid'): 6.90875477931522,
#  ('agon', 'wish'): -6.90875477931522,
#  ('asystol', 'dead'): -6.90875477931522,
#  ('dic', 'diflucan'): -6.90875477931522,
#  ('cocain', 'echocardiogram'): 6.90875477931522,
#  ('sluggish', 'west'): 6.90875477931522,
#  ('dni', 'rememb'): 6.90875477931522,
#  ('aox', 'captopril'): 6.90875477931522,
#  ('pathologist', 'vallecula'): 6.90875477931522,
#  ('mso', 'neo'): 6.90875477931522,
#  ('dnr', 'tran'): 6.90875477931522,
#  ('cracker', 'incent'): -6.90875477931522,
#  ('cocain', 'db'): 6.90875477931522,
#  ('declin', 'scab'): 6.90875477931522,
#  ('declin', 'scar'): 6.90875477931522,
#  ('chip', 'xanax'): 6.90875477931522,
#  ('cvvh', 'synthet'): 6.90875477931522,
#  ('dnr', 'stg'): -6.90875477931522,
#  ('neoplast', 'palli'): 6.90875477931522,
#  ('gastriti', 'solut'): 6.90875477931522,
#  ('lymphangit', 'soln'): 6.90875477931522,
#  ('cocain', 'prec'): 6.90875477931522,
#  ('ba', 'subq'): 6.90875477931522,
#  ('compani', 'predict'): 6.90875477931522,
#  ('dnr', 'rememb'): 6.90875477931522,
#  ('dni', 'funer'): 6.90875477931522,
#  ('asthma', 'gabapentin'): 6.90875477931522,
#  ('gabapentin', 'mellitu'): 6.90875477931522,
#  ('ciwa', 'habitu'): 6.90875477931522,
#  ('dead', 'dni'): -6.90875477931522,
#  ('oob', 'rhinorrhea'): 6.90875477931522,
#  ('fliud', 'vasopressor'): -6.90875477931522,
#  ('dni', 'transmitr'): 6.90875477931522,
#  ('mva', 'ppd'): 6.90875477931522,
#  ('arrang', 'prognosi'): -6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('dni', 'stg'): -6.90875477931522,
#  ('cyanot', 'gentamycin'): -6.90875477931522,
#  ('ambien', 'ambul'): 6.90875477931522,
#  ('ctx', 'sibl'): 6.90875477931522,
#  ('expir', 'im'): 6.90875477931522,
#  ('captopril', 'oob'): 6.90875477931522,
#  ('fibrinogen', 'suffer'): 6.90875477931522,
#  ('diaphoresi', 'lighthead'): 6.90875477931522,
#  ('fdp', 'prilosec'): -6.90875477931522,
#  ('agon', 'levoph'): -6.90875477931522,
#  ('dnr', 'life'): -2.552122795903801,
#  ('cdb', 'commod'): 6.90875477931522,
#  ('bill', 'synthet'): 6.90875477931522,
#  ('icter', 'prilosec'): 6.90875477931522,
#  ('lat', 'plate'): 6.90875477931522,
#  ('angioplasti', 'ppd'): 6.90875477931522,
#  ('schistocyt', 'young'): 6.90875477931522,
#  ('dni', 'lac'): 6.90875477931522,
#  ('hypercapnia', 'norepinephrin'): -6.90875477931522,
#  ('fibrinogen', 'readdress'): 6.90875477931522,
#  ('para', 'solut'): 6.90875477931522,
#  ('anur', 'pronounc'): 6.90875477931522,
#  ('gabapentin', 'wish'): 6.90875477931522,
#  ('dnr', 'gasp'): -6.90875477931522,
#  ('abnl', 'lat'): 6.90875477931522,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('azotemia', 'cpr'): -6.90875477931522,
#  ('ctx', 'lotion'): 6.90875477931522,
#  ('pleasantli', 'subdur'): 6.90875477931522,
#  ('chair', 'xopenex'): 6.90875477931522,
#  ('bipolar', 'lotion'): -6.90875477931522,
#  ('captopril', 'sibl'): 6.90875477931522,
#  ('hugger', 'pcv'): 6.90875477931522,
#  ('tranfer', 'xl'): 6.90875477931522,
#  ('cvvh', 'wma'): -6.90875477931522,
#  ('commod', 'signatur'): -6.90875477931522,
#  ('hugger', 'pinpoint'): -6.90875477931522,
#  ('ipf', 'levoph'): -6.90875477931522,
#  ('hctz', 'pericard'): 6.90875477931522,
#  ('diaphoresi', 'echocardiogram'): 6.90875477931522,
#  ('gait', 'unavail'): 6.90875477931522,
#  ('nifedipin', 'suprapub'): 6.90875477931522,
#  ('death', 'ferrou'): 6.90875477931522,
#  ('diaphoresi', 'levoph'): 6.90875477931522,
#  ('adam', 'levoph'): -6.90875477931522,
#  ('barium', 'pharyng'): 6.90875477931522,
#  ('asthma', 'eg'): 6.90875477931522,
#  ('diflucan', 'money'): 6.90875477931522,
#  ('chip', 'palli'): 6.90875477931522,
#  ('oob', 'simpli'): 6.90875477931522,
#  ('ofm', 'svn'): 6.90875477931522,
#  ...}

# %% [markdown]
# ### Train mode

# %% [markdown]
# #### Method 2. Each patient graph => [model training]

# %%
# Dictionaries to use
 # struct: {word: word2vec[128, numpy.array]}
patient_cooc_odd_scores # struct: {cooc_tuple: log_odds_score}
print()

# %%
patient_cooc_odd_scores
# Out:
# {('assymetr', 'death'): 6.90875477931522,
#  ('sweat', 'ultrafiltr'): 6.90875477931522,
#  ('gabapentin', 'puff'): 6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('historian', 'incent'): 6.90875477931522,
#  ('dnr', 'paperwork'): 2.625239572123001,
#  ('cash', 'cdb'): 6.90875477931522,
#  ('echocardiogram', 'slice'): -6.90875477931522,
#  ('itchi', 'xii'): 6.90875477931522,
#  ('cyanot', 'laminectomi'): 6.90875477931522,
#  ('jewelri', 'wallet'): 2.2927445483990123,
#  ('dic', 'hive'): -6.90875477931522,
#  ('lc', 'sluggish'): -6.90875477931522,
#  ('gastrojejunostomi', 'homogen'): 6.90875477931522,
#  ('absorb', 'deterior'): 6.90875477931522,
#  ('epigastr', 'nifedipin'): 6.90875477931522,
#  ('fibrinogen', 'levoph'): -2.061768222000086,
#  ('hctz', 'unstabl'): 6.90875477931522,
#  ('breakfast', 'ruptur'): 6.90875477931522,
#  ('dead', 'mortem'): -6.90875477931522,
#  ('life', 'trazodon'): -6.90875477931522,
#  ('caspofungin', 'metoclopramid'): 6.90875477931522,
#  ('dermat', 'herp'): 6.90875477931522,
#  ('breakfast', 'nitroglycerin'): 6.90875477931522,
#  ('natg', 'scar'): -6.90875477931522,
#  ('arrest', 'ffp'): 6.90875477931522,
#  ('bipolar', 'moan'): 6.90875477931522,
#  ('puff', 'unavail'): 6.90875477931522,
#  ('freeli', 'pharyng'): 6.90875477931522,
#  ('deliv', 'moan'): 6.90875477931522,
#  ('autoset', 'cocain'): 6.90875477931522,
#  ('fibrinogen', 'mellitu'): 6.90875477931522,
#  ('aricept', 'gown'): -6.90875477931522,
#  ('splint', 'uri'): 6.90875477931522,
#  ('bronchovascular', 'peribronchovascular'): 6.90875477931522,
#  ('solut', 'treatement'): 6.90875477931522,
#  ('oob', 'wallet'): 6.90875477931522,
#  ('cocain', 'ultram'): 6.90875477931522,
#  ('im', 'nocturn'): 6.90875477931522,
#  ('duski', 'wish'): -6.90875477931522,
#  ('duski', 'palli'): -6.90875477931522,
#  ('dnr', 'td'): 6.90875477931522,
#  ('incis', 'motor'): 6.90875477931522,
#  ('aaox', 'moan'): 6.90875477931522,
#  ('osa', 'pleasant'): 6.90875477931522,
#  ('dni', 'epigastr'): 6.90875477931522,
#  ('omeprazol', 'prilosec'): 6.90875477931522,
#  ('ctx', 'ferritin'): 6.90875477931522,
#  ('oncologist', 'palli'): -0.05395925023558934,
#  ('behavior', 'im'): 6.90875477931522,
#  ('scopalamin', 'seroquel'): 6.90875477931522,
#  ('bipolar', 'strictur'): 6.90875477931522,
#  ('binder', 'cramp'): 6.90875477931522,
#  ('metoclopramid', 'sarna'): 6.90875477931522,
#  ('dni', 'herp'): 6.90875477931522,
#  ('hive', 'itchi'): 6.90875477931522,
#  ('escal', 'mva'): 6.90875477931522,
#  ('bicarbon', 'hypercapnia'): -6.90875477931522,
#  ('historian', 'oder'): -6.90875477931522,
#  ('dietari', 'iddm'): 6.90875477931522,
#  ('laminectomi', 'mellitu'): 6.90875477931522,
#  ('asthma', 'lac'): 6.90875477931522,
#  ('chemic', 'lusb'): -6.90875477931522,
#  ('suprapub', 'thrive'): 6.90875477931522,
#  ('palli', 'xanax'): 6.90875477931522,
#  ('clonazepam', 'zyprexa'): 6.90875477931522,
#  ('chair', 'nectar'): 6.90875477931522,
#  ('arrang', 'dnr'): -6.90875477931522,
#  ('currenlti', 'trabecul'): 6.90875477931522,
#  ('fatti', 'occipit'): 6.90875477931522,
#  ('ambul', 'palli'): -6.90875477931522,
#  ('gabapentin', 'suprapub'): 6.90875477931522,
#  ('ctx', 'money'): 6.90875477931522,
#  ('hunger', 'mso'): -6.90875477931522,
#  ('azotemia', 'unasyn'): 6.90875477931522,
#  ('oligur', 'wish'): -6.90875477931522,
#  ('db', 'hive'): 6.90875477931522,
#  ('dead', 'dnr'): -6.90875477931522,
#  ('incent', 'tracheomalacia'): 6.90875477931522,
#  ('echocardiogram', 'omeprazol'): 6.90875477931522,
#  ('laryng', 'vallecula'): 6.90875477931522,
#  ('cocain', 'dni'): 6.90875477931522,
#  ('motor', 'soln'): 6.90875477931522,
#  ('acc', 'distanc'): 6.90875477931522,
#  ('declin', 'dietari'): 6.90875477931522,
#  ('gabapentin', 'laminectomi'): 6.90875477931522,
#  ('dnr', 'lat'): 6.90875477931522,
#  ('fatti', 'vagu'): 6.90875477931522,
#  ('ciwa', 'protrud'): 6.90875477931522,
#  ('arrest', 'artifici'): -6.90875477931522,
#  ('fatti', 'splint'): 6.90875477931522,
#  ('ambul', 'commod'): 6.90875477931522,
#  ('paperwork', 'wish'): 6.90875477931522,
#  ('asthma', 'unstabl'): 6.90875477931522,
#  ('chair', 'gentamycin'): -6.90875477931522,
#  ('behavior', 'nectar'): 6.90875477931522,
#  ('azotemia', 'crack'): 6.90875477931522,
#  ('colonoscopi', 'gabapentin'): 6.90875477931522,
#  ('oob', 'quietli'): -6.90875477931522,
#  ('ferritin', 'seriou'): 6.90875477931522,
#  ('bipolar', 'incis'): 6.90875477931522,
#  ('ffp', 'mean'): -6.90875477931522,
#  ('cmo', 'hypotherm'): -6.90875477931522,
#  ('prec', 'vagu'): 6.90875477931522,
#  ('epigastr', 'splint'): 6.90875477931522,
#  ('dizzi', 'dni'): 6.90875477931522,
#  ('stair', 'sweat'): 6.90875477931522,
#  ('ccn', 'levoph'): -6.90875477931522,
#  ('lpm', 'strictur'): 6.90875477931522,
#  ('dni', 'zyprexa'): 1.6812038300138494,
#  ('asthma', 'barium'): 6.90875477931522,
#  ('led', 'predict'): 6.90875477931522,
#  ('peribronchovascular', 'smooth'): -6.90875477931522,
#  ('azotemia', 'subq'): 6.90875477931522,
#  ('dnr', 'uri'): 6.90875477931522,
#  ('adam', 'icter'): -6.90875477931522,
#  ('breakfast', 'intiat'): 6.90875477931522,
#  ('metoclopramid', 'soln'): 6.90875477931522,
#  ('azotemia', 'phenylephrin'): -6.90875477931522,
#  ('breakfast', 'uffp'): 6.90875477931522,
#  ('hook', 'sluggish'): 6.90875477931522,
#  ('gait', 'thirst'): 6.90875477931522,
#  ('dnr', 'sluggishli'): -6.90875477931522,
#  ('hemothorax', 'levoph'): -6.90875477931522,
#  ('hilum', 'vagu'): 6.90875477931522,
#  ('hurt', 'profound'): 6.90875477931522,
#  ('ciwa', 'fibrinogen'): 6.90875477931522,
#  ('gait', 'religi'): -6.90875477931522,
#  ('anuria', 'mellitu'): 6.90875477931522,
#  ('preme', 'rigor'): 6.90875477931522,
#  ('asthma', 'nectar'): 6.90875477931522,
#  ('compani', 'prilosec'): 6.90875477931522,
#  ('depth', 'diaphoresi'): 6.90875477931522,
#  ('pleasant', 'venti'): 6.90875477931522,
#  ('grave', 'judgement'): -6.90875477931522,
#  ('commod', 'wallet'): -6.90875477931522,
#  ('agon', 'pea'): -6.90875477931522,
#  ('bipolar', 'ppd'): 6.90875477931522,
#  ('agon', 'venti'): 6.90875477931522,
#  ('life', 'pleasant'): -6.90875477931522,
#  ('intiat', 'jerk'): -6.90875477931522,
#  ('dietari', 'historian'): 6.90875477931522,
#  ('dnr', 'fliud'): -6.90875477931522,
#  ('cagluc', 'hung'): -6.90875477931522,
#  ('dnr', 'wish'): 0.45453473275630624,
#  ('nocturn', 'sweat'): 6.90875477931522,
#  ('abnl', 'dnr'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('opinion', 'prognosi'): -6.90875477931522,
#  ('ppd', 'schizophrenia'): 6.90875477931522,
#  ('para', 'young'): 6.90875477931522,
#  ('option', 'unstabl'): -6.90875477931522,
#  ('azotemia', 'puff'): 6.90875477931522,
#  ('chol', 'stg'): -6.90875477931522,
#  ('declin', 'trazodon'): 6.90875477931522,
#  ('ctx', 'mellitu'): 6.90875477931522,
#  ('ffp', 'lw'): 6.90875477931522,
#  ('burn', 'scar'): 6.90875477931522,
#  ('itchi', 'nitroglycerin'): 6.90875477931522,
#  ('ciwa', 'ntnd'): 6.90875477931522,
#  ('pharyng', 'vallecula'): 6.90875477931522,
#  ('fibrinogen', 'schizophrenia'): 6.90875477931522,
#  ('fu', 'pleasant'): 6.90875477931522,
#  ('mva', 'scopalamin'): 6.90875477931522,
#  ('occipit', 'zyprexa'): 6.90875477931522,
#  ('neosynephrin', 'unrel'): -6.90875477931522,
#  ('phlegm', 'stair'): 6.90875477931522,
#  ('hospic', 'mucinex'): 6.90875477931522,
#  ('ambien', 'scl'): 6.90875477931522,
#  ('clergi', 'paralyt'): -6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('fatti', 'habitu'): 6.90875477931522,
#  ('bottl', 'strictur'): 6.90875477931522,
#  ('assymetr', 'hive'): 6.90875477931522,
#  ('hive', 'wish'): 6.90875477931522,
#  ('cmo', 'vasopressin'): -6.90875477931522,
#  ('levoph', 'sibl'): -6.90875477931522,
#  ('hive', 'palli'): -6.90875477931522,
#  ('opiat', 'unasyn'): 6.90875477931522,
#  ('ffp', 'wish'): 6.90875477931522,
#  ('mso', 'vasoconstrict'): -6.90875477931522,
#  ('gabapentin', 'jerk'): 6.90875477931522,
#  ('mrg', 'platelet'): 6.90875477931522,
#  ('azotemia', 'prilosec'): -6.90875477931522,
#  ('epidur', 'ofm'): 6.90875477931522,
#  ('ambien', 'hive'): 6.90875477931522,
#  ('ntnd', 'thiamin'): 6.90875477931522,
#  ('cash', 'chair'): 6.90875477931522,
#  ('dyslipidemia', 'gastrojejunostomi'): 6.90875477931522,
#  ('dnr', 'lw'): 6.90875477931522,
#  ('declin', 'vasopressor'): -6.90875477931522,
#  ('intent', 'unasyn'): 6.90875477931522,
#  ('hypercapn', 'neo'): 6.90875477931522,
#  ('historian', 'money'): 6.90875477931522,
#  ('ferrou', 'omeprazol'): 6.90875477931522,
#  ('calculi', 'trazodon'): 6.90875477931522,
#  ('dermat', 'osa'): 6.90875477931522,
#  ('argatroban', 'norepinephrin'): -6.90875477931522,
#  ('cpr', 'icter'): -6.90875477931522,
#  ('rehabilit', 'rhinorrhea'): 6.90875477931522,
#  ('aox', 'solut'): 6.90875477931522,
#  ('hsq', 'venti'): 6.90875477931522,
#  ('nectar', 'quiac'): 6.90875477931522,
#  ('dizzi', 'unstabl'): 6.90875477931522,
#  ('bromid', 'dizzi'): 6.90875477931522,
#  ('scar', 'wish'): 6.90875477931522,
#  ('abruptli', 'levoph'): -6.90875477931522,
#  ('rhinorrhea', 'sweat'): 6.90875477931522,
#  ('colonoscopi', 'dnr'): 6.90875477931522,
#  ('lighthead', 'sweat'): 6.90875477931522,
#  ('ba', 'hypothermia'): 6.90875477931522,
#  ('laryng', 'lat'): 6.90875477931522,
#  ('bottl', 'qam'): 6.90875477931522,
#  ('mva', 'td'): 6.90875477931522,
#  ('arrest', 'dnr'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('deliv', 'soln'): 6.90875477931522,
#  ('pastor', 'trazodon'): -6.90875477931522,
#  ('fatti', 'homogen'): 6.90875477931522,
#  ('chair', 'money'): 6.90875477931522,
#  ('azotemia', 'bottl'): 6.90875477931522,
#  ('clonidin', 'thrive'): 6.90875477931522,
#  ('hsq', 'sweat'): 6.90875477931522,
#  ('hive', 'lusb'): 6.90875477931522,
#  ('cocain', 'osa'): 6.90875477931522,
#  ('historian', 'ppd'): 6.90875477931522,
#  ('osa', 'rhinorrhea'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('anaphylaxi', 'ferritin'): 6.90875477931522,
#  ('aox', 'xii'): 6.90875477931522,
#  ('asystol', 'bank'): -6.90875477931522,
#  ('cisatracurium', 'levoph'): -6.90875477931522,
#  ('hive', 'sarna'): 6.90875477931522,
#  ('massag', 'refractori'): 6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('emper', 'respitori'): 6.90875477931522,
#  ('clonazepam', 'gum'): 6.90875477931522,
#  ('declin', 'hunger'): -6.90875477931522,
#  ('escal', 'wish'): -6.90875477931522,
#  ('dyslipidemia', 'metoclopramid'): 6.90875477931522,
#  ('declin', 'gait'): 6.90875477931522,
#  ('oob', 'rigor'): 6.90875477931522,
#  ('chair', 'sooner'): 6.90875477931522,
#  ('burn', 'tran'): 6.90875477931522,
#  ('dnr', 'nephrolog'): -1.2495579516853903,
#  ('hospic', 'synthet'): 6.90875477931522,
#  ('agonist', 'asthma'): 6.90875477931522,
#  ('fdp', 'petechia'): -6.90875477931522,
#  ('fatti', 'protrud'): -6.90875477931522,
#  ('ferrou', 'retic'): 6.90875477931522,
#  ('ppd', 'vagu'): 6.90875477931522,
#  ('omeprazol', 'sibl'): 6.90875477931522,
#  ('chair', 'predict'): 6.90875477931522,
#  ('cash', 'oob'): 6.90875477931522,
#  ('pneumococc', 'qam'): 6.90875477931522,
#  ('sensat', 'signatur'): 6.90875477931522,
#  ('declin', 'sweat'): 6.90875477931522,
#  ('hypothermia', 'nifedipin'): 6.90875477931522,
#  ('cmo', 'prognosi'): -6.90875477931522,
#  ('bipolar', 'historian'): 6.90875477931522,
#  ('declin', 'ferritin'): 6.90875477931522,
#  ('syncop', 'young'): 6.90875477931522,
#  ('bank', 'dni'): 6.90875477931522,
#  ('levoph', 'para'): 6.90875477931522,
#  ('chemic', 'exophyt'): -6.90875477931522,
#  ('mrcp', 'wma'): -6.90875477931522,
#  ('lpm', 'meropenam'): -6.90875477931522,
#  ('dni', 'lotion'): -6.90875477931522,
#  ('mortem', 'mso'): -6.90875477931522,
#  ('crrt', 'unstabl'): -6.90875477931522,
#  ('cellcept', 'cocain'): 6.90875477931522,
#  ('asthma', 'young'): 6.90875477931522,
#  ('chair', 'romi'): 6.90875477931522,
#  ('compani', 'gastriti'): 6.90875477931522,
#  ('chair', 'platelet'): 6.90875477931522,
#  ('gum', 'impli'): 6.90875477931522,
#  ('sibl', 'xl'): 6.90875477931522,
#  ('dni', 'tran'): 6.90875477931522,
#  ('aliv', 'paperwork'): 6.90875477931522,
#  ('contractur', 'dnr'): 0.6916505477038827,
#  ('phenylephrin', 'vasopressin'): -6.90875477931522,
#  ('gastriti', 'soln'): 6.90875477931522,
#  ('omeprazol', 'xii'): 0.4046335072286383,
#  ('autopeep', 'bicarbon'): -6.90875477931522,
#  ('arrest', 'chair'): 6.90875477931522,
#  ('bair', 'chair'): -6.90875477931522,
#  ('levoph', 'trazodon'): 6.90875477931522,
#  ('hilum', 'unenhanc'): 6.90875477931522,
#  ('phasic', 'spectral'): 6.90875477931522,
#  ('lat', 'lax'): 6.90875477931522,
#  ('stitch', 'weekli'): 6.90875477931522,
#  ('absorb', 'asthma'): 6.90875477931522,
#  ('azotemia', 'ciwa'): 6.90875477931522,
#  ('mso', 'unstabl'): -6.90875477931522,
#  ('cvvh', 'permiss'): -6.90875477931522,
#  ('dnr', 'funer'): 6.90875477931522,
#  ('postop', 'tremul'): 6.90875477931522,
#  ('lotion', 'oob'): -3.02380801661965,
#  ('asthma', 'quinolon'): 6.90875477931522,
#  ('diaphoresi', 'osa'): 6.90875477931522,
#  ('lat', 'pneumothorac'): 0.6916505477038827,
#  ('hypothermia', 'paralyt'): -6.90875477931522,
#  ('carvedilol', 'thirst'): 6.90875477931522,
#  ('flight', 'pleasantli'): 6.90875477931522,
#  ('barium', 'freeli'): 6.90875477931522,
#  ('recalibr', 'video'): 6.90875477931522,
#  ('commod', 'foci'): 6.90875477931522,
#  ('ambien', 'dni'): 6.90875477931522,
#  ('nice', 'quinton'): 6.90875477931522,
#  ('cdb', 'wallet'): 6.90875477931522,
#  ('spill', 'video'): 6.90875477931522,
#  ('lift', 'readmit'): 6.90875477931522,
#  ('bicarbon', 'hypothermia'): -6.90875477931522,
#  ('effac', 'subdur'): 6.90875477931522,
#  ('declar', 'deterior'): -6.90875477931522,
#  ('acc', 'im'): 6.90875477931522,
#  ('dermat', 'fibrinogen'): 6.90875477931522,
#  ('olanzapin', 'xanax'): 6.90875477931522,
#  ('aricept', 'sundown'): -6.90875477931522,
#  ('bipolar', 'habitu'): 6.90875477931522,
#  ('norepinephrin', 'sluggishli'): -6.90875477931522,
#  ('dni', 'levoph'): -0.5525652299387559,
#  ('incent', 'syst'): 6.90875477931522,
#  ('omeprazol', 'rhinorrhea'): 0.4046335072286383,
#  ('expir', 'ipf'): 6.90875477931522,
#  ('contd', 'refractori'): 6.90875477931522,
#  ('hospic', 'levoph'): -6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('subq', 'vp'): 6.90875477931522,
#  ('aliv', 'robitussin'): 6.90875477931522,
#  ('freeli', 'gastrojejunostomi'): 6.90875477931522,
#  ('cpr', 'suport'): -6.90875477931522,
#  ('levoph', 'modifi'): 6.90875477931522,
#  ('phlegm', 'thiamin'): 6.90875477931522,
#  ('commod', 'msicu'): 6.90875477931522,
#  ('thiamin', 'xii'): 6.90875477931522,
#  ('duski', 'escal'): -6.90875477931522,
#  ('bicarbon', 'permiss'): -6.90875477931522,
#  ('bottl', 'syncop'): 6.90875477931522,
#  ('strictur', 'trabecul'): 6.90875477931522,
#  ('gabapentin', 'pod'): 6.90875477931522,
#  ('hhn', 'lpm'): 6.90875477931522,
#  ('chair', 'levoph'): 6.90875477931522,
#  ('epigastr', 'fibrinogen'): 6.90875477931522,
#  ('agon', 'cmo'): -6.90875477931522,
#  ('parastern', 'subcost'): 6.90875477931522,
#  ('dizzi', 'historian'): -6.90875477931522,
#  ('aox', 'pleasant'): 6.90875477931522,
#  ('caspofungin', 'fungemia'): 6.90875477931522,
#  ('habitu', 'trabecul'): 6.90875477931522,
#  ('modifi', 'omeprazol'): 6.90875477931522,
#  ('autoset', 'clonidin'): 6.90875477931522,
#  ('dnr', 'tranfer'): 6.90875477931522,
#  ('dermat', 'uri'): 6.90875477931522,
#  ('bottl', 'historian'): 6.90875477931522,
#  ('hive', 'lymphangit'): 6.90875477931522,
#  ('contractur', 'oligur'): -0.6916505477038827,
#  ('para', 'slice'): 6.90875477931522,
#  ('distanc', 'romi'): 6.90875477931522,
#  ('puff', 'xii'): 6.90875477931522,
#  ('hilum', 'pronounc'): 6.90875477931522,
#  ('chb', 'oob'): 6.90875477931522,
#  ('ambul', 'xl'): 6.90875477931522,
#  ('phenylephrin', 'prognosi'): -6.90875477931522,
#  ('arrest', 'osa'): 6.90875477931522,
#  ('asthma', 'lat'): 6.90875477931522,
#  ('rhochor', 'scar'): 6.90875477931522,
#  ('absorb', 'quinolon'): 6.90875477931522,
#  ('omeprazol', 'video'): 6.90875477931522,
#  ('dopamin', 'neo'): 2.473073171472692,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('hypotherm', 'levoph'): 1.2495579516853903,
#  ('breakfast', 'hsq'): 6.90875477931522,
#  ('cash', 'money'): 2.1509787690125033,
#  ('lusb', 'xii'): 6.90875477931522,
#  ('hctz', 'sensat'): 6.90875477931522,
#  ('dni', 'quietli'): -6.90875477931522,
#  ('mtg', 'palli'): -6.90875477931522,
#  ('qam', 'rhochor'): 6.90875477931522,
#  ('cocain', 'dnr'): 6.90875477931522,
#  ('dex', 'dopamin'): 6.90875477931522,
#  ('oob', 'tcdb'): 6.90875477931522,
#  ('mood', 'nocturn'): 6.90875477931522,
#  ('arrest', 'autopeep'): -6.90875477931522,
#  ('cyanot', 'gvhd'): -6.90875477931522,
#  ('asthma', 'rhinorrhea'): 6.90875477931522,
#  ('lat', 'pericard'): 6.90875477931522,
#  ('dni', 'occipit'): 6.90875477931522,
#  ('bair', 'sluggish'): -6.90875477931522,
#  ('platelet', 'young'): 6.90875477931522,
#  ('db', 'iddm'): 6.90875477931522,
#  ('struggl', 'wish'): -6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('morbid', 'osa'): 6.90875477931522,
#  ('cocain', 'ppd'): 6.90875477931522,
#  ('bronchovascular', 'fatti'): 6.90875477931522,
#  ('declin', 'doen'): -6.90875477931522,
#  ('bicarbon', 'diaphoresi'): 6.90875477931522,
#  ('ambul', 'life'): 6.90875477931522,
#  ('exophyt', 'fc'): -6.90875477931522,
#  ('ipf', 'pcv'): 6.90875477931522,
#  ('lighthead', 'schizophrenia'): 6.90875477931522,
#  ('omeprazol', 'zyprexa'): 6.90875477931522,
#  ('hook', 'prognosi'): 6.90875477931522,
#  ('db', 'wallet'): 6.90875477931522,
#  ('pronounc', 'sacrament'): -6.90875477931522,
#  ('levoph', 'palli'): -6.90875477931522,
#  ('cellcept', 'lpm'): 6.90875477931522,
#  ('dnr', 'quietli'): -6.90875477931522,
#  ('cash', 'palli'): 6.90875477931522,
#  ('ambien', 'bromid'): 6.90875477931522,
#  ('ipf', 'occipit'): 0.0,
#  ('hive', 'nocturn'): 6.90875477931522,
#  ('conc', 'omeprazol'): 6.90875477931522,
#  ('goc', 'neosynephrin'): -6.90875477931522,
#  ('bicarbon', 'omeprazol'): 6.90875477931522,
#  ('asthma', 'db'): 6.90875477931522,
#  ('ppd', 'xl'): 6.90875477931522,
#  ('asthma', 'ctx'): 6.90875477931522,
#  ('bicarbon', 'readmit'): 6.90875477931522,
#  ('captopril', 'venti'): 6.90875477931522,
#  ('dni', 'refractori'): 6.90875477931522,
#  ('adam', 'neo'): -6.90875477931522,
#  ('ctx', 'signatur'): 6.90875477931522,
#  ('hospic', 'rigor'): 6.90875477931522,
#  ('adenocarcinoma', 'readmit'): 6.90875477931522,
#  ('banana', 'oob'): 6.90875477931522,
#  ('chair', 'cyanot'): -6.90875477931522,
#  ('aox', 'rememb'): 6.90875477931522,
#  ('levoph', 'opiat'): 6.90875477931522,
#  ('contractur', 'pharmacolog'): 6.90875477931522,
#  ('aaox', 'deliv'): 6.90875477931522,
#  ('sensat', 'unstabl'): 6.90875477931522,
#  ('asthma', 'fatti'): 6.90875477931522,
#  ('echocardiogram', 'fatti'): 6.90875477931522,
#  ('esld', 'venti'): 6.90875477931522,
#  ('adam', 'cpr'): -6.90875477931522,
#  ('gastriti', 'omeprazol'): 6.90875477931522,
#  ('nicotin', 'pleasant'): 6.90875477931522,
#  ('declin', 'oligur'): -6.90875477931522,
#  ('plate', 'splint'): 6.90875477931522,
#  ('ferritin', 'ferrou'): 6.90875477931522,
#  ('dni', 'scab'): 0.4046335072286383,
#  ('dic', 'hypotherm'): -6.90875477931522,
#  ('deterior', 'sluggish'): 6.90875477931522,
#  ('dni', 'dyslipidemia'): 6.90875477931522,
#  ('bottl', 'rememb'): 6.90875477931522,
#  ('hive', 'wallet'): 6.90875477931522,
#  ('contractur', 'hypothermia'): -6.90875477931522,
#  ('homogen', 'slice'): 6.90875477931522,
#  ('clonidin', 'dz'): 6.90875477931522,
#  ('lotion', 'sarna'): 6.90875477931522,
#  ('flight', 'nitroglycerin'): 6.90875477931522,
#  ('dopamin', 'xanax'): 6.90875477931522,
#  ('dnr', 'gc'): 6.90875477931522,
#  ('cmo', 'expir'): -6.90875477931522,
#  ('flight', 'xii'): 6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('carvedilol', 'ctx'): 6.90875477931522,
#  ('anur', 'judgement'): -6.90875477931522,
#  ('mrg', 'readmit'): 6.90875477931522,
#  ('acidot', 'agon'): -6.90875477931522,
#  ('dnr', 'mucinex'): 6.90875477931522,
#  ('dni', 'thk'): 6.90875477931522,
#  ('ambul', 'fungemia'): -6.90875477931522,
#  ('arrest', 'passi'): 6.90875477931522,
#  ('ctx', 'db'): 6.90875477931522,
#  ('aox', 'ba'): 6.90875477931522,
#  ('ambul', 'levoph'): 6.90875477931522,
#  ('bipolar', 'dni'): -2.2784985714248847,
#  ('asthma', 'lusb'): 6.90875477931522,
#  ('death', 'trazodon'): 6.90875477931522,
#  ('gasp', 'oder'): -6.90875477931522,
#  ('gabapentin', 'jewelri'): 6.90875477931522,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('dni', 'option'): -1.6812038300138494,
#  ('motor', 'ppd'): 6.90875477931522,
#  ('cmo', 'life'): -6.90875477931522,
#  ('lc', 'viabl'): -6.90875477931522,
#  ('dizzi', 'gastriti'): 6.90875477931522,
#  ('angiogram', 'tran'): 6.90875477931522,
#  ('ctx', 'neo'): 6.90875477931522,
#  ('barium', 'stitch'): 6.90875477931522,
#  ('oncologist', 'thrive'): 6.90875477931522,
#  ('cellcept', 'gvhd'): -6.90875477931522,
#  ('bair', 'paperwork'): -6.90875477931522,
#  ('moan', 'mso'): -6.90875477931522,
#  ('asthma', 'iddm'): 6.90875477931522,
#  ('fungemia', 'twitch'): -6.90875477931522,
#  ('norepinephrin', 'readdress'): -6.90875477931522,
#  ('aricept', 'signatur'): -6.90875477931522,
#  ('asthma', 'dizzi'): 6.90875477931522,
#  ('pivot', 'wallet'): -6.90875477931522,
#  ('dnr', 'option'): -1.6812038300138494,
#  ('dni', 'phenylephrin'): -6.90875477931522,
#  ('dni', 'xl'): 6.90875477931522,
#  ('pea', 'rhinorrhea'): 6.90875477931522,
#  ('escal', 'ultram'): 6.90875477931522,
#  ('nectar', 'videofluoroscopi'): 6.90875477931522,
#  ('echocardiogram', 'tdi'): 6.90875477931522,
#  ('ferrou', 'trazodon'): 6.90875477931522,
#  ('oob', 'rusti'): 6.90875477931522,
#  ('dietari', 'hugger'): 6.90875477931522,
#  ('neo', 'platelet'): -6.90875477931522,
#  ('hospic', 'wallet'): 6.90875477931522,
#  ('dnr', 'laryng'): 1.095952712632351,
#  ('oob', 'xl'): 6.90875477931522,
#  ('dnr', 'sarna'): 6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('commod', 'xopenex'): 6.90875477931522,
#  ('nectar', 'silent'): 6.90875477931522,
#  ('barium', 'laryng'): 6.90875477931522,
#  ('cmo', 'nifedipin'): -6.90875477931522,
#  ('agon', 'neosynephrin'): -6.90875477931522,
#  ('expir', 'neo'): -6.90875477931522,
#  ('asthma', 'pea'): 6.90875477931522,
#  ('sluggish', 'venti'): 6.90875477931522,
#  ('omeprazol', 'pneumococc'): 6.90875477931522,
#  ('epigastr', 'unstabl'): 6.90875477931522,
#  ('ciwa', 'qam'): 6.90875477931522,
#  ('paperwork', 'vasopressor'): -6.90875477931522,
#  ('hemangioma', 'plerual'): 6.90875477931522,
#  ('mtg', 'paralyt'): -6.90875477931522,
#  ('dni', 'ipf'): -0.4046335072286383,
#  ('mso', 'rememb'): 6.90875477931522,
#  ('declin', 'ppn'): 6.90875477931522,
#  ('incent', 'osa'): 6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('pharmacolog', 'scar'): 6.90875477931522,
#  ('icter', 'weekli'): 6.90875477931522,
#  ('captopril', 'cpr'): -6.90875477931522,
#  ('ambien', 'klonopin'): 6.90875477931522,
#  ('asthma', 'habitu'): 6.90875477931522,
#  ('clonidin', 'proph'): 6.90875477931522,
#  ('fatti', 'hsq'): 6.90875477931522,
#  ('life', 'peac'): -6.90875477931522,
#  ('bicarbon', 'bromid'): 6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('levoph', 'ultram'): 6.90875477931522,
#  ('anyway', 'weekli'): 6.90875477931522,
#  ('burn', 'levoph'): 6.90875477931522,
#  ('paco', 'pleasant'): 6.90875477931522,
#  ('incis', 'levoph'): 6.90875477931522,
#  ('ctx', 'seroquel'): 6.90875477931522,
#  ('mortem', 'sluggish'): -6.90875477931522,
#  ('ipf', 'nectar'): 6.90875477931522,
#  ('norepinephrin', 'pcv'): -6.90875477931522,
#  ('omeprazol', 'retic'): 6.90875477931522,
#  ('arrest', 'oncologist'): 6.90875477931522,
#  ('reveiw', 'wish'): -6.90875477931522,
#  ('neo', 'phenylephrin'): -0.2463623386430715,
#  ('compani', 'dizzi'): 6.90875477931522,
#  ('asthma', 'unavail'): 6.90875477931522,
#  ('ambien', 'hctz'): 6.90875477931522,
#  ('moan', 'zyprexa'): 6.90875477931522,
#  ('behavior', 'flight'): 6.90875477931522,
#  ('anur', 'ggt'): -6.90875477931522,
#  ('dni', 'pca'): 6.90875477931522,
#  ('levoph', 'neosynephrin'): -6.90875477931522,
#  ('opiat', 'thiamin'): 6.90875477931522,
#  ('preme', 'zero'): 6.90875477931522,
#  ('db', 'yel'): 6.90875477931522,
#  ('epigastr', 'romi'): 6.90875477931522,
#  ('angioplasti', 'dnr'): 6.90875477931522,
#  ('contractur', 'scar'): 6.90875477931522,
#  ('absorb', 'uri'): 6.90875477931522,
#  ('hemangioma', 'mjmgb'): 6.90875477931522,
#  ('pose', 'vasoconstrict'): -6.90875477931522,
#  ('ultram', 'unstabl'): 6.90875477931522,
#  ('ba', 'omeprazol'): 6.90875477931522,
#  ('ambul', 'seroquel'): 6.90875477931522,
#  ('ba', 'phlegm'): 6.90875477931522,
#  ('aliv', 'rehabilit'): 6.90875477931522,
#  ('dead', 'morgu'): -6.90875477931522,
#  ('calculi', 'rehabilit'): 6.90875477931522,
#  ('aricept', 'jewelri'): -6.90875477931522,
#  ('laminectomi', 'osa'): 6.90875477931522,
#  ('cyanot', 'hive'): 6.90875477931522,
#  ('synthet', 'wma'): -6.90875477931522,
#  ('ambul', 'twitch'): -6.90875477931522,
#  ('commod', 'unasyn'): 6.90875477931522,
#  ('fibrinogen', 'futil'): -6.90875477931522,
#  ('dni', 'lpm'): -6.90875477931522,
#  ('habitu', 'unstabl'): 6.90875477931522,
#  ('purpl', 'ultram'): 6.90875477931522,
#  ('foci', 'subdur'): 6.90875477931522,
#  ('angioplasti', 'diaphoresi'): 6.90875477931522,
#  ('nectar', 'seroquel'): 6.90875477931522,
#  ('slice', 'vertebra'): 6.90875477931522,
#  ('cyanot', 'oob'): -6.90875477931522,
#  ('gadolinium', 'occipit'): 6.90875477931522,
#  ('chair', 'hugger'): -6.90875477931522,
#  ('calculi', 'suprapub'): 6.90875477931522,
#  ('lusb', 'romi'): 6.90875477931522,
#  ('cash', 'ctx'): 6.90875477931522,
#  ('para', 'sweat'): 6.90875477931522,
#  ('arrest', 'recruit'): 6.90875477931522,
#  ('phenylephrin', 'sluggish'): -6.90875477931522,
#  ('commod', 'pose'): 6.90875477931522,
#  ('epigastr', 'sensat'): 6.90875477931522,
#  ('ciwa', 'motor'): 6.90875477931522,
#  ('forth', 'pleasant'): 6.90875477931522,
#  ('death', 'mso'): -6.90875477931522,
#  ('bronchovascular', 'unenhanc'): 6.90875477931522,
#  ('panic', 'sensat'): 6.90875477931522,
#  ('clonidin', 'mellitu'): 6.90875477931522,
#  ('cmo', 'colonoscopi'): 6.90875477931522,
#  ('azotemia', 'chemic'): 6.90875477931522,
#  ('dnr', 'unasyn'): 6.90875477931522,
#  ('mean', 'phenylephrin'): 6.90875477931522,
#  ('neo', 'rememb'): 6.90875477931522,
#  ('dni', 'vp'): 6.90875477931522,
#  ('dizzi', 'jewelri'): 6.90875477931522,
#  ('mellitu', 'romi'): 6.90875477931522,
#  ('cvvh', 'phenylephrin'): -6.90875477931522,
#  ('acc', 'ctx'): 6.90875477931522,
#  ('anur', 'prilosec'): -6.90875477931522,
#  ('robitussin', 'sweat'): 6.90875477931522,
#  ('hsq', 'phlegm'): 6.90875477931522,
#  ('echocardiogram', 'transmitr'): 6.90875477931522,
#  ('metoclopramid', 'omeprazol'): 6.90875477931522,
#  ('aox', 'ffp'): 6.90875477931522,
#  ('chair', 'zyprexa'): 6.90875477931522,
#  ('mellitu', 'paralyt'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('ambul', 'eyelid'): -6.90875477931522,
#  ('asthma', 'para'): 6.90875477931522,
#  ('pleasant', 'qam'): 6.90875477931522,
#  ('occupi', 'rehabilit'): 6.90875477931522,
#  ('deterior', 'gc'): 6.90875477931522,
#  ('hctz', 'mellitu'): 6.90875477931522,
#  ('chair', 'qtc'): 6.90875477931522,
#  ('hctz', 'thiamin'): 6.90875477931522,
#  ('cash', 'crack'): 6.90875477931522,
#  ('platelet', 'prognosi'): 6.90875477931522,
#  ('dic', 'zoloft'): 6.90875477931522,
#  ('hilum', 'vertebra'): -6.90875477931522,
#  ('cmo', 'mso'): -6.90875477931522,
#  ('nonlabor', 'oob'): 6.90875477931522,
#  ('hilum', 'peribronchovascular'): 0.0,
#  ('intiat', 'levoph'): -0.6916505477038827,
#  ('fatti', 'nephrogram'): 6.90875477931522,
#  ('expir', 'vasopressin'): -6.90875477931522,
#  ('gasp', 'hospic'): -6.90875477931522,
#  ('dni', 'ntnd'): 1.4174966125472825,
#  ('asthma', 'director'): 6.90875477931522,
#  ('commod', 'diaper'): 6.90875477931522,
#  ('ferrou', 'xii'): 6.90875477931522,
#  ('binder', 'dnr'): 6.90875477931522,
#  ('palli', 'scopalamin'): -6.90875477931522,
#  ('criticar', 'pinpoint'): -6.90875477931522,
#  ('dizzi', 'schizophrenia'): 6.90875477931522,
#  ('compani', 'dni'): 6.90875477931522,
#  ('death', 'im'): -0.4046335072286383,
#  ('reguard', 'simpli'): 6.90875477931522,
#  ('neosynephrin', 'wish'): -6.90875477931522,
#  ('requr', 'rm'): 6.90875477931522,
#  ('bell', 'option'): 6.90875477931522,
#  ('gait', 'im'): 6.90875477931522,
#  ('fdp', 'ggt'): -6.90875477931522,
#  ('declin', 'fliud'): -6.90875477931522,
#  ('dic', 'vasopressor'): -6.90875477931522,
#  ('cash', 'wallet'): 2.0293823968853086,
#  ('declin', 'ferrou'): 6.90875477931522,
#  ('cagluc', 'neosynephrin'): -6.90875477931522,
#  ('autopsi', 'prognosi'): -6.90875477931522,
#  ('anaphylaxi', 'dyslipidemia'): 6.90875477931522,
#  ('osa', 'seat'): 6.90875477931522,
#  ('chair', 'sundown'): -6.90875477931522,
#  ('aaox', 'commod'): 6.90875477931522,
#  ('platelet', 'profound'): 6.90875477931522,
#  ('coach', 'gait'): 6.90875477931522,
#  ('lat', 'occupi'): 6.90875477931522,
#  ('dic', 'ferritin'): 6.90875477931522,
#  ('director', 'venti'): 6.90875477931522,
#  ('dnr', 'friction'): 6.90875477931522,
#  ('osa', 'ppd'): 6.90875477931522,
#  ('^th', 'commod'): 6.90875477931522,
#  ('cocain', 'cramp'): 6.90875477931522,
#  ('barium', 'video'): 6.90875477931522,
#  ('bronchovascular', 'hilum'): 6.90875477931522,
#  ('dni', 'fibrinogen'): 1.095952712632351,
#  ('moan', 'rabbi'): -6.90875477931522,
#  ('foci', 'peribronchovascular'): 0.0,
#  ('bicarbon', 'wma'): -6.90875477931522,
#  ('lac', 'vertebra'): 6.90875477931522,
#  ('cdb', 'levoph'): 6.90875477931522,
#  ('dnr', 'shorter'): 6.90875477931522,
#  ('myeloma', 'omeprazol'): 0.5584397574369147,
#  ('acidot', 'neo'): -6.90875477931522,
#  ('heroic', 'readdress'): -6.90875477931522,
#  ('habitu', 'subcost'): 6.90875477931522,
#  ('cocain', 'ferrou'): 6.90875477931522,
#  ('subcost', 'unavail'): 6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('duski', 'sluggish'): 6.90875477931522,
#  ('arrest', 'life'): -6.90875477931522,
#  ('captopril', 'prilosec'): 6.90875477931522,
#  ('morgu', 'mso'): -6.90875477931522,
#  ('mrg', 'zoloft'): 6.90875477931522,
#  ('ba', 'rhinorrhea'): 6.90875477931522,
#  ('mellitu', 'oob'): 6.90875477931522,
#  ('dyslipidemia', 'soln'): 6.90875477931522,
#  ('cefapim', 'kerlix'): 6.90875477931522,
#  ('ba', 'seroquel'): 6.90875477931522,
#  ('deterior', 'escal'): -6.90875477931522,
#  ('grave', 'mottl'): -6.90875477931522,
#  ('furhter', 'rescan'): 6.90875477931522,
#  ('chair', 'cramp'): 6.90875477931522,
#  ('ambien', 'pharmacolog'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('rhinorrhea', 'stair'): 6.90875477931522,
#  ('aox', 'phenylephrin'): 6.90875477931522,
#  ('occupi', 'recruit'): 6.90875477931522,
#  ('aricept', 'romi'): 6.90875477931522,
#  ('deliv', 'lymphangit'): 6.90875477931522,
#  ('ambul', 'syncop'): 6.90875477931522,
#  ('cisatracurium', 'dopamin'): -6.90875477931522,
#  ('dopamin', 'scar'): 6.90875477931522,
#  ('dnr', 'omeprazol'): 2.040109298143704,
#  ('incent', 'nonrebreath'): 6.90875477931522,
#  ('declin', 'im'): 6.90875477931522,
#  ('ppd', 'puff'): 6.90875477931522,
#  ('pleasant', 'strictur'): 6.90875477931522,
#  ('endplat', 'gadolinium'): 6.90875477931522,
#  ('ba', 'diaphoresi'): 6.90875477931522,
#  ('cpr', 'cvvhd'): 6.90875477931522,
#  ('clinician', 'im'): 6.90875477931522,
#  ('oob', 'thk'): 6.90875477931522,
#  ('aox', 'omeprazol'): 6.90875477931522,
#  ('hypercapnia', 'pea'): -6.90875477931522,
#  ('levoph', 'pitressin'): -6.90875477931522,
#  ('ciwa', 'thiamin'): 6.90875477931522,
#  ('captopril', 'lpm'): 6.90875477931522,
#  ('fibrinogen', 'subq'): 6.90875477931522,
#  ('arrest', 'carvedilol'): 6.90875477931522,
#  ('lighthead', 'omeprazol'): 6.90875477931522,
#  ('ferritin', 'mellitu'): 6.90875477931522,
#  ('friction', 'unobtain'): 6.90875477931522,
#  ('liw', 'vasoconstrict'): -6.90875477931522,
#  ('sundown', 'zyprexa'): 6.90875477931522,
#  ('dopamin', 'twitch'): -6.90875477931522,
#  ('bronchovascular', 'ctx'): 6.90875477931522,
#  ('bell', 'lpm'): 6.90875477931522,
#  ('osa', 'silent'): 6.90875477931522,
#  ('dnr', 'nicotin'): 6.90875477931522,
#  ('clonidin', 'gastriti'): 6.90875477931522,
#  ('exophyt', 'lusb'): -6.90875477931522,
#  ('barium', 'motor'): 6.90875477931522,
#  ('judgement', 'mso'): -6.90875477931522,
#  ('asthma', 'bipolar'): 6.90875477931522,
#  ('dni', 'gvhd'): 6.90875477931522,
#  ('dni', 'dobutamin'): 6.90875477931522,
#  ('lotion', 'neo'): 6.90875477931522,
#  ('ctx', 'hilum'): 6.90875477931522,
#  ('qam', 'vagu'): 6.90875477931522,
#  ('ferritin', 'platelet'): 6.90875477931522,
#  ('cyanot', 'neosynephrin'): -6.90875477931522,
#  ('barium', 'osa'): 6.90875477931522,
#  ('argatroban', 'cvvh'): -6.90875477931522,
#  ('adam', 'duski'): -6.90875477931522,
#  ('conc', 'hospic'): 6.90875477931522,
#  ('ferritin', 'hive'): 6.90875477931522,
#  ('acc', 'romi'): 6.90875477931522,
#  ('caspofungin', 'fibrinogen'): 6.90875477931522,
#  ('seriou', 'wish'): -6.90875477931522,
#  ('eg', 'pharyng'): 6.90875477931522,
#  ('fatti', 'spectral'): -6.90875477931522,
#  ('nocturn', 'trazodon'): 6.90875477931522,
#  ('aaox', 'lac'): 6.90875477931522,
#  ('ntnd', 'synthet'): -6.90875477931522,
#  ('calculi', 'habitu'): 6.90875477931522,
#  ('aprv', 'gvhd'): -6.90875477931522,
#  ('cellcept', 'option'): 6.90875477931522,
#  ('cracker', 'spiromet'): -6.90875477931522,
#  ('articul', 'splint'): 6.90875477931522,
#  ('assymetr', 'pronounc'): -6.90875477931522,
#  ('barium', 'hsq'): 6.90875477931522,
#  ('platelet', 'scar'): 6.90875477931522,
#  ('gadolinium', 'impli'): 6.90875477931522,
#  ('dnr', 'platelet'): -1.128632200393624,
#  ('grave', 'prognosi'): -0.6916505477038827,
#  ('declin', 'mso'): -6.90875477931522,
#  ('nitroglycerin', 'pleasant'): 6.90875477931522,
#  ('cvvhd', 'hugger'): -6.90875477931522,
#  ('bipolar', 'klonopin'): 6.90875477931522,
#  ('declin', 'levoph'): -2.552122795903801,
#  ('pose', 'unstabl'): -6.90875477931522,
#  ('dnr', 'paralyt'): -4.232757431880003,
#  ('osa', 'robitussin'): -6.90875477931522,
#  ('seroquel', 'vp'): 6.90875477931522,
#  ('dic', 'hypothermia'): -6.90875477931522,
#  ('flight', 'gvhd'): 6.90875477931522,
#  ('arrest', 'escal'): -6.90875477931522,
#  ('ciwa', 'declin'): 6.90875477931522,
#  ('bicarbon', 'fibrinogen'): -6.90875477931522,
#  ('cg', 'levoph'): -6.90875477931522,
#  ('bromid', 'dyslipidemia'): 6.90875477931522,
#  ('rehabilit', 'suprapub'): 6.90875477931522,
#  ('levoph', 'life'): 6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('dni', 'synthet'): -6.90875477931522,
#  ('bank', 'gabapentin'): 6.90875477931522,
#  ('ppd', 'suprapub'): 6.90875477931522,
#  ('bicarbon', 'oligur'): -6.90875477931522,
#  ('hospic', 'oder'): -6.90875477931522,
#  ('life', 'mean'): 6.90875477931522,
#  ('epidur', 'fibrinogen'): 6.90875477931522,
#  ('levoph', 'rpr'): 6.90875477931522,
#  ('chip', 'hook'): 6.90875477931522,
#  ('ambien', 'unasyn'): 6.90875477931522,
#  ('asthma', 'historian'): 6.90875477931522,
#  ('historian', 'opiat'): 6.90875477931522,
#  ('ctx', 'dz'): 6.90875477931522,
#  ('ciwa', 'tubular'): 6.90875477931522,
#  ('coach', 'soln'): 6.90875477931522,
#  ('declin', 'retic'): 6.90875477931522,
#  ('dnr', 'unstabl'): -6.90875477931522,
#  ('anaphylaxi', 'barium'): 6.90875477931522,
#  ('myeloma', 'rhinorrhea'): -6.90875477931522,
#  ('assymetr', 'unenhanc'): -6.90875477931522,
#  ('gurgl', 'levoph'): 6.90875477931522,
#  ('captopril', 'predict'): 6.90875477931522,
#  ('muddi', 'uri'): 6.90875477931522,
#  ('anur', 'hypercapn'): -6.90875477931522,
#  ('chair', 'neo'): 6.90875477931522,
#  ('crack', 'ultram'): 6.90875477931522,
#  ('readmit', 'subdur'): 6.90875477931522,
#  ('rememb', 'uri'): 6.90875477931522,
#  ('abnl', 'clinician'): 6.90875477931522,
#  ('dni', 'syncop'): 6.90875477931522,
#  ('anuria', 'crrt'): -6.90875477931522,
#  ('pleasant', 'redirect'): -6.90875477931522,
#  ('bottl', 'unavail'): 6.90875477931522,
#  ('dermat', 'incis'): -6.90875477931522,
#  ('anaphylaxi', 'imbal'): 6.90875477931522,
#  ('barium', 'thrive'): 6.90875477931522,
#  ('chair', 'msicu'): 6.90875477931522,
#  ('dni', 'neo'): -0.7604677155175794,
#  ('gait', 'rm'): 6.90875477931522,
#  ('mood', 'profound'): 6.90875477931522,
#  ('dni', 'mottl'): -6.90875477931522,
#  ('dnr', 'ffp'): -1.095952712632351,
#  ('oob', 'sooner'): 6.90875477931522,
#  ('mood', 'suprapub'): 6.90875477931522,
#  ('ciwa', 'palli'): 6.90875477931522,
#  ('ggt', 'petechia'): -6.90875477931522,
#  ('intiat', 'neosynephrin'): -6.90875477931522,
#  ('cocain', 'ultrafiltr'): 6.90875477931522,
#  ('ctx', 'metoclopramid'): 6.90875477931522,
#  ('chair', 'jewelri'): 6.90875477931522,
#  ('pastor', 'pea'): -6.90875477931522,
#  ('paperwork', 'robitussin'): 6.90875477931522,
#  ('mucinex', 'omeprazol'): 6.90875477931522,
#  ('ntnd', 'prilosec'): 6.90875477931522,
#  ('captopril', 'twitch'): 6.90875477931522,
#  ('dz', 'phenylephrin'): 6.90875477931522,
#  ('sluggish', 'viabl'): -6.90875477931522,
#  ('bill', 'dyslipidemia'): 6.90875477931522,
#  ('bromid', 'lac'): 6.90875477931522,
#  ('ctx', 'dyslipidemia'): 6.90875477931522,
#  ('hospic', 'ppn'): 6.90875477931522,
#  ('cocain', 'phlegm'): 6.90875477931522,
#  ('cloth', 'dni'): 0.0,
#  ('pinpoint', "tf'ing"): 6.90875477931522,
#  ('hypotherm', 'scopalamin'): -6.90875477931522,
#  ('mso', 'syst'): 6.90875477931522,
#  ('azotemia', 'ctx'): 6.90875477931522,
#  ('cpr', 'dobutamin'): -6.90875477931522,
#  ('mottl', 'mso'): -6.90875477931522,
#  ('dysynchron', 'ffp'): -6.90875477931522,
#  ('aaox', 'foci'): 6.90875477931522,
#  ('bow', 'ipf'): 6.90875477931522,
#  ('dnr', 'strictur'): 6.90875477931522,
#  ('hctz', 'icter'): 6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('distanc', 'young'): 6.90875477931522,
#  ('chip', 'dnr'): 6.90875477931522,
#  ('dni', 'forc'): -6.90875477931522,
#  ('aricept', 'syncop'): 6.90875477931522,
#  ('ctx', 'quinolon'): 6.90875477931522,
#  ('adenocarcinoma', 'vertebra'): 6.90875477931522,
#  ('aricept', 'ruptur'): 6.90875477931522,
#  ('breakfast', 'stitch'): 6.90875477931522,
#  ('harm', 'oob'): 6.90875477931522,
#  ('foci', 'pronounc'): 6.90875477931522,
#  ('bipolar', 'seriou'): 6.90875477931522,
#  ('bair', 'cs'): -6.90875477931522,
#  ('coarctat', 'mean'): -6.90875477931522,
#  ('chair', 'suprapub'): 6.90875477931522,
#  ('ppn', 'prognosi'): 6.90875477931522,
#  ('ctx', 'diaphoresi'): 6.90875477931522,
#  ('asthma', 'motor'): 6.90875477931522,
#  ('echocardiogram', 'hive'): 6.90875477931522,
#  ('bipolar', 'unequ'): 6.90875477931522,
#  ('lotion', 'moan'): 6.90875477931522,
#  ('anyway', 'diaphoresi'): 6.90875477931522,
#  ('deliv', 'dnr'): 6.90875477931522,
#  ('arrest', 'jejunum'): -6.90875477931522,
#  ('chemic', 'habitu'): 6.90875477931522,
#  ('neo', 'readdress'): -6.90875477931522,
#  ('ctx', 'phlegm'): 6.90875477931522,
#  ('banana', 'historian'): 6.90875477931522,
#  ('ambul', 'scar'): 6.90875477931522,
#  ('captopril', 'platelet'): -6.90875477931522,
#  ('dni', 'flight'): 6.90875477931522,
#  ('lw', 'pca'): 6.90875477931522,
#  ('crrt', 'ffp'): -6.90875477931522,
#  ('levoph', 'mean'): 6.90875477931522,
#  ('levoph', 'uri'): 6.90875477931522,
#  ('esophagogastr', 'hemithorac'): -6.90875477931522,
#  ('herp', 'pleasant'): 6.90875477931522,
#  ('mrg', 'suprapub'): 6.90875477931522,
#  ('hive', 'metoclopramid'): 6.90875477931522,
#  ('agon', 'wish'): -6.90875477931522,
#  ('asystol', 'dead'): -6.90875477931522,
#  ('dic', 'diflucan'): -6.90875477931522,
#  ('cocain', 'echocardiogram'): 6.90875477931522,
#  ('sluggish', 'west'): 6.90875477931522,
#  ('dni', 'rememb'): 6.90875477931522,
#  ('aox', 'captopril'): 6.90875477931522,
#  ('pathologist', 'vallecula'): 6.90875477931522,
#  ('mso', 'neo'): 6.90875477931522,
#  ('dnr', 'tran'): 6.90875477931522,
#  ('cracker', 'incent'): -6.90875477931522,
#  ('cocain', 'db'): 6.90875477931522,
#  ('declin', 'scab'): 6.90875477931522,
#  ('declin', 'scar'): 6.90875477931522,
#  ('chip', 'xanax'): 6.90875477931522,
#  ('cvvh', 'synthet'): 6.90875477931522,
#  ('dnr', 'stg'): -6.90875477931522,
#  ('neoplast', 'palli'): 6.90875477931522,
#  ('gastriti', 'solut'): 6.90875477931522,
#  ('lymphangit', 'soln'): 6.90875477931522,
#  ('cocain', 'prec'): 6.90875477931522,
#  ('ba', 'subq'): 6.90875477931522,
#  ('compani', 'predict'): 6.90875477931522,
#  ('dnr', 'rememb'): 6.90875477931522,
#  ('dni', 'funer'): 6.90875477931522,
#  ('asthma', 'gabapentin'): 6.90875477931522,
#  ('gabapentin', 'mellitu'): 6.90875477931522,
#  ('ciwa', 'habitu'): 6.90875477931522,
#  ('dead', 'dni'): -6.90875477931522,
#  ('oob', 'rhinorrhea'): 6.90875477931522,
#  ('fliud', 'vasopressor'): -6.90875477931522,
#  ('dni', 'transmitr'): 6.90875477931522,
#  ('mva', 'ppd'): 6.90875477931522,
#  ('arrang', 'prognosi'): -6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('dni', 'stg'): -6.90875477931522,
#  ('cyanot', 'gentamycin'): -6.90875477931522,
#  ('ambien', 'ambul'): 6.90875477931522,
#  ('ctx', 'sibl'): 6.90875477931522,
#  ('expir', 'im'): 6.90875477931522,
#  ('captopril', 'oob'): 6.90875477931522,
#  ('fibrinogen', 'suffer'): 6.90875477931522,
#  ('diaphoresi', 'lighthead'): 6.90875477931522,
#  ('fdp', 'prilosec'): -6.90875477931522,
#  ('agon', 'levoph'): -6.90875477931522,
#  ('dnr', 'life'): -2.552122795903801,
#  ('cdb', 'commod'): 6.90875477931522,
#  ('bill', 'synthet'): 6.90875477931522,
#  ('icter', 'prilosec'): 6.90875477931522,
#  ('lat', 'plate'): 6.90875477931522,
#  ('angioplasti', 'ppd'): 6.90875477931522,
#  ('schistocyt', 'young'): 6.90875477931522,
#  ('dni', 'lac'): 6.90875477931522,
#  ('hypercapnia', 'norepinephrin'): -6.90875477931522,
#  ('fibrinogen', 'readdress'): 6.90875477931522,
#  ('para', 'solut'): 6.90875477931522,
#  ('anur', 'pronounc'): 6.90875477931522,
#  ('gabapentin', 'wish'): 6.90875477931522,
#  ('dnr', 'gasp'): -6.90875477931522,
#  ('abnl', 'lat'): 6.90875477931522,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('azotemia', 'cpr'): -6.90875477931522,
#  ('ctx', 'lotion'): 6.90875477931522,
#  ('pleasantli', 'subdur'): 6.90875477931522,
#  ('chair', 'xopenex'): 6.90875477931522,
#  ('bipolar', 'lotion'): -6.90875477931522,
#  ('captopril', 'sibl'): 6.90875477931522,
#  ('hugger', 'pcv'): 6.90875477931522,
#  ('tranfer', 'xl'): 6.90875477931522,
#  ('cvvh', 'wma'): -6.90875477931522,
#  ('commod', 'signatur'): -6.90875477931522,
#  ('hugger', 'pinpoint'): -6.90875477931522,
#  ('ipf', 'levoph'): -6.90875477931522,
#  ('hctz', 'pericard'): 6.90875477931522,
#  ('diaphoresi', 'echocardiogram'): 6.90875477931522,
#  ('gait', 'unavail'): 6.90875477931522,
#  ('nifedipin', 'suprapub'): 6.90875477931522,
#  ('death', 'ferrou'): 6.90875477931522,
#  ('diaphoresi', 'levoph'): 6.90875477931522,
#  ('adam', 'levoph'): -6.90875477931522,
#  ('barium', 'pharyng'): 6.90875477931522,
#  ('asthma', 'eg'): 6.90875477931522,
#  ('diflucan', 'money'): 6.90875477931522,
#  ('chip', 'palli'): 6.90875477931522,
#  ('oob', 'simpli'): 6.90875477931522,
#  ('ofm', 'svn'): 6.90875477931522,
#  ...}

# %%
# Data normalization
import numpy
def data_norm(cooc_odd_scores):

    def norm_arr(array):
        arr = numpy.array(list(array))
        start = 0
        end = 1
        width = end - start
        res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
        return res.tolist()

    cooc_keys, cooc_values = zip(*cooc_odd_scores.items())
    new_cooc_odd_scores = dict(zip(cooc_keys, norm_arr(cooc_values)))

    return new_cooc_odd_scores

new_patient_cooc_odd_scores = data_norm(patient_cooc_odd_scores)

# %%
new_patient_cooc_odd_scores
# Out:
# {('assymetr', 'death'): 1.0,
#  ('sweat', 'ultrafiltr'): 1.0,
#  ('gabapentin', 'puff'): 1.0,
#  ('ctx', 'modifi'): 1.0,
#  ('historian', 'incent'): 1.0,
#  ('dnr', 'paperwork'): 0.6899936859810798,
#  ('cash', 'cdb'): 1.0,
#  ('echocardiogram', 'slice'): 0.0,
#  ('itchi', 'xii'): 1.0,
#  ('cyanot', 'laminectomi'): 1.0,
#  ('jewelri', 'wallet'): 0.6659303754175412,
#  ('dic', 'hive'): 0.0,
#  ('lc', 'sluggish'): 0.0,
#  ('gastrojejunostomi', 'homogen'): 1.0,
#  ('absorb', 'deterior'): 1.0,
#  ('epigastr', 'nifedipin'): 1.0,
#  ('fibrinogen', 'levoph'): 0.3507858298739296,
#  ('hctz', 'unstabl'): 1.0,
#  ('breakfast', 'ruptur'): 1.0,
#  ('dead', 'mortem'): 0.0,
#  ('life', 'trazodon'): 0.0,
#  ('caspofungin', 'metoclopramid'): 1.0,
#  ('dermat', 'herp'): 1.0,
#  ('breakfast', 'nitroglycerin'): 1.0,
#  ('natg', 'scar'): 0.0,
#  ('arrest', 'ffp'): 1.0,
#  ('bipolar', 'moan'): 1.0,
#  ('puff', 'unavail'): 1.0,
#  ('freeli', 'pharyng'): 1.0,
#  ('deliv', 'moan'): 1.0,
#  ('autoset', 'cocain'): 1.0,
#  ('fibrinogen', 'mellitu'): 1.0,
#  ('aricept', 'gown'): 0.0,
#  ('splint', 'uri'): 1.0,
#  ('bronchovascular', 'peribronchovascular'): 1.0,
#  ('solut', 'treatement'): 1.0,
#  ('oob', 'wallet'): 1.0,
#  ('cocain', 'ultram'): 1.0,
#  ('im', 'nocturn'): 1.0,
#  ('duski', 'wish'): 0.0,
#  ('duski', 'palli'): 0.0,
#  ('dnr', 'td'): 1.0,
#  ('incis', 'motor'): 1.0,
#  ('aaox', 'moan'): 1.0,
#  ('osa', 'pleasant'): 1.0,
#  ('dni', 'epigastr'): 1.0,
#  ('omeprazol', 'prilosec'): 1.0,
#  ('ctx', 'ferritin'): 1.0,
#  ('oncologist', 'palli'): 0.4960948642729987,
#  ('behavior', 'im'): 1.0,
#  ('scopalamin', 'seroquel'): 1.0,
#  ('bipolar', 'strictur'): 1.0,
#  ('binder', 'cramp'): 1.0,
#  ('metoclopramid', 'sarna'): 1.0,
#  ('dni', 'herp'): 1.0,
#  ('hive', 'itchi'): 1.0,
#  ('escal', 'mva'): 1.0,
#  ('bicarbon', 'hypercapnia'): 0.0,
#  ('historian', 'oder'): 0.0,
#  ('dietari', 'iddm'): 1.0,
#  ('laminectomi', 'mellitu'): 1.0,
#  ('asthma', 'lac'): 1.0,
#  ('chemic', 'lusb'): 0.0,
#  ('suprapub', 'thrive'): 1.0,
#  ('palli', 'xanax'): 1.0,
#  ('clonazepam', 'zyprexa'): 1.0,
#  ('chair', 'nectar'): 1.0,
#  ('arrang', 'dnr'): 0.0,
#  ('currenlti', 'trabecul'): 1.0,
#  ('fatti', 'occipit'): 1.0,
#  ('ambul', 'palli'): 0.0,
#  ('gabapentin', 'suprapub'): 1.0,
#  ('ctx', 'money'): 1.0,
#  ('hunger', 'mso'): 0.0,
#  ('azotemia', 'unasyn'): 1.0,
#  ('oligur', 'wish'): 0.0,
#  ('db', 'hive'): 1.0,
#  ('dead', 'dnr'): 0.0,
#  ('incent', 'tracheomalacia'): 1.0,
#  ('echocardiogram', 'omeprazol'): 1.0,
#  ('laryng', 'vallecula'): 1.0,
#  ('cocain', 'dni'): 1.0,
#  ('motor', 'soln'): 1.0,
#  ('acc', 'distanc'): 1.0,
#  ('declin', 'dietari'): 1.0,
#  ('gabapentin', 'laminectomi'): 1.0,
#  ('dnr', 'lat'): 1.0,
#  ('fatti', 'vagu'): 1.0,
#  ('ciwa', 'protrud'): 1.0,
#  ('arrest', 'artifici'): 0.0,
#  ('fatti', 'splint'): 1.0,
#  ('ambul', 'commod'): 1.0,
#  ('paperwork', 'wish'): 1.0,
#  ('asthma', 'unstabl'): 1.0,
#  ('chair', 'gentamycin'): 0.0,
#  ('behavior', 'nectar'): 1.0,
#  ('azotemia', 'crack'): 1.0,
#  ('colonoscopi', 'gabapentin'): 1.0,
#  ('oob', 'quietli'): 0.0,
#  ('ferritin', 'seriou'): 1.0,
#  ('bipolar', 'incis'): 1.0,
#  ('ffp', 'mean'): 0.0,
#  ('cmo', 'hypotherm'): 0.0,
#  ('prec', 'vagu'): 1.0,
#  ('epigastr', 'splint'): 1.0,
#  ('dizzi', 'dni'): 1.0,
#  ('stair', 'sweat'): 1.0,
#  ('ccn', 'levoph'): 0.0,
#  ('lpm', 'strictur'): 1.0,
#  ('dni', 'zyprexa'): 0.6216719860319377,
#  ('asthma', 'barium'): 1.0,
#  ('led', 'predict'): 1.0,
#  ('peribronchovascular', 'smooth'): 0.0,
#  ('azotemia', 'subq'): 1.0,
#  ('dnr', 'uri'): 1.0,
#  ('adam', 'icter'): 0.0,
#  ('breakfast', 'intiat'): 1.0,
#  ('metoclopramid', 'soln'): 1.0,
#  ('azotemia', 'phenylephrin'): 0.0,
#  ('breakfast', 'uffp'): 1.0,
#  ('hook', 'sluggish'): 1.0,
#  ('gait', 'thirst'): 1.0,
#  ('dnr', 'sluggishli'): 0.0,
#  ('hemothorax', 'levoph'): 0.0,
#  ('hilum', 'vagu'): 1.0,
#  ('hurt', 'profound'): 1.0,
#  ('ciwa', 'fibrinogen'): 1.0,
#  ('gait', 'religi'): 0.0,
#  ('anuria', 'mellitu'): 1.0,
#  ('preme', 'rigor'): 1.0,
#  ('asthma', 'nectar'): 1.0,
#  ('compani', 'prilosec'): 1.0,
#  ('depth', 'diaphoresi'): 1.0,
#  ('pleasant', 'venti'): 1.0,
#  ('grave', 'judgement'): 0.0,
#  ('commod', 'wallet'): 0.0,
#  ('agon', 'pea'): 0.0,
#  ('bipolar', 'ppd'): 1.0,
#  ('agon', 'venti'): 1.0,
#  ('life', 'pleasant'): 0.0,
#  ('intiat', 'jerk'): 0.0,
#  ('dietari', 'historian'): 1.0,
#  ('dnr', 'fliud'): 0.0,
#  ('cagluc', 'hung'): 0.0,
#  ('dnr', 'wish'): 0.5328955613041283,
#  ('nocturn', 'sweat'): 1.0,
#  ('abnl', 'dnr'): 1.0,
#  ('calculi', 'omeprazol'): 1.0,
#  ('opinion', 'prognosi'): 0.0,
#  ('ppd', 'schizophrenia'): 1.0,
#  ('para', 'young'): 1.0,
#  ('option', 'unstabl'): 0.0,
#  ('azotemia', 'puff'): 1.0,
#  ('chol', 'stg'): 0.0,
#  ('declin', 'trazodon'): 1.0,
#  ('ctx', 'mellitu'): 1.0,
#  ('ffp', 'lw'): 1.0,
#  ('burn', 'scar'): 1.0,
#  ('itchi', 'nitroglycerin'): 1.0,
#  ('ciwa', 'ntnd'): 1.0,
#  ('pharyng', 'vallecula'): 1.0,
#  ('fibrinogen', 'schizophrenia'): 1.0,
#  ('fu', 'pleasant'): 1.0,
#  ('mva', 'scopalamin'): 1.0,
#  ('occipit', 'zyprexa'): 1.0,
#  ('neosynephrin', 'unrel'): 0.0,
#  ('phlegm', 'stair'): 1.0,
#  ('hospic', 'mucinex'): 1.0,
#  ('ambien', 'scl'): 1.0,
#  ('clergi', 'paralyt'): 0.0,
#  ('calvarium', 'slice'): 1.0,
#  ('fatti', 'habitu'): 1.0,
#  ('bottl', 'strictur'): 1.0,
#  ('assymetr', 'hive'): 1.0,
#  ('hive', 'wish'): 1.0,
#  ('cmo', 'vasopressin'): 0.0,
#  ('levoph', 'sibl'): 0.0,
#  ('hive', 'palli'): 0.0,
#  ('opiat', 'unasyn'): 1.0,
#  ('ffp', 'wish'): 1.0,
#  ('mso', 'vasoconstrict'): 0.0,
#  ('gabapentin', 'jerk'): 1.0,
#  ('mrg', 'platelet'): 1.0,
#  ('azotemia', 'prilosec'): 0.0,
#  ('epidur', 'ofm'): 1.0,
#  ('ambien', 'hive'): 1.0,
#  ('ntnd', 'thiamin'): 1.0,
#  ('cash', 'chair'): 1.0,
#  ('dyslipidemia', 'gastrojejunostomi'): 1.0,
#  ('dnr', 'lw'): 1.0,
#  ('declin', 'vasopressor'): 0.0,
#  ('intent', 'unasyn'): 1.0,
#  ('hypercapn', 'neo'): 1.0,
#  ('historian', 'money'): 1.0,
#  ('ferrou', 'omeprazol'): 1.0,
#  ('calculi', 'trazodon'): 1.0,
#  ('dermat', 'osa'): 1.0,
#  ('argatroban', 'norepinephrin'): 0.0,
#  ('cpr', 'icter'): 0.0,
#  ('rehabilit', 'rhinorrhea'): 1.0,
#  ('aox', 'solut'): 1.0,
#  ('hsq', 'venti'): 1.0,
#  ('nectar', 'quiac'): 1.0,
#  ('dizzi', 'unstabl'): 1.0,
#  ('bromid', 'dizzi'): 1.0,
#  ('scar', 'wish'): 1.0,
#  ('abruptli', 'levoph'): 0.0,
#  ('rhinorrhea', 'sweat'): 1.0,
#  ('colonoscopi', 'dnr'): 1.0,
#  ('lighthead', 'sweat'): 1.0,
#  ('ba', 'hypothermia'): 1.0,
#  ('laryng', 'lat'): 1.0,
#  ('bottl', 'qam'): 1.0,
#  ('mva', 'td'): 1.0,
#  ('arrest', 'dnr'): 0.0,
#  ('prilosec', 'robitussin'): 1.0,
#  ('deliv', 'soln'): 1.0,
#  ('pastor', 'trazodon'): 0.0,
#  ('fatti', 'homogen'): 1.0,
#  ('chair', 'money'): 1.0,
#  ('azotemia', 'bottl'): 1.0,
#  ('clonidin', 'thrive'): 1.0,
#  ('hsq', 'sweat'): 1.0,
#  ('hive', 'lusb'): 1.0,
#  ('cocain', 'osa'): 1.0,
#  ('historian', 'ppd'): 1.0,
#  ('osa', 'rhinorrhea'): 1.0,
#  ('qtc', 'rm'): 1.0,
#  ('anaphylaxi', 'ferritin'): 1.0,
#  ('aox', 'xii'): 1.0,
#  ('asystol', 'bank'): 0.0,
#  ('cisatracurium', 'levoph'): 0.0,
#  ('hive', 'sarna'): 1.0,
#  ('massag', 'refractori'): 1.0,
#  ('arrest', 'pronounc'): 0.0,
#  ('emper', 'respitori'): 1.0,
#  ('clonazepam', 'gum'): 1.0,
#  ('declin', 'hunger'): 0.0,
#  ('escal', 'wish'): 0.0,
#  ('dyslipidemia', 'metoclopramid'): 1.0,
#  ('declin', 'gait'): 1.0,
#  ('oob', 'rigor'): 1.0,
#  ('chair', 'sooner'): 1.0,
#  ('burn', 'tran'): 1.0,
#  ('dnr', 'nephrolog'): 0.40956706442769103,
#  ('hospic', 'synthet'): 1.0,
#  ('agonist', 'asthma'): 1.0,
#  ('fdp', 'petechia'): 0.0,
#  ('fatti', 'protrud'): 0.0,
#  ('ferrou', 'retic'): 1.0,
#  ('ppd', 'vagu'): 1.0,
#  ('omeprazol', 'sibl'): 1.0,
#  ('chair', 'predict'): 1.0,
#  ('cash', 'oob'): 1.0,
#  ('pneumococc', 'qam'): 1.0,
#  ('sensat', 'signatur'): 1.0,
#  ('declin', 'sweat'): 1.0,
#  ('hypothermia', 'nifedipin'): 1.0,
#  ('cmo', 'prognosi'): 0.0,
#  ('bipolar', 'historian'): 1.0,
#  ('declin', 'ferritin'): 1.0,
#  ('syncop', 'young'): 1.0,
#  ('bank', 'dni'): 1.0,
#  ('levoph', 'para'): 1.0,
#  ('chemic', 'exophyt'): 0.0,
#  ('mrcp', 'wma'): 0.0,
#  ('lpm', 'meropenam'): 0.0,
#  ('dni', 'lotion'): 0.0,
#  ('mortem', 'mso'): 0.0,
#  ('crrt', 'unstabl'): 0.0,
#  ('cellcept', 'cocain'): 1.0,
#  ('asthma', 'young'): 1.0,
#  ('chair', 'romi'): 1.0,
#  ('compani', 'gastriti'): 1.0,
#  ('chair', 'platelet'): 1.0,
#  ('gum', 'impli'): 1.0,
#  ('sibl', 'xl'): 1.0,
#  ('dni', 'tran'): 1.0,
#  ('aliv', 'paperwork'): 1.0,
#  ('contractur', 'dnr'): 0.5500560933045909,
#  ('phenylephrin', 'vasopressin'): 0.0,
#  ('gastriti', 'soln'): 1.0,
#  ('omeprazol', 'xii'): 0.5292841127058171,
#  ('autopeep', 'bicarbon'): 0.0,
#  ('arrest', 'chair'): 1.0,
#  ('bair', 'chair'): 0.0,
#  ('levoph', 'trazodon'): 1.0,
#  ('hilum', 'unenhanc'): 1.0,
#  ('phasic', 'spectral'): 1.0,
#  ('lat', 'lax'): 1.0,
#  ('stitch', 'weekli'): 1.0,
#  ('absorb', 'asthma'): 1.0,
#  ('azotemia', 'ciwa'): 1.0,
#  ('mso', 'unstabl'): 0.0,
#  ('cvvh', 'permiss'): 0.0,
#  ('dnr', 'funer'): 1.0,
#  ('postop', 'tremul'): 1.0,
#  ('lotion', 'oob'): 0.28116114168121026,
#  ('asthma', 'quinolon'): 1.0,
#  ('diaphoresi', 'osa'): 1.0,
#  ('lat', 'pneumothorac'): 0.5500560933045909,
#  ('hypothermia', 'paralyt'): 0.0,
#  ('carvedilol', 'thirst'): 1.0,
#  ('flight', 'pleasantli'): 1.0,
#  ('barium', 'freeli'): 1.0,
#  ('recalibr', 'video'): 1.0,
#  ('commod', 'foci'): 1.0,
#  ('ambien', 'dni'): 1.0,
#  ('nice', 'quinton'): 1.0,
#  ('cdb', 'wallet'): 1.0,
#  ('spill', 'video'): 1.0,
#  ('lift', 'readmit'): 1.0,
#  ('bicarbon', 'hypothermia'): 0.0,
#  ('effac', 'subdur'): 1.0,
#  ('declar', 'deterior'): 0.0,
#  ('acc', 'im'): 1.0,
#  ('dermat', 'fibrinogen'): 1.0,
#  ('olanzapin', 'xanax'): 1.0,
#  ('aricept', 'sundown'): 0.0,
#  ('bipolar', 'habitu'): 1.0,
#  ('norepinephrin', 'sluggishli'): 0.0,
#  ('dni', 'levoph'): 0.4600097812421181,
#  ('incent', 'syst'): 1.0,
#  ('omeprazol', 'rhinorrhea'): 0.5292841127058171,
#  ('expir', 'ipf'): 1.0,
#  ('contd', 'refractori'): 1.0,
#  ('hospic', 'levoph'): 0.0,
#  ('cefapim', 'pea'): 1.0,
#  ('subq', 'vp'): 1.0,
#  ('aliv', 'robitussin'): 1.0,
#  ('freeli', 'gastrojejunostomi'): 1.0,
#  ('cpr', 'suport'): 0.0,
#  ('levoph', 'modifi'): 1.0,
#  ('phlegm', 'thiamin'): 1.0,
#  ('commod', 'msicu'): 1.0,
#  ('thiamin', 'xii'): 1.0,
#  ('duski', 'escal'): 0.0,
#  ('bicarbon', 'permiss'): 0.0,
#  ('bottl', 'syncop'): 1.0,
#  ('strictur', 'trabecul'): 1.0,
#  ('gabapentin', 'pod'): 1.0,
#  ('hhn', 'lpm'): 1.0,
#  ('chair', 'levoph'): 1.0,
#  ('epigastr', 'fibrinogen'): 1.0,
#  ('agon', 'cmo'): 0.0,
#  ('parastern', 'subcost'): 1.0,
#  ('dizzi', 'historian'): 0.0,
#  ('aox', 'pleasant'): 1.0,
#  ('caspofungin', 'fungemia'): 1.0,
#  ('habitu', 'trabecul'): 1.0,
#  ('modifi', 'omeprazol'): 1.0,
#  ('autoset', 'clonidin'): 1.0,
#  ('dnr', 'tranfer'): 1.0,
#  ('dermat', 'uri'): 1.0,
#  ('bottl', 'historian'): 1.0,
#  ('hive', 'lymphangit'): 1.0,
#  ('contractur', 'oligur'): 0.44994390669540907,
#  ('para', 'slice'): 1.0,
#  ('distanc', 'romi'): 1.0,
#  ('puff', 'xii'): 1.0,
#  ('hilum', 'pronounc'): 1.0,
#  ('chb', 'oob'): 1.0,
#  ('ambul', 'xl'): 1.0,
#  ('phenylephrin', 'prognosi'): 0.0,
#  ('arrest', 'osa'): 1.0,
#  ('asthma', 'lat'): 1.0,
#  ('rhochor', 'scar'): 1.0,
#  ('absorb', 'quinolon'): 1.0,
#  ('omeprazol', 'video'): 1.0,
#  ('dopamin', 'neo'): 0.6789811080628495,
#  ('paperwork', 'rhinorrhea'): 1.0,
#  ('hypotherm', 'levoph'): 0.5904329355723089,
#  ('breakfast', 'hsq'): 1.0,
#  ('cash', 'money'): 0.6556705106579064,
#  ('lusb', 'xii'): 1.0,
#  ('hctz', 'sensat'): 1.0,
#  ('dni', 'quietli'): 0.0,
#  ('mtg', 'palli'): 0.0,
#  ('qam', 'rhochor'): 1.0,
#  ('cocain', 'dnr'): 1.0,
#  ('dex', 'dopamin'): 1.0,
#  ('oob', 'tcdb'): 1.0,
#  ('mood', 'nocturn'): 1.0,
#  ('arrest', 'autopeep'): 0.0,
#  ('cyanot', 'gvhd'): 0.0,
#  ('asthma', 'rhinorrhea'): 1.0,
#  ('lat', 'pericard'): 1.0,
#  ('dni', 'occipit'): 1.0,
#  ('bair', 'sluggish'): 0.0,
#  ('platelet', 'young'): 1.0,
#  ('db', 'iddm'): 1.0,
#  ('struggl', 'wish'): 0.0,
#  ('asthma', 'romi'): 1.0,
#  ('morbid', 'osa'): 1.0,
#  ('cocain', 'ppd'): 1.0,
#  ('bronchovascular', 'fatti'): 1.0,
#  ('declin', 'doen'): 0.0,
#  ('bicarbon', 'diaphoresi'): 1.0,
#  ('ambul', 'life'): 1.0,
#  ('exophyt', 'fc'): 0.0,
#  ('ipf', 'pcv'): 1.0,
#  ('lighthead', 'schizophrenia'): 1.0,
#  ('omeprazol', 'zyprexa'): 1.0,
#  ('hook', 'prognosi'): 1.0,
#  ('db', 'wallet'): 1.0,
#  ('pronounc', 'sacrament'): 0.0,
#  ('levoph', 'palli'): 0.0,
#  ('cellcept', 'lpm'): 1.0,
#  ('dnr', 'quietli'): 0.0,
#  ('cash', 'palli'): 1.0,
#  ('ambien', 'bromid'): 1.0,
#  ('ipf', 'occipit'): 0.5,
#  ('hive', 'nocturn'): 1.0,
#  ('conc', 'omeprazol'): 1.0,
#  ('goc', 'neosynephrin'): 0.0,
#  ('bicarbon', 'omeprazol'): 1.0,
#  ('asthma', 'db'): 1.0,
#  ('ppd', 'xl'): 1.0,
#  ('asthma', 'ctx'): 1.0,
#  ('bicarbon', 'readmit'): 1.0,
#  ('captopril', 'venti'): 1.0,
#  ('dni', 'refractori'): 1.0,
#  ('adam', 'neo'): 0.0,
#  ('ctx', 'signatur'): 1.0,
#  ('hospic', 'rigor'): 1.0,
#  ('adenocarcinoma', 'readmit'): 1.0,
#  ('banana', 'oob'): 1.0,
#  ('chair', 'cyanot'): 0.0,
#  ('aox', 'rememb'): 1.0,
#  ('levoph', 'opiat'): 1.0,
#  ('contractur', 'pharmacolog'): 1.0,
#  ('aaox', 'deliv'): 1.0,
#  ('sensat', 'unstabl'): 1.0,
#  ('asthma', 'fatti'): 1.0,
#  ('echocardiogram', 'fatti'): 1.0,
#  ('esld', 'venti'): 1.0,
#  ('adam', 'cpr'): 0.0,
#  ('gastriti', 'omeprazol'): 1.0,
#  ('nicotin', 'pleasant'): 1.0,
#  ('declin', 'oligur'): 0.0,
#  ('plate', 'splint'): 1.0,
#  ('ferritin', 'ferrou'): 1.0,
#  ('dni', 'scab'): 0.5292841127058171,
#  ('dic', 'hypotherm'): 0.0,
#  ('deterior', 'sluggish'): 1.0,
#  ('dni', 'dyslipidemia'): 1.0,
#  ('bottl', 'rememb'): 1.0,
#  ('hive', 'wallet'): 1.0,
#  ('contractur', 'hypothermia'): 0.0,
#  ('homogen', 'slice'): 1.0,
#  ('clonidin', 'dz'): 1.0,
#  ('lotion', 'sarna'): 1.0,
#  ('flight', 'nitroglycerin'): 1.0,
#  ('dopamin', 'xanax'): 1.0,
#  ('dnr', 'gc'): 1.0,
#  ('cmo', 'expir'): 0.0,
#  ('flight', 'xii'): 1.0,
#  ('option', 'readdress'): 0.0,
#  ('carvedilol', 'ctx'): 1.0,
#  ('anur', 'judgement'): 0.0,
#  ('mrg', 'readmit'): 1.0,
#  ('acidot', 'agon'): 0.0,
#  ('dnr', 'mucinex'): 1.0,
#  ('dni', 'thk'): 1.0,
#  ('ambul', 'fungemia'): 0.0,
#  ('arrest', 'passi'): 1.0,
#  ('ctx', 'db'): 1.0,
#  ('aox', 'ba'): 1.0,
#  ('ambul', 'levoph'): 1.0,
#  ('bipolar', 'dni'): 0.33510063360139086,
#  ('asthma', 'lusb'): 1.0,
#  ('death', 'trazodon'): 1.0,
#  ('gasp', 'oder'): 0.0,
#  ('gabapentin', 'jewelri'): 1.0,
#  ('dnr', 'phenylephrin'): 0.0,
#  ('dni', 'option'): 0.3783280139680622,
#  ('motor', 'ppd'): 1.0,
#  ('cmo', 'life'): 0.0,
#  ('lc', 'viabl'): 0.0,
#  ('dizzi', 'gastriti'): 1.0,
#  ('angiogram', 'tran'): 1.0,
#  ('ctx', 'neo'): 1.0,
#  ('barium', 'stitch'): 1.0,
#  ('oncologist', 'thrive'): 1.0,
#  ('cellcept', 'gvhd'): 0.0,
#  ('bair', 'paperwork'): 0.0,
#  ('moan', 'mso'): 0.0,
#  ('asthma', 'iddm'): 1.0,
#  ('fungemia', 'twitch'): 0.0,
#  ('norepinephrin', 'readdress'): 0.0,
#  ('aricept', 'signatur'): 0.0,
#  ('asthma', 'dizzi'): 1.0,
#  ('pivot', 'wallet'): 0.0,
#  ('dnr', 'option'): 0.3783280139680622,
#  ('dni', 'phenylephrin'): 0.0,
#  ('dni', 'xl'): 1.0,
#  ('pea', 'rhinorrhea'): 1.0,
#  ('escal', 'ultram'): 1.0,
#  ('nectar', 'videofluoroscopi'): 1.0,
#  ('echocardiogram', 'tdi'): 1.0,
#  ('ferrou', 'trazodon'): 1.0,
#  ('oob', 'rusti'): 1.0,
#  ('dietari', 'hugger'): 1.0,
#  ('neo', 'platelet'): 0.0,
#  ('hospic', 'wallet'): 1.0,
#  ('dnr', 'laryng'): 0.5793162261246866,
#  ('oob', 'xl'): 1.0,
#  ('dnr', 'sarna'): 1.0,
#  ('bottl', 'bromid'): 1.0,
#  ('commod', 'xopenex'): 1.0,
#  ('nectar', 'silent'): 1.0,
#  ('barium', 'laryng'): 1.0,
#  ('cmo', 'nifedipin'): 0.0,
#  ('agon', 'neosynephrin'): 0.0,
#  ('expir', 'neo'): 0.0,
#  ('asthma', 'pea'): 1.0,
#  ('sluggish', 'venti'): 1.0,
#  ('omeprazol', 'pneumococc'): 1.0,
#  ('epigastr', 'unstabl'): 1.0,
#  ('ciwa', 'qam'): 1.0,
#  ('paperwork', 'vasopressor'): 0.0,
#  ('hemangioma', 'plerual'): 1.0,
#  ('mtg', 'paralyt'): 0.0,
#  ('dni', 'ipf'): 0.47071588729418296,
#  ('mso', 'rememb'): 1.0,
#  ('declin', 'ppn'): 1.0,
#  ('incent', 'osa'): 1.0,
#  ('ambul', 'sarna'): 1.0,
#  ('pharmacolog', 'scar'): 1.0,
#  ('icter', 'weekli'): 1.0,
#  ('captopril', 'cpr'): 0.0,
#  ('ambien', 'klonopin'): 1.0,
#  ('asthma', 'habitu'): 1.0,
#  ('clonidin', 'proph'): 1.0,
#  ('fatti', 'hsq'): 1.0,
#  ('life', 'peac'): 0.0,
#  ('bicarbon', 'bromid'): 1.0,
#  ('imbal', 'strictur'): 1.0,
#  ('levoph', 'ultram'): 1.0,
#  ('anyway', 'weekli'): 1.0,
#  ('burn', 'levoph'): 1.0,
#  ('paco', 'pleasant'): 1.0,
#  ('incis', 'levoph'): 1.0,
#  ('ctx', 'seroquel'): 1.0,
#  ('mortem', 'sluggish'): 0.0,
#  ('ipf', 'nectar'): 1.0,
#  ('norepinephrin', 'pcv'): 0.0,
#  ('omeprazol', 'retic'): 1.0,
#  ('arrest', 'oncologist'): 1.0,
#  ('reveiw', 'wish'): 0.0,
#  ('neo', 'phenylephrin'): 0.4821702791231874,
#  ('compani', 'dizzi'): 1.0,
#  ('asthma', 'unavail'): 1.0,
#  ('ambien', 'hctz'): 1.0,
#  ('moan', 'zyprexa'): 1.0,
#  ('behavior', 'flight'): 1.0,
#  ('anur', 'ggt'): 0.0,
#  ('dni', 'pca'): 1.0,
#  ('levoph', 'neosynephrin'): 0.0,
#  ('opiat', 'thiamin'): 1.0,
#  ('preme', 'zero'): 1.0,
#  ('db', 'yel'): 1.0,
#  ('epigastr', 'romi'): 1.0,
#  ('angioplasti', 'dnr'): 1.0,
#  ('contractur', 'scar'): 1.0,
#  ('absorb', 'uri'): 1.0,
#  ('hemangioma', 'mjmgb'): 1.0,
#  ('pose', 'vasoconstrict'): 0.0,
#  ('ultram', 'unstabl'): 1.0,
#  ('ba', 'omeprazol'): 1.0,
#  ('ambul', 'seroquel'): 1.0,
#  ('ba', 'phlegm'): 1.0,
#  ('aliv', 'rehabilit'): 1.0,
#  ('dead', 'morgu'): 0.0,
#  ('calculi', 'rehabilit'): 1.0,
#  ('aricept', 'jewelri'): 0.0,
#  ('laminectomi', 'osa'): 1.0,
#  ('cyanot', 'hive'): 1.0,
#  ('synthet', 'wma'): 0.0,
#  ('ambul', 'twitch'): 0.0,
#  ('commod', 'unasyn'): 1.0,
#  ('fibrinogen', 'futil'): 0.0,
#  ('dni', 'lpm'): 0.0,
#  ('habitu', 'unstabl'): 1.0,
#  ('purpl', 'ultram'): 1.0,
#  ('foci', 'subdur'): 1.0,
#  ('angioplasti', 'diaphoresi'): 1.0,
#  ('nectar', 'seroquel'): 1.0,
#  ('slice', 'vertebra'): 1.0,
#  ('cyanot', 'oob'): 0.0,
#  ('gadolinium', 'occipit'): 1.0,
#  ('chair', 'hugger'): 0.0,
#  ('calculi', 'suprapub'): 1.0,
#  ('lusb', 'romi'): 1.0,
#  ('cash', 'ctx'): 1.0,
#  ('para', 'sweat'): 1.0,
#  ('arrest', 'recruit'): 1.0,
#  ('phenylephrin', 'sluggish'): 0.0,
#  ('commod', 'pose'): 1.0,
#  ('epigastr', 'sensat'): 1.0,
#  ('ciwa', 'motor'): 1.0,
#  ('forth', 'pleasant'): 1.0,
#  ('death', 'mso'): 0.0,
#  ('bronchovascular', 'unenhanc'): 1.0,
#  ('panic', 'sensat'): 1.0,
#  ('clonidin', 'mellitu'): 1.0,
#  ('cmo', 'colonoscopi'): 1.0,
#  ('azotemia', 'chemic'): 1.0,
#  ('dnr', 'unasyn'): 1.0,
#  ('mean', 'phenylephrin'): 1.0,
#  ('neo', 'rememb'): 1.0,
#  ('dni', 'vp'): 1.0,
#  ('dizzi', 'jewelri'): 1.0,
#  ('mellitu', 'romi'): 1.0,
#  ('cvvh', 'phenylephrin'): 0.0,
#  ('acc', 'ctx'): 1.0,
#  ('anur', 'prilosec'): 0.0,
#  ('robitussin', 'sweat'): 1.0,
#  ('hsq', 'phlegm'): 1.0,
#  ('echocardiogram', 'transmitr'): 1.0,
#  ('metoclopramid', 'omeprazol'): 1.0,
#  ('aox', 'ffp'): 1.0,
#  ('chair', 'zyprexa'): 1.0,
#  ('mellitu', 'paralyt'): 1.0,
#  ('strictur', 'zyprexa'): 1.0,
#  ('ambul', 'eyelid'): 0.0,
#  ('asthma', 'para'): 1.0,
#  ('pleasant', 'qam'): 1.0,
#  ('occupi', 'rehabilit'): 1.0,
#  ('deterior', 'gc'): 1.0,
#  ('hctz', 'mellitu'): 1.0,
#  ('chair', 'qtc'): 1.0,
#  ('hctz', 'thiamin'): 1.0,
#  ('cash', 'crack'): 1.0,
#  ('platelet', 'prognosi'): 1.0,
#  ('dic', 'zoloft'): 1.0,
#  ('hilum', 'vertebra'): 0.0,
#  ('cmo', 'mso'): 0.0,
#  ('nonlabor', 'oob'): 1.0,
#  ('hilum', 'peribronchovascular'): 0.5,
#  ('intiat', 'levoph'): 0.44994390669540907,
#  ('fatti', 'nephrogram'): 1.0,
#  ('expir', 'vasopressin'): 0.0,
#  ('gasp', 'hospic'): 0.0,
#  ('dni', 'ntnd'): 0.602586982591368,
#  ('asthma', 'director'): 1.0,
#  ('commod', 'diaper'): 1.0,
#  ('ferrou', 'xii'): 1.0,
#  ('binder', 'dnr'): 1.0,
#  ('palli', 'scopalamin'): 0.0,
#  ('criticar', 'pinpoint'): 0.0,
#  ('dizzi', 'schizophrenia'): 1.0,
#  ('compani', 'dni'): 1.0,
#  ('death', 'im'): 0.47071588729418296,
#  ('reguard', 'simpli'): 1.0,
#  ('neosynephrin', 'wish'): 0.0,
#  ('requr', 'rm'): 1.0,
#  ('bell', 'option'): 1.0,
#  ('gait', 'im'): 1.0,
#  ('fdp', 'ggt'): 0.0,
#  ('declin', 'fliud'): 0.0,
#  ('dic', 'vasopressor'): 0.0,
#  ('cash', 'wallet'): 0.6468703450700892,
#  ('declin', 'ferrou'): 1.0,
#  ('cagluc', 'neosynephrin'): 0.0,
#  ('autopsi', 'prognosi'): 0.0,
#  ('anaphylaxi', 'dyslipidemia'): 1.0,
#  ('osa', 'seat'): 1.0,
#  ('chair', 'sundown'): 0.0,
#  ('aaox', 'commod'): 1.0,
#  ('platelet', 'profound'): 1.0,
#  ('coach', 'gait'): 1.0,
#  ('lat', 'occupi'): 1.0,
#  ('dic', 'ferritin'): 1.0,
#  ('director', 'venti'): 1.0,
#  ('dnr', 'friction'): 1.0,
#  ('osa', 'ppd'): 1.0,
#  ('^th', 'commod'): 1.0,
#  ('cocain', 'cramp'): 1.0,
#  ('barium', 'video'): 1.0,
#  ('bronchovascular', 'hilum'): 1.0,
#  ('dni', 'fibrinogen'): 0.5793162261246866,
#  ('moan', 'rabbi'): 0.0,
#  ('foci', 'peribronchovascular'): 0.5,
#  ('bicarbon', 'wma'): 0.0,
#  ('lac', 'vertebra'): 1.0,
#  ('cdb', 'levoph'): 1.0,
#  ('dnr', 'shorter'): 1.0,
#  ('myeloma', 'omeprazol'): 0.5404153697211024,
#  ('acidot', 'neo'): 0.0,
#  ('heroic', 'readdress'): 0.0,
#  ('habitu', 'subcost'): 1.0,
#  ('cocain', 'ferrou'): 1.0,
#  ('subcost', 'unavail'): 1.0,
#  ('nahco', 'vasopressin'): 0.0,
#  ('duski', 'sluggish'): 1.0,
#  ('arrest', 'life'): 0.0,
#  ('captopril', 'prilosec'): 1.0,
#  ('morgu', 'mso'): 0.0,
#  ('mrg', 'zoloft'): 1.0,
#  ('ba', 'rhinorrhea'): 1.0,
#  ('mellitu', 'oob'): 1.0,
#  ('dyslipidemia', 'soln'): 1.0,
#  ('cefapim', 'kerlix'): 1.0,
#  ('ba', 'seroquel'): 1.0,
#  ('deterior', 'escal'): 0.0,
#  ('grave', 'mottl'): 0.0,
#  ('furhter', 'rescan'): 1.0,
#  ('chair', 'cramp'): 1.0,
#  ('ambien', 'pharmacolog'): 1.0,
#  ('romi', 'young'): 1.0,
#  ('rhinorrhea', 'stair'): 1.0,
#  ('aox', 'phenylephrin'): 1.0,
#  ('occupi', 'recruit'): 1.0,
#  ('aricept', 'romi'): 1.0,
#  ('deliv', 'lymphangit'): 1.0,
#  ('ambul', 'syncop'): 1.0,
#  ('cisatracurium', 'dopamin'): 0.0,
#  ('dopamin', 'scar'): 1.0,
#  ('dnr', 'omeprazol'): 0.6476466717455208,
#  ('incent', 'nonrebreath'): 1.0,
#  ('declin', 'im'): 1.0,
#  ('ppd', 'puff'): 1.0,
#  ('pleasant', 'strictur'): 1.0,
#  ('endplat', 'gadolinium'): 1.0,
#  ('ba', 'diaphoresi'): 1.0,
#  ('cpr', 'cvvhd'): 1.0,
#  ('clinician', 'im'): 1.0,
#  ('oob', 'thk'): 1.0,
#  ('aox', 'omeprazol'): 1.0,
#  ('hypercapnia', 'pea'): 0.0,
#  ('levoph', 'pitressin'): 0.0,
#  ('ciwa', 'thiamin'): 1.0,
#  ('captopril', 'lpm'): 1.0,
#  ('fibrinogen', 'subq'): 1.0,
#  ('arrest', 'carvedilol'): 1.0,
#  ('lighthead', 'omeprazol'): 1.0,
#  ('ferritin', 'mellitu'): 1.0,
#  ('friction', 'unobtain'): 1.0,
#  ('liw', 'vasoconstrict'): 0.0,
#  ('sundown', 'zyprexa'): 1.0,
#  ('dopamin', 'twitch'): 0.0,
#  ('bronchovascular', 'ctx'): 1.0,
#  ('bell', 'lpm'): 1.0,
#  ('osa', 'silent'): 1.0,
#  ('dnr', 'nicotin'): 1.0,
#  ('clonidin', 'gastriti'): 1.0,
#  ('exophyt', 'lusb'): 0.0,
#  ('barium', 'motor'): 1.0,
#  ('judgement', 'mso'): 0.0,
#  ('asthma', 'bipolar'): 1.0,
#  ('dni', 'gvhd'): 1.0,
#  ('dni', 'dobutamin'): 1.0,
#  ('lotion', 'neo'): 1.0,
#  ('ctx', 'hilum'): 1.0,
#  ('qam', 'vagu'): 1.0,
#  ('ferritin', 'platelet'): 1.0,
#  ('cyanot', 'neosynephrin'): 0.0,
#  ('barium', 'osa'): 1.0,
#  ('argatroban', 'cvvh'): 0.0,
#  ('adam', 'duski'): 0.0,
#  ('conc', 'hospic'): 1.0,
#  ('ferritin', 'hive'): 1.0,
#  ('acc', 'romi'): 1.0,
#  ('caspofungin', 'fibrinogen'): 1.0,
#  ('seriou', 'wish'): 0.0,
#  ('eg', 'pharyng'): 1.0,
#  ('fatti', 'spectral'): 0.0,
#  ('nocturn', 'trazodon'): 1.0,
#  ('aaox', 'lac'): 1.0,
#  ('ntnd', 'synthet'): 0.0,
#  ('calculi', 'habitu'): 1.0,
#  ('aprv', 'gvhd'): 0.0,
#  ('cellcept', 'option'): 1.0,
#  ('cracker', 'spiromet'): 0.0,
#  ('articul', 'splint'): 1.0,
#  ('assymetr', 'pronounc'): 0.0,
#  ('barium', 'hsq'): 1.0,
#  ('platelet', 'scar'): 1.0,
#  ('gadolinium', 'impli'): 1.0,
#  ('dnr', 'platelet'): 0.41831869588332016,
#  ('grave', 'prognosi'): 0.44994390669540907,
#  ('declin', 'mso'): 0.0,
#  ('nitroglycerin', 'pleasant'): 1.0,
#  ('cvvhd', 'hugger'): 0.0,
#  ('bipolar', 'klonopin'): 1.0,
#  ('declin', 'levoph'): 0.31529791710476945,
#  ('pose', 'unstabl'): 0.0,
#  ('dnr', 'paralyt'): 0.19366712475069608,
#  ('osa', 'robitussin'): 0.0,
#  ('seroquel', 'vp'): 1.0,
#  ('dic', 'hypothermia'): 0.0,
#  ('flight', 'gvhd'): 1.0,
#  ('arrest', 'escal'): 0.0,
#  ('ciwa', 'declin'): 1.0,
#  ('bicarbon', 'fibrinogen'): 0.0,
#  ('cg', 'levoph'): 0.0,
#  ('bromid', 'dyslipidemia'): 1.0,
#  ('rehabilit', 'suprapub'): 1.0,
#  ('levoph', 'life'): 1.0,
#  ('neutral', 'scar'): 1.0,
#  ('dni', 'synthet'): 0.0,
#  ('bank', 'gabapentin'): 1.0,
#  ('ppd', 'suprapub'): 1.0,
#  ('bicarbon', 'oligur'): 0.0,
#  ('hospic', 'oder'): 0.0,
#  ('life', 'mean'): 1.0,
#  ('epidur', 'fibrinogen'): 1.0,
#  ('levoph', 'rpr'): 1.0,
#  ('chip', 'hook'): 1.0,
#  ('ambien', 'unasyn'): 1.0,
#  ('asthma', 'historian'): 1.0,
#  ('historian', 'opiat'): 1.0,
#  ('ctx', 'dz'): 1.0,
#  ('ciwa', 'tubular'): 1.0,
#  ('coach', 'soln'): 1.0,
#  ('declin', 'retic'): 1.0,
#  ('dnr', 'unstabl'): 0.0,
#  ('anaphylaxi', 'barium'): 1.0,
#  ('myeloma', 'rhinorrhea'): 0.0,
#  ('assymetr', 'unenhanc'): 0.0,
#  ('gurgl', 'levoph'): 1.0,
#  ('captopril', 'predict'): 1.0,
#  ('muddi', 'uri'): 1.0,
#  ('anur', 'hypercapn'): 0.0,
#  ('chair', 'neo'): 1.0,
#  ('crack', 'ultram'): 1.0,
#  ('readmit', 'subdur'): 1.0,
#  ('rememb', 'uri'): 1.0,
#  ('abnl', 'clinician'): 1.0,
#  ('dni', 'syncop'): 1.0,
#  ('anuria', 'crrt'): 0.0,
#  ('pleasant', 'redirect'): 0.0,
#  ('bottl', 'unavail'): 1.0,
#  ('dermat', 'incis'): 0.0,
#  ('anaphylaxi', 'imbal'): 1.0,
#  ('barium', 'thrive'): 1.0,
#  ('chair', 'msicu'): 1.0,
#  ('dni', 'neo'): 0.44496347461959307,
#  ('gait', 'rm'): 1.0,
#  ('mood', 'profound'): 1.0,
#  ('dni', 'mottl'): 0.0,
#  ('dnr', 'ffp'): 0.42068377387531336,
#  ('oob', 'sooner'): 1.0,
#  ('mood', 'suprapub'): 1.0,
#  ('ciwa', 'palli'): 1.0,
#  ('ggt', 'petechia'): 0.0,
#  ('intiat', 'neosynephrin'): 0.0,
#  ('cocain', 'ultrafiltr'): 1.0,
#  ('ctx', 'metoclopramid'): 1.0,
#  ('chair', 'jewelri'): 1.0,
#  ('pastor', 'pea'): 0.0,
#  ('paperwork', 'robitussin'): 1.0,
#  ('mucinex', 'omeprazol'): 1.0,
#  ('ntnd', 'prilosec'): 1.0,
#  ('captopril', 'twitch'): 1.0,
#  ('dz', 'phenylephrin'): 1.0,
#  ('sluggish', 'viabl'): 0.0,
#  ('bill', 'dyslipidemia'): 1.0,
#  ('bromid', 'lac'): 1.0,
#  ('ctx', 'dyslipidemia'): 1.0,
#  ('hospic', 'ppn'): 1.0,
#  ('cocain', 'phlegm'): 1.0,
#  ('cloth', 'dni'): 0.5,
#  ('pinpoint', "tf'ing"): 1.0,
#  ('hypotherm', 'scopalamin'): 0.0,
#  ('mso', 'syst'): 1.0,
#  ('azotemia', 'ctx'): 1.0,
#  ('cpr', 'dobutamin'): 0.0,
#  ('mottl', 'mso'): 0.0,
#  ('dysynchron', 'ffp'): 0.0,
#  ('aaox', 'foci'): 1.0,
#  ('bow', 'ipf'): 1.0,
#  ('dnr', 'strictur'): 1.0,
#  ('hctz', 'icter'): 1.0,
#  ('hypotherm', 'wish'): 0.0,
#  ('distanc', 'young'): 1.0,
#  ('chip', 'dnr'): 1.0,
#  ('dni', 'forc'): 0.0,
#  ('aricept', 'syncop'): 1.0,
#  ('ctx', 'quinolon'): 1.0,
#  ('adenocarcinoma', 'vertebra'): 1.0,
#  ('aricept', 'ruptur'): 1.0,
#  ('breakfast', 'stitch'): 1.0,
#  ('harm', 'oob'): 1.0,
#  ('foci', 'pronounc'): 1.0,
#  ('bipolar', 'seriou'): 1.0,
#  ('bair', 'cs'): 0.0,
#  ('coarctat', 'mean'): 0.0,
#  ('chair', 'suprapub'): 1.0,
#  ('ppn', 'prognosi'): 1.0,
#  ('ctx', 'diaphoresi'): 1.0,
#  ('asthma', 'motor'): 1.0,
#  ('echocardiogram', 'hive'): 1.0,
#  ('bipolar', 'unequ'): 1.0,
#  ('lotion', 'moan'): 1.0,
#  ('anyway', 'diaphoresi'): 1.0,
#  ('deliv', 'dnr'): 1.0,
#  ('arrest', 'jejunum'): 0.0,
#  ('chemic', 'habitu'): 1.0,
#  ('neo', 'readdress'): 0.0,
#  ('ctx', 'phlegm'): 1.0,
#  ('banana', 'historian'): 1.0,
#  ('ambul', 'scar'): 1.0,
#  ('captopril', 'platelet'): 0.0,
#  ('dni', 'flight'): 1.0,
#  ('lw', 'pca'): 1.0,
#  ('crrt', 'ffp'): 0.0,
#  ('levoph', 'mean'): 1.0,
#  ('levoph', 'uri'): 1.0,
#  ('esophagogastr', 'hemithorac'): 0.0,
#  ('herp', 'pleasant'): 1.0,
#  ('mrg', 'suprapub'): 1.0,
#  ('hive', 'metoclopramid'): 1.0,
#  ('agon', 'wish'): 0.0,
#  ('asystol', 'dead'): 0.0,
#  ('dic', 'diflucan'): 0.0,
#  ('cocain', 'echocardiogram'): 1.0,
#  ('sluggish', 'west'): 1.0,
#  ('dni', 'rememb'): 1.0,
#  ('aox', 'captopril'): 1.0,
#  ('pathologist', 'vallecula'): 1.0,
#  ('mso', 'neo'): 1.0,
#  ('dnr', 'tran'): 1.0,
#  ('cracker', 'incent'): 0.0,
#  ('cocain', 'db'): 1.0,
#  ('declin', 'scab'): 1.0,
#  ('declin', 'scar'): 1.0,
#  ('chip', 'xanax'): 1.0,
#  ('cvvh', 'synthet'): 1.0,
#  ('dnr', 'stg'): 0.0,
#  ('neoplast', 'palli'): 1.0,
#  ('gastriti', 'solut'): 1.0,
#  ('lymphangit', 'soln'): 1.0,
#  ('cocain', 'prec'): 1.0,
#  ('ba', 'subq'): 1.0,
#  ('compani', 'predict'): 1.0,
#  ('dnr', 'rememb'): 1.0,
#  ('dni', 'funer'): 1.0,
#  ('asthma', 'gabapentin'): 1.0,
#  ('gabapentin', 'mellitu'): 1.0,
#  ('ciwa', 'habitu'): 1.0,
#  ('dead', 'dni'): 0.0,
#  ('oob', 'rhinorrhea'): 1.0,
#  ('fliud', 'vasopressor'): 0.0,
#  ('dni', 'transmitr'): 1.0,
#  ('mva', 'ppd'): 1.0,
#  ('arrang', 'prognosi'): 0.0,
#  ('ofm', 'osa'): 1.0,
#  ('dni', 'stg'): 0.0,
#  ('cyanot', 'gentamycin'): 0.0,
#  ('ambien', 'ambul'): 1.0,
#  ('ctx', 'sibl'): 1.0,
#  ('expir', 'im'): 1.0,
#  ('captopril', 'oob'): 1.0,
#  ('fibrinogen', 'suffer'): 1.0,
#  ('diaphoresi', 'lighthead'): 1.0,
#  ('fdp', 'prilosec'): 0.0,
#  ('agon', 'levoph'): 0.0,
#  ('dnr', 'life'): 0.31529791710476945,
#  ('cdb', 'commod'): 1.0,
#  ('bill', 'synthet'): 1.0,
#  ('icter', 'prilosec'): 1.0,
#  ('lat', 'plate'): 1.0,
#  ('angioplasti', 'ppd'): 1.0,
#  ('schistocyt', 'young'): 1.0,
#  ('dni', 'lac'): 1.0,
#  ('hypercapnia', 'norepinephrin'): 0.0,
#  ('fibrinogen', 'readdress'): 1.0,
#  ('para', 'solut'): 1.0,
#  ('anur', 'pronounc'): 1.0,
#  ('gabapentin', 'wish'): 1.0,
#  ('dnr', 'gasp'): 0.0,
#  ('abnl', 'lat'): 1.0,
#  ('deploy', 'epigastr'): 1.0,
#  ('azotemia', 'cpr'): 0.0,
#  ('ctx', 'lotion'): 1.0,
#  ('pleasantli', 'subdur'): 1.0,
#  ('chair', 'xopenex'): 1.0,
#  ('bipolar', 'lotion'): 0.0,
#  ('captopril', 'sibl'): 1.0,
#  ('hugger', 'pcv'): 1.0,
#  ('tranfer', 'xl'): 1.0,
#  ('cvvh', 'wma'): 0.0,
#  ('commod', 'signatur'): 0.0,
#  ('hugger', 'pinpoint'): 0.0,
#  ('ipf', 'levoph'): 0.0,
#  ('hctz', 'pericard'): 1.0,
#  ('diaphoresi', 'echocardiogram'): 1.0,
#  ('gait', 'unavail'): 1.0,
#  ('nifedipin', 'suprapub'): 1.0,
#  ('death', 'ferrou'): 1.0,
#  ('diaphoresi', 'levoph'): 1.0,
#  ('adam', 'levoph'): 0.0,
#  ('barium', 'pharyng'): 1.0,
#  ('asthma', 'eg'): 1.0,
#  ('diflucan', 'money'): 1.0,
#  ('chip', 'palli'): 1.0,
#  ('oob', 'simpli'): 1.0,
#  ('ofm', 'svn'): 1.0,
#  ...}

# %%
# patient_dead_cooc_df
print(patient_cooc_0)
# Out:
# {111: {('arrest', 'pea'): 5.0, ('cpr', 'pea'): 4.0, ('arrest', 'cpr'): 4.0, ('cpr', 'vasopressin'): 4.0, ('pea', 'vasopressin'): 4.0, ('arrest', 'vasopressin'): 4.0, ('pcv', 'vasopressin'): 2.0, ('cpr', 'pcv'): 2.0, ('pcv', 'pea'): 2.0, ('arrest', 'pcv'): 2.0, ('paralyt', 'pcv'): 2.0, ('paralyt', 'vasopressin'): 2.0, ('cpr', 'paralyt'): 2.0, ('paralyt', 'pea'): 2.0, ('arrest', 'paralyt'): 2.0, ('norepinephrin', 'paralyt'): 2.0, ('norepinephrin', 'pcv'): 2.0, ('norepinephrin', 'vasopressin'): 2.0, ('cpr', 'norepinephrin'): 2.0, ('norepinephrin', 'pea'): 2.0, ('arrest', 'norepinephrin'): 2.0, ('hypothermia', 'norepinephrin'): 2.0, ('hypothermia', 'paralyt'): 2.0, ('hypothermia', 'pcv'): 2.0, ('hypothermia', 'vasopressin'): 2.0, ('cpr', 'hypothermia'): 2.0, ('hypothermia', 'pea'): 2.0, ('arrest', 'hypothermia'): 2.0, ('hypercapnia', 'hypothermia'): 2.0, ('hypercapnia', 'norepinephrin'): 2.0, ('hypercapnia', 'paralyt'): 2.0, ('hypercapnia', 'pcv'): 2.0, ('hypercapnia', 'vasopressin'): 2.0, ('cpr', 'hypercapnia'): 2.0, ('hypercapnia', 'pea'): 2.0, ('arrest', 'hypercapnia'): 2.0, ('dic', 'hypercapnia'): 2.0, ('dic', 'hypothermia'): 2.0, ('dic', 'norepinephrin'): 2.0, ('dic', 'paralyt'): 2.0, ('dic', 'pcv'): 2.0, ('dic', 'vasopressin'): 2.0, ('cpr', 'dic'): 2.0, ('dic', 'pea'): 2.0, ('arrest', 'dic'): 2.0, ('dic', 'phenylephrin'): 2.0, ('hypercapnia', 'phenylephrin'): 2.0, ('hypothermia', 'phenylephrin'): 2.0, ('norepinephrin', 'phenylephrin'): 2.0, ('paralyt', 'phenylephrin'): 2.0, ('pcv', 'phenylephrin'): 2.0, ('phenylephrin', 'vasopressin'): 2.0, ('cpr', 'phenylephrin'): 2.0, ('pea', 'phenylephrin'): 2.0, ('arrest', 'phenylephrin'): 2.0, ('bicarbon', 'phenylephrin'): 2.0, ('bicarbon', 'dic'): 2.0, ('bicarbon', 'hypercapnia'): 2.0, ('bicarbon', 'hypothermia'): 2.0, ('bicarbon', 'norepinephrin'): 2.0, ('bicarbon', 'paralyt'): 2.0, ('bicarbon', 'pcv'): 2.0, ('bicarbon', 'vasopressin'): 2.0, ('bicarbon', 'cpr'): 2.0, ('bicarbon', 'pea'): 2.0, ('arrest', 'bicarbon'): 2.0, ('azotemia', 'bicarbon'): 2.0, ('azotemia', 'phenylephrin'): 2.0, ('azotemia', 'dic'): 2.0, ('azotemia', 'hypercapnia'): 2.0, ('azotemia', 'hypothermia'): 2.0, ('azotemia', 'norepinephrin'): 2.0, ('azotemia', 'paralyt'): 2.0, ('azotemia', 'pcv'): 2.0, ('azotemia', 'vasopressin'): 2.0, ('azotemia', 'cpr'): 2.0, ('azotemia', 'pea'): 2.0, ('arrest', 'azotemia'): 2.0, ('autopeep', 'azotemia'): 2.0, ('autopeep', 'bicarbon'): 2.0, ('autopeep', 'phenylephrin'): 2.0, ('autopeep', 'dic'): 2.0, ('autopeep', 'hypercapnia'): 2.0, ('autopeep', 'hypothermia'): 2.0, ('autopeep', 'norepinephrin'): 2.0, ('autopeep', 'paralyt'): 2.0, ('autopeep', 'pcv'): 2.0, ('autopeep', 'vasopressin'): 2.0, ('autopeep', 'cpr'): 2.0, ('autopeep', 'pea'): 2.0, ('arrest', 'autopeep'): 2.0, ('arrest', 'death'): 3.0, ('death', 'vasopressin'): 2.0, ('cpr', 'death'): 2.0, ('death', 'pea'): 2.0, ('clinician', 'death'): 2.0, ('clinician', 'vasopressin'): 2.0, ('clinician', 'cpr'): 2.0, ('clinician', 'pea'): 2.0, ('arrest', 'clinician'): 2.0, ('profound', 'vasopressin'): 2.0, ('cpr', 'profound'): 2.0, ('pea', 'profound'): 2.0, ('arrest', 'profound'): 2.0, ('death', 'expir'): 2.0, ('arrest', 'expir'): 2.0}, 346: {}, 404: {('death', 'paco'): 1.0}, 546: {('hurt', 'oder'): 1.0, ('historian', 'oder'): 1.0, ('historian', 'hurt'): 1.0}, 618: {}, 705: {('dni', 'dnr'): 2.0, ('cmo', 'dnr'): 2.0}, 726: {}, 1039: {}, 1556: {('dnr', 'mso'): 7.0, ('dni', 'dnr'): 8.0, ('dni', 'mso'): 7.0}, 1872: {}, 1944: {}, 2286: {('cyanot', 'pitressin'): 11.0, ('cyanot', 'incis'): 8.0, ('anur', 'cyanot'): 7.0, ('bair', 'hugger'): 7.0}, 2990: {}, 3055: {}, 3099: {('neo', 'neosynephrin'): 1.0, ('dopamin', 'neosynephrin'): 1.0, ('ffp', 'neo'): 1.0, ('ffp', 'neosynephrin'): 1.0, ('ffp', 'vasopressin'): 1.0, ('neo', 'vasopressin'): 1.0, ('neosynephrin', 'vasopressin'): 1.0, ('levoph', 'vasopressin'): 1.0, ('ffp', 'levoph'): 1.0, ('levoph', 'neo'): 1.0, ('levoph', 'neosynephrin'): 1.0, ('hypotherm', 'levoph'): 1.0, ('hypotherm', 'vasopressin'): ...

# %%
print(patient_node_0)
# Out:
# {111: {'arrest': 6.0, 'pea': 5.0, 'cpr': 4.0, 'vasopressin': 4.0, 'pcv': 2.0, 'paralyt': 2.0, 'norepinephrin': 2.0, 'hypothermia': 2.0, 'hypercapnia': 2.0, 'dic': 2.0, 'phenylephrin': 2.0, 'bicarbon': 2.0, 'azotemia': 2.0, 'autopeep': 2.0, 'death': 3.0, 'clinician': 2.0, 'profound': 2.0, 'expir': 2.0}, 346: {'arrest': 4.0, 'sluggish': 6.0}, 404: {'paco': 1.0, 'death': 1.0}, 546: {'oder': 1.0, 'hurt': 1.0, 'historian': 1.0}, 618: {'video': 2.0}, 705: {'dnr': 5.0, 'dni': 2.0, 'cmo': 5.0, 'mso': 2.0}, 726: {'mso': 3.0, 'dnr': 3.0}, 1039: {'wish': 4.0}, 1556: {'mso': 13.0, 'dnr': 8.0, 'dni': 8.0}, 1872: {'pronounc': 1.0}, 1944: {'arrest': 4.0, 'cvvhd': 5.0}, 2286: {'cyanot': 17.0, 'vasopressin': 14.0, 'levoph': 8.0, 'dnr': 7.0, 'prognosi': 7.0, 'purpl': 10.0, 'mottl': 7.0, 'pitressin': 15.0, 'incis': 10.0, 'anur': 9.0, 'cvvh': 9.0, 'hugger': 7.0, 'bair': 7.0}, 2990: {'chair': 17.0, 'oob': 17.0, 'levoph': 31.0, 'anur': 24.0}, 3055: {'gc': 3.0, 'wish': 3.0, 'cmo': 4.0}, 3099: {'neo': 2.0, 'neosynephrin': 2.0, 'dopamin': 1.0, 'ffp': 2.0, 'vasopressin': 1.0, 'levoph': 1.0, 'hypotherm': 1.0, 'hung': 1.0, 'dic': 1.0, 'cagluc': 1.0, 'suport': 1.0, 'polici': 1.0, 'ethic': 1.0, 'cpr': 1.0}, 3201: {'sluggish': 3.0, 'dopamin': 3.0, 'norepinephrin': 1.0, 'levoph': 1.0, 'unavail': 1.0, 'neo': 2.0, 'pitressin': 1.0, 'vasopressin': 1.0, 'unequ': 1.0, 'pronounc': 1.0, 'nahco': 1.0, 'mortem': 1.0, 'levof': 1.0, 'expir': 1.0, 'cpr': 1.0}, 3526: {'levoph': 2.0, 'dnr': 2.0, 'dni': 2.0, 'laryng': 1.0, 'pronounc': 1.0, 'mso': 1.0, 'jerk': 1.0, 'intiat': 1.0, 'declin': 1.0, 'death': 1.0, 'agon': 1.0}, 3773: {'plate': 1.0, 'mso': 2.0, 'escal': 1.0, 'dopamin': 1.0, 'dnr': 1.0, 'dni': 1.0, 'cmo': 1.0, 'pronounc': 1.0, 'death': 1.0}, 3881: {'dnr': 3.0, 'dni': 3.0, 'cmo': 3.0, 'moan': 2.0, 'sluggish': 2.0}, 4122: {}, 4754: {'levoph': 11.0, 'dobutamin': 10.0, 'captopril': 17.0}, 4811: {'life': 2.0, 'dnr': 2.0, 'dni': 2.0, 'hospic': 2.0}, 5476: {}, 5494: {'dnr': 2.0, 'dni': 2.0, 'wish': 2.0, 'escal': 2.0, 'video': 2.0}, 5774: {'levoph': 13.0, 'neo': 11.0, 'cvvhd': 11.0, 'sluggish': 9.0, 'pneumococc': 13.0, 'hugger': 12.0, 'cpr': 12.0}, 5786: {'dobutamin': 9.0}, 5913: {}, 6133: {'lc': 6.0}, 6735: {'prognosi': 3.0, 'dopamin': 3.0, 'mottl': 2.0, 'mso': 2.0, 'levoph': 2.0, 'cpr': 2.0, 'grave': 2.0}, 6745: {'dnr': 4.0, 'dni': 4.0, 'mso': 2.0, 'wish': 1.0, 'heroic': 1.0, 'rabbi': 1.0, 'profound': 1.0, 'moan': 1.0}, 6973: {'dnr': 3.0, 'dni': 3.0}, 6981: {'lat': 1.0, 'occupi': 1.0, 'dnr': 2.0, 'dni': 2.0, 'pleuravac': 1.0, 'priest': 1.0}, 7277: {'neo': 6.0, 'mso': 14.0}, 7310: {'hospic': 3.0, 'dnr': 3.0, 'dni': 3.0, 'nonrebreath': 1.0, 'palliat': 2.0, 'opinion': 2.0, 'sacrament': 1.0, 'peac': 1.0, 'prognosi': 1.0}, 7924: {'neo': 1.0, 'wish': 1.0, 'reveiw': 1.0}, 7977: {'neo': 3.0, 'levoph': 2.0}, 9908: {'levof': 1.0, 'neosynephrin': 1.0, 'levoph': 1.0, 'intiat': 1.0, 'dnr': 1.0, 'dni': 1.0, 'agon': 1.0, 'cmo': 2.0}, 9984: {'levoph': 4.0, 'incis': 2.0, 'hugger': 2.0}, 10302: {'levoph': 56.0, 'dnr': 41.0, 'hive': 39.0, 'fibrinogen': 39.0, 'platelet': 36.0, 'hemothorax': 36.0, 'chb': 29.999999999999996, 'suffer': 26.0, 'norepinephrin': 17.0, 'dic': 31.0, 'abruptli': 18.0}, 10510: {'xopenex': 7.000000000000001}, 10545: {'gvhd': 2.0, 'dopamin': 2.0, 'cyanot': 1.0, 'eyelid': 1.0, 'fungemia': 1.0, 'furhter': 1.0, 'lw': 1.0, 'twitch': 1.0, 'ambul': 1.0, 'vasopressin': 1.0, 'cmo': 1.0, 'levoph': 1.0, 'vasoconstrict': 1.0, 'liw': 1.0, 'mso': 1.0, 'pose': 1.0, 'prognosi': 1.0, 'sibl': 1.0, 'unstabl': 1.0, 'asystol': 1.0, 'dead': 1.0, 'pronounc': 1.0, 'autopsi': 1.0}, 10642: {'scar': 1.0, 'centimet': 1.0, 'dnr': 4.0, 'dni': 3.0, 'mso': 1.0, 'gasp': 1.0, 'prognosi': 1.0, 'moan': 1.0}, 11049: {'neo': 6.0, 'lw': 2.0, 'phenylephrin': 2.0}, 11209: {'subdur': 1.0, 'deterior': 1.0, 'dni': 3.0, 'dnr': 3.0, 'vasopressor': 1.0, 'bair': 1.0, 'dopamin': 1.0, 'hugger': 1.0, 'hypotherm': 1.0, 'hypothermia': 1.0, 'levoph': 1.0, 'paperwork': 1.0, 'rusti': 1.0, 'sluggish': 1.0, 'wish': 1.0, 'arre ...

# %%
# Check if all nodes has embeddings
patient_node_set = set()
patient_node_0_dict = {}
patient_node_1_dict = {}
    
for k, v in patient_node_0.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_0_dict:
            patient_node_0_dict[item] = v[item]
        else:
            patient_node_0_dict[item] = patient_node_0_dict[item] + v[item]
        
    
for k, v in patient_node_1.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_1_dict:
            patient_node_1_dict[item] = v[item]
        else:
            patient_node_1_dict[item] = patient_node_1_dict[item] + v[item]

# %%
print(len(patient_node_set))
print(len(patient_node_0_dict))
print(len(patient_node_1_dict))
# Out:
# 633
# 379
# 571

# %%
patient_node_odd_scores = {}

for set_item in patient_node_set:
    if set_item in patient_node_0_dict and set_item in patient_node_1_dict:
        d_prob = patient_node_0_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        a_prob = patient_node_1_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_node_odd_scores[set_item] = log_odd_score

# %%
print(patient_node_odd_scores)
# Out:
# {'autoset': 6.90875477931522, 'town': 2.9256884298210646, 'fliud': -6.90875477931522, 'ardsnet': 0.6460928627110164, 'lpm': 2.2816822783879074, 'sibl': 0.809128888289493, 'ligament': 1.3825560390092835, 'young': 6.90875477931522, 'sarna': 6.90875477931522, 'petechia': -6.90875477931522, 'oligur': 1.5098168539127583, 'tubular': 0.6916505477038827, 'itchi': -0.03383387098398164, 'palli': 0.29299432963307714, 'dnr': 0.8878077019401656, 'contractur': 2.8995119199810393, 'quiac': 6.90875477931522, 'jewelri': 2.625239572123001, 'precordium': 1.604655121332035, 'lotion': 0.28709992764761555, 'barium': 3.5875897086472195, 'nrbm': 0.0, 'recalibr': 6.90875477931522, 'commod': 1.8085373893992105, 'subq': 6.90875477931522, 'money': 2.5001408943598484, 'nice': 6.90875477931522, 'slice': 2.1883847407670785, 'passey': 6.90875477931522, 'epidur': 6.90875477931522, 'effac': 2.552122795903801, 'warmer': 6.90875477931522, 'strictur': 6.90875477931522, 'angioplasti': 6.90875477931522, 'anyway': 6.90875477931522, 'lax': 6.90875477931522, 'binder': 6.90875477931522, 'derecruit': -6.90875477931522, 'morgu': -6.90875477931522, 'spiromet': 3.696591728053012, 'gaol': 6.90875477931522, 'ultrafiltr': 6.90875477931522, 'cpr': -1.36687383632168, 'diflucan': 0.5378679732223675, 'bair': 0.12235699519301034, 'oximetri': 6.90875477931522, 'diaphoresi': 6.90875477931522, 'hygein': 6.90875477931522, 'chair': 1.8559553610868105, 'panic': 6.90875477931522, 'td': 6.90875477931522, 'heroic': -6.90875477931522, 'captopril': 2.956624359695953, 'bicarbon': -0.21662784268989682, 'twitch': 3.60035323709679, 'yankuer': 6.90875477931522, 'acetazolamid': 6.90875477931522, 'norepinephrin': -0.597800307795547, 'mva': 6.90875477931522, 'colonoscopi': 6.90875477931522, 'glycopyrrol': 1.7859498421315991, 'occurr': 6.90875477931522, 'treatement': 6.90875477931522, 'incent': 2.3410355182973803, 'hive': 2.0229359235263975, 'aprv': -6.90875477931522, 'arrang': -6.90875477931522, 'lat': 2.781918475709505, 'spur': 6.90875477931522, 'cvvhd': -0.3782571110465018, 'subdur': 4.7177301007748484, 'quietli': -1.604655121332035, 'quadrent': 6.90875477931522, 'priest': -6.90875477931522, 'underneath': 1.3825560390092835, 'ambien': 6.90875477931522, 'piriform': 6.90875477931522, 'defibril': 6.90875477931522, 'olanzapin': 6.90875477931522, 'tacycard': 6.90875477931522, 'tcdb': 6.90875477931522, 'tachpnea': 6.90875477931522, 'zyprexa': 2.906721752674218, 'dxae': 0.0, 'macu': 6.90875477931522, 'vertebra': 1.3825560390092835, 'vasoconstrict': -6.90875477931522, 'agon': -3.3046522316270157, 'burn': 0.5918095650214555, 'unenhanc': 1.7859498421315991, 'method': -6.90875477931522, 'autopeep': -6.90875477931522, 'nocturn': 6.90875477931522, 'lc': -0.8453976222857144, 'montitor': -6.90875477931522, 'sml': -6.90875477931522, 'rigor': 6.90875477931522, 'gum': 6.90875477931522, 'vtach': -2.007571633726069, 'yel': 6.90875477931522, 'pod': 6.90875477931522, 'pvr': 0.0, 'doen': -6.90875477931522, 'video': 2.322003749327675, 'rememb': 6.90875477931522, 'wether': 6.90875477931522, 'eg': 6.90875477931522, 'pitressin': -1.095952712632351, 'svv': -6.90875477931522, 'dopamin': 2.121381791838009, 'wish': 0.30117515279635937, 'flake': 6.90875477931522, 'uri': 6.90875477931522, 'distort': 2.625239572123001, 'option': -1.4352492835070114, 'rabbi': -6.90875477931522, 'od': 6.90875477931522, 'kerlix': 6.90875477931522, 'dome': 1.6994502465251524, 'death': -0.6916505477038827, 'muir': 6.90875477931522, 'prilosec': 3.3046522316270157, 'argatroban': -0.8013676005646301, 'dietari': 6.90875477931522, 'proph': 6.90875477931522, 'rpr': 6.90875477931522, 'sacrament': -6.90875477931522, 'arrest': 1.1884144866522524, 'gurgl': 3.464102558012661, 'calvarium': 1.3825560390092835, 'trabecul': 1.9390841839849136, 'grim': -6.90875477931522, 'impli': 0.6916505477038827, 'hepatobiliari': -6.90875477931522, 'ctx': 4.020284968191801, 'mrcp': -1.0271828417136022, 'readmit': 6.90875477931522, 'rehabilit': 6.90875477931522, 'gvhd': -3.914727064 ...

# %%
patient_square_node_data = pd.DataFrame({'node':list(patient_node_odd_scores.keys()), 'feature':list(patient_node_odd_scores.values())})
patient_square_node_data
# Out:
#           node   feature
# 0      autoset  6.908755
# 1         town  2.925688
# 2        fliud -6.908755
# 3      ardsnet  0.646093
# 4          lpm  2.281682
# ..         ...       ...
# 628   clonidin  6.908755
# 629     massag -1.200948
# 630  pulseless -6.908755
# 631       scar  0.988463
# 632  readdress  1.604655
#
# [633 rows x 2 columns]

# %%
patient_square_node_id_data = patient_square_node_data.set_index("node")
patient_square_node_id_data['subject'] = ["positive" if r['feature'] > 0 else "negative" for i, r in patient_square_node_id_data.iterrows()]
patient_square_node_id_data
# Out:
#             feature   subject
# node
# autoset    6.908755  positive
# town       2.925688  positive
# fliud     -6.908755  negative
# ardsnet    0.646093  positive
# lpm        2.281682  positive
# ...             ...       ...
# clonidin   6.908755  positive
# massag    -1.200948  negative
# pulseless -6.908755  negative
# scar       0.988463  positive
# readdress  1.604655  positive
#
# [633 rows x 2 columns]

# %%
patient_subjects = patient_square_node_id_data["subject"]
patient_subjects
# Out:
# node
# autoset      positive
# town         positive
# fliud        negative
# ardsnet      positive
# lpm          positive
#                ...
# clonidin     positive
# massag       negative
# pulseless    negative
# scar         positive
# readdress    positive
# Name: subject, Length: 633, dtype: object

# %%
patient_square_node_data_no_feature = patient_square_node_id_data.drop(columns=["feature","subject"])
patient_square_node_data_no_feature
# Out:
# Empty DataFrame
# Columns: []
# Index: [autoset, town, fliud, ardsnet, lpm, sibl, ligament, young, sarna, petechia, oligur, tubular, itchi, palli, dnr, contractur, quiac, jewelri, precordium, lotion, barium, nrbm, recalibr, commod, subq, money, nice, slice, passey, epidur, effac, warmer, strictur, angioplasti, anyway, lax, binder, derecruit, morgu, spiromet, gaol, ultrafiltr, cpr, diflucan, bair, oximetri, diaphoresi, hygein, chair, panic, td, heroic, captopril, bicarbon, twitch, yankuer, acetazolamid, norepinephrin, mva, colonoscopi, glycopyrrol, occurr, treatement, incent, hive, aprv, arrang, lat, spur, cvvhd, subdur, quietli, quadrent, priest, underneath, ambien, piriform, defibril, olanzapin, tacycard, tcdb, tachpnea, zyprexa, dxae, macu, vertebra, vasoconstrict, agon, burn, unenhanc, method, autopeep, nocturn, lc, montitor, sml, rigor, gum, vtach, yel, ...]
#
# [633 rows x 0 columns]

# %%
from sklearn.manifold import TSNE
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
from gensim.models import Word2Vec

# %% [markdown]
# ### Create a bi-directional df

# %%
# with edge weight
bidirect_source = []
bidirect_target = []
edge_weight = []

for item, val in new_patient_cooc_odd_scores.items():
    bidirect_source.extend([item[0], item[1]])
    bidirect_target.extend([item[1], item[0]])
    edge_weight.extend([val, val])
    
print(f"source: {len(bidirect_source)}, target: {len(bidirect_target)}")

weighted_patient_bidirect_square_edge_data = pd.DataFrame(
    {
        "source": bidirect_source,
        "target": bidirect_target,
        "weight": edge_weight,
    })
weighted_patient_bidirect_square_edge_data
# Out:
# source: 13552, target: 13552
#            source      target    weight
# 0        assymetr       death  1.000000
# 1           death    assymetr  1.000000
# 2           sweat  ultrafiltr  1.000000
# 3      ultrafiltr       sweat  1.000000
# 4      gabapentin        puff  1.000000
# ...           ...         ...       ...
# 13547         xii         dni  0.383868
# 13548        gait       motor  1.000000
# 13549       motor        gait  1.000000
# 13550      declin       palli  0.629253
# 13551       palli      declin  0.629253
#
# [13552 rows x 3 columns]

# %%
# Weighted
G_weighted_patient_bidirect = StellarGraph(
    {"corner": patient_square_node_data_no_feature}, {"line": weighted_patient_bidirect_square_edge_data}
)
print(G_weighted_patient_bidirect.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 633, Edges: 13552
#
#  Node types:
#   corner: [633]
#     Features: none
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [13552]
#         Weights: range=[0, 1], mean=0.734681, std=0.426758
#         Features: none

# %%
# Weighted
rw_weighted_patient_bidirect = BiasedRandomWalk(G_weighted_patient_bidirect)

# %%
# Weighted
weighted_walks_patient_bidirect = rw_weighted_patient_bidirect.run(
    nodes=G_weighted_patient_bidirect.nodes(),  # root nodes
    length=100,  # maximum length of a random walk
    n=10,  # number of random walks per root node
    p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
    q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
#     weighted=True,  # for weighted random walks
    seed=42,  # random seed fixed for reproducibility
)
print("Number of random walks: {}".format(len(weighted_walks_patient_bidirect)))
# Out:
# Number of random walks: 6330

# %%
print(weighted_walks_patient_bidirect[0])
# Out:
# ['autoset', 'diaphoresi', 'puff', 'lotion', 'xl', 'ferrou', 'xl', 'puff', 'rehabilit', 'ppd', 'trazodon', 'mellitu', 'scar', 'romi', 'oncologist', 'predict', 'led', 'asthma', 'ultram', 'anaphylaxi', 'ctx', 'anaphylaxi', 'nocturn', 'im', 'adenocarcinoma', 'institut', 'slice', 'calvarium', 'occipit', 'calvarium', 'occipit', 'slice', 'scar', 'nephrogram', 'hilum', 'aricept', 'jewelri', 'gabapentin', 'db', 'pleasant', 'ctx', 'phlegm', 'signatur', 'cdb', 'phlegm', 'silent', 'lusb', 'fibrinogen', 'xl', 'osa', 'robitussin', 'wish', 'unstabl', 'acidot', 'fibrinogen', 'levof', 'vasopressin', 'pronounc', 'expir', 'dni', 'moan', 'expir', 'vasopressin', 'cpr', 'sluggish', 'bair', 'dopamin', 'unequ', 'deterior', 'gurgl', 'arrest', 'asystol', 'mortem', 'dead', 'sundown', 'occipit', 'flight', 'pleasant', 'quadrent', 'dnr', 'bell', 'dnr', 'stg', 'dnr', 'neo', 'life', 'ambul', 'spill', 'pathologist', 'elimin', 'barium', 'neo', 'mso', 'vasopressin', 'levof', 'cpr', 'death', 'suffer', 'declin', 'cmo']

# %%
# Weighted
weighted_model_patient = Word2Vec(
    weighted_walks_patient_bidirect, size=128, window=5, min_count=0, sg=1, workers=4, iter=1
)

# %%
# Weighted
emb = weighted_model_patient.wv["cmo"]
emb
# Out:
# array([ 0.08301433, -0.25073513, -0.06341648, -0.15192394, -0.20951189,
#         0.372557  , -0.05152877, -0.14490008, -0.10225144,  0.18015818,
#         0.11243024, -0.30200225,  0.2706989 ,  0.24509913, -0.2985278 ,
#        -0.04450993, -0.0766446 , -0.24935915, -0.09190227,  0.2408084 ,
#        -0.08580315, -0.07759851,  0.01756599,  0.41381818,  0.02675799,
#         0.07103227,  0.28175396, -0.00916883, -0.21056369,  0.02021801,
#        -0.21438456, -0.1518971 ,  0.01151159, -0.20563693,  0.07197459,
#         0.08217105, -0.1178382 , -0.33433816,  0.0115987 , -0.29124415,
#        -0.1385774 , -0.10356584, -0.26698214,  0.1592149 ,  0.03224485,
#         0.13406579,  0.14211793, -0.5147041 , -0.08417584,  0.01875398,
#        -0.05670372, -0.02122601,  0.2347743 , -0.23943947,  0.05191777,
#        -0.26338556,  0.19814873,  0.03473796, -0.8269398 ,  0.09794654,
#         0.32029855, -0.11360966, -0.17854166,  0.07981684, -0.25593415,
#        -0.19080812,  0.26462963, -0.23877752, -0.10979508,  0.07231146,
#        -0.15838985, -0.21915324,  0.06464833,  0.17985392, -0.03035601,
#         0.27515143,  0.1526148 , -0.00722221, -0.03805415,  0.4691725 ,
#         0.08077779,  0.30775544, -0.03036582, -0.02366387,  0.15217161,
#         0.00728329,  0.1550098 , -0.1926401 ,  0.07177895,  0.06381242,
#         0.02106343, -0.07779507,  0.20738451, -0.27473387,  0.26823258,
#         0.02429383,  0.25436154,  0.09088978, -0.20324449,  0.00375887,
#         0.41451636,  0.28723404,  0.52564543, -0.03310166, -0.17395753,
#        -0.22759058,  0.03430979, -0.07721849,  0.0075892 , -0.22797355,
#        -0.02941027,  0.16013011, -0.22094905, -0.13594793,  0.17127061,
#        -0.11619913, -0.0314796 , -0.03945909,  0.15290985, -0.22135948,
#         0.4539569 , -0.00346257, -0.15677767, -0.0306406 , -0.1481599 ,
#         0.05158706, -0.34830087,  0.05452947], dtype=float32)

# %% [markdown]
# ### Visualise Node Embeddings generated by weighted random walks

# %% [markdown]
# ### Weighted edges

# %%
# Retrieve node embeddings and corresponding subjects
patient_weighted_node_ids = weighted_model_patient.wv.index2word  # list of node IDs
patient_weighted_node_embeddings = (
    weighted_model_patient.wv.vectors
)  # numpy.ndarray of size number of nodes times embeddings dimensionality
# the gensim ordering may not match the StellarGraph one, so rearrange
patient_node_targets = patient_subjects.loc[patient_weighted_node_ids].astype("category")

# %%
# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2, random_state=42)
patient_weighted_node_embeddings_2d = tsne.fit_transform(patient_weighted_node_embeddings)

# %%
# draw the points
alpha = 0.7

plt.figure(figsize=(10, 8))
plt.scatter(
    patient_weighted_node_embeddings_2d[:, 0],
    patient_weighted_node_embeddings_2d[:, 1],
    c=patient_node_targets.cat.codes,
    cmap="jet",
    alpha=0.7,
)
plt.show()

# %%
patient_weighted_node_emb_dict = {}
for index, row in patient_square_node_data_no_feature.iterrows():
    if index not in patient_weighted_node_emb_dict:
        patient_weighted_node_emb_dict[index] = weighted_model_patient.wv[index]
    else:
        print(f"index: {index} is already in a dictionary!")

# %%
# print(type(patient_weighted_node_emb_dict['aprv']))

# %%
import pandas as pd
import numpy as np

import stellargraph as sg
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import GCNSupervisedGraphClassification
from stellargraph import StellarGraph

from stellargraph import datasets

from sklearn import model_selection
from IPython.display import display, HTML

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import matplotlib.pyplot as plt

seed = 42
numpy.random.seed(seed)
tf.random.set_seed(seed)
sg.random.set_seed(seed)

# %% [markdown]
# ### Load the data

# %%
from collections import defaultdict

def create_graph_list(patient_cooc_dict, cooc_odd_scores, node_emb_dict, label):
    
    graphs = []
    labels = []
    
    for key,row in patient_cooc_dict.items():
     
        if row:
            source = []
            target = []
            edge_weight = []
            
            node_feature = []
            node_idx = []
            for cooc in row:
                source.extend([cooc[0], cooc[1]])
                target.extend([cooc[1], cooc[0]])
                edge_weight.extend([cooc_odd_scores[cooc], cooc_odd_scores[cooc]])
        
            node_idx = list(set(source + target))
    
            # Create a dataframe of only nodes
            square_node_data = pd.DataFrame(
                index=node_idx)
            
#             square_node_data['feature'] = [1] * len(node_idx)
        
            # Create a dictionary for each column for a vector
            node_features = defaultdict(list)
            for node in node_idx:
                for i, vec in enumerate(node_emb_dict[node]):
                    node_features['w_' + str(i)].append(vec)
        
            # Add columns to a dataframe
            for k, v in node_features.items():
              
                square_node_data[k] = v

            square_edges = pd.DataFrame({ 
                "source": source, 
                "target": target, 
                "weight":edge_weight
            })
        
            square = StellarGraph({"corner": square_node_data}, {"line": square_edges})
            graphs.append(square)
            labels.append(label)
            
    return graphs, labels

graphs = []
labels = []

# patient_weighted_node_emb_dict
graph_0, label_0 = create_graph_list(patient_cooc_0, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, -1)
graph_1, label_1 = create_graph_list(patient_cooc_1, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, 1)

graphs.extend(graph_0)
labels.extend(label_0)
print(f"graphs_0: {len(graphs)}, labels_0: {len(labels)}")
graphs.extend(graph_1)
labels.extend(label_1)
print(f"graphs_1: {len(graph_1)}, labels_1: {len(label_1)}")
print(f"graphs: {len(graphs)}, labels: {len(labels)}")
# Out:
# graphs_0: 162, labels_0: 162
# graphs_1: 726, labels_1: 726
# graphs: 888, labels: 888

# %%
# prepare test and train datasets
test_cnt = int(len(graphs)*0.1)/2
print(test_cnt)

pos_start = len(graph_0)
print(pos_start)

test_arr = []
train_arr = []
for i, v in enumerate(graphs):
    # Take first items for neg set
    if i < test_cnt:
        test_arr.append(i)    
    elif i > pos_start and i <= pos_start + test_cnt:
        test_arr.append(i)    
    else:
        train_arr.append(i)
# Out:
# 44.0
# 162

# %%
import random
seed = 42
c = list(test_arr)
random.Random(seed).shuffle(c)
test_arr =  c

# %%
c = list(train_arr)
random.Random(seed).shuffle(c)
train_arr =  c

# %%
train_index = np.array(train_arr)
test_index = np.array(test_arr)

# %%
print(len(test_index))
print(test_index)
# Out:
# 88
# [178 182  33  30  19  26 165 187  15 185  42   1 195 179 175  37 186  36
#  171 164 192  20 202   8  41 198  40 177  32 174  39 205  43 196  12  23
#   18 189 169 168   7  34 190   2  16  38 166  22 180  24   5   6 184 181
#  199   9 206  21 191 163  10 170 167   0 203 176 201 172  25 193 183  29
#   27 197 204   4 173 194  11 188  13  17  28  31  35   3  14 200]

# %% [markdown]
# 78
# [154 155 159   8 158 175  33  15 168 160 174 157 147 181 163  23  25   7
#  167 164  36  18 172  19  20 149  30 169 165 173 150 170   2  16 166  22
#  146  24   5   6 153 178   9 156  21 171 162  10   0 179  37 180 184  26
#   34 151 148 152  12 182   1  38  32  29  27 177 183   4 161  11 176  13
#   17  28  31  35   3  14]

# %%
print(len(train_index))
print(train_index)
# Out:
# 800
# [820 462 661 578 735 619 446 737 538 861 583 732 876 425  68 879 265 466
#  428 149 486 132 703 509 288 289 577 319 327 464 108 822 818 317 632 700
#  598 324 719 767 309 532 587 819 417 368 390 279 489 404 122 300 762 471
#  824 479 744 838 389 238 626  80 690 273 260 268 136  53 445  94 551 118
#  754  57 826 262 857 627 490 539 365 353 447 663 408 716 320 870 522 444
#  791 595 301 728 777 335  52 442  72 835 734 485 582 611 413  54 675 473
#  510 352 693 261 492 725 741 350 714 102 671 565 860  77 525  67 610 154
#   61 286 775 695 569 678 665 250  86 814 351 236 670 812 638 789 519 568
#  399 502 225 592 457 813 505 677 608 602 329  49 237 649 360 474 623 808
#  207 497 128 684 755  60 590  83 325 394 469 381 615 226 783 129 666 766
#  800 837 752 276 694 571 212 540 790 749 564 481 344 491 278  84 421 228
#  463 217 272 337 511 281 844 240 697 403 452 739 315 866 705  75 378 480
#  850 162 220 727 763  89 100 723 287 864 400 589 280 881 483 398 630 736
#  339 664 573 883 531 555  93 235 545 560 150 518 465 636 776 423 443 804
#  798 852 537 145 159 544 576 488 259 527  87 130 621 395 535 356 612 815
#  252 382 453 770 243 594 295 606 874 603 303 720 707 239 575 794 297 604
#  534 512 107 657 409 415 460 456 625 682 354 713 396 484 218 141 383 285
#  761 349 868 554 264 601 722 549 647 773 385 438 591 507  58 873 781 548
#  618 563 416 530 768 613 292 142 495 708 160 718 267 672 146 157 328 709
#  283 643 816 224 859 556 298 745 135  56 299 134 127 209 503 644 296 374
#  269  96 515 832 437 499 271 887 274 245 674 676 845 119 831 562 528  62
#  367 120 441  82 786 516 375 616 449 370 314 807 126 222 414 110 620  45
#   66 757 688 494  91  70 696 795 346 645 412 439 771 797 839 151 397 232
#  227 123 513 468  98 726 827 112  97 427 796 371 506 429 542 836 422 501
#  401 242 448 366 514 758 710 233 277 213 581 266 680 729 347 153 363 829
#  624 376 406 546  48  81 472 559 667 241 418 431 877 290 656 210 597 454
#  430 843 221 750 355 377 386 424 805 584 405  64 681 817 214 379 543 570
#  105 294 208 648 433  78 392  79 622 523  85 348 579 596 712 756 524 834
#  740 332 387 885  73 248 683 641 865 310 391 635 246 586 858 380 553 854
#  487  46 792 256 702 782 306 580 659 652 258 330 869  59  95 642 541 121
#  343 793 660 275 748 231 855 651 823 342 155 435 500 106 144  99 566 508
#  689 450 529 840 140 282 504 673 336 572 223 687 307 699 373 331 614 669
#  426 784 113 785 104 116  51 856 323 655  65 434 772 318 341 211 550 617
#  536 717 760 407 293 715 779 521 628 769 257 650 574 219 216 633 114 585
#  131 830 778 334 103 333 402 459 733  63 588 419 701  44 631 640 253 470
#  801 862 799 724 393 152 607 270 600 764  47 811 249 533 828 886 848 803
#  833 161  55 654 345 629 567 747 478 482 109 698 849 851 730 244 156  92
#  137 593 609 229 788 825 496 685 526 686 357 639 863 340 880 359 234 557
#  746 493 599 759 305 410 668 304 111 362 498 411 871 322 101 420 312 658
#  743 364 476 561 255 882 634 263 810 711 117 751 787 361 774 302 451 467
#  254 461 738 552 884 841 147 867 125 384 321 765  90 115 809 284 679 458
#  721 731 388 653 124 475 215 637 558  88 358 706 440 455 143 477 138 878
#  432 308 247 853 436 872 802 251  50 372 691 547 313 517 875 806 753 821
#  291 662  71 704 605 326 311 139  74  76 520 692 133 646 846 780 148 842
#  230 316 338 369 847  69 158 742]

# %% [markdown]
# 709
# [461 734 405 329 689 489 140 646 228 300  54 610 517 480  55 726  52 358
#  113 432 502  67 664  78 417 653 576 603 287 258 464 341  44 705 125 544
#  435 384 745 447 484 236 406 690 342 221 269 433 139  53 380 254 667 462
#  309 250 418 715  63 634 725 626 665 252 661 299  41 144 470 437 574 635
#  605 654 633 364 500  47 388 716 265 688 645 758  49 593 714  81 662 747
#   75 343 193 290 514 278 291 563 333 350 545 655  72 604 459 475 368 494
#  659 334 240 103 131 270 117 210 339 135  79 728 775 539 481 700 216 399
#   97 276 102 477 196 722  95 641 438 419 227 505 518 704 778 263 145 340
#  687 553 101 297 756 503 285 381 522 768  62 562 617 657 371  82 375 598
#  631 398 456 197 404 706 386 315 515 413 731 255 394 218 268 116 601 579
#  740 332 495 271 436 569 592 393 736 428 786 531 742 638 561 207 379 650
#  695 615 781 751 482 527  56 188 541 530 249 266 458 262 402 625 469 490
#  632 305 363 656 372 570 225 431 319 497 233 607 471 279 720 127 493 230
#  560  48 429 226  84 389 559 478 759 346 513 215 293 552 344 208 242 776
#  543 275 325 427 606 246 282 686 498 628 194 637 257 671 141 191 318 680
#  273 549 723 214 640 616 390 130  51 289 129 122 521 407 533 566  91 538
#  403 261 649 264 235 600 602 567 114 385 425  57 357 115 536 699 499 365
#  296 360 535 121 212 105 248 613  61 672 504 524  65 618 707 336 528 453
#  709 185 387 222 217 496 568  93 708 763 107  92 443 361 439 741 558 391
#  232 356 673 501 223 267 203 474 256 446 582 337 532 353 440  90 366 396
#  442  43  76 455 594 231 660 421 670 280 509 200 609 444 587 748 211 702
#  345 367 376 414 713 476 395  59 473 534 204 369 100 554 198 423  73 382
#   74 771  80 338 485 622 614 691 322 377 580 492 238 608 555 355 454 724
#   68 189 229 546 118 327 744 591 719 761 452 434 647 685 310 508 620 213
#  277  40 272 123 772 611 585 623 586 572 124 199 512 463  86 639 506 584
#  411 784 581 783 677 550 573 304  77 525 739 314 588 729 565 727 307 767
#  571 137 737  94 519 487 251 450 284  70  89 408 412 749 766 717 520 317
#  288 612 259 750 415  88 668 136 286 491 577 479 202 320 373 370 529 556
#  674 693 703 187 326 420 683 321 596 416 697 108 698  99 111  46 760 313
#   60 424 663 308 331 201 540 526 762 678 397 283 692 511 684 247 564 209
#  206 109 575 126 735 324  98 323 392 449 651  58 578 409  39 621 630 243
#  460 666 764 642 383 186 597 260 590 679  42 718 239 523 733 785 753 712
#  738 195  50 644 335 619 557 468 472 104 754 755 234 190  87 132 583 599
#  219 710 730 486 675 516 676 347 629 765 330 780 349 224 547 483 589 295
#  400 658 294 106 352 488 401 773 312  96 410 302 648 354 466 551 245 782
#  624 253 701 112 351 292 441 457 244 451 542 752 746 142 769 120 374 311
#   85 110 274 669 448 711 721 378 643 119 465 205 627 548  83 348 696 430
#  445 138 467 133 779 422 298 237 757 426 774 241  45 362 681 537 303 507
#  777 743 281 652  66 694 595 316 301 134  69  71 510 682 128 636 770 143
#  220 306 328 359  64 192 732]

# %%
print(graphs[0].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 18, Edges: 212
#
#  Node types:
#   corner: [18]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [212]
#         Weights: range=[0, 0.788597], mean=0.0526238, std=0.175607
#         Features: none

# %%
print(graphs[100].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 11, Edges: 76
#
#  Node types:
#   corner: [11]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [76]
#         Weights: range=[0, 0.552589], mean=0.214523, std=0.219258
#         Features: none

# %%
summary = pd.DataFrame(
    [(g.number_of_nodes(), g.number_of_edges()) for g in graphs],
    columns=["nodes", "edges"],
)
summary.describe().round(1)
# Out:
#        nodes  edges
# count  888.0  888.0
# mean     5.6   22.4
# std      3.7   33.8
# min      2.0    2.0
# 25%      2.0    2.0
# 50%      5.0    8.0
# 75%      8.0   26.0
# max     23.0  272.0

# %%
graph_labels = pd.Series(labels)

# %%
print(graph_labels)
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 883    1
# 884    1
# 885    1
# 886    1
# 887    1
# Length: 888, dtype: int64

# %%
graph_labels.value_counts().to_frame()
# Out:
#       0
#  1  726
# -1  162

# %%
graph_labels = pd.get_dummies(graph_labels, drop_first=True)

# %%
print(type(graph_labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
graph_labels
# Out:
#      1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 883  1
# 884  1
# 885  1
# 886  1
# 887  1
#
# [888 rows x 1 columns]

# %%
generator = PaddedGraphGenerator(graphs=graphs)

# %%
def create_graph_classification_model(generator):
    gc_model = GCNSupervisedGraphClassification(
        layer_sizes=[64, 64],
        activations=["relu", "relu"],
        generator=generator,
        dropout=0.5,
    )
    x_inp, x_out = gc_model.in_out_tensors()
    predictions = Dense(units=32, activation="relu")(x_out)
    predictions = Dense(units=16, activation="relu")(predictions)
    predictions = Dense(units=1, activation="sigmoid")(predictions)

    # Let's create the Keras model and prepare it for training
    model = Model(inputs=x_inp, outputs=predictions)
    model.compile(optimizer=Adam(0.005), loss=binary_crossentropy, metrics=["acc"])

    return model

# %%
epochs = 200  # maximum number of training epochs
# folds = 10  # the number of folds for k-fold cross validation
# n_repeats = 5  # the number of repeats for repeated k-fold cross validation

# %%
es = EarlyStopping(
    monitor="val_loss", min_delta=0, patience=25, restore_best_weights=True
)

# %%
# To train in folds
def train_fold(model, train_gen, test_gen, es, epochs):
    history = model.fit(
        train_gen, epochs=epochs, validation_data=test_gen, verbose=0, callbacks=[es],
    )
    # calculate performance on the test data and return along with history
    test_metrics = model.evaluate(test_gen, verbose=0)
    test_acc = test_metrics[model.metrics_names.index("acc")]

    return history, test_acc

# %%
# To train in folds
def get_generators(train_index, test_index, graph_labels, batch_size):
    train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, batch_size=batch_size, shuffle=False, seed=42
    )
    test_gen = generator.flow(
        test_index, targets=graph_labels.iloc[test_index].values, batch_size=batch_size, shuffle=False, seed=42
    )

    return train_gen, test_gen

# %%
# # To train in folds
# test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"Training and evaluating on fold {i+1} out of {folds * n_repeats}...")
#     train_gen, test_gen = get_generators(
#         train_index, test_index, graph_labels, batch_size=30
#     )

#     model = create_graph_classification_model(generator)

#     history, acc = train_fold(model, train_gen, test_gen, es, epochs)

#     test_accs.append(acc)

# %%
# To train in folds
test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
for i in range(50):
    print(f"Training and evaluating on fold {i+1}...")
    
    train_gen, test_gen = get_generators(
        train_index, test_index, graph_labels, batch_size=30
    )

    model = create_graph_classification_model(generator)

    history, acc = train_fold(model, train_gen, test_gen, es, epochs)

    test_accs.append(acc)
# Out:
# Training and evaluating on fold 1...
# Training and evaluating on fold 2...
# Training and evaluating on fold 3...
# Training and evaluating on fold 4...
# Training and evaluating on fold 5...
# Training and evaluating on fold 6...
# Training and evaluating on fold 7...
# Training and evaluating on fold 8...
# Training and evaluating on fold 9...
# Training and evaluating on fold 10...
# Training and evaluating on fold 11...
# Training and evaluating on fold 12...
# Training and evaluating on fold 13...
# Training and evaluating on fold 14...
# Training and evaluating on fold 15...
# Training and evaluating on fold 16...
# Training and evaluating on fold 17...
# Training and evaluating on fold 18...
# Training and evaluating on fold 19...
# Training and evaluating on fold 20...
# Training and evaluating on fold 21...
# Training and evaluating on fold 22...
# Training and evaluating on fold 23...
# Training and evaluating on fold 24...
# Training and evaluating on fold 25...
# Training and evaluating on fold 26...
# Training and evaluating on fold 27...
# Training and evaluating on fold 28...
# Training and evaluating on fold 29...
# Training and evaluating on fold 30...
# Training and evaluating on fold 31...
# Training and evaluating on fold 32...
# Training and evaluating on fold 33...
# Training and evaluating on fold 34...
# Training and evaluating on fold 35...
# Training and evaluating on fold 36...
# Training and evaluating on fold 37...
# Training and evaluating on fold 38...
# Training and evaluating on fold 39...
# Training and evaluating on fold 40...
# Training and evaluating on fold 41...
# Training and evaluating on fold 42...
# Training and evaluating on fold 43...
# Training and evaluating on fold 44...
# Training and evaluating on fold 45...
# Training and evaluating on fold 46...
# Training and evaluating on fold 47...
# Training and evaluating on fold 48...
# Training and evaluating on fold 49...
# Training and evaluating on fold 50...

# %%
# 1: Accuracy over all folds mean: 78.4% and std: 1.8%
# 2: Accuracy over all folds mean: 79.7% and std: 1.9%
# 3: Accuracy over all folds mean: 78.7% and std: 2.0%
# 4: Accuracy over all folds mean: 78.3% and std: 1.8%
# 5: Accuracy over all folds mean: 79.2% and std: 2.0%

# -----------------After setting random
# 1: Accuracy over all folds mean: 79.9% and std: 1.9%
# 2: Accuracy over all folds mean: 80.1% and std: 1.8%
# 3: Accuracy over all folds mean: 78.5% and std: 1.6%
# 4: Accuracy over all folds mean: 77.3% and std: 1.9%
# 5: Accuracy over all folds mean: 77.5% and std: 2.0%
# 6: Accuracy over all folds mean: 79.3% and std: 2.3%
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 79.3% and std: 2.3%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 76.6% and std: 2.0%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"\ntrain_index: \n{train_index}\ntest_index: \n{test_index}\n")
#     break
# print(f"train: {len(train_index)}, test: {len(test_index)}")

# %%
train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, batch_size=40, shuffle=False, seed=42)
test_gen = generator.flow(
    test_index, targets=graph_labels.iloc[test_index].values, batch_size=40, shuffle=False, seed=42)

# %%
model_weighted = create_graph_classification_model(generator)

history = model_weighted.fit(
        train_gen, epochs=200, validation_data=test_gen, verbose=1, callbacks=[es])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 77ms/step - loss: 0.4545 - acc: 0.8124 - val_loss: 0.6831 - val_acc: 0.5000
# Epoch 2/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3787 - acc: 0.8505 - val_loss: 0.6394 - val_acc: 0.5000
# Epoch 3/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3466 - acc: 0.8519 - val_loss: 0.5799 - val_acc: 0.5769
# Epoch 4/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3435 - acc: 0.8590 - val_loss: 0.5773 - val_acc: 0.6795
# Epoch 5/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.3203 - acc: 0.8688 - val_loss: 0.6534 - val_acc: 0.6667
# Epoch 6/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.3344 - acc: 0.8590 - val_loss: 0.5594 - val_acc: 0.7179
# Epoch 7/200
# 18/18 [==============================] - 1s 37ms/step - loss: 0.3305 - acc: 0.8731 - val_loss: 0.5513 - val_acc: 0.7051
# Epoch 8/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.3165 - acc: 0.8759 - val_loss: 0.5025 - val_acc: 0.7821
# Epoch 9/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.3068 - acc: 0.8759 - val_loss: 0.5402 - val_acc: 0.7308
# Epoch 10/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3061 - acc: 0.8815 - val_loss: 0.6015 - val_acc: 0.6795
# Epoch 11/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.3211 - acc: 0.8801 - val_loss: 0.5629 - val_acc: 0.7436
# Epoch 12/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3113 - acc: 0.8787 - val_loss: 0.5380 - val_acc: 0.6795
# Epoch 13/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2988 - acc: 0.8829 - val_loss: 0.5589 - val_acc: 0.7436
# Epoch 14/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.2867 - acc: 0.8773 - val_loss: 0.4789 - val_acc: 0.7564
# Epoch 15/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2932 - acc: 0.8829 - val_loss: 0.5177 - val_acc: 0.7821
# Epoch 16/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2699 - acc: 0.8872 - val_loss: 0.4517 - val_acc: 0.7949
# Epoch 17/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2955 - acc: 0.8843 - val_loss: 0.4657 - val_acc: 0.7692
# Epoch 18/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2963 - acc: 0.8886 - val_loss: 0.4670 - val_acc: 0.7692
# Epoch 19/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2709 - acc: 0.8984 - val_loss: 0.5247 - val_acc: 0.7564
# Epoch 20/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2815 - acc: 0.8886 - val_loss: 0.6811 - val_acc: 0.6410
# Epoch 21/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2908 - acc: 0.8914 - val_loss: 0.6899 - val_acc: 0.6923
# Epoch 22/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2949 - acc: 0.8801 - val_loss: 0.6158 - val_acc: 0.7436
# Epoch 23/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2782 - acc: 0.8914 - val_loss: 0.5815 - val_acc: 0.7179
# Epoch 24/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2888 - acc: 0.8858 - val_loss: 0.5642 - val_acc: 0.6795
# Epoch 25/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2613 - acc: 0.8928 - val_loss: 0.4942 - val_acc: 0.7564
# Epoch 26/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2741 - acc: 0.8886 - val_loss: 0.5232 - val_acc: 0.7308
# Epoch 27/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2665 - acc: 0.8914 - val_loss: 0.7339 - val_acc: 0.6923
# Epoch 28/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2651 - acc: 0.8956 - val_loss: 0.5083 - val_acc: 0.7179
# Epoch 29/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2389 - acc: 0.8970 - val_loss: 0.6075 - val_acc: 0.7179
# Epoch 30/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2714 - acc: 0.9041 - val_loss: 0.6651 - val_acc: 0.6923
# Epoch 31/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2547 - acc: 0.8858 - val_loss: 0.4895 - val_acc: 0.7564
# Epoch 32/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2864 - acc: 0.8858 - val_loss: 0.4942 - val_acc: 0.7436
# Epoch 33/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2507 - acc: 0.8872 - val_loss: 0.6530 - val_acc: 0.7179
# Epoch 34/200
# 18/18 [==============================] - 1s 36ms/step - loss: 0.2481 - acc: 0.8942 - val_loss: 0.6970 - val_acc: 0.6667
# Epoch 35/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2423 - acc: 0.9055 - val_loss: 0.5584 - val_acc: 0.7564
# Epoch 36/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2380 - acc: 0.9111 - val_loss: 1.0306 - val_acc: 0.5769
# Epoch 37/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2485 - acc: 0.8999 - val_loss: 0.6896 - val_acc: 0.6923
# Epoch 38/200
# 18/18 [==============================] - 1s 30ms/step - loss: 0.2622 - acc: 0.9027 - val_loss: 0.6254 - val_acc: 0.6667
# Epoch 39/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2390 - acc: 0.9027 - val_loss: 0.4496 - val_acc: 0.8077
# Epoch 40/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2670 - acc: 0.8942 - val_loss: 0.5748 - val_acc: 0.7179
# Epoch 41/200
# 18/18 [==============================] - 0s 27ms/step - loss: 0.2619 - acc: 0.8886 - val_loss: 0.6052 - val_acc: 0.7308
# Epoch 42/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2518 - acc: 0.8956 - val_loss: 0.5485 - val_acc: 0.7179
# Epoch 43/200
# 18/18 [==============================] - 0s 25ms/step - loss: 0.2429 - acc: 0.9069 - val_loss: 0.5876 - val_acc: 0.7051
# Epoch 44/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2291 - acc: 0.9154 - val_loss: 0.6344 - val_acc: 0.7051
# Epoch 45/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2546 - acc: 0.8942 - val_loss: 0.7019 - val_acc: 0.6795
# Epoch 46/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2357 - acc: 0.9083 - val_loss: 0.5528 - val_acc: 0.7564
# Epoch 47/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2447 - acc: 0.9041 - val_loss: 0.6164 - val_acc: 0.6923
# Epoch 48/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2270 - acc: 0.9140 - val_loss: 0.6715 - val_acc: 0.7179
# Epoch 49/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2085 - acc: 0.9252 - val_loss: 0.6481 - val_acc: 0.7179
# Epoch 50/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2148 - acc: 0.9111 - val_loss: 0.6449 - val_acc: 0.7051
# Epoch 51/200
# 18/18 [==============================] - 1s 36ms/step - loss: 0.2249 - acc: 0.9083 - val_loss: 0.6945 - val_acc: 0.7308
# Epoch 52/200
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2425 - acc: 0.9055 - val_loss: 0.5141 - val_acc: 0.7564
# Epoch 53/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2151 - acc: 0.9238 - val_loss: 0.5243 - val_acc: 0.7949
# Epoch 54/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2026 - acc: 0.9168 - val_loss: 0.6427 - val_acc: 0.7051
# Epoch 55/200
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2139 - acc: 0.9126 - val_loss: 0.7280 - val_acc: 0.7051
# Epoch 56/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2376 - acc: 0.9069 - val_loss: 0.6771 - val_acc: 0.6923
# Epoch 57/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2144 - acc: 0.9083 - val_loss: 0.6399 - val_acc: 0.7179
# Epoch 58/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2169 - acc: 0.9055 - val_loss: 0.6096 - val_acc: 0.7308
# Epoch 59/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2308 - acc: 0.9140 - val_loss: 0.5738 - val_acc: 0.7308
# Epoch 60/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2379 - acc: 0.8970 - val_loss: 0.5135 - val_acc: 0.7692
# Epoch 61/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2295 - acc: 0.8984 - val_loss: 0.5606 - val_acc: 0.7949
# Epoch 62/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2455 - acc: 0.9041 - val_loss: 0.6577 - val_acc: 0.7179
# Epoch 63/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2195 - acc: 0.9238 - val_loss: 0.7046 - val_acc: 0.6667
# Epoch 64/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2218 - acc: 0.9224 - val_loss: 0.6804 - val_acc: 0.7308

# %%
# calculate performance on the test data and return along with history
# Node features 128 node2vec, edge features all 1
test_metrics = model_weighted.evaluate(test_gen, verbose=1)
test_acc = test_metrics[model_weighted.metrics_names.index("acc")]
# Out:
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4496 - acc: 0.8077

# %%
print(test_metrics)
#test loss, test acc: [0.4930313229560852, 0.7435897588729858]
# 2nd try: [0.49709418416023254, 0.7948718070983887]
# 3d [0.5272901654243469, 0.7435897588729858]
# 4: [0.4769172668457031, 0.7307692170143127]
print(test_acc)
# Out:
# [0.4495735168457031, 0.807692289352417]
# 0.807692289352417

# %%
print("Generate predictions for samples")
predictions = model_weighted.predict(test_gen, verbose=0)
print("predictions shape:", predictions.shape)
# predictions shape: (79, 1)
print(predictions)

# %%
print(test_gen.targets)
