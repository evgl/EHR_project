# %% [markdown]
# ### Data extraction
# Extract data from MIMIC-III

# %%
import time
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Import pandas 
import pandas as pd 

start = time.time()
# reading csv file 
admissions_df = pd.read_csv("../../datasets/mmc-3/ADMISSIONS.csv")
noteevents_df = pd.read_csv("../../datasets/mmc-3/NOTEEVENTS.csv") 
end = time.time()
print(end - start)
# Out:
# /home/evan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning:
#
# Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
# 32.93941640853882

# %%
start = time.time()
# Left join of two dataframes
note_admiss_df_left = noteevents_df.merge(admissions_df, on='HADM_ID', how='left', indicator=True)
end = time.time()
print(end - start)
# Out:
# 4.417093515396118

# %%
note_admiss_df_left[['DIAGNOSIS', 'SUBJECT_ID_x', 'SUBJECT_ID_y','DESCRIPTION', 'CATEGORY']]
# Out:
#                                      DIAGNOSIS  SUBJECT_ID_x  SUBJECT_ID_y  \
# 0                      RT LOWER LOBE PNEUMONIA         22532       22532.0
# 1        CHRONIC OBSTRUCTIVE PULMONARY DISEASE         13702       13702.0
# 2                TRACHEALBRONCHEAL MALACEA/SDA         13702       13702.0
# 3                     ASTHMA;COPD EXACERBATION         13702       13702.0
# 4                           S/P FALL;TELEMETRY         26880       26880.0
# ...                                        ...           ...           ...
# 2083175                                NEWBORN         31097       31097.0
# 2083176                                NEWBORN         31097       31097.0
# 2083177                                NEWBORN         31097       31097.0
# 2083178                                NEWBORN         31097       31097.0
# 2083179                                NEWBORN         31097       31097.0
#
#         DESCRIPTION           CATEGORY
# 0            Report  Discharge summary
# 1            Report  Discharge summary
# 2            Report  Discharge summary
# 3            Report  Discharge summary
# 4            Report  Discharge summary
# ...             ...                ...
# 2083175      Report      Nursing/other
# 2083176      Report      Nursing/other
# 2083177      Report      Nursing/other
# 2083178      Report      Nursing/other
# 2083179      Report      Nursing/other
#
# [2083180 rows x 5 columns]

# %%
pneumonia_df = note_admiss_df_left.loc[note_admiss_df_left["DIAGNOSIS"] == 'PNEUMONIA', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]

# %%
#pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]
pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x','SUBJECT_ID_x','CHARTDATE','STORETIME','CATEGORY','DESCRIPTION','TEXT', 'DEATHTIME']]

# %%
pneumonia_alive_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.isnull()]
pneumonia_dead_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.notnull()]

# %%
pneumonia_dead_no_disch.shape
# Out:
# (11895, 8)

# %%
pneumonia_alive_no_disch.shape
# Out:
# (46134, 8)

# %%
pneumonia_alive_no_disch = pneumonia_alive_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])
pneumonia_dead_no_disch = pneumonia_dead_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])

# %%
# Number of patients
pneumonia_dead_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 252

# %%
# Number of patients
pneumonia_alive_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 1167

# %%
# import text handling tool
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from collections import Counter

import sys
import re
import csv
import os.path

# define constants
# RESULT_HEADER = "WORD, FREQUENCY\n"
MIN_SEQ_LEN = 4
USE_1_N_SEQ = 2


# words that do not have meaning (can be modified later)
USELESS_WORDS = ["a", "the", "he", "she", ",", ".", "?", "!", ":", ";", "+", "*", "**"\
                 "your", "you"]

# count up the frequency of every word in every disease file
stemmer = PorterStemmer()
# create set of words to ignore in text
stop_words = set(stopwords.words('english'))

for word in USELESS_WORDS:
    stop_words.add(word)

# %%
#----------
def count_notes_per_patient(disease_df):
    patient_id_to_num_notes = {}
    patient_id = -1
    note_counter = 0
            
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        patient_id_check = int(row['SUBJECT_ID_x'])
                
        if not patient_id == patient_id_check:
            patient_id_to_num_notes[patient_id] = note_counter
            note_counter = 1
        else:
            note_counter += 1
                    
        patient_id = patient_id_check
                
    patient_id_to_num_notes[patient_id] = note_counter
    del patient_id_to_num_notes[-1]
    return patient_id_to_num_notes

patient_id_to_num_notes = {}
patient_id_to_num_notes['pneumonia_dead'] = count_notes_per_patient(pneumonia_dead_no_disch)
patient_id_to_num_notes['pneumonia_alive'] = count_notes_per_patient(pneumonia_alive_no_disch)
# Out:
# 100%|██████████| 11895/11895 [00:01<00:00, 8937.40it/s]
# 100%|██████████| 46134/46134 [00:04<00:00, 9342.53it/s]

# %%
patient_id_to_num_notes
# Out:
# {'pneumonia_dead': {111: 12,
#   346: 25,
#   404: 3,
#   546: 6,
#   618: 16,
#   705: 15,
#   726: 48,
#   1039: 55,
#   1556: 37,
#   1872: 3,
#   1944: 56,
#   2286: 69,
#   2990: 166,
#   3055: 29,
#   3099: 13,
#   3201: 8,
#   3526: 7,
#   3773: 6,
#   3881: 20,
#   4122: 51,
#   4754: 101,
#   4811: 21,
#   5476: 1,
#   5494: 22,
#   5774: 104,
#   5786: 152,
#   5913: 1,
#   6133: 68,
#   6735: 13,
#   6745: 13,
#   6973: 36,
#   6981: 8,
#   7277: 66,
#   7310: 8,
#   7924: 9,
#   7977: 9,
#   9908: 11,
#   9984: 15,
#   10302: 100,
#   10510: 86,
#   10545: 10,
#   10642: 10,
#   11049: 14,
#   11209: 9,
#   11395: 41,
#   12530: 24,
#   12849: 50,
#   13098: 46,
#   13566: 23,
#   14125: 9,
#   14514: 96,
#   14965: 25,
#   15159: 15,
#   15251: 11,
#   15396: 17,
#   15566: 37,
#   15853: 45,
#   16275: 17,
#   16344: 27,
#   16622: 51,
#   16684: 29,
#   17122: 16,
#   17354: 5,
#   17802: 64,
#   17983: 65,
#   18094: 23,
#   18736: 35,
#   18768: 46,
#   18848: 205,
#   18971: 26,
#   19243: 25,
#   19323: 6,
#   19390: 21,
#   19463: 20,
#   19535: 59,
#   19754: 13,
#   19827: 22,
#   19833: 58,
#   19872: 10,
#   20006: 8,
#   20023: 9,
#   20190: 6,
#   21046: 101,
#   21094: 36,
#   21427: 10,
#   21502: 102,
#   21580: 52,
#   21676: 12,
#   21699: 7,
#   21979: 11,
#   22735: 15,
#   23660: 12,
#   23795: 78,
#   24181: 13,
#   24582: 37,
#   24725: 57,
#   24730: 19,
#   24854: 25,
#   25003: 182,
#   25046: 7,
#   25774: 61,
#   25975: 9,
#   26474: 89,
#   26578: 15,
#   26716: 41,
#   26774: 3,
#   26849: 33,
#   27005: 5,
#   27145: 24,
#   27421: 61,
#   27431: 5,
#   27496: 7,
#   27504: 72,
#   27639: 221,
#   28004: 13,
#   28072: 34,
#   28178: 202,
#   28427: 6,
#   28498: 25,
#   28726: 34,
#   28750: 19,
#   28906: 32,
#   28907: 13,
#   28933: 394,
#   29105: 468,
#   29588: 72,
#   29647: 26,
#   29872: 225,
#   30476: 174,
#   30549: 12,
#   30614: 8,
#   30699: 14,
#   30786: 9,
#   30941: 110,
#   31030: 168,
#   31134: 24,
#   31139: 9,
#   31451: 48,
#   31556: 57,
#   31690: 18,
#   31692: 35,
#   32050: 34,
#   32326: 24,
#   32618: 42,
#   41546: 25,
#   43937: 6,
#   44851: 274,
#   45381: 16,
#   46589: 26,
#   46763: 6,
#   47045: 9,
#   48632: 147,
#   49079: 20,
#   49683: 3,
#   49922: 13,
#   50093: 8,
#   50231: 3,
#   50556: 216,
#   50859: 537,
#   51914: 313,
#   52010: 12,
#   53105: 115,
#   53399: 78,
#   54193: 85,
#   54401: 14,
#   54408: 2,
#   54739: 75,
#   54946: 7,
#   55400: 5,
#   55570: 14,
#   55887: 37,
#   55944: 34,
#   55987: 20,
#   56390: 19,
#   56648: 8,
#   56854: 170,
#   57091: 88,
#   57102: 35,
#   58702: 479,
#   59260: 11,
#   59437: 26,
#   60849: 2,
#   60868: 6,
#   61652: 7,
#   61667: 30,
#   63039: 8,
#   65513: 8,
#   68044: 40,
#   68095: 23,
#   68184: 5,
#   68308: 8,
#   68860: 14,
#   69719: 13,
#   69745: 25,
#   69776: 17,
#   70226: 8,
#   70447: 9,
#   72930: 11,
#   73811: 9,
#   73888: 109,
#   74316: 2,
#   74444: 81,
#   74686: 75,
#   75824: 10,
#   76282: 21,
#   76827: 2,
#   77382: 10,
#   78241: 3,
#   78388: 14,
#   79008: 27,
#   79055: 21,
#   79222: 18,
#   79877: 156,
#   80637: 148,
#   80678: 9,
#   80737: 46,
#   80805: 79,
#   81437: 27,
#   82393: 5,
#   82769: 85,
#   83932: 2,
#   84474: 34,
#   85160: 8,
#   85258: 52,
#   85404: 11,
#   85797: 9,
#   86007: 35,
#   86394: 4,
#   86684: 11,
#   86832: 67,
#   86863: 8,
#   86872: 326,
#   88193: 16,
#   88660: 11,
#   90256: 18,
#   91350: 19,
#   92074: 28,
#   92278: 52,
#   92331: 42,
#   93422: 7,
#   94341: 2,
#   94997: 9,
#   95280: 23,
#   95803: 18,
#   95830: 33,
#   95933: 56,
#   96699: 85,
#   97181: 30,
#   97795: 60,
#   98009: 33,
#   98299: 29,
#   98597: 2},
#  'pneumonia_alive': {68: 18,
#   85: 8,
#   94: 100,
#   165: 2,
#   211: 24,
#   224: 8,
#   231: 75,
#   283: 131,
#   357: 17,
#   368: 45,
#   370: 13,
#   384: 26,
#   426: 10,
#   509: 34,
#   514: 7,
#   596: 23,
#   674: 16,
#   707: 29,
#   711: 537,
#   770: 83,
#   773: 74,
#   899: 17,
#   1096: 17,
#   1135: 32,
#   1163: 12,
#   1174: 42,
#   1180: 5,
#   1283: 3,
#   1332: 66,
#   1339: 134,
#   1546: 21,
#   1568: 22,
#   1601: 12,
#   1606: 13,
#   1642: 4,
#   1660: 23,
#   1895: 22,
#   1923: 23,
#   2029: 175,
#   2090: 179,
#   2098: 26,
#   2128: 31,
#   2170: 9,
#   2187: 30,
#   2208: 139,
#   2337: 8,
#   2378: 57,
#   2386: 18,
#   2452: 22,
#   2508: 22,
#   2561: 126,
#   2585: 9,
#   2589: 92,
#   2590: 5,
#   2628: 218,
#   2658: 16,
#   2732: 12,
#   2784: 23,
#   2823: 21,
#   3070: 8,
#   3100: 70,
#   3154: 22,
#   3220: 28,
#   3277: 35,
#   3347: 15,
#   3359: 15,
#   3516: 11,
#   3602: 18,
#   3623: 116,
#   3641: 57,
#   3676: 49,
#   3830: 80,
#   3860: 203,
#   3862: 22,
#   3865: 8,
#   3895: 6,
#   3935: 44,
#   3952: 20,
#   3975: 34,
#   4109: 9,
#   4155: 23,
#   4236: 14,
#   4275: 45,
#   4316: 13,
#   4317: 106,
#   4328: 23,
#   4388: 14,
#   4454: 5,
#   4467: 12,
#   4489: 21,
#   4494: 18,
#   4584: 39,
#   4588: 80,
#   4641: 23,
#   4694: 19,
#   4804: 6,
#   5030: 49,
#   5145: 9,
#   5244: 113,
#   5264: 115,
#   5360: 19,
#   5434: 24,
#   5476: 36,
#   5516: 31,
#   5536: 21,
#   5564: 30,
#   5579: 14,
#   5609: 39,
#   5619: 25,
#   5631: 9,
#   5681: 9,
#   5691: 12,
#   5727: 41,
#   5761: 85,
#   5819: 19,
#   5904: 16,
#   5937: 61,
#   6038: 4,
#   6143: 15,
#   6176: 5,
#   6183: 17,
#   6206: 7,
#   6279: 20,
#   6378: 112,
#   6398: 11,
#   6557: 16,
#   6603: 15,
#   6884: 43,
#   6901: 8,
#   6915: 190,
#   7107: 230,
#   7169: 9,
#   7271: 117,
#   7356: 12,
#   7363: 284,
#   7492: 58,
#   7569: 32,
#   7603: 39,
#   7666: 9,
#   7700: 68,
#   7787: 18,
#   7849: 96,
#   7936: 3,
#   8070: 69,
#   8312: 29,
#   8337: 22,
#   8366: 25,
#   8471: 15,
#   8512: 16,
#   8515: 21,
#   8532: 9,
#   8556: 71,
#   8803: 4,
#   8895: 10,
#   8900: 11,
#   9124: 18,
#   9128: 2,
#   9253: 76,
#   9304: 12,
#   9332: 7,
#   9457: 6,
#   9505: 2,
#   9518: 80,
#   9544: 228,
#   9727: 37,
#   9736: 19,
#   9859: 12,
#   9871: 17,
#   9957: 15,
#   9973: 59,
#   10057: 144,
#   10207: 36,
#   10299: 167,
#   10304: 8,
#   10377: 125,
#   10502: 9,
#   10581: 11,
#   10589: 18,
#   10626: 72,
#   10635: 6,
#   10666: 84,
#   10675: 13,
#   10761: 9,
#   10830: 14,
#   10848: 16,
#   10950: 23,
#   11003: 63,
#   11018: 24,
#   11061: 11,
#   11065: 40,
#   11197: 14,
#   11236: 58,
#   11247: 6,
#   11275: 26,
#   11313: 9,
#   11320: 66,
#   11421: 37,
#   11446: 13,
#   11593: 19,
#   11616: 64,
#   11671: 14,
#   11702: 7,
#   11708: 44,
#   11747: 20,
#   11762: 10,
#   11829: 25,
#   11850: 23,
#   11860: 11,
#   11932: 18,
#   11989: 17,
#   12028: 221,
#   12140: 36,
#   12177: 53,
#   12183: 26,
#   12274: 9,
#   12312: 13,
#   12380: 45,
#   12508: 136,
#   12567: 61,
#   12585: 4,
#   12629: 43,
#   12633: 11,
#   12799: 77,
#   12803: 21,
#   12824: 21,
#   13123: 10,
#   13329: 22,
#   13330: 13,
#   13503: 15,
#   13546: 20,
#   13577: 7,
#   13593: 20,
#   13615: 10,
#   13627: 31,
#   13664: 120,
#   13728: 13,
#   13748: 21,
#   13864: 5,
#   13881: 2,
#   14035: 12,
#   14144: 24,
#   14172: 9,
#   14193: 8,
#   14256: 26,
#   14269: 21,
#   14309: 13,
#   14342: 20,
#   14385: 14,
#   14507: 9,
#   14520: 56,
#   14705: 17,
#   14805: 16,
#   14855: 96,
#   14975: 23,
#   15046: 86,
#   15054: 33,
#   15301: 5,
#   15347: 4,
#   15361: 15,
#   15472: 13,
#   15590: 85,
#   15716: 323,
#   15852: 15,
#   15875: 192,
#   16038: 89,
#   16053: 17,
#   16076: 397,
#   16102: 6,
#   16129: 22,
#   16147: 7,
#   16216: 17,
#   16275: 90,
#   16318: 12,
#   16367: 47,
#   16384: 48,
#   16409: 40,
#   16412: 8,
#   16438: 28,
#   16468: 15,
#   16469: 20,
#   16479: 7,
#   16492: 6,
#   16554: 19,
#   16560: 8,
#   16685: 1,
#   16733: 14,
#   16755: 24,
#   16800: 12,
#   16802: 27,
#   16850: 14,
#   16975: 186,
#   16992: 42,
#   17107: 6,
#   17149: 17,
#   17150: 23,
#   17250: 28,
#   17260: 10,
#   17276: 10,
#   17539: 24,
#   17547: 9,
#   17617: 4,
#   17631: 19,
#   17664: 24,
#   17722: 8,
#   17764: 3,
#   17795: 215,
#   17843: 37,
#   17882: 6,
#   17903: 7,
#   17906: 88,
#   18082: 22,
#   18123: 146,
#   18233: 8,
#   18250: 2,
#   18281: 61,
#   18320: 207,
#   18353: 16,
#   18365: 10,
#   18459: 33,
#   18637: 35,
#   18673: 38,
#   18681: 10,
#   18737: 7,
#   18999: 40,
#   19029: 4,
#   19036: 12,
#   19164: 20,
#   19463: 14,
#   19569: 4,
#   19653: 30,
#   19698: 79,
#   19793: 37,
#   19803: 9,
#   19833: 77,
#   19851: 83,
#   19859: 14,
#   19940: 9,
#   20061: 7,
#   20086: 85,
#   20133: 121,
#   20181: 204,
#   20187: 25,
#   20263: 6,
#   20265: 7,
#   20289: 63,
#   20381: 10,
#   20425: 103,
#   20528: 37,
#   20580: 1,
#   20598: 31,
#   20600: 16,
#   20624: 32,
#   20643: 20,
#   20804: 25,
#   20899: 17,
#   20951: 8,
#   20979: 26,
#   21037: 21,
#   21056: 9,
#   21093: 60,
#   21255: 3,
#   21269: 279,
#   21277: 23,
#   21301: 16,
#   21350: 18,
#   21548: 7,
#   21581: 11,
#   21737: 7,
#   21745: 5,
#   21764: 7,
#   22019: 2,
#   22180: 5,
#   22192: 5,
#   22287: 10,
#   22432: 6,
#   22450: 11,
#   22520: 63,
#   22534: 4,
#   22580: 10,
#   22624: 43,
#   22667: 72,
#   22684: 14,
#   22706: 8,
#   22754: 44,
#   22855: 47,
#   22921: 2,
#   23028: 22,
#   23109: 2,
#   23131: 49,
#   23161: 29,
#   23215: 9,
#   23318: 15,
#   23418: 22,
#   23423: 11,
#   23451: 26,
#   23568: 8,
#   23657: 34,
#   23734: 15,
#   23763: 21,
#   23847: 9,
#   24099: 2,
#   24170: 2,
#   24178: 209,
#   24276: 82,
#   24344: 290,
#   24483: 7,
#   24535: 23,
#   24562: 10,
#   24569: 20,
#   24622: 1,
#   24687: 45,
#   24807: 41,
#   24847: 12,
#   24868: 57,
#   24903: 45,
#   25001: 25,
#   25016: 78,
#   25038: 66,
#   25097: 42,
#   25117: 38,
#   25225: 17,
#   25256: 30,
#   25295: 59,
#   25326: 17,
#   25373: 158,
#   25406: 5,
#   25515: 18,
#   25526: 86,
#   25579: 27,
#   25591: 61,
#   25671: 11,
#   25750: 107,
#   25775: 38,
#   25844: 22,
#   25860: 9,
#   25861: 16,
#   25889: 20,
#   25941: 86,
#   26036: 11,
#   26040: 79,
#   26052: 3,
#   26080: 5,
#   26097: 65,
#   26118: 60,
#   26311: 28,
#   26391: 64,
#   26398: 14,
#   26469: 52,
#   26542: 55,
#   26601: 58,
#   26638: 155,
#   26727: 10,
#   26797: 8,
#   26869: 11,
#   26884: 5,
#   26887: 4,
#   26956: 23,
#   27003: 18,
#   27036: 10,
#   27043: 30,
#   27047: 41,
#   27049: 14,
#   27089: 24,
#   27121: 89,
#   27143: 135,
#   27172: 9,
#   27179: 118,
#   27194: 60,
#   27269: 19,
#   27367: 84,
#   27371: 17,
#   27431: 33,
#   27486: 2,
#   27576: 84,
#   27597: 60,
#   27600: 28,
#   27677: 11,
#   27726: 59,
#   27729: 70,
#   27752: 11,
#   27800: 12,
#   27809: 18,
#   27823: 31,
#   27879: 13,
#   27886: 30,
#   27999: 25,
#   28050: 20,
#   28055: 4,
#   28073: 74,
#   28093: 21,
#   28103: 16,
#   28164: 159,
#   28173: 124,
#   28230: 23,
#   28291: 36,
#   28298: 31,
#   28356: 10,
#   28527: 46,
#   28530: 24,
#   28642: 2,
#   28668: 3,
#   28671: 33,
#   28689: 5,
#   28717: 23,
#   28729: 73,
#   28742: 7,
#   28758: 94,
#   28827: 12,
#   28843: 1,
#   28884: 12,
#   28932: 24,
#   28935: 4,
#   28939: 4,
#   28973: 152,
#   29007: 9,
#   29043: 12,
#   29093: 5,
#   29096: 21,
#   29102: 18,
#   29129: 15,
#   29137: 8,
#   29139: 17,
#   29141: 27,
#   29219: 19,
#   29240: 10,
#   29274: 17,
#   29350: 18,
#   29377: 80,
#   29379: 21,
#   29456: 22,
#   29478: 32,
#   29501: 6,
#   29503: 11,
#   29504: 18,
#   29513: 65,
#   29528: 5,
#   29556: 5,
#   29566: 17,
#   29619: 18,
#   29638: 15,
#   29639: 26,
#   29660: 9,
#   29703: 12,
#   29866: 12,
#   29872: 14,
#   29913: 11,
#   29919: 24,
#   29927: 63,
#   29965: 26,
#   29972: 7,
#   30010: 7,
#   30015: 36,
#   30139: 529,
#   30208: 18,
#   30227: 35,
#   30287: 23,
#   30299: 1,
#   30301: 117,
#   30316: 17,
#   30365: 47,
#   30490: 17,
#   30501: 10,
#   30505: 33,
#   30561: 6,
#   30575: 6,
#   30599: 24,
#   30631: 11,
#   30663: 24,
#   30696: 54,
#   30786: 11,
#   30798: 14,
#   30860: 28,
#   31003: 45,
#   31183: 129,
#   31216: 80,
#   31221: 17,
#   31262: 28,
#   31298: 13,
#   31332: 59,
#   31361: 20,
#   31442: 32,
#   31470: 17,
#   31516: 74,
#   31528: 60,
#   31544: 11,
#   31580: 34,
#   31585: 39,
#   31610: 17,
#   31660: 3,
#   31664: 45,
#   31692: 23,
#   31723: 17,
#   31813: 234,
#   31942: 102,
#   31986: 41,
#   32018: 145,
#   32061: 11,
#   32106: 18,
#   32135: 12,
#   32161: 25,
#   32181: 8,
#   32183: 27,
#   32193: 16,
#   32268: 6,
#   32286: 117,
#   32355: 6,
#   32367: 42,
#   32394: 6,
#   32414: 485,
#   32436: 271,
#   32583: 5,
#   32605: 19,
#   32639: 12,
#   32740: 48,
#   32746: 11,
#   32773: 112,
#   32790: 103,
#   40059: 11,
#   40124: 68,
#   40246: 20,
#   40370: 11,
#   40442: 107,
#   40456: 43,
#   40576: 48,
#   40631: 4,
#   40911: 35,
#   41192: 45,
#   41373: 28,
#   41434: 10,
#   41446: 8,
#   41890: 7,
#   41958: 5,
#   41962: 10,
#   41976: 177,
#   42009: 30,
#   42035: 49,
#   42054: 18,
#   42194: 1,
#   42346: 30,
#   42458: 9,
#   42515: 38,
#   42572: 17,
#   42715: 21,
#   42794: 6,
#   42924: 3,
#   43067: 90,
#   43074: 18,
#   43112: 394,
#   43128: 1,
#   43147: 150,
#   43305: 48,
#   43323: 15,
#   43937: 4,
#   43943: 6,
#   43959: 3,
#   44146: 16,
#   44206: 5,
#   44214: 30,
#   44326: 8,
#   44437: 12,
#   44530: 2,
#   44534: 37,
#   44741: 8,
#   44787: 7,
#   44829: 55,
#   44841: 19,
#   44848: 2,
#   45193: 11,
#   45280: 9,
#   45435: 7,
#   46011: 61,
#   46335: 49,
#   46366: 42,
#   46415: 53,
#   46521: 14,
#   46728: 34,
#   46926: 1,
#   46961: 1,
#   47216: 17,
#   47219: 67,
#   47407: 2,
#   47467: 6,
#   47670: 7,
#   47747: 12,
#   47852: 95,
#   47930: 5,
#   48058: 4,
#   48143: 6,
#   48297: 11,
#   48340: 7,
#   48660: 343,
#   48687: 15,
#   48750: 8,
#   48812: 36,
#   48837: 14,
#   48929: 7,
#   49292: 18,
#   49510: 31,
#   49558: 347,
#   49623: 9,
#   49747: 7,
#   49764: 10,
#   49963: 4,
#   50007: 4,
#   50041: 10,
#   50093: 6,
#   50257: 11,
#   50294: 20,
#   50409: 75,
#   50762: 8,
#   50772: 17,
#   50807: 21,
#   50828: 126,
#   50911: 81,
#   50998: 29,
#   51195: 29,
#   51237: 11,
#   51401: 33,
#   51418: 68,
#   51497: 3,
#   51545: 97,
#   51601: 5,
#   51607: 5,
#   51669: 10,
#   51933: 5,
#   52011: 8,
#   52054: 1,
#   52172: 13,
#   52191: 46,
#   52307: 5,
#   52452: 5,
#   52606: 54,
#   52622: 5,
#   52898: 6,
#   52957: 52,
#   53119: 7,
#   53160: 13,
#   53173: 14,
#   53534: 9,
#   53650: 15,
#   53743: 151,
#   53749: 6,
#   53847: 14,
#   54172: 6,
#   54197: 13,
#   54305: 8,
#   54514: 116,
#   54709: 9,
#   54741: 5,
#   54832: 7,
#   54922: 2,
#   55059: 17,
#   55074: 7,
#   55188: 9,
#   55571: 212,
#   55700: 4,
#   55753: 37,
#   55841: 14,
#   55920: 17,
#   56027: 7,
#   56229: 31,
#   56440: 9,
#   56490: 12,
#   56621: 11,
#   56635: 2,
#   56772: 31,
#   56798: 4,
#   56867: 16,
#   56874: 51,
#   57050: 205,
#   57081: 32,
#   57157: 5,
#   57277: 19,
#   57290: 15,
#   57449: 17,
#   57788: 36,
#   57795: 7,
#   57889: 105,
#   58105: 49,
#   58242: 6,
#   58264: 7,
#   58286: 20,
#   58416: 3,
#   58433: 51,
#   58522: 9,
#   58580: 5,
#   58610: 13,
#   58631: 15,
#   58732: 5,
#   58794: 32,
#   58810: 10,
#   58955: 6,
#   59275: 1,
#   59278: 17,
#   59411: 6,
#   59496: 75,
#   59765: 300,
#   59789: 10,
#   59801: 2,
#   59822: 14,
#   59903: 483,
#   59943: 121,
#   60003: 9,
#   60050: 4,
#   60130: 44,
#   60674: 10,
#   60685: 4,
#   60958: 8,
#   60977: 9,
#   61005: 10,
#   61084: 216,
#   61195: 9,
#   61259: 83,
#   61331: 4,
#   61630: 19,
#   61738: 6,
#   61886: 6,
#   62231: 4,
#   62239: 5,
#   62284: 6,
#   62402: 56,
#   62641: 8,
#   62733: 9,
#   62858: 120,
#   63145: 25,
#   63327: 16,
#   63351: 10,
#   63362: 7,
#   63430: 56,
#   63499: 32,
#   63560: 25,
#   63943: 31,
#   63968: 10,
#   64160: 4,
#   64232: 28,
#   64249: 7,
#   64715: 17,
#   65004: 11,
#   65027: 1,
#   65033: 2,
#   65164: 4,
#   65361: 20,
#   65435: 40,
#   65449: 6,
#   65515: 5,
#   65582: 576,
#   65594: 9,
#   65692: 25,
#   65710: 18,
#   65837: 47,
#   66002: 636,
#   66009: 373,
#   66206: 12,
#   66412: 5,
#   66492: 1,
#   66549: 36,
#   66556: 20,
#   66671: 32,
#   66739: 1,
#   66753: 8,
#   66823: 21,
#   67053: 238,
#   67111: 16,
#   67117: 19,
#   67408: 15,
#   67446: 8,
#   67796: 7,
#   67844: 7,
#   67887: 13,
#   68059: 3,
#   68315: 3,
#   68591: 7,
#   68791: 13,
#   68836: 7,
#   68839: 21,
#   68905: 3,
#   68944: 39,
#   68962: 1,
#   69098: 12,
#   69158: 13,
#   69250: 4,
#   69296: 13,
#   69359: 26,
#   69380: 265,
#   69483: 26,
#   69546: 64,
#   69556: 11,
#   69578: 7,
#   69673: 6,
#   69776: 53,
#   69799: 6,
#   69932: 6,
#   70285: 2,
#   70466: 18,
#   70476: 22,
#   70492: 10,
#   70563: 3,
#   70645: 29,
#   70682: 48,
#   70728: 12,
#   71107: 9,
#   71108: 220,
#   71220: 45,
#   71336: 5,
#   71377: 39,
#   71915: 6,
#   71943: 4,
#   71983: 3,
#   72229: 189,
#   72230: 154,
#   72233: 2,
#   72378: 7,
#   72532: 6,
#   72714: 4,
#   72751: 35,
#   73043: 3,
#   73107: 479,
#   73129: 105,
#   73388: 37,
#   73389: 87,
#   73479: 3,
#   73686: 4,
#   73713: 458,
#   73770: 9,
#   73808: 49,
#   73899: 2,
#   73941: 7,
#   74016: 8,
#   74253: 388,
#   74505: 32,
#   74562: 98,
#   74640: 7,
#   74654: 7,
#   75047: 3,
#   75107: 124,
#   75200: 87,
#   75387: 14,
#   75446: 34,
#   75609: 5,
#   75640: 45,
#   75741: 8,
#   75782: 90,
#   75806: 3,
#   75983: 9,
#   76021: 39,
#   76056: 1,
#   76074: 31,
#   76141: 4,
#   76178: 22,
#   76437: 5,
#   76446: 18,
#   76476: 3,
#   76797: 6,
#   76915: 8,
#   76993: 13,
#   77019: 8,
#   77128: 9,
#   77177: 14,
#   77237: 198,
#   77279: 2,
#   77434: 18,
#   77453: 2,
#   77469: 31,
#   77676: 4,
#   77690: 19,
#   77697: 10,
#   77816: 8,
#   77947: 11,
#   78017: 2,
#   78086: 110,
#   78565: 78,
#   78705: 3,
#   78707: 16,
#   78859: 5,
#   78914: 13,
#   79079: 18,
#   79090: 16,
#   79115: 12,
#   79292: 15,
#   80045: 6,
#   80106: 5,
#   80218: 13,
#   80430: 10,
#   80722: 3,
#   80813: 11,
#   80825: 3,
#   81114: 58,
#   81223: 39,
#   81233: 22,
#   81436: 9,
#   81745: 28,
#   81840: 25,
#   81960: 8,
#   81992: 11,
#   82100: 74,
#   82104: 2,
#   82150: 84,
#   82202: 28,
#   82211: 647,
#   82309: 9,
#   ...}}

# %%
print(len(patient_id_to_num_notes['pneumonia_dead']))
print(len(patient_id_to_num_notes['pneumonia_alive']))
# Out:
# 252
# 1167

# %%
pneumonia_dead_no_disch.loc[pneumonia_dead_no_disch["SUBJECT_ID_x"] == 111, ['ROW_ID_x','SUBJECT_ID_x','DESCRIPTION','TEXT', 'DEATHTIME']]
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 70391       70124           111
# 142529     151749           111
# 142097     151750           111
# 142303     151751           111
# 380576     375732           111
# 380109     375744           111
# 379907     375749           111
# 379806     375753           111
# 379909     375760           111
# 1066971   1079317           111
# 1065833   1079339           111
# 1067121   1079351           111
#
#                                                DESCRIPTION  \
# 70391                                               Report
# 142529                                              Report
# 142097                                              Report
# 142303                                              Report
# 380576                   Physician Resident Admission Note
# 380109                                      ICU Event Note
# 379907   Physician Resident/Attending Admission Note - ...
# 379806                          Social Work Admission Note
# 379909                                      ICU Event Note
# 1066971                                CHEST (PORTABLE AP)
# 1065833                                CHEST (PORTABLE AP)
# 1067121                         CHEST PORT. LINE PLACEMENT
#
#                                                       TEXT  \
# 70391    PATIENT/TEST INFORMATION:\nIndication: s/p PEA...
# 142529   Compared to the previous tracing QRS voltage i...
# 142097   Normal sinus rhythm, rate 80.  Biatrial abnorm...
# 142303   Normal sinus rhythm.  Q waves in leads V1-V2 c...
# 380576   Chief Complaint:  respiratory distress\n   HPI...
# 380109   Clinician:  Nurse\n   Pt admitted from the ED ...
# 379907   Chief Complaint:  respiratory distress\n   HPI...
# 379806   Social Work Initial Note:\n   Family Informati...
# 379909   TITLE:\n   Clinician:  Resident\n   Patient ex...
# 1066971  [**2144-7-1**] 2:43 AM\n CHEST (PORTABLE AP)  ...
# 1065833  [**2144-7-1**] 7:27 AM\n CHEST (PORTABLE AP); ...
# 1067121  [**2144-7-1**] 9:01 AM\n CHEST PORT. LINE PLAC...
#
#                    DEATHTIME
# 70391    2144-07-01 14:55:00
# 142529   2144-07-01 14:55:00
# 142097   2144-07-01 14:55:00
# 142303   2144-07-01 14:55:00
# 380576   2144-07-01 14:55:00
# 380109   2144-07-01 14:55:00
# 379907   2144-07-01 14:55:00
# 379806   2144-07-01 14:55:00
# 379909   2144-07-01 14:55:00
# 1066971  2144-07-01 14:55:00
# 1065833  2144-07-01 14:55:00
# 1067121  2144-07-01 14:55:00

# %%
def count_words_per_patient(disease_df, patient_id_to_num_notes):
    note_appearance_counter = {}
    number_of_patients = 0 # number of patients
    note_counter = 0

# -----------
    patient_id = -1
    word_set = set()
    note_event_counter = 0

    # Iterate through each note
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):

        
        patient_id_check = int(row['SUBJECT_ID_x'])
    
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check:
            number_of_patients += 1
            note_event_counter = 0
        
            for word in word_set:
                if word in note_appearance_counter:
                    note_appearance_counter[word] += 1
                else:
                    note_appearance_counter[word] = 1

        
            # reset word_set
            word_set = set()
        
        # update patient id
        patient_id = patient_id_check

            
        if patient_id_to_num_notes[patient_id_check] <= MIN_SEQ_LEN:
            continue
            
        if note_event_counter < patient_id_to_num_notes[patient_id] // USE_1_N_SEQ:
            note_event_counter += 1
            continue
                
        note_counter += 1
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        tokenized_note = word_tokenize(note)
        
        
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())
            if not stemmed_word in stop_words:
                word_set.add(stemmed_word)
    
    print(str(note_counter) + " note events")
    print("finished counting frequent words for patients!")
#     return note_counter, note_appearance_counter
    return number_of_patients, note_appearance_counter

# variable dictionaries
number_of_notes = {}
note_appearance_counter = {}

number_of_notes['pneumonia_dead'], note_appearance_counter['pneumonia_dead'] = count_words_per_patient(pneumonia_dead_no_disch, patient_id_to_num_notes['pneumonia_dead'])
number_of_notes['pneumonia_alive'], note_appearance_counter['pneumonia_alive'] = count_words_per_patient(pneumonia_alive_no_disch, patient_id_to_num_notes['pneumonia_alive'])
# Out:
# 100%|██████████| 11895/11895 [00:42<00:00, 279.63it/s]
#   0%|          | 24/46134 [00:00<03:18, 231.91it/s]
# 5989 note events
# finished counting frequent words for patients!
# 100%|██████████| 46134/46134 [02:36<00:00, 294.65it/s]
# 23172 note events
# finished counting frequent words for patients!

# %%
number_of_notes
# Out:
# {'pneumonia_dead': 252, 'pneumonia_alive': 1167}

# %%
print(note_appearance_counter)
# Out:
# {'pneumonia_dead': {'emot': 68, 'r': 178, 'inh': 3, 'pao': 66, 'clinician': 41, 'x': 185, 'amount': 132, 'place': 196, 'bipap': 43, 'hilar': 36, 'bpm': 102, 'speak': 65, 'plan': 161, 'two': 87, 'simultan': 2, 'medic': 217, 'set': 141, 'preren': 12, 'hospit': 75, 'previou': 172, 'hepat': 27, 'meantim': 3, 'copi': 13, 'answer': 59, 'marri': 4, 'wave': 81, 'extens': 86, 'pea': 8, '%': 188, 'acidosi': 70, 'metabol': 52, 'pupil': 73, 'icu': 108, 'system': 99, ')': 229, 'autopeep': 6, 'demonstr': 88, 'admiss': 88, 'atenolol': 4, 'wait': 34, 'suffer': 13, 'infus': 111, 'bag': 43, 'head': 114, 'park': 4, 'drug': 55, 'dilat': 85, 'mosf': 3, 'grief': 2, 'hemodynam': 111, 'region': 80, 'list': 25, 'meal': 10, 'gaug': 57, 'abg': 143, 'recruit': 14, 'histori': 173, 'scale': 61, 'minut': 91, 'connect': 7, 'member': 57, 'form': 38, 'abov': 158, 'sinu': 139, '#': 211, 'nurs': 141, 'ul': 64, 'dr': 150, 'elder': 1, 'state': 94, 'alk': 47, 'epinephrin': 9, 'ng': 131, 'thorac': 49, 'assist': 81, 'employ': 7, 'st': 140, 'come': 72, 'want': 92, 'ns': 119, 'devic': 94, 'enter': 58, 'licsw': 11, 'got': 28, 'mcg': 105, 'rosc': 1, 'rml': 18, 'azotemia': 6, 'function': 95, 'resid': 111, 'contour': 68, 'presep': 6, 'mg': 163, 'g': 96, 'acid': 56, 'cage': 1, 'mode': 73, 'caucasian': 2, 'arteri': 119, 'aspir': 108, 'anterior': 62, 'normal': 164, 'map': 90, 'understand': 45, 'keep': 104, 'salmeterol': 1, 'lab': 132, 'carina': 78, 'cxr': 136, 'sodium': 63, 'ceftriaxon': 24, 'ext': 68, 'sw': 33, 'abdomen': 119, 'need': 155, 'refractori': 8, 'exclud': 72, 'pericardi': 61, 'tender': 82, 'limb': 32, 'major': 40, 'work': 87, 'pedal': 41, 'anion': 8, 'attempt': 119, 'norepinephrin': 22, 'ca': 105, 'privat': 7, 'intub': 147, 'apic': 43, 'addendum': 98, 'physic': 72, 'think': 20, 'absent': 62, 'q': 136, 'would': 127, 'decid': 61, 'second': 40, 'glycem': 62, 'drip': 79, 'went': 50, 'central': 107, 'consolid': 110, 'today': 148, 'ml': 99, 'hr': 189, 'resp': 163, 'failur': 141, 'ye': 42, 'verapamil': 2, 'current': 158, 'next': 81, 'hypertens': 82, 'veteran': 1, 'cpr': 32, 'key': 61, 'fluticason': 2, 'alcohol': 15, 'jvp': 18, 'recurr': 33, 'renal': 107, 'year': 195, 'pneumonia': 203, 'vasopressin': 27, 'receiv': 151, 'b': 106, 'ha': 212, 'amylas': 17, 'densiti': 45, 'insert': 61, 'check': 116, 'iadl': 1, 'deliveri': 63, 'slide': 50, 'tip': 126, 'dl': 70, 'portion': 101, 'htn': 50, 'evid': 141, 'like': 172, 'full': 124, 'neut': 43, 'son': 89, 'pmh': 78, 'tc': 12, 'underli': 79, 'event': 121, 'occup': 18, 'epi': 11, 'stomach': 93, 'albuterol': 58, 'angl': 28, 'shock': 66, 'appropri': 101, 'elig': 3, 'va': 11, 'opac': 148, 'might': 41, 'notabl': 38, 'clinic': 117, 'show': 131, 'spoke': 86, 'leukocytosi': 37, 'bs': 138, 'yo': 75, 'ani': 142, 'micu': 131, 'unabl': 130, 'distend': 108, 'primari': 43, 'sr': 94, 'present': 189, 'afternoon': 103, 'ij': 79, 'sepsi': 79, 'elev': 122, 'cathet': 130, ']': 80, 'subsequ': 50, 'etho': 2, 'prophylaxi': 70, 'propofol': 31, 'saw': 64, 'morn': 93, 'ptx': 24, 'addict': 8, 'arriv': 82, 'vap': 72, 'simvastatin': 4, 'lymph': 71, 'adjust': 59, 'gallop': 7, 'glucos': 82, 'acidem': 4, 'access': 113, 'hpi': 58, 'drop': 120, 'urin': 165, 'ap': 175, 'day': 160, 'addit': 117, 'room': 70, 'pneumoboot': 25, 'recommend': 82, 'concern': 114, 'reason': 199, 'one': 117, 'artic': 2, 'admit': 194, 'infecti': 53, 'serial': 23, 'provid': 114, 'social': 138, 'exam': 110, 'ast': 48, 'statu': 197, 'hl': 5, 'organomegali': 4, 'phenylephrin': 16, 'po': 143, 'volum': 119, 'exchang': 20, 'section': 56, 'girlfriend': 2, 'depress': 51, 'agre': 84, 'feel': 52, 'issu': 84, 'hypercapn': 6, 'team': 141, 'defer': 39, 'rebound': 8, 'dextros': 11, 'inr': 88, 'respiratiori': 1, 'mmhg': 71, 'costophren': 30, 'appear': 201, 'without': 143, 'bolus': 98, 'prevent': 35, 'sputum': 132, 'logist': 2, 'level': 148, 'cardiomediastin': 48, 'chief': 63, 'pho': 56, '[': 80, 'inquir': 4, 'fissur': 12, 'abnorm': 102, 'mass': 65, 'radiolog': 68, 'pco': 36, 'murmur': 42, 'ga': 70, 'interv': 15 ...

# %%
# # get hyper-paramters n_fold and threshold from user input
n_fold = float(3)
threshold = float(0.01)

frequent_word_lists = {}
factor = {}

# %%
"""function description:
for each disease in note_appearance_counter
    1. checks whether a word in disease file is frequent(frequency standard as defined by factor, n_fold, and threshold)
    2. adds to frequent_word_list
"""

# def find_frequent_word(note_appearance_counter, frequent_word_lists, number_of_notes, factor, n_fold, threshold):

# calculate normalizing factor for each disease
note_sum = 0

# Count from two labels
for disease in number_of_notes:
    note_sum += float(number_of_notes[disease])
    
for disease in number_of_notes:
    factor[disease] = number_of_notes[disease] / note_sum

# determine frequent word for each disease file
for disease in note_appearance_counter:
    frequent_word_lists[disease] = []

    print(disease + " has " + str(len(note_appearance_counter[disease])) + " unique words!")

    for word in note_appearance_counter[disease]:
        
        freq_check = True
        for check_disease in note_appearance_counter:
            
            if not disease == check_disease:
                if word in note_appearance_counter[check_disease]:
                    if not (note_appearance_counter[disease][word] / note_appearance_counter[check_disease][word] / factor[disease] * factor[check_disease] > n_fold \
                        and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):

                        freq_check = False
                        break

                else:
                    if not (note_appearance_counter[disease][word] > n_fold and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):
                        freq_check = False
                        break
        if freq_check:
            frequent_word_lists[disease].append((word))
            # Create a tuple of word and its count
#             frequent_word_lists[disease].append((word, note_appearance_counter[disease][word]))

        

print("finished making frequent words list for " + disease)
# Out:
# pneumonia_dead has 11678 unique words!
# pneumonia_alive has 22572 unique words!
# finished making frequent words list for pneumonia_alive

# %%
print(note_sum)
print(factor)

# number of notes
# 58029.0
# {'pneumonia_dead': 0.2049837150390322, 'pneumonia_alive': 0.7950162849609678}
# Out:
# 1419.0
# {'pneumonia_dead': 0.17758985200845667, 'pneumonia_alive': 0.8224101479915433}

# %%
print(len(frequent_word_lists['pneumonia_dead']))
print(len(frequent_word_lists['pneumonia_alive']))


# n_fold = float(3) threshold = float(0.01)
# 454
# 329

# n_fold = float(2) threshold = float(0.01)
# 914
# 600

# n_fold = float(1) threshold = float(0.01)
# 3320
# 2196
# Out:
# 454
# 329

# %%
print(frequent_word_lists)
# Out:
# {'pneumonia_dead': ['clinician', 'pea', 'autopeep', 'suffer', 'park', 'recruit', 'azotemia', 'refractori', 'norepinephrin', 'cpr', 'vasopressin', 'elig', 'acidem', 'phenylephrin', 'hypercapn', 'funer', 'bicarbon', 'profound', 'arrang', 'clergi', 'unrespons', 'hypothermia', 'cremat', 'dic', 'expir', 'mottl', 'paralyt', 'hypercapnia', 'anur', 'arrest', 'pcv', 'death', 'sluggish', 'gum', 'nacl', 'dnr', 'lubric', 'slough', 'cmo', 'dni', 'dk', 'pinpoint', 'nonpurpos', 'virtual', 'oder', 'float', 'mso', 'clariti', 'levoph', 'wish', 'priest', 'option', 'dead', 'antb', 'pronounc', 'peerla', 'viabl', 'hypotent', 'gather', 'suport', 'purpl', 'dd', 'prognosi', 'respon', 'grim', 'bow', 'institut', 'remin', 'aprv', 'synch', 'centimet', 'depth', 'bye', 'mad', 'life', 'asystol', 'agreement', 'acv', 'mortem', 'sync', 'chaplain', 'duski', 'mgx', 'nrbm', 'moniotr', 'ppn', 'througout', 'surviv', 'peac', 'cathol', 'hover', 'pulseless', 'crrt', 'suppport', 'agon', 'vasopressor', 'deliv', 'hemothorax', 'defibril', 'seriou', 'cvvh', 'corneal', 'jerk', 'deterior', 'cvvhdf', 'vtach', 'quiac', 'neosynephrin', 'cvvhd', 'mortum', 'rusti', 'pfr', 'acidot', 'lc', 'maroon', 'pray', 'ethic', 'cagluc', 'uffp', 'levof', 'brb', 'ffp', 'quinton', 'multisystem', 'declin', 'among', 'scl', 'elimin', 'cooler', 'hugger', 'gratitud', 'ultrafiltr', 'cyanot', 'hypotherm', 'bair', 'mtg', 'rewir', 'lw', 'unequ', 'spiritu', 'pitressin', 'towel', 'bank', 'syring', 'promod', "tf'ing", 'motil', 'circuit', 'norepi', 'sml', 'bairhugg', 'paco', 'town', 'rabbi', 'warmer', 'nahco', 'polymorph', 'morgu', 'ashen', 'triadyn', 'neo', 'zero', 'discard', 'prayer', 'ran', 'autopsi', 'chane', 'absorb', 'bond', 'erythro', 'asynchron', 'discoordin', 'escal', 'hunger', 'gc', 'edt', '^rr', 'unstabl', 'mind', 'rediscuss', 'hung', 'polici', 'dopamin', 'intiat', 'moan', 'cantones', 'tacycard', 'palli', 'acc', 'artifici', 'fliud', 'readdress', 'overlay', 'ozz', 'inclus', 'broader', 'anuria', 'gurgl', 'proph', 'dobutamin', 'judgement', 'underneath', 'recalibr', 'hospic', 'adenosin', 'oncologist', 'platelet', 'platlet', 'quadrent', 'pheresi', 'oligur', 'kerlix', 'nephrolog', 'cellcept', 'sorb', 'influenc', 'core', 'surgicel', 'anyway', 'psup', 'gvhd', 'griev', 'gut', 'hepati', 'cardiovert', 'cisatracurium', 'barotrauma', 'grimmac', 'caspofungin', 'fentenyl', 'ettub', 'premed', 'repsons', 'hiccup', 'pose', 'extremitiy', 'oximetri', 'twitch', 'fungemia', 'snt', 'wether', 'chemic', 'fc', 'rescan', 'lcw', 'liw', 'fentani', 'sacrament', 'conc', 'crt', 'postpylor', 'plat', 'nephrogram', 'mail', 'grave', 'nonreact', 'chb', 'heroic', 'awhil', 'nonrebreath', 'occupi', 'pleuravac', 'reappear', 'struggl', 'ultra', 'propos', 'familt', 'opinion', 'palliat', 'reveiw', 'icter', 'gentamycin', 'criticar', 'resucit', 'ardsnet', 'reguard', 'abruptli', 'ogtub', 'tubular', 'meaning', 'cvo', 'themselv', 'preoxygen', 'amongst', 'pplat', 'sooner', 'wma', 'fibrinogen', 'kyphoscoliosi', 'pneumonectomi', 'vasoconstrict', 'sibl', 'gasp', 'recev', 'hook', 'tran', 'hida', 'colour', 'realist', 'innumer', 'moreov', 'aricept', 'pvr', 'buck', 'creep', 'argatroban', 'vigil', 'aliv', 'pharmacolog', 'irrevers', 'unreli', 'derecruit', 'wil', 'attemtp', 'epsiod', 'ration', 'eyelid', 'religi', 'famil', 'respitori', 'myeloma', 'imbal', 'analgesia', 'declar', 'muddi', 'dorsal', 'adam', 'neob', 'moisten', 'od', 'heliox', 'requr', 'diflucan', 'osteoblast', 'emper', 'futil', 'illeu', 'currentl', 'nimv', 'perisplen', 'preliminarili', 'fli', 'rhochor', 'plerual', 'sluggishli', 'forth', 'prioriti', 'dysynchron', 'esoph', 'binder', 'unplan', 'occurr', 'ipf', 'goodby', 'ccn', 'stg', 'meatu', 'unarous', 'scopalamin', 'tobra', 'harm', 'fentayl', 'bless', 'rite', 'petechia', 'hemodynim', 'doen', 'furhter', 'calvarium', 'stack', 'fmaili', 'montitor', 'chol', 'underpenetr', 'figur', 'massag', 'thrombot', 'pyuria', 'ggt', 'outer', 'mrcp', 'contini', 'formul', 'synchroni', 'treatement', 'amioderon', 'news', 'anasarc', 'pastor', 'led', 'mvo', 'unobtain',  ...

# %% [markdown]
# ### 2. Co-occurrence generation
# FP-growth

# %%
FREQUENT_WORD_LIST = frequent_word_lists['pneumonia_dead'] + frequent_word_lists['pneumonia_alive']
print(len(FREQUENT_WORD_LIST))
print(len(set(FREQUENT_WORD_LIST)))
# Out:
# 783
# 783

# %%
"""function description:
generates frequent word set for the disease
"""
word_dict = {}
word_id = 1
stemmer = PorterStemmer()


for word in FREQUENT_WORD_LIST:
    if not word == "WORD":
        word_dict[stemmer.stem(word.strip())] = word_id
        word_id += 1
             
print(f"\nword dictionary created! Length: {len(word_dict)}\n")
print(word_dict)
# Out:
# word dictionary created! Length: 783
#
# {'clinician': 1, 'pea': 2, 'autopeep': 3, 'suffer': 4, 'park': 5, 'recruit': 6, 'azotemia': 7, 'refractori': 8, 'norepinephrin': 9, 'cpr': 10, 'vasopressin': 11, 'elig': 12, 'acidem': 13, 'phenylephrin': 14, 'hypercapn': 15, 'funer': 16, 'bicarbon': 17, 'profound': 18, 'arrang': 19, 'clergi': 20, 'unrespon': 21, 'hypothermia': 22, 'cremat': 23, 'dic': 24, 'expir': 25, 'mottl': 26, 'paralyt': 27, 'hypercapnia': 28, 'anur': 29, 'arrest': 30, 'pcv': 31, 'death': 32, 'sluggish': 33, 'gum': 34, 'nacl': 35, 'dnr': 36, 'lubric': 37, 'slough': 38, 'cmo': 39, 'dni': 40, 'dk': 41, 'pinpoint': 42, 'nonpurpo': 43, 'virtual': 44, 'oder': 45, 'float': 46, 'mso': 47, 'clariti': 48, 'levoph': 49, 'wish': 50, 'priest': 51, 'option': 52, 'dead': 53, 'antb': 54, 'pronounc': 55, 'peerla': 56, 'viabl': 57, 'hypot': 58, 'gather': 59, 'suport': 60, 'purpl': 61, 'dd': 62, 'prognosi': 63, 'respon': 64, 'grim': 65, 'bow': 66, 'institut': 67, 'remin': 68, 'aprv': 69, 'synch': 70, 'centimet': 71, 'depth': 72, 'bye': 73, 'mad': 74, 'life': 75, 'asystol': 76, 'agreement': 77, 'acv': 78, 'mortem': 79, 'sync': 80, 'chaplain': 81, 'duski': 82, 'mgx': 83, 'nrbm': 84, 'moniotr': 85, 'ppn': 86, 'througout': 87, 'surviv': 88, 'peac': 89, 'cathol': 90, 'hover': 91, 'pulseless': 92, 'crrt': 93, 'suppport': 94, 'agon': 95, 'vasopressor': 96, 'deliv': 97, 'hemothorax': 98, 'defibril': 99, 'seriou': 100, 'cvvh': 101, 'corneal': 102, 'jerk': 103, 'deterior': 104, 'cvvhdf': 105, 'vtach': 106, 'quiac': 107, 'neosynephrin': 108, 'cvvhd': 109, 'mortum': 110, 'rusti': 111, 'pfr': 112, 'acidot': 113, 'lc': 114, 'maroon': 115, 'pray': 116, 'ethic': 117, 'cagluc': 118, 'uffp': 119, 'levof': 120, 'brb': 121, 'ffp': 122, 'quinton': 123, 'multisystem': 124, 'declin': 125, 'among': 126, 'scl': 127, 'elimin': 128, 'cooler': 129, 'hugger': 130, 'gratitud': 131, 'ultrafiltr': 132, 'cyanot': 133, 'hypotherm': 134, 'bair': 135, 'mtg': 136, 'rewir': 137, 'lw': 138, 'unequ': 139, 'spiritu': 140, 'pitressin': 141, 'towel': 142, 'bank': 143, 'syre': 144, 'promod': 145, "tf'ing": 146, 'motil': 147, 'circuit': 148, 'norepi': 149, 'sml': 150, 'bairhugg': 151, 'paco': 152, 'town': 153, 'rabbi': 154, 'warmer': 155, 'nahco': 156, 'polymorph': 157, 'morgu': 158, 'ashen': 159, 'triadyn': 160, 'neo': 161, 'zero': 162, 'discard': 163, 'prayer': 164, 'ran': 165, 'autopsi': 166, 'chane': 167, 'absorb': 168, 'bond': 169, 'erythro': 170, 'asynchron': 171, 'discoordin': 172, 'escal': 173, 'hunger': 174, 'gc': 175, 'edt': 176, '^rr': 177, 'unstabl': 178, 'mind': 179, 'rediscuss': 180, 'hung': 181, 'polici': 182, 'dopamin': 183, 'intiat': 184, 'moan': 185, 'canton': 186, 'tacycard': 187, 'palli': 188, 'acc': 189, 'artifici': 190, 'fliud': 191, 'readdress': 192, 'overlay': 193, 'ozz': 194, 'inclu': 195, 'broader': 196, 'anuria': 197, 'gurgl': 198, 'proph': 199, 'dobutamin': 200, 'judgement': 201, 'underneath': 202, 'recalibr': 203, 'hospic': 204, 'adenosin': 205, 'oncologist': 206, 'platelet': 207, 'platlet': 208, 'quadrent': 209, 'pheresi': 210, 'oligur': 211, 'kerlix': 212, 'nephrolog': 213, 'cellcept': 214, 'sorb': 215, 'influenc': 216, 'core': 217, 'surgicel': 218, 'anyway': 219, 'psup': 220, 'gvhd': 221, 'griev': 222, 'gut': 223, 'hepati': 224, 'cardiovert': 225, 'cisatracurium': 226, 'barotrauma': 227, 'grimmac': 228, 'caspofungin': 229, 'fentenyl': 230, 'ettub': 231, 'preme': 232, 'repson': 233, 'hiccup': 234, 'pose': 235, 'extremitiy': 236, 'oximetri': 237, 'twitch': 238, 'fungemia': 239, 'snt': 240, 'wether': 241, 'chemic': 242, 'fc': 243, 'rescan': 244, 'lcw': 245, 'liw': 246, 'fentani': 247, 'sacrament': 248, 'conc': 249, 'crt': 250, 'postpylor': 251, 'plat': 252, 'nephrogram': 253, 'mail': 254, 'grave': 255, 'nonreact': 256, 'chb': 257, 'heroic': 258, 'awhil': 259, 'nonrebreath': 260, 'occupi': 261, 'pleuravac': 262, 'reappear': 263, 'struggl': 264, 'ultra': 265, 'propo': 266, 'familt': 267, 'opinion': 268, 'palliat': 269, 'reveiw': 270, 'icter': 271, 'gentamycin': 272, 'criticar': 273, 'resucit ...

# %% [markdown]
# ### Implementetion with python for FP_growth

# %% [markdown]
# ### Count co-occurrences per patient

# %%
import os
import operator
from pathlib import Path
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import math

# ----
def fp_growth_input_per_patient_python(disease_df, word_dict, min_support):
    
    # For dataframe
    patient_cooc_dict = {}
    patient_node_dict = {}
    patient_note_cnt = {}
    
    # --------------    
    patient_id = -1
    note_cnt = 0
    patient_note_list = []
    
    # read line in from file (each line is one note)
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        
        # only regard certain type of notes
        patient_id_check = int(row['SUBJECT_ID_x'])
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        patient_word_set = set()
    
#         print(f"patient_id_check: {patient_id_check}, patient_id: {patient_id}")
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check and not patient_id == -1:
            te = TransactionEncoder()
            te_ary = te.fit(patient_note_list).transform(patient_note_list)
            df = pd.DataFrame(te_ary, columns=te.columns_)
            df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
            cooc_tmp = []
            cooc_minsup_tmp = []
            node_minsup_tmp = []
            cooc_node_idx_tmp = []
            
            for index, row in df_itemsets.iterrows():
                if len(row['itemsets']) == 1:
                    word = list(row['itemsets'])[0]
                    min_sup = row['support']

                    node_minsup_tmp.append(len(patient_note_list) * row['support'])
                    cooc_node_idx_tmp.append(word)
                    
                if len(row['itemsets']) == 2:
                    cooc_ = sorted(list(row['itemsets']))
                    cooc_tmp.append(cooc_)
                    cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
            
            cooc_dict = {}

            for num, i in enumerate(cooc_tmp):
                if tuple(i) not in cooc_dict:
                    cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

            # dictionary = dict(zip(keys, values))
            node_dict = {}
            for num, i in enumerate(cooc_node_idx_tmp):
                if i not in node_dict:
                    node_dict[i] = node_minsup_tmp[num]
                    
            # Update glob lists
            if patient_id not in patient_cooc_dict:
                patient_cooc_dict[patient_id] = cooc_dict
                patient_node_dict[patient_id] = node_dict
                patient_note_cnt[patient_id] = note_cnt
            else:
                print(f"patient_id: {patient_id} is already in the dictionary!")
            
            
            # Reset local lists
            patient_note_list = []
            note_cnt = 0
                    
        # update patient id
        patient_id = patient_id_check
        tokenized_note = word_tokenize(note)
        note_cnt += 1

        # loop through each word in note to count word belonging to each disease
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())       
            if stemmed_word in word_dict:
                    patient_word_set.add(stemmed_word)

        templst = []
        for word in patient_word_set:
            templst.append(word)

        if templst:
            patient_note_list.append(templst)
    
    # Last patient info
    te = TransactionEncoder()
    te_ary = te.fit(patient_note_list).transform(patient_note_list)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
    cooc_tmp = []
    cooc_minsup_tmp = []
    #-----
    node_minsup_tmp = []
    cooc_node_idx_tmp = []
            
    for index, row in df_itemsets.iterrows():
        if len(row['itemsets']) == 1:
            word = list(row['itemsets'])[0]
            node_minsup_tmp.append(len(patient_note_list) * row['support'])
            cooc_node_idx_tmp.append(word)

        if len(row['itemsets']) == 2:
            cooc_ = sorted(list(row['itemsets']))
            cooc_tmp.append(cooc_)
            cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
    
                    
    cooc_dict = {}

    for num, i in enumerate(cooc_tmp):
        if tuple(i) not in cooc_dict:
            cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

    # dictionary = dict(zip(keys, values))
    node_dict = {}
    for num, i in enumerate(cooc_node_idx_tmp):
        if i not in node_dict:
            node_dict[i] = node_minsup_tmp[num]

    # Update glob lists
    if patient_id not in patient_cooc_dict:
        patient_cooc_dict[patient_id] = cooc_dict
        patient_node_dict[patient_id] = node_dict
        patient_note_cnt[patient_id] = note_cnt
    else:
        print(f"patient_id: {patient_id} is already in the dictionary!")

    return patient_node_dict, patient_cooc_dict, patient_note_cnt

patient_node_0, patient_cooc_0, patient_note_num_0 = fp_growth_input_per_patient_python(pneumonia_dead_no_disch, word_dict, 0.1)
patient_node_1, patient_cooc_1, patient_note_num_1 = fp_growth_input_per_patient_python(pneumonia_alive_no_disch, word_dict, 0.1)
# Out:
# 100%|██████████| 11895/11895 [46:52<00:00,  4.23it/s]
# 100%|██████████| 46134/46134 [44:58<00:00, 17.10it/s]

# %%
print(patient_node_1)
# Out:
# {68: {'dizzi': 1.0, 'declin': 1.0, 'breakfast': 1.0, 'chip': 1.0, 'lpm': 1.0, 'thirst': 1.0, 'aaox': 1.0, 'fee': 1.0, 'fluor': 1.0, 'ambul': 4.0, 'commod': 4.0, 'cracker': 1.0, 'hunger': 1.0, 'chair': 2.0, 'gait': 2.0, 'vtach': 1.0, 'unsteadi': 1.0, 'oob': 2.0, 'pcv': 1.0, 'ambien': 1.0, 'pleasant': 1.0}, 85: {'lat': 1.0}, 94: {'lift': 11.0, 'incis': 6.0, 'dopamin': 11.0, 'oob': 7.000000000000001}, 165: {'habitu': 1.0}, 211: {'dopamin': 3.0, 'aox': 3.0, 'chair': 2.0, 'lpm': 2.0, 'levoph': 3.0, 'lat': 2.0}, 224: {'lat': 1.0, 'rigor': 1.0, 'platelet': 1.0, 'commod': 1.0, 'awhil': 1.0, 'fax': 1.0, 'bank': 1.0, 'pleasant': 1.0, 'chair': 1.0}, 231: {"tf'ing": 3.0, 'oob': 3.0, 'msicu': 3.0}, 283: {'recruit': 10.0, 'criticar': 10.0}, 357: {'unasyn': 4.0, 'intent': 2.0, 'dz': 2.0, 'ctx': 2.0, 'thiamin': 1.0, 'moan': 4.0, 'wallet': 1.0, 'signatur': 1.0, 'money': 1.0, 'jewelri': 1.0, 'cloth': 1.0, 'cash': 1.0, 'distort': 2.0}, 368: {'pleasant': 3.0, 'dnr': 3.0, 'epigastr': 2.0, 'hhn': 3.0, 'lpm': 2.0, 'oob': 6.0, 'ambul': 4.0, 'chair': 2.0}, 370: {'para': 1.0, 'pleasant': 1.0, 'mean': 1.0, 'ambul': 1.0, 'declin': 1.0, 'thirst': 1.0, 'readdress': 1.0, 'chip': 1.0, 'dnr': 2.0, 'platlet': 1.0, 'dni': 1.0, 'hilum': 1.0}, 384: {'bipolar': 9.0, 'calvarium': 2.0, 'wish': 4.0, 'dnr': 3.0, 'schizophrenia': 4.0}, 426: {'align': 1.0, 'mottl': 1.0, 'lat': 1.0, 'unenhanc': 1.0, 'mail': 1.0, 'bronchovascular': 1.0, 'pleasant': 1.0, 'arthrit': 1.0}, 509: {'mean': 2.0, 'oob': 3.0, 'lift': 2.0, 'chair': 2.0, 'fresh': 2.0}, 514: {'lat': 1.0, 'schizophrenia': 1.0, 'nicotin': 1.0, 'lighthead': 1.0, 'burn': 1.0, 'pleasant': 2.0, 'commod': 2.0, 'ambul': 1.0, 'oob': 1.0}, 596: {'dnr': 4.0, 'dopamin': 3.0, 'dni': 4.0, 'chair': 2.0}, 674: {'profound': 1.0, 'nimv': 1.0, 'xl': 2.0, 'rememb': 1.0, 'neo': 1.0, 'mso': 1.0, 'lotion': 1.0, 'tranfer': 1.0, 'fu': 1.0, 'cardiovert': 1.0}, 707: {'pleasantli': 4.0, 'lpm': 2.0, 'oob': 3.0, 'pleasant': 2.0}, 711: {'dnr': 190.99999999999997, 'mellitu': 78.0, 'fibrinogen': 186.0, 'captopril': 77.0, 'olanzapin': 109.0, 'palli': 60.0, 'fungemia': 95.0, 'caspofungin': 105.0}, 770: {'iddm': 24.0, 'vp': 20.0, 'captopril': 8.0, 'criticar': 6.0}, 773: {'pneumococc': 7.0, 'mso': 8.0, 'lat': 4.0, 'sluggish': 5.0, 'levoph': 8.0}, 899: {'lat': 2.0, 'suprapub': 1.0, 'chip': 2.0, 'pleasant': 3.0, 'bottl': 1.0, 'oob': 1.0, 'lift': 1.0, 'diaper': 1.0, 'smooth': 1.0, 'exophyt': 1.0, 'fluor': 1.0, 'fee': 1.0}, 1096: {'syst': 1.0, 'ppd': 1.0, 'lc': 1.0, 'forc': 1.0, 'tubular': 1.0}, 1135: {'trazodon': 2.0, 'incis': 2.0, 'deflat': 2.0, 'scab': 3.0, 'oob': 6.0, 'lift': 2.0, 'chair': 7.0, 'captopril': 2.0, 'argatroban': 4.0, 'pleasant': 3.0, 'lat': 3.0, 'xl': 3.0, 'lotion': 2.0, 'hugger': 2.0}, 1163: {'osa': 1.0, 'pleasant': 1.0, 'twitch': 1.0, 'captopril': 1.0}, 1174: {'occipit': 1.0, 'perpher': 1.0, 'iddm': 1.0, 'lpm': 1.0, 'circuit': 1.0, 'ardsnet': 1.0, 'unasyn': 1.0, 'reappear': 1.0, 'spiromet': 1.0, 'phlegm': 1.0, 'incent': 1.0}, 1180: {'influenc': 1.0}, 1283: {'unavail': 1.0, 'seat': 1.0, 'habitu': 1.0}, 1332: {'levoph': 4.0, 'dnr': 6.0, 'dni': 5.0, 'oob': 4.0}, 1339: {'oob': 20.0, 'stair': 18.0, 'ctx': 18.0, 'ambul': 18.0, 'tracheomalacia': 12.0, 'seroquel': 23.0, 'zoloft': 14.0, 'video': 22.0, 'barium': 18.0, 'nectar': 12.0, 'phenylephrin': 25.0, 'neo': 27.0}, 1546: {'asthma': 4.0, 'spacer': 2.0, 'oob': 2.0, 'db': 2.0, 'freeli': 1.0, 'arthrit': 1.0, 'puff': 1.0, 'lpm': 1.0, 'breakfast': 1.0, 'lat': 1.0}, 1568: {'lat': 1.0, 'cocain': 1.0, 'pericard': 5.0, 'hhn': 1.0, 'pleasant': 4.0, 'sweat': 1.0, 'lotion': 1.0, 'itchi': 1.0, 'oob': 2.0, 'quadrent': 1.0, 'chair': 1.0, 'ambien': 1.0}, 1601: {'lat': 1.0, 'dz': 1.0, 'levoph': 3.0, 'pleasant': 2.0, 'platelet': 1.0, 'mean': 1.0, 'ffp': 1.0, 'dopamin': 1.0, 'exophyt': 1.0, 'ambien': 2.0, 'knew': 1.0, 'rememb': 1.0, 'hunger': 1.0}, 1606: {'precordium': 1.0, 'unalt': 1.0, 'dnr': 1.0, 'dni': 1.0, 'lat': 1.0, 'dome': 1.0}, 1642: {'pleasant': 2.0, 'dnr': 2.0, 'dni': 2.0, 'quadrent': 1.0, 'declin': 1. ...

# %%
print(patient_cooc_1)
# Out:
# {68: {('breakfast', 'declin'): 1.0, ('breakfast', 'chip'): 1.0, ('chip', 'declin'): 1.0, ('chip', 'lpm'): 1.0, ('breakfast', 'lpm'): 1.0, ('declin', 'lpm'): 1.0, ('lpm', 'thirst'): 1.0, ('chip', 'thirst'): 1.0, ('breakfast', 'thirst'): 1.0, ('declin', 'thirst'): 1.0, ('aaox', 'thirst'): 1.0, ('aaox', 'lpm'): 1.0, ('aaox', 'chip'): 1.0, ('aaox', 'breakfast'): 1.0, ('aaox', 'declin'): 1.0, ('fee', 'fluor'): 1.0, ('ambul', 'commod'): 3.0, ('commod', 'cracker'): 1.0, ('ambul', 'cracker'): 1.0, ('cracker', 'hunger'): 1.0, ('commod', 'hunger'): 1.0, ('ambul', 'hunger'): 1.0, ('chair', 'oob'): 1.0, ('chair', 'commod'): 1.0, ('ambul', 'chair'): 1.0, ('chair', 'gait'): 1.0, ('ambul', 'gait'): 1.0, ('gait', 'vtach'): 1.0, ('ambul', 'vtach'): 1.0, ('unsteadi', 'vtach'): 1.0, ('gait', 'unsteadi'): 1.0, ('ambul', 'unsteadi'): 1.0, ('commod', 'oob'): 2.0, ('ambul', 'oob'): 2.0, ('oob', 'pcv'): 1.0, ('commod', 'pcv'): 1.0, ('ambul', 'pcv'): 1.0, ('ambien', 'commod'): 1.0, ('ambien', 'pleasant'): 1.0, ('commod', 'pleasant'): 1.0}, 85: {}, 94: {}, 165: {}, 211: {}, 224: {('platelet', 'rigor'): 1.0, ('commod', 'platelet'): 1.0, ('commod', 'rigor'): 1.0, ('bank', 'fax'): 1.0, ('chair', 'pleasant'): 1.0}, 231: {}, 283: {}, 357: {('intent', 'unasyn'): 2.0, ('dz', 'intent'): 2.0, ('dz', 'unasyn'): 2.0, ('ctx', 'unasyn'): 2.0, ('ctx', 'dz'): 1.0, ('ctx', 'intent'): 1.0, ('ctx', 'thiamin'): 1.0, ('dz', 'thiamin'): 1.0, ('intent', 'thiamin'): 1.0, ('thiamin', 'unasyn'): 1.0, ('moan', 'wallet'): 1.0, ('signatur', 'wallet'): 1.0, ('moan', 'signatur'): 1.0, ('money', 'signatur'): 1.0, ('money', 'wallet'): 1.0, ('moan', 'money'): 1.0, ('jewelri', 'money'): 1.0, ('jewelri', 'signatur'): 1.0, ('jewelri', 'wallet'): 1.0, ('jewelri', 'moan'): 1.0, ('cloth', 'jewelri'): 1.0, ('cloth', 'money'): 1.0, ('cloth', 'signatur'): 1.0, ('cloth', 'wallet'): 1.0, ('cloth', 'moan'): 1.0, ('cash', 'cloth'): 1.0, ('cash', 'jewelri'): 1.0, ('cash', 'money'): 1.0, ('cash', 'signatur'): 1.0, ('cash', 'wallet'): 1.0, ('cash', 'moan'): 1.0}, 368: {('ambul', 'oob'): 2.0, ('ambul', 'chair'): 2.0, ('chair', 'oob'): 2.0}, 370: {('mean', 'pleasant'): 1.0, ('ambul', 'mean'): 1.0, ('ambul', 'pleasant'): 1.0, ('readdress', 'thirst'): 1.0, ('chip', 'readdress'): 1.0, ('chip', 'thirst'): 1.0, ('dnr', 'platlet'): 1.0, ('dni', 'platlet'): 1.0, ('dni', 'dnr'): 1.0}, 384: {('bipolar', 'wish'): 4.0, ('bipolar', 'dnr'): 2.0}, 426: {('lat', 'mottl'): 1.0, ('mail', 'unenhanc'): 1.0, ('bronchovascular', 'mail'): 1.0, ('bronchovascular', 'unenhanc'): 1.0, ('arthrit', 'pleasant'): 1.0}, 509: {('lift', 'oob'): 2.0, ('chair', 'lift'): 2.0, ('chair', 'oob'): 2.0}, 514: {('nicotin', 'schizophrenia'): 1.0, ('lighthead', 'nicotin'): 1.0, ('lighthead', 'schizophrenia'): 1.0, ('burn', 'lighthead'): 1.0, ('burn', 'nicotin'): 1.0, ('burn', 'schizophrenia'): 1.0, ('commod', 'pleasant'): 2.0, ('ambul', 'commod'): 1.0, ('ambul', 'pleasant'): 1.0, ('commod', 'oob'): 1.0, ('oob', 'pleasant'): 1.0}, 596: {('dni', 'dnr'): 2.0}, 674: {('nimv', 'profound'): 1.0, ('rememb', 'xl'): 1.0, ('neo', 'rememb'): 1.0, ('neo', 'xl'): 1.0, ('mso', 'neo'): 1.0, ('mso', 'rememb'): 1.0, ('mso', 'xl'): 1.0, ('lotion', 'mso'): 1.0, ('lotion', 'neo'): 1.0, ('lotion', 'rememb'): 1.0, ('lotion', 'xl'): 1.0, ('tranfer', 'xl'): 1.0, ('fu', 'tranfer'): 1.0, ('fu', 'xl'): 1.0, ('cardiovert', 'fu'): 1.0, ('cardiovert', 'tranfer'): 1.0, ('cardiovert', 'xl'): 1.0}, 707: {('oob', 'pleasantli'): 2.0}, 711: {('dnr', 'mellitu'): 54.0, ('fibrinogen', 'mellitu'): 59.0, ('dnr', 'fibrinogen'): 159.0, ('captopril', 'fibrinogen'): 66.0, ('captopril', 'dnr'): 48.0, ('fibrinogen', 'olanzapin'): 99.0, ('dnr', 'olanzapin'): 85.0, ('fibrinogen', 'palli'): 46.0, ('olanzapin', 'palli'): 40.0, ('dnr', 'palli'): 49.0, ('dnr', 'fungemia'): 80.0, ('fibrinogen', 'fungemia'): 78.0, ('caspofungin', 'fungemia'): 87.0, ('fungemia', 'olanzapin'): 57.0, ('caspofungin', 'dnr'): 81.0, ('caspofungin', 'fibrinogen'): 79.0, ('caspofungin', 'olanzapin'): 53.0}, 770: {('iddm', ' ...

# %%
patient_note_num_0
# Out:
# {111: 12,
#  346: 25,
#  404: 3,
#  546: 6,
#  618: 16,
#  705: 15,
#  726: 48,
#  1039: 55,
#  1556: 37,
#  1872: 3,
#  1944: 56,
#  2286: 69,
#  2990: 166,
#  3055: 29,
#  3099: 13,
#  3201: 8,
#  3526: 7,
#  3773: 6,
#  3881: 20,
#  4122: 51,
#  4754: 101,
#  4811: 21,
#  5476: 1,
#  5494: 22,
#  5774: 104,
#  5786: 152,
#  5913: 1,
#  6133: 68,
#  6735: 13,
#  6745: 13,
#  6973: 36,
#  6981: 8,
#  7277: 66,
#  7310: 8,
#  7924: 9,
#  7977: 9,
#  9908: 11,
#  9984: 15,
#  10302: 100,
#  10510: 86,
#  10545: 10,
#  10642: 10,
#  11049: 14,
#  11209: 9,
#  11395: 41,
#  12530: 24,
#  12849: 50,
#  13098: 46,
#  13566: 23,
#  14125: 9,
#  14514: 96,
#  14965: 25,
#  15159: 15,
#  15251: 11,
#  15396: 17,
#  15566: 37,
#  15853: 45,
#  16275: 17,
#  16344: 27,
#  16622: 51,
#  16684: 29,
#  17122: 16,
#  17354: 5,
#  17802: 64,
#  17983: 65,
#  18094: 23,
#  18736: 35,
#  18768: 46,
#  18848: 205,
#  18971: 26,
#  19243: 25,
#  19323: 6,
#  19390: 21,
#  19463: 20,
#  19535: 59,
#  19754: 13,
#  19827: 22,
#  19833: 58,
#  19872: 10,
#  20006: 8,
#  20023: 9,
#  20190: 6,
#  21046: 101,
#  21094: 36,
#  21427: 10,
#  21502: 102,
#  21580: 52,
#  21676: 12,
#  21699: 7,
#  21979: 11,
#  22735: 15,
#  23660: 12,
#  23795: 78,
#  24181: 13,
#  24582: 37,
#  24725: 57,
#  24730: 19,
#  24854: 25,
#  25003: 182,
#  25046: 7,
#  25774: 61,
#  25975: 9,
#  26474: 89,
#  26578: 15,
#  26716: 41,
#  26774: 3,
#  26849: 33,
#  27005: 5,
#  27145: 24,
#  27421: 61,
#  27431: 5,
#  27496: 7,
#  27504: 72,
#  27639: 221,
#  28004: 13,
#  28072: 34,
#  28178: 202,
#  28427: 6,
#  28498: 25,
#  28726: 34,
#  28750: 19,
#  28906: 32,
#  28907: 13,
#  28933: 394,
#  29105: 468,
#  29588: 72,
#  29647: 26,
#  29872: 225,
#  30476: 174,
#  30549: 12,
#  30614: 8,
#  30699: 14,
#  30786: 9,
#  30941: 110,
#  31030: 168,
#  31134: 24,
#  31139: 9,
#  31451: 48,
#  31556: 57,
#  31690: 18,
#  31692: 35,
#  32050: 34,
#  32326: 24,
#  32618: 42,
#  41546: 25,
#  43937: 6,
#  44851: 274,
#  45381: 16,
#  46589: 26,
#  46763: 6,
#  47045: 9,
#  48632: 147,
#  49079: 20,
#  49683: 3,
#  49922: 13,
#  50093: 8,
#  50231: 3,
#  50556: 216,
#  50859: 537,
#  51914: 313,
#  52010: 12,
#  53105: 115,
#  53399: 78,
#  54193: 85,
#  54401: 14,
#  54408: 2,
#  54739: 75,
#  54946: 7,
#  55400: 5,
#  55570: 14,
#  55887: 37,
#  55944: 34,
#  55987: 20,
#  56390: 19,
#  56648: 8,
#  56854: 170,
#  57091: 88,
#  57102: 35,
#  58702: 479,
#  59260: 11,
#  59437: 26,
#  60849: 2,
#  60868: 6,
#  61652: 7,
#  61667: 30,
#  63039: 8,
#  65513: 8,
#  68044: 40,
#  68095: 23,
#  68184: 5,
#  68308: 8,
#  68860: 14,
#  69719: 13,
#  69745: 25,
#  69776: 17,
#  70226: 8,
#  70447: 9,
#  72930: 11,
#  73811: 9,
#  73888: 109,
#  74316: 2,
#  74444: 81,
#  74686: 75,
#  75824: 10,
#  76282: 21,
#  76827: 2,
#  77382: 10,
#  78241: 3,
#  78388: 14,
#  79008: 27,
#  79055: 21,
#  79222: 18,
#  79877: 156,
#  80637: 148,
#  80678: 9,
#  80737: 46,
#  80805: 79,
#  81437: 27,
#  82393: 5,
#  82769: 85,
#  83932: 2,
#  84474: 34,
#  85160: 8,
#  85258: 52,
#  85404: 11,
#  85797: 9,
#  86007: 35,
#  86394: 4,
#  86684: 11,
#  86832: 67,
#  86863: 8,
#  86872: 326,
#  88193: 16,
#  88660: 11,
#  90256: 18,
#  91350: 19,
#  92074: 28,
#  92278: 52,
#  92331: 42,
#  93422: 7,
#  94341: 2,
#  94997: 9,
#  95280: 23,
#  95803: 18,
#  95830: 33,
#  95933: 56,
#  96699: 85,
#  97181: 30,
#  97795: 60,
#  98009: 33,
#  98299: 29,
#  98597: 2}

# %% [markdown]
# #### Create set of patient co-occurrences from two groups

# %%
# Create a set of all unique co-occurrences from both group
patient_cooc_set = set()
patient_cooc_0_dict = {}
patient_cooc_1_dict = {}

for k, v in patient_cooc_0.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_0_dict:
            patient_cooc_0_dict[item] = v[item]
        else:
            patient_cooc_0_dict[item] = patient_cooc_0_dict[item] + v[item]
            
    
for k, v in patient_cooc_1.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_1_dict:
            patient_cooc_1_dict[item] = v[item]
        else:
            patient_cooc_1_dict[item] = patient_cooc_1_dict[item] + v[item]

# %%
print(len(patient_cooc_set))
print(len(patient_cooc_0_dict))
print(len(patient_cooc_1_dict))
# Out:
# 11183
# 3508
# 8465

# %%
# count log-odds score

# reverse
# --------------- co-occurrences --------------->

        
# Get the set of coocurrencies from two groups
# Count log_odd_score

patient_cooc_odd_scores = {}
for set_item in patient_cooc_set:
    if set_item in patient_cooc_0_dict and set_item in patient_cooc_1_dict: 
        d_prob = patient_cooc_0_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        a_prob = patient_cooc_1_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
# --------------- co-occurrences ---------------<

# %%
patient_cooc_odd_scores
# Out:
# {('fibrinogen', 'mean'): 6.90875477931522,
#  ('gabapentin', 'gastriti'): 6.90875477931522,
#  ('postop', 'scar'): 6.90875477931522,
#  ('lac', 'qam'): 6.90875477931522,
#  ('adenosin', 'tcdb'): 6.90875477931522,
#  ('herp', 'mellitu'): 6.90875477931522,
#  ('anuria', 'cpr'): -6.90875477931522,
#  ('dyslipidemia', 'thiamin'): 6.90875477931522,
#  ('bair', 'sluggish'): 0.6916505477038827,
#  ('dizzi', 'mellitu'): 6.90875477931522,
#  ('captopril', 'lpm'): 6.90875477931522,
#  ('ambul', 'hurt'): 6.90875477931522,
#  ('dic', 'rigor'): 6.90875477931522,
#  ('pleasantli', 'robitussin'): 6.90875477931522,
#  ('mva', 'wether'): 6.90875477931522,
#  ('contractur', 'gadolinium'): 6.90875477931522,
#  ('anur', 'twitch'): -6.90875477931522,
#  ('artifici', 'xl'): -6.90875477931522,
#  ('gadolinium', 'leukocyt'): 6.90875477931522,
#  ('dni', 'pinpoint'): -6.90875477931522,
#  ('dni', 'vasopressin'): -6.90875477931522,
#  ('cash', 'cdb'): 6.90875477931522,
#  ('commod', 'cramp'): 6.90875477931522,
#  ('oligur', 'vasopressin'): 0.44092196573215015,
#  ('bipolar', 'ffp'): 6.90875477931522,
#  ('pulseless', 'syncop'): 6.90875477931522,
#  ('death', 'rigor'): 6.90875477931522,
#  ('flight', 'seroquel'): 6.90875477931522,
#  ('gadolinium', 'paperwork'): 6.90875477931522,
#  ('lax', 'xopenex'): 6.90875477931522,
#  ('itchi', 'vasopressin'): -6.90875477931522,
#  ('db', 'stg'): 6.90875477931522,
#  ('priest', 'rite'): -6.90875477931522,
#  ('ambien', 'sarna'): 6.90875477931522,
#  ('bipolar', 'refractori'): 6.90875477931522,
#  ('hctz', 'puff'): 6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('lusb', 'sweat'): 6.90875477931522,
#  ('duski', 'mottl'): -6.90875477931522,
#  ('hemangioma', 'smooth'): 6.90875477931522,
#  ('dietari', 'mellitu'): 6.90875477931522,
#  ('duski', 'vasopressor'): -6.90875477931522,
#  ('dni', 'institut'): 6.90875477931522,
#  ('cardiovert', 'xl'): 6.90875477931522,
#  ('norepi', 'purpl'): -6.90875477931522,
#  ('cash', 'scopalamin'): -6.90875477931522,
#  ('dni', 'respitori'): 6.90875477931522,
#  ('hypercapn', 'unstabl'): -6.90875477931522,
#  ('articul', 'opiat'): 6.90875477931522,
#  ('diaper', 'scar'): 6.90875477931522,
#  ('bicarbon', 'trazodon'): -6.90875477931522,
#  ('artifici', 'gait'): -6.90875477931522,
#  ('fatti', 'slice'): 6.90875477931522,
#  ('mean', 'nonrebreath'): -6.90875477931522,
#  ('mellitu', 'ppd'): 0.9785433477333831,
#  ('dizzi', 'oob'): 2.95117249214323,
#  ('aliv', 'zyprexa'): 6.90875477931522,
#  ('dnr', 'ipf'): -6.90875477931522,
#  ('gentamycin', 'oob'): -6.90875477931522,
#  ('absorb', 'trazodon'): 6.90875477931522,
#  ('dermat', 'dic'): 6.90875477931522,
#  ('sensat', 'uri'): 6.90875477931522,
#  ('hypotherm', 'vtach'): 6.90875477931522,
#  ('chair', 'unasyn'): -0.5584397574369144,
#  ('chair', 'habitu'): 6.90875477931522,
#  ('cramp', 'rhinorrhea'): -6.90875477931522,
#  ('aaox', 'thirst'): 6.90875477931522,
#  ('omeprazol', 'seroquel'): 6.90875477931522,
#  ('hunger', 'impli'): -6.90875477931522,
#  ('hilum', 'reguard'): 6.90875477931522,
#  ('contd', 'money'): 6.90875477931522,
#  ('exophyt', 'treatement'): 6.90875477931522,
#  ('oob', 'unsteadi'): 6.90875477931522,
#  ('cocain', 'expir'): 6.90875477931522,
#  ('autopsi', 'norepi'): -6.90875477931522,
#  ('levoph', 'rpr'): 6.90875477931522,
#  ('cvvh', 'platelet'): -6.90875477931522,
#  ('laryng', 'modifi'): 6.90875477931522,
#  ('fdp', 'ration'): 6.90875477931522,
#  ('deflat', 'zyprexa'): 6.90875477931522,
#  ('dietari', 'rhinorrhea'): 6.90875477931522,
#  ('acidot', 'imbal'): 6.90875477931522,
#  ('ambul', 'unasyn'): 6.90875477931522,
#  ('core', 'futil'): -6.90875477931522,
#  ('contractur', 'fliud'): -6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('stair', 'thiamin'): 6.90875477931522,
#  ('captopril', 'struggl'): 6.90875477931522,
#  ('chair', 'ultram'): 6.90875477931522,
#  ('ferritin', 'neoplast'): 6.90875477931522,
#  ('fatti', 'pca'): 6.90875477931522,
#  ('oncologist', 'synthet'): 6.90875477931522,
#  ('dnr', 'mrg'): 6.90875477931522,
#  ('bair', 'lpm'): -6.90875477931522,
#  ('dyslipidemia', 'romi'): 6.90875477931522,
#  ('peac', 'prognosi'): -6.90875477931522,
#  ('commod', 'spiromet'): 6.90875477931522,
#  ('aox', 'seroquel'): 6.90875477931522,
#  ('captopril', 'cash'): 6.90875477931522,
#  ('ambien', 'carvedilol'): 6.90875477931522,
#  ('qam', 'thiamin'): 6.90875477931522,
#  ('breakfast', 'tran'): 6.90875477931522,
#  ('cs', 'dni'): 2.0716061679700735,
#  ('levoph', 'petechia'): -6.90875477931522,
#  ('ntnd', 'scar'): 6.90875477931522,
#  ('incent', 'mucinex'): 6.90875477931522,
#  ('bottl', 'expir'): -6.90875477931522,
#  ('levoph', 'trazodon'): 6.90875477931522,
#  ('method', 'predict'): -6.90875477931522,
#  ('declin', 'gabapentin'): 6.90875477931522,
#  ('ambien', 'wish'): 6.90875477931522,
#  ('dni', 'nicotin'): 6.90875477931522,
#  ('platelet', 'sweat'): -6.90875477931522,
#  ('gather', 'retic'): -6.90875477931522,
#  ('dz', 'levoph'): -6.90875477931522,
#  ('dni', 'hypercapn'): 6.90875477931522,
#  ('sensat', 'unstabl'): 6.90875477931522,
#  ('dopamin', 'neo'): 2.473073171472692,
#  ('palli', 'priest'): -6.90875477931522,
#  ('aox', 'bmx'): 6.90875477931522,
#  ('method', 'neoplast'): 6.90875477931522,
#  ('crrt', 'dobutamin'): -6.90875477931522,
#  ('gurgl', 'pleasant'): 6.90875477931522,
#  ('hypothermia', 'prilosec'): 6.90875477931522,
#  ('readmit', 'scab'): 6.90875477931522,
#  ('ambul', 'neo'): -1.095952712632351,
#  ('burn', 'scar'): 6.90875477931522,
#  ('cooler', 'epidur'): 6.90875477931522,
#  ('moan', 'rhinorrhea'): -6.90875477931522,
#  ('dni', 'muddi'): -6.90875477931522,
#  ('arrest', 'impli'): 6.90875477931522,
#  ('angiogram', 'bow'): 6.90875477931522,
#  ('contd', 'deterior'): 6.90875477931522,
#  ('exophyt', 'hilum'): 6.90875477931522,
#  ('hctz', 'sibl'): 6.90875477931522,
#  ('pleasant', 'sweat'): 6.90875477931522,
#  ('dermat', 'dizzi'): 6.90875477931522,
#  ('core', 'romi'): 6.90875477931522,
#  ('cs', 'dyslipidemia'): 6.90875477931522,
#  ('fibrinogen', 'wish'): 6.90875477931522,
#  ('aliv', 'wish'): 6.90875477931522,
#  ('jewelri', 'life'): 6.90875477931522,
#  ('cmo', 'sacrament'): -6.90875477931522,
#  ('hygein', 'readmit'): 6.90875477931522,
#  ('gvhd', 'xii'): 6.90875477931522,
#  ('neo', 'rite'): -6.90875477931522,
#  ('sweat', 'video'): 6.90875477931522,
#  ('cloth', 'scopalamin'): -6.90875477931522,
#  ('pneumococc', 'thiamin'): 6.90875477931522,
#  ('adenocarcinoma', 'pleasant'): 6.90875477931522,
#  ('ctx', 'video'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('ambul', 'splint'): 6.90875477931522,
#  ('anur', 'phenylephrin'): -6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('deterior', 'hugger'): 6.90875477931522,
#  ('oncologist', 'puff'): 6.90875477931522,
#  ('lat', 'lax'): 6.90875477931522,
#  ('hypothermia', 'recruit'): -6.90875477931522,
#  ('gentamycin', 'levoph'): -3.1544023422659846,
#  ('oob', "tf'ing"): 6.90875477931522,
#  ('dnr', 'hypotherm'): -0.22269446071510993,
#  ('seroquel', 'td'): 6.90875477931522,
#  ('crack', 'dni'): 6.90875477931522,
#  ('hypothermia', 'sensat'): 6.90875477931522,
#  ('lat', 'wallet'): 6.90875477931522,
#  ('sensat', 'subq'): 6.90875477931522,
#  ('dnr', 'surviv'): 6.90875477931522,
#  ('acidot', 'dni'): -6.90875477931522,
#  ('dermat', 'diamox'): 6.90875477931522,
#  ('historian', 'hsq'): 6.90875477931522,
#  ('escal', 'mso'): -6.90875477931522,
#  ('aricept', 'ba'): 6.90875477931522,
#  ('cup', 'seat'): 6.90875477931522,
#  ('anaphylaxi', 'paperwork'): 6.90875477931522,
#  ('option', 'unstabl'): -6.90875477931522,
#  ('anur', 'mottl'): -6.90875477931522,
#  ('anuria', 'dead'): -6.90875477931522,
#  ('trazodon', 'uri'): 6.90875477931522,
#  ('asthma', 'director'): 6.90875477931522,
#  ('aricept', 'meatu'): 6.90875477931522,
#  ('mucinex', 'reguard'): 6.90875477931522,
#  ('db', 'epigastr'): 6.90875477931522,
#  ('pericard', 'quadrent'): 6.90875477931522,
#  ('deliv', 'lymphangit'): 6.90875477931522,
#  ('death', 'puff'): 6.90875477931522,
#  ('levoph', 'vtach'): -2.1883847407670785,
#  ('dni', 'fdp'): -6.90875477931522,
#  ('hsq', 'stair'): 6.90875477931522,
#  ('bell', 'icter'): 6.90875477931522,
#  ('incent', 'rememb'): 6.90875477931522,
#  ('bell', 'dni'): 6.90875477931522,
#  ('asthma', 'pod'): 6.90875477931522,
#  ('phlegm', 'qam'): 6.90875477931522,
#  ('mood', 'sweat'): 6.90875477931522,
#  ('arrest', 'neo'): 0.9008114586605904,
#  ('azotemia', 'pneumococc'): 6.90875477931522,
#  ('agon', 'pinpoint'): -6.90875477931522,
#  ('cpr', 'lotion'): -6.90875477931522,
#  ('diaphoresi', 'xii'): 6.90875477931522,
#  ('death', 'sooner'): 6.90875477931522,
#  ('olanzapin', 'zyprexa'): 6.90875477931522,
#  ('aricept', 'pleasant'): 0.4046335072286383,
#  ('hospic', 'levoph'): -6.90875477931522,
#  ('profound', 'zyprexa'): 6.90875477931522,
#  ('aricept', 'puff'): 6.90875477931522,
#  ('hospic', 'osa'): -6.90875477931522,
#  ('dizzi', 'myeloma'): 6.90875477931522,
#  ('align', 'aricept'): -6.90875477931522,
#  ('protrud', 'thiamin'): 6.90875477931522,
#  ('chip', 'silent'): 6.90875477931522,
#  ('dnr', 'romi'): 2.6932429501279174,
#  ('aaox', 'gurgl'): -6.90875477931522,
#  ('derecruit', 'norepinephrin'): -6.90875477931522,
#  ('aricept', 'sundown'): -6.90875477931522,
#  ('dysynchron', 'vasopressin'): -6.90875477931522,
#  ('articul', 'seroquel'): 6.90875477931522,
#  ('autopeep', 'recruit'): -6.90875477931522,
#  ('cardiovert', 'dysynchron'): -6.90875477931522,
#  ('gabapentin', 'laminectomi'): 6.90875477931522,
#  ('palliat', 'prognosi'): -6.90875477931522,
#  ('captopril', 'money'): 6.90875477931522,
#  ('dk', 'oligur'): 6.90875477931522,
#  ('ctx', 'ppd'): 6.90875477931522,
#  ('heroic', 'mottl'): -6.90875477931522,
#  ('ciwa', 'commod'): 6.90875477931522,
#  ('bicarbon', 'mva'): 6.90875477931522,
#  ('aox', 'zyprexa'): -6.90875477931522,
#  ('spiromet', 'syst'): 6.90875477931522,
#  ('angri', 'burn'): 6.90875477931522,
#  ('declin', 'money'): 6.90875477931522,
#  ('fibrinogen', 'surgicel'): -6.90875477931522,
#  ('clinician', 'profound'): -6.90875477931522,
#  ('platelet', 'pleasant'): 6.90875477931522,
#  ('splint', 'xii'): 6.90875477931522,
#  ('aox', 'syncop'): 6.90875477931522,
#  ('colonoscopi', 'pleasant'): 6.90875477931522,
#  ('mottl', 'recruit'): -6.90875477931522,
#  ('dietari', 'mso'): 6.90875477931522,
#  ('lpm', 'strictur'): 6.90875477931522,
#  ('cooler', 'cup'): 6.90875477931522,
#  ('diaphoresi', 'life'): 6.90875477931522,
#  ('captopril', 'epidur'): 6.90875477931522,
#  ('dnr', 'sibl'): 1.604655121332035,
#  ('cmo', 'rememb'): -6.90875477931522,
#  ('mrcp', 'ppd'): -6.90875477931522,
#  ('habitu', 'thiamin'): 6.90875477931522,
#  ('align', 'ligament'): 6.90875477931522,
#  ('prilosec', 'zoloft'): 6.90875477931522,
#  ('aaox', 'bill'): 6.90875477931522,
#  ('clonazepam', 'fibrinogen'): 6.90875477931522,
#  ('itchi', 'sensat'): 6.90875477931522,
#  ('nephrogram', 'scar'): 6.90875477931522,
#  ('argatroban', 'crrt'): -6.90875477931522,
#  ('epigastr', 'gather'): -6.90875477931522,
#  ('nitroglycerin', 'readdress'): 6.90875477931522,
#  ('uncoop', 'vagu'): 6.90875477931522,
#  ('institut', 'myeloma'): -6.90875477931522,
#  ('echocardiogram', 'neoplast'): -6.90875477931522,
#  ('db', 'zoloft'): 6.90875477931522,
#  ('puff', 'young'): 6.90875477931522,
#  ('hypercapnia', 'oob'): 6.90875477931522,
#  ('argatroban', 'ffp'): -6.90875477931522,
#  ('gait', 'omeprazol'): 6.90875477931522,
#  ('adenocarcinoma', 'laryng'): 6.90875477931522,
#  ('diaper', 'wish'): -6.90875477931522,
#  ('dni', 'ntnd'): 1.4174966125472825,
#  ('breakfast', 'uri'): 6.90875477931522,
#  ('historian', 'sweat'): 6.90875477931522,
#  ('cocain', 'ultrafiltr'): 6.90875477931522,
#  ('abruptli', 'cmo'): -6.90875477931522,
#  ('subq', 'sweat'): 6.90875477931522,
#  ('breakfast', 'osa'): 6.90875477931522,
#  ('bicarbon', 'gait'): -6.90875477931522,
#  ('calculi', 'thrive'): 6.90875477931522,
#  ('cmo', 'knowledg'): 6.90875477931522,
#  ('dead', 'unrel'): -6.90875477931522,
#  ('dnr', 'pivot'): 0.2226944607151099,
#  ('xopenex', 'zoloft'): -6.90875477931522,
#  ('diflucan', 'romi'): 6.90875477931522,
#  ('lat', 'pronounc'): 6.90875477931522,
#  ('bipolar', 'pneumococc'): 6.90875477931522,
#  ('fatti', 'stair'): 6.90875477931522,
#  ('anur', 'dic'): -6.90875477931522,
#  ('hypothermia', 'trazodon'): 6.90875477931522,
#  ('venti', 'xanax'): 6.90875477931522,
#  ('dizzi', 'incis'): 6.90875477931522,
#  ('norepinephrin', 'wma'): -6.90875477931522,
#  ('klonopin', 'seroquel'): 6.90875477931522,
#  ('echocardiogram', 'sweat'): 6.90875477931522,
#  ('declin', 'xopenex'): 6.90875477931522,
#  ('clonidin', 'qam'): 6.90875477931522,
#  ('knowledg', 'wish'): 6.90875477931522,
#  ('dni', 'strictur'): 6.90875477931522,
#  ('lotion', 'pca'): 6.90875477931522,
#  ('anuria', 'paralyt'): 6.90875477931522,
#  ('cpr', 'nonreact'): -6.90875477931522,
#  ('aliv', 'prilosec'): 6.90875477931522,
#  ('dz', 'pathologist'): 6.90875477931522,
#  ('ctx', 'moan'): 6.90875477931522,
#  ('cloth', 'probe'): 6.90875477931522,
#  ('conc', 'flake'): 6.90875477931522,
#  ('probe', 'sundown'): 6.90875477931522,
#  ('ba', 'quinolon'): -6.90875477931522,
#  ('pharmacolog', 'splint'): 6.90875477931522,
#  ('anuria', 'slough'): 6.90875477931522,
#  ('crack', 'puff'): 6.90875477931522,
#  ('dz', 'pleasant'): 6.90875477931522,
#  ('abnl', 'nifedipin'): 6.90875477931522,
#  ('chemic', 'habitu'): 6.90875477931522,
#  ('chemic', 'unasyn'): 6.90875477931522,
#  ('bottl', 'gentamycin'): -6.90875477931522,
#  ('qam', 'schizophrenia'): 6.90875477931522,
#  ('rigor', 'uri'): 6.90875477931522,
#  ('bicarbon', 'cvvh'): -6.90875477931522,
#  ('bottl', 'neosynephrin'): -6.90875477931522,
#  ('incent', 'levoph'): 6.90875477931522,
#  ('pea', 'recruit'): 3.649722139527292,
#  ('mucinex', 'transmitr'): 6.90875477931522,
#  ('angiogram', 'flight'): 6.90875477931522,
#  ('ciwa', 'epigastr'): 6.90875477931522,
#  ('broader', 'dnr'): 6.90875477931522,
#  ('cloth', 'moan'): 6.90875477931522,
#  ('motor', 'puff'): 6.90875477931522,
#  ('rehabilit', 'trazodon'): 6.90875477931522,
#  ('refractori', 'thoracocentesi'): 6.90875477931522,
#  ('pitressin', 'purpl'): -6.90875477931522,
#  ('aaox', 'moan'): 6.90875477931522,
#  ('dnr', 'zoloft'): -1.3825560390092835,
#  ('ambien', 'qam'): 6.90875477931522,
#  ('autopeep', 'fibrinogen'): -6.90875477931522,
#  ('burn', 'spacer'): 6.90875477931522,
#  ('fibrinogen', 'vasopressin'): -2.4136656596891792,
#  ('signatur', 'young'): 6.90875477931522,
#  ('deterior', 'leukocyt'): 6.90875477931522,
#  ('gabapentin', 'qtc'): 6.90875477931522,
#  ('cocain', 'epigastr'): 6.90875477931522,
#  ('erythro', 'oob'): 6.90875477931522,
#  ('cash', 'spiromet'): 6.90875477931522,
#  ('diaphoresi', 'signatur'): 6.90875477931522,
#  ('dz', 'silent'): -6.90875477931522,
#  ('arrest', 'azotemia'): -6.90875477931522,
#  ('fatti', 'signatur'): 6.90875477931522,
#  ('chair', 'lcw'): 6.90875477931522,
#  ('levoph', 'vasoconstrict'): -6.90875477931522,
#  ('diamox', 'neosynephrin'): 6.90875477931522,
#  ('neo', 'outer'): 6.90875477931522,
#  ('cmo', 'grim'): -6.90875477931522,
#  ('rememb', 'seroquel'): 6.90875477931522,
#  ('ntnd', 'thiamin'): 6.90875477931522,
#  ('dizzi', 'thiamin'): 6.90875477931522,
#  ('gabapentin', 'shorter'): 6.90875477931522,
#  ('declin', 'scab'): 6.90875477931522,
#  ('platelet', 'postop'): 6.90875477931522,
#  ('chair', 'reguard'): 6.90875477931522,
#  ('core', 'synthet'): 6.90875477931522,
#  ('scar', 'uri'): 6.90875477931522,
#  ('arthrit', 'cdb'): 6.90875477931522,
#  ('anur', 'dnr'): 1.604655121332035,
#  ('ba', 'ctx'): 6.90875477931522,
#  ('unavail', 'venti'): 6.90875477931522,
#  ('ciwa', 'prec'): 6.90875477931522,
#  ('hypothermia', 'rpr'): 6.90875477931522,
#  ('bell', 'dermat'): 6.90875477931522,
#  ('video', 'vp'): 6.90875477931522,
#  ('neosynephrin', 'vasopressin'): -6.90875477931522,
#  ('cash', 'ciwa'): 6.90875477931522,
#  ('dysynchron', 'osa'): -6.90875477931522,
#  ('diflucan', 'iddm'): 6.90875477931522,
#  ('levoph', 'qam'): 6.90875477931522,
#  ('asystol', 'neosynephrin'): -6.90875477931522,
#  ('chair', 'fibrinogen'): -6.90875477931522,
#  ('dopamin', 'unstabl'): -6.90875477931522,
#  ('sensat', 'silent'): 6.90875477931522,
#  ('goc', 'nifedipin'): 6.90875477931522,
#  ('bow', 'scar'): 6.90875477931522,
#  ('platelet', 'rhinorrhea'): -0.2870999276476155,
#  ('silent', 'vallecula'): 6.90875477931522,
#  ('compani', 'dni'): 6.90875477931522,
#  ('deterior', 'heroic'): -6.90875477931522,
#  ('puff', 'video'): 6.90875477931522,
#  ('hctz', 'prilosec'): 6.90875477931522,
#  ('gabapentin', 'mellitu'): 6.90875477931522,
#  ('hunger', 'signatur'): 6.90875477931522,
#  ('dnr', 'epidur'): 6.90875477931522,
#  ('dni', 'ofm'): 6.90875477931522,
#  ('dome', 'slice'): 6.90875477931522,
#  ('seroquel', 'zoloft'): 6.90875477931522,
#  ('adenosin', 'oligur'): 6.90875477931522,
#  ('cpr', 'syncop'): 6.90875477931522,
#  ('norepinephrin', 'vasopressin'): -0.8484241605198924,
#  ('dnr', 'opinion'): -6.90875477931522,
#  ('gather', 'levoph'): -6.90875477931522,
#  ('refractori', 'spfc'): 6.90875477931522,
#  ('abruptli', 'platelet'): -6.90875477931522,
#  ('fibrinogen', 'fungemia'): 6.90875477931522,
#  ('mellitu', 'stair'): 6.90875477931522,
#  ('hhn', 'lpm'): 6.90875477931522,
#  ('barium', 'silent'): 6.90875477931522,
#  ('oob', 'simpli'): 6.90875477931522,
#  ('mso', 'pca'): 6.90875477931522,
#  ('burn', 'lighthead'): 6.90875477931522,
#  ('dni', 'dobutamin'): 6.90875477931522,
#  ('colonoscopi', 'epidur'): 6.90875477931522,
#  ('escal', 'prognosi'): -2.387057016415087,
#  ('dic', 'vasopressor'): -6.90875477931522,
#  ('dni', 'phenylephrin'): -1.4998139424623853,
#  ('anur', 'corneal'): -6.90875477931522,
#  ('ambul', 'osa'): -6.90875477931522,
#  ('ferrou', 'gabapentin'): 6.90875477931522,
#  ('ferrou', 'unavail'): 6.90875477931522,
#  ('cyanot', 'illeu'): -6.90875477931522,
#  ('autopsi', 'mottl'): -6.90875477931522,
#  ('fibrinogen', 'mellitu'): 3.0544069933991973,
#  ('bromid', 'dyslipidemia'): 6.90875477931522,
#  ('pyuria', 'seroquel'): 6.90875477931522,
#  ('db', 'spacer'): 6.90875477931522,
#  ('adam', 'hypotherm'): -6.90875477931522,
#  ('gabapentin', 'incis'): 6.90875477931522,
#  ('nahco', 'wish'): -6.90875477931522,
#  ('dni', 'ipf'): -0.4046335072286383,
#  ('historian', 'hurt'): -6.90875477931522,
#  ('arrest', 'led'): 6.90875477931522,
#  ('gabapentin', 'nocturn'): 6.90875477931522,
#  ('anur', 'chemic'): 6.90875477931522,
#  ('dyslipidemia', 'soln'): 6.90875477931522,
#  ('commod', 'compani'): 6.90875477931522,
#  ('intiat', 'pronounc'): -6.90875477931522,
#  ('levoph', 'recruit'): -6.90875477931522,
#  ('gotten', 'msicu'): 6.90875477931522,
#  ('banana', 'oob'): 6.90875477931522,
#  ('led', 'schizophrenia'): 6.90875477931522,
#  ('dni', 'intiat'): -6.90875477931522,
#  ('ppd', 'soln'): 6.90875477931522,
#  ('arrest', 'sweat'): 6.90875477931522,
#  ('dnr', 'ppn'): 6.90875477931522,
#  ('cremat', 'funer'): -6.90875477931522,
#  ('friction', 'unobtain'): 6.90875477931522,
#  ('chb', 'moan'): -6.90875477931522,
#  ('epigastr', 'xanax'): 6.90875477931522,
#  ('dnr', 'fc'): -6.90875477931522,
#  ('brb', 'ppd'): 6.90875477931522,
#  ('cocain', 'pneumococc'): 6.90875477931522,
#  ('icter', 'mellitu'): -0.4046335072286383,
#  ('currenlti', 'dni'): 6.90875477931522,
#  ('dermat', 'platelet'): 6.90875477931522,
#  ('adenocarcinoma', 'synthet'): 6.90875477931522,
#  ('oob', 'video'): 6.90875477931522,
#  ('captopril', 'omeprazol'): 0.0,
#  ('bipolar', 'forc'): -3.521008960463551,
#  ('fatti', 'natg'): -6.90875477931522,
#  ('ferrou', 'xii'): 6.90875477931522,
#  ('platelet', 'rpr'): 6.90875477931522,
#  ('adam', 'futil'): -6.90875477931522,
#  ('neo', 'pca'): 6.90875477931522,
#  ('ambul', 'trazodon'): 6.90875477931522,
#  ('aox', 'wish'): 6.90875477931522,
#  ('levoph', 'sluggish'): -1.3182829507563796,
#  ('incent', 'mrcp'): -6.90875477931522,
#  ('chol', 'nahco'): -6.90875477931522,
#  ('aox', 'diamox'): 6.90875477931522,
#  ('chemic', 'exophyt'): -6.90875477931522,
#  ('gabapentin', 'thiamin'): 6.90875477931522,
#  ('levoph', 'xii'): 6.90875477931522,
#  ('homogen', 'scar'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('ppd', 'weekli'): 6.90875477931522,
#  ('oncologist', 'wish'): 0.6916505477038827,
#  ('bill', 'lotion'): 6.90875477931522,
#  ('dnr', 'ffp'): -1.9029698713994427,
#  ('incent', 'ntnd'): -6.90875477931522,
#  ('aox', 'dnr'): 2.387057016415087,
#  ('aricept', 'levoph'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('levoph', 'pitressin'): 1.3825560390092835,
#  ('hypotherm', 'xl'): 6.90875477931522,
#  ('escal', 'tobra'): -6.90875477931522,
#  ('nicotin', 'uri'): 6.90875477931522,
#  ('cocain', 'thrive'): 6.90875477931522,
#  ('bromid', 'laminectomi'): 6.90875477931522,
#  ('hive', 'wallet'): 6.90875477931522,
#  ('cpr', 'neo'): 1.095952712632351,
#  ('neosynephrin', 'pea'): -6.90875477931522,
#  ('cooki', 'neutral'): 6.90875477931522,
#  ('ppd', 'suprapub'): 6.90875477931522,
#  ('nice', 'suffer'): 6.90875477931522,
#  ('neo', 'sorb'): -6.90875477931522,
#  ('hypotherm', 'readdress'): -6.90875477931522,
#  ('grave', 'purpl'): -6.90875477931522,
#  ('anur', 'transmitr'): 6.90875477931522,
#  ('lymphangit', 'osa'): 6.90875477931522,
#  ('pyuria', 'rigor'): 6.90875477931522,
#  ('dni', 'norepinephrin'): -1.604655121332035,
#  ('carvedilol', 'fibrinogen'): 6.90875477931522,
#  ('cocain', 'ctx'): 6.90875477931522,
#  ('asthma', 'wallet'): 6.90875477931522,
#  ('caspofungin', 'levoph'): 6.90875477931522,
#  ('cramp', 'dnr'): 6.90875477931522,
#  ('endur', 'xanax'): 6.90875477931522,
#  ('death', 'lusb'): 6.90875477931522,
#  ('anuria', 'readmit'): 6.90875477931522,
#  ('motor', 'sibl'): 6.90875477931522,
#  ('coach', 'spiromet'): 6.90875477931522,
#  ('ambul', 'platelet'): -6.90875477931522,
#  ('plate', 'scar'): 6.90875477931522,
#  ('defibril', 'unstabl'): -6.90875477931522,
#  ('asystol', 'peac'): -6.90875477931522,
#  ('^th', 'banana'): 6.90875477931522,
#  ('aricept', 'norepinephrin'): 6.90875477931522,
#  ('nectar', 'pivot'): 6.90875477931522,
#  ('ambien', 'hunger'): 6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('rememb', 'uri'): 6.90875477931522,
#  ('gabapentin', 'opiat'): 6.90875477931522,
#  ('diaphoresi', 'ruptur'): 6.90875477931522,
#  ('agon', 'clergi'): -6.90875477931522,
#  ('aox', 'hugger'): 6.90875477931522,
#  ('dizzi', 'ipf'): 6.90875477931522,
#  ('elimin', 'pharyng'): 6.90875477931522,
#  ('ipf', 'lpm'): 6.90875477931522,
#  ('barium', 'smooth'): 6.90875477931522,
#  ('intent', 'thiamin'): 6.90875477931522,
#  ('morbid', 'underpenetr'): 6.90875477931522,
#  ('barium', 'xii'): 6.90875477931522,
#  ('magnevist', 'vertebra'): 6.90875477931522,
#  ('famil', 'struggl'): -6.90875477931522,
#  ('angioplasti', 'deploy'): 6.90875477931522,
#  ('pleasant', 'tubular'): 6.90875477931522,
#  ('hypothermia', 'refractori'): -6.90875477931522,
#  ('cpr', 'recalibr'): -6.90875477931522,
#  ('asthma', 'thiamin'): 6.90875477931522,
#  ('tdi', 'unavail'): 6.90875477931522,
#  ('dnr', 'xopenex'): -3.1942475376942854,
#  ('forc', 'oob'): -6.90875477931522,
#  ('diaper', 'video'): 6.90875477931522,
#  ('ambul', 'rusti'): -6.90875477931522,
#  ('anur', 'conc'): 6.90875477931522,
#  ('dnr', 'vp'): 6.90875477931522,
#  ('dz', 'underneath'): 6.90875477931522,
#  ('kerlix', 'nectar'): 6.90875477931522,
#  ('modifi', 'wfl'): 6.90875477931522,
#  ('levoph', 'phlegm'): -6.90875477931522,
#  ('ferritin', 'readmit'): 6.90875477931522,
#  ('cyanot', 'knowledg'): 6.90875477931522,
#  ('mellitu', 'omeprazol'): 1.5360079185039965,
#  ('gabapentin', 'sibl'): 6.90875477931522,
#  ('colonoscopi', 'dnr'): 6.90875477931522,
#  ('pca', 'wish'): 6.90875477931522,
#  ('barium', 'spur'): 6.90875477931522,
#  ('ethic', 'sorb'): -6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('spacer', 'unstabl'): 6.90875477931522,
#  ('lw', 'unstabl'): 6.90875477931522,
#  ('bottl', 'levoph'): -1.5295247690781295,
#  ('dic', 'dni'): 0.6916505477038827,
#  ('jejunum', 'scar'): 6.90875477931522,
#  ('phlegm', 'splint'): 6.90875477931522,
#  ('im', 'lusb'): 6.90875477931522,
#  ('dni', 'mycolyt'): -6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('bottl', 'deterior'): 6.90875477931522,
#  ('cmo', 'gentamycin'): -6.90875477931522,
#  ('flight', 'nephrolog'): 6.90875477931522,
#  ('arrest', 'pastor'): -6.90875477931522,
#  ('expir', 'wish'): -6.90875477931522,
#  ('diaphoresi', 'money'): 6.90875477931522,
#  ('deterior', 'unequ'): 6.90875477931522,
#  ('clergi', 'levoph'): -6.90875477931522,
#  ('qam', 'strictur'): 6.90875477931522,
#  ('neo', 'recruit'): 6.90875477931522,
#  ('dietari', 'distanc'): 6.90875477931522,
#  ('cpr', 'mottl'): -6.90875477931522,
#  ('arrang', 'dnr'): -6.90875477931522,
#  ('death', 'paco'): -6.90875477931522,
#  ('nitroglycerin', 'sweat'): -6.90875477931522,
#  ('ferrou', 'thrive'): 6.90875477931522,
#  ('hive', 'metoclopramid'): 6.90875477931522,
#  ('dni', 'thirst'): 6.90875477931522,
#  ('lpm', 'oob'): 6.90875477931522,
#  ('echocardiogram', 'ppd'): 6.90875477931522,
#  ('adenocarcinoma', 'osa'): 6.90875477931522,
#  ('lat', 'syncop'): 6.90875477931522,
#  ('criticar', 'pinpoint'): -6.90875477931522,
#  ('fibrinogen', 'opiat'): 0.044363007362570685,
#  ('fibrinogen', 'religi'): -6.90875477931522,
#  ('ferritin', 'trazodon'): 6.90875477931522,
#  ('mail', 'pleasant'): 6.90875477931522,
#  ('pleasant', 'silent'): 6.90875477931522,
#  ('deterior', 'mellitu'): 6.90875477931522,
#  ('core', 'declin'): -6.90875477931522,
#  ('autopeep', 'paralyt'): -6.90875477931522,
#  ('ppd', 'puff'): 6.90875477931522,
#  ('chair', 'dni'): 0.4119976373686585,
#  ('qam', 'sensat'): 1.3825560390092835,
#  ('historian', 'ppd'): 6.90875477931522,
#  ('xl', 'zyprexa'): 6.90875477931522,
#  ('dni', 'sibl'): 1.604655121332035,
#  ('pod', 'xanax'): 6.90875477931522,
#  ('postop', 'tubular'): 6.90875477931522,
#  ('ppd', 'rpr'): 6.90875477931522,
#  ('dni', 'morgu'): -6.90875477931522,
#  ('hsq', 'ppd'): 0.0,
#  ('pneumococc', 'qam'): 6.90875477931522,
#  ('homogen', 'pronounc'): 6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('intent', 'nifedipin'): 6.90875477931522,
#  ('crrt', 'lotion'): 6.90875477931522,
#  ('coach', 'oob'): 6.90875477931522,
#  ('ciwa', 'dopamin'): 6.90875477931522,
#  ('romi', 'thirst'): 6.90875477931522,
#  ('cs', 'hugger'): -6.90875477931522,
#  ('arrest', 'declin'): 6.90875477931522,
#  ('gastrojejunostomi', 'metoclopramid'): 6.90875477931522,
#  ('burn', 'thirst'): 6.90875477931522,
#  ('antb', 'captopril'): 6.90875477931522,
#  ('ambul', 'west'): 6.90875477931522,
#  ('dni', 'levoph'): -0.2870999276476155,
#  ('neo', 'scab'): 6.90875477931522,
#  ('platelet', 'rm'): 6.90875477931522,
#  ('ambien', 'crack'): 6.90875477931522,
#  ('brb', 'crrt'): -6.90875477931522,
#  ('levoph', 'meropenam'): -6.90875477931522,
#  ('expir', 'vasopressin'): -6.90875477931522,
#  ('cocain', 'sweat'): 6.90875477931522,
#  ('neo', 'video'): 6.90875477931522,
#  ('oob', 'ppd'): 6.90875477931522,
#  ('griev', 'levoph'): -6.90875477931522,
#  ('contractur', 'criticar'): 6.90875477931522,
#  ('ipf', 'robitussin'): -6.90875477931522,
#  ('life', 'prognosi'): -6.90875477931522,
#  ('ffp', 'opinion'): 6.90875477931522,
#  ('proph', 'thoracocentesi'): 6.90875477931522,
#  ('rigor', 'young'): 6.90875477931522,
#  ('fdp', 'neutral'): 6.90875477931522,
#  ('nahco', 'purpl'): -6.90875477931522,
#  ('declin', 'signatur'): 6.90875477931522,
#  ('commod', 'nectar'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('aaox', 'readmit'): 6.90875477931522,
#  ('crrt', 'surgicel'): -6.90875477931522,
#  ('aox', 'puff'): 6.90875477931522,
#  ('cellcept', 'lat'): 6.90875477931522,
#  ('azotemia', 'petechia'): -6.90875477931522,
#  ('dni', 'rm'): 6.90875477931522,
#  ('omeprazol', 'quinolon'): 6.90875477931522,
#  ('colonoscopi', 'dopamin'): 6.90875477931522,
#  ('captopril', 'yel'): 6.90875477931522,
#  ('clonazepam', 'recruit'): 6.90875477931522,
#  ('adenocarcinoma', 'pod'): 6.90875477931522,
#  ('cash', 'dopamin'): -6.90875477931522,
#  ('autopsi', 'prognosi'): -6.90875477931522,
#  ('clinician', 'im'): 6.90875477931522,
#  ('hypothermia', 'sweat'): 6.90875477931522,
#  ('bottl', 'carvedilol'): 6.90875477931522,
#  ('declin', 'ozz'): -6.90875477931522,
#  ('occipit', 'zyprexa'): 6.90875477931522,
#  ('angioplasti', 'tran'): 6.90875477931522,
#  ('ppd', 'subq'): 6.90875477931522,
#  ('arrest', 'scar'): 6.90875477931522,
#  ('cyanot', 'iddm'): 6.90875477931522,
#  ('pneumothorac', 'scar'): 6.90875477931522,
#  ('liw', 'prognosi'): -6.90875477931522,
#  ('chair', 'ctx'): 6.90875477931522,
#  ('strictur', 'vagu'): 6.90875477931522,
#  ('ctx', 'stair'): 6.90875477931522,
#  ('pca', 'pharmacolog'): 6.90875477931522,
#  ('romi', 'venti'): 6.90875477931522,
#  ('levoph', 'pcv'): 1.4998139424623853,
#  ('suprapub', 'wish'): 6.90875477931522,
#  ('ambien', 'puff'): 6.90875477931522,
#  ('omeprazol', 'zyprexa'): 6.90875477931522,
#  ('hugger', 'moan'): -6.90875477931522,
#  ('dni', 'jerk'): -6.90875477931522,
#  ('bicarbon', 'levoph'): -6.90875477931522,
#  ('gentamycin', 'multisystem'): -6.90875477931522,
#  ('cpr', 'dobutamin'): -6.90875477931522,
#  ('dizzi', 'sibl'): -6.90875477931522,
#  ('bottl', 'motor'): 6.90875477931522,
#  ('mtg', 'ruptur'): 6.90875477931522,
#  ('pleasant', 'redirect'): 0.2226944607151099,
#  ('dni', 'spacer'): 6.90875477931522,
#  ('profound', 'ud'): 6.90875477931522,
#  ('permiss', 'sluggishli'): -6.90875477931522,
#  ('diaphoresi', 'ppd'): 6.90875477931522,
#  ('core', 'dorsal'): -6.90875477931522,
#  ('cpr', 'struggl'): 6.90875477931522,
#  ('crowd', 'habitu'): 6.90875477931522,
#  ('hugger', 'pinpoint'): -6.90875477931522,
#  ('cocain', 'gabapentin'): 6.90875477931522,
#  ('incis', 'purpl'): 6.90875477931522,
#  ('levoph', 'mean'): 6.90875477931522,
#  ('diaphoresi', 'hsq'): 6.90875477931522,
#  ('cramp', 'platelet'): -6.90875477931522,
#  ('buck', 'triadyn'): 6.90875477931522,
#  ('levoph', 'montitor'): -6.90875477931522,
#  ('death', 'sweat'): 6.90875477931522,
#  ('bromid', 'subdur'): 6.90875477931522,
#  ('dnr', 'rpr'): 6.90875477931522,
#  ('incent', 'phlegm'): 6.90875477931522,
#  ('gait', 'gown'): 6.90875477931522,
#  ('dni', 'historian'): 6.90875477931522,
#  ('acidot', 'fdp'): -6.90875477931522,
#  ('bottl', 'chemic'): 6.90875477931522,
#  ('fatti', 'sweat'): 6.90875477931522,
#  ('cmo', 'sibl'): -6.90875477931522,
#  ('icter', 'weekli'): 6.90875477931522,
#  ('incent', 'spacer'): 6.90875477931522,
#  ('ba', 'precordium'): 6.90875477931522,
#  ('cocain', 'klonopin'): 6.90875477931522,
#  ('dopamin', 'qam'): 6.90875477931522,
#  ('cs', 'lpm'): -6.90875477931522,
#  ('gait', 'thiamin'): 6.90875477931522,
#  ('cpr', 'twitch'): -6.90875477931522,
#  ('cyanot', 'fungemia'): -6.90875477931522,
#  ('captopril', 'chol'): 6.90875477931522,
#  ('compani', 'unstabl'): 6.90875477931522,
#  ('dnr', 'vagu'): 6.90875477931522,
#  ('aricept', 'gown'): -6.90875477931522,
#  ('cardiovert', 'levoph'): -4.245250472054411,
#  ('intent', 'precordium'): 6.90875477931522,
#  ('asthma', 'death'): 6.90875477931522,
#  ('cpr', 'nitroglycerin'): -6.90875477931522,
#  ('behavior', 'cocain'): 6.90875477931522,
#  ('hospic', 'mso'): -6.90875477931522,
#  ('chip', 'readmit'): 6.90875477931522,
#  ('bicarbon', 'weekli'): 6.90875477931522,
#  ('habitu', 'underpenetr'): 6.90875477931522,
#  ('cpr', 'prognosi'): -6.90875477931522,
#  ('dni', 'epidur'): 6.90875477931522,
#  ('prognosi', 'viabl'): -6.90875477931522,
#  ('bicarbon', 'thiamin'): 6.90875477931522,
#  ('bottl', 'cisatracurium'): -6.90875477931522,
#  ('tubular', 'vp'): 6.90875477931522,
#  ('clergi', 'suffer'): -6.90875477931522,
#  ('dopamin', 'grave'): -6.90875477931522,
#  ('aox', 'esld'): 6.90875477931522,
#  ('commod', 'sooner'): 6.90875477931522,
#  ('aox', 'money'): 6.90875477931522,
#  ('argatroban', 'norepinephrin'): -6.90875477931522,
#  ('arrest', 'dic'): -6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('normotherm', 'oob'): 6.90875477931522,
#  ('bipolar', 'sundown'): 6.90875477931522,
#  ('autopeep', 'levoph'): -6.90875477931522,
#  ('signatur', 'sweat'): 6.90875477931522,
#  ('dizzi', 'herp'): 6.90875477931522,
#  ('dome', 'homogen'): 6.90875477931522,
#  ('core', 'hsq'): -6.90875477931522,
#  ('dobutamin', 'hugger'): 6.90875477931522,
#  ('osa', 'platelet'): -6.90875477931522,
#  ('norepinephrin', 'phenylephrin'): -6.90875477931522,
#  ('chip', 'moisten'): -6.90875477931522,
#  ('pcv', 'vasopressin'): -6.90875477931522,
#  ('db', 'sweat'): 6.90875477931522,
#  ('cup', 'readmit'): 6.90875477931522,
#  ('pharyng', 'wfl'): 6.90875477931522,
#  ('lift', 'readmit'): 6.90875477931522,
#  ('ambul', 'omeprazol'): 6.90875477931522,
#  ('nocturn', 'romi'): 6.90875477931522,
#  ('gabapentin', 'hive'): 6.90875477931522,
#  ('bell', 'chair'): 2.473073171472692,
#  ('ppd', 'romi'): 6.90875477931522,
#  ('maroon', 'reguard'): 6.90875477931522,
#  ('absorb', 'paralyt'): 6.90875477931522,
#  ('grave', 'prognosi'): -2.8164316892990344,
#  ('angioplasti', 'iddm'): 6.90875477931522,
#  ('hypothermia', 'resucit'): -6.90875477931522,
#  ('dnr', 'pyuria'): 0.509761227710204,
#  ('crrt', 'synthet'): 6.90875477931522,
#  ('outer', 'vertebra'): 6.90875477931522,
#  ('fibrinogen', 'norepinephrin'): -1.982039101659681,
#  ('herp', 'ipf'): 6.90875477931522,
#  ('anuria', 'cvvhd'): -6.90875477931522,
#  ('clergi', 'paralyt'): -6.90875477931522,
#  ('goc', 'ind'): -6.90875477931522,
#  ('plate', 'requr'): 6.90875477931522,
#  ('dni', 'plerual'): -6.90875477931522,
#  ('ambien', 'freeli'): 6.90875477931522,
#  ('conc', 'rigor'): 6.90875477931522,
#  ('dnr', 'robitussin'): -1.095952712632351,
#  ('ambul', 'stair'): 6.90875477931522,
#  ('chair', 'stood'): 6.90875477931522,
#  ('deterior', 'friction'): 6.90875477931522,
#  ('diuril', 'gabapentin'): 6.90875477931522,
#  ('anaphylaxi', 'dni'): 6.90875477931522,
#  ('asthma', 'lusb'): 6.90875477931522,
#  ('cramp', 'hsq'): -6.90875477931522,
#  ('diaphoresi', 'uncoop'): 6.90875477931522,
#  ('arrest', 'recruit'): 3.649722139527292,
#  ('bicarbon', 'crrt'): -6.90875477931522,
#  ('acc', 'angri'): 6.90875477931522,
#  ('coach', 'unavail'): 6.90875477931522,
#  ('dnr', 'vasopressin'): -6.90875477931522,
#  ('ppd', 'tran'): 6.90875477931522,
#  ("sxn'ing", 'thk'): 6.90875477931522,
#  ('cyanot', 'laminectomi'): 6.90875477931522,
#  ('cs', 'oob'): 6.90875477931522,
#  ('imbal', 'pca'): 6.90875477931522,
#  ('soln', 'subdur'): 6.90875477931522,
#  ('cellcept', 'dyslipidemia'): 6.90875477931522,
#  ('pyuria', 'sibl'): 6.90875477931522,
#  ('mso', 'prognosi'): -6.90875477931522,
#  ('hospic', 'wish'): 0.4046335072286383,
#  ('silent', 'videofluoroscopi'): 6.90875477931522,
#  ('contd', 'signatur'): 6.90875477931522,
#  ('itchi', 'quinolon'): 6.90875477931522,
#  ('dni', 'pleuravac'): -6.90875477931522,
#  ('hunger', 'wish'): 6.90875477931522,
#  ('azotemia', 'declin'): 6.90875477931522,
#  ('cracker', 'mellitu'): 6.90875477931522,
#  ('news', 'pronounc'): -6.90875477931522,
#  ('aox', 'palli'): 6.90875477931522,
#  ('gait', 'mellitu'): 6.90875477931522,
#  ('dyslipidemia', 'flight'): 6.90875477931522,
#  ('esld', 'oob'): 6.90875477931522,
#  ('ctx', 'syncop'): 6.90875477931522,
#  ('icter', 'prilosec'): 6.90875477931522,
#  ('cvvh', 'vasopressin'): -6.90875477931522,
#  ('mva', 'spiromet'): 6.90875477931522,
#  ('cash', 'ppd'): 6.90875477931522,
#  ('ggt', 'vasopressor'): -6.90875477931522,
#  ('sensat', 'thirst'): 6.90875477931522,
#  ('chair', 'illeu'): -6.90875477931522,
#  ('gabapentin', 'xl'): 6.90875477931522,
#  ('articul', 'robitussin'): 6.90875477931522,
#  ('anur', 'cardiovert'): 6.90875477931522,
#  ('death', 'declar'): -6.90875477931522,
#  ('chair', 'ppd'): 0.0,
#  ('dnr', 'meropenam'): -6.90875477931522,
#  ('nitroglycerin', 'rhinorrhea'): -6.90875477931522,
#  ('declar', 'nimv'): -6.90875477931522,
#  ('colonoscopi', 'signatur'): 6.90875477931522,
#  ('breakfast', 'recalibr'): 6.90875477931522,
#  ('cmo', 'hunger'): 0.0,
#  ('corneal', 'twitch'): -6.90875477931522,
#  ('purpl', 'seroquel'): 6.90875477931522,
#  ('intiat', 'splint'): 6.90875477931522,
#  ('dni', 'pivot'): 0.2226944607151099,
#  ('hugger', 'incis'): -6.90875477931522,
#  ('olanzapin', 'palli'): 6.90875477931522,
#  ('purpl', 'wish'): -6.90875477931522,
#  ('pleasant', 'unstabl'): 6.90875477931522,
#  ('chemic', 'gabapentin'): 6.90875477931522,
#  ('osa', 'paco'): 6.90875477931522,
#  ('clonidin', 'refractori'): 6.90875477931522,
#  ('fibrinogen', 'hemothorax'): -6.90875477931522,
#  ('levoph', 'paco'): 6.90875477931522,
#  ('ctx', 'signatur'): 6.90875477931522,
#  ('asthma', 'cash'): 6.90875477931522,
#  ('nocturn', 'thiamin'): 6.90875477931522,
#  ('cmo', 'incis'): -6.90875477931522,
#  ('bill', 'readmit'): 6.90875477931522,
#  ('mva', 'spacer'): 6.90875477931522,
#  ('money', 'ultram'): 6.90875477931522,
#  ('absorb', 'seroquel'): 6.90875477931522,
#  ('cocain', 'omeprazol'): 6.90875477931522,
#  ('anaphylaxi', 'deterior'): 6.90875477931522,
#  ('anur', 'crrt'): 6.90875477931522,
#  ('life', 'qam'): 6.90875477931522,
#  ('permiss', 'vasopressin'): -6.90875477931522,
#  ('dni', 'ind'): -6.90875477931522,
#  ('death', 'peac'): -6.90875477931522,
#  ('knew', 'spiromet'): 6.90875477931522,
#  ('cardiovert', 'contini'): 6.90875477931522,
#  ('palli', 'wish'): -0.809128888289493,
#  ('gastrojejunostomi', 'strictur'): 6.90875477931522,
#  ('levoph', 'occipit'): 6.90875477931522,
#  ('levoph', 'moan'): -6.90875477931522,
#  ('lotion', 'puff'): 6.90875477931522,
#  ('omeprazol', 'postop'): 6.90875477931522,
#  ('ruptur', 'spiromet'): 6.90875477931522,
#  ('phlegm', 'signatur'): 6.90875477931522,
#  ('bair', 'vtach'): 6.90875477931522,
#  ('hemothorax', 'hive'): -6.90875477931522,
#  ('anaphylaxi', 'articul'): 6.90875477931522,
#  ('paperwork', 'xanax'): 6.90875477931522,
#  ('bottl', 'zoloft'): 6.90875477931522,
#  ('cash', 'osa'): 6.90875477931522,
#  ('pharyng', 'vallecula'): 6.90875477931522,
#  ('ambul', 'bair'): -6.90875477931522,
#  ('arrest', 'venti'): 6.90875477931522,
#  ('ppd', 'wallet'): 6.90875477931522,
#  ('appi', 'venti'): 6.90875477931522,
#  ('recalibr', 'video'): 6.90875477931522,
#  ('gabapentin', 'ultram'): 6.90875477931522,
#  ('clonidin', 'mellitu'): 6.90875477931522,
#  ('fliud', 'moan'): -6.90875477931522,
#  ('dnr', 'led'): -0.6916505477038827,
#  ('brb', 'tran'): 6.90875477931522,
#  ('hilum', 'tranfer'): 6.90875477931522,
#  ('pharmacolog', 'wish'): 6.90875477931522,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('adenosin', 'td'): 6.90875477931522,
#  ('asthma', 'ffp'): 6.90875477931522,
#  ('ambul', 'asthma'): 6.90875477931522,
#  ('aricept', 'distanc'): 6.90875477931522,
#  ('brb', 'clonazepam'): 6.90875477931522,
#  ('homogen', 'peribronchovascular'): 6.90875477931522,
#  ('breakfast', 'fax'): 6.90875477931522,
#  ('nifedipin', 'venti'): 6.90875477931522,
#  ('bromid', 'readmit'): 6.90875477931522,
#  ('lat', 'splint'): 6.90875477931522,
#  ('precordium', 'puff'): 6.90875477931522,
#  ('fu', 'incent'): 6.90875477931522,
#  ('neo', 'pleasant'): 6.90875477931522,
#  ('acidot', 'levoph'): -6.90875477931522,
#  ('dnr', 'grim'): -6.90875477931522,
#  ('incent', 'itchi'): 6.90875477931522,
#  ('robitussin', 'zyprexa'): 6.90875477931522,
#  ('cramp', 'ppd'): -6.90875477931522,
#  ('aliv', 'syncop'): 6.90875477931522,
#  ('ambien', 'neo'): -6.90875477931522,
#  ('hctz', 'splint'): 6.90875477931522,
#  ('fax', 'pleasant'): 6.90875477931522,
#  ('conc', 'prognosi'): -6.90875477931522,
#  ('epidur', 'neoplast'): 6.90875477931522,
#  ('arrest', 'hypercapnia'): -6.90875477931522,
#  ('ambien', 'commod'): 6.90875477931522,
#  ('captopril', 'pose'): 6.90875477931522,
#  ('occupi', 'seriou'): 6.90875477931522,
#  ('hilum', 'prilosec'): 6.90875477931522,
#  ('jewelri', 'xl'): 6.90875477931522,
#  ('nahco', 'prognosi'): -6.90875477931522,
#  ('dizzi', 'qam'): 6.90875477931522,
#  ('nectar', 'pleasantli'): 6.90875477931522,
#  ('cvvh', 'esld'): -6.90875477931522,
#  ('aaox', 'ipf'): 6.90875477931522,
#  ('aaox', 'redirect'): 6.90875477931522,
#  ('dni', 'unequ'): 6.90875477931522,
#  ('gait', 'paperwork'): 6.90875477931522,
#  ('flight', 'pleasantli'): 6.90875477931522,
#  ('purpl', 'ultram'): 6.90875477931522,
#  ('gastriti', 'pleasant'): 6.90875477931522,
#  ('mean', 'seat'): 6.90875477931522,
#  ('anuria', 'chair'): 6.90875477931522,
#  ('mtg', 'sibl'): 6.90875477931522,
#  ('dnr', 'thirst'): 6.90875477931522,
#  ('im', 'trazodon'): 6.90875477931522,
#  ('discard', 'levof'): -6.90875477931522,
#  ('oob', 'spiromet'): 6.90875477931522,
#  ('ciwa', 'cloth'): 6.90875477931522,
#  ('captopril', 'pod'): 6.90875477931522,
#  ('mva', 'panic'): 6.90875477931522,
#  ('para', 'vertebra'): -6.90875477931522,
#  ('gurgl', 'zyprexa'): 6.90875477931522,
#  ('adenocarcinoma', 'spfc'): 6.90875477931522,
#  ('foci', 'ligament'): 6.90875477931522,
#  ('cyanot', 'lw'): -6.90875477931522,
#  ('mrg', 'seroquel'): 6.90875477931522,
#  ('clinician', 'recruit'): 6.90875477931522,
#  ('acc', 'young'): 6.90875477931522,
#  ('cmo', 'icter'): -6.90875477931522,
#  ('asthma', 'soln'): 6.90875477931522,
#  ('incent', 'pinpoint'): 6.90875477931522,
#  ('cup', 'neutral'): 6.90875477931522,
#  ('death', 'dietari'): 6.90875477931522,
#  ('ppd', 'spacer'): 6.90875477931522,
#  ('eob', 'levoph'): 6.90875477931522,
#  ('bottl', 'crack'): 6.90875477931522,
#  ('neo', 'palli'): -6.90875477931522,
#  ('life', 'scopalamin'): -6.90875477931522,
#  ('metoclopramid', 'nitroglycerin'): 6.90875477931522,
#  ('dead', 'rehabilit'): 6.90875477931522,
#  ('hypotherm', 'normotherm'): -6.90875477931522,
#  ('neo', 'rabbi'): -6.90875477931522,
#  ('align', 'seroquel'): -6.90875477931522,
#  ('hilum', 'treitz'): 6.90875477931522,
#  ('hypothermia', 'pcv'): -6.90875477931522,
#  ('consciou', 'incis'): 6.90875477931522,
#  ('bipolar', 'proph'): 6.90875477931522,
#  ('commod', 'oob'): 3.217378503389662,
#  ('deploy', 'postpylor'): 6.90875477931522,
#  ('cash', 'oob'): 6.90875477931522,
#  ('mrg', 'zoloft'): 6.90875477931522,
#  ('clergi', 'mtg'): -6.90875477931522,
#  ('aox', 'ruptur'): 6.90875477931522,
#  ('cracker', 'ferrou'): 6.90875477931522,
#  ('cash', 'hive'): 6.90875477931522,
#  ('dni', 'hypothermia'): 0.5584397574369147,
#  ('carvedilol', 'prilosec'): 6.90875477931522,
#  ('coach', 'puff'): 6.90875477931522,
#  ('cg', 'dnr'): -6.90875477931522,
#  ('hive', 'jewelri'): 6.90875477931522,
#  ('postop', 'readmit'): 6.90875477931522,
#  ('romi', 'weekli'): 6.90875477931522,
#  ('ctx', 'ultram'): 6.90875477931522,
#  ('^th', 'levoph'): 6.90875477931522,
#  ('acidot', 'lw'): 6.90875477931522,
#  ('angri', 'gabapentin'): 6.90875477931522,
#  ('norepinephrin', 'ultram'): 6.90875477931522,
#  ('agon', 'arrest'): 0.0,
#  ('fc', 'lusb'): -6.90875477931522,
#  ('hctz', 'oncologist'): 6.90875477931522,
#  ('cardiovert', 'neosynephrin'): -6.90875477931522,
#  ('contd', 'levoph'): 6.90875477931522,
#  ('declin', 'hypotherm'): -6.90875477931522,
#  ('dni', 'gabapentin'): 6.90875477931522,
#  ('unasyn', 'wish'): 6.90875477931522,
#  ('puff', 'xanax'): 6.90875477931522,
#  ('dnr', 'seroquel'): 4.004134668267055,
#  ...}

# %% [markdown]
# ### Train mode

# %% [markdown]
# #### Method 2. Each patient graph => [model training]

# %%
# Dictionaries to use
 # struct: {word: word2vec[128, numpy.array]}
patient_cooc_odd_scores # struct: {cooc_tuple: log_odds_score}
print()

# %%
patient_cooc_odd_scores
# Out:
# {('fibrinogen', 'mean'): 6.90875477931522,
#  ('gabapentin', 'gastriti'): 6.90875477931522,
#  ('postop', 'scar'): 6.90875477931522,
#  ('lac', 'qam'): 6.90875477931522,
#  ('adenosin', 'tcdb'): 6.90875477931522,
#  ('herp', 'mellitu'): 6.90875477931522,
#  ('anuria', 'cpr'): -6.90875477931522,
#  ('dyslipidemia', 'thiamin'): 6.90875477931522,
#  ('bair', 'sluggish'): 0.6916505477038827,
#  ('dizzi', 'mellitu'): 6.90875477931522,
#  ('captopril', 'lpm'): 6.90875477931522,
#  ('ambul', 'hurt'): 6.90875477931522,
#  ('dic', 'rigor'): 6.90875477931522,
#  ('pleasantli', 'robitussin'): 6.90875477931522,
#  ('mva', 'wether'): 6.90875477931522,
#  ('contractur', 'gadolinium'): 6.90875477931522,
#  ('anur', 'twitch'): -6.90875477931522,
#  ('artifici', 'xl'): -6.90875477931522,
#  ('gadolinium', 'leukocyt'): 6.90875477931522,
#  ('dni', 'pinpoint'): -6.90875477931522,
#  ('dni', 'vasopressin'): -6.90875477931522,
#  ('cash', 'cdb'): 6.90875477931522,
#  ('commod', 'cramp'): 6.90875477931522,
#  ('oligur', 'vasopressin'): 0.44092196573215015,
#  ('bipolar', 'ffp'): 6.90875477931522,
#  ('pulseless', 'syncop'): 6.90875477931522,
#  ('death', 'rigor'): 6.90875477931522,
#  ('flight', 'seroquel'): 6.90875477931522,
#  ('gadolinium', 'paperwork'): 6.90875477931522,
#  ('lax', 'xopenex'): 6.90875477931522,
#  ('itchi', 'vasopressin'): -6.90875477931522,
#  ('db', 'stg'): 6.90875477931522,
#  ('priest', 'rite'): -6.90875477931522,
#  ('ambien', 'sarna'): 6.90875477931522,
#  ('bipolar', 'refractori'): 6.90875477931522,
#  ('hctz', 'puff'): 6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('lusb', 'sweat'): 6.90875477931522,
#  ('duski', 'mottl'): -6.90875477931522,
#  ('hemangioma', 'smooth'): 6.90875477931522,
#  ('dietari', 'mellitu'): 6.90875477931522,
#  ('duski', 'vasopressor'): -6.90875477931522,
#  ('dni', 'institut'): 6.90875477931522,
#  ('cardiovert', 'xl'): 6.90875477931522,
#  ('norepi', 'purpl'): -6.90875477931522,
#  ('cash', 'scopalamin'): -6.90875477931522,
#  ('dni', 'respitori'): 6.90875477931522,
#  ('hypercapn', 'unstabl'): -6.90875477931522,
#  ('articul', 'opiat'): 6.90875477931522,
#  ('diaper', 'scar'): 6.90875477931522,
#  ('bicarbon', 'trazodon'): -6.90875477931522,
#  ('artifici', 'gait'): -6.90875477931522,
#  ('fatti', 'slice'): 6.90875477931522,
#  ('mean', 'nonrebreath'): -6.90875477931522,
#  ('mellitu', 'ppd'): 0.9785433477333831,
#  ('dizzi', 'oob'): 2.95117249214323,
#  ('aliv', 'zyprexa'): 6.90875477931522,
#  ('dnr', 'ipf'): -6.90875477931522,
#  ('gentamycin', 'oob'): -6.90875477931522,
#  ('absorb', 'trazodon'): 6.90875477931522,
#  ('dermat', 'dic'): 6.90875477931522,
#  ('sensat', 'uri'): 6.90875477931522,
#  ('hypotherm', 'vtach'): 6.90875477931522,
#  ('chair', 'unasyn'): -0.5584397574369144,
#  ('chair', 'habitu'): 6.90875477931522,
#  ('cramp', 'rhinorrhea'): -6.90875477931522,
#  ('aaox', 'thirst'): 6.90875477931522,
#  ('omeprazol', 'seroquel'): 6.90875477931522,
#  ('hunger', 'impli'): -6.90875477931522,
#  ('hilum', 'reguard'): 6.90875477931522,
#  ('contd', 'money'): 6.90875477931522,
#  ('exophyt', 'treatement'): 6.90875477931522,
#  ('oob', 'unsteadi'): 6.90875477931522,
#  ('cocain', 'expir'): 6.90875477931522,
#  ('autopsi', 'norepi'): -6.90875477931522,
#  ('levoph', 'rpr'): 6.90875477931522,
#  ('cvvh', 'platelet'): -6.90875477931522,
#  ('laryng', 'modifi'): 6.90875477931522,
#  ('fdp', 'ration'): 6.90875477931522,
#  ('deflat', 'zyprexa'): 6.90875477931522,
#  ('dietari', 'rhinorrhea'): 6.90875477931522,
#  ('acidot', 'imbal'): 6.90875477931522,
#  ('ambul', 'unasyn'): 6.90875477931522,
#  ('core', 'futil'): -6.90875477931522,
#  ('contractur', 'fliud'): -6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('stair', 'thiamin'): 6.90875477931522,
#  ('captopril', 'struggl'): 6.90875477931522,
#  ('chair', 'ultram'): 6.90875477931522,
#  ('ferritin', 'neoplast'): 6.90875477931522,
#  ('fatti', 'pca'): 6.90875477931522,
#  ('oncologist', 'synthet'): 6.90875477931522,
#  ('dnr', 'mrg'): 6.90875477931522,
#  ('bair', 'lpm'): -6.90875477931522,
#  ('dyslipidemia', 'romi'): 6.90875477931522,
#  ('peac', 'prognosi'): -6.90875477931522,
#  ('commod', 'spiromet'): 6.90875477931522,
#  ('aox', 'seroquel'): 6.90875477931522,
#  ('captopril', 'cash'): 6.90875477931522,
#  ('ambien', 'carvedilol'): 6.90875477931522,
#  ('qam', 'thiamin'): 6.90875477931522,
#  ('breakfast', 'tran'): 6.90875477931522,
#  ('cs', 'dni'): 2.0716061679700735,
#  ('levoph', 'petechia'): -6.90875477931522,
#  ('ntnd', 'scar'): 6.90875477931522,
#  ('incent', 'mucinex'): 6.90875477931522,
#  ('bottl', 'expir'): -6.90875477931522,
#  ('levoph', 'trazodon'): 6.90875477931522,
#  ('method', 'predict'): -6.90875477931522,
#  ('declin', 'gabapentin'): 6.90875477931522,
#  ('ambien', 'wish'): 6.90875477931522,
#  ('dni', 'nicotin'): 6.90875477931522,
#  ('platelet', 'sweat'): -6.90875477931522,
#  ('gather', 'retic'): -6.90875477931522,
#  ('dz', 'levoph'): -6.90875477931522,
#  ('dni', 'hypercapn'): 6.90875477931522,
#  ('sensat', 'unstabl'): 6.90875477931522,
#  ('dopamin', 'neo'): 2.473073171472692,
#  ('palli', 'priest'): -6.90875477931522,
#  ('aox', 'bmx'): 6.90875477931522,
#  ('method', 'neoplast'): 6.90875477931522,
#  ('crrt', 'dobutamin'): -6.90875477931522,
#  ('gurgl', 'pleasant'): 6.90875477931522,
#  ('hypothermia', 'prilosec'): 6.90875477931522,
#  ('readmit', 'scab'): 6.90875477931522,
#  ('ambul', 'neo'): -1.095952712632351,
#  ('burn', 'scar'): 6.90875477931522,
#  ('cooler', 'epidur'): 6.90875477931522,
#  ('moan', 'rhinorrhea'): -6.90875477931522,
#  ('dni', 'muddi'): -6.90875477931522,
#  ('arrest', 'impli'): 6.90875477931522,
#  ('angiogram', 'bow'): 6.90875477931522,
#  ('contd', 'deterior'): 6.90875477931522,
#  ('exophyt', 'hilum'): 6.90875477931522,
#  ('hctz', 'sibl'): 6.90875477931522,
#  ('pleasant', 'sweat'): 6.90875477931522,
#  ('dermat', 'dizzi'): 6.90875477931522,
#  ('core', 'romi'): 6.90875477931522,
#  ('cs', 'dyslipidemia'): 6.90875477931522,
#  ('fibrinogen', 'wish'): 6.90875477931522,
#  ('aliv', 'wish'): 6.90875477931522,
#  ('jewelri', 'life'): 6.90875477931522,
#  ('cmo', 'sacrament'): -6.90875477931522,
#  ('hygein', 'readmit'): 6.90875477931522,
#  ('gvhd', 'xii'): 6.90875477931522,
#  ('neo', 'rite'): -6.90875477931522,
#  ('sweat', 'video'): 6.90875477931522,
#  ('cloth', 'scopalamin'): -6.90875477931522,
#  ('pneumococc', 'thiamin'): 6.90875477931522,
#  ('adenocarcinoma', 'pleasant'): 6.90875477931522,
#  ('ctx', 'video'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('ambul', 'splint'): 6.90875477931522,
#  ('anur', 'phenylephrin'): -6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('deterior', 'hugger'): 6.90875477931522,
#  ('oncologist', 'puff'): 6.90875477931522,
#  ('lat', 'lax'): 6.90875477931522,
#  ('hypothermia', 'recruit'): -6.90875477931522,
#  ('gentamycin', 'levoph'): -3.1544023422659846,
#  ('oob', "tf'ing"): 6.90875477931522,
#  ('dnr', 'hypotherm'): -0.22269446071510993,
#  ('seroquel', 'td'): 6.90875477931522,
#  ('crack', 'dni'): 6.90875477931522,
#  ('hypothermia', 'sensat'): 6.90875477931522,
#  ('lat', 'wallet'): 6.90875477931522,
#  ('sensat', 'subq'): 6.90875477931522,
#  ('dnr', 'surviv'): 6.90875477931522,
#  ('acidot', 'dni'): -6.90875477931522,
#  ('dermat', 'diamox'): 6.90875477931522,
#  ('historian', 'hsq'): 6.90875477931522,
#  ('escal', 'mso'): -6.90875477931522,
#  ('aricept', 'ba'): 6.90875477931522,
#  ('cup', 'seat'): 6.90875477931522,
#  ('anaphylaxi', 'paperwork'): 6.90875477931522,
#  ('option', 'unstabl'): -6.90875477931522,
#  ('anur', 'mottl'): -6.90875477931522,
#  ('anuria', 'dead'): -6.90875477931522,
#  ('trazodon', 'uri'): 6.90875477931522,
#  ('asthma', 'director'): 6.90875477931522,
#  ('aricept', 'meatu'): 6.90875477931522,
#  ('mucinex', 'reguard'): 6.90875477931522,
#  ('db', 'epigastr'): 6.90875477931522,
#  ('pericard', 'quadrent'): 6.90875477931522,
#  ('deliv', 'lymphangit'): 6.90875477931522,
#  ('death', 'puff'): 6.90875477931522,
#  ('levoph', 'vtach'): -2.1883847407670785,
#  ('dni', 'fdp'): -6.90875477931522,
#  ('hsq', 'stair'): 6.90875477931522,
#  ('bell', 'icter'): 6.90875477931522,
#  ('incent', 'rememb'): 6.90875477931522,
#  ('bell', 'dni'): 6.90875477931522,
#  ('asthma', 'pod'): 6.90875477931522,
#  ('phlegm', 'qam'): 6.90875477931522,
#  ('mood', 'sweat'): 6.90875477931522,
#  ('arrest', 'neo'): 0.9008114586605904,
#  ('azotemia', 'pneumococc'): 6.90875477931522,
#  ('agon', 'pinpoint'): -6.90875477931522,
#  ('cpr', 'lotion'): -6.90875477931522,
#  ('diaphoresi', 'xii'): 6.90875477931522,
#  ('death', 'sooner'): 6.90875477931522,
#  ('olanzapin', 'zyprexa'): 6.90875477931522,
#  ('aricept', 'pleasant'): 0.4046335072286383,
#  ('hospic', 'levoph'): -6.90875477931522,
#  ('profound', 'zyprexa'): 6.90875477931522,
#  ('aricept', 'puff'): 6.90875477931522,
#  ('hospic', 'osa'): -6.90875477931522,
#  ('dizzi', 'myeloma'): 6.90875477931522,
#  ('align', 'aricept'): -6.90875477931522,
#  ('protrud', 'thiamin'): 6.90875477931522,
#  ('chip', 'silent'): 6.90875477931522,
#  ('dnr', 'romi'): 2.6932429501279174,
#  ('aaox', 'gurgl'): -6.90875477931522,
#  ('derecruit', 'norepinephrin'): -6.90875477931522,
#  ('aricept', 'sundown'): -6.90875477931522,
#  ('dysynchron', 'vasopressin'): -6.90875477931522,
#  ('articul', 'seroquel'): 6.90875477931522,
#  ('autopeep', 'recruit'): -6.90875477931522,
#  ('cardiovert', 'dysynchron'): -6.90875477931522,
#  ('gabapentin', 'laminectomi'): 6.90875477931522,
#  ('palliat', 'prognosi'): -6.90875477931522,
#  ('captopril', 'money'): 6.90875477931522,
#  ('dk', 'oligur'): 6.90875477931522,
#  ('ctx', 'ppd'): 6.90875477931522,
#  ('heroic', 'mottl'): -6.90875477931522,
#  ('ciwa', 'commod'): 6.90875477931522,
#  ('bicarbon', 'mva'): 6.90875477931522,
#  ('aox', 'zyprexa'): -6.90875477931522,
#  ('spiromet', 'syst'): 6.90875477931522,
#  ('angri', 'burn'): 6.90875477931522,
#  ('declin', 'money'): 6.90875477931522,
#  ('fibrinogen', 'surgicel'): -6.90875477931522,
#  ('clinician', 'profound'): -6.90875477931522,
#  ('platelet', 'pleasant'): 6.90875477931522,
#  ('splint', 'xii'): 6.90875477931522,
#  ('aox', 'syncop'): 6.90875477931522,
#  ('colonoscopi', 'pleasant'): 6.90875477931522,
#  ('mottl', 'recruit'): -6.90875477931522,
#  ('dietari', 'mso'): 6.90875477931522,
#  ('lpm', 'strictur'): 6.90875477931522,
#  ('cooler', 'cup'): 6.90875477931522,
#  ('diaphoresi', 'life'): 6.90875477931522,
#  ('captopril', 'epidur'): 6.90875477931522,
#  ('dnr', 'sibl'): 1.604655121332035,
#  ('cmo', 'rememb'): -6.90875477931522,
#  ('mrcp', 'ppd'): -6.90875477931522,
#  ('habitu', 'thiamin'): 6.90875477931522,
#  ('align', 'ligament'): 6.90875477931522,
#  ('prilosec', 'zoloft'): 6.90875477931522,
#  ('aaox', 'bill'): 6.90875477931522,
#  ('clonazepam', 'fibrinogen'): 6.90875477931522,
#  ('itchi', 'sensat'): 6.90875477931522,
#  ('nephrogram', 'scar'): 6.90875477931522,
#  ('argatroban', 'crrt'): -6.90875477931522,
#  ('epigastr', 'gather'): -6.90875477931522,
#  ('nitroglycerin', 'readdress'): 6.90875477931522,
#  ('uncoop', 'vagu'): 6.90875477931522,
#  ('institut', 'myeloma'): -6.90875477931522,
#  ('echocardiogram', 'neoplast'): -6.90875477931522,
#  ('db', 'zoloft'): 6.90875477931522,
#  ('puff', 'young'): 6.90875477931522,
#  ('hypercapnia', 'oob'): 6.90875477931522,
#  ('argatroban', 'ffp'): -6.90875477931522,
#  ('gait', 'omeprazol'): 6.90875477931522,
#  ('adenocarcinoma', 'laryng'): 6.90875477931522,
#  ('diaper', 'wish'): -6.90875477931522,
#  ('dni', 'ntnd'): 1.4174966125472825,
#  ('breakfast', 'uri'): 6.90875477931522,
#  ('historian', 'sweat'): 6.90875477931522,
#  ('cocain', 'ultrafiltr'): 6.90875477931522,
#  ('abruptli', 'cmo'): -6.90875477931522,
#  ('subq', 'sweat'): 6.90875477931522,
#  ('breakfast', 'osa'): 6.90875477931522,
#  ('bicarbon', 'gait'): -6.90875477931522,
#  ('calculi', 'thrive'): 6.90875477931522,
#  ('cmo', 'knowledg'): 6.90875477931522,
#  ('dead', 'unrel'): -6.90875477931522,
#  ('dnr', 'pivot'): 0.2226944607151099,
#  ('xopenex', 'zoloft'): -6.90875477931522,
#  ('diflucan', 'romi'): 6.90875477931522,
#  ('lat', 'pronounc'): 6.90875477931522,
#  ('bipolar', 'pneumococc'): 6.90875477931522,
#  ('fatti', 'stair'): 6.90875477931522,
#  ('anur', 'dic'): -6.90875477931522,
#  ('hypothermia', 'trazodon'): 6.90875477931522,
#  ('venti', 'xanax'): 6.90875477931522,
#  ('dizzi', 'incis'): 6.90875477931522,
#  ('norepinephrin', 'wma'): -6.90875477931522,
#  ('klonopin', 'seroquel'): 6.90875477931522,
#  ('echocardiogram', 'sweat'): 6.90875477931522,
#  ('declin', 'xopenex'): 6.90875477931522,
#  ('clonidin', 'qam'): 6.90875477931522,
#  ('knowledg', 'wish'): 6.90875477931522,
#  ('dni', 'strictur'): 6.90875477931522,
#  ('lotion', 'pca'): 6.90875477931522,
#  ('anuria', 'paralyt'): 6.90875477931522,
#  ('cpr', 'nonreact'): -6.90875477931522,
#  ('aliv', 'prilosec'): 6.90875477931522,
#  ('dz', 'pathologist'): 6.90875477931522,
#  ('ctx', 'moan'): 6.90875477931522,
#  ('cloth', 'probe'): 6.90875477931522,
#  ('conc', 'flake'): 6.90875477931522,
#  ('probe', 'sundown'): 6.90875477931522,
#  ('ba', 'quinolon'): -6.90875477931522,
#  ('pharmacolog', 'splint'): 6.90875477931522,
#  ('anuria', 'slough'): 6.90875477931522,
#  ('crack', 'puff'): 6.90875477931522,
#  ('dz', 'pleasant'): 6.90875477931522,
#  ('abnl', 'nifedipin'): 6.90875477931522,
#  ('chemic', 'habitu'): 6.90875477931522,
#  ('chemic', 'unasyn'): 6.90875477931522,
#  ('bottl', 'gentamycin'): -6.90875477931522,
#  ('qam', 'schizophrenia'): 6.90875477931522,
#  ('rigor', 'uri'): 6.90875477931522,
#  ('bicarbon', 'cvvh'): -6.90875477931522,
#  ('bottl', 'neosynephrin'): -6.90875477931522,
#  ('incent', 'levoph'): 6.90875477931522,
#  ('pea', 'recruit'): 3.649722139527292,
#  ('mucinex', 'transmitr'): 6.90875477931522,
#  ('angiogram', 'flight'): 6.90875477931522,
#  ('ciwa', 'epigastr'): 6.90875477931522,
#  ('broader', 'dnr'): 6.90875477931522,
#  ('cloth', 'moan'): 6.90875477931522,
#  ('motor', 'puff'): 6.90875477931522,
#  ('rehabilit', 'trazodon'): 6.90875477931522,
#  ('refractori', 'thoracocentesi'): 6.90875477931522,
#  ('pitressin', 'purpl'): -6.90875477931522,
#  ('aaox', 'moan'): 6.90875477931522,
#  ('dnr', 'zoloft'): -1.3825560390092835,
#  ('ambien', 'qam'): 6.90875477931522,
#  ('autopeep', 'fibrinogen'): -6.90875477931522,
#  ('burn', 'spacer'): 6.90875477931522,
#  ('fibrinogen', 'vasopressin'): -2.4136656596891792,
#  ('signatur', 'young'): 6.90875477931522,
#  ('deterior', 'leukocyt'): 6.90875477931522,
#  ('gabapentin', 'qtc'): 6.90875477931522,
#  ('cocain', 'epigastr'): 6.90875477931522,
#  ('erythro', 'oob'): 6.90875477931522,
#  ('cash', 'spiromet'): 6.90875477931522,
#  ('diaphoresi', 'signatur'): 6.90875477931522,
#  ('dz', 'silent'): -6.90875477931522,
#  ('arrest', 'azotemia'): -6.90875477931522,
#  ('fatti', 'signatur'): 6.90875477931522,
#  ('chair', 'lcw'): 6.90875477931522,
#  ('levoph', 'vasoconstrict'): -6.90875477931522,
#  ('diamox', 'neosynephrin'): 6.90875477931522,
#  ('neo', 'outer'): 6.90875477931522,
#  ('cmo', 'grim'): -6.90875477931522,
#  ('rememb', 'seroquel'): 6.90875477931522,
#  ('ntnd', 'thiamin'): 6.90875477931522,
#  ('dizzi', 'thiamin'): 6.90875477931522,
#  ('gabapentin', 'shorter'): 6.90875477931522,
#  ('declin', 'scab'): 6.90875477931522,
#  ('platelet', 'postop'): 6.90875477931522,
#  ('chair', 'reguard'): 6.90875477931522,
#  ('core', 'synthet'): 6.90875477931522,
#  ('scar', 'uri'): 6.90875477931522,
#  ('arthrit', 'cdb'): 6.90875477931522,
#  ('anur', 'dnr'): 1.604655121332035,
#  ('ba', 'ctx'): 6.90875477931522,
#  ('unavail', 'venti'): 6.90875477931522,
#  ('ciwa', 'prec'): 6.90875477931522,
#  ('hypothermia', 'rpr'): 6.90875477931522,
#  ('bell', 'dermat'): 6.90875477931522,
#  ('video', 'vp'): 6.90875477931522,
#  ('neosynephrin', 'vasopressin'): -6.90875477931522,
#  ('cash', 'ciwa'): 6.90875477931522,
#  ('dysynchron', 'osa'): -6.90875477931522,
#  ('diflucan', 'iddm'): 6.90875477931522,
#  ('levoph', 'qam'): 6.90875477931522,
#  ('asystol', 'neosynephrin'): -6.90875477931522,
#  ('chair', 'fibrinogen'): -6.90875477931522,
#  ('dopamin', 'unstabl'): -6.90875477931522,
#  ('sensat', 'silent'): 6.90875477931522,
#  ('goc', 'nifedipin'): 6.90875477931522,
#  ('bow', 'scar'): 6.90875477931522,
#  ('platelet', 'rhinorrhea'): -0.2870999276476155,
#  ('silent', 'vallecula'): 6.90875477931522,
#  ('compani', 'dni'): 6.90875477931522,
#  ('deterior', 'heroic'): -6.90875477931522,
#  ('puff', 'video'): 6.90875477931522,
#  ('hctz', 'prilosec'): 6.90875477931522,
#  ('gabapentin', 'mellitu'): 6.90875477931522,
#  ('hunger', 'signatur'): 6.90875477931522,
#  ('dnr', 'epidur'): 6.90875477931522,
#  ('dni', 'ofm'): 6.90875477931522,
#  ('dome', 'slice'): 6.90875477931522,
#  ('seroquel', 'zoloft'): 6.90875477931522,
#  ('adenosin', 'oligur'): 6.90875477931522,
#  ('cpr', 'syncop'): 6.90875477931522,
#  ('norepinephrin', 'vasopressin'): -0.8484241605198924,
#  ('dnr', 'opinion'): -6.90875477931522,
#  ('gather', 'levoph'): -6.90875477931522,
#  ('refractori', 'spfc'): 6.90875477931522,
#  ('abruptli', 'platelet'): -6.90875477931522,
#  ('fibrinogen', 'fungemia'): 6.90875477931522,
#  ('mellitu', 'stair'): 6.90875477931522,
#  ('hhn', 'lpm'): 6.90875477931522,
#  ('barium', 'silent'): 6.90875477931522,
#  ('oob', 'simpli'): 6.90875477931522,
#  ('mso', 'pca'): 6.90875477931522,
#  ('burn', 'lighthead'): 6.90875477931522,
#  ('dni', 'dobutamin'): 6.90875477931522,
#  ('colonoscopi', 'epidur'): 6.90875477931522,
#  ('escal', 'prognosi'): -2.387057016415087,
#  ('dic', 'vasopressor'): -6.90875477931522,
#  ('dni', 'phenylephrin'): -1.4998139424623853,
#  ('anur', 'corneal'): -6.90875477931522,
#  ('ambul', 'osa'): -6.90875477931522,
#  ('ferrou', 'gabapentin'): 6.90875477931522,
#  ('ferrou', 'unavail'): 6.90875477931522,
#  ('cyanot', 'illeu'): -6.90875477931522,
#  ('autopsi', 'mottl'): -6.90875477931522,
#  ('fibrinogen', 'mellitu'): 3.0544069933991973,
#  ('bromid', 'dyslipidemia'): 6.90875477931522,
#  ('pyuria', 'seroquel'): 6.90875477931522,
#  ('db', 'spacer'): 6.90875477931522,
#  ('adam', 'hypotherm'): -6.90875477931522,
#  ('gabapentin', 'incis'): 6.90875477931522,
#  ('nahco', 'wish'): -6.90875477931522,
#  ('dni', 'ipf'): -0.4046335072286383,
#  ('historian', 'hurt'): -6.90875477931522,
#  ('arrest', 'led'): 6.90875477931522,
#  ('gabapentin', 'nocturn'): 6.90875477931522,
#  ('anur', 'chemic'): 6.90875477931522,
#  ('dyslipidemia', 'soln'): 6.90875477931522,
#  ('commod', 'compani'): 6.90875477931522,
#  ('intiat', 'pronounc'): -6.90875477931522,
#  ('levoph', 'recruit'): -6.90875477931522,
#  ('gotten', 'msicu'): 6.90875477931522,
#  ('banana', 'oob'): 6.90875477931522,
#  ('led', 'schizophrenia'): 6.90875477931522,
#  ('dni', 'intiat'): -6.90875477931522,
#  ('ppd', 'soln'): 6.90875477931522,
#  ('arrest', 'sweat'): 6.90875477931522,
#  ('dnr', 'ppn'): 6.90875477931522,
#  ('cremat', 'funer'): -6.90875477931522,
#  ('friction', 'unobtain'): 6.90875477931522,
#  ('chb', 'moan'): -6.90875477931522,
#  ('epigastr', 'xanax'): 6.90875477931522,
#  ('dnr', 'fc'): -6.90875477931522,
#  ('brb', 'ppd'): 6.90875477931522,
#  ('cocain', 'pneumococc'): 6.90875477931522,
#  ('icter', 'mellitu'): -0.4046335072286383,
#  ('currenlti', 'dni'): 6.90875477931522,
#  ('dermat', 'platelet'): 6.90875477931522,
#  ('adenocarcinoma', 'synthet'): 6.90875477931522,
#  ('oob', 'video'): 6.90875477931522,
#  ('captopril', 'omeprazol'): 0.0,
#  ('bipolar', 'forc'): -3.521008960463551,
#  ('fatti', 'natg'): -6.90875477931522,
#  ('ferrou', 'xii'): 6.90875477931522,
#  ('platelet', 'rpr'): 6.90875477931522,
#  ('adam', 'futil'): -6.90875477931522,
#  ('neo', 'pca'): 6.90875477931522,
#  ('ambul', 'trazodon'): 6.90875477931522,
#  ('aox', 'wish'): 6.90875477931522,
#  ('levoph', 'sluggish'): -1.3182829507563796,
#  ('incent', 'mrcp'): -6.90875477931522,
#  ('chol', 'nahco'): -6.90875477931522,
#  ('aox', 'diamox'): 6.90875477931522,
#  ('chemic', 'exophyt'): -6.90875477931522,
#  ('gabapentin', 'thiamin'): 6.90875477931522,
#  ('levoph', 'xii'): 6.90875477931522,
#  ('homogen', 'scar'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('ppd', 'weekli'): 6.90875477931522,
#  ('oncologist', 'wish'): 0.6916505477038827,
#  ('bill', 'lotion'): 6.90875477931522,
#  ('dnr', 'ffp'): -1.9029698713994427,
#  ('incent', 'ntnd'): -6.90875477931522,
#  ('aox', 'dnr'): 2.387057016415087,
#  ('aricept', 'levoph'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('levoph', 'pitressin'): 1.3825560390092835,
#  ('hypotherm', 'xl'): 6.90875477931522,
#  ('escal', 'tobra'): -6.90875477931522,
#  ('nicotin', 'uri'): 6.90875477931522,
#  ('cocain', 'thrive'): 6.90875477931522,
#  ('bromid', 'laminectomi'): 6.90875477931522,
#  ('hive', 'wallet'): 6.90875477931522,
#  ('cpr', 'neo'): 1.095952712632351,
#  ('neosynephrin', 'pea'): -6.90875477931522,
#  ('cooki', 'neutral'): 6.90875477931522,
#  ('ppd', 'suprapub'): 6.90875477931522,
#  ('nice', 'suffer'): 6.90875477931522,
#  ('neo', 'sorb'): -6.90875477931522,
#  ('hypotherm', 'readdress'): -6.90875477931522,
#  ('grave', 'purpl'): -6.90875477931522,
#  ('anur', 'transmitr'): 6.90875477931522,
#  ('lymphangit', 'osa'): 6.90875477931522,
#  ('pyuria', 'rigor'): 6.90875477931522,
#  ('dni', 'norepinephrin'): -1.604655121332035,
#  ('carvedilol', 'fibrinogen'): 6.90875477931522,
#  ('cocain', 'ctx'): 6.90875477931522,
#  ('asthma', 'wallet'): 6.90875477931522,
#  ('caspofungin', 'levoph'): 6.90875477931522,
#  ('cramp', 'dnr'): 6.90875477931522,
#  ('endur', 'xanax'): 6.90875477931522,
#  ('death', 'lusb'): 6.90875477931522,
#  ('anuria', 'readmit'): 6.90875477931522,
#  ('motor', 'sibl'): 6.90875477931522,
#  ('coach', 'spiromet'): 6.90875477931522,
#  ('ambul', 'platelet'): -6.90875477931522,
#  ('plate', 'scar'): 6.90875477931522,
#  ('defibril', 'unstabl'): -6.90875477931522,
#  ('asystol', 'peac'): -6.90875477931522,
#  ('^th', 'banana'): 6.90875477931522,
#  ('aricept', 'norepinephrin'): 6.90875477931522,
#  ('nectar', 'pivot'): 6.90875477931522,
#  ('ambien', 'hunger'): 6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('rememb', 'uri'): 6.90875477931522,
#  ('gabapentin', 'opiat'): 6.90875477931522,
#  ('diaphoresi', 'ruptur'): 6.90875477931522,
#  ('agon', 'clergi'): -6.90875477931522,
#  ('aox', 'hugger'): 6.90875477931522,
#  ('dizzi', 'ipf'): 6.90875477931522,
#  ('elimin', 'pharyng'): 6.90875477931522,
#  ('ipf', 'lpm'): 6.90875477931522,
#  ('barium', 'smooth'): 6.90875477931522,
#  ('intent', 'thiamin'): 6.90875477931522,
#  ('morbid', 'underpenetr'): 6.90875477931522,
#  ('barium', 'xii'): 6.90875477931522,
#  ('magnevist', 'vertebra'): 6.90875477931522,
#  ('famil', 'struggl'): -6.90875477931522,
#  ('angioplasti', 'deploy'): 6.90875477931522,
#  ('pleasant', 'tubular'): 6.90875477931522,
#  ('hypothermia', 'refractori'): -6.90875477931522,
#  ('cpr', 'recalibr'): -6.90875477931522,
#  ('asthma', 'thiamin'): 6.90875477931522,
#  ('tdi', 'unavail'): 6.90875477931522,
#  ('dnr', 'xopenex'): -3.1942475376942854,
#  ('forc', 'oob'): -6.90875477931522,
#  ('diaper', 'video'): 6.90875477931522,
#  ('ambul', 'rusti'): -6.90875477931522,
#  ('anur', 'conc'): 6.90875477931522,
#  ('dnr', 'vp'): 6.90875477931522,
#  ('dz', 'underneath'): 6.90875477931522,
#  ('kerlix', 'nectar'): 6.90875477931522,
#  ('modifi', 'wfl'): 6.90875477931522,
#  ('levoph', 'phlegm'): -6.90875477931522,
#  ('ferritin', 'readmit'): 6.90875477931522,
#  ('cyanot', 'knowledg'): 6.90875477931522,
#  ('mellitu', 'omeprazol'): 1.5360079185039965,
#  ('gabapentin', 'sibl'): 6.90875477931522,
#  ('colonoscopi', 'dnr'): 6.90875477931522,
#  ('pca', 'wish'): 6.90875477931522,
#  ('barium', 'spur'): 6.90875477931522,
#  ('ethic', 'sorb'): -6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('spacer', 'unstabl'): 6.90875477931522,
#  ('lw', 'unstabl'): 6.90875477931522,
#  ('bottl', 'levoph'): -1.5295247690781295,
#  ('dic', 'dni'): 0.6916505477038827,
#  ('jejunum', 'scar'): 6.90875477931522,
#  ('phlegm', 'splint'): 6.90875477931522,
#  ('im', 'lusb'): 6.90875477931522,
#  ('dni', 'mycolyt'): -6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('bottl', 'deterior'): 6.90875477931522,
#  ('cmo', 'gentamycin'): -6.90875477931522,
#  ('flight', 'nephrolog'): 6.90875477931522,
#  ('arrest', 'pastor'): -6.90875477931522,
#  ('expir', 'wish'): -6.90875477931522,
#  ('diaphoresi', 'money'): 6.90875477931522,
#  ('deterior', 'unequ'): 6.90875477931522,
#  ('clergi', 'levoph'): -6.90875477931522,
#  ('qam', 'strictur'): 6.90875477931522,
#  ('neo', 'recruit'): 6.90875477931522,
#  ('dietari', 'distanc'): 6.90875477931522,
#  ('cpr', 'mottl'): -6.90875477931522,
#  ('arrang', 'dnr'): -6.90875477931522,
#  ('death', 'paco'): -6.90875477931522,
#  ('nitroglycerin', 'sweat'): -6.90875477931522,
#  ('ferrou', 'thrive'): 6.90875477931522,
#  ('hive', 'metoclopramid'): 6.90875477931522,
#  ('dni', 'thirst'): 6.90875477931522,
#  ('lpm', 'oob'): 6.90875477931522,
#  ('echocardiogram', 'ppd'): 6.90875477931522,
#  ('adenocarcinoma', 'osa'): 6.90875477931522,
#  ('lat', 'syncop'): 6.90875477931522,
#  ('criticar', 'pinpoint'): -6.90875477931522,
#  ('fibrinogen', 'opiat'): 0.044363007362570685,
#  ('fibrinogen', 'religi'): -6.90875477931522,
#  ('ferritin', 'trazodon'): 6.90875477931522,
#  ('mail', 'pleasant'): 6.90875477931522,
#  ('pleasant', 'silent'): 6.90875477931522,
#  ('deterior', 'mellitu'): 6.90875477931522,
#  ('core', 'declin'): -6.90875477931522,
#  ('autopeep', 'paralyt'): -6.90875477931522,
#  ('ppd', 'puff'): 6.90875477931522,
#  ('chair', 'dni'): 0.4119976373686585,
#  ('qam', 'sensat'): 1.3825560390092835,
#  ('historian', 'ppd'): 6.90875477931522,
#  ('xl', 'zyprexa'): 6.90875477931522,
#  ('dni', 'sibl'): 1.604655121332035,
#  ('pod', 'xanax'): 6.90875477931522,
#  ('postop', 'tubular'): 6.90875477931522,
#  ('ppd', 'rpr'): 6.90875477931522,
#  ('dni', 'morgu'): -6.90875477931522,
#  ('hsq', 'ppd'): 0.0,
#  ('pneumococc', 'qam'): 6.90875477931522,
#  ('homogen', 'pronounc'): 6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('intent', 'nifedipin'): 6.90875477931522,
#  ('crrt', 'lotion'): 6.90875477931522,
#  ('coach', 'oob'): 6.90875477931522,
#  ('ciwa', 'dopamin'): 6.90875477931522,
#  ('romi', 'thirst'): 6.90875477931522,
#  ('cs', 'hugger'): -6.90875477931522,
#  ('arrest', 'declin'): 6.90875477931522,
#  ('gastrojejunostomi', 'metoclopramid'): 6.90875477931522,
#  ('burn', 'thirst'): 6.90875477931522,
#  ('antb', 'captopril'): 6.90875477931522,
#  ('ambul', 'west'): 6.90875477931522,
#  ('dni', 'levoph'): -0.2870999276476155,
#  ('neo', 'scab'): 6.90875477931522,
#  ('platelet', 'rm'): 6.90875477931522,
#  ('ambien', 'crack'): 6.90875477931522,
#  ('brb', 'crrt'): -6.90875477931522,
#  ('levoph', 'meropenam'): -6.90875477931522,
#  ('expir', 'vasopressin'): -6.90875477931522,
#  ('cocain', 'sweat'): 6.90875477931522,
#  ('neo', 'video'): 6.90875477931522,
#  ('oob', 'ppd'): 6.90875477931522,
#  ('griev', 'levoph'): -6.90875477931522,
#  ('contractur', 'criticar'): 6.90875477931522,
#  ('ipf', 'robitussin'): -6.90875477931522,
#  ('life', 'prognosi'): -6.90875477931522,
#  ('ffp', 'opinion'): 6.90875477931522,
#  ('proph', 'thoracocentesi'): 6.90875477931522,
#  ('rigor', 'young'): 6.90875477931522,
#  ('fdp', 'neutral'): 6.90875477931522,
#  ('nahco', 'purpl'): -6.90875477931522,
#  ('declin', 'signatur'): 6.90875477931522,
#  ('commod', 'nectar'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('aaox', 'readmit'): 6.90875477931522,
#  ('crrt', 'surgicel'): -6.90875477931522,
#  ('aox', 'puff'): 6.90875477931522,
#  ('cellcept', 'lat'): 6.90875477931522,
#  ('azotemia', 'petechia'): -6.90875477931522,
#  ('dni', 'rm'): 6.90875477931522,
#  ('omeprazol', 'quinolon'): 6.90875477931522,
#  ('colonoscopi', 'dopamin'): 6.90875477931522,
#  ('captopril', 'yel'): 6.90875477931522,
#  ('clonazepam', 'recruit'): 6.90875477931522,
#  ('adenocarcinoma', 'pod'): 6.90875477931522,
#  ('cash', 'dopamin'): -6.90875477931522,
#  ('autopsi', 'prognosi'): -6.90875477931522,
#  ('clinician', 'im'): 6.90875477931522,
#  ('hypothermia', 'sweat'): 6.90875477931522,
#  ('bottl', 'carvedilol'): 6.90875477931522,
#  ('declin', 'ozz'): -6.90875477931522,
#  ('occipit', 'zyprexa'): 6.90875477931522,
#  ('angioplasti', 'tran'): 6.90875477931522,
#  ('ppd', 'subq'): 6.90875477931522,
#  ('arrest', 'scar'): 6.90875477931522,
#  ('cyanot', 'iddm'): 6.90875477931522,
#  ('pneumothorac', 'scar'): 6.90875477931522,
#  ('liw', 'prognosi'): -6.90875477931522,
#  ('chair', 'ctx'): 6.90875477931522,
#  ('strictur', 'vagu'): 6.90875477931522,
#  ('ctx', 'stair'): 6.90875477931522,
#  ('pca', 'pharmacolog'): 6.90875477931522,
#  ('romi', 'venti'): 6.90875477931522,
#  ('levoph', 'pcv'): 1.4998139424623853,
#  ('suprapub', 'wish'): 6.90875477931522,
#  ('ambien', 'puff'): 6.90875477931522,
#  ('omeprazol', 'zyprexa'): 6.90875477931522,
#  ('hugger', 'moan'): -6.90875477931522,
#  ('dni', 'jerk'): -6.90875477931522,
#  ('bicarbon', 'levoph'): -6.90875477931522,
#  ('gentamycin', 'multisystem'): -6.90875477931522,
#  ('cpr', 'dobutamin'): -6.90875477931522,
#  ('dizzi', 'sibl'): -6.90875477931522,
#  ('bottl', 'motor'): 6.90875477931522,
#  ('mtg', 'ruptur'): 6.90875477931522,
#  ('pleasant', 'redirect'): 0.2226944607151099,
#  ('dni', 'spacer'): 6.90875477931522,
#  ('profound', 'ud'): 6.90875477931522,
#  ('permiss', 'sluggishli'): -6.90875477931522,
#  ('diaphoresi', 'ppd'): 6.90875477931522,
#  ('core', 'dorsal'): -6.90875477931522,
#  ('cpr', 'struggl'): 6.90875477931522,
#  ('crowd', 'habitu'): 6.90875477931522,
#  ('hugger', 'pinpoint'): -6.90875477931522,
#  ('cocain', 'gabapentin'): 6.90875477931522,
#  ('incis', 'purpl'): 6.90875477931522,
#  ('levoph', 'mean'): 6.90875477931522,
#  ('diaphoresi', 'hsq'): 6.90875477931522,
#  ('cramp', 'platelet'): -6.90875477931522,
#  ('buck', 'triadyn'): 6.90875477931522,
#  ('levoph', 'montitor'): -6.90875477931522,
#  ('death', 'sweat'): 6.90875477931522,
#  ('bromid', 'subdur'): 6.90875477931522,
#  ('dnr', 'rpr'): 6.90875477931522,
#  ('incent', 'phlegm'): 6.90875477931522,
#  ('gait', 'gown'): 6.90875477931522,
#  ('dni', 'historian'): 6.90875477931522,
#  ('acidot', 'fdp'): -6.90875477931522,
#  ('bottl', 'chemic'): 6.90875477931522,
#  ('fatti', 'sweat'): 6.90875477931522,
#  ('cmo', 'sibl'): -6.90875477931522,
#  ('icter', 'weekli'): 6.90875477931522,
#  ('incent', 'spacer'): 6.90875477931522,
#  ('ba', 'precordium'): 6.90875477931522,
#  ('cocain', 'klonopin'): 6.90875477931522,
#  ('dopamin', 'qam'): 6.90875477931522,
#  ('cs', 'lpm'): -6.90875477931522,
#  ('gait', 'thiamin'): 6.90875477931522,
#  ('cpr', 'twitch'): -6.90875477931522,
#  ('cyanot', 'fungemia'): -6.90875477931522,
#  ('captopril', 'chol'): 6.90875477931522,
#  ('compani', 'unstabl'): 6.90875477931522,
#  ('dnr', 'vagu'): 6.90875477931522,
#  ('aricept', 'gown'): -6.90875477931522,
#  ('cardiovert', 'levoph'): -4.245250472054411,
#  ('intent', 'precordium'): 6.90875477931522,
#  ('asthma', 'death'): 6.90875477931522,
#  ('cpr', 'nitroglycerin'): -6.90875477931522,
#  ('behavior', 'cocain'): 6.90875477931522,
#  ('hospic', 'mso'): -6.90875477931522,
#  ('chip', 'readmit'): 6.90875477931522,
#  ('bicarbon', 'weekli'): 6.90875477931522,
#  ('habitu', 'underpenetr'): 6.90875477931522,
#  ('cpr', 'prognosi'): -6.90875477931522,
#  ('dni', 'epidur'): 6.90875477931522,
#  ('prognosi', 'viabl'): -6.90875477931522,
#  ('bicarbon', 'thiamin'): 6.90875477931522,
#  ('bottl', 'cisatracurium'): -6.90875477931522,
#  ('tubular', 'vp'): 6.90875477931522,
#  ('clergi', 'suffer'): -6.90875477931522,
#  ('dopamin', 'grave'): -6.90875477931522,
#  ('aox', 'esld'): 6.90875477931522,
#  ('commod', 'sooner'): 6.90875477931522,
#  ('aox', 'money'): 6.90875477931522,
#  ('argatroban', 'norepinephrin'): -6.90875477931522,
#  ('arrest', 'dic'): -6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('normotherm', 'oob'): 6.90875477931522,
#  ('bipolar', 'sundown'): 6.90875477931522,
#  ('autopeep', 'levoph'): -6.90875477931522,
#  ('signatur', 'sweat'): 6.90875477931522,
#  ('dizzi', 'herp'): 6.90875477931522,
#  ('dome', 'homogen'): 6.90875477931522,
#  ('core', 'hsq'): -6.90875477931522,
#  ('dobutamin', 'hugger'): 6.90875477931522,
#  ('osa', 'platelet'): -6.90875477931522,
#  ('norepinephrin', 'phenylephrin'): -6.90875477931522,
#  ('chip', 'moisten'): -6.90875477931522,
#  ('pcv', 'vasopressin'): -6.90875477931522,
#  ('db', 'sweat'): 6.90875477931522,
#  ('cup', 'readmit'): 6.90875477931522,
#  ('pharyng', 'wfl'): 6.90875477931522,
#  ('lift', 'readmit'): 6.90875477931522,
#  ('ambul', 'omeprazol'): 6.90875477931522,
#  ('nocturn', 'romi'): 6.90875477931522,
#  ('gabapentin', 'hive'): 6.90875477931522,
#  ('bell', 'chair'): 2.473073171472692,
#  ('ppd', 'romi'): 6.90875477931522,
#  ('maroon', 'reguard'): 6.90875477931522,
#  ('absorb', 'paralyt'): 6.90875477931522,
#  ('grave', 'prognosi'): -2.8164316892990344,
#  ('angioplasti', 'iddm'): 6.90875477931522,
#  ('hypothermia', 'resucit'): -6.90875477931522,
#  ('dnr', 'pyuria'): 0.509761227710204,
#  ('crrt', 'synthet'): 6.90875477931522,
#  ('outer', 'vertebra'): 6.90875477931522,
#  ('fibrinogen', 'norepinephrin'): -1.982039101659681,
#  ('herp', 'ipf'): 6.90875477931522,
#  ('anuria', 'cvvhd'): -6.90875477931522,
#  ('clergi', 'paralyt'): -6.90875477931522,
#  ('goc', 'ind'): -6.90875477931522,
#  ('plate', 'requr'): 6.90875477931522,
#  ('dni', 'plerual'): -6.90875477931522,
#  ('ambien', 'freeli'): 6.90875477931522,
#  ('conc', 'rigor'): 6.90875477931522,
#  ('dnr', 'robitussin'): -1.095952712632351,
#  ('ambul', 'stair'): 6.90875477931522,
#  ('chair', 'stood'): 6.90875477931522,
#  ('deterior', 'friction'): 6.90875477931522,
#  ('diuril', 'gabapentin'): 6.90875477931522,
#  ('anaphylaxi', 'dni'): 6.90875477931522,
#  ('asthma', 'lusb'): 6.90875477931522,
#  ('cramp', 'hsq'): -6.90875477931522,
#  ('diaphoresi', 'uncoop'): 6.90875477931522,
#  ('arrest', 'recruit'): 3.649722139527292,
#  ('bicarbon', 'crrt'): -6.90875477931522,
#  ('acc', 'angri'): 6.90875477931522,
#  ('coach', 'unavail'): 6.90875477931522,
#  ('dnr', 'vasopressin'): -6.90875477931522,
#  ('ppd', 'tran'): 6.90875477931522,
#  ("sxn'ing", 'thk'): 6.90875477931522,
#  ('cyanot', 'laminectomi'): 6.90875477931522,
#  ('cs', 'oob'): 6.90875477931522,
#  ('imbal', 'pca'): 6.90875477931522,
#  ('soln', 'subdur'): 6.90875477931522,
#  ('cellcept', 'dyslipidemia'): 6.90875477931522,
#  ('pyuria', 'sibl'): 6.90875477931522,
#  ('mso', 'prognosi'): -6.90875477931522,
#  ('hospic', 'wish'): 0.4046335072286383,
#  ('silent', 'videofluoroscopi'): 6.90875477931522,
#  ('contd', 'signatur'): 6.90875477931522,
#  ('itchi', 'quinolon'): 6.90875477931522,
#  ('dni', 'pleuravac'): -6.90875477931522,
#  ('hunger', 'wish'): 6.90875477931522,
#  ('azotemia', 'declin'): 6.90875477931522,
#  ('cracker', 'mellitu'): 6.90875477931522,
#  ('news', 'pronounc'): -6.90875477931522,
#  ('aox', 'palli'): 6.90875477931522,
#  ('gait', 'mellitu'): 6.90875477931522,
#  ('dyslipidemia', 'flight'): 6.90875477931522,
#  ('esld', 'oob'): 6.90875477931522,
#  ('ctx', 'syncop'): 6.90875477931522,
#  ('icter', 'prilosec'): 6.90875477931522,
#  ('cvvh', 'vasopressin'): -6.90875477931522,
#  ('mva', 'spiromet'): 6.90875477931522,
#  ('cash', 'ppd'): 6.90875477931522,
#  ('ggt', 'vasopressor'): -6.90875477931522,
#  ('sensat', 'thirst'): 6.90875477931522,
#  ('chair', 'illeu'): -6.90875477931522,
#  ('gabapentin', 'xl'): 6.90875477931522,
#  ('articul', 'robitussin'): 6.90875477931522,
#  ('anur', 'cardiovert'): 6.90875477931522,
#  ('death', 'declar'): -6.90875477931522,
#  ('chair', 'ppd'): 0.0,
#  ('dnr', 'meropenam'): -6.90875477931522,
#  ('nitroglycerin', 'rhinorrhea'): -6.90875477931522,
#  ('declar', 'nimv'): -6.90875477931522,
#  ('colonoscopi', 'signatur'): 6.90875477931522,
#  ('breakfast', 'recalibr'): 6.90875477931522,
#  ('cmo', 'hunger'): 0.0,
#  ('corneal', 'twitch'): -6.90875477931522,
#  ('purpl', 'seroquel'): 6.90875477931522,
#  ('intiat', 'splint'): 6.90875477931522,
#  ('dni', 'pivot'): 0.2226944607151099,
#  ('hugger', 'incis'): -6.90875477931522,
#  ('olanzapin', 'palli'): 6.90875477931522,
#  ('purpl', 'wish'): -6.90875477931522,
#  ('pleasant', 'unstabl'): 6.90875477931522,
#  ('chemic', 'gabapentin'): 6.90875477931522,
#  ('osa', 'paco'): 6.90875477931522,
#  ('clonidin', 'refractori'): 6.90875477931522,
#  ('fibrinogen', 'hemothorax'): -6.90875477931522,
#  ('levoph', 'paco'): 6.90875477931522,
#  ('ctx', 'signatur'): 6.90875477931522,
#  ('asthma', 'cash'): 6.90875477931522,
#  ('nocturn', 'thiamin'): 6.90875477931522,
#  ('cmo', 'incis'): -6.90875477931522,
#  ('bill', 'readmit'): 6.90875477931522,
#  ('mva', 'spacer'): 6.90875477931522,
#  ('money', 'ultram'): 6.90875477931522,
#  ('absorb', 'seroquel'): 6.90875477931522,
#  ('cocain', 'omeprazol'): 6.90875477931522,
#  ('anaphylaxi', 'deterior'): 6.90875477931522,
#  ('anur', 'crrt'): 6.90875477931522,
#  ('life', 'qam'): 6.90875477931522,
#  ('permiss', 'vasopressin'): -6.90875477931522,
#  ('dni', 'ind'): -6.90875477931522,
#  ('death', 'peac'): -6.90875477931522,
#  ('knew', 'spiromet'): 6.90875477931522,
#  ('cardiovert', 'contini'): 6.90875477931522,
#  ('palli', 'wish'): -0.809128888289493,
#  ('gastrojejunostomi', 'strictur'): 6.90875477931522,
#  ('levoph', 'occipit'): 6.90875477931522,
#  ('levoph', 'moan'): -6.90875477931522,
#  ('lotion', 'puff'): 6.90875477931522,
#  ('omeprazol', 'postop'): 6.90875477931522,
#  ('ruptur', 'spiromet'): 6.90875477931522,
#  ('phlegm', 'signatur'): 6.90875477931522,
#  ('bair', 'vtach'): 6.90875477931522,
#  ('hemothorax', 'hive'): -6.90875477931522,
#  ('anaphylaxi', 'articul'): 6.90875477931522,
#  ('paperwork', 'xanax'): 6.90875477931522,
#  ('bottl', 'zoloft'): 6.90875477931522,
#  ('cash', 'osa'): 6.90875477931522,
#  ('pharyng', 'vallecula'): 6.90875477931522,
#  ('ambul', 'bair'): -6.90875477931522,
#  ('arrest', 'venti'): 6.90875477931522,
#  ('ppd', 'wallet'): 6.90875477931522,
#  ('appi', 'venti'): 6.90875477931522,
#  ('recalibr', 'video'): 6.90875477931522,
#  ('gabapentin', 'ultram'): 6.90875477931522,
#  ('clonidin', 'mellitu'): 6.90875477931522,
#  ('fliud', 'moan'): -6.90875477931522,
#  ('dnr', 'led'): -0.6916505477038827,
#  ('brb', 'tran'): 6.90875477931522,
#  ('hilum', 'tranfer'): 6.90875477931522,
#  ('pharmacolog', 'wish'): 6.90875477931522,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('adenosin', 'td'): 6.90875477931522,
#  ('asthma', 'ffp'): 6.90875477931522,
#  ('ambul', 'asthma'): 6.90875477931522,
#  ('aricept', 'distanc'): 6.90875477931522,
#  ('brb', 'clonazepam'): 6.90875477931522,
#  ('homogen', 'peribronchovascular'): 6.90875477931522,
#  ('breakfast', 'fax'): 6.90875477931522,
#  ('nifedipin', 'venti'): 6.90875477931522,
#  ('bromid', 'readmit'): 6.90875477931522,
#  ('lat', 'splint'): 6.90875477931522,
#  ('precordium', 'puff'): 6.90875477931522,
#  ('fu', 'incent'): 6.90875477931522,
#  ('neo', 'pleasant'): 6.90875477931522,
#  ('acidot', 'levoph'): -6.90875477931522,
#  ('dnr', 'grim'): -6.90875477931522,
#  ('incent', 'itchi'): 6.90875477931522,
#  ('robitussin', 'zyprexa'): 6.90875477931522,
#  ('cramp', 'ppd'): -6.90875477931522,
#  ('aliv', 'syncop'): 6.90875477931522,
#  ('ambien', 'neo'): -6.90875477931522,
#  ('hctz', 'splint'): 6.90875477931522,
#  ('fax', 'pleasant'): 6.90875477931522,
#  ('conc', 'prognosi'): -6.90875477931522,
#  ('epidur', 'neoplast'): 6.90875477931522,
#  ('arrest', 'hypercapnia'): -6.90875477931522,
#  ('ambien', 'commod'): 6.90875477931522,
#  ('captopril', 'pose'): 6.90875477931522,
#  ('occupi', 'seriou'): 6.90875477931522,
#  ('hilum', 'prilosec'): 6.90875477931522,
#  ('jewelri', 'xl'): 6.90875477931522,
#  ('nahco', 'prognosi'): -6.90875477931522,
#  ('dizzi', 'qam'): 6.90875477931522,
#  ('nectar', 'pleasantli'): 6.90875477931522,
#  ('cvvh', 'esld'): -6.90875477931522,
#  ('aaox', 'ipf'): 6.90875477931522,
#  ('aaox', 'redirect'): 6.90875477931522,
#  ('dni', 'unequ'): 6.90875477931522,
#  ('gait', 'paperwork'): 6.90875477931522,
#  ('flight', 'pleasantli'): 6.90875477931522,
#  ('purpl', 'ultram'): 6.90875477931522,
#  ('gastriti', 'pleasant'): 6.90875477931522,
#  ('mean', 'seat'): 6.90875477931522,
#  ('anuria', 'chair'): 6.90875477931522,
#  ('mtg', 'sibl'): 6.90875477931522,
#  ('dnr', 'thirst'): 6.90875477931522,
#  ('im', 'trazodon'): 6.90875477931522,
#  ('discard', 'levof'): -6.90875477931522,
#  ('oob', 'spiromet'): 6.90875477931522,
#  ('ciwa', 'cloth'): 6.90875477931522,
#  ('captopril', 'pod'): 6.90875477931522,
#  ('mva', 'panic'): 6.90875477931522,
#  ('para', 'vertebra'): -6.90875477931522,
#  ('gurgl', 'zyprexa'): 6.90875477931522,
#  ('adenocarcinoma', 'spfc'): 6.90875477931522,
#  ('foci', 'ligament'): 6.90875477931522,
#  ('cyanot', 'lw'): -6.90875477931522,
#  ('mrg', 'seroquel'): 6.90875477931522,
#  ('clinician', 'recruit'): 6.90875477931522,
#  ('acc', 'young'): 6.90875477931522,
#  ('cmo', 'icter'): -6.90875477931522,
#  ('asthma', 'soln'): 6.90875477931522,
#  ('incent', 'pinpoint'): 6.90875477931522,
#  ('cup', 'neutral'): 6.90875477931522,
#  ('death', 'dietari'): 6.90875477931522,
#  ('ppd', 'spacer'): 6.90875477931522,
#  ('eob', 'levoph'): 6.90875477931522,
#  ('bottl', 'crack'): 6.90875477931522,
#  ('neo', 'palli'): -6.90875477931522,
#  ('life', 'scopalamin'): -6.90875477931522,
#  ('metoclopramid', 'nitroglycerin'): 6.90875477931522,
#  ('dead', 'rehabilit'): 6.90875477931522,
#  ('hypotherm', 'normotherm'): -6.90875477931522,
#  ('neo', 'rabbi'): -6.90875477931522,
#  ('align', 'seroquel'): -6.90875477931522,
#  ('hilum', 'treitz'): 6.90875477931522,
#  ('hypothermia', 'pcv'): -6.90875477931522,
#  ('consciou', 'incis'): 6.90875477931522,
#  ('bipolar', 'proph'): 6.90875477931522,
#  ('commod', 'oob'): 3.217378503389662,
#  ('deploy', 'postpylor'): 6.90875477931522,
#  ('cash', 'oob'): 6.90875477931522,
#  ('mrg', 'zoloft'): 6.90875477931522,
#  ('clergi', 'mtg'): -6.90875477931522,
#  ('aox', 'ruptur'): 6.90875477931522,
#  ('cracker', 'ferrou'): 6.90875477931522,
#  ('cash', 'hive'): 6.90875477931522,
#  ('dni', 'hypothermia'): 0.5584397574369147,
#  ('carvedilol', 'prilosec'): 6.90875477931522,
#  ('coach', 'puff'): 6.90875477931522,
#  ('cg', 'dnr'): -6.90875477931522,
#  ('hive', 'jewelri'): 6.90875477931522,
#  ('postop', 'readmit'): 6.90875477931522,
#  ('romi', 'weekli'): 6.90875477931522,
#  ('ctx', 'ultram'): 6.90875477931522,
#  ('^th', 'levoph'): 6.90875477931522,
#  ('acidot', 'lw'): 6.90875477931522,
#  ('angri', 'gabapentin'): 6.90875477931522,
#  ('norepinephrin', 'ultram'): 6.90875477931522,
#  ('agon', 'arrest'): 0.0,
#  ('fc', 'lusb'): -6.90875477931522,
#  ('hctz', 'oncologist'): 6.90875477931522,
#  ('cardiovert', 'neosynephrin'): -6.90875477931522,
#  ('contd', 'levoph'): 6.90875477931522,
#  ('declin', 'hypotherm'): -6.90875477931522,
#  ('dni', 'gabapentin'): 6.90875477931522,
#  ('unasyn', 'wish'): 6.90875477931522,
#  ('puff', 'xanax'): 6.90875477931522,
#  ('dnr', 'seroquel'): 4.004134668267055,
#  ...}

# %%
# Data normalization
import numpy
def data_norm(cooc_odd_scores):

    def norm_arr(array):
        arr = numpy.array(list(array))
        start = 0
        end = 1
        width = end - start
        res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
        return res.tolist()

    cooc_keys, cooc_values = zip(*cooc_odd_scores.items())
    new_cooc_odd_scores = dict(zip(cooc_keys, norm_arr(cooc_values)))

    return new_cooc_odd_scores

new_patient_cooc_odd_scores = data_norm(patient_cooc_odd_scores)

# %%
new_patient_cooc_odd_scores
# Out:
# {('fibrinogen', 'mean'): 1.0,
#  ('gabapentin', 'gastriti'): 1.0,
#  ('postop', 'scar'): 1.0,
#  ('lac', 'qam'): 1.0,
#  ('adenosin', 'tcdb'): 1.0,
#  ('herp', 'mellitu'): 1.0,
#  ('anuria', 'cpr'): 0.0,
#  ('dyslipidemia', 'thiamin'): 1.0,
#  ('bair', 'sluggish'): 0.5500560933045909,
#  ('dizzi', 'mellitu'): 1.0,
#  ('captopril', 'lpm'): 1.0,
#  ('ambul', 'hurt'): 1.0,
#  ('dic', 'rigor'): 1.0,
#  ('pleasantli', 'robitussin'): 1.0,
#  ('mva', 'wether'): 1.0,
#  ('contractur', 'gadolinium'): 1.0,
#  ('anur', 'twitch'): 0.0,
#  ('artifici', 'xl'): 0.0,
#  ('gadolinium', 'leukocyt'): 1.0,
#  ('dni', 'pinpoint'): 0.0,
#  ('dni', 'vasopressin'): 0.0,
#  ('cash', 'cdb'): 1.0,
#  ('commod', 'cramp'): 1.0,
#  ('oligur', 'vasopressin'): 0.5319103789189528,
#  ('bipolar', 'ffp'): 1.0,
#  ('pulseless', 'syncop'): 1.0,
#  ('death', 'rigor'): 1.0,
#  ('flight', 'seroquel'): 1.0,
#  ('gadolinium', 'paperwork'): 1.0,
#  ('lax', 'xopenex'): 1.0,
#  ('itchi', 'vasopressin'): 0.0,
#  ('db', 'stg'): 1.0,
#  ('priest', 'rite'): 0.0,
#  ('ambien', 'sarna'): 1.0,
#  ('bipolar', 'refractori'): 1.0,
#  ('hctz', 'puff'): 1.0,
#  ('calvarium', 'slice'): 1.0,
#  ('lusb', 'sweat'): 1.0,
#  ('duski', 'mottl'): 0.0,
#  ('hemangioma', 'smooth'): 1.0,
#  ('dietari', 'mellitu'): 1.0,
#  ('duski', 'vasopressor'): 0.0,
#  ('dni', 'institut'): 1.0,
#  ('cardiovert', 'xl'): 1.0,
#  ('norepi', 'purpl'): 0.0,
#  ('cash', 'scopalamin'): 0.0,
#  ('dni', 'respitori'): 1.0,
#  ('hypercapn', 'unstabl'): 0.0,
#  ('articul', 'opiat'): 1.0,
#  ('diaper', 'scar'): 1.0,
#  ('bicarbon', 'trazodon'): 0.0,
#  ('artifici', 'gait'): 0.0,
#  ('fatti', 'slice'): 1.0,
#  ('mean', 'nonrebreath'): 0.0,
#  ('mellitu', 'ppd'): 0.5708190823810347,
#  ('dizzi', 'oob'): 0.7135820843561437,
#  ('aliv', 'zyprexa'): 1.0,
#  ('dnr', 'ipf'): 0.0,
#  ('gentamycin', 'oob'): 0.0,
#  ('absorb', 'trazodon'): 1.0,
#  ('dermat', 'dic'): 1.0,
#  ('sensat', 'uri'): 1.0,
#  ('hypotherm', 'vtach'): 1.0,
#  ('chair', 'unasyn'): 0.4595846302788977,
#  ('chair', 'habitu'): 1.0,
#  ('cramp', 'rhinorrhea'): 0.0,
#  ('aaox', 'thirst'): 1.0,
#  ('omeprazol', 'seroquel'): 1.0,
#  ('hunger', 'impli'): 0.0,
#  ('hilum', 'reguard'): 1.0,
#  ('contd', 'money'): 1.0,
#  ('exophyt', 'treatement'): 1.0,
#  ('oob', 'unsteadi'): 1.0,
#  ('cocain', 'expir'): 1.0,
#  ('autopsi', 'norepi'): 0.0,
#  ('levoph', 'rpr'): 1.0,
#  ('cvvh', 'platelet'): 0.0,
#  ('laryng', 'modifi'): 1.0,
#  ('fdp', 'ration'): 1.0,
#  ('deflat', 'zyprexa'): 1.0,
#  ('dietari', 'rhinorrhea'): 1.0,
#  ('acidot', 'imbal'): 1.0,
#  ('ambul', 'unasyn'): 1.0,
#  ('core', 'futil'): 0.0,
#  ('contractur', 'fliud'): 0.0,
#  ('bottl', 'bromid'): 1.0,
#  ('stair', 'thiamin'): 1.0,
#  ('captopril', 'struggl'): 1.0,
#  ('chair', 'ultram'): 1.0,
#  ('ferritin', 'neoplast'): 1.0,
#  ('fatti', 'pca'): 1.0,
#  ('oncologist', 'synthet'): 1.0,
#  ('dnr', 'mrg'): 1.0,
#  ('bair', 'lpm'): 0.0,
#  ('dyslipidemia', 'romi'): 1.0,
#  ('peac', 'prognosi'): 0.0,
#  ('commod', 'spiromet'): 1.0,
#  ('aox', 'seroquel'): 1.0,
#  ('captopril', 'cash'): 1.0,
#  ('ambien', 'carvedilol'): 1.0,
#  ('qam', 'thiamin'): 1.0,
#  ('breakfast', 'tran'): 1.0,
#  ('cs', 'dni'): 0.649926161380952,
#  ('levoph', 'petechia'): 0.0,
#  ('ntnd', 'scar'): 1.0,
#  ('incent', 'mucinex'): 1.0,
#  ('bottl', 'expir'): 0.0,
#  ('levoph', 'trazodon'): 1.0,
#  ('method', 'predict'): 0.0,
#  ('declin', 'gabapentin'): 1.0,
#  ('ambien', 'wish'): 1.0,
#  ('dni', 'nicotin'): 1.0,
#  ('platelet', 'sweat'): 0.0,
#  ('gather', 'retic'): 0.0,
#  ('dz', 'levoph'): 0.0,
#  ('dni', 'hypercapn'): 1.0,
#  ('sensat', 'unstabl'): 1.0,
#  ('dopamin', 'neo'): 0.6789811080628495,
#  ('palli', 'priest'): 0.0,
#  ('aox', 'bmx'): 1.0,
#  ('method', 'neoplast'): 1.0,
#  ('crrt', 'dobutamin'): 0.0,
#  ('gurgl', 'pleasant'): 1.0,
#  ('hypothermia', 'prilosec'): 1.0,
#  ('readmit', 'scab'): 1.0,
#  ('ambul', 'neo'): 0.42068377387531336,
#  ('burn', 'scar'): 1.0,
#  ('cooler', 'epidur'): 1.0,
#  ('moan', 'rhinorrhea'): 0.0,
#  ('dni', 'muddi'): 0.0,
#  ('arrest', 'impli'): 1.0,
#  ('angiogram', 'bow'): 1.0,
#  ('contd', 'deterior'): 1.0,
#  ('exophyt', 'hilum'): 1.0,
#  ('hctz', 'sibl'): 1.0,
#  ('pleasant', 'sweat'): 1.0,
#  ('dermat', 'dizzi'): 1.0,
#  ('core', 'romi'): 1.0,
#  ('cs', 'dyslipidemia'): 1.0,
#  ('fibrinogen', 'wish'): 1.0,
#  ('aliv', 'wish'): 1.0,
#  ('jewelri', 'life'): 1.0,
#  ('cmo', 'sacrament'): 0.0,
#  ('hygein', 'readmit'): 1.0,
#  ('gvhd', 'xii'): 1.0,
#  ('neo', 'rite'): 0.0,
#  ('sweat', 'video'): 1.0,
#  ('cloth', 'scopalamin'): 0.0,
#  ('pneumococc', 'thiamin'): 1.0,
#  ('adenocarcinoma', 'pleasant'): 1.0,
#  ('ctx', 'video'): 1.0,
#  ('arrest', 'pcv'): 0.0,
#  ('ambul', 'splint'): 1.0,
#  ('anur', 'phenylephrin'): 0.0,
#  ('ctx', 'modifi'): 1.0,
#  ('deterior', 'hugger'): 1.0,
#  ('oncologist', 'puff'): 1.0,
#  ('lat', 'lax'): 1.0,
#  ('hypothermia', 'recruit'): 0.0,
#  ('gentamycin', 'levoph'): 0.27170977672342267,
#  ('oob', "tf'ing"): 1.0,
#  ('dnr', 'hypotherm'): 0.4838831694112334,
#  ('seroquel', 'td'): 1.0,
#  ('crack', 'dni'): 1.0,
#  ('hypothermia', 'sensat'): 1.0,
#  ('lat', 'wallet'): 1.0,
#  ('sensat', 'subq'): 1.0,
#  ('dnr', 'surviv'): 1.0,
#  ('acidot', 'dni'): 0.0,
#  ('dermat', 'diamox'): 1.0,
#  ('historian', 'hsq'): 1.0,
#  ('escal', 'mso'): 0.0,
#  ('aricept', 'ba'): 1.0,
#  ('cup', 'seat'): 1.0,
#  ('anaphylaxi', 'paperwork'): 1.0,
#  ('option', 'unstabl'): 0.0,
#  ('anur', 'mottl'): 0.0,
#  ('anuria', 'dead'): 0.0,
#  ('trazodon', 'uri'): 1.0,
#  ('asthma', 'director'): 1.0,
#  ('aricept', 'meatu'): 1.0,
#  ('mucinex', 'reguard'): 1.0,
#  ('db', 'epigastr'): 1.0,
#  ('pericard', 'quadrent'): 1.0,
#  ('deliv', 'lymphangit'): 1.0,
#  ('death', 'puff'): 1.0,
#  ('levoph', 'vtach'): 0.3416223465247969,
#  ('dni', 'fdp'): 0.0,
#  ('hsq', 'stair'): 1.0,
#  ('bell', 'icter'): 1.0,
#  ('incent', 'rememb'): 1.0,
#  ('bell', 'dni'): 1.0,
#  ('asthma', 'pod'): 1.0,
#  ('phlegm', 'qam'): 1.0,
#  ('mood', 'sweat'): 1.0,
#  ('arrest', 'neo'): 0.5651934746155426,
#  ('azotemia', 'pneumococc'): 1.0,
#  ('agon', 'pinpoint'): 0.0,
#  ('cpr', 'lotion'): 0.0,
#  ('diaphoresi', 'xii'): 1.0,
#  ('death', 'sooner'): 1.0,
#  ('olanzapin', 'zyprexa'): 1.0,
#  ('aricept', 'pleasant'): 0.5292841127058171,
#  ('hospic', 'levoph'): 0.0,
#  ('profound', 'zyprexa'): 1.0,
#  ('aricept', 'puff'): 1.0,
#  ('hospic', 'osa'): 0.0,
#  ('dizzi', 'myeloma'): 1.0,
#  ('align', 'aricept'): 0.0,
#  ('protrud', 'thiamin'): 1.0,
#  ('chip', 'silent'): 1.0,
#  ('dnr', 'romi'): 0.6949152225080758,
#  ('aaox', 'gurgl'): 0.0,
#  ('derecruit', 'norepinephrin'): 0.0,
#  ('aricept', 'sundown'): 0.0,
#  ('dysynchron', 'vasopressin'): 0.0,
#  ('articul', 'seroquel'): 1.0,
#  ('autopeep', 'recruit'): 0.0,
#  ('cardiovert', 'dysynchron'): 0.0,
#  ('gabapentin', 'laminectomi'): 1.0,
#  ('palliat', 'prognosi'): 0.0,
#  ('captopril', 'money'): 1.0,
#  ('dk', 'oligur'): 1.0,
#  ('ctx', 'ppd'): 1.0,
#  ('heroic', 'mottl'): 0.0,
#  ('ciwa', 'commod'): 1.0,
#  ('bicarbon', 'mva'): 1.0,
#  ('aox', 'zyprexa'): 0.0,
#  ('spiromet', 'syst'): 1.0,
#  ('angri', 'burn'): 1.0,
#  ('declin', 'money'): 1.0,
#  ('fibrinogen', 'surgicel'): 0.0,
#  ('clinician', 'profound'): 0.0,
#  ('platelet', 'pleasant'): 1.0,
#  ('splint', 'xii'): 1.0,
#  ('aox', 'syncop'): 1.0,
#  ('colonoscopi', 'pleasant'): 1.0,
#  ('mottl', 'recruit'): 0.0,
#  ('dietari', 'mso'): 1.0,
#  ('lpm', 'strictur'): 1.0,
#  ('cooler', 'cup'): 1.0,
#  ('diaphoresi', 'life'): 1.0,
#  ('captopril', 'epidur'): 1.0,
#  ('dnr', 'sibl'): 0.6161320073290462,
#  ('cmo', 'rememb'): 0.0,
#  ('mrcp', 'ppd'): 0.0,
#  ('habitu', 'thiamin'): 1.0,
#  ('align', 'ligament'): 1.0,
#  ('prilosec', 'zoloft'): 1.0,
#  ('aaox', 'bill'): 1.0,
#  ('clonazepam', 'fibrinogen'): 1.0,
#  ('itchi', 'sensat'): 1.0,
#  ('nephrogram', 'scar'): 1.0,
#  ('argatroban', 'crrt'): 0.0,
#  ('epigastr', 'gather'): 0.0,
#  ('nitroglycerin', 'readdress'): 1.0,
#  ('uncoop', 'vagu'): 1.0,
#  ('institut', 'myeloma'): 0.0,
#  ('echocardiogram', 'neoplast'): 0.0,
#  ('db', 'zoloft'): 1.0,
#  ('puff', 'young'): 1.0,
#  ('hypercapnia', 'oob'): 1.0,
#  ('argatroban', 'ffp'): 0.0,
#  ('gait', 'omeprazol'): 1.0,
#  ('adenocarcinoma', 'laryng'): 1.0,
#  ('diaper', 'wish'): 0.0,
#  ('dni', 'ntnd'): 0.602586982591368,
#  ('breakfast', 'uri'): 1.0,
#  ('historian', 'sweat'): 1.0,
#  ('cocain', 'ultrafiltr'): 1.0,
#  ('abruptli', 'cmo'): 0.0,
#  ('subq', 'sweat'): 1.0,
#  ('breakfast', 'osa'): 1.0,
#  ('bicarbon', 'gait'): 0.0,
#  ('calculi', 'thrive'): 1.0,
#  ('cmo', 'knowledg'): 1.0,
#  ('dead', 'unrel'): 0.0,
#  ('dnr', 'pivot'): 0.5161168305887667,
#  ('xopenex', 'zoloft'): 0.0,
#  ('diflucan', 'romi'): 1.0,
#  ('lat', 'pronounc'): 1.0,
#  ('bipolar', 'pneumococc'): 1.0,
#  ('fatti', 'stair'): 1.0,
#  ('anur', 'dic'): 0.0,
#  ('hypothermia', 'trazodon'): 1.0,
#  ('venti', 'xanax'): 1.0,
#  ('dizzi', 'incis'): 1.0,
#  ('norepinephrin', 'wma'): 0.0,
#  ('klonopin', 'seroquel'): 1.0,
#  ('echocardiogram', 'sweat'): 1.0,
#  ('declin', 'xopenex'): 1.0,
#  ('clonidin', 'qam'): 1.0,
#  ('knowledg', 'wish'): 1.0,
#  ('dni', 'strictur'): 1.0,
#  ('lotion', 'pca'): 1.0,
#  ('anuria', 'paralyt'): 1.0,
#  ('cpr', 'nonreact'): 0.0,
#  ('aliv', 'prilosec'): 1.0,
#  ('dz', 'pathologist'): 1.0,
#  ('ctx', 'moan'): 1.0,
#  ('cloth', 'probe'): 1.0,
#  ('conc', 'flake'): 1.0,
#  ('probe', 'sundown'): 1.0,
#  ('ba', 'quinolon'): 0.0,
#  ('pharmacolog', 'splint'): 1.0,
#  ('anuria', 'slough'): 1.0,
#  ('crack', 'puff'): 1.0,
#  ('dz', 'pleasant'): 1.0,
#  ('abnl', 'nifedipin'): 1.0,
#  ('chemic', 'habitu'): 1.0,
#  ('chemic', 'unasyn'): 1.0,
#  ('bottl', 'gentamycin'): 0.0,
#  ('qam', 'schizophrenia'): 1.0,
#  ('rigor', 'uri'): 1.0,
#  ('bicarbon', 'cvvh'): 0.0,
#  ('bottl', 'neosynephrin'): 0.0,
#  ('incent', 'levoph'): 1.0,
#  ('pea', 'recruit'): 0.7641374789024603,
#  ('mucinex', 'transmitr'): 1.0,
#  ('angiogram', 'flight'): 1.0,
#  ('ciwa', 'epigastr'): 1.0,
#  ('broader', 'dnr'): 1.0,
#  ('cloth', 'moan'): 1.0,
#  ('motor', 'puff'): 1.0,
#  ('rehabilit', 'trazodon'): 1.0,
#  ('refractori', 'thoracocentesi'): 1.0,
#  ('pitressin', 'purpl'): 0.0,
#  ('aaox', 'moan'): 1.0,
#  ('dnr', 'zoloft'): 0.39994173456925625,
#  ('ambien', 'qam'): 1.0,
#  ('autopeep', 'fibrinogen'): 0.0,
#  ('burn', 'spacer'): 1.0,
#  ('fibrinogen', 'vasopressin'): 0.3253183289327562,
#  ('signatur', 'young'): 1.0,
#  ('deterior', 'leukocyt'): 1.0,
#  ('gabapentin', 'qtc'): 1.0,
#  ('cocain', 'epigastr'): 1.0,
#  ('erythro', 'oob'): 1.0,
#  ('cash', 'spiromet'): 1.0,
#  ('diaphoresi', 'signatur'): 1.0,
#  ('dz', 'silent'): 0.0,
#  ('arrest', 'azotemia'): 0.0,
#  ('fatti', 'signatur'): 1.0,
#  ('chair', 'lcw'): 1.0,
#  ('levoph', 'vasoconstrict'): 0.0,
#  ('diamox', 'neosynephrin'): 1.0,
#  ('neo', 'outer'): 1.0,
#  ('cmo', 'grim'): 0.0,
#  ('rememb', 'seroquel'): 1.0,
#  ('ntnd', 'thiamin'): 1.0,
#  ('dizzi', 'thiamin'): 1.0,
#  ('gabapentin', 'shorter'): 1.0,
#  ('declin', 'scab'): 1.0,
#  ('platelet', 'postop'): 1.0,
#  ('chair', 'reguard'): 1.0,
#  ('core', 'synthet'): 1.0,
#  ('scar', 'uri'): 1.0,
#  ('arthrit', 'cdb'): 1.0,
#  ('anur', 'dnr'): 0.6161320073290462,
#  ('ba', 'ctx'): 1.0,
#  ('unavail', 'venti'): 1.0,
#  ('ciwa', 'prec'): 1.0,
#  ('hypothermia', 'rpr'): 1.0,
#  ('bell', 'dermat'): 1.0,
#  ('video', 'vp'): 1.0,
#  ('neosynephrin', 'vasopressin'): 0.0,
#  ('cash', 'ciwa'): 1.0,
#  ('dysynchron', 'osa'): 0.0,
#  ('diflucan', 'iddm'): 1.0,
#  ('levoph', 'qam'): 1.0,
#  ('asystol', 'neosynephrin'): 0.0,
#  ('chair', 'fibrinogen'): 0.0,
#  ('dopamin', 'unstabl'): 0.0,
#  ('sensat', 'silent'): 1.0,
#  ('goc', 'nifedipin'): 1.0,
#  ('bow', 'scar'): 1.0,
#  ('platelet', 'rhinorrhea'): 0.4792220206955969,
#  ('silent', 'vallecula'): 1.0,
#  ('compani', 'dni'): 1.0,
#  ('deterior', 'heroic'): 0.0,
#  ('puff', 'video'): 1.0,
#  ('hctz', 'prilosec'): 1.0,
#  ('gabapentin', 'mellitu'): 1.0,
#  ('hunger', 'signatur'): 1.0,
#  ('dnr', 'epidur'): 1.0,
#  ('dni', 'ofm'): 1.0,
#  ('dome', 'slice'): 1.0,
#  ('seroquel', 'zoloft'): 1.0,
#  ('adenosin', 'oligur'): 1.0,
#  ('cpr', 'syncop'): 1.0,
#  ('norepinephrin', 'vasopressin'): 0.4385978958856616,
#  ('dnr', 'opinion'): 0.0,
#  ('gather', 'levoph'): 0.0,
#  ('refractori', 'spfc'): 1.0,
#  ('abruptli', 'platelet'): 0.0,
#  ('fibrinogen', 'fungemia'): 1.0,
#  ('mellitu', 'stair'): 1.0,
#  ('hhn', 'lpm'): 1.0,
#  ('barium', 'silent'): 1.0,
#  ('oob', 'simpli'): 1.0,
#  ('mso', 'pca'): 1.0,
#  ('burn', 'lighthead'): 1.0,
#  ('dni', 'dobutamin'): 1.0,
#  ('colonoscopi', 'epidur'): 1.0,
#  ('escal', 'prognosi'): 0.32724404811979113,
#  ('dic', 'vasopressor'): 0.0,
#  ('dni', 'phenylephrin'): 0.3914555523845758,
#  ('anur', 'corneal'): 0.0,
#  ('ambul', 'osa'): 0.0,
#  ('ferrou', 'gabapentin'): 1.0,
#  ('ferrou', 'unavail'): 1.0,
#  ('cyanot', 'illeu'): 0.0,
#  ('autopsi', 'mottl'): 0.0,
#  ('fibrinogen', 'mellitu'): 0.7210533656907376,
#  ('bromid', 'dyslipidemia'): 1.0,
#  ('pyuria', 'seroquel'): 1.0,
#  ('db', 'spacer'): 1.0,
#  ('adam', 'hypotherm'): 0.0,
#  ('gabapentin', 'incis'): 1.0,
#  ('nahco', 'wish'): 0.0,
#  ('dni', 'ipf'): 0.47071588729418296,
#  ('historian', 'hurt'): 0.0,
#  ('arrest', 'led'): 1.0,
#  ('gabapentin', 'nocturn'): 1.0,
#  ('anur', 'chemic'): 1.0,
#  ('dyslipidemia', 'soln'): 1.0,
#  ('commod', 'compani'): 1.0,
#  ('intiat', 'pronounc'): 0.0,
#  ('levoph', 'recruit'): 0.0,
#  ('gotten', 'msicu'): 1.0,
#  ('banana', 'oob'): 1.0,
#  ('led', 'schizophrenia'): 1.0,
#  ('dni', 'intiat'): 0.0,
#  ('ppd', 'soln'): 1.0,
#  ('arrest', 'sweat'): 1.0,
#  ('dnr', 'ppn'): 1.0,
#  ('cremat', 'funer'): 0.0,
#  ('friction', 'unobtain'): 1.0,
#  ('chb', 'moan'): 0.0,
#  ('epigastr', 'xanax'): 1.0,
#  ('dnr', 'fc'): 0.0,
#  ('brb', 'ppd'): 1.0,
#  ('cocain', 'pneumococc'): 1.0,
#  ('icter', 'mellitu'): 0.47071588729418296,
#  ('currenlti', 'dni'): 1.0,
#  ('dermat', 'platelet'): 1.0,
#  ('adenocarcinoma', 'synthet'): 1.0,
#  ('oob', 'video'): 1.0,
#  ('captopril', 'omeprazol'): 0.5,
#  ('bipolar', 'forc'): 0.2451777438240075,
#  ('fatti', 'natg'): 0.0,
#  ('ferrou', 'xii'): 1.0,
#  ('platelet', 'rpr'): 1.0,
#  ('adam', 'futil'): 0.0,
#  ('neo', 'pca'): 1.0,
#  ('ambul', 'trazodon'): 1.0,
#  ('aox', 'wish'): 1.0,
#  ('levoph', 'sluggish'): 0.4045933027827741,
#  ('incent', 'mrcp'): 0.0,
#  ('chol', 'nahco'): 0.0,
#  ('aox', 'diamox'): 1.0,
#  ('chemic', 'exophyt'): 0.0,
#  ('gabapentin', 'thiamin'): 1.0,
#  ('levoph', 'xii'): 1.0,
#  ('homogen', 'scar'): 1.0,
#  ('anaphylaxi', 'ctx'): 1.0,
#  ('ppd', 'weekli'): 1.0,
#  ('oncologist', 'wish'): 0.5500560933045909,
#  ('bill', 'lotion'): 1.0,
#  ('dnr', 'ffp'): 0.3622783748891388,
#  ('incent', 'ntnd'): 0.0,
#  ('aox', 'dnr'): 0.6727559518802089,
#  ('aricept', 'levoph'): 1.0,
#  ('epigastr', 'postop'): 1.0,
#  ('levoph', 'pitressin'): 0.6000582654307438,
#  ('hypotherm', 'xl'): 1.0,
#  ('escal', 'tobra'): 0.0,
#  ('nicotin', 'uri'): 1.0,
#  ('cocain', 'thrive'): 1.0,
#  ('bromid', 'laminectomi'): 1.0,
#  ('hive', 'wallet'): 1.0,
#  ('cpr', 'neo'): 0.5793162261246866,
#  ('neosynephrin', 'pea'): 0.0,
#  ('cooki', 'neutral'): 1.0,
#  ('ppd', 'suprapub'): 1.0,
#  ('nice', 'suffer'): 1.0,
#  ('neo', 'sorb'): 0.0,
#  ('hypotherm', 'readdress'): 0.0,
#  ('grave', 'purpl'): 0.0,
#  ('anur', 'transmitr'): 1.0,
#  ('lymphangit', 'osa'): 1.0,
#  ('pyuria', 'rigor'): 1.0,
#  ('dni', 'norepinephrin'): 0.3838679926709539,
#  ('carvedilol', 'fibrinogen'): 1.0,
#  ('cocain', 'ctx'): 1.0,
#  ('asthma', 'wallet'): 1.0,
#  ('caspofungin', 'levoph'): 1.0,
#  ('cramp', 'dnr'): 1.0,
#  ('endur', 'xanax'): 1.0,
#  ('death', 'lusb'): 1.0,
#  ('anuria', 'readmit'): 1.0,
#  ('motor', 'sibl'): 1.0,
#  ('coach', 'spiromet'): 1.0,
#  ('ambul', 'platelet'): 0.0,
#  ('plate', 'scar'): 1.0,
#  ('defibril', 'unstabl'): 0.0,
#  ('asystol', 'peac'): 0.0,
#  ('^th', 'banana'): 1.0,
#  ('aricept', 'norepinephrin'): 1.0,
#  ('nectar', 'pivot'): 1.0,
#  ('ambien', 'hunger'): 1.0,
#  ('dnr', 'laminectomi'): 1.0,
#  ('rememb', 'uri'): 1.0,
#  ('gabapentin', 'opiat'): 1.0,
#  ('diaphoresi', 'ruptur'): 1.0,
#  ('agon', 'clergi'): 0.0,
#  ('aox', 'hugger'): 1.0,
#  ('dizzi', 'ipf'): 1.0,
#  ('elimin', 'pharyng'): 1.0,
#  ('ipf', 'lpm'): 1.0,
#  ('barium', 'smooth'): 1.0,
#  ('intent', 'thiamin'): 1.0,
#  ('morbid', 'underpenetr'): 1.0,
#  ('barium', 'xii'): 1.0,
#  ('magnevist', 'vertebra'): 1.0,
#  ('famil', 'struggl'): 0.0,
#  ('angioplasti', 'deploy'): 1.0,
#  ('pleasant', 'tubular'): 1.0,
#  ('hypothermia', 'refractori'): 0.0,
#  ('cpr', 'recalibr'): 0.0,
#  ('asthma', 'thiamin'): 1.0,
#  ('tdi', 'unavail'): 1.0,
#  ('dnr', 'xopenex'): 0.2688261025519499,
#  ('forc', 'oob'): 0.0,
#  ('diaper', 'video'): 1.0,
#  ('ambul', 'rusti'): 0.0,
#  ('anur', 'conc'): 1.0,
#  ('dnr', 'vp'): 1.0,
#  ('dz', 'underneath'): 1.0,
#  ('kerlix', 'nectar'): 1.0,
#  ('modifi', 'wfl'): 1.0,
#  ('levoph', 'phlegm'): 0.0,
#  ('ferritin', 'readmit'): 1.0,
#  ('cyanot', 'knowledg'): 1.0,
#  ('mellitu', 'omeprazol'): 0.6111638759493098,
#  ('gabapentin', 'sibl'): 1.0,
#  ('colonoscopi', 'dnr'): 1.0,
#  ('pca', 'wish'): 1.0,
#  ('barium', 'spur'): 1.0,
#  ('ethic', 'sorb'): 0.0,
#  ('ambul', 'sarna'): 1.0,
#  ('spacer', 'unstabl'): 1.0,
#  ('lw', 'unstabl'): 1.0,
#  ('bottl', 'levoph'): 0.3893053221647467,
#  ('dic', 'dni'): 0.5500560933045909,
#  ('jejunum', 'scar'): 1.0,
#  ('phlegm', 'splint'): 1.0,
#  ('im', 'lusb'): 1.0,
#  ('dni', 'mycolyt'): 0.0,
#  ('cefapim', 'pea'): 1.0,
#  ('bottl', 'deterior'): 1.0,
#  ('cmo', 'gentamycin'): 0.0,
#  ('flight', 'nephrolog'): 1.0,
#  ('arrest', 'pastor'): 0.0,
#  ('expir', 'wish'): 0.0,
#  ('diaphoresi', 'money'): 1.0,
#  ('deterior', 'unequ'): 1.0,
#  ('clergi', 'levoph'): 0.0,
#  ('qam', 'strictur'): 1.0,
#  ('neo', 'recruit'): 1.0,
#  ('dietari', 'distanc'): 1.0,
#  ('cpr', 'mottl'): 0.0,
#  ('arrang', 'dnr'): 0.0,
#  ('death', 'paco'): 0.0,
#  ('nitroglycerin', 'sweat'): 0.0,
#  ('ferrou', 'thrive'): 1.0,
#  ('hive', 'metoclopramid'): 1.0,
#  ('dni', 'thirst'): 1.0,
#  ('lpm', 'oob'): 1.0,
#  ('echocardiogram', 'ppd'): 1.0,
#  ('adenocarcinoma', 'osa'): 1.0,
#  ('lat', 'syncop'): 1.0,
#  ('criticar', 'pinpoint'): 0.0,
#  ('fibrinogen', 'opiat'): 0.5032106369946284,
#  ('fibrinogen', 'religi'): 0.0,
#  ('ferritin', 'trazodon'): 1.0,
#  ('mail', 'pleasant'): 1.0,
#  ('pleasant', 'silent'): 1.0,
#  ('deterior', 'mellitu'): 1.0,
#  ('core', 'declin'): 0.0,
#  ('autopeep', 'paralyt'): 0.0,
#  ('ppd', 'puff'): 1.0,
#  ('chair', 'dni'): 0.5298170691049984,
#  ('qam', 'sensat'): 0.6000582654307438,
#  ('historian', 'ppd'): 1.0,
#  ('xl', 'zyprexa'): 1.0,
#  ('dni', 'sibl'): 0.6161320073290462,
#  ('pod', 'xanax'): 1.0,
#  ('postop', 'tubular'): 1.0,
#  ('ppd', 'rpr'): 1.0,
#  ('dni', 'morgu'): 0.0,
#  ('hsq', 'ppd'): 0.5,
#  ('pneumococc', 'qam'): 1.0,
#  ('homogen', 'pronounc'): 1.0,
#  ('asthma', 'romi'): 1.0,
#  ('intent', 'nifedipin'): 1.0,
#  ('crrt', 'lotion'): 1.0,
#  ('coach', 'oob'): 1.0,
#  ('ciwa', 'dopamin'): 1.0,
#  ('romi', 'thirst'): 1.0,
#  ('cs', 'hugger'): 0.0,
#  ('arrest', 'declin'): 1.0,
#  ('gastrojejunostomi', 'metoclopramid'): 1.0,
#  ('burn', 'thirst'): 1.0,
#  ('antb', 'captopril'): 1.0,
#  ('ambul', 'west'): 1.0,
#  ('dni', 'levoph'): 0.4792220206955969,
#  ('neo', 'scab'): 1.0,
#  ('platelet', 'rm'): 1.0,
#  ('ambien', 'crack'): 1.0,
#  ('brb', 'crrt'): 0.0,
#  ('levoph', 'meropenam'): 0.0,
#  ('expir', 'vasopressin'): 0.0,
#  ('cocain', 'sweat'): 1.0,
#  ('neo', 'video'): 1.0,
#  ('oob', 'ppd'): 1.0,
#  ('griev', 'levoph'): 0.0,
#  ('contractur', 'criticar'): 1.0,
#  ('ipf', 'robitussin'): 0.0,
#  ('life', 'prognosi'): 0.0,
#  ('ffp', 'opinion'): 1.0,
#  ('proph', 'thoracocentesi'): 1.0,
#  ('rigor', 'young'): 1.0,
#  ('fdp', 'neutral'): 1.0,
#  ('nahco', 'purpl'): 0.0,
#  ('declin', 'signatur'): 1.0,
#  ('commod', 'nectar'): 1.0,
#  ('qtc', 'rm'): 1.0,
#  ('aaox', 'readmit'): 1.0,
#  ('crrt', 'surgicel'): 0.0,
#  ('aox', 'puff'): 1.0,
#  ('cellcept', 'lat'): 1.0,
#  ('azotemia', 'petechia'): 0.0,
#  ('dni', 'rm'): 1.0,
#  ('omeprazol', 'quinolon'): 1.0,
#  ('colonoscopi', 'dopamin'): 1.0,
#  ('captopril', 'yel'): 1.0,
#  ('clonazepam', 'recruit'): 1.0,
#  ('adenocarcinoma', 'pod'): 1.0,
#  ('cash', 'dopamin'): 0.0,
#  ('autopsi', 'prognosi'): 0.0,
#  ('clinician', 'im'): 1.0,
#  ('hypothermia', 'sweat'): 1.0,
#  ('bottl', 'carvedilol'): 1.0,
#  ('declin', 'ozz'): 0.0,
#  ('occipit', 'zyprexa'): 1.0,
#  ('angioplasti', 'tran'): 1.0,
#  ('ppd', 'subq'): 1.0,
#  ('arrest', 'scar'): 1.0,
#  ('cyanot', 'iddm'): 1.0,
#  ('pneumothorac', 'scar'): 1.0,
#  ('liw', 'prognosi'): 0.0,
#  ('chair', 'ctx'): 1.0,
#  ('strictur', 'vagu'): 1.0,
#  ('ctx', 'stair'): 1.0,
#  ('pca', 'pharmacolog'): 1.0,
#  ('romi', 'venti'): 1.0,
#  ('levoph', 'pcv'): 0.6085444476154243,
#  ('suprapub', 'wish'): 1.0,
#  ('ambien', 'puff'): 1.0,
#  ('omeprazol', 'zyprexa'): 1.0,
#  ('hugger', 'moan'): 0.0,
#  ('dni', 'jerk'): 0.0,
#  ('bicarbon', 'levoph'): 0.0,
#  ('gentamycin', 'multisystem'): 0.0,
#  ('cpr', 'dobutamin'): 0.0,
#  ('dizzi', 'sibl'): 0.0,
#  ('bottl', 'motor'): 1.0,
#  ('mtg', 'ruptur'): 1.0,
#  ('pleasant', 'redirect'): 0.5161168305887667,
#  ('dni', 'spacer'): 1.0,
#  ('profound', 'ud'): 1.0,
#  ('permiss', 'sluggishli'): 0.0,
#  ('diaphoresi', 'ppd'): 1.0,
#  ('core', 'dorsal'): 0.0,
#  ('cpr', 'struggl'): 1.0,
#  ('crowd', 'habitu'): 1.0,
#  ('hugger', 'pinpoint'): 0.0,
#  ('cocain', 'gabapentin'): 1.0,
#  ('incis', 'purpl'): 1.0,
#  ('levoph', 'mean'): 1.0,
#  ('diaphoresi', 'hsq'): 1.0,
#  ('cramp', 'platelet'): 0.0,
#  ('buck', 'triadyn'): 1.0,
#  ('levoph', 'montitor'): 0.0,
#  ('death', 'sweat'): 1.0,
#  ('bromid', 'subdur'): 1.0,
#  ('dnr', 'rpr'): 1.0,
#  ('incent', 'phlegm'): 1.0,
#  ('gait', 'gown'): 1.0,
#  ('dni', 'historian'): 1.0,
#  ('acidot', 'fdp'): 0.0,
#  ('bottl', 'chemic'): 1.0,
#  ('fatti', 'sweat'): 1.0,
#  ('cmo', 'sibl'): 0.0,
#  ('icter', 'weekli'): 1.0,
#  ('incent', 'spacer'): 1.0,
#  ('ba', 'precordium'): 1.0,
#  ('cocain', 'klonopin'): 1.0,
#  ('dopamin', 'qam'): 1.0,
#  ('cs', 'lpm'): 0.0,
#  ('gait', 'thiamin'): 1.0,
#  ('cpr', 'twitch'): 0.0,
#  ('cyanot', 'fungemia'): 0.0,
#  ('captopril', 'chol'): 1.0,
#  ('compani', 'unstabl'): 1.0,
#  ('dnr', 'vagu'): 1.0,
#  ('aricept', 'gown'): 0.0,
#  ('cardiovert', 'levoph'): 0.19276297917211715,
#  ('intent', 'precordium'): 1.0,
#  ('asthma', 'death'): 1.0,
#  ('cpr', 'nitroglycerin'): 0.0,
#  ('behavior', 'cocain'): 1.0,
#  ('hospic', 'mso'): 0.0,
#  ('chip', 'readmit'): 1.0,
#  ('bicarbon', 'weekli'): 1.0,
#  ('habitu', 'underpenetr'): 1.0,
#  ('cpr', 'prognosi'): 0.0,
#  ('dni', 'epidur'): 1.0,
#  ('prognosi', 'viabl'): 0.0,
#  ('bicarbon', 'thiamin'): 1.0,
#  ('bottl', 'cisatracurium'): 0.0,
#  ('tubular', 'vp'): 1.0,
#  ('clergi', 'suffer'): 0.0,
#  ('dopamin', 'grave'): 0.0,
#  ('aox', 'esld'): 1.0,
#  ('commod', 'sooner'): 1.0,
#  ('aox', 'money'): 1.0,
#  ('argatroban', 'norepinephrin'): 0.0,
#  ('arrest', 'dic'): 0.0,
#  ('arrest', 'pronounc'): 0.0,
#  ('normotherm', 'oob'): 1.0,
#  ('bipolar', 'sundown'): 1.0,
#  ('autopeep', 'levoph'): 0.0,
#  ('signatur', 'sweat'): 1.0,
#  ('dizzi', 'herp'): 1.0,
#  ('dome', 'homogen'): 1.0,
#  ('core', 'hsq'): 0.0,
#  ('dobutamin', 'hugger'): 1.0,
#  ('osa', 'platelet'): 0.0,
#  ('norepinephrin', 'phenylephrin'): 0.0,
#  ('chip', 'moisten'): 0.0,
#  ('pcv', 'vasopressin'): 0.0,
#  ('db', 'sweat'): 1.0,
#  ('cup', 'readmit'): 1.0,
#  ('pharyng', 'wfl'): 1.0,
#  ('lift', 'readmit'): 1.0,
#  ('ambul', 'omeprazol'): 1.0,
#  ('nocturn', 'romi'): 1.0,
#  ('gabapentin', 'hive'): 1.0,
#  ('bell', 'chair'): 0.6789811080628495,
#  ('ppd', 'romi'): 1.0,
#  ('maroon', 'reguard'): 1.0,
#  ('absorb', 'paralyt'): 1.0,
#  ('grave', 'prognosi'): 0.29616936920880316,
#  ('angioplasti', 'iddm'): 1.0,
#  ('hypothermia', 'resucit'): 0.0,
#  ('dnr', 'pyuria'): 0.5368924099923496,
#  ('crrt', 'synthet'): 1.0,
#  ('outer', 'vertebra'): 1.0,
#  ('fibrinogen', 'norepinephrin'): 0.35655598114482967,
#  ('herp', 'ipf'): 1.0,
#  ('anuria', 'cvvhd'): 0.0,
#  ('clergi', 'paralyt'): 0.0,
#  ('goc', 'ind'): 0.0,
#  ('plate', 'requr'): 1.0,
#  ('dni', 'plerual'): 0.0,
#  ('ambien', 'freeli'): 1.0,
#  ('conc', 'rigor'): 1.0,
#  ('dnr', 'robitussin'): 0.42068377387531336,
#  ('ambul', 'stair'): 1.0,
#  ('chair', 'stood'): 1.0,
#  ('deterior', 'friction'): 1.0,
#  ('diuril', 'gabapentin'): 1.0,
#  ('anaphylaxi', 'dni'): 1.0,
#  ('asthma', 'lusb'): 1.0,
#  ('cramp', 'hsq'): 0.0,
#  ('diaphoresi', 'uncoop'): 1.0,
#  ('arrest', 'recruit'): 0.7641374789024603,
#  ('bicarbon', 'crrt'): 0.0,
#  ('acc', 'angri'): 1.0,
#  ('coach', 'unavail'): 1.0,
#  ('dnr', 'vasopressin'): 0.0,
#  ('ppd', 'tran'): 1.0,
#  ("sxn'ing", 'thk'): 1.0,
#  ('cyanot', 'laminectomi'): 1.0,
#  ('cs', 'oob'): 1.0,
#  ('imbal', 'pca'): 1.0,
#  ('soln', 'subdur'): 1.0,
#  ('cellcept', 'dyslipidemia'): 1.0,
#  ('pyuria', 'sibl'): 1.0,
#  ('mso', 'prognosi'): 0.0,
#  ('hospic', 'wish'): 0.5292841127058171,
#  ('silent', 'videofluoroscopi'): 1.0,
#  ('contd', 'signatur'): 1.0,
#  ('itchi', 'quinolon'): 1.0,
#  ('dni', 'pleuravac'): 0.0,
#  ('hunger', 'wish'): 1.0,
#  ('azotemia', 'declin'): 1.0,
#  ('cracker', 'mellitu'): 1.0,
#  ('news', 'pronounc'): 0.0,
#  ('aox', 'palli'): 1.0,
#  ('gait', 'mellitu'): 1.0,
#  ('dyslipidemia', 'flight'): 1.0,
#  ('esld', 'oob'): 1.0,
#  ('ctx', 'syncop'): 1.0,
#  ('icter', 'prilosec'): 1.0,
#  ('cvvh', 'vasopressin'): 0.0,
#  ('mva', 'spiromet'): 1.0,
#  ('cash', 'ppd'): 1.0,
#  ('ggt', 'vasopressor'): 0.0,
#  ('sensat', 'thirst'): 1.0,
#  ('chair', 'illeu'): 0.0,
#  ('gabapentin', 'xl'): 1.0,
#  ('articul', 'robitussin'): 1.0,
#  ('anur', 'cardiovert'): 1.0,
#  ('death', 'declar'): 0.0,
#  ('chair', 'ppd'): 0.5,
#  ('dnr', 'meropenam'): 0.0,
#  ('nitroglycerin', 'rhinorrhea'): 0.0,
#  ('declar', 'nimv'): 0.0,
#  ('colonoscopi', 'signatur'): 1.0,
#  ('breakfast', 'recalibr'): 1.0,
#  ('cmo', 'hunger'): 0.5,
#  ('corneal', 'twitch'): 0.0,
#  ('purpl', 'seroquel'): 1.0,
#  ('intiat', 'splint'): 1.0,
#  ('dni', 'pivot'): 0.5161168305887667,
#  ('hugger', 'incis'): 0.0,
#  ('olanzapin', 'palli'): 1.0,
#  ('purpl', 'wish'): 0.0,
#  ('pleasant', 'unstabl'): 1.0,
#  ('chemic', 'gabapentin'): 1.0,
#  ('osa', 'paco'): 1.0,
#  ('clonidin', 'refractori'): 1.0,
#  ('fibrinogen', 'hemothorax'): 0.0,
#  ('levoph', 'paco'): 1.0,
#  ('ctx', 'signatur'): 1.0,
#  ('asthma', 'cash'): 1.0,
#  ('nocturn', 'thiamin'): 1.0,
#  ('cmo', 'incis'): 0.0,
#  ('bill', 'readmit'): 1.0,
#  ('mva', 'spacer'): 1.0,
#  ('money', 'ultram'): 1.0,
#  ('absorb', 'seroquel'): 1.0,
#  ('cocain', 'omeprazol'): 1.0,
#  ('anaphylaxi', 'deterior'): 1.0,
#  ('anur', 'crrt'): 1.0,
#  ('life', 'qam'): 1.0,
#  ('permiss', 'vasopressin'): 0.0,
#  ('dni', 'ind'): 0.0,
#  ('death', 'peac'): 0.0,
#  ('knew', 'spiromet'): 1.0,
#  ('cardiovert', 'contini'): 1.0,
#  ('palli', 'wish'): 0.4414417710473658,
#  ('gastrojejunostomi', 'strictur'): 1.0,
#  ('levoph', 'occipit'): 1.0,
#  ('levoph', 'moan'): 0.0,
#  ('lotion', 'puff'): 1.0,
#  ('omeprazol', 'postop'): 1.0,
#  ('ruptur', 'spiromet'): 1.0,
#  ('phlegm', 'signatur'): 1.0,
#  ('bair', 'vtach'): 1.0,
#  ('hemothorax', 'hive'): 0.0,
#  ('anaphylaxi', 'articul'): 1.0,
#  ('paperwork', 'xanax'): 1.0,
#  ('bottl', 'zoloft'): 1.0,
#  ('cash', 'osa'): 1.0,
#  ('pharyng', 'vallecula'): 1.0,
#  ('ambul', 'bair'): 0.0,
#  ('arrest', 'venti'): 1.0,
#  ('ppd', 'wallet'): 1.0,
#  ('appi', 'venti'): 1.0,
#  ('recalibr', 'video'): 1.0,
#  ('gabapentin', 'ultram'): 1.0,
#  ('clonidin', 'mellitu'): 1.0,
#  ('fliud', 'moan'): 0.0,
#  ('dnr', 'led'): 0.44994390669540907,
#  ('brb', 'tran'): 1.0,
#  ('hilum', 'tranfer'): 1.0,
#  ('pharmacolog', 'wish'): 1.0,
#  ('ambul', 'msicu'): 1.0,
#  ('adenosin', 'td'): 1.0,
#  ('asthma', 'ffp'): 1.0,
#  ('ambul', 'asthma'): 1.0,
#  ('aricept', 'distanc'): 1.0,
#  ('brb', 'clonazepam'): 1.0,
#  ('homogen', 'peribronchovascular'): 1.0,
#  ('breakfast', 'fax'): 1.0,
#  ('nifedipin', 'venti'): 1.0,
#  ('bromid', 'readmit'): 1.0,
#  ('lat', 'splint'): 1.0,
#  ('precordium', 'puff'): 1.0,
#  ('fu', 'incent'): 1.0,
#  ('neo', 'pleasant'): 1.0,
#  ('acidot', 'levoph'): 0.0,
#  ('dnr', 'grim'): 0.0,
#  ('incent', 'itchi'): 1.0,
#  ('robitussin', 'zyprexa'): 1.0,
#  ('cramp', 'ppd'): 0.0,
#  ('aliv', 'syncop'): 1.0,
#  ('ambien', 'neo'): 0.0,
#  ('hctz', 'splint'): 1.0,
#  ('fax', 'pleasant'): 1.0,
#  ('conc', 'prognosi'): 0.0,
#  ('epidur', 'neoplast'): 1.0,
#  ('arrest', 'hypercapnia'): 0.0,
#  ('ambien', 'commod'): 1.0,
#  ('captopril', 'pose'): 1.0,
#  ('occupi', 'seriou'): 1.0,
#  ('hilum', 'prilosec'): 1.0,
#  ('jewelri', 'xl'): 1.0,
#  ('nahco', 'prognosi'): 0.0,
#  ('dizzi', 'qam'): 1.0,
#  ('nectar', 'pleasantli'): 1.0,
#  ('cvvh', 'esld'): 0.0,
#  ('aaox', 'ipf'): 1.0,
#  ('aaox', 'redirect'): 1.0,
#  ('dni', 'unequ'): 1.0,
#  ('gait', 'paperwork'): 1.0,
#  ('flight', 'pleasantli'): 1.0,
#  ('purpl', 'ultram'): 1.0,
#  ('gastriti', 'pleasant'): 1.0,
#  ('mean', 'seat'): 1.0,
#  ('anuria', 'chair'): 1.0,
#  ('mtg', 'sibl'): 1.0,
#  ('dnr', 'thirst'): 1.0,
#  ('im', 'trazodon'): 1.0,
#  ('discard', 'levof'): 0.0,
#  ('oob', 'spiromet'): 1.0,
#  ('ciwa', 'cloth'): 1.0,
#  ('captopril', 'pod'): 1.0,
#  ('mva', 'panic'): 1.0,
#  ('para', 'vertebra'): 0.0,
#  ('gurgl', 'zyprexa'): 1.0,
#  ('adenocarcinoma', 'spfc'): 1.0,
#  ('foci', 'ligament'): 1.0,
#  ('cyanot', 'lw'): 0.0,
#  ('mrg', 'seroquel'): 1.0,
#  ('clinician', 'recruit'): 1.0,
#  ('acc', 'young'): 1.0,
#  ('cmo', 'icter'): 0.0,
#  ('asthma', 'soln'): 1.0,
#  ('incent', 'pinpoint'): 1.0,
#  ('cup', 'neutral'): 1.0,
#  ('death', 'dietari'): 1.0,
#  ('ppd', 'spacer'): 1.0,
#  ('eob', 'levoph'): 1.0,
#  ('bottl', 'crack'): 1.0,
#  ('neo', 'palli'): 0.0,
#  ('life', 'scopalamin'): 0.0,
#  ('metoclopramid', 'nitroglycerin'): 1.0,
#  ('dead', 'rehabilit'): 1.0,
#  ('hypotherm', 'normotherm'): 0.0,
#  ('neo', 'rabbi'): 0.0,
#  ('align', 'seroquel'): 0.0,
#  ('hilum', 'treitz'): 1.0,
#  ('hypothermia', 'pcv'): 0.0,
#  ('consciou', 'incis'): 1.0,
#  ('bipolar', 'proph'): 1.0,
#  ('commod', 'oob'): 0.7328479303551545,
#  ('deploy', 'postpylor'): 1.0,
#  ('cash', 'oob'): 1.0,
#  ('mrg', 'zoloft'): 1.0,
#  ('clergi', 'mtg'): 0.0,
#  ('aox', 'ruptur'): 1.0,
#  ('cracker', 'ferrou'): 1.0,
#  ('cash', 'hive'): 1.0,
#  ('dni', 'hypothermia'): 0.5404153697211024,
#  ('carvedilol', 'prilosec'): 1.0,
#  ('coach', 'puff'): 1.0,
#  ('cg', 'dnr'): 0.0,
#  ('hive', 'jewelri'): 1.0,
#  ('postop', 'readmit'): 1.0,
#  ('romi', 'weekli'): 1.0,
#  ('ctx', 'ultram'): 1.0,
#  ('^th', 'levoph'): 1.0,
#  ('acidot', 'lw'): 1.0,
#  ('angri', 'gabapentin'): 1.0,
#  ('norepinephrin', 'ultram'): 1.0,
#  ('agon', 'arrest'): 0.5,
#  ('fc', 'lusb'): 0.0,
#  ('hctz', 'oncologist'): 1.0,
#  ('cardiovert', 'neosynephrin'): 0.0,
#  ('contd', 'levoph'): 1.0,
#  ('declin', 'hypotherm'): 0.0,
#  ('dni', 'gabapentin'): 1.0,
#  ('unasyn', 'wish'): 1.0,
#  ('puff', 'xanax'): 1.0,
#  ('dnr', 'seroquel'): 0.7897870018672116,
#  ...}

# %%
# patient_dead_cooc_df
print(patient_cooc_0)
# Out:
# {111: {('arrest', 'pea'): 5.0, ('pea', 'vasopressin'): 4.0, ('arrest', 'vasopressin'): 4.0, ('cpr', 'vasopressin'): 4.0, ('cpr', 'pea'): 4.0, ('arrest', 'cpr'): 4.0, ('azotemia', 'cpr'): 2.0, ('azotemia', 'vasopressin'): 2.0, ('azotemia', 'pea'): 2.0, ('arrest', 'azotemia'): 2.0, ('azotemia', 'profound'): 1.0, ('azotemia', 'dic'): 2.0, ('cpr', 'dic'): 2.0, ('dic', 'vasopressin'): 2.0, ('dic', 'pea'): 2.0, ('arrest', 'dic'): 2.0, ('dic', 'profound'): 1.0, ('dic', 'hypercapnia'): 2.0, ('azotemia', 'hypercapnia'): 2.0, ('cpr', 'hypercapnia'): 2.0, ('hypercapnia', 'vasopressin'): 2.0, ('hypercapnia', 'pea'): 2.0, ('arrest', 'hypercapnia'): 2.0, ('hypercapnia', 'profound'): 1.0, ('hypercapnia', 'hypothermia'): 2.0, ('dic', 'hypothermia'): 2.0, ('azotemia', 'hypothermia'): 2.0, ('cpr', 'hypothermia'): 2.0, ('hypothermia', 'vasopressin'): 2.0, ('hypothermia', 'pea'): 2.0, ('arrest', 'hypothermia'): 2.0, ('hypothermia', 'profound'): 1.0, ('hypothermia', 'phenylephrin'): 2.0, ('hypercapnia', 'phenylephrin'): 2.0, ('dic', 'phenylephrin'): 2.0, ('azotemia', 'phenylephrin'): 2.0, ('cpr', 'phenylephrin'): 2.0, ('phenylephrin', 'vasopressin'): 2.0, ('pea', 'phenylephrin'): 2.0, ('arrest', 'phenylephrin'): 2.0, ('phenylephrin', 'profound'): 1.0, ('bicarbon', 'phenylephrin'): 2.0, ('bicarbon', 'hypothermia'): 2.0, ('bicarbon', 'hypercapnia'): 2.0, ('bicarbon', 'dic'): 2.0, ('azotemia', 'bicarbon'): 2.0, ('bicarbon', 'cpr'): 2.0, ('bicarbon', 'vasopressin'): 2.0, ('bicarbon', 'pea'): 2.0, ('arrest', 'bicarbon'): 2.0, ('bicarbon', 'profound'): 1.0, ('autopeep', 'bicarbon'): 2.0, ('autopeep', 'phenylephrin'): 2.0, ('autopeep', 'hypothermia'): 2.0, ('autopeep', 'hypercapnia'): 2.0, ('autopeep', 'dic'): 2.0, ('autopeep', 'azotemia'): 2.0, ('autopeep', 'cpr'): 2.0, ('autopeep', 'vasopressin'): 2.0, ('autopeep', 'pea'): 2.0, ('arrest', 'autopeep'): 2.0, ('autopeep', 'profound'): 1.0, ('autopeep', 'paralyt'): 2.0, ('bicarbon', 'paralyt'): 2.0, ('paralyt', 'phenylephrin'): 2.0, ('hypothermia', 'paralyt'): 2.0, ('hypercapnia', 'paralyt'): 2.0, ('dic', 'paralyt'): 2.0, ('azotemia', 'paralyt'): 2.0, ('cpr', 'paralyt'): 2.0, ('paralyt', 'vasopressin'): 2.0, ('paralyt', 'pea'): 2.0, ('arrest', 'paralyt'): 2.0, ('paralyt', 'profound'): 1.0, ('paralyt', 'pcv'): 2.0, ('autopeep', 'pcv'): 2.0, ('bicarbon', 'pcv'): 2.0, ('pcv', 'phenylephrin'): 2.0, ('hypothermia', 'pcv'): 2.0, ('hypercapnia', 'pcv'): 2.0, ('dic', 'pcv'): 2.0, ('azotemia', 'pcv'): 2.0, ('cpr', 'pcv'): 2.0, ('pcv', 'vasopressin'): 2.0, ('pcv', 'pea'): 2.0, ('arrest', 'pcv'): 2.0, ('pcv', 'profound'): 1.0, ('norepinephrin', 'pcv'): 2.0, ('norepinephrin', 'paralyt'): 2.0, ('autopeep', 'norepinephrin'): 2.0, ('bicarbon', 'norepinephrin'): 2.0, ('norepinephrin', 'phenylephrin'): 2.0, ('hypothermia', 'norepinephrin'): 2.0, ('hypercapnia', 'norepinephrin'): 2.0, ('dic', 'norepinephrin'): 2.0, ('azotemia', 'norepinephrin'): 2.0, ('cpr', 'norepinephrin'): 2.0, ('norepinephrin', 'vasopressin'): 2.0, ('norepinephrin', 'pea'): 2.0, ('arrest', 'norepinephrin'): 2.0, ('norepinephrin', 'profound'): 1.0, ('arrest', 'death'): 3.0, ('cpr', 'death'): 2.0, ('death', 'vasopressin'): 2.0, ('death', 'pea'): 2.0, ('clinician', 'death'): 2.0, ('clinician', 'cpr'): 2.0, ('clinician', 'vasopressin'): 2.0, ('clinician', 'pea'): 2.0, ('arrest', 'clinician'): 2.0, ('clinician', 'expir'): 1.0, ('clinician', 'profound'): 1.0, ('asystol', 'clinician'): 1.0, ('asystol', 'death'): 1.0, ('asystol', 'cpr'): 1.0, ('asystol', 'vasopressin'): 1.0, ('asystol', 'pea'): 1.0, ('arrest', 'asystol'): 1.0, ('asystol', 'levoph'): 1.0, ('clinician', 'levoph'): 1.0, ('death', 'levoph'): 1.0, ('cpr', 'levoph'): 1.0, ('levoph', 'vasopressin'): 1.0, ('levoph', 'pea'): 1.0, ('arrest', 'levoph'): 1.0, ('levoph', 'neosynephrin'): 1.0, ('asystol', 'neosynephrin'): 1.0, ('clinician', 'neosynephrin'): 1.0, ('death', 'neosynephrin'): 1.0, ('cpr', 'neosynephrin'): 1.0, ('neosynephrin', 'vasopressin'): 1.0, ('neosynephrin', 'pea'): 1.0, ('arrest', 'neosyn ...

# %%
print(patient_node_0)
# Out:
# {111: {'arrest': 6.0, 'pea': 5.0, 'precordium': 1.0, 'vasopressin': 4.0, 'cpr': 4.0, 'azotemia': 2.0, 'dic': 2.0, 'hypercapnia': 2.0, 'hypothermia': 2.0, 'phenylephrin': 2.0, 'bicarbon': 2.0, 'autopeep': 2.0, 'paralyt': 2.0, 'pcv': 2.0, 'norepinephrin': 2.0, 'death': 3.0, 'clinician': 2.0, 'asystol': 1.0, 'levoph': 1.0, 'neosynephrin': 1.0, 'profound': 2.0, 'anur': 1.0, 'mottl': 1.0, 'recruit': 1.0, 'refractori': 1.0, 'expir': 2.0, 'cremat': 1.0, 'clergi': 1.0, 'arrang': 1.0, 'elig': 1.0, 'funer': 1.0, 'suffer': 1.0, 'park': 1.0, 'hypercapn': 1.0, 'acidem': 1.0}, 346: {'arrest': 4.0, 'ruptur': 2.0, 'sluggish': 6.0, 'dnr': 2.0, 'cmo': 2.0}, 404: {'paco': 1.0, 'death': 1.0}, 546: {'oder': 1.0, 'hurt': 1.0, 'historian': 1.0}, 618: {'lat': 1.0, 'readmit': 1.0, 'video': 2.0, 'vallecula': 1.0, 'spill': 1.0, 'nectar': 1.0, 'laryng': 1.0, 'cooki': 1.0, 'barium': 1.0, 'vtach': 1.0, 'aaox': 1.0, 'float': 1.0, 'foci': 1.0}, 705: {'dnr': 5.0, 'dni': 2.0, 'cmo': 5.0, 'mso': 2.0, 'wish': 1.0, 'levoph': 1.0, 'clariti': 1.0, 'expir': 1.0}, 726: {'levoph': 2.0, 'arrest': 2.0, 'mso': 3.0, 'dnr': 3.0}, 1039: {'wish': 4.0}, 1556: {'mso': 13.0, 'dnr': 8.0, 'dni': 8.0, 'wish': 2.0, 'duski': 2.0, 'chip': 2.0}, 1872: {'pronounc': 1.0}, 1944: {'arrest': 4.0, 'cvvhd': 5.0, 'lift': 3.0}, 2286: {'cyanot': 17.0, 'vasopressin': 14.0, 'levoph': 8.0, 'dnr': 7.0, 'ffp': 5.0, 'prognosi': 7.0, 'purpl': 10.0, 'mottl': 7.0, 'levof': 6.0, 'lc': 5.0, 'pitressin': 15.0, 'incis': 10.0, 'anur': 9.0, 'lw': 5.0, 'ethic': 6.0, 'cvvh': 9.0, 'brb': 5.0, 'hugger': 7.0, 'bair': 7.0}, 2990: {'chair': 17.0, 'oob': 17.0, 'levoph': 31.0, 'anur': 24.0, 'pcv': 11.0}, 3055: {'gc': 3.0, 'wish': 3.0, 'cmo': 4.0}, 3099: {'neo': 2.0, 'neosynephrin': 2.0, 'dopamin': 1.0, 'ffp': 2.0, 'vasopressin': 1.0, 'levoph': 1.0, 'hypotherm': 1.0, 'hung': 1.0, 'dic': 1.0, 'cagluc': 1.0, 'suport': 1.0, 'polici': 1.0, 'ethic': 1.0, 'cpr': 1.0}, 3201: {'sluggish': 3.0, 'dopamin': 3.0, 'norepinephrin': 1.0, 'levoph': 1.0, 'unavail': 1.0, 'neo': 2.0, 'pitressin': 1.0, 'vasopressin': 1.0, 'unequ': 1.0, 'pronounc': 1.0, 'nahco': 1.0, 'mortem': 1.0, 'levof': 1.0, 'expir': 1.0, 'cpr': 1.0}, 3526: {'levoph': 2.0, 'dnr': 2.0, 'dni': 2.0, 'laryng': 1.0, 'pronounc': 1.0, 'mso': 1.0, 'jerk': 1.0, 'intiat': 1.0, 'declin': 1.0, 'death': 1.0, 'agon': 1.0}, 3773: {'plate': 1.0, 'mso': 2.0, 'escal': 1.0, 'dopamin': 1.0, 'dnr': 1.0, 'dni': 1.0, 'cmo': 1.0, 'pronounc': 1.0, 'death': 1.0}, 3881: {'dnr': 3.0, 'dni': 3.0, 'cmo': 3.0, 'moan': 2.0, 'sluggish': 2.0}, 4122: {}, 4754: {'levoph': 11.0, 'dobutamin': 10.0, 'captopril': 17.0, 'purpl': 7.0}, 4811: {'life': 2.0, 'dnr': 2.0, 'dni': 2.0, 'hospic': 2.0}, 5476: {}, 5494: {'dnr': 2.0, 'dni': 2.0, 'vasopressor': 1.0, 'cooler': 1.0, 'wish': 2.0, 'quadrent': 1.0, 'cyanot': 1.0, 'escal': 2.0, 'peerla': 1.0, 'hospic': 1.0, 'deterior': 1.0, 'edt': 1.0, 'video': 2.0, 'nectar': 1.0}, 5774: {'cardiovert': 7.0, 'levoph': 13.0, 'neo': 11.0, 'gum': 6.0, 'crrt': 6.0, 'cvvhd': 11.0, 'vasopressin': 6.0, 'sluggish': 9.0, 'gvhd': 6.0, 'pneumococc': 13.0, 'hugger': 12.0, 'bair': 6.0, 'cpr': 12.0}, 5786: {'dobutamin': 9.0, 'triadyn': 7.0, 'pcv': 6.0, 'caspofungin': 6.0}, 5913: {}, 6133: {'incis': 5.0, 'neo': 5.0, 'lc': 6.0}, 6735: {'arrest': 1.0, 'prognosi': 3.0, 'dopamin': 3.0, 'mottl': 2.0, 'asystol': 1.0, 'nahco': 1.0, 'agon': 1.0, 'mso': 2.0, 'levoph': 2.0, 'cpr': 2.0, 'cyanot': 1.0, 'ffp': 1.0, 'mail': 1.0, 'grave': 2.0, 'anur': 1.0, 'bottl': 1.0, 'corneal': 1.0, 'vasopressor': 1.0, 'nonreact': 1.0, 'twitch': 1.0, 'cmo': 1.0, 'vasopressin': 1.0, 'griev': 1.0, 'rememb': 1.0, 'chb': 1.0}, 6745: {'dnr': 4.0, 'dni': 4.0, 'mso': 2.0, 'wish': 1.0, 'heroic': 1.0, 'rabbi': 1.0, 'profound': 1.0, 'moan': 1.0}, 6973: {'venti': 2.0, 'declin': 2.0, 'pleasant': 2.0, 'dnr': 3.0, 'dni': 3.0, 'bank': 2.0, 'nonrebreath': 2.0}, 6981: {'lat': 1.0, 'occupi': 1.0, 'dnr': 2.0, 'dni': 2.0, 'pleuravac': 1.0, 'priest': 1.0}, 7277: {'neo': 6.0, 'mso': 14.0}, 7310: {'hospic': 3.0, 'dnr': 3.0, 'dni': 3.0, 'nonrebr ...

# %%
# Check if all nodes has embeddings
patient_node_set = set()
patient_node_0_dict = {}
patient_node_1_dict = {}
    
for k, v in patient_node_0.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_0_dict:
            patient_node_0_dict[item] = v[item]
        else:
            patient_node_0_dict[item] = patient_node_0_dict[item] + v[item]
        
    
for k, v in patient_node_1.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_1_dict:
            patient_node_1_dict[item] = v[item]
        else:
            patient_node_1_dict[item] = patient_node_1_dict[item] + v[item]

# %%
print(len(patient_node_set))
print(len(patient_node_0_dict))
print(len(patient_node_1_dict))
# Out:
# 705
# 498
# 648

# %%
patient_node_odd_scores = {}

for set_item in patient_node_set:
    if set_item in patient_node_0_dict and set_item in patient_node_1_dict:
        d_prob = patient_node_0_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        a_prob = patient_node_1_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_node_odd_scores[set_item] = log_odd_score

# %%
print(patient_node_odd_scores)
# Out:
# {'pleasant': 2.938925682595307, 'priest': -3.0693478748272645, 'ardsnet': 0.6203660925382052, 'clinician': 0.550909995900324, 'morbid': 6.90875477931522, 'xl': 1.969020421268059, 'unsteadi': 6.90875477931522, 'doen': -6.90875477931522, 'permiss': -2.387057016415087, 'fdp': 0.17150555668934245, 'plat': 0.9141958635336067, 'rhochor': -1.604655121332035, 'harm': 6.90875477931522, 'sluggishli': -0.8734901684270467, 'declar': -6.90875477931522, 'stood': 6.90875477931522, 'aox': 2.1362040798195827, 'ration': 6.90875477931522, 'moan': 0.8453976222857142, 'nitroglycerin': 3.1942475376942854, 'pneumococc': 0.910426054828574, "sxn'ing": 6.90875477931522, 'pea': 1.242916320903325, 'opiat': 1.4022741716305158, 'captopril': 3.013615327318743, 'seroquel': 5.822640501584422, 'inhibit': 6.90875477931522, 'angioplasti': 6.90875477931522, 'sluggish': 0.6311744306487658, 'neo': 0.32885950730718444, 'hung': -0.2870999276476155, 'qam': 3.434299431289231, 'autopeep': -6.90875477931522, 'exophyt': 1.2495579516853903, 'kyphoscoliosi': -0.4046335072286383, 'mood': 6.90875477931522, 'suffer': 1.5505353776716928, 'zero': 6.90875477931522, 'aprv': -6.90875477931522, 'effac': 3.02380801661965, 'tie': 6.90875477931522, 'park': 0.0, 'subq': 6.90875477931522, 'foci': 1.5108116143566748, 'align': 1.9029698713994425, 'crack': 6.90875477931522, 'uncoop': 6.90875477931522, 'rm': 1.7522526603261124, 'angiogram': 2.7567935411197357, 'puff': 6.90875477931522, 'lc': -1.0271828417136022, 'barium': 3.1844412998697607, 'deflat': 6.90875477931522, 'calmer': 6.90875477931522, 'pleuravac': -6.90875477931522, 'reappear': 6.90875477931522, 'ggt': 0.9141958635336067, 'recruit': 2.0577318106732485, 'osteoblast': -1.095952712632351, 'knew': 6.90875477931522, 'hiccup': 1.775542362071692, 'mean': 1.451248012080289, 'osa': 2.8667403184631204, 'option': -1.0071107915651871, 'distort': 3.0693478748272645, 'vigileo': 0.0, 'polici': -6.90875477931522, 'pulseless': -0.7151219590646479, 'hunger': -1.5360079185039965, 'cg': -6.90875477931522, 'freeli': 3.338770975794994, 'stack': -6.90875477931522, 'unalt': 2.2927445483990123, 'spur': 2.387057016415087, 'nectar': 3.5588781367463964, 'angri': 6.90875477931522, 'pod': 6.90875477931522, 'pneumothorac': 1.0434802179733935, 'gum': 1.3401731317586105, 'crrt': 0.3047626159366483, 'famil': 0.6916505477038827, 'eyelid': -6.90875477931522, 'seat': 1.7522526603261124, 'yel': 6.90875477931522, 'core': 1.3825560390092835, 'echocardiogram': 0.7003623951165779, 'burn': 0.99618891094063, 'maroon': 0.0, 'nice': 6.90875477931522, 'azotemia': 0.17657571316704399, 'zyprexa': 3.1394903406223924, 'cloth': 2.7567935411197357, 'spfc': 2.1883847407670785, 'vagu': 2.714892378932811, 'metoclopramid': 6.90875477931522, 'discard': 0.0, 'pose': 0.6916505477038827, 'intent': 6.90875477931522, 'tremul': 6.90875477931522, 'liw': -0.6916505477038827, 'heliox': -6.90875477931522, 'pray': 6.90875477931522, 'centimet': 0.9141958635336067, 'macu': 0.28709992764761555, 'lymphangit': 1.4174966125472825, 'probe': 6.90875477931522, 'cramp': 2.6710997456326173, 'moreov': 0.0, 'dead': -0.3178073296807483, 'depth': 6.90875477931522, 'gotten': 6.90875477931522, 'underpenetr': 0.9533015672059649, 'tranfer': 6.90875477931522, 'robitussin': 0.809128888289493, 'sml': 0.28709992764761555, 'prayer': -6.90875477931522, 'hospic': 0.07395991702210732, 'bairhugg': 6.90875477931522, 'bank': 1.8906318970131915, 'refractori': 3.8042847712588044, 'antb': 6.90875477931522, 'inspit': 6.90875477931522, 'stg': 0.8248347128488595, 'abnl': 2.224418442526018, 'contractur': 3.3553795061977376, 'pronounc': 1.1450568570896096, 'plate': 2.5264781167542063, 'gasp': -6.90875477931522, 'impli': 0.6916505477038827, 'norepinephrin': -0.43242991070027637, 'pvr': -2.1120928625609148, 'buck': 6.90875477931522, 'arthrit': 6.90875477931522, 'nacl': 1.2495579516853903, 'gc': 1.9390841839849136, 'sensat': 2.8378811669427866, 'emper': 6.90875477931522, 'thirst': 1.442917247910699, 'postpylor': 6.90875477931522, 'cisatr ...

# %%
patient_square_node_data = pd.DataFrame({'node':list(patient_node_odd_scores.keys()), 'feature':list(patient_node_odd_scores.values())})
patient_square_node_data
# Out:
#           node   feature
# 0     pleasant  2.938926
# 1       priest -3.069348
# 2      ardsnet  0.620366
# 3    clinician  0.550910
# 4       morbid  6.908755
# ..         ...       ...
# 700        chb  0.576098
# 701     splint  6.908755
# 702      bottl  0.829441
# 703      escal  0.206077
# 704        bsn  6.908755
#
# [705 rows x 2 columns]

# %%
patient_square_node_id_data = patient_square_node_data.set_index("node")
patient_square_node_id_data['subject'] = ["positive" if r['feature'] > 0 else "negative" for i, r in patient_square_node_id_data.iterrows()]
patient_square_node_id_data
# Out:
#             feature   subject
# node
# pleasant   2.938926  positive
# priest    -3.069348  negative
# ardsnet    0.620366  positive
# clinician  0.550910  positive
# morbid     6.908755  positive
# ...             ...       ...
# chb        0.576098  positive
# splint     6.908755  positive
# bottl      0.829441  positive
# escal      0.206077  positive
# bsn        6.908755  positive
#
# [705 rows x 2 columns]

# %%
patient_subjects = patient_square_node_id_data["subject"]
patient_subjects
# Out:
# node
# pleasant     positive
# priest       negative
# ardsnet      positive
# clinician    positive
# morbid       positive
#                ...
# chb          positive
# splint       positive
# bottl        positive
# escal        positive
# bsn          positive
# Name: subject, Length: 705, dtype: object

# %%
patient_square_node_data_no_feature = patient_square_node_id_data.drop(columns=["feature","subject"])
patient_square_node_data_no_feature
# Out:
# Empty DataFrame
# Columns: []
# Index: [pleasant, priest, ardsnet, clinician, morbid, xl, unsteadi, doen, permiss, fdp, plat, rhochor, harm, sluggishli, declar, stood, aox, ration, moan, nitroglycerin, pneumococc, sxn'ing, pea, opiat, captopril, seroquel, inhibit, angioplasti, sluggish, neo, hung, qam, autopeep, exophyt, kyphoscoliosi, mood, suffer, zero, aprv, effac, tie, park, subq, foci, align, crack, uncoop, rm, angiogram, puff, lc, barium, deflat, calmer, pleuravac, reappear, ggt, recruit, osteoblast, knew, hiccup, mean, osa, option, distort, vigileo, polici, pulseless, hunger, cg, freeli, stack, unalt, spur, nectar, angri, pod, pneumothorac, gum, crrt, famil, eyelid, seat, yel, core, echocardiogram, burn, maroon, nice, azotemia, zyprexa, cloth, spfc, vagu, metoclopramid, discard, pose, intent, tremul, liw, ...]
#
# [705 rows x 0 columns]

# %%
from sklearn.manifold import TSNE
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
from gensim.models import Word2Vec

# %% [markdown]
# ### Create a bi-directional df

# %%
# with edge weight
bidirect_source = []
bidirect_target = []
edge_weight = []

for item, val in new_patient_cooc_odd_scores.items():
    bidirect_source.extend([item[0], item[1]])
    bidirect_target.extend([item[1], item[0]])
    edge_weight.extend([val, val])
    
print(f"source: {len(bidirect_source)}, target: {len(bidirect_target)}")

weighted_patient_bidirect_square_edge_data = pd.DataFrame(
    {
        "source": bidirect_source,
        "target": bidirect_target,
        "weight": edge_weight,
    })
weighted_patient_bidirect_square_edge_data
# Out:
# source: 22366, target: 22366
#              source        target  weight
# 0        fibrinogen          mean     1.0
# 1              mean    fibrinogen     1.0
# 2        gabapentin      gastriti     1.0
# 3          gastriti    gabapentin     1.0
# 4            postop          scar     1.0
# ...             ...           ...     ...
# 22361           xii      artifici     1.0
# 22362  phenylephrin       synthet     0.0
# 22363       synthet  phenylephrin     0.0
# 22364          anur        oligur     0.0
# 22365        oligur          anur     0.0
#
# [22366 rows x 3 columns]

# %%
# Weighted
G_weighted_patient_bidirect = StellarGraph(
    {"corner": patient_square_node_data_no_feature}, {"line": weighted_patient_bidirect_square_edge_data}
)
print(G_weighted_patient_bidirect.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 705, Edges: 22366
#
#  Node types:
#   corner: [705]
#     Features: none
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [22366]
#         Weights: range=[0, 1], mean=0.723306, std=0.428236
#         Features: none

# %%
# Weighted
rw_weighted_patient_bidirect = BiasedRandomWalk(G_weighted_patient_bidirect)

# %%
# Weighted
weighted_walks_patient_bidirect = rw_weighted_patient_bidirect.run(
    nodes=G_weighted_patient_bidirect.nodes(),  # root nodes
    length=100,  # maximum length of a random walk
    n=10,  # number of random walks per root node
    p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
    q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
    weighted=True,  # for weighted random walks
    seed=42,  # random seed fixed for reproducibility
)
print("Number of random walks: {}".format(len(weighted_walks_patient_bidirect)))
# Out:
# Number of random walks: 7050

# %%
print(weighted_walks_patient_bidirect[0])
# Out:
# ['pleasant', 'msicu', 'ambul', 'levoph', 'triadyn', 'levoph', 'trazodon', 'osa', 'incis', 'soln', 'motor', 'mellitu', 'ggo', 'mellitu', 'predict', 'dizzi', 'cdb', 'dnr', 'asthma', 'stair', 'asthma', 'prilosec', 'dead', 'paperwork', 'mind', 'paperwork', 'xii', 'hctz', 'xii', 'puff', 'azotemia', 'sibl', 'dnr', 'appi', 'death', 'appi', 'dni', 'waist', 'dnr', 'chip', 'hook', 'rhochor', 'chip', 'readmit', 'rpr', 'levoph', 'rpr', 'platelet', 'ambien', 'hive', 'postop', 'zoloft', 'hctz', 'oncologist', 'money', 'palli', 'signatur', 'young', 'ctx', 'osa', 'unstabl', 'dizzi', 'gait', 'diaper', 'oob', 'probe', 'jewelri', 'probe', 'gait', 'ambien', 'nocturn', 'thiamin', 'ctx', 'neoplast', 'palli', 'dnr', 'dyslipidemia', 'cloth', 'money', 'cloth', 'dyslipidemia', 'asthma', 'phlegm', 'jewelri', 'aliv', 'scar', 'gait', 'influenc', 'pleasantli', 'bank', 'fax', 'ambul', 'bottl', 'fibrinogen', 'azotemia', 'seroquel', 'cvvh', 'synthet', 'bill', 'crrt']

# %%
# Weighted
weighted_model_patient = Word2Vec(
    weighted_walks_patient_bidirect, size=128, window=5, min_count=0, sg=1, workers=4, iter=1
)

# %%
# Weighted
emb = weighted_model_patient.wv["cmo"]
emb
# Out:
# array([ 6.54290468e-02,  9.95246023e-02,  1.40479937e-01,  1.89646840e-01,
#         1.99213117e-01, -1.73435003e-01, -3.07834923e-01, -1.32280216e-01,
#         8.10530707e-02,  3.18686187e-01,  3.98649067e-01,  7.50897676e-02,
#        -8.19182694e-02, -6.65437058e-02, -2.33812779e-01, -5.04806591e-03,
#        -6.39941194e-04,  3.98906231e-01,  7.37207234e-02, -2.93873519e-01,
#         1.04639553e-01,  3.48409027e-01, -2.58163154e-01,  2.47938320e-01,
#         3.52980345e-02, -1.54357895e-01, -2.85563797e-01,  2.91159421e-01,
#        -3.23553458e-02, -1.52166188e-01, -1.59802169e-01,  3.14140208e-02,
#        -9.51338410e-02,  1.40077267e-02, -1.65999651e-01, -7.69640729e-02,
#        -2.65287012e-01,  3.93515855e-01, -2.11960495e-01,  1.02740742e-01,
#        -1.41596720e-01,  4.40558910e-01,  2.53099412e-01, -1.13663383e-01,
#         7.04936311e-02,  1.55011743e-01,  1.55317709e-01, -2.44399488e-01,
#         7.79144466e-02, -3.04230750e-01,  5.90023398e-02,  1.93022281e-01,
#         2.39053711e-01, -3.28145504e-01, -3.59908678e-02,  9.56901088e-02,
#        -1.23378746e-01,  1.59220934e-01,  4.38835509e-02,  2.08328590e-01,
#        -1.78010419e-01,  4.24249381e-01,  3.07501882e-01,  5.47437906e-01,
#        -4.25021648e-01,  8.91756192e-02, -5.57858706e-01, -1.02691472e-01,
#         1.69602767e-01, -1.70778438e-01, -9.13983285e-02,  4.83678609e-01,
#        -4.54654604e-01, -1.23931706e-01,  2.51197778e-02,  1.17705837e-01,
#        -1.51261345e-01,  2.56750703e-01, -1.16323628e-01,  1.88884530e-02,
#        -1.68629333e-01, -1.62181139e-01, -1.71268255e-01,  8.72598439e-02,
#         5.35859838e-02, -3.28095220e-02, -1.31084487e-01,  2.57306486e-01,
#         5.41706663e-03,  5.68642579e-02,  6.67681471e-02, -3.88394557e-02,
#         1.11047395e-01, -5.32249689e-01, -4.72582996e-01, -3.33158016e-01,
#         1.28506944e-01, -1.79394156e-01,  2.62659222e-01,  2.28215605e-01,
#        -2.65043199e-01, -3.64128686e-02,  7.09201172e-02, -8.66929721e-03,
#        -2.36167952e-01,  4.20745581e-01,  1.22224689e-01, -5.00988960e-01,
#        -3.32882166e-01, -1.80872470e-01,  2.12909862e-01, -2.64610887e-01,
#        -1.57814380e-02,  6.37475848e-01, -1.53433114e-01, -1.08052239e-01,
#         1.64193258e-01,  6.75516054e-02, -3.33346315e-02, -2.07813844e-01,
#        -3.07386369e-01,  2.23399818e-01,  4.06433880e-01,  6.80263281e-01,
#        -2.19024047e-02, -3.32088917e-02, -2.73123056e-01,  2.49452576e-01],
#       dtype=float32)

# %% [markdown]
# ### Visualise Node Embeddings generated by weighted random walks

# %% [markdown]
# ### Weighted edges

# %%
# Retrieve node embeddings and corresponding subjects
patient_weighted_node_ids = weighted_model_patient.wv.index2word  # list of node IDs
patient_weighted_node_embeddings = (
    weighted_model_patient.wv.vectors
)  # numpy.ndarray of size number of nodes times embeddings dimensionality
# the gensim ordering may not match the StellarGraph one, so rearrange
patient_node_targets = patient_subjects.loc[patient_weighted_node_ids].astype("category")

# %%
# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2, random_state=42)
patient_weighted_node_embeddings_2d = tsne.fit_transform(patient_weighted_node_embeddings)

# %%
# draw the points
alpha = 0.7

plt.figure(figsize=(10, 8))
plt.scatter(
    patient_weighted_node_embeddings_2d[:, 0],
    patient_weighted_node_embeddings_2d[:, 1],
    c=patient_node_targets.cat.codes,
    cmap="jet",
    alpha=0.7,
)
plt.show()

# %%
patient_weighted_node_emb_dict = {}
for index, row in patient_square_node_data_no_feature.iterrows():
    if index not in patient_weighted_node_emb_dict:
        patient_weighted_node_emb_dict[index] = weighted_model_patient.wv[index]
    else:
        print(f"index: {index} is already in a dictionary!")

# %%
# print(type(patient_weighted_node_emb_dict['aprv']))

# %%
import pandas as pd
import numpy as np

import stellargraph as sg
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import GCNSupervisedGraphClassification
from stellargraph import StellarGraph

from stellargraph import datasets

from sklearn import model_selection
from IPython.display import display, HTML

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import matplotlib.pyplot as plt

seed = 42
numpy.random.seed(seed)
tf.random.set_seed(seed)
sg.random.set_seed(seed)

# %% [markdown]
# ### Load the data

# %%
from collections import defaultdict

def create_graph_list(patient_cooc_dict, cooc_odd_scores, node_emb_dict, label):
    
    graphs = []
    labels = []
    
    for key,row in patient_cooc_dict.items():
     
        if row:
            source = []
            target = []
            edge_weight = []
            
            node_feature = []
            node_idx = []
            for cooc in row:
                source.extend([cooc[0], cooc[1]])
                target.extend([cooc[1], cooc[0]])
                edge_weight.extend([cooc_odd_scores[cooc], cooc_odd_scores[cooc]])
        
            node_idx = list(set(source + target))
    
            # Create a dataframe of only nodes
            square_node_data = pd.DataFrame(
                index=node_idx)
            
#             square_node_data['feature'] = [1] * len(node_idx)
        
            # Create a dictionary for each column for a vector
            node_features = defaultdict(list)
            for node in node_idx:
                for i, vec in enumerate(node_emb_dict[node]):
                    node_features['w_' + str(i)].append(vec)
        
            # Add columns to a dataframe
            for k, v in node_features.items():
              
                square_node_data[k] = v

            square_edges = pd.DataFrame({ 
                "source": source, 
                "target": target, 
                "weight":edge_weight
            })
        
            square = StellarGraph({"corner": square_node_data}, {"line": square_edges})
            graphs.append(square)
            labels.append(label)
            
    return graphs, labels

graphs = []
labels = []

# patient_weighted_node_emb_dict
graph_0, label_0 = create_graph_list(patient_cooc_0, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, -1)
graph_1, label_1 = create_graph_list(patient_cooc_1, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, 1)

graphs.extend(graph_0)
labels.extend(label_0)
print(f"graphs_0: {len(graphs)}, labels_0: {len(labels)}")
graphs.extend(graph_1)
labels.extend(label_1)
print(f"graphs_1: {len(graph_1)}, labels_1: {len(label_1)}")
print(f"graphs: {len(graphs)}, labels: {len(labels)}")
# Out:
# graphs_0: 191, labels_0: 191
# graphs_1: 846, labels_1: 846
# graphs: 1037, labels: 1037

# %%
# prepare test and train datasets
test_cnt = int(len(graphs)*0.1)/2
print(test_cnt)

pos_start = len(graph_0)
print(pos_start)

test_arr = []
train_arr = []
for i, v in enumerate(graphs):
    # Take first items for neg set
    if i < test_cnt:
        test_arr.append(i)    
    elif i > pos_start and i <= pos_start + test_cnt:
        test_arr.append(i)    
    else:
        train_arr.append(i)
# Out:
# 51.5
# 191

# %%
import random
seed = 42
c = list(test_arr)
random.Random(seed).shuffle(c)
test_arr =  c

# %%
c = list(train_arr)
random.Random(seed).shuffle(c)
train_arr =  c

# %%
train_index = np.array(train_arr)
test_index = np.array(test_arr)

# %%
print(len(test_index))
print(test_index)
# Out:
# 103
# [ 41 218 222   9 207  47   1 212  15 220 198  10  45  33 196  37  50  32
#  206  44  30 205   8  21 195 237 229  42 203  26 219 192 235  49 201 214
#   48 216 241 199 227  12  36  23  39  40  18 208   5 202   7  34 223  46
#    2  51  16  38 200 210  22   6  24 225 233 242 224  19 213  43 228  20
#    0 238 197 236 193 231  25 211 232 217 204  29  27 230 240   4 194 215
#   11 209 226  13 239  17  28  31  35 234   3  14 221]

# %%
print(len(train_index))
print(train_index)
# Out:
# 934
# [ 846  787  715  547  401  101  814  105  530  342   90  616  350  330
#   932  695  729  730  820  912  671  610  938  933  292  464  304  561
#   635  280  414  855  744  684  558   70  937  714  805  740  494  779
#   392  815  944  803  478  283  528   68  253  747  663  976  698  577
#   303  475  421  843  742  136  969  980  987  692  281   80  776  854
#   825  986  888  979  852  335  525  596  676  798   76  712   53  559
#   301  685  578  553   85  520  526  252  534  390  741  630  847  881
#   137  275  775  921  484  844  887  951  919  647  365  488  950  467
#   640  531 1006 1025  277  393  405  507  385  636  402  483  794  524
#   883  628  708  934 1033  144  162  436  430  296  737  819  181  711
#   963  872  352  140  925  822 1018  859   78  407  522  102  830  760
#   250  566  487  251 1012  763  501  974  927  461  504  631  826  324
#   552  943   81  816  584  458  113 1032  770   57  890  588  334  457
#   287   69  946  918  468   65  190   56  382  634  116  961  354  960
#   909  633  367  305  546  416  869  924  118  432  959  375   86  848
#   500  611  428  651  247  517  495  998  564  642  885  171  533   94
#   288  967  592  276  380  496  731  783  339  748  690  404  419  108
#   332  688  569  641  291  294  697  477  316  359  396  509  423  295
#   128  456  344  627  675  982   62  302  472  157   83  678  453  971
#   590  908  777  469  130  489  650  618  657   93  877  439  191  437
#   704   91  784  243  767  764  594  886  178  184  792  429  602 1030
#   463  662  361 1028  265  593  660  411  120  866  703 1026  739 1034
#   340  368  585  997  907  106  718  433  176  682  793  966  858  397
#   315  957   89  415  773  177   75  926  664  153  167  537  172   99
#   274  812  427  366  248   95  604  138  728  754  808  448  599  329
#   953  267  438  570  955  871  605  901  258  734  383  310  257  895
#   418 1022  800  709 1013  639  735  612  906  905  459  309  930  896
#   597  710  362  256  499  115  442  750  939  529  443  538  613  609
#   733  446  574  945  471  680  378  369  832  514  863   74  182  149
#   398  300  527  364  413 1024  263  505  947  279 1021  975  560  557
#   659  400  575  625 1002   66  810  913  781  891  363  431  699  539
#   498   87  899  720  307  150  440  586  619  168  606  755  837  282
#   786  521  811  165  689  542  828  549  298  935  462  506  954  188
#   598  607  479  583  445  722  313  503  727  480  143   64  314  554
#   142  518  512  940  545  173  579  738  131  486  420  637  550  840
#   389  717  284  796  626  972  452  159  286  988   72  543  725  510
#   580  563  289  260  942  791  989  254  769   88  255  965  827  667
#   540  555  835  371  185  444  851   97  386  870  985  104  893  829
#  1014  645  311  454  318  391  381  990  161  170  978  189  158  409
#    60  868  412  797  785  394  481 1000  691  460  864  674  621  723
#   653  127  154  902   61  126  679  571  410  186  904  831  347  702
#   312  370  915  638  681 1005  135   92  898  686  174  516  343  813
#   994  293  134  623  892  853  833  617  591  732  110  424  751  658
#   696  823  325  406  878  261  601  672  756  395  568  809  502   54
#   996  271  958  914  321  595  771  762  273  345 1017   67  656  103
#   752  666  556  129  358  977  772  290  875  246 1003  860  903  962
#   357  163  450  515  114  152  107  581  523  806  465  544  983  148
#   297  519  765  351  587  693  687  187  922  322  818  388  346  629
#   782  441  916  121  917  112  749  124   59 1004  788  338  670  705
#    73  449  873  333  356  175  565  632  551 1009 1008  790  920  422
#   308  834  911  536  724  643  900  272  665  589  778  183  180  648
#   122  600  139  981  910  349  111  348  417  474  856   71  603  434
#   716   52  646  655  268  485  879 1010  936  845 1036  408  743  160
#   622  285  615  956  839  842   55  949  264  548  968 1035  992  759
#   941  973  801  169  841  882   63  669  360  644  582  874  493  497
#   117  713  999  799  995  745  259  164  100  876  145  608  624  244
#   923  964  511  700  541  701  867  372  654 1011  865  355 1029  374
#   249  572  761  508  614  774  320  425  838  683  319  119  377  513
#   426 1019  337  109  897  889  435  804  327  673  807  758  379  491
#   576  270 1031  849  649  278  948  726  125  766  802 1007  376  789
#   317  466  482  269  476  753  567  991  984  155 1015  133  399  894
#   336  780   98  123  824  299  694  473  736  746  952  403  668  132
#   490  179  652  573  850   96  929  373  721  455  970  470  151  492
#   146 1027  447  884  323  262 1001  451 1020  817  266  928  880   58
#   993  931  387  706  562  328  532 1023  821  768  836  306  677   79
#   719  620  341  326  147   82   84  535  707  141  661 1016  861  795
#   156  857  245  331  353  384  862   77  166  757]

# %%
print(test_arr)
# Out:
# [41, 218, 222, 9, 207, 47, 1, 212, 15, 220, 198, 10, 45, 33, 196, 37, 50, 32, 206, 44, 30, 205, 8, 21, 195, 237, 229, 42, 203, 26, 219, 192, 235, 49, 201, 214, 48, 216, 241, 199, 227, 12, 36, 23, 39, 40, 18, 208, 5, 202, 7, 34, 223, 46, 2, 51, 16, 38, 200, 210, 22, 6, 24, 225, 233, 242, 224, 19, 213, 43, 228, 20, 0, 238, 197, 236, 193, 231, 25, 211, 232, 217, 204, 29, 27, 230, 240, 4, 194, 215, 11, 209, 226, 13, 239, 17, 28, 31, 35, 234, 3, 14, 221]

# %%
print(graphs[0].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 34, Edges: 538
#
#  Node types:
#   corner: [34]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [538]
#         Weights: range=[0, 0.788597], mean=0.066801, std=0.188837
#         Features: none

# %%
print(graphs[100].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 6, Edges: 18
#
#  Node types:
#   corner: [6]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [18]
#         Weights: range=[0.529817, 0.713582], mean=0.606562, std=0.0576769
#         Features: none

# %%
summary = pd.DataFrame(
    [(g.number_of_nodes(), g.number_of_edges()) for g in graphs],
    columns=["nodes", "edges"],
)
summary.describe().round(1)
# Out:
#         nodes   edges
# count  1037.0  1037.0
# mean      7.5    34.8
# std       5.2    53.4
# min       2.0     2.0
# 25%       3.0     6.0
# 50%       6.0    16.0
# 75%      10.0    44.0
# max      35.0   552.0

# %%
graph_labels = pd.Series(labels)

# %%
print(graph_labels)
# Out:
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 1032    1
# 1033    1
# 1034    1
# 1035    1
# 1036    1
# Length: 1037, dtype: int64

# %%
graph_labels.value_counts().to_frame()
# Out:
#       0
#  1  846
# -1  191

# %%
graph_labels = pd.get_dummies(graph_labels, drop_first=True)

# %%
print(type(graph_labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
graph_labels
# Out:
#       1
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1032  1
# 1033  1
# 1034  1
# 1035  1
# 1036  1
#
# [1037 rows x 1 columns]

# %%
generator = PaddedGraphGenerator(graphs=graphs)

# %%
def create_graph_classification_model(generator):
    gc_model = GCNSupervisedGraphClassification(
        layer_sizes=[64, 64],
        activations=["relu", "relu"],
        generator=generator,
        dropout=0.5,
    )
    x_inp, x_out = gc_model.in_out_tensors()
    predictions = Dense(units=32, activation="relu")(x_out)
    predictions = Dense(units=16, activation="relu")(predictions)
    predictions = Dense(units=1, activation="sigmoid")(predictions)

    # Let's create the Keras model and prepare it for training
    model = Model(inputs=x_inp, outputs=predictions)
    model.compile(optimizer=Adam(0.005), loss=binary_crossentropy, metrics=["acc"])

    return model

# %%
epochs = 200  # maximum number of training epochs
# folds = 10  # the number of folds for k-fold cross validation
# n_repeats = 5  # the number of repeats for repeated k-fold cross validation

# %%
es = EarlyStopping(
    monitor="val_loss", min_delta=0, patience=25, restore_best_weights=True
)

# %%
# To train in folds
def train_fold(model, train_gen, test_gen, es, epochs):
    history = model.fit(
        train_gen, epochs=epochs, validation_data=test_gen, verbose=0, callbacks=[es],
    )
    # calculate performance on the test data and return along with history
    test_metrics = model.evaluate(test_gen, verbose=0)
    test_acc = test_metrics[model.metrics_names.index("acc")]

    return history, test_acc

# %%
# To train in folds
def get_generators(train_index, test_index, graph_labels, batch_size):
    train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )
    test_gen = generator.flow(
        test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )

    return train_gen, test_gen

# %%
# # To train in folds
# test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"Training and evaluating on fold {i+1} out of {folds * n_repeats}...")
#     train_gen, test_gen = get_generators(
#         train_index, test_index, graph_labels, batch_size=30
#     )

#     model = create_graph_classification_model(generator)

#     history, acc = train_fold(model, train_gen, test_gen, es, epochs)

#     test_accs.append(acc)

# %%
# To train in folds
test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
for i in range(50):
    print(f"Training and evaluating on fold {i+1}...")
    
    train_gen, test_gen = get_generators(
        train_index, test_index, graph_labels, batch_size=30
    )

    model = create_graph_classification_model(generator)

    history, acc = train_fold(model, train_gen, test_gen, es, epochs)

    test_accs.append(acc)
# Out:
# Training and evaluating on fold 1...
# Training and evaluating on fold 2...
# Training and evaluating on fold 3...
# Training and evaluating on fold 4...
# Training and evaluating on fold 5...
# Training and evaluating on fold 6...
# Training and evaluating on fold 7...
# Training and evaluating on fold 8...
# Training and evaluating on fold 9...
# Training and evaluating on fold 10...
# Training and evaluating on fold 11...
# Training and evaluating on fold 12...
# Training and evaluating on fold 13...
# Training and evaluating on fold 14...
# Training and evaluating on fold 15...
# Training and evaluating on fold 16...
# Training and evaluating on fold 17...
# Training and evaluating on fold 18...
# Training and evaluating on fold 19...
# Training and evaluating on fold 20...
# Training and evaluating on fold 21...
# Training and evaluating on fold 22...
# Training and evaluating on fold 23...
# Training and evaluating on fold 24...
# Training and evaluating on fold 25...
# Training and evaluating on fold 26...
# Training and evaluating on fold 27...
# Training and evaluating on fold 28...
# Training and evaluating on fold 29...
# Training and evaluating on fold 30...
# Training and evaluating on fold 31...
# Training and evaluating on fold 32...
# Training and evaluating on fold 33...
# Training and evaluating on fold 34...
# Training and evaluating on fold 35...
# Training and evaluating on fold 36...
# Training and evaluating on fold 37...
# Training and evaluating on fold 38...
# Training and evaluating on fold 39...
# Training and evaluating on fold 40...
# Training and evaluating on fold 41...
# Training and evaluating on fold 42...
# Training and evaluating on fold 43...
# Training and evaluating on fold 44...
# Training and evaluating on fold 45...
# Training and evaluating on fold 46...
# Training and evaluating on fold 47...
# Training and evaluating on fold 48...
# Training and evaluating on fold 49...
# Training and evaluating on fold 50...

# %%
# 1: Accuracy over all folds mean: 76.0% and std: 4.3%
# 2: Accuracy over all folds mean: 73.9% and std: 6.9%
# 3: Accuracy over all folds mean: 74.4% and std: 6.9%
# 4: Accuracy over all folds mean: 76.4% and std: 2.8%
# 5: Accuracy over all folds mean: 73.4% and std: 5.5%

# -------------- After setting random
# 1: Accuracy over all folds mean: 74.5% and std: 6.6%
# 2: Accuracy over all folds mean: 74.5% and std: 4.7%
# 3: Accuracy over all folds mean: 75.5% and std: 4.6%
# 4: Accuracy over all folds mean: 75.0% and std: 4.5%
# 5: Accuracy over all folds mean: 75.0% and std: 4.7%

print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 75.0% and std: 4.7%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# First try
# Accuracy over all folds mean: 77.1% and std: 2.0%

# %%
# Second try
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 77.3% and std: 2.6%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"\ntrain_index: \n{train_index}\ntest_index: \n{test_index}\n")
#     break
# print(f"train: {len(train_index)}, test: {len(test_index)}")

# %%
train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)
test_gen = generator.flow(
    test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)

# %%
model_weighted = create_graph_classification_model(generator)

history = model_weighted.fit(
        train_gen, epochs=200, validation_data=test_gen, verbose=1, callbacks=[es])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 65ms/step - loss: 0.4357 - acc: 0.8561 - val_loss: 1.0024 - val_acc: 0.5000
# Epoch 2/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.3849 - acc: 0.8505 - val_loss: 0.8525 - val_acc: 0.5000
# Epoch 3/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.3468 - acc: 0.8505 - val_loss: 0.6412 - val_acc: 0.5000
# Epoch 4/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.3245 - acc: 0.8505 - val_loss: 0.6924 - val_acc: 0.5000
# Epoch 5/200
# 18/18 [==============================] - 1s 46ms/step - loss: 0.3225 - acc: 0.8674 - val_loss: 1.0016 - val_acc: 0.5000
# Epoch 6/200
# 18/18 [==============================] - 1s 52ms/step - loss: 0.3271 - acc: 0.8660 - val_loss: 0.8193 - val_acc: 0.5256
# Epoch 7/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.2875 - acc: 0.8858 - val_loss: 0.6751 - val_acc: 0.6410
# Epoch 8/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.2763 - acc: 0.8956 - val_loss: 0.9120 - val_acc: 0.6410
# Epoch 9/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2735 - acc: 0.9083 - val_loss: 0.7075 - val_acc: 0.7051
# Epoch 10/200
# 18/18 [==============================] - 1s 52ms/step - loss: 0.2538 - acc: 0.9055 - val_loss: 0.7557 - val_acc: 0.7051
# Epoch 11/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2607 - acc: 0.9097 - val_loss: 0.5693 - val_acc: 0.7308
# Epoch 12/200
# 18/18 [==============================] - 1s 46ms/step - loss: 0.2427 - acc: 0.9168 - val_loss: 0.6739 - val_acc: 0.7179
# Epoch 13/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2489 - acc: 0.9097 - val_loss: 0.6731 - val_acc: 0.7308
# Epoch 14/200
# 18/18 [==============================] - 1s 54ms/step - loss: 0.2423 - acc: 0.9154 - val_loss: 0.6892 - val_acc: 0.7308
# Epoch 15/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.2108 - acc: 0.9182 - val_loss: 0.6712 - val_acc: 0.7308
# Epoch 16/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2189 - acc: 0.9140 - val_loss: 0.4964 - val_acc: 0.7564
# Epoch 17/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2459 - acc: 0.9210 - val_loss: 0.4220 - val_acc: 0.7436
# Epoch 18/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2028 - acc: 0.9295 - val_loss: 0.6804 - val_acc: 0.7308
# Epoch 19/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.1929 - acc: 0.9337 - val_loss: 0.5348 - val_acc: 0.7436
# Epoch 20/200
# 18/18 [==============================] - 1s 54ms/step - loss: 0.2086 - acc: 0.9224 - val_loss: 0.6170 - val_acc: 0.7308
# Epoch 21/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2056 - acc: 0.9252 - val_loss: 0.7177 - val_acc: 0.7308
# Epoch 22/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.2104 - acc: 0.9323 - val_loss: 0.6680 - val_acc: 0.7308
# Epoch 23/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1893 - acc: 0.9337 - val_loss: 0.5349 - val_acc: 0.7436
# Epoch 24/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1983 - acc: 0.9210 - val_loss: 0.4698 - val_acc: 0.7436
# Epoch 25/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.1891 - acc: 0.9365 - val_loss: 0.5062 - val_acc: 0.7436
# Epoch 26/200
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1857 - acc: 0.9252 - val_loss: 0.6617 - val_acc: 0.7436
# Epoch 27/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2091 - acc: 0.9309 - val_loss: 0.5592 - val_acc: 0.7436
# Epoch 28/200
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1997 - acc: 0.9309 - val_loss: 0.5586 - val_acc: 0.7436
# Epoch 29/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.1954 - acc: 0.9295 - val_loss: 0.4385 - val_acc: 0.7821
# Epoch 30/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2123 - acc: 0.9281 - val_loss: 0.5874 - val_acc: 0.7436
# Epoch 31/200
# 18/18 [==============================] - 1s 36ms/step - loss: 0.1653 - acc: 0.9351 - val_loss: 0.7863 - val_acc: 0.7436
# Epoch 32/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.1866 - acc: 0.9309 - val_loss: 0.8133 - val_acc: 0.7436
# Epoch 33/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2092 - acc: 0.9210 - val_loss: 0.6797 - val_acc: 0.7308
# Epoch 34/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2184 - acc: 0.9210 - val_loss: 0.5364 - val_acc: 0.7436
# Epoch 35/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1951 - acc: 0.9323 - val_loss: 0.6809 - val_acc: 0.7436
# Epoch 36/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.1696 - acc: 0.9379 - val_loss: 0.6214 - val_acc: 0.7436
# Epoch 37/200
# 18/18 [==============================] - 1s 52ms/step - loss: 0.1819 - acc: 0.9351 - val_loss: 0.5393 - val_acc: 0.7564
# Epoch 38/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.1883 - acc: 0.9309 - val_loss: 0.4312 - val_acc: 0.7821
# Epoch 39/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.1874 - acc: 0.9379 - val_loss: 0.5837 - val_acc: 0.7436
# Epoch 40/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.1865 - acc: 0.9365 - val_loss: 0.6816 - val_acc: 0.7436
# Epoch 41/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1789 - acc: 0.9351 - val_loss: 0.4685 - val_acc: 0.7821
# Epoch 42/200
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1823 - acc: 0.9422 - val_loss: 0.4413 - val_acc: 0.7692

# %%
# calculate performance on the test data and return along with history
# Node features 128 node2vec, edge features all 1
test_metrics = model_weighted.evaluate(test_gen, verbose=1)
test_acc = test_metrics[model_weighted.metrics_names.index("acc")]
# Out:
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4220 - acc: 0.7436

# %%
print(test_metrics)
#test loss, test acc: [0.4488869309425354, 0.7692307829856873]
# 2nd time:[0.42735838890075684, 0.7820512652397156]
# 3 : [0.446189284324646, 0.7820512652397156]
print(test_acc)
# Out:
# [0.42195096611976624, 0.7435897588729858]
# 0.7435897588729858

# %%
print("Generate predictions for samples")
predictions = model_weighted.predict(test_gen, verbose=0)
print("predictions shape:", predictions.shape)
# predictions shape: (79, 1)
print(predictions)

# %%
print(test_gen.targets)
