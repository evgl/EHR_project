# %% [markdown]
# ### Data extraction
# Extract data from MIMIC-III

# %%
import time
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Import pandas 
import pandas as pd 

start = time.time()
# reading csv file 
admissions_df = pd.read_csv("../MIMIC-III/ADMISSIONS.csv")
noteevents_df = pd.read_csv("../MIMIC-III/NOTEEVENTS.csv") 
end = time.time()
print(end - start)
# Out:
# /data/home/evgenii/anaconda3/envs/qqq/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning:
#
# Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
# 45.65408992767334

# %%
start = time.time()
# Left join of two dataframes
note_admiss_df_left = noteevents_df.merge(admissions_df, on='HADM_ID', how='left', indicator=True)
end = time.time()
print(end - start)
# Out:
# 27.120221376419067

# %%
note_admiss_df_left[['DIAGNOSIS', 'SUBJECT_ID_x', 'SUBJECT_ID_y','DESCRIPTION', 'CATEGORY']]
# Out:
#                                      DIAGNOSIS  SUBJECT_ID_x  SUBJECT_ID_y  \
# 0                      RT LOWER LOBE PNEUMONIA         22532       22532.0
# 1        CHRONIC OBSTRUCTIVE PULMONARY DISEASE         13702       13702.0
# 2                TRACHEALBRONCHEAL MALACEA/SDA         13702       13702.0
# 3                     ASTHMA;COPD EXACERBATION         13702       13702.0
# 4                           S/P FALL;TELEMETRY         26880       26880.0
# ...                                        ...           ...           ...
# 2083175                                NEWBORN         31097       31097.0
# 2083176                                NEWBORN         31097       31097.0
# 2083177                                NEWBORN         31097       31097.0
# 2083178                                NEWBORN         31097       31097.0
# 2083179                                NEWBORN         31097       31097.0
#
#         DESCRIPTION           CATEGORY
# 0            Report  Discharge summary
# 1            Report  Discharge summary
# 2            Report  Discharge summary
# 3            Report  Discharge summary
# 4            Report  Discharge summary
# ...             ...                ...
# 2083175      Report      Nursing/other
# 2083176      Report      Nursing/other
# 2083177      Report      Nursing/other
# 2083178      Report      Nursing/other
# 2083179      Report      Nursing/other
#
# [2083180 rows x 5 columns]

# %%
note_admiss_df_left['DIAGNOSIS'].value_counts()
# Out:
# NEWBORN                                              403664
# PNEUMONIA                                             59727
# SEPSIS                                                41980
# CONGESTIVE HEART FAILURE                              29571
# CORONARY ARTERY DISEASE                               21190
#                                                       ...
# NEUTROPENIC FEVER;? PNEUMONIA                             1
# SUBCLAVIAN STENOSIS, RIGHT/SDA                            1
# RECURRENT CAROTID STENOSIS\ CAROTID ANGIOGRAM/SDA         1
# PANCREAS CANCER/SDA                                       1
# OLIGODENDROGLIOMA RIGHT /SDA                              1
# Name: DIAGNOSIS, Length: 15597, dtype: int64

# %%
pneumonia_df = note_admiss_df_left.loc[note_admiss_df_left["DIAGNOSIS"] == 'PNEUMONIA', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]

# %%
#pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]
pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x','SUBJECT_ID_x','CHARTDATE','STORETIME','CATEGORY','DESCRIPTION','TEXT', 'DEATHTIME']]

# %%
pneumonia_alive_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.isnull()]
pneumonia_dead_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.notnull()]

# %%
pneumonia_dead_no_disch.shape
# Out:
# (11895, 8)

# %%
pneumonia_alive_no_disch.shape
# Out:
# (46134, 8)

# %%
pneumonia_alive_no_disch = pneumonia_alive_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])
pneumonia_dead_no_disch = pneumonia_dead_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])

# %%
# Number of patients
pneumonia_dead_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 252

# %%
# Number of patients
pneumonia_alive_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 1167

# %%
# import text handling tool
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from collections import Counter

import sys
import re
import csv
import os.path

# define constants
# RESULT_HEADER = "WORD, FREQUENCY\n"
MIN_SEQ_LEN = 4
USE_1_N_SEQ = 2


# words that do not have meaning (can be modified later)
USELESS_WORDS = ["a", "the", "he", "she", ",", ".", "?", "!", ":", ";", "+", "*", "**"\
                 "your", "you"]

# count up the frequency of every word in every disease file
stemmer = PorterStemmer()
# create set of words to ignore in text
stop_words = set(stopwords.words('english'))

for word in USELESS_WORDS:
    stop_words.add(word)

# %%
#----------
def count_notes_per_patient(disease_df):
    patient_id_to_num_notes = {}
    patient_id = -1
    note_counter = 0
            
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        patient_id_check = int(row['SUBJECT_ID_x'])
                
        if not patient_id == patient_id_check:
            patient_id_to_num_notes[patient_id] = note_counter
            note_counter = 1
        else:
            note_counter += 1
                    
        patient_id = patient_id_check
                
    patient_id_to_num_notes[patient_id] = note_counter
    del patient_id_to_num_notes[-1]
    return patient_id_to_num_notes

patient_id_to_num_notes = {}
patient_id_to_num_notes['pneumonia_dead'] = count_notes_per_patient(pneumonia_dead_no_disch)
patient_id_to_num_notes['pneumonia_alive'] = count_notes_per_patient(pneumonia_alive_no_disch)
# Out:
# 100%|██████████| 11895/11895 [00:01<00:00, 8960.30it/s]
# 100%|██████████| 46134/46134 [00:05<00:00, 9049.83it/s]

# %%
patient_id_to_num_notes
# Out:
# {'pneumonia_dead': {111: 12,
#   346: 25,
#   404: 3,
#   546: 6,
#   618: 16,
#   705: 15,
#   726: 48,
#   1039: 55,
#   1556: 37,
#   1872: 3,
#   1944: 56,
#   2286: 69,
#   2990: 166,
#   3055: 29,
#   3099: 13,
#   3201: 8,
#   3526: 7,
#   3773: 6,
#   3881: 20,
#   4122: 51,
#   4754: 101,
#   4811: 21,
#   5476: 1,
#   5494: 22,
#   5774: 104,
#   5786: 152,
#   5913: 1,
#   6133: 68,
#   6735: 13,
#   6745: 13,
#   6973: 36,
#   6981: 8,
#   7277: 66,
#   7310: 8,
#   7924: 9,
#   7977: 9,
#   9908: 11,
#   9984: 15,
#   10302: 100,
#   10510: 86,
#   10545: 10,
#   10642: 10,
#   11049: 14,
#   11209: 9,
#   11395: 41,
#   12530: 24,
#   12849: 50,
#   13098: 46,
#   13566: 23,
#   14125: 9,
#   14514: 96,
#   14965: 25,
#   15159: 15,
#   15251: 11,
#   15396: 17,
#   15566: 37,
#   15853: 45,
#   16275: 17,
#   16344: 27,
#   16622: 51,
#   16684: 29,
#   17122: 16,
#   17354: 5,
#   17802: 64,
#   17983: 65,
#   18094: 23,
#   18736: 35,
#   18768: 46,
#   18848: 205,
#   18971: 26,
#   19243: 25,
#   19323: 6,
#   19390: 21,
#   19463: 20,
#   19535: 59,
#   19754: 13,
#   19827: 22,
#   19833: 58,
#   19872: 10,
#   20006: 8,
#   20023: 9,
#   20190: 6,
#   21046: 101,
#   21094: 36,
#   21427: 10,
#   21502: 102,
#   21580: 52,
#   21676: 12,
#   21699: 7,
#   21979: 11,
#   22735: 15,
#   23660: 12,
#   23795: 78,
#   24181: 13,
#   24582: 37,
#   24725: 57,
#   24730: 19,
#   24854: 25,
#   25003: 182,
#   25046: 7,
#   25774: 61,
#   25975: 9,
#   26474: 89,
#   26578: 15,
#   26716: 41,
#   26774: 3,
#   26849: 33,
#   27005: 5,
#   27145: 24,
#   27421: 61,
#   27431: 5,
#   27496: 7,
#   27504: 72,
#   27639: 221,
#   28004: 13,
#   28072: 34,
#   28178: 202,
#   28427: 6,
#   28498: 25,
#   28726: 34,
#   28750: 19,
#   28906: 32,
#   28907: 13,
#   28933: 394,
#   29105: 468,
#   29588: 72,
#   29647: 26,
#   29872: 225,
#   30476: 174,
#   30549: 12,
#   30614: 8,
#   30699: 14,
#   30786: 9,
#   30941: 110,
#   31030: 168,
#   31134: 24,
#   31139: 9,
#   31451: 48,
#   31556: 57,
#   31690: 18,
#   31692: 35,
#   32050: 34,
#   32326: 24,
#   32618: 42,
#   41546: 25,
#   43937: 6,
#   44851: 274,
#   45381: 16,
#   46589: 26,
#   46763: 6,
#   47045: 9,
#   48632: 147,
#   49079: 20,
#   49683: 3,
#   49922: 13,
#   50093: 8,
#   50231: 3,
#   50556: 216,
#   50859: 537,
#   51914: 313,
#   52010: 12,
#   53105: 115,
#   53399: 78,
#   54193: 85,
#   54401: 14,
#   54408: 2,
#   54739: 75,
#   54946: 7,
#   55400: 5,
#   55570: 14,
#   55887: 37,
#   55944: 34,
#   55987: 20,
#   56390: 19,
#   56648: 8,
#   56854: 170,
#   57091: 88,
#   57102: 35,
#   58702: 479,
#   59260: 11,
#   59437: 26,
#   60849: 2,
#   60868: 6,
#   61652: 7,
#   61667: 30,
#   63039: 8,
#   65513: 8,
#   68044: 40,
#   68095: 23,
#   68184: 5,
#   68308: 8,
#   68860: 14,
#   69719: 13,
#   69745: 25,
#   69776: 17,
#   70226: 8,
#   70447: 9,
#   72930: 11,
#   73811: 9,
#   73888: 109,
#   74316: 2,
#   74444: 81,
#   74686: 75,
#   75824: 10,
#   76282: 21,
#   76827: 2,
#   77382: 10,
#   78241: 3,
#   78388: 14,
#   79008: 27,
#   79055: 21,
#   79222: 18,
#   79877: 156,
#   80637: 148,
#   80678: 9,
#   80737: 46,
#   80805: 79,
#   81437: 27,
#   82393: 5,
#   82769: 85,
#   83932: 2,
#   84474: 34,
#   85160: 8,
#   85258: 52,
#   85404: 11,
#   85797: 9,
#   86007: 35,
#   86394: 4,
#   86684: 11,
#   86832: 67,
#   86863: 8,
#   86872: 326,
#   88193: 16,
#   88660: 11,
#   90256: 18,
#   91350: 19,
#   92074: 28,
#   92278: 52,
#   92331: 42,
#   93422: 7,
#   94341: 2,
#   94997: 9,
#   95280: 23,
#   95803: 18,
#   95830: 33,
#   95933: 56,
#   96699: 85,
#   97181: 30,
#   97795: 60,
#   98009: 33,
#   98299: 29,
#   98597: 2},
#  'pneumonia_alive': {68: 18,
#   85: 8,
#   94: 100,
#   165: 2,
#   211: 24,
#   224: 8,
#   231: 75,
#   283: 131,
#   357: 17,
#   368: 45,
#   370: 13,
#   384: 26,
#   426: 10,
#   509: 34,
#   514: 7,
#   596: 23,
#   674: 16,
#   707: 29,
#   711: 537,
#   770: 83,
#   773: 74,
#   899: 17,
#   1096: 17,
#   1135: 32,
#   1163: 12,
#   1174: 42,
#   1180: 5,
#   1283: 3,
#   1332: 66,
#   1339: 134,
#   1546: 21,
#   1568: 22,
#   1601: 12,
#   1606: 13,
#   1642: 4,
#   1660: 23,
#   1895: 22,
#   1923: 23,
#   2029: 175,
#   2090: 179,
#   2098: 26,
#   2128: 31,
#   2170: 9,
#   2187: 30,
#   2208: 139,
#   2337: 8,
#   2378: 57,
#   2386: 18,
#   2452: 22,
#   2508: 22,
#   2561: 126,
#   2585: 9,
#   2589: 92,
#   2590: 5,
#   2628: 218,
#   2658: 16,
#   2732: 12,
#   2784: 23,
#   2823: 21,
#   3070: 8,
#   3100: 70,
#   3154: 22,
#   3220: 28,
#   3277: 35,
#   3347: 15,
#   3359: 15,
#   3516: 11,
#   3602: 18,
#   3623: 116,
#   3641: 57,
#   3676: 49,
#   3830: 80,
#   3860: 203,
#   3862: 22,
#   3865: 8,
#   3895: 6,
#   3935: 44,
#   3952: 20,
#   3975: 34,
#   4109: 9,
#   4155: 23,
#   4236: 14,
#   4275: 45,
#   4316: 13,
#   4317: 106,
#   4328: 23,
#   4388: 14,
#   4454: 5,
#   4467: 12,
#   4489: 21,
#   4494: 18,
#   4584: 39,
#   4588: 80,
#   4641: 23,
#   4694: 19,
#   4804: 6,
#   5030: 49,
#   5145: 9,
#   5244: 113,
#   5264: 115,
#   5360: 19,
#   5434: 24,
#   5476: 36,
#   5516: 31,
#   5536: 21,
#   5564: 30,
#   5579: 14,
#   5609: 39,
#   5619: 25,
#   5631: 9,
#   5681: 9,
#   5691: 12,
#   5727: 41,
#   5761: 85,
#   5819: 19,
#   5904: 16,
#   5937: 61,
#   6038: 4,
#   6143: 15,
#   6176: 5,
#   6183: 17,
#   6206: 7,
#   6279: 20,
#   6378: 112,
#   6398: 11,
#   6557: 16,
#   6603: 15,
#   6884: 43,
#   6901: 8,
#   6915: 190,
#   7107: 230,
#   7169: 9,
#   7271: 117,
#   7356: 12,
#   7363: 284,
#   7492: 58,
#   7569: 32,
#   7603: 39,
#   7666: 9,
#   7700: 68,
#   7787: 18,
#   7849: 96,
#   7936: 3,
#   8070: 69,
#   8312: 29,
#   8337: 22,
#   8366: 25,
#   8471: 15,
#   8512: 16,
#   8515: 21,
#   8532: 9,
#   8556: 71,
#   8803: 4,
#   8895: 10,
#   8900: 11,
#   9124: 18,
#   9128: 2,
#   9253: 76,
#   9304: 12,
#   9332: 7,
#   9457: 6,
#   9505: 2,
#   9518: 80,
#   9544: 228,
#   9727: 37,
#   9736: 19,
#   9859: 12,
#   9871: 17,
#   9957: 15,
#   9973: 59,
#   10057: 144,
#   10207: 36,
#   10299: 167,
#   10304: 8,
#   10377: 125,
#   10502: 9,
#   10581: 11,
#   10589: 18,
#   10626: 72,
#   10635: 6,
#   10666: 84,
#   10675: 13,
#   10761: 9,
#   10830: 14,
#   10848: 16,
#   10950: 23,
#   11003: 63,
#   11018: 24,
#   11061: 11,
#   11065: 40,
#   11197: 14,
#   11236: 58,
#   11247: 6,
#   11275: 26,
#   11313: 9,
#   11320: 66,
#   11421: 37,
#   11446: 13,
#   11593: 19,
#   11616: 64,
#   11671: 14,
#   11702: 7,
#   11708: 44,
#   11747: 20,
#   11762: 10,
#   11829: 25,
#   11850: 23,
#   11860: 11,
#   11932: 18,
#   11989: 17,
#   12028: 221,
#   12140: 36,
#   12177: 53,
#   12183: 26,
#   12274: 9,
#   12312: 13,
#   12380: 45,
#   12508: 136,
#   12567: 61,
#   12585: 4,
#   12629: 43,
#   12633: 11,
#   12799: 77,
#   12803: 21,
#   12824: 21,
#   13123: 10,
#   13329: 22,
#   13330: 13,
#   13503: 15,
#   13546: 20,
#   13577: 7,
#   13593: 20,
#   13615: 10,
#   13627: 31,
#   13664: 120,
#   13728: 13,
#   13748: 21,
#   13864: 5,
#   13881: 2,
#   14035: 12,
#   14144: 24,
#   14172: 9,
#   14193: 8,
#   14256: 26,
#   14269: 21,
#   14309: 13,
#   14342: 20,
#   14385: 14,
#   14507: 9,
#   14520: 56,
#   14705: 17,
#   14805: 16,
#   14855: 96,
#   14975: 23,
#   15046: 86,
#   15054: 33,
#   15301: 5,
#   15347: 4,
#   15361: 15,
#   15472: 13,
#   15590: 85,
#   15716: 323,
#   15852: 15,
#   15875: 192,
#   16038: 89,
#   16053: 17,
#   16076: 397,
#   16102: 6,
#   16129: 22,
#   16147: 7,
#   16216: 17,
#   16275: 90,
#   16318: 12,
#   16367: 47,
#   16384: 48,
#   16409: 40,
#   16412: 8,
#   16438: 28,
#   16468: 15,
#   16469: 20,
#   16479: 7,
#   16492: 6,
#   16554: 19,
#   16560: 8,
#   16685: 1,
#   16733: 14,
#   16755: 24,
#   16800: 12,
#   16802: 27,
#   16850: 14,
#   16975: 186,
#   16992: 42,
#   17107: 6,
#   17149: 17,
#   17150: 23,
#   17250: 28,
#   17260: 10,
#   17276: 10,
#   17539: 24,
#   17547: 9,
#   17617: 4,
#   17631: 19,
#   17664: 24,
#   17722: 8,
#   17764: 3,
#   17795: 215,
#   17843: 37,
#   17882: 6,
#   17903: 7,
#   17906: 88,
#   18082: 22,
#   18123: 146,
#   18233: 8,
#   18250: 2,
#   18281: 61,
#   18320: 207,
#   18353: 16,
#   18365: 10,
#   18459: 33,
#   18637: 35,
#   18673: 38,
#   18681: 10,
#   18737: 7,
#   18999: 40,
#   19029: 4,
#   19036: 12,
#   19164: 20,
#   19463: 14,
#   19569: 4,
#   19653: 30,
#   19698: 79,
#   19793: 37,
#   19803: 9,
#   19833: 77,
#   19851: 83,
#   19859: 14,
#   19940: 9,
#   20061: 7,
#   20086: 85,
#   20133: 121,
#   20181: 204,
#   20187: 25,
#   20263: 6,
#   20265: 7,
#   20289: 63,
#   20381: 10,
#   20425: 103,
#   20528: 37,
#   20580: 1,
#   20598: 31,
#   20600: 16,
#   20624: 32,
#   20643: 20,
#   20804: 25,
#   20899: 17,
#   20951: 8,
#   20979: 26,
#   21037: 21,
#   21056: 9,
#   21093: 60,
#   21255: 3,
#   21269: 279,
#   21277: 23,
#   21301: 16,
#   21350: 18,
#   21548: 7,
#   21581: 11,
#   21737: 7,
#   21745: 5,
#   21764: 7,
#   22019: 2,
#   22180: 5,
#   22192: 5,
#   22287: 10,
#   22432: 6,
#   22450: 11,
#   22520: 63,
#   22534: 4,
#   22580: 10,
#   22624: 43,
#   22667: 72,
#   22684: 14,
#   22706: 8,
#   22754: 44,
#   22855: 47,
#   22921: 2,
#   23028: 22,
#   23109: 2,
#   23131: 49,
#   23161: 29,
#   23215: 9,
#   23318: 15,
#   23418: 22,
#   23423: 11,
#   23451: 26,
#   23568: 8,
#   23657: 34,
#   23734: 15,
#   23763: 21,
#   23847: 9,
#   24099: 2,
#   24170: 2,
#   24178: 209,
#   24276: 82,
#   24344: 290,
#   24483: 7,
#   24535: 23,
#   24562: 10,
#   24569: 20,
#   24622: 1,
#   24687: 45,
#   24807: 41,
#   24847: 12,
#   24868: 57,
#   24903: 45,
#   25001: 25,
#   25016: 78,
#   25038: 66,
#   25097: 42,
#   25117: 38,
#   25225: 17,
#   25256: 30,
#   25295: 59,
#   25326: 17,
#   25373: 158,
#   25406: 5,
#   25515: 18,
#   25526: 86,
#   25579: 27,
#   25591: 61,
#   25671: 11,
#   25750: 107,
#   25775: 38,
#   25844: 22,
#   25860: 9,
#   25861: 16,
#   25889: 20,
#   25941: 86,
#   26036: 11,
#   26040: 79,
#   26052: 3,
#   26080: 5,
#   26097: 65,
#   26118: 60,
#   26311: 28,
#   26391: 64,
#   26398: 14,
#   26469: 52,
#   26542: 55,
#   26601: 58,
#   26638: 155,
#   26727: 10,
#   26797: 8,
#   26869: 11,
#   26884: 5,
#   26887: 4,
#   26956: 23,
#   27003: 18,
#   27036: 10,
#   27043: 30,
#   27047: 41,
#   27049: 14,
#   27089: 24,
#   27121: 89,
#   27143: 135,
#   27172: 9,
#   27179: 118,
#   27194: 60,
#   27269: 19,
#   27367: 84,
#   27371: 17,
#   27431: 33,
#   27486: 2,
#   27576: 84,
#   27597: 60,
#   27600: 28,
#   27677: 11,
#   27726: 59,
#   27729: 70,
#   27752: 11,
#   27800: 12,
#   27809: 18,
#   27823: 31,
#   27879: 13,
#   27886: 30,
#   27999: 25,
#   28050: 20,
#   28055: 4,
#   28073: 74,
#   28093: 21,
#   28103: 16,
#   28164: 159,
#   28173: 124,
#   28230: 23,
#   28291: 36,
#   28298: 31,
#   28356: 10,
#   28527: 46,
#   28530: 24,
#   28642: 2,
#   28668: 3,
#   28671: 33,
#   28689: 5,
#   28717: 23,
#   28729: 73,
#   28742: 7,
#   28758: 94,
#   28827: 12,
#   28843: 1,
#   28884: 12,
#   28932: 24,
#   28935: 4,
#   28939: 4,
#   28973: 152,
#   29007: 9,
#   29043: 12,
#   29093: 5,
#   29096: 21,
#   29102: 18,
#   29129: 15,
#   29137: 8,
#   29139: 17,
#   29141: 27,
#   29219: 19,
#   29240: 10,
#   29274: 17,
#   29350: 18,
#   29377: 80,
#   29379: 21,
#   29456: 22,
#   29478: 32,
#   29501: 6,
#   29503: 11,
#   29504: 18,
#   29513: 65,
#   29528: 5,
#   29556: 5,
#   29566: 17,
#   29619: 18,
#   29638: 15,
#   29639: 26,
#   29660: 9,
#   29703: 12,
#   29866: 12,
#   29872: 14,
#   29913: 11,
#   29919: 24,
#   29927: 63,
#   29965: 26,
#   29972: 7,
#   30010: 7,
#   30015: 36,
#   30139: 529,
#   30208: 18,
#   30227: 35,
#   30287: 23,
#   30299: 1,
#   30301: 117,
#   30316: 17,
#   30365: 47,
#   30490: 17,
#   30501: 10,
#   30505: 33,
#   30561: 6,
#   30575: 6,
#   30599: 24,
#   30631: 11,
#   30663: 24,
#   30696: 54,
#   30786: 11,
#   30798: 14,
#   30860: 28,
#   31003: 45,
#   31183: 129,
#   31216: 80,
#   31221: 17,
#   31262: 28,
#   31298: 13,
#   31332: 59,
#   31361: 20,
#   31442: 32,
#   31470: 17,
#   31516: 74,
#   31528: 60,
#   31544: 11,
#   31580: 34,
#   31585: 39,
#   31610: 17,
#   31660: 3,
#   31664: 45,
#   31692: 23,
#   31723: 17,
#   31813: 234,
#   31942: 102,
#   31986: 41,
#   32018: 145,
#   32061: 11,
#   32106: 18,
#   32135: 12,
#   32161: 25,
#   32181: 8,
#   32183: 27,
#   32193: 16,
#   32268: 6,
#   32286: 117,
#   32355: 6,
#   32367: 42,
#   32394: 6,
#   32414: 485,
#   32436: 271,
#   32583: 5,
#   32605: 19,
#   32639: 12,
#   32740: 48,
#   32746: 11,
#   32773: 112,
#   32790: 103,
#   40059: 11,
#   40124: 68,
#   40246: 20,
#   40370: 11,
#   40442: 107,
#   40456: 43,
#   40576: 48,
#   40631: 4,
#   40911: 35,
#   41192: 45,
#   41373: 28,
#   41434: 10,
#   41446: 8,
#   41890: 7,
#   41958: 5,
#   41962: 10,
#   41976: 177,
#   42009: 30,
#   42035: 49,
#   42054: 18,
#   42194: 1,
#   42346: 30,
#   42458: 9,
#   42515: 38,
#   42572: 17,
#   42715: 21,
#   42794: 6,
#   42924: 3,
#   43067: 90,
#   43074: 18,
#   43112: 394,
#   43128: 1,
#   43147: 150,
#   43305: 48,
#   43323: 15,
#   43937: 4,
#   43943: 6,
#   43959: 3,
#   44146: 16,
#   44206: 5,
#   44214: 30,
#   44326: 8,
#   44437: 12,
#   44530: 2,
#   44534: 37,
#   44741: 8,
#   44787: 7,
#   44829: 55,
#   44841: 19,
#   44848: 2,
#   45193: 11,
#   45280: 9,
#   45435: 7,
#   46011: 61,
#   46335: 49,
#   46366: 42,
#   46415: 53,
#   46521: 14,
#   46728: 34,
#   46926: 1,
#   46961: 1,
#   47216: 17,
#   47219: 67,
#   47407: 2,
#   47467: 6,
#   47670: 7,
#   47747: 12,
#   47852: 95,
#   47930: 5,
#   48058: 4,
#   48143: 6,
#   48297: 11,
#   48340: 7,
#   48660: 343,
#   48687: 15,
#   48750: 8,
#   48812: 36,
#   48837: 14,
#   48929: 7,
#   49292: 18,
#   49510: 31,
#   49558: 347,
#   49623: 9,
#   49747: 7,
#   49764: 10,
#   49963: 4,
#   50007: 4,
#   50041: 10,
#   50093: 6,
#   50257: 11,
#   50294: 20,
#   50409: 75,
#   50762: 8,
#   50772: 17,
#   50807: 21,
#   50828: 126,
#   50911: 81,
#   50998: 29,
#   51195: 29,
#   51237: 11,
#   51401: 33,
#   51418: 68,
#   51497: 3,
#   51545: 97,
#   51601: 5,
#   51607: 5,
#   51669: 10,
#   51933: 5,
#   52011: 8,
#   52054: 1,
#   52172: 13,
#   52191: 46,
#   52307: 5,
#   52452: 5,
#   52606: 54,
#   52622: 5,
#   52898: 6,
#   52957: 52,
#   53119: 7,
#   53160: 13,
#   53173: 14,
#   53534: 9,
#   53650: 15,
#   53743: 151,
#   53749: 6,
#   53847: 14,
#   54172: 6,
#   54197: 13,
#   54305: 8,
#   54514: 116,
#   54709: 9,
#   54741: 5,
#   54832: 7,
#   54922: 2,
#   55059: 17,
#   55074: 7,
#   55188: 9,
#   55571: 212,
#   55700: 4,
#   55753: 37,
#   55841: 14,
#   55920: 17,
#   56027: 7,
#   56229: 31,
#   56440: 9,
#   56490: 12,
#   56621: 11,
#   56635: 2,
#   56772: 31,
#   56798: 4,
#   56867: 16,
#   56874: 51,
#   57050: 205,
#   57081: 32,
#   57157: 5,
#   57277: 19,
#   57290: 15,
#   57449: 17,
#   57788: 36,
#   57795: 7,
#   57889: 105,
#   58105: 49,
#   58242: 6,
#   58264: 7,
#   58286: 20,
#   58416: 3,
#   58433: 51,
#   58522: 9,
#   58580: 5,
#   58610: 13,
#   58631: 15,
#   58732: 5,
#   58794: 32,
#   58810: 10,
#   58955: 6,
#   59275: 1,
#   59278: 17,
#   59411: 6,
#   59496: 75,
#   59765: 300,
#   59789: 10,
#   59801: 2,
#   59822: 14,
#   59903: 483,
#   59943: 121,
#   60003: 9,
#   60050: 4,
#   60130: 44,
#   60674: 10,
#   60685: 4,
#   60958: 8,
#   60977: 9,
#   61005: 10,
#   61084: 216,
#   61195: 9,
#   61259: 83,
#   61331: 4,
#   61630: 19,
#   61738: 6,
#   61886: 6,
#   62231: 4,
#   62239: 5,
#   62284: 6,
#   62402: 56,
#   62641: 8,
#   62733: 9,
#   62858: 120,
#   63145: 25,
#   63327: 16,
#   63351: 10,
#   63362: 7,
#   63430: 56,
#   63499: 32,
#   63560: 25,
#   63943: 31,
#   63968: 10,
#   64160: 4,
#   64232: 28,
#   64249: 7,
#   64715: 17,
#   65004: 11,
#   65027: 1,
#   65033: 2,
#   65164: 4,
#   65361: 20,
#   65435: 40,
#   65449: 6,
#   65515: 5,
#   65582: 576,
#   65594: 9,
#   65692: 25,
#   65710: 18,
#   65837: 47,
#   66002: 636,
#   66009: 373,
#   66206: 12,
#   66412: 5,
#   66492: 1,
#   66549: 36,
#   66556: 20,
#   66671: 32,
#   66739: 1,
#   66753: 8,
#   66823: 21,
#   67053: 238,
#   67111: 16,
#   67117: 19,
#   67408: 15,
#   67446: 8,
#   67796: 7,
#   67844: 7,
#   67887: 13,
#   68059: 3,
#   68315: 3,
#   68591: 7,
#   68791: 13,
#   68836: 7,
#   68839: 21,
#   68905: 3,
#   68944: 39,
#   68962: 1,
#   69098: 12,
#   69158: 13,
#   69250: 4,
#   69296: 13,
#   69359: 26,
#   69380: 265,
#   69483: 26,
#   69546: 64,
#   69556: 11,
#   69578: 7,
#   69673: 6,
#   69776: 53,
#   69799: 6,
#   69932: 6,
#   70285: 2,
#   70466: 18,
#   70476: 22,
#   70492: 10,
#   70563: 3,
#   70645: 29,
#   70682: 48,
#   70728: 12,
#   71107: 9,
#   71108: 220,
#   71220: 45,
#   71336: 5,
#   71377: 39,
#   71915: 6,
#   71943: 4,
#   71983: 3,
#   72229: 189,
#   72230: 154,
#   72233: 2,
#   72378: 7,
#   72532: 6,
#   72714: 4,
#   72751: 35,
#   73043: 3,
#   73107: 479,
#   73129: 105,
#   73388: 37,
#   73389: 87,
#   73479: 3,
#   73686: 4,
#   73713: 458,
#   73770: 9,
#   73808: 49,
#   73899: 2,
#   73941: 7,
#   74016: 8,
#   74253: 388,
#   74505: 32,
#   74562: 98,
#   74640: 7,
#   74654: 7,
#   75047: 3,
#   75107: 124,
#   75200: 87,
#   75387: 14,
#   75446: 34,
#   75609: 5,
#   75640: 45,
#   75741: 8,
#   75782: 90,
#   75806: 3,
#   75983: 9,
#   76021: 39,
#   76056: 1,
#   76074: 31,
#   76141: 4,
#   76178: 22,
#   76437: 5,
#   76446: 18,
#   76476: 3,
#   76797: 6,
#   76915: 8,
#   76993: 13,
#   77019: 8,
#   77128: 9,
#   77177: 14,
#   77237: 198,
#   77279: 2,
#   77434: 18,
#   77453: 2,
#   77469: 31,
#   77676: 4,
#   77690: 19,
#   77697: 10,
#   77816: 8,
#   77947: 11,
#   78017: 2,
#   78086: 110,
#   78565: 78,
#   78705: 3,
#   78707: 16,
#   78859: 5,
#   78914: 13,
#   79079: 18,
#   79090: 16,
#   79115: 12,
#   79292: 15,
#   80045: 6,
#   80106: 5,
#   80218: 13,
#   80430: 10,
#   80722: 3,
#   80813: 11,
#   80825: 3,
#   81114: 58,
#   81223: 39,
#   81233: 22,
#   81436: 9,
#   81745: 28,
#   81840: 25,
#   81960: 8,
#   81992: 11,
#   82100: 74,
#   82104: 2,
#   82150: 84,
#   82202: 28,
#   82211: 647,
#   82309: 9,
#   ...}}

# %%
print(len(patient_id_to_num_notes['pneumonia_dead']))
print(len(patient_id_to_num_notes['pneumonia_alive']))
# Out:
# 252
# 1167

# %%
pneumonia_dead_no_disch.loc[pneumonia_dead_no_disch["SUBJECT_ID_x"] == 111, ['ROW_ID_x','SUBJECT_ID_x','DESCRIPTION','TEXT', 'DEATHTIME']]
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 70391       70124           111
# 142529     151749           111
# 142097     151750           111
# 142303     151751           111
# 380576     375732           111
# 380109     375744           111
# 379907     375749           111
# 379806     375753           111
# 379909     375760           111
# 1066971   1079317           111
# 1065833   1079339           111
# 1067121   1079351           111
#
#                                                DESCRIPTION  \
# 70391                                               Report
# 142529                                              Report
# 142097                                              Report
# 142303                                              Report
# 380576                   Physician Resident Admission Note
# 380109                                      ICU Event Note
# 379907   Physician Resident/Attending Admission Note - ...
# 379806                          Social Work Admission Note
# 379909                                      ICU Event Note
# 1066971                                CHEST (PORTABLE AP)
# 1065833                                CHEST (PORTABLE AP)
# 1067121                         CHEST PORT. LINE PLACEMENT
#
#                                                       TEXT  \
# 70391    PATIENT/TEST INFORMATION:\nIndication: s/p PEA...
# 142529   Compared to the previous tracing QRS voltage i...
# 142097   Normal sinus rhythm, rate 80.  Biatrial abnorm...
# 142303   Normal sinus rhythm.  Q waves in leads V1-V2 c...
# 380576   Chief Complaint:  respiratory distress\n   HPI...
# 380109   Clinician:  Nurse\n   Pt admitted from the ED ...
# 379907   Chief Complaint:  respiratory distress\n   HPI...
# 379806   Social Work Initial Note:\n   Family Informati...
# 379909   TITLE:\n   Clinician:  Resident\n   Patient ex...
# 1066971  [**2144-7-1**] 2:43 AM\n CHEST (PORTABLE AP)  ...
# 1065833  [**2144-7-1**] 7:27 AM\n CHEST (PORTABLE AP); ...
# 1067121  [**2144-7-1**] 9:01 AM\n CHEST PORT. LINE PLAC...
#
#                    DEATHTIME
# 70391    2144-07-01 14:55:00
# 142529   2144-07-01 14:55:00
# 142097   2144-07-01 14:55:00
# 142303   2144-07-01 14:55:00
# 380576   2144-07-01 14:55:00
# 380109   2144-07-01 14:55:00
# 379907   2144-07-01 14:55:00
# 379806   2144-07-01 14:55:00
# 379909   2144-07-01 14:55:00
# 1066971  2144-07-01 14:55:00
# 1065833  2144-07-01 14:55:00
# 1067121  2144-07-01 14:55:00

# %%
def count_words_per_patient(disease_df, patient_id_to_num_notes):
    note_appearance_counter = {}
    number_of_patients = 0 # number of patients
    note_counter = 0

# -----------
    patient_id = -1
    word_set = set()
    note_event_counter = 0

    # Iterate through each note
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):

        
        patient_id_check = int(row['SUBJECT_ID_x'])
    
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check:
            number_of_patients += 1
            note_event_counter = 0
        
            for word in word_set:
                if word in note_appearance_counter:
                    note_appearance_counter[word] += 1
                else:
                    note_appearance_counter[word] = 1

        
            # reset word_set
            word_set = set()
        
        # update patient id
        patient_id = patient_id_check

            
        if patient_id_to_num_notes[patient_id_check] <= MIN_SEQ_LEN:
            continue
            
        if note_event_counter < patient_id_to_num_notes[patient_id] // USE_1_N_SEQ:
            note_event_counter += 1
            continue
                
        note_counter += 1
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        tokenized_note = word_tokenize(note)
        
        
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())
            if not stemmed_word in stop_words:
                word_set.add(stemmed_word)
    
    print(str(note_counter) + " note events")
    print("finished counting frequent words for patients!")
#     return note_counter, note_appearance_counter
    return number_of_patients, note_appearance_counter

# variable dictionaries
number_of_notes = {}
note_appearance_counter = {}

number_of_notes['pneumonia_dead'], note_appearance_counter['pneumonia_dead'] = count_words_per_patient(pneumonia_dead_no_disch, patient_id_to_num_notes['pneumonia_dead'])
number_of_notes['pneumonia_alive'], note_appearance_counter['pneumonia_alive'] = count_words_per_patient(pneumonia_alive_no_disch, patient_id_to_num_notes['pneumonia_alive'])
# Out:
# 100%|██████████| 11895/11895 [00:47<00:00, 250.27it/s]
#   0%|          | 24/46134 [00:00<03:23, 226.95it/s]
# 5989 note events
# finished counting frequent words for patients!
# 100%|██████████| 46134/46134 [03:00<00:00, 255.91it/s]
# 23172 note events
# finished counting frequent words for patients!

# %%
number_of_notes
# Out:
# {'pneumonia_dead': 252, 'pneumonia_alive': 1167}

# %%
print(note_appearance_counter)
# Out:
# {'pneumonia_dead': {'includ': 113, 'atropin': 8, 'proxi': 40, ']': 80, 'caucasian': 2, 'intub': 147, 'recommend': 82, 'cxr': 136, 'section': 56, 'unabl': 130, 'gaug': 57, 'approxim': 72, 'sw': 33, 'father': 16, 'soft': 154, 'qday': 4, 'et': 95, 'pneumothorax': 118, 'cardiac': 156, 'upright': 57, 'view': 119, 'loss': 52, 'ul': 64, 'balanc': 85, 'physic': 72, 'alcohol': 15, 'inh': 3, 'etho': 2, 'yo': 75, 'neck': 50, 'rate': 165, 'densiti': 45, 'plan': 161, 'u': 143, 'employ': 7, 'new': 160, 'imag': 136, 'unemploy': 1, 'refractori': 8, 'like': 172, 'exceed': 3, 'infus': 111, 'aris': 6, 'b': 106, 'weak': 65, 'left': 216, 'warfarin': 5, 'next': 81, 'friend': 32, 'control': 101, 'anion': 8, 'interim': 26, 'vasopressin': 27, 'girlfriend': 2, 'pericardi': 61, 'calcif': 59, 'went': 50, 'bag': 43, 'consult': 99, 'mg': 163, 'hypertens': 82, 'right': 211, 'process': 94, 'studi': 160, 'tc': 12, 'copd': 45, 'pneumonia': 203, 'taken': 60, 'ng': 131, 'lab': 132, 'though': 89, 'transfus': 52, 'meq': 92, 'port': 83, 'daughter': 84, 'long': 58, 'major': 40, 'cremat': 3, 'depress': 51, 'event': 121, 'fio': 119, 'pea': 8, 'apic': 43, 'cr': 88, 'rhythm': 126, 'pcv': 14, 'emot': 68, 'follow': 159, 'insp': 84, 'hospit': 75, 'enter': 58, 'provid': 114, 'addict': 8, 'adl': 9, 'emphysema': 28, 'ecg': 31, 'use': 112, 'g': 96, 'licsw': 11, 'regular': 66, 'care': 171, 'underli': 79, 'home': 99, 'repres': 91, 'shock': 66, 'malign': 32, 'bp': 181, 'promin': 65, 'dic': 20, 'ga': 70, 'contact': 91, 'statin': 17, 'boni': 11, 'bowel': 151, 'histori': 173, 'edema': 182, 'found': 81, 'rapid': 61, 'tf': 110, 'radiolog': 68, 'tachycardia': 94, 'boot': 52, 'fissur': 12, 'cvl': 42, 'arriv': 82, 'commun': 88, 'final': 196, 'volum': 119, 'pm': 197, 'azotemia': 6, 'reason': 199, 'full': 124, 'ipratropium': 6, 'anterior': 62, 'second': 40, 'hyperinfl': 5, 'sulcu': 7, 'abdomen': 119, 'dr': 150, 'antibiot': 102, 'compar': 163, 'entir': 36, 'appropri': 101, 'methylpr': 5, 'acid': 56, 'given': 180, 'pna': 151, 'sat': 167, 'bs': 138, 'tazo': 9, 'present': 189, 'report': 205, 'lead': 83, 'mottl': 15, 'kg': 111, 'c': 177, 'mmhg': 71, 'want': 92, 'npo': 121, 'flowsheet': 113, 'opac': 148, 'concern': 114, 'mosf': 3, 'bedsid': 127, 'allergi': 82, 'cultur': 100, 'lactat': 47, 'anicter': 12, 'situat': 29, 'expir': 58, 'experienc': 17, 'bili': 47, 'atenolol': 4, 'feel': 52, '[': 80, 'show': 131, 'evalu': 173, '>': 160, 'ill': 73, 'poor': 134, 'attempt': 119, 'anur': 28, 'hco': 15, 'psychiatr': 14, 'protocol': 57, 'etiolog': 57, 'develop': 87, 'ptt': 80, 'abg': 143, 'speak': 65, 'arf': 34, 'trend': 68, 'aspirin': 11, 'met': 61, 'niec': 13, 'extens': 86, 'clear': 163, 'fix': 29, 'ratio': 7, 'keep': 104, 'gtt': 134, 'tobacco': 15, 'independ': 19, 'need': 155, 'exchang': 20, 'amount': 132, 'artic': 2, 'sick': 18, 'know': 27, 'glycem': 62, 'connect': 7, 'arrang': 21, 'sun': 14, 'fir': 2, 'po': 143, 'bandemia': 11, 'meantim': 3, 'rr': 150, 'recent': 129, 'low': 172, 'assess': 176, 'progress': 166, 'access': 113, 'chemistri': 16, 'sodium': 63, 'r': 178, 'stress': 66, 'data': 132, 'stabl': 177, 'jvp': 18, 'map': 90, 'signific': 121, 'member': 57, 'lower': 166, 'jpg': 63, 'cage': 1, 'intact': 103, 'effus': 183, 'health': 39, 'around': 76, 'propofol': 31, 'earli': 73, 'tidal': 47, 'gap': 11, 'limb': 32, 'rebound': 8, 'undetect': 3, 'ns': 119, 'diagnosi': 176, 'note': 199, 'lymph': 71, 'drug': 55, 'drip': 79, 'consist': 152, 'worsen': 162, 'chief': 63, 'nurs': 141, 'followup': 38, 'later': 115, 'peripher': 97, 'disposit': 64, 'hemodynam': 111, 'agenc': 1, 'empir': 36, 'spontan': 91, 'dl': 70, 'ed': 61, 'clergi': 16, 'abov': 158, 'eeg': 7, 'inflammatori': 22, 'repeat': 107, 'short': 86, 'without': 143, 'bed': 103, 'baselin': 86, 'lvef': 38, 'law': 18, 'inform': 122, 'physician': 107, 'notabl': 38, 'tmax': 105, 'chang': 222, 'ph': 61, 'transient': 33, 'today': 148, 'despit': 90, 'primari': 43, 'bpm': 102, 'arrest': 27, 'blood': 141, 'hl': 5, 'homemak': 1, 'infiltr': 112, 'mix': 30, 'dure': 114, 'c ...

# %%
# # get hyper-paramters n_fold and threshold from user input
n_fold = float(3)
threshold = float(0.01)

frequent_word_lists = {}
factor = {}

# %%
"""function description:
for each disease in note_appearance_counter
    1. checks whether a word in disease file is frequent(frequency standard as defined by factor, n_fold, and threshold)
    2. adds to frequent_word_list
"""

# def find_frequent_word(note_appearance_counter, frequent_word_lists, number_of_notes, factor, n_fold, threshold):

# calculate normalizing factor for each disease
note_sum = 0

# Count from two labels
for disease in number_of_notes:
    note_sum += float(number_of_notes[disease])
    
for disease in number_of_notes:
    factor[disease] = number_of_notes[disease] / note_sum

# determine frequent word for each disease file
for disease in note_appearance_counter:
    frequent_word_lists[disease] = []

    print(disease + " has " + str(len(note_appearance_counter[disease])) + " unique words!")

    for word in note_appearance_counter[disease]:
        
        freq_check = True
        for check_disease in note_appearance_counter:
            
            if not disease == check_disease:
                if word in note_appearance_counter[check_disease]:
                    if not (note_appearance_counter[disease][word] / note_appearance_counter[check_disease][word] / factor[disease] * factor[check_disease] > n_fold \
                        and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):

                        freq_check = False
                        break

                else:
                    if not (note_appearance_counter[disease][word] > n_fold and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):
                        freq_check = False
                        break
        if freq_check:
            frequent_word_lists[disease].append((word))
            # Create a tuple of word and its count
#             frequent_word_lists[disease].append((word, note_appearance_counter[disease][word]))

        

print("finished making frequent words list for " + disease)
# Out:
# pneumonia_dead has 11678 unique words!
# pneumonia_alive has 22572 unique words!
# finished making frequent words list for pneumonia_alive

# %%
print(note_sum)
print(factor)

# number of notes
# 58029.0
# {'pneumonia_dead': 0.2049837150390322, 'pneumonia_alive': 0.7950162849609678}
# Out:
# 1419.0
# {'pneumonia_dead': 0.17758985200845667, 'pneumonia_alive': 0.8224101479915433}

# %%
print(len(frequent_word_lists['pneumonia_dead']))
print(len(frequent_word_lists['pneumonia_alive']))


# n_fold = float(3) threshold = float(0.01)
# 454
# 329

# n_fold = float(2) threshold = float(0.01)
# 914
# 600

# n_fold = float(1) threshold = float(0.01)
# 3320
# 2196
# Out:
# 454
# 329

# %%
print(frequent_word_lists)
# Out:
# {'pneumonia_dead': ['refractori', 'vasopressin', 'cremat', 'pea', 'pcv', 'dic', 'azotemia', 'mottl', 'expir', 'anur', 'arrang', 'clergi', 'arrest', 'recruit', 'bicarbon', 'norepinephrin', 'funer', 'phenylephrin', 'paralyt', 'elig', 'autopeep', 'suffer', 'acidem', 'hypercapnia', 'park', 'hypercapn', 'death', 'hypothermia', 'clinician', 'unrespons', 'cpr', 'profound', 'cmo', 'slough', 'dnr', 'dni', 'sluggish', 'nonpurpos', 'dk', 'gum', 'virtual', 'pinpoint', 'nacl', 'lubric', 'oder', 'float', 'mso', 'levoph', 'clariti', 'wish', 'bow', 'suport', 'prognosi', 'respon', 'grim', 'antb', 'gather', 'purpl', 'pronounc', 'dd', 'institut', 'hypotent', 'priest', 'option', 'viabl', 'remin', 'dead', 'peerla', 'mad', 'asystol', 'centimet', 'aprv', 'acv', 'agreement', 'bye', 'synch', 'mortem', 'life', 'depth', 'ppn', 'hover', 'nrbm', 'chaplain', 'cathol', 'peac', 'moniotr', 'sync', 'througout', 'surviv', 'mgx', 'duski', 'cvvhdf', 'neosynephrin', 'agon', 'vtach', 'acidot', 'deliv', 'mortum', 'corneal', 'vasopressor', 'suppport', 'pfr', 'rusti', 'cvvhd', 'quiac', 'seriou', 'defibril', 'jerk', 'deterior', 'pulseless', 'hemothorax', 'crrt', 'cvvh', 'unequ', 'maroon', 'quinton', 'cagluc', 'cooler', 'rewir', 'brb', 'multisystem', 'declin', 'among', 'towel', 'spiritu', 'uffp', 'lc', 'pitressin', 'ffp', 'bair', 'elimin', 'hypotherm', 'mtg', 'lw', 'ethic', 'ultrafiltr', 'gratitud', 'scl', 'hugger', 'pray', 'levof', 'cyanot', 'zero', 'triadyn', 'paco', 'autopsi', 'promod', 'warmer', 'morgu', 'sml', 'ashen', 'erythro', 'bond', 'ran', 'town', 'polymorph', 'discard', 'rabbi', 'motil', "tf'ing", 'norepi', 'escal', 'bairhugg', 'bank', 'prayer', 'circuit', 'syring', 'nahco', 'neo', 'absorb', 'discoordin', 'chane', 'asynchron', 'mind', 'unstabl', 'rediscuss', 'hunger', 'edt', '^rr', 'gc', 'dopamin', 'polici', 'hung', 'intiat', 'cantones', 'tacycard', 'palli', 'moan', 'artifici', 'fliud', 'readdress', 'overlay', 'ozz', 'acc', 'underneath', 'anuria', 'judgement', 'inclus', 'dobutamin', 'recalibr', 'gurgl', 'proph', 'broader', 'hospic', 'adenosin', 'platlet', 'platelet', 'oncologist', 'quadrent', 'anyway', 'cellcept', 'pheresi', 'cardiovert', 'influenc', 'sorb', 'griev', 'core', 'surgicel', 'gut', 'nephrolog', 'kerlix', 'psup', 'gvhd', 'hepati', 'oligur', 'cisatracurium', 'grimmac', 'fungemia', 'fc', 'extremitiy', 'pose', 'chemic', 'snt', 'twitch', 'caspofungin', 'premed', 'repsons', 'wether', 'oximetri', 'barotrauma', 'hiccup', 'fentenyl', 'ettub', 'fentani', 'plat', 'nephrogram', 'liw', 'sacrament', 'crt', 'lcw', 'postpylor', 'conc', 'rescan', 'grave', 'nonreact', 'chb', 'mail', 'heroic', 'nonrebreath', 'awhil', 'occupi', 'pleuravac', 'propos', 'struggl', 'familt', 'reappear', 'ultra', 'palliat', 'opinion', 'reveiw', 'icter', 'gentamycin', 'criticar', 'resucit', 'ardsnet', 'themselv', 'abruptli', 'fibrinogen', 'ogtub', 'preoxygen', 'pplat', 'tubular', 'wma', 'amongst', 'sooner', 'cvo', 'meaning', 'reguard', 'pneumonectomi', 'kyphoscoliosi', 'vasoconstrict', 'sibl', 'gasp', 'hook', 'recev', 'colour', 'realist', 'hida', 'tran', 'innumer', 'aricept', 'moreov', 'vigil', 'creep', 'pharmacolog', 'pvr', 'argatroban', 'aliv', 'unreli', 'irrevers', 'buck', 'derecruit', 'wil', 'epsiod', 'attemtp', 'eyelid', 'religi', 'ration', 'respitori', 'famil', 'imbal', 'myeloma', 'analgesia', 'dorsal', 'muddi', 'adam', 'declar', 'neob', 'od', 'moisten', 'diflucan', 'requr', 'heliox', 'emper', 'futil', 'osteoblast', 'illeu', 'currentl', 'perisplen', 'nimv', 'fli', 'preliminarili', 'plerual', 'rhochor', 'sluggishli', 'prioriti', 'esoph', 'forth', 'dysynchron', 'unplan', 'binder', 'occurr', 'ipf', 'goodby', 'ccn', 'meatu', 'stg', 'scopalamin', 'unarous', 'tobra', 'petechia', 'hemodynim', 'fentayl', 'harm', 'rite', 'bless', 'doen', 'furhter', 'calvarium', 'fmaili', 'montitor', 'stack', 'chol', 'figur', 'underpenetr', 'massag', 'thrombot', 'ggt', 'pyuria', 'outer', 'mrcp', 'contini', 'synchroni', 'formul', 'treatement', 'news', 'amioderon', 'mvo', 'unobtain', 'pastor', 'anasarc', 'led',  ...

# %% [markdown]
# ### 2. Co-occurrence generation
# FP-growth

# %%
FREQUENT_WORD_LIST = frequent_word_lists['pneumonia_dead'] + frequent_word_lists['pneumonia_alive']
print(len(FREQUENT_WORD_LIST))
print(len(set(FREQUENT_WORD_LIST)))
# Out:
# 783
# 783

# %%
"""function description:
generates frequent word set for the disease
"""
word_dict = {}
word_id = 1
stemmer = PorterStemmer()


for word in FREQUENT_WORD_LIST:
    if not word == "WORD":
        word_dict[stemmer.stem(word.strip())] = word_id
        word_id += 1
             
print(f"\nword dictionary created! Length: {len(word_dict)}\n")
print(word_dict)
# Out:
# word dictionary created! Length: 783
#
# {'refractori': 1, 'vasopressin': 2, 'cremat': 3, 'pea': 4, 'pcv': 5, 'dic': 6, 'azotemia': 7, 'mottl': 8, 'expir': 9, 'anur': 10, 'arrang': 11, 'clergi': 12, 'arrest': 13, 'recruit': 14, 'bicarbon': 15, 'norepinephrin': 16, 'funer': 17, 'phenylephrin': 18, 'paralyt': 19, 'elig': 20, 'autopeep': 21, 'suffer': 22, 'acidem': 23, 'hypercapnia': 24, 'park': 25, 'hypercapn': 26, 'death': 27, 'hypothermia': 28, 'clinician': 29, 'unrespon': 30, 'cpr': 31, 'profound': 32, 'cmo': 33, 'slough': 34, 'dnr': 35, 'dni': 36, 'sluggish': 37, 'nonpurpo': 38, 'dk': 39, 'gum': 40, 'virtual': 41, 'pinpoint': 42, 'nacl': 43, 'lubric': 44, 'oder': 45, 'float': 46, 'mso': 47, 'levoph': 48, 'clariti': 49, 'wish': 50, 'bow': 51, 'suport': 52, 'prognosi': 53, 'respon': 54, 'grim': 55, 'antb': 56, 'gather': 57, 'purpl': 58, 'pronounc': 59, 'dd': 60, 'institut': 61, 'hypot': 62, 'priest': 63, 'option': 64, 'viabl': 65, 'remin': 66, 'dead': 67, 'peerla': 68, 'mad': 69, 'asystol': 70, 'centimet': 71, 'aprv': 72, 'acv': 73, 'agreement': 74, 'bye': 75, 'synch': 76, 'mortem': 77, 'life': 78, 'depth': 79, 'ppn': 80, 'hover': 81, 'nrbm': 82, 'chaplain': 83, 'cathol': 84, 'peac': 85, 'moniotr': 86, 'sync': 87, 'througout': 88, 'surviv': 89, 'mgx': 90, 'duski': 91, 'cvvhdf': 92, 'neosynephrin': 93, 'agon': 94, 'vtach': 95, 'acidot': 96, 'deliv': 97, 'mortum': 98, 'corneal': 99, 'vasopressor': 100, 'suppport': 101, 'pfr': 102, 'rusti': 103, 'cvvhd': 104, 'quiac': 105, 'seriou': 106, 'defibril': 107, 'jerk': 108, 'deterior': 109, 'pulseless': 110, 'hemothorax': 111, 'crrt': 112, 'cvvh': 113, 'unequ': 114, 'maroon': 115, 'quinton': 116, 'cagluc': 117, 'cooler': 118, 'rewir': 119, 'brb': 120, 'multisystem': 121, 'declin': 122, 'among': 123, 'towel': 124, 'spiritu': 125, 'uffp': 126, 'lc': 127, 'pitressin': 128, 'ffp': 129, 'bair': 130, 'elimin': 131, 'hypotherm': 132, 'mtg': 133, 'lw': 134, 'ethic': 135, 'ultrafiltr': 136, 'gratitud': 137, 'scl': 138, 'hugger': 139, 'pray': 140, 'levof': 141, 'cyanot': 142, 'zero': 143, 'triadyn': 144, 'paco': 145, 'autopsi': 146, 'promod': 147, 'warmer': 148, 'morgu': 149, 'sml': 150, 'ashen': 151, 'erythro': 152, 'bond': 153, 'ran': 154, 'town': 155, 'polymorph': 156, 'discard': 157, 'rabbi': 158, 'motil': 159, "tf'ing": 160, 'norepi': 161, 'escal': 162, 'bairhugg': 163, 'bank': 164, 'prayer': 165, 'circuit': 166, 'syre': 167, 'nahco': 168, 'neo': 169, 'absorb': 170, 'discoordin': 171, 'chane': 172, 'asynchron': 173, 'mind': 174, 'unstabl': 175, 'rediscuss': 176, 'hunger': 177, 'edt': 178, '^rr': 179, 'gc': 180, 'dopamin': 181, 'polici': 182, 'hung': 183, 'intiat': 184, 'canton': 185, 'tacycard': 186, 'palli': 187, 'moan': 188, 'artifici': 189, 'fliud': 190, 'readdress': 191, 'overlay': 192, 'ozz': 193, 'acc': 194, 'underneath': 195, 'anuria': 196, 'judgement': 197, 'inclu': 198, 'dobutamin': 199, 'recalibr': 200, 'gurgl': 201, 'proph': 202, 'broader': 203, 'hospic': 204, 'adenosin': 205, 'platlet': 206, 'platelet': 207, 'oncologist': 208, 'quadrent': 209, 'anyway': 210, 'cellcept': 211, 'pheresi': 212, 'cardiovert': 213, 'influenc': 214, 'sorb': 215, 'griev': 216, 'core': 217, 'surgicel': 218, 'gut': 219, 'nephrolog': 220, 'kerlix': 221, 'psup': 222, 'gvhd': 223, 'hepati': 224, 'oligur': 225, 'cisatracurium': 226, 'grimmac': 227, 'fungemia': 228, 'fc': 229, 'extremitiy': 230, 'pose': 231, 'chemic': 232, 'snt': 233, 'twitch': 234, 'caspofungin': 235, 'preme': 236, 'repson': 237, 'wether': 238, 'oximetri': 239, 'barotrauma': 240, 'hiccup': 241, 'fentenyl': 242, 'ettub': 243, 'fentani': 244, 'plat': 245, 'nephrogram': 246, 'liw': 247, 'sacrament': 248, 'crt': 249, 'lcw': 250, 'postpylor': 251, 'conc': 252, 'rescan': 253, 'grave': 254, 'nonreact': 255, 'chb': 256, 'mail': 257, 'heroic': 258, 'nonrebreath': 259, 'awhil': 260, 'occupi': 261, 'pleuravac': 262, 'propo': 263, 'struggl': 264, 'familt': 265, 'reappear': 266, 'ultra': 267, 'palliat': 268, 'opinion': 269, 'reveiw': 270, 'icter': 271, 'gentamycin': 272, 'criticar': 273, 'resucit ...

# %% [markdown]
# ### Implementetion with python for FP_growth

# %% [markdown]
# ### Count co-occurrences per patient

# %%
import os
import operator
from pathlib import Path
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import math

# ----
def fp_growth_input_per_patient_python(disease_df, word_dict, min_support):
    
    # For dataframe
    patient_cooc_dict = {}
    patient_node_dict = {}
    patient_note_cnt = {}
    
    # --------------    
    patient_id = -1
    note_cnt = 0
    patient_note_list = []
    
    # read line in from file (each line is one note)
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        
        # only regard certain type of notes
        patient_id_check = int(row['SUBJECT_ID_x'])
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        patient_word_set = set()
    
#         print(f"patient_id_check: {patient_id_check}, patient_id: {patient_id}")
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check and not patient_id == -1:
            te = TransactionEncoder()
            te_ary = te.fit(patient_note_list).transform(patient_note_list)
            df = pd.DataFrame(te_ary, columns=te.columns_)
            df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
            cooc_tmp = []
            cooc_minsup_tmp = []
            node_minsup_tmp = []
            cooc_node_idx_tmp = []
            
            for index, row in df_itemsets.iterrows():
                if len(row['itemsets']) == 1:
                    word = list(row['itemsets'])[0]
                    min_sup = row['support']

                    node_minsup_tmp.append(len(patient_note_list) * row['support'])
                    cooc_node_idx_tmp.append(word)
                    
                if len(row['itemsets']) == 2:
                    cooc_ = sorted(list(row['itemsets']))
                    cooc_tmp.append(cooc_)
                    cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
            
            cooc_dict = {}

            for num, i in enumerate(cooc_tmp):
                if tuple(i) not in cooc_dict:
                    cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

            # dictionary = dict(zip(keys, values))
            node_dict = {}
            for num, i in enumerate(cooc_node_idx_tmp):
                if i not in node_dict:
                    node_dict[i] = node_minsup_tmp[num]
                    
            # Update glob lists
            if patient_id not in patient_cooc_dict:
                patient_cooc_dict[patient_id] = cooc_dict
                patient_node_dict[patient_id] = node_dict
                patient_note_cnt[patient_id] = note_cnt
            else:
                print(f"patient_id: {patient_id} is already in the dictionary!")
            
            
            # Reset local lists
            patient_note_list = []
            note_cnt = 0
                    
        # update patient id
        patient_id = patient_id_check
        tokenized_note = word_tokenize(note)
        note_cnt += 1

        # loop through each word in note to count word belonging to each disease
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())       
            if stemmed_word in word_dict:
                    patient_word_set.add(stemmed_word)

        templst = []
        for word in patient_word_set:
            templst.append(word)

        if templst:
            patient_note_list.append(templst)
    
    # Last patient info
    te = TransactionEncoder()
    te_ary = te.fit(patient_note_list).transform(patient_note_list)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
    cooc_tmp = []
    cooc_minsup_tmp = []
    #-----
    node_minsup_tmp = []
    cooc_node_idx_tmp = []
            
    for index, row in df_itemsets.iterrows():
        if len(row['itemsets']) == 1:
            word = list(row['itemsets'])[0]
            node_minsup_tmp.append(len(patient_note_list) * row['support'])
            cooc_node_idx_tmp.append(word)

        if len(row['itemsets']) == 2:
            cooc_ = sorted(list(row['itemsets']))
            cooc_tmp.append(cooc_)
            cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
    
                    
    cooc_dict = {}

    for num, i in enumerate(cooc_tmp):
        if tuple(i) not in cooc_dict:
            cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

    # dictionary = dict(zip(keys, values))
    node_dict = {}
    for num, i in enumerate(cooc_node_idx_tmp):
        if i not in node_dict:
            node_dict[i] = node_minsup_tmp[num]

    # Update glob lists
    if patient_id not in patient_cooc_dict:
        patient_cooc_dict[patient_id] = cooc_dict
        patient_node_dict[patient_id] = node_dict
        patient_note_cnt[patient_id] = note_cnt
    else:
        print(f"patient_id: {patient_id} is already in the dictionary!")

    return patient_node_dict, patient_cooc_dict, patient_note_cnt

patient_node_0, patient_cooc_0, patient_note_num_0 = fp_growth_input_per_patient_python(pneumonia_dead_no_disch, word_dict, 0.15)
patient_node_1, patient_cooc_1, patient_note_num_1 = fp_growth_input_per_patient_python(pneumonia_alive_no_disch, word_dict, 0.15)
# Out:
# 100%|██████████| 11895/11895 [01:41<00:00, 116.67it/s]
# 100%|██████████| 46134/46134 [06:27<00:00, 118.92it/s]

# %%
print(patient_node_1)
# Out:
# {68: {'commod': 4.0, 'ambul': 4.0, 'gait': 2.0, 'chair': 2.0, 'oob': 2.0}, 85: {'lat': 1.0}, 94: {'lift': 11.0, 'dopamin': 11.0}, 165: {'habitu': 1.0}, 211: {'dopamin': 3.0, 'aox': 3.0, 'levoph': 3.0}, 224: {'lat': 1.0, 'rigor': 1.0, 'platelet': 1.0, 'commod': 1.0, 'awhil': 1.0, 'fax': 1.0, 'bank': 1.0, 'pleasant': 1.0, 'chair': 1.0}, 231: {}, 283: {'recruit': 10.0, 'criticar': 10.0}, 357: {'unasyn': 4.0, 'intent': 2.0, 'dz': 2.0, 'ctx': 2.0, 'moan': 4.0, 'distort': 2.0}, 368: {'pleasant': 3.0, 'dnr': 3.0, 'hhn': 3.0, 'oob': 6.0, 'ambul': 4.0}, 370: {'dnr': 2.0}, 384: {'bipolar': 9.0, 'wish': 4.0, 'dnr': 3.0, 'schizophrenia': 4.0}, 426: {'align': 1.0, 'mottl': 1.0, 'lat': 1.0, 'unenhanc': 1.0, 'mail': 1.0, 'bronchovascular': 1.0, 'pleasant': 1.0, 'arthrit': 1.0}, 509: {'oob': 3.0}, 514: {'lat': 1.0, 'schizophrenia': 1.0, 'nicotin': 1.0, 'lighthead': 1.0, 'burn': 1.0, 'pleasant': 2.0, 'commod': 2.0, 'ambul': 1.0, 'oob': 1.0}, 596: {'dnr': 4.0, 'dopamin': 3.0, 'dni': 4.0, 'chair': 2.0}, 674: {'profound': 1.0, 'nimv': 1.0, 'xl': 2.0, 'rememb': 1.0, 'neo': 1.0, 'mso': 1.0, 'lotion': 1.0, 'tranfer': 1.0, 'fu': 1.0, 'cardiovert': 1.0}, 707: {'pleasantli': 4.0, 'lpm': 2.0, 'oob': 3.0, 'pleasant': 2.0}, 711: {'dnr': 190.99999999999997, 'mellitu': 78.0, 'fibrinogen': 186.0, 'captopril': 77.0, 'olanzapin': 109.0, 'palli': 60.0, 'fungemia': 95.0, 'caspofungin': 105.0}, 770: {'iddm': 24.0, 'vp': 20.0}, 773: {'pneumococc': 7.0, 'mso': 8.0, 'levoph': 8.0}, 899: {'lat': 2.0, 'chip': 2.0, 'pleasant': 3.0}, 1096: {'syst': 1.0, 'ppd': 1.0, 'lc': 1.0, 'forc': 1.0, 'tubular': 1.0}, 1135: {'scab': 3.0, 'oob': 6.0, 'chair': 7.0, 'argatroban': 4.0, 'pleasant': 3.0, 'lat': 3.0, 'xl': 3.0}, 1163: {'osa': 1.0, 'pleasant': 1.0, 'twitch': 1.0, 'captopril': 1.0}, 1174: {}, 1180: {'influenc': 1.0}, 1283: {'unavail': 1.0, 'seat': 1.0, 'habitu': 1.0}, 1332: {'levoph': 4.0, 'dnr': 6.0, 'dni': 5.0, 'oob': 4.0}, 1339: {'oob': 20.0, 'stair': 18.0, 'ctx': 18.0, 'ambul': 18.0, 'seroquel': 23.0, 'video': 22.0, 'barium': 18.0, 'phenylephrin': 25.0, 'neo': 27.0}, 1546: {'asthma': 4.0, 'spacer': 2.0, 'oob': 2.0, 'db': 2.0}, 1568: {'pericard': 5.0, 'pleasant': 4.0, 'oob': 2.0}, 1601: {'levoph': 3.0, 'pleasant': 2.0, 'ambien': 2.0}, 1606: {'precordium': 1.0, 'unalt': 1.0, 'dnr': 1.0, 'dni': 1.0, 'lat': 1.0, 'dome': 1.0}, 1642: {'pleasant': 2.0, 'dnr': 2.0, 'dni': 2.0, 'quadrent': 1.0, 'declin': 1.0}, 1660: {'behavior': 2.0, 'pleasant': 2.0}, 1895: {'pleasant': 2.0}, 1923: {'moan': 3.0, 'dnr': 3.0, 'sarna': 2.0, 'lotion': 2.0}, 2029: {'xanax': 28.0, 'dnr': 20.0}, 2090: {'chair': 18.0, 'splint': 13.0, 'dyslipidemia': 23.000000000000004, 'ctx': 17.0, 'bromid': 17.0, 'ntnd': 14.000000000000002}, 2098: {'hugger': 4.0, 'bair': 4.0, 'cpr': 2.0}, 2128: {'dopamin': 10.0, 'mso': 6.0, 'unasyn': 4.0, 'flight': 3.0}, 2170: {'qtc': 1.0, 'nonrebreath': 1.0, 'spur': 2.0, 'lat': 1.0}, 2187: {'osa': 2.0, 'morbid': 2.0, 'captopril': 2.0}, 2208: {'vp': 35.0, 'bipolar': 16.0, 'clonidin': 19.0, 'levoph': 16.0}, 2337: {'smooth': 1.0, 'hemangioma': 1.0, 'slough': 1.0, 'pleasant': 1.0, 'dnr': 2.0, 'pleasantli': 1.0}, 2378: {'ultram': 16.0, 'silent': 16.0, 'video': 15.0, 'sensat': 13.0}, 2386: {'dnr': 7.0, 'hospic': 3.0, 'town': 2.0, 'dni': 3.0}, 2452: {'lat': 4.0}, 2508: {'levoph': 2.0, 'dopamin': 2.0, 'ppd': 2.0, 'ciwa': 2.0, 'lpm': 2.0, 'chair': 2.0}, 2561: {}, 2585: {'hilum': 2.0, 'para': 1.0, 'ultram': 1.0, 'sluggish': 1.0, 'prognosi': 1.0, 'hook': 1.0, 'grave': 1.0, 'dnr': 1.0, 'dni': 1.0}, 2589: {'bipolar': 28.000000000000004, 'pneumococc': 22.0, 'zyprexa': 7.000000000000001, 'dz': 9.0, 'mood': 7.000000000000001, 'historian': 10.0}, 2590: {'dnr': 2.0, 'dni': 2.0, 'nonrebreath': 1.0, 'venti': 2.0, 'lpm': 1.0, 'pleasant': 1.0}, 2628: {}, 2658: {'moan': 3.0}, 2732: {'vertebra': 2.0, 'lat': 2.0}, 2784: {'arrest': 2.0, 'commod': 3.0, 'video': 2.0, 'diaper': 2.0, 'gait': 2.0}, 2823: {'dnr': 4.0, 'venti': 3.0, 'dni': 3.0}, 3070: {'svn': 2.0, 'osa': 1.0, 'ofm': 1.0, 'pleasant': 1.0, 'video': 1.0, ...

# %%
print(patient_cooc_1)
# Out:
# {68: {('ambul', 'commod'): 3.0, ('ambul', 'oob'): 2.0, ('commod', 'oob'): 2.0}, 85: {}, 94: {}, 165: {}, 211: {}, 224: {('platelet', 'rigor'): 1.0, ('commod', 'platelet'): 1.0, ('commod', 'rigor'): 1.0, ('bank', 'fax'): 1.0, ('chair', 'pleasant'): 1.0}, 231: {}, 283: {}, 357: {('intent', 'unasyn'): 2.0, ('dz', 'intent'): 2.0, ('dz', 'unasyn'): 2.0, ('ctx', 'unasyn'): 2.0}, 368: {}, 370: {}, 384: {('bipolar', 'wish'): 4.0}, 426: {('lat', 'mottl'): 1.0, ('mail', 'unenhanc'): 1.0, ('bronchovascular', 'mail'): 1.0, ('bronchovascular', 'unenhanc'): 1.0, ('arthrit', 'pleasant'): 1.0}, 509: {}, 514: {('nicotin', 'schizophrenia'): 1.0, ('lighthead', 'nicotin'): 1.0, ('lighthead', 'schizophrenia'): 1.0, ('burn', 'lighthead'): 1.0, ('burn', 'nicotin'): 1.0, ('burn', 'schizophrenia'): 1.0, ('commod', 'pleasant'): 2.0, ('ambul', 'commod'): 1.0, ('ambul', 'pleasant'): 1.0, ('commod', 'oob'): 1.0, ('oob', 'pleasant'): 1.0}, 596: {('dni', 'dnr'): 2.0}, 674: {('nimv', 'profound'): 1.0, ('rememb', 'xl'): 1.0, ('neo', 'rememb'): 1.0, ('neo', 'xl'): 1.0, ('mso', 'neo'): 1.0, ('mso', 'rememb'): 1.0, ('mso', 'xl'): 1.0, ('lotion', 'mso'): 1.0, ('lotion', 'neo'): 1.0, ('lotion', 'rememb'): 1.0, ('lotion', 'xl'): 1.0, ('tranfer', 'xl'): 1.0, ('fu', 'tranfer'): 1.0, ('fu', 'xl'): 1.0, ('cardiovert', 'fu'): 1.0, ('cardiovert', 'tranfer'): 1.0, ('cardiovert', 'xl'): 1.0}, 707: {('oob', 'pleasantli'): 2.0}, 711: {('fibrinogen', 'mellitu'): 59.0, ('dnr', 'fibrinogen'): 159.0, ('captopril', 'fibrinogen'): 66.0, ('fibrinogen', 'olanzapin'): 99.0, ('dnr', 'olanzapin'): 85.0, ('dnr', 'fungemia'): 80.0, ('fibrinogen', 'fungemia'): 78.0, ('caspofungin', 'fungemia'): 87.0, ('fungemia', 'olanzapin'): 57.0, ('caspofungin', 'dnr'): 81.0, ('caspofungin', 'fibrinogen'): 79.0}, 770: {('iddm', 'vp'): 16.0}, 773: {}, 899: {}, 1096: {('ppd', 'syst'): 1.0}, 1135: {('chair', 'oob'): 4.0, ('argatroban', 'chair'): 3.0}, 1163: {('captopril', 'twitch'): 1.0}, 1174: {}, 1180: {}, 1283: {('seat', 'unavail'): 1.0, ('habitu', 'unavail'): 1.0, ('habitu', 'seat'): 1.0}, 1332: {('dni', 'dnr'): 5.0}, 1339: {('oob', 'stair'): 18.0, ('ctx', 'stair'): 18.0, ('ctx', 'oob'): 18.0, ('ambul', 'ctx'): 18.0, ('ambul', 'stair'): 18.0, ('ambul', 'oob'): 18.0, ('phenylephrin', 'video'): 15.0, ('barium', 'video'): 15.0}, 1546: {('db', 'oob'): 2.0}, 1568: {('pericard', 'pleasant'): 3.0, ('oob', 'pleasant'): 2.0}, 1601: {('levoph', 'pleasant'): 2.0}, 1606: {('dni', 'dnr'): 1.0}, 1642: {('dnr', 'pleasant'): 2.0, ('dni', 'pleasant'): 2.0, ('pleasant', 'quadrent'): 1.0, ('declin', 'pleasant'): 1.0, ('dni', 'dnr'): 2.0, ('dnr', 'quadrent'): 1.0, ('declin', 'dnr'): 1.0, ('dni', 'quadrent'): 1.0, ('declin', 'dni'): 1.0, ('declin', 'quadrent'): 1.0}, 1660: {}, 1895: {}, 1923: {('dnr', 'moan'): 2.0, ('dnr', 'sarna'): 2.0, ('moan', 'sarna'): 2.0, ('lotion', 'sarna'): 2.0, ('dnr', 'lotion'): 2.0, ('lotion', 'moan'): 2.0}, 2029: {}, 2090: {('ctx', 'dyslipidemia'): 13.0, ('bromid', 'dyslipidemia'): 17.0}, 2098: {('bair', 'hugger'): 4.0}, 2128: {('dopamin', 'mso'): 4.0, ('dopamin', 'unasyn'): 3.0}, 2170: {}, 2187: {('morbid', 'osa'): 2.0}, 2208: {('bipolar', 'vp'): 16.0}, 2337: {('hemangioma', 'smooth'): 1.0, ('pleasant', 'slough'): 1.0, ('dnr', 'pleasantli'): 1.0}, 2378: {('silent', 'video'): 14.000000000000002, ('sensat', 'video'): 12.0, ('sensat', 'silent'): 12.0}, 2386: {('dnr', 'hospic'): 3.0, ('dnr', 'town'): 2.0, ('dni', 'dnr'): 3.0}, 2452: {}, 2508: {('dopamin', 'levoph'): 2.0}, 2561: {}, 2585: {('hilum', 'para'): 1.0, ('prognosi', 'sluggish'): 1.0, ('hook', 'prognosi'): 1.0, ('hook', 'sluggish'): 1.0, ('grave', 'hook'): 1.0, ('grave', 'prognosi'): 1.0, ('grave', 'sluggish'): 1.0, ('dnr', 'grave'): 1.0, ('dnr', 'hook'): 1.0, ('dnr', 'prognosi'): 1.0, ('dnr', 'sluggish'): 1.0, ('dni', 'dnr'): 1.0, ('dni', 'grave'): 1.0, ('dni', 'hook'): 1.0, ('dni', 'prognosi'): 1.0, ('dni', 'sluggish'): 1.0}, 2589: {('bipolar', 'pneumococc'): 19.0, ('pneumococc', 'zyprexa'): 7.000000000000001, ('bipolar', 'zyprexa'): 7. ...

# %%
patient_note_num_0
# Out:
# {111: 12,
#  346: 25,
#  404: 3,
#  546: 6,
#  618: 16,
#  705: 15,
#  726: 48,
#  1039: 55,
#  1556: 37,
#  1872: 3,
#  1944: 56,
#  2286: 69,
#  2990: 166,
#  3055: 29,
#  3099: 13,
#  3201: 8,
#  3526: 7,
#  3773: 6,
#  3881: 20,
#  4122: 51,
#  4754: 101,
#  4811: 21,
#  5476: 1,
#  5494: 22,
#  5774: 104,
#  5786: 152,
#  5913: 1,
#  6133: 68,
#  6735: 13,
#  6745: 13,
#  6973: 36,
#  6981: 8,
#  7277: 66,
#  7310: 8,
#  7924: 9,
#  7977: 9,
#  9908: 11,
#  9984: 15,
#  10302: 100,
#  10510: 86,
#  10545: 10,
#  10642: 10,
#  11049: 14,
#  11209: 9,
#  11395: 41,
#  12530: 24,
#  12849: 50,
#  13098: 46,
#  13566: 23,
#  14125: 9,
#  14514: 96,
#  14965: 25,
#  15159: 15,
#  15251: 11,
#  15396: 17,
#  15566: 37,
#  15853: 45,
#  16275: 17,
#  16344: 27,
#  16622: 51,
#  16684: 29,
#  17122: 16,
#  17354: 5,
#  17802: 64,
#  17983: 65,
#  18094: 23,
#  18736: 35,
#  18768: 46,
#  18848: 205,
#  18971: 26,
#  19243: 25,
#  19323: 6,
#  19390: 21,
#  19463: 20,
#  19535: 59,
#  19754: 13,
#  19827: 22,
#  19833: 58,
#  19872: 10,
#  20006: 8,
#  20023: 9,
#  20190: 6,
#  21046: 101,
#  21094: 36,
#  21427: 10,
#  21502: 102,
#  21580: 52,
#  21676: 12,
#  21699: 7,
#  21979: 11,
#  22735: 15,
#  23660: 12,
#  23795: 78,
#  24181: 13,
#  24582: 37,
#  24725: 57,
#  24730: 19,
#  24854: 25,
#  25003: 182,
#  25046: 7,
#  25774: 61,
#  25975: 9,
#  26474: 89,
#  26578: 15,
#  26716: 41,
#  26774: 3,
#  26849: 33,
#  27005: 5,
#  27145: 24,
#  27421: 61,
#  27431: 5,
#  27496: 7,
#  27504: 72,
#  27639: 221,
#  28004: 13,
#  28072: 34,
#  28178: 202,
#  28427: 6,
#  28498: 25,
#  28726: 34,
#  28750: 19,
#  28906: 32,
#  28907: 13,
#  28933: 394,
#  29105: 468,
#  29588: 72,
#  29647: 26,
#  29872: 225,
#  30476: 174,
#  30549: 12,
#  30614: 8,
#  30699: 14,
#  30786: 9,
#  30941: 110,
#  31030: 168,
#  31134: 24,
#  31139: 9,
#  31451: 48,
#  31556: 57,
#  31690: 18,
#  31692: 35,
#  32050: 34,
#  32326: 24,
#  32618: 42,
#  41546: 25,
#  43937: 6,
#  44851: 274,
#  45381: 16,
#  46589: 26,
#  46763: 6,
#  47045: 9,
#  48632: 147,
#  49079: 20,
#  49683: 3,
#  49922: 13,
#  50093: 8,
#  50231: 3,
#  50556: 216,
#  50859: 537,
#  51914: 313,
#  52010: 12,
#  53105: 115,
#  53399: 78,
#  54193: 85,
#  54401: 14,
#  54408: 2,
#  54739: 75,
#  54946: 7,
#  55400: 5,
#  55570: 14,
#  55887: 37,
#  55944: 34,
#  55987: 20,
#  56390: 19,
#  56648: 8,
#  56854: 170,
#  57091: 88,
#  57102: 35,
#  58702: 479,
#  59260: 11,
#  59437: 26,
#  60849: 2,
#  60868: 6,
#  61652: 7,
#  61667: 30,
#  63039: 8,
#  65513: 8,
#  68044: 40,
#  68095: 23,
#  68184: 5,
#  68308: 8,
#  68860: 14,
#  69719: 13,
#  69745: 25,
#  69776: 17,
#  70226: 8,
#  70447: 9,
#  72930: 11,
#  73811: 9,
#  73888: 109,
#  74316: 2,
#  74444: 81,
#  74686: 75,
#  75824: 10,
#  76282: 21,
#  76827: 2,
#  77382: 10,
#  78241: 3,
#  78388: 14,
#  79008: 27,
#  79055: 21,
#  79222: 18,
#  79877: 156,
#  80637: 148,
#  80678: 9,
#  80737: 46,
#  80805: 79,
#  81437: 27,
#  82393: 5,
#  82769: 85,
#  83932: 2,
#  84474: 34,
#  85160: 8,
#  85258: 52,
#  85404: 11,
#  85797: 9,
#  86007: 35,
#  86394: 4,
#  86684: 11,
#  86832: 67,
#  86863: 8,
#  86872: 326,
#  88193: 16,
#  88660: 11,
#  90256: 18,
#  91350: 19,
#  92074: 28,
#  92278: 52,
#  92331: 42,
#  93422: 7,
#  94341: 2,
#  94997: 9,
#  95280: 23,
#  95803: 18,
#  95830: 33,
#  95933: 56,
#  96699: 85,
#  97181: 30,
#  97795: 60,
#  98009: 33,
#  98299: 29,
#  98597: 2}

# %% [markdown]
# #### Create set of patient co-occurrences from two groups

# %%
# Create a set of all unique co-occurrences from both group
patient_cooc_set = set()
patient_cooc_0_dict = {}
patient_cooc_1_dict = {}

for k, v in patient_cooc_0.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_0_dict:
            patient_cooc_0_dict[item] = v[item]
        else:
            patient_cooc_0_dict[item] = patient_cooc_0_dict[item] + v[item]
            
    
for k, v in patient_cooc_1.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_1_dict:
            patient_cooc_1_dict[item] = v[item]
        else:
            patient_cooc_1_dict[item] = patient_cooc_1_dict[item] + v[item]

# %%
print(len(patient_cooc_set))
print(len(patient_cooc_0_dict))
print(len(patient_cooc_1_dict))
# Out:
# 6776
# 1989
# 5152

# %%
# count log-odds score

# reverse
# --------------- co-occurrences --------------->

        
# Get the set of coocurrencies from two groups
# Count log_odd_score

patient_cooc_odd_scores = {}
for set_item in patient_cooc_set:
    if set_item in patient_cooc_0_dict and set_item in patient_cooc_1_dict: 
        d_prob = patient_cooc_0_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        a_prob = patient_cooc_1_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
# --------------- co-occurrences ---------------<

# %%
patient_cooc_odd_scores
# Out:
# {('aricept', 'gentamycin'): -6.90875477931522,
#  ('dnr', 'refractori'): 6.90875477931522,
#  ('aricept', 'romi'): 6.90875477931522,
#  ('oncologist', 'pleasant'): 6.90875477931522,
#  ('fu', 'ntnd'): 6.90875477931522,
#  ('autopsi', 'dead'): -6.90875477931522,
#  ('appi', 'dnr'): 6.90875477931522,
#  ('gait', 'sarna'): 6.90875477931522,
#  ('ligament', 'treitz'): 0.6916505477038827,
#  ('director', 'zero'): 6.90875477931522,
#  ('dd', 'dnr'): 6.90875477931522,
#  ('romi', 'scar'): 6.90875477931522,
#  ('death', 'intiat'): -6.90875477931522,
#  ('adenocarcinoma', 'natg'): 6.90875477931522,
#  ('hypothermia', 'wma'): 6.90875477931522,
#  ('herp', 'nephrolog'): 6.90875477931522,
#  ('agon', 'pea'): -6.90875477931522,
#  ('adam', 'captopril'): -6.90875477931522,
#  ('dermat', 'pharmacolog'): 6.90875477931522,
#  ('cmo', 'lpm'): -6.90875477931522,
#  ('dni', 'surviv'): 6.90875477931522,
#  ('asthma', 'coach'): 6.90875477931522,
#  ('breakfast', 'video'): 6.90875477931522,
#  ('levoph', 'trazodon'): 6.90875477931522,
#  ('agon', 'readmit'): 6.90875477931522,
#  ('cocain', 'lac'): 6.90875477931522,
#  ('calculi', 'rehabilit'): 6.90875477931522,
#  ('barium', 'cooki'): 6.90875477931522,
#  ('incis', 'occipit'): 6.90875477931522,
#  ('laminectomi', 'stitch'): 6.90875477931522,
#  ('lpm', 'moan'): 6.90875477931522,
#  ('cash', 'hospic'): 6.90875477931522,
#  ('aliv', 'jewelri'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('bank', 'gabapentin'): 6.90875477931522,
#  ('freeli', 'refractori'): 6.90875477931522,
#  ('fatti', 'pca'): 6.90875477931522,
#  ('azotemia', 'wish'): 6.90875477931522,
#  ('flight', 'magnevist'): 6.90875477931522,
#  ('cocain', 'rm'): 6.90875477931522,
#  ('hypothermia', 'prilosec'): 6.90875477931522,
#  ('burn', 'historian'): 6.90875477931522,
#  ('burn', 'dnr'): 6.90875477931522,
#  ('foci', 'gastrojejunostomi'): 6.90875477931522,
#  ('epidur', 'norepinephrin'): 6.90875477931522,
#  ('dni', 'unasyn'): 6.90875477931522,
#  ('cocain', 'nifedipin'): 6.90875477931522,
#  ('gvhd', 'xii'): 6.90875477931522,
#  ('oligur', 'wish'): -6.90875477931522,
#  ('adenosin', 'vasopressin'): 6.90875477931522,
#  ('oncologist', 'paperwork'): 6.90875477931522,
#  ('dyslipidemia', 'gait'): 6.90875477931522,
#  ('historian', 'young'): 6.90875477931522,
#  ('dizzi', 'levoph'): 6.90875477931522,
#  ('pea', 'wish'): -6.90875477931522,
#  ('cocain', 'sweat'): 6.90875477931522,
#  ('plate', 'splint'): 6.90875477931522,
#  ('dnr', 'lift'): 6.90875477931522,
#  ('vasopressor', 'vtach'): -6.90875477931522,
#  ('aliv', 'mind'): 6.90875477931522,
#  ('expir', 'forc'): 6.90875477931522,
#  ('cmo', 'hypotherm'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('anuria', 'arrest'): 6.90875477931522,
#  ('breakfast', 'esld'): 6.90875477931522,
#  ('xii', 'young'): 6.90875477931522,
#  ('platelet', 'rhinorrhea'): 1.095952712632351,
#  ('breakfast', 'fibrinogen'): 6.90875477931522,
#  ('asthma', 'habitu'): 6.90875477931522,
#  ('gasp', 'mso'): -6.90875477931522,
#  ('jewelri', 'probe'): 6.90875477931522,
#  ('intiat', 'pronounc'): -6.90875477931522,
#  ('fax', 'pleasant'): 6.90875477931522,
#  ('hospic', 'hunger'): -6.90875477931522,
#  ('colonoscopi', 'motor'): 6.90875477931522,
#  ('levoph', 'sweat'): 6.90875477931522,
#  ('angioplasti', 'cyanot'): 6.90875477931522,
#  ('anur', 'gabapentin'): 6.90875477931522,
#  ('dni', 'profound'): 0.6916505477038827,
#  ('anur', 'ggt'): -6.90875477931522,
#  ('ambien', 'commod'): 6.90875477931522,
#  ('barium', 'lusb'): 6.90875477931522,
#  ('dobutamin', 'intiat'): 6.90875477931522,
#  ('db', 'rm'): 6.90875477931522,
#  ('cocain', 'herp'): 6.90875477931522,
#  ('expir', 'wish'): -6.90875477931522,
#  ('db', 'dyslipidemia'): 6.90875477931522,
#  ('iddm', 'tubular'): 6.90875477931522,
#  ('escal', 'neo'): -6.90875477931522,
#  ('profound', 'romi'): 6.90875477931522,
#  ('pastor', 'pea'): -6.90875477931522,
#  ('dopamin', 'lat'): 6.90875477931522,
#  ('captopril', 'core'): -6.90875477931522,
#  ('foci', 'postop'): 6.90875477931522,
#  ('aaox', 'dz'): 6.90875477931522,
#  ('mellitu', 'palli'): 6.90875477931522,
#  ('predict', 'rabbi'): -6.90875477931522,
#  ('hive', 'platelet'): -6.90875477931522,
#  ('levoph', 'vasoconstrict'): -6.90875477931522,
#  ('aricept', 'cash'): -6.90875477931522,
#  ('omeprazol', 'solut'): 6.90875477931522,
#  ('dizzi', 'dni'): 6.90875477931522,
#  ('fibrinogen', 'pod'): 6.90875477931522,
#  ('autopsi', 'pea'): -6.90875477931522,
#  ('motor', 'unavail'): 6.90875477931522,
#  ('fungemia', 'lw'): -6.90875477931522,
#  ('hypothermia', 'ppd'): 6.90875477931522,
#  ('prec', 'rm'): 6.90875477931522,
#  ('oob', 'palli'): 6.90875477931522,
#  ('dnr', 'unrel'): -6.90875477931522,
#  ('fibrinogen', 'prilosec'): -6.90875477931522,
#  ('dnr', 'zyprexa'): 1.8806492362025304,
#  ('ctx', 'hsq'): 6.90875477931522,
#  ('rehabilit', 'thrive'): 6.90875477931522,
#  ('metoclopramid', 'silent'): 6.90875477931522,
#  ('bicarbon', 'levoph'): -6.90875477931522,
#  ('cloth', 'diflucan'): 6.90875477931522,
#  ('aaox', 'gurgl'): -6.90875477931522,
#  ('epidur', 'oob'): 6.90875477931522,
#  ('cmo', 'dnr'): -1.521688576085562,
#  ('eg', 'mandibl'): 6.90875477931522,
#  ('hypothermia', 'pcv'): -6.90875477931522,
#  ('dermat', 'xii'): -6.90875477931522,
#  ('amb', 'nahco'): 6.90875477931522,
#  ('dyslipidemia', 'romi'): 6.90875477931522,
#  ('cpr', 'paralyt'): -6.90875477931522,
#  ('death', 'puff'): 6.90875477931522,
#  ('dnr', 'rusti'): -6.90875477931522,
#  ('asthma', 'readdress'): 6.90875477931522,
#  ('im', 'occipit'): 6.90875477931522,
#  ('palli', 'struggl'): -6.90875477931522,
#  ('sweat', 'xl'): 6.90875477931522,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('dni', 'unobtain'): 0.6916505477038827,
#  ('nonlabor', 'subq'): 6.90875477931522,
#  ('gasp', 'sensat'): -6.90875477931522,
#  ('homogen', 'mjmgb'): 6.90875477931522,
#  ('dopamin', 'mso'): 0.6916505477038827,
#  ('gabapentin', 'mood'): 6.90875477931522,
#  ('levoph', 'rigor'): 6.90875477931522,
#  ('aricept', 'lusb'): 6.90875477931522,
#  ('fatti', 'nephrogram'): 6.90875477931522,
#  ('norepinephrin', 'permiss'): -6.90875477931522,
#  ('aox', 'coach'): 6.90875477931522,
#  ('crowd', 'xl'): 6.90875477931522,
#  ('chemic', 'unasyn'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('flight', 'gvhd'): 6.90875477931522,
#  ('oob', 'uri'): 6.90875477931522,
#  ('fatti', 'intiat'): 6.90875477931522,
#  ('prognosi', 'scopalamin'): -6.90875477931522,
#  ('hilum', 'vertebra'): -6.90875477931522,
#  ('peac', 'scopalamin'): -6.90875477931522,
#  ('diaphoresi', 'iddm'): 6.90875477931522,
#  ('gait', 'vasopressin'): -6.90875477931522,
#  ('ffp', 'opinion'): 6.90875477931522,
#  ('asthma', 'dnr'): 3.0693478748272645,
#  ('hunger', 'zoloft'): -6.90875477931522,
#  ('bipolar', 'dnr'): -2.0293823968853086,
#  ('occupi', 'rehabilit'): 6.90875477931522,
#  ('dnr', 'pleuravac'): -6.90875477931522,
#  ('autopeep', 'hypothermia'): -6.90875477931522,
#  ('hive', 'im'): 6.90875477931522,
#  ('phenylephrin', 'requr'): -6.90875477931522,
#  ('silent', 'young'): 6.90875477931522,
#  ('ctx', 'lat'): 6.90875477931522,
#  ('recalibr', 'stitch'): 6.90875477931522,
#  ('emper', 'lac'): 6.90875477931522,
#  ('sluggishli', 'wma'): -6.90875477931522,
#  ('historian', 'opiat'): 6.90875477931522,
#  ('heroic', 'option'): -6.90875477931522,
#  ('declin', 'sweat'): 6.90875477931522,
#  ('venti', 'young'): 6.90875477931522,
#  ('gastrojejunostomi', 'metoclopramid'): 6.90875477931522,
#  ('nicotin', 'uri'): 6.90875477931522,
#  ('barium', 'foci'): 0.0,
#  ('commod', 'platelet'): 6.90875477931522,
#  ('asthma', 'ruptur'): 6.90875477931522,
#  ('azotemia', 'fdp'): -6.90875477931522,
#  ('barium', 'laryng'): 6.90875477931522,
#  ('sensat', 'thirst'): 6.90875477931522,
#  ('palli', 'xii'): -6.90875477931522,
#  ('commod', 'tracheomalacia'): 6.90875477931522,
#  ('ba', 'precordium'): 6.90875477931522,
#  ('deterior', 'echocardiogram'): 6.90875477931522,
#  ('chemic', 'cocain'): 6.90875477931522,
#  ('cocain', 'xii'): 6.90875477931522,
#  ('echocardiogram', 'jejunum'): 6.90875477931522,
#  ('cmo', 'levoph'): -1.3825560390092835,
#  ('piriform', 'silent'): 6.90875477931522,
#  ('autopeep', 'norepinephrin'): -6.90875477931522,
#  ('hypothermia', 'vasopressor'): -6.90875477931522,
#  ('declin', 'xii'): 6.90875477931522,
#  ('oob', 'ultram'): 6.90875477931522,
#  ('epigastr', 'qam'): 6.90875477931522,
#  ('cmo', 'suffer'): -6.90875477931522,
#  ('dnr', 'vtach'): -6.90875477931522,
#  ('asthma', 'mucinex'): 6.90875477931522,
#  ('esld', 'phenylephrin'): -0.06655815957840429,
#  ('ctx', 'wma'): 6.90875477931522,
#  ('arrest', 'incis'): 6.90875477931522,
#  ('arrest', 'profound'): -6.90875477931522,
#  ('commod', 'spirit'): 6.90875477931522,
#  ('deterior', 'palli'): -6.90875477931522,
#  ('dopamin', 'vasopressor'): -6.90875477931522,
#  ('agreement', 'heroic'): -6.90875477931522,
#  ('iddm', 'sluggish'): 6.90875477931522,
#  ('anaphylaxi', 'ferritin'): 6.90875477931522,
#  ('ctx', 'retic'): 6.90875477931522,
#  ('dni', 'stair'): 6.90875477931522,
#  ('gastriti', 'seriou'): 6.90875477931522,
#  ('hctz', 'predict'): 6.90875477931522,
#  ('freeli', 'scar'): 6.90875477931522,
#  ('cracker', 'venti'): 6.90875477931522,
#  ('pyuria', 'silent'): -6.90875477931522,
#  ('commod', 'diaper'): 6.90875477931522,
#  ('im', 'platelet'): 6.90875477931522,
#  ('captopril', 'hypotherm'): -6.90875477931522,
#  ('life', 'wish'): 0.4046335072286383,
#  ('pod', 'soln'): 6.90875477931522,
#  ('dnr', 'underneath'): -6.90875477931522,
#  ('mso', 'syst'): 6.90875477931522,
#  ('exophyt', 'unenhanc'): 6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('hive', 'sweat'): 6.90875477931522,
#  ('flight', 'pleasant'): 6.90875477931522,
#  ('anur', 'trazodon'): 6.90875477931522,
#  ('incent', 'oob'): 6.90875477931522,
#  ('bipolar', 'mood'): 6.90875477931522,
#  ('db', 'jewelri'): 6.90875477931522,
#  ('uncoop', 'video'): 6.90875477931522,
#  ('seat', 'tdi'): 6.90875477931522,
#  ('dnr', 'friction'): 6.90875477931522,
#  ('bill', 'metoclopramid'): 6.90875477931522,
#  ('norepinephrin', 'ultram'): 6.90875477931522,
#  ('lighthead', 'pleasant'): 6.90875477931522,
#  ('incent', 'phlegm'): 6.90875477931522,
#  ('pronounc', 'sacrament'): -6.90875477931522,
#  ('jejunum', 'tie'): 6.90875477931522,
#  ('dni', 'lat'): 6.90875477931522,
#  ('hive', 'money'): 6.90875477931522,
#  ('bottl', 'crack'): 6.90875477931522,
#  ('chair', 'dni'): 0.4510520218895015,
#  ('life', 'pastor'): -6.90875477931522,
#  ('ambien', 'unasyn'): 6.90875477931522,
#  ('sibl', 'vasoconstrict'): -6.90875477931522,
#  ('scopalamin', 'seroquel'): 6.90875477931522,
#  ('aaox', 'pod'): 6.90875477931522,
#  ('acc', 'romi'): 6.90875477931522,
#  ('breakfast', 'nahco'): 6.90875477931522,
#  ('bank', 'dnr'): 6.90875477931522,
#  ('hospic', 'oder'): -6.90875477931522,
#  ('oob', 'syst'): 6.90875477931522,
#  ('anur', 'pleasant'): 6.90875477931522,
#  ('aricept', 'wallet'): -6.90875477931522,
#  ('gasp', 'hilum'): -6.90875477931522,
#  ('escal', 'wish'): -6.90875477931522,
#  ('expir', 'nahco'): -6.90875477931522,
#  ('criticar', 'oligur'): 6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('thrive', 'young'): 6.90875477931522,
#  ('ppd', 'thrive'): 6.90875477931522,
#  ('norepinephrin', 'oligur'): -6.90875477931522,
#  ('romi', 'thiamin'): 6.90875477931522,
#  ('deterior', 'mellitu'): 6.90875477931522,
#  ('icter', 'mellitu'): 6.90875477931522,
#  ('declin', 'oob'): 6.90875477931522,
#  ('natg', 'occipit'): 6.90875477931522,
#  ('dnr', 'fibrinogen'): 1.6507429622330152,
#  ('mucinex', 'option'): 6.90875477931522,
#  ('hive', 'metoclopramid'): 6.90875477931522,
#  ('hive', 'refractori'): 6.90875477931522,
#  ('requr', 'rm'): 6.90875477931522,
#  ('gabapentin', 'morbid'): 6.90875477931522,
#  ('epidur', 'gabapentin'): 6.90875477931522,
#  ('currenlti', 'qam'): 6.90875477931522,
#  ('epidur', 'zoloft'): 6.90875477931522,
#  ('aliv', 'dead'): 6.90875477931522,
#  ('acc', 'hsq'): 6.90875477931522,
#  ('aaox', 'dnr'): 1.604655121332035,
#  ('gabapentin', 'ppd'): 6.90875477931522,
#  ('diaphoresi', 'xl'): 6.90875477931522,
#  ('dyslipidemia', 'scar'): 6.90875477931522,
#  ('rigor', 'strictur'): 6.90875477931522,
#  ('scar', 'smooth'): 6.90875477931522,
#  ('liw', 'vasopressin'): -6.90875477931522,
#  ('arthrit', 'dnr'): 6.90875477931522,
#  ('duski', 'palli'): -6.90875477931522,
#  ('norepinephrin', 'recalibr'): 6.90875477931522,
#  ('plate', 'requr'): 6.90875477931522,
#  ('predict', 'ultram'): 6.90875477931522,
#  ('aox', 'predict'): 6.90875477931522,
#  ('clonazepam', 'schizophrenia'): 6.90875477931522,
#  ('dni', 'simpli'): 6.90875477931522,
#  ('dobutamin', 'levoph'): -3.403520263078295,
#  ('dni', 'fibrinogen'): 1.095952712632351,
#  ('calculi', 'oncologist'): 6.90875477931522,
#  ('clonidin', 'qam'): 6.90875477931522,
#  ('money', 'probe'): 6.90875477931522,
#  ('dni', 'unrel'): -6.90875477931522,
#  ('asystol', 'bank'): -6.90875477931522,
#  ('aricept', 'qam'): -6.90875477931522,
#  ('deliv', 'dni'): 6.90875477931522,
#  ('fc', 'pyuria'): -6.90875477931522,
#  ('commod', 'sarna'): 6.90875477931522,
#  ('eg', 'pharyng'): 6.90875477931522,
#  ('cloth', 'fatti'): 6.90875477931522,
#  ('ligament', 'smooth'): 6.90875477931522,
#  ('life', 'palli'): -6.90875477931522,
#  ('crowd', 'rhinorrhea'): 6.90875477931522,
#  ('fdp', 'ggt'): -6.90875477931522,
#  ('asthma', 'respon'): 6.90875477931522,
#  ('hemangioma', 'slice'): 6.90875477931522,
#  ('subcost', 'unavail'): 6.90875477931522,
#  ('dizzi', 'tcdb'): 6.90875477931522,
#  ('^th', 'commod'): 6.90875477931522,
#  ('opiat', 'thiamin'): 6.90875477931522,
#  ('ciwa', 'ran'): 6.90875477931522,
#  ('laryng', 'lat'): 6.90875477931522,
#  ('dopamin', 'unequ'): -6.90875477931522,
#  ('asthma', 'bottl'): 6.90875477931522,
#  ('hunger', 'prognosi'): -6.90875477931522,
#  ('hsq', 'xii'): 6.90875477931522,
#  ('chair', 'unasyn'): -0.5584397574369144,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('acv', 'levoph'): 6.90875477931522,
#  ('commod', 'incent'): 6.90875477931522,
#  ('lat', 'pneumothorac'): 0.6916505477038827,
#  ('ntnd', 'zoloft'): 6.90875477931522,
#  ('articul', 'rhinorrhea'): 6.90875477931522,
#  ('bromid', 'fibrinogen'): 6.90875477931522,
#  ('db', 'pleasant'): 6.90875477931522,
#  ('agon', 'arrest'): 0.0,
#  ('ciwa', 'itchi'): 6.90875477931522,
#  ('dni', 'lotion'): -6.90875477931522,
#  ('epigastr', 'hsq'): 6.90875477931522,
#  ('dni', 'video'): 0.20026746965023628,
#  ('rigor', 'sensat'): 6.90875477931522,
#  ('asthma', 'crack'): 6.90875477931522,
#  ('ba', 'sensat'): 6.90875477931522,
#  ('bair', 'paralyt'): 6.90875477931522,
#  ('pleasant', 'venti'): 6.90875477931522,
#  ('rigor', 'sweat'): 6.90875477931522,
#  ('ciwa', 'fatti'): 6.90875477931522,
#  ('db', 'scar'): 6.90875477931522,
#  ('option', 'pleasant'): 6.90875477931522,
#  ('dxae', 'pneumonectomi'): -6.90875477931522,
#  ('goc', 'nifedipin'): 6.90875477931522,
#  ('imbal', 'shorter'): 6.90875477931522,
#  ('ffp', 'mean'): -6.90875477931522,
#  ('ligament', 'para'): 6.90875477931522,
#  ('ofm', 'oob'): 6.90875477931522,
#  ('dni', 'hook'): 6.90875477931522,
#  ('calculi', 'trazodon'): 6.90875477931522,
#  ('anuria', 'bill'): 6.90875477931522,
#  ('dni', 'stg'): -6.90875477931522,
#  ('hemangioma', 'mjmgb'): 6.90875477931522,
#  ('captopril', 'ciwa'): 6.90875477931522,
#  ('pneumonectomi', 'tubular'): -6.90875477931522,
#  ('coarctat', 'habitu'): 6.90875477931522,
#  ('clonidin', 'unobtain'): 6.90875477931522,
#  ('dnr', 'unasyn'): 6.90875477931522,
#  ('fibrinogen', 'rigor'): 6.90875477931522,
#  ('calculi', 'homogen'): 6.90875477931522,
#  ('bronchovascular', 'mail'): 6.90875477931522,
#  ('barium', 'motor'): 6.90875477931522,
#  ('dyslipidemia', 'mellitu'): 6.90875477931522,
#  ('echocardiogram', 'rigor'): 6.90875477931522,
#  ('autopeep', 'hypercapnia'): -6.90875477931522,
#  ('palli', 'pleasant'): -6.90875477931522,
#  ('arrest', 'expir'): -6.90875477931522,
#  ('cdb', 'levoph'): 6.90875477931522,
#  ('paperwork', 'rehabilit'): 6.90875477931522,
#  ('chair', 'simpli'): 6.90875477931522,
#  ('diuril', 'dopamin'): 6.90875477931522,
#  ('gurgl', 'pleasant'): 6.90875477931522,
#  ('morgu', 'mortem'): -6.90875477931522,
#  ('deterior', 'readdress'): -6.90875477931522,
#  ('metoclopramid', 'soln'): 6.90875477931522,
#  ('hypothermia', 'robitussin'): 6.90875477931522,
#  ('clonidin', 'laminectomi'): 6.90875477931522,
#  ('asthma', 'escal'): 6.90875477931522,
#  ('dnr', 'synthet'): -6.90875477931522,
#  ('tcdb', 'uri'): 6.90875477931522,
#  ('autopsi', 'dnr'): -6.90875477931522,
#  ('aox', 'laminectomi'): 6.90875477931522,
#  ('opiat', 'ultram'): 6.90875477931522,
#  ('ctx', 'ultram'): 6.90875477931522,
#  ('arrest', 'dnr'): -6.90875477931522,
#  ('bank', 'colonoscopi'): 6.90875477931522,
#  ('pplat', 'thk'): 6.90875477931522,
#  ('readmit', 'scar'): 6.90875477931522,
#  ('escal', 'pea'): -6.90875477931522,
#  ('jewelri', 'signatur'): 2.387057016415087,
#  ('cs', 'oob'): 6.90875477931522,
#  ('dnr', 'nicotin'): 6.90875477931522,
#  ('palli', 'postop'): 6.90875477931522,
#  ('aricept', 'distanc'): 6.90875477931522,
#  ('ccn', 'levoph'): -6.90875477931522,
#  ('arrest', 'gait'): -6.90875477931522,
#  ('phenylephrin', 'synthet'): -6.90875477931522,
#  ('echocardiogram', 'palli'): -6.90875477931522,
#  ('among', 'foci'): -6.90875477931522,
#  ('dopamin', 'pitressin'): -6.90875477931522,
#  ('asthma', 'chair'): 2.09609753878805,
#  ('levoph', 'unstabl'): 0.0,
#  ('compani', 'omeprazol'): 6.90875477931522,
#  ('ipf', 'robitussin'): -6.90875477931522,
#  ('bottl', 'gum'): 6.90875477931522,
#  ('angioplasti', 'diaphoresi'): 6.90875477931522,
#  ('dnr', 'lotion'): -3.046848290615153,
#  ('rememb', 'ruptur'): 6.90875477931522,
#  ('judgement', 'mso'): -6.90875477931522,
#  ('aricept', 'commod'): -6.90875477931522,
#  ('breakfast', 'readdress'): 6.90875477931522,
#  ('dnr', 'west'): 6.90875477931522,
#  ('adam', 'deterior'): -6.90875477931522,
#  ('^th', 'oob'): 6.90875477931522,
#  ('dnr', 'dobutamin'): 1.2495579516853903,
#  ('ambul', 'dni'): 1.3825560390092835,
#  ('dni', 'heroic'): -6.90875477931522,
#  ('hctz', 'pneumococc'): 6.90875477931522,
#  ('gabapentin', 'xanax'): 6.90875477931522,
#  ('dnr', 'epigastr'): 6.90875477931522,
#  ('banana', 'rememb'): 6.90875477931522,
#  ('declin', 'zyprexa'): -6.90875477931522,
#  ('asthma', 'cellcept'): 6.90875477931522,
#  ('dni', 'mood'): 6.90875477931522,
#  ('endur', 'incis'): 6.90875477931522,
#  ('gvhd', 'levoph'): -6.90875477931522,
#  ('barium', 'spill'): 6.90875477931522,
#  ('contractur', 'scar'): 6.90875477931522,
#  ('aricept', 'gabapentin'): 6.90875477931522,
#  ('argatroban', 'norepinephrin'): -6.90875477931522,
#  ('im', 'prec'): 6.90875477931522,
#  ('cisatracurium', 'paralyt'): -6.90875477931522,
#  ('dnr', 'sluggish'): -0.5865449245323548,
#  ('asthma', 'clonidin'): 6.90875477931522,
#  ('hugger', 'vasopressor'): -6.90875477931522,
#  ('dnr', 'nitroglycerin'): 6.90875477931522,
#  ('dni', 'qam'): 1.3825560390092835,
#  ('bottl', 'opiat'): 6.90875477931522,
#  ('spill', 'videofluoroscopi'): 6.90875477931522,
#  ('commod', 'levoph'): -0.25080752166759324,
#  ('oob', 'tcdb'): 6.90875477931522,
#  ('hsq', 'platelet'): -6.90875477931522,
#  ('dni', 'oligur'): -1.604655121332035,
#  ('smooth', 'vertebra'): 0.0,
#  ('seroquel', 'unasyn'): 6.90875477931522,
#  ('flight', 'vp'): 6.90875477931522,
#  ('db', 'oob'): 6.90875477931522,
#  ('dni', 'jerk'): -6.90875477931522,
#  ('arrest', 'chb'): -6.90875477931522,
#  ('readmit', 'sweat'): 6.90875477931522,
#  ('im', 'mva'): 6.90875477931522,
#  ('schizophrenia', 'ultram'): 6.90875477931522,
#  ('ambul', 'furhter'): -6.90875477931522,
#  ('nocturn', 'profound'): 6.90875477931522,
#  ('anur', 'tcdb'): 6.90875477931522,
#  ('signatur', 'thiamin'): 6.90875477931522,
#  ('reguard', 'uncoop'): 6.90875477931522,
#  ('dni', 'meropenam'): -6.90875477931522,
#  ('aaox', 'nimv'): 6.90875477931522,
#  ('pneumococc', 'pod'): 6.90875477931522,
#  ('agon', 'neosynephrin'): -6.90875477931522,
#  ('cracker', 'spiromet'): -6.90875477931522,
#  ('chair', 'compani'): 6.90875477931522,
#  ('declin', 'dietari'): 6.90875477931522,
#  ('hugger', 'levoph'): 1.6688498669946448,
#  ('ambien', 'ferrou'): 6.90875477931522,
#  ('dead', 'sundown'): -6.90875477931522,
#  ('purpl', 'seroquel'): 6.90875477931522,
#  ('azotemia', 'habitu'): 6.90875477931522,
#  ('para', 'pneumococc'): 6.90875477931522,
#  ('clonidin', 'refractori'): 6.90875477931522,
#  ('incis', 'wish'): -6.90875477931522,
#  ('clonazepam', 'osa'): 6.90875477931522,
#  ('anaphylaxi', 'opiat'): 6.90875477931522,
#  ('absorb', 'paralyt'): 6.90875477931522,
#  ('pronounc', 'wish'): -6.90875477931522,
#  ('crack', 'ultram'): 6.90875477931522,
#  ('lat', 'mva'): 6.90875477931522,
#  ('chol', 'stg'): -6.90875477931522,
#  ('hospic', 'requr'): 6.90875477931522,
#  ('anur', 'flake'): 6.90875477931522,
#  ('gasp', 'qam'): -6.90875477931522,
#  ('deflat', 'lpm'): 6.90875477931522,
#  ('autopeep', 'dic'): -6.90875477931522,
#  ('autoset', 'ciwa'): 6.90875477931522,
#  ('soln', 'subdur'): 6.90875477931522,
#  ('hunger', 'xopenex'): -6.90875477931522,
#  ('asthma', 'uri'): 6.90875477931522,
#  ('phlegm', 'silent'): 6.90875477931522,
#  ('fatti', 'thiamin'): 6.90875477931522,
#  ('articul', 'dead'): 6.90875477931522,
#  ('ipf', 'norepinephrin'): -6.90875477931522,
#  ('mellitu', 'oob'): 6.90875477931522,
#  ('chair', 'prec'): 6.90875477931522,
#  ('cardiovert', 'neo'): -6.90875477931522,
#  ('oob', 'romi'): 6.90875477931522,
#  ('perisplen', 'scar'): 6.90875477931522,
#  ('mellitu', 'subdur'): 6.90875477931522,
#  ('dic', 'hive'): -6.90875477931522,
#  ('chair', 'lotion'): -3.02380801661965,
#  ('exophyt', 'fc'): -6.90875477931522,
#  ('adam', 'futil'): -6.90875477931522,
#  ('agreement', 'moan'): -6.90875477931522,
#  ('homogen', 'scar'): 6.90875477931522,
#  ('liw', 'vasoconstrict'): -6.90875477931522,
#  ('bill', 'fibrinogen'): 6.90875477931522,
#  ('autopeep', 'pcv'): -6.90875477931522,
#  ('calculi', 'fatti'): 6.90875477931522,
#  ('bicarbon', 'dic'): -6.90875477931522,
#  ('dic', 'sluggish'): -6.90875477931522,
#  ('expir', 'pea'): -6.90875477931522,
#  ('dni', 'gastriti'): 6.90875477931522,
#  ('cramp', 'fibrinogen'): 6.90875477931522,
#  ('levof', 'paralyt'): -6.90875477931522,
#  ('anur', 'rhinorrhea'): -6.90875477931522,
#  ('gown', 'gurgl'): -6.90875477931522,
#  ('lusb', 'retic'): 6.90875477931522,
#  ('diaphoresi', 'pleasant'): 6.90875477931522,
#  ('oncologist', 'ppn'): 6.90875477931522,
#  ('hung', 'religi'): -6.90875477931522,
#  ('asthma', 'ultram'): 6.90875477931522,
#  ('dni', 'hypotherm'): -1.604655121332035,
#  ('subq', 'zoloft'): 6.90875477931522,
#  ('dnr', 'sarna'): 6.90875477931522,
#  ('epigastr', 'incis'): 6.90875477931522,
#  ('hctz', 'prilosec'): 6.90875477931522,
#  ('asystol', 'mortem'): -6.90875477931522,
#  ('bromid', 'currenlti'): 6.90875477931522,
#  ('puff', 'refractori'): 6.90875477931522,
#  ('lw', 'twitch'): -6.90875477931522,
#  ('eg', 'mellitu'): 6.90875477931522,
#  ('ciwa', 'epigastr'): 6.90875477931522,
#  ('osteoblast', 'scar'): -6.90875477931522,
#  ('moan', 'oligur'): -6.90875477931522,
#  ('incis', 'lw'): 6.90875477931522,
#  ('bottl', 'gotten'): 6.90875477931522,
#  ('bipolar', 'zyprexa'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('oncologist', 'scar'): 6.90875477931522,
#  ('dni', 'quinolon'): -6.90875477931522,
#  ('acidot', 'phenylephrin'): -6.90875477931522,
#  ('life', 'scopalamin'): -6.90875477931522,
#  ('gait', 'hive'): 6.90875477931522,
#  ('binder', 'dni'): 6.90875477931522,
#  ('levoph', 'wma'): -6.90875477931522,
#  ('ctx', 'rhinorrhea'): 6.90875477931522,
#  ('cocain', 'ctx'): 6.90875477931522,
#  ('arrest', 'fibrinogen'): -6.90875477931522,
#  ('breakfast', 'nitroglycerin'): 6.90875477931522,
#  ('muir', 'passi'): 6.90875477931522,
#  ('breakfast', 'stitch'): 6.90875477931522,
#  ('suprapub', 'thrive'): 6.90875477931522,
#  ('cefapim', 'pleasant'): 6.90875477931522,
#  ('montitor', 'sluggish'): -6.90875477931522,
#  ('laminectomi', 'pleasant'): 6.90875477931522,
#  ('ciwa', 'wish'): 6.90875477931522,
#  ('dni', 'refractori'): 6.90875477931522,
#  ('dni', 'knowledg'): 6.90875477931522,
#  ('barium', 'nocturn'): 6.90875477931522,
#  ('chair', 'oob'): 1.6867328713947312,
#  ('core', 'scar'): 6.90875477931522,
#  ('cg', 'montitor'): -6.90875477931522,
#  ('autopeep', 'paralyt'): -6.90875477931522,
#  ('cocain', 'mycolyt'): 6.90875477931522,
#  ('lpm', 'mottl'): 6.90875477931522,
#  ('declin', 'scar'): 6.90875477931522,
#  ('puff', 'thrive'): 6.90875477931522,
#  ('ardsnet', 'norepinephrin'): -6.90875477931522,
#  ('autopeep', 'azotemia'): -6.90875477931522,
#  ('dic', 'futil'): -6.90875477931522,
#  ('pvr', 'spiromet'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('laryng', 'silent'): 6.90875477931522,
#  ('bill', 'subdur'): 6.90875477931522,
#  ('bicarbon', 'cpr'): -6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('fibrinogen', 'levof'): -6.90875477931522,
#  ('dni', 'redirect'): 2.2204460492503128e-16,
#  ('homogen', 'nephrogram'): 0.6916505477038827,
#  ('gadolinium', 'levoph'): 6.90875477931522,
#  ('dic', 'impli'): 6.90875477931522,
#  ('ciwa', 'neoplast'): 6.90875477931522,
#  ('dnr', 'sibl'): 6.90875477931522,
#  ('lc', 'pinpoint'): -6.90875477931522,
#  ('money', 'oob'): 6.90875477931522,
#  ('schistocyt', 'syncop'): 6.90875477931522,
#  ('gait', 'pleasant'): 6.90875477931522,
#  ('cmo', 'peac'): -6.90875477931522,
#  ('ferrou', 'nocturn'): 6.90875477931522,
#  ('aaox', 'commod'): 6.90875477931522,
#  ('deliv', 'respitori'): 6.90875477931522,
#  ('ba', 'ciwa'): 6.90875477931522,
#  ('contd', 'refractori'): 6.90875477931522,
#  ('gotten', 'msicu'): 6.90875477931522,
#  ('nephrolog', 'omeprazol'): 6.90875477931522,
#  ('mva', 'spacer'): 6.90875477931522,
#  ('puff', 'sweat'): 6.90875477931522,
#  ('fibrinogen', 'readdress'): 6.90875477931522,
#  ('bicarbon', 'cvvh'): -6.90875477931522,
#  ('cash', 'redirect'): -6.90875477931522,
#  ('omeprazol', 'stitch'): 6.90875477931522,
#  ('ctx', 'lotion'): 6.90875477931522,
#  ('ethic', 'polici'): -6.90875477931522,
#  ('elimin', 'pathologist'): 6.90875477931522,
#  ('intent', 'ppd'): 6.90875477931522,
#  ('aox', 'declin'): -6.90875477931522,
#  ('lymphangit', 'pronounc'): -6.90875477931522,
#  ('sarna', 'soln'): 6.90875477931522,
#  ('aliv', 'robitussin'): 6.90875477931522,
#  ('chol', 'underneath'): -6.90875477931522,
#  ('commod', 'xopenex'): 6.90875477931522,
#  ('fibrinogen', 'rhinorrhea'): 0.4046335072286383,
#  ('barium', 'spur'): 6.90875477931522,
#  ('postop', 'retic'): 6.90875477931522,
#  ('bicarbon', 'hypercapnia'): -6.90875477931522,
#  ('ntnd', 'subq'): 6.90875477931522,
#  ('dnr', 'hemothorax'): -6.90875477931522,
#  ('barium', 'neo'): 6.90875477931522,
#  ('agon', 'death'): -6.90875477931522,
#  ('incent', 'mottl'): 6.90875477931522,
#  ('oob', 'zyprexa'): 6.90875477931522,
#  ('ruptur', 'sibl'): 6.90875477931522,
#  ('habitu', 'mean'): 6.90875477931522,
#  ('arrest', 'tracheomalacia'): 6.90875477931522,
#  ('crack', 'habitu'): 6.90875477931522,
#  ('bottl', 'msicu'): 6.90875477931522,
#  ('ciwa', 'omeprazol'): 6.90875477931522,
#  ('dietari', 'wma'): 6.90875477931522,
#  ('ba', 'banana'): 6.90875477931522,
#  ('hygein', 'thiamin'): 6.90875477931522,
#  ('cvvhd', 'paralyt'): -6.90875477931522,
#  ('dni', 'occurr'): 6.90875477931522,
#  ('fatti', 'homogen'): 6.90875477931522,
#  ('arrest', 'norepinephrin'): -6.90875477931522,
#  ('criticar', 'dni'): 6.90875477931522,
#  ('schistocyt', 'young'): 6.90875477931522,
#  ('fdp', 'prilosec'): -6.90875477931522,
#  ('anur', 'commod'): -6.90875477931522,
#  ('hctz', 'led'): 6.90875477931522,
#  ('anyway', 'weekli'): 6.90875477931522,
#  ('declin', 'lusb'): 6.90875477931522,
#  ('asthma', 'mva'): 6.90875477931522,
#  ('asthma', 'breakfast'): 6.90875477931522,
#  ('bair', 'sluggish'): -6.90875477931522,
#  ('agon', 'pinpoint'): -6.90875477931522,
#  ('esoph', 'hunger'): -6.90875477931522,
#  ('chair', 'intent'): 6.90875477931522,
#  ('nocturn', 'sweat'): 6.90875477931522,
#  ('historian', 'unstabl'): 6.90875477931522,
#  ('bottl', 'trabecul'): 6.90875477931522,
#  ('gabapentin', 'syncop'): 6.90875477931522,
#  ('arthrit', 'commod'): 6.90875477931522,
#  ('pleasant', 'sensat'): 6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('lotion', 'pca'): 6.90875477931522,
#  ('phenylephrin', 'prognosi'): -6.90875477931522,
#  ('knowledg', 'life'): 6.90875477931522,
#  ('chair', 'maroon'): 6.90875477931522,
#  ('anuria', 'dead'): -6.90875477931522,
#  ('bair', 'hugger'): 0.12235699519301034,
#  ('gabapentin', 'postop'): 6.90875477931522,
#  ('contractur', 'dni'): -0.6916505477038827,
#  ('anyway', 'dni'): 6.90875477931522,
#  ('lighthead', 'nicotin'): 6.90875477931522,
#  ('agon', 'agreement'): -6.90875477931522,
#  ('ipf', 'occipit'): 0.0,
#  ('angioplasti', 'iddm'): 6.90875477931522,
#  ('deterior', 'gc'): 6.90875477931522,
#  ('dopamin', 'moan'): -6.90875477931522,
#  ('osa', 'romi'): 6.90875477931522,
#  ('chair', 'nectar'): 6.90875477931522,
#  ('fibrinogen', 'religi'): -6.90875477931522,
#  ('osa', 'trazodon'): 6.90875477931522,
#  ('declin', 'romi'): 6.90875477931522,
#  ('fibrinogen', 'ggt'): -6.90875477931522,
#  ('nonlabor', 'pleasant'): 6.90875477931522,
#  ('nonreact', 'palli'): -6.90875477931522,
#  ('lpm', 'polici'): -6.90875477931522,
#  ('aliv', 'sweat'): 6.90875477931522,
#  ('shorter', 'strictur'): 6.90875477931522,
#  ('anur', 'illeu'): -6.90875477931522,
#  ('cisatracurium', 'phenylephrin'): -6.90875477931522,
#  ('omeprazol', 'schizophrenia'): 6.90875477931522,
#  ('fibrinogen', 'pastor'): -6.90875477931522,
#  ('historian', 'jewelri'): 6.90875477931522,
#  ('fatti', 'intent'): 6.90875477931522,
#  ('chair', 'gurgl'): -6.90875477931522,
#  ('dnr', 'muddi'): 1.0271828417136022,
#  ('pneumococc', 'sibl'): 6.90875477931522,
#  ('dni', 'ffp'): -2.473073171472692,
#  ('peribronchovascular', 'slice'): 6.90875477931522,
#  ('anuria', 'levoph'): -6.90875477931522,
#  ('burn', 'commod'): 6.90875477931522,
#  ('captopril', 'futil'): -6.90875477931522,
#  ('autoset', 'habitu'): 6.90875477931522,
#  ('cpr', 'mortem'): -6.90875477931522,
#  ('peribronchovascular', 'unstabl'): 6.90875477931522,
#  ('exophyt', 'pyuria'): -6.90875477931522,
#  ('grave', 'hook'): 6.90875477931522,
#  ('epigastr', 'hctz'): 6.90875477931522,
#  ('dni', 'gc'): 6.90875477931522,
#  ('cash', 'xl'): 6.90875477931522,
#  ('ambul', 'lac'): 6.90875477931522,
#  ('angiogram', 'deploy'): 6.90875477931522,
#  ('nectar', 'oob'): 6.90875477931522,
#  ('gvhd', 'wish'): 6.90875477931522,
#  ('ambul', 'asthma'): 6.90875477931522,
#  ('olanzapin', 'reguard'): 6.90875477931522,
#  ('oncologist', 'refractori'): 6.90875477931522,
#  ('crack', 'mycolyt'): 6.90875477931522,
#  ('echocardiogram', 'hive'): 6.90875477931522,
#  ('cdb', 'ctx'): 6.90875477931522,
#  ('cmo', 'oder'): -6.90875477931522,
#  ('mellitu', 'simpli'): 6.90875477931522,
#  ('gadolinium', 'vertebra'): 6.90875477931522,
#  ('ferrou', 'xl'): 6.90875477931522,
#  ('gait', 'lotion'): 6.90875477931522,
#  ('pronounc', 'vasopressin'): -6.90875477931522,
#  ('dni', 'respitori'): 6.90875477931522,
#  ('para', 'sweat'): 6.90875477931522,
#  ('laryng', 'vallecula'): 6.90875477931522,
#  ('peac', 'prognosi'): -6.90875477931522,
#  ('hilum', 'jejunum'): 6.90875477931522,
#  ('aricept', 'dnr'): 0.1428142402977353,
#  ('fibrinogen', 'pyuria'): 6.90875477931522,
#  ('dizzi', 'xl'): 6.90875477931522,
#  ('flight', 'gadolinium'): 6.90875477931522,
#  ('diaphoresi', 'sensat'): 6.90875477931522,
#  ('levoph', 'motil'): -6.90875477931522,
#  ('ctx', 'pleasant'): 6.90875477931522,
#  ('ppd', 'sensat'): 6.90875477931522,
#  ('ofm', 'svn'): 6.90875477931522,
#  ('dnr', 'sluggishli'): -6.90875477931522,
#  ('mind', 'paperwork'): 6.90875477931522,
#  ('absorb', 'asthma'): 6.90875477931522,
#  ('profound', 'slice'): 6.90875477931522,
#  ('barium', 'vallecula'): 6.90875477931522,
#  ('gabapentin', 'hive'): 6.90875477931522,
#  ('cyanot', 'oob'): -6.90875477931522,
#  ('death', 'hive'): 6.90875477931522,
#  ('qam', 'vagu'): 6.90875477931522,
#  ('ntnd', 'thiamin'): 6.90875477931522,
#  ('ambul', 'dz'): 6.90875477931522,
#  ('osa', 'young'): 6.90875477931522,
#  ('gait', 'oob'): 2.1883847407670785,
#  ('ctx', 'silent'): 6.90875477931522,
#  ('ctx', 'declin'): 6.90875477931522,
#  ('dz', 'slough'): 6.90875477931522,
#  ('oncologist', 'thrive'): 6.90875477931522,
#  ('neoplast', 'palli'): 6.90875477931522,
#  ('gabapentin', 'nocturn'): 6.90875477931522,
#  ('learn', 'moan'): 6.90875477931522,
#  ('gastriti', 'laminectomi'): 6.90875477931522,
#  ('arrang', 'cpr'): -6.90875477931522,
#  ('assymetr', 'xl'): 6.90875477931522,
#  ('platelet', 'suffer'): -6.90875477931522,
#  ('freeli', 'strictur'): 6.90875477931522,
#  ('hunger', 'suffer'): -6.90875477931522,
#  ('nocturn', 'rhinorrhea'): 6.90875477931522,
#  ('azotemia', 'hctz'): 6.90875477931522,
#  ('asystol', 'dnr'): -6.90875477931522,
#  ('anyway', 'dnr'): 6.90875477931522,
#  ('dic', 'goc'): -6.90875477931522,
#  ('ppd', 'suprapub'): 6.90875477931522,
#  ('opiat', 'unasyn'): 6.90875477931522,
#  ('pronounc', 'unenhanc'): -6.90875477931522,
#  ('ferritin', 'hive'): 6.90875477931522,
#  ('jewelri', 'wallet'): 2.2927445483990123,
#  ('gvhd', 'lw'): -6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('crrt', 'platelet'): -6.90875477931522,
#  ('im', 'trazodon'): 6.90875477931522,
#  ('bipolar', 'forc'): -6.90875477931522,
#  ('dnr', 'pleasantli'): 6.90875477931522,
#  ('hctz', 'protrud'): 6.90875477931522,
#  ('calvarium', 'thrive'): -6.90875477931522,
#  ('anaphylaxi', 'escal'): 6.90875477931522,
#  ('bottl', 'osa'): 6.90875477931522,
#  ('pea', 'trazodon'): -6.90875477931522,
#  ('incis', 'seriou'): 6.90875477931522,
#  ('grave', 'prognosi'): -0.6916505477038827,
#  ('dni', 'moan'): -0.5378679732223673,
#  ('aaox', 'sundown'): 0.6916505477038827,
#  ('flake', 'gabapentin'): 6.90875477931522,
#  ('db', 'habitu'): 6.90875477931522,
#  ('retic', 'tremul'): 6.90875477931522,
#  ('dnr', 'mellitu'): 6.90875477931522,
#  ('fatti', 'stair'): 6.90875477931522,
#  ('dni', 'hypercapn'): 6.90875477931522,
#  ('dni', 'hospic'): -0.19198555128397649,
#  ('herp', 'stair'): 6.90875477931522,
#  ('cloth', 'db'): 6.90875477931522,
#  ('motor', 'retic'): 6.90875477931522,
#  ('crack', 'echocardiogram'): 6.90875477931522,
#  ('fdp', 'ffp'): -6.90875477931522,
#  ('mtg', 'palli'): -6.90875477931522,
#  ('cvvh', 'norepinephrin'): -6.90875477931522,
#  ('deterior', 'hugger'): 6.90875477931522,
#  ('ambien', 'appi'): 6.90875477931522,
#  ('mind', 'rehabilit'): 6.90875477931522,
#  ('hypotherm', 'pinpoint'): -6.90875477931522,
#  ('lotion', 'metoclopramid'): 6.90875477931522,
#  ('hospic', 'option'): 6.90875477931522,
#  ('cvvh', 'levoph'): -6.90875477931522,
#  ('quinolon', 'trazodon'): 6.90875477931522,
#  ('pneumococc', 'young'): 6.90875477931522,
#  ('arrest', 'azotemia'): -6.90875477931522,
#  ('option', 'tran'): 6.90875477931522,
#  ('chair', 'cramp'): 6.90875477931522,
#  ('bronchovascular', 'ctx'): 6.90875477931522,
#  ('ppd', 'thiamin'): 6.90875477931522,
#  ('predict', 'unstabl'): 6.90875477931522,
#  ('fwb', 'tremul'): 6.90875477931522,
#  ('ctx', 'moan'): 6.90875477931522,
#  ('cyanot', 'furhter'): -6.90875477931522,
#  ('cdb', 'hive'): 6.90875477931522,
#  ('dni', 'escal'): 2.224418442526018,
#  ('hilum', 'syncop'): 6.90875477931522,
#  ('absorb', 'omeprazol'): 6.90875477931522,
#  ('mtg', 'paralyt'): -6.90875477931522,
#  ('fdp', 'rhinorrhea'): -6.90875477931522,
#  ('bill', 'soln'): 6.90875477931522,
#  ('historian', 'venti'): -6.90875477931522,
#  ('bronchovascular', 'crowd'): 1.462247919771027,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('dnr', 'opinion'): -6.90875477931522,
#  ('clonazepam', 'platelet'): 6.90875477931522,
#  ('oncologist', 'romi'): 6.90875477931522,
#  ('dome', 'foci'): 6.90875477931522,
#  ('mva', 'promod'): 6.90875477931522,
#  ('autopeep', 'phenylephrin'): -6.90875477931522,
#  ('chair', 'death'): 6.90875477931522,
#  ('levoph', 'scopalamin'): -6.90875477931522,
#  ('clinician', 'escal'): -6.90875477931522,
#  ('banana', 'flake'): 6.90875477931522,
#  ('adam', 'declin'): -6.90875477931522,
#  ('declin', 'rhinorrhea'): 6.90875477931522,
#  ('prognosi', 'sibl'): -6.90875477931522,
#  ('esld', 'itchi'): -6.90875477931522,
#  ('autoset', 'ppd'): 6.90875477931522,
#  ('lusb', 'sweat'): 6.90875477931522,
#  ('asthma', 'para'): 6.90875477931522,
#  ('precordium', 'sweat'): 6.90875477931522,
#  ('barium', 'mottl'): 6.90875477931522,
#  ('declin', 'dni'): 2.5893673028298645,
#  ('cmo', 'prognosi'): -6.90875477931522,
#  ('mood', 'nocturn'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('gastriti', 'predict'): 6.90875477931522,
#  ('autoset', 'declin'): 6.90875477931522,
#  ('im', 'nifedipin'): 6.90875477931522,
#  ('dnr', 'hctz'): 6.90875477931522,
#  ('ffp', 'platelet'): -6.90875477931522,
#  ('dopamin', 'scar'): 6.90875477931522,
#  ('azotemia', 'motor'): 6.90875477931522,
#  ('hive', 'mood'): 6.90875477931522,
#  ('hypotherm', 'rusti'): -6.90875477931522,
#  ('seroquel', 'ultram'): 6.90875477931522,
#  ('thrive', 'vagu'): 6.90875477931522,
#  ('captopril', 'predict'): 6.90875477931522,
#  ('hospic', 'underneath'): -6.90875477931522,
#  ('anur', 'rpr'): 6.90875477931522,
#  ('hung', 'vasopressin'): -6.90875477931522,
#  ('rhinorrhea', 'wish'): 6.90875477931522,
#  ('neo', 'recalibr'): 6.90875477931522,
#  ('acc', 'ba'): 6.90875477931522,
#  ('gastriti', 'hive'): 6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('carvedilol', 'pleasant'): 6.90875477931522,
#  ('bair', 'vasopressor'): -6.90875477931522,
#  ('cocain', 'crack'): 6.90875477931522,
#  ('ferritin', 'nifedipin'): 6.90875477931522,
#  ('bottl', 'hygein'): 6.90875477931522,
#  ('calculi', 'suprapub'): 6.90875477931522,
#  ('acc', 'scar'): 6.90875477931522,
#  ('colonoscopi', 'dnr'): 6.90875477931522,
#  ('burn', 'epigastr'): 6.90875477931522,
#  ('hunger', 'scar'): -6.90875477931522,
#  ('ctx', 'dopamin'): 6.90875477931522,
#  ('familt', 'palli'): -6.90875477931522,
#  ('ctx', 'neo'): 6.90875477931522,
#  ('flight', 'stair'): 6.90875477931522,
#  ('anaphylaxi', 'levoph'): 6.90875477931522,
#  ('calvarium', 'occipit'): 6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('occipit', 'subdur'): 6.90875477931522,
#  ('breakfast', 'mellitu'): 6.90875477931522,
#  ('epigastr', 'nicotin'): 6.90875477931522,
#  ('bromid', 'omeprazol'): 6.90875477931522,
#  ('anur', 'gentamycin'): -6.90875477931522,
#  ('dead', 'synthet'): -6.90875477931522,
#  ('massag', 'oncologist'): 6.90875477931522,
#  ('fibrinogen', 'norepinephrin'): -2.4258395487508584,
#  ('arrest', 'dic'): -6.90875477931522,
#  ('ctx', 'gabapentin'): 6.90875477931522,
#  ('ciwa', 'oob'): 6.90875477931522,
#  ('fdp', 'fibrinogen'): -6.90875477931522,
#  ('dz', 'pneumococc'): 6.90875477931522,
#  ('oob', 'readmit'): 6.90875477931522,
#  ('paralyt', 'phenylephrin'): -6.90875477931522,
#  ('seroquel', 'uri'): 6.90875477931522,
#  ('intiat', 'sensat'): 6.90875477931522,
#  ('ppd', 'prec'): 6.90875477931522,
#  ('adam', 'dnr'): -6.90875477931522,
#  ('azotemia', 'ciwa'): 6.90875477931522,
#  ('banana', 'ciwa'): 6.90875477931522,
#  ('nonrebreath', 'romi'): 6.90875477931522,
#  ('calvarium', 'effac'): 0.0,
#  ('bottl', 'currenlti'): 6.90875477931522,
#  ('dic', 'gadolinium'): 6.90875477931522,
#  ('book', 'fax'): 6.90875477931522,
#  ('klonopin', 'zyprexa'): 6.90875477931522,
#  ('oob', 'spiromet'): 6.90875477931522,
#  ('neosynephrin', 'phenylephrin'): -6.90875477931522,
#  ('ppd', 'soln'): 6.90875477931522,
#  ('redirect', 'wallet'): -6.90875477931522,
#  ('cs', 'zyprexa'): 6.90875477931522,
#  ('myeloma', 'rhinorrhea'): -6.90875477931522,
#  ('carvedilol', 'seroquel'): 6.90875477931522,
#  ('asthma', 'nectar'): 6.90875477931522,
#  ('angioplasti', 'dnr'): 6.90875477931522,
#  ('bottl', 'dnr'): 6.90875477931522,
#  ('hilum', 'slice'): 6.90875477931522,
#  ('anur', 'dnr'): -1.3825560390092835,
#  ('acc', 'dietari'): 6.90875477931522,
#  ('chair', 'zyprexa'): 6.90875477931522,
#  ('osa', 'seat'): 6.90875477931522,
#  ('hilum', 'nephrogram'): 6.90875477931522,
#  ('dnr', 'xl'): 6.90875477931522,
#  ('ferritin', 'ration'): 6.90875477931522,
#  ('moan', 'rabbi'): -6.90875477931522,
#  ('hsq', 'phlegm'): 6.90875477931522,
#  ('nicotin', 'xopenex'): 6.90875477931522,
#  ('aaox', 'subdur'): 6.90875477931522,
#  ('crack', 'hygein'): 6.90875477931522,
#  ('exophyt', 'peribronchovascular'): 6.90875477931522,
#  ('hive', 'iddm'): 6.90875477931522,
#  ('intent', 'phlegm'): 6.90875477931522,
#  ('dopamin', 'neo'): 2.473073171472692,
#  ('barium', 'breakfast'): 6.90875477931522,
#  ('ba', 'opiat'): 6.90875477931522,
#  ('dni', 'hugger'): -6.90875477931522,
#  ('cefapim', 'kerlix'): 6.90875477931522,
#  ('pleasantli', 'subdur'): 6.90875477931522,
#  ('clonazepam', 'recruit'): 6.90875477931522,
#  ('dni', 'nectar'): 6.90875477931522,
#  ('aaox', 'syst'): 6.90875477931522,
#  ('puff', 'sibl'): 6.90875477931522,
#  ('lymphangit', 'soln'): 6.90875477931522,
#  ('acc', 'angri'): 6.90875477931522,
#  ('db', 'para'): 6.90875477931522,
#  ('dnr', 'oligur'): -1.604655121332035,
#  ('incent', 'nonrebreath'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('bipolar', 'opiat'): 6.90875477931522,
#  ('morbid', 'romi'): 6.90875477931522,
#  ('aaox', 'pleasant'): 6.90875477931522,
#  ('dni', 'pca'): 6.90875477931522,
#  ('bair', 'pinpoint'): -6.90875477931522,
#  ('harm', 'oob'): 6.90875477931522,
#  ('ambien', 'ciwa'): 6.90875477931522,
#  ('permiss', 'pose'): 6.90875477931522,
#  ('dni', 'hilum'): -6.90875477931522,
#  ('mtg', 'rhinorrhea'): 6.90875477931522,
#  ('ambul', 'palli'): -6.90875477931522,
#  ('hctz', 'sensat'): 6.90875477931522,
#  ('bank', 'itchi'): 6.90875477931522,
#  ('cs', 'tran'): 6.90875477931522,
#  ('acidot', 'dic'): -6.90875477931522,
#  ('qam', 'sibl'): 6.90875477931522,
#  ('cagluc', 'neo'): -6.90875477931522,
#  ('laminectomi', 'unstabl'): 6.90875477931522,
#  ('ciwa', 'sweat'): 6.90875477931522,
#  ('eg', 'foci'): 6.90875477931522,
#  ('articul', 'lat'): 6.90875477931522,
#  ('morbid', 'uri'): 6.90875477931522,
#  ('commod', 'option'): 6.90875477931522,
#  ('lat', 'qtc'): 6.90875477931522,
#  ('dyslipidemia', 'thiamin'): 6.90875477931522,
#  ('freeli', 'protrud'): -6.90875477931522,
#  ('mellitu', 'rigor'): 6.90875477931522,
#  ('grim', 'sluggish'): -6.90875477931522,
#  ('bicarbon', 'sluggishli'): -6.90875477931522,
#  ('appi', 'arrest'): 6.90875477931522,
#  ('gadolinium', 'uri'): 6.90875477931522,
#  ('gabapentin', 'profound'): 6.90875477931522,
#  ('deterior', 'lift'): 6.90875477931522,
#  ('anaphylaxi', 'subq'): 6.90875477931522,
#  ('diaphoresi', 'strictur'): 6.90875477931522,
#  ('dnr', 'scopalamin'): 0.2226944607151099,
#  ('dnr', 'heroic'): -6.90875477931522,
#  ('dnr', 'pinpoint'): -6.90875477931522,
#  ('sweat', 'thiamin'): 6.90875477931522,
#  ('death', 'omeprazol'): 6.90875477931522,
#  ('declin', 'nicotin'): 6.90875477931522,
#  ...}

# %% [markdown]
# ### Train mode

# %% [markdown]
# #### Method 2. Each patient graph => [model training]

# %%
# Dictionaries to use
 # struct: {word: word2vec[128, numpy.array]}
patient_cooc_odd_scores # struct: {cooc_tuple: log_odds_score}
print()

# %%
patient_cooc_odd_scores
# Out:
# {('aricept', 'gentamycin'): -6.90875477931522,
#  ('dnr', 'refractori'): 6.90875477931522,
#  ('aricept', 'romi'): 6.90875477931522,
#  ('oncologist', 'pleasant'): 6.90875477931522,
#  ('fu', 'ntnd'): 6.90875477931522,
#  ('autopsi', 'dead'): -6.90875477931522,
#  ('appi', 'dnr'): 6.90875477931522,
#  ('gait', 'sarna'): 6.90875477931522,
#  ('ligament', 'treitz'): 0.6916505477038827,
#  ('director', 'zero'): 6.90875477931522,
#  ('dd', 'dnr'): 6.90875477931522,
#  ('romi', 'scar'): 6.90875477931522,
#  ('death', 'intiat'): -6.90875477931522,
#  ('adenocarcinoma', 'natg'): 6.90875477931522,
#  ('hypothermia', 'wma'): 6.90875477931522,
#  ('herp', 'nephrolog'): 6.90875477931522,
#  ('agon', 'pea'): -6.90875477931522,
#  ('adam', 'captopril'): -6.90875477931522,
#  ('dermat', 'pharmacolog'): 6.90875477931522,
#  ('cmo', 'lpm'): -6.90875477931522,
#  ('dni', 'surviv'): 6.90875477931522,
#  ('asthma', 'coach'): 6.90875477931522,
#  ('breakfast', 'video'): 6.90875477931522,
#  ('levoph', 'trazodon'): 6.90875477931522,
#  ('agon', 'readmit'): 6.90875477931522,
#  ('cocain', 'lac'): 6.90875477931522,
#  ('calculi', 'rehabilit'): 6.90875477931522,
#  ('barium', 'cooki'): 6.90875477931522,
#  ('incis', 'occipit'): 6.90875477931522,
#  ('laminectomi', 'stitch'): 6.90875477931522,
#  ('lpm', 'moan'): 6.90875477931522,
#  ('cash', 'hospic'): 6.90875477931522,
#  ('aliv', 'jewelri'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('bank', 'gabapentin'): 6.90875477931522,
#  ('freeli', 'refractori'): 6.90875477931522,
#  ('fatti', 'pca'): 6.90875477931522,
#  ('azotemia', 'wish'): 6.90875477931522,
#  ('flight', 'magnevist'): 6.90875477931522,
#  ('cocain', 'rm'): 6.90875477931522,
#  ('hypothermia', 'prilosec'): 6.90875477931522,
#  ('burn', 'historian'): 6.90875477931522,
#  ('burn', 'dnr'): 6.90875477931522,
#  ('foci', 'gastrojejunostomi'): 6.90875477931522,
#  ('epidur', 'norepinephrin'): 6.90875477931522,
#  ('dni', 'unasyn'): 6.90875477931522,
#  ('cocain', 'nifedipin'): 6.90875477931522,
#  ('gvhd', 'xii'): 6.90875477931522,
#  ('oligur', 'wish'): -6.90875477931522,
#  ('adenosin', 'vasopressin'): 6.90875477931522,
#  ('oncologist', 'paperwork'): 6.90875477931522,
#  ('dyslipidemia', 'gait'): 6.90875477931522,
#  ('historian', 'young'): 6.90875477931522,
#  ('dizzi', 'levoph'): 6.90875477931522,
#  ('pea', 'wish'): -6.90875477931522,
#  ('cocain', 'sweat'): 6.90875477931522,
#  ('plate', 'splint'): 6.90875477931522,
#  ('dnr', 'lift'): 6.90875477931522,
#  ('vasopressor', 'vtach'): -6.90875477931522,
#  ('aliv', 'mind'): 6.90875477931522,
#  ('expir', 'forc'): 6.90875477931522,
#  ('cmo', 'hypotherm'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('anuria', 'arrest'): 6.90875477931522,
#  ('breakfast', 'esld'): 6.90875477931522,
#  ('xii', 'young'): 6.90875477931522,
#  ('platelet', 'rhinorrhea'): 1.095952712632351,
#  ('breakfast', 'fibrinogen'): 6.90875477931522,
#  ('asthma', 'habitu'): 6.90875477931522,
#  ('gasp', 'mso'): -6.90875477931522,
#  ('jewelri', 'probe'): 6.90875477931522,
#  ('intiat', 'pronounc'): -6.90875477931522,
#  ('fax', 'pleasant'): 6.90875477931522,
#  ('hospic', 'hunger'): -6.90875477931522,
#  ('colonoscopi', 'motor'): 6.90875477931522,
#  ('levoph', 'sweat'): 6.90875477931522,
#  ('angioplasti', 'cyanot'): 6.90875477931522,
#  ('anur', 'gabapentin'): 6.90875477931522,
#  ('dni', 'profound'): 0.6916505477038827,
#  ('anur', 'ggt'): -6.90875477931522,
#  ('ambien', 'commod'): 6.90875477931522,
#  ('barium', 'lusb'): 6.90875477931522,
#  ('dobutamin', 'intiat'): 6.90875477931522,
#  ('db', 'rm'): 6.90875477931522,
#  ('cocain', 'herp'): 6.90875477931522,
#  ('expir', 'wish'): -6.90875477931522,
#  ('db', 'dyslipidemia'): 6.90875477931522,
#  ('iddm', 'tubular'): 6.90875477931522,
#  ('escal', 'neo'): -6.90875477931522,
#  ('profound', 'romi'): 6.90875477931522,
#  ('pastor', 'pea'): -6.90875477931522,
#  ('dopamin', 'lat'): 6.90875477931522,
#  ('captopril', 'core'): -6.90875477931522,
#  ('foci', 'postop'): 6.90875477931522,
#  ('aaox', 'dz'): 6.90875477931522,
#  ('mellitu', 'palli'): 6.90875477931522,
#  ('predict', 'rabbi'): -6.90875477931522,
#  ('hive', 'platelet'): -6.90875477931522,
#  ('levoph', 'vasoconstrict'): -6.90875477931522,
#  ('aricept', 'cash'): -6.90875477931522,
#  ('omeprazol', 'solut'): 6.90875477931522,
#  ('dizzi', 'dni'): 6.90875477931522,
#  ('fibrinogen', 'pod'): 6.90875477931522,
#  ('autopsi', 'pea'): -6.90875477931522,
#  ('motor', 'unavail'): 6.90875477931522,
#  ('fungemia', 'lw'): -6.90875477931522,
#  ('hypothermia', 'ppd'): 6.90875477931522,
#  ('prec', 'rm'): 6.90875477931522,
#  ('oob', 'palli'): 6.90875477931522,
#  ('dnr', 'unrel'): -6.90875477931522,
#  ('fibrinogen', 'prilosec'): -6.90875477931522,
#  ('dnr', 'zyprexa'): 1.8806492362025304,
#  ('ctx', 'hsq'): 6.90875477931522,
#  ('rehabilit', 'thrive'): 6.90875477931522,
#  ('metoclopramid', 'silent'): 6.90875477931522,
#  ('bicarbon', 'levoph'): -6.90875477931522,
#  ('cloth', 'diflucan'): 6.90875477931522,
#  ('aaox', 'gurgl'): -6.90875477931522,
#  ('epidur', 'oob'): 6.90875477931522,
#  ('cmo', 'dnr'): -1.521688576085562,
#  ('eg', 'mandibl'): 6.90875477931522,
#  ('hypothermia', 'pcv'): -6.90875477931522,
#  ('dermat', 'xii'): -6.90875477931522,
#  ('amb', 'nahco'): 6.90875477931522,
#  ('dyslipidemia', 'romi'): 6.90875477931522,
#  ('cpr', 'paralyt'): -6.90875477931522,
#  ('death', 'puff'): 6.90875477931522,
#  ('dnr', 'rusti'): -6.90875477931522,
#  ('asthma', 'readdress'): 6.90875477931522,
#  ('im', 'occipit'): 6.90875477931522,
#  ('palli', 'struggl'): -6.90875477931522,
#  ('sweat', 'xl'): 6.90875477931522,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('dni', 'unobtain'): 0.6916505477038827,
#  ('nonlabor', 'subq'): 6.90875477931522,
#  ('gasp', 'sensat'): -6.90875477931522,
#  ('homogen', 'mjmgb'): 6.90875477931522,
#  ('dopamin', 'mso'): 0.6916505477038827,
#  ('gabapentin', 'mood'): 6.90875477931522,
#  ('levoph', 'rigor'): 6.90875477931522,
#  ('aricept', 'lusb'): 6.90875477931522,
#  ('fatti', 'nephrogram'): 6.90875477931522,
#  ('norepinephrin', 'permiss'): -6.90875477931522,
#  ('aox', 'coach'): 6.90875477931522,
#  ('crowd', 'xl'): 6.90875477931522,
#  ('chemic', 'unasyn'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('flight', 'gvhd'): 6.90875477931522,
#  ('oob', 'uri'): 6.90875477931522,
#  ('fatti', 'intiat'): 6.90875477931522,
#  ('prognosi', 'scopalamin'): -6.90875477931522,
#  ('hilum', 'vertebra'): -6.90875477931522,
#  ('peac', 'scopalamin'): -6.90875477931522,
#  ('diaphoresi', 'iddm'): 6.90875477931522,
#  ('gait', 'vasopressin'): -6.90875477931522,
#  ('ffp', 'opinion'): 6.90875477931522,
#  ('asthma', 'dnr'): 3.0693478748272645,
#  ('hunger', 'zoloft'): -6.90875477931522,
#  ('bipolar', 'dnr'): -2.0293823968853086,
#  ('occupi', 'rehabilit'): 6.90875477931522,
#  ('dnr', 'pleuravac'): -6.90875477931522,
#  ('autopeep', 'hypothermia'): -6.90875477931522,
#  ('hive', 'im'): 6.90875477931522,
#  ('phenylephrin', 'requr'): -6.90875477931522,
#  ('silent', 'young'): 6.90875477931522,
#  ('ctx', 'lat'): 6.90875477931522,
#  ('recalibr', 'stitch'): 6.90875477931522,
#  ('emper', 'lac'): 6.90875477931522,
#  ('sluggishli', 'wma'): -6.90875477931522,
#  ('historian', 'opiat'): 6.90875477931522,
#  ('heroic', 'option'): -6.90875477931522,
#  ('declin', 'sweat'): 6.90875477931522,
#  ('venti', 'young'): 6.90875477931522,
#  ('gastrojejunostomi', 'metoclopramid'): 6.90875477931522,
#  ('nicotin', 'uri'): 6.90875477931522,
#  ('barium', 'foci'): 0.0,
#  ('commod', 'platelet'): 6.90875477931522,
#  ('asthma', 'ruptur'): 6.90875477931522,
#  ('azotemia', 'fdp'): -6.90875477931522,
#  ('barium', 'laryng'): 6.90875477931522,
#  ('sensat', 'thirst'): 6.90875477931522,
#  ('palli', 'xii'): -6.90875477931522,
#  ('commod', 'tracheomalacia'): 6.90875477931522,
#  ('ba', 'precordium'): 6.90875477931522,
#  ('deterior', 'echocardiogram'): 6.90875477931522,
#  ('chemic', 'cocain'): 6.90875477931522,
#  ('cocain', 'xii'): 6.90875477931522,
#  ('echocardiogram', 'jejunum'): 6.90875477931522,
#  ('cmo', 'levoph'): -1.3825560390092835,
#  ('piriform', 'silent'): 6.90875477931522,
#  ('autopeep', 'norepinephrin'): -6.90875477931522,
#  ('hypothermia', 'vasopressor'): -6.90875477931522,
#  ('declin', 'xii'): 6.90875477931522,
#  ('oob', 'ultram'): 6.90875477931522,
#  ('epigastr', 'qam'): 6.90875477931522,
#  ('cmo', 'suffer'): -6.90875477931522,
#  ('dnr', 'vtach'): -6.90875477931522,
#  ('asthma', 'mucinex'): 6.90875477931522,
#  ('esld', 'phenylephrin'): -0.06655815957840429,
#  ('ctx', 'wma'): 6.90875477931522,
#  ('arrest', 'incis'): 6.90875477931522,
#  ('arrest', 'profound'): -6.90875477931522,
#  ('commod', 'spirit'): 6.90875477931522,
#  ('deterior', 'palli'): -6.90875477931522,
#  ('dopamin', 'vasopressor'): -6.90875477931522,
#  ('agreement', 'heroic'): -6.90875477931522,
#  ('iddm', 'sluggish'): 6.90875477931522,
#  ('anaphylaxi', 'ferritin'): 6.90875477931522,
#  ('ctx', 'retic'): 6.90875477931522,
#  ('dni', 'stair'): 6.90875477931522,
#  ('gastriti', 'seriou'): 6.90875477931522,
#  ('hctz', 'predict'): 6.90875477931522,
#  ('freeli', 'scar'): 6.90875477931522,
#  ('cracker', 'venti'): 6.90875477931522,
#  ('pyuria', 'silent'): -6.90875477931522,
#  ('commod', 'diaper'): 6.90875477931522,
#  ('im', 'platelet'): 6.90875477931522,
#  ('captopril', 'hypotherm'): -6.90875477931522,
#  ('life', 'wish'): 0.4046335072286383,
#  ('pod', 'soln'): 6.90875477931522,
#  ('dnr', 'underneath'): -6.90875477931522,
#  ('mso', 'syst'): 6.90875477931522,
#  ('exophyt', 'unenhanc'): 6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('hive', 'sweat'): 6.90875477931522,
#  ('flight', 'pleasant'): 6.90875477931522,
#  ('anur', 'trazodon'): 6.90875477931522,
#  ('incent', 'oob'): 6.90875477931522,
#  ('bipolar', 'mood'): 6.90875477931522,
#  ('db', 'jewelri'): 6.90875477931522,
#  ('uncoop', 'video'): 6.90875477931522,
#  ('seat', 'tdi'): 6.90875477931522,
#  ('dnr', 'friction'): 6.90875477931522,
#  ('bill', 'metoclopramid'): 6.90875477931522,
#  ('norepinephrin', 'ultram'): 6.90875477931522,
#  ('lighthead', 'pleasant'): 6.90875477931522,
#  ('incent', 'phlegm'): 6.90875477931522,
#  ('pronounc', 'sacrament'): -6.90875477931522,
#  ('jejunum', 'tie'): 6.90875477931522,
#  ('dni', 'lat'): 6.90875477931522,
#  ('hive', 'money'): 6.90875477931522,
#  ('bottl', 'crack'): 6.90875477931522,
#  ('chair', 'dni'): 0.4510520218895015,
#  ('life', 'pastor'): -6.90875477931522,
#  ('ambien', 'unasyn'): 6.90875477931522,
#  ('sibl', 'vasoconstrict'): -6.90875477931522,
#  ('scopalamin', 'seroquel'): 6.90875477931522,
#  ('aaox', 'pod'): 6.90875477931522,
#  ('acc', 'romi'): 6.90875477931522,
#  ('breakfast', 'nahco'): 6.90875477931522,
#  ('bank', 'dnr'): 6.90875477931522,
#  ('hospic', 'oder'): -6.90875477931522,
#  ('oob', 'syst'): 6.90875477931522,
#  ('anur', 'pleasant'): 6.90875477931522,
#  ('aricept', 'wallet'): -6.90875477931522,
#  ('gasp', 'hilum'): -6.90875477931522,
#  ('escal', 'wish'): -6.90875477931522,
#  ('expir', 'nahco'): -6.90875477931522,
#  ('criticar', 'oligur'): 6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('thrive', 'young'): 6.90875477931522,
#  ('ppd', 'thrive'): 6.90875477931522,
#  ('norepinephrin', 'oligur'): -6.90875477931522,
#  ('romi', 'thiamin'): 6.90875477931522,
#  ('deterior', 'mellitu'): 6.90875477931522,
#  ('icter', 'mellitu'): 6.90875477931522,
#  ('declin', 'oob'): 6.90875477931522,
#  ('natg', 'occipit'): 6.90875477931522,
#  ('dnr', 'fibrinogen'): 1.6507429622330152,
#  ('mucinex', 'option'): 6.90875477931522,
#  ('hive', 'metoclopramid'): 6.90875477931522,
#  ('hive', 'refractori'): 6.90875477931522,
#  ('requr', 'rm'): 6.90875477931522,
#  ('gabapentin', 'morbid'): 6.90875477931522,
#  ('epidur', 'gabapentin'): 6.90875477931522,
#  ('currenlti', 'qam'): 6.90875477931522,
#  ('epidur', 'zoloft'): 6.90875477931522,
#  ('aliv', 'dead'): 6.90875477931522,
#  ('acc', 'hsq'): 6.90875477931522,
#  ('aaox', 'dnr'): 1.604655121332035,
#  ('gabapentin', 'ppd'): 6.90875477931522,
#  ('diaphoresi', 'xl'): 6.90875477931522,
#  ('dyslipidemia', 'scar'): 6.90875477931522,
#  ('rigor', 'strictur'): 6.90875477931522,
#  ('scar', 'smooth'): 6.90875477931522,
#  ('liw', 'vasopressin'): -6.90875477931522,
#  ('arthrit', 'dnr'): 6.90875477931522,
#  ('duski', 'palli'): -6.90875477931522,
#  ('norepinephrin', 'recalibr'): 6.90875477931522,
#  ('plate', 'requr'): 6.90875477931522,
#  ('predict', 'ultram'): 6.90875477931522,
#  ('aox', 'predict'): 6.90875477931522,
#  ('clonazepam', 'schizophrenia'): 6.90875477931522,
#  ('dni', 'simpli'): 6.90875477931522,
#  ('dobutamin', 'levoph'): -3.403520263078295,
#  ('dni', 'fibrinogen'): 1.095952712632351,
#  ('calculi', 'oncologist'): 6.90875477931522,
#  ('clonidin', 'qam'): 6.90875477931522,
#  ('money', 'probe'): 6.90875477931522,
#  ('dni', 'unrel'): -6.90875477931522,
#  ('asystol', 'bank'): -6.90875477931522,
#  ('aricept', 'qam'): -6.90875477931522,
#  ('deliv', 'dni'): 6.90875477931522,
#  ('fc', 'pyuria'): -6.90875477931522,
#  ('commod', 'sarna'): 6.90875477931522,
#  ('eg', 'pharyng'): 6.90875477931522,
#  ('cloth', 'fatti'): 6.90875477931522,
#  ('ligament', 'smooth'): 6.90875477931522,
#  ('life', 'palli'): -6.90875477931522,
#  ('crowd', 'rhinorrhea'): 6.90875477931522,
#  ('fdp', 'ggt'): -6.90875477931522,
#  ('asthma', 'respon'): 6.90875477931522,
#  ('hemangioma', 'slice'): 6.90875477931522,
#  ('subcost', 'unavail'): 6.90875477931522,
#  ('dizzi', 'tcdb'): 6.90875477931522,
#  ('^th', 'commod'): 6.90875477931522,
#  ('opiat', 'thiamin'): 6.90875477931522,
#  ('ciwa', 'ran'): 6.90875477931522,
#  ('laryng', 'lat'): 6.90875477931522,
#  ('dopamin', 'unequ'): -6.90875477931522,
#  ('asthma', 'bottl'): 6.90875477931522,
#  ('hunger', 'prognosi'): -6.90875477931522,
#  ('hsq', 'xii'): 6.90875477931522,
#  ('chair', 'unasyn'): -0.5584397574369144,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('acv', 'levoph'): 6.90875477931522,
#  ('commod', 'incent'): 6.90875477931522,
#  ('lat', 'pneumothorac'): 0.6916505477038827,
#  ('ntnd', 'zoloft'): 6.90875477931522,
#  ('articul', 'rhinorrhea'): 6.90875477931522,
#  ('bromid', 'fibrinogen'): 6.90875477931522,
#  ('db', 'pleasant'): 6.90875477931522,
#  ('agon', 'arrest'): 0.0,
#  ('ciwa', 'itchi'): 6.90875477931522,
#  ('dni', 'lotion'): -6.90875477931522,
#  ('epigastr', 'hsq'): 6.90875477931522,
#  ('dni', 'video'): 0.20026746965023628,
#  ('rigor', 'sensat'): 6.90875477931522,
#  ('asthma', 'crack'): 6.90875477931522,
#  ('ba', 'sensat'): 6.90875477931522,
#  ('bair', 'paralyt'): 6.90875477931522,
#  ('pleasant', 'venti'): 6.90875477931522,
#  ('rigor', 'sweat'): 6.90875477931522,
#  ('ciwa', 'fatti'): 6.90875477931522,
#  ('db', 'scar'): 6.90875477931522,
#  ('option', 'pleasant'): 6.90875477931522,
#  ('dxae', 'pneumonectomi'): -6.90875477931522,
#  ('goc', 'nifedipin'): 6.90875477931522,
#  ('imbal', 'shorter'): 6.90875477931522,
#  ('ffp', 'mean'): -6.90875477931522,
#  ('ligament', 'para'): 6.90875477931522,
#  ('ofm', 'oob'): 6.90875477931522,
#  ('dni', 'hook'): 6.90875477931522,
#  ('calculi', 'trazodon'): 6.90875477931522,
#  ('anuria', 'bill'): 6.90875477931522,
#  ('dni', 'stg'): -6.90875477931522,
#  ('hemangioma', 'mjmgb'): 6.90875477931522,
#  ('captopril', 'ciwa'): 6.90875477931522,
#  ('pneumonectomi', 'tubular'): -6.90875477931522,
#  ('coarctat', 'habitu'): 6.90875477931522,
#  ('clonidin', 'unobtain'): 6.90875477931522,
#  ('dnr', 'unasyn'): 6.90875477931522,
#  ('fibrinogen', 'rigor'): 6.90875477931522,
#  ('calculi', 'homogen'): 6.90875477931522,
#  ('bronchovascular', 'mail'): 6.90875477931522,
#  ('barium', 'motor'): 6.90875477931522,
#  ('dyslipidemia', 'mellitu'): 6.90875477931522,
#  ('echocardiogram', 'rigor'): 6.90875477931522,
#  ('autopeep', 'hypercapnia'): -6.90875477931522,
#  ('palli', 'pleasant'): -6.90875477931522,
#  ('arrest', 'expir'): -6.90875477931522,
#  ('cdb', 'levoph'): 6.90875477931522,
#  ('paperwork', 'rehabilit'): 6.90875477931522,
#  ('chair', 'simpli'): 6.90875477931522,
#  ('diuril', 'dopamin'): 6.90875477931522,
#  ('gurgl', 'pleasant'): 6.90875477931522,
#  ('morgu', 'mortem'): -6.90875477931522,
#  ('deterior', 'readdress'): -6.90875477931522,
#  ('metoclopramid', 'soln'): 6.90875477931522,
#  ('hypothermia', 'robitussin'): 6.90875477931522,
#  ('clonidin', 'laminectomi'): 6.90875477931522,
#  ('asthma', 'escal'): 6.90875477931522,
#  ('dnr', 'synthet'): -6.90875477931522,
#  ('tcdb', 'uri'): 6.90875477931522,
#  ('autopsi', 'dnr'): -6.90875477931522,
#  ('aox', 'laminectomi'): 6.90875477931522,
#  ('opiat', 'ultram'): 6.90875477931522,
#  ('ctx', 'ultram'): 6.90875477931522,
#  ('arrest', 'dnr'): -6.90875477931522,
#  ('bank', 'colonoscopi'): 6.90875477931522,
#  ('pplat', 'thk'): 6.90875477931522,
#  ('readmit', 'scar'): 6.90875477931522,
#  ('escal', 'pea'): -6.90875477931522,
#  ('jewelri', 'signatur'): 2.387057016415087,
#  ('cs', 'oob'): 6.90875477931522,
#  ('dnr', 'nicotin'): 6.90875477931522,
#  ('palli', 'postop'): 6.90875477931522,
#  ('aricept', 'distanc'): 6.90875477931522,
#  ('ccn', 'levoph'): -6.90875477931522,
#  ('arrest', 'gait'): -6.90875477931522,
#  ('phenylephrin', 'synthet'): -6.90875477931522,
#  ('echocardiogram', 'palli'): -6.90875477931522,
#  ('among', 'foci'): -6.90875477931522,
#  ('dopamin', 'pitressin'): -6.90875477931522,
#  ('asthma', 'chair'): 2.09609753878805,
#  ('levoph', 'unstabl'): 0.0,
#  ('compani', 'omeprazol'): 6.90875477931522,
#  ('ipf', 'robitussin'): -6.90875477931522,
#  ('bottl', 'gum'): 6.90875477931522,
#  ('angioplasti', 'diaphoresi'): 6.90875477931522,
#  ('dnr', 'lotion'): -3.046848290615153,
#  ('rememb', 'ruptur'): 6.90875477931522,
#  ('judgement', 'mso'): -6.90875477931522,
#  ('aricept', 'commod'): -6.90875477931522,
#  ('breakfast', 'readdress'): 6.90875477931522,
#  ('dnr', 'west'): 6.90875477931522,
#  ('adam', 'deterior'): -6.90875477931522,
#  ('^th', 'oob'): 6.90875477931522,
#  ('dnr', 'dobutamin'): 1.2495579516853903,
#  ('ambul', 'dni'): 1.3825560390092835,
#  ('dni', 'heroic'): -6.90875477931522,
#  ('hctz', 'pneumococc'): 6.90875477931522,
#  ('gabapentin', 'xanax'): 6.90875477931522,
#  ('dnr', 'epigastr'): 6.90875477931522,
#  ('banana', 'rememb'): 6.90875477931522,
#  ('declin', 'zyprexa'): -6.90875477931522,
#  ('asthma', 'cellcept'): 6.90875477931522,
#  ('dni', 'mood'): 6.90875477931522,
#  ('endur', 'incis'): 6.90875477931522,
#  ('gvhd', 'levoph'): -6.90875477931522,
#  ('barium', 'spill'): 6.90875477931522,
#  ('contractur', 'scar'): 6.90875477931522,
#  ('aricept', 'gabapentin'): 6.90875477931522,
#  ('argatroban', 'norepinephrin'): -6.90875477931522,
#  ('im', 'prec'): 6.90875477931522,
#  ('cisatracurium', 'paralyt'): -6.90875477931522,
#  ('dnr', 'sluggish'): -0.5865449245323548,
#  ('asthma', 'clonidin'): 6.90875477931522,
#  ('hugger', 'vasopressor'): -6.90875477931522,
#  ('dnr', 'nitroglycerin'): 6.90875477931522,
#  ('dni', 'qam'): 1.3825560390092835,
#  ('bottl', 'opiat'): 6.90875477931522,
#  ('spill', 'videofluoroscopi'): 6.90875477931522,
#  ('commod', 'levoph'): -0.25080752166759324,
#  ('oob', 'tcdb'): 6.90875477931522,
#  ('hsq', 'platelet'): -6.90875477931522,
#  ('dni', 'oligur'): -1.604655121332035,
#  ('smooth', 'vertebra'): 0.0,
#  ('seroquel', 'unasyn'): 6.90875477931522,
#  ('flight', 'vp'): 6.90875477931522,
#  ('db', 'oob'): 6.90875477931522,
#  ('dni', 'jerk'): -6.90875477931522,
#  ('arrest', 'chb'): -6.90875477931522,
#  ('readmit', 'sweat'): 6.90875477931522,
#  ('im', 'mva'): 6.90875477931522,
#  ('schizophrenia', 'ultram'): 6.90875477931522,
#  ('ambul', 'furhter'): -6.90875477931522,
#  ('nocturn', 'profound'): 6.90875477931522,
#  ('anur', 'tcdb'): 6.90875477931522,
#  ('signatur', 'thiamin'): 6.90875477931522,
#  ('reguard', 'uncoop'): 6.90875477931522,
#  ('dni', 'meropenam'): -6.90875477931522,
#  ('aaox', 'nimv'): 6.90875477931522,
#  ('pneumococc', 'pod'): 6.90875477931522,
#  ('agon', 'neosynephrin'): -6.90875477931522,
#  ('cracker', 'spiromet'): -6.90875477931522,
#  ('chair', 'compani'): 6.90875477931522,
#  ('declin', 'dietari'): 6.90875477931522,
#  ('hugger', 'levoph'): 1.6688498669946448,
#  ('ambien', 'ferrou'): 6.90875477931522,
#  ('dead', 'sundown'): -6.90875477931522,
#  ('purpl', 'seroquel'): 6.90875477931522,
#  ('azotemia', 'habitu'): 6.90875477931522,
#  ('para', 'pneumococc'): 6.90875477931522,
#  ('clonidin', 'refractori'): 6.90875477931522,
#  ('incis', 'wish'): -6.90875477931522,
#  ('clonazepam', 'osa'): 6.90875477931522,
#  ('anaphylaxi', 'opiat'): 6.90875477931522,
#  ('absorb', 'paralyt'): 6.90875477931522,
#  ('pronounc', 'wish'): -6.90875477931522,
#  ('crack', 'ultram'): 6.90875477931522,
#  ('lat', 'mva'): 6.90875477931522,
#  ('chol', 'stg'): -6.90875477931522,
#  ('hospic', 'requr'): 6.90875477931522,
#  ('anur', 'flake'): 6.90875477931522,
#  ('gasp', 'qam'): -6.90875477931522,
#  ('deflat', 'lpm'): 6.90875477931522,
#  ('autopeep', 'dic'): -6.90875477931522,
#  ('autoset', 'ciwa'): 6.90875477931522,
#  ('soln', 'subdur'): 6.90875477931522,
#  ('hunger', 'xopenex'): -6.90875477931522,
#  ('asthma', 'uri'): 6.90875477931522,
#  ('phlegm', 'silent'): 6.90875477931522,
#  ('fatti', 'thiamin'): 6.90875477931522,
#  ('articul', 'dead'): 6.90875477931522,
#  ('ipf', 'norepinephrin'): -6.90875477931522,
#  ('mellitu', 'oob'): 6.90875477931522,
#  ('chair', 'prec'): 6.90875477931522,
#  ('cardiovert', 'neo'): -6.90875477931522,
#  ('oob', 'romi'): 6.90875477931522,
#  ('perisplen', 'scar'): 6.90875477931522,
#  ('mellitu', 'subdur'): 6.90875477931522,
#  ('dic', 'hive'): -6.90875477931522,
#  ('chair', 'lotion'): -3.02380801661965,
#  ('exophyt', 'fc'): -6.90875477931522,
#  ('adam', 'futil'): -6.90875477931522,
#  ('agreement', 'moan'): -6.90875477931522,
#  ('homogen', 'scar'): 6.90875477931522,
#  ('liw', 'vasoconstrict'): -6.90875477931522,
#  ('bill', 'fibrinogen'): 6.90875477931522,
#  ('autopeep', 'pcv'): -6.90875477931522,
#  ('calculi', 'fatti'): 6.90875477931522,
#  ('bicarbon', 'dic'): -6.90875477931522,
#  ('dic', 'sluggish'): -6.90875477931522,
#  ('expir', 'pea'): -6.90875477931522,
#  ('dni', 'gastriti'): 6.90875477931522,
#  ('cramp', 'fibrinogen'): 6.90875477931522,
#  ('levof', 'paralyt'): -6.90875477931522,
#  ('anur', 'rhinorrhea'): -6.90875477931522,
#  ('gown', 'gurgl'): -6.90875477931522,
#  ('lusb', 'retic'): 6.90875477931522,
#  ('diaphoresi', 'pleasant'): 6.90875477931522,
#  ('oncologist', 'ppn'): 6.90875477931522,
#  ('hung', 'religi'): -6.90875477931522,
#  ('asthma', 'ultram'): 6.90875477931522,
#  ('dni', 'hypotherm'): -1.604655121332035,
#  ('subq', 'zoloft'): 6.90875477931522,
#  ('dnr', 'sarna'): 6.90875477931522,
#  ('epigastr', 'incis'): 6.90875477931522,
#  ('hctz', 'prilosec'): 6.90875477931522,
#  ('asystol', 'mortem'): -6.90875477931522,
#  ('bromid', 'currenlti'): 6.90875477931522,
#  ('puff', 'refractori'): 6.90875477931522,
#  ('lw', 'twitch'): -6.90875477931522,
#  ('eg', 'mellitu'): 6.90875477931522,
#  ('ciwa', 'epigastr'): 6.90875477931522,
#  ('osteoblast', 'scar'): -6.90875477931522,
#  ('moan', 'oligur'): -6.90875477931522,
#  ('incis', 'lw'): 6.90875477931522,
#  ('bottl', 'gotten'): 6.90875477931522,
#  ('bipolar', 'zyprexa'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('oncologist', 'scar'): 6.90875477931522,
#  ('dni', 'quinolon'): -6.90875477931522,
#  ('acidot', 'phenylephrin'): -6.90875477931522,
#  ('life', 'scopalamin'): -6.90875477931522,
#  ('gait', 'hive'): 6.90875477931522,
#  ('binder', 'dni'): 6.90875477931522,
#  ('levoph', 'wma'): -6.90875477931522,
#  ('ctx', 'rhinorrhea'): 6.90875477931522,
#  ('cocain', 'ctx'): 6.90875477931522,
#  ('arrest', 'fibrinogen'): -6.90875477931522,
#  ('breakfast', 'nitroglycerin'): 6.90875477931522,
#  ('muir', 'passi'): 6.90875477931522,
#  ('breakfast', 'stitch'): 6.90875477931522,
#  ('suprapub', 'thrive'): 6.90875477931522,
#  ('cefapim', 'pleasant'): 6.90875477931522,
#  ('montitor', 'sluggish'): -6.90875477931522,
#  ('laminectomi', 'pleasant'): 6.90875477931522,
#  ('ciwa', 'wish'): 6.90875477931522,
#  ('dni', 'refractori'): 6.90875477931522,
#  ('dni', 'knowledg'): 6.90875477931522,
#  ('barium', 'nocturn'): 6.90875477931522,
#  ('chair', 'oob'): 1.6867328713947312,
#  ('core', 'scar'): 6.90875477931522,
#  ('cg', 'montitor'): -6.90875477931522,
#  ('autopeep', 'paralyt'): -6.90875477931522,
#  ('cocain', 'mycolyt'): 6.90875477931522,
#  ('lpm', 'mottl'): 6.90875477931522,
#  ('declin', 'scar'): 6.90875477931522,
#  ('puff', 'thrive'): 6.90875477931522,
#  ('ardsnet', 'norepinephrin'): -6.90875477931522,
#  ('autopeep', 'azotemia'): -6.90875477931522,
#  ('dic', 'futil'): -6.90875477931522,
#  ('pvr', 'spiromet'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('laryng', 'silent'): 6.90875477931522,
#  ('bill', 'subdur'): 6.90875477931522,
#  ('bicarbon', 'cpr'): -6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('fibrinogen', 'levof'): -6.90875477931522,
#  ('dni', 'redirect'): 2.2204460492503128e-16,
#  ('homogen', 'nephrogram'): 0.6916505477038827,
#  ('gadolinium', 'levoph'): 6.90875477931522,
#  ('dic', 'impli'): 6.90875477931522,
#  ('ciwa', 'neoplast'): 6.90875477931522,
#  ('dnr', 'sibl'): 6.90875477931522,
#  ('lc', 'pinpoint'): -6.90875477931522,
#  ('money', 'oob'): 6.90875477931522,
#  ('schistocyt', 'syncop'): 6.90875477931522,
#  ('gait', 'pleasant'): 6.90875477931522,
#  ('cmo', 'peac'): -6.90875477931522,
#  ('ferrou', 'nocturn'): 6.90875477931522,
#  ('aaox', 'commod'): 6.90875477931522,
#  ('deliv', 'respitori'): 6.90875477931522,
#  ('ba', 'ciwa'): 6.90875477931522,
#  ('contd', 'refractori'): 6.90875477931522,
#  ('gotten', 'msicu'): 6.90875477931522,
#  ('nephrolog', 'omeprazol'): 6.90875477931522,
#  ('mva', 'spacer'): 6.90875477931522,
#  ('puff', 'sweat'): 6.90875477931522,
#  ('fibrinogen', 'readdress'): 6.90875477931522,
#  ('bicarbon', 'cvvh'): -6.90875477931522,
#  ('cash', 'redirect'): -6.90875477931522,
#  ('omeprazol', 'stitch'): 6.90875477931522,
#  ('ctx', 'lotion'): 6.90875477931522,
#  ('ethic', 'polici'): -6.90875477931522,
#  ('elimin', 'pathologist'): 6.90875477931522,
#  ('intent', 'ppd'): 6.90875477931522,
#  ('aox', 'declin'): -6.90875477931522,
#  ('lymphangit', 'pronounc'): -6.90875477931522,
#  ('sarna', 'soln'): 6.90875477931522,
#  ('aliv', 'robitussin'): 6.90875477931522,
#  ('chol', 'underneath'): -6.90875477931522,
#  ('commod', 'xopenex'): 6.90875477931522,
#  ('fibrinogen', 'rhinorrhea'): 0.4046335072286383,
#  ('barium', 'spur'): 6.90875477931522,
#  ('postop', 'retic'): 6.90875477931522,
#  ('bicarbon', 'hypercapnia'): -6.90875477931522,
#  ('ntnd', 'subq'): 6.90875477931522,
#  ('dnr', 'hemothorax'): -6.90875477931522,
#  ('barium', 'neo'): 6.90875477931522,
#  ('agon', 'death'): -6.90875477931522,
#  ('incent', 'mottl'): 6.90875477931522,
#  ('oob', 'zyprexa'): 6.90875477931522,
#  ('ruptur', 'sibl'): 6.90875477931522,
#  ('habitu', 'mean'): 6.90875477931522,
#  ('arrest', 'tracheomalacia'): 6.90875477931522,
#  ('crack', 'habitu'): 6.90875477931522,
#  ('bottl', 'msicu'): 6.90875477931522,
#  ('ciwa', 'omeprazol'): 6.90875477931522,
#  ('dietari', 'wma'): 6.90875477931522,
#  ('ba', 'banana'): 6.90875477931522,
#  ('hygein', 'thiamin'): 6.90875477931522,
#  ('cvvhd', 'paralyt'): -6.90875477931522,
#  ('dni', 'occurr'): 6.90875477931522,
#  ('fatti', 'homogen'): 6.90875477931522,
#  ('arrest', 'norepinephrin'): -6.90875477931522,
#  ('criticar', 'dni'): 6.90875477931522,
#  ('schistocyt', 'young'): 6.90875477931522,
#  ('fdp', 'prilosec'): -6.90875477931522,
#  ('anur', 'commod'): -6.90875477931522,
#  ('hctz', 'led'): 6.90875477931522,
#  ('anyway', 'weekli'): 6.90875477931522,
#  ('declin', 'lusb'): 6.90875477931522,
#  ('asthma', 'mva'): 6.90875477931522,
#  ('asthma', 'breakfast'): 6.90875477931522,
#  ('bair', 'sluggish'): -6.90875477931522,
#  ('agon', 'pinpoint'): -6.90875477931522,
#  ('esoph', 'hunger'): -6.90875477931522,
#  ('chair', 'intent'): 6.90875477931522,
#  ('nocturn', 'sweat'): 6.90875477931522,
#  ('historian', 'unstabl'): 6.90875477931522,
#  ('bottl', 'trabecul'): 6.90875477931522,
#  ('gabapentin', 'syncop'): 6.90875477931522,
#  ('arthrit', 'commod'): 6.90875477931522,
#  ('pleasant', 'sensat'): 6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('lotion', 'pca'): 6.90875477931522,
#  ('phenylephrin', 'prognosi'): -6.90875477931522,
#  ('knowledg', 'life'): 6.90875477931522,
#  ('chair', 'maroon'): 6.90875477931522,
#  ('anuria', 'dead'): -6.90875477931522,
#  ('bair', 'hugger'): 0.12235699519301034,
#  ('gabapentin', 'postop'): 6.90875477931522,
#  ('contractur', 'dni'): -0.6916505477038827,
#  ('anyway', 'dni'): 6.90875477931522,
#  ('lighthead', 'nicotin'): 6.90875477931522,
#  ('agon', 'agreement'): -6.90875477931522,
#  ('ipf', 'occipit'): 0.0,
#  ('angioplasti', 'iddm'): 6.90875477931522,
#  ('deterior', 'gc'): 6.90875477931522,
#  ('dopamin', 'moan'): -6.90875477931522,
#  ('osa', 'romi'): 6.90875477931522,
#  ('chair', 'nectar'): 6.90875477931522,
#  ('fibrinogen', 'religi'): -6.90875477931522,
#  ('osa', 'trazodon'): 6.90875477931522,
#  ('declin', 'romi'): 6.90875477931522,
#  ('fibrinogen', 'ggt'): -6.90875477931522,
#  ('nonlabor', 'pleasant'): 6.90875477931522,
#  ('nonreact', 'palli'): -6.90875477931522,
#  ('lpm', 'polici'): -6.90875477931522,
#  ('aliv', 'sweat'): 6.90875477931522,
#  ('shorter', 'strictur'): 6.90875477931522,
#  ('anur', 'illeu'): -6.90875477931522,
#  ('cisatracurium', 'phenylephrin'): -6.90875477931522,
#  ('omeprazol', 'schizophrenia'): 6.90875477931522,
#  ('fibrinogen', 'pastor'): -6.90875477931522,
#  ('historian', 'jewelri'): 6.90875477931522,
#  ('fatti', 'intent'): 6.90875477931522,
#  ('chair', 'gurgl'): -6.90875477931522,
#  ('dnr', 'muddi'): 1.0271828417136022,
#  ('pneumococc', 'sibl'): 6.90875477931522,
#  ('dni', 'ffp'): -2.473073171472692,
#  ('peribronchovascular', 'slice'): 6.90875477931522,
#  ('anuria', 'levoph'): -6.90875477931522,
#  ('burn', 'commod'): 6.90875477931522,
#  ('captopril', 'futil'): -6.90875477931522,
#  ('autoset', 'habitu'): 6.90875477931522,
#  ('cpr', 'mortem'): -6.90875477931522,
#  ('peribronchovascular', 'unstabl'): 6.90875477931522,
#  ('exophyt', 'pyuria'): -6.90875477931522,
#  ('grave', 'hook'): 6.90875477931522,
#  ('epigastr', 'hctz'): 6.90875477931522,
#  ('dni', 'gc'): 6.90875477931522,
#  ('cash', 'xl'): 6.90875477931522,
#  ('ambul', 'lac'): 6.90875477931522,
#  ('angiogram', 'deploy'): 6.90875477931522,
#  ('nectar', 'oob'): 6.90875477931522,
#  ('gvhd', 'wish'): 6.90875477931522,
#  ('ambul', 'asthma'): 6.90875477931522,
#  ('olanzapin', 'reguard'): 6.90875477931522,
#  ('oncologist', 'refractori'): 6.90875477931522,
#  ('crack', 'mycolyt'): 6.90875477931522,
#  ('echocardiogram', 'hive'): 6.90875477931522,
#  ('cdb', 'ctx'): 6.90875477931522,
#  ('cmo', 'oder'): -6.90875477931522,
#  ('mellitu', 'simpli'): 6.90875477931522,
#  ('gadolinium', 'vertebra'): 6.90875477931522,
#  ('ferrou', 'xl'): 6.90875477931522,
#  ('gait', 'lotion'): 6.90875477931522,
#  ('pronounc', 'vasopressin'): -6.90875477931522,
#  ('dni', 'respitori'): 6.90875477931522,
#  ('para', 'sweat'): 6.90875477931522,
#  ('laryng', 'vallecula'): 6.90875477931522,
#  ('peac', 'prognosi'): -6.90875477931522,
#  ('hilum', 'jejunum'): 6.90875477931522,
#  ('aricept', 'dnr'): 0.1428142402977353,
#  ('fibrinogen', 'pyuria'): 6.90875477931522,
#  ('dizzi', 'xl'): 6.90875477931522,
#  ('flight', 'gadolinium'): 6.90875477931522,
#  ('diaphoresi', 'sensat'): 6.90875477931522,
#  ('levoph', 'motil'): -6.90875477931522,
#  ('ctx', 'pleasant'): 6.90875477931522,
#  ('ppd', 'sensat'): 6.90875477931522,
#  ('ofm', 'svn'): 6.90875477931522,
#  ('dnr', 'sluggishli'): -6.90875477931522,
#  ('mind', 'paperwork'): 6.90875477931522,
#  ('absorb', 'asthma'): 6.90875477931522,
#  ('profound', 'slice'): 6.90875477931522,
#  ('barium', 'vallecula'): 6.90875477931522,
#  ('gabapentin', 'hive'): 6.90875477931522,
#  ('cyanot', 'oob'): -6.90875477931522,
#  ('death', 'hive'): 6.90875477931522,
#  ('qam', 'vagu'): 6.90875477931522,
#  ('ntnd', 'thiamin'): 6.90875477931522,
#  ('ambul', 'dz'): 6.90875477931522,
#  ('osa', 'young'): 6.90875477931522,
#  ('gait', 'oob'): 2.1883847407670785,
#  ('ctx', 'silent'): 6.90875477931522,
#  ('ctx', 'declin'): 6.90875477931522,
#  ('dz', 'slough'): 6.90875477931522,
#  ('oncologist', 'thrive'): 6.90875477931522,
#  ('neoplast', 'palli'): 6.90875477931522,
#  ('gabapentin', 'nocturn'): 6.90875477931522,
#  ('learn', 'moan'): 6.90875477931522,
#  ('gastriti', 'laminectomi'): 6.90875477931522,
#  ('arrang', 'cpr'): -6.90875477931522,
#  ('assymetr', 'xl'): 6.90875477931522,
#  ('platelet', 'suffer'): -6.90875477931522,
#  ('freeli', 'strictur'): 6.90875477931522,
#  ('hunger', 'suffer'): -6.90875477931522,
#  ('nocturn', 'rhinorrhea'): 6.90875477931522,
#  ('azotemia', 'hctz'): 6.90875477931522,
#  ('asystol', 'dnr'): -6.90875477931522,
#  ('anyway', 'dnr'): 6.90875477931522,
#  ('dic', 'goc'): -6.90875477931522,
#  ('ppd', 'suprapub'): 6.90875477931522,
#  ('opiat', 'unasyn'): 6.90875477931522,
#  ('pronounc', 'unenhanc'): -6.90875477931522,
#  ('ferritin', 'hive'): 6.90875477931522,
#  ('jewelri', 'wallet'): 2.2927445483990123,
#  ('gvhd', 'lw'): -6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('crrt', 'platelet'): -6.90875477931522,
#  ('im', 'trazodon'): 6.90875477931522,
#  ('bipolar', 'forc'): -6.90875477931522,
#  ('dnr', 'pleasantli'): 6.90875477931522,
#  ('hctz', 'protrud'): 6.90875477931522,
#  ('calvarium', 'thrive'): -6.90875477931522,
#  ('anaphylaxi', 'escal'): 6.90875477931522,
#  ('bottl', 'osa'): 6.90875477931522,
#  ('pea', 'trazodon'): -6.90875477931522,
#  ('incis', 'seriou'): 6.90875477931522,
#  ('grave', 'prognosi'): -0.6916505477038827,
#  ('dni', 'moan'): -0.5378679732223673,
#  ('aaox', 'sundown'): 0.6916505477038827,
#  ('flake', 'gabapentin'): 6.90875477931522,
#  ('db', 'habitu'): 6.90875477931522,
#  ('retic', 'tremul'): 6.90875477931522,
#  ('dnr', 'mellitu'): 6.90875477931522,
#  ('fatti', 'stair'): 6.90875477931522,
#  ('dni', 'hypercapn'): 6.90875477931522,
#  ('dni', 'hospic'): -0.19198555128397649,
#  ('herp', 'stair'): 6.90875477931522,
#  ('cloth', 'db'): 6.90875477931522,
#  ('motor', 'retic'): 6.90875477931522,
#  ('crack', 'echocardiogram'): 6.90875477931522,
#  ('fdp', 'ffp'): -6.90875477931522,
#  ('mtg', 'palli'): -6.90875477931522,
#  ('cvvh', 'norepinephrin'): -6.90875477931522,
#  ('deterior', 'hugger'): 6.90875477931522,
#  ('ambien', 'appi'): 6.90875477931522,
#  ('mind', 'rehabilit'): 6.90875477931522,
#  ('hypotherm', 'pinpoint'): -6.90875477931522,
#  ('lotion', 'metoclopramid'): 6.90875477931522,
#  ('hospic', 'option'): 6.90875477931522,
#  ('cvvh', 'levoph'): -6.90875477931522,
#  ('quinolon', 'trazodon'): 6.90875477931522,
#  ('pneumococc', 'young'): 6.90875477931522,
#  ('arrest', 'azotemia'): -6.90875477931522,
#  ('option', 'tran'): 6.90875477931522,
#  ('chair', 'cramp'): 6.90875477931522,
#  ('bronchovascular', 'ctx'): 6.90875477931522,
#  ('ppd', 'thiamin'): 6.90875477931522,
#  ('predict', 'unstabl'): 6.90875477931522,
#  ('fwb', 'tremul'): 6.90875477931522,
#  ('ctx', 'moan'): 6.90875477931522,
#  ('cyanot', 'furhter'): -6.90875477931522,
#  ('cdb', 'hive'): 6.90875477931522,
#  ('dni', 'escal'): 2.224418442526018,
#  ('hilum', 'syncop'): 6.90875477931522,
#  ('absorb', 'omeprazol'): 6.90875477931522,
#  ('mtg', 'paralyt'): -6.90875477931522,
#  ('fdp', 'rhinorrhea'): -6.90875477931522,
#  ('bill', 'soln'): 6.90875477931522,
#  ('historian', 'venti'): -6.90875477931522,
#  ('bronchovascular', 'crowd'): 1.462247919771027,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('dnr', 'opinion'): -6.90875477931522,
#  ('clonazepam', 'platelet'): 6.90875477931522,
#  ('oncologist', 'romi'): 6.90875477931522,
#  ('dome', 'foci'): 6.90875477931522,
#  ('mva', 'promod'): 6.90875477931522,
#  ('autopeep', 'phenylephrin'): -6.90875477931522,
#  ('chair', 'death'): 6.90875477931522,
#  ('levoph', 'scopalamin'): -6.90875477931522,
#  ('clinician', 'escal'): -6.90875477931522,
#  ('banana', 'flake'): 6.90875477931522,
#  ('adam', 'declin'): -6.90875477931522,
#  ('declin', 'rhinorrhea'): 6.90875477931522,
#  ('prognosi', 'sibl'): -6.90875477931522,
#  ('esld', 'itchi'): -6.90875477931522,
#  ('autoset', 'ppd'): 6.90875477931522,
#  ('lusb', 'sweat'): 6.90875477931522,
#  ('asthma', 'para'): 6.90875477931522,
#  ('precordium', 'sweat'): 6.90875477931522,
#  ('barium', 'mottl'): 6.90875477931522,
#  ('declin', 'dni'): 2.5893673028298645,
#  ('cmo', 'prognosi'): -6.90875477931522,
#  ('mood', 'nocturn'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('gastriti', 'predict'): 6.90875477931522,
#  ('autoset', 'declin'): 6.90875477931522,
#  ('im', 'nifedipin'): 6.90875477931522,
#  ('dnr', 'hctz'): 6.90875477931522,
#  ('ffp', 'platelet'): -6.90875477931522,
#  ('dopamin', 'scar'): 6.90875477931522,
#  ('azotemia', 'motor'): 6.90875477931522,
#  ('hive', 'mood'): 6.90875477931522,
#  ('hypotherm', 'rusti'): -6.90875477931522,
#  ('seroquel', 'ultram'): 6.90875477931522,
#  ('thrive', 'vagu'): 6.90875477931522,
#  ('captopril', 'predict'): 6.90875477931522,
#  ('hospic', 'underneath'): -6.90875477931522,
#  ('anur', 'rpr'): 6.90875477931522,
#  ('hung', 'vasopressin'): -6.90875477931522,
#  ('rhinorrhea', 'wish'): 6.90875477931522,
#  ('neo', 'recalibr'): 6.90875477931522,
#  ('acc', 'ba'): 6.90875477931522,
#  ('gastriti', 'hive'): 6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('carvedilol', 'pleasant'): 6.90875477931522,
#  ('bair', 'vasopressor'): -6.90875477931522,
#  ('cocain', 'crack'): 6.90875477931522,
#  ('ferritin', 'nifedipin'): 6.90875477931522,
#  ('bottl', 'hygein'): 6.90875477931522,
#  ('calculi', 'suprapub'): 6.90875477931522,
#  ('acc', 'scar'): 6.90875477931522,
#  ('colonoscopi', 'dnr'): 6.90875477931522,
#  ('burn', 'epigastr'): 6.90875477931522,
#  ('hunger', 'scar'): -6.90875477931522,
#  ('ctx', 'dopamin'): 6.90875477931522,
#  ('familt', 'palli'): -6.90875477931522,
#  ('ctx', 'neo'): 6.90875477931522,
#  ('flight', 'stair'): 6.90875477931522,
#  ('anaphylaxi', 'levoph'): 6.90875477931522,
#  ('calvarium', 'occipit'): 6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('occipit', 'subdur'): 6.90875477931522,
#  ('breakfast', 'mellitu'): 6.90875477931522,
#  ('epigastr', 'nicotin'): 6.90875477931522,
#  ('bromid', 'omeprazol'): 6.90875477931522,
#  ('anur', 'gentamycin'): -6.90875477931522,
#  ('dead', 'synthet'): -6.90875477931522,
#  ('massag', 'oncologist'): 6.90875477931522,
#  ('fibrinogen', 'norepinephrin'): -2.4258395487508584,
#  ('arrest', 'dic'): -6.90875477931522,
#  ('ctx', 'gabapentin'): 6.90875477931522,
#  ('ciwa', 'oob'): 6.90875477931522,
#  ('fdp', 'fibrinogen'): -6.90875477931522,
#  ('dz', 'pneumococc'): 6.90875477931522,
#  ('oob', 'readmit'): 6.90875477931522,
#  ('paralyt', 'phenylephrin'): -6.90875477931522,
#  ('seroquel', 'uri'): 6.90875477931522,
#  ('intiat', 'sensat'): 6.90875477931522,
#  ('ppd', 'prec'): 6.90875477931522,
#  ('adam', 'dnr'): -6.90875477931522,
#  ('azotemia', 'ciwa'): 6.90875477931522,
#  ('banana', 'ciwa'): 6.90875477931522,
#  ('nonrebreath', 'romi'): 6.90875477931522,
#  ('calvarium', 'effac'): 0.0,
#  ('bottl', 'currenlti'): 6.90875477931522,
#  ('dic', 'gadolinium'): 6.90875477931522,
#  ('book', 'fax'): 6.90875477931522,
#  ('klonopin', 'zyprexa'): 6.90875477931522,
#  ('oob', 'spiromet'): 6.90875477931522,
#  ('neosynephrin', 'phenylephrin'): -6.90875477931522,
#  ('ppd', 'soln'): 6.90875477931522,
#  ('redirect', 'wallet'): -6.90875477931522,
#  ('cs', 'zyprexa'): 6.90875477931522,
#  ('myeloma', 'rhinorrhea'): -6.90875477931522,
#  ('carvedilol', 'seroquel'): 6.90875477931522,
#  ('asthma', 'nectar'): 6.90875477931522,
#  ('angioplasti', 'dnr'): 6.90875477931522,
#  ('bottl', 'dnr'): 6.90875477931522,
#  ('hilum', 'slice'): 6.90875477931522,
#  ('anur', 'dnr'): -1.3825560390092835,
#  ('acc', 'dietari'): 6.90875477931522,
#  ('chair', 'zyprexa'): 6.90875477931522,
#  ('osa', 'seat'): 6.90875477931522,
#  ('hilum', 'nephrogram'): 6.90875477931522,
#  ('dnr', 'xl'): 6.90875477931522,
#  ('ferritin', 'ration'): 6.90875477931522,
#  ('moan', 'rabbi'): -6.90875477931522,
#  ('hsq', 'phlegm'): 6.90875477931522,
#  ('nicotin', 'xopenex'): 6.90875477931522,
#  ('aaox', 'subdur'): 6.90875477931522,
#  ('crack', 'hygein'): 6.90875477931522,
#  ('exophyt', 'peribronchovascular'): 6.90875477931522,
#  ('hive', 'iddm'): 6.90875477931522,
#  ('intent', 'phlegm'): 6.90875477931522,
#  ('dopamin', 'neo'): 2.473073171472692,
#  ('barium', 'breakfast'): 6.90875477931522,
#  ('ba', 'opiat'): 6.90875477931522,
#  ('dni', 'hugger'): -6.90875477931522,
#  ('cefapim', 'kerlix'): 6.90875477931522,
#  ('pleasantli', 'subdur'): 6.90875477931522,
#  ('clonazepam', 'recruit'): 6.90875477931522,
#  ('dni', 'nectar'): 6.90875477931522,
#  ('aaox', 'syst'): 6.90875477931522,
#  ('puff', 'sibl'): 6.90875477931522,
#  ('lymphangit', 'soln'): 6.90875477931522,
#  ('acc', 'angri'): 6.90875477931522,
#  ('db', 'para'): 6.90875477931522,
#  ('dnr', 'oligur'): -1.604655121332035,
#  ('incent', 'nonrebreath'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('bipolar', 'opiat'): 6.90875477931522,
#  ('morbid', 'romi'): 6.90875477931522,
#  ('aaox', 'pleasant'): 6.90875477931522,
#  ('dni', 'pca'): 6.90875477931522,
#  ('bair', 'pinpoint'): -6.90875477931522,
#  ('harm', 'oob'): 6.90875477931522,
#  ('ambien', 'ciwa'): 6.90875477931522,
#  ('permiss', 'pose'): 6.90875477931522,
#  ('dni', 'hilum'): -6.90875477931522,
#  ('mtg', 'rhinorrhea'): 6.90875477931522,
#  ('ambul', 'palli'): -6.90875477931522,
#  ('hctz', 'sensat'): 6.90875477931522,
#  ('bank', 'itchi'): 6.90875477931522,
#  ('cs', 'tran'): 6.90875477931522,
#  ('acidot', 'dic'): -6.90875477931522,
#  ('qam', 'sibl'): 6.90875477931522,
#  ('cagluc', 'neo'): -6.90875477931522,
#  ('laminectomi', 'unstabl'): 6.90875477931522,
#  ('ciwa', 'sweat'): 6.90875477931522,
#  ('eg', 'foci'): 6.90875477931522,
#  ('articul', 'lat'): 6.90875477931522,
#  ('morbid', 'uri'): 6.90875477931522,
#  ('commod', 'option'): 6.90875477931522,
#  ('lat', 'qtc'): 6.90875477931522,
#  ('dyslipidemia', 'thiamin'): 6.90875477931522,
#  ('freeli', 'protrud'): -6.90875477931522,
#  ('mellitu', 'rigor'): 6.90875477931522,
#  ('grim', 'sluggish'): -6.90875477931522,
#  ('bicarbon', 'sluggishli'): -6.90875477931522,
#  ('appi', 'arrest'): 6.90875477931522,
#  ('gadolinium', 'uri'): 6.90875477931522,
#  ('gabapentin', 'profound'): 6.90875477931522,
#  ('deterior', 'lift'): 6.90875477931522,
#  ('anaphylaxi', 'subq'): 6.90875477931522,
#  ('diaphoresi', 'strictur'): 6.90875477931522,
#  ('dnr', 'scopalamin'): 0.2226944607151099,
#  ('dnr', 'heroic'): -6.90875477931522,
#  ('dnr', 'pinpoint'): -6.90875477931522,
#  ('sweat', 'thiamin'): 6.90875477931522,
#  ('death', 'omeprazol'): 6.90875477931522,
#  ('declin', 'nicotin'): 6.90875477931522,
#  ...}

# %%
# Data normalization
import numpy
def data_norm(cooc_odd_scores):

    def norm_arr(array):
        arr = numpy.array(list(array))
        start = 0
        end = 1
        width = end - start
        res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
        return res.tolist()

    cooc_keys, cooc_values = zip(*cooc_odd_scores.items())
    new_cooc_odd_scores = dict(zip(cooc_keys, norm_arr(cooc_values)))

    return new_cooc_odd_scores

new_patient_cooc_odd_scores = data_norm(patient_cooc_odd_scores)

# %%
new_patient_cooc_odd_scores
# Out:
# {('aricept', 'gentamycin'): 0.0,
#  ('dnr', 'refractori'): 1.0,
#  ('aricept', 'romi'): 1.0,
#  ('oncologist', 'pleasant'): 1.0,
#  ('fu', 'ntnd'): 1.0,
#  ('autopsi', 'dead'): 0.0,
#  ('appi', 'dnr'): 1.0,
#  ('gait', 'sarna'): 1.0,
#  ('ligament', 'treitz'): 0.5500560933045909,
#  ('director', 'zero'): 1.0,
#  ('dd', 'dnr'): 1.0,
#  ('romi', 'scar'): 1.0,
#  ('death', 'intiat'): 0.0,
#  ('adenocarcinoma', 'natg'): 1.0,
#  ('hypothermia', 'wma'): 1.0,
#  ('herp', 'nephrolog'): 1.0,
#  ('agon', 'pea'): 0.0,
#  ('adam', 'captopril'): 0.0,
#  ('dermat', 'pharmacolog'): 1.0,
#  ('cmo', 'lpm'): 0.0,
#  ('dni', 'surviv'): 1.0,
#  ('asthma', 'coach'): 1.0,
#  ('breakfast', 'video'): 1.0,
#  ('levoph', 'trazodon'): 1.0,
#  ('agon', 'readmit'): 1.0,
#  ('cocain', 'lac'): 1.0,
#  ('calculi', 'rehabilit'): 1.0,
#  ('barium', 'cooki'): 1.0,
#  ('incis', 'occipit'): 1.0,
#  ('laminectomi', 'stitch'): 1.0,
#  ('lpm', 'moan'): 1.0,
#  ('cash', 'hospic'): 1.0,
#  ('aliv', 'jewelri'): 1.0,
#  ('anaphylaxi', 'uri'): 1.0,
#  ('bank', 'gabapentin'): 1.0,
#  ('freeli', 'refractori'): 1.0,
#  ('fatti', 'pca'): 1.0,
#  ('azotemia', 'wish'): 1.0,
#  ('flight', 'magnevist'): 1.0,
#  ('cocain', 'rm'): 1.0,
#  ('hypothermia', 'prilosec'): 1.0,
#  ('burn', 'historian'): 1.0,
#  ('burn', 'dnr'): 1.0,
#  ('foci', 'gastrojejunostomi'): 1.0,
#  ('epidur', 'norepinephrin'): 1.0,
#  ('dni', 'unasyn'): 1.0,
#  ('cocain', 'nifedipin'): 1.0,
#  ('gvhd', 'xii'): 1.0,
#  ('oligur', 'wish'): 0.0,
#  ('adenosin', 'vasopressin'): 1.0,
#  ('oncologist', 'paperwork'): 1.0,
#  ('dyslipidemia', 'gait'): 1.0,
#  ('historian', 'young'): 1.0,
#  ('dizzi', 'levoph'): 1.0,
#  ('pea', 'wish'): 0.0,
#  ('cocain', 'sweat'): 1.0,
#  ('plate', 'splint'): 1.0,
#  ('dnr', 'lift'): 1.0,
#  ('vasopressor', 'vtach'): 0.0,
#  ('aliv', 'mind'): 1.0,
#  ('expir', 'forc'): 1.0,
#  ('cmo', 'hypotherm'): 0.0,
#  ('prilosec', 'robitussin'): 1.0,
#  ('anuria', 'arrest'): 1.0,
#  ('breakfast', 'esld'): 1.0,
#  ('xii', 'young'): 1.0,
#  ('platelet', 'rhinorrhea'): 0.5793162261246866,
#  ('breakfast', 'fibrinogen'): 1.0,
#  ('asthma', 'habitu'): 1.0,
#  ('gasp', 'mso'): 0.0,
#  ('jewelri', 'probe'): 1.0,
#  ('intiat', 'pronounc'): 0.0,
#  ('fax', 'pleasant'): 1.0,
#  ('hospic', 'hunger'): 0.0,
#  ('colonoscopi', 'motor'): 1.0,
#  ('levoph', 'sweat'): 1.0,
#  ('angioplasti', 'cyanot'): 1.0,
#  ('anur', 'gabapentin'): 1.0,
#  ('dni', 'profound'): 0.5500560933045909,
#  ('anur', 'ggt'): 0.0,
#  ('ambien', 'commod'): 1.0,
#  ('barium', 'lusb'): 1.0,
#  ('dobutamin', 'intiat'): 1.0,
#  ('db', 'rm'): 1.0,
#  ('cocain', 'herp'): 1.0,
#  ('expir', 'wish'): 0.0,
#  ('db', 'dyslipidemia'): 1.0,
#  ('iddm', 'tubular'): 1.0,
#  ('escal', 'neo'): 0.0,
#  ('profound', 'romi'): 1.0,
#  ('pastor', 'pea'): 0.0,
#  ('dopamin', 'lat'): 1.0,
#  ('captopril', 'core'): 0.0,
#  ('foci', 'postop'): 1.0,
#  ('aaox', 'dz'): 1.0,
#  ('mellitu', 'palli'): 1.0,
#  ('predict', 'rabbi'): 0.0,
#  ('hive', 'platelet'): 0.0,
#  ('levoph', 'vasoconstrict'): 0.0,
#  ('aricept', 'cash'): 0.0,
#  ('omeprazol', 'solut'): 1.0,
#  ('dizzi', 'dni'): 1.0,
#  ('fibrinogen', 'pod'): 1.0,
#  ('autopsi', 'pea'): 0.0,
#  ('motor', 'unavail'): 1.0,
#  ('fungemia', 'lw'): 0.0,
#  ('hypothermia', 'ppd'): 1.0,
#  ('prec', 'rm'): 1.0,
#  ('oob', 'palli'): 1.0,
#  ('dnr', 'unrel'): 0.0,
#  ('fibrinogen', 'prilosec'): 0.0,
#  ('dnr', 'zyprexa'): 0.6361062373955713,
#  ('ctx', 'hsq'): 1.0,
#  ('rehabilit', 'thrive'): 1.0,
#  ('metoclopramid', 'silent'): 1.0,
#  ('bicarbon', 'levoph'): 0.0,
#  ('cloth', 'diflucan'): 1.0,
#  ('aaox', 'gurgl'): 0.0,
#  ('epidur', 'oob'): 1.0,
#  ('cmo', 'dnr'): 0.3898724426693005,
#  ('eg', 'mandibl'): 1.0,
#  ('hypothermia', 'pcv'): 0.0,
#  ('dermat', 'xii'): 0.0,
#  ('amb', 'nahco'): 1.0,
#  ('dyslipidemia', 'romi'): 1.0,
#  ('cpr', 'paralyt'): 0.0,
#  ('death', 'puff'): 1.0,
#  ('dnr', 'rusti'): 0.0,
#  ('asthma', 'readdress'): 1.0,
#  ('im', 'occipit'): 1.0,
#  ('palli', 'struggl'): 0.0,
#  ('sweat', 'xl'): 1.0,
#  ('paperwork', 'rhinorrhea'): 1.0,
#  ('strictur', 'zyprexa'): 1.0,
#  ('dni', 'unobtain'): 0.5500560933045909,
#  ('nonlabor', 'subq'): 1.0,
#  ('gasp', 'sensat'): 0.0,
#  ('homogen', 'mjmgb'): 1.0,
#  ('dopamin', 'mso'): 0.5500560933045909,
#  ('gabapentin', 'mood'): 1.0,
#  ('levoph', 'rigor'): 1.0,
#  ('aricept', 'lusb'): 1.0,
#  ('fatti', 'nephrogram'): 1.0,
#  ('norepinephrin', 'permiss'): 0.0,
#  ('aox', 'coach'): 1.0,
#  ('crowd', 'xl'): 1.0,
#  ('chemic', 'unasyn'): 1.0,
#  ('arrest', 'pcv'): 0.0,
#  ('flight', 'gvhd'): 1.0,
#  ('oob', 'uri'): 1.0,
#  ('fatti', 'intiat'): 1.0,
#  ('prognosi', 'scopalamin'): 0.0,
#  ('hilum', 'vertebra'): 0.0,
#  ('peac', 'scopalamin'): 0.0,
#  ('diaphoresi', 'iddm'): 1.0,
#  ('gait', 'vasopressin'): 0.0,
#  ('ffp', 'opinion'): 1.0,
#  ('asthma', 'dnr'): 0.7221346662944875,
#  ('hunger', 'zoloft'): 0.0,
#  ('bipolar', 'dnr'): 0.35312965492991083,
#  ('occupi', 'rehabilit'): 1.0,
#  ('dnr', 'pleuravac'): 0.0,
#  ('autopeep', 'hypothermia'): 0.0,
#  ('hive', 'im'): 1.0,
#  ('phenylephrin', 'requr'): 0.0,
#  ('silent', 'young'): 1.0,
#  ('ctx', 'lat'): 1.0,
#  ('recalibr', 'stitch'): 1.0,
#  ('emper', 'lac'): 1.0,
#  ('sluggishli', 'wma'): 0.0,
#  ('historian', 'opiat'): 1.0,
#  ('heroic', 'option'): 0.0,
#  ('declin', 'sweat'): 1.0,
#  ('venti', 'young'): 1.0,
#  ('gastrojejunostomi', 'metoclopramid'): 1.0,
#  ('nicotin', 'uri'): 1.0,
#  ('barium', 'foci'): 0.5,
#  ('commod', 'platelet'): 1.0,
#  ('asthma', 'ruptur'): 1.0,
#  ('azotemia', 'fdp'): 0.0,
#  ('barium', 'laryng'): 1.0,
#  ('sensat', 'thirst'): 1.0,
#  ('palli', 'xii'): 0.0,
#  ('commod', 'tracheomalacia'): 1.0,
#  ('ba', 'precordium'): 1.0,
#  ('deterior', 'echocardiogram'): 1.0,
#  ('chemic', 'cocain'): 1.0,
#  ('cocain', 'xii'): 1.0,
#  ('echocardiogram', 'jejunum'): 1.0,
#  ('cmo', 'levoph'): 0.39994173456925625,
#  ('piriform', 'silent'): 1.0,
#  ('autopeep', 'norepinephrin'): 0.0,
#  ('hypothermia', 'vasopressor'): 0.0,
#  ('declin', 'xii'): 1.0,
#  ('oob', 'ultram'): 1.0,
#  ('epigastr', 'qam'): 1.0,
#  ('cmo', 'suffer'): 0.0,
#  ('dnr', 'vtach'): 0.0,
#  ('asthma', 'mucinex'): 1.0,
#  ('esld', 'phenylephrin'): 0.495183056737107,
#  ('ctx', 'wma'): 1.0,
#  ('arrest', 'incis'): 1.0,
#  ('arrest', 'profound'): 0.0,
#  ('commod', 'spirit'): 1.0,
#  ('deterior', 'palli'): 0.0,
#  ('dopamin', 'vasopressor'): 0.0,
#  ('agreement', 'heroic'): 0.0,
#  ('iddm', 'sluggish'): 1.0,
#  ('anaphylaxi', 'ferritin'): 1.0,
#  ('ctx', 'retic'): 1.0,
#  ('dni', 'stair'): 1.0,
#  ('gastriti', 'seriou'): 1.0,
#  ('hctz', 'predict'): 1.0,
#  ('freeli', 'scar'): 1.0,
#  ('cracker', 'venti'): 1.0,
#  ('pyuria', 'silent'): 0.0,
#  ('commod', 'diaper'): 1.0,
#  ('im', 'platelet'): 1.0,
#  ('captopril', 'hypotherm'): 0.0,
#  ('life', 'wish'): 0.5292841127058171,
#  ('pod', 'soln'): 1.0,
#  ('dnr', 'underneath'): 0.0,
#  ('mso', 'syst'): 1.0,
#  ('exophyt', 'unenhanc'): 1.0,
#  ('asthma', 'romi'): 1.0,
#  ('hive', 'sweat'): 1.0,
#  ('flight', 'pleasant'): 1.0,
#  ('anur', 'trazodon'): 1.0,
#  ('incent', 'oob'): 1.0,
#  ('bipolar', 'mood'): 1.0,
#  ('db', 'jewelri'): 1.0,
#  ('uncoop', 'video'): 1.0,
#  ('seat', 'tdi'): 1.0,
#  ('dnr', 'friction'): 1.0,
#  ('bill', 'metoclopramid'): 1.0,
#  ('norepinephrin', 'ultram'): 1.0,
#  ('lighthead', 'pleasant'): 1.0,
#  ('incent', 'phlegm'): 1.0,
#  ('pronounc', 'sacrament'): 0.0,
#  ('jejunum', 'tie'): 1.0,
#  ('dni', 'lat'): 1.0,
#  ('hive', 'money'): 1.0,
#  ('bottl', 'crack'): 1.0,
#  ('chair', 'dni'): 0.5326435107553643,
#  ('life', 'pastor'): 0.0,
#  ('ambien', 'unasyn'): 1.0,
#  ('sibl', 'vasoconstrict'): 0.0,
#  ('scopalamin', 'seroquel'): 1.0,
#  ('aaox', 'pod'): 1.0,
#  ('acc', 'romi'): 1.0,
#  ('breakfast', 'nahco'): 1.0,
#  ('bank', 'dnr'): 1.0,
#  ('hospic', 'oder'): 0.0,
#  ('oob', 'syst'): 1.0,
#  ('anur', 'pleasant'): 1.0,
#  ('aricept', 'wallet'): 0.0,
#  ('gasp', 'hilum'): 0.0,
#  ('escal', 'wish'): 0.0,
#  ('expir', 'nahco'): 0.0,
#  ('criticar', 'oligur'): 1.0,
#  ('neutral', 'scar'): 1.0,
#  ('thrive', 'young'): 1.0,
#  ('ppd', 'thrive'): 1.0,
#  ('norepinephrin', 'oligur'): 0.0,
#  ('romi', 'thiamin'): 1.0,
#  ('deterior', 'mellitu'): 1.0,
#  ('icter', 'mellitu'): 1.0,
#  ('declin', 'oob'): 1.0,
#  ('natg', 'occipit'): 1.0,
#  ('dnr', 'fibrinogen'): 0.6194674738764308,
#  ('mucinex', 'option'): 1.0,
#  ('hive', 'metoclopramid'): 1.0,
#  ('hive', 'refractori'): 1.0,
#  ('requr', 'rm'): 1.0,
#  ('gabapentin', 'morbid'): 1.0,
#  ('epidur', 'gabapentin'): 1.0,
#  ('currenlti', 'qam'): 1.0,
#  ('epidur', 'zoloft'): 1.0,
#  ('aliv', 'dead'): 1.0,
#  ('acc', 'hsq'): 1.0,
#  ('aaox', 'dnr'): 0.6161320073290462,
#  ('gabapentin', 'ppd'): 1.0,
#  ('diaphoresi', 'xl'): 1.0,
#  ('dyslipidemia', 'scar'): 1.0,
#  ('rigor', 'strictur'): 1.0,
#  ('scar', 'smooth'): 1.0,
#  ('liw', 'vasopressin'): 0.0,
#  ('arthrit', 'dnr'): 1.0,
#  ('duski', 'palli'): 0.0,
#  ('norepinephrin', 'recalibr'): 1.0,
#  ('plate', 'requr'): 1.0,
#  ('predict', 'ultram'): 1.0,
#  ('aox', 'predict'): 1.0,
#  ('clonazepam', 'schizophrenia'): 1.0,
#  ('dni', 'simpli'): 1.0,
#  ('dobutamin', 'levoph'): 0.25368062901375377,
#  ('dni', 'fibrinogen'): 0.5793162261246866,
#  ('calculi', 'oncologist'): 1.0,
#  ('clonidin', 'qam'): 1.0,
#  ('money', 'probe'): 1.0,
#  ('dni', 'unrel'): 0.0,
#  ('asystol', 'bank'): 0.0,
#  ('aricept', 'qam'): 0.0,
#  ('deliv', 'dni'): 1.0,
#  ('fc', 'pyuria'): 0.0,
#  ('commod', 'sarna'): 1.0,
#  ('eg', 'pharyng'): 1.0,
#  ('cloth', 'fatti'): 1.0,
#  ('ligament', 'smooth'): 1.0,
#  ('life', 'palli'): 0.0,
#  ('crowd', 'rhinorrhea'): 1.0,
#  ('fdp', 'ggt'): 0.0,
#  ('asthma', 'respon'): 1.0,
#  ('hemangioma', 'slice'): 1.0,
#  ('subcost', 'unavail'): 1.0,
#  ('dizzi', 'tcdb'): 1.0,
#  ('^th', 'commod'): 1.0,
#  ('opiat', 'thiamin'): 1.0,
#  ('ciwa', 'ran'): 1.0,
#  ('laryng', 'lat'): 1.0,
#  ('dopamin', 'unequ'): 0.0,
#  ('asthma', 'bottl'): 1.0,
#  ('hunger', 'prognosi'): 0.0,
#  ('hsq', 'xii'): 1.0,
#  ('chair', 'unasyn'): 0.4595846302788977,
#  ('deploy', 'epigastr'): 1.0,
#  ('acv', 'levoph'): 1.0,
#  ('commod', 'incent'): 1.0,
#  ('lat', 'pneumothorac'): 0.5500560933045909,
#  ('ntnd', 'zoloft'): 1.0,
#  ('articul', 'rhinorrhea'): 1.0,
#  ('bromid', 'fibrinogen'): 1.0,
#  ('db', 'pleasant'): 1.0,
#  ('agon', 'arrest'): 0.5,
#  ('ciwa', 'itchi'): 1.0,
#  ('dni', 'lotion'): 0.0,
#  ('epigastr', 'hsq'): 1.0,
#  ('dni', 'video'): 0.5144937456927721,
#  ('rigor', 'sensat'): 1.0,
#  ('asthma', 'crack'): 1.0,
#  ('ba', 'sensat'): 1.0,
#  ('bair', 'paralyt'): 1.0,
#  ('pleasant', 'venti'): 1.0,
#  ('rigor', 'sweat'): 1.0,
#  ('ciwa', 'fatti'): 1.0,
#  ('db', 'scar'): 1.0,
#  ('option', 'pleasant'): 1.0,
#  ('dxae', 'pneumonectomi'): 0.0,
#  ('goc', 'nifedipin'): 1.0,
#  ('imbal', 'shorter'): 1.0,
#  ('ffp', 'mean'): 0.0,
#  ('ligament', 'para'): 1.0,
#  ('ofm', 'oob'): 1.0,
#  ('dni', 'hook'): 1.0,
#  ('calculi', 'trazodon'): 1.0,
#  ('anuria', 'bill'): 1.0,
#  ('dni', 'stg'): 0.0,
#  ('hemangioma', 'mjmgb'): 1.0,
#  ('captopril', 'ciwa'): 1.0,
#  ('pneumonectomi', 'tubular'): 0.0,
#  ('coarctat', 'habitu'): 1.0,
#  ('clonidin', 'unobtain'): 1.0,
#  ('dnr', 'unasyn'): 1.0,
#  ('fibrinogen', 'rigor'): 1.0,
#  ('calculi', 'homogen'): 1.0,
#  ('bronchovascular', 'mail'): 1.0,
#  ('barium', 'motor'): 1.0,
#  ('dyslipidemia', 'mellitu'): 1.0,
#  ('echocardiogram', 'rigor'): 1.0,
#  ('autopeep', 'hypercapnia'): 0.0,
#  ('palli', 'pleasant'): 0.0,
#  ('arrest', 'expir'): 0.0,
#  ('cdb', 'levoph'): 1.0,
#  ('paperwork', 'rehabilit'): 1.0,
#  ('chair', 'simpli'): 1.0,
#  ('diuril', 'dopamin'): 1.0,
#  ('gurgl', 'pleasant'): 1.0,
#  ('morgu', 'mortem'): 0.0,
#  ('deterior', 'readdress'): 0.0,
#  ('metoclopramid', 'soln'): 1.0,
#  ('hypothermia', 'robitussin'): 1.0,
#  ('clonidin', 'laminectomi'): 1.0,
#  ('asthma', 'escal'): 1.0,
#  ('dnr', 'synthet'): 0.0,
#  ('tcdb', 'uri'): 1.0,
#  ('autopsi', 'dnr'): 0.0,
#  ('aox', 'laminectomi'): 1.0,
#  ('opiat', 'ultram'): 1.0,
#  ('ctx', 'ultram'): 1.0,
#  ('arrest', 'dnr'): 0.0,
#  ('bank', 'colonoscopi'): 1.0,
#  ('pplat', 'thk'): 1.0,
#  ('readmit', 'scar'): 1.0,
#  ('escal', 'pea'): 0.0,
#  ('jewelri', 'signatur'): 0.6727559518802089,
#  ('cs', 'oob'): 1.0,
#  ('dnr', 'nicotin'): 1.0,
#  ('palli', 'postop'): 1.0,
#  ('aricept', 'distanc'): 1.0,
#  ('ccn', 'levoph'): 0.0,
#  ('arrest', 'gait'): 0.0,
#  ('phenylephrin', 'synthet'): 0.0,
#  ('echocardiogram', 'palli'): 0.0,
#  ('among', 'foci'): 0.0,
#  ('dopamin', 'pitressin'): 0.0,
#  ('asthma', 'chair'): 0.6516986494486501,
#  ('levoph', 'unstabl'): 0.5,
#  ('compani', 'omeprazol'): 1.0,
#  ('ipf', 'robitussin'): 0.0,
#  ('bottl', 'gum'): 1.0,
#  ('angioplasti', 'diaphoresi'): 1.0,
#  ('dnr', 'lotion'): 0.27949367230854666,
#  ('rememb', 'ruptur'): 1.0,
#  ('judgement', 'mso'): 0.0,
#  ('aricept', 'commod'): 0.0,
#  ('breakfast', 'readdress'): 1.0,
#  ('dnr', 'west'): 1.0,
#  ('adam', 'deterior'): 0.0,
#  ('^th', 'oob'): 1.0,
#  ('dnr', 'dobutamin'): 0.5904329355723089,
#  ('ambul', 'dni'): 0.6000582654307438,
#  ('dni', 'heroic'): 0.0,
#  ('hctz', 'pneumococc'): 1.0,
#  ('gabapentin', 'xanax'): 1.0,
#  ('dnr', 'epigastr'): 1.0,
#  ('banana', 'rememb'): 1.0,
#  ('declin', 'zyprexa'): 0.0,
#  ('asthma', 'cellcept'): 1.0,
#  ('dni', 'mood'): 1.0,
#  ('endur', 'incis'): 1.0,
#  ('gvhd', 'levoph'): 0.0,
#  ('barium', 'spill'): 1.0,
#  ('contractur', 'scar'): 1.0,
#  ('aricept', 'gabapentin'): 1.0,
#  ('argatroban', 'norepinephrin'): 0.0,
#  ('im', 'prec'): 1.0,
#  ('cisatracurium', 'paralyt'): 0.0,
#  ('dnr', 'sluggish'): 0.4575506047567018,
#  ('asthma', 'clonidin'): 1.0,
#  ('hugger', 'vasopressor'): 0.0,
#  ('dnr', 'nitroglycerin'): 1.0,
#  ('dni', 'qam'): 0.6000582654307438,
#  ('bottl', 'opiat'): 1.0,
#  ('spill', 'videofluoroscopi'): 1.0,
#  ('commod', 'levoph'): 0.4818485725952736,
#  ('oob', 'tcdb'): 1.0,
#  ('hsq', 'platelet'): 0.0,
#  ('dni', 'oligur'): 0.3838679926709539,
#  ('smooth', 'vertebra'): 0.5,
#  ('seroquel', 'unasyn'): 1.0,
#  ('flight', 'vp'): 1.0,
#  ('db', 'oob'): 1.0,
#  ('dni', 'jerk'): 0.0,
#  ('arrest', 'chb'): 0.0,
#  ('readmit', 'sweat'): 1.0,
#  ('im', 'mva'): 1.0,
#  ('schizophrenia', 'ultram'): 1.0,
#  ('ambul', 'furhter'): 0.0,
#  ('nocturn', 'profound'): 1.0,
#  ('anur', 'tcdb'): 1.0,
#  ('signatur', 'thiamin'): 1.0,
#  ('reguard', 'uncoop'): 1.0,
#  ('dni', 'meropenam'): 0.0,
#  ('aaox', 'nimv'): 1.0,
#  ('pneumococc', 'pod'): 1.0,
#  ('agon', 'neosynephrin'): 0.0,
#  ('cracker', 'spiromet'): 0.0,
#  ('chair', 'compani'): 1.0,
#  ('declin', 'dietari'): 1.0,
#  ('hugger', 'levoph'): 0.6207779057371651,
#  ('ambien', 'ferrou'): 1.0,
#  ('dead', 'sundown'): 0.0,
#  ('purpl', 'seroquel'): 1.0,
#  ('azotemia', 'habitu'): 1.0,
#  ('para', 'pneumococc'): 1.0,
#  ('clonidin', 'refractori'): 1.0,
#  ('incis', 'wish'): 0.0,
#  ('clonazepam', 'osa'): 1.0,
#  ('anaphylaxi', 'opiat'): 1.0,
#  ('absorb', 'paralyt'): 1.0,
#  ('pronounc', 'wish'): 0.0,
#  ('crack', 'ultram'): 1.0,
#  ('lat', 'mva'): 1.0,
#  ('chol', 'stg'): 0.0,
#  ('hospic', 'requr'): 1.0,
#  ('anur', 'flake'): 1.0,
#  ('gasp', 'qam'): 0.0,
#  ('deflat', 'lpm'): 1.0,
#  ('autopeep', 'dic'): 0.0,
#  ('autoset', 'ciwa'): 1.0,
#  ('soln', 'subdur'): 1.0,
#  ('hunger', 'xopenex'): 0.0,
#  ('asthma', 'uri'): 1.0,
#  ('phlegm', 'silent'): 1.0,
#  ('fatti', 'thiamin'): 1.0,
#  ('articul', 'dead'): 1.0,
#  ('ipf', 'norepinephrin'): 0.0,
#  ('mellitu', 'oob'): 1.0,
#  ('chair', 'prec'): 1.0,
#  ('cardiovert', 'neo'): 0.0,
#  ('oob', 'romi'): 1.0,
#  ('perisplen', 'scar'): 1.0,
#  ('mellitu', 'subdur'): 1.0,
#  ('dic', 'hive'): 0.0,
#  ('chair', 'lotion'): 0.28116114168121026,
#  ('exophyt', 'fc'): 0.0,
#  ('adam', 'futil'): 0.0,
#  ('agreement', 'moan'): 0.0,
#  ('homogen', 'scar'): 1.0,
#  ('liw', 'vasoconstrict'): 0.0,
#  ('bill', 'fibrinogen'): 1.0,
#  ('autopeep', 'pcv'): 0.0,
#  ('calculi', 'fatti'): 1.0,
#  ('bicarbon', 'dic'): 0.0,
#  ('dic', 'sluggish'): 0.0,
#  ('expir', 'pea'): 0.0,
#  ('dni', 'gastriti'): 1.0,
#  ('cramp', 'fibrinogen'): 1.0,
#  ('levof', 'paralyt'): 0.0,
#  ('anur', 'rhinorrhea'): 0.0,
#  ('gown', 'gurgl'): 0.0,
#  ('lusb', 'retic'): 1.0,
#  ('diaphoresi', 'pleasant'): 1.0,
#  ('oncologist', 'ppn'): 1.0,
#  ('hung', 'religi'): 0.0,
#  ('asthma', 'ultram'): 1.0,
#  ('dni', 'hypotherm'): 0.3838679926709539,
#  ('subq', 'zoloft'): 1.0,
#  ('dnr', 'sarna'): 1.0,
#  ('epigastr', 'incis'): 1.0,
#  ('hctz', 'prilosec'): 1.0,
#  ('asystol', 'mortem'): 0.0,
#  ('bromid', 'currenlti'): 1.0,
#  ('puff', 'refractori'): 1.0,
#  ('lw', 'twitch'): 0.0,
#  ('eg', 'mellitu'): 1.0,
#  ('ciwa', 'epigastr'): 1.0,
#  ('osteoblast', 'scar'): 0.0,
#  ('moan', 'oligur'): 0.0,
#  ('incis', 'lw'): 1.0,
#  ('bottl', 'gotten'): 1.0,
#  ('bipolar', 'zyprexa'): 1.0,
#  ('anaphylaxi', 'ctx'): 1.0,
#  ('oncologist', 'scar'): 1.0,
#  ('dni', 'quinolon'): 0.0,
#  ('acidot', 'phenylephrin'): 0.0,
#  ('life', 'scopalamin'): 0.0,
#  ('gait', 'hive'): 1.0,
#  ('binder', 'dni'): 1.0,
#  ('levoph', 'wma'): 0.0,
#  ('ctx', 'rhinorrhea'): 1.0,
#  ('cocain', 'ctx'): 1.0,
#  ('arrest', 'fibrinogen'): 0.0,
#  ('breakfast', 'nitroglycerin'): 1.0,
#  ('muir', 'passi'): 1.0,
#  ('breakfast', 'stitch'): 1.0,
#  ('suprapub', 'thrive'): 1.0,
#  ('cefapim', 'pleasant'): 1.0,
#  ('montitor', 'sluggish'): 0.0,
#  ('laminectomi', 'pleasant'): 1.0,
#  ('ciwa', 'wish'): 1.0,
#  ('dni', 'refractori'): 1.0,
#  ('dni', 'knowledg'): 1.0,
#  ('barium', 'nocturn'): 1.0,
#  ('chair', 'oob'): 0.6220721334939259,
#  ('core', 'scar'): 1.0,
#  ('cg', 'montitor'): 0.0,
#  ('autopeep', 'paralyt'): 0.0,
#  ('cocain', 'mycolyt'): 1.0,
#  ('lpm', 'mottl'): 1.0,
#  ('declin', 'scar'): 1.0,
#  ('puff', 'thrive'): 1.0,
#  ('ardsnet', 'norepinephrin'): 0.0,
#  ('autopeep', 'azotemia'): 0.0,
#  ('dic', 'futil'): 0.0,
#  ('pvr', 'spiromet'): 1.0,
#  ('romi', 'young'): 1.0,
#  ('laryng', 'silent'): 1.0,
#  ('bill', 'subdur'): 1.0,
#  ('bicarbon', 'cpr'): 0.0,
#  ('dnr', 'laminectomi'): 1.0,
#  ('fibrinogen', 'levof'): 0.0,
#  ('dni', 'redirect'): 0.5,
#  ('homogen', 'nephrogram'): 0.5500560933045909,
#  ('gadolinium', 'levoph'): 1.0,
#  ('dic', 'impli'): 1.0,
#  ('ciwa', 'neoplast'): 1.0,
#  ('dnr', 'sibl'): 1.0,
#  ('lc', 'pinpoint'): 0.0,
#  ('money', 'oob'): 1.0,
#  ('schistocyt', 'syncop'): 1.0,
#  ('gait', 'pleasant'): 1.0,
#  ('cmo', 'peac'): 0.0,
#  ('ferrou', 'nocturn'): 1.0,
#  ('aaox', 'commod'): 1.0,
#  ('deliv', 'respitori'): 1.0,
#  ('ba', 'ciwa'): 1.0,
#  ('contd', 'refractori'): 1.0,
#  ('gotten', 'msicu'): 1.0,
#  ('nephrolog', 'omeprazol'): 1.0,
#  ('mva', 'spacer'): 1.0,
#  ('puff', 'sweat'): 1.0,
#  ('fibrinogen', 'readdress'): 1.0,
#  ('bicarbon', 'cvvh'): 0.0,
#  ('cash', 'redirect'): 0.0,
#  ('omeprazol', 'stitch'): 1.0,
#  ('ctx', 'lotion'): 1.0,
#  ('ethic', 'polici'): 0.0,
#  ('elimin', 'pathologist'): 1.0,
#  ('intent', 'ppd'): 1.0,
#  ('aox', 'declin'): 0.0,
#  ('lymphangit', 'pronounc'): 0.0,
#  ('sarna', 'soln'): 1.0,
#  ('aliv', 'robitussin'): 1.0,
#  ('chol', 'underneath'): 0.0,
#  ('commod', 'xopenex'): 1.0,
#  ('fibrinogen', 'rhinorrhea'): 0.5292841127058171,
#  ('barium', 'spur'): 1.0,
#  ('postop', 'retic'): 1.0,
#  ('bicarbon', 'hypercapnia'): 0.0,
#  ('ntnd', 'subq'): 1.0,
#  ('dnr', 'hemothorax'): 0.0,
#  ('barium', 'neo'): 1.0,
#  ('agon', 'death'): 0.0,
#  ('incent', 'mottl'): 1.0,
#  ('oob', 'zyprexa'): 1.0,
#  ('ruptur', 'sibl'): 1.0,
#  ('habitu', 'mean'): 1.0,
#  ('arrest', 'tracheomalacia'): 1.0,
#  ('crack', 'habitu'): 1.0,
#  ('bottl', 'msicu'): 1.0,
#  ('ciwa', 'omeprazol'): 1.0,
#  ('dietari', 'wma'): 1.0,
#  ('ba', 'banana'): 1.0,
#  ('hygein', 'thiamin'): 1.0,
#  ('cvvhd', 'paralyt'): 0.0,
#  ('dni', 'occurr'): 1.0,
#  ('fatti', 'homogen'): 1.0,
#  ('arrest', 'norepinephrin'): 0.0,
#  ('criticar', 'dni'): 1.0,
#  ('schistocyt', 'young'): 1.0,
#  ('fdp', 'prilosec'): 0.0,
#  ('anur', 'commod'): 0.0,
#  ('hctz', 'led'): 1.0,
#  ('anyway', 'weekli'): 1.0,
#  ('declin', 'lusb'): 1.0,
#  ('asthma', 'mva'): 1.0,
#  ('asthma', 'breakfast'): 1.0,
#  ('bair', 'sluggish'): 0.0,
#  ('agon', 'pinpoint'): 0.0,
#  ('esoph', 'hunger'): 0.0,
#  ('chair', 'intent'): 1.0,
#  ('nocturn', 'sweat'): 1.0,
#  ('historian', 'unstabl'): 1.0,
#  ('bottl', 'trabecul'): 1.0,
#  ('gabapentin', 'syncop'): 1.0,
#  ('arthrit', 'commod'): 1.0,
#  ('pleasant', 'sensat'): 1.0,
#  ('option', 'readdress'): 0.0,
#  ('lotion', 'pca'): 1.0,
#  ('phenylephrin', 'prognosi'): 0.0,
#  ('knowledg', 'life'): 1.0,
#  ('chair', 'maroon'): 1.0,
#  ('anuria', 'dead'): 0.0,
#  ('bair', 'hugger'): 0.5088552133562003,
#  ('gabapentin', 'postop'): 1.0,
#  ('contractur', 'dni'): 0.44994390669540907,
#  ('anyway', 'dni'): 1.0,
#  ('lighthead', 'nicotin'): 1.0,
#  ('agon', 'agreement'): 0.0,
#  ('ipf', 'occipit'): 0.5,
#  ('angioplasti', 'iddm'): 1.0,
#  ('deterior', 'gc'): 1.0,
#  ('dopamin', 'moan'): 0.0,
#  ('osa', 'romi'): 1.0,
#  ('chair', 'nectar'): 1.0,
#  ('fibrinogen', 'religi'): 0.0,
#  ('osa', 'trazodon'): 1.0,
#  ('declin', 'romi'): 1.0,
#  ('fibrinogen', 'ggt'): 0.0,
#  ('nonlabor', 'pleasant'): 1.0,
#  ('nonreact', 'palli'): 0.0,
#  ('lpm', 'polici'): 0.0,
#  ('aliv', 'sweat'): 1.0,
#  ('shorter', 'strictur'): 1.0,
#  ('anur', 'illeu'): 0.0,
#  ('cisatracurium', 'phenylephrin'): 0.0,
#  ('omeprazol', 'schizophrenia'): 1.0,
#  ('fibrinogen', 'pastor'): 0.0,
#  ('historian', 'jewelri'): 1.0,
#  ('fatti', 'intent'): 1.0,
#  ('chair', 'gurgl'): 0.0,
#  ('dnr', 'muddi'): 0.5743392170170073,
#  ('pneumococc', 'sibl'): 1.0,
#  ('dni', 'ffp'): 0.32101889193715044,
#  ('peribronchovascular', 'slice'): 1.0,
#  ('anuria', 'levoph'): 0.0,
#  ('burn', 'commod'): 1.0,
#  ('captopril', 'futil'): 0.0,
#  ('autoset', 'habitu'): 1.0,
#  ('cpr', 'mortem'): 0.0,
#  ('peribronchovascular', 'unstabl'): 1.0,
#  ('exophyt', 'pyuria'): 0.0,
#  ('grave', 'hook'): 1.0,
#  ('epigastr', 'hctz'): 1.0,
#  ('dni', 'gc'): 1.0,
#  ('cash', 'xl'): 1.0,
#  ('ambul', 'lac'): 1.0,
#  ('angiogram', 'deploy'): 1.0,
#  ('nectar', 'oob'): 1.0,
#  ('gvhd', 'wish'): 1.0,
#  ('ambul', 'asthma'): 1.0,
#  ('olanzapin', 'reguard'): 1.0,
#  ('oncologist', 'refractori'): 1.0,
#  ('crack', 'mycolyt'): 1.0,
#  ('echocardiogram', 'hive'): 1.0,
#  ('cdb', 'ctx'): 1.0,
#  ('cmo', 'oder'): 0.0,
#  ('mellitu', 'simpli'): 1.0,
#  ('gadolinium', 'vertebra'): 1.0,
#  ('ferrou', 'xl'): 1.0,
#  ('gait', 'lotion'): 1.0,
#  ('pronounc', 'vasopressin'): 0.0,
#  ('dni', 'respitori'): 1.0,
#  ('para', 'sweat'): 1.0,
#  ('laryng', 'vallecula'): 1.0,
#  ('peac', 'prognosi'): 0.0,
#  ('hilum', 'jejunum'): 1.0,
#  ('aricept', 'dnr'): 0.5103357439118639,
#  ('fibrinogen', 'pyuria'): 1.0,
#  ('dizzi', 'xl'): 1.0,
#  ('flight', 'gadolinium'): 1.0,
#  ('diaphoresi', 'sensat'): 1.0,
#  ('levoph', 'motil'): 0.0,
#  ('ctx', 'pleasant'): 1.0,
#  ('ppd', 'sensat'): 1.0,
#  ('ofm', 'svn'): 1.0,
#  ('dnr', 'sluggishli'): 0.0,
#  ('mind', 'paperwork'): 1.0,
#  ('absorb', 'asthma'): 1.0,
#  ('profound', 'slice'): 1.0,
#  ('barium', 'vallecula'): 1.0,
#  ('gabapentin', 'hive'): 1.0,
#  ('cyanot', 'oob'): 0.0,
#  ('death', 'hive'): 1.0,
#  ('qam', 'vagu'): 1.0,
#  ('ntnd', 'thiamin'): 1.0,
#  ('ambul', 'dz'): 1.0,
#  ('osa', 'young'): 1.0,
#  ('gait', 'oob'): 0.6583776534752032,
#  ('ctx', 'silent'): 1.0,
#  ('ctx', 'declin'): 1.0,
#  ('dz', 'slough'): 1.0,
#  ('oncologist', 'thrive'): 1.0,
#  ('neoplast', 'palli'): 1.0,
#  ('gabapentin', 'nocturn'): 1.0,
#  ('learn', 'moan'): 1.0,
#  ('gastriti', 'laminectomi'): 1.0,
#  ('arrang', 'cpr'): 0.0,
#  ('assymetr', 'xl'): 1.0,
#  ('platelet', 'suffer'): 0.0,
#  ('freeli', 'strictur'): 1.0,
#  ('hunger', 'suffer'): 0.0,
#  ('nocturn', 'rhinorrhea'): 1.0,
#  ('azotemia', 'hctz'): 1.0,
#  ('asystol', 'dnr'): 0.0,
#  ('anyway', 'dnr'): 1.0,
#  ('dic', 'goc'): 0.0,
#  ('ppd', 'suprapub'): 1.0,
#  ('opiat', 'unasyn'): 1.0,
#  ('pronounc', 'unenhanc'): 0.0,
#  ('ferritin', 'hive'): 1.0,
#  ('jewelri', 'wallet'): 0.6659303754175412,
#  ('gvhd', 'lw'): 0.0,
#  ('nahco', 'vasopressin'): 0.0,
#  ('crrt', 'platelet'): 0.0,
#  ('im', 'trazodon'): 1.0,
#  ('bipolar', 'forc'): 0.0,
#  ('dnr', 'pleasantli'): 1.0,
#  ('hctz', 'protrud'): 1.0,
#  ('calvarium', 'thrive'): 0.0,
#  ('anaphylaxi', 'escal'): 1.0,
#  ('bottl', 'osa'): 1.0,
#  ('pea', 'trazodon'): 0.0,
#  ('incis', 'seriou'): 1.0,
#  ('grave', 'prognosi'): 0.44994390669540907,
#  ('dni', 'moan'): 0.461073450252371,
#  ('aaox', 'sundown'): 0.5500560933045909,
#  ('flake', 'gabapentin'): 1.0,
#  ('db', 'habitu'): 1.0,
#  ('retic', 'tremul'): 1.0,
#  ('dnr', 'mellitu'): 1.0,
#  ('fatti', 'stair'): 1.0,
#  ('dni', 'hypercapn'): 1.0,
#  ('dni', 'hospic'): 0.4861056328226629,
#  ('herp', 'stair'): 1.0,
#  ('cloth', 'db'): 1.0,
#  ('motor', 'retic'): 1.0,
#  ('crack', 'echocardiogram'): 1.0,
#  ('fdp', 'ffp'): 0.0,
#  ('mtg', 'palli'): 0.0,
#  ('cvvh', 'norepinephrin'): 0.0,
#  ('deterior', 'hugger'): 1.0,
#  ('ambien', 'appi'): 1.0,
#  ('mind', 'rehabilit'): 1.0,
#  ('hypotherm', 'pinpoint'): 0.0,
#  ('lotion', 'metoclopramid'): 1.0,
#  ('hospic', 'option'): 1.0,
#  ('cvvh', 'levoph'): 0.0,
#  ('quinolon', 'trazodon'): 1.0,
#  ('pneumococc', 'young'): 1.0,
#  ('arrest', 'azotemia'): 0.0,
#  ('option', 'tran'): 1.0,
#  ('chair', 'cramp'): 1.0,
#  ('bronchovascular', 'ctx'): 1.0,
#  ('ppd', 'thiamin'): 1.0,
#  ('predict', 'unstabl'): 1.0,
#  ('fwb', 'tremul'): 1.0,
#  ('ctx', 'moan'): 1.0,
#  ('cyanot', 'furhter'): 0.0,
#  ('cdb', 'hive'): 1.0,
#  ('dni', 'escal'): 0.6609854824480033,
#  ('hilum', 'syncop'): 1.0,
#  ('absorb', 'omeprazol'): 1.0,
#  ('mtg', 'paralyt'): 0.0,
#  ('fdp', 'rhinorrhea'): 0.0,
#  ('bill', 'soln'): 1.0,
#  ('historian', 'venti'): 0.0,
#  ('bronchovascular', 'crowd'): 0.6058257216010178,
#  ('ambul', 'msicu'): 1.0,
#  ('dnr', 'opinion'): 0.0,
#  ('clonazepam', 'platelet'): 1.0,
#  ('oncologist', 'romi'): 1.0,
#  ('dome', 'foci'): 1.0,
#  ('mva', 'promod'): 1.0,
#  ('autopeep', 'phenylephrin'): 0.0,
#  ('chair', 'death'): 1.0,
#  ('levoph', 'scopalamin'): 0.0,
#  ('clinician', 'escal'): 0.0,
#  ('banana', 'flake'): 1.0,
#  ('adam', 'declin'): 0.0,
#  ('declin', 'rhinorrhea'): 1.0,
#  ('prognosi', 'sibl'): 0.0,
#  ('esld', 'itchi'): 0.0,
#  ('autoset', 'ppd'): 1.0,
#  ('lusb', 'sweat'): 1.0,
#  ('asthma', 'para'): 1.0,
#  ('precordium', 'sweat'): 1.0,
#  ('barium', 'mottl'): 1.0,
#  ('declin', 'dni'): 0.6873975401893274,
#  ('cmo', 'prognosi'): 0.0,
#  ('mood', 'nocturn'): 1.0,
#  ('qtc', 'rm'): 1.0,
#  ('gastriti', 'predict'): 1.0,
#  ('autoset', 'declin'): 1.0,
#  ('im', 'nifedipin'): 1.0,
#  ('dnr', 'hctz'): 1.0,
#  ('ffp', 'platelet'): 0.0,
#  ('dopamin', 'scar'): 1.0,
#  ('azotemia', 'motor'): 1.0,
#  ('hive', 'mood'): 1.0,
#  ('hypotherm', 'rusti'): 0.0,
#  ('seroquel', 'ultram'): 1.0,
#  ('thrive', 'vagu'): 1.0,
#  ('captopril', 'predict'): 1.0,
#  ('hospic', 'underneath'): 0.0,
#  ('anur', 'rpr'): 1.0,
#  ('hung', 'vasopressin'): 0.0,
#  ('rhinorrhea', 'wish'): 1.0,
#  ('neo', 'recalibr'): 1.0,
#  ('acc', 'ba'): 1.0,
#  ('gastriti', 'hive'): 1.0,
#  ('ofm', 'osa'): 1.0,
#  ('carvedilol', 'pleasant'): 1.0,
#  ('bair', 'vasopressor'): 0.0,
#  ('cocain', 'crack'): 1.0,
#  ('ferritin', 'nifedipin'): 1.0,
#  ('bottl', 'hygein'): 1.0,
#  ('calculi', 'suprapub'): 1.0,
#  ('acc', 'scar'): 1.0,
#  ('colonoscopi', 'dnr'): 1.0,
#  ('burn', 'epigastr'): 1.0,
#  ('hunger', 'scar'): 0.0,
#  ('ctx', 'dopamin'): 1.0,
#  ('familt', 'palli'): 0.0,
#  ('ctx', 'neo'): 1.0,
#  ('flight', 'stair'): 1.0,
#  ('anaphylaxi', 'levoph'): 1.0,
#  ('calvarium', 'occipit'): 1.0,
#  ('imbal', 'strictur'): 1.0,
#  ('occipit', 'subdur'): 1.0,
#  ('breakfast', 'mellitu'): 1.0,
#  ('epigastr', 'nicotin'): 1.0,
#  ('bromid', 'omeprazol'): 1.0,
#  ('anur', 'gentamycin'): 0.0,
#  ('dead', 'synthet'): 0.0,
#  ('massag', 'oncologist'): 1.0,
#  ('fibrinogen', 'norepinephrin'): 0.32443728093998864,
#  ('arrest', 'dic'): 0.0,
#  ('ctx', 'gabapentin'): 1.0,
#  ('ciwa', 'oob'): 1.0,
#  ('fdp', 'fibrinogen'): 0.0,
#  ('dz', 'pneumococc'): 1.0,
#  ('oob', 'readmit'): 1.0,
#  ('paralyt', 'phenylephrin'): 0.0,
#  ('seroquel', 'uri'): 1.0,
#  ('intiat', 'sensat'): 1.0,
#  ('ppd', 'prec'): 1.0,
#  ('adam', 'dnr'): 0.0,
#  ('azotemia', 'ciwa'): 1.0,
#  ('banana', 'ciwa'): 1.0,
#  ('nonrebreath', 'romi'): 1.0,
#  ('calvarium', 'effac'): 0.5,
#  ('bottl', 'currenlti'): 1.0,
#  ('dic', 'gadolinium'): 1.0,
#  ('book', 'fax'): 1.0,
#  ('klonopin', 'zyprexa'): 1.0,
#  ('oob', 'spiromet'): 1.0,
#  ('neosynephrin', 'phenylephrin'): 0.0,
#  ('ppd', 'soln'): 1.0,
#  ('redirect', 'wallet'): 0.0,
#  ('cs', 'zyprexa'): 1.0,
#  ('myeloma', 'rhinorrhea'): 0.0,
#  ('carvedilol', 'seroquel'): 1.0,
#  ('asthma', 'nectar'): 1.0,
#  ('angioplasti', 'dnr'): 1.0,
#  ('bottl', 'dnr'): 1.0,
#  ('hilum', 'slice'): 1.0,
#  ('anur', 'dnr'): 0.39994173456925625,
#  ('acc', 'dietari'): 1.0,
#  ('chair', 'zyprexa'): 1.0,
#  ('osa', 'seat'): 1.0,
#  ('hilum', 'nephrogram'): 1.0,
#  ('dnr', 'xl'): 1.0,
#  ('ferritin', 'ration'): 1.0,
#  ('moan', 'rabbi'): 0.0,
#  ('hsq', 'phlegm'): 1.0,
#  ('nicotin', 'xopenex'): 1.0,
#  ('aaox', 'subdur'): 1.0,
#  ('crack', 'hygein'): 1.0,
#  ('exophyt', 'peribronchovascular'): 1.0,
#  ('hive', 'iddm'): 1.0,
#  ('intent', 'phlegm'): 1.0,
#  ('dopamin', 'neo'): 0.6789811080628495,
#  ('barium', 'breakfast'): 1.0,
#  ('ba', 'opiat'): 1.0,
#  ('dni', 'hugger'): 0.0,
#  ('cefapim', 'kerlix'): 1.0,
#  ('pleasantli', 'subdur'): 1.0,
#  ('clonazepam', 'recruit'): 1.0,
#  ('dni', 'nectar'): 1.0,
#  ('aaox', 'syst'): 1.0,
#  ('puff', 'sibl'): 1.0,
#  ('lymphangit', 'soln'): 1.0,
#  ('acc', 'angri'): 1.0,
#  ('db', 'para'): 1.0,
#  ('dnr', 'oligur'): 0.3838679926709539,
#  ('incent', 'nonrebreath'): 1.0,
#  ('calculi', 'omeprazol'): 1.0,
#  ('bipolar', 'opiat'): 1.0,
#  ('morbid', 'romi'): 1.0,
#  ('aaox', 'pleasant'): 1.0,
#  ('dni', 'pca'): 1.0,
#  ('bair', 'pinpoint'): 0.0,
#  ('harm', 'oob'): 1.0,
#  ('ambien', 'ciwa'): 1.0,
#  ('permiss', 'pose'): 1.0,
#  ('dni', 'hilum'): 0.0,
#  ('mtg', 'rhinorrhea'): 1.0,
#  ('ambul', 'palli'): 0.0,
#  ('hctz', 'sensat'): 1.0,
#  ('bank', 'itchi'): 1.0,
#  ('cs', 'tran'): 1.0,
#  ('acidot', 'dic'): 0.0,
#  ('qam', 'sibl'): 1.0,
#  ('cagluc', 'neo'): 0.0,
#  ('laminectomi', 'unstabl'): 1.0,
#  ('ciwa', 'sweat'): 1.0,
#  ('eg', 'foci'): 1.0,
#  ('articul', 'lat'): 1.0,
#  ('morbid', 'uri'): 1.0,
#  ('commod', 'option'): 1.0,
#  ('lat', 'qtc'): 1.0,
#  ('dyslipidemia', 'thiamin'): 1.0,
#  ('freeli', 'protrud'): 0.0,
#  ('mellitu', 'rigor'): 1.0,
#  ('grim', 'sluggish'): 0.0,
#  ('bicarbon', 'sluggishli'): 0.0,
#  ('appi', 'arrest'): 1.0,
#  ('gadolinium', 'uri'): 1.0,
#  ('gabapentin', 'profound'): 1.0,
#  ('deterior', 'lift'): 1.0,
#  ('anaphylaxi', 'subq'): 1.0,
#  ('diaphoresi', 'strictur'): 1.0,
#  ('dnr', 'scopalamin'): 0.5161168305887667,
#  ('dnr', 'heroic'): 0.0,
#  ('dnr', 'pinpoint'): 0.0,
#  ('sweat', 'thiamin'): 1.0,
#  ('death', 'omeprazol'): 1.0,
#  ('declin', 'nicotin'): 1.0,
#  ...}

# %%
# patient_dead_cooc_df
print(patient_cooc_0)
# Out:
# {111: {('arrest', 'pea'): 5.0, ('cpr', 'pea'): 4.0, ('arrest', 'cpr'): 4.0, ('cpr', 'vasopressin'): 4.0, ('pea', 'vasopressin'): 4.0, ('arrest', 'vasopressin'): 4.0, ('pcv', 'vasopressin'): 2.0, ('cpr', 'pcv'): 2.0, ('pcv', 'pea'): 2.0, ('arrest', 'pcv'): 2.0, ('paralyt', 'pcv'): 2.0, ('paralyt', 'vasopressin'): 2.0, ('cpr', 'paralyt'): 2.0, ('paralyt', 'pea'): 2.0, ('arrest', 'paralyt'): 2.0, ('norepinephrin', 'paralyt'): 2.0, ('norepinephrin', 'pcv'): 2.0, ('norepinephrin', 'vasopressin'): 2.0, ('cpr', 'norepinephrin'): 2.0, ('norepinephrin', 'pea'): 2.0, ('arrest', 'norepinephrin'): 2.0, ('hypothermia', 'norepinephrin'): 2.0, ('hypothermia', 'paralyt'): 2.0, ('hypothermia', 'pcv'): 2.0, ('hypothermia', 'vasopressin'): 2.0, ('cpr', 'hypothermia'): 2.0, ('hypothermia', 'pea'): 2.0, ('arrest', 'hypothermia'): 2.0, ('hypercapnia', 'hypothermia'): 2.0, ('hypercapnia', 'norepinephrin'): 2.0, ('hypercapnia', 'paralyt'): 2.0, ('hypercapnia', 'pcv'): 2.0, ('hypercapnia', 'vasopressin'): 2.0, ('cpr', 'hypercapnia'): 2.0, ('hypercapnia', 'pea'): 2.0, ('arrest', 'hypercapnia'): 2.0, ('dic', 'hypercapnia'): 2.0, ('dic', 'hypothermia'): 2.0, ('dic', 'norepinephrin'): 2.0, ('dic', 'paralyt'): 2.0, ('dic', 'pcv'): 2.0, ('dic', 'vasopressin'): 2.0, ('cpr', 'dic'): 2.0, ('dic', 'pea'): 2.0, ('arrest', 'dic'): 2.0, ('dic', 'phenylephrin'): 2.0, ('hypercapnia', 'phenylephrin'): 2.0, ('hypothermia', 'phenylephrin'): 2.0, ('norepinephrin', 'phenylephrin'): 2.0, ('paralyt', 'phenylephrin'): 2.0, ('pcv', 'phenylephrin'): 2.0, ('phenylephrin', 'vasopressin'): 2.0, ('cpr', 'phenylephrin'): 2.0, ('pea', 'phenylephrin'): 2.0, ('arrest', 'phenylephrin'): 2.0, ('bicarbon', 'phenylephrin'): 2.0, ('bicarbon', 'dic'): 2.0, ('bicarbon', 'hypercapnia'): 2.0, ('bicarbon', 'hypothermia'): 2.0, ('bicarbon', 'norepinephrin'): 2.0, ('bicarbon', 'paralyt'): 2.0, ('bicarbon', 'pcv'): 2.0, ('bicarbon', 'vasopressin'): 2.0, ('bicarbon', 'cpr'): 2.0, ('bicarbon', 'pea'): 2.0, ('arrest', 'bicarbon'): 2.0, ('azotemia', 'bicarbon'): 2.0, ('azotemia', 'phenylephrin'): 2.0, ('azotemia', 'dic'): 2.0, ('azotemia', 'hypercapnia'): 2.0, ('azotemia', 'hypothermia'): 2.0, ('azotemia', 'norepinephrin'): 2.0, ('azotemia', 'paralyt'): 2.0, ('azotemia', 'pcv'): 2.0, ('azotemia', 'vasopressin'): 2.0, ('azotemia', 'cpr'): 2.0, ('azotemia', 'pea'): 2.0, ('arrest', 'azotemia'): 2.0, ('autopeep', 'azotemia'): 2.0, ('autopeep', 'bicarbon'): 2.0, ('autopeep', 'phenylephrin'): 2.0, ('autopeep', 'dic'): 2.0, ('autopeep', 'hypercapnia'): 2.0, ('autopeep', 'hypothermia'): 2.0, ('autopeep', 'norepinephrin'): 2.0, ('autopeep', 'paralyt'): 2.0, ('autopeep', 'pcv'): 2.0, ('autopeep', 'vasopressin'): 2.0, ('autopeep', 'cpr'): 2.0, ('autopeep', 'pea'): 2.0, ('arrest', 'autopeep'): 2.0, ('arrest', 'death'): 3.0, ('death', 'vasopressin'): 2.0, ('cpr', 'death'): 2.0, ('death', 'pea'): 2.0, ('clinician', 'death'): 2.0, ('clinician', 'vasopressin'): 2.0, ('clinician', 'cpr'): 2.0, ('clinician', 'pea'): 2.0, ('arrest', 'clinician'): 2.0, ('profound', 'vasopressin'): 2.0, ('cpr', 'profound'): 2.0, ('pea', 'profound'): 2.0, ('arrest', 'profound'): 2.0, ('death', 'expir'): 2.0, ('arrest', 'expir'): 2.0}, 346: {}, 404: {('death', 'paco'): 1.0}, 546: {('hurt', 'oder'): 1.0, ('historian', 'oder'): 1.0, ('historian', 'hurt'): 1.0}, 618: {}, 705: {('dni', 'dnr'): 2.0, ('cmo', 'dnr'): 2.0}, 726: {}, 1039: {}, 1556: {('dnr', 'mso'): 7.0, ('dni', 'dnr'): 8.0, ('dni', 'mso'): 7.0}, 1872: {}, 1944: {}, 2286: {('cyanot', 'pitressin'): 11.0, ('cyanot', 'incis'): 8.0, ('anur', 'cyanot'): 7.0, ('bair', 'hugger'): 7.0}, 2990: {}, 3055: {}, 3099: {('neo', 'neosynephrin'): 1.0, ('dopamin', 'neosynephrin'): 1.0, ('ffp', 'neo'): 1.0, ('ffp', 'neosynephrin'): 1.0, ('ffp', 'vasopressin'): 1.0, ('neo', 'vasopressin'): 1.0, ('neosynephrin', 'vasopressin'): 1.0, ('levoph', 'vasopressin'): 1.0, ('ffp', 'levoph'): 1.0, ('levoph', 'neo'): 1.0, ('levoph', 'neosynephrin'): 1.0, ('hypotherm', 'levoph'): 1.0, ('hypotherm', 'vasopressin'): ...

# %%
print(patient_node_0)
# Out:
# {111: {'arrest': 6.0, 'pea': 5.0, 'cpr': 4.0, 'vasopressin': 4.0, 'pcv': 2.0, 'paralyt': 2.0, 'norepinephrin': 2.0, 'hypothermia': 2.0, 'hypercapnia': 2.0, 'dic': 2.0, 'phenylephrin': 2.0, 'bicarbon': 2.0, 'azotemia': 2.0, 'autopeep': 2.0, 'death': 3.0, 'clinician': 2.0, 'profound': 2.0, 'expir': 2.0}, 346: {'arrest': 4.0, 'sluggish': 6.0}, 404: {'paco': 1.0, 'death': 1.0}, 546: {'oder': 1.0, 'hurt': 1.0, 'historian': 1.0}, 618: {'video': 2.0}, 705: {'dnr': 5.0, 'dni': 2.0, 'cmo': 5.0, 'mso': 2.0}, 726: {'mso': 3.0, 'dnr': 3.0}, 1039: {'wish': 4.0}, 1556: {'mso': 13.0, 'dnr': 8.0, 'dni': 8.0}, 1872: {'pronounc': 1.0}, 1944: {'arrest': 4.0, 'cvvhd': 5.0}, 2286: {'cyanot': 17.0, 'vasopressin': 14.0, 'levoph': 8.0, 'dnr': 7.0, 'prognosi': 7.0, 'purpl': 10.0, 'mottl': 7.0, 'pitressin': 15.0, 'incis': 10.0, 'anur': 9.0, 'cvvh': 9.0, 'hugger': 7.0, 'bair': 7.0}, 2990: {'chair': 17.0, 'oob': 17.0, 'levoph': 31.0, 'anur': 24.0}, 3055: {'gc': 3.0, 'wish': 3.0, 'cmo': 4.0}, 3099: {'neo': 2.0, 'neosynephrin': 2.0, 'dopamin': 1.0, 'ffp': 2.0, 'vasopressin': 1.0, 'levoph': 1.0, 'hypotherm': 1.0, 'hung': 1.0, 'dic': 1.0, 'cagluc': 1.0, 'suport': 1.0, 'polici': 1.0, 'ethic': 1.0, 'cpr': 1.0}, 3201: {'sluggish': 3.0, 'dopamin': 3.0, 'norepinephrin': 1.0, 'levoph': 1.0, 'unavail': 1.0, 'neo': 2.0, 'pitressin': 1.0, 'vasopressin': 1.0, 'unequ': 1.0, 'pronounc': 1.0, 'nahco': 1.0, 'mortem': 1.0, 'levof': 1.0, 'expir': 1.0, 'cpr': 1.0}, 3526: {'levoph': 2.0, 'dnr': 2.0, 'dni': 2.0, 'laryng': 1.0, 'pronounc': 1.0, 'mso': 1.0, 'jerk': 1.0, 'intiat': 1.0, 'declin': 1.0, 'death': 1.0, 'agon': 1.0}, 3773: {'plate': 1.0, 'mso': 2.0, 'escal': 1.0, 'dopamin': 1.0, 'dnr': 1.0, 'dni': 1.0, 'cmo': 1.0, 'pronounc': 1.0, 'death': 1.0}, 3881: {'dnr': 3.0, 'dni': 3.0, 'cmo': 3.0, 'moan': 2.0, 'sluggish': 2.0}, 4122: {}, 4754: {'levoph': 11.0, 'dobutamin': 10.0, 'captopril': 17.0}, 4811: {'life': 2.0, 'dnr': 2.0, 'dni': 2.0, 'hospic': 2.0}, 5476: {}, 5494: {'dnr': 2.0, 'dni': 2.0, 'wish': 2.0, 'escal': 2.0, 'video': 2.0}, 5774: {'levoph': 13.0, 'neo': 11.0, 'cvvhd': 11.0, 'sluggish': 9.0, 'pneumococc': 13.0, 'hugger': 12.0, 'cpr': 12.0}, 5786: {'dobutamin': 9.0}, 5913: {}, 6133: {'lc': 6.0}, 6735: {'prognosi': 3.0, 'dopamin': 3.0, 'mottl': 2.0, 'mso': 2.0, 'levoph': 2.0, 'cpr': 2.0, 'grave': 2.0}, 6745: {'dnr': 4.0, 'dni': 4.0, 'mso': 2.0, 'wish': 1.0, 'heroic': 1.0, 'rabbi': 1.0, 'profound': 1.0, 'moan': 1.0}, 6973: {'dnr': 3.0, 'dni': 3.0}, 6981: {'lat': 1.0, 'occupi': 1.0, 'dnr': 2.0, 'dni': 2.0, 'pleuravac': 1.0, 'priest': 1.0}, 7277: {'neo': 6.0, 'mso': 14.0}, 7310: {'hospic': 3.0, 'dnr': 3.0, 'dni': 3.0, 'nonrebreath': 1.0, 'palliat': 2.0, 'opinion': 2.0, 'sacrament': 1.0, 'peac': 1.0, 'prognosi': 1.0}, 7924: {'neo': 1.0, 'wish': 1.0, 'reveiw': 1.0}, 7977: {'neo': 3.0, 'levoph': 2.0}, 9908: {'levof': 1.0, 'neosynephrin': 1.0, 'levoph': 1.0, 'intiat': 1.0, 'dnr': 1.0, 'dni': 1.0, 'agon': 1.0, 'cmo': 2.0}, 9984: {'levoph': 4.0, 'incis': 2.0, 'hugger': 2.0}, 10302: {'levoph': 56.0, 'dnr': 41.0, 'hive': 39.0, 'fibrinogen': 39.0, 'platelet': 36.0, 'hemothorax': 36.0, 'chb': 29.999999999999996, 'suffer': 26.0, 'norepinephrin': 17.0, 'dic': 31.0, 'abruptli': 18.0}, 10510: {'xopenex': 7.000000000000001}, 10545: {'gvhd': 2.0, 'dopamin': 2.0, 'cyanot': 1.0, 'eyelid': 1.0, 'fungemia': 1.0, 'furhter': 1.0, 'lw': 1.0, 'twitch': 1.0, 'ambul': 1.0, 'vasopressin': 1.0, 'cmo': 1.0, 'levoph': 1.0, 'vasoconstrict': 1.0, 'liw': 1.0, 'mso': 1.0, 'pose': 1.0, 'prognosi': 1.0, 'sibl': 1.0, 'unstabl': 1.0, 'asystol': 1.0, 'dead': 1.0, 'pronounc': 1.0, 'autopsi': 1.0}, 10642: {'scar': 1.0, 'centimet': 1.0, 'dnr': 4.0, 'dni': 3.0, 'mso': 1.0, 'gasp': 1.0, 'prognosi': 1.0, 'moan': 1.0}, 11049: {'neo': 6.0, 'lw': 2.0, 'phenylephrin': 2.0}, 11209: {'subdur': 1.0, 'deterior': 1.0, 'dni': 3.0, 'dnr': 3.0, 'vasopressor': 1.0, 'bair': 1.0, 'dopamin': 1.0, 'hugger': 1.0, 'hypotherm': 1.0, 'hypothermia': 1.0, 'levoph': 1.0, 'paperwork': 1.0, 'rusti': 1.0, 'sluggish': 1.0, 'wish': 1.0, 'arre ...

# %%
# Count support of each node
patient_node_set = set()
patient_node_0_dict = {}
patient_node_1_dict = {}
    
for k, v in patient_node_0.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_0_dict:
            patient_node_0_dict[item] = v[item]
        else:
            patient_node_0_dict[item] = patient_node_0_dict[item] + v[item]
        
    
for k, v in patient_node_1.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_1_dict:
            patient_node_1_dict[item] = v[item]
        else:
            patient_node_1_dict[item] = patient_node_1_dict[item] + v[item]

# %%
print(len(patient_node_set))
print(len(patient_node_0_dict))
print(len(patient_node_1_dict))
# Out:
# 633
# 379
# 571

# %%
patient_node_odd_scores = {}

for set_item in patient_node_set:
    if set_item in patient_node_0_dict and set_item in patient_node_1_dict:
        d_prob = patient_node_0_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        a_prob = patient_node_1_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_node_odd_scores[set_item] = log_odd_score

# %%
print(patient_node_odd_scores)
# Out:
# {'cisatracurium': -0.9533015672059649, 'itchi': -0.03383387098398164, 'mellitu': 3.6335560595180567, 'tobra': -6.90875477931522, 'jewelri': 2.625239572123001, 'readmit': 6.90875477931522, 'bmx': 6.90875477931522, 'scar': 0.9884634019134366, 'cooki': 6.90875477931522, 'mjmgb': 0.28709992764761555, 'cmo': -1.3973812618169323, 'weekli': 6.90875477931522, 'doen': -6.90875477931522, 'zero': 6.90875477931522, 'lat': 2.781918475709505, 'unequ': 0.0, 'pneumothorac': 0.4585825764835029, 'dorsal': 0.6916505477038827, 'beeper': 6.90875477931522, 'gastriti': 6.90875477931522, 'align': 2.1317280276818393, 'tranfer': 6.90875477931522, 'crack': 6.90875477931522, 'passi': 6.90875477931522, 'tie': 6.90875477931522, 'solut': 6.90875477931522, 'laryng': 4.509960818540722, 'postop': 2.6598359419686672, 'contractur': 2.8995119199810393, 'proport': 0.6916505477038827, 'respitori': -0.6916505477038827, 'echocardiogram': 0.41045180799574615, 'petechia': -6.90875477931522, 'spacer': 6.90875477931522, 'vigil': 6.90875477931522, 'maroon': 6.90875477931522, 'nicotin': 6.90875477931522, 'underneath': 1.3825560390092835, 'vagu': 3.7191633588776987, 'gait': 2.601472222000523, 'refractori': 6.90875477931522, 'mva': 6.90875477931522, 'natg': 0.1332640725070919, 'abruptli': -6.90875477931522, 'fc': -1.7859498421315991, 'grimmac': 6.90875477931522, 'dex': 6.90875477931522, 'vasopressin': -0.5628251784941475, 'thoracocentesi': 6.90875477931522, 'hctz': 6.90875477931522, 'artifici': 0.7560249394646842, 'wma': -1.9852670803394386, 'tracheomalacia': 6.90875477931522, 'pharmacolog': 6.90875477931522, 'escal': 0.27845984279047015, 'thrive': 0.9294189568548948, 'slough': 6.90875477931522, 'compani': 6.90875477931522, 'omeprazol': 3.936461279816705, 'dnr': 0.8878077019401656, 'videofluoroscopi': 6.90875477931522, 'triadyn': -0.07988277164760577, 'anuria': 1.1884144866522524, 'neosynephrin': -0.03502126292381994, 'quinton': 6.90875477931522, 'pea': 1.242916320903325, 'vp': 6.90875477931522, 'agon': -3.3046522316270157, 'crowd': 2.0716061679700735, 'hemithorac': -6.90875477931522, 'emper': 6.90875477931522, 'pcv': 0.03564677390926459, 'abnl': 6.90875477931522, 'hive': 2.0229359235263975, 'puff': 6.90875477931522, 'perisplen': 0.4046335072286383, 'heroic': -6.90875477931522, 'sensat': 3.269258198656955, 'mind': 6.90875477931522, 'articul': 6.90875477931522, 'goc': 0.3357879300251662, 'dni': 0.7852182412326755, 'angioplasti': 6.90875477931522, 'habitu': 3.4292390061376663, 'fwb': 6.90875477931522, 'futil': -1.7859498421315991, 'ardsnet': 0.6460928627110164, 'slice': 2.1883847407670785, 'protrud': 2.9256884298210646, 'tea': 6.90875477931522, 'asystol': -1.9390841839849136, 'ruptur': 6.90875477931522, 'paco': 2.2927445483990123, 'autopsi': -6.90875477931522, 'fdp': -6.90875477931522, 'vtach': -2.007571633726069, 'tacycard': 6.90875477931522, 'resucit': 6.90875477931522, 'stair': 6.90875477931522, 'dermat': 2.8834579772384417, 'bow': 6.90875477931522, 'hospic': 0.4149738469106543, 'cellcept': 0.2580521194945898, 'unavail': 2.4165779821478726, 'fibrinogen': 0.6890116342592116, 'acidot': 3.213562170762998, 'core': -0.2870999276476155, 'muir': 6.90875477931522, 'dic': 1.1780886503127903, 'plate': 1.7859498421315991, 'pleasant': 3.4542729200809688, 'calculi': 1.5360079185039965, 'news': -6.90875477931522, 'msicu': 6.90875477931522, 'seat': 1.4311353280322385, 'consciou': 6.90875477931522, 'pvr': 0.0, 'argatroban': -0.8013676005646301, 'struggl': -6.90875477931522, 'diuril': 6.90875477931522, 'cagluc': -6.90875477931522, 'endplat': 1.2495579516853903, 'motor': 6.90875477931522, 'azotemia': -0.3422467750096624, 'hsq': 1.9624460326754531, 'lotion': 0.28709992764761555, 'judgement': -1.095952712632351, 'fliud': -6.90875477931522, 'oder': -6.90875477931522, 'deploy': 1.604655121332035, 'fu': 2.8726050025040895, 'ntnd': 0.9566305237694903, 'ferrou': 6.90875477931522, 'readdress': 1.604655121332035, 'ppn': 6.90875477931522, 'modifi': 6.90875477931522, 'centimet': 0.8453976222857142, 'me ...

# %%
patient_square_node_data = pd.DataFrame({'node':list(patient_node_odd_scores.keys()), 'feature':list(patient_node_odd_scores.values())})
patient_square_node_data
# Out:
#               node   feature
# 0    cisatracurium -0.953302
# 1            itchi -0.033834
# 2          mellitu  3.633556
# 3            tobra -6.908755
# 4          jewelri  2.625240
# ..             ...       ...
# 628        xopenex  1.104657
# 629         tf'ing  6.908755
# 630     lymphangit  2.224418
# 631          venti  1.255234
# 632           gaol  6.908755
#
# [633 rows x 2 columns]

# %%
patient_square_node_id_data = patient_square_node_data.set_index("node")
patient_square_node_id_data['subject'] = ["positive" if r['feature'] > 0 else "negative" for i, r in patient_square_node_id_data.iterrows()]
patient_square_node_id_data
# Out:
#                 feature   subject
# node
# cisatracurium -0.953302  negative
# itchi         -0.033834  negative
# mellitu        3.633556  positive
# tobra         -6.908755  negative
# jewelri        2.625240  positive
# ...                 ...       ...
# xopenex        1.104657  positive
# tf'ing         6.908755  positive
# lymphangit     2.224418  positive
# venti          1.255234  positive
# gaol           6.908755  positive
#
# [633 rows x 2 columns]

# %%
patient_subjects = patient_square_node_id_data["subject"]
patient_subjects
# Out:
# node
# cisatracurium    negative
# itchi            negative
# mellitu          positive
# tobra            negative
# jewelri          positive
#                    ...
# xopenex          positive
# tf'ing           positive
# lymphangit       positive
# venti            positive
# gaol             positive
# Name: subject, Length: 633, dtype: object

# %%
patient_square_node_data_no_feature = patient_square_node_id_data.drop(columns=["feature","subject"])
patient_square_node_data_no_feature
# Out:
# Empty DataFrame
# Columns: []
# Index: [cisatracurium, itchi, mellitu, tobra, jewelri, readmit, bmx, scar, cooki, mjmgb, cmo, weekli, doen, zero, lat, unequ, pneumothorac, dorsal, beeper, gastriti, align, tranfer, crack, passi, tie, solut, laryng, postop, contractur, proport, respitori, echocardiogram, petechia, spacer, vigil, maroon, nicotin, underneath, vagu, gait, refractori, mva, natg, abruptli, fc, grimmac, dex, vasopressin, thoracocentesi, hctz, artifici, wma, tracheomalacia, pharmacolog, escal, thrive, slough, compani, omeprazol, dnr, videofluoroscopi, triadyn, anuria, neosynephrin, quinton, pea, vp, agon, crowd, hemithorac, emper, pcv, abnl, hive, puff, perisplen, heroic, sensat, mind, articul, goc, dni, angioplasti, habitu, fwb, futil, ardsnet, slice, protrud, tea, asystol, ruptur, paco, autopsi, fdp, vtach, tacycard, resucit, stair, dermat, ...]
#
# [633 rows x 0 columns]

# %%
from sklearn.manifold import TSNE
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
from gensim.models import Word2Vec

# %% [markdown]
# ### Create a bi-directional df

# %%
# with edge weight
bidirect_source = []
bidirect_target = []
edge_weight = []

for item, val in new_patient_cooc_odd_scores.items():
    bidirect_source.extend([item[0], item[1]])
    bidirect_target.extend([item[1], item[0]])
    edge_weight.extend([val, val])
    
print(f"source: {len(bidirect_source)}, target: {len(bidirect_target)}")

weighted_patient_bidirect_square_edge_data = pd.DataFrame(
    {
        "source": bidirect_source,
        "target": bidirect_target,
        "weight": edge_weight,
    })
weighted_patient_bidirect_square_edge_data
# Out:
# source: 13552, target: 13552
#            source      target  weight
# 0         aricept  gentamycin     0.0
# 1      gentamycin     aricept     0.0
# 2             dnr  refractori     1.0
# 3      refractori         dnr     1.0
# 4         aricept        romi     1.0
# ...           ...         ...     ...
# 13547          xl  fibrinogen     1.0
# 13548        life     paralyt     0.0
# 13549     paralyt        life     0.0
# 13550        doen       rabbi     0.0
# 13551       rabbi        doen     0.0
#
# [13552 rows x 3 columns]

# %%
# Weighted
G_weighted_patient_bidirect = StellarGraph(
    {"corner": patient_square_node_data_no_feature}, {"line": weighted_patient_bidirect_square_edge_data}
)
print(G_weighted_patient_bidirect.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 633, Edges: 13552
#
#  Node types:
#   corner: [633]
#     Features: none
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [13552]
#         Weights: range=[0, 1], mean=0.734681, std=0.426758
#         Features: none

# %%
# Weighted
rw_weighted_patient_bidirect = BiasedRandomWalk(G_weighted_patient_bidirect)

# %%
# Weighted
weighted_walks_patient_bidirect = rw_weighted_patient_bidirect.run(
    nodes=G_weighted_patient_bidirect.nodes(),  # root nodes
    length=100,  # maximum length of a random walk
    n=10,  # number of random walks per root node
    p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
    q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
    weighted=True,  # for weighted random walks
    seed=42,  # random seed fixed for reproducibility
)
print("Number of random walks: {}".format(len(weighted_walks_patient_bidirect)))
# Out:
# Number of random walks: 6330

# %%
print(weighted_walks_patient_bidirect[0])
# Out:
# ['cisatracurium']

# %%
# Weighted
weighted_model_patient = Word2Vec(
    weighted_walks_patient_bidirect, size=128, window=5, min_count=0, sg=1, workers=4, iter=1
)

# %%
# Weighted
emb = weighted_model_patient.wv["cmo"]
emb
# Out:
# array([-1.01303880e-03,  1.04699925e-01, -1.50071621e-01, -1.44534573e-01,
#         2.41005197e-01,  1.36627361e-01, -2.80210853e-01,  2.62291729e-01,
#         3.48975182e-01, -4.18060809e-01, -1.53201064e-02, -2.41898954e-01,
#         1.57691106e-01, -1.27571941e-04,  1.60265386e-01,  1.38786808e-01,
#         1.46415994e-01, -1.49806619e-01, -3.34125638e-01, -1.00209050e-01,
#        -1.77354738e-02,  2.03140348e-01,  3.75837266e-01,  2.33276542e-02,
#        -2.75741428e-01,  6.38003275e-02,  2.70108551e-01,  1.08512789e-01,
#         2.37649873e-01, -3.58122468e-01,  8.29499960e-02,  3.74757266e-03,
#        -2.09547147e-01,  3.01052071e-03,  4.42683287e-02,  3.15992057e-01,
#         1.52249500e-01, -5.71697690e-02,  1.57711934e-02,  4.19643432e-01,
#        -4.27124828e-01,  4.79553849e-01, -9.56899598e-02,  4.20023978e-01,
#         8.05617794e-02,  2.75234878e-01, -2.54100651e-01, -1.17758475e-01,
#         3.83420497e-01, -3.79768491e-01, -3.18998158e-01, -2.07696870e-01,
#         2.82956511e-01, -8.03861842e-02,  1.14726931e-01,  6.53553307e-02,
#         6.60536140e-02,  5.27097099e-02,  4.42597985e-01, -9.41177234e-02,
#         2.29659095e-01,  1.73274614e-02,  3.08203906e-01, -3.07749361e-01,
#         3.67165118e-01,  3.18352915e-02,  8.01839307e-02, -3.82694423e-01,
#         3.86117697e-01, -1.96295157e-01, -2.38850966e-01,  2.88086295e-01,
#         2.01121569e-01,  2.92866588e-01, -1.12650961e-01, -2.95469344e-01,
#        -4.29680198e-02, -1.78106472e-01,  2.12078378e-01,  3.13573807e-01,
#        -3.22724842e-02, -3.69091779e-02, -1.80906668e-01,  1.11437917e-01,
#         3.59952599e-01, -1.17122479e-01, -1.77071884e-01,  1.86090618e-01,
#         8.77199043e-03,  4.74570781e-01, -3.88649590e-02, -1.12491082e-02,
#         1.73794985e-01,  7.30401836e-03, -1.11332890e-02,  3.57546031e-01,
#         4.79561426e-02,  3.89582425e-01, -1.56617895e-01,  1.17380798e-01,
#        -1.13134056e-01,  3.13894600e-01,  2.00613782e-01, -1.42807007e-01,
#        -1.92010313e-01, -2.20338941e-01,  3.27983722e-02, -2.05923796e-01,
#        -1.29655942e-01,  5.47794104e-01, -5.61070405e-02,  2.36094147e-01,
#        -1.03357546e-02, -1.52899995e-01,  1.87040105e-01,  9.60317552e-02,
#         2.38333821e-01, -1.53705433e-01, -8.32454190e-02, -2.08243281e-01,
#        -1.84326261e-01, -3.46960351e-02,  2.54285127e-01,  3.53325993e-01,
#         2.89694518e-01,  3.17851812e-01,  4.08031106e-01,  5.34077287e-02],
#       dtype=float32)

# %% [markdown]
# ### Visualise Node Embeddings generated by weighted random walks

# %% [markdown]
# ### Weighted edges

# %%
# Retrieve node embeddings and corresponding subjects
patient_weighted_node_ids = weighted_model_patient.wv.index2word  # list of node IDs
patient_weighted_node_embeddings = (
    weighted_model_patient.wv.vectors
)  # numpy.ndarray of size number of nodes times embeddings dimensionality
# the gensim ordering may not match the StellarGraph one, so rearrange
patient_node_targets = patient_subjects.loc[patient_weighted_node_ids].astype("category")

# %%
# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2, random_state=42)
patient_weighted_node_embeddings_2d = tsne.fit_transform(patient_weighted_node_embeddings)

# %%
# draw the points
alpha = 0.7

plt.figure(figsize=(10, 8))
plt.scatter(
    patient_weighted_node_embeddings_2d[:, 0],
    patient_weighted_node_embeddings_2d[:, 1],
    c=patient_node_targets.cat.codes,
    cmap="jet",
    alpha=0.7,
)
plt.show()

# %%
patient_weighted_node_emb_dict = {}
for index, row in patient_square_node_data_no_feature.iterrows():
    if index not in patient_weighted_node_emb_dict:
        patient_weighted_node_emb_dict[index] = weighted_model_patient.wv[index]
    else:
        print(f"index: {index} is already in a dictionary!")

# %%
# print(type(patient_weighted_node_emb_dict['aprv']))

# %%
import pandas as pd
import numpy as np

import stellargraph as sg
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import GCNSupervisedGraphClassification
from stellargraph import StellarGraph

from stellargraph import datasets

from sklearn import model_selection
from IPython.display import display, HTML

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import matplotlib.pyplot as plt

seed = 42
numpy.random.seed(seed)
tf.random.set_seed(seed)
sg.random.set_seed(seed)

# %% [markdown]
# ### Load the data

# %%
from collections import defaultdict

def create_graph_list(patient_cooc_dict, cooc_odd_scores, node_emb_dict, label):
    
    graphs = []
    labels = []
    
    for key,row in patient_cooc_dict.items():
     
        if row:
            source = []
            target = []
            edge_weight = []
            
            node_feature = []
            node_idx = []
            for cooc in row:
                source.extend([cooc[0], cooc[1]])
                target.extend([cooc[1], cooc[0]])
                edge_weight.extend([cooc_odd_scores[cooc], cooc_odd_scores[cooc]])
        
            node_idx = list(set(source + target))
    
            # Create a dataframe of only nodes
            square_node_data = pd.DataFrame(
                index=node_idx)
            
#             square_node_data['feature'] = [1] * len(node_idx)
        
            # Create a dictionary for each column for a vector
            node_features = defaultdict(list)
            for node in node_idx:
                for i, vec in enumerate(node_emb_dict[node]):
                    node_features['w_' + str(i)].append(vec)
        
            # Add columns to a dataframe
            for k, v in node_features.items():
              
                square_node_data[k] = v

            square_edges = pd.DataFrame({ 
                "source": source, 
                "target": target, 
                "weight":edge_weight
            })
        
            square = StellarGraph({"corner": square_node_data}, {"line": square_edges})
            graphs.append(square)
            labels.append(label)
            
    return graphs, labels

graphs = []
labels = []

# patient_weighted_node_emb_dict
graph_0, label_0 = create_graph_list(patient_cooc_0, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, -1)
graph_1, label_1 = create_graph_list(patient_cooc_1, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, 1)

graphs.extend(graph_0)
labels.extend(label_0)
print(f"graphs_0: {len(graphs)}, labels_0: {len(labels)}")
graphs.extend(graph_1)
labels.extend(label_1)
print(f"graphs_1: {len(graph_1)}, labels_1: {len(label_1)}")
print(f"graphs: {len(graphs)}, labels: {len(labels)}")
# Out:
# graphs_0: 162, labels_0: 162
# graphs_1: 726, labels_1: 726
# graphs: 888, labels: 888

# %%
# prepare test and train datasets
test_cnt = int(len(graphs)*0.1)/2
print(test_cnt)

pos_start = len(graph_0)
print(pos_start)

test_arr = []
train_arr = []
for i, v in enumerate(graphs):
    # Take first items for neg set
    if i < test_cnt:
        test_arr.append(i)    
    elif i > pos_start and i <= pos_start + test_cnt:
        test_arr.append(i)    
    else:
        train_arr.append(i)
# Out:
# 44.0
# 162

# %%
import random
seed = 42
c = list(test_arr)
random.Random(seed).shuffle(c)
test_arr =  c

# %%
c = list(train_arr)
random.Random(seed).shuffle(c)
train_arr =  c

# %%
train_index = np.array(train_arr)
test_index = np.array(test_arr)

# %%
print(len(test_index))
print(test_index)
# Out:
# 88
# [178 182  33  30  19  26 165 187  15 185  42   1 195 179 175  37 186  36
#  171 164 192  20 202   8  41 198  40 177  32 174  39 205  43 196  12  23
#   18 189 169 168   7  34 190   2  16  38 166  22 180  24   5   6 184 181
#  199   9 206  21 191 163  10 170 167   0 203 176 201 172  25 193 183  29
#   27 197 204   4 173 194  11 188  13  17  28  31  35   3  14 200]

# %%
print(len(train_index))
print(train_index)
# Out:
# 800
# [820 462 661 578 735 619 446 737 538 861 583 732 876 425  68 879 265 466
#  428 149 486 132 703 509 288 289 577 319 327 464 108 822 818 317 632 700
#  598 324 719 767 309 532 587 819 417 368 390 279 489 404 122 300 762 471
#  824 479 744 838 389 238 626  80 690 273 260 268 136  53 445  94 551 118
#  754  57 826 262 857 627 490 539 365 353 447 663 408 716 320 870 522 444
#  791 595 301 728 777 335  52 442  72 835 734 485 582 611 413  54 675 473
#  510 352 693 261 492 725 741 350 714 102 671 565 860  77 525  67 610 154
#   61 286 775 695 569 678 665 250  86 814 351 236 670 812 638 789 519 568
#  399 502 225 592 457 813 505 677 608 602 329  49 237 649 360 474 623 808
#  207 497 128 684 755  60 590  83 325 394 469 381 615 226 783 129 666 766
#  800 837 752 276 694 571 212 540 790 749 564 481 344 491 278  84 421 228
#  463 217 272 337 511 281 844 240 697 403 452 739 315 866 705  75 378 480
#  850 162 220 727 763  89 100 723 287 864 400 589 280 881 483 398 630 736
#  339 664 573 883 531 555  93 235 545 560 150 518 465 636 776 423 443 804
#  798 852 537 145 159 544 576 488 259 527  87 130 621 395 535 356 612 815
#  252 382 453 770 243 594 295 606 874 603 303 720 707 239 575 794 297 604
#  534 512 107 657 409 415 460 456 625 682 354 713 396 484 218 141 383 285
#  761 349 868 554 264 601 722 549 647 773 385 438 591 507  58 873 781 548
#  618 563 416 530 768 613 292 142 495 708 160 718 267 672 146 157 328 709
#  283 643 816 224 859 556 298 745 135  56 299 134 127 209 503 644 296 374
#  269  96 515 832 437 499 271 887 274 245 674 676 845 119 831 562 528  62
#  367 120 441  82 786 516 375 616 449 370 314 807 126 222 414 110 620  45
#   66 757 688 494  91  70 696 795 346 645 412 439 771 797 839 151 397 232
#  227 123 513 468  98 726 827 112  97 427 796 371 506 429 542 836 422 501
#  401 242 448 366 514 758 710 233 277 213 581 266 680 729 347 153 363 829
#  624 376 406 546  48  81 472 559 667 241 418 431 877 290 656 210 597 454
#  430 843 221 750 355 377 386 424 805 584 405  64 681 817 214 379 543 570
#  105 294 208 648 433  78 392  79 622 523  85 348 579 596 712 756 524 834
#  740 332 387 885  73 248 683 641 865 310 391 635 246 586 858 380 553 854
#  487  46 792 256 702 782 306 580 659 652 258 330 869  59  95 642 541 121
#  343 793 660 275 748 231 855 651 823 342 155 435 500 106 144  99 566 508
#  689 450 529 840 140 282 504 673 336 572 223 687 307 699 373 331 614 669
#  426 784 113 785 104 116  51 856 323 655  65 434 772 318 341 211 550 617
#  536 717 760 407 293 715 779 521 628 769 257 650 574 219 216 633 114 585
#  131 830 778 334 103 333 402 459 733  63 588 419 701  44 631 640 253 470
#  801 862 799 724 393 152 607 270 600 764  47 811 249 533 828 886 848 803
#  833 161  55 654 345 629 567 747 478 482 109 698 849 851 730 244 156  92
#  137 593 609 229 788 825 496 685 526 686 357 639 863 340 880 359 234 557
#  746 493 599 759 305 410 668 304 111 362 498 411 871 322 101 420 312 658
#  743 364 476 561 255 882 634 263 810 711 117 751 787 361 774 302 451 467
#  254 461 738 552 884 841 147 867 125 384 321 765  90 115 809 284 679 458
#  721 731 388 653 124 475 215 637 558  88 358 706 440 455 143 477 138 878
#  432 308 247 853 436 872 802 251  50 372 691 547 313 517 875 806 753 821
#  291 662  71 704 605 326 311 139  74  76 520 692 133 646 846 780 148 842
#  230 316 338 369 847  69 158 742]

# %%
print(test_arr)
# Out:
# [178, 182, 33, 30, 19, 26, 165, 187, 15, 185, 42, 1, 195, 179, 175, 37, 186, 36, 171, 164, 192, 20, 202, 8, 41, 198, 40, 177, 32, 174, 39, 205, 43, 196, 12, 23, 18, 189, 169, 168, 7, 34, 190, 2, 16, 38, 166, 22, 180, 24, 5, 6, 184, 181, 199, 9, 206, 21, 191, 163, 10, 170, 167, 0, 203, 176, 201, 172, 25, 193, 183, 29, 27, 197, 204, 4, 173, 194, 11, 188, 13, 17, 28, 31, 35, 3, 14, 200]

# %%
print(graphs[0].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 18, Edges: 212
#
#  Node types:
#   corner: [18]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [212]
#         Weights: range=[0, 0.788597], mean=0.0526238, std=0.175607
#         Features: none

# %%
print(graphs[100].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 11, Edges: 76
#
#  Node types:
#   corner: [11]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [76]
#         Weights: range=[0, 0.552589], mean=0.214523, std=0.219258
#         Features: none

# %%
summary = pd.DataFrame(
    [(g.number_of_nodes(), g.number_of_edges()) for g in graphs],
    columns=["nodes", "edges"],
)
summary.describe().round(1)
# Out:
#        nodes  edges
# count  888.0  888.0
# mean     5.6   22.4
# std      3.7   33.8
# min      2.0    2.0
# 25%      2.0    2.0
# 50%      5.0    8.0
# 75%      8.0   26.0
# max     23.0  272.0

# %%
graph_labels = pd.Series(labels)

# %%
print(graph_labels)
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 883    1
# 884    1
# 885    1
# 886    1
# 887    1
# Length: 888, dtype: int64

# %%
graph_labels.value_counts().to_frame()
# Out:
#       0
#  1  726
# -1  162

# %%
graph_labels = pd.get_dummies(graph_labels, drop_first=True)

# %%
print(type(graph_labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
graph_labels
# Out:
#      1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 883  1
# 884  1
# 885  1
# 886  1
# 887  1
#
# [888 rows x 1 columns]

# %%
generator = PaddedGraphGenerator(graphs=graphs)

# %%
def create_graph_classification_model(generator):
    gc_model = GCNSupervisedGraphClassification(
        layer_sizes=[64, 64],
        activations=["relu", "relu"],
        generator=generator,
        dropout=0.5,
    )
    x_inp, x_out = gc_model.in_out_tensors()
    predictions = Dense(units=32, activation="relu")(x_out)
    predictions = Dense(units=16, activation="relu")(predictions)
    predictions = Dense(units=1, activation="sigmoid")(predictions)

    # Let's create the Keras model and prepare it for training
    model = Model(inputs=x_inp, outputs=predictions)
    model.compile(optimizer=Adam(0.005), loss=binary_crossentropy, metrics=["acc"])

    return model

# %%
epochs = 200  # maximum number of training epochs
# folds = 10  # the number of folds for k-fold cross validation
# n_repeats = 5  # the number of repeats for repeated k-fold cross validation

# %%
es = EarlyStopping(
    monitor="val_loss", min_delta=0, patience=25, restore_best_weights=True
)

# %%
# To train in folds
def train_fold(model, train_gen, test_gen, es, epochs):
    history = model.fit(
        train_gen, epochs=epochs, validation_data=test_gen, verbose=0, callbacks=[es],
    )
    # calculate performance on the test data and return along with history
    test_metrics = model.evaluate(test_gen, verbose=0)
    test_acc = test_metrics[model.metrics_names.index("acc")]

    return history, test_acc

# %%
# To train in folds
def get_generators(train_index, test_index, graph_labels, batch_size):
    train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )
    test_gen = generator.flow(
        test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )

    return train_gen, test_gen

# %%
# # To train in folds
# test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"Training and evaluating on fold {i+1} out of {folds * n_repeats}...")
#     train_gen, test_gen = get_generators(
#         train_index, test_index, graph_labels, batch_size=30
#     )

#     model = create_graph_classification_model(generator)

#     history, acc = train_fold(model, train_gen, test_gen, es, epochs)

#     test_accs.append(acc)

# %%
# To train in folds
test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
for i in range(50):
    print(f"Training and evaluating on fold {i+1}...")
    
    train_gen, test_gen = get_generators(
        train_index, test_index, graph_labels, batch_size=30
    )

    model = create_graph_classification_model(generator)

    history, acc = train_fold(model, train_gen, test_gen, es, epochs)

    test_accs.append(acc)
# Out:
# Training and evaluating on fold 1...
# Training and evaluating on fold 2...
# Training and evaluating on fold 3...
# Training and evaluating on fold 4...
# Training and evaluating on fold 5...
# Training and evaluating on fold 6...
# Training and evaluating on fold 7...
# Training and evaluating on fold 8...
# Training and evaluating on fold 9...
# Training and evaluating on fold 10...
# Training and evaluating on fold 11...
# Training and evaluating on fold 12...
# Training and evaluating on fold 13...
# Training and evaluating on fold 14...
# Training and evaluating on fold 15...
# Training and evaluating on fold 16...
# Training and evaluating on fold 17...
# Training and evaluating on fold 18...
# Training and evaluating on fold 19...
# Training and evaluating on fold 20...
# Training and evaluating on fold 21...
# Training and evaluating on fold 22...
# Training and evaluating on fold 23...
# Training and evaluating on fold 24...
# Training and evaluating on fold 25...
# Training and evaluating on fold 26...
# Training and evaluating on fold 27...
# Training and evaluating on fold 28...
# Training and evaluating on fold 29...
# Training and evaluating on fold 30...
# Training and evaluating on fold 31...
# Training and evaluating on fold 32...
# Training and evaluating on fold 33...
# Training and evaluating on fold 34...
# Training and evaluating on fold 35...
# Training and evaluating on fold 36...
# Training and evaluating on fold 37...
# Training and evaluating on fold 38...
# Training and evaluating on fold 39...
# Training and evaluating on fold 40...
# Training and evaluating on fold 41...
# Training and evaluating on fold 42...
# Training and evaluating on fold 43...
# Training and evaluating on fold 44...
# Training and evaluating on fold 45...
# Training and evaluating on fold 46...
# Training and evaluating on fold 47...
# Training and evaluating on fold 48...
# Training and evaluating on fold 49...
# Training and evaluating on fold 50...

# %%
# 1: Accuracy over all folds mean: 79.5% and std: 2.5%
# 2: Accuracy over all folds mean: 79.4% and std: 2.0%
# 3: Accuracy over all folds mean: 79.5% and std: 2.5%
# 4: Accuracy over all folds mean: 78.6% and std: 4.9%
# 5: Accuracy over all folds mean: 79.2% and std: 1.8%
# 6: Accuracy over all folds mean: 78.9% and std: 2.3%
# 7: Accuracy over all folds mean: 78.5% and std: 2.1%
# 8: Accuracy over all folds mean: 79.5% and std: 2.6%

# ----------------After setting random seed
# 1: Accuracy over all folds mean: 79.1% and std: 2.2%
# 2: Accuracy over all folds mean: 80.4% and std: 2.3%
# 3: Accuracy over all folds mean: 79.0% and std: 2.4%
# 4: Accuracy over all folds mean: 79.4% and std: 1.9%
# 5: Accuracy over all folds mean: 79.1% and std: 2.1%
# 6: Accuracy over all folds mean: 80.2% and std: 2.4%

# Sepsis
# 1: Accuracy over all folds mean: 83.4% and std: 2.2%
# 2: Accuracy over all folds mean: 82.2% and std: 5.1%

print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 78.9% and std: 2.1%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Second try
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 77.3% and std: 2.6%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"\ntrain_index: \n{train_index}\ntest_index: \n{test_index}\n")
#     break
# print(f"train: {len(train_index)}, test: {len(test_index)}")

# %%
train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)
test_gen = generator.flow(
    test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)

# %%
model_weighted = create_graph_classification_model(generator)

history = model_weighted.fit(
        train_gen, epochs=200, validation_data=test_gen, verbose=1, callbacks=[es])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 65ms/step - loss: 0.4357 - acc: 0.8561 - val_loss: 1.0024 - val_acc: 0.5000
# Epoch 2/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.3849 - acc: 0.8505 - val_loss: 0.8525 - val_acc: 0.5000
# Epoch 3/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.3468 - acc: 0.8505 - val_loss: 0.6412 - val_acc: 0.5000
# Epoch 4/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.3245 - acc: 0.8505 - val_loss: 0.6924 - val_acc: 0.5000
# Epoch 5/200
# 18/18 [==============================] - 1s 46ms/step - loss: 0.3225 - acc: 0.8674 - val_loss: 1.0016 - val_acc: 0.5000
# Epoch 6/200
# 18/18 [==============================] - 1s 52ms/step - loss: 0.3271 - acc: 0.8660 - val_loss: 0.8193 - val_acc: 0.5256
# Epoch 7/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.2875 - acc: 0.8858 - val_loss: 0.6751 - val_acc: 0.6410
# Epoch 8/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.2763 - acc: 0.8956 - val_loss: 0.9120 - val_acc: 0.6410
# Epoch 9/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2735 - acc: 0.9083 - val_loss: 0.7075 - val_acc: 0.7051
# Epoch 10/200
# 18/18 [==============================] - 1s 52ms/step - loss: 0.2538 - acc: 0.9055 - val_loss: 0.7557 - val_acc: 0.7051
# Epoch 11/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2607 - acc: 0.9097 - val_loss: 0.5693 - val_acc: 0.7308
# Epoch 12/200
# 18/18 [==============================] - 1s 46ms/step - loss: 0.2427 - acc: 0.9168 - val_loss: 0.6739 - val_acc: 0.7179
# Epoch 13/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2489 - acc: 0.9097 - val_loss: 0.6731 - val_acc: 0.7308
# Epoch 14/200
# 18/18 [==============================] - 1s 54ms/step - loss: 0.2423 - acc: 0.9154 - val_loss: 0.6892 - val_acc: 0.7308
# Epoch 15/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.2108 - acc: 0.9182 - val_loss: 0.6712 - val_acc: 0.7308
# Epoch 16/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2189 - acc: 0.9140 - val_loss: 0.4964 - val_acc: 0.7564
# Epoch 17/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2459 - acc: 0.9210 - val_loss: 0.4220 - val_acc: 0.7436
# Epoch 18/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2028 - acc: 0.9295 - val_loss: 0.6804 - val_acc: 0.7308
# Epoch 19/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.1929 - acc: 0.9337 - val_loss: 0.5348 - val_acc: 0.7436
# Epoch 20/200
# 18/18 [==============================] - 1s 54ms/step - loss: 0.2086 - acc: 0.9224 - val_loss: 0.6170 - val_acc: 0.7308
# Epoch 21/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2056 - acc: 0.9252 - val_loss: 0.7177 - val_acc: 0.7308
# Epoch 22/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.2104 - acc: 0.9323 - val_loss: 0.6680 - val_acc: 0.7308
# Epoch 23/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1893 - acc: 0.9337 - val_loss: 0.5349 - val_acc: 0.7436
# Epoch 24/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1983 - acc: 0.9210 - val_loss: 0.4698 - val_acc: 0.7436
# Epoch 25/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.1891 - acc: 0.9365 - val_loss: 0.5062 - val_acc: 0.7436
# Epoch 26/200
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1857 - acc: 0.9252 - val_loss: 0.6617 - val_acc: 0.7436
# Epoch 27/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2091 - acc: 0.9309 - val_loss: 0.5592 - val_acc: 0.7436
# Epoch 28/200
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1997 - acc: 0.9309 - val_loss: 0.5586 - val_acc: 0.7436
# Epoch 29/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.1954 - acc: 0.9295 - val_loss: 0.4385 - val_acc: 0.7821
# Epoch 30/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2123 - acc: 0.9281 - val_loss: 0.5874 - val_acc: 0.7436
# Epoch 31/200
# 18/18 [==============================] - 1s 36ms/step - loss: 0.1653 - acc: 0.9351 - val_loss: 0.7863 - val_acc: 0.7436
# Epoch 32/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.1866 - acc: 0.9309 - val_loss: 0.8133 - val_acc: 0.7436
# Epoch 33/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2092 - acc: 0.9210 - val_loss: 0.6797 - val_acc: 0.7308
# Epoch 34/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2184 - acc: 0.9210 - val_loss: 0.5364 - val_acc: 0.7436
# Epoch 35/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1951 - acc: 0.9323 - val_loss: 0.6809 - val_acc: 0.7436
# Epoch 36/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.1696 - acc: 0.9379 - val_loss: 0.6214 - val_acc: 0.7436
# Epoch 37/200
# 18/18 [==============================] - 1s 52ms/step - loss: 0.1819 - acc: 0.9351 - val_loss: 0.5393 - val_acc: 0.7564
# Epoch 38/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.1883 - acc: 0.9309 - val_loss: 0.4312 - val_acc: 0.7821
# Epoch 39/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.1874 - acc: 0.9379 - val_loss: 0.5837 - val_acc: 0.7436
# Epoch 40/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.1865 - acc: 0.9365 - val_loss: 0.6816 - val_acc: 0.7436
# Epoch 41/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1789 - acc: 0.9351 - val_loss: 0.4685 - val_acc: 0.7821
# Epoch 42/200
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1823 - acc: 0.9422 - val_loss: 0.4413 - val_acc: 0.7692

# %%
# calculate performance on the test data and return along with history
# Node features 128 node2vec, edge features all 1
test_metrics = model_weighted.evaluate(test_gen, verbose=1)
test_acc = test_metrics[model_weighted.metrics_names.index("acc")]
# Out:
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4220 - acc: 0.7436

# %%
print(test_metrics)
#test loss, test acc: [0.4488869309425354, 0.7692307829856873]
# 2nd time:[0.42735838890075684, 0.7820512652397156]
# 3 : [0.446189284324646, 0.7820512652397156]
print(test_acc)
# Out:
# [0.42195096611976624, 0.7435897588729858]
# 0.7435897588729858

# %%
print("Generate predictions for samples")
predictions = model_weighted.predict(test_gen, verbose=0)
print("predictions shape:", predictions.shape)
# predictions shape: (79, 1)
print(predictions)

# %%
print(test_gen.targets)
