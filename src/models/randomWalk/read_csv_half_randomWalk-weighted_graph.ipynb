# %% [markdown]
# ### Data extraction
# Extract data from MIMIC-III

# %%
import time
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Import pandas 
import pandas as pd 

start = time.time()
# reading csv file 
admissions_df = pd.read_csv("../../datasets/mmc-3/ADMISSIONS.csv")
noteevents_df = pd.read_csv("../../datasets/mmc-3/NOTEEVENTS.csv") 
end = time.time()
print(end - start)
# Out:
# /home/evan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning:
#
# Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
# 35.297778367996216

# %%
start = time.time()
# Left join of two dataframes
note_admiss_df_left = noteevents_df.merge(admissions_df, on='HADM_ID', how='left', indicator=True)
end = time.time()
print(end - start)
# Out:
# 4.591442108154297

# %%
note_admiss_df_left[['DIAGNOSIS', 'SUBJECT_ID_x', 'SUBJECT_ID_y','DESCRIPTION', 'CATEGORY']]
# Out:
#                                      DIAGNOSIS  SUBJECT_ID_x  SUBJECT_ID_y  \
# 0                      RT LOWER LOBE PNEUMONIA         22532       22532.0
# 1        CHRONIC OBSTRUCTIVE PULMONARY DISEASE         13702       13702.0
# 2                TRACHEALBRONCHEAL MALACEA/SDA         13702       13702.0
# 3                     ASTHMA;COPD EXACERBATION         13702       13702.0
# 4                           S/P FALL;TELEMETRY         26880       26880.0
# ...                                        ...           ...           ...
# 2083175                                NEWBORN         31097       31097.0
# 2083176                                NEWBORN         31097       31097.0
# 2083177                                NEWBORN         31097       31097.0
# 2083178                                NEWBORN         31097       31097.0
# 2083179                                NEWBORN         31097       31097.0
#
#         DESCRIPTION           CATEGORY
# 0            Report  Discharge summary
# 1            Report  Discharge summary
# 2            Report  Discharge summary
# 3            Report  Discharge summary
# 4            Report  Discharge summary
# ...             ...                ...
# 2083175      Report      Nursing/other
# 2083176      Report      Nursing/other
# 2083177      Report      Nursing/other
# 2083178      Report      Nursing/other
# 2083179      Report      Nursing/other
#
# [2083180 rows x 5 columns]

# %%
pneumonia_df = note_admiss_df_left.loc[note_admiss_df_left["DIAGNOSIS"] == 'PNEUMONIA', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]

# %%
#pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]
pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x','SUBJECT_ID_x','CHARTDATE','STORETIME','CATEGORY','DESCRIPTION','TEXT', 'DEATHTIME']]

# %%
pneumonia_alive_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.isnull()]
pneumonia_dead_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.notnull()]

# %%
pneumonia_dead_no_disch.shape
# Out:
# (11895, 8)

# %%
pneumonia_alive_no_disch.shape
# Out:
# (46134, 8)

# %%
pneumonia_alive_no_disch = pneumonia_alive_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])
pneumonia_dead_no_disch = pneumonia_dead_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])

# %%
# Number of patients
pneumonia_dead_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 252

# %%
# Number of patients
pneumonia_alive_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 1167

# %%
# import text handling tool
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from collections import Counter

import sys
import re
import csv
import os.path

# define constants
# RESULT_HEADER = "WORD, FREQUENCY\n"
MIN_SEQ_LEN = 4
USE_1_N_SEQ = 2


# words that do not have meaning (can be modified later)
USELESS_WORDS = ["a", "the", "he", "she", ",", ".", "?", "!", ":", ";", "+", "*", "**"\
                 "your", "you"]

# count up the frequency of every word in every disease file
stemmer = PorterStemmer()
# create set of words to ignore in text
stop_words = set(stopwords.words('english'))

for word in USELESS_WORDS:
    stop_words.add(word)

# %%
#----------
def count_notes_per_patient(disease_df):
    patient_id_to_num_notes = {}
    patient_id = -1
    note_counter = 0
            
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        patient_id_check = int(row['SUBJECT_ID_x'])
                
        if not patient_id == patient_id_check:
            patient_id_to_num_notes[patient_id] = note_counter
            note_counter = 1
        else:
            note_counter += 1
                    
        patient_id = patient_id_check
                
    patient_id_to_num_notes[patient_id] = note_counter
    del patient_id_to_num_notes[-1]
    return patient_id_to_num_notes

patient_id_to_num_notes = {}
patient_id_to_num_notes['pneumonia_dead'] = count_notes_per_patient(pneumonia_dead_no_disch)
patient_id_to_num_notes['pneumonia_alive'] = count_notes_per_patient(pneumonia_alive_no_disch)
# Out:
# 100%|██████████| 11895/11895 [00:01<00:00, 7245.87it/s]
# 100%|██████████| 46134/46134 [00:05<00:00, 9117.25it/s]

# %%
patient_id_to_num_notes
# Out:
# {'pneumonia_dead': {111: 12,
#   346: 25,
#   404: 3,
#   546: 6,
#   618: 16,
#   705: 15,
#   726: 48,
#   1039: 55,
#   1556: 37,
#   1872: 3,
#   1944: 56,
#   2286: 69,
#   2990: 166,
#   3055: 29,
#   3099: 13,
#   3201: 8,
#   3526: 7,
#   3773: 6,
#   3881: 20,
#   4122: 51,
#   4754: 101,
#   4811: 21,
#   5476: 1,
#   5494: 22,
#   5774: 104,
#   5786: 152,
#   5913: 1,
#   6133: 68,
#   6735: 13,
#   6745: 13,
#   6973: 36,
#   6981: 8,
#   7277: 66,
#   7310: 8,
#   7924: 9,
#   7977: 9,
#   9908: 11,
#   9984: 15,
#   10302: 100,
#   10510: 86,
#   10545: 10,
#   10642: 10,
#   11049: 14,
#   11209: 9,
#   11395: 41,
#   12530: 24,
#   12849: 50,
#   13098: 46,
#   13566: 23,
#   14125: 9,
#   14514: 96,
#   14965: 25,
#   15159: 15,
#   15251: 11,
#   15396: 17,
#   15566: 37,
#   15853: 45,
#   16275: 17,
#   16344: 27,
#   16622: 51,
#   16684: 29,
#   17122: 16,
#   17354: 5,
#   17802: 64,
#   17983: 65,
#   18094: 23,
#   18736: 35,
#   18768: 46,
#   18848: 205,
#   18971: 26,
#   19243: 25,
#   19323: 6,
#   19390: 21,
#   19463: 20,
#   19535: 59,
#   19754: 13,
#   19827: 22,
#   19833: 58,
#   19872: 10,
#   20006: 8,
#   20023: 9,
#   20190: 6,
#   21046: 101,
#   21094: 36,
#   21427: 10,
#   21502: 102,
#   21580: 52,
#   21676: 12,
#   21699: 7,
#   21979: 11,
#   22735: 15,
#   23660: 12,
#   23795: 78,
#   24181: 13,
#   24582: 37,
#   24725: 57,
#   24730: 19,
#   24854: 25,
#   25003: 182,
#   25046: 7,
#   25774: 61,
#   25975: 9,
#   26474: 89,
#   26578: 15,
#   26716: 41,
#   26774: 3,
#   26849: 33,
#   27005: 5,
#   27145: 24,
#   27421: 61,
#   27431: 5,
#   27496: 7,
#   27504: 72,
#   27639: 221,
#   28004: 13,
#   28072: 34,
#   28178: 202,
#   28427: 6,
#   28498: 25,
#   28726: 34,
#   28750: 19,
#   28906: 32,
#   28907: 13,
#   28933: 394,
#   29105: 468,
#   29588: 72,
#   29647: 26,
#   29872: 225,
#   30476: 174,
#   30549: 12,
#   30614: 8,
#   30699: 14,
#   30786: 9,
#   30941: 110,
#   31030: 168,
#   31134: 24,
#   31139: 9,
#   31451: 48,
#   31556: 57,
#   31690: 18,
#   31692: 35,
#   32050: 34,
#   32326: 24,
#   32618: 42,
#   41546: 25,
#   43937: 6,
#   44851: 274,
#   45381: 16,
#   46589: 26,
#   46763: 6,
#   47045: 9,
#   48632: 147,
#   49079: 20,
#   49683: 3,
#   49922: 13,
#   50093: 8,
#   50231: 3,
#   50556: 216,
#   50859: 537,
#   51914: 313,
#   52010: 12,
#   53105: 115,
#   53399: 78,
#   54193: 85,
#   54401: 14,
#   54408: 2,
#   54739: 75,
#   54946: 7,
#   55400: 5,
#   55570: 14,
#   55887: 37,
#   55944: 34,
#   55987: 20,
#   56390: 19,
#   56648: 8,
#   56854: 170,
#   57091: 88,
#   57102: 35,
#   58702: 479,
#   59260: 11,
#   59437: 26,
#   60849: 2,
#   60868: 6,
#   61652: 7,
#   61667: 30,
#   63039: 8,
#   65513: 8,
#   68044: 40,
#   68095: 23,
#   68184: 5,
#   68308: 8,
#   68860: 14,
#   69719: 13,
#   69745: 25,
#   69776: 17,
#   70226: 8,
#   70447: 9,
#   72930: 11,
#   73811: 9,
#   73888: 109,
#   74316: 2,
#   74444: 81,
#   74686: 75,
#   75824: 10,
#   76282: 21,
#   76827: 2,
#   77382: 10,
#   78241: 3,
#   78388: 14,
#   79008: 27,
#   79055: 21,
#   79222: 18,
#   79877: 156,
#   80637: 148,
#   80678: 9,
#   80737: 46,
#   80805: 79,
#   81437: 27,
#   82393: 5,
#   82769: 85,
#   83932: 2,
#   84474: 34,
#   85160: 8,
#   85258: 52,
#   85404: 11,
#   85797: 9,
#   86007: 35,
#   86394: 4,
#   86684: 11,
#   86832: 67,
#   86863: 8,
#   86872: 326,
#   88193: 16,
#   88660: 11,
#   90256: 18,
#   91350: 19,
#   92074: 28,
#   92278: 52,
#   92331: 42,
#   93422: 7,
#   94341: 2,
#   94997: 9,
#   95280: 23,
#   95803: 18,
#   95830: 33,
#   95933: 56,
#   96699: 85,
#   97181: 30,
#   97795: 60,
#   98009: 33,
#   98299: 29,
#   98597: 2},
#  'pneumonia_alive': {68: 18,
#   85: 8,
#   94: 100,
#   165: 2,
#   211: 24,
#   224: 8,
#   231: 75,
#   283: 131,
#   357: 17,
#   368: 45,
#   370: 13,
#   384: 26,
#   426: 10,
#   509: 34,
#   514: 7,
#   596: 23,
#   674: 16,
#   707: 29,
#   711: 537,
#   770: 83,
#   773: 74,
#   899: 17,
#   1096: 17,
#   1135: 32,
#   1163: 12,
#   1174: 42,
#   1180: 5,
#   1283: 3,
#   1332: 66,
#   1339: 134,
#   1546: 21,
#   1568: 22,
#   1601: 12,
#   1606: 13,
#   1642: 4,
#   1660: 23,
#   1895: 22,
#   1923: 23,
#   2029: 175,
#   2090: 179,
#   2098: 26,
#   2128: 31,
#   2170: 9,
#   2187: 30,
#   2208: 139,
#   2337: 8,
#   2378: 57,
#   2386: 18,
#   2452: 22,
#   2508: 22,
#   2561: 126,
#   2585: 9,
#   2589: 92,
#   2590: 5,
#   2628: 218,
#   2658: 16,
#   2732: 12,
#   2784: 23,
#   2823: 21,
#   3070: 8,
#   3100: 70,
#   3154: 22,
#   3220: 28,
#   3277: 35,
#   3347: 15,
#   3359: 15,
#   3516: 11,
#   3602: 18,
#   3623: 116,
#   3641: 57,
#   3676: 49,
#   3830: 80,
#   3860: 203,
#   3862: 22,
#   3865: 8,
#   3895: 6,
#   3935: 44,
#   3952: 20,
#   3975: 34,
#   4109: 9,
#   4155: 23,
#   4236: 14,
#   4275: 45,
#   4316: 13,
#   4317: 106,
#   4328: 23,
#   4388: 14,
#   4454: 5,
#   4467: 12,
#   4489: 21,
#   4494: 18,
#   4584: 39,
#   4588: 80,
#   4641: 23,
#   4694: 19,
#   4804: 6,
#   5030: 49,
#   5145: 9,
#   5244: 113,
#   5264: 115,
#   5360: 19,
#   5434: 24,
#   5476: 36,
#   5516: 31,
#   5536: 21,
#   5564: 30,
#   5579: 14,
#   5609: 39,
#   5619: 25,
#   5631: 9,
#   5681: 9,
#   5691: 12,
#   5727: 41,
#   5761: 85,
#   5819: 19,
#   5904: 16,
#   5937: 61,
#   6038: 4,
#   6143: 15,
#   6176: 5,
#   6183: 17,
#   6206: 7,
#   6279: 20,
#   6378: 112,
#   6398: 11,
#   6557: 16,
#   6603: 15,
#   6884: 43,
#   6901: 8,
#   6915: 190,
#   7107: 230,
#   7169: 9,
#   7271: 117,
#   7356: 12,
#   7363: 284,
#   7492: 58,
#   7569: 32,
#   7603: 39,
#   7666: 9,
#   7700: 68,
#   7787: 18,
#   7849: 96,
#   7936: 3,
#   8070: 69,
#   8312: 29,
#   8337: 22,
#   8366: 25,
#   8471: 15,
#   8512: 16,
#   8515: 21,
#   8532: 9,
#   8556: 71,
#   8803: 4,
#   8895: 10,
#   8900: 11,
#   9124: 18,
#   9128: 2,
#   9253: 76,
#   9304: 12,
#   9332: 7,
#   9457: 6,
#   9505: 2,
#   9518: 80,
#   9544: 228,
#   9727: 37,
#   9736: 19,
#   9859: 12,
#   9871: 17,
#   9957: 15,
#   9973: 59,
#   10057: 144,
#   10207: 36,
#   10299: 167,
#   10304: 8,
#   10377: 125,
#   10502: 9,
#   10581: 11,
#   10589: 18,
#   10626: 72,
#   10635: 6,
#   10666: 84,
#   10675: 13,
#   10761: 9,
#   10830: 14,
#   10848: 16,
#   10950: 23,
#   11003: 63,
#   11018: 24,
#   11061: 11,
#   11065: 40,
#   11197: 14,
#   11236: 58,
#   11247: 6,
#   11275: 26,
#   11313: 9,
#   11320: 66,
#   11421: 37,
#   11446: 13,
#   11593: 19,
#   11616: 64,
#   11671: 14,
#   11702: 7,
#   11708: 44,
#   11747: 20,
#   11762: 10,
#   11829: 25,
#   11850: 23,
#   11860: 11,
#   11932: 18,
#   11989: 17,
#   12028: 221,
#   12140: 36,
#   12177: 53,
#   12183: 26,
#   12274: 9,
#   12312: 13,
#   12380: 45,
#   12508: 136,
#   12567: 61,
#   12585: 4,
#   12629: 43,
#   12633: 11,
#   12799: 77,
#   12803: 21,
#   12824: 21,
#   13123: 10,
#   13329: 22,
#   13330: 13,
#   13503: 15,
#   13546: 20,
#   13577: 7,
#   13593: 20,
#   13615: 10,
#   13627: 31,
#   13664: 120,
#   13728: 13,
#   13748: 21,
#   13864: 5,
#   13881: 2,
#   14035: 12,
#   14144: 24,
#   14172: 9,
#   14193: 8,
#   14256: 26,
#   14269: 21,
#   14309: 13,
#   14342: 20,
#   14385: 14,
#   14507: 9,
#   14520: 56,
#   14705: 17,
#   14805: 16,
#   14855: 96,
#   14975: 23,
#   15046: 86,
#   15054: 33,
#   15301: 5,
#   15347: 4,
#   15361: 15,
#   15472: 13,
#   15590: 85,
#   15716: 323,
#   15852: 15,
#   15875: 192,
#   16038: 89,
#   16053: 17,
#   16076: 397,
#   16102: 6,
#   16129: 22,
#   16147: 7,
#   16216: 17,
#   16275: 90,
#   16318: 12,
#   16367: 47,
#   16384: 48,
#   16409: 40,
#   16412: 8,
#   16438: 28,
#   16468: 15,
#   16469: 20,
#   16479: 7,
#   16492: 6,
#   16554: 19,
#   16560: 8,
#   16685: 1,
#   16733: 14,
#   16755: 24,
#   16800: 12,
#   16802: 27,
#   16850: 14,
#   16975: 186,
#   16992: 42,
#   17107: 6,
#   17149: 17,
#   17150: 23,
#   17250: 28,
#   17260: 10,
#   17276: 10,
#   17539: 24,
#   17547: 9,
#   17617: 4,
#   17631: 19,
#   17664: 24,
#   17722: 8,
#   17764: 3,
#   17795: 215,
#   17843: 37,
#   17882: 6,
#   17903: 7,
#   17906: 88,
#   18082: 22,
#   18123: 146,
#   18233: 8,
#   18250: 2,
#   18281: 61,
#   18320: 207,
#   18353: 16,
#   18365: 10,
#   18459: 33,
#   18637: 35,
#   18673: 38,
#   18681: 10,
#   18737: 7,
#   18999: 40,
#   19029: 4,
#   19036: 12,
#   19164: 20,
#   19463: 14,
#   19569: 4,
#   19653: 30,
#   19698: 79,
#   19793: 37,
#   19803: 9,
#   19833: 77,
#   19851: 83,
#   19859: 14,
#   19940: 9,
#   20061: 7,
#   20086: 85,
#   20133: 121,
#   20181: 204,
#   20187: 25,
#   20263: 6,
#   20265: 7,
#   20289: 63,
#   20381: 10,
#   20425: 103,
#   20528: 37,
#   20580: 1,
#   20598: 31,
#   20600: 16,
#   20624: 32,
#   20643: 20,
#   20804: 25,
#   20899: 17,
#   20951: 8,
#   20979: 26,
#   21037: 21,
#   21056: 9,
#   21093: 60,
#   21255: 3,
#   21269: 279,
#   21277: 23,
#   21301: 16,
#   21350: 18,
#   21548: 7,
#   21581: 11,
#   21737: 7,
#   21745: 5,
#   21764: 7,
#   22019: 2,
#   22180: 5,
#   22192: 5,
#   22287: 10,
#   22432: 6,
#   22450: 11,
#   22520: 63,
#   22534: 4,
#   22580: 10,
#   22624: 43,
#   22667: 72,
#   22684: 14,
#   22706: 8,
#   22754: 44,
#   22855: 47,
#   22921: 2,
#   23028: 22,
#   23109: 2,
#   23131: 49,
#   23161: 29,
#   23215: 9,
#   23318: 15,
#   23418: 22,
#   23423: 11,
#   23451: 26,
#   23568: 8,
#   23657: 34,
#   23734: 15,
#   23763: 21,
#   23847: 9,
#   24099: 2,
#   24170: 2,
#   24178: 209,
#   24276: 82,
#   24344: 290,
#   24483: 7,
#   24535: 23,
#   24562: 10,
#   24569: 20,
#   24622: 1,
#   24687: 45,
#   24807: 41,
#   24847: 12,
#   24868: 57,
#   24903: 45,
#   25001: 25,
#   25016: 78,
#   25038: 66,
#   25097: 42,
#   25117: 38,
#   25225: 17,
#   25256: 30,
#   25295: 59,
#   25326: 17,
#   25373: 158,
#   25406: 5,
#   25515: 18,
#   25526: 86,
#   25579: 27,
#   25591: 61,
#   25671: 11,
#   25750: 107,
#   25775: 38,
#   25844: 22,
#   25860: 9,
#   25861: 16,
#   25889: 20,
#   25941: 86,
#   26036: 11,
#   26040: 79,
#   26052: 3,
#   26080: 5,
#   26097: 65,
#   26118: 60,
#   26311: 28,
#   26391: 64,
#   26398: 14,
#   26469: 52,
#   26542: 55,
#   26601: 58,
#   26638: 155,
#   26727: 10,
#   26797: 8,
#   26869: 11,
#   26884: 5,
#   26887: 4,
#   26956: 23,
#   27003: 18,
#   27036: 10,
#   27043: 30,
#   27047: 41,
#   27049: 14,
#   27089: 24,
#   27121: 89,
#   27143: 135,
#   27172: 9,
#   27179: 118,
#   27194: 60,
#   27269: 19,
#   27367: 84,
#   27371: 17,
#   27431: 33,
#   27486: 2,
#   27576: 84,
#   27597: 60,
#   27600: 28,
#   27677: 11,
#   27726: 59,
#   27729: 70,
#   27752: 11,
#   27800: 12,
#   27809: 18,
#   27823: 31,
#   27879: 13,
#   27886: 30,
#   27999: 25,
#   28050: 20,
#   28055: 4,
#   28073: 74,
#   28093: 21,
#   28103: 16,
#   28164: 159,
#   28173: 124,
#   28230: 23,
#   28291: 36,
#   28298: 31,
#   28356: 10,
#   28527: 46,
#   28530: 24,
#   28642: 2,
#   28668: 3,
#   28671: 33,
#   28689: 5,
#   28717: 23,
#   28729: 73,
#   28742: 7,
#   28758: 94,
#   28827: 12,
#   28843: 1,
#   28884: 12,
#   28932: 24,
#   28935: 4,
#   28939: 4,
#   28973: 152,
#   29007: 9,
#   29043: 12,
#   29093: 5,
#   29096: 21,
#   29102: 18,
#   29129: 15,
#   29137: 8,
#   29139: 17,
#   29141: 27,
#   29219: 19,
#   29240: 10,
#   29274: 17,
#   29350: 18,
#   29377: 80,
#   29379: 21,
#   29456: 22,
#   29478: 32,
#   29501: 6,
#   29503: 11,
#   29504: 18,
#   29513: 65,
#   29528: 5,
#   29556: 5,
#   29566: 17,
#   29619: 18,
#   29638: 15,
#   29639: 26,
#   29660: 9,
#   29703: 12,
#   29866: 12,
#   29872: 14,
#   29913: 11,
#   29919: 24,
#   29927: 63,
#   29965: 26,
#   29972: 7,
#   30010: 7,
#   30015: 36,
#   30139: 529,
#   30208: 18,
#   30227: 35,
#   30287: 23,
#   30299: 1,
#   30301: 117,
#   30316: 17,
#   30365: 47,
#   30490: 17,
#   30501: 10,
#   30505: 33,
#   30561: 6,
#   30575: 6,
#   30599: 24,
#   30631: 11,
#   30663: 24,
#   30696: 54,
#   30786: 11,
#   30798: 14,
#   30860: 28,
#   31003: 45,
#   31183: 129,
#   31216: 80,
#   31221: 17,
#   31262: 28,
#   31298: 13,
#   31332: 59,
#   31361: 20,
#   31442: 32,
#   31470: 17,
#   31516: 74,
#   31528: 60,
#   31544: 11,
#   31580: 34,
#   31585: 39,
#   31610: 17,
#   31660: 3,
#   31664: 45,
#   31692: 23,
#   31723: 17,
#   31813: 234,
#   31942: 102,
#   31986: 41,
#   32018: 145,
#   32061: 11,
#   32106: 18,
#   32135: 12,
#   32161: 25,
#   32181: 8,
#   32183: 27,
#   32193: 16,
#   32268: 6,
#   32286: 117,
#   32355: 6,
#   32367: 42,
#   32394: 6,
#   32414: 485,
#   32436: 271,
#   32583: 5,
#   32605: 19,
#   32639: 12,
#   32740: 48,
#   32746: 11,
#   32773: 112,
#   32790: 103,
#   40059: 11,
#   40124: 68,
#   40246: 20,
#   40370: 11,
#   40442: 107,
#   40456: 43,
#   40576: 48,
#   40631: 4,
#   40911: 35,
#   41192: 45,
#   41373: 28,
#   41434: 10,
#   41446: 8,
#   41890: 7,
#   41958: 5,
#   41962: 10,
#   41976: 177,
#   42009: 30,
#   42035: 49,
#   42054: 18,
#   42194: 1,
#   42346: 30,
#   42458: 9,
#   42515: 38,
#   42572: 17,
#   42715: 21,
#   42794: 6,
#   42924: 3,
#   43067: 90,
#   43074: 18,
#   43112: 394,
#   43128: 1,
#   43147: 150,
#   43305: 48,
#   43323: 15,
#   43937: 4,
#   43943: 6,
#   43959: 3,
#   44146: 16,
#   44206: 5,
#   44214: 30,
#   44326: 8,
#   44437: 12,
#   44530: 2,
#   44534: 37,
#   44741: 8,
#   44787: 7,
#   44829: 55,
#   44841: 19,
#   44848: 2,
#   45193: 11,
#   45280: 9,
#   45435: 7,
#   46011: 61,
#   46335: 49,
#   46366: 42,
#   46415: 53,
#   46521: 14,
#   46728: 34,
#   46926: 1,
#   46961: 1,
#   47216: 17,
#   47219: 67,
#   47407: 2,
#   47467: 6,
#   47670: 7,
#   47747: 12,
#   47852: 95,
#   47930: 5,
#   48058: 4,
#   48143: 6,
#   48297: 11,
#   48340: 7,
#   48660: 343,
#   48687: 15,
#   48750: 8,
#   48812: 36,
#   48837: 14,
#   48929: 7,
#   49292: 18,
#   49510: 31,
#   49558: 347,
#   49623: 9,
#   49747: 7,
#   49764: 10,
#   49963: 4,
#   50007: 4,
#   50041: 10,
#   50093: 6,
#   50257: 11,
#   50294: 20,
#   50409: 75,
#   50762: 8,
#   50772: 17,
#   50807: 21,
#   50828: 126,
#   50911: 81,
#   50998: 29,
#   51195: 29,
#   51237: 11,
#   51401: 33,
#   51418: 68,
#   51497: 3,
#   51545: 97,
#   51601: 5,
#   51607: 5,
#   51669: 10,
#   51933: 5,
#   52011: 8,
#   52054: 1,
#   52172: 13,
#   52191: 46,
#   52307: 5,
#   52452: 5,
#   52606: 54,
#   52622: 5,
#   52898: 6,
#   52957: 52,
#   53119: 7,
#   53160: 13,
#   53173: 14,
#   53534: 9,
#   53650: 15,
#   53743: 151,
#   53749: 6,
#   53847: 14,
#   54172: 6,
#   54197: 13,
#   54305: 8,
#   54514: 116,
#   54709: 9,
#   54741: 5,
#   54832: 7,
#   54922: 2,
#   55059: 17,
#   55074: 7,
#   55188: 9,
#   55571: 212,
#   55700: 4,
#   55753: 37,
#   55841: 14,
#   55920: 17,
#   56027: 7,
#   56229: 31,
#   56440: 9,
#   56490: 12,
#   56621: 11,
#   56635: 2,
#   56772: 31,
#   56798: 4,
#   56867: 16,
#   56874: 51,
#   57050: 205,
#   57081: 32,
#   57157: 5,
#   57277: 19,
#   57290: 15,
#   57449: 17,
#   57788: 36,
#   57795: 7,
#   57889: 105,
#   58105: 49,
#   58242: 6,
#   58264: 7,
#   58286: 20,
#   58416: 3,
#   58433: 51,
#   58522: 9,
#   58580: 5,
#   58610: 13,
#   58631: 15,
#   58732: 5,
#   58794: 32,
#   58810: 10,
#   58955: 6,
#   59275: 1,
#   59278: 17,
#   59411: 6,
#   59496: 75,
#   59765: 300,
#   59789: 10,
#   59801: 2,
#   59822: 14,
#   59903: 483,
#   59943: 121,
#   60003: 9,
#   60050: 4,
#   60130: 44,
#   60674: 10,
#   60685: 4,
#   60958: 8,
#   60977: 9,
#   61005: 10,
#   61084: 216,
#   61195: 9,
#   61259: 83,
#   61331: 4,
#   61630: 19,
#   61738: 6,
#   61886: 6,
#   62231: 4,
#   62239: 5,
#   62284: 6,
#   62402: 56,
#   62641: 8,
#   62733: 9,
#   62858: 120,
#   63145: 25,
#   63327: 16,
#   63351: 10,
#   63362: 7,
#   63430: 56,
#   63499: 32,
#   63560: 25,
#   63943: 31,
#   63968: 10,
#   64160: 4,
#   64232: 28,
#   64249: 7,
#   64715: 17,
#   65004: 11,
#   65027: 1,
#   65033: 2,
#   65164: 4,
#   65361: 20,
#   65435: 40,
#   65449: 6,
#   65515: 5,
#   65582: 576,
#   65594: 9,
#   65692: 25,
#   65710: 18,
#   65837: 47,
#   66002: 636,
#   66009: 373,
#   66206: 12,
#   66412: 5,
#   66492: 1,
#   66549: 36,
#   66556: 20,
#   66671: 32,
#   66739: 1,
#   66753: 8,
#   66823: 21,
#   67053: 238,
#   67111: 16,
#   67117: 19,
#   67408: 15,
#   67446: 8,
#   67796: 7,
#   67844: 7,
#   67887: 13,
#   68059: 3,
#   68315: 3,
#   68591: 7,
#   68791: 13,
#   68836: 7,
#   68839: 21,
#   68905: 3,
#   68944: 39,
#   68962: 1,
#   69098: 12,
#   69158: 13,
#   69250: 4,
#   69296: 13,
#   69359: 26,
#   69380: 265,
#   69483: 26,
#   69546: 64,
#   69556: 11,
#   69578: 7,
#   69673: 6,
#   69776: 53,
#   69799: 6,
#   69932: 6,
#   70285: 2,
#   70466: 18,
#   70476: 22,
#   70492: 10,
#   70563: 3,
#   70645: 29,
#   70682: 48,
#   70728: 12,
#   71107: 9,
#   71108: 220,
#   71220: 45,
#   71336: 5,
#   71377: 39,
#   71915: 6,
#   71943: 4,
#   71983: 3,
#   72229: 189,
#   72230: 154,
#   72233: 2,
#   72378: 7,
#   72532: 6,
#   72714: 4,
#   72751: 35,
#   73043: 3,
#   73107: 479,
#   73129: 105,
#   73388: 37,
#   73389: 87,
#   73479: 3,
#   73686: 4,
#   73713: 458,
#   73770: 9,
#   73808: 49,
#   73899: 2,
#   73941: 7,
#   74016: 8,
#   74253: 388,
#   74505: 32,
#   74562: 98,
#   74640: 7,
#   74654: 7,
#   75047: 3,
#   75107: 124,
#   75200: 87,
#   75387: 14,
#   75446: 34,
#   75609: 5,
#   75640: 45,
#   75741: 8,
#   75782: 90,
#   75806: 3,
#   75983: 9,
#   76021: 39,
#   76056: 1,
#   76074: 31,
#   76141: 4,
#   76178: 22,
#   76437: 5,
#   76446: 18,
#   76476: 3,
#   76797: 6,
#   76915: 8,
#   76993: 13,
#   77019: 8,
#   77128: 9,
#   77177: 14,
#   77237: 198,
#   77279: 2,
#   77434: 18,
#   77453: 2,
#   77469: 31,
#   77676: 4,
#   77690: 19,
#   77697: 10,
#   77816: 8,
#   77947: 11,
#   78017: 2,
#   78086: 110,
#   78565: 78,
#   78705: 3,
#   78707: 16,
#   78859: 5,
#   78914: 13,
#   79079: 18,
#   79090: 16,
#   79115: 12,
#   79292: 15,
#   80045: 6,
#   80106: 5,
#   80218: 13,
#   80430: 10,
#   80722: 3,
#   80813: 11,
#   80825: 3,
#   81114: 58,
#   81223: 39,
#   81233: 22,
#   81436: 9,
#   81745: 28,
#   81840: 25,
#   81960: 8,
#   81992: 11,
#   82100: 74,
#   82104: 2,
#   82150: 84,
#   82202: 28,
#   82211: 647,
#   82309: 9,
#   ...}}

# %%
print(len(patient_id_to_num_notes['pneumonia_dead']))
print(len(patient_id_to_num_notes['pneumonia_alive']))
# Out:
# 252
# 1167

# %%
pneumonia_dead_no_disch.loc[pneumonia_dead_no_disch["SUBJECT_ID_x"] == 111, ['ROW_ID_x','SUBJECT_ID_x','DESCRIPTION','TEXT', 'DEATHTIME']]
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 70391       70124           111
# 142529     151749           111
# 142097     151750           111
# 142303     151751           111
# 380576     375732           111
# 380109     375744           111
# 379907     375749           111
# 379806     375753           111
# 379909     375760           111
# 1066971   1079317           111
# 1065833   1079339           111
# 1067121   1079351           111
#
#                                                DESCRIPTION  \
# 70391                                               Report
# 142529                                              Report
# 142097                                              Report
# 142303                                              Report
# 380576                   Physician Resident Admission Note
# 380109                                      ICU Event Note
# 379907   Physician Resident/Attending Admission Note - ...
# 379806                          Social Work Admission Note
# 379909                                      ICU Event Note
# 1066971                                CHEST (PORTABLE AP)
# 1065833                                CHEST (PORTABLE AP)
# 1067121                         CHEST PORT. LINE PLACEMENT
#
#                                                       TEXT  \
# 70391    PATIENT/TEST INFORMATION:\nIndication: s/p PEA...
# 142529   Compared to the previous tracing QRS voltage i...
# 142097   Normal sinus rhythm, rate 80.  Biatrial abnorm...
# 142303   Normal sinus rhythm.  Q waves in leads V1-V2 c...
# 380576   Chief Complaint:  respiratory distress\n   HPI...
# 380109   Clinician:  Nurse\n   Pt admitted from the ED ...
# 379907   Chief Complaint:  respiratory distress\n   HPI...
# 379806   Social Work Initial Note:\n   Family Informati...
# 379909   TITLE:\n   Clinician:  Resident\n   Patient ex...
# 1066971  [**2144-7-1**] 2:43 AM\n CHEST (PORTABLE AP)  ...
# 1065833  [**2144-7-1**] 7:27 AM\n CHEST (PORTABLE AP); ...
# 1067121  [**2144-7-1**] 9:01 AM\n CHEST PORT. LINE PLAC...
#
#                    DEATHTIME
# 70391    2144-07-01 14:55:00
# 142529   2144-07-01 14:55:00
# 142097   2144-07-01 14:55:00
# 142303   2144-07-01 14:55:00
# 380576   2144-07-01 14:55:00
# 380109   2144-07-01 14:55:00
# 379907   2144-07-01 14:55:00
# 379806   2144-07-01 14:55:00
# 379909   2144-07-01 14:55:00
# 1066971  2144-07-01 14:55:00
# 1065833  2144-07-01 14:55:00
# 1067121  2144-07-01 14:55:00

# %%
def count_words_per_patient(disease_df, patient_id_to_num_notes):
    note_appearance_counter = {}
    number_of_patients = 0 # number of patients
    note_counter = 0

# -----------
    patient_id = -1
    word_set = set()
    note_event_counter = 0

    # Iterate through each note
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):

        
        patient_id_check = int(row['SUBJECT_ID_x'])
    
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check:
            number_of_patients += 1
            note_event_counter = 0
        
            for word in word_set:
                if word in note_appearance_counter:
                    note_appearance_counter[word] += 1
                else:
                    note_appearance_counter[word] = 1

        
            # reset word_set
            word_set = set()
        
        # update patient id
        patient_id = patient_id_check

            
        if patient_id_to_num_notes[patient_id_check] <= MIN_SEQ_LEN:
            continue
            
        if note_event_counter < patient_id_to_num_notes[patient_id] // USE_1_N_SEQ:
            note_event_counter += 1
            continue
                
        note_counter += 1
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        tokenized_note = word_tokenize(note)
        
        
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())
            if not stemmed_word in stop_words:
                word_set.add(stemmed_word)
    
    print(str(note_counter) + " note events")
    print("finished counting frequent words for patients!")
#     return note_counter, note_appearance_counter
    return number_of_patients, note_appearance_counter

# variable dictionaries
number_of_notes = {}
note_appearance_counter = {}

number_of_notes['pneumonia_dead'], note_appearance_counter['pneumonia_dead'] = count_words_per_patient(pneumonia_dead_no_disch, patient_id_to_num_notes['pneumonia_dead'])
number_of_notes['pneumonia_alive'], note_appearance_counter['pneumonia_alive'] = count_words_per_patient(pneumonia_alive_no_disch, patient_id_to_num_notes['pneumonia_alive'])
# Out:
# 100%|██████████| 11895/11895 [00:44<00:00, 266.46it/s]
#   0%|          | 24/46134 [00:00<03:25, 224.15it/s]
# 5989 note events
# finished counting frequent words for patients!
# 100%|██████████| 46134/46134 [02:46<00:00, 276.38it/s]
# 23172 note events
# finished counting frequent words for patients!

# %%
number_of_notes
# Out:
# {'pneumonia_dead': 252, 'pneumonia_alive': 1167}

# %%
print(note_appearance_counter)
# Out:
# {'pneumonia_dead': {'amylas': 17, 'intact': 103, 'stool': 150, 'arf': 34, 'time': 188, 'ha': 212, 'patient': 205, '(': 229, 'father': 16, 'mmhg': 71, 'upper': 162, 'sbp': 114, 'mid': 138, 'daughter': 84, 'yo': 75, 'portion': 101, 'min': 142, 'meq': 92, 'sign': 110, 'failur': 141, 'ventilatori': 63, 'termin': 88, 'funer': 16, 'intub': 147, 'inh': 3, 'veteran': 1, 'suffer': 13, 'fen': 44, 'dvt': 79, 'extrem': 141, 'fio': 119, 'etiolog': 57, 'p': 193, 'acidosi': 70, 'wean': 118, 'logist': 2, 'sr': 94, 'ceftriaxon': 24, 'situat': 29, 'develop': 87, 'urin': 165, 'cardiomediastin': 48, 'hct': 122, 'med': 141, 'cardiac': 156, 'record': 46, 'tf': 110, 'hour': 154, 'set': 141, 'team': 141, 'ye': 42, 'saw': 64, 'start': 154, '[': 80, 'radiolog': 68, 'repres': 91, 'f': 111, 'report': 205, 'ap': 175, 'show': 131, 'mandat': 6, 'poor': 134, 'admit': 194, 'clip': 175, 'hpi': 58, 'organomegali': 4, 'onli': 153, 'gener': 124, 'attend': 94, 'recent': 129, 'infiltr': 112, 'concern': 114, 'epi': 11, 'sinu': 139, 'assist': 81, 'tip': 126, 'hypercapnia': 4, 'commun': 88, 'sclera': 23, 'ro': 63, 'anoth': 58, 'impress': 176, 'present': 189, 'resid': 111, 'plan': 161, 'caucasian': 2, 'etho': 2, 'arrang': 21, 'hl': 5, 'post': 131, 'ventil': 129, 'disconnect': 2, 'fix': 29, 'sever': 172, 'meal': 10, 'copd': 45, 'hyperinfl': 5, 'heart': 157, 'heent': 34, 'emphas': 19, 'jugular': 68, 'tender': 82, 'pressor': 87, 'got': 28, 'sw': 33, 'regular': 66, 'could': 111, 'question': 128, 'dic': 20, 'tube': 161, 'mosf': 3, 'known': 85, 'sat': 167, 'comparison': 166, 'propofol': 31, 'gap': 11, 'methylpr': 5, 'normal': 164, 'thi': 230, 'decid': 61, 'loss': 52, 'lipas': 16, 'critic': 66, 'final': 196, 'protocol': 57, 'licsw': 11, 'arrest': 27, 'state': 94, 'receiv': 151, 'flowsheet': 113, 'code': 135, 'grief': 2, 'abnorm': 102, 'product': 99, 'mass': 65, 'angl': 28, 'cmh': 51, 'md': 134, 'prior': 186, 'alt': 53, 'brother': 29, 'pedal': 41, 'friend': 32, 'blocker': 33, 'list': 25, 'home': 99, 'seem': 69, 'band': 44, 'park': 4, 'hcp': 52, 'underli': 79, 'serial': 23, 'bs': 138, 'rapid': 61, 'design': 10, 'provid': 114, 'includ': 113, 'review': 135, 'bradi': 12, 'sodium': 63, 'q': 136, 'feel': 52, 'would': 127, 'member': 57, 'rel': 59, 'dextros': 11, 'niec': 13, 'aortic': 68, 'issu': 84, 'addit': 117, 'dr': 150, 'notabl': 38, 'laundri': 1, 'chang': 222, 'hypertens': 82, 'experienc': 17, "c'ed": 12, 'paralyt': 16, 'differ': 81, 'level': 148, 'boot': 52, 'clergi': 16, 'depress': 51, 'check': 116, 'addendum': 98, 'warfarin': 5, 'pneumoboot': 25, 'attempt': 119, 'phenylephrin': 16, 'glucos': 82, 'inflammatori': 22, 'restrict': 24, 'tobacco': 15, 'spoke': 86, 'malign': 32, 'rij': 35, 'exchang': 20, 'section': 56, 'neck': 50, 'ill': 73, 'growth': 28, 'prepar': 21, 'ga': 70, 'recommend': 82, 'arch': 15, 'subsequ': 50, 'hypercapn': 6, 'continu': 176, 'short': 86, 'compar': 163, 'superimpos': 56, 'simultan': 2, 'nc': 62, 'cvp': 66, 'adjust': 59, 'htn': 50, 'recruit': 14, 'ptt': 80, 'electrolyt': 43, 'region': 80, 'tachycardia': 94, 'bicarb': 28, 'cool': 67, 'wave': 81, 'along': 46, 'around': 76, 'albuterol': 58, 'pmh': 78, 'femal': 61, 'artic': 2, 'last': 148, 'edema': 182, 'trend': 68, 'speak': 65, '#': 211, 'comment': 93, 'express': 42, 'spontan': 91, 'distant': 27, 'pm': 197, 'signific': 121, 'infus': 111, 'vap': 72, 'emphysema': 28, 'earli': 73, 'bed': 103, 'still': 115, 'mottl': 15, 'rebound': 8, 'complaint': 68, 'long': 58, 'placement': 143, 'spent': 65, 'intern': 78, 'lvef': 38, 'peep': 106, 'bandemia': 11, 'bpm': 102, 'keep': 104, 'appropri': 101, 'visit': 106, 'care': 171, 'resp': 163, 'law': 18, 'medic': 217, 'plt': 82, 'prophylaxi': 70, 'puls': 133, 'aggress': 62, 'think': 20, 'ns': 119, 'acidem': 4, 'ulcer': 81, 'ij': 79, 'condit': 206, 'diagnosi': 176, 'monitor': 174, 'tc': 12, 'infecti': 53, 'costophren': 30, 'admiss': 88, 'access': 113, 'reason': 199, 'hr': 189, 'insert': 61, 'distend': 108, 'deliveri': 63, 'hold': 90, 'er': 19, 'defer': 39, 'detail': 69, 'woman': 8 ...

# %%
# # get hyper-paramters n_fold and threshold from user input
n_fold = float(3)
threshold = float(0.01)

frequent_word_lists = {}
factor = {}

# %%
"""function description:
for each disease in note_appearance_counter
    1. checks whether a word in disease file is frequent(frequency standard as defined by factor, n_fold, and threshold)
    2. adds to frequent_word_list
"""

# def find_frequent_word(note_appearance_counter, frequent_word_lists, number_of_notes, factor, n_fold, threshold):

# calculate normalizing factor for each disease
note_sum = 0

# Count from two labels
for disease in number_of_notes:
    note_sum += float(number_of_notes[disease])
    
for disease in number_of_notes:
    factor[disease] = number_of_notes[disease] / note_sum

# determine frequent word for each disease file
for disease in note_appearance_counter:
    frequent_word_lists[disease] = []

    print(disease + " has " + str(len(note_appearance_counter[disease])) + " unique words!")

    for word in note_appearance_counter[disease]:
        
        freq_check = True
        for check_disease in note_appearance_counter:
            
            if not disease == check_disease:
                if word in note_appearance_counter[check_disease]:
                    if not (note_appearance_counter[disease][word] / note_appearance_counter[check_disease][word] / factor[disease] * factor[check_disease] > n_fold \
                        and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):

                        freq_check = False
                        break

                else:
                    if not (note_appearance_counter[disease][word] > n_fold and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):
                        freq_check = False
                        break
        if freq_check:
            frequent_word_lists[disease].append((word))
            # Create a tuple of word and its count
#             frequent_word_lists[disease].append((word, note_appearance_counter[disease][word]))

        

print("finished making frequent words list for " + disease)
# Out:
# pneumonia_dead has 11678 unique words!
# pneumonia_alive has 22572 unique words!
# finished making frequent words list for pneumonia_alive

# %%
print(note_sum)
print(factor)

# number of notes
# 58029.0
# {'pneumonia_dead': 0.2049837150390322, 'pneumonia_alive': 0.7950162849609678}
# Out:
# 1419.0
# {'pneumonia_dead': 0.17758985200845667, 'pneumonia_alive': 0.8224101479915433}

# %%
print(len(frequent_word_lists['pneumonia_dead']))
print(len(frequent_word_lists['pneumonia_alive']))


# n_fold = float(3) threshold = float(0.01)
# 454
# 329

# n_fold = float(2) threshold = float(0.01)
# 914
# 600

# n_fold = float(1) threshold = float(0.01)
# 3320
# 2196
# Out:
# 454
# 329

# %%
print(frequent_word_lists)
# Out:
# {'pneumonia_dead': ['funer', 'suffer', 'hypercapnia', 'arrang', 'dic', 'arrest', 'park', 'paralyt', 'clergi', 'phenylephrin', 'hypercapn', 'recruit', 'mottl', 'acidem', 'refractori', 'bicarbon', 'anur', 'unrespons', 'elig', 'autopeep', 'death', 'profound', 'expir', 'azotemia', 'pea', 'cremat', 'norepinephrin', 'pcv', 'vasopressin', 'hypothermia', 'cpr', 'clinician', 'lubric', 'nacl', 'sluggish', 'dnr', 'cmo', 'gum', 'dni', 'slough', 'dk', 'nonpurpos', 'virtual', 'pinpoint', 'oder', 'float', 'mso', 'wish', 'clariti', 'levoph', 'viabl', 'gather', 'antb', 'institut', 'purpl', 'priest', 'hypotent', 'prognosi', 'option', 'dd', 'remin', 'respon', 'dead', 'peerla', 'pronounc', 'suport', 'grim', 'bow', 'agreement', 'acv', 'aprv', 'life', 'mortem', 'synch', 'asystol', 'centimet', 'bye', 'mad', 'depth', 'duski', 'peac', 'surviv', 'sync', 'mgx', 'ppn', 'nrbm', 'hover', 'cathol', 'moniotr', 'chaplain', 'througout', 'pulseless', 'deliv', 'rusti', 'cvvh', 'cvvhd', 'neosynephrin', 'crrt', 'mortum', 'pfr', 'acidot', 'seriou', 'corneal', 'suppport', 'deterior', 'cvvhdf', 'quiac', 'defibril', 'jerk', 'hemothorax', 'vtach', 'vasopressor', 'agon', 'declin', 'unequ', 'hypotherm', 'multisystem', 'rewir', 'among', 'cooler', 'scl', 'ultrafiltr', 'levof', 'ethic', 'hugger', 'mtg', 'gratitud', 'elimin', 'lw', 'brb', 'cyanot', 'spiritu', 'uffp', 'ffp', 'pray', 'pitressin', 'quinton', 'towel', 'bair', 'maroon', 'cagluc', 'lc', 'town', 'bond', 'zero', 'absorb', 'motil', 'prayer', 'nahco', 'chane', 'paco', 'polymorph', 'asynchron', 'ran', 'warmer', 'bank', "tf'ing", 'discoordin', 'promod', 'syring', 'rabbi', 'discard', 'neo', 'erythro', 'circuit', 'escal', 'autopsi', 'bairhugg', 'morgu', 'ashen', 'sml', 'triadyn', 'norepi', 'edt', 'unstabl', 'rediscuss', '^rr', 'hunger', 'gc', 'mind', 'polici', 'hung', 'dopamin', 'intiat', 'moan', 'cantones', 'tacycard', 'palli', 'fliud', 'overlay', 'acc', 'ozz', 'artifici', 'readdress', 'judgement', 'proph', 'inclus', 'dobutamin', 'recalibr', 'anuria', 'underneath', 'gurgl', 'broader', 'hospic', 'oncologist', 'adenosin', 'platelet', 'platlet', 'quadrent', 'oligur', 'psup', 'nephrolog', 'surgicel', 'cellcept', 'pheresi', 'gvhd', 'kerlix', 'anyway', 'sorb', 'griev', 'hepati', 'core', 'gut', 'cardiovert', 'influenc', 'fc', 'fentenyl', 'grimmac', 'hiccup', 'caspofungin', 'extremitiy', 'fungemia', 'snt', 'premed', 'barotrauma', 'cisatracurium', 'chemic', 'oximetri', 'repsons', 'pose', 'twitch', 'wether', 'ettub', 'lcw', 'liw', 'fentani', 'rescan', 'nephrogram', 'plat', 'crt', 'postpylor', 'conc', 'sacrament', 'nonreact', 'mail', 'grave', 'chb', 'heroic', 'nonrebreath', 'awhil', 'pleuravac', 'occupi', 'ultra', 'reappear', 'familt', 'propos', 'struggl', 'opinion', 'palliat', 'reveiw', 'gentamycin', 'icter', 'criticar', 'resucit', 'ogtub', 'sooner', 'preoxygen', 'amongst', 'wma', 'themselv', 'fibrinogen', 'meaning', 'pplat', 'tubular', 'reguard', 'abruptli', 'ardsnet', 'cvo', 'kyphoscoliosi', 'pneumonectomi', 'sibl', 'vasoconstrict', 'gasp', 'hook', 'recev', 'hida', 'realist', 'tran', 'colour', 'moreov', 'aricept', 'innumer', 'unreli', 'argatroban', 'irrevers', 'aliv', 'vigil', 'creep', 'buck', 'pvr', 'pharmacolog', 'derecruit', 'wil', 'epsiod', 'attemtp', 'ration', 'eyelid', 'religi', 'respitori', 'famil', 'analgesia', 'imbal', 'myeloma', 'adam', 'neob', 'declar', 'dorsal', 'muddi', 'od', 'moisten', 'requr', 'heliox', 'diflucan', 'emper', 'osteoblast', 'futil', 'illeu', 'currentl', 'nimv', 'perisplen', 'preliminarili', 'fli', 'plerual', 'rhochor', 'forth', 'esoph', 'sluggishli', 'dysynchron', 'prioriti', 'unplan', 'binder', 'occurr', 'ipf', 'goodby', 'ccn', 'stg', 'meatu', 'scopalamin', 'unarous', 'tobra', 'bless', 'fentayl', 'hemodynim', 'petechia', 'rite', 'harm', 'doen', 'calvarium', 'furhter', 'stack', 'chol', 'montitor', 'fmaili', 'underpenetr', 'figur', 'pyuria', 'massag', 'ggt', 'thrombot', 'outer', 'mrcp', 'formul', 'contini', 'synchroni', 'treatement', 'news', 'amioderon', 'unobtain', 'led', 'pastor', 'mvo', 'anasarc',  ...

# %% [markdown]
# ### 2. Co-occurrence generation
# FP-growth

# %%
FREQUENT_WORD_LIST = frequent_word_lists['pneumonia_dead'] + frequent_word_lists['pneumonia_alive']
print(len(FREQUENT_WORD_LIST))
print(len(set(FREQUENT_WORD_LIST)))
# Out:
# 783
# 783

# %%
"""function description:
generates frequent word set for the disease
"""
word_dict = {}
word_id = 1
stemmer = PorterStemmer()


for word in FREQUENT_WORD_LIST:
    if not word == "WORD":
        word_dict[stemmer.stem(word.strip())] = word_id
        word_id += 1
             
print(f"\nword dictionary created! Length: {len(word_dict)}\n")
print(word_dict)
# Out:
# word dictionary created! Length: 783
#
# {'funer': 1, 'suffer': 2, 'hypercapnia': 3, 'arrang': 4, 'dic': 5, 'arrest': 6, 'park': 7, 'paralyt': 8, 'clergi': 9, 'phenylephrin': 10, 'hypercapn': 11, 'recruit': 12, 'mottl': 13, 'acidem': 14, 'refractori': 15, 'bicarbon': 16, 'anur': 17, 'unrespon': 18, 'elig': 19, 'autopeep': 20, 'death': 21, 'profound': 22, 'expir': 23, 'azotemia': 24, 'pea': 25, 'cremat': 26, 'norepinephrin': 27, 'pcv': 28, 'vasopressin': 29, 'hypothermia': 30, 'cpr': 31, 'clinician': 32, 'lubric': 33, 'nacl': 34, 'sluggish': 35, 'dnr': 36, 'cmo': 37, 'gum': 38, 'dni': 39, 'slough': 40, 'dk': 41, 'nonpurpo': 42, 'virtual': 43, 'pinpoint': 44, 'oder': 45, 'float': 46, 'mso': 47, 'wish': 48, 'clariti': 49, 'levoph': 50, 'viabl': 51, 'gather': 52, 'antb': 53, 'institut': 54, 'purpl': 55, 'priest': 56, 'hypot': 57, 'prognosi': 58, 'option': 59, 'dd': 60, 'remin': 61, 'respon': 62, 'dead': 63, 'peerla': 64, 'pronounc': 65, 'suport': 66, 'grim': 67, 'bow': 68, 'agreement': 69, 'acv': 70, 'aprv': 71, 'life': 72, 'mortem': 73, 'synch': 74, 'asystol': 75, 'centimet': 76, 'bye': 77, 'mad': 78, 'depth': 79, 'duski': 80, 'peac': 81, 'surviv': 82, 'sync': 83, 'mgx': 84, 'ppn': 85, 'nrbm': 86, 'hover': 87, 'cathol': 88, 'moniotr': 89, 'chaplain': 90, 'througout': 91, 'pulseless': 92, 'deliv': 93, 'rusti': 94, 'cvvh': 95, 'cvvhd': 96, 'neosynephrin': 97, 'crrt': 98, 'mortum': 99, 'pfr': 100, 'acidot': 101, 'seriou': 102, 'corneal': 103, 'suppport': 104, 'deterior': 105, 'cvvhdf': 106, 'quiac': 107, 'defibril': 108, 'jerk': 109, 'hemothorax': 110, 'vtach': 111, 'vasopressor': 112, 'agon': 113, 'declin': 114, 'unequ': 115, 'hypotherm': 116, 'multisystem': 117, 'rewir': 118, 'among': 119, 'cooler': 120, 'scl': 121, 'ultrafiltr': 122, 'levof': 123, 'ethic': 124, 'hugger': 125, 'mtg': 126, 'gratitud': 127, 'elimin': 128, 'lw': 129, 'brb': 130, 'cyanot': 131, 'spiritu': 132, 'uffp': 133, 'ffp': 134, 'pray': 135, 'pitressin': 136, 'quinton': 137, 'towel': 138, 'bair': 139, 'maroon': 140, 'cagluc': 141, 'lc': 142, 'town': 143, 'bond': 144, 'zero': 145, 'absorb': 146, 'motil': 147, 'prayer': 148, 'nahco': 149, 'chane': 150, 'paco': 151, 'polymorph': 152, 'asynchron': 153, 'ran': 154, 'warmer': 155, 'bank': 156, "tf'ing": 157, 'discoordin': 158, 'promod': 159, 'syre': 160, 'rabbi': 161, 'discard': 162, 'neo': 163, 'erythro': 164, 'circuit': 165, 'escal': 166, 'autopsi': 167, 'bairhugg': 168, 'morgu': 169, 'ashen': 170, 'sml': 171, 'triadyn': 172, 'norepi': 173, 'edt': 174, 'unstabl': 175, 'rediscuss': 176, '^rr': 177, 'hunger': 178, 'gc': 179, 'mind': 180, 'polici': 181, 'hung': 182, 'dopamin': 183, 'intiat': 184, 'moan': 185, 'canton': 186, 'tacycard': 187, 'palli': 188, 'fliud': 189, 'overlay': 190, 'acc': 191, 'ozz': 192, 'artifici': 193, 'readdress': 194, 'judgement': 195, 'proph': 196, 'inclu': 197, 'dobutamin': 198, 'recalibr': 199, 'anuria': 200, 'underneath': 201, 'gurgl': 202, 'broader': 203, 'hospic': 204, 'oncologist': 205, 'adenosin': 206, 'platelet': 207, 'platlet': 208, 'quadrent': 209, 'oligur': 210, 'psup': 211, 'nephrolog': 212, 'surgicel': 213, 'cellcept': 214, 'pheresi': 215, 'gvhd': 216, 'kerlix': 217, 'anyway': 218, 'sorb': 219, 'griev': 220, 'hepati': 221, 'core': 222, 'gut': 223, 'cardiovert': 224, 'influenc': 225, 'fc': 226, 'fentenyl': 227, 'grimmac': 228, 'hiccup': 229, 'caspofungin': 230, 'extremitiy': 231, 'fungemia': 232, 'snt': 233, 'preme': 234, 'barotrauma': 235, 'cisatracurium': 236, 'chemic': 237, 'oximetri': 238, 'repson': 239, 'pose': 240, 'twitch': 241, 'wether': 242, 'ettub': 243, 'lcw': 244, 'liw': 245, 'fentani': 246, 'rescan': 247, 'nephrogram': 248, 'plat': 249, 'crt': 250, 'postpylor': 251, 'conc': 252, 'sacrament': 253, 'nonreact': 254, 'mail': 255, 'grave': 256, 'chb': 257, 'heroic': 258, 'nonrebreath': 259, 'awhil': 260, 'pleuravac': 261, 'occupi': 262, 'ultra': 263, 'reappear': 264, 'familt': 265, 'propo': 266, 'struggl': 267, 'opinion': 268, 'palliat': 269, 'reveiw': 270, 'gentamycin': 271, 'icter': 272, 'criticar': 273, 'resucit ...

# %% [markdown]
# ### Implementetion with python for FP_growth

# %% [markdown]
# ### Count co-occurrences per patient

# %%
import os
import operator
from pathlib import Path
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import math

# ----
def fp_growth_input_per_patient_python(disease_df, word_dict, min_support):
    
    # For dataframe
    patient_cooc_dict = {}
    patient_node_dict = {}
    patient_note_cnt = {}
    
    # --------------    
    patient_id = -1
    note_cnt = 0
    patient_note_list = []
    
    # read line in from file (each line is one note)
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        
        # only regard certain type of notes
        patient_id_check = int(row['SUBJECT_ID_x'])
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        patient_word_set = set()
    
#         print(f"patient_id_check: {patient_id_check}, patient_id: {patient_id}")
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check and not patient_id == -1:
            te = TransactionEncoder()
            te_ary = te.fit(patient_note_list).transform(patient_note_list)
            df = pd.DataFrame(te_ary, columns=te.columns_)
            df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
            cooc_tmp = []
            cooc_minsup_tmp = []
            node_minsup_tmp = []
            cooc_node_idx_tmp = []
            
            for index, row in df_itemsets.iterrows():
                if len(row['itemsets']) == 1:
                    word = list(row['itemsets'])[0]
                    min_sup = row['support']

                    node_minsup_tmp.append(len(patient_note_list) * row['support'])
                    cooc_node_idx_tmp.append(word)
                    
                if len(row['itemsets']) == 2:
                    cooc_ = sorted(list(row['itemsets']))
                    cooc_tmp.append(cooc_)
                    cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
            
            cooc_dict = {}

            for num, i in enumerate(cooc_tmp):
                if tuple(i) not in cooc_dict:
                    cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

            # dictionary = dict(zip(keys, values))
            node_dict = {}
            for num, i in enumerate(cooc_node_idx_tmp):
                if i not in node_dict:
                    node_dict[i] = node_minsup_tmp[num]
                    
            # Update glob lists
            if patient_id not in patient_cooc_dict:
                patient_cooc_dict[patient_id] = cooc_dict
                patient_node_dict[patient_id] = node_dict
                patient_note_cnt[patient_id] = note_cnt
            else:
                print(f"patient_id: {patient_id} is already in the dictionary!")
            
            
            # Reset local lists
            patient_note_list = []
            note_cnt = 0
                    
        # update patient id
        patient_id = patient_id_check
        tokenized_note = word_tokenize(note)
        note_cnt += 1

        # loop through each word in note to count word belonging to each disease
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())       
            if stemmed_word in word_dict:
                    patient_word_set.add(stemmed_word)

        templst = []
        for word in patient_word_set:
            templst.append(word)

        if templst:
            patient_note_list.append(templst)
    
    # Last patient info
    te = TransactionEncoder()
    te_ary = te.fit(patient_note_list).transform(patient_note_list)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
    cooc_tmp = []
    cooc_minsup_tmp = []
    #-----
    node_minsup_tmp = []
    cooc_node_idx_tmp = []
            
    for index, row in df_itemsets.iterrows():
        if len(row['itemsets']) == 1:
            word = list(row['itemsets'])[0]
            node_minsup_tmp.append(len(patient_note_list) * row['support'])
            cooc_node_idx_tmp.append(word)

        if len(row['itemsets']) == 2:
            cooc_ = sorted(list(row['itemsets']))
            cooc_tmp.append(cooc_)
            cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
    
                    
    cooc_dict = {}

    for num, i in enumerate(cooc_tmp):
        if tuple(i) not in cooc_dict:
            cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

    # dictionary = dict(zip(keys, values))
    node_dict = {}
    for num, i in enumerate(cooc_node_idx_tmp):
        if i not in node_dict:
            node_dict[i] = node_minsup_tmp[num]

    # Update glob lists
    if patient_id not in patient_cooc_dict:
        patient_cooc_dict[patient_id] = cooc_dict
        patient_node_dict[patient_id] = node_dict
        patient_note_cnt[patient_id] = note_cnt
    else:
        print(f"patient_id: {patient_id} is already in the dictionary!")

    return patient_node_dict, patient_cooc_dict, patient_note_cnt

patient_node_0, patient_cooc_0, patient_note_num_0 = fp_growth_input_per_patient_python(pneumonia_dead_no_disch, word_dict, 0.15)
patient_node_1, patient_cooc_1, patient_note_num_1 = fp_growth_input_per_patient_python(pneumonia_alive_no_disch, word_dict, 0.15)
# Out:
# 100%|██████████| 11895/11895 [01:32<00:00, 128.00it/s]
# 100%|██████████| 46134/46134 [05:55<00:00, 129.74it/s]

# %%
print(patient_node_1)
# Out:
# {68: {'commod': 4.0, 'ambul': 4.0, 'gait': 2.0, 'chair': 2.0, 'oob': 2.0}, 85: {'lat': 1.0}, 94: {'lift': 11.0, 'dopamin': 11.0}, 165: {'habitu': 1.0}, 211: {'dopamin': 3.0, 'aox': 3.0, 'levoph': 3.0}, 224: {'lat': 1.0, 'rigor': 1.0, 'platelet': 1.0, 'commod': 1.0, 'awhil': 1.0, 'fax': 1.0, 'bank': 1.0, 'pleasant': 1.0, 'chair': 1.0}, 231: {}, 283: {'recruit': 10.0, 'criticar': 10.0}, 357: {'unasyn': 4.0, 'intent': 2.0, 'dz': 2.0, 'ctx': 2.0, 'moan': 4.0, 'distort': 2.0}, 368: {'pleasant': 3.0, 'dnr': 3.0, 'hhn': 3.0, 'oob': 6.0, 'ambul': 4.0}, 370: {'dnr': 2.0}, 384: {'bipolar': 9.0, 'wish': 4.0, 'dnr': 3.0, 'schizophrenia': 4.0}, 426: {'align': 1.0, 'mottl': 1.0, 'lat': 1.0, 'unenhanc': 1.0, 'mail': 1.0, 'bronchovascular': 1.0, 'pleasant': 1.0, 'arthrit': 1.0}, 509: {'oob': 3.0}, 514: {'lat': 1.0, 'schizophrenia': 1.0, 'nicotin': 1.0, 'lighthead': 1.0, 'burn': 1.0, 'pleasant': 2.0, 'commod': 2.0, 'ambul': 1.0, 'oob': 1.0}, 596: {'dnr': 4.0, 'dopamin': 3.0, 'dni': 4.0, 'chair': 2.0}, 674: {'profound': 1.0, 'nimv': 1.0, 'xl': 2.0, 'rememb': 1.0, 'neo': 1.0, 'mso': 1.0, 'lotion': 1.0, 'tranfer': 1.0, 'fu': 1.0, 'cardiovert': 1.0}, 707: {'pleasantli': 4.0, 'lpm': 2.0, 'oob': 3.0, 'pleasant': 2.0}, 711: {'dnr': 190.99999999999997, 'mellitu': 78.0, 'fibrinogen': 186.0, 'captopril': 77.0, 'olanzapin': 109.0, 'palli': 60.0, 'fungemia': 95.0, 'caspofungin': 105.0}, 770: {'iddm': 24.0, 'vp': 20.0}, 773: {'pneumococc': 7.0, 'mso': 8.0, 'levoph': 8.0}, 899: {'lat': 2.0, 'chip': 2.0, 'pleasant': 3.0}, 1096: {'syst': 1.0, 'ppd': 1.0, 'lc': 1.0, 'forc': 1.0, 'tubular': 1.0}, 1135: {'scab': 3.0, 'oob': 6.0, 'chair': 7.0, 'argatroban': 4.0, 'pleasant': 3.0, 'lat': 3.0, 'xl': 3.0}, 1163: {'osa': 1.0, 'pleasant': 1.0, 'twitch': 1.0, 'captopril': 1.0}, 1174: {}, 1180: {'influenc': 1.0}, 1283: {'unavail': 1.0, 'seat': 1.0, 'habitu': 1.0}, 1332: {'levoph': 4.0, 'dnr': 6.0, 'dni': 5.0, 'oob': 4.0}, 1339: {'oob': 20.0, 'stair': 18.0, 'ctx': 18.0, 'ambul': 18.0, 'seroquel': 23.0, 'video': 22.0, 'barium': 18.0, 'phenylephrin': 25.0, 'neo': 27.0}, 1546: {'asthma': 4.0, 'spacer': 2.0, 'oob': 2.0, 'db': 2.0}, 1568: {'pericard': 5.0, 'pleasant': 4.0, 'oob': 2.0}, 1601: {'levoph': 3.0, 'pleasant': 2.0, 'ambien': 2.0}, 1606: {'precordium': 1.0, 'unalt': 1.0, 'dnr': 1.0, 'dni': 1.0, 'lat': 1.0, 'dome': 1.0}, 1642: {'pleasant': 2.0, 'dnr': 2.0, 'dni': 2.0, 'quadrent': 1.0, 'declin': 1.0}, 1660: {'behavior': 2.0, 'pleasant': 2.0}, 1895: {'pleasant': 2.0}, 1923: {'moan': 3.0, 'dnr': 3.0, 'sarna': 2.0, 'lotion': 2.0}, 2029: {'xanax': 28.0, 'dnr': 20.0}, 2090: {'chair': 18.0, 'splint': 13.0, 'dyslipidemia': 23.000000000000004, 'ctx': 17.0, 'bromid': 17.0, 'ntnd': 14.000000000000002}, 2098: {'hugger': 4.0, 'bair': 4.0, 'cpr': 2.0}, 2128: {'dopamin': 10.0, 'mso': 6.0, 'unasyn': 4.0, 'flight': 3.0}, 2170: {'qtc': 1.0, 'nonrebreath': 1.0, 'spur': 2.0, 'lat': 1.0}, 2187: {'osa': 2.0, 'morbid': 2.0, 'captopril': 2.0}, 2208: {'vp': 35.0, 'bipolar': 16.0, 'clonidin': 19.0, 'levoph': 16.0}, 2337: {'smooth': 1.0, 'hemangioma': 1.0, 'slough': 1.0, 'pleasant': 1.0, 'dnr': 2.0, 'pleasantli': 1.0}, 2378: {'ultram': 16.0, 'silent': 16.0, 'video': 15.0, 'sensat': 13.0}, 2386: {'dnr': 7.0, 'hospic': 3.0, 'town': 2.0, 'dni': 3.0}, 2452: {'lat': 4.0}, 2508: {'levoph': 2.0, 'dopamin': 2.0, 'ppd': 2.0, 'ciwa': 2.0, 'lpm': 2.0, 'chair': 2.0}, 2561: {}, 2585: {'hilum': 2.0, 'para': 1.0, 'ultram': 1.0, 'sluggish': 1.0, 'prognosi': 1.0, 'hook': 1.0, 'grave': 1.0, 'dnr': 1.0, 'dni': 1.0}, 2589: {'bipolar': 28.000000000000004, 'pneumococc': 22.0, 'zyprexa': 7.000000000000001, 'dz': 9.0, 'mood': 7.000000000000001, 'historian': 10.0}, 2590: {'dnr': 2.0, 'dni': 2.0, 'nonrebreath': 1.0, 'venti': 2.0, 'lpm': 1.0, 'pleasant': 1.0}, 2628: {}, 2658: {'moan': 3.0}, 2732: {'vertebra': 2.0, 'lat': 2.0}, 2784: {'arrest': 2.0, 'commod': 3.0, 'video': 2.0, 'diaper': 2.0, 'gait': 2.0}, 2823: {'dnr': 4.0, 'venti': 3.0, 'dni': 3.0}, 3070: {'svn': 2.0, 'osa': 1.0, 'ofm': 1.0, 'pleasant': 1.0, 'video': 1.0, ...

# %%
print(patient_cooc_1)
# Out:
# {68: {('ambul', 'commod'): 3.0, ('ambul', 'oob'): 2.0, ('commod', 'oob'): 2.0}, 85: {}, 94: {}, 165: {}, 211: {}, 224: {('platelet', 'rigor'): 1.0, ('commod', 'platelet'): 1.0, ('commod', 'rigor'): 1.0, ('bank', 'fax'): 1.0, ('chair', 'pleasant'): 1.0}, 231: {}, 283: {}, 357: {('intent', 'unasyn'): 2.0, ('dz', 'intent'): 2.0, ('dz', 'unasyn'): 2.0, ('ctx', 'unasyn'): 2.0}, 368: {}, 370: {}, 384: {('bipolar', 'wish'): 4.0}, 426: {('lat', 'mottl'): 1.0, ('mail', 'unenhanc'): 1.0, ('bronchovascular', 'mail'): 1.0, ('bronchovascular', 'unenhanc'): 1.0, ('arthrit', 'pleasant'): 1.0}, 509: {}, 514: {('nicotin', 'schizophrenia'): 1.0, ('lighthead', 'nicotin'): 1.0, ('lighthead', 'schizophrenia'): 1.0, ('burn', 'lighthead'): 1.0, ('burn', 'nicotin'): 1.0, ('burn', 'schizophrenia'): 1.0, ('commod', 'pleasant'): 2.0, ('ambul', 'commod'): 1.0, ('ambul', 'pleasant'): 1.0, ('commod', 'oob'): 1.0, ('oob', 'pleasant'): 1.0}, 596: {('dni', 'dnr'): 2.0}, 674: {('nimv', 'profound'): 1.0, ('rememb', 'xl'): 1.0, ('neo', 'rememb'): 1.0, ('neo', 'xl'): 1.0, ('mso', 'neo'): 1.0, ('mso', 'rememb'): 1.0, ('mso', 'xl'): 1.0, ('lotion', 'mso'): 1.0, ('lotion', 'neo'): 1.0, ('lotion', 'rememb'): 1.0, ('lotion', 'xl'): 1.0, ('tranfer', 'xl'): 1.0, ('fu', 'tranfer'): 1.0, ('fu', 'xl'): 1.0, ('cardiovert', 'fu'): 1.0, ('cardiovert', 'tranfer'): 1.0, ('cardiovert', 'xl'): 1.0}, 707: {('oob', 'pleasantli'): 2.0}, 711: {('fibrinogen', 'mellitu'): 59.0, ('dnr', 'fibrinogen'): 159.0, ('captopril', 'fibrinogen'): 66.0, ('fibrinogen', 'olanzapin'): 99.0, ('dnr', 'olanzapin'): 85.0, ('dnr', 'fungemia'): 80.0, ('fibrinogen', 'fungemia'): 78.0, ('caspofungin', 'fungemia'): 87.0, ('fungemia', 'olanzapin'): 57.0, ('caspofungin', 'dnr'): 81.0, ('caspofungin', 'fibrinogen'): 79.0}, 770: {('iddm', 'vp'): 16.0}, 773: {}, 899: {}, 1096: {('ppd', 'syst'): 1.0}, 1135: {('chair', 'oob'): 4.0, ('argatroban', 'chair'): 3.0}, 1163: {('captopril', 'twitch'): 1.0}, 1174: {}, 1180: {}, 1283: {('seat', 'unavail'): 1.0, ('habitu', 'unavail'): 1.0, ('habitu', 'seat'): 1.0}, 1332: {('dni', 'dnr'): 5.0}, 1339: {('oob', 'stair'): 18.0, ('ctx', 'stair'): 18.0, ('ctx', 'oob'): 18.0, ('ambul', 'ctx'): 18.0, ('ambul', 'stair'): 18.0, ('ambul', 'oob'): 18.0, ('phenylephrin', 'video'): 15.0, ('barium', 'video'): 15.0}, 1546: {('db', 'oob'): 2.0}, 1568: {('pericard', 'pleasant'): 3.0, ('oob', 'pleasant'): 2.0}, 1601: {('levoph', 'pleasant'): 2.0}, 1606: {('dni', 'dnr'): 1.0}, 1642: {('dnr', 'pleasant'): 2.0, ('dni', 'pleasant'): 2.0, ('pleasant', 'quadrent'): 1.0, ('declin', 'pleasant'): 1.0, ('dni', 'dnr'): 2.0, ('dnr', 'quadrent'): 1.0, ('declin', 'dnr'): 1.0, ('dni', 'quadrent'): 1.0, ('declin', 'dni'): 1.0, ('declin', 'quadrent'): 1.0}, 1660: {}, 1895: {}, 1923: {('dnr', 'moan'): 2.0, ('dnr', 'sarna'): 2.0, ('moan', 'sarna'): 2.0, ('lotion', 'sarna'): 2.0, ('dnr', 'lotion'): 2.0, ('lotion', 'moan'): 2.0}, 2029: {}, 2090: {('ctx', 'dyslipidemia'): 13.0, ('bromid', 'dyslipidemia'): 17.0}, 2098: {('bair', 'hugger'): 4.0}, 2128: {('dopamin', 'mso'): 4.0, ('dopamin', 'unasyn'): 3.0}, 2170: {}, 2187: {('morbid', 'osa'): 2.0}, 2208: {('bipolar', 'vp'): 16.0}, 2337: {('hemangioma', 'smooth'): 1.0, ('pleasant', 'slough'): 1.0, ('dnr', 'pleasantli'): 1.0}, 2378: {('silent', 'video'): 14.000000000000002, ('sensat', 'video'): 12.0, ('sensat', 'silent'): 12.0}, 2386: {('dnr', 'hospic'): 3.0, ('dnr', 'town'): 2.0, ('dni', 'dnr'): 3.0}, 2452: {}, 2508: {('dopamin', 'levoph'): 2.0}, 2561: {}, 2585: {('hilum', 'para'): 1.0, ('prognosi', 'sluggish'): 1.0, ('hook', 'prognosi'): 1.0, ('hook', 'sluggish'): 1.0, ('grave', 'hook'): 1.0, ('grave', 'prognosi'): 1.0, ('grave', 'sluggish'): 1.0, ('dnr', 'grave'): 1.0, ('dnr', 'hook'): 1.0, ('dnr', 'prognosi'): 1.0, ('dnr', 'sluggish'): 1.0, ('dni', 'dnr'): 1.0, ('dni', 'grave'): 1.0, ('dni', 'hook'): 1.0, ('dni', 'prognosi'): 1.0, ('dni', 'sluggish'): 1.0}, 2589: {('bipolar', 'pneumococc'): 19.0, ('pneumococc', 'zyprexa'): 7.000000000000001, ('bipolar', 'zyprexa'): 7. ...

# %%
patient_note_num_0
# Out:
# {111: 12,
#  346: 25,
#  404: 3,
#  546: 6,
#  618: 16,
#  705: 15,
#  726: 48,
#  1039: 55,
#  1556: 37,
#  1872: 3,
#  1944: 56,
#  2286: 69,
#  2990: 166,
#  3055: 29,
#  3099: 13,
#  3201: 8,
#  3526: 7,
#  3773: 6,
#  3881: 20,
#  4122: 51,
#  4754: 101,
#  4811: 21,
#  5476: 1,
#  5494: 22,
#  5774: 104,
#  5786: 152,
#  5913: 1,
#  6133: 68,
#  6735: 13,
#  6745: 13,
#  6973: 36,
#  6981: 8,
#  7277: 66,
#  7310: 8,
#  7924: 9,
#  7977: 9,
#  9908: 11,
#  9984: 15,
#  10302: 100,
#  10510: 86,
#  10545: 10,
#  10642: 10,
#  11049: 14,
#  11209: 9,
#  11395: 41,
#  12530: 24,
#  12849: 50,
#  13098: 46,
#  13566: 23,
#  14125: 9,
#  14514: 96,
#  14965: 25,
#  15159: 15,
#  15251: 11,
#  15396: 17,
#  15566: 37,
#  15853: 45,
#  16275: 17,
#  16344: 27,
#  16622: 51,
#  16684: 29,
#  17122: 16,
#  17354: 5,
#  17802: 64,
#  17983: 65,
#  18094: 23,
#  18736: 35,
#  18768: 46,
#  18848: 205,
#  18971: 26,
#  19243: 25,
#  19323: 6,
#  19390: 21,
#  19463: 20,
#  19535: 59,
#  19754: 13,
#  19827: 22,
#  19833: 58,
#  19872: 10,
#  20006: 8,
#  20023: 9,
#  20190: 6,
#  21046: 101,
#  21094: 36,
#  21427: 10,
#  21502: 102,
#  21580: 52,
#  21676: 12,
#  21699: 7,
#  21979: 11,
#  22735: 15,
#  23660: 12,
#  23795: 78,
#  24181: 13,
#  24582: 37,
#  24725: 57,
#  24730: 19,
#  24854: 25,
#  25003: 182,
#  25046: 7,
#  25774: 61,
#  25975: 9,
#  26474: 89,
#  26578: 15,
#  26716: 41,
#  26774: 3,
#  26849: 33,
#  27005: 5,
#  27145: 24,
#  27421: 61,
#  27431: 5,
#  27496: 7,
#  27504: 72,
#  27639: 221,
#  28004: 13,
#  28072: 34,
#  28178: 202,
#  28427: 6,
#  28498: 25,
#  28726: 34,
#  28750: 19,
#  28906: 32,
#  28907: 13,
#  28933: 394,
#  29105: 468,
#  29588: 72,
#  29647: 26,
#  29872: 225,
#  30476: 174,
#  30549: 12,
#  30614: 8,
#  30699: 14,
#  30786: 9,
#  30941: 110,
#  31030: 168,
#  31134: 24,
#  31139: 9,
#  31451: 48,
#  31556: 57,
#  31690: 18,
#  31692: 35,
#  32050: 34,
#  32326: 24,
#  32618: 42,
#  41546: 25,
#  43937: 6,
#  44851: 274,
#  45381: 16,
#  46589: 26,
#  46763: 6,
#  47045: 9,
#  48632: 147,
#  49079: 20,
#  49683: 3,
#  49922: 13,
#  50093: 8,
#  50231: 3,
#  50556: 216,
#  50859: 537,
#  51914: 313,
#  52010: 12,
#  53105: 115,
#  53399: 78,
#  54193: 85,
#  54401: 14,
#  54408: 2,
#  54739: 75,
#  54946: 7,
#  55400: 5,
#  55570: 14,
#  55887: 37,
#  55944: 34,
#  55987: 20,
#  56390: 19,
#  56648: 8,
#  56854: 170,
#  57091: 88,
#  57102: 35,
#  58702: 479,
#  59260: 11,
#  59437: 26,
#  60849: 2,
#  60868: 6,
#  61652: 7,
#  61667: 30,
#  63039: 8,
#  65513: 8,
#  68044: 40,
#  68095: 23,
#  68184: 5,
#  68308: 8,
#  68860: 14,
#  69719: 13,
#  69745: 25,
#  69776: 17,
#  70226: 8,
#  70447: 9,
#  72930: 11,
#  73811: 9,
#  73888: 109,
#  74316: 2,
#  74444: 81,
#  74686: 75,
#  75824: 10,
#  76282: 21,
#  76827: 2,
#  77382: 10,
#  78241: 3,
#  78388: 14,
#  79008: 27,
#  79055: 21,
#  79222: 18,
#  79877: 156,
#  80637: 148,
#  80678: 9,
#  80737: 46,
#  80805: 79,
#  81437: 27,
#  82393: 5,
#  82769: 85,
#  83932: 2,
#  84474: 34,
#  85160: 8,
#  85258: 52,
#  85404: 11,
#  85797: 9,
#  86007: 35,
#  86394: 4,
#  86684: 11,
#  86832: 67,
#  86863: 8,
#  86872: 326,
#  88193: 16,
#  88660: 11,
#  90256: 18,
#  91350: 19,
#  92074: 28,
#  92278: 52,
#  92331: 42,
#  93422: 7,
#  94341: 2,
#  94997: 9,
#  95280: 23,
#  95803: 18,
#  95830: 33,
#  95933: 56,
#  96699: 85,
#  97181: 30,
#  97795: 60,
#  98009: 33,
#  98299: 29,
#  98597: 2}

# %% [markdown]
# #### Create set of patient co-occurrences from two groups

# %%
# Create a set of all unique co-occurrences from both group
patient_cooc_set = set()
patient_cooc_0_dict = {}
patient_cooc_1_dict = {}

for k, v in patient_cooc_0.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_0_dict:
            patient_cooc_0_dict[item] = v[item]
        else:
            patient_cooc_0_dict[item] = patient_cooc_0_dict[item] + v[item]
            
    
for k, v in patient_cooc_1.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_1_dict:
            patient_cooc_1_dict[item] = v[item]
        else:
            patient_cooc_1_dict[item] = patient_cooc_1_dict[item] + v[item]

# %%
print(len(patient_cooc_set))
print(len(patient_cooc_0_dict))
print(len(patient_cooc_1_dict))
# Out:
# 6776
# 1989
# 5152

# %%
# count log-odds score

# reverse
# --------------- co-occurrences --------------->

        
# Get the set of coocurrencies from two groups
# Count log_odd_score

patient_cooc_odd_scores = {}
for set_item in patient_cooc_set:
    if set_item in patient_cooc_0_dict and set_item in patient_cooc_1_dict: 
        d_prob = patient_cooc_0_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        a_prob = patient_cooc_1_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
# --------------- co-occurrences ---------------<

# %%
patient_cooc_odd_scores
# Out:
# {('contd', 'refractori'): 6.90875477931522,
#  ('breakfast', 'dizzi'): 6.90875477931522,
#  ('mortem', 'mso'): -6.90875477931522,
#  ('nicotin', 'ppd'): 6.90875477931522,
#  ('dni', 'pleasant'): 0.9671491491076459,
#  ('chip', 'scar'): 6.90875477931522,
#  ('lighthead', 'xl'): 6.90875477931522,
#  ('pod', 'readmit'): 6.90875477931522,
#  ('hunger', 'scar'): -6.90875477931522,
#  ('captopril', 'scar'): 6.90875477931522,
#  ('dobutamin', 'phenylephrin'): -6.90875477931522,
#  ('hive', 'profound'): 6.90875477931522,
#  ('cloth', 'dni'): 0.0,
#  ('asthma', 'osa'): 6.90875477931522,
#  ('robitussin', 'splint'): 6.90875477931522,
#  ('gait', 'im'): 6.90875477931522,
#  ('dopamin', 'liw'): -6.90875477931522,
#  ('dnr', 'meropenam'): -6.90875477931522,
#  ('qam', 'xii'): 6.90875477931522,
#  ('reguard', 'xanax'): 6.90875477931522,
#  ('grave', 'hook'): 6.90875477931522,
#  ('scar', 'sibl'): 6.90875477931522,
#  ('pea', 'subcost'): 6.90875477931522,
#  ('calculi', 'suprapub'): 6.90875477931522,
#  ('rigor', 'zero'): 6.90875477931522,
#  ('cmo', 'pronounc'): -6.90875477931522,
#  ('prilosec', 'syst'): 6.90875477931522,
#  ('contd', 'deterior'): 6.90875477931522,
#  ('hospic', 'underneath'): -6.90875477931522,
#  ('hepatobiliari', 'ntnd'): -6.90875477931522,
#  ('laryng', 'mucinex'): 6.90875477931522,
#  ('^th', 'ciwa'): 6.90875477931522,
#  ('cocain', 'herp'): 6.90875477931522,
#  ('azotemia', 'phenylephrin'): -6.90875477931522,
#  ('captopril', 'ffp'): 6.90875477931522,
#  ('clonazepam', 'seroquel'): 6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('bromid', 'opiat'): 6.90875477931522,
#  ('mrg', 'weekli'): 6.90875477931522,
#  ('asthma', 'schizophrenia'): 6.90875477931522,
#  ('pleasantli', 'subdur'): 6.90875477931522,
#  ('gabapentin', 'pneumococc'): 6.90875477931522,
#  ('dnr', 'learn'): 6.90875477931522,
#  ('chip', 'readmit'): 6.90875477931522,
#  ('dyslipidemia', 'profound'): 6.90875477931522,
#  ('dietari', 'hypothermia'): 6.90875477931522,
#  ('hsq', 'platelet'): -6.90875477931522,
#  ('absorb', 'option'): 6.90875477931522,
#  ('nicotin', 'oob'): 6.90875477931522,
#  ('habitu', 'levoph'): 6.90875477931522,
#  ('dni', 'occipit'): 6.90875477931522,
#  ('jerk', 'mso'): -6.90875477931522,
#  ('ggt', 'zyprexa'): 6.90875477931522,
#  ('ffp', 'neo'): -6.90875477931522,
#  ('endur', 'knowledg'): 6.90875477931522,
#  ('echocardiogram', 'thiamin'): 6.90875477931522,
#  ('chair', 'signatur'): 6.90875477931522,
#  ('effac', 'readmit'): 6.90875477931522,
#  ('oob', 'tracheomalacia'): 6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('core', 'dic'): -6.90875477931522,
#  ('deliv', 'dni'): 6.90875477931522,
#  ('captopril', 'tcdb'): 6.90875477931522,
#  ('fibrinogen', 'norepinephrin'): -2.4258395487508584,
#  ('palli', 'readmit'): 6.90875477931522,
#  ('clinician', 'cpr'): -6.90875477931522,
#  ('abnl', 'splint'): 6.90875477931522,
#  ('foci', 'jejunum'): 6.90875477931522,
#  ('ctx', 'hugger'): 6.90875477931522,
#  ('dnr', 'sarna'): 6.90875477931522,
#  ('gabapentin', 'phenylephrin'): 6.90875477931522,
#  ('mva', 'omeprazol'): 6.90875477931522,
#  ('behavior', 'seroquel'): 6.90875477931522,
#  ('hospic', 'mean'): -6.90875477931522,
#  ('declin', 'mva'): 6.90875477931522,
#  ('anur', 'azotemia'): -6.90875477931522,
#  ('romi', 'thiamin'): 6.90875477931522,
#  ('mrg', 'ntnd'): 6.90875477931522,
#  ('thiamin', 'vp'): 6.90875477931522,
#  ('dyslipidemia', 'gait'): 6.90875477931522,
#  ('ambul', 'nephrolog'): 6.90875477931522,
#  ('aox', 'unobtain'): 6.90875477931522,
#  ('laminectomi', 'stitch'): 6.90875477931522,
#  ('adenocarcinoma', 'assymetr'): -6.90875477931522,
#  ('angiogram', 'option'): 6.90875477931522,
#  ('oncologist', 'prognosi'): 6.90875477931522,
#  ('cracker', 'incent'): -6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('coarctat', 'tdi'): 6.90875477931522,
#  ('bank', 'fax'): 6.90875477931522,
#  ('carvedilol', 'ctx'): 6.90875477931522,
#  ('klonopin', 'zoloft'): 6.90875477931522,
#  ('deterior', 'gc'): 6.90875477931522,
#  ('ctx', 'quinolon'): 6.90875477931522,
#  ('dizzi', 'lat'): 6.90875477931522,
#  ('norepinephrin', 'pea'): -6.90875477931522,
#  ('hive', 'stitch'): 6.90875477931522,
#  ('ipf', 'scar'): 6.90875477931522,
#  ('abruptli', 'cmo'): -6.90875477931522,
#  ('diuril', 'dopamin'): 6.90875477931522,
#  ('burn', 'splint'): 6.90875477931522,
#  ('levoph', 'sluggish'): -6.90875477931522,
#  ('deploy', 'futil'): 6.90875477931522,
#  ('dni', 'scar'): -1.7436457586061653,
#  ('autopeep', 'azotemia'): -6.90875477931522,
#  ('captopril', 'omeprazol'): 6.90875477931522,
#  ('rhinorrhea', 'romi'): 6.90875477931522,
#  ('plerual', 'scar'): 6.90875477931522,
#  ('platelet', 'qtc'): 6.90875477931522,
#  ('ciwa', 'syncop'): 6.90875477931522,
#  ('arthrit', 'cdb'): 6.90875477931522,
#  ('rememb', 'ruptur'): 6.90875477931522,
#  ('dopamin', 'scopalamin'): -6.90875477931522,
#  ('furhter', 'lw'): -6.90875477931522,
#  ('mrg', 'oncologist'): 6.90875477931522,
#  ('ctx', 'young'): 6.90875477931522,
#  ('mellitu', 'pea'): 6.90875477931522,
#  ('ciwa', 'epigastr'): 6.90875477931522,
#  ('agonist', 'asthma'): 6.90875477931522,
#  ('dz', 'postop'): 6.90875477931522,
#  ('illeu', 'oob'): -6.90875477931522,
#  ('scar', 'smooth'): 6.90875477931522,
#  ('subq', 'xl'): 6.90875477931522,
#  ('dni', 'ntnd'): 1.4174966125472825,
#  ('hctz', 'puff'): 6.90875477931522,
#  ('dnr', 'hypothermia'): 2.0716061679700735,
#  ('bottl', 'occipit'): 6.90875477931522,
#  ('expir', 'im'): 6.90875477931522,
#  ('oob', 'seroquel'): 6.90875477931522,
#  ('pneumococc', 'puff'): 6.90875477931522,
#  ('clinician', 'dnr'): 0.4046335072286383,
#  ('cdb', 'dni'): 6.90875477931522,
#  ('aox', 'gait'): 6.90875477931522,
#  ('diaphoresi', 'subq'): 6.90875477931522,
#  ('captopril', 'hctz'): 6.90875477931522,
#  ('burn', 'spacer'): 6.90875477931522,
#  ('ofm', 'unsteadi'): 6.90875477931522,
#  ('autoset', 'declin'): 6.90875477931522,
#  ('historian', 'mellitu'): 6.90875477931522,
#  ('oob', 'video'): 6.90875477931522,
#  ('qam', 'thrive'): 6.90875477931522,
#  ('cash', 'ctx'): 6.90875477931522,
#  ('omeprazol', 'young'): 6.90875477931522,
#  ('cagluc', 'neo'): -6.90875477931522,
#  ('hsq', 'venti'): 6.90875477931522,
#  ('crack', 'hygein'): 6.90875477931522,
#  ('fibrinogen', 'rpr'): 6.90875477931522,
#  ('prognosi', 'wish'): -6.90875477931522,
#  ('scar', 'treitz'): 6.90875477931522,
#  ('arrest', 'autopeep'): -6.90875477931522,
#  ('adenocarcinoma', 'bill'): 6.90875477931522,
#  ('levoph', 'permiss'): -6.90875477931522,
#  ('gabapentin', 'strictur'): 6.90875477931522,
#  ('brb', 'crrt'): -6.90875477931522,
#  ('sensat', 'silent'): 6.90875477931522,
#  ('dnr', 'shorter'): 6.90875477931522,
#  ('mellitu', 'paralyt'): 6.90875477931522,
#  ('levoph', 'vasoconstrict'): -6.90875477931522,
#  ('chair', 'redirect'): 6.90875477931522,
#  ('commod', 'oob'): 2.850526026718352,
#  ('agon', 'jerk'): -6.90875477931522,
#  ('postop', 'scar'): 6.90875477931522,
#  ('phenylephrin', 'seat'): 6.90875477931522,
#  ('acc', 'young'): 6.90875477931522,
#  ('bromid', 'effac'): 6.90875477931522,
#  ('asthma', 'knowledg'): 6.90875477931522,
#  ('aox', 'predict'): 6.90875477931522,
#  ('appi', 'venti'): 6.90875477931522,
#  ('conc', 'dnr'): 6.90875477931522,
#  ('anur', 'gentamycin'): -6.90875477931522,
#  ('articul', 'hypothermia'): 6.90875477931522,
#  ('lat', 'rehabilit'): 6.90875477931522,
#  ('asthma', 'norepinephrin'): 6.90875477931522,
#  ('bromid', 'clonazepam'): 6.90875477931522,
#  ('omeprazol', 'subq'): 6.90875477931522,
#  ('omeprazol', 'solut'): 6.90875477931522,
#  ('chemic', 'dni'): -6.90875477931522,
#  ('neoplast', 'thiamin'): 6.90875477931522,
#  ('dz', 'venti'): 6.90875477931522,
#  ('arrest', 'carvedilol'): 6.90875477931522,
#  ('asthma', 'burn'): 6.90875477931522,
#  ('hive', 'sarna'): 6.90875477931522,
#  ('profound', 'vertebra'): 6.90875477931522,
#  ('barium', 'breakfast'): 6.90875477931522,
#  ('ferrou', 'nocturn'): 6.90875477931522,
#  ('ambul', 'ctx'): 6.90875477931522,
#  ('mrg', 'readmit'): 6.90875477931522,
#  ('arrest', 'cefapim'): 6.90875477931522,
#  ('chip', 'hook'): 6.90875477931522,
#  ('declin', 'moan'): -6.90875477931522,
#  ('asthma', 'jewelri'): 6.90875477931522,
#  ('homogen', 'ligament'): 6.90875477931522,
#  ('sibl', 'thiamin'): 6.90875477931522,
#  ('rhinorrhea', 'thiamin'): 6.90875477931522,
#  ('anur', 'cpr'): 6.90875477931522,
#  ('dizzi', 'jewelri'): 6.90875477931522,
#  ('paralyt', 'recruit'): 6.90875477931522,
#  ('nifedipin', 'xl'): 6.90875477931522,
#  ('iddm', 'uri'): 6.90875477931522,
#  ('gabapentin', 'rhinorrhea'): 6.90875477931522,
#  ('artifici', 'gait'): -6.90875477931522,
#  ('barium', 'thrive'): 6.90875477931522,
#  ('option', 'unstabl'): -6.90875477931522,
#  ('neo', 'paralyt'): -3.1942475376942854,
#  ('declin', 'unasyn'): 6.90875477931522,
#  ('duski', 'levoph'): -6.90875477931522,
#  ('epidur', 'vertebra'): 6.90875477931522,
#  ('scar', 'slice'): 6.90875477931522,
#  ('echocardiogram', 'ppd'): 6.90875477931522,
#  ('contd', 'dopamin'): 6.90875477931522,
#  ('mva', 'seroquel'): 6.90875477931522,
#  ('lat', 'pneumothorac'): 0.6916505477038827,
#  ('hugger', 'sluggish'): -6.90875477931522,
#  ('asystol', 'neo'): -6.90875477931522,
#  ('quinolon', 'trazodon'): 6.90875477931522,
#  ('dnr', 'fibrinogen'): 1.6507429622330152,
#  ('norepinephrin', 'opiat'): 6.90875477931522,
#  ('dnr', 'occurr'): 6.90875477931522,
#  ('arrest', 'chb'): -6.90875477931522,
#  ('dopamin', 'vasopressin'): 0.9785433477333831,
#  ('ferrou', 'sibl'): 6.90875477931522,
#  ('laminectomi', 'unstabl'): 6.90875477931522,
#  ('ciwa', 'ran'): 6.90875477931522,
#  ('chip', 'dopamin'): 6.90875477931522,
#  ('agon', 'death'): -6.90875477931522,
#  ('deterior', 'echocardiogram'): 6.90875477931522,
#  ('barium', 'mottl'): 6.90875477931522,
#  ('bill', 'dyslipidemia'): 6.90875477931522,
#  ('pleasant', 'thirst'): 6.90875477931522,
#  ('crowd', 'mellitu'): 6.90875477931522,
#  ('dic', 'dnr'): 1.3552715766147616,
#  ('qam', 'sweat'): 6.90875477931522,
#  ('cagluc', 'neosynephrin'): -6.90875477931522,
#  ('influenc', 'jerk'): 6.90875477931522,
#  ('bromid', 'gabapentin'): 6.90875477931522,
#  ('mood', 'pneumococc'): 6.90875477931522,
#  ('ffp', 'vasopressin'): -6.90875477931522,
#  ('captopril', 'mellitu'): 6.90875477931522,
#  ('dnr', 'mean'): -6.90875477931522,
#  ('dobutamin', 'mean'): 6.90875477931522,
#  ('diflucan', 'jewelri'): 6.90875477931522,
#  ('dni', 'intiat'): -6.90875477931522,
#  ('hive', 'ppd'): 6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('captopril', 'core'): -6.90875477931522,
#  ('agon', 'rabbi'): -6.90875477931522,
#  ('fatti', 'xii'): 6.90875477931522,
#  ('conc', 'dni'): 6.90875477931522,
#  ('chip', 'palli'): 6.90875477931522,
#  ('lat', 'occupi'): 6.90875477931522,
#  ('hctz', 'sensat'): 6.90875477931522,
#  ('gastrojejunostomi', 'ligament'): 6.90875477931522,
#  ('fibrinogen', 'option'): -6.90875477931522,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('articul', 'dome'): 6.90875477931522,
#  ('bottl', 'pea'): 6.90875477931522,
#  ('dizzi', 'laryng'): 6.90875477931522,
#  ('bromid', 'nicotin'): 6.90875477931522,
#  ('hive', 'mood'): 6.90875477931522,
#  ('ambien', 'laryng'): 6.90875477931522,
#  ('captopril', 'palli'): 6.90875477931522,
#  ('foci', 'postop'): 6.90875477931522,
#  ('colonoscopi', 'hive'): 6.90875477931522,
#  ('od', 'uri'): 6.90875477931522,
#  ('perisplen', 'plerual'): 6.90875477931522,
#  ('clonazepam', 'strictur'): 6.90875477931522,
#  ('laminectomi', 'pleasant'): 6.90875477931522,
#  ('chol', 'dnr'): -6.90875477931522,
#  ('diaphoresi', 'xl'): 6.90875477931522,
#  ('oob', 'xanax'): 6.90875477931522,
#  ('peac', 'rabbi'): -6.90875477931522,
#  ('futil', 'platelet'): -6.90875477931522,
#  ('historian', 'unstabl'): 6.90875477931522,
#  ('banana', 'oob'): 6.90875477931522,
#  ('bottl', 'omeprazol'): 6.90875477931522,
#  ('autoset', 'hctz'): 6.90875477931522,
#  ('hypercapnia', 'norepinephrin'): -6.90875477931522,
#  ('wish', 'xii'): -6.90875477931522,
#  ('iddm', 'lat'): 6.90875477931522,
#  ('asthma', 'prilosec'): 6.90875477931522,
#  ('captopril', 'nephrolog'): 6.90875477931522,
#  ('levoph', 'vasopressin'): -1.121185584669415,
#  ('oob', 'thk'): 6.90875477931522,
#  ('bipolar', 'dni'): -2.2784985714248847,
#  ('echocardiogram', 'sweat'): 6.90875477931522,
#  ('natg', 'simpli'): 6.90875477931522,
#  ('habitu', 'shorter'): 6.90875477931522,
#  ('mso', 'pose'): -6.90875477931522,
#  ('escal', 'mso'): -6.90875477931522,
#  ('carvedilol', 'video'): 6.90875477931522,
#  ('flight', 'nephrolog'): 6.90875477931522,
#  ('pleasant', 'qtc'): 6.90875477931522,
#  ('laryng', 'lat'): 6.90875477931522,
#  ('bicarbon', 'weekli'): 6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('chemic', 'cocain'): 6.90875477931522,
#  ('db', 'incent'): 6.90875477931522,
#  ('phlegm', 'thiamin'): 6.90875477931522,
#  ('bronchovascular', 'tracheomalacia'): 6.90875477931522,
#  ('incis', 'romi'): 6.90875477931522,
#  ('abnl', 'dz'): 6.90875477931522,
#  ('cmo', 'prognosi'): -6.90875477931522,
#  ('ipf', 'occipit'): 0.0,
#  ('bromid', 'trazodon'): 6.90875477931522,
#  ('arrang', 'levoph'): -6.90875477931522,
#  ('ferritin', 'trazodon'): 6.90875477931522,
#  ('cloth', 'paperwork'): 6.90875477931522,
#  ('dizzi', 'venti'): 1.9390841839849136,
#  ('crrt', 'readmit'): 6.90875477931522,
#  ('aox', 'gastriti'): 6.90875477931522,
#  ('cs', 'oob'): 6.90875477931522,
#  ('dni', 'sweat'): 6.90875477931522,
#  ('cash', 'cloth'): 2.1509787690125033,
#  ('dobutamin', 'paralyt'): -6.90875477931522,
#  ('barium', 'vallecula'): 6.90875477931522,
#  ('echocardiogram', 'hygein'): 6.90875477931522,
#  ('dnr', 'robitussin'): -6.90875477931522,
#  ('pronounc', 'slice'): 6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('aricept', 'commod'): -6.90875477931522,
#  ('dex', 'levoph'): 6.90875477931522,
#  ('mottl', 'ppd'): 6.90875477931522,
#  ('pneumococc', 'splint'): 6.90875477931522,
#  ('burn', 'ppd'): 6.90875477931522,
#  ('breakfast', 'probe'): 6.90875477931522,
#  ('nifedipin', 'pleasant'): 6.90875477931522,
#  ('dni', 'pleuravac'): -6.90875477931522,
#  ('dnr', 'lotion'): -3.046848290615153,
#  ('dic', 'hypotherm'): -6.90875477931522,
#  ('levoph', 'mean'): 6.90875477931522,
#  ('dnr', 'palliat'): -6.90875477931522,
#  ('incent', 'romi'): 6.90875477931522,
#  ('forth', 'pleasant'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('fdp', 'platelet'): -6.90875477931522,
#  ('gait', 'mellitu'): 6.90875477931522,
#  ('epidur', 'norepinephrin'): 6.90875477931522,
#  ('ambien', 'ambul'): 6.90875477931522,
#  ('qtc', 'schizophrenia'): 6.90875477931522,
#  ('emper', 'moan'): 6.90875477931522,
#  ('habitu', 'occupi'): 6.90875477931522,
#  ('angiogram', 'fatti'): 6.90875477931522,
#  ('arrest', 'ethic'): -6.90875477931522,
#  ('qtc', 'retic'): 6.90875477931522,
#  ('ciwa', 'unasyn'): 6.90875477931522,
#  ('predict', 'zyprexa'): 6.90875477931522,
#  ('dnr', 'dz'): 6.90875477931522,
#  ('hunger', 'peac'): -6.90875477931522,
#  ('epigastr', 'splint'): 6.90875477931522,
#  ('ffp', 'sluggish'): -6.90875477931522,
#  ('azotemia', 'ggt'): -6.90875477931522,
#  ('subq', 'zoloft'): 6.90875477931522,
#  ('dni', 'requr'): 6.90875477931522,
#  ('ctx', 'diflucan'): 6.90875477931522,
#  ('flight', 'pleasantli'): 6.90875477931522,
#  ('anur', 'hypercapn'): -6.90875477931522,
#  ('dopamin', 'paperwork'): -6.90875477931522,
#  ('aricept', 'pivot'): -6.90875477931522,
#  ('moreov', 'scar'): 6.90875477931522,
#  ('dermat', 'pharmacolog'): 6.90875477931522,
#  ('mellitu', 'phlegm'): 6.90875477931522,
#  ('chair', 'xl'): 6.90875477931522,
#  ('clinician', 'dni'): 0.4046335072286383,
#  ('pronounc', 'underpenetr'): 6.90875477931522,
#  ('breakfast', 'panic'): 6.90875477931522,
#  ('articul', 'rhinorrhea'): 6.90875477931522,
#  ('cellcept', 'ultram'): 6.90875477931522,
#  ('compani', 'pleasant'): 6.90875477931522,
#  ('parastern', 'unavail'): 6.90875477931522,
#  ('bottl', 'motor'): 6.90875477931522,
#  ('hilum', 'lat'): 6.90875477931522,
#  ('epigastr', 'fibrinogen'): 6.90875477931522,
#  ('nimv', 'religi'): -6.90875477931522,
#  ('prognosi', 'vasopressin'): -6.90875477931522,
#  ('levoph', 'olanzapin'): 6.90875477931522,
#  ('dz', 'lat'): 6.90875477931522,
#  ('mjmgb', 'plate'): 6.90875477931522,
#  ('gabapentin', 'imbal'): 6.90875477931522,
#  ('fc', 'osa'): 6.90875477931522,
#  ('solut', 'treatement'): 6.90875477931522,
#  ('hsq', 'precordium'): 6.90875477931522,
#  ('compani', 'gabapentin'): 6.90875477931522,
#  ('anaphylaxi', 'subq'): 6.90875477931522,
#  ('barium', 'nectar'): 6.90875477931522,
#  ('sweat', 'ultrafiltr'): 6.90875477931522,
#  ('dni', 'expir'): -6.90875477931522,
#  ('neo', 'neosynephrin'): -6.90875477931522,
#  ('dnr', 'inspit'): 6.90875477931522,
#  ('mso', 'pronounc'): -6.90875477931522,
#  ('gentamycin', 'illeu'): -6.90875477931522,
#  ('futil', 'icter'): -6.90875477931522,
#  ('laryng', 'motor'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('thrive', 'weekli'): 6.90875477931522,
#  ('burn', 'mva'): 6.90875477931522,
#  ('hook', 'scar'): 6.90875477931522,
#  ('captopril', 'yel'): 6.90875477931522,
#  ('colonoscopi', 'retic'): 6.90875477931522,
#  ('phlegm', 'stair'): 6.90875477931522,
#  ('commod', 'spirit'): 6.90875477931522,
#  ('cracker', 'spiromet'): -6.90875477931522,
#  ('mso', 'unstabl'): -6.90875477931522,
#  ('lusb', 'wish'): 6.90875477931522,
#  ('arrest', 'jejunum'): -6.90875477931522,
#  ('predict', 'prilosec'): 6.90875477931522,
#  ('crack', 'lotion'): 6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('chair', 'xanax'): 6.90875477931522,
#  ('ferritin', 'seriou'): 6.90875477931522,
#  ('para', 'peribronchovascular'): -6.90875477931522,
#  ('ffp', 'myeloma'): 6.90875477931522,
#  ('pivot', 'wallet'): -6.90875477931522,
#  ('endur', 'pod'): 6.90875477931522,
#  ('arrest', 'asystol'): -6.90875477931522,
#  ('db', 'habitu'): 6.90875477931522,
#  ('aricept', 'dnr'): 0.1428142402977353,
#  ('rhinorrhea', 'xl'): 6.90875477931522,
#  ('mean', 'underneath'): -6.90875477931522,
#  ('autopsi', 'dni'): -6.90875477931522,
#  ('money', 'xl'): 6.90875477931522,
#  ('strictur', 'tracheomalacia'): 6.90875477931522,
#  ('compani', 'predict'): 6.90875477931522,
#  ('bronchovascular', 'habitu'): 6.90875477931522,
#  ('dd', 'inspit'): 6.90875477931522,
#  ('opiat', 'rhinorrhea'): 6.90875477931522,
#  ('captopril', 'hsq'): -6.90875477931522,
#  ('lpm', 'myeloma'): -1.3825560390092835,
#  ('dizzi', 'dni'): 6.90875477931522,
#  ('levoph', 'thrive'): 6.90875477931522,
#  ('rhinorrhea', 'stair'): 6.90875477931522,
#  ('habitu', 'unasyn'): 6.90875477931522,
#  ('aricept', 'seroquel'): 6.90875477931522,
#  ('erythro', 'pleasant'): 6.90875477931522,
#  ('asthma', 'escal'): 6.90875477931522,
#  ('ppd', 'rm'): 6.90875477931522,
#  ('nephrolog', 'option'): -6.90875477931522,
#  ('fibrinogen', 'hung'): -6.90875477931522,
#  ('priest', 'wish'): -6.90875477931522,
#  ('mean', 'stg'): -6.90875477931522,
#  ('phenylephrin', 'rhinorrhea'): 6.90875477931522,
#  ('intent', 'nifedipin'): 6.90875477931522,
#  ('mellitu', 'osa'): 6.90875477931522,
#  ('bronchovascular', 'uri'): 6.90875477931522,
#  ('dni', 'heroic'): -6.90875477931522,
#  ('readmit', 'seroquel'): 6.90875477931522,
#  ('bank', 'pleasant'): 6.90875477931522,
#  ('flight', 'phlegm'): 6.90875477931522,
#  ('derecruit', 'levoph'): -6.90875477931522,
#  ('epigastr', 'unstabl'): 6.90875477931522,
#  ('oob', 'predict'): 6.90875477931522,
#  ('anur', 'chair'): -6.90875477931522,
#  ('dni', 'nifedipin'): 1.8654833430478823,
#  ('foci', 'magnevist'): 6.90875477931522,
#  ('oncologist', 'prilosec'): 6.90875477931522,
#  ('dyslipidemia', 'thiamin'): 6.90875477931522,
#  ('ardsnet', 'bicarbon'): -6.90875477931522,
#  ('hsq', 'splint'): 6.90875477931522,
#  ('dizzi', 'money'): 6.90875477931522,
#  ('dizzi', 'platelet'): 6.90875477931522,
#  ('among', 'ipf'): -6.90875477931522,
#  ('hilum', 'perisplen'): -6.90875477931522,
#  ('anur', 'trazodon'): 6.90875477931522,
#  ('bell', 'cellcept'): 6.90875477931522,
#  ('option', 'thrive'): -6.90875477931522,
#  ('oob', 'sweat'): 6.90875477931522,
#  ('commod', 'kerlix'): 6.90875477931522,
#  ('breakfast', 'nitroglycerin'): 6.90875477931522,
#  ('ambul', 'dni'): 1.3825560390092835,
#  ('expir', 'mso'): -6.90875477931522,
#  ('oob', 'stair'): 6.90875477931522,
#  ('hugger', 'wma'): 6.90875477931522,
#  ('ambul', 'seroquel'): 6.90875477931522,
#  ('arrest', 'clonazepam'): 6.90875477931522,
#  ('aox', 'broader'): 6.90875477931522,
#  ('dietari', 'romi'): 6.90875477931522,
#  ('oob', 'uncoop'): 6.90875477931522,
#  ('bicarbon', 'oligur'): -6.90875477931522,
#  ('dopamin', 'pitressin'): -6.90875477931522,
#  ('ggo', 'iddm'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('judgement', 'uri'): 6.90875477931522,
#  ('life', 'pea'): -6.90875477931522,
#  ('crrt', 'ffp'): -6.90875477931522,
#  ('anaphylaxi', 'thiamin'): 6.90875477931522,
#  ('mellitu', 'rhinorrhea'): 6.90875477931522,
#  ('bromid', 'readmit'): 6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('dobutamin', 'intiat'): 6.90875477931522,
#  ('db', 'tubular'): 6.90875477931522,
#  ('gait', 'thirst'): 6.90875477931522,
#  ('aox', 'clonidin'): 6.90875477931522,
#  ('oncologist', 'romi'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('bronchovascular', 'fatti'): 6.90875477931522,
#  ('dead', 'gurgl'): -6.90875477931522,
#  ('burn', 'dni'): 6.90875477931522,
#  ('fu', 'prilosec'): 6.90875477931522,
#  ('hsq', 'sweat'): 6.90875477931522,
#  ('hospic', 'palli'): -0.2660901613908308,
#  ('dni', 'thk'): 6.90875477931522,
#  ('amb', 'pleasant'): 6.90875477931522,
#  ('judgement', 'pleasant'): -6.90875477931522,
#  ('dyslipidemia', 'gastrojejunostomi'): 6.90875477931522,
#  ('phenylephrin', 'prognosi'): -6.90875477931522,
#  ('duski', 'prognosi'): -6.90875477931522,
#  ('dnr', 'dyslipidemia'): 6.90875477931522,
#  ('vallecula', 'video'): 6.90875477931522,
#  ('sensat', 'suprapub'): 6.90875477931522,
#  ('cdb', 'pleasantli'): 6.90875477931522,
#  ('incent', 'syst'): 6.90875477931522,
#  ('thrive', 'wish'): 6.90875477931522,
#  ('flight', 'readmit'): 6.90875477931522,
#  ('chair', 'vagu'): 6.90875477931522,
#  ('fibrinogen', 'nicotin'): 6.90875477931522,
#  ('crack', 'rm'): 6.90875477931522,
#  ('death', 'sweat'): 6.90875477931522,
#  ('fibrinogen', 'hypotherm'): -6.90875477931522,
#  ('clinician', 'stitch'): 6.90875477931522,
#  ('ferrou', 'omeprazol'): 6.90875477931522,
#  ('grim', 'prognosi'): -6.90875477931522,
#  ('diaphoresi', 'osa'): 6.90875477931522,
#  ('pleasant', 'rigor'): 6.90875477931522,
#  ('ciwa', 'sibl'): 6.90875477931522,
#  ('aaox', 'gown'): -6.90875477931522,
#  ('dead', 'dopamin'): -6.90875477931522,
#  ('ambien', 'ferrou'): 6.90875477931522,
#  ('declin', 'hctz'): 6.90875477931522,
#  ('rehabilit', 'rhinorrhea'): 6.90875477931522,
#  ('im', 'nifedipin'): 6.90875477931522,
#  ('endplat', 'foci'): 6.90875477931522,
#  ('opinion', 'palliat'): -6.90875477931522,
#  ('hook', 'rhochor'): 6.90875477931522,
#  ('nonlabor', 'pneumococc'): 6.90875477931522,
#  ('death', 'mso'): -6.90875477931522,
#  ('dopamin', 'pose'): -6.90875477931522,
#  ('cardiovert', 'neosynephrin'): -6.90875477931522,
#  ('chair', 'death'): 6.90875477931522,
#  ('fatti', 'hilum'): 0.6916505477038827,
#  ('sensat', 'signatur'): 6.90875477931522,
#  ('foci', 'gadolinium'): 6.90875477931522,
#  ('klonopin', 'pleasant'): 6.90875477931522,
#  ('hypercapn', 'neo'): 6.90875477931522,
#  ('icter', 'oncologist'): 6.90875477931522,
#  ('gown', 'sundown'): -6.90875477931522,
#  ('clonidin', 'dz'): 6.90875477931522,
#  ('brb', 'chair'): 6.90875477931522,
#  ('herp', 'sensat'): 6.90875477931522,
#  ('gc', 'mva'): 6.90875477931522,
#  ('phenylephrin', 'ruptur'): 6.90875477931522,
#  ('declin', 'predict'): -6.90875477931522,
#  ('dnr', 'illeu'): -6.90875477931522,
#  ('bipolar', 'strictur'): 6.90875477931522,
#  ('neoplast', 'palli'): 6.90875477931522,
#  ('anaphylaxi', 'pcv'): -6.90875477931522,
#  ('magnevist', 'occipit'): 6.90875477931522,
#  ('gabapentin', 'unstabl'): 6.90875477931522,
#  ('dysynchron', 'platelet'): -6.90875477931522,
#  ('laryng', 'pathologist'): 6.90875477931522,
#  ('criticar', 'pinpoint'): -6.90875477931522,
#  ('cmo', 'levoph'): -1.3825560390092835,
#  ('clonidin', 'friction'): 6.90875477931522,
#  ('lw', 'pca'): 6.90875477931522,
#  ('lat', 'syncop'): 6.90875477931522,
#  ('mrcp', 'wma'): -6.90875477931522,
#  ('goc', 'moan'): -6.90875477931522,
#  ('angiogram', 'deploy'): 6.90875477931522,
#  ('barium', 'pharyng'): 6.90875477931522,
#  ('bell', 'dnr'): 6.90875477931522,
#  ('arrest', 'neo'): -6.90875477931522,
#  ('osa', 'silent'): 6.90875477931522,
#  ('contd', 'dizzi'): 6.90875477931522,
#  ('osteoblast', 'scar'): -6.90875477931522,
#  ('dni', 'inspit'): 6.90875477931522,
#  ('ppd', 'xii'): 6.90875477931522,
#  ('homogen', 'nephrogram'): 0.6916505477038827,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('asthma', 'mean'): 6.90875477931522,
#  ('bottl', 'currenlti'): 6.90875477931522,
#  ('profound', 'sweat'): 6.90875477931522,
#  ('ambul', 'permiss'): 6.90875477931522,
#  ('cash', 'klonopin'): 6.90875477931522,
#  ('director', 'zero'): 6.90875477931522,
#  ('puff', 'thrive'): 6.90875477931522,
#  ('epidur', 'fibrinogen'): 6.90875477931522,
#  ('lift', "sxn'ing"): 6.90875477931522,
#  ('fibrinogen', 'icter'): -6.90875477931522,
#  ('hugger', 'lpm'): -6.90875477931522,
#  ('epigastr', 'ppd'): 6.90875477931522,
#  ('asthma', 'gait'): 6.90875477931522,
#  ('fibrinogen', 'impli'): 6.90875477931522,
#  ('liw', 'unstabl'): -6.90875477931522,
#  ('aricept', 'resucit'): 6.90875477931522,
#  ('chb', 'zyprexa'): 6.90875477931522,
#  ('intent', 'sweat'): 6.90875477931522,
#  ('cyanot', 'furhter'): -6.90875477931522,
#  ('dermat', 'sarna'): 6.90875477931522,
#  ('dermat', 'scab'): 6.90875477931522,
#  ('ba', 'qam'): 6.90875477931522,
#  ('bromid', 'trabecul'): 6.90875477931522,
#  ('cdb', 'phlegm'): 6.90875477931522,
#  ('norepinephrin', 'zoloft'): 6.90875477931522,
#  ('ba', 'puff'): 6.90875477931522,
#  ('align', 'epidur'): 6.90875477931522,
#  ('dnr', 'ofm'): 6.90875477931522,
#  ('money', 'probe'): 6.90875477931522,
#  ('arrest', 'trazodon'): -6.90875477931522,
#  ('mellitu', 'pod'): 6.90875477931522,
#  ('oob', 'unsteadi'): 6.90875477931522,
#  ('osa', 'seat'): 6.90875477931522,
#  ('breakfast', 'fatti'): 6.90875477931522,
#  ('caspofungin', 'hive'): 6.90875477931522,
#  ('aox', 'mind'): 6.90875477931522,
#  ('cocain', 'rm'): 6.90875477931522,
#  ('caspofungin', 'metoclopramid'): 6.90875477931522,
#  ('nitroglycerin', 'pleasant'): 6.90875477931522,
#  ('bill', 'hctz'): 6.90875477931522,
#  ('coarctat', 'subcost'): 1.095952712632351,
#  ('ambien', 'pharmacolog'): 6.90875477931522,
#  ('eg', 'pronounc'): 6.90875477931522,
#  ('arrest', 'venti'): 6.90875477931522,
#  ('ba', 'hypothermia'): 6.90875477931522,
#  ('death', 'declin'): 0.4046335072286383,
#  ('cmo', 'suffer'): -6.90875477931522,
#  ('acidot', 'prognosi'): -6.90875477931522,
#  ('bottl', 'mottl'): 6.90875477931522,
#  ('icter', 'platelet'): -6.90875477931522,
#  ('commod', 'dni'): -1.095952712632351,
#  ('nectar', 'vallecula'): 6.90875477931522,
#  ('mso', 'neo'): 6.90875477931522,
#  ('dni', 'moan'): -0.5378679732223673,
#  ('asthma', 'piriform'): 6.90875477931522,
#  ('dead', 'unrel'): -6.90875477931522,
#  ('compani', 'dnr'): 6.90875477931522,
#  ('bipolar', 'klonopin'): 6.90875477931522,
#  ('rhinorrhea', 'sibl'): 6.90875477931522,
#  ('lat', 'plate'): 6.90875477931522,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('dz', 'suffer'): 6.90875477931522,
#  ('agon', 'deterior'): -6.90875477931522,
#  ('cyanot', 'eyelid'): -6.90875477931522,
#  ('^th', 'omeprazol'): 6.90875477931522,
#  ('ambul', 'sweat'): 6.90875477931522,
#  ('acidot', 'dic'): -6.90875477931522,
#  ('klonopin', 'osa'): 6.90875477931522,
#  ('svv', 'vasopressin'): -6.90875477931522,
#  ('death', 'scar'): 6.90875477931522,
#  ('ambul', 'aricept'): 6.90875477931522,
#  ('hospic', 'money'): 6.90875477931522,
#  ('dnr', 'uri'): 6.90875477931522,
#  ('lat', 'sweat'): 6.90875477931522,
#  ('stair', 'vp'): 6.90875477931522,
#  ('life', 'ppd'): 6.90875477931522,
#  ('pose', 'prognosi'): -6.90875477931522,
#  ('ppd', 'thrive'): 6.90875477931522,
#  ('escal', 'prognosi'): -6.90875477931522,
#  ('amb', 'oob'): 6.90875477931522,
#  ('cefapim', 'db'): 6.90875477931522,
#  ('nonlabor', 'subq'): 6.90875477931522,
#  ('crack', 'habitu'): 6.90875477931522,
#  ('fibrinogen', 'trazodon'): -6.90875477931522,
#  ('hctz', 'xanax'): 6.90875477931522,
#  ('articul', 'sweat'): 6.90875477931522,
#  ('aliv', 'dead'): 6.90875477931522,
#  ('oncologist', 'synthet'): 6.90875477931522,
#  ('anuria', 'dead'): -6.90875477931522,
#  ('acc', 'declin'): 6.90875477931522,
#  ('profound', 'romi'): 6.90875477931522,
#  ('neoplast', 'slice'): -6.90875477931522,
#  ('incis', 'pod'): 6.90875477931522,
#  ('ambul', 'pose'): 6.90875477931522,
#  ('adenocarcinoma', 'distort'): 6.90875477931522,
#  ('arthrit', 'commod'): 6.90875477931522,
#  ('chair', 'prec'): 6.90875477931522,
#  ('bromid', 'im'): 6.90875477931522,
#  ('conc', 'mso'): -6.90875477931522,
#  ('gabapentin', 'morbid'): 6.90875477931522,
#  ('fatti', 'ferritin'): 6.90875477931522,
#  ('palli', 'pneumonectomi'): 6.90875477931522,
#  ('osa', 'romi'): 6.90875477931522,
#  ('declin', 'norepinephrin'): -6.90875477931522,
#  ('chair', 'ofm'): 6.90875477931522,
#  ('bipolar', 'ferritin'): 6.90875477931522,
#  ('jewelri', 'money'): 2.5001408943598484,
#  ('declin', 'hypothermia'): -6.90875477931522,
#  ('deterior', 'nimv'): -6.90875477931522,
#  ('lat', 'splint'): 6.90875477931522,
#  ('gvhd', 'pleasant'): 6.90875477931522,
#  ('bair', 'paralyt'): 6.90875477931522,
#  ('nectar', 'subdur'): 6.90875477931522,
#  ('aricept', 'pyuria'): 6.90875477931522,
#  ('cpr', 'crrt'): -6.90875477931522,
#  ('ctx', 'resucit'): 6.90875477931522,
#  ('bipolar', 'lotion'): -6.90875477931522,
#  ('neo', 'recalibr'): 6.90875477931522,
#  ('ba', 'romi'): 6.90875477931522,
#  ('declar', 'dnr'): -6.90875477931522,
#  ('lusb', 'romi'): 6.90875477931522,
#  ('asthma', 'uri'): 6.90875477931522,
#  ('gait', 'pea'): -6.90875477931522,
#  ('duski', 'palli'): -6.90875477931522,
#  ('klonopin', 'oob'): 6.90875477931522,
#  ('hemangioma', 'phasic'): 6.90875477931522,
#  ('mtg', 'seroquel'): 6.90875477931522,
#  ('norepinephrin', 'refractori'): 6.90875477931522,
#  ('lat', 'osa'): 6.90875477931522,
#  ('burn', 'schizophrenia'): 6.90875477931522,
#  ('anur', 'myeloma'): 6.90875477931522,
#  ('angiogram', 'futil'): 6.90875477931522,
#  ('dni', 'struggl'): -6.90875477931522,
#  ('klonopin', 'schizophrenia'): 6.90875477931522,
#  ('binder', 'dnr'): 6.90875477931522,
#  ('bank', 'dnr'): 6.90875477931522,
#  ('predict', 'suffer'): -6.90875477931522,
#  ('agon', 'cmo'): -6.90875477931522,
#  ('dopamin', 'pronounc'): -6.90875477931522,
#  ('im', 'ppd'): 6.90875477931522,
#  ('asthma', 'cocain'): 6.90875477931522,
#  ('prilosec', 'wish'): 6.90875477931522,
#  ('paperwork', 'sweat'): 6.90875477931522,
#  ('adam', 'neo'): -6.90875477931522,
#  ('colonoscopi', 'readdress'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('judgement', 'rememb'): 6.90875477931522,
#  ('dead', 'dnr'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('fu', 'xl'): 6.90875477931522,
#  ('^th', 'stitch'): 6.90875477931522,
#  ('colonoscopi', 'wish'): 6.90875477931522,
#  ('adenocarcinoma', 'laryng'): 6.90875477931522,
#  ('osa', 'pleasant'): 6.90875477931522,
#  ('dni', 'mva'): 6.90875477931522,
#  ('stitch', 'video'): 6.90875477931522,
#  ('refractori', 'thrive'): 6.90875477931522,
#  ('aox', 'xii'): 6.90875477931522,
#  ('fibrinogen', 'xl'): 6.90875477931522,
#  ('ctx', 'historian'): 6.90875477931522,
#  ('aricept', 'gentamycin'): -6.90875477931522,
#  ('nocturn', 'trazodon'): 6.90875477931522,
#  ('palli', 'struggl'): -6.90875477931522,
#  ('cpr', 'escal'): -6.90875477931522,
#  ('cocain', 'pneumococc'): 6.90875477931522,
#  ('muddi', 'uri'): 6.90875477931522,
#  ('platelet', 'profound'): 6.90875477931522,
#  ('ctx', 'neo'): 6.90875477931522,
#  ('gabapentin', 'gait'): 6.90875477931522,
#  ('historian', 'romi'): 6.90875477931522,
#  ('cardiovert', 'dysynchron'): -6.90875477931522,
#  ('burn', 'ctx'): 6.90875477931522,
#  ('gastriti', 'xii'): 6.90875477931522,
#  ('anuria', 'unstabl'): -6.90875477931522,
#  ('lac', 'soln'): 6.90875477931522,
#  ('bicarbon', 'paralyt'): -6.90875477931522,
#  ('aricept', 'paperwork'): 6.90875477931522,
#  ('chair', 'cloth'): 6.90875477931522,
#  ('ctx', 'readdress'): 6.90875477931522,
#  ('agon', 'mortum'): -6.90875477931522,
#  ('foci', 'subdur'): 6.90875477931522,
#  ('historian', 'signatur'): 6.90875477931522,
#  ('asthma', 'mva'): 6.90875477931522,
#  ('hsq', 'xii'): 6.90875477931522,
#  ('bromid', 'lymphangit'): 6.90875477931522,
#  ('ciwa', 'neoplast'): 6.90875477931522,
#  ('dead', 'prognosi'): -6.90875477931522,
#  ('ambul', 'lac'): 6.90875477931522,
#  ('foci', 'occipit'): 0.0,
#  ('paralyt', 'phenylephrin'): -6.90875477931522,
#  ('cup', 'oob'): 6.90875477931522,
#  ('death', 'romi'): 6.90875477931522,
#  ('incent', 'levoph'): 6.90875477931522,
#  ('osa', 'uri'): 6.90875477931522,
#  ('declin', 'wish'): 0.509761227710204,
#  ('cefapim', 'dnr'): 6.90875477931522,
#  ('gait', 'rm'): 6.90875477931522,
#  ('ambul', 'twitch'): -6.90875477931522,
#  ('schizophrenia', 'xanax'): 6.90875477931522,
#  ('aricept', 'ctx'): 6.90875477931522,
#  ('pose', 'vasoconstrict'): -6.90875477931522,
#  ('aox', 'ruptur'): 6.90875477931522,
#  ('epigastr', 'homogen'): 6.90875477931522,
#  ('commod', 'lotion'): 6.90875477931522,
#  ('hypotherm', 'scopalamin'): -6.90875477931522,
#  ('asystol', 'cmo'): -6.90875477931522,
#  ('massag', 'refractori'): 6.90875477931522,
#  ('hung', 'pea'): -6.90875477931522,
#  ('romi', 'scar'): 6.90875477931522,
#  ('hilum', 'zyprexa'): -6.90875477931522,
#  ('dnr', 'nocturn'): 6.90875477931522,
#  ('incent', 'rm'): 6.90875477931522,
#  ('seroquel', 'subdur'): 6.90875477931522,
#  ('dead', 'pulseless'): -6.90875477931522,
#  ('hospic', 'stg'): -6.90875477931522,
#  ('silent', 'treitz'): -6.90875477931522,
#  ('dizzi', 'ultram'): 6.90875477931522,
#  ('deterior', 'prognosi'): -6.90875477931522,
#  ('dnr', 'osa'): 0.11100317119789695,
#  ('oncologist', 'refractori'): 6.90875477931522,
#  ('historian', 'jewelri'): 6.90875477931522,
#  ('qtc', 'rhinorrhea'): 6.90875477931522,
#  ('ciwa', 'rememb'): 6.90875477931522,
#  ('incis', 'levoph'): 6.90875477931522,
#  ('dni', 'norepinephrin'): -6.90875477931522,
#  ('esld', 'venti'): 6.90875477931522,
#  ('declin', 'park'): 6.90875477931522,
#  ('pea', 'phenylephrin'): -6.90875477931522,
#  ('palli', 'postop'): 6.90875477931522,
#  ('liw', 'pose'): -6.90875477931522,
#  ('azotemia', 'wma'): -6.90875477931522,
#  ('rhochor', 'scar'): 6.90875477931522,
#  ('pharyng', 'vallecula'): 6.90875477931522,
#  ('anuria', 'cpr'): -6.90875477931522,
#  ('dnr', 'unasyn'): 6.90875477931522,
#  ('asthma', 'nicotin'): 6.90875477931522,
#  ('hsq', 'phlegm'): 6.90875477931522,
#  ('adenosin', 'dni'): 6.90875477931522,
#  ('bill', 'bromid'): 6.90875477931522,
#  ('acv', 'levoph'): 6.90875477931522,
#  ('laryng', 'vallecula'): 6.90875477931522,
#  ('dizzi', 'sweat'): 6.90875477931522,
#  ('acc', 'ctx'): 6.90875477931522,
#  ('deterior', 'mrg'): 6.90875477931522,
#  ('gastriti', 'motor'): 6.90875477931522,
#  ('osa', 'xl'): 6.90875477931522,
#  ('para', 'slice'): 6.90875477931522,
#  ('commod', 'signatur'): -6.90875477931522,
#  ('hsq', 'sensat'): 6.90875477931522,
#  ('deterior', 'levoph'): 2.09609753878805,
#  ('hurt', 'osa'): 6.90875477931522,
#  ('nitroglycerin', 'readdress'): 6.90875477931522,
#  ('defibril', 'tran'): 6.90875477931522,
#  ('intent', 'ppd'): 6.90875477931522,
#  ('breakfast', 'hsq'): 6.90875477931522,
#  ('petechia', 'rhinorrhea'): -6.90875477931522,
#  ('exophyt', 'lusb'): -6.90875477931522,
#  ('asthma', 'mellitu'): 6.90875477931522,
#  ('breakfast', 'oob'): 6.90875477931522,
#  ('bicarbon', 'laminectomi'): 6.90875477931522,
#  ('cisatracurium', 'paralyt'): -6.90875477931522,
#  ('bill', 'lotion'): 6.90875477931522,
#  ('anuria', 'brb'): -6.90875477931522,
#  ('cmo', 'rabbi'): -6.90875477931522,
#  ('rm', 'venti'): 6.90875477931522,
#  ('vasoconstrict', 'vasopressin'): -6.90875477931522,
#  ('asthma', 'crack'): 6.90875477931522,
#  ('incent', 'synthet'): -6.90875477931522,
#  ('depth', 'levoph'): 6.90875477931522,
#  ('dome', 'foci'): 6.90875477931522,
#  ('gadolinium', 'magnevist'): 6.90875477931522,
#  ('mellitu', 'nocturn'): 6.90875477931522,
#  ('anaphylaxi', 'gadolinium'): 6.90875477931522,
#  ('hepatobiliari', 'wma'): -6.90875477931522,
#  ('chair', 'rusti'): 6.90875477931522,
#  ('expir', 'peribronchovascular'): 6.90875477931522,
#  ('burn', 'intiat'): 6.90875477931522,
#  ('director', 'young'): 6.90875477931522,
#  ('gait', 'unavail'): 6.90875477931522,
#  ('anaphylaxi', 'seroquel'): 6.90875477931522,
#  ('bicarbon', 'wma'): -6.90875477931522,
#  ('laminectomi', 'paco'): 6.90875477931522,
#  ('hive', 'signatur'): 6.90875477931522,
#  ('norepinephrin', 'oligur'): -6.90875477931522,
#  ('bronchovascular', 'crowd'): 1.462247919771027,
#  ('cvvh', 'sluggishli'): -6.90875477931522,
#  ('consciou', 'core'): 6.90875477931522,
#  ('foci', 'neo'): 6.90875477931522,
#  ('dni', 'friction'): 6.90875477931522,
#  ('habitu', 'mean'): 6.90875477931522,
#  ('osa', 'suprapub'): 6.90875477931522,
#  ('crack', 'klonopin'): 6.90875477931522,
#  ('nicotin', 'tran'): 6.90875477931522,
#  ('cyanot', 'lw'): -6.90875477931522,
#  ('contractur', 'vasopressor'): -6.90875477931522,
#  ('pleasant', 'retic'): 6.90875477931522,
#  ('chair', 'readmit'): 6.90875477931522,
#  ('sibl', 'unstabl'): -6.90875477931522,
#  ('pneumococc', 'zyprexa'): 6.90875477931522,
#  ('furhter', 'twitch'): -6.90875477931522,
#  ('pathologist', 'vallecula'): 6.90875477931522,
#  ('moan', 'zyprexa'): 6.90875477931522,
#  ('historian', 'xii'): 6.90875477931522,
#  ('abnl', 'occipit'): 6.90875477931522,
#  ('arrest', 'pulseless'): -6.90875477931522,
#  ('cdb', 'commod'): 6.90875477931522,
#  ('cash', 'dni'): -0.4046335072286383,
#  ('bipolar', 'zyprexa'): 6.90875477931522,
#  ('ppd', 'spacer'): 6.90875477931522,
#  ('cash', 'palli'): 6.90875477931522,
#  ('dni', 'zyprexa'): 1.6812038300138494,
#  ('paralyt', 'vasopressin'): -6.90875477931522,
#  ('mva', 'panic'): 6.90875477931522,
#  ('aliv', 'articul'): 6.90875477931522,
#  ('clonidin', 'unasyn'): 6.90875477931522,
#  ('ashen', 'declin'): 6.90875477931522,
#  ('rehabilit', 'young'): 6.90875477931522,
#  ('gait', 'thiamin'): 6.90875477931522,
#  ('cloth', 'declin'): 6.90875477931522,
#  ('dyslipidemia', 'lat'): 6.90875477931522,
#  ('dnr', 'suffer'): 4.804452358089091,
#  ('nicotin', 'prilosec'): 6.90875477931522,
#  ('aox', 'dz'): 6.90875477931522,
#  ('mellitu', 'retic'): 6.90875477931522,
#  ('bipolar', 'historian'): 6.90875477931522,
#  ('dnr', 'mrg'): 6.90875477931522,
#  ('dni', 'mood'): 6.90875477931522,
#  ('pneumococc', 'pod'): 6.90875477931522,
#  ('ggt', 'rhinorrhea'): -6.90875477931522,
#  ('dni', 'stair'): 6.90875477931522,
#  ('incent', 'mottl'): 6.90875477931522,
#  ('pod', 'soln'): 6.90875477931522,
#  ('cmo', 'viabl'): -6.90875477931522,
#  ('gentamycin', 'hugger'): -6.90875477931522,
#  ('dnr', 'quadrent'): 6.90875477931522,
#  ('morbid', 'osa'): 6.90875477931522,
#  ('opinion', 'prognosi'): -6.90875477931522,
#  ('chair', 'pivot'): 6.90875477931522,
#  ('aox', 'oncologist'): 6.90875477931522,
#  ('readmit', 'soln'): 6.90875477931522,
#  ('brb', 'unstabl'): -6.90875477931522,
#  ('ferritin', 'qam'): 6.90875477931522,
#  ('religi', 'trazodon'): -6.90875477931522,
#  ('cardiovert', 'tranfer'): 6.90875477931522,
#  ('ctx', 'ruptur'): 6.90875477931522,
#  ('paperwork', 'wish'): 6.90875477931522,
#  ('prilosec', 'sweat'): 6.90875477931522,
#  ('absorb', 'omeprazol'): 6.90875477931522,
#  ('lusb', 'nifedipin'): 6.90875477931522,
#  ('pastor', 'pea'): -6.90875477931522,
#  ('lift', 'mrg'): 6.90875477931522,
#  ('coach', 'soln'): 6.90875477931522,
#  ('anur', 'quietli'): -6.90875477931522,
#  ('rememb', 'sensat'): 6.90875477931522,
#  ('gait', 'hive'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('clonidin', 'sweat'): 6.90875477931522,
#  ('institut', 'smooth'): 6.90875477931522,
#  ('levoph', 'modifi'): 6.90875477931522,
#  ('homogen', 'ipf'): 6.90875477931522,
#  ('hypotherm', 'sluggish'): -6.90875477931522,
#  ('azotemia', 'dic'): -6.90875477931522,
#  ('fatti', 'syncop'): 6.90875477931522,
#  ('commod', 'jewelri'): -6.90875477931522,
#  ('ambul', 'phlegm'): 6.90875477931522,
#  ('itchi', 'palli'): 6.90875477931522,
#  ('pleasant', 'scab'): 6.90875477931522,
#  ('hive', 'lymphangit'): 6.90875477931522,
#  ('neo', 'phenylephrin'): -0.2463623386430715,
#  ('lusb', 'mellitu'): 6.90875477931522,
#  ('deterior', 'option'): -6.90875477931522,
#  ('grave', 'prognosi'): -0.6916505477038827,
#  ('caspofungin', 'fibrinogen'): 6.90875477931522,
#  ('thrive', 'trazodon'): 6.90875477931522,
#  ('readmit', 'xanax'): 6.90875477931522,
#  ('habitu', 'thiamin'): 6.90875477931522,
#  ('dermat', 'romi'): 6.90875477931522,
#  ('mva', 'scl'): 6.90875477931522,
#  ('declin', 'sweat'): 6.90875477931522,
#  ('ethic', 'neo'): -6.90875477931522,
#  ('freeli', 'spill'): 6.90875477931522,
#  ('fax', 'pleasant'): 6.90875477931522,
#  ('mrg', 'ppd'): 6.90875477931522,
#  ('life', 'religi'): -6.90875477931522,
#  ('declin', 'oligur'): -6.90875477931522,
#  ('hsq', 'hypotherm'): -6.90875477931522,
#  ('arrest', 'asthma'): 6.90875477931522,
#  ('ctx', 'signatur'): 6.90875477931522,
#  ('dnr', 'proph'): 6.90875477931522,
#  ('moan', 'venti'): -6.90875477931522,
#  ('asthma', 'director'): 6.90875477931522,
#  ('levoph', 'lpm'): 6.90875477931522,
#  ('dic', 'hung'): -6.90875477931522,
#  ('chair', 'cocain'): 6.90875477931522,
#  ('dnr', 'tremul'): 6.90875477931522,
#  ('among', 'barium'): -6.90875477931522,
#  ('gait', 'hung'): -6.90875477931522,
#  ('fibrinogen', 'itchi'): -6.90875477931522,
#  ('chair', 'intent'): 6.90875477931522,
#  ('occupi', 'seriou'): 6.90875477931522,
#  ('agreement', 'heroic'): -6.90875477931522,
#  ('pneumococc', 'rpr'): 6.90875477931522,
#  ('iddm', 'purpl'): 6.90875477931522,
#  ('dead', 'expir'): -6.90875477931522,
#  ('asthma', 'pleasant'): 6.90875477931522,
#  ('deterior', 'mottl'): -6.90875477931522,
#  ('brb', 'tran'): 6.90875477931522,
#  ('spill', 'videofluoroscopi'): 6.90875477931522,
#  ('ctx', 'itchi'): 6.90875477931522,
#  ('adenosin', 'tcdb'): 6.90875477931522,
#  ('dz', 'hive'): 6.90875477931522,
#  ('echocardiogram', 'fatti'): 6.90875477931522,
#  ('anuria', 'synthet'): 6.90875477931522,
#  ('echocardiogram', 'omeprazol'): 6.90875477931522,
#  ('metoclopramid', 'soln'): 6.90875477931522,
#  ('agon', 'venti'): 6.90875477931522,
#  ('klonopin', 'led'): 6.90875477931522,
#  ('moan', 'rabbi'): -6.90875477931522,
#  ('motor', 'sibl'): 6.90875477931522,
#  ('clonazepam', 'hive'): 6.90875477931522,
#  ('dic', 'pneumonectomi'): -6.90875477931522,
#  ('sluggishli', 'vasopressin'): -6.90875477931522,
#  ('fdp', 'neo'): -6.90875477931522,
#  ...}

# %% [markdown]
# ### Train mode

# %% [markdown]
# #### Method 2. Each patient graph => [model training]

# %%
# Dictionaries to use
 # struct: {word: word2vec[128, numpy.array]}
patient_cooc_odd_scores # struct: {cooc_tuple: log_odds_score}
print()

# %%
patient_cooc_odd_scores
# Out:
# {('contd', 'refractori'): 6.90875477931522,
#  ('breakfast', 'dizzi'): 6.90875477931522,
#  ('mortem', 'mso'): -6.90875477931522,
#  ('nicotin', 'ppd'): 6.90875477931522,
#  ('dni', 'pleasant'): 0.9671491491076459,
#  ('chip', 'scar'): 6.90875477931522,
#  ('lighthead', 'xl'): 6.90875477931522,
#  ('pod', 'readmit'): 6.90875477931522,
#  ('hunger', 'scar'): -6.90875477931522,
#  ('captopril', 'scar'): 6.90875477931522,
#  ('dobutamin', 'phenylephrin'): -6.90875477931522,
#  ('hive', 'profound'): 6.90875477931522,
#  ('cloth', 'dni'): 0.0,
#  ('asthma', 'osa'): 6.90875477931522,
#  ('robitussin', 'splint'): 6.90875477931522,
#  ('gait', 'im'): 6.90875477931522,
#  ('dopamin', 'liw'): -6.90875477931522,
#  ('dnr', 'meropenam'): -6.90875477931522,
#  ('qam', 'xii'): 6.90875477931522,
#  ('reguard', 'xanax'): 6.90875477931522,
#  ('grave', 'hook'): 6.90875477931522,
#  ('scar', 'sibl'): 6.90875477931522,
#  ('pea', 'subcost'): 6.90875477931522,
#  ('calculi', 'suprapub'): 6.90875477931522,
#  ('rigor', 'zero'): 6.90875477931522,
#  ('cmo', 'pronounc'): -6.90875477931522,
#  ('prilosec', 'syst'): 6.90875477931522,
#  ('contd', 'deterior'): 6.90875477931522,
#  ('hospic', 'underneath'): -6.90875477931522,
#  ('hepatobiliari', 'ntnd'): -6.90875477931522,
#  ('laryng', 'mucinex'): 6.90875477931522,
#  ('^th', 'ciwa'): 6.90875477931522,
#  ('cocain', 'herp'): 6.90875477931522,
#  ('azotemia', 'phenylephrin'): -6.90875477931522,
#  ('captopril', 'ffp'): 6.90875477931522,
#  ('clonazepam', 'seroquel'): 6.90875477931522,
#  ('neutral', 'scar'): 6.90875477931522,
#  ('bromid', 'opiat'): 6.90875477931522,
#  ('mrg', 'weekli'): 6.90875477931522,
#  ('asthma', 'schizophrenia'): 6.90875477931522,
#  ('pleasantli', 'subdur'): 6.90875477931522,
#  ('gabapentin', 'pneumococc'): 6.90875477931522,
#  ('dnr', 'learn'): 6.90875477931522,
#  ('chip', 'readmit'): 6.90875477931522,
#  ('dyslipidemia', 'profound'): 6.90875477931522,
#  ('dietari', 'hypothermia'): 6.90875477931522,
#  ('hsq', 'platelet'): -6.90875477931522,
#  ('absorb', 'option'): 6.90875477931522,
#  ('nicotin', 'oob'): 6.90875477931522,
#  ('habitu', 'levoph'): 6.90875477931522,
#  ('dni', 'occipit'): 6.90875477931522,
#  ('jerk', 'mso'): -6.90875477931522,
#  ('ggt', 'zyprexa'): 6.90875477931522,
#  ('ffp', 'neo'): -6.90875477931522,
#  ('endur', 'knowledg'): 6.90875477931522,
#  ('echocardiogram', 'thiamin'): 6.90875477931522,
#  ('chair', 'signatur'): 6.90875477931522,
#  ('effac', 'readmit'): 6.90875477931522,
#  ('oob', 'tracheomalacia'): 6.90875477931522,
#  ('imbal', 'strictur'): 6.90875477931522,
#  ('core', 'dic'): -6.90875477931522,
#  ('deliv', 'dni'): 6.90875477931522,
#  ('captopril', 'tcdb'): 6.90875477931522,
#  ('fibrinogen', 'norepinephrin'): -2.4258395487508584,
#  ('palli', 'readmit'): 6.90875477931522,
#  ('clinician', 'cpr'): -6.90875477931522,
#  ('abnl', 'splint'): 6.90875477931522,
#  ('foci', 'jejunum'): 6.90875477931522,
#  ('ctx', 'hugger'): 6.90875477931522,
#  ('dnr', 'sarna'): 6.90875477931522,
#  ('gabapentin', 'phenylephrin'): 6.90875477931522,
#  ('mva', 'omeprazol'): 6.90875477931522,
#  ('behavior', 'seroquel'): 6.90875477931522,
#  ('hospic', 'mean'): -6.90875477931522,
#  ('declin', 'mva'): 6.90875477931522,
#  ('anur', 'azotemia'): -6.90875477931522,
#  ('romi', 'thiamin'): 6.90875477931522,
#  ('mrg', 'ntnd'): 6.90875477931522,
#  ('thiamin', 'vp'): 6.90875477931522,
#  ('dyslipidemia', 'gait'): 6.90875477931522,
#  ('ambul', 'nephrolog'): 6.90875477931522,
#  ('aox', 'unobtain'): 6.90875477931522,
#  ('laminectomi', 'stitch'): 6.90875477931522,
#  ('adenocarcinoma', 'assymetr'): -6.90875477931522,
#  ('angiogram', 'option'): 6.90875477931522,
#  ('oncologist', 'prognosi'): 6.90875477931522,
#  ('cracker', 'incent'): -6.90875477931522,
#  ('ofm', 'osa'): 6.90875477931522,
#  ('coarctat', 'tdi'): 6.90875477931522,
#  ('bank', 'fax'): 6.90875477931522,
#  ('carvedilol', 'ctx'): 6.90875477931522,
#  ('klonopin', 'zoloft'): 6.90875477931522,
#  ('deterior', 'gc'): 6.90875477931522,
#  ('ctx', 'quinolon'): 6.90875477931522,
#  ('dizzi', 'lat'): 6.90875477931522,
#  ('norepinephrin', 'pea'): -6.90875477931522,
#  ('hive', 'stitch'): 6.90875477931522,
#  ('ipf', 'scar'): 6.90875477931522,
#  ('abruptli', 'cmo'): -6.90875477931522,
#  ('diuril', 'dopamin'): 6.90875477931522,
#  ('burn', 'splint'): 6.90875477931522,
#  ('levoph', 'sluggish'): -6.90875477931522,
#  ('deploy', 'futil'): 6.90875477931522,
#  ('dni', 'scar'): -1.7436457586061653,
#  ('autopeep', 'azotemia'): -6.90875477931522,
#  ('captopril', 'omeprazol'): 6.90875477931522,
#  ('rhinorrhea', 'romi'): 6.90875477931522,
#  ('plerual', 'scar'): 6.90875477931522,
#  ('platelet', 'qtc'): 6.90875477931522,
#  ('ciwa', 'syncop'): 6.90875477931522,
#  ('arthrit', 'cdb'): 6.90875477931522,
#  ('rememb', 'ruptur'): 6.90875477931522,
#  ('dopamin', 'scopalamin'): -6.90875477931522,
#  ('furhter', 'lw'): -6.90875477931522,
#  ('mrg', 'oncologist'): 6.90875477931522,
#  ('ctx', 'young'): 6.90875477931522,
#  ('mellitu', 'pea'): 6.90875477931522,
#  ('ciwa', 'epigastr'): 6.90875477931522,
#  ('agonist', 'asthma'): 6.90875477931522,
#  ('dz', 'postop'): 6.90875477931522,
#  ('illeu', 'oob'): -6.90875477931522,
#  ('scar', 'smooth'): 6.90875477931522,
#  ('subq', 'xl'): 6.90875477931522,
#  ('dni', 'ntnd'): 1.4174966125472825,
#  ('hctz', 'puff'): 6.90875477931522,
#  ('dnr', 'hypothermia'): 2.0716061679700735,
#  ('bottl', 'occipit'): 6.90875477931522,
#  ('expir', 'im'): 6.90875477931522,
#  ('oob', 'seroquel'): 6.90875477931522,
#  ('pneumococc', 'puff'): 6.90875477931522,
#  ('clinician', 'dnr'): 0.4046335072286383,
#  ('cdb', 'dni'): 6.90875477931522,
#  ('aox', 'gait'): 6.90875477931522,
#  ('diaphoresi', 'subq'): 6.90875477931522,
#  ('captopril', 'hctz'): 6.90875477931522,
#  ('burn', 'spacer'): 6.90875477931522,
#  ('ofm', 'unsteadi'): 6.90875477931522,
#  ('autoset', 'declin'): 6.90875477931522,
#  ('historian', 'mellitu'): 6.90875477931522,
#  ('oob', 'video'): 6.90875477931522,
#  ('qam', 'thrive'): 6.90875477931522,
#  ('cash', 'ctx'): 6.90875477931522,
#  ('omeprazol', 'young'): 6.90875477931522,
#  ('cagluc', 'neo'): -6.90875477931522,
#  ('hsq', 'venti'): 6.90875477931522,
#  ('crack', 'hygein'): 6.90875477931522,
#  ('fibrinogen', 'rpr'): 6.90875477931522,
#  ('prognosi', 'wish'): -6.90875477931522,
#  ('scar', 'treitz'): 6.90875477931522,
#  ('arrest', 'autopeep'): -6.90875477931522,
#  ('adenocarcinoma', 'bill'): 6.90875477931522,
#  ('levoph', 'permiss'): -6.90875477931522,
#  ('gabapentin', 'strictur'): 6.90875477931522,
#  ('brb', 'crrt'): -6.90875477931522,
#  ('sensat', 'silent'): 6.90875477931522,
#  ('dnr', 'shorter'): 6.90875477931522,
#  ('mellitu', 'paralyt'): 6.90875477931522,
#  ('levoph', 'vasoconstrict'): -6.90875477931522,
#  ('chair', 'redirect'): 6.90875477931522,
#  ('commod', 'oob'): 2.850526026718352,
#  ('agon', 'jerk'): -6.90875477931522,
#  ('postop', 'scar'): 6.90875477931522,
#  ('phenylephrin', 'seat'): 6.90875477931522,
#  ('acc', 'young'): 6.90875477931522,
#  ('bromid', 'effac'): 6.90875477931522,
#  ('asthma', 'knowledg'): 6.90875477931522,
#  ('aox', 'predict'): 6.90875477931522,
#  ('appi', 'venti'): 6.90875477931522,
#  ('conc', 'dnr'): 6.90875477931522,
#  ('anur', 'gentamycin'): -6.90875477931522,
#  ('articul', 'hypothermia'): 6.90875477931522,
#  ('lat', 'rehabilit'): 6.90875477931522,
#  ('asthma', 'norepinephrin'): 6.90875477931522,
#  ('bromid', 'clonazepam'): 6.90875477931522,
#  ('omeprazol', 'subq'): 6.90875477931522,
#  ('omeprazol', 'solut'): 6.90875477931522,
#  ('chemic', 'dni'): -6.90875477931522,
#  ('neoplast', 'thiamin'): 6.90875477931522,
#  ('dz', 'venti'): 6.90875477931522,
#  ('arrest', 'carvedilol'): 6.90875477931522,
#  ('asthma', 'burn'): 6.90875477931522,
#  ('hive', 'sarna'): 6.90875477931522,
#  ('profound', 'vertebra'): 6.90875477931522,
#  ('barium', 'breakfast'): 6.90875477931522,
#  ('ferrou', 'nocturn'): 6.90875477931522,
#  ('ambul', 'ctx'): 6.90875477931522,
#  ('mrg', 'readmit'): 6.90875477931522,
#  ('arrest', 'cefapim'): 6.90875477931522,
#  ('chip', 'hook'): 6.90875477931522,
#  ('declin', 'moan'): -6.90875477931522,
#  ('asthma', 'jewelri'): 6.90875477931522,
#  ('homogen', 'ligament'): 6.90875477931522,
#  ('sibl', 'thiamin'): 6.90875477931522,
#  ('rhinorrhea', 'thiamin'): 6.90875477931522,
#  ('anur', 'cpr'): 6.90875477931522,
#  ('dizzi', 'jewelri'): 6.90875477931522,
#  ('paralyt', 'recruit'): 6.90875477931522,
#  ('nifedipin', 'xl'): 6.90875477931522,
#  ('iddm', 'uri'): 6.90875477931522,
#  ('gabapentin', 'rhinorrhea'): 6.90875477931522,
#  ('artifici', 'gait'): -6.90875477931522,
#  ('barium', 'thrive'): 6.90875477931522,
#  ('option', 'unstabl'): -6.90875477931522,
#  ('neo', 'paralyt'): -3.1942475376942854,
#  ('declin', 'unasyn'): 6.90875477931522,
#  ('duski', 'levoph'): -6.90875477931522,
#  ('epidur', 'vertebra'): 6.90875477931522,
#  ('scar', 'slice'): 6.90875477931522,
#  ('echocardiogram', 'ppd'): 6.90875477931522,
#  ('contd', 'dopamin'): 6.90875477931522,
#  ('mva', 'seroquel'): 6.90875477931522,
#  ('lat', 'pneumothorac'): 0.6916505477038827,
#  ('hugger', 'sluggish'): -6.90875477931522,
#  ('asystol', 'neo'): -6.90875477931522,
#  ('quinolon', 'trazodon'): 6.90875477931522,
#  ('dnr', 'fibrinogen'): 1.6507429622330152,
#  ('norepinephrin', 'opiat'): 6.90875477931522,
#  ('dnr', 'occurr'): 6.90875477931522,
#  ('arrest', 'chb'): -6.90875477931522,
#  ('dopamin', 'vasopressin'): 0.9785433477333831,
#  ('ferrou', 'sibl'): 6.90875477931522,
#  ('laminectomi', 'unstabl'): 6.90875477931522,
#  ('ciwa', 'ran'): 6.90875477931522,
#  ('chip', 'dopamin'): 6.90875477931522,
#  ('agon', 'death'): -6.90875477931522,
#  ('deterior', 'echocardiogram'): 6.90875477931522,
#  ('barium', 'mottl'): 6.90875477931522,
#  ('bill', 'dyslipidemia'): 6.90875477931522,
#  ('pleasant', 'thirst'): 6.90875477931522,
#  ('crowd', 'mellitu'): 6.90875477931522,
#  ('dic', 'dnr'): 1.3552715766147616,
#  ('qam', 'sweat'): 6.90875477931522,
#  ('cagluc', 'neosynephrin'): -6.90875477931522,
#  ('influenc', 'jerk'): 6.90875477931522,
#  ('bromid', 'gabapentin'): 6.90875477931522,
#  ('mood', 'pneumococc'): 6.90875477931522,
#  ('ffp', 'vasopressin'): -6.90875477931522,
#  ('captopril', 'mellitu'): 6.90875477931522,
#  ('dnr', 'mean'): -6.90875477931522,
#  ('dobutamin', 'mean'): 6.90875477931522,
#  ('diflucan', 'jewelri'): 6.90875477931522,
#  ('dni', 'intiat'): -6.90875477931522,
#  ('hive', 'ppd'): 6.90875477931522,
#  ('asthma', 'romi'): 6.90875477931522,
#  ('captopril', 'core'): -6.90875477931522,
#  ('agon', 'rabbi'): -6.90875477931522,
#  ('fatti', 'xii'): 6.90875477931522,
#  ('conc', 'dni'): 6.90875477931522,
#  ('chip', 'palli'): 6.90875477931522,
#  ('lat', 'occupi'): 6.90875477931522,
#  ('hctz', 'sensat'): 6.90875477931522,
#  ('gastrojejunostomi', 'ligament'): 6.90875477931522,
#  ('fibrinogen', 'option'): -6.90875477931522,
#  ('deploy', 'epigastr'): 6.90875477931522,
#  ('articul', 'dome'): 6.90875477931522,
#  ('bottl', 'pea'): 6.90875477931522,
#  ('dizzi', 'laryng'): 6.90875477931522,
#  ('bromid', 'nicotin'): 6.90875477931522,
#  ('hive', 'mood'): 6.90875477931522,
#  ('ambien', 'laryng'): 6.90875477931522,
#  ('captopril', 'palli'): 6.90875477931522,
#  ('foci', 'postop'): 6.90875477931522,
#  ('colonoscopi', 'hive'): 6.90875477931522,
#  ('od', 'uri'): 6.90875477931522,
#  ('perisplen', 'plerual'): 6.90875477931522,
#  ('clonazepam', 'strictur'): 6.90875477931522,
#  ('laminectomi', 'pleasant'): 6.90875477931522,
#  ('chol', 'dnr'): -6.90875477931522,
#  ('diaphoresi', 'xl'): 6.90875477931522,
#  ('oob', 'xanax'): 6.90875477931522,
#  ('peac', 'rabbi'): -6.90875477931522,
#  ('futil', 'platelet'): -6.90875477931522,
#  ('historian', 'unstabl'): 6.90875477931522,
#  ('banana', 'oob'): 6.90875477931522,
#  ('bottl', 'omeprazol'): 6.90875477931522,
#  ('autoset', 'hctz'): 6.90875477931522,
#  ('hypercapnia', 'norepinephrin'): -6.90875477931522,
#  ('wish', 'xii'): -6.90875477931522,
#  ('iddm', 'lat'): 6.90875477931522,
#  ('asthma', 'prilosec'): 6.90875477931522,
#  ('captopril', 'nephrolog'): 6.90875477931522,
#  ('levoph', 'vasopressin'): -1.121185584669415,
#  ('oob', 'thk'): 6.90875477931522,
#  ('bipolar', 'dni'): -2.2784985714248847,
#  ('echocardiogram', 'sweat'): 6.90875477931522,
#  ('natg', 'simpli'): 6.90875477931522,
#  ('habitu', 'shorter'): 6.90875477931522,
#  ('mso', 'pose'): -6.90875477931522,
#  ('escal', 'mso'): -6.90875477931522,
#  ('carvedilol', 'video'): 6.90875477931522,
#  ('flight', 'nephrolog'): 6.90875477931522,
#  ('pleasant', 'qtc'): 6.90875477931522,
#  ('laryng', 'lat'): 6.90875477931522,
#  ('bicarbon', 'weekli'): 6.90875477931522,
#  ('bottl', 'bromid'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('chemic', 'cocain'): 6.90875477931522,
#  ('db', 'incent'): 6.90875477931522,
#  ('phlegm', 'thiamin'): 6.90875477931522,
#  ('bronchovascular', 'tracheomalacia'): 6.90875477931522,
#  ('incis', 'romi'): 6.90875477931522,
#  ('abnl', 'dz'): 6.90875477931522,
#  ('cmo', 'prognosi'): -6.90875477931522,
#  ('ipf', 'occipit'): 0.0,
#  ('bromid', 'trazodon'): 6.90875477931522,
#  ('arrang', 'levoph'): -6.90875477931522,
#  ('ferritin', 'trazodon'): 6.90875477931522,
#  ('cloth', 'paperwork'): 6.90875477931522,
#  ('dizzi', 'venti'): 1.9390841839849136,
#  ('crrt', 'readmit'): 6.90875477931522,
#  ('aox', 'gastriti'): 6.90875477931522,
#  ('cs', 'oob'): 6.90875477931522,
#  ('dni', 'sweat'): 6.90875477931522,
#  ('cash', 'cloth'): 2.1509787690125033,
#  ('dobutamin', 'paralyt'): -6.90875477931522,
#  ('barium', 'vallecula'): 6.90875477931522,
#  ('echocardiogram', 'hygein'): 6.90875477931522,
#  ('dnr', 'robitussin'): -6.90875477931522,
#  ('pronounc', 'slice'): 6.90875477931522,
#  ('arrest', 'pronounc'): -6.90875477931522,
#  ('aricept', 'commod'): -6.90875477931522,
#  ('dex', 'levoph'): 6.90875477931522,
#  ('mottl', 'ppd'): 6.90875477931522,
#  ('pneumococc', 'splint'): 6.90875477931522,
#  ('burn', 'ppd'): 6.90875477931522,
#  ('breakfast', 'probe'): 6.90875477931522,
#  ('nifedipin', 'pleasant'): 6.90875477931522,
#  ('dni', 'pleuravac'): -6.90875477931522,
#  ('dnr', 'lotion'): -3.046848290615153,
#  ('dic', 'hypotherm'): -6.90875477931522,
#  ('levoph', 'mean'): 6.90875477931522,
#  ('dnr', 'palliat'): -6.90875477931522,
#  ('incent', 'romi'): 6.90875477931522,
#  ('forth', 'pleasant'): 6.90875477931522,
#  ('strictur', 'zyprexa'): 6.90875477931522,
#  ('fdp', 'platelet'): -6.90875477931522,
#  ('gait', 'mellitu'): 6.90875477931522,
#  ('epidur', 'norepinephrin'): 6.90875477931522,
#  ('ambien', 'ambul'): 6.90875477931522,
#  ('qtc', 'schizophrenia'): 6.90875477931522,
#  ('emper', 'moan'): 6.90875477931522,
#  ('habitu', 'occupi'): 6.90875477931522,
#  ('angiogram', 'fatti'): 6.90875477931522,
#  ('arrest', 'ethic'): -6.90875477931522,
#  ('qtc', 'retic'): 6.90875477931522,
#  ('ciwa', 'unasyn'): 6.90875477931522,
#  ('predict', 'zyprexa'): 6.90875477931522,
#  ('dnr', 'dz'): 6.90875477931522,
#  ('hunger', 'peac'): -6.90875477931522,
#  ('epigastr', 'splint'): 6.90875477931522,
#  ('ffp', 'sluggish'): -6.90875477931522,
#  ('azotemia', 'ggt'): -6.90875477931522,
#  ('subq', 'zoloft'): 6.90875477931522,
#  ('dni', 'requr'): 6.90875477931522,
#  ('ctx', 'diflucan'): 6.90875477931522,
#  ('flight', 'pleasantli'): 6.90875477931522,
#  ('anur', 'hypercapn'): -6.90875477931522,
#  ('dopamin', 'paperwork'): -6.90875477931522,
#  ('aricept', 'pivot'): -6.90875477931522,
#  ('moreov', 'scar'): 6.90875477931522,
#  ('dermat', 'pharmacolog'): 6.90875477931522,
#  ('mellitu', 'phlegm'): 6.90875477931522,
#  ('chair', 'xl'): 6.90875477931522,
#  ('clinician', 'dni'): 0.4046335072286383,
#  ('pronounc', 'underpenetr'): 6.90875477931522,
#  ('breakfast', 'panic'): 6.90875477931522,
#  ('articul', 'rhinorrhea'): 6.90875477931522,
#  ('cellcept', 'ultram'): 6.90875477931522,
#  ('compani', 'pleasant'): 6.90875477931522,
#  ('parastern', 'unavail'): 6.90875477931522,
#  ('bottl', 'motor'): 6.90875477931522,
#  ('hilum', 'lat'): 6.90875477931522,
#  ('epigastr', 'fibrinogen'): 6.90875477931522,
#  ('nimv', 'religi'): -6.90875477931522,
#  ('prognosi', 'vasopressin'): -6.90875477931522,
#  ('levoph', 'olanzapin'): 6.90875477931522,
#  ('dz', 'lat'): 6.90875477931522,
#  ('mjmgb', 'plate'): 6.90875477931522,
#  ('gabapentin', 'imbal'): 6.90875477931522,
#  ('fc', 'osa'): 6.90875477931522,
#  ('solut', 'treatement'): 6.90875477931522,
#  ('hsq', 'precordium'): 6.90875477931522,
#  ('compani', 'gabapentin'): 6.90875477931522,
#  ('anaphylaxi', 'subq'): 6.90875477931522,
#  ('barium', 'nectar'): 6.90875477931522,
#  ('sweat', 'ultrafiltr'): 6.90875477931522,
#  ('dni', 'expir'): -6.90875477931522,
#  ('neo', 'neosynephrin'): -6.90875477931522,
#  ('dnr', 'inspit'): 6.90875477931522,
#  ('mso', 'pronounc'): -6.90875477931522,
#  ('gentamycin', 'illeu'): -6.90875477931522,
#  ('futil', 'icter'): -6.90875477931522,
#  ('laryng', 'motor'): 6.90875477931522,
#  ('qtc', 'rm'): 6.90875477931522,
#  ('thrive', 'weekli'): 6.90875477931522,
#  ('burn', 'mva'): 6.90875477931522,
#  ('hook', 'scar'): 6.90875477931522,
#  ('captopril', 'yel'): 6.90875477931522,
#  ('colonoscopi', 'retic'): 6.90875477931522,
#  ('phlegm', 'stair'): 6.90875477931522,
#  ('commod', 'spirit'): 6.90875477931522,
#  ('cracker', 'spiromet'): -6.90875477931522,
#  ('mso', 'unstabl'): -6.90875477931522,
#  ('lusb', 'wish'): 6.90875477931522,
#  ('arrest', 'jejunum'): -6.90875477931522,
#  ('predict', 'prilosec'): 6.90875477931522,
#  ('crack', 'lotion'): 6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('chair', 'xanax'): 6.90875477931522,
#  ('ferritin', 'seriou'): 6.90875477931522,
#  ('para', 'peribronchovascular'): -6.90875477931522,
#  ('ffp', 'myeloma'): 6.90875477931522,
#  ('pivot', 'wallet'): -6.90875477931522,
#  ('endur', 'pod'): 6.90875477931522,
#  ('arrest', 'asystol'): -6.90875477931522,
#  ('db', 'habitu'): 6.90875477931522,
#  ('aricept', 'dnr'): 0.1428142402977353,
#  ('rhinorrhea', 'xl'): 6.90875477931522,
#  ('mean', 'underneath'): -6.90875477931522,
#  ('autopsi', 'dni'): -6.90875477931522,
#  ('money', 'xl'): 6.90875477931522,
#  ('strictur', 'tracheomalacia'): 6.90875477931522,
#  ('compani', 'predict'): 6.90875477931522,
#  ('bronchovascular', 'habitu'): 6.90875477931522,
#  ('dd', 'inspit'): 6.90875477931522,
#  ('opiat', 'rhinorrhea'): 6.90875477931522,
#  ('captopril', 'hsq'): -6.90875477931522,
#  ('lpm', 'myeloma'): -1.3825560390092835,
#  ('dizzi', 'dni'): 6.90875477931522,
#  ('levoph', 'thrive'): 6.90875477931522,
#  ('rhinorrhea', 'stair'): 6.90875477931522,
#  ('habitu', 'unasyn'): 6.90875477931522,
#  ('aricept', 'seroquel'): 6.90875477931522,
#  ('erythro', 'pleasant'): 6.90875477931522,
#  ('asthma', 'escal'): 6.90875477931522,
#  ('ppd', 'rm'): 6.90875477931522,
#  ('nephrolog', 'option'): -6.90875477931522,
#  ('fibrinogen', 'hung'): -6.90875477931522,
#  ('priest', 'wish'): -6.90875477931522,
#  ('mean', 'stg'): -6.90875477931522,
#  ('phenylephrin', 'rhinorrhea'): 6.90875477931522,
#  ('intent', 'nifedipin'): 6.90875477931522,
#  ('mellitu', 'osa'): 6.90875477931522,
#  ('bronchovascular', 'uri'): 6.90875477931522,
#  ('dni', 'heroic'): -6.90875477931522,
#  ('readmit', 'seroquel'): 6.90875477931522,
#  ('bank', 'pleasant'): 6.90875477931522,
#  ('flight', 'phlegm'): 6.90875477931522,
#  ('derecruit', 'levoph'): -6.90875477931522,
#  ('epigastr', 'unstabl'): 6.90875477931522,
#  ('oob', 'predict'): 6.90875477931522,
#  ('anur', 'chair'): -6.90875477931522,
#  ('dni', 'nifedipin'): 1.8654833430478823,
#  ('foci', 'magnevist'): 6.90875477931522,
#  ('oncologist', 'prilosec'): 6.90875477931522,
#  ('dyslipidemia', 'thiamin'): 6.90875477931522,
#  ('ardsnet', 'bicarbon'): -6.90875477931522,
#  ('hsq', 'splint'): 6.90875477931522,
#  ('dizzi', 'money'): 6.90875477931522,
#  ('dizzi', 'platelet'): 6.90875477931522,
#  ('among', 'ipf'): -6.90875477931522,
#  ('hilum', 'perisplen'): -6.90875477931522,
#  ('anur', 'trazodon'): 6.90875477931522,
#  ('bell', 'cellcept'): 6.90875477931522,
#  ('option', 'thrive'): -6.90875477931522,
#  ('oob', 'sweat'): 6.90875477931522,
#  ('commod', 'kerlix'): 6.90875477931522,
#  ('breakfast', 'nitroglycerin'): 6.90875477931522,
#  ('ambul', 'dni'): 1.3825560390092835,
#  ('expir', 'mso'): -6.90875477931522,
#  ('oob', 'stair'): 6.90875477931522,
#  ('hugger', 'wma'): 6.90875477931522,
#  ('ambul', 'seroquel'): 6.90875477931522,
#  ('arrest', 'clonazepam'): 6.90875477931522,
#  ('aox', 'broader'): 6.90875477931522,
#  ('dietari', 'romi'): 6.90875477931522,
#  ('oob', 'uncoop'): 6.90875477931522,
#  ('bicarbon', 'oligur'): -6.90875477931522,
#  ('dopamin', 'pitressin'): -6.90875477931522,
#  ('ggo', 'iddm'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('judgement', 'uri'): 6.90875477931522,
#  ('life', 'pea'): -6.90875477931522,
#  ('crrt', 'ffp'): -6.90875477931522,
#  ('anaphylaxi', 'thiamin'): 6.90875477931522,
#  ('mellitu', 'rhinorrhea'): 6.90875477931522,
#  ('bromid', 'readmit'): 6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('dobutamin', 'intiat'): 6.90875477931522,
#  ('db', 'tubular'): 6.90875477931522,
#  ('gait', 'thirst'): 6.90875477931522,
#  ('aox', 'clonidin'): 6.90875477931522,
#  ('oncologist', 'romi'): 6.90875477931522,
#  ('romi', 'young'): 6.90875477931522,
#  ('bronchovascular', 'fatti'): 6.90875477931522,
#  ('dead', 'gurgl'): -6.90875477931522,
#  ('burn', 'dni'): 6.90875477931522,
#  ('fu', 'prilosec'): 6.90875477931522,
#  ('hsq', 'sweat'): 6.90875477931522,
#  ('hospic', 'palli'): -0.2660901613908308,
#  ('dni', 'thk'): 6.90875477931522,
#  ('amb', 'pleasant'): 6.90875477931522,
#  ('judgement', 'pleasant'): -6.90875477931522,
#  ('dyslipidemia', 'gastrojejunostomi'): 6.90875477931522,
#  ('phenylephrin', 'prognosi'): -6.90875477931522,
#  ('duski', 'prognosi'): -6.90875477931522,
#  ('dnr', 'dyslipidemia'): 6.90875477931522,
#  ('vallecula', 'video'): 6.90875477931522,
#  ('sensat', 'suprapub'): 6.90875477931522,
#  ('cdb', 'pleasantli'): 6.90875477931522,
#  ('incent', 'syst'): 6.90875477931522,
#  ('thrive', 'wish'): 6.90875477931522,
#  ('flight', 'readmit'): 6.90875477931522,
#  ('chair', 'vagu'): 6.90875477931522,
#  ('fibrinogen', 'nicotin'): 6.90875477931522,
#  ('crack', 'rm'): 6.90875477931522,
#  ('death', 'sweat'): 6.90875477931522,
#  ('fibrinogen', 'hypotherm'): -6.90875477931522,
#  ('clinician', 'stitch'): 6.90875477931522,
#  ('ferrou', 'omeprazol'): 6.90875477931522,
#  ('grim', 'prognosi'): -6.90875477931522,
#  ('diaphoresi', 'osa'): 6.90875477931522,
#  ('pleasant', 'rigor'): 6.90875477931522,
#  ('ciwa', 'sibl'): 6.90875477931522,
#  ('aaox', 'gown'): -6.90875477931522,
#  ('dead', 'dopamin'): -6.90875477931522,
#  ('ambien', 'ferrou'): 6.90875477931522,
#  ('declin', 'hctz'): 6.90875477931522,
#  ('rehabilit', 'rhinorrhea'): 6.90875477931522,
#  ('im', 'nifedipin'): 6.90875477931522,
#  ('endplat', 'foci'): 6.90875477931522,
#  ('opinion', 'palliat'): -6.90875477931522,
#  ('hook', 'rhochor'): 6.90875477931522,
#  ('nonlabor', 'pneumococc'): 6.90875477931522,
#  ('death', 'mso'): -6.90875477931522,
#  ('dopamin', 'pose'): -6.90875477931522,
#  ('cardiovert', 'neosynephrin'): -6.90875477931522,
#  ('chair', 'death'): 6.90875477931522,
#  ('fatti', 'hilum'): 0.6916505477038827,
#  ('sensat', 'signatur'): 6.90875477931522,
#  ('foci', 'gadolinium'): 6.90875477931522,
#  ('klonopin', 'pleasant'): 6.90875477931522,
#  ('hypercapn', 'neo'): 6.90875477931522,
#  ('icter', 'oncologist'): 6.90875477931522,
#  ('gown', 'sundown'): -6.90875477931522,
#  ('clonidin', 'dz'): 6.90875477931522,
#  ('brb', 'chair'): 6.90875477931522,
#  ('herp', 'sensat'): 6.90875477931522,
#  ('gc', 'mva'): 6.90875477931522,
#  ('phenylephrin', 'ruptur'): 6.90875477931522,
#  ('declin', 'predict'): -6.90875477931522,
#  ('dnr', 'illeu'): -6.90875477931522,
#  ('bipolar', 'strictur'): 6.90875477931522,
#  ('neoplast', 'palli'): 6.90875477931522,
#  ('anaphylaxi', 'pcv'): -6.90875477931522,
#  ('magnevist', 'occipit'): 6.90875477931522,
#  ('gabapentin', 'unstabl'): 6.90875477931522,
#  ('dysynchron', 'platelet'): -6.90875477931522,
#  ('laryng', 'pathologist'): 6.90875477931522,
#  ('criticar', 'pinpoint'): -6.90875477931522,
#  ('cmo', 'levoph'): -1.3825560390092835,
#  ('clonidin', 'friction'): 6.90875477931522,
#  ('lw', 'pca'): 6.90875477931522,
#  ('lat', 'syncop'): 6.90875477931522,
#  ('mrcp', 'wma'): -6.90875477931522,
#  ('goc', 'moan'): -6.90875477931522,
#  ('angiogram', 'deploy'): 6.90875477931522,
#  ('barium', 'pharyng'): 6.90875477931522,
#  ('bell', 'dnr'): 6.90875477931522,
#  ('arrest', 'neo'): -6.90875477931522,
#  ('osa', 'silent'): 6.90875477931522,
#  ('contd', 'dizzi'): 6.90875477931522,
#  ('osteoblast', 'scar'): -6.90875477931522,
#  ('dni', 'inspit'): 6.90875477931522,
#  ('ppd', 'xii'): 6.90875477931522,
#  ('homogen', 'nephrogram'): 0.6916505477038827,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('asthma', 'mean'): 6.90875477931522,
#  ('bottl', 'currenlti'): 6.90875477931522,
#  ('profound', 'sweat'): 6.90875477931522,
#  ('ambul', 'permiss'): 6.90875477931522,
#  ('cash', 'klonopin'): 6.90875477931522,
#  ('director', 'zero'): 6.90875477931522,
#  ('puff', 'thrive'): 6.90875477931522,
#  ('epidur', 'fibrinogen'): 6.90875477931522,
#  ('lift', "sxn'ing"): 6.90875477931522,
#  ('fibrinogen', 'icter'): -6.90875477931522,
#  ('hugger', 'lpm'): -6.90875477931522,
#  ('epigastr', 'ppd'): 6.90875477931522,
#  ('asthma', 'gait'): 6.90875477931522,
#  ('fibrinogen', 'impli'): 6.90875477931522,
#  ('liw', 'unstabl'): -6.90875477931522,
#  ('aricept', 'resucit'): 6.90875477931522,
#  ('chb', 'zyprexa'): 6.90875477931522,
#  ('intent', 'sweat'): 6.90875477931522,
#  ('cyanot', 'furhter'): -6.90875477931522,
#  ('dermat', 'sarna'): 6.90875477931522,
#  ('dermat', 'scab'): 6.90875477931522,
#  ('ba', 'qam'): 6.90875477931522,
#  ('bromid', 'trabecul'): 6.90875477931522,
#  ('cdb', 'phlegm'): 6.90875477931522,
#  ('norepinephrin', 'zoloft'): 6.90875477931522,
#  ('ba', 'puff'): 6.90875477931522,
#  ('align', 'epidur'): 6.90875477931522,
#  ('dnr', 'ofm'): 6.90875477931522,
#  ('money', 'probe'): 6.90875477931522,
#  ('arrest', 'trazodon'): -6.90875477931522,
#  ('mellitu', 'pod'): 6.90875477931522,
#  ('oob', 'unsteadi'): 6.90875477931522,
#  ('osa', 'seat'): 6.90875477931522,
#  ('breakfast', 'fatti'): 6.90875477931522,
#  ('caspofungin', 'hive'): 6.90875477931522,
#  ('aox', 'mind'): 6.90875477931522,
#  ('cocain', 'rm'): 6.90875477931522,
#  ('caspofungin', 'metoclopramid'): 6.90875477931522,
#  ('nitroglycerin', 'pleasant'): 6.90875477931522,
#  ('bill', 'hctz'): 6.90875477931522,
#  ('coarctat', 'subcost'): 1.095952712632351,
#  ('ambien', 'pharmacolog'): 6.90875477931522,
#  ('eg', 'pronounc'): 6.90875477931522,
#  ('arrest', 'venti'): 6.90875477931522,
#  ('ba', 'hypothermia'): 6.90875477931522,
#  ('death', 'declin'): 0.4046335072286383,
#  ('cmo', 'suffer'): -6.90875477931522,
#  ('acidot', 'prognosi'): -6.90875477931522,
#  ('bottl', 'mottl'): 6.90875477931522,
#  ('icter', 'platelet'): -6.90875477931522,
#  ('commod', 'dni'): -1.095952712632351,
#  ('nectar', 'vallecula'): 6.90875477931522,
#  ('mso', 'neo'): 6.90875477931522,
#  ('dni', 'moan'): -0.5378679732223673,
#  ('asthma', 'piriform'): 6.90875477931522,
#  ('dead', 'unrel'): -6.90875477931522,
#  ('compani', 'dnr'): 6.90875477931522,
#  ('bipolar', 'klonopin'): 6.90875477931522,
#  ('rhinorrhea', 'sibl'): 6.90875477931522,
#  ('lat', 'plate'): 6.90875477931522,
#  ('paperwork', 'rhinorrhea'): 6.90875477931522,
#  ('dz', 'suffer'): 6.90875477931522,
#  ('agon', 'deterior'): -6.90875477931522,
#  ('cyanot', 'eyelid'): -6.90875477931522,
#  ('^th', 'omeprazol'): 6.90875477931522,
#  ('ambul', 'sweat'): 6.90875477931522,
#  ('acidot', 'dic'): -6.90875477931522,
#  ('klonopin', 'osa'): 6.90875477931522,
#  ('svv', 'vasopressin'): -6.90875477931522,
#  ('death', 'scar'): 6.90875477931522,
#  ('ambul', 'aricept'): 6.90875477931522,
#  ('hospic', 'money'): 6.90875477931522,
#  ('dnr', 'uri'): 6.90875477931522,
#  ('lat', 'sweat'): 6.90875477931522,
#  ('stair', 'vp'): 6.90875477931522,
#  ('life', 'ppd'): 6.90875477931522,
#  ('pose', 'prognosi'): -6.90875477931522,
#  ('ppd', 'thrive'): 6.90875477931522,
#  ('escal', 'prognosi'): -6.90875477931522,
#  ('amb', 'oob'): 6.90875477931522,
#  ('cefapim', 'db'): 6.90875477931522,
#  ('nonlabor', 'subq'): 6.90875477931522,
#  ('crack', 'habitu'): 6.90875477931522,
#  ('fibrinogen', 'trazodon'): -6.90875477931522,
#  ('hctz', 'xanax'): 6.90875477931522,
#  ('articul', 'sweat'): 6.90875477931522,
#  ('aliv', 'dead'): 6.90875477931522,
#  ('oncologist', 'synthet'): 6.90875477931522,
#  ('anuria', 'dead'): -6.90875477931522,
#  ('acc', 'declin'): 6.90875477931522,
#  ('profound', 'romi'): 6.90875477931522,
#  ('neoplast', 'slice'): -6.90875477931522,
#  ('incis', 'pod'): 6.90875477931522,
#  ('ambul', 'pose'): 6.90875477931522,
#  ('adenocarcinoma', 'distort'): 6.90875477931522,
#  ('arthrit', 'commod'): 6.90875477931522,
#  ('chair', 'prec'): 6.90875477931522,
#  ('bromid', 'im'): 6.90875477931522,
#  ('conc', 'mso'): -6.90875477931522,
#  ('gabapentin', 'morbid'): 6.90875477931522,
#  ('fatti', 'ferritin'): 6.90875477931522,
#  ('palli', 'pneumonectomi'): 6.90875477931522,
#  ('osa', 'romi'): 6.90875477931522,
#  ('declin', 'norepinephrin'): -6.90875477931522,
#  ('chair', 'ofm'): 6.90875477931522,
#  ('bipolar', 'ferritin'): 6.90875477931522,
#  ('jewelri', 'money'): 2.5001408943598484,
#  ('declin', 'hypothermia'): -6.90875477931522,
#  ('deterior', 'nimv'): -6.90875477931522,
#  ('lat', 'splint'): 6.90875477931522,
#  ('gvhd', 'pleasant'): 6.90875477931522,
#  ('bair', 'paralyt'): 6.90875477931522,
#  ('nectar', 'subdur'): 6.90875477931522,
#  ('aricept', 'pyuria'): 6.90875477931522,
#  ('cpr', 'crrt'): -6.90875477931522,
#  ('ctx', 'resucit'): 6.90875477931522,
#  ('bipolar', 'lotion'): -6.90875477931522,
#  ('neo', 'recalibr'): 6.90875477931522,
#  ('ba', 'romi'): 6.90875477931522,
#  ('declar', 'dnr'): -6.90875477931522,
#  ('lusb', 'romi'): 6.90875477931522,
#  ('asthma', 'uri'): 6.90875477931522,
#  ('gait', 'pea'): -6.90875477931522,
#  ('duski', 'palli'): -6.90875477931522,
#  ('klonopin', 'oob'): 6.90875477931522,
#  ('hemangioma', 'phasic'): 6.90875477931522,
#  ('mtg', 'seroquel'): 6.90875477931522,
#  ('norepinephrin', 'refractori'): 6.90875477931522,
#  ('lat', 'osa'): 6.90875477931522,
#  ('burn', 'schizophrenia'): 6.90875477931522,
#  ('anur', 'myeloma'): 6.90875477931522,
#  ('angiogram', 'futil'): 6.90875477931522,
#  ('dni', 'struggl'): -6.90875477931522,
#  ('klonopin', 'schizophrenia'): 6.90875477931522,
#  ('binder', 'dnr'): 6.90875477931522,
#  ('bank', 'dnr'): 6.90875477931522,
#  ('predict', 'suffer'): -6.90875477931522,
#  ('agon', 'cmo'): -6.90875477931522,
#  ('dopamin', 'pronounc'): -6.90875477931522,
#  ('im', 'ppd'): 6.90875477931522,
#  ('asthma', 'cocain'): 6.90875477931522,
#  ('prilosec', 'wish'): 6.90875477931522,
#  ('paperwork', 'sweat'): 6.90875477931522,
#  ('adam', 'neo'): -6.90875477931522,
#  ('colonoscopi', 'readdress'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('judgement', 'rememb'): 6.90875477931522,
#  ('dead', 'dnr'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('fu', 'xl'): 6.90875477931522,
#  ('^th', 'stitch'): 6.90875477931522,
#  ('colonoscopi', 'wish'): 6.90875477931522,
#  ('adenocarcinoma', 'laryng'): 6.90875477931522,
#  ('osa', 'pleasant'): 6.90875477931522,
#  ('dni', 'mva'): 6.90875477931522,
#  ('stitch', 'video'): 6.90875477931522,
#  ('refractori', 'thrive'): 6.90875477931522,
#  ('aox', 'xii'): 6.90875477931522,
#  ('fibrinogen', 'xl'): 6.90875477931522,
#  ('ctx', 'historian'): 6.90875477931522,
#  ('aricept', 'gentamycin'): -6.90875477931522,
#  ('nocturn', 'trazodon'): 6.90875477931522,
#  ('palli', 'struggl'): -6.90875477931522,
#  ('cpr', 'escal'): -6.90875477931522,
#  ('cocain', 'pneumococc'): 6.90875477931522,
#  ('muddi', 'uri'): 6.90875477931522,
#  ('platelet', 'profound'): 6.90875477931522,
#  ('ctx', 'neo'): 6.90875477931522,
#  ('gabapentin', 'gait'): 6.90875477931522,
#  ('historian', 'romi'): 6.90875477931522,
#  ('cardiovert', 'dysynchron'): -6.90875477931522,
#  ('burn', 'ctx'): 6.90875477931522,
#  ('gastriti', 'xii'): 6.90875477931522,
#  ('anuria', 'unstabl'): -6.90875477931522,
#  ('lac', 'soln'): 6.90875477931522,
#  ('bicarbon', 'paralyt'): -6.90875477931522,
#  ('aricept', 'paperwork'): 6.90875477931522,
#  ('chair', 'cloth'): 6.90875477931522,
#  ('ctx', 'readdress'): 6.90875477931522,
#  ('agon', 'mortum'): -6.90875477931522,
#  ('foci', 'subdur'): 6.90875477931522,
#  ('historian', 'signatur'): 6.90875477931522,
#  ('asthma', 'mva'): 6.90875477931522,
#  ('hsq', 'xii'): 6.90875477931522,
#  ('bromid', 'lymphangit'): 6.90875477931522,
#  ('ciwa', 'neoplast'): 6.90875477931522,
#  ('dead', 'prognosi'): -6.90875477931522,
#  ('ambul', 'lac'): 6.90875477931522,
#  ('foci', 'occipit'): 0.0,
#  ('paralyt', 'phenylephrin'): -6.90875477931522,
#  ('cup', 'oob'): 6.90875477931522,
#  ('death', 'romi'): 6.90875477931522,
#  ('incent', 'levoph'): 6.90875477931522,
#  ('osa', 'uri'): 6.90875477931522,
#  ('declin', 'wish'): 0.509761227710204,
#  ('cefapim', 'dnr'): 6.90875477931522,
#  ('gait', 'rm'): 6.90875477931522,
#  ('ambul', 'twitch'): -6.90875477931522,
#  ('schizophrenia', 'xanax'): 6.90875477931522,
#  ('aricept', 'ctx'): 6.90875477931522,
#  ('pose', 'vasoconstrict'): -6.90875477931522,
#  ('aox', 'ruptur'): 6.90875477931522,
#  ('epigastr', 'homogen'): 6.90875477931522,
#  ('commod', 'lotion'): 6.90875477931522,
#  ('hypotherm', 'scopalamin'): -6.90875477931522,
#  ('asystol', 'cmo'): -6.90875477931522,
#  ('massag', 'refractori'): 6.90875477931522,
#  ('hung', 'pea'): -6.90875477931522,
#  ('romi', 'scar'): 6.90875477931522,
#  ('hilum', 'zyprexa'): -6.90875477931522,
#  ('dnr', 'nocturn'): 6.90875477931522,
#  ('incent', 'rm'): 6.90875477931522,
#  ('seroquel', 'subdur'): 6.90875477931522,
#  ('dead', 'pulseless'): -6.90875477931522,
#  ('hospic', 'stg'): -6.90875477931522,
#  ('silent', 'treitz'): -6.90875477931522,
#  ('dizzi', 'ultram'): 6.90875477931522,
#  ('deterior', 'prognosi'): -6.90875477931522,
#  ('dnr', 'osa'): 0.11100317119789695,
#  ('oncologist', 'refractori'): 6.90875477931522,
#  ('historian', 'jewelri'): 6.90875477931522,
#  ('qtc', 'rhinorrhea'): 6.90875477931522,
#  ('ciwa', 'rememb'): 6.90875477931522,
#  ('incis', 'levoph'): 6.90875477931522,
#  ('dni', 'norepinephrin'): -6.90875477931522,
#  ('esld', 'venti'): 6.90875477931522,
#  ('declin', 'park'): 6.90875477931522,
#  ('pea', 'phenylephrin'): -6.90875477931522,
#  ('palli', 'postop'): 6.90875477931522,
#  ('liw', 'pose'): -6.90875477931522,
#  ('azotemia', 'wma'): -6.90875477931522,
#  ('rhochor', 'scar'): 6.90875477931522,
#  ('pharyng', 'vallecula'): 6.90875477931522,
#  ('anuria', 'cpr'): -6.90875477931522,
#  ('dnr', 'unasyn'): 6.90875477931522,
#  ('asthma', 'nicotin'): 6.90875477931522,
#  ('hsq', 'phlegm'): 6.90875477931522,
#  ('adenosin', 'dni'): 6.90875477931522,
#  ('bill', 'bromid'): 6.90875477931522,
#  ('acv', 'levoph'): 6.90875477931522,
#  ('laryng', 'vallecula'): 6.90875477931522,
#  ('dizzi', 'sweat'): 6.90875477931522,
#  ('acc', 'ctx'): 6.90875477931522,
#  ('deterior', 'mrg'): 6.90875477931522,
#  ('gastriti', 'motor'): 6.90875477931522,
#  ('osa', 'xl'): 6.90875477931522,
#  ('para', 'slice'): 6.90875477931522,
#  ('commod', 'signatur'): -6.90875477931522,
#  ('hsq', 'sensat'): 6.90875477931522,
#  ('deterior', 'levoph'): 2.09609753878805,
#  ('hurt', 'osa'): 6.90875477931522,
#  ('nitroglycerin', 'readdress'): 6.90875477931522,
#  ('defibril', 'tran'): 6.90875477931522,
#  ('intent', 'ppd'): 6.90875477931522,
#  ('breakfast', 'hsq'): 6.90875477931522,
#  ('petechia', 'rhinorrhea'): -6.90875477931522,
#  ('exophyt', 'lusb'): -6.90875477931522,
#  ('asthma', 'mellitu'): 6.90875477931522,
#  ('breakfast', 'oob'): 6.90875477931522,
#  ('bicarbon', 'laminectomi'): 6.90875477931522,
#  ('cisatracurium', 'paralyt'): -6.90875477931522,
#  ('bill', 'lotion'): 6.90875477931522,
#  ('anuria', 'brb'): -6.90875477931522,
#  ('cmo', 'rabbi'): -6.90875477931522,
#  ('rm', 'venti'): 6.90875477931522,
#  ('vasoconstrict', 'vasopressin'): -6.90875477931522,
#  ('asthma', 'crack'): 6.90875477931522,
#  ('incent', 'synthet'): -6.90875477931522,
#  ('depth', 'levoph'): 6.90875477931522,
#  ('dome', 'foci'): 6.90875477931522,
#  ('gadolinium', 'magnevist'): 6.90875477931522,
#  ('mellitu', 'nocturn'): 6.90875477931522,
#  ('anaphylaxi', 'gadolinium'): 6.90875477931522,
#  ('hepatobiliari', 'wma'): -6.90875477931522,
#  ('chair', 'rusti'): 6.90875477931522,
#  ('expir', 'peribronchovascular'): 6.90875477931522,
#  ('burn', 'intiat'): 6.90875477931522,
#  ('director', 'young'): 6.90875477931522,
#  ('gait', 'unavail'): 6.90875477931522,
#  ('anaphylaxi', 'seroquel'): 6.90875477931522,
#  ('bicarbon', 'wma'): -6.90875477931522,
#  ('laminectomi', 'paco'): 6.90875477931522,
#  ('hive', 'signatur'): 6.90875477931522,
#  ('norepinephrin', 'oligur'): -6.90875477931522,
#  ('bronchovascular', 'crowd'): 1.462247919771027,
#  ('cvvh', 'sluggishli'): -6.90875477931522,
#  ('consciou', 'core'): 6.90875477931522,
#  ('foci', 'neo'): 6.90875477931522,
#  ('dni', 'friction'): 6.90875477931522,
#  ('habitu', 'mean'): 6.90875477931522,
#  ('osa', 'suprapub'): 6.90875477931522,
#  ('crack', 'klonopin'): 6.90875477931522,
#  ('nicotin', 'tran'): 6.90875477931522,
#  ('cyanot', 'lw'): -6.90875477931522,
#  ('contractur', 'vasopressor'): -6.90875477931522,
#  ('pleasant', 'retic'): 6.90875477931522,
#  ('chair', 'readmit'): 6.90875477931522,
#  ('sibl', 'unstabl'): -6.90875477931522,
#  ('pneumococc', 'zyprexa'): 6.90875477931522,
#  ('furhter', 'twitch'): -6.90875477931522,
#  ('pathologist', 'vallecula'): 6.90875477931522,
#  ('moan', 'zyprexa'): 6.90875477931522,
#  ('historian', 'xii'): 6.90875477931522,
#  ('abnl', 'occipit'): 6.90875477931522,
#  ('arrest', 'pulseless'): -6.90875477931522,
#  ('cdb', 'commod'): 6.90875477931522,
#  ('cash', 'dni'): -0.4046335072286383,
#  ('bipolar', 'zyprexa'): 6.90875477931522,
#  ('ppd', 'spacer'): 6.90875477931522,
#  ('cash', 'palli'): 6.90875477931522,
#  ('dni', 'zyprexa'): 1.6812038300138494,
#  ('paralyt', 'vasopressin'): -6.90875477931522,
#  ('mva', 'panic'): 6.90875477931522,
#  ('aliv', 'articul'): 6.90875477931522,
#  ('clonidin', 'unasyn'): 6.90875477931522,
#  ('ashen', 'declin'): 6.90875477931522,
#  ('rehabilit', 'young'): 6.90875477931522,
#  ('gait', 'thiamin'): 6.90875477931522,
#  ('cloth', 'declin'): 6.90875477931522,
#  ('dyslipidemia', 'lat'): 6.90875477931522,
#  ('dnr', 'suffer'): 4.804452358089091,
#  ('nicotin', 'prilosec'): 6.90875477931522,
#  ('aox', 'dz'): 6.90875477931522,
#  ('mellitu', 'retic'): 6.90875477931522,
#  ('bipolar', 'historian'): 6.90875477931522,
#  ('dnr', 'mrg'): 6.90875477931522,
#  ('dni', 'mood'): 6.90875477931522,
#  ('pneumococc', 'pod'): 6.90875477931522,
#  ('ggt', 'rhinorrhea'): -6.90875477931522,
#  ('dni', 'stair'): 6.90875477931522,
#  ('incent', 'mottl'): 6.90875477931522,
#  ('pod', 'soln'): 6.90875477931522,
#  ('cmo', 'viabl'): -6.90875477931522,
#  ('gentamycin', 'hugger'): -6.90875477931522,
#  ('dnr', 'quadrent'): 6.90875477931522,
#  ('morbid', 'osa'): 6.90875477931522,
#  ('opinion', 'prognosi'): -6.90875477931522,
#  ('chair', 'pivot'): 6.90875477931522,
#  ('aox', 'oncologist'): 6.90875477931522,
#  ('readmit', 'soln'): 6.90875477931522,
#  ('brb', 'unstabl'): -6.90875477931522,
#  ('ferritin', 'qam'): 6.90875477931522,
#  ('religi', 'trazodon'): -6.90875477931522,
#  ('cardiovert', 'tranfer'): 6.90875477931522,
#  ('ctx', 'ruptur'): 6.90875477931522,
#  ('paperwork', 'wish'): 6.90875477931522,
#  ('prilosec', 'sweat'): 6.90875477931522,
#  ('absorb', 'omeprazol'): 6.90875477931522,
#  ('lusb', 'nifedipin'): 6.90875477931522,
#  ('pastor', 'pea'): -6.90875477931522,
#  ('lift', 'mrg'): 6.90875477931522,
#  ('coach', 'soln'): 6.90875477931522,
#  ('anur', 'quietli'): -6.90875477931522,
#  ('rememb', 'sensat'): 6.90875477931522,
#  ('gait', 'hive'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('clonidin', 'sweat'): 6.90875477931522,
#  ('institut', 'smooth'): 6.90875477931522,
#  ('levoph', 'modifi'): 6.90875477931522,
#  ('homogen', 'ipf'): 6.90875477931522,
#  ('hypotherm', 'sluggish'): -6.90875477931522,
#  ('azotemia', 'dic'): -6.90875477931522,
#  ('fatti', 'syncop'): 6.90875477931522,
#  ('commod', 'jewelri'): -6.90875477931522,
#  ('ambul', 'phlegm'): 6.90875477931522,
#  ('itchi', 'palli'): 6.90875477931522,
#  ('pleasant', 'scab'): 6.90875477931522,
#  ('hive', 'lymphangit'): 6.90875477931522,
#  ('neo', 'phenylephrin'): -0.2463623386430715,
#  ('lusb', 'mellitu'): 6.90875477931522,
#  ('deterior', 'option'): -6.90875477931522,
#  ('grave', 'prognosi'): -0.6916505477038827,
#  ('caspofungin', 'fibrinogen'): 6.90875477931522,
#  ('thrive', 'trazodon'): 6.90875477931522,
#  ('readmit', 'xanax'): 6.90875477931522,
#  ('habitu', 'thiamin'): 6.90875477931522,
#  ('dermat', 'romi'): 6.90875477931522,
#  ('mva', 'scl'): 6.90875477931522,
#  ('declin', 'sweat'): 6.90875477931522,
#  ('ethic', 'neo'): -6.90875477931522,
#  ('freeli', 'spill'): 6.90875477931522,
#  ('fax', 'pleasant'): 6.90875477931522,
#  ('mrg', 'ppd'): 6.90875477931522,
#  ('life', 'religi'): -6.90875477931522,
#  ('declin', 'oligur'): -6.90875477931522,
#  ('hsq', 'hypotherm'): -6.90875477931522,
#  ('arrest', 'asthma'): 6.90875477931522,
#  ('ctx', 'signatur'): 6.90875477931522,
#  ('dnr', 'proph'): 6.90875477931522,
#  ('moan', 'venti'): -6.90875477931522,
#  ('asthma', 'director'): 6.90875477931522,
#  ('levoph', 'lpm'): 6.90875477931522,
#  ('dic', 'hung'): -6.90875477931522,
#  ('chair', 'cocain'): 6.90875477931522,
#  ('dnr', 'tremul'): 6.90875477931522,
#  ('among', 'barium'): -6.90875477931522,
#  ('gait', 'hung'): -6.90875477931522,
#  ('fibrinogen', 'itchi'): -6.90875477931522,
#  ('chair', 'intent'): 6.90875477931522,
#  ('occupi', 'seriou'): 6.90875477931522,
#  ('agreement', 'heroic'): -6.90875477931522,
#  ('pneumococc', 'rpr'): 6.90875477931522,
#  ('iddm', 'purpl'): 6.90875477931522,
#  ('dead', 'expir'): -6.90875477931522,
#  ('asthma', 'pleasant'): 6.90875477931522,
#  ('deterior', 'mottl'): -6.90875477931522,
#  ('brb', 'tran'): 6.90875477931522,
#  ('spill', 'videofluoroscopi'): 6.90875477931522,
#  ('ctx', 'itchi'): 6.90875477931522,
#  ('adenosin', 'tcdb'): 6.90875477931522,
#  ('dz', 'hive'): 6.90875477931522,
#  ('echocardiogram', 'fatti'): 6.90875477931522,
#  ('anuria', 'synthet'): 6.90875477931522,
#  ('echocardiogram', 'omeprazol'): 6.90875477931522,
#  ('metoclopramid', 'soln'): 6.90875477931522,
#  ('agon', 'venti'): 6.90875477931522,
#  ('klonopin', 'led'): 6.90875477931522,
#  ('moan', 'rabbi'): -6.90875477931522,
#  ('motor', 'sibl'): 6.90875477931522,
#  ('clonazepam', 'hive'): 6.90875477931522,
#  ('dic', 'pneumonectomi'): -6.90875477931522,
#  ('sluggishli', 'vasopressin'): -6.90875477931522,
#  ('fdp', 'neo'): -6.90875477931522,
#  ...}

# %%
# Data normalization
import numpy
def data_norm(cooc_odd_scores):

    def norm_arr(array):
        arr = numpy.array(list(array))
        start = 0
        end = 1
        width = end - start
        res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
        return res.tolist()

    cooc_keys, cooc_values = zip(*cooc_odd_scores.items())
    new_cooc_odd_scores = dict(zip(cooc_keys, norm_arr(cooc_values)))

    return new_cooc_odd_scores

new_patient_cooc_odd_scores = data_norm(patient_cooc_odd_scores)

# %%
new_patient_cooc_odd_scores
# Out:
# {('contd', 'refractori'): 1.0,
#  ('breakfast', 'dizzi'): 1.0,
#  ('mortem', 'mso'): 0.0,
#  ('nicotin', 'ppd'): 1.0,
#  ('dni', 'pleasant'): 0.5699944620992545,
#  ('chip', 'scar'): 1.0,
#  ('lighthead', 'xl'): 1.0,
#  ('pod', 'readmit'): 1.0,
#  ('hunger', 'scar'): 0.0,
#  ('captopril', 'scar'): 1.0,
#  ('dobutamin', 'phenylephrin'): 0.0,
#  ('hive', 'profound'): 1.0,
#  ('cloth', 'dni'): 0.5,
#  ('asthma', 'osa'): 1.0,
#  ('robitussin', 'splint'): 1.0,
#  ('gait', 'im'): 1.0,
#  ('dopamin', 'liw'): 0.0,
#  ('dnr', 'meropenam'): 0.0,
#  ('qam', 'xii'): 1.0,
#  ('reguard', 'xanax'): 1.0,
#  ('grave', 'hook'): 1.0,
#  ('scar', 'sibl'): 1.0,
#  ('pea', 'subcost'): 1.0,
#  ('calculi', 'suprapub'): 1.0,
#  ('rigor', 'zero'): 1.0,
#  ('cmo', 'pronounc'): 0.0,
#  ('prilosec', 'syst'): 1.0,
#  ('contd', 'deterior'): 1.0,
#  ('hospic', 'underneath'): 0.0,
#  ('hepatobiliari', 'ntnd'): 0.0,
#  ('laryng', 'mucinex'): 1.0,
#  ('^th', 'ciwa'): 1.0,
#  ('cocain', 'herp'): 1.0,
#  ('azotemia', 'phenylephrin'): 0.0,
#  ('captopril', 'ffp'): 1.0,
#  ('clonazepam', 'seroquel'): 1.0,
#  ('neutral', 'scar'): 1.0,
#  ('bromid', 'opiat'): 1.0,
#  ('mrg', 'weekli'): 1.0,
#  ('asthma', 'schizophrenia'): 1.0,
#  ('pleasantli', 'subdur'): 1.0,
#  ('gabapentin', 'pneumococc'): 1.0,
#  ('dnr', 'learn'): 1.0,
#  ('chip', 'readmit'): 1.0,
#  ('dyslipidemia', 'profound'): 1.0,
#  ('dietari', 'hypothermia'): 1.0,
#  ('hsq', 'platelet'): 0.0,
#  ('absorb', 'option'): 1.0,
#  ('nicotin', 'oob'): 1.0,
#  ('habitu', 'levoph'): 1.0,
#  ('dni', 'occipit'): 1.0,
#  ('jerk', 'mso'): 0.0,
#  ('ggt', 'zyprexa'): 1.0,
#  ('ffp', 'neo'): 0.0,
#  ('endur', 'knowledg'): 1.0,
#  ('echocardiogram', 'thiamin'): 1.0,
#  ('chair', 'signatur'): 1.0,
#  ('effac', 'readmit'): 1.0,
#  ('oob', 'tracheomalacia'): 1.0,
#  ('imbal', 'strictur'): 1.0,
#  ('core', 'dic'): 0.0,
#  ('deliv', 'dni'): 1.0,
#  ('captopril', 'tcdb'): 1.0,
#  ('fibrinogen', 'norepinephrin'): 0.32443728093998864,
#  ('palli', 'readmit'): 1.0,
#  ('clinician', 'cpr'): 0.0,
#  ('abnl', 'splint'): 1.0,
#  ('foci', 'jejunum'): 1.0,
#  ('ctx', 'hugger'): 1.0,
#  ('dnr', 'sarna'): 1.0,
#  ('gabapentin', 'phenylephrin'): 1.0,
#  ('mva', 'omeprazol'): 1.0,
#  ('behavior', 'seroquel'): 1.0,
#  ('hospic', 'mean'): 0.0,
#  ('declin', 'mva'): 1.0,
#  ('anur', 'azotemia'): 0.0,
#  ('romi', 'thiamin'): 1.0,
#  ('mrg', 'ntnd'): 1.0,
#  ('thiamin', 'vp'): 1.0,
#  ('dyslipidemia', 'gait'): 1.0,
#  ('ambul', 'nephrolog'): 1.0,
#  ('aox', 'unobtain'): 1.0,
#  ('laminectomi', 'stitch'): 1.0,
#  ('adenocarcinoma', 'assymetr'): 0.0,
#  ('angiogram', 'option'): 1.0,
#  ('oncologist', 'prognosi'): 1.0,
#  ('cracker', 'incent'): 0.0,
#  ('ofm', 'osa'): 1.0,
#  ('coarctat', 'tdi'): 1.0,
#  ('bank', 'fax'): 1.0,
#  ('carvedilol', 'ctx'): 1.0,
#  ('klonopin', 'zoloft'): 1.0,
#  ('deterior', 'gc'): 1.0,
#  ('ctx', 'quinolon'): 1.0,
#  ('dizzi', 'lat'): 1.0,
#  ('norepinephrin', 'pea'): 0.0,
#  ('hive', 'stitch'): 1.0,
#  ('ipf', 'scar'): 1.0,
#  ('abruptli', 'cmo'): 0.0,
#  ('diuril', 'dopamin'): 1.0,
#  ('burn', 'splint'): 1.0,
#  ('levoph', 'sluggish'): 0.0,
#  ('deploy', 'futil'): 1.0,
#  ('dni', 'scar'): 0.3738089703352453,
#  ('autopeep', 'azotemia'): 0.0,
#  ('captopril', 'omeprazol'): 1.0,
#  ('rhinorrhea', 'romi'): 1.0,
#  ('plerual', 'scar'): 1.0,
#  ('platelet', 'qtc'): 1.0,
#  ('ciwa', 'syncop'): 1.0,
#  ('arthrit', 'cdb'): 1.0,
#  ('rememb', 'ruptur'): 1.0,
#  ('dopamin', 'scopalamin'): 0.0,
#  ('furhter', 'lw'): 0.0,
#  ('mrg', 'oncologist'): 1.0,
#  ('ctx', 'young'): 1.0,
#  ('mellitu', 'pea'): 1.0,
#  ('ciwa', 'epigastr'): 1.0,
#  ('agonist', 'asthma'): 1.0,
#  ('dz', 'postop'): 1.0,
#  ('illeu', 'oob'): 0.0,
#  ('scar', 'smooth'): 1.0,
#  ('subq', 'xl'): 1.0,
#  ('dni', 'ntnd'): 0.602586982591368,
#  ('hctz', 'puff'): 1.0,
#  ('dnr', 'hypothermia'): 0.649926161380952,
#  ('bottl', 'occipit'): 1.0,
#  ('expir', 'im'): 1.0,
#  ('oob', 'seroquel'): 1.0,
#  ('pneumococc', 'puff'): 1.0,
#  ('clinician', 'dnr'): 0.5292841127058171,
#  ('cdb', 'dni'): 1.0,
#  ('aox', 'gait'): 1.0,
#  ('diaphoresi', 'subq'): 1.0,
#  ('captopril', 'hctz'): 1.0,
#  ('burn', 'spacer'): 1.0,
#  ('ofm', 'unsteadi'): 1.0,
#  ('autoset', 'declin'): 1.0,
#  ('historian', 'mellitu'): 1.0,
#  ('oob', 'video'): 1.0,
#  ('qam', 'thrive'): 1.0,
#  ('cash', 'ctx'): 1.0,
#  ('omeprazol', 'young'): 1.0,
#  ('cagluc', 'neo'): 0.0,
#  ('hsq', 'venti'): 1.0,
#  ('crack', 'hygein'): 1.0,
#  ('fibrinogen', 'rpr'): 1.0,
#  ('prognosi', 'wish'): 0.0,
#  ('scar', 'treitz'): 1.0,
#  ('arrest', 'autopeep'): 0.0,
#  ('adenocarcinoma', 'bill'): 1.0,
#  ('levoph', 'permiss'): 0.0,
#  ('gabapentin', 'strictur'): 1.0,
#  ('brb', 'crrt'): 0.0,
#  ('sensat', 'silent'): 1.0,
#  ('dnr', 'shorter'): 1.0,
#  ('mellitu', 'paralyt'): 1.0,
#  ('levoph', 'vasoconstrict'): 0.0,
#  ('chair', 'redirect'): 1.0,
#  ('commod', 'oob'): 0.7062981042005437,
#  ('agon', 'jerk'): 0.0,
#  ('postop', 'scar'): 1.0,
#  ('phenylephrin', 'seat'): 1.0,
#  ('acc', 'young'): 1.0,
#  ('bromid', 'effac'): 1.0,
#  ('asthma', 'knowledg'): 1.0,
#  ('aox', 'predict'): 1.0,
#  ('appi', 'venti'): 1.0,
#  ('conc', 'dnr'): 1.0,
#  ('anur', 'gentamycin'): 0.0,
#  ('articul', 'hypothermia'): 1.0,
#  ('lat', 'rehabilit'): 1.0,
#  ('asthma', 'norepinephrin'): 1.0,
#  ('bromid', 'clonazepam'): 1.0,
#  ('omeprazol', 'subq'): 1.0,
#  ('omeprazol', 'solut'): 1.0,
#  ('chemic', 'dni'): 0.0,
#  ('neoplast', 'thiamin'): 1.0,
#  ('dz', 'venti'): 1.0,
#  ('arrest', 'carvedilol'): 1.0,
#  ('asthma', 'burn'): 1.0,
#  ('hive', 'sarna'): 1.0,
#  ('profound', 'vertebra'): 1.0,
#  ('barium', 'breakfast'): 1.0,
#  ('ferrou', 'nocturn'): 1.0,
#  ('ambul', 'ctx'): 1.0,
#  ('mrg', 'readmit'): 1.0,
#  ('arrest', 'cefapim'): 1.0,
#  ('chip', 'hook'): 1.0,
#  ('declin', 'moan'): 0.0,
#  ('asthma', 'jewelri'): 1.0,
#  ('homogen', 'ligament'): 1.0,
#  ('sibl', 'thiamin'): 1.0,
#  ('rhinorrhea', 'thiamin'): 1.0,
#  ('anur', 'cpr'): 1.0,
#  ('dizzi', 'jewelri'): 1.0,
#  ('paralyt', 'recruit'): 1.0,
#  ('nifedipin', 'xl'): 1.0,
#  ('iddm', 'uri'): 1.0,
#  ('gabapentin', 'rhinorrhea'): 1.0,
#  ('artifici', 'gait'): 0.0,
#  ('barium', 'thrive'): 1.0,
#  ('option', 'unstabl'): 0.0,
#  ('neo', 'paralyt'): 0.2688261025519499,
#  ('declin', 'unasyn'): 1.0,
#  ('duski', 'levoph'): 0.0,
#  ('epidur', 'vertebra'): 1.0,
#  ('scar', 'slice'): 1.0,
#  ('echocardiogram', 'ppd'): 1.0,
#  ('contd', 'dopamin'): 1.0,
#  ('mva', 'seroquel'): 1.0,
#  ('lat', 'pneumothorac'): 0.5500560933045909,
#  ('hugger', 'sluggish'): 0.0,
#  ('asystol', 'neo'): 0.0,
#  ('quinolon', 'trazodon'): 1.0,
#  ('dnr', 'fibrinogen'): 0.6194674738764308,
#  ('norepinephrin', 'opiat'): 1.0,
#  ('dnr', 'occurr'): 1.0,
#  ('arrest', 'chb'): 0.0,
#  ('dopamin', 'vasopressin'): 0.5708190823810347,
#  ('ferrou', 'sibl'): 1.0,
#  ('laminectomi', 'unstabl'): 1.0,
#  ('ciwa', 'ran'): 1.0,
#  ('chip', 'dopamin'): 1.0,
#  ('agon', 'death'): 0.0,
#  ('deterior', 'echocardiogram'): 1.0,
#  ('barium', 'mottl'): 1.0,
#  ('bill', 'dyslipidemia'): 1.0,
#  ('pleasant', 'thirst'): 1.0,
#  ('crowd', 'mellitu'): 1.0,
#  ('dic', 'dnr'): 0.5980836359015403,
#  ('qam', 'sweat'): 1.0,
#  ('cagluc', 'neosynephrin'): 0.0,
#  ('influenc', 'jerk'): 1.0,
#  ('bromid', 'gabapentin'): 1.0,
#  ('mood', 'pneumococc'): 1.0,
#  ('ffp', 'vasopressin'): 0.0,
#  ('captopril', 'mellitu'): 1.0,
#  ('dnr', 'mean'): 0.0,
#  ('dobutamin', 'mean'): 1.0,
#  ('diflucan', 'jewelri'): 1.0,
#  ('dni', 'intiat'): 0.0,
#  ('hive', 'ppd'): 1.0,
#  ('asthma', 'romi'): 1.0,
#  ('captopril', 'core'): 0.0,
#  ('agon', 'rabbi'): 0.0,
#  ('fatti', 'xii'): 1.0,
#  ('conc', 'dni'): 1.0,
#  ('chip', 'palli'): 1.0,
#  ('lat', 'occupi'): 1.0,
#  ('hctz', 'sensat'): 1.0,
#  ('gastrojejunostomi', 'ligament'): 1.0,
#  ('fibrinogen', 'option'): 0.0,
#  ('deploy', 'epigastr'): 1.0,
#  ('articul', 'dome'): 1.0,
#  ('bottl', 'pea'): 1.0,
#  ('dizzi', 'laryng'): 1.0,
#  ('bromid', 'nicotin'): 1.0,
#  ('hive', 'mood'): 1.0,
#  ('ambien', 'laryng'): 1.0,
#  ('captopril', 'palli'): 1.0,
#  ('foci', 'postop'): 1.0,
#  ('colonoscopi', 'hive'): 1.0,
#  ('od', 'uri'): 1.0,
#  ('perisplen', 'plerual'): 1.0,
#  ('clonazepam', 'strictur'): 1.0,
#  ('laminectomi', 'pleasant'): 1.0,
#  ('chol', 'dnr'): 0.0,
#  ('diaphoresi', 'xl'): 1.0,
#  ('oob', 'xanax'): 1.0,
#  ('peac', 'rabbi'): 0.0,
#  ('futil', 'platelet'): 0.0,
#  ('historian', 'unstabl'): 1.0,
#  ('banana', 'oob'): 1.0,
#  ('bottl', 'omeprazol'): 1.0,
#  ('autoset', 'hctz'): 1.0,
#  ('hypercapnia', 'norepinephrin'): 0.0,
#  ('wish', 'xii'): 0.0,
#  ('iddm', 'lat'): 1.0,
#  ('asthma', 'prilosec'): 1.0,
#  ('captopril', 'nephrolog'): 1.0,
#  ('levoph', 'vasopressin'): 0.418857621924414,
#  ('oob', 'thk'): 1.0,
#  ('bipolar', 'dni'): 0.33510063360139086,
#  ('echocardiogram', 'sweat'): 1.0,
#  ('natg', 'simpli'): 1.0,
#  ('habitu', 'shorter'): 1.0,
#  ('mso', 'pose'): 0.0,
#  ('escal', 'mso'): 0.0,
#  ('carvedilol', 'video'): 1.0,
#  ('flight', 'nephrolog'): 1.0,
#  ('pleasant', 'qtc'): 1.0,
#  ('laryng', 'lat'): 1.0,
#  ('bicarbon', 'weekli'): 1.0,
#  ('bottl', 'bromid'): 1.0,
#  ('anaphylaxi', 'ctx'): 1.0,
#  ('chemic', 'cocain'): 1.0,
#  ('db', 'incent'): 1.0,
#  ('phlegm', 'thiamin'): 1.0,
#  ('bronchovascular', 'tracheomalacia'): 1.0,
#  ('incis', 'romi'): 1.0,
#  ('abnl', 'dz'): 1.0,
#  ('cmo', 'prognosi'): 0.0,
#  ('ipf', 'occipit'): 0.5,
#  ('bromid', 'trazodon'): 1.0,
#  ('arrang', 'levoph'): 0.0,
#  ('ferritin', 'trazodon'): 1.0,
#  ('cloth', 'paperwork'): 1.0,
#  ('dizzi', 'venti'): 0.6403352880457216,
#  ('crrt', 'readmit'): 1.0,
#  ('aox', 'gastriti'): 1.0,
#  ('cs', 'oob'): 1.0,
#  ('dni', 'sweat'): 1.0,
#  ('cash', 'cloth'): 0.6556705106579064,
#  ('dobutamin', 'paralyt'): 0.0,
#  ('barium', 'vallecula'): 1.0,
#  ('echocardiogram', 'hygein'): 1.0,
#  ('dnr', 'robitussin'): 0.0,
#  ('pronounc', 'slice'): 1.0,
#  ('arrest', 'pronounc'): 0.0,
#  ('aricept', 'commod'): 0.0,
#  ('dex', 'levoph'): 1.0,
#  ('mottl', 'ppd'): 1.0,
#  ('pneumococc', 'splint'): 1.0,
#  ('burn', 'ppd'): 1.0,
#  ('breakfast', 'probe'): 1.0,
#  ('nifedipin', 'pleasant'): 1.0,
#  ('dni', 'pleuravac'): 0.0,
#  ('dnr', 'lotion'): 0.27949367230854666,
#  ('dic', 'hypotherm'): 0.0,
#  ('levoph', 'mean'): 1.0,
#  ('dnr', 'palliat'): 0.0,
#  ('incent', 'romi'): 1.0,
#  ('forth', 'pleasant'): 1.0,
#  ('strictur', 'zyprexa'): 1.0,
#  ('fdp', 'platelet'): 0.0,
#  ('gait', 'mellitu'): 1.0,
#  ('epidur', 'norepinephrin'): 1.0,
#  ('ambien', 'ambul'): 1.0,
#  ('qtc', 'schizophrenia'): 1.0,
#  ('emper', 'moan'): 1.0,
#  ('habitu', 'occupi'): 1.0,
#  ('angiogram', 'fatti'): 1.0,
#  ('arrest', 'ethic'): 0.0,
#  ('qtc', 'retic'): 1.0,
#  ('ciwa', 'unasyn'): 1.0,
#  ('predict', 'zyprexa'): 1.0,
#  ('dnr', 'dz'): 1.0,
#  ('hunger', 'peac'): 0.0,
#  ('epigastr', 'splint'): 1.0,
#  ('ffp', 'sluggish'): 0.0,
#  ('azotemia', 'ggt'): 0.0,
#  ('subq', 'zoloft'): 1.0,
#  ('dni', 'requr'): 1.0,
#  ('ctx', 'diflucan'): 1.0,
#  ('flight', 'pleasantli'): 1.0,
#  ('anur', 'hypercapn'): 0.0,
#  ('dopamin', 'paperwork'): 0.0,
#  ('aricept', 'pivot'): 0.0,
#  ('moreov', 'scar'): 1.0,
#  ('dermat', 'pharmacolog'): 1.0,
#  ('mellitu', 'phlegm'): 1.0,
#  ('chair', 'xl'): 1.0,
#  ('clinician', 'dni'): 0.5292841127058171,
#  ('pronounc', 'underpenetr'): 1.0,
#  ('breakfast', 'panic'): 1.0,
#  ('articul', 'rhinorrhea'): 1.0,
#  ('cellcept', 'ultram'): 1.0,
#  ('compani', 'pleasant'): 1.0,
#  ('parastern', 'unavail'): 1.0,
#  ('bottl', 'motor'): 1.0,
#  ('hilum', 'lat'): 1.0,
#  ('epigastr', 'fibrinogen'): 1.0,
#  ('nimv', 'religi'): 0.0,
#  ('prognosi', 'vasopressin'): 0.0,
#  ('levoph', 'olanzapin'): 1.0,
#  ('dz', 'lat'): 1.0,
#  ('mjmgb', 'plate'): 1.0,
#  ('gabapentin', 'imbal'): 1.0,
#  ('fc', 'osa'): 1.0,
#  ('solut', 'treatement'): 1.0,
#  ('hsq', 'precordium'): 1.0,
#  ('compani', 'gabapentin'): 1.0,
#  ('anaphylaxi', 'subq'): 1.0,
#  ('barium', 'nectar'): 1.0,
#  ('sweat', 'ultrafiltr'): 1.0,
#  ('dni', 'expir'): 0.0,
#  ('neo', 'neosynephrin'): 0.0,
#  ('dnr', 'inspit'): 1.0,
#  ('mso', 'pronounc'): 0.0,
#  ('gentamycin', 'illeu'): 0.0,
#  ('futil', 'icter'): 0.0,
#  ('laryng', 'motor'): 1.0,
#  ('qtc', 'rm'): 1.0,
#  ('thrive', 'weekli'): 1.0,
#  ('burn', 'mva'): 1.0,
#  ('hook', 'scar'): 1.0,
#  ('captopril', 'yel'): 1.0,
#  ('colonoscopi', 'retic'): 1.0,
#  ('phlegm', 'stair'): 1.0,
#  ('commod', 'spirit'): 1.0,
#  ('cracker', 'spiromet'): 0.0,
#  ('mso', 'unstabl'): 0.0,
#  ('lusb', 'wish'): 1.0,
#  ('arrest', 'jejunum'): 0.0,
#  ('predict', 'prilosec'): 1.0,
#  ('crack', 'lotion'): 1.0,
#  ('hypotherm', 'wish'): 0.0,
#  ('chair', 'xanax'): 1.0,
#  ('ferritin', 'seriou'): 1.0,
#  ('para', 'peribronchovascular'): 0.0,
#  ('ffp', 'myeloma'): 1.0,
#  ('pivot', 'wallet'): 0.0,
#  ('endur', 'pod'): 1.0,
#  ('arrest', 'asystol'): 0.0,
#  ('db', 'habitu'): 1.0,
#  ('aricept', 'dnr'): 0.5103357439118639,
#  ('rhinorrhea', 'xl'): 1.0,
#  ('mean', 'underneath'): 0.0,
#  ('autopsi', 'dni'): 0.0,
#  ('money', 'xl'): 1.0,
#  ('strictur', 'tracheomalacia'): 1.0,
#  ('compani', 'predict'): 1.0,
#  ('bronchovascular', 'habitu'): 1.0,
#  ('dd', 'inspit'): 1.0,
#  ('opiat', 'rhinorrhea'): 1.0,
#  ('captopril', 'hsq'): 0.0,
#  ('lpm', 'myeloma'): 0.39994173456925625,
#  ('dizzi', 'dni'): 1.0,
#  ('levoph', 'thrive'): 1.0,
#  ('rhinorrhea', 'stair'): 1.0,
#  ('habitu', 'unasyn'): 1.0,
#  ('aricept', 'seroquel'): 1.0,
#  ('erythro', 'pleasant'): 1.0,
#  ('asthma', 'escal'): 1.0,
#  ('ppd', 'rm'): 1.0,
#  ('nephrolog', 'option'): 0.0,
#  ('fibrinogen', 'hung'): 0.0,
#  ('priest', 'wish'): 0.0,
#  ('mean', 'stg'): 0.0,
#  ('phenylephrin', 'rhinorrhea'): 1.0,
#  ('intent', 'nifedipin'): 1.0,
#  ('mellitu', 'osa'): 1.0,
#  ('bronchovascular', 'uri'): 1.0,
#  ('dni', 'heroic'): 0.0,
#  ('readmit', 'seroquel'): 1.0,
#  ('bank', 'pleasant'): 1.0,
#  ('flight', 'phlegm'): 1.0,
#  ('derecruit', 'levoph'): 0.0,
#  ('epigastr', 'unstabl'): 1.0,
#  ('oob', 'predict'): 1.0,
#  ('anur', 'chair'): 0.0,
#  ('dni', 'nifedipin'): 0.6350086522562018,
#  ('foci', 'magnevist'): 1.0,
#  ('oncologist', 'prilosec'): 1.0,
#  ('dyslipidemia', 'thiamin'): 1.0,
#  ('ardsnet', 'bicarbon'): 0.0,
#  ('hsq', 'splint'): 1.0,
#  ('dizzi', 'money'): 1.0,
#  ('dizzi', 'platelet'): 1.0,
#  ('among', 'ipf'): 0.0,
#  ('hilum', 'perisplen'): 0.0,
#  ('anur', 'trazodon'): 1.0,
#  ('bell', 'cellcept'): 1.0,
#  ('option', 'thrive'): 0.0,
#  ('oob', 'sweat'): 1.0,
#  ('commod', 'kerlix'): 1.0,
#  ('breakfast', 'nitroglycerin'): 1.0,
#  ('ambul', 'dni'): 0.6000582654307438,
#  ('expir', 'mso'): 0.0,
#  ('oob', 'stair'): 1.0,
#  ('hugger', 'wma'): 1.0,
#  ('ambul', 'seroquel'): 1.0,
#  ('arrest', 'clonazepam'): 1.0,
#  ('aox', 'broader'): 1.0,
#  ('dietari', 'romi'): 1.0,
#  ('oob', 'uncoop'): 1.0,
#  ('bicarbon', 'oligur'): 0.0,
#  ('dopamin', 'pitressin'): 0.0,
#  ('ggo', 'iddm'): 1.0,
#  ('arrest', 'pcv'): 0.0,
#  ('judgement', 'uri'): 1.0,
#  ('life', 'pea'): 0.0,
#  ('crrt', 'ffp'): 0.0,
#  ('anaphylaxi', 'thiamin'): 1.0,
#  ('mellitu', 'rhinorrhea'): 1.0,
#  ('bromid', 'readmit'): 1.0,
#  ('cefapim', 'pea'): 1.0,
#  ('dobutamin', 'intiat'): 1.0,
#  ('db', 'tubular'): 1.0,
#  ('gait', 'thirst'): 1.0,
#  ('aox', 'clonidin'): 1.0,
#  ('oncologist', 'romi'): 1.0,
#  ('romi', 'young'): 1.0,
#  ('bronchovascular', 'fatti'): 1.0,
#  ('dead', 'gurgl'): 0.0,
#  ('burn', 'dni'): 1.0,
#  ('fu', 'prilosec'): 1.0,
#  ('hsq', 'sweat'): 1.0,
#  ('hospic', 'palli'): 0.48074253828001656,
#  ('dni', 'thk'): 1.0,
#  ('amb', 'pleasant'): 1.0,
#  ('judgement', 'pleasant'): 0.0,
#  ('dyslipidemia', 'gastrojejunostomi'): 1.0,
#  ('phenylephrin', 'prognosi'): 0.0,
#  ('duski', 'prognosi'): 0.0,
#  ('dnr', 'dyslipidemia'): 1.0,
#  ('vallecula', 'video'): 1.0,
#  ('sensat', 'suprapub'): 1.0,
#  ('cdb', 'pleasantli'): 1.0,
#  ('incent', 'syst'): 1.0,
#  ('thrive', 'wish'): 1.0,
#  ('flight', 'readmit'): 1.0,
#  ('chair', 'vagu'): 1.0,
#  ('fibrinogen', 'nicotin'): 1.0,
#  ('crack', 'rm'): 1.0,
#  ('death', 'sweat'): 1.0,
#  ('fibrinogen', 'hypotherm'): 0.0,
#  ('clinician', 'stitch'): 1.0,
#  ('ferrou', 'omeprazol'): 1.0,
#  ('grim', 'prognosi'): 0.0,
#  ('diaphoresi', 'osa'): 1.0,
#  ('pleasant', 'rigor'): 1.0,
#  ('ciwa', 'sibl'): 1.0,
#  ('aaox', 'gown'): 0.0,
#  ('dead', 'dopamin'): 0.0,
#  ('ambien', 'ferrou'): 1.0,
#  ('declin', 'hctz'): 1.0,
#  ('rehabilit', 'rhinorrhea'): 1.0,
#  ('im', 'nifedipin'): 1.0,
#  ('endplat', 'foci'): 1.0,
#  ('opinion', 'palliat'): 0.0,
#  ('hook', 'rhochor'): 1.0,
#  ('nonlabor', 'pneumococc'): 1.0,
#  ('death', 'mso'): 0.0,
#  ('dopamin', 'pose'): 0.0,
#  ('cardiovert', 'neosynephrin'): 0.0,
#  ('chair', 'death'): 1.0,
#  ('fatti', 'hilum'): 0.5500560933045909,
#  ('sensat', 'signatur'): 1.0,
#  ('foci', 'gadolinium'): 1.0,
#  ('klonopin', 'pleasant'): 1.0,
#  ('hypercapn', 'neo'): 1.0,
#  ('icter', 'oncologist'): 1.0,
#  ('gown', 'sundown'): 0.0,
#  ('clonidin', 'dz'): 1.0,
#  ('brb', 'chair'): 1.0,
#  ('herp', 'sensat'): 1.0,
#  ('gc', 'mva'): 1.0,
#  ('phenylephrin', 'ruptur'): 1.0,
#  ('declin', 'predict'): 0.0,
#  ('dnr', 'illeu'): 0.0,
#  ('bipolar', 'strictur'): 1.0,
#  ('neoplast', 'palli'): 1.0,
#  ('anaphylaxi', 'pcv'): 0.0,
#  ('magnevist', 'occipit'): 1.0,
#  ('gabapentin', 'unstabl'): 1.0,
#  ('dysynchron', 'platelet'): 0.0,
#  ('laryng', 'pathologist'): 1.0,
#  ('criticar', 'pinpoint'): 0.0,
#  ('cmo', 'levoph'): 0.39994173456925625,
#  ('clonidin', 'friction'): 1.0,
#  ('lw', 'pca'): 1.0,
#  ('lat', 'syncop'): 1.0,
#  ('mrcp', 'wma'): 0.0,
#  ('goc', 'moan'): 0.0,
#  ('angiogram', 'deploy'): 1.0,
#  ('barium', 'pharyng'): 1.0,
#  ('bell', 'dnr'): 1.0,
#  ('arrest', 'neo'): 0.0,
#  ('osa', 'silent'): 1.0,
#  ('contd', 'dizzi'): 1.0,
#  ('osteoblast', 'scar'): 0.0,
#  ('dni', 'inspit'): 1.0,
#  ('ppd', 'xii'): 1.0,
#  ('homogen', 'nephrogram'): 0.5500560933045909,
#  ('dnr', 'phenylephrin'): 0.0,
#  ('asthma', 'mean'): 1.0,
#  ('bottl', 'currenlti'): 1.0,
#  ('profound', 'sweat'): 1.0,
#  ('ambul', 'permiss'): 1.0,
#  ('cash', 'klonopin'): 1.0,
#  ('director', 'zero'): 1.0,
#  ('puff', 'thrive'): 1.0,
#  ('epidur', 'fibrinogen'): 1.0,
#  ('lift', "sxn'ing"): 1.0,
#  ('fibrinogen', 'icter'): 0.0,
#  ('hugger', 'lpm'): 0.0,
#  ('epigastr', 'ppd'): 1.0,
#  ('asthma', 'gait'): 1.0,
#  ('fibrinogen', 'impli'): 1.0,
#  ('liw', 'unstabl'): 0.0,
#  ('aricept', 'resucit'): 1.0,
#  ('chb', 'zyprexa'): 1.0,
#  ('intent', 'sweat'): 1.0,
#  ('cyanot', 'furhter'): 0.0,
#  ('dermat', 'sarna'): 1.0,
#  ('dermat', 'scab'): 1.0,
#  ('ba', 'qam'): 1.0,
#  ('bromid', 'trabecul'): 1.0,
#  ('cdb', 'phlegm'): 1.0,
#  ('norepinephrin', 'zoloft'): 1.0,
#  ('ba', 'puff'): 1.0,
#  ('align', 'epidur'): 1.0,
#  ('dnr', 'ofm'): 1.0,
#  ('money', 'probe'): 1.0,
#  ('arrest', 'trazodon'): 0.0,
#  ('mellitu', 'pod'): 1.0,
#  ('oob', 'unsteadi'): 1.0,
#  ('osa', 'seat'): 1.0,
#  ('breakfast', 'fatti'): 1.0,
#  ('caspofungin', 'hive'): 1.0,
#  ('aox', 'mind'): 1.0,
#  ('cocain', 'rm'): 1.0,
#  ('caspofungin', 'metoclopramid'): 1.0,
#  ('nitroglycerin', 'pleasant'): 1.0,
#  ('bill', 'hctz'): 1.0,
#  ('coarctat', 'subcost'): 0.5793162261246866,
#  ('ambien', 'pharmacolog'): 1.0,
#  ('eg', 'pronounc'): 1.0,
#  ('arrest', 'venti'): 1.0,
#  ('ba', 'hypothermia'): 1.0,
#  ('death', 'declin'): 0.5292841127058171,
#  ('cmo', 'suffer'): 0.0,
#  ('acidot', 'prognosi'): 0.0,
#  ('bottl', 'mottl'): 1.0,
#  ('icter', 'platelet'): 0.0,
#  ('commod', 'dni'): 0.42068377387531336,
#  ('nectar', 'vallecula'): 1.0,
#  ('mso', 'neo'): 1.0,
#  ('dni', 'moan'): 0.461073450252371,
#  ('asthma', 'piriform'): 1.0,
#  ('dead', 'unrel'): 0.0,
#  ('compani', 'dnr'): 1.0,
#  ('bipolar', 'klonopin'): 1.0,
#  ('rhinorrhea', 'sibl'): 1.0,
#  ('lat', 'plate'): 1.0,
#  ('paperwork', 'rhinorrhea'): 1.0,
#  ('dz', 'suffer'): 1.0,
#  ('agon', 'deterior'): 0.0,
#  ('cyanot', 'eyelid'): 0.0,
#  ('^th', 'omeprazol'): 1.0,
#  ('ambul', 'sweat'): 1.0,
#  ('acidot', 'dic'): 0.0,
#  ('klonopin', 'osa'): 1.0,
#  ('svv', 'vasopressin'): 0.0,
#  ('death', 'scar'): 1.0,
#  ('ambul', 'aricept'): 1.0,
#  ('hospic', 'money'): 1.0,
#  ('dnr', 'uri'): 1.0,
#  ('lat', 'sweat'): 1.0,
#  ('stair', 'vp'): 1.0,
#  ('life', 'ppd'): 1.0,
#  ('pose', 'prognosi'): 0.0,
#  ('ppd', 'thrive'): 1.0,
#  ('escal', 'prognosi'): 0.0,
#  ('amb', 'oob'): 1.0,
#  ('cefapim', 'db'): 1.0,
#  ('nonlabor', 'subq'): 1.0,
#  ('crack', 'habitu'): 1.0,
#  ('fibrinogen', 'trazodon'): 0.0,
#  ('hctz', 'xanax'): 1.0,
#  ('articul', 'sweat'): 1.0,
#  ('aliv', 'dead'): 1.0,
#  ('oncologist', 'synthet'): 1.0,
#  ('anuria', 'dead'): 0.0,
#  ('acc', 'declin'): 1.0,
#  ('profound', 'romi'): 1.0,
#  ('neoplast', 'slice'): 0.0,
#  ('incis', 'pod'): 1.0,
#  ('ambul', 'pose'): 1.0,
#  ('adenocarcinoma', 'distort'): 1.0,
#  ('arthrit', 'commod'): 1.0,
#  ('chair', 'prec'): 1.0,
#  ('bromid', 'im'): 1.0,
#  ('conc', 'mso'): 0.0,
#  ('gabapentin', 'morbid'): 1.0,
#  ('fatti', 'ferritin'): 1.0,
#  ('palli', 'pneumonectomi'): 1.0,
#  ('osa', 'romi'): 1.0,
#  ('declin', 'norepinephrin'): 0.0,
#  ('chair', 'ofm'): 1.0,
#  ('bipolar', 'ferritin'): 1.0,
#  ('jewelri', 'money'): 0.6809400517330025,
#  ('declin', 'hypothermia'): 0.0,
#  ('deterior', 'nimv'): 0.0,
#  ('lat', 'splint'): 1.0,
#  ('gvhd', 'pleasant'): 1.0,
#  ('bair', 'paralyt'): 1.0,
#  ('nectar', 'subdur'): 1.0,
#  ('aricept', 'pyuria'): 1.0,
#  ('cpr', 'crrt'): 0.0,
#  ('ctx', 'resucit'): 1.0,
#  ('bipolar', 'lotion'): 0.0,
#  ('neo', 'recalibr'): 1.0,
#  ('ba', 'romi'): 1.0,
#  ('declar', 'dnr'): 0.0,
#  ('lusb', 'romi'): 1.0,
#  ('asthma', 'uri'): 1.0,
#  ('gait', 'pea'): 0.0,
#  ('duski', 'palli'): 0.0,
#  ('klonopin', 'oob'): 1.0,
#  ('hemangioma', 'phasic'): 1.0,
#  ('mtg', 'seroquel'): 1.0,
#  ('norepinephrin', 'refractori'): 1.0,
#  ('lat', 'osa'): 1.0,
#  ('burn', 'schizophrenia'): 1.0,
#  ('anur', 'myeloma'): 1.0,
#  ('angiogram', 'futil'): 1.0,
#  ('dni', 'struggl'): 0.0,
#  ('klonopin', 'schizophrenia'): 1.0,
#  ('binder', 'dnr'): 1.0,
#  ('bank', 'dnr'): 1.0,
#  ('predict', 'suffer'): 0.0,
#  ('agon', 'cmo'): 0.0,
#  ('dopamin', 'pronounc'): 0.0,
#  ('im', 'ppd'): 1.0,
#  ('asthma', 'cocain'): 1.0,
#  ('prilosec', 'wish'): 1.0,
#  ('paperwork', 'sweat'): 1.0,
#  ('adam', 'neo'): 0.0,
#  ('colonoscopi', 'readdress'): 1.0,
#  ('epigastr', 'postop'): 1.0,
#  ('judgement', 'rememb'): 1.0,
#  ('dead', 'dnr'): 0.0,
#  ('prilosec', 'robitussin'): 1.0,
#  ('fu', 'xl'): 1.0,
#  ('^th', 'stitch'): 1.0,
#  ('colonoscopi', 'wish'): 1.0,
#  ('adenocarcinoma', 'laryng'): 1.0,
#  ('osa', 'pleasant'): 1.0,
#  ('dni', 'mva'): 1.0,
#  ('stitch', 'video'): 1.0,
#  ('refractori', 'thrive'): 1.0,
#  ('aox', 'xii'): 1.0,
#  ('fibrinogen', 'xl'): 1.0,
#  ('ctx', 'historian'): 1.0,
#  ('aricept', 'gentamycin'): 0.0,
#  ('nocturn', 'trazodon'): 1.0,
#  ('palli', 'struggl'): 0.0,
#  ('cpr', 'escal'): 0.0,
#  ('cocain', 'pneumococc'): 1.0,
#  ('muddi', 'uri'): 1.0,
#  ('platelet', 'profound'): 1.0,
#  ('ctx', 'neo'): 1.0,
#  ('gabapentin', 'gait'): 1.0,
#  ('historian', 'romi'): 1.0,
#  ('cardiovert', 'dysynchron'): 0.0,
#  ('burn', 'ctx'): 1.0,
#  ('gastriti', 'xii'): 1.0,
#  ('anuria', 'unstabl'): 0.0,
#  ('lac', 'soln'): 1.0,
#  ('bicarbon', 'paralyt'): 0.0,
#  ('aricept', 'paperwork'): 1.0,
#  ('chair', 'cloth'): 1.0,
#  ('ctx', 'readdress'): 1.0,
#  ('agon', 'mortum'): 0.0,
#  ('foci', 'subdur'): 1.0,
#  ('historian', 'signatur'): 1.0,
#  ('asthma', 'mva'): 1.0,
#  ('hsq', 'xii'): 1.0,
#  ('bromid', 'lymphangit'): 1.0,
#  ('ciwa', 'neoplast'): 1.0,
#  ('dead', 'prognosi'): 0.0,
#  ('ambul', 'lac'): 1.0,
#  ('foci', 'occipit'): 0.5,
#  ('paralyt', 'phenylephrin'): 0.0,
#  ('cup', 'oob'): 1.0,
#  ('death', 'romi'): 1.0,
#  ('incent', 'levoph'): 1.0,
#  ('osa', 'uri'): 1.0,
#  ('declin', 'wish'): 0.5368924099923496,
#  ('cefapim', 'dnr'): 1.0,
#  ('gait', 'rm'): 1.0,
#  ('ambul', 'twitch'): 0.0,
#  ('schizophrenia', 'xanax'): 1.0,
#  ('aricept', 'ctx'): 1.0,
#  ('pose', 'vasoconstrict'): 0.0,
#  ('aox', 'ruptur'): 1.0,
#  ('epigastr', 'homogen'): 1.0,
#  ('commod', 'lotion'): 1.0,
#  ('hypotherm', 'scopalamin'): 0.0,
#  ('asystol', 'cmo'): 0.0,
#  ('massag', 'refractori'): 1.0,
#  ('hung', 'pea'): 0.0,
#  ('romi', 'scar'): 1.0,
#  ('hilum', 'zyprexa'): 0.0,
#  ('dnr', 'nocturn'): 1.0,
#  ('incent', 'rm'): 1.0,
#  ('seroquel', 'subdur'): 1.0,
#  ('dead', 'pulseless'): 0.0,
#  ('hospic', 'stg'): 0.0,
#  ('silent', 'treitz'): 0.0,
#  ('dizzi', 'ultram'): 1.0,
#  ('deterior', 'prognosi'): 0.0,
#  ('dnr', 'osa'): 0.508033515064845,
#  ('oncologist', 'refractori'): 1.0,
#  ('historian', 'jewelri'): 1.0,
#  ('qtc', 'rhinorrhea'): 1.0,
#  ('ciwa', 'rememb'): 1.0,
#  ('incis', 'levoph'): 1.0,
#  ('dni', 'norepinephrin'): 0.0,
#  ('esld', 'venti'): 1.0,
#  ('declin', 'park'): 1.0,
#  ('pea', 'phenylephrin'): 0.0,
#  ('palli', 'postop'): 1.0,
#  ('liw', 'pose'): 0.0,
#  ('azotemia', 'wma'): 0.0,
#  ('rhochor', 'scar'): 1.0,
#  ('pharyng', 'vallecula'): 1.0,
#  ('anuria', 'cpr'): 0.0,
#  ('dnr', 'unasyn'): 1.0,
#  ('asthma', 'nicotin'): 1.0,
#  ('hsq', 'phlegm'): 1.0,
#  ('adenosin', 'dni'): 1.0,
#  ('bill', 'bromid'): 1.0,
#  ('acv', 'levoph'): 1.0,
#  ('laryng', 'vallecula'): 1.0,
#  ('dizzi', 'sweat'): 1.0,
#  ('acc', 'ctx'): 1.0,
#  ('deterior', 'mrg'): 1.0,
#  ('gastriti', 'motor'): 1.0,
#  ('osa', 'xl'): 1.0,
#  ('para', 'slice'): 1.0,
#  ('commod', 'signatur'): 0.0,
#  ('hsq', 'sensat'): 1.0,
#  ('deterior', 'levoph'): 0.6516986494486501,
#  ('hurt', 'osa'): 1.0,
#  ('nitroglycerin', 'readdress'): 1.0,
#  ('defibril', 'tran'): 1.0,
#  ('intent', 'ppd'): 1.0,
#  ('breakfast', 'hsq'): 1.0,
#  ('petechia', 'rhinorrhea'): 0.0,
#  ('exophyt', 'lusb'): 0.0,
#  ('asthma', 'mellitu'): 1.0,
#  ('breakfast', 'oob'): 1.0,
#  ('bicarbon', 'laminectomi'): 1.0,
#  ('cisatracurium', 'paralyt'): 0.0,
#  ('bill', 'lotion'): 1.0,
#  ('anuria', 'brb'): 0.0,
#  ('cmo', 'rabbi'): 0.0,
#  ('rm', 'venti'): 1.0,
#  ('vasoconstrict', 'vasopressin'): 0.0,
#  ('asthma', 'crack'): 1.0,
#  ('incent', 'synthet'): 0.0,
#  ('depth', 'levoph'): 1.0,
#  ('dome', 'foci'): 1.0,
#  ('gadolinium', 'magnevist'): 1.0,
#  ('mellitu', 'nocturn'): 1.0,
#  ('anaphylaxi', 'gadolinium'): 1.0,
#  ('hepatobiliari', 'wma'): 0.0,
#  ('chair', 'rusti'): 1.0,
#  ('expir', 'peribronchovascular'): 1.0,
#  ('burn', 'intiat'): 1.0,
#  ('director', 'young'): 1.0,
#  ('gait', 'unavail'): 1.0,
#  ('anaphylaxi', 'seroquel'): 1.0,
#  ('bicarbon', 'wma'): 0.0,
#  ('laminectomi', 'paco'): 1.0,
#  ('hive', 'signatur'): 1.0,
#  ('norepinephrin', 'oligur'): 0.0,
#  ('bronchovascular', 'crowd'): 0.6058257216010178,
#  ('cvvh', 'sluggishli'): 0.0,
#  ('consciou', 'core'): 1.0,
#  ('foci', 'neo'): 1.0,
#  ('dni', 'friction'): 1.0,
#  ('habitu', 'mean'): 1.0,
#  ('osa', 'suprapub'): 1.0,
#  ('crack', 'klonopin'): 1.0,
#  ('nicotin', 'tran'): 1.0,
#  ('cyanot', 'lw'): 0.0,
#  ('contractur', 'vasopressor'): 0.0,
#  ('pleasant', 'retic'): 1.0,
#  ('chair', 'readmit'): 1.0,
#  ('sibl', 'unstabl'): 0.0,
#  ('pneumococc', 'zyprexa'): 1.0,
#  ('furhter', 'twitch'): 0.0,
#  ('pathologist', 'vallecula'): 1.0,
#  ('moan', 'zyprexa'): 1.0,
#  ('historian', 'xii'): 1.0,
#  ('abnl', 'occipit'): 1.0,
#  ('arrest', 'pulseless'): 0.0,
#  ('cdb', 'commod'): 1.0,
#  ('cash', 'dni'): 0.47071588729418296,
#  ('bipolar', 'zyprexa'): 1.0,
#  ('ppd', 'spacer'): 1.0,
#  ('cash', 'palli'): 1.0,
#  ('dni', 'zyprexa'): 0.6216719860319377,
#  ('paralyt', 'vasopressin'): 0.0,
#  ('mva', 'panic'): 1.0,
#  ('aliv', 'articul'): 1.0,
#  ('clonidin', 'unasyn'): 1.0,
#  ('ashen', 'declin'): 1.0,
#  ('rehabilit', 'young'): 1.0,
#  ('gait', 'thiamin'): 1.0,
#  ('cloth', 'declin'): 1.0,
#  ('dyslipidemia', 'lat'): 1.0,
#  ('dnr', 'suffer'): 0.8477075472756392,
#  ('nicotin', 'prilosec'): 1.0,
#  ('aox', 'dz'): 1.0,
#  ('mellitu', 'retic'): 1.0,
#  ('bipolar', 'historian'): 1.0,
#  ('dnr', 'mrg'): 1.0,
#  ('dni', 'mood'): 1.0,
#  ('pneumococc', 'pod'): 1.0,
#  ('ggt', 'rhinorrhea'): 0.0,
#  ('dni', 'stair'): 1.0,
#  ('incent', 'mottl'): 1.0,
#  ('pod', 'soln'): 1.0,
#  ('cmo', 'viabl'): 0.0,
#  ('gentamycin', 'hugger'): 0.0,
#  ('dnr', 'quadrent'): 1.0,
#  ('morbid', 'osa'): 1.0,
#  ('opinion', 'prognosi'): 0.0,
#  ('chair', 'pivot'): 1.0,
#  ('aox', 'oncologist'): 1.0,
#  ('readmit', 'soln'): 1.0,
#  ('brb', 'unstabl'): 0.0,
#  ('ferritin', 'qam'): 1.0,
#  ('religi', 'trazodon'): 0.0,
#  ('cardiovert', 'tranfer'): 1.0,
#  ('ctx', 'ruptur'): 1.0,
#  ('paperwork', 'wish'): 1.0,
#  ('prilosec', 'sweat'): 1.0,
#  ('absorb', 'omeprazol'): 1.0,
#  ('lusb', 'nifedipin'): 1.0,
#  ('pastor', 'pea'): 0.0,
#  ('lift', 'mrg'): 1.0,
#  ('coach', 'soln'): 1.0,
#  ('anur', 'quietli'): 0.0,
#  ('rememb', 'sensat'): 1.0,
#  ('gait', 'hive'): 1.0,
#  ('anaphylaxi', 'uri'): 1.0,
#  ('clonidin', 'sweat'): 1.0,
#  ('institut', 'smooth'): 1.0,
#  ('levoph', 'modifi'): 1.0,
#  ('homogen', 'ipf'): 1.0,
#  ('hypotherm', 'sluggish'): 0.0,
#  ('azotemia', 'dic'): 0.0,
#  ('fatti', 'syncop'): 1.0,
#  ('commod', 'jewelri'): 0.0,
#  ('ambul', 'phlegm'): 1.0,
#  ('itchi', 'palli'): 1.0,
#  ('pleasant', 'scab'): 1.0,
#  ('hive', 'lymphangit'): 1.0,
#  ('neo', 'phenylephrin'): 0.4821702791231874,
#  ('lusb', 'mellitu'): 1.0,
#  ('deterior', 'option'): 0.0,
#  ('grave', 'prognosi'): 0.44994390669540907,
#  ('caspofungin', 'fibrinogen'): 1.0,
#  ('thrive', 'trazodon'): 1.0,
#  ('readmit', 'xanax'): 1.0,
#  ('habitu', 'thiamin'): 1.0,
#  ('dermat', 'romi'): 1.0,
#  ('mva', 'scl'): 1.0,
#  ('declin', 'sweat'): 1.0,
#  ('ethic', 'neo'): 0.0,
#  ('freeli', 'spill'): 1.0,
#  ('fax', 'pleasant'): 1.0,
#  ('mrg', 'ppd'): 1.0,
#  ('life', 'religi'): 0.0,
#  ('declin', 'oligur'): 0.0,
#  ('hsq', 'hypotherm'): 0.0,
#  ('arrest', 'asthma'): 1.0,
#  ('ctx', 'signatur'): 1.0,
#  ('dnr', 'proph'): 1.0,
#  ('moan', 'venti'): 0.0,
#  ('asthma', 'director'): 1.0,
#  ('levoph', 'lpm'): 1.0,
#  ('dic', 'hung'): 0.0,
#  ('chair', 'cocain'): 1.0,
#  ('dnr', 'tremul'): 1.0,
#  ('among', 'barium'): 0.0,
#  ('gait', 'hung'): 0.0,
#  ('fibrinogen', 'itchi'): 0.0,
#  ('chair', 'intent'): 1.0,
#  ('occupi', 'seriou'): 1.0,
#  ('agreement', 'heroic'): 0.0,
#  ('pneumococc', 'rpr'): 1.0,
#  ('iddm', 'purpl'): 1.0,
#  ('dead', 'expir'): 0.0,
#  ('asthma', 'pleasant'): 1.0,
#  ('deterior', 'mottl'): 0.0,
#  ('brb', 'tran'): 1.0,
#  ('spill', 'videofluoroscopi'): 1.0,
#  ('ctx', 'itchi'): 1.0,
#  ('adenosin', 'tcdb'): 1.0,
#  ('dz', 'hive'): 1.0,
#  ('echocardiogram', 'fatti'): 1.0,
#  ('anuria', 'synthet'): 1.0,
#  ('echocardiogram', 'omeprazol'): 1.0,
#  ('metoclopramid', 'soln'): 1.0,
#  ('agon', 'venti'): 1.0,
#  ('klonopin', 'led'): 1.0,
#  ('moan', 'rabbi'): 0.0,
#  ('motor', 'sibl'): 1.0,
#  ('clonazepam', 'hive'): 1.0,
#  ('dic', 'pneumonectomi'): 0.0,
#  ('sluggishli', 'vasopressin'): 0.0,
#  ('fdp', 'neo'): 0.0,
#  ...}

# %%
# patient_dead_cooc_df
print(patient_cooc_0)
# Out:
# {111: {('arrest', 'pea'): 5.0, ('cpr', 'pea'): 4.0, ('arrest', 'cpr'): 4.0, ('cpr', 'vasopressin'): 4.0, ('pea', 'vasopressin'): 4.0, ('arrest', 'vasopressin'): 4.0, ('pcv', 'vasopressin'): 2.0, ('cpr', 'pcv'): 2.0, ('pcv', 'pea'): 2.0, ('arrest', 'pcv'): 2.0, ('paralyt', 'pcv'): 2.0, ('paralyt', 'vasopressin'): 2.0, ('cpr', 'paralyt'): 2.0, ('paralyt', 'pea'): 2.0, ('arrest', 'paralyt'): 2.0, ('norepinephrin', 'paralyt'): 2.0, ('norepinephrin', 'pcv'): 2.0, ('norepinephrin', 'vasopressin'): 2.0, ('cpr', 'norepinephrin'): 2.0, ('norepinephrin', 'pea'): 2.0, ('arrest', 'norepinephrin'): 2.0, ('hypothermia', 'norepinephrin'): 2.0, ('hypothermia', 'paralyt'): 2.0, ('hypothermia', 'pcv'): 2.0, ('hypothermia', 'vasopressin'): 2.0, ('cpr', 'hypothermia'): 2.0, ('hypothermia', 'pea'): 2.0, ('arrest', 'hypothermia'): 2.0, ('hypercapnia', 'hypothermia'): 2.0, ('hypercapnia', 'norepinephrin'): 2.0, ('hypercapnia', 'paralyt'): 2.0, ('hypercapnia', 'pcv'): 2.0, ('hypercapnia', 'vasopressin'): 2.0, ('cpr', 'hypercapnia'): 2.0, ('hypercapnia', 'pea'): 2.0, ('arrest', 'hypercapnia'): 2.0, ('dic', 'hypercapnia'): 2.0, ('dic', 'hypothermia'): 2.0, ('dic', 'norepinephrin'): 2.0, ('dic', 'paralyt'): 2.0, ('dic', 'pcv'): 2.0, ('dic', 'vasopressin'): 2.0, ('cpr', 'dic'): 2.0, ('dic', 'pea'): 2.0, ('arrest', 'dic'): 2.0, ('dic', 'phenylephrin'): 2.0, ('hypercapnia', 'phenylephrin'): 2.0, ('hypothermia', 'phenylephrin'): 2.0, ('norepinephrin', 'phenylephrin'): 2.0, ('paralyt', 'phenylephrin'): 2.0, ('pcv', 'phenylephrin'): 2.0, ('phenylephrin', 'vasopressin'): 2.0, ('cpr', 'phenylephrin'): 2.0, ('pea', 'phenylephrin'): 2.0, ('arrest', 'phenylephrin'): 2.0, ('bicarbon', 'phenylephrin'): 2.0, ('bicarbon', 'dic'): 2.0, ('bicarbon', 'hypercapnia'): 2.0, ('bicarbon', 'hypothermia'): 2.0, ('bicarbon', 'norepinephrin'): 2.0, ('bicarbon', 'paralyt'): 2.0, ('bicarbon', 'pcv'): 2.0, ('bicarbon', 'vasopressin'): 2.0, ('bicarbon', 'cpr'): 2.0, ('bicarbon', 'pea'): 2.0, ('arrest', 'bicarbon'): 2.0, ('azotemia', 'bicarbon'): 2.0, ('azotemia', 'phenylephrin'): 2.0, ('azotemia', 'dic'): 2.0, ('azotemia', 'hypercapnia'): 2.0, ('azotemia', 'hypothermia'): 2.0, ('azotemia', 'norepinephrin'): 2.0, ('azotemia', 'paralyt'): 2.0, ('azotemia', 'pcv'): 2.0, ('azotemia', 'vasopressin'): 2.0, ('azotemia', 'cpr'): 2.0, ('azotemia', 'pea'): 2.0, ('arrest', 'azotemia'): 2.0, ('autopeep', 'azotemia'): 2.0, ('autopeep', 'bicarbon'): 2.0, ('autopeep', 'phenylephrin'): 2.0, ('autopeep', 'dic'): 2.0, ('autopeep', 'hypercapnia'): 2.0, ('autopeep', 'hypothermia'): 2.0, ('autopeep', 'norepinephrin'): 2.0, ('autopeep', 'paralyt'): 2.0, ('autopeep', 'pcv'): 2.0, ('autopeep', 'vasopressin'): 2.0, ('autopeep', 'cpr'): 2.0, ('autopeep', 'pea'): 2.0, ('arrest', 'autopeep'): 2.0, ('arrest', 'death'): 3.0, ('death', 'vasopressin'): 2.0, ('cpr', 'death'): 2.0, ('death', 'pea'): 2.0, ('clinician', 'death'): 2.0, ('clinician', 'vasopressin'): 2.0, ('clinician', 'cpr'): 2.0, ('clinician', 'pea'): 2.0, ('arrest', 'clinician'): 2.0, ('profound', 'vasopressin'): 2.0, ('cpr', 'profound'): 2.0, ('pea', 'profound'): 2.0, ('arrest', 'profound'): 2.0, ('death', 'expir'): 2.0, ('arrest', 'expir'): 2.0}, 346: {}, 404: {('death', 'paco'): 1.0}, 546: {('hurt', 'oder'): 1.0, ('historian', 'oder'): 1.0, ('historian', 'hurt'): 1.0}, 618: {}, 705: {('dni', 'dnr'): 2.0, ('cmo', 'dnr'): 2.0}, 726: {}, 1039: {}, 1556: {('dnr', 'mso'): 7.0, ('dni', 'dnr'): 8.0, ('dni', 'mso'): 7.0}, 1872: {}, 1944: {}, 2286: {('cyanot', 'pitressin'): 11.0, ('cyanot', 'incis'): 8.0, ('anur', 'cyanot'): 7.0, ('bair', 'hugger'): 7.0}, 2990: {}, 3055: {}, 3099: {('neo', 'neosynephrin'): 1.0, ('dopamin', 'neosynephrin'): 1.0, ('ffp', 'neo'): 1.0, ('ffp', 'neosynephrin'): 1.0, ('ffp', 'vasopressin'): 1.0, ('neo', 'vasopressin'): 1.0, ('neosynephrin', 'vasopressin'): 1.0, ('levoph', 'vasopressin'): 1.0, ('ffp', 'levoph'): 1.0, ('levoph', 'neo'): 1.0, ('levoph', 'neosynephrin'): 1.0, ('hypotherm', 'levoph'): 1.0, ('hypotherm', 'vasopressin'): ...

# %%
print(patient_node_0)
# Out:
# {111: {'arrest': 6.0, 'pea': 5.0, 'cpr': 4.0, 'vasopressin': 4.0, 'pcv': 2.0, 'paralyt': 2.0, 'norepinephrin': 2.0, 'hypothermia': 2.0, 'hypercapnia': 2.0, 'dic': 2.0, 'phenylephrin': 2.0, 'bicarbon': 2.0, 'azotemia': 2.0, 'autopeep': 2.0, 'death': 3.0, 'clinician': 2.0, 'profound': 2.0, 'expir': 2.0}, 346: {'arrest': 4.0, 'sluggish': 6.0}, 404: {'paco': 1.0, 'death': 1.0}, 546: {'oder': 1.0, 'hurt': 1.0, 'historian': 1.0}, 618: {'video': 2.0}, 705: {'dnr': 5.0, 'dni': 2.0, 'cmo': 5.0, 'mso': 2.0}, 726: {'mso': 3.0, 'dnr': 3.0}, 1039: {'wish': 4.0}, 1556: {'mso': 13.0, 'dnr': 8.0, 'dni': 8.0}, 1872: {'pronounc': 1.0}, 1944: {'arrest': 4.0, 'cvvhd': 5.0}, 2286: {'cyanot': 17.0, 'vasopressin': 14.0, 'levoph': 8.0, 'dnr': 7.0, 'prognosi': 7.0, 'purpl': 10.0, 'mottl': 7.0, 'pitressin': 15.0, 'incis': 10.0, 'anur': 9.0, 'cvvh': 9.0, 'hugger': 7.0, 'bair': 7.0}, 2990: {'chair': 17.0, 'oob': 17.0, 'levoph': 31.0, 'anur': 24.0}, 3055: {'gc': 3.0, 'wish': 3.0, 'cmo': 4.0}, 3099: {'neo': 2.0, 'neosynephrin': 2.0, 'dopamin': 1.0, 'ffp': 2.0, 'vasopressin': 1.0, 'levoph': 1.0, 'hypotherm': 1.0, 'hung': 1.0, 'dic': 1.0, 'cagluc': 1.0, 'suport': 1.0, 'polici': 1.0, 'ethic': 1.0, 'cpr': 1.0}, 3201: {'sluggish': 3.0, 'dopamin': 3.0, 'norepinephrin': 1.0, 'levoph': 1.0, 'unavail': 1.0, 'neo': 2.0, 'pitressin': 1.0, 'vasopressin': 1.0, 'unequ': 1.0, 'pronounc': 1.0, 'nahco': 1.0, 'mortem': 1.0, 'levof': 1.0, 'expir': 1.0, 'cpr': 1.0}, 3526: {'levoph': 2.0, 'dnr': 2.0, 'dni': 2.0, 'laryng': 1.0, 'pronounc': 1.0, 'mso': 1.0, 'jerk': 1.0, 'intiat': 1.0, 'declin': 1.0, 'death': 1.0, 'agon': 1.0}, 3773: {'plate': 1.0, 'mso': 2.0, 'escal': 1.0, 'dopamin': 1.0, 'dnr': 1.0, 'dni': 1.0, 'cmo': 1.0, 'pronounc': 1.0, 'death': 1.0}, 3881: {'dnr': 3.0, 'dni': 3.0, 'cmo': 3.0, 'moan': 2.0, 'sluggish': 2.0}, 4122: {}, 4754: {'levoph': 11.0, 'dobutamin': 10.0, 'captopril': 17.0}, 4811: {'life': 2.0, 'dnr': 2.0, 'dni': 2.0, 'hospic': 2.0}, 5476: {}, 5494: {'dnr': 2.0, 'dni': 2.0, 'wish': 2.0, 'escal': 2.0, 'video': 2.0}, 5774: {'levoph': 13.0, 'neo': 11.0, 'cvvhd': 11.0, 'sluggish': 9.0, 'pneumococc': 13.0, 'hugger': 12.0, 'cpr': 12.0}, 5786: {'dobutamin': 9.0}, 5913: {}, 6133: {'lc': 6.0}, 6735: {'prognosi': 3.0, 'dopamin': 3.0, 'mottl': 2.0, 'mso': 2.0, 'levoph': 2.0, 'cpr': 2.0, 'grave': 2.0}, 6745: {'dnr': 4.0, 'dni': 4.0, 'mso': 2.0, 'wish': 1.0, 'heroic': 1.0, 'rabbi': 1.0, 'profound': 1.0, 'moan': 1.0}, 6973: {'dnr': 3.0, 'dni': 3.0}, 6981: {'lat': 1.0, 'occupi': 1.0, 'dnr': 2.0, 'dni': 2.0, 'pleuravac': 1.0, 'priest': 1.0}, 7277: {'neo': 6.0, 'mso': 14.0}, 7310: {'hospic': 3.0, 'dnr': 3.0, 'dni': 3.0, 'nonrebreath': 1.0, 'palliat': 2.0, 'opinion': 2.0, 'sacrament': 1.0, 'peac': 1.0, 'prognosi': 1.0}, 7924: {'neo': 1.0, 'wish': 1.0, 'reveiw': 1.0}, 7977: {'neo': 3.0, 'levoph': 2.0}, 9908: {'levof': 1.0, 'neosynephrin': 1.0, 'levoph': 1.0, 'intiat': 1.0, 'dnr': 1.0, 'dni': 1.0, 'agon': 1.0, 'cmo': 2.0}, 9984: {'levoph': 4.0, 'incis': 2.0, 'hugger': 2.0}, 10302: {'levoph': 56.0, 'dnr': 41.0, 'hive': 39.0, 'fibrinogen': 39.0, 'platelet': 36.0, 'hemothorax': 36.0, 'chb': 29.999999999999996, 'suffer': 26.0, 'norepinephrin': 17.0, 'dic': 31.0, 'abruptli': 18.0}, 10510: {'xopenex': 7.000000000000001}, 10545: {'gvhd': 2.0, 'dopamin': 2.0, 'cyanot': 1.0, 'eyelid': 1.0, 'fungemia': 1.0, 'furhter': 1.0, 'lw': 1.0, 'twitch': 1.0, 'ambul': 1.0, 'vasopressin': 1.0, 'cmo': 1.0, 'levoph': 1.0, 'vasoconstrict': 1.0, 'liw': 1.0, 'mso': 1.0, 'pose': 1.0, 'prognosi': 1.0, 'sibl': 1.0, 'unstabl': 1.0, 'asystol': 1.0, 'dead': 1.0, 'pronounc': 1.0, 'autopsi': 1.0}, 10642: {'scar': 1.0, 'centimet': 1.0, 'dnr': 4.0, 'dni': 3.0, 'mso': 1.0, 'gasp': 1.0, 'prognosi': 1.0, 'moan': 1.0}, 11049: {'neo': 6.0, 'lw': 2.0, 'phenylephrin': 2.0}, 11209: {'subdur': 1.0, 'deterior': 1.0, 'dni': 3.0, 'dnr': 3.0, 'vasopressor': 1.0, 'bair': 1.0, 'dopamin': 1.0, 'hugger': 1.0, 'hypotherm': 1.0, 'hypothermia': 1.0, 'levoph': 1.0, 'paperwork': 1.0, 'rusti': 1.0, 'sluggish': 1.0, 'wish': 1.0, 'arre ...

# %%
# Check if all nodes has embeddings
patient_node_set = set()
patient_node_0_dict = {}
patient_node_1_dict = {}
    
for k, v in patient_node_0.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_0_dict:
            patient_node_0_dict[item] = v[item]
        else:
            patient_node_0_dict[item] = patient_node_0_dict[item] + v[item]
        
    
for k, v in patient_node_1.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_1_dict:
            patient_node_1_dict[item] = v[item]
        else:
            patient_node_1_dict[item] = patient_node_1_dict[item] + v[item]

# %%
print(len(patient_node_set))
print(len(patient_node_0_dict))
print(len(patient_node_1_dict))
# Out:
# 633
# 379
# 571

# %%
patient_node_odd_scores = {}

for set_item in patient_node_set:
    if set_item in patient_node_0_dict and set_item in patient_node_1_dict:
        d_prob = patient_node_0_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        a_prob = patient_node_1_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_node_odd_scores[set_item] = log_odd_score

# %%
print(patient_node_odd_scores)
# Out:
# {'zoloft': 0.8974370375810735, 'readmit': 6.90875477931522, 'agonist': 6.90875477931522, 'pleuravac': -6.90875477931522, 'viabl': -6.90875477931522, 'mso': -0.3669741958284662, 'zyprexa': 2.906721752674218, 'book': 6.90875477931522, 'beeper': 6.90875477931522, 'morbid': 6.90875477931522, 'mrg': 6.90875477931522, 'sooner': 6.90875477931522, 'preme': 6.90875477931522, 'simpli': 6.90875477931522, 'deploy': 1.604655121332035, 'qam': 3.174533094073146, 'subdur': 4.7177301007748484, 'twitch': 3.60035323709679, 'funer': 6.90875477931522, 'judgement': -1.095952712632351, 'impli': 0.6916505477038827, 'suffer': 1.6864515242778426, 'contractur': 2.8995119199810393, 'anyway': 6.90875477931522, 'town': 2.9256884298210646, 'thrive': 0.9294189568548948, 'laryng': 4.509960818540722, 'mrcp': -1.0271828417136022, 'moreov': 6.90875477931522, 'captopril': 2.956624359695953, 'lax': 6.90875477931522, 'rescan': 6.90875477931522, 'pulseless': -6.90875477931522, 'nacl': 6.90875477931522, 'declin': -0.3251358805203766, 'sluggish': 0.5836985542843016, 'hospic': 0.4149738469106543, 'adam': -6.90875477931522, 'sundown': 4.051735818618102, 'ligament': 1.3825560390092835, 'float': 6.90875477931522, 'waist': 0.4046335072286383, 'syst': 6.90875477931522, 'stack': -6.90875477931522, 'duski': -0.809128888289493, 'deliv': 6.90875477931522, 'agreement': -6.90875477931522, 'diuril': 6.90875477931522, 'fwb': 6.90875477931522, 'aricept': -0.24207273499980653, 'appi': 6.90875477931522, 'warmer': 6.90875477931522, 'fibrinogen': 0.6890116342592116, 'acv': 6.90875477931522, 'align': 2.1317280276818393, 'tea': 6.90875477931522, 'respitori': -0.6916505477038827, 'redirect': 0.863048163908824, 'permiss': -2.1883847407670785, 'grimmac': 6.90875477931522, 'magnevist': 6.90875477931522, 'peac': -6.90875477931522, 'moan': 1.0548445068920116, 'hypercapnia': -2.014895675944767, 'institut': 2.007571633726069, 'surviv': 6.90875477931522, 'panic': 6.90875477931522, 'uncoop': 6.90875477931522, 'director': 6.90875477931522, 'deflat': 6.90875477931522, 'breakfast': 6.90875477931522, 'ud': 6.90875477931522, 'arrang': -6.90875477931522, 'ntnd': 0.9566305237694903, 'bromid': 6.90875477931522, 'angiogram': 6.90875477931522, 'nectar': 6.90875477931522, 'stair': 6.90875477931522, 'sibl': 0.809128888289493, 'knew': 6.90875477931522, 'schistocyt': 6.90875477931522, 'wallet': 2.2927445483990123, 'nicotin': 6.90875477931522, 'piriform': 6.90875477931522, 'xanax': 6.90875477931522, 'unequ': 0.0, 'bank': 2.387057016415087, 'plerual': -1.095952712632351, 'ultram': 6.90875477931522, 'rhochor': 6.90875477931522, 'rusti': -0.6916505477038827, 'unavail': 2.4165779821478726, 'nahco': 2.473073171472692, 'nifedipin': 2.4270957194435745, 'ferritin': 6.90875477931522, 'dic': 1.1780886503127903, 'hemangioma': 6.90875477931522, 'sweat': 6.90875477931522, 'cvvh': -0.02545138452962548, 'gown': 1.3825560390092835, 'cvvhd': -0.3782571110465018, 'cisatracurium': -0.9533015672059649, 'thk': 6.90875477931522, 'chol': -6.90875477931522, 'cooki': 6.90875477931522, 'weekli': 6.90875477931522, 'forth': 6.90875477931522, 'spill': 6.90875477931522, 'reappear': 6.90875477931522, 'nonreact': -6.90875477931522, 'ggo': 6.90875477931522, 'unstabl': 1.423202222234302, 'purpl': 1.160271244612009, 'hiccup': 0.0, 'hida': 6.90875477931522, 'dnr': 0.8878077019401656, 'arrest': 1.1884144866522524, 'opiat': 1.069012844912209, 'familt': -6.90875477931522, 'oligur': 1.5098168539127583, 'nephrogram': 1.095952712632351, 'argatroban': -0.8013676005646301, 'unobtain': 1.095952712632351, 'spfc': 2.0716061679700735, 'resucit': 6.90875477931522, 'hypotherm': 0.5741514985877892, 'diamox': 6.90875477931522, 'quinolon': 0.44536653690200506, 'park': 6.90875477931522, 'kyphoscoliosi': 6.90875477931522, 'neoplast': 2.040109298143704, "tf'ing": 6.90875477931522, 'esoph': -1.4998139424623853, 'fliud': -6.90875477931522, 'od': 6.90875477931522, 'proph': 6.90875477931522, 'nonrebreath': 2.513398374617902, 'calvarium': 1.3825560390092835, 'retic': 6.908 ...

# %%
patient_square_node_data = pd.DataFrame({'node':list(patient_node_odd_scores.keys()), 'feature':list(patient_node_odd_scores.values())})
patient_square_node_data
# Out:
#                node   feature
# 0            zoloft  0.897437
# 1           readmit  6.908755
# 2           agonist  6.908755
# 3         pleuravac -6.908755
# 4             viabl -6.908755
# ..              ...       ...
# 628           motor  6.908755
# 629             ipf  1.017070
# 630  adenocarcinoma  3.112821
# 631           cramp  6.908755
# 632           itchi -0.033834
#
# [633 rows x 2 columns]

# %%
patient_square_node_id_data = patient_square_node_data.set_index("node")
patient_square_node_id_data['subject'] = ["positive" if r['feature'] > 0 else "negative" for i, r in patient_square_node_id_data.iterrows()]
patient_square_node_id_data
# Out:
#                  feature   subject
# node
# zoloft          0.897437  positive
# readmit         6.908755  positive
# agonist         6.908755  positive
# pleuravac      -6.908755  negative
# viabl          -6.908755  negative
# ...                  ...       ...
# motor           6.908755  positive
# ipf             1.017070  positive
# adenocarcinoma  3.112821  positive
# cramp           6.908755  positive
# itchi          -0.033834  negative
#
# [633 rows x 2 columns]

# %%
patient_subjects = patient_square_node_id_data["subject"]
patient_subjects
# Out:
# node
# zoloft            positive
# readmit           positive
# agonist           positive
# pleuravac         negative
# viabl             negative
#                     ...
# motor             positive
# ipf               positive
# adenocarcinoma    positive
# cramp             positive
# itchi             negative
# Name: subject, Length: 633, dtype: object

# %%
patient_square_node_data_no_feature = patient_square_node_id_data.drop(columns=["feature","subject"])
patient_square_node_data_no_feature
# Out:
# Empty DataFrame
# Columns: []
# Index: [zoloft, readmit, agonist, pleuravac, viabl, mso, zyprexa, book, beeper, morbid, mrg, sooner, preme, simpli, deploy, qam, subdur, twitch, funer, judgement, impli, suffer, contractur, anyway, town, thrive, laryng, mrcp, moreov, captopril, lax, rescan, pulseless, nacl, declin, sluggish, hospic, adam, sundown, ligament, float, waist, syst, stack, duski, deliv, agreement, diuril, fwb, aricept, appi, warmer, fibrinogen, acv, align, tea, respitori, redirect, permiss, grimmac, magnevist, peac, moan, hypercapnia, institut, surviv, panic, uncoop, director, deflat, breakfast, ud, arrang, ntnd, bromid, angiogram, nectar, stair, sibl, knew, schistocyt, wallet, nicotin, piriform, xanax, unequ, bank, plerual, ultram, rhochor, rusti, unavail, nahco, nifedipin, ferritin, dic, hemangioma, sweat, cvvh, gown, ...]
#
# [633 rows x 0 columns]

# %%
from sklearn.manifold import TSNE
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
from gensim.models import Word2Vec

# %% [markdown]
# ### Create a bi-directional df

# %%
# with edge weight
bidirect_source = []
bidirect_target = []
edge_weight = []

for item, val in new_patient_cooc_odd_scores.items():
    bidirect_source.extend([item[0], item[1]])
    bidirect_target.extend([item[1], item[0]])
    edge_weight.extend([val, val])
    
print(f"source: {len(bidirect_source)}, target: {len(bidirect_target)}")

weighted_patient_bidirect_square_edge_data = pd.DataFrame(
    {
        "source": bidirect_source,
        "target": bidirect_target,
        "weight": edge_weight,
    })
weighted_patient_bidirect_square_edge_data
# Out:
# source: 13552, target: 13552
#            source      target  weight
# 0           contd  refractori     1.0
# 1      refractori       contd     1.0
# 2       breakfast       dizzi     1.0
# 3           dizzi   breakfast     1.0
# 4          mortem         mso     0.0
# ...           ...         ...     ...
# 13547        iddm          gc     1.0
# 13548       expir         neo     0.0
# 13549         neo       expir     0.0
# 13550       mottl      phlegm     1.0
# 13551      phlegm       mottl     1.0
#
# [13552 rows x 3 columns]

# %%
# Weighted
G_weighted_patient_bidirect = StellarGraph(
    {"corner": patient_square_node_data_no_feature}, {"line": weighted_patient_bidirect_square_edge_data}
)
print(G_weighted_patient_bidirect.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 633, Edges: 13552
#
#  Node types:
#   corner: [633]
#     Features: none
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [13552]
#         Weights: range=[0, 1], mean=0.734681, std=0.426758
#         Features: none

# %%
# Weighted
rw_weighted_patient_bidirect = BiasedRandomWalk(G_weighted_patient_bidirect)

# %%
# Weighted
weighted_walks_patient_bidirect = rw_weighted_patient_bidirect.run(
    nodes=G_weighted_patient_bidirect.nodes(),  # root nodes
    length=100,  # maximum length of a random walk
    n=10,  # number of random walks per root node
    p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
    q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
#     weighted=True,  # for weighted random walks
    seed=42,  # random seed fixed for reproducibility
)
print("Number of random walks: {}".format(len(weighted_walks_patient_bidirect)))
# Out:
# Number of random walks: 6330

# %%
print(weighted_walks_patient_bidirect[0])
# Out:
# ['zoloft', 'fibrinogen', 'asthma', 'declin', 'bromid', 'mellitu', 'readmit', 'ferrou', 'trazodon', 'ppd', 'epigastr', 'fibrinogen', 'hive', 'hypothermia', 'oligur', 'norepinephrin', 'vasopressin', 'argatroban', 'cvvh', 'ardsnet', 'levoph', 'cmo', 'dnr', 'sensat', 'gabapentin', 'tremul', 'dnr', 'hsq', 'adam', 'futil', 'platelet', 'ffp', 'fibrinogen', 'olanzapin', 'schizophrenia', 'olanzapin', 'oob', 'nonlabor', 'cracker', 'pleasant', 'cracker', 'incent', 'ctx', 'anaphylaxi', 'ferritin', 'asthma', 'puff', 'crack', 'ultram', 'chair', '^th', 'ciwa', 'unasyn', 'echocardiogram', 'ppn', 'palli', 'xii', 'wish', 'xii', 'gvhd', 'dni', 'pea', 'bottl', 'oob', 'pleasantli', 'dni', 'nephrolog', 'dnr', 'money', 'dni', 'asystol', 'mso', 'prognosi', 'duski', 'neo', 'platelet', 'fdp', 'dnr', 'aricept', 'qam', 'aricept', 'mucinex', 'lpm', 'dni', 'unobtain', 'ppd', 'prec', 'vagu', 'chair', 'oob', 'db', 'money', 'signatur', 'ctx', 'signatur', 'diflucan', 'signatur', 'dnr', 'clonidin', 'dnr']

# %%
# Weighted
weighted_model_patient = Word2Vec(
    weighted_walks_patient_bidirect, size=128, window=5, min_count=0, sg=1, workers=4, iter=1
)

# %%
# Weighted
emb = weighted_model_patient.wv["cmo"]
emb
# Out:
# array([ 0.22423363, -0.25791198, -0.16557254, -0.1013716 ,  0.1569474 ,
#         0.11453626,  0.19616999,  0.12984107,  0.10460763, -0.15463032,
#         0.12444249, -0.15833847,  0.32350397,  0.29587132,  0.29815635,
#        -0.01629423, -0.09374627, -0.08437286, -0.2736841 ,  0.01144493,
#        -0.2687303 ,  0.06614881, -0.18390699, -0.02563416,  0.43154728,
#        -0.00948659, -0.1726561 , -0.10919049, -0.0449353 ,  0.11768422,
#         0.29234502, -0.34140745,  0.02771469, -0.21413943, -0.46133587,
#        -0.2023961 , -0.14290754, -0.3865803 ,  0.27182764, -0.01578524,
#         0.03137282, -0.49968663, -0.01120763,  0.32723638, -0.36426842,
#        -0.23432218,  0.28859916, -0.01543511, -0.29749978,  0.25565013,
#        -0.35839397,  0.26185727, -0.03817436, -0.12513338,  0.16185139,
#         0.27888975,  0.09717166, -0.03586515,  0.23065111,  0.18864413,
#        -0.01429134, -0.0455811 ,  0.05854176,  0.21725284,  0.21818916,
#         0.0846917 , -0.28954488,  0.02374705,  0.20545566,  0.04229008,
#         0.01070937, -0.19537081, -0.01800178,  0.02347814, -0.14892097,
#         0.15831348, -0.16581702,  0.0037206 , -0.02121662,  0.2628553 ,
#        -0.2645151 ,  0.09574968, -0.16670643,  0.21681954,  0.01888646,
#        -0.37709078, -0.3345548 , -0.11874082,  0.390587  ,  0.04731015,
#        -0.03231204,  0.2787348 , -0.22075745, -0.07118578, -0.53327227,
#         0.06116667,  0.33815747,  0.16181377, -0.0249775 ,  0.17031072,
#        -0.18508588, -0.03261378,  0.0315529 ,  0.0789431 ,  0.15025848,
#        -0.16512382, -0.31037518, -0.16893137,  0.0891519 , -0.2344661 ,
#         0.15662888,  0.11037888, -0.2808792 , -0.08060925, -0.10249492,
#         0.07259184, -0.05402074, -0.40909988, -0.21762115, -0.04326519,
#        -0.15812005,  0.03526984,  0.0355536 , -0.22357085,  0.06691548,
#         0.46452877,  0.33331728, -0.18321063], dtype=float32)

# %% [markdown]
# ### Visualise Node Embeddings generated by weighted random walks

# %% [markdown]
# ### Weighted edges

# %%
# Retrieve node embeddings and corresponding subjects
patient_weighted_node_ids = weighted_model_patient.wv.index2word  # list of node IDs
patient_weighted_node_embeddings = (
    weighted_model_patient.wv.vectors
)  # numpy.ndarray of size number of nodes times embeddings dimensionality
# the gensim ordering may not match the StellarGraph one, so rearrange
patient_node_targets = patient_subjects.loc[patient_weighted_node_ids].astype("category")

# %%
# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2, random_state=42)
patient_weighted_node_embeddings_2d = tsne.fit_transform(patient_weighted_node_embeddings)

# %%
# draw the points
alpha = 0.7

plt.figure(figsize=(10, 8))
plt.scatter(
    patient_weighted_node_embeddings_2d[:, 0],
    patient_weighted_node_embeddings_2d[:, 1],
    c=patient_node_targets.cat.codes,
    cmap="jet",
    alpha=0.7,
)
plt.show()

# %%
patient_weighted_node_emb_dict = {}
for index, row in patient_square_node_data_no_feature.iterrows():
    if index not in patient_weighted_node_emb_dict:
        patient_weighted_node_emb_dict[index] = weighted_model_patient.wv[index]
    else:
        print(f"index: {index} is already in a dictionary!")

# %%
# print(type(patient_weighted_node_emb_dict['aprv']))

# %%
import pandas as pd
import numpy as np

import stellargraph as sg
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import GCNSupervisedGraphClassification
from stellargraph import StellarGraph

from stellargraph import datasets

from sklearn import model_selection
from IPython.display import display, HTML

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import matplotlib.pyplot as plt

seed = 42
numpy.random.seed(seed)
tf.random.set_seed(seed)
sg.random.set_seed(seed)

# %% [markdown]
# ### Load the data

# %%
from collections import defaultdict

def create_graph_list(patient_cooc_dict, cooc_odd_scores, node_emb_dict, label):
    
    graphs = []
    labels = []
    
    for key,row in patient_cooc_dict.items():
     
        if row:
            source = []
            target = []
            edge_weight = []
            
            node_feature = []
            node_idx = []
            for cooc in row:
                source.extend([cooc[0], cooc[1]])
                target.extend([cooc[1], cooc[0]])
                edge_weight.extend([cooc_odd_scores[cooc], cooc_odd_scores[cooc]])
        
            node_idx = list(set(source + target))
    
            # Create a dataframe of only nodes
            square_node_data = pd.DataFrame(
                index=node_idx)
            
#             square_node_data['feature'] = [1] * len(node_idx)
        
            # Create a dictionary for each column for a vector
            node_features = defaultdict(list)
            for node in node_idx:
                for i, vec in enumerate(node_emb_dict[node]):
                    node_features['w_' + str(i)].append(vec)
        
            # Add columns to a dataframe
            for k, v in node_features.items():
              
                square_node_data[k] = v

            square_edges = pd.DataFrame({ 
                "source": source, 
                "target": target, 
                "weight":edge_weight
            })
        
            square = StellarGraph({"corner": square_node_data}, {"line": square_edges})
            graphs.append(square)
            labels.append(label)
            
    return graphs, labels

graphs = []
labels = []

# patient_weighted_node_emb_dict
graph_0, label_0 = create_graph_list(patient_cooc_0, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, -1)
graph_1, label_1 = create_graph_list(patient_cooc_1, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, 1)

graphs.extend(graph_0)
labels.extend(label_0)
print(f"graphs_0: {len(graphs)}, labels_0: {len(labels)}")
graphs.extend(graph_1)
labels.extend(label_1)
print(f"graphs_1: {len(graph_1)}, labels_1: {len(label_1)}")
print(f"graphs: {len(graphs)}, labels: {len(labels)}")
# Out:
# graphs_0: 162, labels_0: 162
# graphs_1: 726, labels_1: 726
# graphs: 888, labels: 888

# %%
# prepare test and train datasets
test_cnt = int(len(graphs)*0.1)/2
print(test_cnt)

pos_start = len(graph_0)
print(pos_start)

test_arr = []
train_arr = []
for i, v in enumerate(graphs):
    # Take first items for neg set
    if i < test_cnt:
        test_arr.append(i)    
    elif i > pos_start and i <= pos_start + test_cnt:
        test_arr.append(i)    
    else:
        train_arr.append(i)
# Out:
# 44.0
# 162

# %%
import random
seed = 42
c = list(test_arr)
random.Random(seed).shuffle(c)
test_arr =  c

# %%
c = list(train_arr)
random.Random(seed).shuffle(c)
train_arr =  c

# %%
train_index = np.array(train_arr)
test_index = np.array(test_arr)

# %%
print(len(test_index))
print(test_index)
# Out:
# 88
# [178 182  33  30  19  26 165 187  15 185  42   1 195 179 175  37 186  36
#  171 164 192  20 202   8  41 198  40 177  32 174  39 205  43 196  12  23
#   18 189 169 168   7  34 190   2  16  38 166  22 180  24   5   6 184 181
#  199   9 206  21 191 163  10 170 167   0 203 176 201 172  25 193 183  29
#   27 197 204   4 173 194  11 188  13  17  28  31  35   3  14 200]

# %%
print(len(train_index))
print(train_index)
# Out:
# 800
# [820 462 661 578 735 619 446 737 538 861 583 732 876 425  68 879 265 466
#  428 149 486 132 703 509 288 289 577 319 327 464 108 822 818 317 632 700
#  598 324 719 767 309 532 587 819 417 368 390 279 489 404 122 300 762 471
#  824 479 744 838 389 238 626  80 690 273 260 268 136  53 445  94 551 118
#  754  57 826 262 857 627 490 539 365 353 447 663 408 716 320 870 522 444
#  791 595 301 728 777 335  52 442  72 835 734 485 582 611 413  54 675 473
#  510 352 693 261 492 725 741 350 714 102 671 565 860  77 525  67 610 154
#   61 286 775 695 569 678 665 250  86 814 351 236 670 812 638 789 519 568
#  399 502 225 592 457 813 505 677 608 602 329  49 237 649 360 474 623 808
#  207 497 128 684 755  60 590  83 325 394 469 381 615 226 783 129 666 766
#  800 837 752 276 694 571 212 540 790 749 564 481 344 491 278  84 421 228
#  463 217 272 337 511 281 844 240 697 403 452 739 315 866 705  75 378 480
#  850 162 220 727 763  89 100 723 287 864 400 589 280 881 483 398 630 736
#  339 664 573 883 531 555  93 235 545 560 150 518 465 636 776 423 443 804
#  798 852 537 145 159 544 576 488 259 527  87 130 621 395 535 356 612 815
#  252 382 453 770 243 594 295 606 874 603 303 720 707 239 575 794 297 604
#  534 512 107 657 409 415 460 456 625 682 354 713 396 484 218 141 383 285
#  761 349 868 554 264 601 722 549 647 773 385 438 591 507  58 873 781 548
#  618 563 416 530 768 613 292 142 495 708 160 718 267 672 146 157 328 709
#  283 643 816 224 859 556 298 745 135  56 299 134 127 209 503 644 296 374
#  269  96 515 832 437 499 271 887 274 245 674 676 845 119 831 562 528  62
#  367 120 441  82 786 516 375 616 449 370 314 807 126 222 414 110 620  45
#   66 757 688 494  91  70 696 795 346 645 412 439 771 797 839 151 397 232
#  227 123 513 468  98 726 827 112  97 427 796 371 506 429 542 836 422 501
#  401 242 448 366 514 758 710 233 277 213 581 266 680 729 347 153 363 829
#  624 376 406 546  48  81 472 559 667 241 418 431 877 290 656 210 597 454
#  430 843 221 750 355 377 386 424 805 584 405  64 681 817 214 379 543 570
#  105 294 208 648 433  78 392  79 622 523  85 348 579 596 712 756 524 834
#  740 332 387 885  73 248 683 641 865 310 391 635 246 586 858 380 553 854
#  487  46 792 256 702 782 306 580 659 652 258 330 869  59  95 642 541 121
#  343 793 660 275 748 231 855 651 823 342 155 435 500 106 144  99 566 508
#  689 450 529 840 140 282 504 673 336 572 223 687 307 699 373 331 614 669
#  426 784 113 785 104 116  51 856 323 655  65 434 772 318 341 211 550 617
#  536 717 760 407 293 715 779 521 628 769 257 650 574 219 216 633 114 585
#  131 830 778 334 103 333 402 459 733  63 588 419 701  44 631 640 253 470
#  801 862 799 724 393 152 607 270 600 764  47 811 249 533 828 886 848 803
#  833 161  55 654 345 629 567 747 478 482 109 698 849 851 730 244 156  92
#  137 593 609 229 788 825 496 685 526 686 357 639 863 340 880 359 234 557
#  746 493 599 759 305 410 668 304 111 362 498 411 871 322 101 420 312 658
#  743 364 476 561 255 882 634 263 810 711 117 751 787 361 774 302 451 467
#  254 461 738 552 884 841 147 867 125 384 321 765  90 115 809 284 679 458
#  721 731 388 653 124 475 215 637 558  88 358 706 440 455 143 477 138 878
#  432 308 247 853 436 872 802 251  50 372 691 547 313 517 875 806 753 821
#  291 662  71 704 605 326 311 139  74  76 520 692 133 646 846 780 148 842
#  230 316 338 369 847  69 158 742]

# %%
print(test_arr)
# Out:
# [178, 182, 33, 30, 19, 26, 165, 187, 15, 185, 42, 1, 195, 179, 175, 37, 186, 36, 171, 164, 192, 20, 202, 8, 41, 198, 40, 177, 32, 174, 39, 205, 43, 196, 12, 23, 18, 189, 169, 168, 7, 34, 190, 2, 16, 38, 166, 22, 180, 24, 5, 6, 184, 181, 199, 9, 206, 21, 191, 163, 10, 170, 167, 0, 203, 176, 201, 172, 25, 193, 183, 29, 27, 197, 204, 4, 173, 194, 11, 188, 13, 17, 28, 31, 35, 3, 14, 200]

# %%
print(graphs[0].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 18, Edges: 212
#
#  Node types:
#   corner: [18]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [212]
#         Weights: range=[0, 0.788597], mean=0.0526238, std=0.175607
#         Features: none

# %%
print(graphs[100].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 11, Edges: 76
#
#  Node types:
#   corner: [11]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [76]
#         Weights: range=[0, 0.552589], mean=0.214523, std=0.219258
#         Features: none

# %%
summary = pd.DataFrame(
    [(g.number_of_nodes(), g.number_of_edges()) for g in graphs],
    columns=["nodes", "edges"],
)
summary.describe().round(1)
# Out:
#        nodes  edges
# count  888.0  888.0
# mean     5.6   22.4
# std      3.7   33.8
# min      2.0    2.0
# 25%      2.0    2.0
# 50%      5.0    8.0
# 75%      8.0   26.0
# max     23.0  272.0

# %%
graph_labels = pd.Series(labels)

# %%
print(graph_labels)
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 883    1
# 884    1
# 885    1
# 886    1
# 887    1
# Length: 888, dtype: int64

# %%
graph_labels.value_counts().to_frame()
# Out:
#       0
#  1  726
# -1  162

# %%
graph_labels = pd.get_dummies(graph_labels, drop_first=True)

# %%
print(type(graph_labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
graph_labels
# Out:
#      1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 883  1
# 884  1
# 885  1
# 886  1
# 887  1
#
# [888 rows x 1 columns]

# %%
generator = PaddedGraphGenerator(graphs=graphs)

# %%
def create_graph_classification_model(generator):
    gc_model = GCNSupervisedGraphClassification(
        layer_sizes=[64, 64],
        activations=["relu", "relu"],
        generator=generator,
        dropout=0.5,
    )
    x_inp, x_out = gc_model.in_out_tensors()
    predictions = Dense(units=32, activation="relu")(x_out)
    predictions = Dense(units=16, activation="relu")(predictions)
    predictions = Dense(units=1, activation="sigmoid")(predictions)

    # Let's create the Keras model and prepare it for training
    model = Model(inputs=x_inp, outputs=predictions)
    model.compile(optimizer=Adam(0.005), loss=binary_crossentropy, metrics=["acc"])

    return model

# %%
epochs = 200  # maximum number of training epochs
# folds = 10  # the number of folds for k-fold cross validation
# n_repeats = 5  # the number of repeats for repeated k-fold cross validation

# %%
es = EarlyStopping(
    monitor="val_loss", min_delta=0, patience=25, restore_best_weights=True
)

# %%
# To train in folds
def train_fold(model, train_gen, test_gen, es, epochs):
    history = model.fit(
        train_gen, epochs=epochs, validation_data=test_gen, verbose=0, callbacks=[es],
    )
    # calculate performance on the test data and return along with history
    test_metrics = model.evaluate(test_gen, verbose=0)
    test_acc = test_metrics[model.metrics_names.index("acc")]

    return history, test_acc

# %%
# To train in folds
def get_generators(train_index, test_index, graph_labels, batch_size):
    train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )
    test_gen = generator.flow(
        test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=batch_size, shuffle=False, seed=42
    )

    return train_gen, test_gen

# %%
# # To train in folds
# test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"Training and evaluating on fold {i+1} out of {folds * n_repeats}...")
#     train_gen, test_gen = get_generators(
#         train_index, test_index, graph_labels, batch_size=30
#     )

#     model = create_graph_classification_model(generator)

#     history, acc = train_fold(model, train_gen, test_gen, es, epochs)

#     test_accs.append(acc)

# %%
# To train in folds
test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
for i in range(50):
    print(f"Training and evaluating on fold {i+1}...")
    
    train_gen, test_gen = get_generators(
        train_index, test_index, graph_labels, batch_size=30
    )

    model = create_graph_classification_model(generator)

    history, acc = train_fold(model, train_gen, test_gen, es, epochs)

    test_accs.append(acc)
# Out:
# Training and evaluating on fold 1...
# Training and evaluating on fold 2...
# Training and evaluating on fold 3...
# Training and evaluating on fold 4...
# Training and evaluating on fold 5...
# Training and evaluating on fold 6...
# Training and evaluating on fold 7...
# Training and evaluating on fold 8...
# Training and evaluating on fold 9...
# Training and evaluating on fold 10...
# Training and evaluating on fold 11...
# Training and evaluating on fold 12...
# Training and evaluating on fold 13...
# Training and evaluating on fold 14...
# Training and evaluating on fold 15...
# Training and evaluating on fold 16...
# Training and evaluating on fold 17...
# Training and evaluating on fold 18...
# Training and evaluating on fold 19...
# Training and evaluating on fold 20...
# Training and evaluating on fold 21...
# Training and evaluating on fold 22...
# Training and evaluating on fold 23...
# Training and evaluating on fold 24...
# Training and evaluating on fold 25...
# Training and evaluating on fold 26...
# Training and evaluating on fold 27...
# Training and evaluating on fold 28...
# Training and evaluating on fold 29...
# Training and evaluating on fold 30...
# Training and evaluating on fold 31...
# Training and evaluating on fold 32...
# Training and evaluating on fold 33...
# Training and evaluating on fold 34...
# Training and evaluating on fold 35...
# Training and evaluating on fold 36...
# Training and evaluating on fold 37...
# Training and evaluating on fold 38...
# Training and evaluating on fold 39...
# Training and evaluating on fold 40...
# Training and evaluating on fold 41...
# Training and evaluating on fold 42...
# Training and evaluating on fold 43...
# Training and evaluating on fold 44...
# Training and evaluating on fold 45...
# Training and evaluating on fold 46...
# Training and evaluating on fold 47...
# Training and evaluating on fold 48...
# Training and evaluating on fold 49...
# Training and evaluating on fold 50...

# %%
# 1: Accuracy over all folds mean: 78.3% and std: 3.2%
# 2: Accuracy over all folds mean: 80.2% and std: 2.6%
# 3: Accuracy over all folds mean: 78.0% and std: 4.5%
# 4: Accuracy over all folds mean: 78.0% and std: 4.5%
# 5: Accuracy over all folds mean: 78.9% and std: 4.8%

# ------------------ After setting random
# 1: Accuracy over all folds mean: 78.1% and std: 2.6%
# 2: Accuracy over all folds mean: 77.4% and std: 4.7%
# 3: Accuracy over all folds mean: 78.5% and std: 2.4%
# 4: Accuracy over all folds mean: 77.7% and std: 4.5%
# 5: Accuracy over all folds mean: 77.0% and std: 7.5%

print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 77.9% and std: 4.9%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# 2nd try
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 72.1% and std: 9.2%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"\ntrain_index: \n{train_index}\ntest_index: \n{test_index}\n")
#     break
# print(f"train: {len(train_index)}, test: {len(test_index)}")

# %%
train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)
test_gen = generator.flow(
    test_index, targets=graph_labels.iloc[test_index].values, weighted=True, batch_size=40, shuffle=False, seed=42)

# %%
model_weighted = create_graph_classification_model(generator)

history = model_weighted.fit(
        train_gen, epochs=200, validation_data=test_gen, verbose=1, callbacks=[es])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 61ms/step - loss: 0.5292 - acc: 0.7898 - val_loss: 0.7795 - val_acc: 0.5000
# Epoch 2/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3744 - acc: 0.8505 - val_loss: 0.6660 - val_acc: 0.5000
# Epoch 3/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3378 - acc: 0.8505 - val_loss: 0.5932 - val_acc: 0.5000
# Epoch 4/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.3253 - acc: 0.8660 - val_loss: 0.5577 - val_acc: 0.7564
# Epoch 5/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.3111 - acc: 0.8970 - val_loss: 0.7263 - val_acc: 0.6410
# Epoch 6/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2923 - acc: 0.8787 - val_loss: 0.7418 - val_acc: 0.6410
# Epoch 7/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3078 - acc: 0.8886 - val_loss: 0.6489 - val_acc: 0.6410
# Epoch 8/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.2972 - acc: 0.8956 - val_loss: 0.5324 - val_acc: 0.7564
# Epoch 9/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2898 - acc: 0.8900 - val_loss: 0.5721 - val_acc: 0.7308
# Epoch 10/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2881 - acc: 0.8928 - val_loss: 0.5497 - val_acc: 0.7308
# Epoch 11/200
# 18/18 [==============================] - 1s 49ms/step - loss: 0.2663 - acc: 0.9013 - val_loss: 0.4908 - val_acc: 0.7821
# Epoch 12/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2608 - acc: 0.8984 - val_loss: 0.6779 - val_acc: 0.6667
# Epoch 13/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2698 - acc: 0.9013 - val_loss: 0.5233 - val_acc: 0.7436
# Epoch 14/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2573 - acc: 0.9055 - val_loss: 0.6405 - val_acc: 0.6923
# Epoch 15/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2375 - acc: 0.9097 - val_loss: 0.7150 - val_acc: 0.7179
# Epoch 16/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2365 - acc: 0.9041 - val_loss: 0.8433 - val_acc: 0.6667
# Epoch 17/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2410 - acc: 0.9069 - val_loss: 0.8310 - val_acc: 0.6282
# Epoch 18/200
# 18/18 [==============================] - 0s 28ms/step - loss: 0.2296 - acc: 0.9111 - val_loss: 0.7483 - val_acc: 0.6795
# Epoch 19/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2328 - acc: 0.9111 - val_loss: 0.9809 - val_acc: 0.5513
# Epoch 20/200
# 18/18 [==============================] - 1s 39ms/step - loss: 0.2223 - acc: 0.9140 - val_loss: 1.2209 - val_acc: 0.5513
# Epoch 21/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2456 - acc: 0.9154 - val_loss: 0.6157 - val_acc: 0.6923
# Epoch 22/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2258 - acc: 0.9126 - val_loss: 0.6728 - val_acc: 0.6923
# Epoch 23/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2157 - acc: 0.9267 - val_loss: 0.6729 - val_acc: 0.7308
# Epoch 24/200
# 18/18 [==============================] - 1s 49ms/step - loss: 0.2148 - acc: 0.9083 - val_loss: 0.7301 - val_acc: 0.6795
# Epoch 25/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2020 - acc: 0.9182 - val_loss: 0.7652 - val_acc: 0.6795
# Epoch 26/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2361 - acc: 0.9013 - val_loss: 0.8236 - val_acc: 0.5256
# Epoch 27/200
# 18/18 [==============================] - 1s 37ms/step - loss: 0.2234 - acc: 0.9126 - val_loss: 1.0063 - val_acc: 0.5513
# Epoch 28/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.2185 - acc: 0.9140 - val_loss: 0.8404 - val_acc: 0.6667
# Epoch 29/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2188 - acc: 0.9182 - val_loss: 0.7107 - val_acc: 0.6795
# Epoch 30/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2028 - acc: 0.9168 - val_loss: 1.0354 - val_acc: 0.6154
# Epoch 31/200
# 18/18 [==============================] - 1s 47ms/step - loss: 0.1995 - acc: 0.9140 - val_loss: 0.8398 - val_acc: 0.6923
# Epoch 32/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2047 - acc: 0.9224 - val_loss: 0.9179 - val_acc: 0.6282
# Epoch 33/200
# 18/18 [==============================] - 1s 49ms/step - loss: 0.2040 - acc: 0.9252 - val_loss: 0.8058 - val_acc: 0.6795
# Epoch 34/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2086 - acc: 0.9210 - val_loss: 0.7145 - val_acc: 0.6538
# Epoch 35/200
# 18/18 [==============================] - 1s 44ms/step - loss: 0.1910 - acc: 0.9210 - val_loss: 0.7358 - val_acc: 0.7179
# Epoch 36/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.1947 - acc: 0.9323 - val_loss: 0.6610 - val_acc: 0.7308

# %%
# calculate performance on the test data and return along with history
# Node features 128 node2vec, edge features all 1
test_metrics = model_weighted.evaluate(test_gen, verbose=1)
test_acc = test_metrics[model_weighted.metrics_names.index("acc")]
# Out:
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4908 - acc: 0.7821

# %%
print(test_metrics)
# loss and accuracy: [0.594617486000061, 0.7307692170143127]
# 2nd try: [0.5068581700325012, 0.7948718070983887]
# [0.5637023448944092, 0.7051281929016113]
print(test_acc)
# Out:
# [0.4908079504966736, 0.7820512652397156]
# 0.7820512652397156

# %%
print("Generate predictions for samples")
predictions = model_weighted.predict(test_gen, verbose=0)
print("predictions shape:", predictions.shape)
# predictions shape: (79, 1)
print(predictions)

# %%
print(test_gen.targets)
