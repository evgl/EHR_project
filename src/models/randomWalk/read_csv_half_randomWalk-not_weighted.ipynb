# %% [markdown]
# ### Data extraction
# Extract data from MIMIC-III

# %%
import time
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Import pandas 
import pandas as pd 

start = time.time()
# reading csv file 
admissions_df = pd.read_csv("../../datasets/mmc-3/ADMISSIONS.csv")
noteevents_df = pd.read_csv("../../datasets/mmc-3/NOTEEVENTS.csv") 
end = time.time()
print(end - start)
# Out:
# /home/evan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning:
#
# Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
# 34.75624132156372

# %%
start = time.time()
# Left join of two dataframes
note_admiss_df_left = noteevents_df.merge(admissions_df, on='HADM_ID', how='left', indicator=True)
end = time.time()
print(end - start)
# Out:
# 4.889202356338501

# %%
note_admiss_df_left[['DIAGNOSIS', 'SUBJECT_ID_x', 'SUBJECT_ID_y','DESCRIPTION', 'CATEGORY']]
# Out:
#                                      DIAGNOSIS  SUBJECT_ID_x  SUBJECT_ID_y  \
# 0                      RT LOWER LOBE PNEUMONIA         22532       22532.0
# 1        CHRONIC OBSTRUCTIVE PULMONARY DISEASE         13702       13702.0
# 2                TRACHEALBRONCHEAL MALACEA/SDA         13702       13702.0
# 3                     ASTHMA;COPD EXACERBATION         13702       13702.0
# 4                           S/P FALL;TELEMETRY         26880       26880.0
# ...                                        ...           ...           ...
# 2083175                                NEWBORN         31097       31097.0
# 2083176                                NEWBORN         31097       31097.0
# 2083177                                NEWBORN         31097       31097.0
# 2083178                                NEWBORN         31097       31097.0
# 2083179                                NEWBORN         31097       31097.0
#
#         DESCRIPTION           CATEGORY
# 0            Report  Discharge summary
# 1            Report  Discharge summary
# 2            Report  Discharge summary
# 3            Report  Discharge summary
# 4            Report  Discharge summary
# ...             ...                ...
# 2083175      Report      Nursing/other
# 2083176      Report      Nursing/other
# 2083177      Report      Nursing/other
# 2083178      Report      Nursing/other
# 2083179      Report      Nursing/other
#
# [2083180 rows x 5 columns]

# %%
pneumonia_df = note_admiss_df_left.loc[note_admiss_df_left["DIAGNOSIS"] == 'PNEUMONIA', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]

# %%
#pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'CHARTDATE', 'CHARTTIME', 'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'DIAGNOSIS', 'HAS_CHARTEVENTS_DATA']]
pneumonia_no_disch_df = pneumonia_df.loc[pneumonia_df["CATEGORY"] != 'Discharge summary', ['ROW_ID_x','SUBJECT_ID_x','CHARTDATE','STORETIME','CATEGORY','DESCRIPTION','TEXT', 'DEATHTIME']]

# %%
pneumonia_alive_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.isnull()]
pneumonia_dead_no_disch = pneumonia_no_disch_df[pneumonia_no_disch_df.DEATHTIME.notnull()]

# %%
pneumonia_dead_no_disch.shape
# Out:
# (11895, 8)

# %%
pneumonia_alive_no_disch.shape
# Out:
# (46134, 8)

# %%
pneumonia_alive_no_disch = pneumonia_alive_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])
pneumonia_dead_no_disch = pneumonia_dead_no_disch.sort_values(by=['SUBJECT_ID_x','CHARTDATE', 'ROW_ID_x'])

# %%
# Number of patients
pneumonia_dead_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 252

# %%
# Number of patients
pneumonia_alive_no_disch['SUBJECT_ID_x'].nunique()
# Out:
# 1167

# %%
# import text handling tool
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from collections import Counter

import sys
import re
import csv
import os.path

# define constants
# RESULT_HEADER = "WORD, FREQUENCY\n"
MIN_SEQ_LEN = 4
USE_1_N_SEQ = 2


# words that do not have meaning (can be modified later)
USELESS_WORDS = ["a", "the", "he", "she", ",", ".", "?", "!", ":", ";", "+", "*", "**"\
                 "your", "you"]

# count up the frequency of every word in every disease file
stemmer = PorterStemmer()
# create set of words to ignore in text
stop_words = set(stopwords.words('english'))

for word in USELESS_WORDS:
    stop_words.add(word)

# %%
#----------
def count_notes_per_patient(disease_df):
    patient_id_to_num_notes = {}
    patient_id = -1
    note_counter = 0
            
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        patient_id_check = int(row['SUBJECT_ID_x'])
                
        if not patient_id == patient_id_check:
            patient_id_to_num_notes[patient_id] = note_counter
            note_counter = 1
        else:
            note_counter += 1
                    
        patient_id = patient_id_check
                
    patient_id_to_num_notes[patient_id] = note_counter
    del patient_id_to_num_notes[-1]
    return patient_id_to_num_notes

patient_id_to_num_notes = {}
patient_id_to_num_notes['pneumonia_dead'] = count_notes_per_patient(pneumonia_dead_no_disch)
patient_id_to_num_notes['pneumonia_alive'] = count_notes_per_patient(pneumonia_alive_no_disch)
# Out:
# 100%|██████████| 11895/11895 [00:01<00:00, 8334.59it/s]
# 100%|██████████| 46134/46134 [00:04<00:00, 9691.44it/s]

# %%
patient_id_to_num_notes
# Out:
# {'pneumonia_dead': {111: 12,
#   346: 25,
#   404: 3,
#   546: 6,
#   618: 16,
#   705: 15,
#   726: 48,
#   1039: 55,
#   1556: 37,
#   1872: 3,
#   1944: 56,
#   2286: 69,
#   2990: 166,
#   3055: 29,
#   3099: 13,
#   3201: 8,
#   3526: 7,
#   3773: 6,
#   3881: 20,
#   4122: 51,
#   4754: 101,
#   4811: 21,
#   5476: 1,
#   5494: 22,
#   5774: 104,
#   5786: 152,
#   5913: 1,
#   6133: 68,
#   6735: 13,
#   6745: 13,
#   6973: 36,
#   6981: 8,
#   7277: 66,
#   7310: 8,
#   7924: 9,
#   7977: 9,
#   9908: 11,
#   9984: 15,
#   10302: 100,
#   10510: 86,
#   10545: 10,
#   10642: 10,
#   11049: 14,
#   11209: 9,
#   11395: 41,
#   12530: 24,
#   12849: 50,
#   13098: 46,
#   13566: 23,
#   14125: 9,
#   14514: 96,
#   14965: 25,
#   15159: 15,
#   15251: 11,
#   15396: 17,
#   15566: 37,
#   15853: 45,
#   16275: 17,
#   16344: 27,
#   16622: 51,
#   16684: 29,
#   17122: 16,
#   17354: 5,
#   17802: 64,
#   17983: 65,
#   18094: 23,
#   18736: 35,
#   18768: 46,
#   18848: 205,
#   18971: 26,
#   19243: 25,
#   19323: 6,
#   19390: 21,
#   19463: 20,
#   19535: 59,
#   19754: 13,
#   19827: 22,
#   19833: 58,
#   19872: 10,
#   20006: 8,
#   20023: 9,
#   20190: 6,
#   21046: 101,
#   21094: 36,
#   21427: 10,
#   21502: 102,
#   21580: 52,
#   21676: 12,
#   21699: 7,
#   21979: 11,
#   22735: 15,
#   23660: 12,
#   23795: 78,
#   24181: 13,
#   24582: 37,
#   24725: 57,
#   24730: 19,
#   24854: 25,
#   25003: 182,
#   25046: 7,
#   25774: 61,
#   25975: 9,
#   26474: 89,
#   26578: 15,
#   26716: 41,
#   26774: 3,
#   26849: 33,
#   27005: 5,
#   27145: 24,
#   27421: 61,
#   27431: 5,
#   27496: 7,
#   27504: 72,
#   27639: 221,
#   28004: 13,
#   28072: 34,
#   28178: 202,
#   28427: 6,
#   28498: 25,
#   28726: 34,
#   28750: 19,
#   28906: 32,
#   28907: 13,
#   28933: 394,
#   29105: 468,
#   29588: 72,
#   29647: 26,
#   29872: 225,
#   30476: 174,
#   30549: 12,
#   30614: 8,
#   30699: 14,
#   30786: 9,
#   30941: 110,
#   31030: 168,
#   31134: 24,
#   31139: 9,
#   31451: 48,
#   31556: 57,
#   31690: 18,
#   31692: 35,
#   32050: 34,
#   32326: 24,
#   32618: 42,
#   41546: 25,
#   43937: 6,
#   44851: 274,
#   45381: 16,
#   46589: 26,
#   46763: 6,
#   47045: 9,
#   48632: 147,
#   49079: 20,
#   49683: 3,
#   49922: 13,
#   50093: 8,
#   50231: 3,
#   50556: 216,
#   50859: 537,
#   51914: 313,
#   52010: 12,
#   53105: 115,
#   53399: 78,
#   54193: 85,
#   54401: 14,
#   54408: 2,
#   54739: 75,
#   54946: 7,
#   55400: 5,
#   55570: 14,
#   55887: 37,
#   55944: 34,
#   55987: 20,
#   56390: 19,
#   56648: 8,
#   56854: 170,
#   57091: 88,
#   57102: 35,
#   58702: 479,
#   59260: 11,
#   59437: 26,
#   60849: 2,
#   60868: 6,
#   61652: 7,
#   61667: 30,
#   63039: 8,
#   65513: 8,
#   68044: 40,
#   68095: 23,
#   68184: 5,
#   68308: 8,
#   68860: 14,
#   69719: 13,
#   69745: 25,
#   69776: 17,
#   70226: 8,
#   70447: 9,
#   72930: 11,
#   73811: 9,
#   73888: 109,
#   74316: 2,
#   74444: 81,
#   74686: 75,
#   75824: 10,
#   76282: 21,
#   76827: 2,
#   77382: 10,
#   78241: 3,
#   78388: 14,
#   79008: 27,
#   79055: 21,
#   79222: 18,
#   79877: 156,
#   80637: 148,
#   80678: 9,
#   80737: 46,
#   80805: 79,
#   81437: 27,
#   82393: 5,
#   82769: 85,
#   83932: 2,
#   84474: 34,
#   85160: 8,
#   85258: 52,
#   85404: 11,
#   85797: 9,
#   86007: 35,
#   86394: 4,
#   86684: 11,
#   86832: 67,
#   86863: 8,
#   86872: 326,
#   88193: 16,
#   88660: 11,
#   90256: 18,
#   91350: 19,
#   92074: 28,
#   92278: 52,
#   92331: 42,
#   93422: 7,
#   94341: 2,
#   94997: 9,
#   95280: 23,
#   95803: 18,
#   95830: 33,
#   95933: 56,
#   96699: 85,
#   97181: 30,
#   97795: 60,
#   98009: 33,
#   98299: 29,
#   98597: 2},
#  'pneumonia_alive': {68: 18,
#   85: 8,
#   94: 100,
#   165: 2,
#   211: 24,
#   224: 8,
#   231: 75,
#   283: 131,
#   357: 17,
#   368: 45,
#   370: 13,
#   384: 26,
#   426: 10,
#   509: 34,
#   514: 7,
#   596: 23,
#   674: 16,
#   707: 29,
#   711: 537,
#   770: 83,
#   773: 74,
#   899: 17,
#   1096: 17,
#   1135: 32,
#   1163: 12,
#   1174: 42,
#   1180: 5,
#   1283: 3,
#   1332: 66,
#   1339: 134,
#   1546: 21,
#   1568: 22,
#   1601: 12,
#   1606: 13,
#   1642: 4,
#   1660: 23,
#   1895: 22,
#   1923: 23,
#   2029: 175,
#   2090: 179,
#   2098: 26,
#   2128: 31,
#   2170: 9,
#   2187: 30,
#   2208: 139,
#   2337: 8,
#   2378: 57,
#   2386: 18,
#   2452: 22,
#   2508: 22,
#   2561: 126,
#   2585: 9,
#   2589: 92,
#   2590: 5,
#   2628: 218,
#   2658: 16,
#   2732: 12,
#   2784: 23,
#   2823: 21,
#   3070: 8,
#   3100: 70,
#   3154: 22,
#   3220: 28,
#   3277: 35,
#   3347: 15,
#   3359: 15,
#   3516: 11,
#   3602: 18,
#   3623: 116,
#   3641: 57,
#   3676: 49,
#   3830: 80,
#   3860: 203,
#   3862: 22,
#   3865: 8,
#   3895: 6,
#   3935: 44,
#   3952: 20,
#   3975: 34,
#   4109: 9,
#   4155: 23,
#   4236: 14,
#   4275: 45,
#   4316: 13,
#   4317: 106,
#   4328: 23,
#   4388: 14,
#   4454: 5,
#   4467: 12,
#   4489: 21,
#   4494: 18,
#   4584: 39,
#   4588: 80,
#   4641: 23,
#   4694: 19,
#   4804: 6,
#   5030: 49,
#   5145: 9,
#   5244: 113,
#   5264: 115,
#   5360: 19,
#   5434: 24,
#   5476: 36,
#   5516: 31,
#   5536: 21,
#   5564: 30,
#   5579: 14,
#   5609: 39,
#   5619: 25,
#   5631: 9,
#   5681: 9,
#   5691: 12,
#   5727: 41,
#   5761: 85,
#   5819: 19,
#   5904: 16,
#   5937: 61,
#   6038: 4,
#   6143: 15,
#   6176: 5,
#   6183: 17,
#   6206: 7,
#   6279: 20,
#   6378: 112,
#   6398: 11,
#   6557: 16,
#   6603: 15,
#   6884: 43,
#   6901: 8,
#   6915: 190,
#   7107: 230,
#   7169: 9,
#   7271: 117,
#   7356: 12,
#   7363: 284,
#   7492: 58,
#   7569: 32,
#   7603: 39,
#   7666: 9,
#   7700: 68,
#   7787: 18,
#   7849: 96,
#   7936: 3,
#   8070: 69,
#   8312: 29,
#   8337: 22,
#   8366: 25,
#   8471: 15,
#   8512: 16,
#   8515: 21,
#   8532: 9,
#   8556: 71,
#   8803: 4,
#   8895: 10,
#   8900: 11,
#   9124: 18,
#   9128: 2,
#   9253: 76,
#   9304: 12,
#   9332: 7,
#   9457: 6,
#   9505: 2,
#   9518: 80,
#   9544: 228,
#   9727: 37,
#   9736: 19,
#   9859: 12,
#   9871: 17,
#   9957: 15,
#   9973: 59,
#   10057: 144,
#   10207: 36,
#   10299: 167,
#   10304: 8,
#   10377: 125,
#   10502: 9,
#   10581: 11,
#   10589: 18,
#   10626: 72,
#   10635: 6,
#   10666: 84,
#   10675: 13,
#   10761: 9,
#   10830: 14,
#   10848: 16,
#   10950: 23,
#   11003: 63,
#   11018: 24,
#   11061: 11,
#   11065: 40,
#   11197: 14,
#   11236: 58,
#   11247: 6,
#   11275: 26,
#   11313: 9,
#   11320: 66,
#   11421: 37,
#   11446: 13,
#   11593: 19,
#   11616: 64,
#   11671: 14,
#   11702: 7,
#   11708: 44,
#   11747: 20,
#   11762: 10,
#   11829: 25,
#   11850: 23,
#   11860: 11,
#   11932: 18,
#   11989: 17,
#   12028: 221,
#   12140: 36,
#   12177: 53,
#   12183: 26,
#   12274: 9,
#   12312: 13,
#   12380: 45,
#   12508: 136,
#   12567: 61,
#   12585: 4,
#   12629: 43,
#   12633: 11,
#   12799: 77,
#   12803: 21,
#   12824: 21,
#   13123: 10,
#   13329: 22,
#   13330: 13,
#   13503: 15,
#   13546: 20,
#   13577: 7,
#   13593: 20,
#   13615: 10,
#   13627: 31,
#   13664: 120,
#   13728: 13,
#   13748: 21,
#   13864: 5,
#   13881: 2,
#   14035: 12,
#   14144: 24,
#   14172: 9,
#   14193: 8,
#   14256: 26,
#   14269: 21,
#   14309: 13,
#   14342: 20,
#   14385: 14,
#   14507: 9,
#   14520: 56,
#   14705: 17,
#   14805: 16,
#   14855: 96,
#   14975: 23,
#   15046: 86,
#   15054: 33,
#   15301: 5,
#   15347: 4,
#   15361: 15,
#   15472: 13,
#   15590: 85,
#   15716: 323,
#   15852: 15,
#   15875: 192,
#   16038: 89,
#   16053: 17,
#   16076: 397,
#   16102: 6,
#   16129: 22,
#   16147: 7,
#   16216: 17,
#   16275: 90,
#   16318: 12,
#   16367: 47,
#   16384: 48,
#   16409: 40,
#   16412: 8,
#   16438: 28,
#   16468: 15,
#   16469: 20,
#   16479: 7,
#   16492: 6,
#   16554: 19,
#   16560: 8,
#   16685: 1,
#   16733: 14,
#   16755: 24,
#   16800: 12,
#   16802: 27,
#   16850: 14,
#   16975: 186,
#   16992: 42,
#   17107: 6,
#   17149: 17,
#   17150: 23,
#   17250: 28,
#   17260: 10,
#   17276: 10,
#   17539: 24,
#   17547: 9,
#   17617: 4,
#   17631: 19,
#   17664: 24,
#   17722: 8,
#   17764: 3,
#   17795: 215,
#   17843: 37,
#   17882: 6,
#   17903: 7,
#   17906: 88,
#   18082: 22,
#   18123: 146,
#   18233: 8,
#   18250: 2,
#   18281: 61,
#   18320: 207,
#   18353: 16,
#   18365: 10,
#   18459: 33,
#   18637: 35,
#   18673: 38,
#   18681: 10,
#   18737: 7,
#   18999: 40,
#   19029: 4,
#   19036: 12,
#   19164: 20,
#   19463: 14,
#   19569: 4,
#   19653: 30,
#   19698: 79,
#   19793: 37,
#   19803: 9,
#   19833: 77,
#   19851: 83,
#   19859: 14,
#   19940: 9,
#   20061: 7,
#   20086: 85,
#   20133: 121,
#   20181: 204,
#   20187: 25,
#   20263: 6,
#   20265: 7,
#   20289: 63,
#   20381: 10,
#   20425: 103,
#   20528: 37,
#   20580: 1,
#   20598: 31,
#   20600: 16,
#   20624: 32,
#   20643: 20,
#   20804: 25,
#   20899: 17,
#   20951: 8,
#   20979: 26,
#   21037: 21,
#   21056: 9,
#   21093: 60,
#   21255: 3,
#   21269: 279,
#   21277: 23,
#   21301: 16,
#   21350: 18,
#   21548: 7,
#   21581: 11,
#   21737: 7,
#   21745: 5,
#   21764: 7,
#   22019: 2,
#   22180: 5,
#   22192: 5,
#   22287: 10,
#   22432: 6,
#   22450: 11,
#   22520: 63,
#   22534: 4,
#   22580: 10,
#   22624: 43,
#   22667: 72,
#   22684: 14,
#   22706: 8,
#   22754: 44,
#   22855: 47,
#   22921: 2,
#   23028: 22,
#   23109: 2,
#   23131: 49,
#   23161: 29,
#   23215: 9,
#   23318: 15,
#   23418: 22,
#   23423: 11,
#   23451: 26,
#   23568: 8,
#   23657: 34,
#   23734: 15,
#   23763: 21,
#   23847: 9,
#   24099: 2,
#   24170: 2,
#   24178: 209,
#   24276: 82,
#   24344: 290,
#   24483: 7,
#   24535: 23,
#   24562: 10,
#   24569: 20,
#   24622: 1,
#   24687: 45,
#   24807: 41,
#   24847: 12,
#   24868: 57,
#   24903: 45,
#   25001: 25,
#   25016: 78,
#   25038: 66,
#   25097: 42,
#   25117: 38,
#   25225: 17,
#   25256: 30,
#   25295: 59,
#   25326: 17,
#   25373: 158,
#   25406: 5,
#   25515: 18,
#   25526: 86,
#   25579: 27,
#   25591: 61,
#   25671: 11,
#   25750: 107,
#   25775: 38,
#   25844: 22,
#   25860: 9,
#   25861: 16,
#   25889: 20,
#   25941: 86,
#   26036: 11,
#   26040: 79,
#   26052: 3,
#   26080: 5,
#   26097: 65,
#   26118: 60,
#   26311: 28,
#   26391: 64,
#   26398: 14,
#   26469: 52,
#   26542: 55,
#   26601: 58,
#   26638: 155,
#   26727: 10,
#   26797: 8,
#   26869: 11,
#   26884: 5,
#   26887: 4,
#   26956: 23,
#   27003: 18,
#   27036: 10,
#   27043: 30,
#   27047: 41,
#   27049: 14,
#   27089: 24,
#   27121: 89,
#   27143: 135,
#   27172: 9,
#   27179: 118,
#   27194: 60,
#   27269: 19,
#   27367: 84,
#   27371: 17,
#   27431: 33,
#   27486: 2,
#   27576: 84,
#   27597: 60,
#   27600: 28,
#   27677: 11,
#   27726: 59,
#   27729: 70,
#   27752: 11,
#   27800: 12,
#   27809: 18,
#   27823: 31,
#   27879: 13,
#   27886: 30,
#   27999: 25,
#   28050: 20,
#   28055: 4,
#   28073: 74,
#   28093: 21,
#   28103: 16,
#   28164: 159,
#   28173: 124,
#   28230: 23,
#   28291: 36,
#   28298: 31,
#   28356: 10,
#   28527: 46,
#   28530: 24,
#   28642: 2,
#   28668: 3,
#   28671: 33,
#   28689: 5,
#   28717: 23,
#   28729: 73,
#   28742: 7,
#   28758: 94,
#   28827: 12,
#   28843: 1,
#   28884: 12,
#   28932: 24,
#   28935: 4,
#   28939: 4,
#   28973: 152,
#   29007: 9,
#   29043: 12,
#   29093: 5,
#   29096: 21,
#   29102: 18,
#   29129: 15,
#   29137: 8,
#   29139: 17,
#   29141: 27,
#   29219: 19,
#   29240: 10,
#   29274: 17,
#   29350: 18,
#   29377: 80,
#   29379: 21,
#   29456: 22,
#   29478: 32,
#   29501: 6,
#   29503: 11,
#   29504: 18,
#   29513: 65,
#   29528: 5,
#   29556: 5,
#   29566: 17,
#   29619: 18,
#   29638: 15,
#   29639: 26,
#   29660: 9,
#   29703: 12,
#   29866: 12,
#   29872: 14,
#   29913: 11,
#   29919: 24,
#   29927: 63,
#   29965: 26,
#   29972: 7,
#   30010: 7,
#   30015: 36,
#   30139: 529,
#   30208: 18,
#   30227: 35,
#   30287: 23,
#   30299: 1,
#   30301: 117,
#   30316: 17,
#   30365: 47,
#   30490: 17,
#   30501: 10,
#   30505: 33,
#   30561: 6,
#   30575: 6,
#   30599: 24,
#   30631: 11,
#   30663: 24,
#   30696: 54,
#   30786: 11,
#   30798: 14,
#   30860: 28,
#   31003: 45,
#   31183: 129,
#   31216: 80,
#   31221: 17,
#   31262: 28,
#   31298: 13,
#   31332: 59,
#   31361: 20,
#   31442: 32,
#   31470: 17,
#   31516: 74,
#   31528: 60,
#   31544: 11,
#   31580: 34,
#   31585: 39,
#   31610: 17,
#   31660: 3,
#   31664: 45,
#   31692: 23,
#   31723: 17,
#   31813: 234,
#   31942: 102,
#   31986: 41,
#   32018: 145,
#   32061: 11,
#   32106: 18,
#   32135: 12,
#   32161: 25,
#   32181: 8,
#   32183: 27,
#   32193: 16,
#   32268: 6,
#   32286: 117,
#   32355: 6,
#   32367: 42,
#   32394: 6,
#   32414: 485,
#   32436: 271,
#   32583: 5,
#   32605: 19,
#   32639: 12,
#   32740: 48,
#   32746: 11,
#   32773: 112,
#   32790: 103,
#   40059: 11,
#   40124: 68,
#   40246: 20,
#   40370: 11,
#   40442: 107,
#   40456: 43,
#   40576: 48,
#   40631: 4,
#   40911: 35,
#   41192: 45,
#   41373: 28,
#   41434: 10,
#   41446: 8,
#   41890: 7,
#   41958: 5,
#   41962: 10,
#   41976: 177,
#   42009: 30,
#   42035: 49,
#   42054: 18,
#   42194: 1,
#   42346: 30,
#   42458: 9,
#   42515: 38,
#   42572: 17,
#   42715: 21,
#   42794: 6,
#   42924: 3,
#   43067: 90,
#   43074: 18,
#   43112: 394,
#   43128: 1,
#   43147: 150,
#   43305: 48,
#   43323: 15,
#   43937: 4,
#   43943: 6,
#   43959: 3,
#   44146: 16,
#   44206: 5,
#   44214: 30,
#   44326: 8,
#   44437: 12,
#   44530: 2,
#   44534: 37,
#   44741: 8,
#   44787: 7,
#   44829: 55,
#   44841: 19,
#   44848: 2,
#   45193: 11,
#   45280: 9,
#   45435: 7,
#   46011: 61,
#   46335: 49,
#   46366: 42,
#   46415: 53,
#   46521: 14,
#   46728: 34,
#   46926: 1,
#   46961: 1,
#   47216: 17,
#   47219: 67,
#   47407: 2,
#   47467: 6,
#   47670: 7,
#   47747: 12,
#   47852: 95,
#   47930: 5,
#   48058: 4,
#   48143: 6,
#   48297: 11,
#   48340: 7,
#   48660: 343,
#   48687: 15,
#   48750: 8,
#   48812: 36,
#   48837: 14,
#   48929: 7,
#   49292: 18,
#   49510: 31,
#   49558: 347,
#   49623: 9,
#   49747: 7,
#   49764: 10,
#   49963: 4,
#   50007: 4,
#   50041: 10,
#   50093: 6,
#   50257: 11,
#   50294: 20,
#   50409: 75,
#   50762: 8,
#   50772: 17,
#   50807: 21,
#   50828: 126,
#   50911: 81,
#   50998: 29,
#   51195: 29,
#   51237: 11,
#   51401: 33,
#   51418: 68,
#   51497: 3,
#   51545: 97,
#   51601: 5,
#   51607: 5,
#   51669: 10,
#   51933: 5,
#   52011: 8,
#   52054: 1,
#   52172: 13,
#   52191: 46,
#   52307: 5,
#   52452: 5,
#   52606: 54,
#   52622: 5,
#   52898: 6,
#   52957: 52,
#   53119: 7,
#   53160: 13,
#   53173: 14,
#   53534: 9,
#   53650: 15,
#   53743: 151,
#   53749: 6,
#   53847: 14,
#   54172: 6,
#   54197: 13,
#   54305: 8,
#   54514: 116,
#   54709: 9,
#   54741: 5,
#   54832: 7,
#   54922: 2,
#   55059: 17,
#   55074: 7,
#   55188: 9,
#   55571: 212,
#   55700: 4,
#   55753: 37,
#   55841: 14,
#   55920: 17,
#   56027: 7,
#   56229: 31,
#   56440: 9,
#   56490: 12,
#   56621: 11,
#   56635: 2,
#   56772: 31,
#   56798: 4,
#   56867: 16,
#   56874: 51,
#   57050: 205,
#   57081: 32,
#   57157: 5,
#   57277: 19,
#   57290: 15,
#   57449: 17,
#   57788: 36,
#   57795: 7,
#   57889: 105,
#   58105: 49,
#   58242: 6,
#   58264: 7,
#   58286: 20,
#   58416: 3,
#   58433: 51,
#   58522: 9,
#   58580: 5,
#   58610: 13,
#   58631: 15,
#   58732: 5,
#   58794: 32,
#   58810: 10,
#   58955: 6,
#   59275: 1,
#   59278: 17,
#   59411: 6,
#   59496: 75,
#   59765: 300,
#   59789: 10,
#   59801: 2,
#   59822: 14,
#   59903: 483,
#   59943: 121,
#   60003: 9,
#   60050: 4,
#   60130: 44,
#   60674: 10,
#   60685: 4,
#   60958: 8,
#   60977: 9,
#   61005: 10,
#   61084: 216,
#   61195: 9,
#   61259: 83,
#   61331: 4,
#   61630: 19,
#   61738: 6,
#   61886: 6,
#   62231: 4,
#   62239: 5,
#   62284: 6,
#   62402: 56,
#   62641: 8,
#   62733: 9,
#   62858: 120,
#   63145: 25,
#   63327: 16,
#   63351: 10,
#   63362: 7,
#   63430: 56,
#   63499: 32,
#   63560: 25,
#   63943: 31,
#   63968: 10,
#   64160: 4,
#   64232: 28,
#   64249: 7,
#   64715: 17,
#   65004: 11,
#   65027: 1,
#   65033: 2,
#   65164: 4,
#   65361: 20,
#   65435: 40,
#   65449: 6,
#   65515: 5,
#   65582: 576,
#   65594: 9,
#   65692: 25,
#   65710: 18,
#   65837: 47,
#   66002: 636,
#   66009: 373,
#   66206: 12,
#   66412: 5,
#   66492: 1,
#   66549: 36,
#   66556: 20,
#   66671: 32,
#   66739: 1,
#   66753: 8,
#   66823: 21,
#   67053: 238,
#   67111: 16,
#   67117: 19,
#   67408: 15,
#   67446: 8,
#   67796: 7,
#   67844: 7,
#   67887: 13,
#   68059: 3,
#   68315: 3,
#   68591: 7,
#   68791: 13,
#   68836: 7,
#   68839: 21,
#   68905: 3,
#   68944: 39,
#   68962: 1,
#   69098: 12,
#   69158: 13,
#   69250: 4,
#   69296: 13,
#   69359: 26,
#   69380: 265,
#   69483: 26,
#   69546: 64,
#   69556: 11,
#   69578: 7,
#   69673: 6,
#   69776: 53,
#   69799: 6,
#   69932: 6,
#   70285: 2,
#   70466: 18,
#   70476: 22,
#   70492: 10,
#   70563: 3,
#   70645: 29,
#   70682: 48,
#   70728: 12,
#   71107: 9,
#   71108: 220,
#   71220: 45,
#   71336: 5,
#   71377: 39,
#   71915: 6,
#   71943: 4,
#   71983: 3,
#   72229: 189,
#   72230: 154,
#   72233: 2,
#   72378: 7,
#   72532: 6,
#   72714: 4,
#   72751: 35,
#   73043: 3,
#   73107: 479,
#   73129: 105,
#   73388: 37,
#   73389: 87,
#   73479: 3,
#   73686: 4,
#   73713: 458,
#   73770: 9,
#   73808: 49,
#   73899: 2,
#   73941: 7,
#   74016: 8,
#   74253: 388,
#   74505: 32,
#   74562: 98,
#   74640: 7,
#   74654: 7,
#   75047: 3,
#   75107: 124,
#   75200: 87,
#   75387: 14,
#   75446: 34,
#   75609: 5,
#   75640: 45,
#   75741: 8,
#   75782: 90,
#   75806: 3,
#   75983: 9,
#   76021: 39,
#   76056: 1,
#   76074: 31,
#   76141: 4,
#   76178: 22,
#   76437: 5,
#   76446: 18,
#   76476: 3,
#   76797: 6,
#   76915: 8,
#   76993: 13,
#   77019: 8,
#   77128: 9,
#   77177: 14,
#   77237: 198,
#   77279: 2,
#   77434: 18,
#   77453: 2,
#   77469: 31,
#   77676: 4,
#   77690: 19,
#   77697: 10,
#   77816: 8,
#   77947: 11,
#   78017: 2,
#   78086: 110,
#   78565: 78,
#   78705: 3,
#   78707: 16,
#   78859: 5,
#   78914: 13,
#   79079: 18,
#   79090: 16,
#   79115: 12,
#   79292: 15,
#   80045: 6,
#   80106: 5,
#   80218: 13,
#   80430: 10,
#   80722: 3,
#   80813: 11,
#   80825: 3,
#   81114: 58,
#   81223: 39,
#   81233: 22,
#   81436: 9,
#   81745: 28,
#   81840: 25,
#   81960: 8,
#   81992: 11,
#   82100: 74,
#   82104: 2,
#   82150: 84,
#   82202: 28,
#   82211: 647,
#   82309: 9,
#   ...}}

# %%
print(len(patient_id_to_num_notes['pneumonia_dead']))
print(len(patient_id_to_num_notes['pneumonia_alive']))
# Out:
# 252
# 1167

# %%
pneumonia_dead_no_disch.loc[pneumonia_dead_no_disch["SUBJECT_ID_x"] == 111, ['ROW_ID_x','SUBJECT_ID_x','DESCRIPTION','TEXT', 'DEATHTIME']]
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 70391       70124           111
# 142529     151749           111
# 142097     151750           111
# 142303     151751           111
# 380576     375732           111
# 380109     375744           111
# 379907     375749           111
# 379806     375753           111
# 379909     375760           111
# 1066971   1079317           111
# 1065833   1079339           111
# 1067121   1079351           111
#
#                                                DESCRIPTION  \
# 70391                                               Report
# 142529                                              Report
# 142097                                              Report
# 142303                                              Report
# 380576                   Physician Resident Admission Note
# 380109                                      ICU Event Note
# 379907   Physician Resident/Attending Admission Note - ...
# 379806                          Social Work Admission Note
# 379909                                      ICU Event Note
# 1066971                                CHEST (PORTABLE AP)
# 1065833                                CHEST (PORTABLE AP)
# 1067121                         CHEST PORT. LINE PLACEMENT
#
#                                                       TEXT  \
# 70391    PATIENT/TEST INFORMATION:\nIndication: s/p PEA...
# 142529   Compared to the previous tracing QRS voltage i...
# 142097   Normal sinus rhythm, rate 80.  Biatrial abnorm...
# 142303   Normal sinus rhythm.  Q waves in leads V1-V2 c...
# 380576   Chief Complaint:  respiratory distress\n   HPI...
# 380109   Clinician:  Nurse\n   Pt admitted from the ED ...
# 379907   Chief Complaint:  respiratory distress\n   HPI...
# 379806   Social Work Initial Note:\n   Family Informati...
# 379909   TITLE:\n   Clinician:  Resident\n   Patient ex...
# 1066971  [**2144-7-1**] 2:43 AM\n CHEST (PORTABLE AP)  ...
# 1065833  [**2144-7-1**] 7:27 AM\n CHEST (PORTABLE AP); ...
# 1067121  [**2144-7-1**] 9:01 AM\n CHEST PORT. LINE PLAC...
#
#                    DEATHTIME
# 70391    2144-07-01 14:55:00
# 142529   2144-07-01 14:55:00
# 142097   2144-07-01 14:55:00
# 142303   2144-07-01 14:55:00
# 380576   2144-07-01 14:55:00
# 380109   2144-07-01 14:55:00
# 379907   2144-07-01 14:55:00
# 379806   2144-07-01 14:55:00
# 379909   2144-07-01 14:55:00
# 1066971  2144-07-01 14:55:00
# 1065833  2144-07-01 14:55:00
# 1067121  2144-07-01 14:55:00

# %%
def count_words_per_patient(disease_df, patient_id_to_num_notes):
    note_appearance_counter = {}
    number_of_patients = 0 # number of patients
    note_counter = 0

# -----------
    patient_id = -1
    word_set = set()
    note_event_counter = 0

    # Iterate through each note
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):

        
        patient_id_check = int(row['SUBJECT_ID_x'])
    
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check:
            number_of_patients += 1
            note_event_counter = 0
        
            for word in word_set:
                if word in note_appearance_counter:
                    note_appearance_counter[word] += 1
                else:
                    note_appearance_counter[word] = 1

        
            # reset word_set
            word_set = set()
        
        # update patient id
        patient_id = patient_id_check

            
        if patient_id_to_num_notes[patient_id_check] <= MIN_SEQ_LEN:
            continue
            
        if note_event_counter < patient_id_to_num_notes[patient_id] // USE_1_N_SEQ:
            note_event_counter += 1
            continue
                
        note_counter += 1
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        tokenized_note = word_tokenize(note)
        
        
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())
            if not stemmed_word in stop_words:
                word_set.add(stemmed_word)
    
    print(str(note_counter) + " note events")
    print("finished counting frequent words for patients!")
#     return note_counter, note_appearance_counter
    return number_of_patients, note_appearance_counter

# variable dictionaries
number_of_notes = {}
note_appearance_counter = {}

number_of_notes['pneumonia_dead'], note_appearance_counter['pneumonia_dead'] = count_words_per_patient(pneumonia_dead_no_disch, patient_id_to_num_notes['pneumonia_dead'])
number_of_notes['pneumonia_alive'], note_appearance_counter['pneumonia_alive'] = count_words_per_patient(pneumonia_alive_no_disch, patient_id_to_num_notes['pneumonia_alive'])
# Out:
# 100%|██████████| 11895/11895 [00:42<00:00, 278.20it/s]
#   0%|          | 13/46134 [00:00<05:55, 129.59it/s]
# 5989 note events
# finished counting frequent words for patients!
# 100%|██████████| 46134/46134 [02:44<00:00, 280.56it/s]
# 23172 note events
# finished counting frequent words for patients!

# %%
number_of_notes
# Out:
# {'pneumonia_dead': 252, 'pneumonia_alive': 1167}

# %%
print(note_appearance_counter)
# Out:
# {'pneumonia_dead': {'nc': 62, 'ast': 48, 'growth': 28, 'lower': 166, 'death': 42, 'cmh': 51, 'ptt': 80, 'head': 114, 'meq': 92, 'recent': 129, 'last': 148, 'versu': 30, 'servic': 92, 'septic': 41, 'pleural': 176, 'serial': 23, 'x': 185, 'htn': 50, 'requir': 145, 'dextros': 11, 'lactat': 47, 'demonstr': 88, 'prepar': 21, 'dx': 29, 'appoint': 7, 'pm': 197, 'marri': 4, 'elder': 1, 'occup': 18, 'cardiac': 156, 'epinephrin': 9, 'pedal': 41, 'set': 141, 'hi': 121, 'arf': 34, 'ha': 212, 'st': 140, 'elig': 3, 'includ': 113, 'underli': 79, 'hyperinfl': 5, 'alcohol': 15, 'paralyt': 16, 'hemodynam': 111, 'edema': 182, 'nutrit': 85, 'central': 107, 'park': 4, 'consult': 99, 'retrocardiac': 50, 'code': 135, 'hematoma': 20, 'took': 27, 'hpi': 58, 'densiti': 45, '#': 211, 'rebound': 8, 'continu': 176, 'inr': 88, 'lead': 83, 'salmeterol': 1, 'commun': 88, 'member': 57, 'hypercapnia': 4, 'home': 99, 'sinu': 139, 'vap': 72, 'differenti': 70, 'heart': 157, 'renal': 107, 'dr': 150, 'arteri': 119, 'clergi': 16, 'went': 50, 'tcurrent': 61, 'exam': 110, 'hospit': 75, 'experienc': 17, 'examin': 202, 'atrial': 90, 'drop': 120, 'kg': 111, 'offer': 47, 'band': 44, 'visual': 109, 'sbp': 114, 'hco': 15, 'anion': 8, 'ulcer': 81, 'verapamil': 2, 'lung': 203, '[': 80, 'prophylaxi': 70, 'block': 44, 'day': 160, 'express': 42, 'apic': 43, 'critic': 66, 'well': 180, 'funer': 16, 'ml': 99, 'urin': 165, 'rub': 32, 'spontan': 91, 'cm': 141, 'pmh': 78, 'abov': 158, 'nodular': 15, 'transfus': 52, 'interv': 156, 'jpg': 63, 'stay': 55, 'time': 188, 'form': 38, 'statin': 17, 'note': 199, 'degre': 47, 'total': 119, 'employ': 7, 'acid': 56, 'adjust': 59, 'chang': 222, 'l': 171, 'deliveri': 63, 'infecti': 53, 'hilar': 36, 'emphysema': 28, '%': 188, 'promin': 65, 'ischem': 31, 'depress': 51, 'simvastatin': 4, 'work': 87, 'think': 20, 'major': 40, 'ratio': 7, 'known': 85, 'effus': 183, 'superimpos': 56, 'mix': 30, 'albuterol': 58, 'around': 76, 'artic': 2, 'come': 72, 'preren': 12, 'pip': 58, 'drip': 79, 'differ': 81, 'pna': 151, 'receiv': 151, 'insp': 84, 'point': 75, 'evalu': 173, 'deni': 66, 'view': 119, 'ca': 105, 'resp': 163, 'arch': 15, 'absent': 62, 'immedi': 45, 'hypertens': 82, 'product': 99, 'shock': 66, 'min': 142, 'tazo': 9, 'ap': 175, 'copi': 13, 'signific': 121, 'social': 138, 'fall': 42, 'physician': 107, 'arrang': 21, 'chest': 206, 'drug': 55, 'legal': 10, 'hous': 20, 'resourc': 3, 'pao': 66, 'respiratiori': 1, 'need': 155, 'chemistri': 16, 'defer': 39, 'sw': 33, 'distend': 108, 'balanc': 85, 'admit': 194, 'licsw': 11, 'pneumoboot': 25, 'guard': 18, 'left': 216, 'phenylephrin': 16, 'issu': 84, 'minut': 91, 'fluid': 183, 'list': 25, 'electrolyt': 43, 'aspir': 108, 'next': 81, 'one': 117, 'veteran': 1, 'function': 95, 'cpr': 32, 'ext': 68, 'elderli': 5, 'intervent': 65, 'contact': 91, 'evid': 141, 'hold': 90, 'could': 111, 'place': 196, 'appropri': 101, 'bili': 47, 'bicarb': 28, 'emphas': 19, 'dilat': 85, 'mid': 138, 'person': 33, 'portion': 101, 'nurs': 141, 'right': 211, 'agre': 84, 'decid': 61, 'glycem': 62, 'disconnect': 2, 'fen': 44, 'aggress': 62, 'manual': 14, 'onli': 153, 'manag': 90, 'access': 113, 'famili': 167, 'repres': 91, ']': 80, 'intact': 103, 'rapid': 61, 'sick': 18, 'notabl': 38, 'unrespons': 78, 'wbc': 131, 'fluticason': 2, 'mmol': 49, 'brother': 29, 'attend': 94, 'addendum': 98, 'pneumothorax': 118, 'cvl': 42, 'ptx': 24, 'sclera': 23, 'placement': 143, 'unsuccess': 37, 'plt': 82, 'resid': 111, 'dic': 20, 'detail': 69, 'admiss': 88, 'spokesperson': 10, 'encourag': 43, 'propofol': 31, 'seen': 157, 'echo': 58, 'record': 46, 'laundri': 1, 'may': 142, 'atenolol': 4, 'undetect': 3, 'tender': 82, 'distant': 27, 'aroudn': 1, 'afternoon': 103, 'despit': 90, 'tf': 110, 'line': 183, 'recommend': 82, 'n': 70, 'regular': 66, 'e': 64, 'bedsid': 127, 'aris': 6, 'pneumonia': 203, 'repeat': 107, 'hr': 189, 'girlfriend': 2, 'amylas': 17, 'coars': 117, 'pt': 179, 'level': 148, 'assist': 81, 'fio': 119, 'speak': 65, 'ph': 61, 'enzym': 32, 'full': 124, 'attempt ...

# %%
# # get hyper-paramters n_fold and threshold from user input
n_fold = float(3)
threshold = float(0.01)

frequent_word_lists = {}
factor = {}

# %%
"""function description:
for each disease in note_appearance_counter
    1. checks whether a word in disease file is frequent(frequency standard as defined by factor, n_fold, and threshold)
    2. adds to frequent_word_list
"""

# def find_frequent_word(note_appearance_counter, frequent_word_lists, number_of_notes, factor, n_fold, threshold):

# calculate normalizing factor for each disease
note_sum = 0

# Count from two labels
for disease in number_of_notes:
    note_sum += float(number_of_notes[disease])
    
for disease in number_of_notes:
    factor[disease] = number_of_notes[disease] / note_sum

# determine frequent word for each disease file
for disease in note_appearance_counter:
    frequent_word_lists[disease] = []

    print(disease + " has " + str(len(note_appearance_counter[disease])) + " unique words!")

    for word in note_appearance_counter[disease]:
        
        freq_check = True
        for check_disease in note_appearance_counter:
            
            if not disease == check_disease:
                if word in note_appearance_counter[check_disease]:
                    if not (note_appearance_counter[disease][word] / note_appearance_counter[check_disease][word] / factor[disease] * factor[check_disease] > n_fold \
                        and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):

                        freq_check = False
                        break

                else:
                    if not (note_appearance_counter[disease][word] > n_fold and note_appearance_counter[disease][word] > (number_of_notes[disease] * threshold)):
                        freq_check = False
                        break
        if freq_check:
            frequent_word_lists[disease].append((word))
            # Create a tuple of word and its count
#             frequent_word_lists[disease].append((word, note_appearance_counter[disease][word]))

        

print("finished making frequent words list for " + disease)
# Out:
# pneumonia_dead has 11678 unique words!
# pneumonia_alive has 22572 unique words!
# finished making frequent words list for pneumonia_alive

# %%
print(note_sum)
print(factor)

# number of notes
# 58029.0
# {'pneumonia_dead': 0.2049837150390322, 'pneumonia_alive': 0.7950162849609678}
# Out:
# 1419.0
# {'pneumonia_dead': 0.17758985200845667, 'pneumonia_alive': 0.8224101479915433}

# %%
print(len(frequent_word_lists['pneumonia_dead']))
print(len(frequent_word_lists['pneumonia_alive']))


# n_fold = float(3) threshold = float(0.01)
# 454
# 329

# n_fold = float(2) threshold = float(0.01)
# 914
# 600

# n_fold = float(1) threshold = float(0.01)
# 3320
# 2196
# Out:
# 454
# 329

# %%
print(frequent_word_lists)
# Out:
# {'pneumonia_dead': ['death', 'elig', 'paralyt', 'park', 'hypercapnia', 'clergi', 'funer', 'arrang', 'phenylephrin', 'cpr', 'unrespons', 'dic', 'recruit', 'pcv', 'refractori', 'bicarbon', 'anur', 'expir', 'clinician', 'hypothermia', 'norepinephrin', 'vasopressin', 'mottl', 'cremat', 'acidem', 'arrest', 'azotemia', 'suffer', 'profound', 'pea', 'hypercapn', 'autopeep', 'dnr', 'sluggish', 'pinpoint', 'lubric', 'nonpurpos', 'virtual', 'slough', 'gum', 'dk', 'dni', 'cmo', 'nacl', 'oder', 'float', 'wish', 'mso', 'levoph', 'clariti', 'respon', 'remin', 'dd', 'dead', 'grim', 'purpl', 'option', 'prognosi', 'bow', 'suport', 'pronounc', 'peerla', 'hypotent', 'antb', 'institut', 'priest', 'gather', 'viabl', 'agreement', 'acv', 'mortem', 'aprv', 'mad', 'centimet', 'synch', 'depth', 'asystol', 'life', 'bye', 'duski', 'chaplain', 'hover', 'cathol', 'througout', 'moniotr', 'sync', 'mgx', 'ppn', 'nrbm', 'peac', 'surviv', 'cvvh', 'acidot', 'corneal', 'jerk', 'crrt', 'mortum', 'quiac', 'pfr', 'cvvhdf', 'agon', 'neosynephrin', 'deterior', 'suppport', 'deliv', 'vtach', 'rusti', 'vasopressor', 'defibril', 'seriou', 'pulseless', 'cvvhd', 'hemothorax', 'ultrafiltr', 'hugger', 'multisystem', 'towel', 'ethic', 'among', 'hypotherm', 'cooler', 'maroon', 'levof', 'lc', 'lw', 'declin', 'mtg', 'spiritu', 'gratitud', 'pitressin', 'quinton', 'ffp', 'uffp', 'unequ', 'pray', 'scl', 'rewir', 'bair', 'elimin', 'cagluc', 'cyanot', 'brb', 'discoordin', 'absorb', 'syring', 'neo', 'norepi', 'erythro', 'autopsi', 'promod', 'morgu', 'bairhugg', 'polymorph', 'discard', 'triadyn', 'warmer', 'chane', 'asynchron', 'town', 'ran', "tf'ing", 'ashen', 'prayer', 'sml', 'escal', 'nahco', 'motil', 'rabbi', 'circuit', 'bond', 'paco', 'bank', 'zero', 'mind', 'unstabl', 'edt', '^rr', 'rediscuss', 'gc', 'hunger', 'hung', 'polici', 'dopamin', 'intiat', 'moan', 'palli', 'tacycard', 'cantones', 'fliud', 'artifici', 'ozz', 'readdress', 'acc', 'overlay', 'underneath', 'broader', 'proph', 'inclus', 'judgement', 'recalibr', 'anuria', 'gurgl', 'dobutamin', 'platelet', 'adenosin', 'oncologist', 'hospic', 'platlet', 'quadrent', 'kerlix', 'sorb', 'gut', 'griev', 'oligur', 'cardiovert', 'influenc', 'gvhd', 'anyway', 'core', 'psup', 'nephrolog', 'hepati', 'pheresi', 'cellcept', 'surgicel', 'fentenyl', 'ettub', 'hiccup', 'twitch', 'premed', 'fc', 'oximetri', 'fungemia', 'chemic', 'extremitiy', 'grimmac', 'caspofungin', 'snt', 'wether', 'cisatracurium', 'repsons', 'barotrauma', 'pose', 'crt', 'rescan', 'liw', 'plat', 'sacrament', 'nephrogram', 'postpylor', 'lcw', 'fentani', 'conc', 'chb', 'nonreact', 'grave', 'mail', 'heroic', 'nonrebreath', 'awhil', 'pleuravac', 'occupi', 'ultra', 'familt', 'struggl', 'reappear', 'propos', 'palliat', 'opinion', 'reveiw', 'icter', 'gentamycin', 'criticar', 'resucit', 'ardsnet', 'ogtub', 'reguard', 'cvo', 'abruptli', 'themselv', 'pplat', 'meaning', 'fibrinogen', 'wma', 'amongst', 'sooner', 'preoxygen', 'tubular', 'pneumonectomi', 'kyphoscoliosi', 'sibl', 'vasoconstrict', 'gasp', 'recev', 'hook', 'tran', 'hida', 'colour', 'realist', 'moreov', 'innumer', 'aricept', 'argatroban', 'pvr', 'unreli', 'vigil', 'irrevers', 'creep', 'buck', 'aliv', 'pharmacolog', 'derecruit', 'wil', 'epsiod', 'attemtp', 'religi', 'ration', 'eyelid', 'respitori', 'famil', 'analgesia', 'myeloma', 'imbal', 'adam', 'dorsal', 'muddi', 'declar', 'neob', 'od', 'moisten', 'heliox', 'diflucan', 'requr', 'osteoblast', 'illeu', 'futil', 'emper', 'currentl', 'perisplen', 'nimv', 'fli', 'preliminarili', 'plerual', 'rhochor', 'forth', 'esoph', 'dysynchron', 'prioriti', 'sluggishli', 'binder', 'unplan', 'occurr', 'ipf', 'goodby', 'ccn', 'meatu', 'stg', 'unarous', 'scopalamin', 'tobra', 'harm', 'bless', 'hemodynim', 'petechia', 'rite', 'fentayl', 'doen', 'calvarium', 'furhter', 'stack', 'chol', 'montitor', 'fmaili', 'underpenetr', 'figur', 'pyuria', 'thrombot', 'ggt', 'massag', 'outer', 'mrcp', 'contini', 'synchroni', 'formul', 'treatement', 'news', 'amioderon', 'unobtain', 'led', 'mvo', 'pastor', 'anasarc',  ...

# %% [markdown]
# ### 2. Co-occurrence generation
# FP-growth

# %%
FREQUENT_WORD_LIST = frequent_word_lists['pneumonia_dead'] + frequent_word_lists['pneumonia_alive']
print(len(FREQUENT_WORD_LIST))
print(len(set(FREQUENT_WORD_LIST)))
# Out:
# 783
# 783

# %%
"""function description:
generates frequent word set for the disease
"""
word_dict = {}
word_id = 1
stemmer = PorterStemmer()


for word in FREQUENT_WORD_LIST:
    if not word == "WORD":
        word_dict[stemmer.stem(word.strip())] = word_id
        word_id += 1
             
print(f"\nword dictionary created! Length: {len(word_dict)}\n")
print(word_dict)
# Out:
# word dictionary created! Length: 783
#
# {'death': 1, 'elig': 2, 'paralyt': 3, 'park': 4, 'hypercapnia': 5, 'clergi': 6, 'funer': 7, 'arrang': 8, 'phenylephrin': 9, 'cpr': 10, 'unrespon': 11, 'dic': 12, 'recruit': 13, 'pcv': 14, 'refractori': 15, 'bicarbon': 16, 'anur': 17, 'expir': 18, 'clinician': 19, 'hypothermia': 20, 'norepinephrin': 21, 'vasopressin': 22, 'mottl': 23, 'cremat': 24, 'acidem': 25, 'arrest': 26, 'azotemia': 27, 'suffer': 28, 'profound': 29, 'pea': 30, 'hypercapn': 31, 'autopeep': 32, 'dnr': 33, 'sluggish': 34, 'pinpoint': 35, 'lubric': 36, 'nonpurpo': 37, 'virtual': 38, 'slough': 39, 'gum': 40, 'dk': 41, 'dni': 42, 'cmo': 43, 'nacl': 44, 'oder': 45, 'float': 46, 'wish': 47, 'mso': 48, 'levoph': 49, 'clariti': 50, 'respon': 51, 'remin': 52, 'dd': 53, 'dead': 54, 'grim': 55, 'purpl': 56, 'option': 57, 'prognosi': 58, 'bow': 59, 'suport': 60, 'pronounc': 61, 'peerla': 62, 'hypot': 63, 'antb': 64, 'institut': 65, 'priest': 66, 'gather': 67, 'viabl': 68, 'agreement': 69, 'acv': 70, 'mortem': 71, 'aprv': 72, 'mad': 73, 'centimet': 74, 'synch': 75, 'depth': 76, 'asystol': 77, 'life': 78, 'bye': 79, 'duski': 80, 'chaplain': 81, 'hover': 82, 'cathol': 83, 'througout': 84, 'moniotr': 85, 'sync': 86, 'mgx': 87, 'ppn': 88, 'nrbm': 89, 'peac': 90, 'surviv': 91, 'cvvh': 92, 'acidot': 93, 'corneal': 94, 'jerk': 95, 'crrt': 96, 'mortum': 97, 'quiac': 98, 'pfr': 99, 'cvvhdf': 100, 'agon': 101, 'neosynephrin': 102, 'deterior': 103, 'suppport': 104, 'deliv': 105, 'vtach': 106, 'rusti': 107, 'vasopressor': 108, 'defibril': 109, 'seriou': 110, 'pulseless': 111, 'cvvhd': 112, 'hemothorax': 113, 'ultrafiltr': 114, 'hugger': 115, 'multisystem': 116, 'towel': 117, 'ethic': 118, 'among': 119, 'hypotherm': 120, 'cooler': 121, 'maroon': 122, 'levof': 123, 'lc': 124, 'lw': 125, 'declin': 126, 'mtg': 127, 'spiritu': 128, 'gratitud': 129, 'pitressin': 130, 'quinton': 131, 'ffp': 132, 'uffp': 133, 'unequ': 134, 'pray': 135, 'scl': 136, 'rewir': 137, 'bair': 138, 'elimin': 139, 'cagluc': 140, 'cyanot': 141, 'brb': 142, 'discoordin': 143, 'absorb': 144, 'syre': 145, 'neo': 146, 'norepi': 147, 'erythro': 148, 'autopsi': 149, 'promod': 150, 'morgu': 151, 'bairhugg': 152, 'polymorph': 153, 'discard': 154, 'triadyn': 155, 'warmer': 156, 'chane': 157, 'asynchron': 158, 'town': 159, 'ran': 160, "tf'ing": 161, 'ashen': 162, 'prayer': 163, 'sml': 164, 'escal': 165, 'nahco': 166, 'motil': 167, 'rabbi': 168, 'circuit': 169, 'bond': 170, 'paco': 171, 'bank': 172, 'zero': 173, 'mind': 174, 'unstabl': 175, 'edt': 176, '^rr': 177, 'rediscuss': 178, 'gc': 179, 'hunger': 180, 'hung': 181, 'polici': 182, 'dopamin': 183, 'intiat': 184, 'moan': 185, 'palli': 186, 'tacycard': 187, 'canton': 188, 'fliud': 189, 'artifici': 190, 'ozz': 191, 'readdress': 192, 'acc': 193, 'overlay': 194, 'underneath': 195, 'broader': 196, 'proph': 197, 'inclu': 198, 'judgement': 199, 'recalibr': 200, 'anuria': 201, 'gurgl': 202, 'dobutamin': 203, 'platelet': 204, 'adenosin': 205, 'oncologist': 206, 'hospic': 207, 'platlet': 208, 'quadrent': 209, 'kerlix': 210, 'sorb': 211, 'gut': 212, 'griev': 213, 'oligur': 214, 'cardiovert': 215, 'influenc': 216, 'gvhd': 217, 'anyway': 218, 'core': 219, 'psup': 220, 'nephrolog': 221, 'hepati': 222, 'pheresi': 223, 'cellcept': 224, 'surgicel': 225, 'fentenyl': 226, 'ettub': 227, 'hiccup': 228, 'twitch': 229, 'preme': 230, 'fc': 231, 'oximetri': 232, 'fungemia': 233, 'chemic': 234, 'extremitiy': 235, 'grimmac': 236, 'caspofungin': 237, 'snt': 238, 'wether': 239, 'cisatracurium': 240, 'repson': 241, 'barotrauma': 242, 'pose': 243, 'crt': 244, 'rescan': 245, 'liw': 246, 'plat': 247, 'sacrament': 248, 'nephrogram': 249, 'postpylor': 250, 'lcw': 251, 'fentani': 252, 'conc': 253, 'chb': 254, 'nonreact': 255, 'grave': 256, 'mail': 257, 'heroic': 258, 'nonrebreath': 259, 'awhil': 260, 'pleuravac': 261, 'occupi': 262, 'ultra': 263, 'familt': 264, 'struggl': 265, 'reappear': 266, 'propo': 267, 'palliat': 268, 'opinion': 269, 'reveiw': 270, 'icter': 271, 'gentamycin': 272, 'criticar': 273, 'resucit ...

# %% [markdown]
# ### Implementetion with python for FP_growth

# %% [markdown]
# ### Count co-occurrences per patient

# %%
import os
import operator
from pathlib import Path
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import math

# ----
def fp_growth_input_per_patient_python(disease_df, word_dict, min_support):
    
    # For dataframe
    patient_cooc_dict = {}
    patient_node_dict = {}
    patient_note_cnt = {}
    
    # --------------    
    patient_id = -1
    note_cnt = 0
    patient_note_list = []
    
    # read line in from file (each line is one note)
    for index, row in tqdm(disease_df.iterrows(), total=disease_df.shape[0]):
        
        # only regard certain type of notes
        patient_id_check = int(row['SUBJECT_ID_x'])
        note = re.sub(r'\[\*\*(.*?)\*\*\]|[_,\d\*:~=\.\-\+\\/]+', ' ', row['TEXT'])
        patient_word_set = set()
    
#         print(f"patient_id_check: {patient_id_check}, patient_id: {patient_id}")
        # if patient id has changed, end sequence and start new sequence
        if not patient_id == patient_id_check and not patient_id == -1:
            te = TransactionEncoder()
            te_ary = te.fit(patient_note_list).transform(patient_note_list)
            df = pd.DataFrame(te_ary, columns=te.columns_)
            df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
            cooc_tmp = []
            cooc_minsup_tmp = []
            node_minsup_tmp = []
            cooc_node_idx_tmp = []
            
            for index, row in df_itemsets.iterrows():
                if len(row['itemsets']) == 1:
                    word = list(row['itemsets'])[0]
                    min_sup = row['support']

                    node_minsup_tmp.append(len(patient_note_list) * row['support'])
                    cooc_node_idx_tmp.append(word)
                    
                if len(row['itemsets']) == 2:
                    cooc_ = sorted(list(row['itemsets']))
                    cooc_tmp.append(cooc_)
                    cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
            
            cooc_dict = {}

            for num, i in enumerate(cooc_tmp):
                if tuple(i) not in cooc_dict:
                    cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

            # dictionary = dict(zip(keys, values))
            node_dict = {}
            for num, i in enumerate(cooc_node_idx_tmp):
                if i not in node_dict:
                    node_dict[i] = node_minsup_tmp[num]
                    
            # Update glob lists
            if patient_id not in patient_cooc_dict:
                patient_cooc_dict[patient_id] = cooc_dict
                patient_node_dict[patient_id] = node_dict
                patient_note_cnt[patient_id] = note_cnt
            else:
                print(f"patient_id: {patient_id} is already in the dictionary!")
            
            
            # Reset local lists
            patient_note_list = []
            note_cnt = 0
                    
        # update patient id
        patient_id = patient_id_check
        tokenized_note = word_tokenize(note)
        note_cnt += 1

        # loop through each word in note to count word belonging to each disease
        for word in tokenized_note:
            stemmed_word = stemmer.stem(word.lower())       
            if stemmed_word in word_dict:
                    patient_word_set.add(stemmed_word)

        templst = []
        for word in patient_word_set:
            templst.append(word)

        if templst:
            patient_note_list.append(templst)
    
    # Last patient info
    te = TransactionEncoder()
    te_ary = te.fit(patient_note_list).transform(patient_note_list)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    df_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
            
    cooc_tmp = []
    cooc_minsup_tmp = []
    #-----
    node_minsup_tmp = []
    cooc_node_idx_tmp = []
            
    for index, row in df_itemsets.iterrows():
        if len(row['itemsets']) == 1:
            word = list(row['itemsets'])[0]
            node_minsup_tmp.append(len(patient_note_list) * row['support'])
            cooc_node_idx_tmp.append(word)

        if len(row['itemsets']) == 2:
            cooc_ = sorted(list(row['itemsets']))
            cooc_tmp.append(cooc_)
            cooc_minsup_tmp.append(len(patient_note_list) * row['support'])
    
                    
    cooc_dict = {}

    for num, i in enumerate(cooc_tmp):
        if tuple(i) not in cooc_dict:
            cooc_dict[tuple(i)] = cooc_minsup_tmp[num]

    # dictionary = dict(zip(keys, values))
    node_dict = {}
    for num, i in enumerate(cooc_node_idx_tmp):
        if i not in node_dict:
            node_dict[i] = node_minsup_tmp[num]

    # Update glob lists
    if patient_id not in patient_cooc_dict:
        patient_cooc_dict[patient_id] = cooc_dict
        patient_node_dict[patient_id] = node_dict
        patient_note_cnt[patient_id] = note_cnt
    else:
        print(f"patient_id: {patient_id} is already in the dictionary!")

    return patient_node_dict, patient_cooc_dict, patient_note_cnt

patient_node_0, patient_cooc_0, patient_note_num_0 = fp_growth_input_per_patient_python(pneumonia_dead_no_disch, word_dict, 0.15)
patient_node_1, patient_cooc_1, patient_note_num_1 = fp_growth_input_per_patient_python(pneumonia_alive_no_disch, word_dict, 0.15)
# Out:
# 100%|██████████| 11895/11895 [01:43<00:00, 115.33it/s]
# 100%|██████████| 46134/46134 [06:39<00:00, 115.36it/s]

# %%
print(patient_node_1)
# Out:
# {68: {'commod': 4.0, 'ambul': 4.0, 'gait': 2.0, 'chair': 2.0, 'oob': 2.0}, 85: {'lat': 1.0}, 94: {'lift': 11.0, 'dopamin': 11.0}, 165: {'habitu': 1.0}, 211: {'dopamin': 3.0, 'aox': 3.0, 'levoph': 3.0}, 224: {'lat': 1.0, 'rigor': 1.0, 'platelet': 1.0, 'commod': 1.0, 'awhil': 1.0, 'fax': 1.0, 'bank': 1.0, 'pleasant': 1.0, 'chair': 1.0}, 231: {}, 283: {'recruit': 10.0, 'criticar': 10.0}, 357: {'unasyn': 4.0, 'intent': 2.0, 'dz': 2.0, 'ctx': 2.0, 'moan': 4.0, 'distort': 2.0}, 368: {'pleasant': 3.0, 'dnr': 3.0, 'hhn': 3.0, 'oob': 6.0, 'ambul': 4.0}, 370: {'dnr': 2.0}, 384: {'bipolar': 9.0, 'wish': 4.0, 'dnr': 3.0, 'schizophrenia': 4.0}, 426: {'align': 1.0, 'mottl': 1.0, 'lat': 1.0, 'unenhanc': 1.0, 'mail': 1.0, 'bronchovascular': 1.0, 'pleasant': 1.0, 'arthrit': 1.0}, 509: {'oob': 3.0}, 514: {'lat': 1.0, 'schizophrenia': 1.0, 'nicotin': 1.0, 'lighthead': 1.0, 'burn': 1.0, 'pleasant': 2.0, 'commod': 2.0, 'ambul': 1.0, 'oob': 1.0}, 596: {'dnr': 4.0, 'dopamin': 3.0, 'dni': 4.0, 'chair': 2.0}, 674: {'profound': 1.0, 'nimv': 1.0, 'xl': 2.0, 'rememb': 1.0, 'neo': 1.0, 'mso': 1.0, 'lotion': 1.0, 'tranfer': 1.0, 'fu': 1.0, 'cardiovert': 1.0}, 707: {'pleasantli': 4.0, 'lpm': 2.0, 'oob': 3.0, 'pleasant': 2.0}, 711: {'dnr': 190.99999999999997, 'mellitu': 78.0, 'fibrinogen': 186.0, 'captopril': 77.0, 'olanzapin': 109.0, 'palli': 60.0, 'fungemia': 95.0, 'caspofungin': 105.0}, 770: {'iddm': 24.0, 'vp': 20.0}, 773: {'pneumococc': 7.0, 'mso': 8.0, 'levoph': 8.0}, 899: {'lat': 2.0, 'chip': 2.0, 'pleasant': 3.0}, 1096: {'syst': 1.0, 'ppd': 1.0, 'lc': 1.0, 'forc': 1.0, 'tubular': 1.0}, 1135: {'scab': 3.0, 'oob': 6.0, 'chair': 7.0, 'argatroban': 4.0, 'pleasant': 3.0, 'lat': 3.0, 'xl': 3.0}, 1163: {'osa': 1.0, 'pleasant': 1.0, 'twitch': 1.0, 'captopril': 1.0}, 1174: {}, 1180: {'influenc': 1.0}, 1283: {'unavail': 1.0, 'seat': 1.0, 'habitu': 1.0}, 1332: {'levoph': 4.0, 'dnr': 6.0, 'dni': 5.0, 'oob': 4.0}, 1339: {'oob': 20.0, 'stair': 18.0, 'ctx': 18.0, 'ambul': 18.0, 'seroquel': 23.0, 'video': 22.0, 'barium': 18.0, 'phenylephrin': 25.0, 'neo': 27.0}, 1546: {'asthma': 4.0, 'spacer': 2.0, 'oob': 2.0, 'db': 2.0}, 1568: {'pericard': 5.0, 'pleasant': 4.0, 'oob': 2.0}, 1601: {'levoph': 3.0, 'pleasant': 2.0, 'ambien': 2.0}, 1606: {'precordium': 1.0, 'unalt': 1.0, 'dnr': 1.0, 'dni': 1.0, 'lat': 1.0, 'dome': 1.0}, 1642: {'pleasant': 2.0, 'dnr': 2.0, 'dni': 2.0, 'quadrent': 1.0, 'declin': 1.0}, 1660: {'behavior': 2.0, 'pleasant': 2.0}, 1895: {'pleasant': 2.0}, 1923: {'moan': 3.0, 'dnr': 3.0, 'sarna': 2.0, 'lotion': 2.0}, 2029: {'xanax': 28.0, 'dnr': 20.0}, 2090: {'chair': 18.0, 'splint': 13.0, 'dyslipidemia': 23.000000000000004, 'ctx': 17.0, 'bromid': 17.0, 'ntnd': 14.000000000000002}, 2098: {'hugger': 4.0, 'bair': 4.0, 'cpr': 2.0}, 2128: {'dopamin': 10.0, 'mso': 6.0, 'unasyn': 4.0, 'flight': 3.0}, 2170: {'qtc': 1.0, 'nonrebreath': 1.0, 'spur': 2.0, 'lat': 1.0}, 2187: {'osa': 2.0, 'morbid': 2.0, 'captopril': 2.0}, 2208: {'vp': 35.0, 'bipolar': 16.0, 'clonidin': 19.0, 'levoph': 16.0}, 2337: {'smooth': 1.0, 'hemangioma': 1.0, 'slough': 1.0, 'pleasant': 1.0, 'dnr': 2.0, 'pleasantli': 1.0}, 2378: {'ultram': 16.0, 'silent': 16.0, 'video': 15.0, 'sensat': 13.0}, 2386: {'dnr': 7.0, 'hospic': 3.0, 'town': 2.0, 'dni': 3.0}, 2452: {'lat': 4.0}, 2508: {'levoph': 2.0, 'dopamin': 2.0, 'ppd': 2.0, 'ciwa': 2.0, 'lpm': 2.0, 'chair': 2.0}, 2561: {}, 2585: {'hilum': 2.0, 'para': 1.0, 'ultram': 1.0, 'sluggish': 1.0, 'prognosi': 1.0, 'hook': 1.0, 'grave': 1.0, 'dnr': 1.0, 'dni': 1.0}, 2589: {'bipolar': 28.000000000000004, 'pneumococc': 22.0, 'zyprexa': 7.000000000000001, 'dz': 9.0, 'mood': 7.000000000000001, 'historian': 10.0}, 2590: {'dnr': 2.0, 'dni': 2.0, 'nonrebreath': 1.0, 'venti': 2.0, 'lpm': 1.0, 'pleasant': 1.0}, 2628: {}, 2658: {'moan': 3.0}, 2732: {'vertebra': 2.0, 'lat': 2.0}, 2784: {'arrest': 2.0, 'commod': 3.0, 'video': 2.0, 'diaper': 2.0, 'gait': 2.0}, 2823: {'dnr': 4.0, 'venti': 3.0, 'dni': 3.0}, 3070: {'svn': 2.0, 'osa': 1.0, 'ofm': 1.0, 'pleasant': 1.0, 'video': 1.0, ...

# %%
print(patient_cooc_1)
# Out:
# {68: {('ambul', 'commod'): 3.0, ('ambul', 'oob'): 2.0, ('commod', 'oob'): 2.0}, 85: {}, 94: {}, 165: {}, 211: {}, 224: {('platelet', 'rigor'): 1.0, ('commod', 'platelet'): 1.0, ('commod', 'rigor'): 1.0, ('bank', 'fax'): 1.0, ('chair', 'pleasant'): 1.0}, 231: {}, 283: {}, 357: {('intent', 'unasyn'): 2.0, ('dz', 'intent'): 2.0, ('dz', 'unasyn'): 2.0, ('ctx', 'unasyn'): 2.0}, 368: {}, 370: {}, 384: {('bipolar', 'wish'): 4.0}, 426: {('lat', 'mottl'): 1.0, ('mail', 'unenhanc'): 1.0, ('bronchovascular', 'mail'): 1.0, ('bronchovascular', 'unenhanc'): 1.0, ('arthrit', 'pleasant'): 1.0}, 509: {}, 514: {('nicotin', 'schizophrenia'): 1.0, ('lighthead', 'nicotin'): 1.0, ('lighthead', 'schizophrenia'): 1.0, ('burn', 'lighthead'): 1.0, ('burn', 'nicotin'): 1.0, ('burn', 'schizophrenia'): 1.0, ('commod', 'pleasant'): 2.0, ('ambul', 'commod'): 1.0, ('ambul', 'pleasant'): 1.0, ('commod', 'oob'): 1.0, ('oob', 'pleasant'): 1.0}, 596: {('dni', 'dnr'): 2.0}, 674: {('nimv', 'profound'): 1.0, ('rememb', 'xl'): 1.0, ('neo', 'rememb'): 1.0, ('neo', 'xl'): 1.0, ('mso', 'neo'): 1.0, ('mso', 'rememb'): 1.0, ('mso', 'xl'): 1.0, ('lotion', 'mso'): 1.0, ('lotion', 'neo'): 1.0, ('lotion', 'rememb'): 1.0, ('lotion', 'xl'): 1.0, ('tranfer', 'xl'): 1.0, ('fu', 'tranfer'): 1.0, ('fu', 'xl'): 1.0, ('cardiovert', 'fu'): 1.0, ('cardiovert', 'tranfer'): 1.0, ('cardiovert', 'xl'): 1.0}, 707: {('oob', 'pleasantli'): 2.0}, 711: {('fibrinogen', 'mellitu'): 59.0, ('dnr', 'fibrinogen'): 159.0, ('captopril', 'fibrinogen'): 66.0, ('fibrinogen', 'olanzapin'): 99.0, ('dnr', 'olanzapin'): 85.0, ('dnr', 'fungemia'): 80.0, ('fibrinogen', 'fungemia'): 78.0, ('caspofungin', 'fungemia'): 87.0, ('fungemia', 'olanzapin'): 57.0, ('caspofungin', 'dnr'): 81.0, ('caspofungin', 'fibrinogen'): 79.0}, 770: {('iddm', 'vp'): 16.0}, 773: {}, 899: {}, 1096: {('ppd', 'syst'): 1.0}, 1135: {('chair', 'oob'): 4.0, ('argatroban', 'chair'): 3.0}, 1163: {('captopril', 'twitch'): 1.0}, 1174: {}, 1180: {}, 1283: {('seat', 'unavail'): 1.0, ('habitu', 'unavail'): 1.0, ('habitu', 'seat'): 1.0}, 1332: {('dni', 'dnr'): 5.0}, 1339: {('oob', 'stair'): 18.0, ('ctx', 'stair'): 18.0, ('ctx', 'oob'): 18.0, ('ambul', 'ctx'): 18.0, ('ambul', 'stair'): 18.0, ('ambul', 'oob'): 18.0, ('phenylephrin', 'video'): 15.0, ('barium', 'video'): 15.0}, 1546: {('db', 'oob'): 2.0}, 1568: {('pericard', 'pleasant'): 3.0, ('oob', 'pleasant'): 2.0}, 1601: {('levoph', 'pleasant'): 2.0}, 1606: {('dni', 'dnr'): 1.0}, 1642: {('dnr', 'pleasant'): 2.0, ('dni', 'pleasant'): 2.0, ('pleasant', 'quadrent'): 1.0, ('declin', 'pleasant'): 1.0, ('dni', 'dnr'): 2.0, ('dnr', 'quadrent'): 1.0, ('declin', 'dnr'): 1.0, ('dni', 'quadrent'): 1.0, ('declin', 'dni'): 1.0, ('declin', 'quadrent'): 1.0}, 1660: {}, 1895: {}, 1923: {('dnr', 'moan'): 2.0, ('dnr', 'sarna'): 2.0, ('moan', 'sarna'): 2.0, ('lotion', 'sarna'): 2.0, ('dnr', 'lotion'): 2.0, ('lotion', 'moan'): 2.0}, 2029: {}, 2090: {('ctx', 'dyslipidemia'): 13.0, ('bromid', 'dyslipidemia'): 17.0}, 2098: {('bair', 'hugger'): 4.0}, 2128: {('dopamin', 'mso'): 4.0, ('dopamin', 'unasyn'): 3.0}, 2170: {}, 2187: {('morbid', 'osa'): 2.0}, 2208: {('bipolar', 'vp'): 16.0}, 2337: {('hemangioma', 'smooth'): 1.0, ('pleasant', 'slough'): 1.0, ('dnr', 'pleasantli'): 1.0}, 2378: {('silent', 'video'): 14.000000000000002, ('sensat', 'video'): 12.0, ('sensat', 'silent'): 12.0}, 2386: {('dnr', 'hospic'): 3.0, ('dnr', 'town'): 2.0, ('dni', 'dnr'): 3.0}, 2452: {}, 2508: {('dopamin', 'levoph'): 2.0}, 2561: {}, 2585: {('hilum', 'para'): 1.0, ('prognosi', 'sluggish'): 1.0, ('hook', 'prognosi'): 1.0, ('hook', 'sluggish'): 1.0, ('grave', 'hook'): 1.0, ('grave', 'prognosi'): 1.0, ('grave', 'sluggish'): 1.0, ('dnr', 'grave'): 1.0, ('dnr', 'hook'): 1.0, ('dnr', 'prognosi'): 1.0, ('dnr', 'sluggish'): 1.0, ('dni', 'dnr'): 1.0, ('dni', 'grave'): 1.0, ('dni', 'hook'): 1.0, ('dni', 'prognosi'): 1.0, ('dni', 'sluggish'): 1.0}, 2589: {('bipolar', 'pneumococc'): 19.0, ('pneumococc', 'zyprexa'): 7.000000000000001, ('bipolar', 'zyprexa'): 7. ...

# %%
patient_note_num_0
# Out:
# {111: 12,
#  346: 25,
#  404: 3,
#  546: 6,
#  618: 16,
#  705: 15,
#  726: 48,
#  1039: 55,
#  1556: 37,
#  1872: 3,
#  1944: 56,
#  2286: 69,
#  2990: 166,
#  3055: 29,
#  3099: 13,
#  3201: 8,
#  3526: 7,
#  3773: 6,
#  3881: 20,
#  4122: 51,
#  4754: 101,
#  4811: 21,
#  5476: 1,
#  5494: 22,
#  5774: 104,
#  5786: 152,
#  5913: 1,
#  6133: 68,
#  6735: 13,
#  6745: 13,
#  6973: 36,
#  6981: 8,
#  7277: 66,
#  7310: 8,
#  7924: 9,
#  7977: 9,
#  9908: 11,
#  9984: 15,
#  10302: 100,
#  10510: 86,
#  10545: 10,
#  10642: 10,
#  11049: 14,
#  11209: 9,
#  11395: 41,
#  12530: 24,
#  12849: 50,
#  13098: 46,
#  13566: 23,
#  14125: 9,
#  14514: 96,
#  14965: 25,
#  15159: 15,
#  15251: 11,
#  15396: 17,
#  15566: 37,
#  15853: 45,
#  16275: 17,
#  16344: 27,
#  16622: 51,
#  16684: 29,
#  17122: 16,
#  17354: 5,
#  17802: 64,
#  17983: 65,
#  18094: 23,
#  18736: 35,
#  18768: 46,
#  18848: 205,
#  18971: 26,
#  19243: 25,
#  19323: 6,
#  19390: 21,
#  19463: 20,
#  19535: 59,
#  19754: 13,
#  19827: 22,
#  19833: 58,
#  19872: 10,
#  20006: 8,
#  20023: 9,
#  20190: 6,
#  21046: 101,
#  21094: 36,
#  21427: 10,
#  21502: 102,
#  21580: 52,
#  21676: 12,
#  21699: 7,
#  21979: 11,
#  22735: 15,
#  23660: 12,
#  23795: 78,
#  24181: 13,
#  24582: 37,
#  24725: 57,
#  24730: 19,
#  24854: 25,
#  25003: 182,
#  25046: 7,
#  25774: 61,
#  25975: 9,
#  26474: 89,
#  26578: 15,
#  26716: 41,
#  26774: 3,
#  26849: 33,
#  27005: 5,
#  27145: 24,
#  27421: 61,
#  27431: 5,
#  27496: 7,
#  27504: 72,
#  27639: 221,
#  28004: 13,
#  28072: 34,
#  28178: 202,
#  28427: 6,
#  28498: 25,
#  28726: 34,
#  28750: 19,
#  28906: 32,
#  28907: 13,
#  28933: 394,
#  29105: 468,
#  29588: 72,
#  29647: 26,
#  29872: 225,
#  30476: 174,
#  30549: 12,
#  30614: 8,
#  30699: 14,
#  30786: 9,
#  30941: 110,
#  31030: 168,
#  31134: 24,
#  31139: 9,
#  31451: 48,
#  31556: 57,
#  31690: 18,
#  31692: 35,
#  32050: 34,
#  32326: 24,
#  32618: 42,
#  41546: 25,
#  43937: 6,
#  44851: 274,
#  45381: 16,
#  46589: 26,
#  46763: 6,
#  47045: 9,
#  48632: 147,
#  49079: 20,
#  49683: 3,
#  49922: 13,
#  50093: 8,
#  50231: 3,
#  50556: 216,
#  50859: 537,
#  51914: 313,
#  52010: 12,
#  53105: 115,
#  53399: 78,
#  54193: 85,
#  54401: 14,
#  54408: 2,
#  54739: 75,
#  54946: 7,
#  55400: 5,
#  55570: 14,
#  55887: 37,
#  55944: 34,
#  55987: 20,
#  56390: 19,
#  56648: 8,
#  56854: 170,
#  57091: 88,
#  57102: 35,
#  58702: 479,
#  59260: 11,
#  59437: 26,
#  60849: 2,
#  60868: 6,
#  61652: 7,
#  61667: 30,
#  63039: 8,
#  65513: 8,
#  68044: 40,
#  68095: 23,
#  68184: 5,
#  68308: 8,
#  68860: 14,
#  69719: 13,
#  69745: 25,
#  69776: 17,
#  70226: 8,
#  70447: 9,
#  72930: 11,
#  73811: 9,
#  73888: 109,
#  74316: 2,
#  74444: 81,
#  74686: 75,
#  75824: 10,
#  76282: 21,
#  76827: 2,
#  77382: 10,
#  78241: 3,
#  78388: 14,
#  79008: 27,
#  79055: 21,
#  79222: 18,
#  79877: 156,
#  80637: 148,
#  80678: 9,
#  80737: 46,
#  80805: 79,
#  81437: 27,
#  82393: 5,
#  82769: 85,
#  83932: 2,
#  84474: 34,
#  85160: 8,
#  85258: 52,
#  85404: 11,
#  85797: 9,
#  86007: 35,
#  86394: 4,
#  86684: 11,
#  86832: 67,
#  86863: 8,
#  86872: 326,
#  88193: 16,
#  88660: 11,
#  90256: 18,
#  91350: 19,
#  92074: 28,
#  92278: 52,
#  92331: 42,
#  93422: 7,
#  94341: 2,
#  94997: 9,
#  95280: 23,
#  95803: 18,
#  95830: 33,
#  95933: 56,
#  96699: 85,
#  97181: 30,
#  97795: 60,
#  98009: 33,
#  98299: 29,
#  98597: 2}

# %% [markdown]
# #### Create set of patient co-occurrences from two groups

# %%
# Create a set of all unique co-occurrences from both group
patient_cooc_set = set()
patient_cooc_0_dict = {}
patient_cooc_1_dict = {}

for k, v in patient_cooc_0.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_0_dict:
            patient_cooc_0_dict[item] = v[item]
        else:
            patient_cooc_0_dict[item] = patient_cooc_0_dict[item] + v[item]
            
    
for k, v in patient_cooc_1.items():
    for item in v:
        patient_cooc_set.add(item)
        if item not in patient_cooc_1_dict:
            patient_cooc_1_dict[item] = v[item]
        else:
            patient_cooc_1_dict[item] = patient_cooc_1_dict[item] + v[item]

# %%
print(len(patient_cooc_set))
print(len(patient_cooc_0_dict))
print(len(patient_cooc_1_dict))
# Out:
# 6776
# 1989
# 5152

# %%
# count log-odds score

# reverse
# --------------- co-occurrences --------------->

        
# Get the set of coocurrencies from two groups
# Count log_odd_score

patient_cooc_odd_scores = {}
for set_item in patient_cooc_set:
    if set_item in patient_cooc_0_dict and set_item in patient_cooc_1_dict: 
        d_prob = patient_cooc_0_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        a_prob = patient_cooc_1_dict[set_item]/(patient_cooc_0_dict[set_item] + patient_cooc_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
    elif set_item in patient_cooc_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_cooc_odd_scores[set_item] = log_odd_score
# --------------- co-occurrences ---------------<

# %%
patient_cooc_odd_scores
# Out:
# {('ardsnet', 'oligur'): -6.90875477931522,
#  ('oob', 'sundown'): 6.90875477931522,
#  ('habitu', 'phasic'): 6.90875477931522,
#  ('cmo', 'sacrament'): -6.90875477931522,
#  ('cramp', 'fibrinogen'): 6.90875477931522,
#  ('knowledg', 'pod'): 6.90875477931522,
#  ('hypothermia', 'paperwork'): 1.3825560390092835,
#  ('dni', 'prilosec'): 6.90875477931522,
#  ('osa', 'unstabl'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('ba', 'subq'): 6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('bipolar', 'seriou'): 6.90875477931522,
#  ('asthma', 'xl'): 6.90875477931522,
#  ('anaphylaxi', 'shorter'): 6.90875477931522,
#  ('dobutamin', 'vasopressin'): -6.90875477931522,
#  ('laminectomi', 'subq'): 6.90875477931522,
#  ('historian', 'incent'): 6.90875477931522,
#  ('pleasant', 'stair'): 6.90875477931522,
#  ('quinolon', 'uri'): 6.90875477931522,
#  ('nectar', 'thk'): 6.90875477931522,
#  ('acetazolamid', 'fibrinogen'): 6.90875477931522,
#  ('cloth', 'commod'): -6.90875477931522,
#  ('mottl', 'pleasant'): 6.90875477931522,
#  ('aox', 'friction'): 6.90875477931522,
#  ('morbid', 'wish'): 6.90875477931522,
#  ('ntnd', 'option'): -6.90875477931522,
#  ('declar', 'dni'): -6.90875477931522,
#  ('ardsnet', 'vasopressin'): -6.90875477931522,
#  ('laminectomi', 'predict'): 6.90875477931522,
#  ('puff', 'refractori'): 6.90875477931522,
#  ('gait', 'sensat'): 6.90875477931522,
#  ('ambien', 'muir'): 6.90875477931522,
#  ('arrang', 'arrest'): -6.90875477931522,
#  ('anaphylaxi', 'impli'): 6.90875477931522,
#  ('dermat', 'gadolinium'): 6.90875477931522,
#  ('angioplasti', 'spectral'): 6.90875477931522,
#  ('lat', 'mellitu'): 6.90875477931522,
#  ('dni', 'hilum'): -6.90875477931522,
#  ('fibrinogen', 'pleasant'): 6.90875477931522,
#  ('diaper', 'oob'): 6.90875477931522,
#  ('levoph', 'spiromet'): 6.90875477931522,
#  ('ambien', 'unsteadi'): 6.90875477931522,
#  ('olanzapin', 'oob'): 6.90875477931522,
#  ('asystol', 'expir'): -6.90875477931522,
#  ('lat', 'pronounc'): 6.90875477931522,
#  ('autopsi', 'prognosi'): -6.90875477931522,
#  ('acidot', 'lc'): -6.90875477931522,
#  ('hypotherm', 'paperwork'): -6.90875477931522,
#  ('incis', 'recalibr'): 6.90875477931522,
#  ('mucinex', 'respon'): 6.90875477931522,
#  ('option', 'tran'): 6.90875477931522,
#  ('dnr', 'video'): 1.0192396636734193,
#  ('ba', 'ciwa'): 6.90875477931522,
#  ('signatur', 'sweat'): 6.90875477931522,
#  ('ctx', 'gastriti'): 6.90875477931522,
#  ('crack', 'lotion'): 6.90875477931522,
#  ('absorb', 'asthma'): 6.90875477931522,
#  ('opiat', 'rememb'): 6.90875477931522,
#  ('hypercapnia', 'strictur'): 6.90875477931522,
#  ('cardiovert', 'cvvhd'): -6.90875477931522,
#  ('hemangioma', 'phasic'): 6.90875477931522,
#  ('ciwa', 'xii'): 6.90875477931522,
#  ('nimv', 'profound'): 6.90875477931522,
#  ('phasic', 'spectral'): 6.90875477931522,
#  ('lighthead', 'omeprazol'): 6.90875477931522,
#  ('ambien', 'chair'): 6.90875477931522,
#  ('gabapentin', 'profound'): 6.90875477931522,
#  ('mso', 'syst'): 6.90875477931522,
#  ('dizzi', 'historian'): -6.90875477931522,
#  ('chair', 'simpli'): 6.90875477931522,
#  ('hepatobiliari', 'ntnd'): -6.90875477931522,
#  ('arthrit', 'commod'): 6.90875477931522,
#  ('gastriti', 'unavail'): 6.90875477931522,
#  ('bottl', 'xii'): 6.90875477931522,
#  ('dopamin', 'vasoconstrict'): -6.90875477931522,
#  ('refractori', 'weekli'): 6.90875477931522,
#  ('habitu', 'unavail'): 6.90875477931522,
#  ('diaper', 'nicotin'): 6.90875477931522,
#  ('goc', 'hypothermia'): 6.90875477931522,
#  ('hypotherm', 'levoph'): 1.2495579516853903,
#  ('aricept', 'gurgl'): -6.90875477931522,
#  ('clonidin', 'ferrou'): 6.90875477931522,
#  ('incent', 'silent'): 6.90875477931522,
#  ('qtc', 'rhinorrhea'): 6.90875477931522,
#  ('ciwa', 'neoplast'): 6.90875477931522,
#  ('azotemia', 'rhinorrhea'): -6.90875477931522,
#  ('dnr', 'trazodon'): 6.90875477931522,
#  ('deterior', 'pea'): 6.90875477931522,
#  ('levoph', 'lpm'): 6.90875477931522,
#  ('bicarbon', 'bill'): 6.90875477931522,
#  ('hung', 'religi'): -6.90875477931522,
#  ('homogen', 'scar'): 6.90875477931522,
#  ('brb', 'gait'): 6.90875477931522,
#  ('incis', 'struggl'): -6.90875477931522,
#  ('sensat', 'suprapub'): 6.90875477931522,
#  ('icter', 'palli'): 6.90875477931522,
#  ('erythro', 'pleasant'): 6.90875477931522,
#  ('grim', 'pinpoint'): -6.90875477931522,
#  ('adam', 'duski'): -6.90875477931522,
#  ('ppd', 'sensat'): 6.90875477931522,
#  ('hive', 'uri'): 6.90875477931522,
#  ('dnr', 'ruptur'): 6.90875477931522,
#  ('articul', 'dead'): 6.90875477931522,
#  ('death', 'pronounc'): -6.90875477931522,
#  ('hive', 'thiamin'): 6.90875477931522,
#  ('retic', 'sweat'): 6.90875477931522,
#  ('assymetr', 'lymphangit'): -6.90875477931522,
#  ('omeprazol', 'postop'): 6.90875477931522,
#  ('ffp', 'opinion'): 6.90875477931522,
#  ('brb', 'cefapim'): 6.90875477931522,
#  ('fibrinogen', 'nitroglycerin'): 6.90875477931522,
#  ('dni', 'epigastr'): 6.90875477931522,
#  ('fibrinogen', 'prilosec'): -6.90875477931522,
#  ('dnr', 'pericard'): 6.90875477931522,
#  ('among', 'fu'): -6.90875477931522,
#  ('bromid', 'readmit'): 6.90875477931522,
#  ('stack', 'underpenetr'): -6.90875477931522,
#  ('ppd', 'scar'): 6.90875477931522,
#  ('db', 'declin'): 6.90875477931522,
#  ('behavior', 'vp'): 6.90875477931522,
#  ('pneumococc', 'pod'): 6.90875477931522,
#  ('ethic', 'polici'): -6.90875477931522,
#  ('asthma', 'escal'): 6.90875477931522,
#  ('cmo', 'dead'): -6.90875477931522,
#  ('asthma', 'lac'): 6.90875477931522,
#  ('escal', 'mso'): -6.90875477931522,
#  ('parastern', 'pea'): 6.90875477931522,
#  ('palli', 'scar'): -6.90875477931522,
#  ('ggt', 'romi'): 6.90875477931522,
#  ('asthma', 'ctx'): 6.90875477931522,
#  ('bromid', 'mellitu'): 6.90875477931522,
#  ('bronchovascular', 'underpenetr'): 6.90875477931522,
#  ('commod', 'morbid'): 6.90875477931522,
#  ('pastor', 'trazodon'): -6.90875477931522,
#  ('nifedipin', 'retic'): 6.90875477931522,
#  ('aricept', 'hilum'): -6.90875477931522,
#  ('bipolar', 'gastriti'): 6.90875477931522,
#  ('cmo', 'news'): -6.90875477931522,
#  ('aricept', 'norepinephrin'): 6.90875477931522,
#  ('aox', 'dnr'): 6.90875477931522,
#  ('arrest', 'pulseless'): -6.90875477931522,
#  ('osa', 'pericard'): 6.90875477931522,
#  ('dic', 'gadolinium'): 6.90875477931522,
#  ('adenocarcinoma', 'peribronchovascular'): 6.90875477931522,
#  ('hive', 'profound'): 6.90875477931522,
#  ('freeli', 'gastrojejunostomi'): 6.90875477931522,
#  ('asthma', 'mellitu'): 6.90875477931522,
#  ('gastriti', 'laminectomi'): 6.90875477931522,
#  ('moan', 'occurr'): 6.90875477931522,
#  ('dni', 'tcdb'): 6.90875477931522,
#  ('hypothermia', 'sensat'): 6.90875477931522,
#  ('captopril', 'sibl'): 6.90875477931522,
#  ('phenylephrin', 'unrel'): -6.90875477931522,
#  ('banana', 'rememb'): 6.90875477931522,
#  ('sweat', 'vagu'): 6.90875477931522,
#  ('hive', 'stitch'): 6.90875477931522,
#  ('align', 'myeloma'): 6.90875477931522,
#  ('conc', 'wish'): 6.90875477931522,
#  ('futil', 'hypotherm'): -6.90875477931522,
#  ('syncop', 'thiamin'): 6.90875477931522,
#  ('hospic', 'weekli'): 6.90875477931522,
#  ('bottl', 'leukocyt'): 6.90875477931522,
#  ('dnr', 'laryng'): 1.095952712632351,
#  ('aox', 'prilosec'): 6.90875477931522,
#  ('dizzi', 'qtc'): 6.90875477931522,
#  ('banana', 'flake'): 6.90875477931522,
#  ('habitu', 'osa'): 6.90875477931522,
#  ('chair', 'palli'): 6.90875477931522,
#  ('declin', 'vasopressor'): -6.90875477931522,
#  ('dnr', 'seroquel'): 6.90875477931522,
#  ('asthma', 'ferrou'): 6.90875477931522,
#  ('ligament', 'silent'): -6.90875477931522,
#  ('chair', 'levoph'): 6.90875477931522,
#  ('bill', 'fibrinogen'): 6.90875477931522,
#  ('cocain', 'ctx'): 6.90875477931522,
#  ('hospic', 'palli'): -0.2660901613908308,
#  ('acc', 'aricept'): 6.90875477931522,
#  ('option', 'palli'): -1.4311353280322388,
#  ('iddm', 'uri'): 6.90875477931522,
#  ('breakfast', 'phenylephrin'): 6.90875477931522,
#  ('foci', 'gastrojejunostomi'): 6.90875477931522,
#  ('nectar', 'pharyng'): 6.90875477931522,
#  ('dnr', 'strictur'): 6.90875477931522,
#  ('levoph', 'scar'): 6.90875477931522,
#  ('bottl', 'life'): 6.90875477931522,
#  ('muir', 'passey'): 6.90875477931522,
#  ('qtc', 'zyprexa'): 6.90875477931522,
#  ('anur', 'ggt'): -6.90875477931522,
#  ('cagluc', 'vasopressin'): -6.90875477931522,
#  ('aricept', 'young'): 6.90875477931522,
#  ('death', 'levoph'): -6.90875477931522,
#  ('core', 'platelet'): -6.90875477931522,
#  ('fc', 'pyuria'): -6.90875477931522,
#  ('hunger', 'predict'): -6.90875477931522,
#  ('cefapim', 'dnr'): 6.90875477931522,
#  ('pca', 'scab'): 6.90875477931522,
#  ('ciwa', 'db'): 6.90875477931522,
#  ('acidot', 'agon'): -6.90875477931522,
#  ('mellitu', 'phlegm'): 6.90875477931522,
#  ('money', 'wallet'): 2.2927445483990123,
#  ('life', 'mean'): 6.90875477931522,
#  ('bicarbon', 'permiss'): -6.90875477931522,
#  ('chair', 'iddm'): 6.90875477931522,
#  ('esld', 'venti'): 6.90875477931522,
#  ('burn', 'ctx'): 6.90875477931522,
#  ('occipit', 'scar'): 6.90875477931522,
#  ('ambul', 'sibl'): 6.90875477931522,
#  ('nephrolog', 'scar'): 6.90875477931522,
#  ('historian', 'ppd'): 6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('asthma', 'led'): 6.90875477931522,
#  ('fdp', 'rhinorrhea'): -6.90875477931522,
#  ('asthma', 'thiamin'): 6.90875477931522,
#  ('bottl', 'oob'): 6.90875477931522,
#  ('adam', 'escal'): -6.90875477931522,
#  ('vasopressin', 'venti'): -6.90875477931522,
#  ('contractur', 'criticar'): 6.90875477931522,
#  ('cvvhd', 'hugger'): -6.90875477931522,
#  ('hemangioma', 'osteoblast'): 6.90875477931522,
#  ('anur', 'levoph'): 0.809128888289493,
#  ('dni', 'zoloft'): -1.3825560390092835,
#  ('solut', 'treatement'): 6.90875477931522,
#  ('grave', 'mso'): -6.90875477931522,
#  ('dni', 'td'): 6.90875477931522,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('phlegm', 'pleasant'): 6.90875477931522,
#  ('nahco', 'pleasant'): 6.90875477931522,
#  ('chip', 'dopamin'): 6.90875477931522,
#  ('aricept', 'hive'): 6.90875477931522,
#  ('aricept', 'declin'): 6.90875477931522,
#  ('habitu', 'occupi'): 6.90875477931522,
#  ('nephrolog', 'qam'): 6.90875477931522,
#  ('asthma', 'death'): 6.90875477931522,
#  ('barium', 'pharyng'): 6.90875477931522,
#  ('aprv', 'gvhd'): -6.90875477931522,
#  ('dead', 'prilosec'): 6.90875477931522,
#  ('im', 'nifedipin'): 6.90875477931522,
#  ('itchi', 'nitroglycerin'): 6.90875477931522,
#  ('commod', 'dni'): -1.095952712632351,
#  ('chair', 'cramp'): 6.90875477931522,
#  ('ambul', 'spill'): 6.90875477931522,
#  ('clonidin', 'ultrafiltr'): 6.90875477931522,
#  ('dni', 'rigor'): 6.90875477931522,
#  ('ferritin', 'ferrou'): 6.90875477931522,
#  ('asthma', 'young'): 6.90875477931522,
#  ('pneumococc', 'subq'): 6.90875477931522,
#  ('cocain', 'klonopin'): 6.90875477931522,
#  ('laminectomi', 'weekli'): 6.90875477931522,
#  ('dead', 'mso'): -6.90875477931522,
#  ('puff', 'rehabilit'): 6.90875477931522,
#  ('dni', 'neosynephrin'): 0.46903068451456703,
#  ('levoph', 'pleasant'): 6.90875477931522,
#  ('dnr', 'dyslipidemia'): 6.90875477931522,
#  ('hive', 'platelet'): -6.90875477931522,
#  ('bicarbon', 'cpr'): -6.90875477931522,
#  ('dni', 'dnr'): 0.7266534394200008,
#  ('foci', 'habitu'): 6.90875477931522,
#  ('dietari', 'video'): 6.90875477931522,
#  ('gabapentin', 'omeprazol'): 6.90875477931522,
#  ('life', 'pleasant'): -6.90875477931522,
#  ('asthma', 'life'): 6.90875477931522,
#  ('asthma', 'rhinorrhea'): 6.90875477931522,
#  ('angiogram', 'gadolinium'): 6.90875477931522,
#  ('asystol', 'autopsi'): -6.90875477931522,
#  ('^th', 'dnr'): 6.90875477931522,
#  ('death', 'nifedipin'): 6.90875477931522,
#  ('epigastr', 'hsq'): 6.90875477931522,
#  ('expir', 'hilum'): 6.90875477931522,
#  ('conc', 'dnr'): 6.90875477931522,
#  ('ba', 'romi'): 6.90875477931522,
#  ('captopril', 'oob'): 6.90875477931522,
#  ('dni', 'rhinorrhea'): 0.3357879300251662,
#  ('death', 'oob'): 6.90875477931522,
#  ('dnr', 'itchi'): -3.338770975794994,
#  ('levoph', 'modifi'): 6.90875477931522,
#  ('mood', 'suprapub'): 6.90875477931522,
#  ('option', 'pleasant'): 6.90875477931522,
#  ('breakfast', 'olanzapin'): 6.90875477931522,
#  ('angri', 'declin'): 6.90875477931522,
#  ('autopsi', 'wish'): -6.90875477931522,
#  ('im', 'omeprazol'): 6.90875477931522,
#  ('life', 'ppd'): 6.90875477931522,
#  ('deterior', 'option'): -6.90875477931522,
#  ('fu', 'xl'): 6.90875477931522,
#  ('chair', 'predict'): 6.90875477931522,
#  ('gabapentin', 'habitu'): 6.90875477931522,
#  ('dnr', 'pinpoint'): -6.90875477931522,
#  ('chb', 'hemothorax'): -6.90875477931522,
#  ('gvhd', 'pleasant'): 6.90875477931522,
#  ('epigastr', 'scar'): 6.90875477931522,
#  ('oob', 'zyprexa'): 6.90875477931522,
#  ('mso', 'wish'): -6.90875477931522,
#  ('bill', 'bromid'): 6.90875477931522,
#  ('lat', 'pericard'): 6.90875477931522,
#  ('mortem', 'sluggish'): -6.90875477931522,
#  ('dnr', 'prognosi'): -2.6932429501279174,
#  ('homogen', 'slice'): 6.90875477931522,
#  ('epigastr', 'splint'): 6.90875477931522,
#  ('arrest', 'passi'): 6.90875477931522,
#  ('hilum', 'peribronchovascular'): 0.0,
#  ('dni', 'romi'): 3.269258198656955,
#  ('fatti', 'flight'): 6.90875477931522,
#  ('rhinorrhea', 'xl'): 6.90875477931522,
#  ('sluggish', 'viabl'): -6.90875477931522,
#  ('morbid', 'uri'): 6.90875477931522,
#  ('agon', 'deterior'): -6.90875477931522,
#  ('gait', 'rememb'): 6.90875477931522,
#  ('articul', 'cup'): 6.90875477931522,
#  ('asthma', 'barium'): 6.90875477931522,
#  ('osa', 'qam'): 6.90875477931522,
#  ('seroquel', 'vp'): 6.90875477931522,
#  ('young', 'zero'): 6.90875477931522,
#  ('fdp', 'fibrinogen'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('ciwa', 'itchi'): 6.90875477931522,
#  ('cmo', 'expir'): -6.90875477931522,
#  ('autoset', 'levoph'): 6.90875477931522,
#  ('ppd', 'precordium'): 6.90875477931522,
#  ('barium', 'silent'): 6.90875477931522,
#  ('aricept', 'colonoscopi'): 6.90875477931522,
#  ('omeprazol', 'strictur'): 6.90875477931522,
#  ('itchi', 'quinolon'): 6.90875477931522,
#  ('permiss', 'pleasant'): 6.90875477931522,
#  ('ctx', 'hugger'): 6.90875477931522,
#  ('arrest', 'dic'): -6.90875477931522,
#  ('declin', 'levoph'): -2.552122795903801,
#  ('ppn', 'readmit'): 6.90875477931522,
#  ('epigastr', 'homogen'): 6.90875477931522,
#  ('norepinephrin', 'sluggishli'): -6.90875477931522,
#  ('fibrinogen', 'wish'): 6.90875477931522,
#  ('ferritin', 'ppd'): 6.90875477931522,
#  ('aox', 'oncologist'): 6.90875477931522,
#  ('laminectomi', 'stitch'): 6.90875477931522,
#  ('dead', 'prognosi'): -6.90875477931522,
#  ('azotemia', 'diaphoresi'): 6.90875477931522,
#  ('dnr', 'tremul'): 6.90875477931522,
#  ('hsq', 'mood'): 6.90875477931522,
#  ('peac', 'prognosi'): -6.90875477931522,
#  ('ligament', 'smooth'): 6.90875477931522,
#  ('hemangioma', 'smooth'): 6.90875477931522,
#  ('dnr', 'lpm'): -6.90875477931522,
#  ('lat', 'ppd'): 6.90875477931522,
#  ('oncologist', 'young'): 6.90875477931522,
#  ('ppd', 'rpr'): 6.90875477931522,
#  ('maroon', 'reguard'): 6.90875477931522,
#  ('oligur', 'seriou'): -6.90875477931522,
#  ('aaox', 'moan'): 6.90875477931522,
#  ('bottl', 'dni'): 6.90875477931522,
#  ('promod', 'wether'): 6.90875477931522,
#  ('gurgl', 'moan'): -6.90875477931522,
#  ('adenocarcinoma', 'osa'): 6.90875477931522,
#  ('dz', 'modifi'): 6.90875477931522,
#  ('acc', 'subcost'): 6.90875477931522,
#  ('klonopin', 'led'): 6.90875477931522,
#  ('bill', 'mellitu'): 6.90875477931522,
#  ('anuria', 'levoph'): -6.90875477931522,
#  ('omeprazol', 'tremul'): 6.90875477931522,
#  ('dni', 'ffp'): -2.473073171472692,
#  ('refractori', 'resucit'): 6.90875477931522,
#  ('pleasant', 'scab'): 6.90875477931522,
#  ('rusti', 'vasopressor'): -6.90875477931522,
#  ('nocturn', 'trazodon'): 6.90875477931522,
#  ('ambien', 'mva'): 6.90875477931522,
#  ('autopeep', 'bicarbon'): -6.90875477931522,
#  ('ctx', 'trazodon'): 6.90875477931522,
#  ('cloth', 'money'): 2.387057016415087,
#  ('hypotherm', 'neosynephrin'): -6.90875477931522,
#  ('depth', 'diaphoresi'): 6.90875477931522,
#  ('declin', 'life'): 6.90875477931522,
#  ('ipf', 'robitussin'): -6.90875477931522,
#  ('acetazolamid', 'suffer'): 6.90875477931522,
#  ('chair', 'neo'): 6.90875477931522,
#  ('ciwa', 'crack'): 6.90875477931522,
#  ('asthma', 'corneal'): -6.90875477931522,
#  ('dnr', 'forc'): -6.90875477931522,
#  ('arrest', 'hung'): -6.90875477931522,
#  ('captopril', 'mellitu'): 6.90875477931522,
#  ('dni', 'pericard'): 6.90875477931522,
#  ('romi', 'trazodon'): 6.90875477931522,
#  ('nitroglycerin', 'oob'): 6.90875477931522,
#  ('osa', 'pleasant'): 6.90875477931522,
#  ('pleasant', 'pneumococc'): 6.90875477931522,
#  ('ntnd', 'zoloft'): 6.90875477931522,
#  ('cpr', 'hypercapnia'): -6.90875477931522,
#  ('adam', 'declin'): -6.90875477931522,
#  ('ambien', 'pca'): 6.90875477931522,
#  ('barium', 'mottl'): 6.90875477931522,
#  ('plate', 'requr'): 6.90875477931522,
#  ('recalibr', 'video'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('gurgl', 'sundown'): -6.90875477931522,
#  ('gastriti', 'xii'): 6.90875477931522,
#  ('bottl', 'unavail'): 6.90875477931522,
#  ('declin', 'oob'): 6.90875477931522,
#  ('pcv', 'vasopressin'): -6.90875477931522,
#  ('cyanot', 'fungemia'): -6.90875477931522,
#  ('fatti', 'pca'): 6.90875477931522,
#  ('ferrou', 'unavail'): 6.90875477931522,
#  ('aliv', 'paperwork'): 6.90875477931522,
#  ('ambien', 'myeloma'): 6.90875477931522,
#  ('arrest', 'deterior'): 6.90875477931522,
#  ('peribronchovascular', 'pericard'): 6.90875477931522,
#  ('conc', 'mso'): -6.90875477931522,
#  ('pleasant', 'rigor'): 6.90875477931522,
#  ('ipf', 'oob'): -6.90875477931522,
#  ('aricept', 'qam'): -6.90875477931522,
#  ('autoset', 'commod'): 6.90875477931522,
#  ('dizzi', 'sundown'): 6.90875477931522,
#  ('compani', 'pleasant'): 6.90875477931522,
#  ('contd', 'refractori'): 6.90875477931522,
#  ('eg', 'foci'): 6.90875477931522,
#  ('dic', 'ferritin'): 6.90875477931522,
#  ('adenocarcinoma', 'laminectomi'): 6.90875477931522,
#  ('echocardiogram', 'xl'): 6.90875477931522,
#  ('clonazepam', 'trazodon'): 6.90875477931522,
#  ('gait', 'mood'): 6.90875477931522,
#  ('aox', 'ctx'): 6.90875477931522,
#  ('sibl', 'subq'): 6.90875477931522,
#  ('palli', 'predict'): 6.90875477931522,
#  ('ciwa', 'signatur'): 6.90875477931522,
#  ('mellitu', 'mood'): 6.90875477931522,
#  ('acidot', 'sluggish'): -6.90875477931522,
#  ('ffp', 'mso'): 6.90875477931522,
#  ('ambul', 'palli'): -6.90875477931522,
#  ('nectar', 'silent'): 6.90875477931522,
#  ('cracker', 'dnr'): 6.90875477931522,
#  ('im', 'rhinorrhea'): 6.90875477931522,
#  ('escal', 'seroquel'): 6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('herp', 'stair'): 6.90875477931522,
#  ('pea', 'vasopressin'): -6.90875477931522,
#  ('hive', 'lat'): 6.90875477931522,
#  ('acidot', 'ffp'): -6.90875477931522,
#  ('dni', 'dz'): 6.90875477931522,
#  ('neo', 'tacycard'): 6.90875477931522,
#  ('assymetr', 'ppd'): 6.90875477931522,
#  ('ipf', 'tachpnea'): 6.90875477931522,
#  ('artifici', 'gait'): -6.90875477931522,
#  ('pea', 'rhinorrhea'): 6.90875477931522,
#  ('mellitu', 'rigor'): 6.90875477931522,
#  ('cash', 'crack'): 6.90875477931522,
#  ('chair', 'dizzi'): 6.90875477931522,
#  ('bronchovascular', 'habitu'): 6.90875477931522,
#  ('appi', 'dnr'): 6.90875477931522,
#  ('hsq', 'intent'): 6.90875477931522,
#  ('dnr', 'escal'): 1.2641724947833943,
#  ('phlegm', 'wish'): -6.90875477931522,
#  ('autoset', 'bipolar'): 6.90875477931522,
#  ('norepinephrin', 'permiss'): -6.90875477931522,
#  ('diaphoresi', 'dietari'): 6.90875477931522,
#  ('paperwork', 'sweat'): 6.90875477931522,
#  ('hilum', 'treitz'): 6.90875477931522,
#  ('breakfast', 'burn'): 6.90875477931522,
#  ('ciwa', 'cloth'): 6.90875477931522,
#  ('dnr', 'ffp'): -1.095952712632351,
#  ('ardsnet', 'permiss'): -6.90875477931522,
#  ('burn', 'lusb'): 6.90875477931522,
#  ('oob', 'sooner'): 6.90875477931522,
#  ('oob', 'strictur'): 6.90875477931522,
#  ('ambul', 'asthma'): 6.90875477931522,
#  ('aox', 'venti'): 6.90875477931522,
#  ('incis', 'sibl'): 6.90875477931522,
#  ('dni', 'lift'): 6.90875477931522,
#  ('mind', 'paperwork'): 6.90875477931522,
#  ('paperwork', 'vasopressor'): -6.90875477931522,
#  ('laminectomi', 'unobtain'): 6.90875477931522,
#  ('contd', 'ctx'): 6.90875477931522,
#  ('jewelri', 'wallet'): 2.2927445483990123,
#  ('ciwa', 'fatti'): 6.90875477931522,
#  ('clonazepam', 'platelet'): 6.90875477931522,
#  ('vasopressin', 'wma'): -6.90875477931522,
#  ('dni', 'forc'): -6.90875477931522,
#  ('lat', 'moreov'): 6.90875477931522,
#  ('oob', 'pose'): 6.90875477931522,
#  ('gait', 'motor'): 6.90875477931522,
#  ('ambien', 'clonazepam'): 6.90875477931522,
#  ('readmit', 'trazodon'): 6.90875477931522,
#  ('schistocyt', 'young'): 6.90875477931522,
#  ('endplat', 'para'): -6.90875477931522,
#  ('autopeep', 'pcv'): -6.90875477931522,
#  ('smooth', 'vertebra'): 0.0,
#  ('depth', 'levoph'): 6.90875477931522,
#  ('led', 'mellitu'): 6.90875477931522,
#  ('ofm', 'unsteadi'): 6.90875477931522,
#  ('aaox', 'dnr'): 1.604655121332035,
#  ('corneal', 'levoph'): -6.90875477931522,
#  ('probe', 'viscou'): 6.90875477931522,
#  ('permiss', 'pose'): 6.90875477931522,
#  ('natg', 'occipit'): 6.90875477931522,
#  ('dic', 'impli'): 6.90875477931522,
#  ('barium', 'panic'): 6.90875477931522,
#  ('platelet', 'scar'): 6.90875477931522,
#  ('asthma', 'chair'): 2.09609753878805,
#  ('binder', 'dni'): 6.90875477931522,
#  ('ferritin', 'trazodon'): 6.90875477931522,
#  ('hospic', 'rm'): 6.90875477931522,
#  ('exophyt', 'pyuria'): -6.90875477931522,
#  ('moan', 'profound'): -6.90875477931522,
#  ('declin', 'platelet'): 0.0,
#  ('asthma', 'bromid'): 6.90875477931522,
#  ('criticar', 'dnr'): 6.90875477931522,
#  ('cefapim', 'pleasant'): 6.90875477931522,
#  ('adam', 'prognosi'): -6.90875477931522,
#  ('omeprazol', 'sweat'): 6.90875477931522,
#  ('diaphoresi', 'phlegm'): 6.90875477931522,
#  ('calculi', 'intent'): 6.90875477931522,
#  ('anaphylaxi', 'schizophrenia'): 6.90875477931522,
#  ('dnr', 'lat'): 6.90875477931522,
#  ('cloth', 'signatur'): 2.552122795903801,
#  ('judgement', 'rememb'): 6.90875477931522,
#  ('centimet', 'homogen'): 6.90875477931522,
#  ('caspofungin', 'fibrinogen'): 6.90875477931522,
#  ('phenylephrin', 'ruptur'): 6.90875477931522,
#  ('hive', 'hypercapnia'): 6.90875477931522,
#  ('declin', 'dni'): 2.5893673028298645,
#  ('mrg', 'thrive'): 6.90875477931522,
#  ('diflucan', 'hive'): 6.90875477931522,
#  ('chair', 'unasyn'): -0.5584397574369144,
#  ('exophyt', 'slice'): 6.90875477931522,
#  ('dnr', 'mean'): -6.90875477931522,
#  ('dex', 'levoph'): 6.90875477931522,
#  ('gastriti', 'ultram'): 6.90875477931522,
#  ('oob', 'pleasant'): 6.90875477931522,
#  ('bank', 'fax'): 6.90875477931522,
#  ('ipf', 'vasopressin'): -6.90875477931522,
#  ('ba', 'phlegm'): 6.90875477931522,
#  ('crrt', 'ffp'): -6.90875477931522,
#  ('cdb', 'chair'): 6.90875477931522,
#  ('cocain', 'phlegm'): 6.90875477931522,
#  ('neo', 'neosynephrin'): -6.90875477931522,
#  ('acc', 'im'): 6.90875477931522,
#  ('osa', 'young'): 6.90875477931522,
#  ('bottl', 'gait'): 6.90875477931522,
#  ('ba', 'opiat'): 6.90875477931522,
#  ('aox', 'ba'): 6.90875477931522,
#  ('asthma', 'lpm'): 6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('ferritin', 'hive'): 6.90875477931522,
#  ('arrest', 'trazodon'): -6.90875477931522,
#  ('cash', 'diflucan'): 6.90875477931522,
#  ('retic', 'wish'): 6.90875477931522,
#  ('jejunum', 'tie'): 6.90875477931522,
#  ('hive', 'nocturn'): 6.90875477931522,
#  ('db', 'myeloma'): -6.90875477931522,
#  ('asthma', 'sweat'): 6.90875477931522,
#  ('habitu', 'hilum'): 6.90875477931522,
#  ('oncologist', 'osa'): 6.90875477931522,
#  ('chol', 'stg'): -6.90875477931522,
#  ('among', 'bronchovascular'): 6.90875477931522,
#  ('burn', 'sensat'): 6.90875477931522,
#  ('lusb', 'nifedipin'): 6.90875477931522,
#  ('paperwork', 'rusti'): -6.90875477931522,
#  ('dopamin', 'nonrebreath'): 6.90875477931522,
#  ('dopamin', 'unasyn'): 6.90875477931522,
#  ('mood', 'profound'): 6.90875477931522,
#  ('anur', 'gentamycin'): -6.90875477931522,
#  ('cdb', 'dnr'): 6.90875477931522,
#  ('predict', 'unstabl'): 6.90875477931522,
#  ('aox', 'ffp'): 6.90875477931522,
#  ('rhinorrhea', 'sibl'): 6.90875477931522,
#  ('sweat', 'xl'): 6.90875477931522,
#  ('bill', 'cvvh'): 6.90875477931522,
#  ('freeli', 'scar'): 6.90875477931522,
#  ('epigastr', 'suprapub'): 6.90875477931522,
#  ('natg', 'scar'): -6.90875477931522,
#  ('lpm', 'mellitu'): 6.90875477931522,
#  ('asthma', 'intent'): 6.90875477931522,
#  ('hospic', 'rigor'): 6.90875477931522,
#  ('declin', 'news'): -6.90875477931522,
#  ('^th', 'pleasant'): 6.90875477931522,
#  ('cash', 'historian'): 6.90875477931522,
#  ('dnr', 'lymphangit'): 6.90875477931522,
#  ('nocturn', 'osa'): 6.90875477931522,
#  ('nicotin', 'schizophrenia'): 6.90875477931522,
#  ('slice', 'unenhanc'): 6.90875477931522,
#  ('levoph', 'rpr'): 6.90875477931522,
#  ('mjmgb', 'pea'): -6.90875477931522,
#  ('commod', 'ctx'): 6.90875477931522,
#  ('dnr', 'lift'): 6.90875477931522,
#  ('gvhd', 'wish'): 6.90875477931522,
#  ('led', 'mottl'): 6.90875477931522,
#  ('argatroban', 'cvvhd'): -6.90875477931522,
#  ('chip', 'venti'): 6.90875477931522,
#  ('nifedipin', 'trazodon'): 6.90875477931522,
#  ('ethic', 'neo'): -6.90875477931522,
#  ('nephrolog', 'nitroglycerin'): 6.90875477931522,
#  ('clonidin', 'dnr'): 6.90875477931522,
#  ('dopamin', 'xanax'): 6.90875477931522,
#  ('anaphylaxi', 'xl'): 6.90875477931522,
#  ('gastrojejunostomi', 'sarna'): 6.90875477931522,
#  ('azotemia', 'cocain'): 6.90875477931522,
#  ('stitch', 'weekli'): 6.90875477931522,
#  ('phenylephrin', 'platelet'): -6.90875477931522,
#  ('articul', 'rehabilit'): 6.90875477931522,
#  ('ambien', 'commod'): 6.90875477931522,
#  ('captopril', 'qam'): 6.90875477931522,
#  ('acidot', 'cmo'): -6.90875477931522,
#  ('burn', 'quadrent'): 6.90875477931522,
#  ('coach', 'unavail'): 6.90875477931522,
#  ('abnl', 'splint'): 6.90875477931522,
#  ('dni', 'unobtain'): 0.6916505477038827,
#  ('motor', 'soln'): 6.90875477931522,
#  ('cdb', 'dizzi'): 6.90875477931522,
#  ('dnr', 'palliat'): -6.90875477931522,
#  ('foci', 'nephrogram'): 0.0,
#  ('chair', 'lotion'): -3.02380801661965,
#  ('diaphoresi', 'osa'): 6.90875477931522,
#  ('adam', 'wish'): -6.90875477931522,
#  ('mva', 'wether'): 6.90875477931522,
#  ('db', 'rhinorrhea'): 6.90875477931522,
#  ('hospic', 'icter'): 6.90875477931522,
#  ('klonopin', 'pleasant'): 6.90875477931522,
#  ('subq', 'xl'): 6.90875477931522,
#  ('cpr', 'paralyt'): -6.90875477931522,
#  ('money', 'signatur'): 2.387057016415087,
#  ('omeprazol', 'pleasant'): 6.90875477931522,
#  ('compani', 'prilosec'): 6.90875477931522,
#  ('anur', 'prilosec'): -6.90875477931522,
#  ('pea', 'trazodon'): -6.90875477931522,
#  ('incis', 'strictur'): 6.90875477931522,
#  ('hilum', 'ligament'): 6.90875477931522,
#  ('foci', 'homogen'): 1.3825560390092835,
#  ('wish', 'xii'): -6.90875477931522,
#  ('asystol', 'pronounc'): -6.90875477931522,
#  ('nectar', 'pleasant'): 6.90875477931522,
#  ('qam', 'seat'): 6.90875477931522,
#  ('ambien', 'oob'): 6.90875477931522,
#  ('aaox', 'dead'): -6.90875477931522,
#  ('declin', 'futil'): -6.90875477931522,
#  ('chair', 'moan'): 6.90875477931522,
#  ('laryng', 'vagu'): 6.90875477931522,
#  ('cvvh', 'synthet'): 6.90875477931522,
#  ('behavior', 'harm'): 6.90875477931522,
#  ('dni', 'hsq'): 6.90875477931522,
#  ('chair', 'cloth'): 6.90875477931522,
#  ('contractur', 'dopamin'): -6.90875477931522,
#  ('dnr', 'plerual'): -6.90875477931522,
#  ('dd', 'dnr'): 6.90875477931522,
#  ('neosynephrin', 'unrel'): -6.90875477931522,
#  ('mellitu', 'morbid'): 6.90875477931522,
#  ('crrt', 'fibrinogen'): -6.90875477931522,
#  ('gabapentin', 'gait'): 6.90875477931522,
#  ('dizzi', 'xl'): 6.90875477931522,
#  ('brb', 'pea'): 6.90875477931522,
#  ('dni', 'lat'): 6.90875477931522,
#  ('echocardiogram', 'palli'): -6.90875477931522,
#  ('cup', 'nectar'): 6.90875477931522,
#  ('silent', 'treitz'): -6.90875477931522,
#  ('ggt', 'rhinorrhea'): -6.90875477931522,
#  ('foci', 'peribronchovascular'): 0.0,
#  ('mso', 'oob'): 6.90875477931522,
#  ('ffp', 'wish'): 6.90875477931522,
#  ('anaphylaxi', 'asthma'): 6.90875477931522,
#  ('barium', 'osa'): 6.90875477931522,
#  ('aricept', 'distanc'): 6.90875477931522,
#  ('jerk', 'sluggish'): -6.90875477931522,
#  ('dni', 'nephrolog'): -1.2495579516853903,
#  ('argatroban', 'levoph'): -6.90875477931522,
#  ('levoph', 'triadyn'): 6.90875477931522,
#  ('asystol', 'pulseless'): -6.90875477931522,
#  ('core', 'icter'): -6.90875477931522,
#  ('bicarbon', 'laminectomi'): 6.90875477931522,
#  ('bair', 'dopamin'): -6.90875477931522,
#  ('hctz', 'subq'): 6.90875477931522,
#  ('mood', 'nocturn'): 6.90875477931522,
#  ('gabapentin', 'opiat'): 6.90875477931522,
#  ('herp', 'hive'): 6.90875477931522,
#  ('asthma', 'pneumococc'): 6.90875477931522,
#  ('venti', 'xanax'): 6.90875477931522,
#  ('vallecula', 'video'): 6.90875477931522,
#  ('pharmacolog', 'splint'): 6.90875477931522,
#  ('im', 'sibl'): 6.90875477931522,
#  ('mind', 'prilosec'): 6.90875477931522,
#  ('dnr', 'lc'): -6.90875477931522,
#  ('aox', 'oob'): 6.90875477931522,
#  ('crack', 'dizzi'): 6.90875477931522,
#  ('bottl', 'seriou'): 6.90875477931522,
#  ('spill', 'vallecula'): 6.90875477931522,
#  ('foci', 'pronounc'): 6.90875477931522,
#  ('incent', 'nonrebreath'): 6.90875477931522,
#  ('retic', 'zero'): 6.90875477931522,
#  ('adenocarcinoma', 'laryng'): 6.90875477931522,
#  ('im', 'retic'): 6.90875477931522,
#  ('gait', 'hive'): 6.90875477931522,
#  ('mellitu', 'scar'): 6.90875477931522,
#  ('ambul', 'captopril'): 6.90875477931522,
#  ('fibrinogen', 'hemothorax'): -6.90875477931522,
#  ('lotion', 'moan'): 6.90875477931522,
#  ('burn', 'tran'): 6.90875477931522,
#  ('historian', 'rhinorrhea'): 6.90875477931522,
#  ('commod', 'ofm'): 6.90875477931522,
#  ('impli', 'slice'): 6.90875477931522,
#  ('ruptur', 'seroquel'): 6.90875477931522,
#  ('lat', 'qtc'): 6.90875477931522,
#  ('mso', 'rememb'): 6.90875477931522,
#  ('commod', 'option'): 6.90875477931522,
#  ('ctx', 'phlegm'): 6.90875477931522,
#  ('historian', 'young'): 6.90875477931522,
#  ('hive', 'lusb'): 6.90875477931522,
#  ('compani', 'laminectomi'): 6.90875477931522,
#  ('neo', 'norepinephrin'): -2.625239572123001,
#  ('hctz', 'palli'): 6.90875477931522,
#  ('calculi', 'habitu'): 6.90875477931522,
#  ('declin', 'rabbi'): -6.90875477931522,
#  ('dnr', 'suffer'): 4.804452358089091,
#  ('aaox', 'dz'): 6.90875477931522,
#  ('burn', 'nicotin'): 6.90875477931522,
#  ('fu', 'mrg'): 6.90875477931522,
#  ('aprv', 'dnr'): -6.90875477931522,
#  ('mellitu', 'prilosec'): 6.90875477931522,
#  ('ashen', 'scar'): 6.90875477931522,
#  ('autopeep', 'hypercapnia'): -6.90875477931522,
#  ('dnr', 'option'): -1.6812038300138494,
#  ('qam', 'schizophrenia'): 6.90875477931522,
#  ('cpr', 'hypothermia'): -6.90875477931522,
#  ('subq', 'sweat'): 6.90875477931522,
#  ('herp', 'pleasant'): 6.90875477931522,
#  ('hypothermia', 'pcv'): -6.90875477931522,
#  ('thrive', 'vagu'): 6.90875477931522,
#  ('oncologist', 'pea'): 6.90875477931522,
#  ('dni', 'xanax'): 6.90875477931522,
#  ('clonazepam', 'dnr'): 6.90875477931522,
#  ('neoplast', 'rescan'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('scar', 'trazodon'): 6.90875477931522,
#  ('ffp', 'hypotherm'): -6.90875477931522,
#  ('lw', 'twitch'): -6.90875477931522,
#  ('commod', 'pose'): 6.90875477931522,
#  ('ntnd', 'scar'): 6.90875477931522,
#  ('chair', 'commod'): 1.521688576085562,
#  ('declin', 'peac'): -6.90875477931522,
#  ('lymphangit', 'soln'): 6.90875477931522,
#  ('hypothermia', 'pea'): -6.90875477931522,
#  ('declin', 'oncologist'): 6.90875477931522,
#  ('gait', 'pea'): -6.90875477931522,
#  ('fatti', 'slice'): 6.90875477931522,
#  ('ambul', 'xopenex'): 6.90875477931522,
#  ('pathologist', 'vallecula'): 6.90875477931522,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('hypercapnia', 'pea'): -6.90875477931522,
#  ('esoph', 'impli'): -6.90875477931522,
#  ('clonazepam', 'pleasant'): 6.90875477931522,
#  ('declin', 'dopamin'): -6.90875477931522,
#  ('anur', 'mso'): -6.90875477931522,
#  ('dnr', 'mellitu'): 6.90875477931522,
#  ('levoph', 'tacycard'): 6.90875477931522,
#  ('gadolinium', 'impli'): 6.90875477931522,
#  ('aox', 'motor'): 6.90875477931522,
#  ('dermat', 'rhinorrhea'): 6.90875477931522,
#  ('dermat', 'scab'): 6.90875477931522,
#  ('aox', 'sibl'): 6.90875477931522,
#  ('metoclopramid', 'omeprazol'): 6.90875477931522,
#  ('asthma', 'cg'): -6.90875477931522,
#  ('expir', 'vasopressin'): -6.90875477931522,
#  ('dz', 'postop'): 6.90875477931522,
#  ('barium', 'fax'): 6.90875477931522,
#  ('rememb', 'thiamin'): 6.90875477931522,
#  ('seroquel', 'subdur'): 6.90875477931522,
#  ('deterior', 'thrive'): -6.90875477931522,
#  ('breakfast', 'recalibr'): 6.90875477931522,
#  ('aox', 'dni'): 6.90875477931522,
#  ('asthma', 'purpl'): 6.90875477931522,
#  ('dnr', 'zyprexa'): 1.8806492362025304,
#  ('epigastr', 'nicotin'): 6.90875477931522,
#  ('dietari', 'laminectomi'): 6.90875477931522,
#  ('levoph', 'mso'): -6.90875477931522,
#  ('osa', 'svn'): 6.90875477931522,
#  ('ctx', 'dz'): 6.90875477931522,
#  ('escal', 'scopalamin'): 6.90875477931522,
#  ('cyanot', 'dni'): -6.90875477931522,
#  ('dni', 'uri'): 6.90875477931522,
#  ('chb', 'levoph'): -0.2994965767895269,
#  ('cvvh', 'norepinephrin'): -6.90875477931522,
#  ('bill', 'im'): 6.90875477931522,
#  ('refractori', 'sarna'): 6.90875477931522,
#  ('rememb', 'sibl'): 6.90875477931522,
#  ('chb', 'fibrinogen'): -0.23133479416950195,
#  ('intiat', 'pronounc'): -6.90875477931522,
#  ('mso', 'vasopressin'): -6.90875477931522,
#  ('fatti', 'intent'): 6.90875477931522,
#  ('dni', 'refractori'): 6.90875477931522,
#  ('asystol', 'sacrament'): -6.90875477931522,
#  ('banana', 'gabapentin'): 6.90875477931522,
#  ('dz', 'mood'): 6.90875477931522,
#  ('palli', 'rigor'): 6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('asthma', 'gait'): 6.90875477931522,
#  ('db', 'hive'): 6.90875477931522,
#  ('dopamin', 'scar'): 6.90875477931522,
#  ('incent', 'syst'): 6.90875477931522,
#  ('mucinex', 'olanzapin'): 6.90875477931522,
#  ('rm', 'thiamin'): 6.90875477931522,
#  ('grim', 'lc'): -6.90875477931522,
#  ('mva', 'thirst'): 6.90875477931522,
#  ('palli', 'robitussin'): -6.90875477931522,
#  ('cpr', 'sluggish'): -6.90875477931522,
#  ('dni', 'jewelri'): -0.4046335072286383,
#  ('led', 'prilosec'): 6.90875477931522,
#  ('cocain', 'habitu'): 6.90875477931522,
#  ('dyslipidemia', 'hive'): 6.90875477931522,
#  ('oncologist', 'town'): 6.90875477931522,
#  ('gabapentin', 'gastriti'): 6.90875477931522,
#  ('align', 'vertebra'): 6.90875477931522,
#  ('pneumococc', 'splint'): 6.90875477931522,
#  ('captopril', 'incis'): 6.90875477931522,
#  ('qtc', 'tremul'): 6.90875477931522,
#  ('exophyt', 'impli'): 6.90875477931522,
#  ('anur', 'omeprazol'): 6.90875477931522,
#  ('gabapentin', 'vagu'): 6.90875477931522,
#  ('rhinorrhea', 'wish'): 6.90875477931522,
#  ('cooki', 'nectar'): 6.90875477931522,
#  ('gait', 'sarna'): 6.90875477931522,
#  ('ctx', 'levoph'): 6.90875477931522,
#  ('im', 'mva'): 6.90875477931522,
#  ('cocain', 'cramp'): 6.90875477931522,
#  ('dnr', 'wallet'): -0.4046335072286383,
#  ('dnr', 'inspit'): 6.90875477931522,
#  ('absorb', 'quinolon'): 6.90875477931522,
#  ('oob', 'platelet'): 6.90875477931522,
#  ('cloth', 'ctx'): 6.90875477931522,
#  ('bank', 'epidur'): 6.90875477931522,
#  ('bipolar', 'forc'): -6.90875477931522,
#  ('bottl', 'gum'): 6.90875477931522,
#  ('oob', 'ultram'): 6.90875477931522,
#  ('cs', 'tran'): 6.90875477931522,
#  ('doen', 'rabbi'): -6.90875477931522,
#  ('fibrinogen', 'icter'): -6.90875477931522,
#  ('chair', 'spiromet'): 6.90875477931522,
#  ('aox', 'esld'): 6.90875477931522,
#  ('chip', 'rhochor'): 6.90875477931522,
#  ('levoph', 'motil'): -6.90875477931522,
#  ('dopamin', 'sluggish'): -6.90875477931522,
#  ('caspofungin', 'hive'): 6.90875477931522,
#  ('gabapentin', 'jewelri'): 6.90875477931522,
#  ('ambul', 'incent'): 6.90875477931522,
#  ('bronchovascular', 'uri'): 6.90875477931522,
#  ('echocardiogram', 'smooth'): 6.90875477931522,
#  ('duski', 'wish'): -6.90875477931522,
#  ('aliv', 'rhinorrhea'): 6.90875477931522,
#  ('institut', 'outer'): 6.90875477931522,
#  ('venti', 'zero'): 6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('azotemia', 'subq'): 6.90875477931522,
#  ('azotemia', 'pneumococc'): 6.90875477931522,
#  ('gadolinium', 'vertebra'): 6.90875477931522,
#  ('bipolar', 'commod'): 6.90875477931522,
#  ('dnr', 'dobutamin'): 1.2495579516853903,
#  ('commod', 'xopenex'): 6.90875477931522,
#  ('knowledg', 'wish'): 6.90875477931522,
#  ('cdb', 'oob'): 6.90875477931522,
#  ('hilum', 'osa'): 6.90875477931522,
#  ('thrive', 'wish'): 6.90875477931522,
#  ('scar', 'treitz'): 6.90875477931522,
#  ('prognosi', 'sibl'): -6.90875477931522,
#  ('dnr', 'mind'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('aaox', 'incent'): 6.90875477931522,
#  ('expir', 'im'): 6.90875477931522,
#  ('bill', 'soln'): 6.90875477931522,
#  ('venti', 'young'): 6.90875477931522,
#  ('icter', 'weekli'): 6.90875477931522,
#  ('life', 'trazodon'): -6.90875477931522,
#  ('mrg', 'oncologist'): 6.90875477931522,
#  ('commod', 'dnr'): -1.095952712632351,
#  ('bromid', 'compani'): 6.90875477931522,
#  ('intent', 'romi'): 6.90875477931522,
#  ('dopamin', 'twitch'): -6.90875477931522,
#  ('aricept', 'sundown'): -6.90875477931522,
#  ('dead', 'phenylephrin'): -6.90875477931522,
#  ('chemic', 'pyuria'): -6.90875477931522,
#  ('death', 'dopamin'): -6.90875477931522,
#  ('pleasant', 'thiamin'): 6.90875477931522,
#  ('pneumococc', 'ppd'): 6.90875477931522,
#  ('fibrinogen', 'rigor'): 6.90875477931522,
#  ('method', 'predict'): -6.90875477931522,
#  ('motor', 'oncologist'): 6.90875477931522,
#  ('clinician', 'pea'): -6.90875477931522,
#  ('anaphylaxi', 'zoloft'): 6.90875477931522,
#  ('asthma', 'mva'): 6.90875477931522,
#  ('rigor', 'unasyn'): 6.90875477931522,
#  ('mellitu', 'pod'): 6.90875477931522,
#  ('arrest', 'muir'): 6.90875477931522,
#  ('impli', 'peribronchovascular'): 6.90875477931522,
#  ('contd', 'deterior'): 6.90875477931522,
#  ('ciwa', 'pleasant'): 6.90875477931522,
#  ('chair', 'wish'): 6.90875477931522,
#  ('epidur', 'gadolinium'): 6.90875477931522,
#  ('angioplasti', 'dni'): 6.90875477931522,
#  ('spill', 'video'): 6.90875477931522,
#  ('ofm', 'oob'): 6.90875477931522,
#  ('influenc', 'jerk'): 6.90875477931522,
#  ('bipolar', 'habitu'): 6.90875477931522,
#  ('readmit', 'scar'): 6.90875477931522,
#  ('cyanot', 'hive'): 6.90875477931522,
#  ('liw', 'vasopressin'): -6.90875477931522,
#  ('clonidin', 'xl'): 6.90875477931522,
#  ('hilum', 'unenhanc'): 6.90875477931522,
#  ('gadolinium', 'outer'): 6.90875477931522,
#  ('dopamin', 'vasopressin'): 0.9785433477333831,
#  ('fatti', 'panic'): 6.90875477931522,
#  ('dni', 'lusb'): -6.90875477931522,
#  ('acidot', 'fibrinogen'): -6.90875477931522,
#  ('cardiovert', 'platelet'): -6.90875477931522,
#  ('dnr', 'mood'): 6.90875477931522,
#  ('furhter', 'neoplast'): 6.90875477931522,
#  ('palli', 'struggl'): -6.90875477931522,
#  ('lighthead', 'schizophrenia'): 6.90875477931522,
#  ('artifici', 'xl'): -6.90875477931522,
#  ('bair', 'levoph'): 2.7567935411197357,
#  ('nifedipin', 'scar'): 6.90875477931522,
#  ('esoph', 'hunger'): -6.90875477931522,
#  ('laminectomi', 'schizophrenia'): 6.90875477931522,
#  ('pronounc', 'sluggish'): -6.90875477931522,
#  ('gastriti', 'omeprazol'): 6.90875477931522,
#  ('burn', 'xii'): 6.90875477931522,
#  ('herp', 'hydralizin'): 6.90875477931522,
#  ('asthma', 'herp'): 6.90875477931522,
#  ('chair', 'compani'): 6.90875477931522,
#  ('cpr', 'expir'): -6.90875477931522,
#  ('od', 'rememb'): 6.90875477931522,
#  ('fu', 'oncologist'): 6.90875477931522,
#  ('ciwa', 'sibl'): 6.90875477931522,
#  ('anaphylaxi', 'imbal'): 6.90875477931522,
#  ('arthrit', 'cdb'): 6.90875477931522,
#  ('asystol', 'morgu'): -6.90875477931522,
#  ('historian', 'rememb'): 6.90875477931522,
#  ('dead', 'expir'): -6.90875477931522,
#  ('fatti', 'spectral'): -6.90875477931522,
#  ('herp', 'nitroglycerin'): 6.90875477931522,
#  ('prognosi', 'vasoconstrict'): -6.90875477931522,
#  ('core', 'declin'): -6.90875477931522,
#  ('colonoscopi', 'syncop'): 6.90875477931522,
#  ('chair', 'zyprexa'): 6.90875477931522,
#  ('clonazepam', 'klonopin'): 6.90875477931522,
#  ('pleasant', 'spacer'): 6.90875477931522,
#  ('autopeep', 'paralyt'): -6.90875477931522,
#  ('dni', 'dobutamin'): 6.90875477931522,
#  ('chip', 'scar'): 6.90875477931522,
#  ('artifici', 'dni'): 6.90875477931522,
#  ('dnr', 'signatur'): -0.4046335072286383,
#  ('pleasant', 'qtc'): 6.90875477931522,
#  ('death', 'puff'): 6.90875477931522,
#  ('acc', 'declin'): 6.90875477931522,
#  ('motor', 'pharyng'): 6.90875477931522,
#  ('phenylephrin', 'refractori'): 6.90875477931522,
#  ('azotemia', 'pcv'): -6.90875477931522,
#  ('ambul', 'hover'): 6.90875477931522,
#  ('dead', 'dnr'): -6.90875477931522,
#  ('azotemia', 'calculi'): 6.90875477931522,
#  ('bottl', 'declin'): 6.90875477931522,
#  ('dermat', 'neosynephrin'): 6.90875477931522,
#  ('retic', 'venti'): 6.90875477931522,
#  ('declin', 'mva'): 6.90875477931522,
#  ('aaox', 'aricept'): -6.90875477931522,
#  ('dermat', 'dnr'): 0.3357879300251662,
#  ('dizzi', 'incis'): 6.90875477931522,
#  ('dni', 'priest'): -6.90875477931522,
#  ('clonidin', 'dni'): 6.90875477931522,
#  ('silent', 'young'): 6.90875477931522,
#  ('dni', 'omeprazol'): 1.7859498421315991,
#  ('bell', 'lpm'): 6.90875477931522,
#  ('dopamin', 'vasopressor'): -6.90875477931522,
#  ('azotemia', 'hepatobiliari'): -6.90875477931522,
#  ('declar', 'deterior'): -6.90875477931522,
#  ('aricept', 'money'): -6.90875477931522,
#  ('dni', 'quadrent'): 6.90875477931522,
#  ('hunger', 'wish'): 6.90875477931522,
#  ('panic', 'stair'): 6.90875477931522,
#  ('prognosi', 'retic'): 6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('ba', 'intent'): 6.90875477931522,
#  ('dnr', 'td'): 6.90875477931522,
#  ('subdur', 'vp'): 6.90875477931522,
#  ('ipf', 'sensat'): 6.90875477931522,
#  ('expir', 'sluggish'): -6.90875477931522,
#  ('lymphangit', 'pronounc'): -6.90875477931522,
#  ('align', 'plate'): 6.90875477931522,
#  ('dni', 'xl'): 6.90875477931522,
#  ('gvhd', 'nephrolog'): 6.90875477931522,
#  ('klonopin', 'unsteadi'): 6.90875477931522,
#  ('subq', 'zoloft'): 6.90875477931522,
#  ('dizzi', 'sarna'): 6.90875477931522,
#  ('cup', 'oob'): 6.90875477931522,
#  ('hive', 'refractori'): 6.90875477931522,
#  ('artifici', 'religi'): -6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('deterior', 'dnr'): 0.20026746965023628,
#  ('nephrolog', 'xii'): 6.90875477931522,
#  ('moan', 'qtc'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('gc', 'scl'): 6.90875477931522,
#  ('declin', 'dietari'): 6.90875477931522,
#  ('crack', 'mycolyt'): 6.90875477931522,
#  ('arrest', 'cardiovert'): -6.90875477931522,
#  ('dni', 'pea'): -6.90875477931522,
#  ('ba', 'qam'): 6.90875477931522,
#  ('hive', 'oncologist'): -1.0473214909132258,
#  ('dnr', 'lusb'): -6.90875477931522,
#  ('dnr', 'simpli'): 6.90875477931522,
#  ...}

# %% [markdown]
# ### Train mode

# %% [markdown]
# #### Method 2. Each patient graph => [model training]

# %%
# Dictionaries to use
 # struct: {word: word2vec[128, numpy.array]}
patient_cooc_odd_scores # struct: {cooc_tuple: log_odds_score}
print()

# %%
patient_cooc_odd_scores
# Out:
# {('ardsnet', 'oligur'): -6.90875477931522,
#  ('oob', 'sundown'): 6.90875477931522,
#  ('habitu', 'phasic'): 6.90875477931522,
#  ('cmo', 'sacrament'): -6.90875477931522,
#  ('cramp', 'fibrinogen'): 6.90875477931522,
#  ('knowledg', 'pod'): 6.90875477931522,
#  ('hypothermia', 'paperwork'): 1.3825560390092835,
#  ('dni', 'prilosec'): 6.90875477931522,
#  ('osa', 'unstabl'): 6.90875477931522,
#  ('anaphylaxi', 'ctx'): 6.90875477931522,
#  ('ba', 'subq'): 6.90875477931522,
#  ('dnr', 'laminectomi'): 6.90875477931522,
#  ('bipolar', 'seriou'): 6.90875477931522,
#  ('asthma', 'xl'): 6.90875477931522,
#  ('anaphylaxi', 'shorter'): 6.90875477931522,
#  ('dobutamin', 'vasopressin'): -6.90875477931522,
#  ('laminectomi', 'subq'): 6.90875477931522,
#  ('historian', 'incent'): 6.90875477931522,
#  ('pleasant', 'stair'): 6.90875477931522,
#  ('quinolon', 'uri'): 6.90875477931522,
#  ('nectar', 'thk'): 6.90875477931522,
#  ('acetazolamid', 'fibrinogen'): 6.90875477931522,
#  ('cloth', 'commod'): -6.90875477931522,
#  ('mottl', 'pleasant'): 6.90875477931522,
#  ('aox', 'friction'): 6.90875477931522,
#  ('morbid', 'wish'): 6.90875477931522,
#  ('ntnd', 'option'): -6.90875477931522,
#  ('declar', 'dni'): -6.90875477931522,
#  ('ardsnet', 'vasopressin'): -6.90875477931522,
#  ('laminectomi', 'predict'): 6.90875477931522,
#  ('puff', 'refractori'): 6.90875477931522,
#  ('gait', 'sensat'): 6.90875477931522,
#  ('ambien', 'muir'): 6.90875477931522,
#  ('arrang', 'arrest'): -6.90875477931522,
#  ('anaphylaxi', 'impli'): 6.90875477931522,
#  ('dermat', 'gadolinium'): 6.90875477931522,
#  ('angioplasti', 'spectral'): 6.90875477931522,
#  ('lat', 'mellitu'): 6.90875477931522,
#  ('dni', 'hilum'): -6.90875477931522,
#  ('fibrinogen', 'pleasant'): 6.90875477931522,
#  ('diaper', 'oob'): 6.90875477931522,
#  ('levoph', 'spiromet'): 6.90875477931522,
#  ('ambien', 'unsteadi'): 6.90875477931522,
#  ('olanzapin', 'oob'): 6.90875477931522,
#  ('asystol', 'expir'): -6.90875477931522,
#  ('lat', 'pronounc'): 6.90875477931522,
#  ('autopsi', 'prognosi'): -6.90875477931522,
#  ('acidot', 'lc'): -6.90875477931522,
#  ('hypotherm', 'paperwork'): -6.90875477931522,
#  ('incis', 'recalibr'): 6.90875477931522,
#  ('mucinex', 'respon'): 6.90875477931522,
#  ('option', 'tran'): 6.90875477931522,
#  ('dnr', 'video'): 1.0192396636734193,
#  ('ba', 'ciwa'): 6.90875477931522,
#  ('signatur', 'sweat'): 6.90875477931522,
#  ('ctx', 'gastriti'): 6.90875477931522,
#  ('crack', 'lotion'): 6.90875477931522,
#  ('absorb', 'asthma'): 6.90875477931522,
#  ('opiat', 'rememb'): 6.90875477931522,
#  ('hypercapnia', 'strictur'): 6.90875477931522,
#  ('cardiovert', 'cvvhd'): -6.90875477931522,
#  ('hemangioma', 'phasic'): 6.90875477931522,
#  ('ciwa', 'xii'): 6.90875477931522,
#  ('nimv', 'profound'): 6.90875477931522,
#  ('phasic', 'spectral'): 6.90875477931522,
#  ('lighthead', 'omeprazol'): 6.90875477931522,
#  ('ambien', 'chair'): 6.90875477931522,
#  ('gabapentin', 'profound'): 6.90875477931522,
#  ('mso', 'syst'): 6.90875477931522,
#  ('dizzi', 'historian'): -6.90875477931522,
#  ('chair', 'simpli'): 6.90875477931522,
#  ('hepatobiliari', 'ntnd'): -6.90875477931522,
#  ('arthrit', 'commod'): 6.90875477931522,
#  ('gastriti', 'unavail'): 6.90875477931522,
#  ('bottl', 'xii'): 6.90875477931522,
#  ('dopamin', 'vasoconstrict'): -6.90875477931522,
#  ('refractori', 'weekli'): 6.90875477931522,
#  ('habitu', 'unavail'): 6.90875477931522,
#  ('diaper', 'nicotin'): 6.90875477931522,
#  ('goc', 'hypothermia'): 6.90875477931522,
#  ('hypotherm', 'levoph'): 1.2495579516853903,
#  ('aricept', 'gurgl'): -6.90875477931522,
#  ('clonidin', 'ferrou'): 6.90875477931522,
#  ('incent', 'silent'): 6.90875477931522,
#  ('qtc', 'rhinorrhea'): 6.90875477931522,
#  ('ciwa', 'neoplast'): 6.90875477931522,
#  ('azotemia', 'rhinorrhea'): -6.90875477931522,
#  ('dnr', 'trazodon'): 6.90875477931522,
#  ('deterior', 'pea'): 6.90875477931522,
#  ('levoph', 'lpm'): 6.90875477931522,
#  ('bicarbon', 'bill'): 6.90875477931522,
#  ('hung', 'religi'): -6.90875477931522,
#  ('homogen', 'scar'): 6.90875477931522,
#  ('brb', 'gait'): 6.90875477931522,
#  ('incis', 'struggl'): -6.90875477931522,
#  ('sensat', 'suprapub'): 6.90875477931522,
#  ('icter', 'palli'): 6.90875477931522,
#  ('erythro', 'pleasant'): 6.90875477931522,
#  ('grim', 'pinpoint'): -6.90875477931522,
#  ('adam', 'duski'): -6.90875477931522,
#  ('ppd', 'sensat'): 6.90875477931522,
#  ('hive', 'uri'): 6.90875477931522,
#  ('dnr', 'ruptur'): 6.90875477931522,
#  ('articul', 'dead'): 6.90875477931522,
#  ('death', 'pronounc'): -6.90875477931522,
#  ('hive', 'thiamin'): 6.90875477931522,
#  ('retic', 'sweat'): 6.90875477931522,
#  ('assymetr', 'lymphangit'): -6.90875477931522,
#  ('omeprazol', 'postop'): 6.90875477931522,
#  ('ffp', 'opinion'): 6.90875477931522,
#  ('brb', 'cefapim'): 6.90875477931522,
#  ('fibrinogen', 'nitroglycerin'): 6.90875477931522,
#  ('dni', 'epigastr'): 6.90875477931522,
#  ('fibrinogen', 'prilosec'): -6.90875477931522,
#  ('dnr', 'pericard'): 6.90875477931522,
#  ('among', 'fu'): -6.90875477931522,
#  ('bromid', 'readmit'): 6.90875477931522,
#  ('stack', 'underpenetr'): -6.90875477931522,
#  ('ppd', 'scar'): 6.90875477931522,
#  ('db', 'declin'): 6.90875477931522,
#  ('behavior', 'vp'): 6.90875477931522,
#  ('pneumococc', 'pod'): 6.90875477931522,
#  ('ethic', 'polici'): -6.90875477931522,
#  ('asthma', 'escal'): 6.90875477931522,
#  ('cmo', 'dead'): -6.90875477931522,
#  ('asthma', 'lac'): 6.90875477931522,
#  ('escal', 'mso'): -6.90875477931522,
#  ('parastern', 'pea'): 6.90875477931522,
#  ('palli', 'scar'): -6.90875477931522,
#  ('ggt', 'romi'): 6.90875477931522,
#  ('asthma', 'ctx'): 6.90875477931522,
#  ('bromid', 'mellitu'): 6.90875477931522,
#  ('bronchovascular', 'underpenetr'): 6.90875477931522,
#  ('commod', 'morbid'): 6.90875477931522,
#  ('pastor', 'trazodon'): -6.90875477931522,
#  ('nifedipin', 'retic'): 6.90875477931522,
#  ('aricept', 'hilum'): -6.90875477931522,
#  ('bipolar', 'gastriti'): 6.90875477931522,
#  ('cmo', 'news'): -6.90875477931522,
#  ('aricept', 'norepinephrin'): 6.90875477931522,
#  ('aox', 'dnr'): 6.90875477931522,
#  ('arrest', 'pulseless'): -6.90875477931522,
#  ('osa', 'pericard'): 6.90875477931522,
#  ('dic', 'gadolinium'): 6.90875477931522,
#  ('adenocarcinoma', 'peribronchovascular'): 6.90875477931522,
#  ('hive', 'profound'): 6.90875477931522,
#  ('freeli', 'gastrojejunostomi'): 6.90875477931522,
#  ('asthma', 'mellitu'): 6.90875477931522,
#  ('gastriti', 'laminectomi'): 6.90875477931522,
#  ('moan', 'occurr'): 6.90875477931522,
#  ('dni', 'tcdb'): 6.90875477931522,
#  ('hypothermia', 'sensat'): 6.90875477931522,
#  ('captopril', 'sibl'): 6.90875477931522,
#  ('phenylephrin', 'unrel'): -6.90875477931522,
#  ('banana', 'rememb'): 6.90875477931522,
#  ('sweat', 'vagu'): 6.90875477931522,
#  ('hive', 'stitch'): 6.90875477931522,
#  ('align', 'myeloma'): 6.90875477931522,
#  ('conc', 'wish'): 6.90875477931522,
#  ('futil', 'hypotherm'): -6.90875477931522,
#  ('syncop', 'thiamin'): 6.90875477931522,
#  ('hospic', 'weekli'): 6.90875477931522,
#  ('bottl', 'leukocyt'): 6.90875477931522,
#  ('dnr', 'laryng'): 1.095952712632351,
#  ('aox', 'prilosec'): 6.90875477931522,
#  ('dizzi', 'qtc'): 6.90875477931522,
#  ('banana', 'flake'): 6.90875477931522,
#  ('habitu', 'osa'): 6.90875477931522,
#  ('chair', 'palli'): 6.90875477931522,
#  ('declin', 'vasopressor'): -6.90875477931522,
#  ('dnr', 'seroquel'): 6.90875477931522,
#  ('asthma', 'ferrou'): 6.90875477931522,
#  ('ligament', 'silent'): -6.90875477931522,
#  ('chair', 'levoph'): 6.90875477931522,
#  ('bill', 'fibrinogen'): 6.90875477931522,
#  ('cocain', 'ctx'): 6.90875477931522,
#  ('hospic', 'palli'): -0.2660901613908308,
#  ('acc', 'aricept'): 6.90875477931522,
#  ('option', 'palli'): -1.4311353280322388,
#  ('iddm', 'uri'): 6.90875477931522,
#  ('breakfast', 'phenylephrin'): 6.90875477931522,
#  ('foci', 'gastrojejunostomi'): 6.90875477931522,
#  ('nectar', 'pharyng'): 6.90875477931522,
#  ('dnr', 'strictur'): 6.90875477931522,
#  ('levoph', 'scar'): 6.90875477931522,
#  ('bottl', 'life'): 6.90875477931522,
#  ('muir', 'passey'): 6.90875477931522,
#  ('qtc', 'zyprexa'): 6.90875477931522,
#  ('anur', 'ggt'): -6.90875477931522,
#  ('cagluc', 'vasopressin'): -6.90875477931522,
#  ('aricept', 'young'): 6.90875477931522,
#  ('death', 'levoph'): -6.90875477931522,
#  ('core', 'platelet'): -6.90875477931522,
#  ('fc', 'pyuria'): -6.90875477931522,
#  ('hunger', 'predict'): -6.90875477931522,
#  ('cefapim', 'dnr'): 6.90875477931522,
#  ('pca', 'scab'): 6.90875477931522,
#  ('ciwa', 'db'): 6.90875477931522,
#  ('acidot', 'agon'): -6.90875477931522,
#  ('mellitu', 'phlegm'): 6.90875477931522,
#  ('money', 'wallet'): 2.2927445483990123,
#  ('life', 'mean'): 6.90875477931522,
#  ('bicarbon', 'permiss'): -6.90875477931522,
#  ('chair', 'iddm'): 6.90875477931522,
#  ('esld', 'venti'): 6.90875477931522,
#  ('burn', 'ctx'): 6.90875477931522,
#  ('occipit', 'scar'): 6.90875477931522,
#  ('ambul', 'sibl'): 6.90875477931522,
#  ('nephrolog', 'scar'): 6.90875477931522,
#  ('historian', 'ppd'): 6.90875477931522,
#  ('cefapim', 'pea'): 6.90875477931522,
#  ('asthma', 'led'): 6.90875477931522,
#  ('fdp', 'rhinorrhea'): -6.90875477931522,
#  ('asthma', 'thiamin'): 6.90875477931522,
#  ('bottl', 'oob'): 6.90875477931522,
#  ('adam', 'escal'): -6.90875477931522,
#  ('vasopressin', 'venti'): -6.90875477931522,
#  ('contractur', 'criticar'): 6.90875477931522,
#  ('cvvhd', 'hugger'): -6.90875477931522,
#  ('hemangioma', 'osteoblast'): 6.90875477931522,
#  ('anur', 'levoph'): 0.809128888289493,
#  ('dni', 'zoloft'): -1.3825560390092835,
#  ('solut', 'treatement'): 6.90875477931522,
#  ('grave', 'mso'): -6.90875477931522,
#  ('dni', 'td'): 6.90875477931522,
#  ('dnr', 'phenylephrin'): -6.90875477931522,
#  ('phlegm', 'pleasant'): 6.90875477931522,
#  ('nahco', 'pleasant'): 6.90875477931522,
#  ('chip', 'dopamin'): 6.90875477931522,
#  ('aricept', 'hive'): 6.90875477931522,
#  ('aricept', 'declin'): 6.90875477931522,
#  ('habitu', 'occupi'): 6.90875477931522,
#  ('nephrolog', 'qam'): 6.90875477931522,
#  ('asthma', 'death'): 6.90875477931522,
#  ('barium', 'pharyng'): 6.90875477931522,
#  ('aprv', 'gvhd'): -6.90875477931522,
#  ('dead', 'prilosec'): 6.90875477931522,
#  ('im', 'nifedipin'): 6.90875477931522,
#  ('itchi', 'nitroglycerin'): 6.90875477931522,
#  ('commod', 'dni'): -1.095952712632351,
#  ('chair', 'cramp'): 6.90875477931522,
#  ('ambul', 'spill'): 6.90875477931522,
#  ('clonidin', 'ultrafiltr'): 6.90875477931522,
#  ('dni', 'rigor'): 6.90875477931522,
#  ('ferritin', 'ferrou'): 6.90875477931522,
#  ('asthma', 'young'): 6.90875477931522,
#  ('pneumococc', 'subq'): 6.90875477931522,
#  ('cocain', 'klonopin'): 6.90875477931522,
#  ('laminectomi', 'weekli'): 6.90875477931522,
#  ('dead', 'mso'): -6.90875477931522,
#  ('puff', 'rehabilit'): 6.90875477931522,
#  ('dni', 'neosynephrin'): 0.46903068451456703,
#  ('levoph', 'pleasant'): 6.90875477931522,
#  ('dnr', 'dyslipidemia'): 6.90875477931522,
#  ('hive', 'platelet'): -6.90875477931522,
#  ('bicarbon', 'cpr'): -6.90875477931522,
#  ('dni', 'dnr'): 0.7266534394200008,
#  ('foci', 'habitu'): 6.90875477931522,
#  ('dietari', 'video'): 6.90875477931522,
#  ('gabapentin', 'omeprazol'): 6.90875477931522,
#  ('life', 'pleasant'): -6.90875477931522,
#  ('asthma', 'life'): 6.90875477931522,
#  ('asthma', 'rhinorrhea'): 6.90875477931522,
#  ('angiogram', 'gadolinium'): 6.90875477931522,
#  ('asystol', 'autopsi'): -6.90875477931522,
#  ('^th', 'dnr'): 6.90875477931522,
#  ('death', 'nifedipin'): 6.90875477931522,
#  ('epigastr', 'hsq'): 6.90875477931522,
#  ('expir', 'hilum'): 6.90875477931522,
#  ('conc', 'dnr'): 6.90875477931522,
#  ('ba', 'romi'): 6.90875477931522,
#  ('captopril', 'oob'): 6.90875477931522,
#  ('dni', 'rhinorrhea'): 0.3357879300251662,
#  ('death', 'oob'): 6.90875477931522,
#  ('dnr', 'itchi'): -3.338770975794994,
#  ('levoph', 'modifi'): 6.90875477931522,
#  ('mood', 'suprapub'): 6.90875477931522,
#  ('option', 'pleasant'): 6.90875477931522,
#  ('breakfast', 'olanzapin'): 6.90875477931522,
#  ('angri', 'declin'): 6.90875477931522,
#  ('autopsi', 'wish'): -6.90875477931522,
#  ('im', 'omeprazol'): 6.90875477931522,
#  ('life', 'ppd'): 6.90875477931522,
#  ('deterior', 'option'): -6.90875477931522,
#  ('fu', 'xl'): 6.90875477931522,
#  ('chair', 'predict'): 6.90875477931522,
#  ('gabapentin', 'habitu'): 6.90875477931522,
#  ('dnr', 'pinpoint'): -6.90875477931522,
#  ('chb', 'hemothorax'): -6.90875477931522,
#  ('gvhd', 'pleasant'): 6.90875477931522,
#  ('epigastr', 'scar'): 6.90875477931522,
#  ('oob', 'zyprexa'): 6.90875477931522,
#  ('mso', 'wish'): -6.90875477931522,
#  ('bill', 'bromid'): 6.90875477931522,
#  ('lat', 'pericard'): 6.90875477931522,
#  ('mortem', 'sluggish'): -6.90875477931522,
#  ('dnr', 'prognosi'): -2.6932429501279174,
#  ('homogen', 'slice'): 6.90875477931522,
#  ('epigastr', 'splint'): 6.90875477931522,
#  ('arrest', 'passi'): 6.90875477931522,
#  ('hilum', 'peribronchovascular'): 0.0,
#  ('dni', 'romi'): 3.269258198656955,
#  ('fatti', 'flight'): 6.90875477931522,
#  ('rhinorrhea', 'xl'): 6.90875477931522,
#  ('sluggish', 'viabl'): -6.90875477931522,
#  ('morbid', 'uri'): 6.90875477931522,
#  ('agon', 'deterior'): -6.90875477931522,
#  ('gait', 'rememb'): 6.90875477931522,
#  ('articul', 'cup'): 6.90875477931522,
#  ('asthma', 'barium'): 6.90875477931522,
#  ('osa', 'qam'): 6.90875477931522,
#  ('seroquel', 'vp'): 6.90875477931522,
#  ('young', 'zero'): 6.90875477931522,
#  ('fdp', 'fibrinogen'): -6.90875477931522,
#  ('prilosec', 'robitussin'): 6.90875477931522,
#  ('ciwa', 'itchi'): 6.90875477931522,
#  ('cmo', 'expir'): -6.90875477931522,
#  ('autoset', 'levoph'): 6.90875477931522,
#  ('ppd', 'precordium'): 6.90875477931522,
#  ('barium', 'silent'): 6.90875477931522,
#  ('aricept', 'colonoscopi'): 6.90875477931522,
#  ('omeprazol', 'strictur'): 6.90875477931522,
#  ('itchi', 'quinolon'): 6.90875477931522,
#  ('permiss', 'pleasant'): 6.90875477931522,
#  ('ctx', 'hugger'): 6.90875477931522,
#  ('arrest', 'dic'): -6.90875477931522,
#  ('declin', 'levoph'): -2.552122795903801,
#  ('ppn', 'readmit'): 6.90875477931522,
#  ('epigastr', 'homogen'): 6.90875477931522,
#  ('norepinephrin', 'sluggishli'): -6.90875477931522,
#  ('fibrinogen', 'wish'): 6.90875477931522,
#  ('ferritin', 'ppd'): 6.90875477931522,
#  ('aox', 'oncologist'): 6.90875477931522,
#  ('laminectomi', 'stitch'): 6.90875477931522,
#  ('dead', 'prognosi'): -6.90875477931522,
#  ('azotemia', 'diaphoresi'): 6.90875477931522,
#  ('dnr', 'tremul'): 6.90875477931522,
#  ('hsq', 'mood'): 6.90875477931522,
#  ('peac', 'prognosi'): -6.90875477931522,
#  ('ligament', 'smooth'): 6.90875477931522,
#  ('hemangioma', 'smooth'): 6.90875477931522,
#  ('dnr', 'lpm'): -6.90875477931522,
#  ('lat', 'ppd'): 6.90875477931522,
#  ('oncologist', 'young'): 6.90875477931522,
#  ('ppd', 'rpr'): 6.90875477931522,
#  ('maroon', 'reguard'): 6.90875477931522,
#  ('oligur', 'seriou'): -6.90875477931522,
#  ('aaox', 'moan'): 6.90875477931522,
#  ('bottl', 'dni'): 6.90875477931522,
#  ('promod', 'wether'): 6.90875477931522,
#  ('gurgl', 'moan'): -6.90875477931522,
#  ('adenocarcinoma', 'osa'): 6.90875477931522,
#  ('dz', 'modifi'): 6.90875477931522,
#  ('acc', 'subcost'): 6.90875477931522,
#  ('klonopin', 'led'): 6.90875477931522,
#  ('bill', 'mellitu'): 6.90875477931522,
#  ('anuria', 'levoph'): -6.90875477931522,
#  ('omeprazol', 'tremul'): 6.90875477931522,
#  ('dni', 'ffp'): -2.473073171472692,
#  ('refractori', 'resucit'): 6.90875477931522,
#  ('pleasant', 'scab'): 6.90875477931522,
#  ('rusti', 'vasopressor'): -6.90875477931522,
#  ('nocturn', 'trazodon'): 6.90875477931522,
#  ('ambien', 'mva'): 6.90875477931522,
#  ('autopeep', 'bicarbon'): -6.90875477931522,
#  ('ctx', 'trazodon'): 6.90875477931522,
#  ('cloth', 'money'): 2.387057016415087,
#  ('hypotherm', 'neosynephrin'): -6.90875477931522,
#  ('depth', 'diaphoresi'): 6.90875477931522,
#  ('declin', 'life'): 6.90875477931522,
#  ('ipf', 'robitussin'): -6.90875477931522,
#  ('acetazolamid', 'suffer'): 6.90875477931522,
#  ('chair', 'neo'): 6.90875477931522,
#  ('ciwa', 'crack'): 6.90875477931522,
#  ('asthma', 'corneal'): -6.90875477931522,
#  ('dnr', 'forc'): -6.90875477931522,
#  ('arrest', 'hung'): -6.90875477931522,
#  ('captopril', 'mellitu'): 6.90875477931522,
#  ('dni', 'pericard'): 6.90875477931522,
#  ('romi', 'trazodon'): 6.90875477931522,
#  ('nitroglycerin', 'oob'): 6.90875477931522,
#  ('osa', 'pleasant'): 6.90875477931522,
#  ('pleasant', 'pneumococc'): 6.90875477931522,
#  ('ntnd', 'zoloft'): 6.90875477931522,
#  ('cpr', 'hypercapnia'): -6.90875477931522,
#  ('adam', 'declin'): -6.90875477931522,
#  ('ambien', 'pca'): 6.90875477931522,
#  ('barium', 'mottl'): 6.90875477931522,
#  ('plate', 'requr'): 6.90875477931522,
#  ('recalibr', 'video'): 6.90875477931522,
#  ('arrest', 'pcv'): -6.90875477931522,
#  ('gurgl', 'sundown'): -6.90875477931522,
#  ('gastriti', 'xii'): 6.90875477931522,
#  ('bottl', 'unavail'): 6.90875477931522,
#  ('declin', 'oob'): 6.90875477931522,
#  ('pcv', 'vasopressin'): -6.90875477931522,
#  ('cyanot', 'fungemia'): -6.90875477931522,
#  ('fatti', 'pca'): 6.90875477931522,
#  ('ferrou', 'unavail'): 6.90875477931522,
#  ('aliv', 'paperwork'): 6.90875477931522,
#  ('ambien', 'myeloma'): 6.90875477931522,
#  ('arrest', 'deterior'): 6.90875477931522,
#  ('peribronchovascular', 'pericard'): 6.90875477931522,
#  ('conc', 'mso'): -6.90875477931522,
#  ('pleasant', 'rigor'): 6.90875477931522,
#  ('ipf', 'oob'): -6.90875477931522,
#  ('aricept', 'qam'): -6.90875477931522,
#  ('autoset', 'commod'): 6.90875477931522,
#  ('dizzi', 'sundown'): 6.90875477931522,
#  ('compani', 'pleasant'): 6.90875477931522,
#  ('contd', 'refractori'): 6.90875477931522,
#  ('eg', 'foci'): 6.90875477931522,
#  ('dic', 'ferritin'): 6.90875477931522,
#  ('adenocarcinoma', 'laminectomi'): 6.90875477931522,
#  ('echocardiogram', 'xl'): 6.90875477931522,
#  ('clonazepam', 'trazodon'): 6.90875477931522,
#  ('gait', 'mood'): 6.90875477931522,
#  ('aox', 'ctx'): 6.90875477931522,
#  ('sibl', 'subq'): 6.90875477931522,
#  ('palli', 'predict'): 6.90875477931522,
#  ('ciwa', 'signatur'): 6.90875477931522,
#  ('mellitu', 'mood'): 6.90875477931522,
#  ('acidot', 'sluggish'): -6.90875477931522,
#  ('ffp', 'mso'): 6.90875477931522,
#  ('ambul', 'palli'): -6.90875477931522,
#  ('nectar', 'silent'): 6.90875477931522,
#  ('cracker', 'dnr'): 6.90875477931522,
#  ('im', 'rhinorrhea'): 6.90875477931522,
#  ('escal', 'seroquel'): 6.90875477931522,
#  ('nahco', 'vasopressin'): -6.90875477931522,
#  ('herp', 'stair'): 6.90875477931522,
#  ('pea', 'vasopressin'): -6.90875477931522,
#  ('hive', 'lat'): 6.90875477931522,
#  ('acidot', 'ffp'): -6.90875477931522,
#  ('dni', 'dz'): 6.90875477931522,
#  ('neo', 'tacycard'): 6.90875477931522,
#  ('assymetr', 'ppd'): 6.90875477931522,
#  ('ipf', 'tachpnea'): 6.90875477931522,
#  ('artifici', 'gait'): -6.90875477931522,
#  ('pea', 'rhinorrhea'): 6.90875477931522,
#  ('mellitu', 'rigor'): 6.90875477931522,
#  ('cash', 'crack'): 6.90875477931522,
#  ('chair', 'dizzi'): 6.90875477931522,
#  ('bronchovascular', 'habitu'): 6.90875477931522,
#  ('appi', 'dnr'): 6.90875477931522,
#  ('hsq', 'intent'): 6.90875477931522,
#  ('dnr', 'escal'): 1.2641724947833943,
#  ('phlegm', 'wish'): -6.90875477931522,
#  ('autoset', 'bipolar'): 6.90875477931522,
#  ('norepinephrin', 'permiss'): -6.90875477931522,
#  ('diaphoresi', 'dietari'): 6.90875477931522,
#  ('paperwork', 'sweat'): 6.90875477931522,
#  ('hilum', 'treitz'): 6.90875477931522,
#  ('breakfast', 'burn'): 6.90875477931522,
#  ('ciwa', 'cloth'): 6.90875477931522,
#  ('dnr', 'ffp'): -1.095952712632351,
#  ('ardsnet', 'permiss'): -6.90875477931522,
#  ('burn', 'lusb'): 6.90875477931522,
#  ('oob', 'sooner'): 6.90875477931522,
#  ('oob', 'strictur'): 6.90875477931522,
#  ('ambul', 'asthma'): 6.90875477931522,
#  ('aox', 'venti'): 6.90875477931522,
#  ('incis', 'sibl'): 6.90875477931522,
#  ('dni', 'lift'): 6.90875477931522,
#  ('mind', 'paperwork'): 6.90875477931522,
#  ('paperwork', 'vasopressor'): -6.90875477931522,
#  ('laminectomi', 'unobtain'): 6.90875477931522,
#  ('contd', 'ctx'): 6.90875477931522,
#  ('jewelri', 'wallet'): 2.2927445483990123,
#  ('ciwa', 'fatti'): 6.90875477931522,
#  ('clonazepam', 'platelet'): 6.90875477931522,
#  ('vasopressin', 'wma'): -6.90875477931522,
#  ('dni', 'forc'): -6.90875477931522,
#  ('lat', 'moreov'): 6.90875477931522,
#  ('oob', 'pose'): 6.90875477931522,
#  ('gait', 'motor'): 6.90875477931522,
#  ('ambien', 'clonazepam'): 6.90875477931522,
#  ('readmit', 'trazodon'): 6.90875477931522,
#  ('schistocyt', 'young'): 6.90875477931522,
#  ('endplat', 'para'): -6.90875477931522,
#  ('autopeep', 'pcv'): -6.90875477931522,
#  ('smooth', 'vertebra'): 0.0,
#  ('depth', 'levoph'): 6.90875477931522,
#  ('led', 'mellitu'): 6.90875477931522,
#  ('ofm', 'unsteadi'): 6.90875477931522,
#  ('aaox', 'dnr'): 1.604655121332035,
#  ('corneal', 'levoph'): -6.90875477931522,
#  ('probe', 'viscou'): 6.90875477931522,
#  ('permiss', 'pose'): 6.90875477931522,
#  ('natg', 'occipit'): 6.90875477931522,
#  ('dic', 'impli'): 6.90875477931522,
#  ('barium', 'panic'): 6.90875477931522,
#  ('platelet', 'scar'): 6.90875477931522,
#  ('asthma', 'chair'): 2.09609753878805,
#  ('binder', 'dni'): 6.90875477931522,
#  ('ferritin', 'trazodon'): 6.90875477931522,
#  ('hospic', 'rm'): 6.90875477931522,
#  ('exophyt', 'pyuria'): -6.90875477931522,
#  ('moan', 'profound'): -6.90875477931522,
#  ('declin', 'platelet'): 0.0,
#  ('asthma', 'bromid'): 6.90875477931522,
#  ('criticar', 'dnr'): 6.90875477931522,
#  ('cefapim', 'pleasant'): 6.90875477931522,
#  ('adam', 'prognosi'): -6.90875477931522,
#  ('omeprazol', 'sweat'): 6.90875477931522,
#  ('diaphoresi', 'phlegm'): 6.90875477931522,
#  ('calculi', 'intent'): 6.90875477931522,
#  ('anaphylaxi', 'schizophrenia'): 6.90875477931522,
#  ('dnr', 'lat'): 6.90875477931522,
#  ('cloth', 'signatur'): 2.552122795903801,
#  ('judgement', 'rememb'): 6.90875477931522,
#  ('centimet', 'homogen'): 6.90875477931522,
#  ('caspofungin', 'fibrinogen'): 6.90875477931522,
#  ('phenylephrin', 'ruptur'): 6.90875477931522,
#  ('hive', 'hypercapnia'): 6.90875477931522,
#  ('declin', 'dni'): 2.5893673028298645,
#  ('mrg', 'thrive'): 6.90875477931522,
#  ('diflucan', 'hive'): 6.90875477931522,
#  ('chair', 'unasyn'): -0.5584397574369144,
#  ('exophyt', 'slice'): 6.90875477931522,
#  ('dnr', 'mean'): -6.90875477931522,
#  ('dex', 'levoph'): 6.90875477931522,
#  ('gastriti', 'ultram'): 6.90875477931522,
#  ('oob', 'pleasant'): 6.90875477931522,
#  ('bank', 'fax'): 6.90875477931522,
#  ('ipf', 'vasopressin'): -6.90875477931522,
#  ('ba', 'phlegm'): 6.90875477931522,
#  ('crrt', 'ffp'): -6.90875477931522,
#  ('cdb', 'chair'): 6.90875477931522,
#  ('cocain', 'phlegm'): 6.90875477931522,
#  ('neo', 'neosynephrin'): -6.90875477931522,
#  ('acc', 'im'): 6.90875477931522,
#  ('osa', 'young'): 6.90875477931522,
#  ('bottl', 'gait'): 6.90875477931522,
#  ('ba', 'opiat'): 6.90875477931522,
#  ('aox', 'ba'): 6.90875477931522,
#  ('asthma', 'lpm'): 6.90875477931522,
#  ('ctx', 'modifi'): 6.90875477931522,
#  ('ferritin', 'hive'): 6.90875477931522,
#  ('arrest', 'trazodon'): -6.90875477931522,
#  ('cash', 'diflucan'): 6.90875477931522,
#  ('retic', 'wish'): 6.90875477931522,
#  ('jejunum', 'tie'): 6.90875477931522,
#  ('hive', 'nocturn'): 6.90875477931522,
#  ('db', 'myeloma'): -6.90875477931522,
#  ('asthma', 'sweat'): 6.90875477931522,
#  ('habitu', 'hilum'): 6.90875477931522,
#  ('oncologist', 'osa'): 6.90875477931522,
#  ('chol', 'stg'): -6.90875477931522,
#  ('among', 'bronchovascular'): 6.90875477931522,
#  ('burn', 'sensat'): 6.90875477931522,
#  ('lusb', 'nifedipin'): 6.90875477931522,
#  ('paperwork', 'rusti'): -6.90875477931522,
#  ('dopamin', 'nonrebreath'): 6.90875477931522,
#  ('dopamin', 'unasyn'): 6.90875477931522,
#  ('mood', 'profound'): 6.90875477931522,
#  ('anur', 'gentamycin'): -6.90875477931522,
#  ('cdb', 'dnr'): 6.90875477931522,
#  ('predict', 'unstabl'): 6.90875477931522,
#  ('aox', 'ffp'): 6.90875477931522,
#  ('rhinorrhea', 'sibl'): 6.90875477931522,
#  ('sweat', 'xl'): 6.90875477931522,
#  ('bill', 'cvvh'): 6.90875477931522,
#  ('freeli', 'scar'): 6.90875477931522,
#  ('epigastr', 'suprapub'): 6.90875477931522,
#  ('natg', 'scar'): -6.90875477931522,
#  ('lpm', 'mellitu'): 6.90875477931522,
#  ('asthma', 'intent'): 6.90875477931522,
#  ('hospic', 'rigor'): 6.90875477931522,
#  ('declin', 'news'): -6.90875477931522,
#  ('^th', 'pleasant'): 6.90875477931522,
#  ('cash', 'historian'): 6.90875477931522,
#  ('dnr', 'lymphangit'): 6.90875477931522,
#  ('nocturn', 'osa'): 6.90875477931522,
#  ('nicotin', 'schizophrenia'): 6.90875477931522,
#  ('slice', 'unenhanc'): 6.90875477931522,
#  ('levoph', 'rpr'): 6.90875477931522,
#  ('mjmgb', 'pea'): -6.90875477931522,
#  ('commod', 'ctx'): 6.90875477931522,
#  ('dnr', 'lift'): 6.90875477931522,
#  ('gvhd', 'wish'): 6.90875477931522,
#  ('led', 'mottl'): 6.90875477931522,
#  ('argatroban', 'cvvhd'): -6.90875477931522,
#  ('chip', 'venti'): 6.90875477931522,
#  ('nifedipin', 'trazodon'): 6.90875477931522,
#  ('ethic', 'neo'): -6.90875477931522,
#  ('nephrolog', 'nitroglycerin'): 6.90875477931522,
#  ('clonidin', 'dnr'): 6.90875477931522,
#  ('dopamin', 'xanax'): 6.90875477931522,
#  ('anaphylaxi', 'xl'): 6.90875477931522,
#  ('gastrojejunostomi', 'sarna'): 6.90875477931522,
#  ('azotemia', 'cocain'): 6.90875477931522,
#  ('stitch', 'weekli'): 6.90875477931522,
#  ('phenylephrin', 'platelet'): -6.90875477931522,
#  ('articul', 'rehabilit'): 6.90875477931522,
#  ('ambien', 'commod'): 6.90875477931522,
#  ('captopril', 'qam'): 6.90875477931522,
#  ('acidot', 'cmo'): -6.90875477931522,
#  ('burn', 'quadrent'): 6.90875477931522,
#  ('coach', 'unavail'): 6.90875477931522,
#  ('abnl', 'splint'): 6.90875477931522,
#  ('dni', 'unobtain'): 0.6916505477038827,
#  ('motor', 'soln'): 6.90875477931522,
#  ('cdb', 'dizzi'): 6.90875477931522,
#  ('dnr', 'palliat'): -6.90875477931522,
#  ('foci', 'nephrogram'): 0.0,
#  ('chair', 'lotion'): -3.02380801661965,
#  ('diaphoresi', 'osa'): 6.90875477931522,
#  ('adam', 'wish'): -6.90875477931522,
#  ('mva', 'wether'): 6.90875477931522,
#  ('db', 'rhinorrhea'): 6.90875477931522,
#  ('hospic', 'icter'): 6.90875477931522,
#  ('klonopin', 'pleasant'): 6.90875477931522,
#  ('subq', 'xl'): 6.90875477931522,
#  ('cpr', 'paralyt'): -6.90875477931522,
#  ('money', 'signatur'): 2.387057016415087,
#  ('omeprazol', 'pleasant'): 6.90875477931522,
#  ('compani', 'prilosec'): 6.90875477931522,
#  ('anur', 'prilosec'): -6.90875477931522,
#  ('pea', 'trazodon'): -6.90875477931522,
#  ('incis', 'strictur'): 6.90875477931522,
#  ('hilum', 'ligament'): 6.90875477931522,
#  ('foci', 'homogen'): 1.3825560390092835,
#  ('wish', 'xii'): -6.90875477931522,
#  ('asystol', 'pronounc'): -6.90875477931522,
#  ('nectar', 'pleasant'): 6.90875477931522,
#  ('qam', 'seat'): 6.90875477931522,
#  ('ambien', 'oob'): 6.90875477931522,
#  ('aaox', 'dead'): -6.90875477931522,
#  ('declin', 'futil'): -6.90875477931522,
#  ('chair', 'moan'): 6.90875477931522,
#  ('laryng', 'vagu'): 6.90875477931522,
#  ('cvvh', 'synthet'): 6.90875477931522,
#  ('behavior', 'harm'): 6.90875477931522,
#  ('dni', 'hsq'): 6.90875477931522,
#  ('chair', 'cloth'): 6.90875477931522,
#  ('contractur', 'dopamin'): -6.90875477931522,
#  ('dnr', 'plerual'): -6.90875477931522,
#  ('dd', 'dnr'): 6.90875477931522,
#  ('neosynephrin', 'unrel'): -6.90875477931522,
#  ('mellitu', 'morbid'): 6.90875477931522,
#  ('crrt', 'fibrinogen'): -6.90875477931522,
#  ('gabapentin', 'gait'): 6.90875477931522,
#  ('dizzi', 'xl'): 6.90875477931522,
#  ('brb', 'pea'): 6.90875477931522,
#  ('dni', 'lat'): 6.90875477931522,
#  ('echocardiogram', 'palli'): -6.90875477931522,
#  ('cup', 'nectar'): 6.90875477931522,
#  ('silent', 'treitz'): -6.90875477931522,
#  ('ggt', 'rhinorrhea'): -6.90875477931522,
#  ('foci', 'peribronchovascular'): 0.0,
#  ('mso', 'oob'): 6.90875477931522,
#  ('ffp', 'wish'): 6.90875477931522,
#  ('anaphylaxi', 'asthma'): 6.90875477931522,
#  ('barium', 'osa'): 6.90875477931522,
#  ('aricept', 'distanc'): 6.90875477931522,
#  ('jerk', 'sluggish'): -6.90875477931522,
#  ('dni', 'nephrolog'): -1.2495579516853903,
#  ('argatroban', 'levoph'): -6.90875477931522,
#  ('levoph', 'triadyn'): 6.90875477931522,
#  ('asystol', 'pulseless'): -6.90875477931522,
#  ('core', 'icter'): -6.90875477931522,
#  ('bicarbon', 'laminectomi'): 6.90875477931522,
#  ('bair', 'dopamin'): -6.90875477931522,
#  ('hctz', 'subq'): 6.90875477931522,
#  ('mood', 'nocturn'): 6.90875477931522,
#  ('gabapentin', 'opiat'): 6.90875477931522,
#  ('herp', 'hive'): 6.90875477931522,
#  ('asthma', 'pneumococc'): 6.90875477931522,
#  ('venti', 'xanax'): 6.90875477931522,
#  ('vallecula', 'video'): 6.90875477931522,
#  ('pharmacolog', 'splint'): 6.90875477931522,
#  ('im', 'sibl'): 6.90875477931522,
#  ('mind', 'prilosec'): 6.90875477931522,
#  ('dnr', 'lc'): -6.90875477931522,
#  ('aox', 'oob'): 6.90875477931522,
#  ('crack', 'dizzi'): 6.90875477931522,
#  ('bottl', 'seriou'): 6.90875477931522,
#  ('spill', 'vallecula'): 6.90875477931522,
#  ('foci', 'pronounc'): 6.90875477931522,
#  ('incent', 'nonrebreath'): 6.90875477931522,
#  ('retic', 'zero'): 6.90875477931522,
#  ('adenocarcinoma', 'laryng'): 6.90875477931522,
#  ('im', 'retic'): 6.90875477931522,
#  ('gait', 'hive'): 6.90875477931522,
#  ('mellitu', 'scar'): 6.90875477931522,
#  ('ambul', 'captopril'): 6.90875477931522,
#  ('fibrinogen', 'hemothorax'): -6.90875477931522,
#  ('lotion', 'moan'): 6.90875477931522,
#  ('burn', 'tran'): 6.90875477931522,
#  ('historian', 'rhinorrhea'): 6.90875477931522,
#  ('commod', 'ofm'): 6.90875477931522,
#  ('impli', 'slice'): 6.90875477931522,
#  ('ruptur', 'seroquel'): 6.90875477931522,
#  ('lat', 'qtc'): 6.90875477931522,
#  ('mso', 'rememb'): 6.90875477931522,
#  ('commod', 'option'): 6.90875477931522,
#  ('ctx', 'phlegm'): 6.90875477931522,
#  ('historian', 'young'): 6.90875477931522,
#  ('hive', 'lusb'): 6.90875477931522,
#  ('compani', 'laminectomi'): 6.90875477931522,
#  ('neo', 'norepinephrin'): -2.625239572123001,
#  ('hctz', 'palli'): 6.90875477931522,
#  ('calculi', 'habitu'): 6.90875477931522,
#  ('declin', 'rabbi'): -6.90875477931522,
#  ('dnr', 'suffer'): 4.804452358089091,
#  ('aaox', 'dz'): 6.90875477931522,
#  ('burn', 'nicotin'): 6.90875477931522,
#  ('fu', 'mrg'): 6.90875477931522,
#  ('aprv', 'dnr'): -6.90875477931522,
#  ('mellitu', 'prilosec'): 6.90875477931522,
#  ('ashen', 'scar'): 6.90875477931522,
#  ('autopeep', 'hypercapnia'): -6.90875477931522,
#  ('dnr', 'option'): -1.6812038300138494,
#  ('qam', 'schizophrenia'): 6.90875477931522,
#  ('cpr', 'hypothermia'): -6.90875477931522,
#  ('subq', 'sweat'): 6.90875477931522,
#  ('herp', 'pleasant'): 6.90875477931522,
#  ('hypothermia', 'pcv'): -6.90875477931522,
#  ('thrive', 'vagu'): 6.90875477931522,
#  ('oncologist', 'pea'): 6.90875477931522,
#  ('dni', 'xanax'): 6.90875477931522,
#  ('clonazepam', 'dnr'): 6.90875477931522,
#  ('neoplast', 'rescan'): 6.90875477931522,
#  ('calculi', 'omeprazol'): 6.90875477931522,
#  ('scar', 'trazodon'): 6.90875477931522,
#  ('ffp', 'hypotherm'): -6.90875477931522,
#  ('lw', 'twitch'): -6.90875477931522,
#  ('commod', 'pose'): 6.90875477931522,
#  ('ntnd', 'scar'): 6.90875477931522,
#  ('chair', 'commod'): 1.521688576085562,
#  ('declin', 'peac'): -6.90875477931522,
#  ('lymphangit', 'soln'): 6.90875477931522,
#  ('hypothermia', 'pea'): -6.90875477931522,
#  ('declin', 'oncologist'): 6.90875477931522,
#  ('gait', 'pea'): -6.90875477931522,
#  ('fatti', 'slice'): 6.90875477931522,
#  ('ambul', 'xopenex'): 6.90875477931522,
#  ('pathologist', 'vallecula'): 6.90875477931522,
#  ('ambul', 'msicu'): 6.90875477931522,
#  ('hypercapnia', 'pea'): -6.90875477931522,
#  ('esoph', 'impli'): -6.90875477931522,
#  ('clonazepam', 'pleasant'): 6.90875477931522,
#  ('declin', 'dopamin'): -6.90875477931522,
#  ('anur', 'mso'): -6.90875477931522,
#  ('dnr', 'mellitu'): 6.90875477931522,
#  ('levoph', 'tacycard'): 6.90875477931522,
#  ('gadolinium', 'impli'): 6.90875477931522,
#  ('aox', 'motor'): 6.90875477931522,
#  ('dermat', 'rhinorrhea'): 6.90875477931522,
#  ('dermat', 'scab'): 6.90875477931522,
#  ('aox', 'sibl'): 6.90875477931522,
#  ('metoclopramid', 'omeprazol'): 6.90875477931522,
#  ('asthma', 'cg'): -6.90875477931522,
#  ('expir', 'vasopressin'): -6.90875477931522,
#  ('dz', 'postop'): 6.90875477931522,
#  ('barium', 'fax'): 6.90875477931522,
#  ('rememb', 'thiamin'): 6.90875477931522,
#  ('seroquel', 'subdur'): 6.90875477931522,
#  ('deterior', 'thrive'): -6.90875477931522,
#  ('breakfast', 'recalibr'): 6.90875477931522,
#  ('aox', 'dni'): 6.90875477931522,
#  ('asthma', 'purpl'): 6.90875477931522,
#  ('dnr', 'zyprexa'): 1.8806492362025304,
#  ('epigastr', 'nicotin'): 6.90875477931522,
#  ('dietari', 'laminectomi'): 6.90875477931522,
#  ('levoph', 'mso'): -6.90875477931522,
#  ('osa', 'svn'): 6.90875477931522,
#  ('ctx', 'dz'): 6.90875477931522,
#  ('escal', 'scopalamin'): 6.90875477931522,
#  ('cyanot', 'dni'): -6.90875477931522,
#  ('dni', 'uri'): 6.90875477931522,
#  ('chb', 'levoph'): -0.2994965767895269,
#  ('cvvh', 'norepinephrin'): -6.90875477931522,
#  ('bill', 'im'): 6.90875477931522,
#  ('refractori', 'sarna'): 6.90875477931522,
#  ('rememb', 'sibl'): 6.90875477931522,
#  ('chb', 'fibrinogen'): -0.23133479416950195,
#  ('intiat', 'pronounc'): -6.90875477931522,
#  ('mso', 'vasopressin'): -6.90875477931522,
#  ('fatti', 'intent'): 6.90875477931522,
#  ('dni', 'refractori'): 6.90875477931522,
#  ('asystol', 'sacrament'): -6.90875477931522,
#  ('banana', 'gabapentin'): 6.90875477931522,
#  ('dz', 'mood'): 6.90875477931522,
#  ('palli', 'rigor'): 6.90875477931522,
#  ('hypotherm', 'wish'): -6.90875477931522,
#  ('asthma', 'gait'): 6.90875477931522,
#  ('db', 'hive'): 6.90875477931522,
#  ('dopamin', 'scar'): 6.90875477931522,
#  ('incent', 'syst'): 6.90875477931522,
#  ('mucinex', 'olanzapin'): 6.90875477931522,
#  ('rm', 'thiamin'): 6.90875477931522,
#  ('grim', 'lc'): -6.90875477931522,
#  ('mva', 'thirst'): 6.90875477931522,
#  ('palli', 'robitussin'): -6.90875477931522,
#  ('cpr', 'sluggish'): -6.90875477931522,
#  ('dni', 'jewelri'): -0.4046335072286383,
#  ('led', 'prilosec'): 6.90875477931522,
#  ('cocain', 'habitu'): 6.90875477931522,
#  ('dyslipidemia', 'hive'): 6.90875477931522,
#  ('oncologist', 'town'): 6.90875477931522,
#  ('gabapentin', 'gastriti'): 6.90875477931522,
#  ('align', 'vertebra'): 6.90875477931522,
#  ('pneumococc', 'splint'): 6.90875477931522,
#  ('captopril', 'incis'): 6.90875477931522,
#  ('qtc', 'tremul'): 6.90875477931522,
#  ('exophyt', 'impli'): 6.90875477931522,
#  ('anur', 'omeprazol'): 6.90875477931522,
#  ('gabapentin', 'vagu'): 6.90875477931522,
#  ('rhinorrhea', 'wish'): 6.90875477931522,
#  ('cooki', 'nectar'): 6.90875477931522,
#  ('gait', 'sarna'): 6.90875477931522,
#  ('ctx', 'levoph'): 6.90875477931522,
#  ('im', 'mva'): 6.90875477931522,
#  ('cocain', 'cramp'): 6.90875477931522,
#  ('dnr', 'wallet'): -0.4046335072286383,
#  ('dnr', 'inspit'): 6.90875477931522,
#  ('absorb', 'quinolon'): 6.90875477931522,
#  ('oob', 'platelet'): 6.90875477931522,
#  ('cloth', 'ctx'): 6.90875477931522,
#  ('bank', 'epidur'): 6.90875477931522,
#  ('bipolar', 'forc'): -6.90875477931522,
#  ('bottl', 'gum'): 6.90875477931522,
#  ('oob', 'ultram'): 6.90875477931522,
#  ('cs', 'tran'): 6.90875477931522,
#  ('doen', 'rabbi'): -6.90875477931522,
#  ('fibrinogen', 'icter'): -6.90875477931522,
#  ('chair', 'spiromet'): 6.90875477931522,
#  ('aox', 'esld'): 6.90875477931522,
#  ('chip', 'rhochor'): 6.90875477931522,
#  ('levoph', 'motil'): -6.90875477931522,
#  ('dopamin', 'sluggish'): -6.90875477931522,
#  ('caspofungin', 'hive'): 6.90875477931522,
#  ('gabapentin', 'jewelri'): 6.90875477931522,
#  ('ambul', 'incent'): 6.90875477931522,
#  ('bronchovascular', 'uri'): 6.90875477931522,
#  ('echocardiogram', 'smooth'): 6.90875477931522,
#  ('duski', 'wish'): -6.90875477931522,
#  ('aliv', 'rhinorrhea'): 6.90875477931522,
#  ('institut', 'outer'): 6.90875477931522,
#  ('venti', 'zero'): 6.90875477931522,
#  ('ambul', 'sarna'): 6.90875477931522,
#  ('azotemia', 'subq'): 6.90875477931522,
#  ('azotemia', 'pneumococc'): 6.90875477931522,
#  ('gadolinium', 'vertebra'): 6.90875477931522,
#  ('bipolar', 'commod'): 6.90875477931522,
#  ('dnr', 'dobutamin'): 1.2495579516853903,
#  ('commod', 'xopenex'): 6.90875477931522,
#  ('knowledg', 'wish'): 6.90875477931522,
#  ('cdb', 'oob'): 6.90875477931522,
#  ('hilum', 'osa'): 6.90875477931522,
#  ('thrive', 'wish'): 6.90875477931522,
#  ('scar', 'treitz'): 6.90875477931522,
#  ('prognosi', 'sibl'): -6.90875477931522,
#  ('dnr', 'mind'): 6.90875477931522,
#  ('epigastr', 'postop'): 6.90875477931522,
#  ('aaox', 'incent'): 6.90875477931522,
#  ('expir', 'im'): 6.90875477931522,
#  ('bill', 'soln'): 6.90875477931522,
#  ('venti', 'young'): 6.90875477931522,
#  ('icter', 'weekli'): 6.90875477931522,
#  ('life', 'trazodon'): -6.90875477931522,
#  ('mrg', 'oncologist'): 6.90875477931522,
#  ('commod', 'dnr'): -1.095952712632351,
#  ('bromid', 'compani'): 6.90875477931522,
#  ('intent', 'romi'): 6.90875477931522,
#  ('dopamin', 'twitch'): -6.90875477931522,
#  ('aricept', 'sundown'): -6.90875477931522,
#  ('dead', 'phenylephrin'): -6.90875477931522,
#  ('chemic', 'pyuria'): -6.90875477931522,
#  ('death', 'dopamin'): -6.90875477931522,
#  ('pleasant', 'thiamin'): 6.90875477931522,
#  ('pneumococc', 'ppd'): 6.90875477931522,
#  ('fibrinogen', 'rigor'): 6.90875477931522,
#  ('method', 'predict'): -6.90875477931522,
#  ('motor', 'oncologist'): 6.90875477931522,
#  ('clinician', 'pea'): -6.90875477931522,
#  ('anaphylaxi', 'zoloft'): 6.90875477931522,
#  ('asthma', 'mva'): 6.90875477931522,
#  ('rigor', 'unasyn'): 6.90875477931522,
#  ('mellitu', 'pod'): 6.90875477931522,
#  ('arrest', 'muir'): 6.90875477931522,
#  ('impli', 'peribronchovascular'): 6.90875477931522,
#  ('contd', 'deterior'): 6.90875477931522,
#  ('ciwa', 'pleasant'): 6.90875477931522,
#  ('chair', 'wish'): 6.90875477931522,
#  ('epidur', 'gadolinium'): 6.90875477931522,
#  ('angioplasti', 'dni'): 6.90875477931522,
#  ('spill', 'video'): 6.90875477931522,
#  ('ofm', 'oob'): 6.90875477931522,
#  ('influenc', 'jerk'): 6.90875477931522,
#  ('bipolar', 'habitu'): 6.90875477931522,
#  ('readmit', 'scar'): 6.90875477931522,
#  ('cyanot', 'hive'): 6.90875477931522,
#  ('liw', 'vasopressin'): -6.90875477931522,
#  ('clonidin', 'xl'): 6.90875477931522,
#  ('hilum', 'unenhanc'): 6.90875477931522,
#  ('gadolinium', 'outer'): 6.90875477931522,
#  ('dopamin', 'vasopressin'): 0.9785433477333831,
#  ('fatti', 'panic'): 6.90875477931522,
#  ('dni', 'lusb'): -6.90875477931522,
#  ('acidot', 'fibrinogen'): -6.90875477931522,
#  ('cardiovert', 'platelet'): -6.90875477931522,
#  ('dnr', 'mood'): 6.90875477931522,
#  ('furhter', 'neoplast'): 6.90875477931522,
#  ('palli', 'struggl'): -6.90875477931522,
#  ('lighthead', 'schizophrenia'): 6.90875477931522,
#  ('artifici', 'xl'): -6.90875477931522,
#  ('bair', 'levoph'): 2.7567935411197357,
#  ('nifedipin', 'scar'): 6.90875477931522,
#  ('esoph', 'hunger'): -6.90875477931522,
#  ('laminectomi', 'schizophrenia'): 6.90875477931522,
#  ('pronounc', 'sluggish'): -6.90875477931522,
#  ('gastriti', 'omeprazol'): 6.90875477931522,
#  ('burn', 'xii'): 6.90875477931522,
#  ('herp', 'hydralizin'): 6.90875477931522,
#  ('asthma', 'herp'): 6.90875477931522,
#  ('chair', 'compani'): 6.90875477931522,
#  ('cpr', 'expir'): -6.90875477931522,
#  ('od', 'rememb'): 6.90875477931522,
#  ('fu', 'oncologist'): 6.90875477931522,
#  ('ciwa', 'sibl'): 6.90875477931522,
#  ('anaphylaxi', 'imbal'): 6.90875477931522,
#  ('arthrit', 'cdb'): 6.90875477931522,
#  ('asystol', 'morgu'): -6.90875477931522,
#  ('historian', 'rememb'): 6.90875477931522,
#  ('dead', 'expir'): -6.90875477931522,
#  ('fatti', 'spectral'): -6.90875477931522,
#  ('herp', 'nitroglycerin'): 6.90875477931522,
#  ('prognosi', 'vasoconstrict'): -6.90875477931522,
#  ('core', 'declin'): -6.90875477931522,
#  ('colonoscopi', 'syncop'): 6.90875477931522,
#  ('chair', 'zyprexa'): 6.90875477931522,
#  ('clonazepam', 'klonopin'): 6.90875477931522,
#  ('pleasant', 'spacer'): 6.90875477931522,
#  ('autopeep', 'paralyt'): -6.90875477931522,
#  ('dni', 'dobutamin'): 6.90875477931522,
#  ('chip', 'scar'): 6.90875477931522,
#  ('artifici', 'dni'): 6.90875477931522,
#  ('dnr', 'signatur'): -0.4046335072286383,
#  ('pleasant', 'qtc'): 6.90875477931522,
#  ('death', 'puff'): 6.90875477931522,
#  ('acc', 'declin'): 6.90875477931522,
#  ('motor', 'pharyng'): 6.90875477931522,
#  ('phenylephrin', 'refractori'): 6.90875477931522,
#  ('azotemia', 'pcv'): -6.90875477931522,
#  ('ambul', 'hover'): 6.90875477931522,
#  ('dead', 'dnr'): -6.90875477931522,
#  ('azotemia', 'calculi'): 6.90875477931522,
#  ('bottl', 'declin'): 6.90875477931522,
#  ('dermat', 'neosynephrin'): 6.90875477931522,
#  ('retic', 'venti'): 6.90875477931522,
#  ('declin', 'mva'): 6.90875477931522,
#  ('aaox', 'aricept'): -6.90875477931522,
#  ('dermat', 'dnr'): 0.3357879300251662,
#  ('dizzi', 'incis'): 6.90875477931522,
#  ('dni', 'priest'): -6.90875477931522,
#  ('clonidin', 'dni'): 6.90875477931522,
#  ('silent', 'young'): 6.90875477931522,
#  ('dni', 'omeprazol'): 1.7859498421315991,
#  ('bell', 'lpm'): 6.90875477931522,
#  ('dopamin', 'vasopressor'): -6.90875477931522,
#  ('azotemia', 'hepatobiliari'): -6.90875477931522,
#  ('declar', 'deterior'): -6.90875477931522,
#  ('aricept', 'money'): -6.90875477931522,
#  ('dni', 'quadrent'): 6.90875477931522,
#  ('hunger', 'wish'): 6.90875477931522,
#  ('panic', 'stair'): 6.90875477931522,
#  ('prognosi', 'retic'): 6.90875477931522,
#  ('calvarium', 'slice'): 6.90875477931522,
#  ('ba', 'intent'): 6.90875477931522,
#  ('dnr', 'td'): 6.90875477931522,
#  ('subdur', 'vp'): 6.90875477931522,
#  ('ipf', 'sensat'): 6.90875477931522,
#  ('expir', 'sluggish'): -6.90875477931522,
#  ('lymphangit', 'pronounc'): -6.90875477931522,
#  ('align', 'plate'): 6.90875477931522,
#  ('dni', 'xl'): 6.90875477931522,
#  ('gvhd', 'nephrolog'): 6.90875477931522,
#  ('klonopin', 'unsteadi'): 6.90875477931522,
#  ('subq', 'zoloft'): 6.90875477931522,
#  ('dizzi', 'sarna'): 6.90875477931522,
#  ('cup', 'oob'): 6.90875477931522,
#  ('hive', 'refractori'): 6.90875477931522,
#  ('artifici', 'religi'): -6.90875477931522,
#  ('option', 'readdress'): -6.90875477931522,
#  ('deterior', 'dnr'): 0.20026746965023628,
#  ('nephrolog', 'xii'): 6.90875477931522,
#  ('moan', 'qtc'): 6.90875477931522,
#  ('anaphylaxi', 'uri'): 6.90875477931522,
#  ('gc', 'scl'): 6.90875477931522,
#  ('declin', 'dietari'): 6.90875477931522,
#  ('crack', 'mycolyt'): 6.90875477931522,
#  ('arrest', 'cardiovert'): -6.90875477931522,
#  ('dni', 'pea'): -6.90875477931522,
#  ('ba', 'qam'): 6.90875477931522,
#  ('hive', 'oncologist'): -1.0473214909132258,
#  ('dnr', 'lusb'): -6.90875477931522,
#  ('dnr', 'simpli'): 6.90875477931522,
#  ...}

# %%
# Data normalization
import numpy
def data_norm(cooc_odd_scores):

    def norm_arr(array):
        arr = numpy.array(list(array))
        start = 0
        end = 1
        width = end - start
        res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
        return res.tolist()

    cooc_keys, cooc_values = zip(*cooc_odd_scores.items())
    new_cooc_odd_scores = dict(zip(cooc_keys, norm_arr(cooc_values)))

    return new_cooc_odd_scores

new_patient_cooc_odd_scores = data_norm(patient_cooc_odd_scores)

# %%
new_patient_cooc_odd_scores
# Out:
# {('ardsnet', 'oligur'): 0.0,
#  ('oob', 'sundown'): 1.0,
#  ('habitu', 'phasic'): 1.0,
#  ('cmo', 'sacrament'): 0.0,
#  ('cramp', 'fibrinogen'): 1.0,
#  ('knowledg', 'pod'): 1.0,
#  ('hypothermia', 'paperwork'): 0.6000582654307438,
#  ('dni', 'prilosec'): 1.0,
#  ('osa', 'unstabl'): 1.0,
#  ('anaphylaxi', 'ctx'): 1.0,
#  ('ba', 'subq'): 1.0,
#  ('dnr', 'laminectomi'): 1.0,
#  ('bipolar', 'seriou'): 1.0,
#  ('asthma', 'xl'): 1.0,
#  ('anaphylaxi', 'shorter'): 1.0,
#  ('dobutamin', 'vasopressin'): 0.0,
#  ('laminectomi', 'subq'): 1.0,
#  ('historian', 'incent'): 1.0,
#  ('pleasant', 'stair'): 1.0,
#  ('quinolon', 'uri'): 1.0,
#  ('nectar', 'thk'): 1.0,
#  ('acetazolamid', 'fibrinogen'): 1.0,
#  ('cloth', 'commod'): 0.0,
#  ('mottl', 'pleasant'): 1.0,
#  ('aox', 'friction'): 1.0,
#  ('morbid', 'wish'): 1.0,
#  ('ntnd', 'option'): 0.0,
#  ('declar', 'dni'): 0.0,
#  ('ardsnet', 'vasopressin'): 0.0,
#  ('laminectomi', 'predict'): 1.0,
#  ('puff', 'refractori'): 1.0,
#  ('gait', 'sensat'): 1.0,
#  ('ambien', 'muir'): 1.0,
#  ('arrang', 'arrest'): 0.0,
#  ('anaphylaxi', 'impli'): 1.0,
#  ('dermat', 'gadolinium'): 1.0,
#  ('angioplasti', 'spectral'): 1.0,
#  ('lat', 'mellitu'): 1.0,
#  ('dni', 'hilum'): 0.0,
#  ('fibrinogen', 'pleasant'): 1.0,
#  ('diaper', 'oob'): 1.0,
#  ('levoph', 'spiromet'): 1.0,
#  ('ambien', 'unsteadi'): 1.0,
#  ('olanzapin', 'oob'): 1.0,
#  ('asystol', 'expir'): 0.0,
#  ('lat', 'pronounc'): 1.0,
#  ('autopsi', 'prognosi'): 0.0,
#  ('acidot', 'lc'): 0.0,
#  ('hypotherm', 'paperwork'): 0.0,
#  ('incis', 'recalibr'): 1.0,
#  ('mucinex', 'respon'): 1.0,
#  ('option', 'tran'): 1.0,
#  ('dnr', 'video'): 0.5737643537967955,
#  ('ba', 'ciwa'): 1.0,
#  ('signatur', 'sweat'): 1.0,
#  ('ctx', 'gastriti'): 1.0,
#  ('crack', 'lotion'): 1.0,
#  ('absorb', 'asthma'): 1.0,
#  ('opiat', 'rememb'): 1.0,
#  ('hypercapnia', 'strictur'): 1.0,
#  ('cardiovert', 'cvvhd'): 0.0,
#  ('hemangioma', 'phasic'): 1.0,
#  ('ciwa', 'xii'): 1.0,
#  ('nimv', 'profound'): 1.0,
#  ('phasic', 'spectral'): 1.0,
#  ('lighthead', 'omeprazol'): 1.0,
#  ('ambien', 'chair'): 1.0,
#  ('gabapentin', 'profound'): 1.0,
#  ('mso', 'syst'): 1.0,
#  ('dizzi', 'historian'): 0.0,
#  ('chair', 'simpli'): 1.0,
#  ('hepatobiliari', 'ntnd'): 0.0,
#  ('arthrit', 'commod'): 1.0,
#  ('gastriti', 'unavail'): 1.0,
#  ('bottl', 'xii'): 1.0,
#  ('dopamin', 'vasoconstrict'): 0.0,
#  ('refractori', 'weekli'): 1.0,
#  ('habitu', 'unavail'): 1.0,
#  ('diaper', 'nicotin'): 1.0,
#  ('goc', 'hypothermia'): 1.0,
#  ('hypotherm', 'levoph'): 0.5904329355723089,
#  ('aricept', 'gurgl'): 0.0,
#  ('clonidin', 'ferrou'): 1.0,
#  ('incent', 'silent'): 1.0,
#  ('qtc', 'rhinorrhea'): 1.0,
#  ('ciwa', 'neoplast'): 1.0,
#  ('azotemia', 'rhinorrhea'): 0.0,
#  ('dnr', 'trazodon'): 1.0,
#  ('deterior', 'pea'): 1.0,
#  ('levoph', 'lpm'): 1.0,
#  ('bicarbon', 'bill'): 1.0,
#  ('hung', 'religi'): 0.0,
#  ('homogen', 'scar'): 1.0,
#  ('brb', 'gait'): 1.0,
#  ('incis', 'struggl'): 0.0,
#  ('sensat', 'suprapub'): 1.0,
#  ('icter', 'palli'): 1.0,
#  ('erythro', 'pleasant'): 1.0,
#  ('grim', 'pinpoint'): 0.0,
#  ('adam', 'duski'): 0.0,
#  ('ppd', 'sensat'): 1.0,
#  ('hive', 'uri'): 1.0,
#  ('dnr', 'ruptur'): 1.0,
#  ('articul', 'dead'): 1.0,
#  ('death', 'pronounc'): 0.0,
#  ('hive', 'thiamin'): 1.0,
#  ('retic', 'sweat'): 1.0,
#  ('assymetr', 'lymphangit'): 0.0,
#  ('omeprazol', 'postop'): 1.0,
#  ('ffp', 'opinion'): 1.0,
#  ('brb', 'cefapim'): 1.0,
#  ('fibrinogen', 'nitroglycerin'): 1.0,
#  ('dni', 'epigastr'): 1.0,
#  ('fibrinogen', 'prilosec'): 0.0,
#  ('dnr', 'pericard'): 1.0,
#  ('among', 'fu'): 0.0,
#  ('bromid', 'readmit'): 1.0,
#  ('stack', 'underpenetr'): 0.0,
#  ('ppd', 'scar'): 1.0,
#  ('db', 'declin'): 1.0,
#  ('behavior', 'vp'): 1.0,
#  ('pneumococc', 'pod'): 1.0,
#  ('ethic', 'polici'): 0.0,
#  ('asthma', 'escal'): 1.0,
#  ('cmo', 'dead'): 0.0,
#  ('asthma', 'lac'): 1.0,
#  ('escal', 'mso'): 0.0,
#  ('parastern', 'pea'): 1.0,
#  ('palli', 'scar'): 0.0,
#  ('ggt', 'romi'): 1.0,
#  ('asthma', 'ctx'): 1.0,
#  ('bromid', 'mellitu'): 1.0,
#  ('bronchovascular', 'underpenetr'): 1.0,
#  ('commod', 'morbid'): 1.0,
#  ('pastor', 'trazodon'): 0.0,
#  ('nifedipin', 'retic'): 1.0,
#  ('aricept', 'hilum'): 0.0,
#  ('bipolar', 'gastriti'): 1.0,
#  ('cmo', 'news'): 0.0,
#  ('aricept', 'norepinephrin'): 1.0,
#  ('aox', 'dnr'): 1.0,
#  ('arrest', 'pulseless'): 0.0,
#  ('osa', 'pericard'): 1.0,
#  ('dic', 'gadolinium'): 1.0,
#  ('adenocarcinoma', 'peribronchovascular'): 1.0,
#  ('hive', 'profound'): 1.0,
#  ('freeli', 'gastrojejunostomi'): 1.0,
#  ('asthma', 'mellitu'): 1.0,
#  ('gastriti', 'laminectomi'): 1.0,
#  ('moan', 'occurr'): 1.0,
#  ('dni', 'tcdb'): 1.0,
#  ('hypothermia', 'sensat'): 1.0,
#  ('captopril', 'sibl'): 1.0,
#  ('phenylephrin', 'unrel'): 0.0,
#  ('banana', 'rememb'): 1.0,
#  ('sweat', 'vagu'): 1.0,
#  ('hive', 'stitch'): 1.0,
#  ('align', 'myeloma'): 1.0,
#  ('conc', 'wish'): 1.0,
#  ('futil', 'hypotherm'): 0.0,
#  ('syncop', 'thiamin'): 1.0,
#  ('hospic', 'weekli'): 1.0,
#  ('bottl', 'leukocyt'): 1.0,
#  ('dnr', 'laryng'): 0.5793162261246866,
#  ('aox', 'prilosec'): 1.0,
#  ('dizzi', 'qtc'): 1.0,
#  ('banana', 'flake'): 1.0,
#  ('habitu', 'osa'): 1.0,
#  ('chair', 'palli'): 1.0,
#  ('declin', 'vasopressor'): 0.0,
#  ('dnr', 'seroquel'): 1.0,
#  ('asthma', 'ferrou'): 1.0,
#  ('ligament', 'silent'): 0.0,
#  ('chair', 'levoph'): 1.0,
#  ('bill', 'fibrinogen'): 1.0,
#  ('cocain', 'ctx'): 1.0,
#  ('hospic', 'palli'): 0.48074253828001656,
#  ('acc', 'aricept'): 1.0,
#  ('option', 'palli'): 0.39642595708295714,
#  ('iddm', 'uri'): 1.0,
#  ('breakfast', 'phenylephrin'): 1.0,
#  ('foci', 'gastrojejunostomi'): 1.0,
#  ('nectar', 'pharyng'): 1.0,
#  ('dnr', 'strictur'): 1.0,
#  ('levoph', 'scar'): 1.0,
#  ('bottl', 'life'): 1.0,
#  ('muir', 'passey'): 1.0,
#  ('qtc', 'zyprexa'): 1.0,
#  ('anur', 'ggt'): 0.0,
#  ('cagluc', 'vasopressin'): 0.0,
#  ('aricept', 'young'): 1.0,
#  ('death', 'levoph'): 0.0,
#  ('core', 'platelet'): 0.0,
#  ('fc', 'pyuria'): 0.0,
#  ('hunger', 'predict'): 0.0,
#  ('cefapim', 'dnr'): 1.0,
#  ('pca', 'scab'): 1.0,
#  ('ciwa', 'db'): 1.0,
#  ('acidot', 'agon'): 0.0,
#  ('mellitu', 'phlegm'): 1.0,
#  ('money', 'wallet'): 0.6659303754175412,
#  ('life', 'mean'): 1.0,
#  ('bicarbon', 'permiss'): 0.0,
#  ('chair', 'iddm'): 1.0,
#  ('esld', 'venti'): 1.0,
#  ('burn', 'ctx'): 1.0,
#  ('occipit', 'scar'): 1.0,
#  ('ambul', 'sibl'): 1.0,
#  ('nephrolog', 'scar'): 1.0,
#  ('historian', 'ppd'): 1.0,
#  ('cefapim', 'pea'): 1.0,
#  ('asthma', 'led'): 1.0,
#  ('fdp', 'rhinorrhea'): 0.0,
#  ('asthma', 'thiamin'): 1.0,
#  ('bottl', 'oob'): 1.0,
#  ('adam', 'escal'): 0.0,
#  ('vasopressin', 'venti'): 0.0,
#  ('contractur', 'criticar'): 1.0,
#  ('cvvhd', 'hugger'): 0.0,
#  ('hemangioma', 'osteoblast'): 1.0,
#  ('anur', 'levoph'): 0.5585582289526342,
#  ('dni', 'zoloft'): 0.39994173456925625,
#  ('solut', 'treatement'): 1.0,
#  ('grave', 'mso'): 0.0,
#  ('dni', 'td'): 1.0,
#  ('dnr', 'phenylephrin'): 0.0,
#  ('phlegm', 'pleasant'): 1.0,
#  ('nahco', 'pleasant'): 1.0,
#  ('chip', 'dopamin'): 1.0,
#  ('aricept', 'hive'): 1.0,
#  ('aricept', 'declin'): 1.0,
#  ('habitu', 'occupi'): 1.0,
#  ('nephrolog', 'qam'): 1.0,
#  ('asthma', 'death'): 1.0,
#  ('barium', 'pharyng'): 1.0,
#  ('aprv', 'gvhd'): 0.0,
#  ('dead', 'prilosec'): 1.0,
#  ('im', 'nifedipin'): 1.0,
#  ('itchi', 'nitroglycerin'): 1.0,
#  ('commod', 'dni'): 0.42068377387531336,
#  ('chair', 'cramp'): 1.0,
#  ('ambul', 'spill'): 1.0,
#  ('clonidin', 'ultrafiltr'): 1.0,
#  ('dni', 'rigor'): 1.0,
#  ('ferritin', 'ferrou'): 1.0,
#  ('asthma', 'young'): 1.0,
#  ('pneumococc', 'subq'): 1.0,
#  ('cocain', 'klonopin'): 1.0,
#  ('laminectomi', 'weekli'): 1.0,
#  ('dead', 'mso'): 0.0,
#  ('puff', 'rehabilit'): 1.0,
#  ('dni', 'neosynephrin'): 0.5339446614836325,
#  ('levoph', 'pleasant'): 1.0,
#  ('dnr', 'dyslipidemia'): 1.0,
#  ('hive', 'platelet'): 0.0,
#  ('bicarbon', 'cpr'): 0.0,
#  ('dni', 'dnr'): 0.552589320552786,
#  ('foci', 'habitu'): 1.0,
#  ('dietari', 'video'): 1.0,
#  ('gabapentin', 'omeprazol'): 1.0,
#  ('life', 'pleasant'): 0.0,
#  ('asthma', 'life'): 1.0,
#  ('asthma', 'rhinorrhea'): 1.0,
#  ('angiogram', 'gadolinium'): 1.0,
#  ('asystol', 'autopsi'): 0.0,
#  ('^th', 'dnr'): 1.0,
#  ('death', 'nifedipin'): 1.0,
#  ('epigastr', 'hsq'): 1.0,
#  ('expir', 'hilum'): 1.0,
#  ('conc', 'dnr'): 1.0,
#  ('ba', 'romi'): 1.0,
#  ('captopril', 'oob'): 1.0,
#  ('dni', 'rhinorrhea'): 0.5243016245872928,
#  ('death', 'oob'): 1.0,
#  ('dnr', 'itchi'): 0.2583666606758675,
#  ('levoph', 'modifi'): 1.0,
#  ('mood', 'suprapub'): 1.0,
#  ('option', 'pleasant'): 1.0,
#  ('breakfast', 'olanzapin'): 1.0,
#  ('angri', 'declin'): 1.0,
#  ('autopsi', 'wish'): 0.0,
#  ('im', 'omeprazol'): 1.0,
#  ('life', 'ppd'): 1.0,
#  ('deterior', 'option'): 0.0,
#  ('fu', 'xl'): 1.0,
#  ('chair', 'predict'): 1.0,
#  ('gabapentin', 'habitu'): 1.0,
#  ('dnr', 'pinpoint'): 0.0,
#  ('chb', 'hemothorax'): 0.0,
#  ('gvhd', 'pleasant'): 1.0,
#  ('epigastr', 'scar'): 1.0,
#  ('oob', 'zyprexa'): 1.0,
#  ('mso', 'wish'): 0.0,
#  ('bill', 'bromid'): 1.0,
#  ('lat', 'pericard'): 1.0,
#  ('mortem', 'sluggish'): 0.0,
#  ('dnr', 'prognosi'): 0.30508477749192414,
#  ('homogen', 'slice'): 1.0,
#  ('epigastr', 'splint'): 1.0,
#  ('arrest', 'passi'): 1.0,
#  ('hilum', 'peribronchovascular'): 0.5,
#  ('dni', 'romi'): 0.7366025646506588,
#  ('fatti', 'flight'): 1.0,
#  ('rhinorrhea', 'xl'): 1.0,
#  ('sluggish', 'viabl'): 0.0,
#  ('morbid', 'uri'): 1.0,
#  ('agon', 'deterior'): 0.0,
#  ('gait', 'rememb'): 1.0,
#  ('articul', 'cup'): 1.0,
#  ('asthma', 'barium'): 1.0,
#  ('osa', 'qam'): 1.0,
#  ('seroquel', 'vp'): 1.0,
#  ('young', 'zero'): 1.0,
#  ('fdp', 'fibrinogen'): 0.0,
#  ('prilosec', 'robitussin'): 1.0,
#  ('ciwa', 'itchi'): 1.0,
#  ('cmo', 'expir'): 0.0,
#  ('autoset', 'levoph'): 1.0,
#  ('ppd', 'precordium'): 1.0,
#  ('barium', 'silent'): 1.0,
#  ('aricept', 'colonoscopi'): 1.0,
#  ('omeprazol', 'strictur'): 1.0,
#  ('itchi', 'quinolon'): 1.0,
#  ('permiss', 'pleasant'): 1.0,
#  ('ctx', 'hugger'): 1.0,
#  ('arrest', 'dic'): 0.0,
#  ('declin', 'levoph'): 0.31529791710476945,
#  ('ppn', 'readmit'): 1.0,
#  ('epigastr', 'homogen'): 1.0,
#  ('norepinephrin', 'sluggishli'): 0.0,
#  ('fibrinogen', 'wish'): 1.0,
#  ('ferritin', 'ppd'): 1.0,
#  ('aox', 'oncologist'): 1.0,
#  ('laminectomi', 'stitch'): 1.0,
#  ('dead', 'prognosi'): 0.0,
#  ('azotemia', 'diaphoresi'): 1.0,
#  ('dnr', 'tremul'): 1.0,
#  ('hsq', 'mood'): 1.0,
#  ('peac', 'prognosi'): 0.0,
#  ('ligament', 'smooth'): 1.0,
#  ('hemangioma', 'smooth'): 1.0,
#  ('dnr', 'lpm'): 0.0,
#  ('lat', 'ppd'): 1.0,
#  ('oncologist', 'young'): 1.0,
#  ('ppd', 'rpr'): 1.0,
#  ('maroon', 'reguard'): 1.0,
#  ('oligur', 'seriou'): 0.0,
#  ('aaox', 'moan'): 1.0,
#  ('bottl', 'dni'): 1.0,
#  ('promod', 'wether'): 1.0,
#  ('gurgl', 'moan'): 0.0,
#  ('adenocarcinoma', 'osa'): 1.0,
#  ('dz', 'modifi'): 1.0,
#  ('acc', 'subcost'): 1.0,
#  ('klonopin', 'led'): 1.0,
#  ('bill', 'mellitu'): 1.0,
#  ('anuria', 'levoph'): 0.0,
#  ('omeprazol', 'tremul'): 1.0,
#  ('dni', 'ffp'): 0.32101889193715044,
#  ('refractori', 'resucit'): 1.0,
#  ('pleasant', 'scab'): 1.0,
#  ('rusti', 'vasopressor'): 0.0,
#  ('nocturn', 'trazodon'): 1.0,
#  ('ambien', 'mva'): 1.0,
#  ('autopeep', 'bicarbon'): 0.0,
#  ('ctx', 'trazodon'): 1.0,
#  ('cloth', 'money'): 0.6727559518802089,
#  ('hypotherm', 'neosynephrin'): 0.0,
#  ('depth', 'diaphoresi'): 1.0,
#  ('declin', 'life'): 1.0,
#  ('ipf', 'robitussin'): 0.0,
#  ('acetazolamid', 'suffer'): 1.0,
#  ('chair', 'neo'): 1.0,
#  ('ciwa', 'crack'): 1.0,
#  ('asthma', 'corneal'): 0.0,
#  ('dnr', 'forc'): 0.0,
#  ('arrest', 'hung'): 0.0,
#  ('captopril', 'mellitu'): 1.0,
#  ('dni', 'pericard'): 1.0,
#  ('romi', 'trazodon'): 1.0,
#  ('nitroglycerin', 'oob'): 1.0,
#  ('osa', 'pleasant'): 1.0,
#  ('pleasant', 'pneumococc'): 1.0,
#  ('ntnd', 'zoloft'): 1.0,
#  ('cpr', 'hypercapnia'): 0.0,
#  ('adam', 'declin'): 0.0,
#  ('ambien', 'pca'): 1.0,
#  ('barium', 'mottl'): 1.0,
#  ('plate', 'requr'): 1.0,
#  ('recalibr', 'video'): 1.0,
#  ('arrest', 'pcv'): 0.0,
#  ('gurgl', 'sundown'): 0.0,
#  ('gastriti', 'xii'): 1.0,
#  ('bottl', 'unavail'): 1.0,
#  ('declin', 'oob'): 1.0,
#  ('pcv', 'vasopressin'): 0.0,
#  ('cyanot', 'fungemia'): 0.0,
#  ('fatti', 'pca'): 1.0,
#  ('ferrou', 'unavail'): 1.0,
#  ('aliv', 'paperwork'): 1.0,
#  ('ambien', 'myeloma'): 1.0,
#  ('arrest', 'deterior'): 1.0,
#  ('peribronchovascular', 'pericard'): 1.0,
#  ('conc', 'mso'): 0.0,
#  ('pleasant', 'rigor'): 1.0,
#  ('ipf', 'oob'): 0.0,
#  ('aricept', 'qam'): 0.0,
#  ('autoset', 'commod'): 1.0,
#  ('dizzi', 'sundown'): 1.0,
#  ('compani', 'pleasant'): 1.0,
#  ('contd', 'refractori'): 1.0,
#  ('eg', 'foci'): 1.0,
#  ('dic', 'ferritin'): 1.0,
#  ('adenocarcinoma', 'laminectomi'): 1.0,
#  ('echocardiogram', 'xl'): 1.0,
#  ('clonazepam', 'trazodon'): 1.0,
#  ('gait', 'mood'): 1.0,
#  ('aox', 'ctx'): 1.0,
#  ('sibl', 'subq'): 1.0,
#  ('palli', 'predict'): 1.0,
#  ('ciwa', 'signatur'): 1.0,
#  ('mellitu', 'mood'): 1.0,
#  ('acidot', 'sluggish'): 0.0,
#  ('ffp', 'mso'): 1.0,
#  ('ambul', 'palli'): 0.0,
#  ('nectar', 'silent'): 1.0,
#  ('cracker', 'dnr'): 1.0,
#  ('im', 'rhinorrhea'): 1.0,
#  ('escal', 'seroquel'): 1.0,
#  ('nahco', 'vasopressin'): 0.0,
#  ('herp', 'stair'): 1.0,
#  ('pea', 'vasopressin'): 0.0,
#  ('hive', 'lat'): 1.0,
#  ('acidot', 'ffp'): 0.0,
#  ('dni', 'dz'): 1.0,
#  ('neo', 'tacycard'): 1.0,
#  ('assymetr', 'ppd'): 1.0,
#  ('ipf', 'tachpnea'): 1.0,
#  ('artifici', 'gait'): 0.0,
#  ('pea', 'rhinorrhea'): 1.0,
#  ('mellitu', 'rigor'): 1.0,
#  ('cash', 'crack'): 1.0,
#  ('chair', 'dizzi'): 1.0,
#  ('bronchovascular', 'habitu'): 1.0,
#  ('appi', 'dnr'): 1.0,
#  ('hsq', 'intent'): 1.0,
#  ('dnr', 'escal'): 0.5914906184373718,
#  ('phlegm', 'wish'): 0.0,
#  ('autoset', 'bipolar'): 1.0,
#  ('norepinephrin', 'permiss'): 0.0,
#  ('diaphoresi', 'dietari'): 1.0,
#  ('paperwork', 'sweat'): 1.0,
#  ('hilum', 'treitz'): 1.0,
#  ('breakfast', 'burn'): 1.0,
#  ('ciwa', 'cloth'): 1.0,
#  ('dnr', 'ffp'): 0.42068377387531336,
#  ('ardsnet', 'permiss'): 0.0,
#  ('burn', 'lusb'): 1.0,
#  ('oob', 'sooner'): 1.0,
#  ('oob', 'strictur'): 1.0,
#  ('ambul', 'asthma'): 1.0,
#  ('aox', 'venti'): 1.0,
#  ('incis', 'sibl'): 1.0,
#  ('dni', 'lift'): 1.0,
#  ('mind', 'paperwork'): 1.0,
#  ('paperwork', 'vasopressor'): 0.0,
#  ('laminectomi', 'unobtain'): 1.0,
#  ('contd', 'ctx'): 1.0,
#  ('jewelri', 'wallet'): 0.6659303754175412,
#  ('ciwa', 'fatti'): 1.0,
#  ('clonazepam', 'platelet'): 1.0,
#  ('vasopressin', 'wma'): 0.0,
#  ('dni', 'forc'): 0.0,
#  ('lat', 'moreov'): 1.0,
#  ('oob', 'pose'): 1.0,
#  ('gait', 'motor'): 1.0,
#  ('ambien', 'clonazepam'): 1.0,
#  ('readmit', 'trazodon'): 1.0,
#  ('schistocyt', 'young'): 1.0,
#  ('endplat', 'para'): 0.0,
#  ('autopeep', 'pcv'): 0.0,
#  ('smooth', 'vertebra'): 0.5,
#  ('depth', 'levoph'): 1.0,
#  ('led', 'mellitu'): 1.0,
#  ('ofm', 'unsteadi'): 1.0,
#  ('aaox', 'dnr'): 0.6161320073290462,
#  ('corneal', 'levoph'): 0.0,
#  ('probe', 'viscou'): 1.0,
#  ('permiss', 'pose'): 1.0,
#  ('natg', 'occipit'): 1.0,
#  ('dic', 'impli'): 1.0,
#  ('barium', 'panic'): 1.0,
#  ('platelet', 'scar'): 1.0,
#  ('asthma', 'chair'): 0.6516986494486501,
#  ('binder', 'dni'): 1.0,
#  ('ferritin', 'trazodon'): 1.0,
#  ('hospic', 'rm'): 1.0,
#  ('exophyt', 'pyuria'): 0.0,
#  ('moan', 'profound'): 0.0,
#  ('declin', 'platelet'): 0.5,
#  ('asthma', 'bromid'): 1.0,
#  ('criticar', 'dnr'): 1.0,
#  ('cefapim', 'pleasant'): 1.0,
#  ('adam', 'prognosi'): 0.0,
#  ('omeprazol', 'sweat'): 1.0,
#  ('diaphoresi', 'phlegm'): 1.0,
#  ('calculi', 'intent'): 1.0,
#  ('anaphylaxi', 'schizophrenia'): 1.0,
#  ('dnr', 'lat'): 1.0,
#  ('cloth', 'signatur'): 0.6847020828952306,
#  ('judgement', 'rememb'): 1.0,
#  ('centimet', 'homogen'): 1.0,
#  ('caspofungin', 'fibrinogen'): 1.0,
#  ('phenylephrin', 'ruptur'): 1.0,
#  ('hive', 'hypercapnia'): 1.0,
#  ('declin', 'dni'): 0.6873975401893274,
#  ('mrg', 'thrive'): 1.0,
#  ('diflucan', 'hive'): 1.0,
#  ('chair', 'unasyn'): 0.4595846302788977,
#  ('exophyt', 'slice'): 1.0,
#  ('dnr', 'mean'): 0.0,
#  ('dex', 'levoph'): 1.0,
#  ('gastriti', 'ultram'): 1.0,
#  ('oob', 'pleasant'): 1.0,
#  ('bank', 'fax'): 1.0,
#  ('ipf', 'vasopressin'): 0.0,
#  ('ba', 'phlegm'): 1.0,
#  ('crrt', 'ffp'): 0.0,
#  ('cdb', 'chair'): 1.0,
#  ('cocain', 'phlegm'): 1.0,
#  ('neo', 'neosynephrin'): 0.0,
#  ('acc', 'im'): 1.0,
#  ('osa', 'young'): 1.0,
#  ('bottl', 'gait'): 1.0,
#  ('ba', 'opiat'): 1.0,
#  ('aox', 'ba'): 1.0,
#  ('asthma', 'lpm'): 1.0,
#  ('ctx', 'modifi'): 1.0,
#  ('ferritin', 'hive'): 1.0,
#  ('arrest', 'trazodon'): 0.0,
#  ('cash', 'diflucan'): 1.0,
#  ('retic', 'wish'): 1.0,
#  ('jejunum', 'tie'): 1.0,
#  ('hive', 'nocturn'): 1.0,
#  ('db', 'myeloma'): 0.0,
#  ('asthma', 'sweat'): 1.0,
#  ('habitu', 'hilum'): 1.0,
#  ('oncologist', 'osa'): 1.0,
#  ('chol', 'stg'): 0.0,
#  ('among', 'bronchovascular'): 1.0,
#  ('burn', 'sensat'): 1.0,
#  ('lusb', 'nifedipin'): 1.0,
#  ('paperwork', 'rusti'): 0.0,
#  ('dopamin', 'nonrebreath'): 1.0,
#  ('dopamin', 'unasyn'): 1.0,
#  ('mood', 'profound'): 1.0,
#  ('anur', 'gentamycin'): 0.0,
#  ('cdb', 'dnr'): 1.0,
#  ('predict', 'unstabl'): 1.0,
#  ('aox', 'ffp'): 1.0,
#  ('rhinorrhea', 'sibl'): 1.0,
#  ('sweat', 'xl'): 1.0,
#  ('bill', 'cvvh'): 1.0,
#  ('freeli', 'scar'): 1.0,
#  ('epigastr', 'suprapub'): 1.0,
#  ('natg', 'scar'): 0.0,
#  ('lpm', 'mellitu'): 1.0,
#  ('asthma', 'intent'): 1.0,
#  ('hospic', 'rigor'): 1.0,
#  ('declin', 'news'): 0.0,
#  ('^th', 'pleasant'): 1.0,
#  ('cash', 'historian'): 1.0,
#  ('dnr', 'lymphangit'): 1.0,
#  ('nocturn', 'osa'): 1.0,
#  ('nicotin', 'schizophrenia'): 1.0,
#  ('slice', 'unenhanc'): 1.0,
#  ('levoph', 'rpr'): 1.0,
#  ('mjmgb', 'pea'): 0.0,
#  ('commod', 'ctx'): 1.0,
#  ('dnr', 'lift'): 1.0,
#  ('gvhd', 'wish'): 1.0,
#  ('led', 'mottl'): 1.0,
#  ('argatroban', 'cvvhd'): 0.0,
#  ('chip', 'venti'): 1.0,
#  ('nifedipin', 'trazodon'): 1.0,
#  ('ethic', 'neo'): 0.0,
#  ('nephrolog', 'nitroglycerin'): 1.0,
#  ('clonidin', 'dnr'): 1.0,
#  ('dopamin', 'xanax'): 1.0,
#  ('anaphylaxi', 'xl'): 1.0,
#  ('gastrojejunostomi', 'sarna'): 1.0,
#  ('azotemia', 'cocain'): 1.0,
#  ('stitch', 'weekli'): 1.0,
#  ('phenylephrin', 'platelet'): 0.0,
#  ('articul', 'rehabilit'): 1.0,
#  ('ambien', 'commod'): 1.0,
#  ('captopril', 'qam'): 1.0,
#  ('acidot', 'cmo'): 0.0,
#  ('burn', 'quadrent'): 1.0,
#  ('coach', 'unavail'): 1.0,
#  ('abnl', 'splint'): 1.0,
#  ('dni', 'unobtain'): 0.5500560933045909,
#  ('motor', 'soln'): 1.0,
#  ('cdb', 'dizzi'): 1.0,
#  ('dnr', 'palliat'): 0.0,
#  ('foci', 'nephrogram'): 0.5,
#  ('chair', 'lotion'): 0.28116114168121026,
#  ('diaphoresi', 'osa'): 1.0,
#  ('adam', 'wish'): 0.0,
#  ('mva', 'wether'): 1.0,
#  ('db', 'rhinorrhea'): 1.0,
#  ('hospic', 'icter'): 1.0,
#  ('klonopin', 'pleasant'): 1.0,
#  ('subq', 'xl'): 1.0,
#  ('cpr', 'paralyt'): 0.0,
#  ('money', 'signatur'): 0.6727559518802089,
#  ('omeprazol', 'pleasant'): 1.0,
#  ('compani', 'prilosec'): 1.0,
#  ('anur', 'prilosec'): 0.0,
#  ('pea', 'trazodon'): 0.0,
#  ('incis', 'strictur'): 1.0,
#  ('hilum', 'ligament'): 1.0,
#  ('foci', 'homogen'): 0.6000582654307438,
#  ('wish', 'xii'): 0.0,
#  ('asystol', 'pronounc'): 0.0,
#  ('nectar', 'pleasant'): 1.0,
#  ('qam', 'seat'): 1.0,
#  ('ambien', 'oob'): 1.0,
#  ('aaox', 'dead'): 0.0,
#  ('declin', 'futil'): 0.0,
#  ('chair', 'moan'): 1.0,
#  ('laryng', 'vagu'): 1.0,
#  ('cvvh', 'synthet'): 1.0,
#  ('behavior', 'harm'): 1.0,
#  ('dni', 'hsq'): 1.0,
#  ('chair', 'cloth'): 1.0,
#  ('contractur', 'dopamin'): 0.0,
#  ('dnr', 'plerual'): 0.0,
#  ('dd', 'dnr'): 1.0,
#  ('neosynephrin', 'unrel'): 0.0,
#  ('mellitu', 'morbid'): 1.0,
#  ('crrt', 'fibrinogen'): 0.0,
#  ('gabapentin', 'gait'): 1.0,
#  ('dizzi', 'xl'): 1.0,
#  ('brb', 'pea'): 1.0,
#  ('dni', 'lat'): 1.0,
#  ('echocardiogram', 'palli'): 0.0,
#  ('cup', 'nectar'): 1.0,
#  ('silent', 'treitz'): 0.0,
#  ('ggt', 'rhinorrhea'): 0.0,
#  ('foci', 'peribronchovascular'): 0.5,
#  ('mso', 'oob'): 1.0,
#  ('ffp', 'wish'): 1.0,
#  ('anaphylaxi', 'asthma'): 1.0,
#  ('barium', 'osa'): 1.0,
#  ('aricept', 'distanc'): 1.0,
#  ('jerk', 'sluggish'): 0.0,
#  ('dni', 'nephrolog'): 0.40956706442769103,
#  ('argatroban', 'levoph'): 0.0,
#  ('levoph', 'triadyn'): 1.0,
#  ('asystol', 'pulseless'): 0.0,
#  ('core', 'icter'): 0.0,
#  ('bicarbon', 'laminectomi'): 1.0,
#  ('bair', 'dopamin'): 0.0,
#  ('hctz', 'subq'): 1.0,
#  ('mood', 'nocturn'): 1.0,
#  ('gabapentin', 'opiat'): 1.0,
#  ('herp', 'hive'): 1.0,
#  ('asthma', 'pneumococc'): 1.0,
#  ('venti', 'xanax'): 1.0,
#  ('vallecula', 'video'): 1.0,
#  ('pharmacolog', 'splint'): 1.0,
#  ('im', 'sibl'): 1.0,
#  ('mind', 'prilosec'): 1.0,
#  ('dnr', 'lc'): 0.0,
#  ('aox', 'oob'): 1.0,
#  ('crack', 'dizzi'): 1.0,
#  ('bottl', 'seriou'): 1.0,
#  ('spill', 'vallecula'): 1.0,
#  ('foci', 'pronounc'): 1.0,
#  ('incent', 'nonrebreath'): 1.0,
#  ('retic', 'zero'): 1.0,
#  ('adenocarcinoma', 'laryng'): 1.0,
#  ('im', 'retic'): 1.0,
#  ('gait', 'hive'): 1.0,
#  ('mellitu', 'scar'): 1.0,
#  ('ambul', 'captopril'): 1.0,
#  ('fibrinogen', 'hemothorax'): 0.0,
#  ('lotion', 'moan'): 1.0,
#  ('burn', 'tran'): 1.0,
#  ('historian', 'rhinorrhea'): 1.0,
#  ('commod', 'ofm'): 1.0,
#  ('impli', 'slice'): 1.0,
#  ('ruptur', 'seroquel'): 1.0,
#  ('lat', 'qtc'): 1.0,
#  ('mso', 'rememb'): 1.0,
#  ('commod', 'option'): 1.0,
#  ('ctx', 'phlegm'): 1.0,
#  ('historian', 'young'): 1.0,
#  ('hive', 'lusb'): 1.0,
#  ('compani', 'laminectomi'): 1.0,
#  ('neo', 'norepinephrin'): 0.31000631401892015,
#  ('hctz', 'palli'): 1.0,
#  ('calculi', 'habitu'): 1.0,
#  ('declin', 'rabbi'): 0.0,
#  ('dnr', 'suffer'): 0.8477075472756392,
#  ('aaox', 'dz'): 1.0,
#  ('burn', 'nicotin'): 1.0,
#  ('fu', 'mrg'): 1.0,
#  ('aprv', 'dnr'): 0.0,
#  ('mellitu', 'prilosec'): 1.0,
#  ('ashen', 'scar'): 1.0,
#  ('autopeep', 'hypercapnia'): 0.0,
#  ('dnr', 'option'): 0.3783280139680622,
#  ('qam', 'schizophrenia'): 1.0,
#  ('cpr', 'hypothermia'): 0.0,
#  ('subq', 'sweat'): 1.0,
#  ('herp', 'pleasant'): 1.0,
#  ('hypothermia', 'pcv'): 0.0,
#  ('thrive', 'vagu'): 1.0,
#  ('oncologist', 'pea'): 1.0,
#  ('dni', 'xanax'): 1.0,
#  ('clonazepam', 'dnr'): 1.0,
#  ('neoplast', 'rescan'): 1.0,
#  ('calculi', 'omeprazol'): 1.0,
#  ('scar', 'trazodon'): 1.0,
#  ('ffp', 'hypotherm'): 0.0,
#  ('lw', 'twitch'): 0.0,
#  ('commod', 'pose'): 1.0,
#  ('ntnd', 'scar'): 1.0,
#  ('chair', 'commod'): 0.6101275573306996,
#  ('declin', 'peac'): 0.0,
#  ('lymphangit', 'soln'): 1.0,
#  ('hypothermia', 'pea'): 0.0,
#  ('declin', 'oncologist'): 1.0,
#  ('gait', 'pea'): 0.0,
#  ('fatti', 'slice'): 1.0,
#  ('ambul', 'xopenex'): 1.0,
#  ('pathologist', 'vallecula'): 1.0,
#  ('ambul', 'msicu'): 1.0,
#  ('hypercapnia', 'pea'): 0.0,
#  ('esoph', 'impli'): 0.0,
#  ('clonazepam', 'pleasant'): 1.0,
#  ('declin', 'dopamin'): 0.0,
#  ('anur', 'mso'): 0.0,
#  ('dnr', 'mellitu'): 1.0,
#  ('levoph', 'tacycard'): 1.0,
#  ('gadolinium', 'impli'): 1.0,
#  ('aox', 'motor'): 1.0,
#  ('dermat', 'rhinorrhea'): 1.0,
#  ('dermat', 'scab'): 1.0,
#  ('aox', 'sibl'): 1.0,
#  ('metoclopramid', 'omeprazol'): 1.0,
#  ('asthma', 'cg'): 0.0,
#  ('expir', 'vasopressin'): 0.0,
#  ('dz', 'postop'): 1.0,
#  ('barium', 'fax'): 1.0,
#  ('rememb', 'thiamin'): 1.0,
#  ('seroquel', 'subdur'): 1.0,
#  ('deterior', 'thrive'): 0.0,
#  ('breakfast', 'recalibr'): 1.0,
#  ('aox', 'dni'): 1.0,
#  ('asthma', 'purpl'): 1.0,
#  ('dnr', 'zyprexa'): 0.6361062373955713,
#  ('epigastr', 'nicotin'): 1.0,
#  ('dietari', 'laminectomi'): 1.0,
#  ('levoph', 'mso'): 0.0,
#  ('osa', 'svn'): 1.0,
#  ('ctx', 'dz'): 1.0,
#  ('escal', 'scopalamin'): 1.0,
#  ('cyanot', 'dni'): 0.0,
#  ('dni', 'uri'): 1.0,
#  ('chb', 'levoph'): 0.4783248511232286,
#  ('cvvh', 'norepinephrin'): 0.0,
#  ('bill', 'im'): 1.0,
#  ('refractori', 'sarna'): 1.0,
#  ('rememb', 'sibl'): 1.0,
#  ('chb', 'fibrinogen'): 0.4832578516998376,
#  ('intiat', 'pronounc'): 0.0,
#  ('mso', 'vasopressin'): 0.0,
#  ('fatti', 'intent'): 1.0,
#  ('dni', 'refractori'): 1.0,
#  ('asystol', 'sacrament'): 0.0,
#  ('banana', 'gabapentin'): 1.0,
#  ('dz', 'mood'): 1.0,
#  ('palli', 'rigor'): 1.0,
#  ('hypotherm', 'wish'): 0.0,
#  ('asthma', 'gait'): 1.0,
#  ('db', 'hive'): 1.0,
#  ('dopamin', 'scar'): 1.0,
#  ('incent', 'syst'): 1.0,
#  ('mucinex', 'olanzapin'): 1.0,
#  ('rm', 'thiamin'): 1.0,
#  ('grim', 'lc'): 0.0,
#  ('mva', 'thirst'): 1.0,
#  ('palli', 'robitussin'): 0.0,
#  ('cpr', 'sluggish'): 0.0,
#  ('dni', 'jewelri'): 0.47071588729418296,
#  ('led', 'prilosec'): 1.0,
#  ('cocain', 'habitu'): 1.0,
#  ('dyslipidemia', 'hive'): 1.0,
#  ('oncologist', 'town'): 1.0,
#  ('gabapentin', 'gastriti'): 1.0,
#  ('align', 'vertebra'): 1.0,
#  ('pneumococc', 'splint'): 1.0,
#  ('captopril', 'incis'): 1.0,
#  ('qtc', 'tremul'): 1.0,
#  ('exophyt', 'impli'): 1.0,
#  ('anur', 'omeprazol'): 1.0,
#  ('gabapentin', 'vagu'): 1.0,
#  ('rhinorrhea', 'wish'): 1.0,
#  ('cooki', 'nectar'): 1.0,
#  ('gait', 'sarna'): 1.0,
#  ('ctx', 'levoph'): 1.0,
#  ('im', 'mva'): 1.0,
#  ('cocain', 'cramp'): 1.0,
#  ('dnr', 'wallet'): 0.47071588729418296,
#  ('dnr', 'inspit'): 1.0,
#  ('absorb', 'quinolon'): 1.0,
#  ('oob', 'platelet'): 1.0,
#  ('cloth', 'ctx'): 1.0,
#  ('bank', 'epidur'): 1.0,
#  ('bipolar', 'forc'): 0.0,
#  ('bottl', 'gum'): 1.0,
#  ('oob', 'ultram'): 1.0,
#  ('cs', 'tran'): 1.0,
#  ('doen', 'rabbi'): 0.0,
#  ('fibrinogen', 'icter'): 0.0,
#  ('chair', 'spiromet'): 1.0,
#  ('aox', 'esld'): 1.0,
#  ('chip', 'rhochor'): 1.0,
#  ('levoph', 'motil'): 0.0,
#  ('dopamin', 'sluggish'): 0.0,
#  ('caspofungin', 'hive'): 1.0,
#  ('gabapentin', 'jewelri'): 1.0,
#  ('ambul', 'incent'): 1.0,
#  ('bronchovascular', 'uri'): 1.0,
#  ('echocardiogram', 'smooth'): 1.0,
#  ('duski', 'wish'): 0.0,
#  ('aliv', 'rhinorrhea'): 1.0,
#  ('institut', 'outer'): 1.0,
#  ('venti', 'zero'): 1.0,
#  ('ambul', 'sarna'): 1.0,
#  ('azotemia', 'subq'): 1.0,
#  ('azotemia', 'pneumococc'): 1.0,
#  ('gadolinium', 'vertebra'): 1.0,
#  ('bipolar', 'commod'): 1.0,
#  ('dnr', 'dobutamin'): 0.5904329355723089,
#  ('commod', 'xopenex'): 1.0,
#  ('knowledg', 'wish'): 1.0,
#  ('cdb', 'oob'): 1.0,
#  ('hilum', 'osa'): 1.0,
#  ('thrive', 'wish'): 1.0,
#  ('scar', 'treitz'): 1.0,
#  ('prognosi', 'sibl'): 0.0,
#  ('dnr', 'mind'): 1.0,
#  ('epigastr', 'postop'): 1.0,
#  ('aaox', 'incent'): 1.0,
#  ('expir', 'im'): 1.0,
#  ('bill', 'soln'): 1.0,
#  ('venti', 'young'): 1.0,
#  ('icter', 'weekli'): 1.0,
#  ('life', 'trazodon'): 0.0,
#  ('mrg', 'oncologist'): 1.0,
#  ('commod', 'dnr'): 0.42068377387531336,
#  ('bromid', 'compani'): 1.0,
#  ('intent', 'romi'): 1.0,
#  ('dopamin', 'twitch'): 0.0,
#  ('aricept', 'sundown'): 0.0,
#  ('dead', 'phenylephrin'): 0.0,
#  ('chemic', 'pyuria'): 0.0,
#  ('death', 'dopamin'): 0.0,
#  ('pleasant', 'thiamin'): 1.0,
#  ('pneumococc', 'ppd'): 1.0,
#  ('fibrinogen', 'rigor'): 1.0,
#  ('method', 'predict'): 0.0,
#  ('motor', 'oncologist'): 1.0,
#  ('clinician', 'pea'): 0.0,
#  ('anaphylaxi', 'zoloft'): 1.0,
#  ('asthma', 'mva'): 1.0,
#  ('rigor', 'unasyn'): 1.0,
#  ('mellitu', 'pod'): 1.0,
#  ('arrest', 'muir'): 1.0,
#  ('impli', 'peribronchovascular'): 1.0,
#  ('contd', 'deterior'): 1.0,
#  ('ciwa', 'pleasant'): 1.0,
#  ('chair', 'wish'): 1.0,
#  ('epidur', 'gadolinium'): 1.0,
#  ('angioplasti', 'dni'): 1.0,
#  ('spill', 'video'): 1.0,
#  ('ofm', 'oob'): 1.0,
#  ('influenc', 'jerk'): 1.0,
#  ('bipolar', 'habitu'): 1.0,
#  ('readmit', 'scar'): 1.0,
#  ('cyanot', 'hive'): 1.0,
#  ('liw', 'vasopressin'): 0.0,
#  ('clonidin', 'xl'): 1.0,
#  ('hilum', 'unenhanc'): 1.0,
#  ('gadolinium', 'outer'): 1.0,
#  ('dopamin', 'vasopressin'): 0.5708190823810347,
#  ('fatti', 'panic'): 1.0,
#  ('dni', 'lusb'): 0.0,
#  ('acidot', 'fibrinogen'): 0.0,
#  ('cardiovert', 'platelet'): 0.0,
#  ('dnr', 'mood'): 1.0,
#  ('furhter', 'neoplast'): 1.0,
#  ('palli', 'struggl'): 0.0,
#  ('lighthead', 'schizophrenia'): 1.0,
#  ('artifici', 'xl'): 0.0,
#  ('bair', 'levoph'): 0.6995145021917382,
#  ('nifedipin', 'scar'): 1.0,
#  ('esoph', 'hunger'): 0.0,
#  ('laminectomi', 'schizophrenia'): 1.0,
#  ('pronounc', 'sluggish'): 0.0,
#  ('gastriti', 'omeprazol'): 1.0,
#  ('burn', 'xii'): 1.0,
#  ('herp', 'hydralizin'): 1.0,
#  ('asthma', 'herp'): 1.0,
#  ('chair', 'compani'): 1.0,
#  ('cpr', 'expir'): 0.0,
#  ('od', 'rememb'): 1.0,
#  ('fu', 'oncologist'): 1.0,
#  ('ciwa', 'sibl'): 1.0,
#  ('anaphylaxi', 'imbal'): 1.0,
#  ('arthrit', 'cdb'): 1.0,
#  ('asystol', 'morgu'): 0.0,
#  ('historian', 'rememb'): 1.0,
#  ('dead', 'expir'): 0.0,
#  ('fatti', 'spectral'): 0.0,
#  ('herp', 'nitroglycerin'): 1.0,
#  ('prognosi', 'vasoconstrict'): 0.0,
#  ('core', 'declin'): 0.0,
#  ('colonoscopi', 'syncop'): 1.0,
#  ('chair', 'zyprexa'): 1.0,
#  ('clonazepam', 'klonopin'): 1.0,
#  ('pleasant', 'spacer'): 1.0,
#  ('autopeep', 'paralyt'): 0.0,
#  ('dni', 'dobutamin'): 1.0,
#  ('chip', 'scar'): 1.0,
#  ('artifici', 'dni'): 1.0,
#  ('dnr', 'signatur'): 0.47071588729418296,
#  ('pleasant', 'qtc'): 1.0,
#  ('death', 'puff'): 1.0,
#  ('acc', 'declin'): 1.0,
#  ('motor', 'pharyng'): 1.0,
#  ('phenylephrin', 'refractori'): 1.0,
#  ('azotemia', 'pcv'): 0.0,
#  ('ambul', 'hover'): 1.0,
#  ('dead', 'dnr'): 0.0,
#  ('azotemia', 'calculi'): 1.0,
#  ('bottl', 'declin'): 1.0,
#  ('dermat', 'neosynephrin'): 1.0,
#  ('retic', 'venti'): 1.0,
#  ('declin', 'mva'): 1.0,
#  ('aaox', 'aricept'): 0.0,
#  ('dermat', 'dnr'): 0.5243016245872928,
#  ('dizzi', 'incis'): 1.0,
#  ('dni', 'priest'): 0.0,
#  ('clonidin', 'dni'): 1.0,
#  ('silent', 'young'): 1.0,
#  ('dni', 'omeprazol'): 0.6292526583429132,
#  ('bell', 'lpm'): 1.0,
#  ('dopamin', 'vasopressor'): 0.0,
#  ('azotemia', 'hepatobiliari'): 0.0,
#  ('declar', 'deterior'): 0.0,
#  ('aricept', 'money'): 0.0,
#  ('dni', 'quadrent'): 1.0,
#  ('hunger', 'wish'): 1.0,
#  ('panic', 'stair'): 1.0,
#  ('prognosi', 'retic'): 1.0,
#  ('calvarium', 'slice'): 1.0,
#  ('ba', 'intent'): 1.0,
#  ('dnr', 'td'): 1.0,
#  ('subdur', 'vp'): 1.0,
#  ('ipf', 'sensat'): 1.0,
#  ('expir', 'sluggish'): 0.0,
#  ('lymphangit', 'pronounc'): 0.0,
#  ('align', 'plate'): 1.0,
#  ('dni', 'xl'): 1.0,
#  ('gvhd', 'nephrolog'): 1.0,
#  ('klonopin', 'unsteadi'): 1.0,
#  ('subq', 'zoloft'): 1.0,
#  ('dizzi', 'sarna'): 1.0,
#  ('cup', 'oob'): 1.0,
#  ('hive', 'refractori'): 1.0,
#  ('artifici', 'religi'): 0.0,
#  ('option', 'readdress'): 0.0,
#  ('deterior', 'dnr'): 0.5144937456927721,
#  ('nephrolog', 'xii'): 1.0,
#  ('moan', 'qtc'): 1.0,
#  ('anaphylaxi', 'uri'): 1.0,
#  ('gc', 'scl'): 1.0,
#  ('declin', 'dietari'): 1.0,
#  ('crack', 'mycolyt'): 1.0,
#  ('arrest', 'cardiovert'): 0.0,
#  ('dni', 'pea'): 0.0,
#  ('ba', 'qam'): 1.0,
#  ('hive', 'oncologist'): 0.4242033098316862,
#  ('dnr', 'lusb'): 0.0,
#  ('dnr', 'simpli'): 1.0,
#  ...}

# %%
# patient_dead_cooc_df
print(patient_cooc_0)
# Out:
# {111: {('arrest', 'pea'): 5.0, ('cpr', 'pea'): 4.0, ('arrest', 'cpr'): 4.0, ('cpr', 'vasopressin'): 4.0, ('pea', 'vasopressin'): 4.0, ('arrest', 'vasopressin'): 4.0, ('pcv', 'vasopressin'): 2.0, ('cpr', 'pcv'): 2.0, ('pcv', 'pea'): 2.0, ('arrest', 'pcv'): 2.0, ('paralyt', 'pcv'): 2.0, ('paralyt', 'vasopressin'): 2.0, ('cpr', 'paralyt'): 2.0, ('paralyt', 'pea'): 2.0, ('arrest', 'paralyt'): 2.0, ('norepinephrin', 'paralyt'): 2.0, ('norepinephrin', 'pcv'): 2.0, ('norepinephrin', 'vasopressin'): 2.0, ('cpr', 'norepinephrin'): 2.0, ('norepinephrin', 'pea'): 2.0, ('arrest', 'norepinephrin'): 2.0, ('hypothermia', 'norepinephrin'): 2.0, ('hypothermia', 'paralyt'): 2.0, ('hypothermia', 'pcv'): 2.0, ('hypothermia', 'vasopressin'): 2.0, ('cpr', 'hypothermia'): 2.0, ('hypothermia', 'pea'): 2.0, ('arrest', 'hypothermia'): 2.0, ('hypercapnia', 'hypothermia'): 2.0, ('hypercapnia', 'norepinephrin'): 2.0, ('hypercapnia', 'paralyt'): 2.0, ('hypercapnia', 'pcv'): 2.0, ('hypercapnia', 'vasopressin'): 2.0, ('cpr', 'hypercapnia'): 2.0, ('hypercapnia', 'pea'): 2.0, ('arrest', 'hypercapnia'): 2.0, ('dic', 'hypercapnia'): 2.0, ('dic', 'hypothermia'): 2.0, ('dic', 'norepinephrin'): 2.0, ('dic', 'paralyt'): 2.0, ('dic', 'pcv'): 2.0, ('dic', 'vasopressin'): 2.0, ('cpr', 'dic'): 2.0, ('dic', 'pea'): 2.0, ('arrest', 'dic'): 2.0, ('dic', 'phenylephrin'): 2.0, ('hypercapnia', 'phenylephrin'): 2.0, ('hypothermia', 'phenylephrin'): 2.0, ('norepinephrin', 'phenylephrin'): 2.0, ('paralyt', 'phenylephrin'): 2.0, ('pcv', 'phenylephrin'): 2.0, ('phenylephrin', 'vasopressin'): 2.0, ('cpr', 'phenylephrin'): 2.0, ('pea', 'phenylephrin'): 2.0, ('arrest', 'phenylephrin'): 2.0, ('bicarbon', 'phenylephrin'): 2.0, ('bicarbon', 'dic'): 2.0, ('bicarbon', 'hypercapnia'): 2.0, ('bicarbon', 'hypothermia'): 2.0, ('bicarbon', 'norepinephrin'): 2.0, ('bicarbon', 'paralyt'): 2.0, ('bicarbon', 'pcv'): 2.0, ('bicarbon', 'vasopressin'): 2.0, ('bicarbon', 'cpr'): 2.0, ('bicarbon', 'pea'): 2.0, ('arrest', 'bicarbon'): 2.0, ('azotemia', 'bicarbon'): 2.0, ('azotemia', 'phenylephrin'): 2.0, ('azotemia', 'dic'): 2.0, ('azotemia', 'hypercapnia'): 2.0, ('azotemia', 'hypothermia'): 2.0, ('azotemia', 'norepinephrin'): 2.0, ('azotemia', 'paralyt'): 2.0, ('azotemia', 'pcv'): 2.0, ('azotemia', 'vasopressin'): 2.0, ('azotemia', 'cpr'): 2.0, ('azotemia', 'pea'): 2.0, ('arrest', 'azotemia'): 2.0, ('autopeep', 'azotemia'): 2.0, ('autopeep', 'bicarbon'): 2.0, ('autopeep', 'phenylephrin'): 2.0, ('autopeep', 'dic'): 2.0, ('autopeep', 'hypercapnia'): 2.0, ('autopeep', 'hypothermia'): 2.0, ('autopeep', 'norepinephrin'): 2.0, ('autopeep', 'paralyt'): 2.0, ('autopeep', 'pcv'): 2.0, ('autopeep', 'vasopressin'): 2.0, ('autopeep', 'cpr'): 2.0, ('autopeep', 'pea'): 2.0, ('arrest', 'autopeep'): 2.0, ('arrest', 'death'): 3.0, ('death', 'vasopressin'): 2.0, ('cpr', 'death'): 2.0, ('death', 'pea'): 2.0, ('clinician', 'death'): 2.0, ('clinician', 'vasopressin'): 2.0, ('clinician', 'cpr'): 2.0, ('clinician', 'pea'): 2.0, ('arrest', 'clinician'): 2.0, ('profound', 'vasopressin'): 2.0, ('cpr', 'profound'): 2.0, ('pea', 'profound'): 2.0, ('arrest', 'profound'): 2.0, ('death', 'expir'): 2.0, ('arrest', 'expir'): 2.0}, 346: {}, 404: {('death', 'paco'): 1.0}, 546: {('hurt', 'oder'): 1.0, ('historian', 'oder'): 1.0, ('historian', 'hurt'): 1.0}, 618: {}, 705: {('dni', 'dnr'): 2.0, ('cmo', 'dnr'): 2.0}, 726: {}, 1039: {}, 1556: {('dnr', 'mso'): 7.0, ('dni', 'dnr'): 8.0, ('dni', 'mso'): 7.0}, 1872: {}, 1944: {}, 2286: {('cyanot', 'pitressin'): 11.0, ('cyanot', 'incis'): 8.0, ('anur', 'cyanot'): 7.0, ('bair', 'hugger'): 7.0}, 2990: {}, 3055: {}, 3099: {('neo', 'neosynephrin'): 1.0, ('dopamin', 'neosynephrin'): 1.0, ('ffp', 'neo'): 1.0, ('ffp', 'neosynephrin'): 1.0, ('ffp', 'vasopressin'): 1.0, ('neo', 'vasopressin'): 1.0, ('neosynephrin', 'vasopressin'): 1.0, ('levoph', 'vasopressin'): 1.0, ('ffp', 'levoph'): 1.0, ('levoph', 'neo'): 1.0, ('levoph', 'neosynephrin'): 1.0, ('hypotherm', 'levoph'): 1.0, ('hypotherm', 'vasopressin'): ...

# %%
print(patient_node_0)
# Out:
# {111: {'arrest': 6.0, 'pea': 5.0, 'cpr': 4.0, 'vasopressin': 4.0, 'pcv': 2.0, 'paralyt': 2.0, 'norepinephrin': 2.0, 'hypothermia': 2.0, 'hypercapnia': 2.0, 'dic': 2.0, 'phenylephrin': 2.0, 'bicarbon': 2.0, 'azotemia': 2.0, 'autopeep': 2.0, 'death': 3.0, 'clinician': 2.0, 'profound': 2.0, 'expir': 2.0}, 346: {'arrest': 4.0, 'sluggish': 6.0}, 404: {'paco': 1.0, 'death': 1.0}, 546: {'oder': 1.0, 'hurt': 1.0, 'historian': 1.0}, 618: {'video': 2.0}, 705: {'dnr': 5.0, 'dni': 2.0, 'cmo': 5.0, 'mso': 2.0}, 726: {'mso': 3.0, 'dnr': 3.0}, 1039: {'wish': 4.0}, 1556: {'mso': 13.0, 'dnr': 8.0, 'dni': 8.0}, 1872: {'pronounc': 1.0}, 1944: {'arrest': 4.0, 'cvvhd': 5.0}, 2286: {'cyanot': 17.0, 'vasopressin': 14.0, 'levoph': 8.0, 'dnr': 7.0, 'prognosi': 7.0, 'purpl': 10.0, 'mottl': 7.0, 'pitressin': 15.0, 'incis': 10.0, 'anur': 9.0, 'cvvh': 9.0, 'hugger': 7.0, 'bair': 7.0}, 2990: {'chair': 17.0, 'oob': 17.0, 'levoph': 31.0, 'anur': 24.0}, 3055: {'gc': 3.0, 'wish': 3.0, 'cmo': 4.0}, 3099: {'neo': 2.0, 'neosynephrin': 2.0, 'dopamin': 1.0, 'ffp': 2.0, 'vasopressin': 1.0, 'levoph': 1.0, 'hypotherm': 1.0, 'hung': 1.0, 'dic': 1.0, 'cagluc': 1.0, 'suport': 1.0, 'polici': 1.0, 'ethic': 1.0, 'cpr': 1.0}, 3201: {'sluggish': 3.0, 'dopamin': 3.0, 'norepinephrin': 1.0, 'levoph': 1.0, 'unavail': 1.0, 'neo': 2.0, 'pitressin': 1.0, 'vasopressin': 1.0, 'unequ': 1.0, 'pronounc': 1.0, 'nahco': 1.0, 'mortem': 1.0, 'levof': 1.0, 'expir': 1.0, 'cpr': 1.0}, 3526: {'levoph': 2.0, 'dnr': 2.0, 'dni': 2.0, 'laryng': 1.0, 'pronounc': 1.0, 'mso': 1.0, 'jerk': 1.0, 'intiat': 1.0, 'declin': 1.0, 'death': 1.0, 'agon': 1.0}, 3773: {'plate': 1.0, 'mso': 2.0, 'escal': 1.0, 'dopamin': 1.0, 'dnr': 1.0, 'dni': 1.0, 'cmo': 1.0, 'pronounc': 1.0, 'death': 1.0}, 3881: {'dnr': 3.0, 'dni': 3.0, 'cmo': 3.0, 'moan': 2.0, 'sluggish': 2.0}, 4122: {}, 4754: {'levoph': 11.0, 'dobutamin': 10.0, 'captopril': 17.0}, 4811: {'life': 2.0, 'dnr': 2.0, 'dni': 2.0, 'hospic': 2.0}, 5476: {}, 5494: {'dnr': 2.0, 'dni': 2.0, 'wish': 2.0, 'escal': 2.0, 'video': 2.0}, 5774: {'levoph': 13.0, 'neo': 11.0, 'cvvhd': 11.0, 'sluggish': 9.0, 'pneumococc': 13.0, 'hugger': 12.0, 'cpr': 12.0}, 5786: {'dobutamin': 9.0}, 5913: {}, 6133: {'lc': 6.0}, 6735: {'prognosi': 3.0, 'dopamin': 3.0, 'mottl': 2.0, 'mso': 2.0, 'levoph': 2.0, 'cpr': 2.0, 'grave': 2.0}, 6745: {'dnr': 4.0, 'dni': 4.0, 'mso': 2.0, 'wish': 1.0, 'heroic': 1.0, 'rabbi': 1.0, 'profound': 1.0, 'moan': 1.0}, 6973: {'dnr': 3.0, 'dni': 3.0}, 6981: {'lat': 1.0, 'occupi': 1.0, 'dnr': 2.0, 'dni': 2.0, 'pleuravac': 1.0, 'priest': 1.0}, 7277: {'neo': 6.0, 'mso': 14.0}, 7310: {'hospic': 3.0, 'dnr': 3.0, 'dni': 3.0, 'nonrebreath': 1.0, 'palliat': 2.0, 'opinion': 2.0, 'sacrament': 1.0, 'peac': 1.0, 'prognosi': 1.0}, 7924: {'neo': 1.0, 'wish': 1.0, 'reveiw': 1.0}, 7977: {'neo': 3.0, 'levoph': 2.0}, 9908: {'levof': 1.0, 'neosynephrin': 1.0, 'levoph': 1.0, 'intiat': 1.0, 'dnr': 1.0, 'dni': 1.0, 'agon': 1.0, 'cmo': 2.0}, 9984: {'levoph': 4.0, 'incis': 2.0, 'hugger': 2.0}, 10302: {'levoph': 56.0, 'dnr': 41.0, 'hive': 39.0, 'fibrinogen': 39.0, 'platelet': 36.0, 'hemothorax': 36.0, 'chb': 29.999999999999996, 'suffer': 26.0, 'norepinephrin': 17.0, 'dic': 31.0, 'abruptli': 18.0}, 10510: {'xopenex': 7.000000000000001}, 10545: {'gvhd': 2.0, 'dopamin': 2.0, 'cyanot': 1.0, 'eyelid': 1.0, 'fungemia': 1.0, 'furhter': 1.0, 'lw': 1.0, 'twitch': 1.0, 'ambul': 1.0, 'vasopressin': 1.0, 'cmo': 1.0, 'levoph': 1.0, 'vasoconstrict': 1.0, 'liw': 1.0, 'mso': 1.0, 'pose': 1.0, 'prognosi': 1.0, 'sibl': 1.0, 'unstabl': 1.0, 'asystol': 1.0, 'dead': 1.0, 'pronounc': 1.0, 'autopsi': 1.0}, 10642: {'scar': 1.0, 'centimet': 1.0, 'dnr': 4.0, 'dni': 3.0, 'mso': 1.0, 'gasp': 1.0, 'prognosi': 1.0, 'moan': 1.0}, 11049: {'neo': 6.0, 'lw': 2.0, 'phenylephrin': 2.0}, 11209: {'subdur': 1.0, 'deterior': 1.0, 'dni': 3.0, 'dnr': 3.0, 'vasopressor': 1.0, 'bair': 1.0, 'dopamin': 1.0, 'hugger': 1.0, 'hypotherm': 1.0, 'hypothermia': 1.0, 'levoph': 1.0, 'paperwork': 1.0, 'rusti': 1.0, 'sluggish': 1.0, 'wish': 1.0, 'arre ...

# %%
# Check if all nodes has embeddings
patient_node_set = set()
patient_node_0_dict = {}
patient_node_1_dict = {}
    
for k, v in patient_node_0.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_0_dict:
            patient_node_0_dict[item] = v[item]
        else:
            patient_node_0_dict[item] = patient_node_0_dict[item] + v[item]
        
    
for k, v in patient_node_1.items():
    for item in v:
        patient_node_set.add(item)
        
        if item not in patient_node_1_dict:
            patient_node_1_dict[item] = v[item]
        else:
            patient_node_1_dict[item] = patient_node_1_dict[item] + v[item]

# %%
print(len(patient_node_set))
print(len(patient_node_0_dict))
print(len(patient_node_1_dict))
# Out:
# 633
# 379
# 571

# %%
patient_node_odd_scores = {}

for set_item in patient_node_set:
    if set_item in patient_node_0_dict and set_item in patient_node_1_dict:
        d_prob = patient_node_0_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        a_prob = patient_node_1_dict[set_item]/(patient_node_0_dict[set_item] + patient_node_1_dict[set_item])
        log_odd_score = math.log((a_prob + 0.001)/(d_prob+0.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_0_dict:
        log_odd_score = math.log((0.001)/(1.001))
        patient_node_odd_scores[set_item] = log_odd_score
    elif set_item in patient_node_1_dict:
        log_odd_score = math.log((1.001)/(0.001))
        patient_node_odd_scores[set_item] = log_odd_score

# %%
print(patient_node_odd_scores)
# Out:
# {'news': -6.90875477931522, 'od': 6.90875477931522, 'death': -0.6916505477038827, 'hurt': 2.2927445483990123, 'treatement': 6.90875477931522, 'unobtain': 1.095952712632351, 'muir': 6.90875477931522, 'ultrafiltr': 6.90875477931522, 'dnr': 0.8878077019401656, 'crowd': 2.0716061679700735, 'osa': 3.0298720743851866, 'town': 2.9256884298210646, 'mind': 6.90875477931522, 'natg': 0.1332640725070919, 'hugger': -0.9072953759720636, 'ctx': 4.020284968191801, 'bronchovascular': 1.9739225981769513, 'argatroban': -0.8013676005646301, 'dietari': 6.90875477931522, 'gastrojejunostomi': 1.4998139424623853, 'deploy': 1.604655121332035, 'db': 1.7755423620716917, 'pneumothorac': 0.4585825764835029, 'moan': 1.0548445068920116, 'moreov': 6.90875477931522, 'pericard': 6.90875477931522, 'oximetri': 6.90875477931522, 'sluggish': 0.5836985542843016, 'pyuria': -0.46903068451456725, 'bmx': 6.90875477931522, 'cvvh': -0.02545138452962548, 'arthrit': 6.90875477931522, 'perpher': 1.9390841839849136, 'paralyt': 0.26516657679136335, 'chair': 1.8559553610868105, 'bell': 6.90875477931522, 'goc': 0.3357879300251662, 'metoclopramid': 6.90875477931522, 'klonopin': 6.90875477931522, 'osteoblast': -0.6916505477038827, 'iddm': 6.90875477931522, 'adenocarcinoma': 3.112820623527696, 'ran': 6.90875477931522, 'park': 6.90875477931522, 'knowledg': 6.90875477931522, 'ardsnet': 0.6460928627110164, 'fliud': -6.90875477931522, 'assymetr': 0.9141958635336067, 'yankuer': 6.90875477931522, 'nice': 6.90875477931522, 'tremul': 6.90875477931522, "tf'ing": 6.90875477931522, 'xanax': 6.90875477931522, 'hilum': 1.604655121332035, 'rehabilit': 6.90875477931522, 'sensat': 3.269258198656955, 'pivot': 1.0092206328555815, 'msicu': 6.90875477931522, 'nonrebreath': 2.513398374617902, 'hydralizin': 6.90875477931522, 'sooner': 6.90875477931522, 'para': 3.464102558012661, 'respon': 6.90875477931522, 'cisatracurium': -0.9533015672059649, 'derecruit': -6.90875477931522, 'nitroglycerin': 6.90875477931522, 'palli': 0.29299432963307714, 'hypercapnia': -2.014895675944767, 'cardiovert': 0.08876971262771659, 'adam': -6.90875477931522, 'angiogram': 6.90875477931522, 'duski': -0.809128888289493, 'splint': 6.90875477931522, 'clergi': -6.90875477931522, 'ashen': 6.90875477931522, 'nephrogram': 1.095952712632351, 'religi': -6.90875477931522, 'plate': 1.7859498421315991, 'transmitr': 2.24195119354922, 'sweat': 6.90875477931522, 'agreement': -6.90875477931522, 'money': 2.5001408943598484, 'acetazolamid': 6.90875477931522, 'artifici': 0.7560249394646842, 'unstabl': 1.423202222234302, 'lat': 2.781918475709505, 'underpenetr': 0.586544924532355, 'ethic': -6.90875477931522, 'pinpoint': -2.473073171472692, 'seat': 1.4311353280322385, 'funer': 6.90875477931522, 'ambul': 2.5039471607851587, 'core': -0.2870999276476155, 'aox': 2.6932429501279174, 'oob': 2.076437778177246, 'acv': 6.90875477931522, 'ccn': -6.90875477931522, 'nifedipin': 2.4270957194435745, 'anaphylaxi': 1.5932198549292915, 'commod': 1.8085373893992105, 'mortem': -6.90875477931522, 'shorter': 0.8734901684270467, 'ggt': 1.9390841839849136, 'bottl': 0.7376251128347686, 'uri': 6.90875477931522, 'friction': 6.90875477931522, 'platelet': 0.3856263430639195, 'puff': 6.90875477931522, 'among': -0.6916505477038827, 'absorb': 6.90875477931522, 'postop': 2.6598359419686672, 'modifi': 6.90875477931522, 'soln': 6.90875477931522, 'epigastr': 6.90875477931522, 'stack': -6.90875477931522, 'diflucan': 0.5378679732223675, 'spirit': 6.90875477931522, 'familt': -6.90875477931522, 'lusb': 1.3314749107825283, 'hung': -1.095952712632351, 'wish': 0.30117515279635937, 'peribronchovascular': 2.1317280276818393, 'agonist': 6.90875477931522, 'rsrc': 6.90875477931522, 'ration': 6.90875477931522, 'mycolyt': 6.90875477931522, 'acidot': 3.213562170762998, 'corneal': -6.90875477931522, 'jewelri': 2.625239572123001, 'appi': 6.90875477931522, 'hsq': 1.9624460326754531, 'levoph': 0.18239584456003188, 'vasoconstrict': -6.90875477931522, 'epidur': 6.90875477931522, 'forth': 6.90875477931522, ...

# %%
patient_square_node_data = pd.DataFrame({'node':list(patient_node_odd_scores.keys()), 'feature':list(patient_node_odd_scores.values())})
patient_square_node_data
# Out:
#            node   feature
# 0          news -6.908755
# 1            od  6.908755
# 2         death -0.691651
# 3          hurt  2.292745
# 4    treatement  6.908755
# ..          ...       ...
# 628  contractur  2.899512
# 629      hunger -1.865483
# 630          eg  6.908755
# 631    autopeep -6.908755
# 632       retic  6.908755
#
# [633 rows x 2 columns]

# %%
patient_square_node_id_data = patient_square_node_data.set_index("node")
patient_square_node_id_data['subject'] = ["positive" if r['feature'] > 0 else "negative" for i, r in patient_square_node_id_data.iterrows()]
patient_square_node_id_data
# Out:
#              feature   subject
# node
# news       -6.908755  negative
# od          6.908755  positive
# death      -0.691651  negative
# hurt        2.292745  positive
# treatement  6.908755  positive
# ...              ...       ...
# contractur  2.899512  positive
# hunger     -1.865483  negative
# eg          6.908755  positive
# autopeep   -6.908755  negative
# retic       6.908755  positive
#
# [633 rows x 2 columns]

# %%
patient_subjects = patient_square_node_id_data["subject"]
patient_subjects
# Out:
# node
# news          negative
# od            positive
# death         negative
# hurt          positive
# treatement    positive
#                 ...
# contractur    positive
# hunger        negative
# eg            positive
# autopeep      negative
# retic         positive
# Name: subject, Length: 633, dtype: object

# %%
patient_square_node_data_no_feature = patient_square_node_id_data.drop(columns=["feature","subject"])
patient_square_node_data_no_feature
# Out:
# Empty DataFrame
# Columns: []
# Index: [news, od, death, hurt, treatement, unobtain, muir, ultrafiltr, dnr, crowd, osa, town, mind, natg, hugger, ctx, bronchovascular, argatroban, dietari, gastrojejunostomi, deploy, db, pneumothorac, moan, moreov, pericard, oximetri, sluggish, pyuria, bmx, cvvh, arthrit, perpher, paralyt, chair, bell, goc, metoclopramid, klonopin, osteoblast, iddm, adenocarcinoma, ran, park, knowledg, ardsnet, fliud, assymetr, yankuer, nice, tremul, tf'ing, xanax, hilum, rehabilit, sensat, pivot, msicu, nonrebreath, hydralizin, sooner, para, respon, cisatracurium, derecruit, nitroglycerin, palli, hypercapnia, cardiovert, adam, angiogram, duski, splint, clergi, ashen, nephrogram, religi, plate, transmitr, sweat, agreement, money, acetazolamid, artifici, unstabl, lat, underpenetr, ethic, pinpoint, seat, funer, ambul, core, aox, oob, acv, ccn, nifedipin, anaphylaxi, commod, ...]
#
# [633 rows x 0 columns]

# %%
from sklearn.manifold import TSNE
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
from gensim.models import Word2Vec

# %% [markdown]
# ### Create a bi-directional df

# %%
# with edge weight
bidirect_source = []
bidirect_target = []
edge_weight = []

for item, val in new_patient_cooc_odd_scores.items():
    bidirect_source.extend([item[0], item[1]])
    bidirect_target.extend([item[1], item[0]])
    edge_weight.extend([val, val])
    
print(f"source: {len(bidirect_source)}, target: {len(bidirect_target)}")

weighted_patient_bidirect_square_edge_data = pd.DataFrame(
    {
        "source": bidirect_source,
        "target": bidirect_target,
        "weight": edge_weight,
    })
weighted_patient_bidirect_square_edge_data
# Out:
# source: 13552, target: 13552
#                source    target  weight
# 0             ardsnet    oligur     0.0
# 1              oligur   ardsnet     0.0
# 2                 oob   sundown     1.0
# 3             sundown       oob     1.0
# 4              habitu    phasic     1.0
# ...               ...       ...     ...
# 13547  tracheomalacia      scar     1.0
# 13548         readmit  seroquel     1.0
# 13549        seroquel   readmit     1.0
# 13550          declin     money     1.0
# 13551           money    declin     1.0
#
# [13552 rows x 3 columns]

# %%
# Weighted
G_weighted_patient_bidirect = StellarGraph(
    {"corner": patient_square_node_data_no_feature}, {"line": weighted_patient_bidirect_square_edge_data}
)
print(G_weighted_patient_bidirect.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 633, Edges: 13552
#
#  Node types:
#   corner: [633]
#     Features: none
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [13552]
#         Weights: range=[0, 1], mean=0.734681, std=0.426758
#         Features: none

# %%
# Weighted
rw_weighted_patient_bidirect = BiasedRandomWalk(G_weighted_patient_bidirect)

# %%
# Weighted
weighted_walks_patient_bidirect = rw_weighted_patient_bidirect.run(
    nodes=G_weighted_patient_bidirect.nodes(),  # root nodes
    length=100,  # maximum length of a random walk
    n=10,  # number of random walks per root node
    p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
    q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
#     weighted=True,  # for weighted random walks
    seed=42,  # random seed fixed for reproducibility
)
print("Number of random walks: {}".format(len(weighted_walks_patient_bidirect)))
# Out:
# Number of random walks: 6330

# %%
print(weighted_walks_patient_bidirect[0])
# Out:
# ['news', 'morgu', 'declin', 'doen', 'declin', 'levoph', 'death', 'ferrou', 'trazodon', 'bromid', 'opiat', 'deterior', 'asthma', 'sluggish', 'bipolar', 'osa', 'knowledg', 'pleasant', 'vagu', 'hilum', 'habitu', 'anaphylaxi', 'impli', 'anaphylaxi', 'ultrafiltr', 'cocain', 'ppd', 'ultrafiltr', 'clonidin', 'nifedipin', 'lat', 'qtc', 'retic', 'hilum', 'dni', 'nitroglycerin', 'cocain', 'anaphylaxi', 'norepinephrin', 'dic', 'ggt', 'ctx', 'levoph', 'cardiovert', 'pitressin', 'neosynephrin', 'neo', 'lotion', 'ctx', 'metoclopramid', 'osa', 'ipf', 'fu', 'ipf', 'dni', 'pericard', 'platelet', 'ration', 'platelet', 'ration', 'profound', 'gait', 'sweat', 'syncop', 'sweat', 'fatti', 'sweat', 'hsq', 'young', 'asthma', 'cash', 'xl', 'mellitu', 'profound', 'thiamin', 'habitu', 'cocain', 'levoph', 'uri', 'dni', 'iddm', 'lat', 'ppd', 'vagu', 'influenc', 'gabapentin', 'sweat', 'dni', 'dnr', 'fungemia', 'fibrinogen', 'acidot', 'platelet', 'commod', 'incent', 'robitussin', 'dni', 'lat', 'dz', 'abnl']

# %%
# Weighted
weighted_model_patient = Word2Vec(
    weighted_walks_patient_bidirect, size=128, window=5, min_count=0, sg=1, workers=4, iter=1
)

# %%
# Weighted
emb = weighted_model_patient.wv["cmo"]
emb
# Out:
# array([ 3.57202142e-02, -8.53736047e-03,  7.85924494e-02, -2.50445575e-01,
#        -2.14620754e-01,  9.52819288e-02,  9.94194672e-02,  8.71900991e-02,
#         5.56090362e-02,  3.06516856e-01, -1.00073695e-01,  3.88583302e-01,
#        -1.88541990e-02, -7.51716197e-02,  8.01729634e-02, -9.03299972e-02,
#        -5.85361943e-02, -3.13977599e-02, -9.91175100e-02,  6.51407018e-02,
#         2.68568695e-01, -3.96300294e-02,  2.53958762e-01,  1.23335905e-01,
#        -4.74533230e-01,  1.49200112e-01,  3.55773345e-02, -3.49043161e-01,
#         2.36195046e-02,  1.60133570e-01, -1.88516870e-01, -1.36292772e-02,
#         2.17825994e-02,  1.44287691e-01,  1.35808170e-01,  4.10367638e-01,
#        -2.06842735e-01, -4.51475978e-02, -4.50129574e-03, -1.13101013e-03,
#        -6.41504973e-02, -1.72416121e-01, -1.28408208e-01, -1.07585164e-02,
#        -3.31019051e-02,  2.67259985e-01,  3.87493908e-01, -6.26284555e-02,
#         6.28070384e-02,  4.90730666e-02,  6.24985620e-02,  3.07914108e-01,
#        -7.64955580e-02, -6.34806454e-02,  1.46762043e-01, -5.34476697e-01,
#        -4.07074615e-02, -1.22860618e-01,  2.36988381e-01,  1.59490421e-01,
#         6.99801603e-03, -3.50644827e-01, -2.79840529e-01,  2.96343386e-01,
#         7.33384341e-02,  1.00849018e-01, -1.31652042e-01,  1.51422679e-01,
#         2.77134538e-01,  1.69479579e-01, -5.99319749e-02, -4.92701888e-01,
#        -4.49393064e-01,  1.11693434e-01,  1.01535626e-01,  3.70487362e-01,
#         1.32499784e-01,  3.23644280e-01, -3.67539167e-01, -2.18359455e-02,
#         3.07378858e-01,  1.47027731e-01, -2.55842060e-01,  3.26290756e-01,
#        -2.42107898e-01, -2.65953019e-02,  1.66090727e-01,  3.57441396e-01,
#        -6.47786483e-02,  3.72805983e-01,  1.95877720e-02, -2.54361153e-01,
#         4.13272858e-01, -7.52130598e-02, -1.76395848e-01,  5.18724442e-01,
#         2.06265464e-01,  4.49924404e-03,  8.45659897e-03, -9.10301059e-02,
#         4.50690538e-01,  3.21954072e-01,  9.14345831e-02, -1.05312347e-01,
#        -2.57535666e-01, -5.63853718e-02, -4.84693535e-02, -6.20564818e-02,
#        -1.23533323e-01,  7.38364533e-02,  5.87135293e-02, -4.54201922e-02,
#         2.34028958e-02, -1.41817611e-04, -2.00264320e-01, -4.89248991e-01,
#        -7.63408542e-02, -7.40320832e-02, -1.00562550e-01, -1.26097828e-01,
#        -1.27381980e-01, -1.01567760e-01, -1.11543894e-01,  4.70396459e-01,
#        -4.28797513e-01, -2.12890968e-01, -1.66419208e-01,  2.09589958e-01],
#       dtype=float32)

# %% [markdown]
# ### Visualise Node Embeddings generated by weighted random walks

# %% [markdown]
# ### Weighted edges

# %%
# Retrieve node embeddings and corresponding subjects
patient_weighted_node_ids = weighted_model_patient.wv.index2word  # list of node IDs
patient_weighted_node_embeddings = (
    weighted_model_patient.wv.vectors
)  # numpy.ndarray of size number of nodes times embeddings dimensionality
# the gensim ordering may not match the StellarGraph one, so rearrange
patient_node_targets = patient_subjects.loc[patient_weighted_node_ids].astype("category")

# %%
# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2, random_state=42)
patient_weighted_node_embeddings_2d = tsne.fit_transform(patient_weighted_node_embeddings)

# %%
# draw the points
alpha = 0.7

plt.figure(figsize=(10, 8))
plt.scatter(
    patient_weighted_node_embeddings_2d[:, 0],
    patient_weighted_node_embeddings_2d[:, 1],
    c=patient_node_targets.cat.codes,
    cmap="jet",
    alpha=0.7,
)
plt.show()

# %%
patient_weighted_node_emb_dict = {}
for index, row in patient_square_node_data_no_feature.iterrows():
    if index not in patient_weighted_node_emb_dict:
        patient_weighted_node_emb_dict[index] = weighted_model_patient.wv[index]
    else:
        print(f"index: {index} is already in a dictionary!")

# %%
# print(type(patient_weighted_node_emb_dict['aprv']))

# %%
import pandas as pd
import numpy as np

import stellargraph as sg
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import GCNSupervisedGraphClassification
from stellargraph import StellarGraph

from stellargraph import datasets

from sklearn import model_selection
from IPython.display import display, HTML

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import matplotlib.pyplot as plt

seed = 42
numpy.random.seed(seed)
tf.random.set_seed(seed)
sg.random.set_seed(seed)

# %% [markdown]
# ### Load the data

# %%
from collections import defaultdict

def create_graph_list(patient_cooc_dict, cooc_odd_scores, node_emb_dict, label):
    
    graphs = []
    labels = []
    
    for key,row in patient_cooc_dict.items():
     
        if row:
            source = []
            target = []
            edge_weight = []
            
            node_feature = []
            node_idx = []
            for cooc in row:
                source.extend([cooc[0], cooc[1]])
                target.extend([cooc[1], cooc[0]])
                edge_weight.extend([cooc_odd_scores[cooc], cooc_odd_scores[cooc]])
        
            node_idx = list(set(source + target))
    
            # Create a dataframe of only nodes
            square_node_data = pd.DataFrame(
                index=node_idx)
            
#             square_node_data['feature'] = [1] * len(node_idx)
        
            # Create a dictionary for each column for a vector
            node_features = defaultdict(list)
            for node in node_idx:
                for i, vec in enumerate(node_emb_dict[node]):
                    node_features['w_' + str(i)].append(vec)
        
            # Add columns to a dataframe
            for k, v in node_features.items():
              
                square_node_data[k] = v

            square_edges = pd.DataFrame({ 
                "source": source, 
                "target": target, 
                "weight":edge_weight
            })
        
            square = StellarGraph({"corner": square_node_data}, {"line": square_edges})
            graphs.append(square)
            labels.append(label)
            
    return graphs, labels

graphs = []
labels = []

# patient_weighted_node_emb_dict
graph_0, label_0 = create_graph_list(patient_cooc_0, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, -1)
graph_1, label_1 = create_graph_list(patient_cooc_1, new_patient_cooc_odd_scores, patient_weighted_node_emb_dict, 1)

graphs.extend(graph_0)
labels.extend(label_0)
print(f"graphs_0: {len(graphs)}, labels_0: {len(labels)}")
graphs.extend(graph_1)
labels.extend(label_1)
print(f"graphs_1: {len(graph_1)}, labels_1: {len(label_1)}")
print(f"graphs: {len(graphs)}, labels: {len(labels)}")
# Out:
# graphs_0: 162, labels_0: 162
# graphs_1: 726, labels_1: 726
# graphs: 888, labels: 888

# %%
# prepare test and train datasets
test_cnt = int(len(graphs)*0.1)/2
print(test_cnt)

pos_start = len(graph_0)
print(pos_start)

test_arr = []
train_arr = []
for i, v in enumerate(graphs):
    # Take first items for neg set
    if i < test_cnt:
        test_arr.append(i)    
    elif i > pos_start and i <= pos_start + test_cnt:
        test_arr.append(i)    
    else:
        train_arr.append(i)
# Out:
# 44.0
# 162

# %%
import random
seed = 42
c = list(test_arr)
random.Random(seed).shuffle(c)
test_arr =  c

# %%
c = list(train_arr)
random.Random(seed).shuffle(c)
train_arr =  c

# %%
train_index = np.array(train_arr)
test_index = np.array(test_arr)

# %%
print(len(test_index))
print(test_index)
# Out:
# 88
# [178 182  33  30  19  26 165 187  15 185  42   1 195 179 175  37 186  36
#  171 164 192  20 202   8  41 198  40 177  32 174  39 205  43 196  12  23
#   18 189 169 168   7  34 190   2  16  38 166  22 180  24   5   6 184 181
#  199   9 206  21 191 163  10 170 167   0 203 176 201 172  25 193 183  29
#   27 197 204   4 173 194  11 188  13  17  28  31  35   3  14 200]

# %% [markdown]
# 78
# [154 155 159   8 158 175  33  15 168 160 174 157 147 181 163  23  25   7
#  167 164  36  18 172  19  20 149  30 169 165 173 150 170   2  16 166  22
#  146  24   5   6 153 178   9 156  21 171 162  10   0 179  37 180 184  26
#   34 151 148 152  12 182   1  38  32  29  27 177 183   4 161  11 176  13
#   17  28  31  35   3  14]

# %%
print(len(train_index))
print(train_index)
# Out:
# 800
# [820 462 661 578 735 619 446 737 538 861 583 732 876 425  68 879 265 466
#  428 149 486 132 703 509 288 289 577 319 327 464 108 822 818 317 632 700
#  598 324 719 767 309 532 587 819 417 368 390 279 489 404 122 300 762 471
#  824 479 744 838 389 238 626  80 690 273 260 268 136  53 445  94 551 118
#  754  57 826 262 857 627 490 539 365 353 447 663 408 716 320 870 522 444
#  791 595 301 728 777 335  52 442  72 835 734 485 582 611 413  54 675 473
#  510 352 693 261 492 725 741 350 714 102 671 565 860  77 525  67 610 154
#   61 286 775 695 569 678 665 250  86 814 351 236 670 812 638 789 519 568
#  399 502 225 592 457 813 505 677 608 602 329  49 237 649 360 474 623 808
#  207 497 128 684 755  60 590  83 325 394 469 381 615 226 783 129 666 766
#  800 837 752 276 694 571 212 540 790 749 564 481 344 491 278  84 421 228
#  463 217 272 337 511 281 844 240 697 403 452 739 315 866 705  75 378 480
#  850 162 220 727 763  89 100 723 287 864 400 589 280 881 483 398 630 736
#  339 664 573 883 531 555  93 235 545 560 150 518 465 636 776 423 443 804
#  798 852 537 145 159 544 576 488 259 527  87 130 621 395 535 356 612 815
#  252 382 453 770 243 594 295 606 874 603 303 720 707 239 575 794 297 604
#  534 512 107 657 409 415 460 456 625 682 354 713 396 484 218 141 383 285
#  761 349 868 554 264 601 722 549 647 773 385 438 591 507  58 873 781 548
#  618 563 416 530 768 613 292 142 495 708 160 718 267 672 146 157 328 709
#  283 643 816 224 859 556 298 745 135  56 299 134 127 209 503 644 296 374
#  269  96 515 832 437 499 271 887 274 245 674 676 845 119 831 562 528  62
#  367 120 441  82 786 516 375 616 449 370 314 807 126 222 414 110 620  45
#   66 757 688 494  91  70 696 795 346 645 412 439 771 797 839 151 397 232
#  227 123 513 468  98 726 827 112  97 427 796 371 506 429 542 836 422 501
#  401 242 448 366 514 758 710 233 277 213 581 266 680 729 347 153 363 829
#  624 376 406 546  48  81 472 559 667 241 418 431 877 290 656 210 597 454
#  430 843 221 750 355 377 386 424 805 584 405  64 681 817 214 379 543 570
#  105 294 208 648 433  78 392  79 622 523  85 348 579 596 712 756 524 834
#  740 332 387 885  73 248 683 641 865 310 391 635 246 586 858 380 553 854
#  487  46 792 256 702 782 306 580 659 652 258 330 869  59  95 642 541 121
#  343 793 660 275 748 231 855 651 823 342 155 435 500 106 144  99 566 508
#  689 450 529 840 140 282 504 673 336 572 223 687 307 699 373 331 614 669
#  426 784 113 785 104 116  51 856 323 655  65 434 772 318 341 211 550 617
#  536 717 760 407 293 715 779 521 628 769 257 650 574 219 216 633 114 585
#  131 830 778 334 103 333 402 459 733  63 588 419 701  44 631 640 253 470
#  801 862 799 724 393 152 607 270 600 764  47 811 249 533 828 886 848 803
#  833 161  55 654 345 629 567 747 478 482 109 698 849 851 730 244 156  92
#  137 593 609 229 788 825 496 685 526 686 357 639 863 340 880 359 234 557
#  746 493 599 759 305 410 668 304 111 362 498 411 871 322 101 420 312 658
#  743 364 476 561 255 882 634 263 810 711 117 751 787 361 774 302 451 467
#  254 461 738 552 884 841 147 867 125 384 321 765  90 115 809 284 679 458
#  721 731 388 653 124 475 215 637 558  88 358 706 440 455 143 477 138 878
#  432 308 247 853 436 872 802 251  50 372 691 547 313 517 875 806 753 821
#  291 662  71 704 605 326 311 139  74  76 520 692 133 646 846 780 148 842
#  230 316 338 369 847  69 158 742]

# %% [markdown]
# 709
# [461 734 405 329 689 489 140 646 228 300  54 610 517 480  55 726  52 358
#  113 432 502  67 664  78 417 653 576 603 287 258 464 341  44 705 125 544
#  435 384 745 447 484 236 406 690 342 221 269 433 139  53 380 254 667 462
#  309 250 418 715  63 634 725 626 665 252 661 299  41 144 470 437 574 635
#  605 654 633 364 500  47 388 716 265 688 645 758  49 593 714  81 662 747
#   75 343 193 290 514 278 291 563 333 350 545 655  72 604 459 475 368 494
#  659 334 240 103 131 270 117 210 339 135  79 728 775 539 481 700 216 399
#   97 276 102 477 196 722  95 641 438 419 227 505 518 704 778 263 145 340
#  687 553 101 297 756 503 285 381 522 768  62 562 617 657 371  82 375 598
#  631 398 456 197 404 706 386 315 515 413 731 255 394 218 268 116 601 579
#  740 332 495 271 436 569 592 393 736 428 786 531 742 638 561 207 379 650
#  695 615 781 751 482 527  56 188 541 530 249 266 458 262 402 625 469 490
#  632 305 363 656 372 570 225 431 319 497 233 607 471 279 720 127 493 230
#  560  48 429 226  84 389 559 478 759 346 513 215 293 552 344 208 242 776
#  543 275 325 427 606 246 282 686 498 628 194 637 257 671 141 191 318 680
#  273 549 723 214 640 616 390 130  51 289 129 122 521 407 533 566  91 538
#  403 261 649 264 235 600 602 567 114 385 425  57 357 115 536 699 499 365
#  296 360 535 121 212 105 248 613  61 672 504 524  65 618 707 336 528 453
#  709 185 387 222 217 496 568  93 708 763 107  92 443 361 439 741 558 391
#  232 356 673 501 223 267 203 474 256 446 582 337 532 353 440  90 366 396
#  442  43  76 455 594 231 660 421 670 280 509 200 609 444 587 748 211 702
#  345 367 376 414 713 476 395  59 473 534 204 369 100 554 198 423  73 382
#   74 771  80 338 485 622 614 691 322 377 580 492 238 608 555 355 454 724
#   68 189 229 546 118 327 744 591 719 761 452 434 647 685 310 508 620 213
#  277  40 272 123 772 611 585 623 586 572 124 199 512 463  86 639 506 584
#  411 784 581 783 677 550 573 304  77 525 739 314 588 729 565 727 307 767
#  571 137 737  94 519 487 251 450 284  70  89 408 412 749 766 717 520 317
#  288 612 259 750 415  88 668 136 286 491 577 479 202 320 373 370 529 556
#  674 693 703 187 326 420 683 321 596 416 697 108 698  99 111  46 760 313
#   60 424 663 308 331 201 540 526 762 678 397 283 692 511 684 247 564 209
#  206 109 575 126 735 324  98 323 392 449 651  58 578 409  39 621 630 243
#  460 666 764 642 383 186 597 260 590 679  42 718 239 523 733 785 753 712
#  738 195  50 644 335 619 557 468 472 104 754 755 234 190  87 132 583 599
#  219 710 730 486 675 516 676 347 629 765 330 780 349 224 547 483 589 295
#  400 658 294 106 352 488 401 773 312  96 410 302 648 354 466 551 245 782
#  624 253 701 112 351 292 441 457 244 451 542 752 746 142 769 120 374 311
#   85 110 274 669 448 711 721 378 643 119 465 205 627 548  83 348 696 430
#  445 138 467 133 779 422 298 237 757 426 774 241  45 362 681 537 303 507
#  777 743 281 652  66 694 595 316 301 134  69  71 510 682 128 636 770 143
#  220 306 328 359  64 192 732]

# %%
print(graphs[0].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 18, Edges: 212
#
#  Node types:
#   corner: [18]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [212]
#         Weights: range=[0, 0.788597], mean=0.0526238, std=0.175607
#         Features: none

# %%
print(graphs[100].info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 11, Edges: 76
#
#  Node types:
#   corner: [11]
#     Features: float32 vector, length 128
#     Edge types: corner-line->corner
#
#  Edge types:
#     corner-line->corner: [76]
#         Weights: range=[0, 0.552589], mean=0.214523, std=0.219258
#         Features: none

# %%
summary = pd.DataFrame(
    [(g.number_of_nodes(), g.number_of_edges()) for g in graphs],
    columns=["nodes", "edges"],
)
summary.describe().round(1)
# Out:
#        nodes  edges
# count  888.0  888.0
# mean     5.6   22.4
# std      3.7   33.8
# min      2.0    2.0
# 25%      2.0    2.0
# 50%      5.0    8.0
# 75%      8.0   26.0
# max     23.0  272.0

# %%
graph_labels = pd.Series(labels)

# %%
print(graph_labels)
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 883    1
# 884    1
# 885    1
# 886    1
# 887    1
# Length: 888, dtype: int64

# %%
graph_labels.value_counts().to_frame()
# Out:
#       0
#  1  726
# -1  162

# %%
graph_labels = pd.get_dummies(graph_labels, drop_first=True)

# %%
print(type(graph_labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
graph_labels
# Out:
#      1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 883  1
# 884  1
# 885  1
# 886  1
# 887  1
#
# [888 rows x 1 columns]

# %%
generator = PaddedGraphGenerator(graphs=graphs)

# %%
def create_graph_classification_model(generator):
    gc_model = GCNSupervisedGraphClassification(
        layer_sizes=[64, 64],
        activations=["relu", "relu"],
        generator=generator,
        dropout=0.5,
    )
    x_inp, x_out = gc_model.in_out_tensors()
    predictions = Dense(units=32, activation="relu")(x_out)
    predictions = Dense(units=16, activation="relu")(predictions)
    predictions = Dense(units=1, activation="sigmoid")(predictions)

    # Let's create the Keras model and prepare it for training
    model = Model(inputs=x_inp, outputs=predictions)
    model.compile(optimizer=Adam(0.005), loss=binary_crossentropy, metrics=["acc"])

    return model

# %%
epochs = 200  # maximum number of training epochs
# folds = 10  # the number of folds for k-fold cross validation
# n_repeats = 5  # the number of repeats for repeated k-fold cross validation

# %%
es = EarlyStopping(
    monitor="val_loss", min_delta=0, patience=25, restore_best_weights=True
)

# %%
# To train in folds
def train_fold(model, train_gen, test_gen, es, epochs):
    history = model.fit(
        train_gen, epochs=epochs, validation_data=test_gen, verbose=0, callbacks=[es],
    )
    # calculate performance on the test data and return along with history
    test_metrics = model.evaluate(test_gen, verbose=0)
    test_acc = test_metrics[model.metrics_names.index("acc")]

    return history, test_acc

# %%
# To train in folds
def get_generators(train_index, test_index, graph_labels, batch_size):
    train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, batch_size=batch_size, shuffle=False, seed=42
    )
    test_gen = generator.flow(
        test_index, targets=graph_labels.iloc[test_index].values, batch_size=batch_size, shuffle=False, seed=42
    )

    return train_gen, test_gen

# %%
# # To train in folds
# test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"Training and evaluating on fold {i+1} out of {folds * n_repeats}...")
#     train_gen, test_gen = get_generators(
#         train_index, test_index, graph_labels, batch_size=30
#     )

#     model = create_graph_classification_model(generator)

#     history, acc = train_fold(model, train_gen, test_gen, es, epochs)

#     test_accs.append(acc)

# %%
# To train in folds
test_accs = []

# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
for i in range(50):
    print(f"Training and evaluating on fold {i+1}...")
    
    train_gen, test_gen = get_generators(
        train_index, test_index, graph_labels, batch_size=30
    )

    model = create_graph_classification_model(generator)

    history, acc = train_fold(model, train_gen, test_gen, es, epochs)

    test_accs.append(acc)
# Out:
# Training and evaluating on fold 1...
# Training and evaluating on fold 2...
# Training and evaluating on fold 3...
# Training and evaluating on fold 4...
# Training and evaluating on fold 5...
# Training and evaluating on fold 6...
# Training and evaluating on fold 7...
# Training and evaluating on fold 8...
# Training and evaluating on fold 9...
# Training and evaluating on fold 10...
# Training and evaluating on fold 11...
# Training and evaluating on fold 12...
# Training and evaluating on fold 13...
# Training and evaluating on fold 14...
# Training and evaluating on fold 15...
# Training and evaluating on fold 16...
# Training and evaluating on fold 17...
# Training and evaluating on fold 18...
# Training and evaluating on fold 19...
# Training and evaluating on fold 20...
# Training and evaluating on fold 21...
# Training and evaluating on fold 22...
# Training and evaluating on fold 23...
# Training and evaluating on fold 24...
# Training and evaluating on fold 25...
# Training and evaluating on fold 26...
# Training and evaluating on fold 27...
# Training and evaluating on fold 28...
# Training and evaluating on fold 29...
# Training and evaluating on fold 30...
# Training and evaluating on fold 31...
# Training and evaluating on fold 32...
# Training and evaluating on fold 33...
# Training and evaluating on fold 34...
# Training and evaluating on fold 35...
# Training and evaluating on fold 36...
# Training and evaluating on fold 37...
# Training and evaluating on fold 38...
# Training and evaluating on fold 39...
# Training and evaluating on fold 40...
# Training and evaluating on fold 41...
# Training and evaluating on fold 42...
# Training and evaluating on fold 43...
# Training and evaluating on fold 44...
# Training and evaluating on fold 45...
# Training and evaluating on fold 46...
# Training and evaluating on fold 47...
# Training and evaluating on fold 48...
# Training and evaluating on fold 49...
# Training and evaluating on fold 50...

# %%
# 1: Accuracy over all folds mean: 78.4% and std: 1.8%
# 2: Accuracy over all folds mean: 79.7% and std: 1.9%
# 3: Accuracy over all folds mean: 78.7% and std: 2.0%
# 4: Accuracy over all folds mean: 78.3% and std: 1.8%
# 5: Accuracy over all folds mean: 79.2% and std: 2.0%

# -----------------After setting random
# 1: Accuracy over all folds mean: 79.9% and std: 1.9%
# 2: Accuracy over all folds mean: 80.1% and std: 1.8%
# 3: Accuracy over all folds mean: 78.5% and std: 1.6%
# 4: Accuracy over all folds mean: 77.3% and std: 1.9%
# 5: Accuracy over all folds mean: 77.5% and std: 2.0%
# 6: Accuracy over all folds mean: 79.3% and std: 2.3%
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 79.7% and std: 2.4%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
print(
    f"Accuracy over all folds mean: {np.mean(test_accs)*100:.3}% and std: {np.std(test_accs)*100:.2}%"
)
# Out:
# Accuracy over all folds mean: 76.6% and std: 2.0%

# %%
plt.figure(figsize=(8, 6))
plt.hist(test_accs)
plt.xlabel("Accuracy")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# stratified_folds = model_selection.RepeatedStratifiedKFold(
#     n_splits=folds, n_repeats=n_repeats
# ).split(graph_labels, graph_labels)

# for i, (train_index, test_index) in enumerate(stratified_folds):
#     print(f"\ntrain_index: \n{train_index}\ntest_index: \n{test_index}\n")
#     break
# print(f"train: {len(train_index)}, test: {len(test_index)}")

# %%
train_gen = generator.flow(
        train_index, targets=graph_labels.iloc[train_index].values, batch_size=40, shuffle=False, seed=42)
test_gen = generator.flow(
    test_index, targets=graph_labels.iloc[test_index].values, batch_size=40, shuffle=False, seed=42)

# %%
model_weighted = create_graph_classification_model(generator)

history = model_weighted.fit(
        train_gen, epochs=200, validation_data=test_gen, verbose=1, callbacks=[es])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 77ms/step - loss: 0.4545 - acc: 0.8124 - val_loss: 0.6831 - val_acc: 0.5000
# Epoch 2/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3787 - acc: 0.8505 - val_loss: 0.6394 - val_acc: 0.5000
# Epoch 3/200
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3466 - acc: 0.8519 - val_loss: 0.5799 - val_acc: 0.5769
# Epoch 4/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3435 - acc: 0.8590 - val_loss: 0.5773 - val_acc: 0.6795
# Epoch 5/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.3203 - acc: 0.8688 - val_loss: 0.6534 - val_acc: 0.6667
# Epoch 6/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.3344 - acc: 0.8590 - val_loss: 0.5594 - val_acc: 0.7179
# Epoch 7/200
# 18/18 [==============================] - 1s 37ms/step - loss: 0.3305 - acc: 0.8731 - val_loss: 0.5513 - val_acc: 0.7051
# Epoch 8/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.3165 - acc: 0.8759 - val_loss: 0.5025 - val_acc: 0.7821
# Epoch 9/200
# 18/18 [==============================] - 1s 43ms/step - loss: 0.3068 - acc: 0.8759 - val_loss: 0.5402 - val_acc: 0.7308
# Epoch 10/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3061 - acc: 0.8815 - val_loss: 0.6015 - val_acc: 0.6795
# Epoch 11/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.3211 - acc: 0.8801 - val_loss: 0.5629 - val_acc: 0.7436
# Epoch 12/200
# 18/18 [==============================] - 1s 38ms/step - loss: 0.3113 - acc: 0.8787 - val_loss: 0.5380 - val_acc: 0.6795
# Epoch 13/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2988 - acc: 0.8829 - val_loss: 0.5589 - val_acc: 0.7436
# Epoch 14/200
# 18/18 [==============================] - 1s 45ms/step - loss: 0.2867 - acc: 0.8773 - val_loss: 0.4789 - val_acc: 0.7564
# Epoch 15/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2932 - acc: 0.8829 - val_loss: 0.5177 - val_acc: 0.7821
# Epoch 16/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2699 - acc: 0.8872 - val_loss: 0.4517 - val_acc: 0.7949
# Epoch 17/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2955 - acc: 0.8843 - val_loss: 0.4657 - val_acc: 0.7692
# Epoch 18/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2963 - acc: 0.8886 - val_loss: 0.4670 - val_acc: 0.7692
# Epoch 19/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2709 - acc: 0.8984 - val_loss: 0.5247 - val_acc: 0.7564
# Epoch 20/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2815 - acc: 0.8886 - val_loss: 0.6811 - val_acc: 0.6410
# Epoch 21/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2908 - acc: 0.8914 - val_loss: 0.6899 - val_acc: 0.6923
# Epoch 22/200
# 18/18 [==============================] - 1s 42ms/step - loss: 0.2949 - acc: 0.8801 - val_loss: 0.6158 - val_acc: 0.7436
# Epoch 23/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2782 - acc: 0.8914 - val_loss: 0.5815 - val_acc: 0.7179
# Epoch 24/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2888 - acc: 0.8858 - val_loss: 0.5642 - val_acc: 0.6795
# Epoch 25/200
# 18/18 [==============================] - 1s 40ms/step - loss: 0.2613 - acc: 0.8928 - val_loss: 0.4942 - val_acc: 0.7564
# Epoch 26/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2741 - acc: 0.8886 - val_loss: 0.5232 - val_acc: 0.7308
# Epoch 27/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2665 - acc: 0.8914 - val_loss: 0.7339 - val_acc: 0.6923
# Epoch 28/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2651 - acc: 0.8956 - val_loss: 0.5083 - val_acc: 0.7179
# Epoch 29/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2389 - acc: 0.8970 - val_loss: 0.6075 - val_acc: 0.7179
# Epoch 30/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2714 - acc: 0.9041 - val_loss: 0.6651 - val_acc: 0.6923
# Epoch 31/200
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2547 - acc: 0.8858 - val_loss: 0.4895 - val_acc: 0.7564
# Epoch 32/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2864 - acc: 0.8858 - val_loss: 0.4942 - val_acc: 0.7436
# Epoch 33/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2507 - acc: 0.8872 - val_loss: 0.6530 - val_acc: 0.7179
# Epoch 34/200
# 18/18 [==============================] - 1s 36ms/step - loss: 0.2481 - acc: 0.8942 - val_loss: 0.6970 - val_acc: 0.6667
# Epoch 35/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2423 - acc: 0.9055 - val_loss: 0.5584 - val_acc: 0.7564
# Epoch 36/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2380 - acc: 0.9111 - val_loss: 1.0306 - val_acc: 0.5769
# Epoch 37/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2485 - acc: 0.8999 - val_loss: 0.6896 - val_acc: 0.6923
# Epoch 38/200
# 18/18 [==============================] - 1s 30ms/step - loss: 0.2622 - acc: 0.9027 - val_loss: 0.6254 - val_acc: 0.6667
# Epoch 39/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2390 - acc: 0.9027 - val_loss: 0.4496 - val_acc: 0.8077
# Epoch 40/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2670 - acc: 0.8942 - val_loss: 0.5748 - val_acc: 0.7179
# Epoch 41/200
# 18/18 [==============================] - 0s 27ms/step - loss: 0.2619 - acc: 0.8886 - val_loss: 0.6052 - val_acc: 0.7308
# Epoch 42/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2518 - acc: 0.8956 - val_loss: 0.5485 - val_acc: 0.7179
# Epoch 43/200
# 18/18 [==============================] - 0s 25ms/step - loss: 0.2429 - acc: 0.9069 - val_loss: 0.5876 - val_acc: 0.7051
# Epoch 44/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2291 - acc: 0.9154 - val_loss: 0.6344 - val_acc: 0.7051
# Epoch 45/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2546 - acc: 0.8942 - val_loss: 0.7019 - val_acc: 0.6795
# Epoch 46/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2357 - acc: 0.9083 - val_loss: 0.5528 - val_acc: 0.7564
# Epoch 47/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2447 - acc: 0.9041 - val_loss: 0.6164 - val_acc: 0.6923
# Epoch 48/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2270 - acc: 0.9140 - val_loss: 0.6715 - val_acc: 0.7179
# Epoch 49/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2085 - acc: 0.9252 - val_loss: 0.6481 - val_acc: 0.7179
# Epoch 50/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2148 - acc: 0.9111 - val_loss: 0.6449 - val_acc: 0.7051
# Epoch 51/200
# 18/18 [==============================] - 1s 36ms/step - loss: 0.2249 - acc: 0.9083 - val_loss: 0.6945 - val_acc: 0.7308
# Epoch 52/200
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2425 - acc: 0.9055 - val_loss: 0.5141 - val_acc: 0.7564
# Epoch 53/200
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2151 - acc: 0.9238 - val_loss: 0.5243 - val_acc: 0.7949
# Epoch 54/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2026 - acc: 0.9168 - val_loss: 0.6427 - val_acc: 0.7051
# Epoch 55/200
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2139 - acc: 0.9126 - val_loss: 0.7280 - val_acc: 0.7051
# Epoch 56/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2376 - acc: 0.9069 - val_loss: 0.6771 - val_acc: 0.6923
# Epoch 57/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2144 - acc: 0.9083 - val_loss: 0.6399 - val_acc: 0.7179
# Epoch 58/200
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2169 - acc: 0.9055 - val_loss: 0.6096 - val_acc: 0.7308
# Epoch 59/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2308 - acc: 0.9140 - val_loss: 0.5738 - val_acc: 0.7308
# Epoch 60/200
# 18/18 [==============================] - 1s 41ms/step - loss: 0.2379 - acc: 0.8970 - val_loss: 0.5135 - val_acc: 0.7692
# Epoch 61/200
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2295 - acc: 0.8984 - val_loss: 0.5606 - val_acc: 0.7949
# Epoch 62/200
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2455 - acc: 0.9041 - val_loss: 0.6577 - val_acc: 0.7179
# Epoch 63/200
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2195 - acc: 0.9238 - val_loss: 0.7046 - val_acc: 0.6667
# Epoch 64/200
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2218 - acc: 0.9224 - val_loss: 0.6804 - val_acc: 0.7308

# %%
# calculate performance on the test data and return along with history
# Node features 128 node2vec, edge features all 1
test_metrics = model_weighted.evaluate(test_gen, verbose=1)
test_acc = test_metrics[model_weighted.metrics_names.index("acc")]
# Out:
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4496 - acc: 0.8077

# %%
print(test_metrics)
#test loss, test acc: [0.4930313229560852, 0.7435897588729858]
# 2nd try: [0.49709418416023254, 0.7948718070983887]
# 3d [0.5272901654243469, 0.7435897588729858]
# 4: [0.4769172668457031, 0.7307692170143127]
print(test_acc)
# Out:
# [0.4495735168457031, 0.807692289352417]
# 0.807692289352417

# %%
print("Generate predictions for samples")
predictions = model_weighted.predict(test_gen, verbose=0)
print("predictions shape:", predictions.shape)
# predictions shape: (79, 1)
print(predictions)

# %%
print(test_gen.targets)
